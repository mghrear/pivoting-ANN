# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import torch 
from torch import nn, optim
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import sklearn
from sklearn.model_selection import train_test_split
import copy
import mytools


# Print and store device being used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cpu

# %% [markdown]
# # Define important parameters

# %%
# Number of class in invariant mass used by the adversary
Num_classes = 5
# Hyper-parameter for adversarial training of the classifier
lambda_ = 100.0

run = 1

# %% [markdown]
# # Load and setup the data

# %%
# Read tritrig, wab, phiKK, and data files
df_tritrig = pd.read_pickle('/Users/mghrear/data/ML_data/patch/2021_v9_pass5_TC_tritrig_limited.pk')
df_tritrig['PhiKK'] = 0.0
df_phiKK = pd.read_pickle('/Users/mghrear/data/ML_data/patch/2021_v9_pass5_TC_phiKK_limited.pk')
df_phiKK['PhiKK'] = 1.0
df_wab = pd.read_pickle('/Users/mghrear/data/ML_data/patch/2021_v9_pass5_TC_wab_limited.pk')
df_wab['PhiKK'] = 0.0 # Add label


print("tritrig: ", len(df_tritrig))
print("phiKK: ", len(df_phiKK))
print("wab: ", len(df_wab))
# Out:
# tritrig:  168949
# phiKK:  3571
# wab:  15066

# %%
# Make Training set with 20000 tritrig, 4000 phiKK, 4000 wab
tritrig_train = df_tritrig[0:20000]
wab_train = df_wab[0:3000]
phiKK_train = df_phiKK[0:3000]

# Combine and shuffle all training data
df_train = pd.concat([tritrig_train, phiKK_train, wab_train], ignore_index=True, sort=False)
df_train = df_train.sample(frac=1, random_state=42).reset_index(drop=True)

# Get edges in invariant mass classes for one-hot encoding
# To be used for adverserial labels
# The edges are chosen such that each bin has equal number of background events
one_hot_edges = mytools.get_one_hot_edges(mytools.get_InvM( pd.concat([df_tritrig, df_wab], ignore_index=True, sort=False) ), n_bins=Num_classes)

# Split the training data into training and validation sets
df_train, df_val = train_test_split(df_train, test_size=0.33, random_state=42)

# Make X and y for training and validation sets
# the adverserial network has its own labels
X_train = df_train.drop(columns=['PhiKK'])
y_train = df_train['PhiKK']
y_adv_train = mytools.get_adv_labels( mytools.get_InvM(df_train), one_hot_edges)
X_val = df_val.drop(columns=['PhiKK'])
y_val = df_val['PhiKK']
y_adv_val = mytools.get_adv_labels( mytools.get_InvM(df_val), one_hot_edges)

# Make testing set with remaining events
tritrig_test = df_tritrig[20000:]
tritrig_test['type']= 'tritrig'
wab_test = df_wab[3000:]
wab_test['type']= 'wab'
phiKK_test = df_phiKK[3000:]
phiKK_test['type']= 'phiKK'

df_test = pd.concat([tritrig_test, phiKK_test,wab_test], ignore_index=True, sort=False)
df_test = df_test.sample(frac=1, random_state=42).reset_index(drop=True) # Now shuffle the combined dataframe

X_test = df_test.drop(columns=['PhiKK','type'])
y_test = df_test['PhiKK']
y_adv_test = mytools.get_adv_labels( mytools.get_InvM(df_test), one_hot_edges)

df_test["InvM"] = mytools.get_InvM(df_test)
# Out:
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_64480/1157922432.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tritrig_test['type']= 'tritrig'
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_64480/1157922432.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wab_test['type']= 'wab'
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_64480/1157922432.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phiKK_test['type']= 'phiKK'

# %% [markdown]
# ## Setup dataloaders

# %%
bsize = 2000

# Convert to tensor dataset and dataloader
train_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy().astype(np.float32))  , torch.from_numpy(y_train.to_numpy().astype(np.float32)).unsqueeze(1)  )
train_loader = DataLoader(train_dataset, batch_size=bsize, shuffle=True)

val_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy().astype(np.float32))  , torch.from_numpy(y_val.to_numpy().astype(np.float32)).unsqueeze(1)  )
val_loader = DataLoader(val_dataset, batch_size=bsize, shuffle=True)

test_dataset = TensorDataset(torch.from_numpy(X_test.to_numpy().astype(np.float32)))
test_loader = DataLoader(test_dataset, batch_size=bsize, shuffle=False)

# %% [markdown]
# ## Initialize model, objective function, and optimizer

# %%
clas = mytools.Classifier(in_features=X_train.shape[1]).to(device)
criterion_clas = nn.BCEWithLogitsLoss()
optimizer_clas = optim.Adam(clas.parameters(), lr=1e-5)
scheduler_clas = torch.optim.lr_scheduler.ExponentialLR(optimizer_clas, gamma=0.9999)

# %% [markdown]
# ## Pre-train the classifier

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 10

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 2500
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train_clas(train_loader, clas, criterion_clas, optimizer_clas, scheduler_clas, device))
    Validation_losses = np.append(Validation_losses, mytools.validate_clas(val_loader, clas, criterion_clas, device))
    
    # Keep a running copy of the model with the lowest loss
    if Validation_losses[-1] == np.min(Validation_losses):
        final_classifier = copy.deepcopy(clas)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Training loss: 0.891228
# Validation loss: 0.733305
#
# Epoch 2
# -------------------------------
# Training loss: 0.864651
# Validation loss: 0.757455
#
# Epoch 3
# -------------------------------
# Training loss: 0.842376
# Validation loss: 0.768802
#
# Epoch 4
# -------------------------------
# Training loss: 0.828666
# Validation loss: 0.774154
#
# Epoch 5
# -------------------------------
# Training loss: 0.812596
# Validation loss: 0.778874
#
# Epoch 6
# -------------------------------
# Training loss: 0.799034
# Validation loss: 0.771872
#
# Epoch 7
# -------------------------------
# Training loss: 0.789777
# Validation loss: 0.765226
#
# Epoch 8
# -------------------------------
# Training loss: 0.785661
# Validation loss: 0.769574
#
# Epoch 9
# -------------------------------
# Training loss: 0.774699
# Validation loss: 0.769195
#
# Epoch 10
# -------------------------------
# Training loss: 0.767385
# Validation loss: 0.760271
#
# Epoch 11
# -------------------------------
# Training loss: 0.759095
# Validation loss: 0.749039
#
# Epoch 12
# -------------------------------
# Training loss: 0.753121
# Validation loss: 0.746385
#
# Epoch 13
# -------------------------------
# Training loss: 0.749140
# Validation loss: 0.739690
#
# Epoch 14
# -------------------------------
# Training loss: 0.741319
# Validation loss: 0.732518
#
# Epoch 15
# -------------------------------
# Training loss: 0.738387
# Validation loss: 0.725650
#
# Epoch 16
# -------------------------------
# Training loss: 0.730617
# Validation loss: 0.721761
#
# Epoch 17
# -------------------------------
# Training loss: 0.728366
# Validation loss: 0.720113
#
# Epoch 18
# -------------------------------
# Training loss: 0.722170
# Validation loss: 0.717032
#
# Epoch 19
# -------------------------------
# Training loss: 0.717417
# Validation loss: 0.708360
#
# Epoch 20
# -------------------------------
# Training loss: 0.711467
# Validation loss: 0.703940
#
# Epoch 21
# -------------------------------
# Training loss: 0.711259
# Validation loss: 0.710257
#
# Epoch 22
# -------------------------------
# Training loss: 0.704645
# Validation loss: 0.702982
#
# Epoch 23
# -------------------------------
# Training loss: 0.699340
# Validation loss: 0.697531
#
# Epoch 24
# -------------------------------
# Training loss: 0.695637
# Validation loss: 0.690552
#
# Epoch 25
# -------------------------------
# Training loss: 0.693598
# Validation loss: 0.690392
#
# Epoch 26
# -------------------------------
# Training loss: 0.686662
# Validation loss: 0.689446
#
# Epoch 27
# -------------------------------
# Training loss: 0.683069
# Validation loss: 0.689202
#
# Epoch 28
# -------------------------------
# Training loss: 0.681036
# Validation loss: 0.681640
#
# Epoch 29
# -------------------------------
# Training loss: 0.677509
# Validation loss: 0.669347
#
# Epoch 30
# -------------------------------
# Training loss: 0.673801
# Validation loss: 0.667768
#
# Epoch 31
# -------------------------------
# Training loss: 0.670946
# Validation loss: 0.669498
#
# Epoch 32
# -------------------------------
# Training loss: 0.666738
# Validation loss: 0.661072
#
# Epoch 33
# -------------------------------
# Training loss: 0.667057
# Validation loss: 0.661290
#
# Epoch 34
# -------------------------------
# Training loss: 0.661854
# Validation loss: 0.657478
#
# Epoch 35
# -------------------------------
# Training loss: 0.658410
# Validation loss: 0.653031
#
# Epoch 36
# -------------------------------
# Training loss: 0.658651
# Validation loss: 0.650632
#
# Epoch 37
# -------------------------------
# Training loss: 0.652921
# Validation loss: 0.647232
#
# Epoch 38
# -------------------------------
# Training loss: 0.653374
# Validation loss: 0.645024
#
# Epoch 39
# -------------------------------
# Training loss: 0.648442
# Validation loss: 0.641627
#
# Epoch 40
# -------------------------------
# Training loss: 0.646758
# Validation loss: 0.639098
#
# Epoch 41
# -------------------------------
# Training loss: 0.642919
# Validation loss: 0.637958
#
# Epoch 42
# -------------------------------
# Training loss: 0.654366
# Validation loss: 0.638516
#
# Epoch 43
# -------------------------------
# Training loss: 0.640123
# Validation loss: 0.642785
#
# Epoch 44
# -------------------------------
# Training loss: 0.639026
# Validation loss: 0.638640
#
# Epoch 45
# -------------------------------
# Training loss: 0.635163
# Validation loss: 0.632270
#
# Epoch 46
# -------------------------------
# Training loss: 0.632866
# Validation loss: 0.627381
#
# Epoch 47
# -------------------------------
# Training loss: 0.631480
# Validation loss: 0.631125
#
# Epoch 48
# -------------------------------
# Training loss: 0.626643
# Validation loss: 0.624251
#
# Epoch 49
# -------------------------------
# Training loss: 0.626663
# Validation loss: 0.622449
#
# Epoch 50
# -------------------------------
# Training loss: 0.626742
# Validation loss: 0.620116
#
# Epoch 51
# -------------------------------
# Training loss: 0.622640
# Validation loss: 0.624262
#
# Epoch 52
# -------------------------------
# Training loss: 0.620721
# Validation loss: 0.620721
#
# Epoch 53
# -------------------------------
# Training loss: 0.621975
# Validation loss: 0.621770
#
# Epoch 54
# -------------------------------
# Training loss: 0.617552
# Validation loss: 0.617126
#
# Epoch 55
# -------------------------------
# Training loss: 0.615923
# Validation loss: 0.618240
#
# Epoch 56
# -------------------------------
# Training loss: 0.615359
# Validation loss: 0.612386
#
# Epoch 57
# -------------------------------
# Training loss: 0.612700
# Validation loss: 0.616538
#
# Epoch 58
# -------------------------------
# Training loss: 0.610855
# Validation loss: 0.605243
#
# Epoch 59
# -------------------------------
# Training loss: 0.609356
# Validation loss: 0.612772
#
# Epoch 60
# -------------------------------
# Training loss: 0.607083
# Validation loss: 0.610283
#
# Epoch 61
# -------------------------------
# Training loss: 0.610948
# Validation loss: 0.602224
#
# Epoch 62
# -------------------------------
# Training loss: 0.605355
# Validation loss: 0.607265
#
# Epoch 63
# -------------------------------
# Training loss: 0.603540
# Validation loss: 0.603395
#
# Epoch 64
# -------------------------------
# Training loss: 0.603124
# Validation loss: 0.601899
#
# Epoch 65
# -------------------------------
# Training loss: 0.599586
# Validation loss: 0.601532
#
# Epoch 66
# -------------------------------
# Training loss: 0.600898
# Validation loss: 0.599449
#
# Epoch 67
# -------------------------------
# Training loss: 0.597180
# Validation loss: 0.601862
#
# Epoch 68
# -------------------------------
# Training loss: 0.596636
# Validation loss: 0.595385
#
# Epoch 69
# -------------------------------
# Training loss: 0.594227
# Validation loss: 0.597607
#
# Epoch 70
# -------------------------------
# Training loss: 0.592202
# Validation loss: 0.593474
#
# Epoch 71
# -------------------------------
# Training loss: 0.590777
# Validation loss: 0.596783
#
# Epoch 72
# -------------------------------
# Training loss: 0.590752
# Validation loss: 0.595448
#
# Epoch 73
# -------------------------------
# Training loss: 0.588727
# Validation loss: 0.589854
#
# Epoch 74
# -------------------------------
# Training loss: 0.586962
# Validation loss: 0.589313
#
# Epoch 75
# -------------------------------
# Training loss: 0.585924
# Validation loss: 0.588682
#
# Epoch 76
# -------------------------------
# Training loss: 0.588170
# Validation loss: 0.579775
#
# Epoch 77
# -------------------------------
# Training loss: 0.582791
# Validation loss: 0.581435
#
# Epoch 78
# -------------------------------
# Training loss: 0.581584
# Validation loss: 0.583070
#
# Epoch 79
# -------------------------------
# Training loss: 0.580846
# Validation loss: 0.578972
#
# Epoch 80
# -------------------------------
# Training loss: 0.579458
# Validation loss: 0.583235
#
# Epoch 81
# -------------------------------
# Training loss: 0.578277
# Validation loss: 0.582235
#
# Epoch 82
# -------------------------------
# Training loss: 0.578362
# Validation loss: 0.572100
#
# Epoch 83
# -------------------------------
# Training loss: 0.576600
# Validation loss: 0.574428
#
# Epoch 84
# -------------------------------
# Training loss: 0.574235
# Validation loss: 0.576247
#
# Epoch 85
# -------------------------------
# Training loss: 0.572192
# Validation loss: 0.569127
#
# Epoch 86
# -------------------------------
# Training loss: 0.572549
# Validation loss: 0.576237
#
# Epoch 87
# -------------------------------
# Training loss: 0.569651
# Validation loss: 0.572337
#
# Epoch 88
# -------------------------------
# Training loss: 0.571829
# Validation loss: 0.570798
#
# Epoch 89
# -------------------------------
# Training loss: 0.569592
# Validation loss: 0.570234
#
# Epoch 90
# -------------------------------
# Training loss: 0.568940
# Validation loss: 0.558528
#
# Epoch 91
# -------------------------------
# Training loss: 0.566136
# Validation loss: 0.567234
#
# Epoch 92
# -------------------------------
# Training loss: 0.565529
# Validation loss: 0.565515
#
# Epoch 93
# -------------------------------
# Training loss: 0.564373
# Validation loss: 0.568087
#
# Epoch 94
# -------------------------------
# Training loss: 0.563284
# Validation loss: 0.565296
#
# Epoch 95
# -------------------------------
# Training loss: 0.564525
# Validation loss: 0.559481
#
# Epoch 96
# -------------------------------
# Training loss: 0.560088
# Validation loss: 0.559156
#
# Epoch 97
# -------------------------------
# Training loss: 0.560143
# Validation loss: 0.564082
#
# Epoch 98
# -------------------------------
# Training loss: 0.558699
# Validation loss: 0.558095
#
# Epoch 99
# -------------------------------
# Training loss: 0.558054
# Validation loss: 0.560101
#
# Epoch 100
# -------------------------------
# Training loss: 0.556016
# Validation loss: 0.552870
#
# Epoch 101
# -------------------------------
# Training loss: 0.556459
# Validation loss: 0.557586
#
# Epoch 102
# -------------------------------
# Training loss: 0.553923
# Validation loss: 0.550946
#
# Epoch 103
# -------------------------------
# Training loss: 0.554876
# Validation loss: 0.550414
#
# Epoch 104
# -------------------------------
# Training loss: 0.551294
# Validation loss: 0.554775
#
# Epoch 105
# -------------------------------
# Training loss: 0.550239
# Validation loss: 0.554241
#
# Epoch 106
# -------------------------------
# Training loss: 0.551105
# Validation loss: 0.556447
#
# Epoch 107
# -------------------------------
# Training loss: 0.549624
# Validation loss: 0.546016
#
# Epoch 108
# -------------------------------
# Training loss: 0.548740
# Validation loss: 0.541830
#
# Epoch 109
# -------------------------------
# Training loss: 0.547728
# Validation loss: 0.550497
#
# Epoch 110
# -------------------------------
# Training loss: 0.544870
# Validation loss: 0.548210
#
# Epoch 111
# -------------------------------
# Training loss: 0.545392
# Validation loss: 0.548197
#
# Epoch 112
# -------------------------------
# Training loss: 0.544554
# Validation loss: 0.541719
#
# Epoch 113
# -------------------------------
# Training loss: 0.542385
# Validation loss: 0.548677
#
# Epoch 114
# -------------------------------
# Training loss: 0.541819
# Validation loss: 0.541770
#
# Epoch 115
# -------------------------------
# Training loss: 0.539910
# Validation loss: 0.541190
#
# Epoch 116
# -------------------------------
# Training loss: 0.540968
# Validation loss: 0.536886
#
# Epoch 117
# -------------------------------
# Training loss: 0.539337
# Validation loss: 0.534910
#
# Epoch 118
# -------------------------------
# Training loss: 0.540426
# Validation loss: 0.540988
#
# Epoch 119
# -------------------------------
# Training loss: 0.537741
# Validation loss: 0.533193
#
# Epoch 120
# -------------------------------
# Training loss: 0.536556
# Validation loss: 0.536171
#
# Epoch 121
# -------------------------------
# Training loss: 0.537582
# Validation loss: 0.533572
#
# Epoch 122
# -------------------------------
# Training loss: 0.534351
# Validation loss: 0.539246
#
# Epoch 123
# -------------------------------
# Training loss: 0.531908
# Validation loss: 0.531469
#
# Epoch 124
# -------------------------------
# Training loss: 0.533019
# Validation loss: 0.534236
#
# Epoch 125
# -------------------------------
# Training loss: 0.532075
# Validation loss: 0.535728
#
# Epoch 126
# -------------------------------
# Training loss: 0.531392
# Validation loss: 0.534684
#
# Epoch 127
# -------------------------------
# Training loss: 0.532557
# Validation loss: 0.529278
#
# Epoch 128
# -------------------------------
# Training loss: 0.529919
# Validation loss: 0.530745
#
# Epoch 129
# -------------------------------
# Training loss: 0.528644
# Validation loss: 0.530842
#
# Epoch 130
# -------------------------------
# Training loss: 0.526027
# Validation loss: 0.531616
#
# Epoch 131
# -------------------------------
# Training loss: 0.527876
# Validation loss: 0.526622
#
# Epoch 132
# -------------------------------
# Training loss: 0.525064
# Validation loss: 0.525241
#
# Epoch 133
# -------------------------------
# Training loss: 0.524498
# Validation loss: 0.523821
#
# Epoch 134
# -------------------------------
# Training loss: 0.525829
# Validation loss: 0.523517
#
# Epoch 135
# -------------------------------
# Training loss: 0.524848
# Validation loss: 0.523702
#
# Epoch 136
# -------------------------------
# Training loss: 0.524014
# Validation loss: 0.524170
#
# Epoch 137
# -------------------------------
# Training loss: 0.521419
# Validation loss: 0.520913
#
# Epoch 138
# -------------------------------
# Training loss: 0.522433
# Validation loss: 0.529033
#
# Epoch 139
# -------------------------------
# Training loss: 0.522949
# Validation loss: 0.522157
#
# Epoch 140
# -------------------------------
# Training loss: 0.520130
# Validation loss: 0.527056
#
# Epoch 141
# -------------------------------
# Training loss: 0.519634
# Validation loss: 0.512471
#
# Epoch 142
# -------------------------------
# Training loss: 0.517768
# Validation loss: 0.518153
#
# Epoch 143
# -------------------------------
# Training loss: 0.520211
# Validation loss: 0.514896
#
# Epoch 144
# -------------------------------
# Training loss: 0.519890
# Validation loss: 0.524079
#
# Epoch 145
# -------------------------------
# Training loss: 0.517843
# Validation loss: 0.513700
#
# Epoch 146
# -------------------------------
# Training loss: 0.512955
# Validation loss: 0.517927
#
# Epoch 147
# -------------------------------
# Training loss: 0.515543
# Validation loss: 0.516598
#
# Epoch 148
# -------------------------------
# Training loss: 0.511549
# Validation loss: 0.511999
#
# Epoch 149
# -------------------------------
# Training loss: 0.512313
# Validation loss: 0.513602
#
# Epoch 150
# -------------------------------
# Training loss: 0.511400
# Validation loss: 0.514702
#
# Epoch 151
# -------------------------------
# Training loss: 0.509195
# Validation loss: 0.513838
#
# Epoch 152
# -------------------------------
# Training loss: 0.509166
# Validation loss: 0.513064
#
# Epoch 153
# -------------------------------
# Training loss: 0.509495
# Validation loss: 0.506843
#
# Epoch 154
# -------------------------------
# Training loss: 0.507747
# Validation loss: 0.508617
#
# Epoch 155
# -------------------------------
# Training loss: 0.506024
# Validation loss: 0.504267
#
# Epoch 156
# -------------------------------
# Training loss: 0.505742
# Validation loss: 0.507513
#
# Epoch 157
# -------------------------------
# Training loss: 0.507918
# Validation loss: 0.507981
#
# Epoch 158
# -------------------------------
# Training loss: 0.504685
# Validation loss: 0.501728
#
# Epoch 159
# -------------------------------
# Training loss: 0.506425
# Validation loss: 0.509653
#
# Epoch 160
# -------------------------------
# Training loss: 0.504689
# Validation loss: 0.503583
#
# Epoch 161
# -------------------------------
# Training loss: 0.504005
# Validation loss: 0.498684
#
# Epoch 162
# -------------------------------
# Training loss: 0.502823
# Validation loss: 0.502114
#
# Epoch 163
# -------------------------------
# Training loss: 0.501976
# Validation loss: 0.500819
#
# Epoch 164
# -------------------------------
# Training loss: 0.500490
# Validation loss: 0.500615
#
# Epoch 165
# -------------------------------
# Training loss: 0.502835
# Validation loss: 0.502561
#
# Epoch 166
# -------------------------------
# Training loss: 0.500463
# Validation loss: 0.500520
#
# Epoch 167
# -------------------------------
# Training loss: 0.498094
# Validation loss: 0.496244
#
# Epoch 168
# -------------------------------
# Training loss: 0.499238
# Validation loss: 0.502680
#
# Epoch 169
# -------------------------------
# Training loss: 0.497352
# Validation loss: 0.495379
#
# Epoch 170
# -------------------------------
# Training loss: 0.498767
# Validation loss: 0.498422
#
# Epoch 171
# -------------------------------
# Training loss: 0.496361
# Validation loss: 0.498112
#
# Epoch 172
# -------------------------------
# Training loss: 0.496073
# Validation loss: 0.490558
#
# Epoch 173
# -------------------------------
# Training loss: 0.496633
# Validation loss: 0.494170
#
# Epoch 174
# -------------------------------
# Training loss: 0.494446
# Validation loss: 0.497336
#
# Epoch 175
# -------------------------------
# Training loss: 0.493130
# Validation loss: 0.494914
#
# Epoch 176
# -------------------------------
# Training loss: 0.491428
# Validation loss: 0.496291
#
# Epoch 177
# -------------------------------
# Training loss: 0.493012
# Validation loss: 0.492271
#
# Epoch 178
# -------------------------------
# Training loss: 0.490141
# Validation loss: 0.491209
#
# Epoch 179
# -------------------------------
# Training loss: 0.490665
# Validation loss: 0.487096
#
# Epoch 180
# -------------------------------
# Training loss: 0.492948
# Validation loss: 0.495481
#
# Epoch 181
# -------------------------------
# Training loss: 0.488661
# Validation loss: 0.494756
#
# Epoch 182
# -------------------------------
# Training loss: 0.489634
# Validation loss: 0.491940
#
# Epoch 183
# -------------------------------
# Training loss: 0.489559
# Validation loss: 0.490644
#
# Epoch 184
# -------------------------------
# Training loss: 0.486832
# Validation loss: 0.487601
#
# Epoch 185
# -------------------------------
# Training loss: 0.487141
# Validation loss: 0.488204
#
# Epoch 186
# -------------------------------
# Training loss: 0.486972
# Validation loss: 0.484599
#
# Epoch 187
# -------------------------------
# Training loss: 0.488550
# Validation loss: 0.493507
#
# Epoch 188
# -------------------------------
# Training loss: 0.484430
# Validation loss: 0.486091
#
# Epoch 189
# -------------------------------
# Training loss: 0.484618
# Validation loss: 0.482819
#
# Epoch 190
# -------------------------------
# Training loss: 0.484331
# Validation loss: 0.485381
#
# Epoch 191
# -------------------------------
# Training loss: 0.484017
# Validation loss: 0.480144
#
# Epoch 192
# -------------------------------
# Training loss: 0.485314
# Validation loss: 0.487950
#
# Epoch 193
# -------------------------------
# Training loss: 0.482112
# Validation loss: 0.489291
#
# Epoch 194
# -------------------------------
# Training loss: 0.482964
# Validation loss: 0.486545
#
# Epoch 195
# -------------------------------
# Training loss: 0.479921
# Validation loss: 0.480005
#
# Epoch 196
# -------------------------------
# Training loss: 0.480444
# Validation loss: 0.485673
#
# Epoch 197
# -------------------------------
# Training loss: 0.479492
# Validation loss: 0.475055
#
# Epoch 198
# -------------------------------
# Training loss: 0.481186
# Validation loss: 0.483524
#
# Epoch 199
# -------------------------------
# Training loss: 0.479495
# Validation loss: 0.478307
#
# Epoch 200
# -------------------------------
# Training loss: 0.476650
# Validation loss: 0.480254
#
# Epoch 201
# -------------------------------
# Training loss: 0.478474
# Validation loss: 0.481333
#
# Epoch 202
# -------------------------------
# Training loss: 0.477084
# Validation loss: 0.477170
#
# Epoch 203
# -------------------------------
# Training loss: 0.476293
# Validation loss: 0.475020
#
# Epoch 204
# -------------------------------
# Training loss: 0.475977
# Validation loss: 0.481147
#
# Epoch 205
# -------------------------------
# Training loss: 0.475688
# Validation loss: 0.477913
#
# Epoch 206
# -------------------------------
# Training loss: 0.475316
# Validation loss: 0.472000
#
# Epoch 207
# -------------------------------
# Training loss: 0.472364
# Validation loss: 0.477922
#
# Epoch 208
# -------------------------------
# Training loss: 0.472642
# Validation loss: 0.470465
#
# Epoch 209
# -------------------------------
# Training loss: 0.472737
# Validation loss: 0.475926
#
# Epoch 210
# -------------------------------
# Training loss: 0.471200
# Validation loss: 0.473009
#
# Epoch 211
# -------------------------------
# Training loss: 0.473904
# Validation loss: 0.470219
#
# Epoch 212
# -------------------------------
# Training loss: 0.473161
# Validation loss: 0.470740
#
# Epoch 213
# -------------------------------
# Training loss: 0.470429
# Validation loss: 0.470972
#
# Epoch 214
# -------------------------------
# Training loss: 0.468619
# Validation loss: 0.473927
#
# Epoch 215
# -------------------------------
# Training loss: 0.469300
# Validation loss: 0.471068
#
# Epoch 216
# -------------------------------
# Training loss: 0.469523
# Validation loss: 0.474232
#
# Epoch 217
# -------------------------------
# Training loss: 0.468418
# Validation loss: 0.474085
#
# Epoch 218
# -------------------------------
# Training loss: 0.468125
# Validation loss: 0.472136
#
# Epoch 219
# -------------------------------
# Training loss: 0.466924
# Validation loss: 0.463691
#
# Epoch 220
# -------------------------------
# Training loss: 0.465002
# Validation loss: 0.462023
#
# Epoch 221
# -------------------------------
# Training loss: 0.466169
# Validation loss: 0.470493
#
# Epoch 222
# -------------------------------
# Training loss: 0.463392
# Validation loss: 0.464484
#
# Epoch 223
# -------------------------------
# Training loss: 0.463725
# Validation loss: 0.466806
#
# Epoch 224
# -------------------------------
# Training loss: 0.463603
# Validation loss: 0.463218
#
# Epoch 225
# -------------------------------
# Training loss: 0.463707
# Validation loss: 0.464995
#
# Epoch 226
# -------------------------------
# Training loss: 0.461746
# Validation loss: 0.465737
#
# Epoch 227
# -------------------------------
# Training loss: 0.462546
# Validation loss: 0.469164
#
# Epoch 228
# -------------------------------
# Training loss: 0.461267
# Validation loss: 0.464005
#
# Epoch 229
# -------------------------------
# Training loss: 0.460610
# Validation loss: 0.458708
#
# Epoch 230
# -------------------------------
# Training loss: 0.460155
# Validation loss: 0.466149
#
# Epoch 231
# -------------------------------
# Training loss: 0.460035
# Validation loss: 0.462512
#
# Epoch 232
# -------------------------------
# Training loss: 0.458934
# Validation loss: 0.462684
#
# Epoch 233
# -------------------------------
# Training loss: 0.458641
# Validation loss: 0.464585
#
# Epoch 234
# -------------------------------
# Training loss: 0.457787
# Validation loss: 0.456569
#
# Epoch 235
# -------------------------------
# Training loss: 0.457698
# Validation loss: 0.459796
#
# Epoch 236
# -------------------------------
# Training loss: 0.457060
# Validation loss: 0.460372
#
# Epoch 237
# -------------------------------
# Training loss: 0.455827
# Validation loss: 0.459556
#
# Epoch 238
# -------------------------------
# Training loss: 0.456066
# Validation loss: 0.454547
#
# Epoch 239
# -------------------------------
# Training loss: 0.458626
# Validation loss: 0.461238
#
# Epoch 240
# -------------------------------
# Training loss: 0.455595
# Validation loss: 0.452919
#
# Epoch 241
# -------------------------------
# Training loss: 0.454983
# Validation loss: 0.459076
#
# Epoch 242
# -------------------------------
# Training loss: 0.453652
# Validation loss: 0.461116
#
# Epoch 243
# -------------------------------
# Training loss: 0.453712
# Validation loss: 0.454825
#
# Epoch 244
# -------------------------------
# Training loss: 0.451819
# Validation loss: 0.456780
#
# Epoch 245
# -------------------------------
# Training loss: 0.450883
# Validation loss: 0.450207
#
# Epoch 246
# -------------------------------
# Training loss: 0.450539
# Validation loss: 0.456630
#
# Epoch 247
# -------------------------------
# Training loss: 0.451243
# Validation loss: 0.458243
#
# Epoch 248
# -------------------------------
# Training loss: 0.450834
# Validation loss: 0.456061
#
# Epoch 249
# -------------------------------
# Training loss: 0.450624
# Validation loss: 0.444123
#
# Epoch 250
# -------------------------------
# Training loss: 0.448979
# Validation loss: 0.448845
#
# Epoch 251
# -------------------------------
# Training loss: 0.447590
# Validation loss: 0.453675
#
# Epoch 252
# -------------------------------
# Training loss: 0.448129
# Validation loss: 0.458002
#
# Epoch 253
# -------------------------------
# Training loss: 0.446429
# Validation loss: 0.443397
#
# Epoch 254
# -------------------------------
# Training loss: 0.449729
# Validation loss: 0.476414
#
# Epoch 255
# -------------------------------
# Training loss: 0.446289
# Validation loss: 0.446150
#
# Epoch 256
# -------------------------------
# Training loss: 0.446147
# Validation loss: 0.446992
#
# Epoch 257
# -------------------------------
# Training loss: 0.447793
# Validation loss: 0.447116
#
# Epoch 258
# -------------------------------
# Training loss: 0.444374
# Validation loss: 0.440844
#
# Epoch 259
# -------------------------------
# Training loss: 0.444964
# Validation loss: 0.443236
#
# Epoch 260
# -------------------------------
# Training loss: 0.444646
# Validation loss: 0.452950
#
# Epoch 261
# -------------------------------
# Training loss: 0.442057
# Validation loss: 0.440570
#
# Epoch 262
# -------------------------------
# Training loss: 0.445968
# Validation loss: 0.455087
#
# Epoch 263
# -------------------------------
# Training loss: 0.441558
# Validation loss: 0.440125
#
# Epoch 264
# -------------------------------
# Training loss: 0.441853
# Validation loss: 0.449839
#
# Epoch 265
# -------------------------------
# Training loss: 0.441382
# Validation loss: 0.441858
#
# Epoch 266
# -------------------------------
# Training loss: 0.442388
# Validation loss: 0.451811
#
# Epoch 267
# -------------------------------
# Training loss: 0.438109
# Validation loss: 0.444944
#
# Epoch 268
# -------------------------------
# Training loss: 0.437262
# Validation loss: 0.444259
#
# Epoch 269
# -------------------------------
# Training loss: 0.438215
# Validation loss: 0.439827
#
# Epoch 270
# -------------------------------
# Training loss: 0.437565
# Validation loss: 0.446038
#
# Epoch 271
# -------------------------------
# Training loss: 0.435942
# Validation loss: 0.439697
#
# Epoch 272
# -------------------------------
# Training loss: 0.435603
# Validation loss: 0.444670
#
# Epoch 273
# -------------------------------
# Training loss: 0.437963
# Validation loss: 0.437338
#
# Epoch 274
# -------------------------------
# Training loss: 0.437072
# Validation loss: 0.467299
#
# Epoch 275
# -------------------------------
# Training loss: 0.437957
# Validation loss: 0.435707
#
# Epoch 276
# -------------------------------
# Training loss: 0.435916
# Validation loss: 0.438533
#
# Epoch 277
# -------------------------------
# Training loss: 0.433161
# Validation loss: 0.439753
#
# Epoch 278
# -------------------------------
# Training loss: 0.433613
# Validation loss: 0.433392
#
# Epoch 279
# -------------------------------
# Training loss: 0.431691
# Validation loss: 0.437140
#
# Epoch 280
# -------------------------------
# Training loss: 0.431367
# Validation loss: 0.440416
#
# Epoch 281
# -------------------------------
# Training loss: 0.430987
# Validation loss: 0.425109
#
# Epoch 282
# -------------------------------
# Training loss: 0.431651
# Validation loss: 0.438455
#
# Epoch 283
# -------------------------------
# Training loss: 0.428586
# Validation loss: 0.434147
#
# Epoch 284
# -------------------------------
# Training loss: 0.430274
# Validation loss: 0.435797
#
# Epoch 285
# -------------------------------
# Training loss: 0.429590
# Validation loss: 0.433548
#
# Epoch 286
# -------------------------------
# Training loss: 0.429044
# Validation loss: 0.428249
#
# Epoch 287
# -------------------------------
# Training loss: 0.429542
# Validation loss: 0.444687
#
# Epoch 288
# -------------------------------
# Training loss: 0.427509
# Validation loss: 0.434142
#
# Epoch 289
# -------------------------------
# Training loss: 0.427363
# Validation loss: 0.425160
#
# Epoch 290
# -------------------------------
# Training loss: 0.424912
# Validation loss: 0.439861
#
# Epoch 291
# -------------------------------
# Training loss: 0.426428
# Validation loss: 0.430560
#
# Epoch 292
# -------------------------------
# Training loss: 0.425103
# Validation loss: 0.431743
#
# Epoch 293
# -------------------------------
# Training loss: 0.427542
# Validation loss: 0.433891
#
# Epoch 294
# -------------------------------
# Training loss: 0.423103
# Validation loss: 0.426657
#
# Epoch 295
# -------------------------------
# Training loss: 0.423011
# Validation loss: 0.437655
#
# Epoch 296
# -------------------------------
# Training loss: 0.422340
# Validation loss: 0.436533
#
# Epoch 297
# -------------------------------
# Training loss: 0.421616
# Validation loss: 0.424956
#
# Epoch 298
# -------------------------------
# Training loss: 0.422019
# Validation loss: 0.423084
#
# Epoch 299
# -------------------------------
# Training loss: 0.420304
# Validation loss: 0.428101
#
# Epoch 300
# -------------------------------
# Training loss: 0.427955
# Validation loss: 0.429995
#
# Epoch 301
# -------------------------------
# Training loss: 0.419749
# Validation loss: 0.430261
#
# Epoch 302
# -------------------------------
# Training loss: 0.417261
# Validation loss: 0.446322
#
# Epoch 303
# -------------------------------
# Training loss: 0.420688
# Validation loss: 0.441682
#
# Epoch 304
# -------------------------------
# Training loss: 0.419502
# Validation loss: 0.428808
#
# Epoch 305
# -------------------------------
# Training loss: 0.419282
# Validation loss: 0.429693
#
# Epoch 306
# -------------------------------
# Training loss: 0.415851
# Validation loss: 0.418160
#
# Epoch 307
# -------------------------------
# Training loss: 0.416209
# Validation loss: 0.428833
#
# Epoch 308
# -------------------------------
# Training loss: 0.413585
# Validation loss: 0.423531
#
# Epoch 309
# -------------------------------
# Training loss: 0.414931
# Validation loss: 0.417252
#
# Epoch 310
# -------------------------------
# Training loss: 0.412964
# Validation loss: 0.420569
#
# Epoch 311
# -------------------------------
# Training loss: 0.413002
# Validation loss: 0.422839
#
# Epoch 312
# -------------------------------
# Training loss: 0.415800
# Validation loss: 0.425571
#
# Epoch 313
# -------------------------------
# Training loss: 0.411020
# Validation loss: 0.413823
#
# Epoch 314
# -------------------------------
# Training loss: 0.409519
# Validation loss: 0.416664
#
# Epoch 315
# -------------------------------
# Training loss: 0.409588
# Validation loss: 0.437031
#
# Epoch 316
# -------------------------------
# Training loss: 0.408776
# Validation loss: 0.411247
#
# Epoch 317
# -------------------------------
# Training loss: 0.409848
# Validation loss: 0.455069
#
# Epoch 318
# -------------------------------
# Training loss: 0.407106
# Validation loss: 0.412077
#
# Epoch 319
# -------------------------------
# Training loss: 0.406293
# Validation loss: 0.420737
#
# Epoch 320
# -------------------------------
# Training loss: 0.404650
# Validation loss: 0.415730
#
# Epoch 321
# -------------------------------
# Training loss: 0.405220
# Validation loss: 0.425306
#
# Epoch 322
# -------------------------------
# Training loss: 0.411269
# Validation loss: 0.410214
#
# Epoch 323
# -------------------------------
# Training loss: 0.409351
# Validation loss: 0.408550
#
# Epoch 324
# -------------------------------
# Training loss: 0.406704
# Validation loss: 0.418233
#
# Epoch 325
# -------------------------------
# Training loss: 0.405287
# Validation loss: 0.395862
#
# Epoch 326
# -------------------------------
# Training loss: 0.404284
# Validation loss: 0.441838
#
# Epoch 327
# -------------------------------
# Training loss: 0.402199
# Validation loss: 0.410174
#
# Epoch 328
# -------------------------------
# Training loss: 0.402314
# Validation loss: 0.420264
#
# Epoch 329
# -------------------------------
# Training loss: 0.402575
# Validation loss: 0.394166
#
# Epoch 330
# -------------------------------
# Training loss: 0.402086
# Validation loss: 0.473155
#
# Epoch 331
# -------------------------------
# Training loss: 0.400529
# Validation loss: 0.426128
#
# Epoch 332
# -------------------------------
# Training loss: 0.396093
# Validation loss: 0.426441
#
# Epoch 333
# -------------------------------
# Training loss: 0.397192
# Validation loss: 0.398580
#
# Epoch 334
# -------------------------------
# Training loss: 0.398565
# Validation loss: 0.407587
#
# Epoch 335
# -------------------------------
# Training loss: 0.398500
# Validation loss: 0.416511
#
# Epoch 336
# -------------------------------
# Training loss: 0.398610
# Validation loss: 0.422018
#
# Epoch 337
# -------------------------------
# Training loss: 0.396107
# Validation loss: 0.395715
#
# Epoch 338
# -------------------------------
# Training loss: 0.394503
# Validation loss: 0.428652
#
# Epoch 339
# -------------------------------
# Training loss: 0.395520
# Validation loss: 0.393891
#
# Epoch 340
# -------------------------------
# Training loss: 0.397952
# Validation loss: 0.393650
#
# Epoch 341
# -------------------------------
# Training loss: 0.393852
# Validation loss: 0.419029
#
# Epoch 342
# -------------------------------
# Training loss: 0.397230
# Validation loss: 0.419768
#
# Epoch 343
# -------------------------------
# Training loss: 0.392566
# Validation loss: 0.390343
#
# Epoch 344
# -------------------------------
# Training loss: 0.389644
# Validation loss: 0.408630
#
# Epoch 345
# -------------------------------
# Training loss: 0.391611
# Validation loss: 0.395404
#
# Epoch 346
# -------------------------------
# Training loss: 0.388775
# Validation loss: 0.409625
#
# Epoch 347
# -------------------------------
# Training loss: 0.390810
# Validation loss: 0.417321
#
# Epoch 348
# -------------------------------
# Training loss: 0.389442
# Validation loss: 0.411318
#
# Epoch 349
# -------------------------------
# Training loss: 0.387125
# Validation loss: 0.386464
#
# Epoch 350
# -------------------------------
# Training loss: 0.384375
# Validation loss: 0.429654
#
# Epoch 351
# -------------------------------
# Training loss: 0.385299
# Validation loss: 0.388443
#
# Epoch 352
# -------------------------------
# Training loss: 0.383647
# Validation loss: 0.428665
#
# Epoch 353
# -------------------------------
# Training loss: 0.384832
# Validation loss: 0.387377
#
# Epoch 354
# -------------------------------
# Training loss: 0.381305
# Validation loss: 0.399861
#
# Epoch 355
# -------------------------------
# Training loss: 0.381417
# Validation loss: 0.436869
#
# Epoch 356
# -------------------------------
# Training loss: 0.382939
# Validation loss: 0.377585
#
# Epoch 357
# -------------------------------
# Training loss: 0.380635
# Validation loss: 0.383266
#
# Epoch 358
# -------------------------------
# Training loss: 0.385179
# Validation loss: 0.407291
#
# Epoch 359
# -------------------------------
# Training loss: 0.383489
# Validation loss: 0.385546
#
# Epoch 360
# -------------------------------
# Training loss: 0.378016
# Validation loss: 0.415989
#
# Epoch 361
# -------------------------------
# Training loss: 0.384348
# Validation loss: 0.391081
#
# Epoch 362
# -------------------------------
# Training loss: 0.379809
# Validation loss: 0.393039
#
# Epoch 363
# -------------------------------
# Training loss: 0.377502
# Validation loss: 0.391022
#
# Epoch 364
# -------------------------------
# Training loss: 0.376062
# Validation loss: 0.405395
#
# Epoch 365
# -------------------------------
# Training loss: 0.374419
# Validation loss: 0.374781
#
# Epoch 366
# -------------------------------
# Training loss: 0.375748
# Validation loss: 0.403100
#
# Epoch 367
# -------------------------------
# Training loss: 0.379312
# Validation loss: 0.377358
#
# Epoch 368
# -------------------------------
# Training loss: 0.374025
# Validation loss: 0.386779
#
# Epoch 369
# -------------------------------
# Training loss: 0.373514
# Validation loss: 0.400996
#
# Epoch 370
# -------------------------------
# Training loss: 0.380329
# Validation loss: 0.380471
#
# Epoch 371
# -------------------------------
# Training loss: 0.376293
# Validation loss: 0.407417
#
# Epoch 372
# -------------------------------
# Training loss: 0.379643
# Validation loss: 0.394648
#
# Epoch 373
# -------------------------------
# Training loss: 0.373956
# Validation loss: 0.389462
#
# Epoch 374
# -------------------------------
# Training loss: 0.376353
# Validation loss: 0.379229
#
# Epoch 375
# -------------------------------
# Training loss: 0.370122
# Validation loss: 0.410272
#
# Epoch 376
# -------------------------------
# Training loss: 0.369005
# Validation loss: 0.378748
#
# Epoch 377
# -------------------------------
# Training loss: 0.369150
# Validation loss: 0.388958
#
# Epoch 378
# -------------------------------
# Training loss: 0.372533
# Validation loss: 0.380791
#
# Epoch 379
# -------------------------------
# Training loss: 0.370063
# Validation loss: 0.394243
#
# Epoch 380
# -------------------------------
# Training loss: 0.368264
# Validation loss: 0.369853
#
# Epoch 381
# -------------------------------
# Training loss: 0.368062
# Validation loss: 0.453255
#
# Epoch 382
# -------------------------------
# Training loss: 0.366970
# Validation loss: 0.376330
#
# Epoch 383
# -------------------------------
# Training loss: 0.367786
# Validation loss: 0.367359
#
# Epoch 384
# -------------------------------
# Training loss: 0.364555
# Validation loss: 0.365293
#
# Epoch 385
# -------------------------------
# Training loss: 0.362803
# Validation loss: 0.403416
#
# Epoch 386
# -------------------------------
# Training loss: 0.363848
# Validation loss: 0.368131
#
# Epoch 387
# -------------------------------
# Training loss: 0.364341
# Validation loss: 0.371359
#
# Epoch 388
# -------------------------------
# Training loss: 0.367521
# Validation loss: 0.378938
#
# Epoch 389
# -------------------------------
# Training loss: 0.362524
# Validation loss: 0.380960
#
# Epoch 390
# -------------------------------
# Training loss: 0.361742
# Validation loss: 0.359322
#
# Epoch 391
# -------------------------------
# Training loss: 0.363898
# Validation loss: 0.389485
#
# Epoch 392
# -------------------------------
# Training loss: 0.364171
# Validation loss: 0.396265
#
# Epoch 393
# -------------------------------
# Training loss: 0.360808
# Validation loss: 0.367587
#
# Epoch 394
# -------------------------------
# Training loss: 0.362231
# Validation loss: 0.359003
#
# Epoch 395
# -------------------------------
# Training loss: 0.360541
# Validation loss: 0.374285
#
# Epoch 396
# -------------------------------
# Training loss: 0.356130
# Validation loss: 0.398825
#
# Epoch 397
# -------------------------------
# Training loss: 0.360598
# Validation loss: 0.359579
#
# Epoch 398
# -------------------------------
# Training loss: 0.356354
# Validation loss: 0.364953
#
# Epoch 399
# -------------------------------
# Training loss: 0.360107
# Validation loss: 0.369356
#
# Epoch 400
# -------------------------------
# Training loss: 0.365661
# Validation loss: 0.379207
#
# Epoch 401
# -------------------------------
# Training loss: 0.359555
# Validation loss: 0.367583
#
# Epoch 402
# -------------------------------
# Training loss: 0.356536
# Validation loss: 0.371075
#
# Epoch 403
# -------------------------------
# Training loss: 0.358429
# Validation loss: 0.368008
#
# Epoch 404
# -------------------------------
# Training loss: 0.362312
# Validation loss: 0.356111
#
# Epoch 405
# -------------------------------
# Training loss: 0.354182
# Validation loss: 0.366728
#
# Epoch 406
# -------------------------------
# Training loss: 0.352914
# Validation loss: 0.357012
#
# Epoch 407
# -------------------------------
# Training loss: 0.351239
# Validation loss: 0.390423
#
# Epoch 408
# -------------------------------
# Training loss: 0.350585
# Validation loss: 0.356848
#
# Epoch 409
# -------------------------------
# Training loss: 0.349769
# Validation loss: 0.361086
#
# Epoch 410
# -------------------------------
# Training loss: 0.359286
# Validation loss: 0.355765
#
# Epoch 411
# -------------------------------
# Training loss: 0.350475
# Validation loss: 0.403332
#
# Epoch 412
# -------------------------------
# Training loss: 0.355592
# Validation loss: 0.351536
#
# Epoch 413
# -------------------------------
# Training loss: 0.351665
# Validation loss: 0.406915
#
# Epoch 414
# -------------------------------
# Training loss: 0.350681
# Validation loss: 0.347169
#
# Epoch 415
# -------------------------------
# Training loss: 0.352146
# Validation loss: 0.359167
#
# Epoch 416
# -------------------------------
# Training loss: 0.351648
# Validation loss: 0.349980
#
# Epoch 417
# -------------------------------
# Training loss: 0.352096
# Validation loss: 0.397848
#
# Epoch 418
# -------------------------------
# Training loss: 0.347215
# Validation loss: 0.344056
#
# Epoch 419
# -------------------------------
# Training loss: 0.347677
# Validation loss: 0.369572
#
# Epoch 420
# -------------------------------
# Training loss: 0.347057
# Validation loss: 0.347786
#
# Epoch 421
# -------------------------------
# Training loss: 0.349513
# Validation loss: 0.355644
#
# Epoch 422
# -------------------------------
# Training loss: 0.349484
# Validation loss: 0.369075
#
# Epoch 423
# -------------------------------
# Training loss: 0.345674
# Validation loss: 0.353043
#
# Epoch 424
# -------------------------------
# Training loss: 0.347814
# Validation loss: 0.351062
#
# Epoch 425
# -------------------------------
# Training loss: 0.345130
# Validation loss: 0.353726
#
# Epoch 426
# -------------------------------
# Training loss: 0.347727
# Validation loss: 0.357952
#
# Epoch 427
# -------------------------------
# Training loss: 0.345119
# Validation loss: 0.344235
#
# Epoch 428
# -------------------------------
# Training loss: 0.343831
# Validation loss: 0.358268
#
# Epoch 429
# -------------------------------
# Training loss: 0.345218
# Validation loss: 0.366764
#
# Epoch 430
# -------------------------------
# Training loss: 0.342897
# Validation loss: 0.366679
#
# Epoch 431
# -------------------------------
# Training loss: 0.340065
# Validation loss: 0.349395
#
# Epoch 432
# -------------------------------
# Training loss: 0.345122
# Validation loss: 0.344575
#
# Epoch 433
# -------------------------------
# Training loss: 0.348078
# Validation loss: 0.370886
#
# Epoch 434
# -------------------------------
# Training loss: 0.343066
# Validation loss: 0.341101
#
# Epoch 435
# -------------------------------
# Training loss: 0.337409
# Validation loss: 0.345177
#
# Epoch 436
# -------------------------------
# Training loss: 0.337678
# Validation loss: 0.342826
#
# Epoch 437
# -------------------------------
# Training loss: 0.343408
# Validation loss: 0.374315
#
# Epoch 438
# -------------------------------
# Training loss: 0.338602
# Validation loss: 0.342885
#
# Epoch 439
# -------------------------------
# Training loss: 0.343740
# Validation loss: 0.350155
#
# Epoch 440
# -------------------------------
# Training loss: 0.340122
# Validation loss: 0.398857
#
# Epoch 441
# -------------------------------
# Training loss: 0.340963
# Validation loss: 0.360843
#
# Epoch 442
# -------------------------------
# Training loss: 0.337800
# Validation loss: 0.336899
#
# Epoch 443
# -------------------------------
# Training loss: 0.335212
# Validation loss: 0.341348
#
# Epoch 444
# -------------------------------
# Training loss: 0.335878
# Validation loss: 0.363752
#
# Epoch 445
# -------------------------------
# Training loss: 0.335379
# Validation loss: 0.341869
#
# Epoch 446
# -------------------------------
# Training loss: 0.335191
# Validation loss: 0.367670
#
# Epoch 447
# -------------------------------
# Training loss: 0.333429
# Validation loss: 0.358748
#
# Epoch 448
# -------------------------------
# Training loss: 0.337725
# Validation loss: 0.360122
#
# Epoch 449
# -------------------------------
# Training loss: 0.341551
# Validation loss: 0.377155
#
# Epoch 450
# -------------------------------
# Training loss: 0.335800
# Validation loss: 0.357298
#
# Epoch 451
# -------------------------------
# Training loss: 0.333810
# Validation loss: 0.328952
#
# Epoch 452
# -------------------------------
# Training loss: 0.337447
# Validation loss: 0.330385
#
# Epoch 453
# -------------------------------
# Training loss: 0.334288
# Validation loss: 0.342435
#
# Epoch 454
# -------------------------------
# Training loss: 0.334262
# Validation loss: 0.348937
#
# Epoch 455
# -------------------------------
# Training loss: 0.332582
# Validation loss: 0.329291
#
# Epoch 456
# -------------------------------
# Training loss: 0.333882
# Validation loss: 0.367388
#
# Epoch 457
# -------------------------------
# Training loss: 0.337834
# Validation loss: 0.332096
#
# Epoch 458
# -------------------------------
# Training loss: 0.329387
# Validation loss: 0.331438
#
# Epoch 459
# -------------------------------
# Training loss: 0.331262
# Validation loss: 0.328498
#
# Epoch 460
# -------------------------------
# Training loss: 0.332662
# Validation loss: 0.366951
#
# Epoch 461
# -------------------------------
# Training loss: 0.330334
# Validation loss: 0.345946
#
# Epoch 462
# -------------------------------
# Training loss: 0.331198
# Validation loss: 0.343002
#
# Epoch 463
# -------------------------------
# Training loss: 0.329474
# Validation loss: 0.329463
#
# Epoch 464
# -------------------------------
# Training loss: 0.325259
# Validation loss: 0.354083
#
# Epoch 465
# -------------------------------
# Training loss: 0.324618
# Validation loss: 0.335407
#
# Epoch 466
# -------------------------------
# Training loss: 0.326003
# Validation loss: 0.324720
#
# Epoch 467
# -------------------------------
# Training loss: 0.327234
# Validation loss: 0.328132
#
# Epoch 468
# -------------------------------
# Training loss: 0.326853
# Validation loss: 0.334212
#
# Epoch 469
# -------------------------------
# Training loss: 0.325875
# Validation loss: 0.327457
#
# Epoch 470
# -------------------------------
# Training loss: 0.327099
# Validation loss: 0.332079
#
# Epoch 471
# -------------------------------
# Training loss: 0.324987
# Validation loss: 0.334437
#
# Epoch 472
# -------------------------------
# Training loss: 0.327088
# Validation loss: 0.320040
#
# Epoch 473
# -------------------------------
# Training loss: 0.326146
# Validation loss: 0.320074
#
# Epoch 474
# -------------------------------
# Training loss: 0.324618
# Validation loss: 0.332395
#
# Epoch 475
# -------------------------------
# Training loss: 0.328110
# Validation loss: 0.351059
#
# Epoch 476
# -------------------------------
# Training loss: 0.326059
# Validation loss: 0.328325
#
# Epoch 477
# -------------------------------
# Training loss: 0.322315
# Validation loss: 0.329456
#
# Epoch 478
# -------------------------------
# Training loss: 0.323922
# Validation loss: 0.358032
#
# Epoch 479
# -------------------------------
# Training loss: 0.326086
# Validation loss: 0.344466
#
# Epoch 480
# -------------------------------
# Training loss: 0.324852
# Validation loss: 0.327385
#
# Epoch 481
# -------------------------------
# Training loss: 0.320323
# Validation loss: 0.323553
#
# Epoch 482
# -------------------------------
# Training loss: 0.320893
# Validation loss: 0.332756
#
# Epoch 483
# -------------------------------
# Training loss: 0.318675
# Validation loss: 0.330930
#
# Epoch 484
# -------------------------------
# Training loss: 0.320004
# Validation loss: 0.320342
#
# Epoch 485
# -------------------------------
# Training loss: 0.320495
# Validation loss: 0.326330
#
# Epoch 486
# -------------------------------
# Training loss: 0.322641
# Validation loss: 0.315786
#
# Epoch 487
# -------------------------------
# Training loss: 0.321654
# Validation loss: 0.327437
#
# Epoch 488
# -------------------------------
# Training loss: 0.320813
# Validation loss: 0.318929
#
# Epoch 489
# -------------------------------
# Training loss: 0.323512
# Validation loss: 0.320599
#
# Epoch 490
# -------------------------------
# Training loss: 0.318604
# Validation loss: 0.324433
#
# Epoch 491
# -------------------------------
# Training loss: 0.319957
# Validation loss: 0.351552
#
# Epoch 492
# -------------------------------
# Training loss: 0.316313
# Validation loss: 0.342938
#
# Epoch 493
# -------------------------------
# Training loss: 0.318908
# Validation loss: 0.321586
#
# Epoch 494
# -------------------------------
# Training loss: 0.319012
# Validation loss: 0.323942
#
# Epoch 495
# -------------------------------
# Training loss: 0.316713
# Validation loss: 0.312211
#
# Epoch 496
# -------------------------------
# Training loss: 0.316709
# Validation loss: 0.367078
#
# Epoch 497
# -------------------------------
# Training loss: 0.317193
# Validation loss: 0.315936
#
# Epoch 498
# -------------------------------
# Training loss: 0.315312
# Validation loss: 0.313423
#
# Epoch 499
# -------------------------------
# Training loss: 0.326160
# Validation loss: 0.313754
#
# Epoch 500
# -------------------------------
# Training loss: 0.315719
# Validation loss: 0.365542
#
# Epoch 501
# -------------------------------
# Training loss: 0.315249
# Validation loss: 0.323093
#
# Epoch 502
# -------------------------------
# Training loss: 0.312829
# Validation loss: 0.310953
#
# Epoch 503
# -------------------------------
# Training loss: 0.315559
# Validation loss: 0.318508
#
# Epoch 504
# -------------------------------
# Training loss: 0.316970
# Validation loss: 0.315463
#
# Epoch 505
# -------------------------------
# Training loss: 0.314851
# Validation loss: 0.329426
#
# Epoch 506
# -------------------------------
# Training loss: 0.313093
# Validation loss: 0.327374
#
# Epoch 507
# -------------------------------
# Training loss: 0.315531
# Validation loss: 0.315996
#
# Epoch 508
# -------------------------------
# Training loss: 0.315151
# Validation loss: 0.335222
#
# Epoch 509
# -------------------------------
# Training loss: 0.314693
# Validation loss: 0.312720
#
# Epoch 510
# -------------------------------
# Training loss: 0.311995
# Validation loss: 0.328610
#
# Epoch 511
# -------------------------------
# Training loss: 0.308095
# Validation loss: 0.308977
#
# Epoch 512
# -------------------------------
# Training loss: 0.311203
# ...
# Validation loss: 0.131319
#
# Epoch 2333
# -------------------------------
# Training loss: 0.107348
# Validation loss: 0.107783
#
# Epoch 2334
# -------------------------------
# Training loss: 0.105720
# Validation loss: 0.105640
#
# Epoch 2335
# -------------------------------
# Training loss: 0.105303
# Validation loss: 0.114856
#
# Epoch 2336
# -------------------------------
# Training loss: 0.105823
# Validation loss: 0.116400
#
# Epoch 2337
# -------------------------------
# Training loss: 0.110818
# Validation loss: 0.106402
#
# Epoch 2338
# -------------------------------
# Training loss: 0.105663
# Validation loss: 0.111969
#
# Epoch 2339
# -------------------------------
# Training loss: 0.106727
# Validation loss: 0.109229
#
# Epoch 2340
# -------------------------------
# Training loss: 0.109731
# Validation loss: 0.121156
#
# Epoch 2341
# -------------------------------
# Training loss: 0.105758
# Validation loss: 0.106256
#
# Epoch 2342
# -------------------------------
# Training loss: 0.107664
# Validation loss: 0.109231
#
# Epoch 2343
# -------------------------------
# Training loss: 0.108421
# Validation loss: 0.112635
#
# Epoch 2344
# -------------------------------
# Training loss: 0.106505
# Validation loss: 0.110981
#
# Epoch 2345
# -------------------------------
# Training loss: 0.106224
# Validation loss: 0.121693
#
# Epoch 2346
# -------------------------------
# Training loss: 0.108780
# Validation loss: 0.109377
#
# Epoch 2347
# -------------------------------
# Training loss: 0.105108
# Validation loss: 0.110092
#
# Epoch 2348
# -------------------------------
# Training loss: 0.114382
# Validation loss: 0.113545
#
# Epoch 2349
# -------------------------------
# Training loss: 0.107508
# Validation loss: 0.124358
#
# Epoch 2350
# -------------------------------
# Training loss: 0.107547
# Validation loss: 0.121195
#
# Epoch 2351
# -------------------------------
# Training loss: 0.106395
# Validation loss: 0.111398
#
# Epoch 2352
# -------------------------------
# Training loss: 0.104359
# Validation loss: 0.126168
#
# Epoch 2353
# -------------------------------
# Training loss: 0.110194
# Validation loss: 0.106607
#
# Epoch 2354
# -------------------------------
# Training loss: 0.104816
# Validation loss: 0.117433
#
# Epoch 2355
# -------------------------------
# Training loss: 0.110419
# Validation loss: 0.108854
#
# Epoch 2356
# -------------------------------
# Training loss: 0.108653
# Validation loss: 0.116936
#
# Epoch 2357
# -------------------------------
# Training loss: 0.104854
# Validation loss: 0.117103
#
# Epoch 2358
# -------------------------------
# Training loss: 0.103330
# Validation loss: 0.115950
#
# Epoch 2359
# -------------------------------
# Training loss: 0.109655
# Validation loss: 0.111118
#
# Epoch 2360
# -------------------------------
# Training loss: 0.105595
# Validation loss: 0.108761
#
# Epoch 2361
# -------------------------------
# Training loss: 0.103794
# Validation loss: 0.122106
#
# Epoch 2362
# -------------------------------
# Training loss: 0.104562
# Validation loss: 0.107835
#
# Epoch 2363
# -------------------------------
# Training loss: 0.104839
# Validation loss: 0.114713
#
# Epoch 2364
# -------------------------------
# Training loss: 0.106562
# Validation loss: 0.105789
#
# Epoch 2365
# -------------------------------
# Training loss: 0.113552
# Validation loss: 0.101731
#
# Epoch 2366
# -------------------------------
# Training loss: 0.107650
# Validation loss: 0.110060
#
# Epoch 2367
# -------------------------------
# Training loss: 0.106209
# Validation loss: 0.126397
#
# Epoch 2368
# -------------------------------
# Training loss: 0.105140
# Validation loss: 0.118073
#
# Epoch 2369
# -------------------------------
# Training loss: 0.105398
# Validation loss: 0.112081
#
# Epoch 2370
# -------------------------------
# Training loss: 0.105708
# Validation loss: 0.114635
#
# Epoch 2371
# -------------------------------
# Training loss: 0.104900
# Validation loss: 0.105596
#
# Epoch 2372
# -------------------------------
# Training loss: 0.107575
# Validation loss: 0.112461
#
# Epoch 2373
# -------------------------------
# Training loss: 0.104627
# Validation loss: 0.105679
#
# Epoch 2374
# -------------------------------
# Training loss: 0.106314
# Validation loss: 0.105775
#
# Epoch 2375
# -------------------------------
# Training loss: 0.104244
# Validation loss: 0.118020
#
# Epoch 2376
# -------------------------------
# Training loss: 0.104624
# Validation loss: 0.109111
#
# Epoch 2377
# -------------------------------
# Training loss: 0.109203
# Validation loss: 0.120024
#
# Epoch 2378
# -------------------------------
# Training loss: 0.104700
# Validation loss: 0.105286
#
# Epoch 2379
# -------------------------------
# Training loss: 0.106482
# Validation loss: 0.116858
#
# Epoch 2380
# -------------------------------
# Training loss: 0.105052
# Validation loss: 0.105656
#
# Epoch 2381
# -------------------------------
# Training loss: 0.103777
# Validation loss: 0.112821
#
# Epoch 2382
# -------------------------------
# Training loss: 0.106806
# Validation loss: 0.106603
#
# Epoch 2383
# -------------------------------
# Training loss: 0.104464
# Validation loss: 0.109684
#
# Epoch 2384
# -------------------------------
# Training loss: 0.108164
# Validation loss: 0.103812
#
# Epoch 2385
# -------------------------------
# Training loss: 0.104700
# Validation loss: 0.109243
#
# Epoch 2386
# -------------------------------
# Training loss: 0.103683
# Validation loss: 0.113172
#
# Epoch 2387
# -------------------------------
# Training loss: 0.104235
# Validation loss: 0.108152
#
# Epoch 2388
# -------------------------------
# Training loss: 0.101687
# Validation loss: 0.110945
#
# Epoch 2389
# -------------------------------
# Training loss: 0.106861
# Validation loss: 0.105184
#
# Epoch 2390
# -------------------------------
# Training loss: 0.104970
# Validation loss: 0.105956
#
# Epoch 2391
# -------------------------------
# Training loss: 0.102456
# Validation loss: 0.117292
#
# Epoch 2392
# -------------------------------
# Training loss: 0.105054
# Validation loss: 0.108732
#
# Epoch 2393
# -------------------------------
# Training loss: 0.104496
# Validation loss: 0.111772
#
# Epoch 2394
# -------------------------------
# Training loss: 0.103372
# Validation loss: 0.106112
#
# Epoch 2395
# -------------------------------
# Training loss: 0.103789
# Validation loss: 0.102546
#
# Epoch 2396
# -------------------------------
# Training loss: 0.105033
# Validation loss: 0.115156
#
# Epoch 2397
# -------------------------------
# Training loss: 0.105996
# Validation loss: 0.102664
#
# Epoch 2398
# -------------------------------
# Training loss: 0.102411
# Validation loss: 0.114537
#
# Epoch 2399
# -------------------------------
# Training loss: 0.102646
# Validation loss: 0.105835
#
# Epoch 2400
# -------------------------------
# Training loss: 0.103336
# Validation loss: 0.125741
#
# Epoch 2401
# -------------------------------
# Training loss: 0.105756
# Validation loss: 0.103493
#
# Epoch 2402
# -------------------------------
# Training loss: 0.104769
# Validation loss: 0.104978
#
# Epoch 2403
# -------------------------------
# Training loss: 0.105066
# Validation loss: 0.106869
#
# Epoch 2404
# -------------------------------
# Training loss: 0.102529
# Validation loss: 0.111928
#
# Epoch 2405
# -------------------------------
# Training loss: 0.102960
# Validation loss: 0.127969
#
# Epoch 2406
# -------------------------------
# Training loss: 0.103414
# Validation loss: 0.109617
#
# Epoch 2407
# -------------------------------
# Training loss: 0.103594
# Validation loss: 0.101501
#
# Epoch 2408
# -------------------------------
# Training loss: 0.104776
# Validation loss: 0.105419
#
# Epoch 2409
# -------------------------------
# Training loss: 0.110481
# Validation loss: 0.104279
#
# Epoch 2410
# -------------------------------
# Training loss: 0.105999
# Validation loss: 0.105809
#
# Epoch 2411
# -------------------------------
# Training loss: 0.103580
# Validation loss: 0.112925
#
# Epoch 2412
# -------------------------------
# Training loss: 0.108652
# Validation loss: 0.111269
#
# Epoch 2413
# -------------------------------
# Training loss: 0.105035
# Validation loss: 0.109974
#
# Epoch 2414
# -------------------------------
# Training loss: 0.107256
# Validation loss: 0.102560
#
# Epoch 2415
# -------------------------------
# Training loss: 0.107166
# Validation loss: 0.103889
#
# Epoch 2416
# -------------------------------
# Training loss: 0.105042
# Validation loss: 0.107878
#
# Epoch 2417
# -------------------------------
# Training loss: 0.103676
# Validation loss: 0.114061
#
# Epoch 2418
# -------------------------------
# Training loss: 0.105927
# Validation loss: 0.107976
#
# Epoch 2419
# -------------------------------
# Training loss: 0.104295
# Validation loss: 0.106883
#
# Epoch 2420
# -------------------------------
# Training loss: 0.102652
# Validation loss: 0.117271
#
# Epoch 2421
# -------------------------------
# Training loss: 0.102633
# Validation loss: 0.111497
#
# Epoch 2422
# -------------------------------
# Training loss: 0.103106
# Validation loss: 0.111516
#
# Epoch 2423
# -------------------------------
# Training loss: 0.114583
# Validation loss: 0.107343
#
# Epoch 2424
# -------------------------------
# Training loss: 0.109607
# Validation loss: 0.106529
#
# Epoch 2425
# -------------------------------
# Training loss: 0.109056
# Validation loss: 0.110472
#
# Epoch 2426
# -------------------------------
# Training loss: 0.108403
# Validation loss: 0.111666
#
# Epoch 2427
# -------------------------------
# Training loss: 0.103090
# Validation loss: 0.111694
#
# Epoch 2428
# -------------------------------
# Training loss: 0.102463
# Validation loss: 0.133685
#
# Epoch 2429
# -------------------------------
# Training loss: 0.106561
# Validation loss: 0.108190
#
# Epoch 2430
# -------------------------------
# Training loss: 0.103822
# Validation loss: 0.122128
#
# Epoch 2431
# -------------------------------
# Training loss: 0.103153
# Validation loss: 0.105197
#
# Epoch 2432
# -------------------------------
# Training loss: 0.105369
# Validation loss: 0.107234
#
# Epoch 2433
# -------------------------------
# Training loss: 0.103019
# Validation loss: 0.105792
#
# Epoch 2434
# -------------------------------
# Training loss: 0.101939
# Validation loss: 0.104474
#
# Epoch 2435
# -------------------------------
# Training loss: 0.101950
# Validation loss: 0.104231
#
# Epoch 2436
# -------------------------------
# Training loss: 0.104699
# Validation loss: 0.104167
#
# Epoch 2437
# -------------------------------
# Training loss: 0.103673
# Validation loss: 0.107646
#
# Epoch 2438
# -------------------------------
# Training loss: 0.104348
# Validation loss: 0.108792
#
# Epoch 2439
# -------------------------------
# Training loss: 0.100907
# Validation loss: 0.115239
#
# Epoch 2440
# -------------------------------
# Training loss: 0.103663
# Validation loss: 0.104526
#
# Epoch 2441
# -------------------------------
# Training loss: 0.104601
# Validation loss: 0.121548
#
# Epoch 2442
# -------------------------------
# Training loss: 0.102824
# Validation loss: 0.106061
#
# Epoch 2443
# -------------------------------
# Training loss: 0.103827
# Validation loss: 0.107717
#
# Epoch 2444
# -------------------------------
# Training loss: 0.104836
# Validation loss: 0.108013
#
# Epoch 2445
# -------------------------------
# Training loss: 0.104670
# Validation loss: 0.114716
#
# Epoch 2446
# -------------------------------
# Training loss: 0.103429
# Validation loss: 0.103953
#
# Epoch 2447
# -------------------------------
# Training loss: 0.104516
# Validation loss: 0.107348
#
# Epoch 2448
# -------------------------------
# Training loss: 0.102104
# Validation loss: 0.108066
#
# Epoch 2449
# -------------------------------
# Training loss: 0.101834
# Validation loss: 0.109907
#
# Epoch 2450
# -------------------------------
# Training loss: 0.102960
# Validation loss: 0.106706
#
# Epoch 2451
# -------------------------------
# Training loss: 0.103602
# Validation loss: 0.104642
#
# Epoch 2452
# -------------------------------
# Training loss: 0.101332
# Validation loss: 0.106929
#
# Epoch 2453
# -------------------------------
# Training loss: 0.103511
# Validation loss: 0.111643
#
# Epoch 2454
# -------------------------------
# Training loss: 0.102751
# Validation loss: 0.104769
#
# Epoch 2455
# -------------------------------
# Training loss: 0.102927
# Validation loss: 0.113193
#
# Epoch 2456
# -------------------------------
# Training loss: 0.104133
# Validation loss: 0.106882
#
# Epoch 2457
# -------------------------------
# Training loss: 0.100768
# Validation loss: 0.115337
#
# Epoch 2458
# -------------------------------
# Training loss: 0.103259
# Validation loss: 0.105740
#
# Epoch 2459
# -------------------------------
# Training loss: 0.102009
# Validation loss: 0.135044
#
# Epoch 2460
# -------------------------------
# Training loss: 0.101836
# Validation loss: 0.107676
#
# Epoch 2461
# -------------------------------
# Training loss: 0.103052
# Validation loss: 0.102358
#
# Epoch 2462
# -------------------------------
# Training loss: 0.101310
# Validation loss: 0.107101
#
# Epoch 2463
# -------------------------------
# Training loss: 0.104202
# Validation loss: 0.103682
#
# Epoch 2464
# -------------------------------
# Training loss: 0.102264
# Validation loss: 0.108546
#
# Epoch 2465
# -------------------------------
# Training loss: 0.104271
# Validation loss: 0.105893
#
# Epoch 2466
# -------------------------------
# Training loss: 0.107105
# Validation loss: 0.104092
#
# Epoch 2467
# -------------------------------
# Training loss: 0.108659
# Validation loss: 0.107445
#
# Epoch 2468
# -------------------------------
# Training loss: 0.105729
# Validation loss: 0.107082
#
# Epoch 2469
# -------------------------------
# Training loss: 0.102764
# Validation loss: 0.106504
#
# Epoch 2470
# -------------------------------
# Training loss: 0.105099
# Validation loss: 0.109333
#
# Epoch 2471
# -------------------------------
# Training loss: 0.107336
# Validation loss: 0.104391
#
# Epoch 2472
# -------------------------------
# Training loss: 0.102252
# Validation loss: 0.108548
#
# Epoch 2473
# -------------------------------
# Training loss: 0.102747
# Validation loss: 0.107965
#
# Epoch 2474
# -------------------------------
# Training loss: 0.102470
# Validation loss: 0.112992
#
# Epoch 2475
# -------------------------------
# Training loss: 0.103588
# Validation loss: 0.110450
#
# Epoch 2476
# -------------------------------
# Training loss: 0.103132
# Validation loss: 0.124504
#
# Epoch 2477
# -------------------------------
# Training loss: 0.101936
# Validation loss: 0.104194
#
# Epoch 2478
# -------------------------------
# Training loss: 0.101219
# Validation loss: 0.107723
#
# Epoch 2479
# -------------------------------
# Training loss: 0.100774
# Validation loss: 0.111947
#
# Epoch 2480
# -------------------------------
# Training loss: 0.104376
# Validation loss: 0.103687
#
# Epoch 2481
# -------------------------------
# Training loss: 0.102035
# Validation loss: 0.104001
#
# Epoch 2482
# -------------------------------
# Training loss: 0.102408
# Validation loss: 0.103821
#
# Epoch 2483
# -------------------------------
# Training loss: 0.104917
# Validation loss: 0.108979
#
# Epoch 2484
# -------------------------------
# Training loss: 0.105914
# Validation loss: 0.104702
#
# Epoch 2485
# -------------------------------
# Training loss: 0.101273
# Validation loss: 0.120011
#
# Epoch 2486
# -------------------------------
# Training loss: 0.102627
# Validation loss: 0.102140
#
# Epoch 2487
# -------------------------------
# Training loss: 0.102028
# Validation loss: 0.107612
#
# Epoch 2488
# -------------------------------
# Training loss: 0.103102
# Validation loss: 0.103557
#
# Epoch 2489
# -------------------------------
# Training loss: 0.102927
# Validation loss: 0.126336
#
# Epoch 2490
# -------------------------------
# Training loss: 0.102331
# Validation loss: 0.104859
#
# Epoch 2491
# -------------------------------
# Training loss: 0.102864
# Validation loss: 0.104618
#
# Epoch 2492
# -------------------------------
# Training loss: 0.101770
# Validation loss: 0.112020
#
# Epoch 2493
# -------------------------------
# Training loss: 0.101004
# Validation loss: 0.113319
#
# Epoch 2494
# -------------------------------
# Training loss: 0.102399
# Validation loss: 0.102201
#
# Epoch 2495
# -------------------------------
# Training loss: 0.100400
# Validation loss: 0.106405
#
# Epoch 2496
# -------------------------------
# Training loss: 0.100905
# Validation loss: 0.108248
#
# Epoch 2497
# -------------------------------
# Training loss: 0.105639
# Validation loss: 0.106900
#
# Epoch 2498
# -------------------------------
# Training loss: 0.102055
# Validation loss: 0.100587
#
# Epoch 2499
# -------------------------------
# Training loss: 0.100682
# Validation loss: 0.137535
#
# Epoch 2500
# -------------------------------
# Training loss: 0.101089
# Validation loss: 0.105401
#
# Done!

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses)+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('BCE Loss')
#plt.yscale('log')
plt.legend()

# %%
# Now test the pretrained model
test_pred = mytools.test_clas(test_loader, final_classifier, device)
test_pred=torch.sigmoid(torch.tensor(test_pred)).numpy()


fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test, test_pred, pos_label=1)
auc_test = sklearn.metrics.auc(fpr, tpr)
print(f'Test AUROC: {auc_test:0.4f}')

plt.plot(fpr, tpr, label=f'Test AUROC: {auc_test:0.4f}')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
# Out:
# Test AUROC: 0.9938

# %%
# Store the pretrained classifier labels
df_test["Class_pre"] = test_pred

# Save the pretrained classifier model
torch.save(final_classifier.state_dict(), "/Users/mghrear/data/ML_data/patch/pretrained_classifier_2021_v9_pass5_TC_run"+str(run)+".pt")

# %% [markdown]
# # Setup the adversary model

# %% [markdown]
# ## Initialize model, objective function, and optimizer

# %%
adv = mytools.Adversary(n_classes=Num_classes).to(device)
criterion_adv = nn.CrossEntropyLoss(reduction='none')  # returns loss per sample so we can weight it
opt_adv = torch.optim.Adam(adv.parameters(), lr=1e-5)
scheduler_adv = torch.optim.lr_scheduler.ExponentialLR(opt_adv, gamma=0.999)

# %% [markdown]
# ## Setup dataloaders

# %%
# Convert to tensor dataset and dataloader

# the structure is: feature, adversary label, weight
# The wight is 1 for tritrig and wab, and 0 for phiKK, to prevent the adversary from learning on phiKK events

train_adv_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_train), (torch.from_numpy(y_train.to_numpy().astype(np.float32))==0).float())
train_adv_loader = DataLoader(train_adv_dataset, batch_size=bsize, shuffle=True)

val_adv_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_val), (torch.from_numpy(y_val.to_numpy().astype(np.float32))==0).float() )
val_adv_loader = DataLoader(val_adv_dataset, batch_size=bsize, shuffle=True)

# Weights are not relavent for testing
test_adv_dataset = TensorDataset(torch.from_numpy(X_test.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_test))
test_adv_loader = DataLoader(test_adv_dataset, batch_size=bsize, shuffle=True)

# %% [markdown]
# ## Pre-train the adversary leaving classifier weights fixed

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 6

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 100
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train_adv(train_adv_loader, final_classifier, adv, criterion_adv, opt_adv, scheduler_adv, device))
    Validation_losses = np.append(Validation_losses, mytools.validate_adv(val_adv_loader, final_classifier, adv, criterion_adv, device))
    
    # Keep a running copy of the model with the lowest loss
    if Validation_losses[-1] == np.min(Validation_losses):
        final_adv = copy.deepcopy(adv)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Training loss: 1.645376
# Validation loss: 1.617419
#
# Epoch 2
# -------------------------------
# Training loss: 1.639671
# Validation loss: 1.625561
#
# Epoch 3
# -------------------------------
# Training loss: 1.634973
# Validation loss: 1.631991
#
# Epoch 4
# -------------------------------
# Training loss: 1.630156
# Validation loss: 1.629839
#
# Epoch 5
# -------------------------------
# Training loss: 1.625881
# Validation loss: 1.624850
#
# Epoch 6
# -------------------------------
# Training loss: 1.621742
# Validation loss: 1.620630
#
# Epoch 7
# -------------------------------
# Training loss: 1.618017
# Validation loss: 1.619335
#
# Epoch 8
# -------------------------------
# Training loss: 1.614877
# Validation loss: 1.615323
#
# Epoch 9
# -------------------------------
# Training loss: 1.612169
# Validation loss: 1.612288
#
# Epoch 10
# -------------------------------
# Training loss: 1.609563
# Validation loss: 1.612301
#
# Epoch 11
# -------------------------------
# Training loss: 1.607195
# Validation loss: 1.609405
#
# Epoch 12
# -------------------------------
# Training loss: 1.605776
# Validation loss: 1.605903
#
# Epoch 13
# -------------------------------
# Training loss: 1.604275
# Validation loss: 1.604549
#
# Epoch 14
# -------------------------------
# Training loss: 1.603005
# Validation loss: 1.604172
#
# Epoch 15
# -------------------------------
# Training loss: 1.601827
# Validation loss: 1.603208
#
# Epoch 16
# -------------------------------
# Training loss: 1.600278
# Validation loss: 1.601425
#
# Epoch 17
# -------------------------------
# Training loss: 1.599302
# Validation loss: 1.603491
#
# Epoch 18
# -------------------------------
# Training loss: 1.598562
# Validation loss: 1.601238
#
# Epoch 19
# -------------------------------
# Training loss: 1.597696
# Validation loss: 1.599621
#
# Epoch 20
# -------------------------------
# Training loss: 1.597177
# Validation loss: 1.598535
#
# Epoch 21
# -------------------------------
# Training loss: 1.596309
# Validation loss: 1.597883
#
# Epoch 22
# -------------------------------
# Training loss: 1.595690
# Validation loss: 1.597961
#
# Epoch 23
# -------------------------------
# Training loss: 1.595321
# Validation loss: 1.596358
#
# Epoch 24
# -------------------------------
# Training loss: 1.595048
# Validation loss: 1.596897
#
# Epoch 25
# -------------------------------
# Training loss: 1.594699
# Validation loss: 1.595345
#
# Epoch 26
# -------------------------------
# Training loss: 1.594166
# Validation loss: 1.594473
#
# Epoch 27
# -------------------------------
# Training loss: 1.593983
# Validation loss: 1.595668
#
# Epoch 28
# -------------------------------
# Training loss: 1.594066
# Validation loss: 1.594668
#
# Epoch 29
# -------------------------------
# Training loss: 1.593793
# Validation loss: 1.596676
#
# Epoch 30
# -------------------------------
# Training loss: 1.593517
# Validation loss: 1.594781
#
# Epoch 31
# -------------------------------
# Training loss: 1.593580
# Validation loss: 1.593781
#
# Epoch 32
# -------------------------------
# Training loss: 1.592937
# Validation loss: 1.594522
#
# Epoch 33
# -------------------------------
# Training loss: 1.592690
# Validation loss: 1.592760
#
# Epoch 34
# -------------------------------
# Training loss: 1.592637
# Validation loss: 1.593497
#
# Epoch 35
# -------------------------------
# Training loss: 1.592532
# Validation loss: 1.593862
#
# Epoch 36
# -------------------------------
# Training loss: 1.592785
# Validation loss: 1.593701
#
# Epoch 37
# -------------------------------
# Training loss: 1.592096
# Validation loss: 1.594155
#
# Epoch 38
# -------------------------------
# Training loss: 1.592187
# Validation loss: 1.593146
#
# Epoch 39
# -------------------------------
# Training loss: 1.592430
# Validation loss: 1.594602
#
# Epoch 40
# -------------------------------
# Training loss: 1.592104
# Validation loss: 1.592756
#
# Epoch 41
# -------------------------------
# Training loss: 1.591947
# Validation loss: 1.593330
#
# Epoch 42
# -------------------------------
# Training loss: 1.591775
# Validation loss: 1.593664
#
# Epoch 43
# -------------------------------
# Training loss: 1.592005
# Validation loss: 1.592920
#
# Epoch 44
# -------------------------------
# Training loss: 1.591645
# Validation loss: 1.594404
#
# Epoch 45
# -------------------------------
# Training loss: 1.591529
# Validation loss: 1.593375
#
# Epoch 46
# -------------------------------
# Training loss: 1.591177
# Validation loss: 1.593584
#
# Epoch 47
# -------------------------------
# Training loss: 1.591404
# Validation loss: 1.592027
#
# Epoch 48
# -------------------------------
# Training loss: 1.590918
# Validation loss: 1.591940
#
# Epoch 49
# -------------------------------
# Training loss: 1.591093
# Validation loss: 1.593189
#
# Epoch 50
# -------------------------------
# Training loss: 1.590876
# Validation loss: 1.592666
#
# Epoch 51
# -------------------------------
# Training loss: 1.590982
# Validation loss: 1.592684
#
# Epoch 52
# -------------------------------
# Training loss: 1.590406
# Validation loss: 1.592409
#
# Epoch 53
# -------------------------------
# Training loss: 1.590789
# Validation loss: 1.591069
#
# Epoch 54
# -------------------------------
# Training loss: 1.590473
# Validation loss: 1.591961
#
# Epoch 55
# -------------------------------
# Training loss: 1.590496
# Validation loss: 1.591625
#
# Epoch 56
# -------------------------------
# Training loss: 1.590164
# Validation loss: 1.592310
#
# Epoch 57
# -------------------------------
# Training loss: 1.590323
# Validation loss: 1.592138
#
# Epoch 58
# -------------------------------
# Training loss: 1.590667
# Validation loss: 1.589421
#
# Epoch 59
# -------------------------------
# Training loss: 1.590242
# Validation loss: 1.592287
#
# Epoch 60
# -------------------------------
# Training loss: 1.590278
# Validation loss: 1.593351
#
# Epoch 61
# -------------------------------
# Training loss: 1.590118
# Validation loss: 1.593418
#
# Epoch 62
# -------------------------------
# Training loss: 1.590145
# Validation loss: 1.593577
#
# Epoch 63
# -------------------------------
# Training loss: 1.590368
# Validation loss: 1.592651
#
# Epoch 64
# -------------------------------
# Training loss: 1.590137
# Validation loss: 1.591136
#
# Epoch 65
# -------------------------------
# Training loss: 1.590288
# Validation loss: 1.592573
#
# Epoch 66
# -------------------------------
# Training loss: 1.589911
# Validation loss: 1.593081
#
# Epoch 67
# -------------------------------
# Training loss: 1.589743
# Validation loss: 1.593297
#
# Epoch 68
# -------------------------------
# Training loss: 1.590022
# Validation loss: 1.590231
#
# Epoch 69
# -------------------------------
# Training loss: 1.589756
# Validation loss: 1.592930
#
# Epoch 70
# -------------------------------
# Training loss: 1.589925
# Validation loss: 1.589673
#
# Epoch 71
# -------------------------------
# Training loss: 1.589426
# Validation loss: 1.590682
#
# Epoch 72
# -------------------------------
# Training loss: 1.589881
# Validation loss: 1.595064
#
# Epoch 73
# -------------------------------
# Training loss: 1.589622
# Validation loss: 1.592690
#
# Epoch 74
# -------------------------------
# Training loss: 1.589908
# Validation loss: 1.592471
#
# Epoch 75
# -------------------------------
# Training loss: 1.589803
# Validation loss: 1.591228
#
# Epoch 76
# -------------------------------
# Training loss: 1.589311
# Validation loss: 1.590193
#
# Epoch 77
# -------------------------------
# Training loss: 1.589734
# Validation loss: 1.591263
#
# Epoch 78
# -------------------------------
# Training loss: 1.589545
# Validation loss: 1.593131
#
# Epoch 79
# -------------------------------
# Training loss: 1.589673
# Validation loss: 1.592142
#
# Epoch 80
# -------------------------------
# Training loss: 1.589657
# Validation loss: 1.593148
#
# Epoch 81
# -------------------------------
# Training loss: 1.589280
# Validation loss: 1.592638
#
# Epoch 82
# -------------------------------
# Training loss: 1.589336
# Validation loss: 1.591780
#
# Epoch 83
# -------------------------------
# Training loss: 1.589281
# Validation loss: 1.593454
#
# Epoch 84
# -------------------------------
# Training loss: 1.589008
# Validation loss: 1.591020
#
# Epoch 85
# -------------------------------
# Training loss: 1.589096
# Validation loss: 1.592473
#
# Epoch 86
# -------------------------------
# Training loss: 1.589100
# Validation loss: 1.591967
#
# Epoch 87
# -------------------------------
# Training loss: 1.589414
# Validation loss: 1.591439
#
# Epoch 88
# -------------------------------
# Training loss: 1.589424
# Validation loss: 1.593400
#
# Epoch 89
# -------------------------------
# Training loss: 1.589075
# Validation loss: 1.591822
#
# Epoch 90
# -------------------------------
# Training loss: 1.588782
# Validation loss: 1.591625
#
# Epoch 91
# -------------------------------
# Training loss: 1.589084
# Validation loss: 1.593362
#
# Epoch 92
# -------------------------------
# Training loss: 1.589167
# Validation loss: 1.591013
#
# Epoch 93
# -------------------------------
# Training loss: 1.589406
# Validation loss: 1.592665
#
# Epoch 94
# -------------------------------
# Training loss: 1.589054
# Validation loss: 1.591986
#
# Epoch 95
# -------------------------------
# Training loss: 1.588757
# Validation loss: 1.590660
#
# Epoch 96
# -------------------------------
# Training loss: 1.589210
# Validation loss: 1.590751
#
# Epoch 97
# -------------------------------
# Training loss: 1.589321
# Validation loss: 1.590202
#
# Epoch 98
# -------------------------------
# Training loss: 1.589310
# Validation loss: 1.590579
#
# Epoch 99
# -------------------------------
# Training loss: 1.589122
# Validation loss: 1.593464
#
# Epoch 100
# -------------------------------
# Training loss: 1.588839
# Validation loss: 1.591574
#
# Done!

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses)+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('BCE Loss')
plt.legend()

# %% [markdown]
# # Train full adverserial neural network

# %% [markdown]
# # Setup dataloaders

# %%
# the structure is: feature, classifier label, adversary label, weight
# The wight is 1 for tritrig and wab, and 0 for phiKK, to prevent the adversary from learning on phiKK events

train_full_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy().astype(np.float32))  , torch.from_numpy(y_train.to_numpy().astype(np.float32)).unsqueeze(1), torch.from_numpy(y_adv_train),  (torch.from_numpy(y_train.to_numpy().astype(np.float32))==0).float())
train_full_loader = DataLoader(train_full_dataset, batch_size=bsize, shuffle=True)

val_full_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy().astype(np.float32))  , torch.from_numpy(y_val.to_numpy().astype(np.float32)).unsqueeze(1),  torch.from_numpy(y_adv_val),  (torch.from_numpy(y_val.to_numpy().astype(np.float32))==0).float())
val_full_loader = DataLoader(val_full_dataset, batch_size=bsize, shuffle=True)

# %% [markdown]
# ## Define loss functions

# %%
BCE_loss = nn.BCEWithLogitsLoss()
CE_loss = nn.CrossEntropyLoss(reduction='none') # returns loss per sample so we can weight it

def full_loss(output_clas, output_adv, target_clas, target_adv, w, lambda_):

    loss1 = BCE_loss(output_clas, target_clas )  # classification loss
    sample_losses2 = CE_loss(output_adv, target_adv)  # adversarial losses, since we set reduction='none', this is now a vector of losses, one per sample in the batch

    # Weighted mean loss over non-zero weights
    nonzero = w > 0
    loss2 = (sample_losses2[nonzero] * w[nonzero]).sum() / w[nonzero].sum()

    loss = loss1 - lambda_*loss2

    return loss

# %% [markdown]
# ## Setup optimizers

# %%
optimizer_clas = optim.Adam(final_classifier.parameters(), lr=1e-7,betas=(0.5, 0.999))
optimizer_adv = optim.Adam(final_adv.parameters(), lr=1e-5,betas=(0.5, 0.999))

scheduler_clas = torch.optim.lr_scheduler.ExponentialLR(optimizer_clas, gamma=0.999)
scheduler_adv = torch.optim.lr_scheduler.ExponentialLR(optimizer_adv, gamma=0.999)

# %% [markdown]
# ## Adversarial training

# %%
Training_losses_clas = np.array([])
Training_losses_adv = np.array([])
Validation_losses_clas = np.array([])
Validation_losses_adv = np.array([])
diff_scores = np.array([])


epochs = 50
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")

    # Get validation losses
    E_clas_val_loss, E_adv_val_loss = mytools.validate_full(val_full_loader, final_classifier, final_adv, full_loss, lambda_, criterion_adv, device)
    Validation_losses_clas = np.append(Validation_losses_clas, E_clas_val_loss)
    Validation_losses_adv = np.append(Validation_losses_adv, E_adv_val_loss)

    # Train adversary and classifier
    E_clas_training_loss , E_adv_training_loss = mytools.train_full(train_full_loader, final_classifier, final_adv, full_loss, lambda_, criterion_adv, optimizer_clas, optimizer_adv, scheduler_clas, scheduler_adv, device)
    Training_losses_clas = np.append(Training_losses_clas, E_clas_training_loss)
    Training_losses_adv = np.append(Training_losses_adv, E_adv_training_loss)

    # Get the diff_score
    df_test["Class_adv"] = mytools.test_clas(test_loader, final_classifier, device)
    df_bkg = df_test.loc[ (df_test.type == 'tritrig') | (df_test.type == 'wab')]
    per = np.percentile(df_bkg['Class_adv'],99)
    df_cut = df_bkg[df_bkg['Class_adv']>per].reset_index(drop=True)
    x1 = 1000* df_bkg.InvM.values
    x2 = 1000*df_cut.InvM.values
    diff_scores = np.append(diff_scores, mytools.get_diff_score(x1,x2) )

    # Keep a running copy of the model with the lowest loss
    if diff_scores[-1] == np.min(diff_scores):
        final_clas_adv = copy.deepcopy(final_classifier)
        final_adv_adv = copy.deepcopy(final_adv)

            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Classifier validation loss: -158.971185
# Adversary validation loss: 1.590703
# Classifier training loss: -159.950977
# Adversary training loss: 1.601258
# Epoch 2
# -------------------------------
# Classifier validation loss: -160.368665
# Adversary validation loss: 1.604769
# Classifier training loss: -159.863807
# Adversary training loss: 1.600408
# Epoch 3
# -------------------------------
# Classifier validation loss: -160.008267
# Adversary validation loss: 1.601133
# Classifier training loss: -160.056737
# Adversary training loss: 1.602099
# Epoch 4
# -------------------------------
# Classifier validation loss: -160.025339
# Adversary validation loss: 1.601275
# Classifier training loss: -159.711121
# Adversary training loss: 1.598578
# Epoch 5
# -------------------------------
# Classifier validation loss: -160.093408
# Adversary validation loss: 1.601956
# Classifier training loss: -160.102359
# Adversary training loss: 1.602485
# Epoch 6
# -------------------------------
# Classifier validation loss: -160.084784
# Adversary validation loss: 1.601913
# Classifier training loss: -160.276915
# Adversary training loss: 1.604594
# Epoch 7
# -------------------------------
# Classifier validation loss: -160.422842
# Adversary validation loss: 1.605314
# Classifier training loss: -160.344225
# Adversary training loss: 1.605302
# Epoch 8
# -------------------------------
# Classifier validation loss: -160.737335
# Adversary validation loss: 1.608499
# Classifier training loss: -161.196935
# Adversary training loss: 1.613851
# Epoch 9
# -------------------------------
# Classifier validation loss: -161.095996
# Adversary validation loss: 1.612177
# Classifier training loss: -161.179206
# Adversary training loss: 1.613661
# Epoch 10
# -------------------------------
# Classifier validation loss: -161.362650
# Adversary validation loss: 1.614877
# Classifier training loss: -161.345734
# Adversary training loss: 1.615290
# Epoch 11
# -------------------------------
# Classifier validation loss: -161.554840
# Adversary validation loss: 1.616871
# Classifier training loss: -161.552439
# Adversary training loss: 1.617333
# Epoch 12
# -------------------------------
# Classifier validation loss: -161.694827
# Adversary validation loss: 1.618371
# Classifier training loss: -161.619251
# Adversary training loss: 1.617992
# Epoch 13
# -------------------------------
# Classifier validation loss: -161.667532
# Adversary validation loss: 1.618187
# Classifier training loss: -161.614887
# Adversary training loss: 1.617970
# Epoch 14
# -------------------------------
# Classifier validation loss: -161.627411
# Adversary validation loss: 1.617910
# Classifier training loss: -161.632848
# Adversary training loss: 1.618230
# Epoch 15
# -------------------------------
# Classifier validation loss: -161.562949
# Adversary validation loss: 1.617280
# Classifier training loss: -161.508906
# Adversary training loss: 1.616940
# Epoch 16
# -------------------------------
# Classifier validation loss: -161.470712
# Adversary validation loss: 1.616418
# Classifier training loss: -161.368647
# Adversary training loss: 1.615544
# Epoch 17
# -------------------------------
# Classifier validation loss: -161.321600
# Adversary validation loss: 1.614963
# Classifier training loss: -161.254523
# Adversary training loss: 1.614441
# Epoch 18
# -------------------------------
# Classifier validation loss: -161.328726
# Adversary validation loss: 1.615135
# Classifier training loss: -161.208442
# Adversary training loss: 1.614038
# Epoch 19
# -------------------------------
# Classifier validation loss: -161.238449
# Adversary validation loss: 1.614245
# Classifier training loss: -161.033242
# Adversary training loss: 1.612289
# Epoch 20
# -------------------------------
# Classifier validation loss: -161.022546
# Adversary validation loss: 1.612089
# Classifier training loss: -161.057053
# Adversary training loss: 1.612603
# Epoch 21
# -------------------------------
# Classifier validation loss: -160.985532
# Adversary validation loss: 1.611793
# Classifier training loss: -160.947479
# Adversary training loss: 1.611495
# Epoch 22
# -------------------------------
# Classifier validation loss: -160.811539
# Adversary validation loss: 1.610146
# Classifier training loss: -160.891663
# Adversary training loss: 1.610952
# Epoch 23
# -------------------------------
# Classifier validation loss: -160.725327
# Adversary validation loss: 1.609200
# Classifier training loss: -160.785760
# Adversary training loss: 1.609930
# Epoch 24
# -------------------------------
# Classifier validation loss: -160.855734
# Adversary validation loss: 1.610555
# Classifier training loss: -160.661350
# Adversary training loss: 1.608681
# Epoch 25
# -------------------------------
# Classifier validation loss: -160.629065
# Adversary validation loss: 1.608359
# Classifier training loss: -160.593318
# Adversary training loss: 1.608022
# Epoch 26
# -------------------------------
# Classifier validation loss: -160.563898
# Adversary validation loss: 1.607655
# Classifier training loss: -160.649763
# Adversary training loss: 1.608678
# Epoch 27
# -------------------------------
# Classifier validation loss: -160.323837
# Adversary validation loss: 1.605294
# Classifier training loss: -160.519155
# Adversary training loss: 1.607351
# Epoch 28
# -------------------------------
# Classifier validation loss: -160.389798
# Adversary validation loss: 1.605997
# Classifier training loss: -160.535424
# Adversary training loss: 1.607539
# Epoch 29
# -------------------------------
# Classifier validation loss: -160.545926
# Adversary validation loss: 1.607565
# Classifier training loss: -160.424279
# Adversary training loss: 1.606454
# Epoch 30
# -------------------------------
# Classifier validation loss: -160.326251
# Adversary validation loss: 1.605468
# Classifier training loss: -160.461463
# Adversary training loss: 1.606822
# Epoch 31
# -------------------------------
# Classifier validation loss: -160.354883
# Adversary validation loss: 1.605742
# Classifier training loss: -160.385635
# Adversary training loss: 1.606079
# Epoch 32
# -------------------------------
# Classifier validation loss: -160.282227
# Adversary validation loss: 1.604996
# Classifier training loss: -160.362610
# Adversary training loss: 1.605885
# Epoch 33
# -------------------------------
# Classifier validation loss: -160.142578
# Adversary validation loss: 1.603658
# Classifier training loss: -160.317137
# Adversary training loss: 1.605425
# Epoch 34
# -------------------------------
# Classifier validation loss: -160.205264
# Adversary validation loss: 1.604320
# Classifier training loss: -160.328551
# Adversary training loss: 1.605595
# Epoch 35
# -------------------------------
# Classifier validation loss: -160.216992
# Adversary validation loss: 1.604441
# Classifier training loss: -160.381646
# Adversary training loss: 1.606132
# Epoch 36
# -------------------------------
# Classifier validation loss: -160.220105
# Adversary validation loss: 1.604494
# Classifier training loss: -160.256705
# Adversary training loss: 1.604914
# Epoch 37
# -------------------------------
# Classifier validation loss: -160.212308
# Adversary validation loss: 1.604409
# Classifier training loss: -160.347692
# Adversary training loss: 1.605854
# Epoch 38
# -------------------------------
# Classifier validation loss: -160.172174
# Adversary validation loss: 1.604058
# Classifier training loss: -160.304710
# Adversary training loss: 1.605406
# Epoch 39
# -------------------------------
# Classifier validation loss: -160.272607
# Adversary validation loss: 1.605040
# Classifier training loss: -160.271345
# Adversary training loss: 1.605119
# Epoch 40
# -------------------------------
# Classifier validation loss: -160.130408
# Adversary validation loss: 1.603731
# Classifier training loss: -160.358344
# Adversary training loss: 1.606007
# Epoch 41
# -------------------------------
# Classifier validation loss: -160.217032
# Adversary validation loss: 1.604635
# Classifier training loss: -160.259615
# Adversary training loss: 1.605043
# Epoch 42
# -------------------------------
# Classifier validation loss: -160.282043
# Adversary validation loss: 1.605334
# Classifier training loss: -160.312844
# Adversary training loss: 1.605591
# Epoch 43
# -------------------------------
# Classifier validation loss: -160.345151
# Adversary validation loss: 1.605844
# Classifier training loss: -160.274319
# Adversary training loss: 1.605214
# Epoch 44
# -------------------------------
# Classifier validation loss: -160.166061
# Adversary validation loss: 1.604006
# Classifier training loss: -160.289254
# Adversary training loss: 1.605357
# Epoch 45
# -------------------------------
# Classifier validation loss: -160.201019
# Adversary validation loss: 1.604358
# Classifier training loss: -160.278631
# Adversary training loss: 1.605255
# Epoch 46
# -------------------------------
# Classifier validation loss: -160.212000
# Adversary validation loss: 1.604577
# Classifier training loss: -160.282957
# Adversary training loss: 1.605323
# Epoch 47
# -------------------------------
# Classifier validation loss: -160.092523
# Adversary validation loss: 1.603419
# Classifier training loss: -160.207982
# Adversary training loss: 1.604611
# Epoch 48
# -------------------------------
# Classifier validation loss: -160.104761
# Adversary validation loss: 1.603615
# Classifier training loss: -160.270450
# Adversary training loss: 1.605246
# Epoch 49
# -------------------------------
# Classifier validation loss: -160.106149
# Adversary validation loss: 1.603677
# Classifier training loss: -160.236040
# Adversary training loss: 1.604894
# Epoch 50
# -------------------------------
# Classifier validation loss: -160.052124
# Adversary validation loss: 1.603046
# Classifier training loss: -160.217831
# Adversary training loss: 1.604694
# Done!

# %%
fig, ax1 = plt.subplots()

best_epoch = np.argmin(diff_scores)+1



#ax1.plot(np.arange(len(Training_losses_adv))+1, Training_losses_adv, 'k-', label='Training Adversary')
ax1.plot(np.arange(len(Validation_losses_adv))+1, Validation_losses_adv, 'k-', label='Validation Adversary')

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Adversary Loss', color='k')
ax1.tick_params(axis='y', labelcolor='k')

ax2 = ax1.twinx()

#ax2.plot(np.arange(len(Training_losses_clas))+1, Training_losses_clas, 'r-', label='Training Classifier')
ax2.plot(np.arange(len(Validation_losses_clas))+1, Validation_losses_clas, 'r-', label='Validation Classifier')
ax2.axvline(best_epoch,label="Final model stopped here",color='k')

ax2.set_ylabel('Classifier Loss', color='r')
ax2.tick_params(axis='y', labelcolor='r')

# %% [markdown]
# ## Test adversarially trained models

# %%
# Now test the pretrained model
test_pred = mytools.test_clas(test_loader, final_clas_adv, device)
test_pred=torch.sigmoid(torch.tensor(test_pred)).numpy()


fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test, test_pred, pos_label=1)
auc_test = sklearn.metrics.auc(fpr, tpr)
print(f'Test AUROC: {auc_test:0.4f}')

plt.plot(fpr, tpr, label=f'Test AUROC: {auc_test:0.4f}')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
# Out:
# Test AUROC: 0.9928

# %%
df_test["Class_adv"] = test_pred
df_bkg = df_test.loc[ (df_test.type == 'tritrig') | (df_test.type == 'wab')]
per = np.percentile(df_bkg['Class_adv'],99)
df_cut = df_bkg[df_bkg['Class_adv']>per].reset_index(drop=True)
x_vals = 1000*df_cut.InvM

plt.figure()
plt.hist(1000*df_bkg.InvM, bins=np.arange(980,1250,1), histtype='step', label='No selection', density=True)
plt.hist(x_vals, bins=np.arange(980,1250,1), histtype='step', label= '99 percent selection', density=True)
plt.axvline(1019.461, color='k', linestyle='dashed', linewidth=1, label='PDG phi mass')
plt.xlabel('Invariant Mass [MeV]')
plt.ylabel('Normalized Counts')
plt.legend()

# %%
x1 = 1000* df_bkg.InvM.values
x2 = 1000*df_cut.InvM.values

N, edges = np.histogram(x1, bins=np.arange(980,1250,1), density=False)
M, edges = np.histogram(x2, bins=np.arange(980,1250,1), density=False)

N2 = N[(N > 0) & (M > 0)]
M2 = M[(N > 0) & (M > 0)]

diff_score = np.mean(np.abs(N2/np.sum(N)-M2/np.sum(M)) / (np.sqrt(N2)/np.sum(N) + np.sqrt(M2)/np.sum(M) ))

print(diff_score)

N = len(df_test.loc[ ((df_test.type == 'tritrig') | (df_test.type == 'wab')) & (df_test.InvM < (1.019 + 0.01) )  & (df_test.InvM > (1.019 - 0.01) ) & ( df_test['Class_adv']>per ) ] )
S = len(df_test.loc[ (df_test.type == 'phiKK') & (df_test.InvM < (1.019 + 0.01) )  & (df_test.InvM > (1.019 - 0.01) ) & ( df_test['Class_adv']>per )  ] )

print(S/N)
# Out:
# 0.7545206326519033
# 2.0772357723577235

# %%
# Save the adversarially trained models
torch.save(final_clas_adv.state_dict(), "/Users/mghrear/data/ML_data/patch/classifier_adv_2021_v9_pass5_TC_run"+str(run)+".pt")
torch.save(final_adv_adv.state_dict(), "/Users/mghrear/data/ML_data/patch/adversary_adv_2021_v9_pass5_TC_run"+str(run)+".pt")

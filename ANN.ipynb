# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import torch 
from torch import nn, optim
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import sklearn
from sklearn.model_selection import train_test_split
import copy
import mytools


# Print and store device being used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cpu

# %% [markdown]
# # Define important parameters

# %%
# Number of class in invariant mass used by the adversary
Num_classes = 5
# Hyper-parameter for adversarial training of the classifier
lambda_ = 100.0

run = 1

# %% [markdown]
# # Load and setup the data

# %%
df_tritrig = pd.read_pickle('/Users/mghrear/data/ML_data/2019_pass2/unscaled/2019_pass2_tritrig.pk')
df_tritrig['PhiKK'] = 0.0
df_phiKK = pd.read_pickle('/Users/mghrear/data/ML_data/2019_pass2/unscaled/2019_pass2_phiKK.pk')
df_phiKK['PhiKK'] = 1.0
df_wab = pd.read_pickle('/Users/mghrear/data/ML_data/2019_pass2/unscaled/2019_pass2_wab.pk')
df_wab['PhiKK'] = 0.0 # Add label


print("tritrig: ", len(df_tritrig))
print("phiKK: ", len(df_phiKK))
print("wab: ", len(df_wab))
# Out:
# tritrig:  149433
# phiKK:  6232
# wab:  16422

# %%
# Make Training set
tritrig_train = df_tritrig[0:50000]
wab_train = df_wab[0:6000]
phiKK_train = df_phiKK[0:5000]

# Combine and shuffle all training data
df_train = pd.concat([tritrig_train, phiKK_train, wab_train], ignore_index=True, sort=False)
df_train = df_train.sample(frac=1, random_state=42).reset_index(drop=True)

# Make a training set with balanced classes (as expected in data), used for scaling
df_train_balanced = pd.concat([df_phiKK[0:25], df_tritrig[0:(1470*25)] , df_wab[0:(228*25)]], ignore_index=True, sort=False).drop(columns=['PhiKK'])

# Get edges in invariant mass classes for one-hot encoding
# To be used for adverserial labels
# The edges are chosen such that each bin has equal number of background events
one_hot_edges = mytools.get_one_hot_edges(mytools.get_InvM( df_train_balanced ), n_bins=Num_classes)
np.save("one_hot_edges.npy", one_hot_edges)

# Split the training data into training and validation sets
df_train, df_val = train_test_split(df_train, test_size=0.33, random_state=42)

# Make X and y for training and validation sets
# the adverserial network has its own labels
X_train = df_train.drop(columns=['PhiKK'])
y_train = df_train['PhiKK']
y_adv_train = mytools.get_adv_labels( mytools.get_InvM(df_train), one_hot_edges)
X_val = df_val.drop(columns=['PhiKK'])
y_val = df_val['PhiKK']
y_adv_val = mytools.get_adv_labels( mytools.get_InvM(df_val), one_hot_edges)

# Make testing set with remaining events
tritrig_test = df_tritrig[50000:]
tritrig_test['type']= 'tritrig'
wab_test = df_wab[6000:]
wab_test['type']= 'wab'
phiKK_test = df_phiKK[5000:]
phiKK_test['type']= 'phiKK'

df_test = pd.concat([tritrig_test, phiKK_test,wab_test], ignore_index=True, sort=False)
df_test = df_test.sample(frac=1, random_state=42).reset_index(drop=True) # Now shuffle the combined dataframe

X_test = df_test.drop(columns=['PhiKK','type'])
y_test = df_test['PhiKK']
y_adv_test = mytools.get_adv_labels( mytools.get_InvM(df_test), one_hot_edges)

df_test["InvM"] = mytools.get_InvM(df_test)
# Out:
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_54798/584016212.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tritrig_test['type']= 'tritrig'
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_54798/584016212.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wab_test['type']= 'wab'
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_54798/584016212.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phiKK_test['type']= 'phiKK'

# %% [markdown]
# ## Setup dataloaders

# %%
bsize = 2000

# Convert to tensor dataset and dataloader
train_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy().astype(np.float32))  , torch.from_numpy(y_train.to_numpy().astype(np.float32)).unsqueeze(1)  )
train_loader = DataLoader(train_dataset, batch_size=bsize, shuffle=True)

val_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy().astype(np.float32))  , torch.from_numpy(y_val.to_numpy().astype(np.float32)).unsqueeze(1)  )
val_loader = DataLoader(val_dataset, batch_size=bsize, shuffle=True)

test_dataset = TensorDataset(torch.from_numpy(X_test.to_numpy().astype(np.float32)))
test_loader = DataLoader(test_dataset, batch_size=bsize, shuffle=False)

# %% [markdown]
# ## Initialize model, objective function, and optimizer

# %%
clas = mytools.Classifier(in_features=X_train.shape[1]).to(device)
criterion_clas = nn.BCEWithLogitsLoss()
optimizer_clas = optim.Adam(clas.parameters(), lr=1e-5)
scheduler_clas = torch.optim.lr_scheduler.ExponentialLR(optimizer_clas, gamma=0.9999)

# %% [markdown]
# ## Pre-train the classifier

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 10

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 2500
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train_clas(train_loader, clas, criterion_clas, optimizer_clas, scheduler_clas, device))
    Validation_losses = np.append(Validation_losses, mytools.validate_clas(val_loader, clas, criterion_clas, device))
    
    # Keep a running copy of the model with the lowest loss
    if Validation_losses[-1] == np.min(Validation_losses):
        final_classifier = copy.deepcopy(clas)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Training loss: 0.573445
# Validation loss: 0.636117
#
# Epoch 2
# -------------------------------
# Training loss: 0.546697
# Validation loss: 0.569385
#
# Epoch 3
# -------------------------------
# Training loss: 0.530965
# Validation loss: 0.517797
#
# Epoch 4
# -------------------------------
# Training loss: 0.520049
# Validation loss: 0.501894
#
# Epoch 5
# -------------------------------
# Training loss: 0.508490
# Validation loss: 0.500905
#
# Epoch 6
# -------------------------------
# Training loss: 0.500252
# Validation loss: 0.499491
#
# Epoch 7
# -------------------------------
# Training loss: 0.492201
# Validation loss: 0.496903
#
# Epoch 8
# -------------------------------
# Training loss: 0.484679
# Validation loss: 0.487282
#
# Epoch 9
# -------------------------------
# Training loss: 0.476761
# Validation loss: 0.473309
#
# Epoch 10
# -------------------------------
# Training loss: 0.471852
# Validation loss: 0.463885
#
# Epoch 11
# -------------------------------
# Training loss: 0.466207
# Validation loss: 0.451285
#
# Epoch 12
# -------------------------------
# Training loss: 0.461353
# Validation loss: 0.455788
#
# Epoch 13
# -------------------------------
# Training loss: 0.457090
# Validation loss: 0.459848
#
# Epoch 14
# -------------------------------
# Training loss: 0.451107
# Validation loss: 0.457203
#
# Epoch 15
# -------------------------------
# Training loss: 0.447691
# Validation loss: 0.449180
#
# Epoch 16
# -------------------------------
# Training loss: 0.443765
# Validation loss: 0.449631
#
# Epoch 17
# -------------------------------
# Training loss: 0.439103
# Validation loss: 0.438776
#
# Epoch 18
# -------------------------------
# Training loss: 0.436944
# Validation loss: 0.442638
#
# Epoch 19
# -------------------------------
# Training loss: 0.432362
# Validation loss: 0.431150
#
# Epoch 20
# -------------------------------
# Training loss: 0.430220
# Validation loss: 0.431775
#
# Epoch 21
# -------------------------------
# Training loss: 0.426161
# Validation loss: 0.424107
#
# Epoch 22
# -------------------------------
# Training loss: 0.422693
# Validation loss: 0.430805
#
# Epoch 23
# -------------------------------
# Training loss: 0.421047
# Validation loss: 0.423310
#
# Epoch 24
# -------------------------------
# Training loss: 0.417314
# Validation loss: 0.421208
#
# Epoch 25
# -------------------------------
# Training loss: 0.414710
# Validation loss: 0.419168
#
# Epoch 26
# -------------------------------
# Training loss: 0.412477
# Validation loss: 0.418109
#
# Epoch 27
# -------------------------------
# Training loss: 0.408952
# Validation loss: 0.407170
#
# Epoch 28
# -------------------------------
# Training loss: 0.407757
# Validation loss: 0.403423
#
# Epoch 29
# -------------------------------
# Training loss: 0.404511
# Validation loss: 0.403244
#
# Epoch 30
# -------------------------------
# Training loss: 0.401640
# Validation loss: 0.404858
#
# Epoch 31
# -------------------------------
# Training loss: 0.400806
# Validation loss: 0.397767
#
# Epoch 32
# -------------------------------
# Training loss: 0.398091
# Validation loss: 0.402579
#
# Epoch 33
# -------------------------------
# Training loss: 0.395972
# Validation loss: 0.397014
#
# Epoch 34
# -------------------------------
# Training loss: 0.393609
# Validation loss: 0.392963
#
# Epoch 35
# -------------------------------
# Training loss: 0.393565
# Validation loss: 0.383830
#
# Epoch 36
# -------------------------------
# Training loss: 0.390758
# Validation loss: 0.385147
#
# Epoch 37
# -------------------------------
# Training loss: 0.386940
# Validation loss: 0.394813
#
# Epoch 38
# -------------------------------
# Training loss: 0.385719
# Validation loss: 0.387723
#
# Epoch 39
# -------------------------------
# Training loss: 0.384219
# Validation loss: 0.382292
#
# Epoch 40
# -------------------------------
# Training loss: 0.381818
# Validation loss: 0.384236
#
# Epoch 41
# -------------------------------
# Training loss: 0.380311
# Validation loss: 0.376774
#
# Epoch 42
# -------------------------------
# Training loss: 0.378286
# Validation loss: 0.382265
#
# Epoch 43
# -------------------------------
# Training loss: 0.375984
# Validation loss: 0.382412
#
# Epoch 44
# -------------------------------
# Training loss: 0.374490
# Validation loss: 0.371801
#
# Epoch 45
# -------------------------------
# Training loss: 0.374223
# Validation loss: 0.369427
#
# Epoch 46
# -------------------------------
# Training loss: 0.372304
# Validation loss: 0.366126
#
# Epoch 47
# -------------------------------
# Training loss: 0.372168
# Validation loss: 0.372740
#
# Epoch 48
# -------------------------------
# Training loss: 0.370121
# Validation loss: 0.368057
#
# Epoch 49
# -------------------------------
# Training loss: 0.367519
# Validation loss: 0.365178
#
# Epoch 50
# -------------------------------
# Training loss: 0.365852
# Validation loss: 0.368766
#
# Epoch 51
# -------------------------------
# Training loss: 0.364678
# Validation loss: 0.368878
#
# Epoch 52
# -------------------------------
# Training loss: 0.363538
# Validation loss: 0.370455
#
# Epoch 53
# -------------------------------
# Training loss: 0.362957
# Validation loss: 0.372657
#
# Epoch 54
# -------------------------------
# Training loss: 0.360831
# Validation loss: 0.358358
#
# Epoch 55
# -------------------------------
# Training loss: 0.359493
# Validation loss: 0.362930
#
# Epoch 56
# -------------------------------
# Training loss: 0.358184
# Validation loss: 0.365166
#
# Epoch 57
# -------------------------------
# Training loss: 0.356988
# Validation loss: 0.357465
#
# Epoch 58
# -------------------------------
# Training loss: 0.355427
# Validation loss: 0.351482
#
# Epoch 59
# -------------------------------
# Training loss: 0.353758
# Validation loss: 0.360525
#
# Epoch 60
# -------------------------------
# Training loss: 0.352681
# Validation loss: 0.350164
#
# Epoch 61
# -------------------------------
# Training loss: 0.352044
# Validation loss: 0.354194
#
# Epoch 62
# -------------------------------
# Training loss: 0.350373
# Validation loss: 0.354849
#
# Epoch 63
# -------------------------------
# Training loss: 0.349752
# Validation loss: 0.348418
#
# Epoch 64
# -------------------------------
# Training loss: 0.347717
# Validation loss: 0.353321
#
# Epoch 65
# -------------------------------
# Training loss: 0.346599
# Validation loss: 0.357463
#
# Epoch 66
# -------------------------------
# Training loss: 0.345695
# Validation loss: 0.337428
#
# Epoch 67
# -------------------------------
# Training loss: 0.345177
# Validation loss: 0.352492
#
# Epoch 68
# -------------------------------
# Training loss: 0.343770
# Validation loss: 0.352039
#
# Epoch 69
# -------------------------------
# Training loss: 0.342167
# Validation loss: 0.346567
#
# Epoch 70
# -------------------------------
# Training loss: 0.341743
# Validation loss: 0.348110
#
# Epoch 71
# -------------------------------
# Training loss: 0.340776
# Validation loss: 0.343270
#
# Epoch 72
# -------------------------------
# Training loss: 0.339144
# Validation loss: 0.339621
#
# Epoch 73
# -------------------------------
# Training loss: 0.337996
# Validation loss: 0.337843
#
# Epoch 74
# -------------------------------
# Training loss: 0.338163
# Validation loss: 0.350680
#
# Epoch 75
# -------------------------------
# Training loss: 0.335694
# Validation loss: 0.343798
#
# Epoch 76
# -------------------------------
# Training loss: 0.334627
# Validation loss: 0.339608
#
# Epoch 77
# -------------------------------
# Training loss: 0.334698
# Validation loss: 0.342353
#
# Epoch 78
# -------------------------------
# Training loss: 0.332101
# Validation loss: 0.327073
#
# Epoch 79
# -------------------------------
# Training loss: 0.331908
# Validation loss: 0.333825
#
# Epoch 80
# -------------------------------
# Training loss: 0.332346
# Validation loss: 0.339688
#
# Epoch 81
# -------------------------------
# Training loss: 0.329816
# Validation loss: 0.342186
#
# Epoch 82
# -------------------------------
# Training loss: 0.327962
# Validation loss: 0.331255
#
# Epoch 83
# -------------------------------
# Training loss: 0.330267
# Validation loss: 0.328629
#
# Epoch 84
# -------------------------------
# Training loss: 0.327463
# Validation loss: 0.341353
#
# Epoch 85
# -------------------------------
# Training loss: 0.326575
# Validation loss: 0.330386
#
# Epoch 86
# -------------------------------
# Training loss: 0.325684
# Validation loss: 0.335720
#
# Epoch 87
# -------------------------------
# Training loss: 0.325387
# Validation loss: 0.321780
#
# Epoch 88
# -------------------------------
# Training loss: 0.324101
# Validation loss: 0.326172
#
# Epoch 89
# -------------------------------
# Training loss: 0.323255
# Validation loss: 0.320091
#
# Epoch 90
# -------------------------------
# Training loss: 0.322165
# Validation loss: 0.329580
#
# Epoch 91
# -------------------------------
# Training loss: 0.321496
# Validation loss: 0.321329
#
# Epoch 92
# -------------------------------
# Training loss: 0.320666
# Validation loss: 0.328053
#
# Epoch 93
# -------------------------------
# Training loss: 0.319452
# Validation loss: 0.316454
#
# Epoch 94
# -------------------------------
# Training loss: 0.318982
# Validation loss: 0.335104
#
# Epoch 95
# -------------------------------
# Training loss: 0.317777
# Validation loss: 0.316607
#
# Epoch 96
# -------------------------------
# Training loss: 0.317967
# Validation loss: 0.325448
#
# Epoch 97
# -------------------------------
# Training loss: 0.316851
# Validation loss: 0.306793
#
# Epoch 98
# -------------------------------
# Training loss: 0.315545
# Validation loss: 0.317776
#
# Epoch 99
# -------------------------------
# Training loss: 0.314533
# Validation loss: 0.310126
#
# Epoch 100
# -------------------------------
# Training loss: 0.314058
# Validation loss: 0.327547
#
# Epoch 101
# -------------------------------
# Training loss: 0.313244
# Validation loss: 0.312294
#
# Epoch 102
# -------------------------------
# Training loss: 0.311563
# Validation loss: 0.322134
#
# Epoch 103
# -------------------------------
# Training loss: 0.312064
# Validation loss: 0.311808
#
# Epoch 104
# -------------------------------
# Training loss: 0.310987
# Validation loss: 0.320272
#
# Epoch 105
# -------------------------------
# Training loss: 0.310620
# Validation loss: 0.307988
#
# Epoch 106
# -------------------------------
# Training loss: 0.309704
# Validation loss: 0.321094
#
# Epoch 107
# -------------------------------
# Training loss: 0.309310
# Validation loss: 0.309285
#
# Epoch 108
# -------------------------------
# Training loss: 0.307450
# Validation loss: 0.313129
#
# Epoch 109
# -------------------------------
# Training loss: 0.307895
# Validation loss: 0.315918
#
# Epoch 110
# -------------------------------
# Training loss: 0.306601
# Validation loss: 0.318553
#
# Epoch 111
# -------------------------------
# Training loss: 0.305633
# Validation loss: 0.304144
#
# Epoch 112
# -------------------------------
# Training loss: 0.305734
# Validation loss: 0.314100
#
# Epoch 113
# -------------------------------
# Training loss: 0.306432
# Validation loss: 0.299826
#
# Epoch 114
# -------------------------------
# Training loss: 0.303903
# Validation loss: 0.318348
#
# Epoch 115
# -------------------------------
# Training loss: 0.303033
# Validation loss: 0.303548
#
# Epoch 116
# -------------------------------
# Training loss: 0.301852
# Validation loss: 0.307514
#
# Epoch 117
# -------------------------------
# Training loss: 0.301710
# Validation loss: 0.307572
#
# Epoch 118
# -------------------------------
# Training loss: 0.300794
# Validation loss: 0.307021
#
# Epoch 119
# -------------------------------
# Training loss: 0.299535
# Validation loss: 0.310137
#
# Epoch 120
# -------------------------------
# Training loss: 0.298518
# Validation loss: 0.306982
#
# Epoch 121
# -------------------------------
# Training loss: 0.298461
# Validation loss: 0.313651
#
# Epoch 122
# -------------------------------
# Training loss: 0.297634
# Validation loss: 0.292433
#
# Epoch 123
# -------------------------------
# Training loss: 0.297492
# Validation loss: 0.299726
#
# Epoch 124
# -------------------------------
# Training loss: 0.296800
# Validation loss: 0.300948
#
# Epoch 125
# -------------------------------
# Training loss: 0.295134
# Validation loss: 0.291110
#
# Epoch 126
# -------------------------------
# Training loss: 0.296403
# Validation loss: 0.307563
#
# Epoch 127
# -------------------------------
# Training loss: 0.293888
# Validation loss: 0.303156
#
# Epoch 128
# -------------------------------
# Training loss: 0.292769
# Validation loss: 0.305177
#
# Epoch 129
# -------------------------------
# Training loss: 0.293125
# Validation loss: 0.292567
#
# Epoch 130
# -------------------------------
# Training loss: 0.291791
# Validation loss: 0.302734
#
# Epoch 131
# -------------------------------
# Training loss: 0.291024
# Validation loss: 0.294575
#
# Epoch 132
# -------------------------------
# Training loss: 0.290893
# Validation loss: 0.290874
#
# Epoch 133
# -------------------------------
# Training loss: 0.290388
# Validation loss: 0.305718
#
# Epoch 134
# -------------------------------
# Training loss: 0.289405
# Validation loss: 0.299814
#
# Epoch 135
# -------------------------------
# Training loss: 0.289007
# Validation loss: 0.303445
#
# Epoch 136
# -------------------------------
# Training loss: 0.288545
# Validation loss: 0.285546
#
# Epoch 137
# -------------------------------
# Training loss: 0.287543
# Validation loss: 0.292375
#
# Epoch 138
# -------------------------------
# Training loss: 0.286837
# Validation loss: 0.287838
#
# Epoch 139
# -------------------------------
# Training loss: 0.285981
# Validation loss: 0.295755
#
# Epoch 140
# -------------------------------
# Training loss: 0.285080
# Validation loss: 0.293782
#
# Epoch 141
# -------------------------------
# Training loss: 0.284686
# Validation loss: 0.307663
#
# Epoch 142
# -------------------------------
# Training loss: 0.283921
# Validation loss: 0.288432
#
# Epoch 143
# -------------------------------
# Training loss: 0.283211
# Validation loss: 0.289609
#
# Epoch 144
# -------------------------------
# Training loss: 0.283858
# Validation loss: 0.298928
#
# Epoch 145
# -------------------------------
# Training loss: 0.282327
# Validation loss: 0.282734
#
# Epoch 146
# -------------------------------
# Training loss: 0.281973
# Validation loss: 0.287851
#
# Epoch 147
# -------------------------------
# Training loss: 0.281026
# Validation loss: 0.281334
#
# Epoch 148
# -------------------------------
# Training loss: 0.280101
# Validation loss: 0.284745
#
# Epoch 149
# -------------------------------
# Training loss: 0.278842
# Validation loss: 0.281045
#
# Epoch 150
# -------------------------------
# Training loss: 0.278908
# Validation loss: 0.274721
#
# Epoch 151
# -------------------------------
# Training loss: 0.279085
# Validation loss: 0.285768
#
# Epoch 152
# -------------------------------
# Training loss: 0.278753
# Validation loss: 0.283324
#
# Epoch 153
# -------------------------------
# Training loss: 0.277489
# Validation loss: 0.274435
#
# Epoch 154
# -------------------------------
# Training loss: 0.275931
# Validation loss: 0.287834
#
# Epoch 155
# -------------------------------
# Training loss: 0.275244
# Validation loss: 0.267434
#
# Epoch 156
# -------------------------------
# Training loss: 0.275043
# Validation loss: 0.280761
#
# Epoch 157
# -------------------------------
# Training loss: 0.274498
# Validation loss: 0.291823
#
# Epoch 158
# -------------------------------
# Training loss: 0.273798
# Validation loss: 0.277658
#
# Epoch 159
# -------------------------------
# Training loss: 0.273215
# Validation loss: 0.297900
#
# Epoch 160
# -------------------------------
# Training loss: 0.272194
# Validation loss: 0.267832
#
# Epoch 161
# -------------------------------
# Training loss: 0.270757
# Validation loss: 0.276440
#
# Epoch 162
# -------------------------------
# Training loss: 0.270819
# Validation loss: 0.266109
#
# Epoch 163
# -------------------------------
# Training loss: 0.270679
# Validation loss: 0.279034
#
# Epoch 164
# -------------------------------
# Training loss: 0.270001
# Validation loss: 0.256154
#
# Epoch 165
# -------------------------------
# Training loss: 0.269616
# Validation loss: 0.269806
#
# Epoch 166
# -------------------------------
# Training loss: 0.267684
# Validation loss: 0.262548
#
# Epoch 167
# -------------------------------
# Training loss: 0.266547
# Validation loss: 0.276653
#
# Epoch 168
# -------------------------------
# Training loss: 0.266031
# Validation loss: 0.278325
#
# Epoch 169
# -------------------------------
# Training loss: 0.265668
# Validation loss: 0.280265
#
# Epoch 170
# -------------------------------
# Training loss: 0.264859
# Validation loss: 0.261979
#
# Epoch 171
# -------------------------------
# Training loss: 0.263587
# Validation loss: 0.276653
#
# Epoch 172
# -------------------------------
# Training loss: 0.263340
# Validation loss: 0.266175
#
# Epoch 173
# -------------------------------
# Training loss: 0.263742
# Validation loss: 0.277472
#
# Epoch 174
# -------------------------------
# Training loss: 0.261606
# Validation loss: 0.268705
#
# Epoch 175
# -------------------------------
# Training loss: 0.260016
# Validation loss: 0.266956
#
# Epoch 176
# -------------------------------
# Training loss: 0.259601
# Validation loss: 0.268838
#
# Epoch 177
# -------------------------------
# Training loss: 0.259520
# Validation loss: 0.279462
#
# Epoch 178
# -------------------------------
# Training loss: 0.257431
# Validation loss: 0.279402
#
# Epoch 179
# -------------------------------
# Training loss: 0.258048
# Validation loss: 0.274842
#
# Epoch 180
# -------------------------------
# Training loss: 0.256866
# Validation loss: 0.256800
#
# Epoch 181
# -------------------------------
# Training loss: 0.255019
# Validation loss: 0.258008
#
# Epoch 182
# -------------------------------
# Training loss: 0.255341
# Validation loss: 0.283678
#
# Epoch 183
# -------------------------------
# Training loss: 0.257354
# Validation loss: 0.282631
#
# Epoch 184
# -------------------------------
# Training loss: 0.252856
# Validation loss: 0.254096
#
# Epoch 185
# -------------------------------
# Training loss: 0.251154
# Validation loss: 0.241152
#
# Epoch 186
# -------------------------------
# Training loss: 0.251713
# Validation loss: 0.283510
#
# Epoch 187
# -------------------------------
# Training loss: 0.252422
# Validation loss: 0.245760
#
# Epoch 188
# -------------------------------
# Training loss: 0.249914
# Validation loss: 0.286034
#
# Epoch 189
# -------------------------------
# Training loss: 0.247943
# Validation loss: 0.262155
#
# Epoch 190
# -------------------------------
# Training loss: 0.246853
# Validation loss: 0.252249
#
# Epoch 191
# -------------------------------
# Training loss: 0.250095
# Validation loss: 0.238464
#
# Epoch 192
# -------------------------------
# Training loss: 0.247196
# Validation loss: 0.252846
#
# Epoch 193
# -------------------------------
# Training loss: 0.245506
# Validation loss: 0.245716
#
# Epoch 194
# -------------------------------
# Training loss: 0.244278
# Validation loss: 0.242361
#
# Epoch 195
# -------------------------------
# Training loss: 0.243204
# Validation loss: 0.252598
#
# Epoch 196
# -------------------------------
# Training loss: 0.241011
# Validation loss: 0.235146
#
# Epoch 197
# -------------------------------
# Training loss: 0.241885
# Validation loss: 0.242851
#
# Epoch 198
# -------------------------------
# Training loss: 0.244471
# Validation loss: 0.264872
#
# Epoch 199
# -------------------------------
# Training loss: 0.240591
# Validation loss: 0.265999
#
# Epoch 200
# -------------------------------
# Training loss: 0.240278
# Validation loss: 0.249297
#
# Epoch 201
# -------------------------------
# Training loss: 0.236710
# Validation loss: 0.231934
#
# Epoch 202
# -------------------------------
# Training loss: 0.238195
# Validation loss: 0.251105
#
# Epoch 203
# -------------------------------
# Training loss: 0.235981
# Validation loss: 0.276208
#
# Epoch 204
# -------------------------------
# Training loss: 0.235681
# Validation loss: 0.239512
#
# Epoch 205
# -------------------------------
# Training loss: 0.233800
# Validation loss: 0.258506
#
# Epoch 206
# -------------------------------
# Training loss: 0.236407
# Validation loss: 0.242809
#
# Epoch 207
# -------------------------------
# Training loss: 0.232375
# Validation loss: 0.230317
#
# Epoch 208
# -------------------------------
# Training loss: 0.229509
# Validation loss: 0.231746
#
# Epoch 209
# -------------------------------
# Training loss: 0.230913
# Validation loss: 0.224227
#
# Epoch 210
# -------------------------------
# Training loss: 0.229787
# Validation loss: 0.245994
#
# Epoch 211
# -------------------------------
# Training loss: 0.227136
# Validation loss: 0.235509
#
# Epoch 212
# -------------------------------
# Training loss: 0.225328
# Validation loss: 0.223205
#
# Epoch 213
# -------------------------------
# Training loss: 0.228184
# Validation loss: 0.331164
#
# Epoch 214
# -------------------------------
# Training loss: 0.228038
# Validation loss: 0.208957
#
# Epoch 215
# -------------------------------
# Training loss: 0.224705
# Validation loss: 0.225657
#
# Epoch 216
# -------------------------------
# Training loss: 0.222813
# Validation loss: 0.231756
#
# Epoch 217
# -------------------------------
# Training loss: 0.222614
# Validation loss: 0.222271
#
# Epoch 218
# -------------------------------
# Training loss: 0.221588
# Validation loss: 0.212675
#
# Epoch 219
# -------------------------------
# Training loss: 0.220838
# Validation loss: 0.238092
#
# Epoch 220
# -------------------------------
# Training loss: 0.222995
# Validation loss: 0.223744
#
# Epoch 221
# -------------------------------
# Training loss: 0.220640
# Validation loss: 0.221754
#
# Epoch 222
# -------------------------------
# Training loss: 0.216391
# Validation loss: 0.230988
#
# Epoch 223
# -------------------------------
# Training loss: 0.216015
# Validation loss: 0.221331
#
# Epoch 224
# -------------------------------
# Training loss: 0.212849
# Validation loss: 0.205683
#
# Epoch 225
# -------------------------------
# Training loss: 0.214412
# Validation loss: 0.259440
#
# Epoch 226
# -------------------------------
# Training loss: 0.216074
# Validation loss: 0.212139
#
# Epoch 227
# -------------------------------
# Training loss: 0.212956
# Validation loss: 0.232354
#
# Epoch 228
# -------------------------------
# Training loss: 0.215184
# Validation loss: 0.212865
#
# Epoch 229
# -------------------------------
# Training loss: 0.212532
# Validation loss: 0.197975
#
# Epoch 230
# -------------------------------
# Training loss: 0.207462
# Validation loss: 0.213664
#
# Epoch 231
# -------------------------------
# Training loss: 0.209287
# Validation loss: 0.210334
#
# Epoch 232
# -------------------------------
# Training loss: 0.211341
# Validation loss: 0.230120
#
# Epoch 233
# -------------------------------
# Training loss: 0.207418
# Validation loss: 0.240127
#
# Epoch 234
# -------------------------------
# Training loss: 0.204693
# Validation loss: 0.205556
#
# Epoch 235
# -------------------------------
# Training loss: 0.205465
# Validation loss: 0.209175
#
# Epoch 236
# -------------------------------
# Training loss: 0.209117
# Validation loss: 0.206044
#
# Epoch 237
# -------------------------------
# Training loss: 0.207857
# Validation loss: 0.219865
#
# Epoch 238
# -------------------------------
# Training loss: 0.202261
# Validation loss: 0.245132
#
# Epoch 239
# -------------------------------
# Training loss: 0.202198
# Validation loss: 0.198817
#
# Epoch 240
# -------------------------------
# Training loss: 0.204148
# Validation loss: 0.216898
#
# Epoch 241
# -------------------------------
# Training loss: 0.199913
# Validation loss: 0.200421
#
# Epoch 242
# -------------------------------
# Training loss: 0.199762
# Validation loss: 0.200646
#
# Epoch 243
# -------------------------------
# Training loss: 0.199709
# Validation loss: 0.203573
#
# Epoch 244
# -------------------------------
# Training loss: 0.201380
# Validation loss: 0.208308
#
# Epoch 245
# -------------------------------
# Training loss: 0.200610
# Validation loss: 0.193629
#
# Epoch 246
# -------------------------------
# Training loss: 0.196643
# Validation loss: 0.205824
#
# Epoch 247
# -------------------------------
# Training loss: 0.196481
# Validation loss: 0.210356
#
# Epoch 248
# -------------------------------
# Training loss: 0.200527
# Validation loss: 0.196776
#
# Epoch 249
# -------------------------------
# Training loss: 0.196189
# Validation loss: 0.196096
#
# Epoch 250
# -------------------------------
# Training loss: 0.197223
# Validation loss: 0.206107
#
# Epoch 251
# -------------------------------
# Training loss: 0.193367
# Validation loss: 0.193582
#
# Epoch 252
# -------------------------------
# Training loss: 0.195392
# Validation loss: 0.208185
#
# Epoch 253
# -------------------------------
# Training loss: 0.192123
# Validation loss: 0.193576
#
# Epoch 254
# -------------------------------
# Training loss: 0.195424
# Validation loss: 0.236282
#
# Epoch 255
# -------------------------------
# Training loss: 0.196795
# Validation loss: 0.200513
#
# Epoch 256
# -------------------------------
# Training loss: 0.192567
# Validation loss: 0.203895
#
# Epoch 257
# -------------------------------
# Training loss: 0.189410
# Validation loss: 0.192685
#
# Epoch 258
# -------------------------------
# Training loss: 0.189171
# Validation loss: 0.187201
#
# Epoch 259
# -------------------------------
# Training loss: 0.193247
# Validation loss: 0.208370
#
# Epoch 260
# -------------------------------
# Training loss: 0.189781
# Validation loss: 0.177523
#
# Epoch 261
# -------------------------------
# Training loss: 0.191226
# Validation loss: 0.188988
#
# Epoch 262
# -------------------------------
# Training loss: 0.188591
# Validation loss: 0.191659
#
# Epoch 263
# -------------------------------
# Training loss: 0.185819
# Validation loss: 0.188477
#
# Epoch 264
# -------------------------------
# Training loss: 0.188870
# Validation loss: 0.194682
#
# Epoch 265
# -------------------------------
# Training loss: 0.186312
# Validation loss: 0.178502
#
# Epoch 266
# -------------------------------
# Training loss: 0.186227
# Validation loss: 0.198201
#
# Epoch 267
# -------------------------------
# Training loss: 0.186856
# Validation loss: 0.205981
#
# Epoch 268
# -------------------------------
# Training loss: 0.183624
# Validation loss: 0.188740
#
# Epoch 269
# -------------------------------
# Training loss: 0.182222
# Validation loss: 0.230500
#
# Epoch 270
# -------------------------------
# Training loss: 0.182626
# Validation loss: 0.190113
#
# Epoch 271
# -------------------------------
# Training loss: 0.183338
# Validation loss: 0.219326
#
# Epoch 272
# -------------------------------
# Training loss: 0.186337
# Validation loss: 0.226324
#
# Epoch 273
# -------------------------------
# Training loss: 0.183193
# Validation loss: 0.177959
#
# Epoch 274
# -------------------------------
# Training loss: 0.181766
# Validation loss: 0.221238
#
# Epoch 275
# -------------------------------
# Training loss: 0.179938
# Validation loss: 0.182157
#
# Epoch 276
# -------------------------------
# Training loss: 0.181032
# Validation loss: 0.185325
#
# Epoch 277
# -------------------------------
# Training loss: 0.179866
# Validation loss: 0.194078
#
# Epoch 278
# -------------------------------
# Training loss: 0.179502
# Validation loss: 0.209752
#
# Epoch 279
# -------------------------------
# Training loss: 0.178622
# Validation loss: 0.180604
#
# Epoch 280
# -------------------------------
# Training loss: 0.176698
# Validation loss: 0.180141
#
# Epoch 281
# -------------------------------
# Training loss: 0.178149
# Validation loss: 0.190787
#
# Epoch 282
# -------------------------------
# Training loss: 0.176735
# Validation loss: 0.185926
#
# Epoch 283
# -------------------------------
# Training loss: 0.175140
# Validation loss: 0.171875
#
# Epoch 284
# -------------------------------
# Training loss: 0.178465
# Validation loss: 0.190699
#
# Epoch 285
# -------------------------------
# Training loss: 0.175669
# Validation loss: 0.192195
#
# Epoch 286
# -------------------------------
# Training loss: 0.172914
# Validation loss: 0.171398
#
# Epoch 287
# -------------------------------
# Training loss: 0.172375
# Validation loss: 0.166417
#
# Epoch 288
# -------------------------------
# Training loss: 0.172709
# Validation loss: 0.166420
#
# Epoch 289
# -------------------------------
# Training loss: 0.173448
# Validation loss: 0.275536
#
# Epoch 290
# -------------------------------
# Training loss: 0.174181
# Validation loss: 0.198536
#
# Epoch 291
# -------------------------------
# Training loss: 0.172429
# Validation loss: 0.183810
#
# Epoch 292
# -------------------------------
# Training loss: 0.172198
# Validation loss: 0.218773
#
# Epoch 293
# -------------------------------
# Training loss: 0.170943
# Validation loss: 0.165161
#
# Epoch 294
# -------------------------------
# Training loss: 0.168859
# Validation loss: 0.165180
#
# Epoch 295
# -------------------------------
# Training loss: 0.170781
# Validation loss: 0.180780
#
# Epoch 296
# -------------------------------
# Training loss: 0.169194
# Validation loss: 0.240271
#
# Epoch 297
# -------------------------------
# Training loss: 0.167844
# Validation loss: 0.161308
#
# Epoch 298
# -------------------------------
# Training loss: 0.167791
# Validation loss: 0.161890
#
# Epoch 299
# -------------------------------
# Training loss: 0.166656
# Validation loss: 0.170225
#
# Epoch 300
# -------------------------------
# Training loss: 0.167321
# Validation loss: 0.166726
#
# Epoch 301
# -------------------------------
# Training loss: 0.170679
# Validation loss: 0.204464
#
# Epoch 302
# -------------------------------
# Training loss: 0.165874
# Validation loss: 0.159912
#
# Epoch 303
# -------------------------------
# Training loss: 0.165960
# Validation loss: 0.271109
#
# Epoch 304
# -------------------------------
# Training loss: 0.165116
# Validation loss: 0.170509
#
# Epoch 305
# -------------------------------
# Training loss: 0.162086
# Validation loss: 0.160659
#
# Epoch 306
# -------------------------------
# Training loss: 0.162991
# Validation loss: 0.167647
#
# Epoch 307
# -------------------------------
# Training loss: 0.165839
# Validation loss: 0.287119
#
# Epoch 308
# -------------------------------
# Training loss: 0.163110
# Validation loss: 0.160714
#
# Epoch 309
# -------------------------------
# Training loss: 0.162383
# Validation loss: 0.158131
#
# Epoch 310
# -------------------------------
# Training loss: 0.159067
# Validation loss: 0.162351
#
# Epoch 311
# -------------------------------
# Training loss: 0.161778
# Validation loss: 0.162399
#
# Epoch 312
# -------------------------------
# Training loss: 0.161135
# Validation loss: 0.217586
#
# Epoch 313
# -------------------------------
# Training loss: 0.159693
# Validation loss: 0.199584
#
# Epoch 314
# -------------------------------
# Training loss: 0.160806
# Validation loss: 0.185897
#
# Epoch 315
# -------------------------------
# Training loss: 0.157869
# Validation loss: 0.170297
#
# Epoch 316
# -------------------------------
# Training loss: 0.157273
# Validation loss: 0.167938
#
# Epoch 317
# -------------------------------
# Training loss: 0.159309
# Validation loss: 0.205221
#
# Epoch 318
# -------------------------------
# Training loss: 0.160748
# Validation loss: 0.283581
#
# Epoch 319
# -------------------------------
# Training loss: 0.158951
# Validation loss: 0.157036
#
# Epoch 320
# -------------------------------
# Training loss: 0.157372
# Validation loss: 0.167276
#
# Epoch 321
# -------------------------------
# Training loss: 0.156136
# Validation loss: 0.160042
#
# Epoch 322
# -------------------------------
# Training loss: 0.154680
# Validation loss: 0.185991
#
# Epoch 323
# -------------------------------
# Training loss: 0.156765
# Validation loss: 0.171534
#
# Epoch 324
# -------------------------------
# Training loss: 0.156463
# Validation loss: 0.167550
#
# Epoch 325
# -------------------------------
# Training loss: 0.157503
# Validation loss: 0.234617
#
# Epoch 326
# -------------------------------
# Training loss: 0.157027
# Validation loss: 0.156051
#
# Epoch 327
# -------------------------------
# Training loss: 0.152092
# Validation loss: 0.152349
#
# Epoch 328
# -------------------------------
# Training loss: 0.152762
# Validation loss: 0.169662
#
# Epoch 329
# -------------------------------
# Training loss: 0.151362
# Validation loss: 0.147754
#
# Epoch 330
# -------------------------------
# Training loss: 0.152145
# Validation loss: 0.151342
#
# Epoch 331
# -------------------------------
# Training loss: 0.152895
# Validation loss: 0.158637
#
# Epoch 332
# -------------------------------
# Training loss: 0.152040
# Validation loss: 0.213367
#
# Epoch 333
# -------------------------------
# Training loss: 0.149374
# Validation loss: 0.165437
#
# Epoch 334
# -------------------------------
# Training loss: 0.150510
# Validation loss: 0.153044
#
# Epoch 335
# -------------------------------
# Training loss: 0.150400
# Validation loss: 0.166699
#
# Epoch 336
# -------------------------------
# Training loss: 0.148952
# Validation loss: 0.149542
#
# Epoch 337
# -------------------------------
# Training loss: 0.152852
# Validation loss: 0.162567
#
# Epoch 338
# -------------------------------
# Training loss: 0.148307
# Validation loss: 0.217581
#
# Epoch 339
# -------------------------------
# Training loss: 0.147673
# Validation loss: 0.144892
#
# Epoch 340
# -------------------------------
# Training loss: 0.149016
# Validation loss: 0.142611
#
# Epoch 341
# -------------------------------
# Training loss: 0.147298
# Validation loss: 0.167988
#
# Epoch 342
# -------------------------------
# Training loss: 0.147846
# Validation loss: 0.151123
#
# Epoch 343
# -------------------------------
# Training loss: 0.148881
# Validation loss: 0.169169
#
# Epoch 344
# -------------------------------
# Training loss: 0.147917
# Validation loss: 0.161248
#
# Epoch 345
# -------------------------------
# Training loss: 0.144065
# Validation loss: 0.147311
#
# Epoch 346
# -------------------------------
# Training loss: 0.145377
# Validation loss: 0.136768
#
# Epoch 347
# -------------------------------
# Training loss: 0.144198
# Validation loss: 0.152092
#
# Epoch 348
# -------------------------------
# Training loss: 0.143946
# Validation loss: 0.141480
#
# Epoch 349
# -------------------------------
# Training loss: 0.143831
# Validation loss: 0.171406
#
# Epoch 350
# -------------------------------
# Training loss: 0.143631
# Validation loss: 0.144209
#
# Epoch 351
# -------------------------------
# Training loss: 0.142207
# Validation loss: 0.150457
#
# Epoch 352
# -------------------------------
# Training loss: 0.145207
# Validation loss: 0.230221
#
# Epoch 353
# -------------------------------
# Training loss: 0.142895
# Validation loss: 0.140020
#
# Epoch 354
# -------------------------------
# Training loss: 0.143760
# Validation loss: 0.206262
#
# Epoch 355
# -------------------------------
# Training loss: 0.140626
# Validation loss: 0.144908
#
# Epoch 356
# -------------------------------
# Training loss: 0.140476
# Validation loss: 0.162243
#
# Epoch 357
# -------------------------------
# Training loss: 0.140900
# Validation loss: 0.179208
#
# Epoch 358
# -------------------------------
# Training loss: 0.144921
# Validation loss: 0.147891
#
# Epoch 359
# -------------------------------
# Training loss: 0.140039
# Validation loss: 0.140807
#
# Epoch 360
# -------------------------------
# Training loss: 0.143887
# Validation loss: 0.154555
#
# Epoch 361
# -------------------------------
# Training loss: 0.141241
# Validation loss: 0.146330
#
# Epoch 362
# -------------------------------
# Training loss: 0.140026
# Validation loss: 0.147502
#
# Epoch 363
# -------------------------------
# Training loss: 0.139038
# Validation loss: 0.144891
#
# Epoch 364
# -------------------------------
# Training loss: 0.137945
# Validation loss: 0.135938
#
# Epoch 365
# -------------------------------
# Training loss: 0.136965
# Validation loss: 0.135777
#
# Epoch 366
# -------------------------------
# Training loss: 0.139701
# Validation loss: 0.136186
#
# Epoch 367
# -------------------------------
# Training loss: 0.135947
# Validation loss: 0.143049
#
# Epoch 368
# -------------------------------
# Training loss: 0.135344
# Validation loss: 0.140947
#
# Epoch 369
# -------------------------------
# Training loss: 0.136442
# Validation loss: 0.135849
#
# Epoch 370
# -------------------------------
# Training loss: 0.134818
# Validation loss: 0.137029
#
# Epoch 371
# -------------------------------
# Training loss: 0.134719
# Validation loss: 0.141287
#
# Epoch 372
# -------------------------------
# Training loss: 0.136142
# Validation loss: 0.258504
#
# Epoch 373
# -------------------------------
# Training loss: 0.139361
# Validation loss: 0.145091
#
# Epoch 374
# -------------------------------
# Training loss: 0.137662
# Validation loss: 0.166367
#
# Epoch 375
# -------------------------------
# Training loss: 0.133891
# Validation loss: 0.139341
#
# Epoch 376
# -------------------------------
# Training loss: 0.134558
# Validation loss: 0.139774
#
# Epoch 377
# -------------------------------
# Training loss: 0.135181
# Validation loss: 0.126500
#
# Epoch 378
# -------------------------------
# Training loss: 0.135222
# Validation loss: 0.196320
#
# Epoch 379
# -------------------------------
# Training loss: 0.138700
# Validation loss: 0.281329
#
# Epoch 380
# -------------------------------
# Training loss: 0.133727
# Validation loss: 0.133436
#
# Epoch 381
# -------------------------------
# Training loss: 0.135792
# Validation loss: 0.168003
#
# Epoch 382
# -------------------------------
# Training loss: 0.133185
# Validation loss: 0.126460
#
# Epoch 383
# -------------------------------
# Training loss: 0.132031
# Validation loss: 0.151125
#
# Epoch 384
# -------------------------------
# Training loss: 0.131814
# Validation loss: 0.169972
#
# Epoch 385
# -------------------------------
# Training loss: 0.130389
# Validation loss: 0.137716
#
# Epoch 386
# -------------------------------
# Training loss: 0.129764
# Validation loss: 0.129425
#
# Epoch 387
# -------------------------------
# Training loss: 0.130313
# Validation loss: 0.132840
#
# Epoch 388
# -------------------------------
# Training loss: 0.129084
# Validation loss: 0.130668
#
# Epoch 389
# -------------------------------
# Training loss: 0.128130
# Validation loss: 0.146862
#
# Epoch 390
# -------------------------------
# Training loss: 0.128068
# Validation loss: 0.121697
#
# Epoch 391
# -------------------------------
# Training loss: 0.128966
# Validation loss: 0.129488
#
# Epoch 392
# -------------------------------
# Training loss: 0.129670
# Validation loss: 0.163019
#
# Epoch 393
# -------------------------------
# Training loss: 0.128620
# Validation loss: 0.149533
#
# Epoch 394
# -------------------------------
# Training loss: 0.128690
# Validation loss: 0.162229
#
# Epoch 395
# -------------------------------
# Training loss: 0.130514
# Validation loss: 0.124218
#
# Epoch 396
# -------------------------------
# Training loss: 0.125856
# Validation loss: 0.127303
#
# Epoch 397
# -------------------------------
# Training loss: 0.126795
# Validation loss: 0.123561
#
# Epoch 398
# -------------------------------
# Training loss: 0.127849
# Validation loss: 0.129342
#
# Epoch 399
# -------------------------------
# Training loss: 0.130365
# Validation loss: 0.422421
#
# Epoch 400
# -------------------------------
# Training loss: 0.127786
# Validation loss: 0.132592
#
# Epoch 401
# -------------------------------
# Training loss: 0.127574
# Validation loss: 0.181538
#
# Epoch 402
# -------------------------------
# Training loss: 0.126567
# Validation loss: 0.120882
#
# Epoch 403
# -------------------------------
# Training loss: 0.126490
# Validation loss: 0.227656
#
# Epoch 404
# -------------------------------
# Training loss: 0.125856
# Validation loss: 0.124910
#
# Epoch 405
# -------------------------------
# Training loss: 0.124316
# Validation loss: 0.117608
#
# Epoch 406
# -------------------------------
# Training loss: 0.123085
# Validation loss: 0.170798
#
# Epoch 407
# -------------------------------
# Training loss: 0.123664
# Validation loss: 0.163012
#
# Epoch 408
# -------------------------------
# Training loss: 0.125022
# Validation loss: 0.120138
#
# Epoch 409
# -------------------------------
# Training loss: 0.123805
# Validation loss: 0.114568
#
# Epoch 410
# -------------------------------
# Training loss: 0.124487
# Validation loss: 0.124167
#
# Epoch 411
# -------------------------------
# Training loss: 0.125760
# Validation loss: 0.127821
#
# Epoch 412
# -------------------------------
# Training loss: 0.120872
# Validation loss: 0.122224
#
# Epoch 413
# -------------------------------
# Training loss: 0.120432
# Validation loss: 0.130132
#
# Epoch 414
# -------------------------------
# Training loss: 0.120879
# Validation loss: 0.121708
#
# Epoch 415
# -------------------------------
# Training loss: 0.121460
# Validation loss: 0.124500
#
# Epoch 416
# -------------------------------
# Training loss: 0.128023
# Validation loss: 0.119773
#
# Epoch 417
# -------------------------------
# Training loss: 0.126013
# Validation loss: 0.151187
#
# Epoch 418
# -------------------------------
# Training loss: 0.120921
# Validation loss: 0.151313
#
# Epoch 419
# -------------------------------
# Training loss: 0.120019
# Validation loss: 0.120768
#
# Epoch 420
# -------------------------------
# Training loss: 0.118927
# Validation loss: 0.112179
#
# Epoch 421
# -------------------------------
# Training loss: 0.120464
# Validation loss: 0.116410
#
# Epoch 422
# -------------------------------
# Training loss: 0.120760
# Validation loss: 0.119256
#
# Epoch 423
# -------------------------------
# Training loss: 0.118321
# Validation loss: 0.142385
#
# Epoch 424
# -------------------------------
# Training loss: 0.119481
# Validation loss: 0.121610
#
# Epoch 425
# -------------------------------
# Training loss: 0.118416
# Validation loss: 0.115954
#
# Epoch 426
# -------------------------------
# Training loss: 0.116537
# Validation loss: 0.112810
#
# Epoch 427
# -------------------------------
# Training loss: 0.118295
# Validation loss: 0.122489
#
# Epoch 428
# -------------------------------
# Training loss: 0.116714
# Validation loss: 0.118541
#
# Epoch 429
# -------------------------------
# Training loss: 0.116575
# Validation loss: 0.130857
#
# Epoch 430
# -------------------------------
# Training loss: 0.118108
# Validation loss: 0.115101
#
# Epoch 431
# -------------------------------
# Training loss: 0.116749
# Validation loss: 0.115438
#
# Epoch 432
# -------------------------------
# Training loss: 0.118660
# Validation loss: 0.151835
#
# Epoch 433
# -------------------------------
# Training loss: 0.119547
# Validation loss: 0.123408
#
# Epoch 434
# -------------------------------
# Training loss: 0.117444
# Validation loss: 0.114197
#
# Epoch 435
# -------------------------------
# Training loss: 0.115873
# Validation loss: 0.142265
#
# Epoch 436
# -------------------------------
# Training loss: 0.115874
# Validation loss: 0.117020
#
# Epoch 437
# -------------------------------
# Training loss: 0.117561
# Validation loss: 0.115508
#
# Epoch 438
# -------------------------------
# Training loss: 0.117341
# Validation loss: 0.173986
#
# Epoch 439
# -------------------------------
# Training loss: 0.116893
# Validation loss: 0.118253
#
# Epoch 440
# -------------------------------
# Training loss: 0.116217
# Validation loss: 0.115204
#
# Epoch 441
# -------------------------------
# Training loss: 0.115146
# Validation loss: 0.114207
#
# Epoch 442
# -------------------------------
# Training loss: 0.113684
# Validation loss: 0.114435
#
# Epoch 443
# -------------------------------
# Training loss: 0.112736
# Validation loss: 0.114350
#
# Epoch 444
# -------------------------------
# Training loss: 0.112590
# Validation loss: 0.125467
#
# Epoch 445
# -------------------------------
# Training loss: 0.114396
# Validation loss: 0.113466
#
# Epoch 446
# -------------------------------
# Training loss: 0.114812
# Validation loss: 0.121526
#
# Epoch 447
# -------------------------------
# Training loss: 0.113186
# Validation loss: 0.115942
#
# Epoch 448
# -------------------------------
# Training loss: 0.113480
# Validation loss: 0.152529
#
# Epoch 449
# -------------------------------
# Training loss: 0.117427
# Validation loss: 0.113321
#
# Epoch 450
# -------------------------------
# Training loss: 0.114831
# Validation loss: 0.113819
#
# Epoch 451
# -------------------------------
# Training loss: 0.114197
# Validation loss: 0.139351
#
# Epoch 452
# -------------------------------
# Training loss: 0.115612
# Validation loss: 0.117743
#
# Epoch 453
# -------------------------------
# Training loss: 0.111335
# Validation loss: 0.117857
#
# Epoch 454
# -------------------------------
# Training loss: 0.112029
# Validation loss: 0.111090
#
# Epoch 455
# -------------------------------
# Training loss: 0.111094
# Validation loss: 0.115490
#
# Epoch 456
# -------------------------------
# Training loss: 0.111822
# Validation loss: 0.115658
#
# Epoch 457
# -------------------------------
# Training loss: 0.109521
# Validation loss: 0.113562
#
# Epoch 458
# -------------------------------
# Training loss: 0.108988
# Validation loss: 0.113198
#
# Epoch 459
# -------------------------------
# Training loss: 0.110438
# Validation loss: 0.126371
#
# Epoch 460
# -------------------------------
# Training loss: 0.109760
# Validation loss: 0.172263
#
# Epoch 461
# -------------------------------
# Training loss: 0.111663
# Validation loss: 0.108081
#
# Epoch 462
# -------------------------------
# Training loss: 0.112223
# Validation loss: 0.115463
#
# Epoch 463
# -------------------------------
# Training loss: 0.110599
# Validation loss: 0.117212
#
# Epoch 464
# -------------------------------
# Training loss: 0.109117
# Validation loss: 0.109997
#
# Epoch 465
# -------------------------------
# Training loss: 0.109966
# Validation loss: 0.116827
#
# Epoch 466
# -------------------------------
# Training loss: 0.109620
# Validation loss: 0.125314
#
# Epoch 467
# -------------------------------
# Training loss: 0.109060
# Validation loss: 0.113265
#
# Epoch 468
# -------------------------------
# Training loss: 0.109202
# Validation loss: 0.106138
#
# Epoch 469
# -------------------------------
# Training loss: 0.110102
# Validation loss: 0.109137
#
# Epoch 470
# -------------------------------
# Training loss: 0.111116
# Validation loss: 0.121221
#
# Epoch 471
# -------------------------------
# Training loss: 0.108287
# Validation loss: 0.106922
#
# Epoch 472
# -------------------------------
# Training loss: 0.106552
# Validation loss: 0.109355
#
# Epoch 473
# -------------------------------
# Training loss: 0.109515
# Validation loss: 0.134941
#
# Epoch 474
# -------------------------------
# Training loss: 0.106159
# Validation loss: 0.108420
#
# Epoch 475
# -------------------------------
# Training loss: 0.107932
# Validation loss: 0.107923
#
# Epoch 476
# -------------------------------
# Training loss: 0.108266
# Validation loss: 0.107587
#
# Epoch 477
# -------------------------------
# Training loss: 0.109049
# Validation loss: 0.101183
#
# Epoch 478
# -------------------------------
# Training loss: 0.105360
# Validation loss: 0.106611
#
# Epoch 479
# -------------------------------
# Training loss: 0.105538
# Validation loss: 0.104345
#
# Epoch 480
# -------------------------------
# Training loss: 0.106976
# Validation loss: 0.108017
#
# Epoch 481
# -------------------------------
# Training loss: 0.104885
# Validation loss: 0.121058
#
# Epoch 482
# -------------------------------
# Training loss: 0.105079
# Validation loss: 0.217591
#
# Epoch 483
# -------------------------------
# Training loss: 0.107620
# Validation loss: 0.117627
#
# Epoch 484
# -------------------------------
# Training loss: 0.108589
# Validation loss: 0.195248
#
# Epoch 485
# -------------------------------
# Training loss: 0.106107
# Validation loss: 0.168411
#
# Epoch 486
# -------------------------------
# Training loss: 0.103492
# Validation loss: 0.103419
#
# Epoch 487
# -------------------------------
# Training loss: 0.103604
# Validation loss: 0.105402
#
# Epoch 488
# -------------------------------
# Training loss: 0.103422
# Validation loss: 0.113754
#
# Epoch 489
# -------------------------------
# Training loss: 0.104221
# Validation loss: 0.113402
#
# Epoch 490
# -------------------------------
# Training loss: 0.103433
# Validation loss: 0.116691
#
# Epoch 491
# -------------------------------
# Training loss: 0.103635
# Validation loss: 0.100270
#
# Epoch 492
# -------------------------------
# Training loss: 0.105859
# Validation loss: 0.111477
#
# Epoch 493
# -------------------------------
# Training loss: 0.102608
# Validation loss: 0.103179
#
# Epoch 494
# -------------------------------
# Training loss: 0.102612
# Validation loss: 0.100227
#
# Epoch 495
# -------------------------------
# Training loss: 0.103945
# Validation loss: 0.109488
#
# Epoch 496
# -------------------------------
# Training loss: 0.103959
# Validation loss: 0.103665
#
# Epoch 497
# -------------------------------
# Training loss: 0.104299
# Validation loss: 0.107737
#
# Epoch 498
# -------------------------------
# Training loss: 0.105381
# Validation loss: 0.108387
#
# Epoch 499
# -------------------------------
# Training loss: 0.101660
# Validation loss: 0.107234
#
# Epoch 500
# -------------------------------
# Training loss: 0.103718
# Validation loss: 0.147999
#
# Epoch 501
# -------------------------------
# Training loss: 0.101160
# Validation loss: 0.098730
#
# Epoch 502
# -------------------------------
# Training loss: 0.102882
# Validation loss: 0.103543
#
# Epoch 503
# -------------------------------
# Training loss: 0.100206
# Validation loss: 0.118657
#
# Epoch 504
# -------------------------------
# Training loss: 0.104042
# Validation loss: 0.103229
#
# Epoch 505
# -------------------------------
# Training loss: 0.101391
# Validation loss: 0.103166
#
# Epoch 506
# -------------------------------
# Training loss: 0.099945
# Validation loss: 0.126055
#
# Epoch 507
# -------------------------------
# Training loss: 0.100289
# Validation loss: 0.116379
#
# Epoch 508
# -------------------------------
# Training loss: 0.100199
# Validation loss: 0.191709
#
# Epoch 509
# -------------------------------
# Training loss: 0.098647
# Validation loss: 0.096499
#
# Epoch 510
# -------------------------------
# Training loss: 0.099931
# Validation loss: 0.100189
#
# Epoch 511
# -------------------------------
# Training loss: 0.097335
# Validation loss: 0.098007
#
# Epoch 512
# -------------------------------
# Training loss: 0.100990
# ...
# Validation loss: 0.048531
#
# Epoch 2333
# -------------------------------
# Training loss: 0.047228
# Validation loss: 0.048311
#
# Epoch 2334
# -------------------------------
# Training loss: 0.046978
# Validation loss: 0.048029
#
# Epoch 2335
# -------------------------------
# Training loss: 0.047377
# Validation loss: 0.048171
#
# Epoch 2336
# -------------------------------
# Training loss: 0.046829
# Validation loss: 0.050767
#
# Epoch 2337
# -------------------------------
# Training loss: 0.047638
# Validation loss: 0.050376
#
# Epoch 2338
# -------------------------------
# Training loss: 0.047645
# Validation loss: 0.051907
#
# Epoch 2339
# -------------------------------
# Training loss: 0.046654
# Validation loss: 0.052003
#
# Epoch 2340
# -------------------------------
# Training loss: 0.047003
# Validation loss: 0.050655
#
# Epoch 2341
# -------------------------------
# Training loss: 0.047693
# Validation loss: 0.049838
#
# Epoch 2342
# -------------------------------
# Training loss: 0.047150
# Validation loss: 0.051127
#
# Epoch 2343
# -------------------------------
# Training loss: 0.047234
# Validation loss: 0.051779
#
# Epoch 2344
# -------------------------------
# Training loss: 0.047081
# Validation loss: 0.050754
#
# Epoch 2345
# -------------------------------
# Training loss: 0.047216
# Validation loss: 0.049906
#
# Epoch 2346
# -------------------------------
# Training loss: 0.048510
# Validation loss: 0.051466
#
# Epoch 2347
# -------------------------------
# Training loss: 0.049843
# Validation loss: 0.052382
#
# Epoch 2348
# -------------------------------
# Training loss: 0.047120
# Validation loss: 0.050166
#
# Epoch 2349
# -------------------------------
# Training loss: 0.046130
# Validation loss: 0.047899
#
# Epoch 2350
# -------------------------------
# Training loss: 0.047778
# Validation loss: 0.048845
#
# Epoch 2351
# -------------------------------
# Training loss: 0.047288
# Validation loss: 0.051460
#
# Epoch 2352
# -------------------------------
# Training loss: 0.046878
# Validation loss: 0.048903
#
# Epoch 2353
# -------------------------------
# Training loss: 0.047088
# Validation loss: 0.048294
#
# Epoch 2354
# -------------------------------
# Training loss: 0.047840
# Validation loss: 0.047461
#
# Epoch 2355
# -------------------------------
# Training loss: 0.048591
# Validation loss: 0.047605
#
# Epoch 2356
# -------------------------------
# Training loss: 0.048073
# Validation loss: 0.052696
#
# Epoch 2357
# -------------------------------
# Training loss: 0.046794
# Validation loss: 0.048873
#
# Epoch 2358
# -------------------------------
# Training loss: 0.047887
# Validation loss: 0.049485
#
# Epoch 2359
# -------------------------------
# Training loss: 0.047919
# Validation loss: 0.049612
#
# Epoch 2360
# -------------------------------
# Training loss: 0.047317
# Validation loss: 0.048035
#
# Epoch 2361
# -------------------------------
# Training loss: 0.047754
# Validation loss: 0.051652
#
# Epoch 2362
# -------------------------------
# Training loss: 0.046742
# Validation loss: 0.049497
#
# Epoch 2363
# -------------------------------
# Training loss: 0.046453
# Validation loss: 0.049092
#
# Epoch 2364
# -------------------------------
# Training loss: 0.047232
# Validation loss: 0.047780
#
# Epoch 2365
# -------------------------------
# Training loss: 0.046995
# Validation loss: 0.048869
#
# Epoch 2366
# -------------------------------
# Training loss: 0.047136
# Validation loss: 0.050991
#
# Epoch 2367
# -------------------------------
# Training loss: 0.047646
# Validation loss: 0.051339
#
# Epoch 2368
# -------------------------------
# Training loss: 0.046405
# Validation loss: 0.047991
#
# Epoch 2369
# -------------------------------
# Training loss: 0.046791
# Validation loss: 0.047087
#
# Epoch 2370
# -------------------------------
# Training loss: 0.047858
# Validation loss: 0.047761
#
# Epoch 2371
# -------------------------------
# Training loss: 0.048398
# Validation loss: 0.049264
#
# Epoch 2372
# -------------------------------
# Training loss: 0.047102
# Validation loss: 0.052465
#
# Epoch 2373
# -------------------------------
# Training loss: 0.047079
# Validation loss: 0.048645
#
# Epoch 2374
# -------------------------------
# Training loss: 0.047341
# Validation loss: 0.051676
#
# Epoch 2375
# -------------------------------
# Training loss: 0.048532
# Validation loss: 0.049903
#
# Epoch 2376
# -------------------------------
# Training loss: 0.047238
# Validation loss: 0.050414
#
# Epoch 2377
# -------------------------------
# Training loss: 0.048213
# Validation loss: 0.047950
#
# Epoch 2378
# -------------------------------
# Training loss: 0.046906
# Validation loss: 0.048739
#
# Epoch 2379
# -------------------------------
# Training loss: 0.047907
# Validation loss: 0.048729
#
# Epoch 2380
# -------------------------------
# Training loss: 0.047411
# Validation loss: 0.048935
#
# Epoch 2381
# -------------------------------
# Training loss: 0.046819
# Validation loss: 0.049586
#
# Epoch 2382
# -------------------------------
# Training loss: 0.047558
# Validation loss: 0.050336
#
# Epoch 2383
# -------------------------------
# Training loss: 0.045919
# Validation loss: 0.047813
#
# Epoch 2384
# -------------------------------
# Training loss: 0.047117
# Validation loss: 0.048054
#
# Epoch 2385
# -------------------------------
# Training loss: 0.047034
# Validation loss: 0.047526
#
# Epoch 2386
# -------------------------------
# Training loss: 0.046386
# Validation loss: 0.050760
#
# Epoch 2387
# -------------------------------
# Training loss: 0.048084
# Validation loss: 0.047923
#
# Epoch 2388
# -------------------------------
# Training loss: 0.047044
# Validation loss: 0.048694
#
# Epoch 2389
# -------------------------------
# Training loss: 0.046722
# Validation loss: 0.052757
#
# Epoch 2390
# -------------------------------
# Training loss: 0.047290
# Validation loss: 0.048781
#
# Epoch 2391
# -------------------------------
# Training loss: 0.045967
# Validation loss: 0.050399
#
# Epoch 2392
# -------------------------------
# Training loss: 0.046731
# Validation loss: 0.050595
#
# Epoch 2393
# -------------------------------
# Training loss: 0.048881
# Validation loss: 0.048546
#
# Epoch 2394
# -------------------------------
# Training loss: 0.047538
# Validation loss: 0.049653
#
# Epoch 2395
# -------------------------------
# Training loss: 0.046970
# Validation loss: 0.051582
#
# Epoch 2396
# -------------------------------
# Training loss: 0.046653
# Validation loss: 0.048482
#
# Epoch 2397
# -------------------------------
# Training loss: 0.047671
# Validation loss: 0.048221
#
# Epoch 2398
# -------------------------------
# Training loss: 0.047308
# Validation loss: 0.047500
#
# Epoch 2399
# -------------------------------
# Training loss: 0.047135
# Validation loss: 0.048814
#
# Epoch 2400
# -------------------------------
# Training loss: 0.047799
# Validation loss: 0.050712
#
# Epoch 2401
# -------------------------------
# Training loss: 0.047344
# Validation loss: 0.051715
#
# Epoch 2402
# -------------------------------
# Training loss: 0.047548
# Validation loss: 0.051241
#
# Epoch 2403
# -------------------------------
# Training loss: 0.047422
# Validation loss: 0.047912
#
# Epoch 2404
# -------------------------------
# Training loss: 0.048575
# Validation loss: 0.048887
#
# Epoch 2405
# -------------------------------
# Training loss: 0.048104
# Validation loss: 0.048978
#
# Epoch 2406
# -------------------------------
# Training loss: 0.046261
# Validation loss: 0.047698
#
# Epoch 2407
# -------------------------------
# Training loss: 0.047010
# Validation loss: 0.048463
#
# Epoch 2408
# -------------------------------
# Training loss: 0.046491
# Validation loss: 0.050202
#
# Epoch 2409
# -------------------------------
# Training loss: 0.047197
# Validation loss: 0.050226
#
# Epoch 2410
# -------------------------------
# Training loss: 0.047440
# Validation loss: 0.050599
#
# Epoch 2411
# -------------------------------
# Training loss: 0.046964
# Validation loss: 0.048780
#
# Epoch 2412
# -------------------------------
# Training loss: 0.047399
# Validation loss: 0.050954
#
# Epoch 2413
# -------------------------------
# Training loss: 0.046802
# Validation loss: 0.051285
#
# Epoch 2414
# -------------------------------
# Training loss: 0.046268
# Validation loss: 0.047576
#
# Epoch 2415
# -------------------------------
# Training loss: 0.048118
# Validation loss: 0.048699
#
# Epoch 2416
# -------------------------------
# Training loss: 0.046743
# Validation loss: 0.050381
#
# Epoch 2417
# -------------------------------
# Training loss: 0.047220
# Validation loss: 0.048035
#
# Epoch 2418
# -------------------------------
# Training loss: 0.048319
# Validation loss: 0.047750
#
# Epoch 2419
# -------------------------------
# Training loss: 0.049247
# Validation loss: 0.049304
#
# Epoch 2420
# -------------------------------
# Training loss: 0.046993
# Validation loss: 0.049682
#
# Epoch 2421
# -------------------------------
# Training loss: 0.047284
# Validation loss: 0.047551
#
# Epoch 2422
# -------------------------------
# Training loss: 0.047006
# Validation loss: 0.049124
#
# Epoch 2423
# -------------------------------
# Training loss: 0.046497
# Validation loss: 0.049877
#
# Epoch 2424
# -------------------------------
# Training loss: 0.047099
# Validation loss: 0.048398
#
# Epoch 2425
# -------------------------------
# Training loss: 0.047535
# Validation loss: 0.048445
#
# Epoch 2426
# -------------------------------
# Training loss: 0.050220
# Validation loss: 0.051395
#
# Epoch 2427
# -------------------------------
# Training loss: 0.046907
# Validation loss: 0.050425
#
# Epoch 2428
# -------------------------------
# Training loss: 0.047539
# Validation loss: 0.049109
#
# Epoch 2429
# -------------------------------
# Training loss: 0.046289
# Validation loss: 0.049877
#
# Epoch 2430
# -------------------------------
# Training loss: 0.047518
# Validation loss: 0.048358
#
# Epoch 2431
# -------------------------------
# Training loss: 0.046638
# Validation loss: 0.049982
#
# Epoch 2432
# -------------------------------
# Training loss: 0.047399
# Validation loss: 0.048045
#
# Epoch 2433
# -------------------------------
# Training loss: 0.046250
# Validation loss: 0.047591
#
# Epoch 2434
# -------------------------------
# Training loss: 0.047354
# Validation loss: 0.050909
#
# Epoch 2435
# -------------------------------
# Training loss: 0.046344
# Validation loss: 0.049828
#
# Epoch 2436
# -------------------------------
# Training loss: 0.048729
# Validation loss: 0.049268
#
# Epoch 2437
# -------------------------------
# Training loss: 0.046990
# Validation loss: 0.047790
#
# Epoch 2438
# -------------------------------
# Training loss: 0.047472
# Validation loss: 0.051362
#
# Epoch 2439
# -------------------------------
# Training loss: 0.047676
# Validation loss: 0.049735
#
# Epoch 2440
# -------------------------------
# Training loss: 0.046803
# Validation loss: 0.048821
#
# Epoch 2441
# -------------------------------
# Training loss: 0.047498
# Validation loss: 0.048788
#
# Epoch 2442
# -------------------------------
# Training loss: 0.047520
# Validation loss: 0.048039
#
# Epoch 2443
# -------------------------------
# Training loss: 0.046571
# Validation loss: 0.049564
#
# Epoch 2444
# -------------------------------
# Training loss: 0.047429
# Validation loss: 0.049952
#
# Epoch 2445
# -------------------------------
# Training loss: 0.048432
# Validation loss: 0.049343
#
# Epoch 2446
# -------------------------------
# Training loss: 0.047710
# Validation loss: 0.048869
#
# Epoch 2447
# -------------------------------
# Training loss: 0.047472
# Validation loss: 0.048623
#
# Epoch 2448
# -------------------------------
# Training loss: 0.048092
# Validation loss: 0.049085
#
# Epoch 2449
# -------------------------------
# Training loss: 0.048274
# Validation loss: 0.050826
#
# Epoch 2450
# -------------------------------
# Training loss: 0.047350
# Validation loss: 0.046968
#
# Epoch 2451
# -------------------------------
# Training loss: 0.047575
# Validation loss: 0.047566
#
# Epoch 2452
# -------------------------------
# Training loss: 0.047908
# Validation loss: 0.048808
#
# Epoch 2453
# -------------------------------
# Training loss: 0.047212
# Validation loss: 0.048598
#
# Epoch 2454
# -------------------------------
# Training loss: 0.046919
# Validation loss: 0.047681
#
# Epoch 2455
# -------------------------------
# Training loss: 0.048405
# Validation loss: 0.048609
#
# Epoch 2456
# -------------------------------
# Training loss: 0.047245
# Validation loss: 0.048355
#
# Epoch 2457
# -------------------------------
# Training loss: 0.047258
# Validation loss: 0.047911
#
# Epoch 2458
# -------------------------------
# Training loss: 0.046862
# Validation loss: 0.048878
#
# Epoch 2459
# -------------------------------
# Training loss: 0.046754
# Validation loss: 0.052720
#
# Epoch 2460
# -------------------------------
# Training loss: 0.046606
# Validation loss: 0.049094
#
# Epoch 2461
# -------------------------------
# Training loss: 0.047177
# Validation loss: 0.048535
#
# Epoch 2462
# -------------------------------
# Training loss: 0.046272
# Validation loss: 0.050665
#
# Epoch 2463
# -------------------------------
# Training loss: 0.047743
# Validation loss: 0.050361
#
# Epoch 2464
# -------------------------------
# Training loss: 0.047118
# Validation loss: 0.050422
#
# Epoch 2465
# -------------------------------
# Training loss: 0.046388
# Validation loss: 0.048241
#
# Epoch 2466
# -------------------------------
# Training loss: 0.047213
# Validation loss: 0.048594
#
# Epoch 2467
# -------------------------------
# Training loss: 0.046702
# Validation loss: 0.047871
#
# Epoch 2468
# -------------------------------
# Training loss: 0.046413
# Validation loss: 0.050077
#
# Epoch 2469
# -------------------------------
# Training loss: 0.047169
# Validation loss: 0.047468
#
# Epoch 2470
# -------------------------------
# Training loss: 0.047185
# Validation loss: 0.049406
#
# Epoch 2471
# -------------------------------
# Training loss: 0.047397
# Validation loss: 0.049054
#
# Epoch 2472
# -------------------------------
# Training loss: 0.048018
# Validation loss: 0.048556
#
# Epoch 2473
# -------------------------------
# Training loss: 0.047939
# Validation loss: 0.050687
#
# Epoch 2474
# -------------------------------
# Training loss: 0.047167
# Validation loss: 0.050550
#
# Epoch 2475
# -------------------------------
# Training loss: 0.047111
# Validation loss: 0.052750
#
# Epoch 2476
# -------------------------------
# Training loss: 0.046645
# Validation loss: 0.048813
#
# Epoch 2477
# -------------------------------
# Training loss: 0.047070
# Validation loss: 0.048450
#
# Epoch 2478
# -------------------------------
# Training loss: 0.046985
# Validation loss: 0.051940
#
# Epoch 2479
# -------------------------------
# Training loss: 0.047105
# Validation loss: 0.052042
#
# Epoch 2480
# -------------------------------
# Training loss: 0.046793
# Validation loss: 0.048462
#
# Epoch 2481
# -------------------------------
# Training loss: 0.046489
# Validation loss: 0.047963
#
# Epoch 2482
# -------------------------------
# Training loss: 0.049287
# Validation loss: 0.049847
#
# Epoch 2483
# -------------------------------
# Training loss: 0.047307
# Validation loss: 0.051642
#
# Epoch 2484
# -------------------------------
# Training loss: 0.047674
# Validation loss: 0.049139
#
# Epoch 2485
# -------------------------------
# Training loss: 0.046493
# Validation loss: 0.049223
#
# Epoch 2486
# -------------------------------
# Training loss: 0.047286
# Validation loss: 0.049805
#
# Epoch 2487
# -------------------------------
# Training loss: 0.047612
# Validation loss: 0.050327
#
# Epoch 2488
# -------------------------------
# Training loss: 0.047873
# Validation loss: 0.048680
#
# Epoch 2489
# -------------------------------
# Training loss: 0.048834
# Validation loss: 0.049035
#
# Epoch 2490
# -------------------------------
# Training loss: 0.047438
# Validation loss: 0.049024
#
# Epoch 2491
# -------------------------------
# Training loss: 0.046656
# Validation loss: 0.048403
#
# Epoch 2492
# -------------------------------
# Training loss: 0.046777
# Validation loss: 0.047660
#
# Epoch 2493
# -------------------------------
# Training loss: 0.046497
# Validation loss: 0.048068
#
# Epoch 2494
# -------------------------------
# Training loss: 0.047806
# Validation loss: 0.048027
#
# Epoch 2495
# -------------------------------
# Training loss: 0.046343
# Validation loss: 0.051032
#
# Epoch 2496
# -------------------------------
# Training loss: 0.046317
# Validation loss: 0.048252
#
# Epoch 2497
# -------------------------------
# Training loss: 0.047491
# Validation loss: 0.051362
#
# Epoch 2498
# -------------------------------
# Training loss: 0.046573
# Validation loss: 0.049331
#
# Epoch 2499
# -------------------------------
# Training loss: 0.046812
# Validation loss: 0.051029
#
# Epoch 2500
# -------------------------------
# Training loss: 0.047591
# Validation loss: 0.048830
#
# Done!

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses)+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('BCE Loss')
#plt.yscale('log')
plt.legend()

# %%
# Now test the pretrained model
test_pred = mytools.test_clas(test_loader, final_classifier, device)
test_pred=torch.sigmoid(torch.tensor(test_pred)).numpy()


fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test, test_pred, pos_label=1)
auc_test = sklearn.metrics.auc(fpr, tpr)
print(f'Test AUROC: {auc_test:0.4f}')

plt.plot(fpr, tpr, label=f'Test AUROC: {auc_test:0.4f}')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
# Out:
# Test AUROC: 0.9966

# %%
# Store the pretrained classifier labels
df_test["Class_pre"] = test_pred

# Save the pretrained classifier model
torch.save(final_classifier.state_dict(), "/Users/mghrear/data/ML_data/2019_pass2/models/pretrained_classifier_2019_pass2_run"+str(run)+"_unscaled.pt")

# %% [markdown]
# # Setup the adversary model

# %% [markdown]
# ## Initialize model, objective function, and optimizer

# %%
adv = mytools.Adversary(n_classes=Num_classes).to(device)
criterion_adv = nn.CrossEntropyLoss(reduction='none')  # returns loss per sample so we can weight it
opt_adv = torch.optim.Adam(adv.parameters(), lr=1e-5)
scheduler_adv = torch.optim.lr_scheduler.ExponentialLR(opt_adv, gamma=0.999)

# %% [markdown]
# ## Setup dataloaders

# %%
# Convert to tensor dataset and dataloader

# the structure is: feature, adversary label, weight
# The wight is 1 for tritrig and wab, and 0 for phiKK, to prevent the adversary from learning on phiKK events

train_adv_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_train), (torch.from_numpy(y_train.to_numpy().astype(np.float32))==0).float())
train_adv_loader = DataLoader(train_adv_dataset, batch_size=bsize, shuffle=True)

val_adv_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_val), (torch.from_numpy(y_val.to_numpy().astype(np.float32))==0).float() )
val_adv_loader = DataLoader(val_adv_dataset, batch_size=bsize, shuffle=True)

# Weights are not relavent for testing
test_adv_dataset = TensorDataset(torch.from_numpy(X_test.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_test))
test_adv_loader = DataLoader(test_adv_dataset, batch_size=bsize, shuffle=True)

# %% [markdown]
# ## Pre-train the adversary leaving classifier weights fixed

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 6

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 100
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train_adv(train_adv_loader, final_classifier, adv, criterion_adv, opt_adv, scheduler_adv, device))
    Validation_losses = np.append(Validation_losses, mytools.validate_adv(val_adv_loader, final_classifier, adv, criterion_adv, device))
    
    # Keep a running copy of the model with the lowest loss
    if Validation_losses[-1] == np.min(Validation_losses):
        final_adv = copy.deepcopy(adv)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Training loss: 1.638956
# Validation loss: 1.615144
#
# Epoch 2
# -------------------------------
# Training loss: 1.625516
# Validation loss: 1.626840
#
# Epoch 3
# -------------------------------
# Training loss: 1.615750
# Validation loss: 1.620495
#
# Epoch 4
# -------------------------------
# Training loss: 1.608509
# Validation loss: 1.609577
#
# Epoch 5
# -------------------------------
# Training loss: 1.602935
# Validation loss: 1.599568
#
# Epoch 6
# -------------------------------
# Training loss: 1.598336
# Validation loss: 1.596914
#
# Epoch 7
# -------------------------------
# Training loss: 1.594374
# Validation loss: 1.596805
#
# Epoch 8
# -------------------------------
# Training loss: 1.591291
# Validation loss: 1.589307
#
# Epoch 9
# -------------------------------
# Training loss: 1.589215
# Validation loss: 1.589177
#
# Epoch 10
# -------------------------------
# Training loss: 1.587623
# Validation loss: 1.583439
#
# Epoch 11
# -------------------------------
# Training loss: 1.586149
# Validation loss: 1.582229
#
# Epoch 12
# -------------------------------
# Training loss: 1.584946
# Validation loss: 1.582534
#
# Epoch 13
# -------------------------------
# Training loss: 1.584129
# Validation loss: 1.581812
#
# Epoch 14
# -------------------------------
# Training loss: 1.583427
# Validation loss: 1.580386
#
# Epoch 15
# -------------------------------
# Training loss: 1.583129
# Validation loss: 1.580714
#
# Epoch 16
# -------------------------------
# Training loss: 1.582684
# Validation loss: 1.582691
#
# Epoch 17
# -------------------------------
# Training loss: 1.582001
# Validation loss: 1.582679
#
# Epoch 18
# -------------------------------
# Training loss: 1.581524
# Validation loss: 1.579553
#
# Epoch 19
# -------------------------------
# Training loss: 1.581311
# Validation loss: 1.578127
#
# Epoch 20
# -------------------------------
# Training loss: 1.580553
# Validation loss: 1.582024
#
# Epoch 21
# -------------------------------
# Training loss: 1.579856
# Validation loss: 1.583265
#
# Epoch 22
# -------------------------------
# Training loss: 1.579592
# Validation loss: 1.577853
#
# Epoch 23
# -------------------------------
# Training loss: 1.580156
# Validation loss: 1.580519
#
# Epoch 24
# -------------------------------
# Training loss: 1.579529
# Validation loss: 1.578296
#
# Epoch 25
# -------------------------------
# Training loss: 1.579688
# Validation loss: 1.574938
#
# Epoch 26
# -------------------------------
# Training loss: 1.579518
# Validation loss: 1.576583
#
# Epoch 27
# -------------------------------
# Training loss: 1.578803
# Validation loss: 1.581206
#
# Epoch 28
# -------------------------------
# Training loss: 1.578597
# Validation loss: 1.577609
#
# Epoch 29
# -------------------------------
# Training loss: 1.578996
# Validation loss: 1.578520
#
# Epoch 30
# -------------------------------
# Training loss: 1.578283
# Validation loss: 1.577996
#
# Epoch 31
# -------------------------------
# Training loss: 1.578474
# Validation loss: 1.580657
#
# Epoch 32
# -------------------------------
# Training loss: 1.578518
# Validation loss: 1.575416
#
# Epoch 33
# -------------------------------
# Training loss: 1.577590
# Validation loss: 1.577830
#
# Epoch 34
# -------------------------------
# Training loss: 1.578104
# Validation loss: 1.577063
#
# Epoch 35
# -------------------------------
# Training loss: 1.578170
# Validation loss: 1.576553
#
# Epoch 36
# -------------------------------
# Training loss: 1.577853
# Validation loss: 1.576325
#
# Epoch 37
# -------------------------------
# Training loss: 1.577798
# Validation loss: 1.574685
#
# Epoch 38
# -------------------------------
# Training loss: 1.577116
# Validation loss: 1.578042
#
# Epoch 39
# -------------------------------
# Training loss: 1.577848
# Validation loss: 1.575103
#
# Epoch 40
# -------------------------------
# Training loss: 1.577098
# Validation loss: 1.577403
#
# Epoch 41
# -------------------------------
# Training loss: 1.577363
# Validation loss: 1.572752
#
# Epoch 42
# -------------------------------
# Training loss: 1.577238
# Validation loss: 1.576923
#
# Epoch 43
# -------------------------------
# Training loss: 1.577289
# Validation loss: 1.578626
#
# Epoch 44
# -------------------------------
# Training loss: 1.577349
# Validation loss: 1.577765
#
# Epoch 45
# -------------------------------
# Training loss: 1.577224
# Validation loss: 1.573566
#
# Epoch 46
# -------------------------------
# Training loss: 1.577296
# Validation loss: 1.577603
#
# Epoch 47
# -------------------------------
# Training loss: 1.576530
# Validation loss: 1.576225
#
# Epoch 48
# -------------------------------
# Training loss: 1.577066
# Validation loss: 1.574067
#
# Epoch 49
# -------------------------------
# Training loss: 1.576750
# Validation loss: 1.574052
#
# Epoch 50
# -------------------------------
# Training loss: 1.576976
# Validation loss: 1.576114
#
# Epoch 51
# -------------------------------
# Training loss: 1.576676
# Validation loss: 1.572836
#
# Epoch 52
# -------------------------------
# Training loss: 1.577028
# Validation loss: 1.574576
#
# Epoch 53
# -------------------------------
# Training loss: 1.576761
# Validation loss: 1.575227
#
# Epoch 54
# -------------------------------
# Training loss: 1.577212
# Validation loss: 1.572640
#
# Epoch 55
# -------------------------------
# Training loss: 1.576854
# Validation loss: 1.573156
#
# Epoch 56
# -------------------------------
# Training loss: 1.576410
# Validation loss: 1.579670
#
# Epoch 57
# -------------------------------
# Training loss: 1.576388
# Validation loss: 1.573261
#
# Epoch 58
# -------------------------------
# Training loss: 1.576608
# Validation loss: 1.574097
#
# Epoch 59
# -------------------------------
# Training loss: 1.576722
# Validation loss: 1.576298
#
# Epoch 60
# -------------------------------
# Training loss: 1.576880
# Validation loss: 1.573438
#
# Epoch 61
# -------------------------------
# Training loss: 1.576580
# Validation loss: 1.574134
#
# Epoch 62
# -------------------------------
# Training loss: 1.576301
# Validation loss: 1.575002
#
# Epoch 63
# -------------------------------
# Training loss: 1.576807
# Validation loss: 1.570121
#
# Epoch 64
# -------------------------------
# Training loss: 1.576300
# Validation loss: 1.573024
#
# Epoch 65
# -------------------------------
# Training loss: 1.576058
# Validation loss: 1.573103
#
# Epoch 66
# -------------------------------
# Training loss: 1.576366
# Validation loss: 1.576466
#
# Epoch 67
# -------------------------------
# Training loss: 1.576542
# Validation loss: 1.577760
#
# Epoch 68
# -------------------------------
# Training loss: 1.576073
# Validation loss: 1.573379
#
# Epoch 69
# -------------------------------
# Training loss: 1.576244
# Validation loss: 1.573695
#
# Epoch 70
# -------------------------------
# Training loss: 1.576254
# Validation loss: 1.572195
#
# Epoch 71
# -------------------------------
# Training loss: 1.576337
# Validation loss: 1.573985
#
# Epoch 72
# -------------------------------
# Training loss: 1.575917
# Validation loss: 1.575141
#
# Epoch 73
# -------------------------------
# Training loss: 1.576125
# Validation loss: 1.576850
#
# Epoch 74
# -------------------------------
# Training loss: 1.576274
# Validation loss: 1.574107
#
# Epoch 75
# -------------------------------
# Training loss: 1.576160
# Validation loss: 1.574440
#
# Epoch 76
# -------------------------------
# Training loss: 1.576449
# Validation loss: 1.576526
#
# Epoch 77
# -------------------------------
# Training loss: 1.576517
# Validation loss: 1.572799
#
# Epoch 78
# -------------------------------
# Training loss: 1.576489
# Validation loss: 1.575053
#
# Epoch 79
# -------------------------------
# Training loss: 1.576340
# Validation loss: 1.573109
#
# Epoch 80
# -------------------------------
# Training loss: 1.575956
# Validation loss: 1.574205
#
# Epoch 81
# -------------------------------
# Training loss: 1.576122
# Validation loss: 1.574330
#
# Epoch 82
# -------------------------------
# Training loss: 1.576113
# Validation loss: 1.574392
#
# Epoch 83
# -------------------------------
# Training loss: 1.576058
# Validation loss: 1.575640
#
# Epoch 84
# -------------------------------
# Training loss: 1.575872
# Validation loss: 1.574258
#
# Epoch 85
# -------------------------------
# Training loss: 1.576109
# Validation loss: 1.576693
#
# Epoch 86
# -------------------------------
# Training loss: 1.575980
# Validation loss: 1.574212
#
# Epoch 87
# -------------------------------
# Training loss: 1.575893
# Validation loss: 1.576572
#
# Epoch 88
# -------------------------------
# Training loss: 1.576164
# Validation loss: 1.573741
#
# Epoch 89
# -------------------------------
# Training loss: 1.576467
# Validation loss: 1.576218
#
# Epoch 90
# -------------------------------
# Training loss: 1.575722
# Validation loss: 1.575980
#
# Epoch 91
# -------------------------------
# Training loss: 1.576435
# Validation loss: 1.577005
#
# Epoch 92
# -------------------------------
# Training loss: 1.576064
# Validation loss: 1.573274
#
# Epoch 93
# -------------------------------
# Training loss: 1.576319
# Validation loss: 1.573695
#
# Epoch 94
# -------------------------------
# Training loss: 1.575908
# Validation loss: 1.575642
#
# Epoch 95
# -------------------------------
# Training loss: 1.575991
# Validation loss: 1.574933
#
# Epoch 96
# -------------------------------
# Training loss: 1.576208
# Validation loss: 1.576002
#
# Epoch 97
# -------------------------------
# Training loss: 1.576221
# Validation loss: 1.576069
#
# Epoch 98
# -------------------------------
# Training loss: 1.575724
# Validation loss: 1.577243
#
# Epoch 99
# -------------------------------
# Training loss: 1.576574
# Validation loss: 1.572406
#
# Epoch 100
# -------------------------------
# Training loss: 1.575784
# Validation loss: 1.575647
#
# Done!

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses)+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('BCE Loss')
plt.legend()

# %% [markdown]
# # Train full adverserial neural network

# %% [markdown]
# # Setup dataloaders

# %%
# the structure is: feature, classifier label, adversary label, weight
# The wight is 1 for tritrig and wab, and 0 for phiKK, to prevent the adversary from learning on phiKK events

train_full_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy().astype(np.float32))  , torch.from_numpy(y_train.to_numpy().astype(np.float32)).unsqueeze(1), torch.from_numpy(y_adv_train),  (torch.from_numpy(y_train.to_numpy().astype(np.float32))==0).float())
train_full_loader = DataLoader(train_full_dataset, batch_size=bsize, shuffle=True)

val_full_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy().astype(np.float32))  , torch.from_numpy(y_val.to_numpy().astype(np.float32)).unsqueeze(1),  torch.from_numpy(y_adv_val),  (torch.from_numpy(y_val.to_numpy().astype(np.float32))==0).float())
val_full_loader = DataLoader(val_full_dataset, batch_size=bsize, shuffle=True)

# %% [markdown]
# ## Define loss functions

# %%
BCE_loss = nn.BCEWithLogitsLoss()
CE_loss = nn.CrossEntropyLoss(reduction='none') # returns loss per sample so we can weight it

def full_loss(output_clas, output_adv, target_clas, target_adv, w, lambda_):

    loss1 = BCE_loss(output_clas, target_clas )  # classification loss
    sample_losses2 = CE_loss(output_adv, target_adv)  # adversarial losses, since we set reduction='none', this is now a vector of losses, one per sample in the batch

    # Weighted mean loss over non-zero weights
    nonzero = w > 0
    loss2 = (sample_losses2[nonzero] * w[nonzero]).sum() / w[nonzero].sum()

    loss = loss1 - lambda_*loss2

    return loss

# %% [markdown]
# ## Setup optimizers

# %%
optimizer_clas = optim.Adam(final_classifier.parameters(), lr=1e-7,betas=(0.5, 0.999))
optimizer_adv = optim.Adam(final_adv.parameters(), lr=1e-5,betas=(0.5, 0.999))

scheduler_clas = torch.optim.lr_scheduler.ExponentialLR(optimizer_clas, gamma=0.999)
scheduler_adv = torch.optim.lr_scheduler.ExponentialLR(optimizer_adv, gamma=0.999)

# %% [markdown]
# ## Adversarial training

# %%
Training_losses_clas = np.array([])
Training_losses_adv = np.array([])
Validation_losses_clas = np.array([])
Validation_losses_adv = np.array([])
diff_scores = np.array([])


epochs = 50
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")

    # Get validation losses
    E_clas_val_loss, E_adv_val_loss = mytools.validate_full(val_full_loader, final_classifier, final_adv, full_loss, lambda_, criterion_adv, device)
    Validation_losses_clas = np.append(Validation_losses_clas, E_clas_val_loss)
    Validation_losses_adv = np.append(Validation_losses_adv, E_adv_val_loss)

    # Train adversary and classifier
    E_clas_training_loss , E_adv_training_loss = mytools.train_full(train_full_loader, final_classifier, final_adv, full_loss, lambda_, criterion_adv, optimizer_clas, optimizer_adv, scheduler_clas, scheduler_adv, device)
    Training_losses_clas = np.append(Training_losses_clas, E_clas_training_loss)
    Training_losses_adv = np.append(Training_losses_adv, E_adv_training_loss)

    # Get the diff_score
    df_test["Class_adv"] = mytools.test_clas(test_loader, final_classifier, device)
    df_bkg = df_test.loc[ (df_test.type == 'tritrig') | (df_test.type == 'wab')]
    per = np.percentile(df_bkg['Class_adv'],99)
    df_cut = df_bkg[df_bkg['Class_adv']>per].reset_index(drop=True)
    x1 = 1000* df_bkg.InvM.values
    x2 = 1000*df_cut.InvM.values
    diff_scores = np.append(diff_scores, mytools.get_diff_score(x1,x2) )

    # Keep a running copy of the model with the lowest loss
    if diff_scores[-1] == np.min(diff_scores):
        final_clas_adv = copy.deepcopy(final_classifier)
        final_adv_adv = copy.deepcopy(final_adv)

            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Classifier validation loss: -157.373125
# Adversary validation loss: 1.574216
# Classifier training loss: -158.373994
# Adversary training loss: 1.584850
# Epoch 2
# -------------------------------
# Classifier validation loss: -158.526507
# Adversary validation loss: 1.585760
# Classifier training loss: -158.751925
# Adversary training loss: 1.588553
# Epoch 3
# -------------------------------
# Classifier validation loss: -159.073015
# Adversary validation loss: 1.591238
# Classifier training loss: -159.593489
# Adversary training loss: 1.597240
# Epoch 4
# -------------------------------
# Classifier validation loss: -160.288957
# Adversary validation loss: 1.603411
# Classifier training loss: -160.663569
# Adversary training loss: 1.607873
# Epoch 5
# -------------------------------
# Classifier validation loss: -161.783214
# Adversary validation loss: 1.618441
# Classifier training loss: -160.954466
# Adversary training loss: 1.610480
# Epoch 6
# -------------------------------
# Classifier validation loss: -160.576175
# Adversary validation loss: 1.606345
# Classifier training loss: -161.020244
# Adversary training loss: 1.611053
# Epoch 7
# -------------------------------
# Classifier validation loss: -161.278835
# Adversary validation loss: 1.613464
# Classifier training loss: -160.806000
# Adversary training loss: 1.608837
# Epoch 8
# -------------------------------
# Classifier validation loss: -160.889177
# Adversary validation loss: 1.609495
# Classifier training loss: -160.735815
# Adversary training loss: 1.608096
# Epoch 9
# -------------------------------
# Classifier validation loss: -160.832399
# Adversary validation loss: 1.608970
# Classifier training loss: -160.506527
# Adversary training loss: 1.605800
# Epoch 10
# -------------------------------
# Classifier validation loss: -160.672198
# Adversary validation loss: 1.607334
# Classifier training loss: -160.516755
# Adversary training loss: 1.605894
# Epoch 11
# -------------------------------
# Classifier validation loss: -160.392720
# Adversary validation loss: 1.604578
# Classifier training loss: -160.621703
# Adversary training loss: 1.606912
# Epoch 12
# -------------------------------
# Classifier validation loss: -160.677075
# Adversary validation loss: 1.607377
# Classifier training loss: -160.615867
# Adversary training loss: 1.606825
# Epoch 13
# -------------------------------
# Classifier validation loss: -160.710664
# Adversary validation loss: 1.607747
# Classifier training loss: -160.608909
# Adversary training loss: 1.606754
# Epoch 14
# -------------------------------
# Classifier validation loss: -160.722131
# Adversary validation loss: 1.607819
# Classifier training loss: -160.740258
# Adversary training loss: 1.608034
# Epoch 15
# -------------------------------
# Classifier validation loss: -160.832318
# Adversary validation loss: 1.608881
# Classifier training loss: -160.700283
# Adversary training loss: 1.607637
# Epoch 16
# -------------------------------
# Classifier validation loss: -161.050103
# Adversary validation loss: 1.611103
# Classifier training loss: -160.695619
# Adversary training loss: 1.607593
# Epoch 17
# -------------------------------
# Classifier validation loss: -160.843056
# Adversary validation loss: 1.608993
# Classifier training loss: -160.723153
# Adversary training loss: 1.607869
# Epoch 18
# -------------------------------
# Classifier validation loss: -160.834156
# Adversary validation loss: 1.608964
# Classifier training loss: -160.711776
# Adversary training loss: 1.607776
# Epoch 19
# -------------------------------
# Classifier validation loss: -160.935561
# Adversary validation loss: 1.609952
# Classifier training loss: -160.794118
# Adversary training loss: 1.608606
# Epoch 20
# -------------------------------
# Classifier validation loss: -160.825512
# Adversary validation loss: 1.608852
# Classifier training loss: -160.775593
# Adversary training loss: 1.608404
# Epoch 21
# -------------------------------
# Classifier validation loss: -160.990173
# Adversary validation loss: 1.610513
# Classifier training loss: -160.748740
# Adversary training loss: 1.608130
# Epoch 22
# -------------------------------
# Classifier validation loss: -160.957374
# Adversary validation loss: 1.610184
# Classifier training loss: -160.743637
# Adversary training loss: 1.608099
# Epoch 23
# -------------------------------
# Classifier validation loss: -160.980606
# Adversary validation loss: 1.610441
# Classifier training loss: -160.813769
# Adversary training loss: 1.608795
# Epoch 24
# -------------------------------
# Classifier validation loss: -160.778270
# Adversary validation loss: 1.608405
# Classifier training loss: -160.777536
# Adversary training loss: 1.608423
# Epoch 25
# -------------------------------
# Classifier validation loss: -160.891184
# Adversary validation loss: 1.609553
# Classifier training loss: -160.736001
# Adversary training loss: 1.608039
# Epoch 26
# -------------------------------
# Classifier validation loss: -160.859833
# Adversary validation loss: 1.609228
# Classifier training loss: -160.783175
# Adversary training loss: 1.608501
# Epoch 27
# -------------------------------
# Classifier validation loss: -160.776385
# Adversary validation loss: 1.608418
# Classifier training loss: -160.833158
# Adversary training loss: 1.608997
# Epoch 28
# -------------------------------
# Classifier validation loss: -160.881195
# Adversary validation loss: 1.609464
# Classifier training loss: -160.759907
# Adversary training loss: 1.608254
# Epoch 29
# -------------------------------
# Classifier validation loss: -160.864768
# Adversary validation loss: 1.609262
# Classifier training loss: -160.778722
# Adversary training loss: 1.608447
# Epoch 30
# -------------------------------
# Classifier validation loss: -160.885509
# Adversary validation loss: 1.609514
# Classifier training loss: -160.782766
# Adversary training loss: 1.608480
# Epoch 31
# -------------------------------
# Classifier validation loss: -160.898948
# Adversary validation loss: 1.609638
# Classifier training loss: -160.772297
# Adversary training loss: 1.608383
# Epoch 32
# -------------------------------
# Classifier validation loss: -161.024449
# Adversary validation loss: 1.610901
# Classifier training loss: -160.808716
# Adversary training loss: 1.608733
# Epoch 33
# -------------------------------
# Classifier validation loss: -160.831661
# Adversary validation loss: 1.608978
# Classifier training loss: -160.794558
# Adversary training loss: 1.608605
# Epoch 34
# -------------------------------
# Classifier validation loss: -160.900289
# Adversary validation loss: 1.609671
# Classifier training loss: -160.755419
# Adversary training loss: 1.608223
# Epoch 35
# -------------------------------
# Classifier validation loss: -160.680055
# Adversary validation loss: 1.607488
# Classifier training loss: -160.842159
# Adversary training loss: 1.609071
# Epoch 36
# -------------------------------
# Classifier validation loss: -160.812808
# Adversary validation loss: 1.608795
# Classifier training loss: -160.784662
# Adversary training loss: 1.608489
# Epoch 37
# -------------------------------
# Classifier validation loss: -160.824703
# Adversary validation loss: 1.608884
# Classifier training loss: -160.714530
# Adversary training loss: 1.607801
# Epoch 38
# -------------------------------
# Classifier validation loss: -160.941627
# Adversary validation loss: 1.610027
# Classifier training loss: -160.827620
# Adversary training loss: 1.608933
# Epoch 39
# -------------------------------
# Classifier validation loss: -160.820702
# Adversary validation loss: 1.608894
# Classifier training loss: -160.791712
# Adversary training loss: 1.608561
# Epoch 40
# -------------------------------
# Classifier validation loss: -160.795396
# Adversary validation loss: 1.608652
# Classifier training loss: -160.794196
# Adversary training loss: 1.608584
# Epoch 41
# -------------------------------
# Classifier validation loss: -160.893804
# Adversary validation loss: 1.609605
# Classifier training loss: -160.830862
# Adversary training loss: 1.608960
# Epoch 42
# -------------------------------
# Classifier validation loss: -160.722624
# Adversary validation loss: 1.607888
# Classifier training loss: -160.789738
# Adversary training loss: 1.608546
# Epoch 43
# -------------------------------
# Classifier validation loss: -160.774587
# Adversary validation loss: 1.608374
# Classifier training loss: -160.797761
# Adversary training loss: 1.608632
# Epoch 44
# -------------------------------
# Classifier validation loss: -160.889929
# Adversary validation loss: 1.609524
# Classifier training loss: -160.818404
# Adversary training loss: 1.608848
# Epoch 45
# -------------------------------
# Classifier validation loss: -160.770186
# Adversary validation loss: 1.608421
# Classifier training loss: -160.786987
# Adversary training loss: 1.608521
# Epoch 46
# -------------------------------
# Classifier validation loss: -160.895617
# Adversary validation loss: 1.609655
# Classifier training loss: -160.819099
# Adversary training loss: 1.608849
# Epoch 47
# -------------------------------
# Classifier validation loss: -160.778584
# Adversary validation loss: 1.608464
# Classifier training loss: -160.828501
# Adversary training loss: 1.608955
# Epoch 48
# -------------------------------
# Classifier validation loss: -160.864433
# Adversary validation loss: 1.609282
# Classifier training loss: -160.835098
# Adversary training loss: 1.609016
# Epoch 49
# -------------------------------
# Classifier validation loss: -160.893274
# Adversary validation loss: 1.609659
# Classifier training loss: -160.835326
# Adversary training loss: 1.609022
# Epoch 50
# -------------------------------
# Classifier validation loss: -160.883340
# Adversary validation loss: 1.609517
# Classifier training loss: -160.829841
# Adversary training loss: 1.608978
# Done!

# %%
fig, ax1 = plt.subplots()

best_epoch = np.argmin(diff_scores)+1



#ax1.plot(np.arange(len(Training_losses_adv))+1, Training_losses_adv, 'k-', label='Training Adversary')
ax1.plot(np.arange(len(Validation_losses_adv))+1, Validation_losses_adv, 'k-', label='Validation Adversary')

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Adversary Loss', color='k')
ax1.tick_params(axis='y', labelcolor='k')

ax2 = ax1.twinx()

#ax2.plot(np.arange(len(Training_losses_clas))+1, Training_losses_clas, 'r-', label='Training Classifier')
ax2.plot(np.arange(len(Validation_losses_clas))+1, Validation_losses_clas, 'r-', label='Validation Classifier')
ax2.axvline(best_epoch,label="Final model stopped here",color='k')

ax2.set_ylabel('Classifier Loss', color='r')
ax2.tick_params(axis='y', labelcolor='r')

# %% [markdown]
# ## Test adversarially trained models

# %%
# Now test the pretrained model
test_pred = mytools.test_clas(test_loader, final_clas_adv, device)
test_pred=torch.sigmoid(torch.tensor(test_pred)).numpy()


fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test, test_pred, pos_label=1)
auc_test = sklearn.metrics.auc(fpr, tpr)
print(f'Test AUROC: {auc_test:0.4f}')

plt.plot(fpr, tpr, label=f'Test AUROC: {auc_test:0.4f}')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
# Out:
# Test AUROC: 0.9874

# %%
df_test["Class_adv"] = test_pred
df_bkg = df_test.loc[ (df_test.type == 'tritrig') | (df_test.type == 'wab')]
per = np.percentile(df_bkg['Class_adv'],99)
df_cut = df_bkg[df_bkg['Class_adv']>per].reset_index(drop=True)
x_vals = 1000*df_cut.InvM

plt.figure()
plt.hist(1000*df_bkg.InvM, bins=np.arange(980,1250,1), histtype='step', label='No selection', density=True)
plt.hist(x_vals, bins=np.arange(980,1250,1), histtype='step', label= '99 percent selection', density=True)
plt.axvline(1019.461, color='k', linestyle='dashed', linewidth=1, label='PDG phi mass')
plt.xlabel('Invariant Mass [MeV]')
plt.ylabel('Normalized Counts')
plt.legend()

# %%
x1 = 1000* df_bkg.InvM.values
x2 = 1000*df_cut.InvM.values

N, edges = np.histogram(x1, bins=np.arange(980,1250,1), density=False)
M, edges = np.histogram(x2, bins=np.arange(980,1250,1), density=False)

N2 = N[(N > 0) & (M > 0)]
M2 = M[(N > 0) & (M > 0)]

diff_score = np.mean(np.abs(N2/np.sum(N)-M2/np.sum(M)) / (np.sqrt(N2)/np.sum(N) + np.sqrt(M2)/np.sum(M) ))

print(diff_score)

N = len(df_test.loc[ ((df_test.type == 'tritrig') | (df_test.type == 'wab')) & (df_test.InvM < (1.019 + 0.01) )  & (df_test.InvM > (1.019 - 0.01) ) & ( df_test['Class_adv']>per ) ] )
S = len(df_test.loc[ (df_test.type == 'phiKK') & (df_test.InvM < (1.019 + 0.01) )  & (df_test.InvM > (1.019 - 0.01) ) & ( df_test['Class_adv']>per )  ] )

print(S/N)
# Out:
# 0.6394097842267273
# 4.258196721311475

# %%
df_test["Class_adv"] = test_pred

# %%
# Save the adversarially trained models
torch.save(final_clas_adv.state_dict(), "/Users/mghrear/data/ML_data/2019_pass2/models/classifier_adv_2019_pass2_run"+str(run)+"_unscaled.pt")
torch.save(final_adv_adv.state_dict(), "/Users/mghrear/data/ML_data/2019_pass2/models/adversary_adv_2019_pass2_run"+str(run)+"_unscaled.pt")

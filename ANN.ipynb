# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import torch 
from torch import nn, optim
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import sklearn
from sklearn.model_selection import train_test_split
import copy
import mytools


# Print and store device being used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cpu

# %% [markdown]
# # Define important parameters

# %%
# Number of class in invariant mass used by the adversary
Num_classes = 5
# Hyper-parameter for adversarial training of the classifier
lambda_ = 100.0

run = 1

# %% [markdown]
# # Load and setup the data

# %%
df_tritrig = pd.read_pickle('/Users/mghrear/data/ML_data/2019_pass2/unscaled/2019_pass2_tritrig.pk')
df_tritrig['PhiKK'] = 0.0
df_phiKK = pd.read_pickle('/Users/mghrear/data/ML_data/2019_pass2/unscaled/2019_pass2_phiKK.pk')
df_phiKK['PhiKK'] = 1.0
df_wab = pd.read_pickle('/Users/mghrear/data/ML_data/2019_pass2/unscaled/2019_pass2_wab.pk')
df_wab['PhiKK'] = 0.0 # Add label


print("tritrig: ", len(df_tritrig))
print("phiKK: ", len(df_phiKK))
print("wab: ", len(df_wab))
# Out:
# tritrig:  149433
# phiKK:  6232
# wab:  16422

# %%
# Make Training set
tritrig_train = df_tritrig[0:50000]
wab_train = df_wab[0:6000]
phiKK_train = df_phiKK[0:5000]

# Combine and shuffle all training data
df_train = pd.concat([tritrig_train, phiKK_train, wab_train], ignore_index=True, sort=False)
df_train = df_train.sample(frac=1, random_state=42).reset_index(drop=True)

# Make a training set with balanced classes (as expected in data), used for scaling
df_train_balanced = pd.concat([df_phiKK[0:25], df_tritrig[0:(1470*25)] , df_wab[0:(228*25)]], ignore_index=True, sort=False).drop(columns=['PhiKK'])

# Get edges in invariant mass classes for one-hot encoding
# To be used for adverserial labels
# The edges are chosen such that each bin has equal number of background events
one_hot_edges = mytools.get_one_hot_edges(mytools.get_InvM( df_train_balanced ), n_bins=Num_classes)
np.save("one_hot_edges.npy", one_hot_edges)

# Split the training data into training and validation sets
df_train, df_val = train_test_split(df_train, test_size=0.33, random_state=42)

# Make X and y for training and validation sets
# the adverserial network has its own labels
X_train = df_train.drop(columns=['PhiKK'])
y_train = df_train['PhiKK']
y_adv_train = mytools.get_adv_labels( mytools.get_InvM(df_train), one_hot_edges)
X_val = df_val.drop(columns=['PhiKK'])
y_val = df_val['PhiKK']
y_adv_val = mytools.get_adv_labels( mytools.get_InvM(df_val), one_hot_edges)

# Make testing set with remaining events
tritrig_test = df_tritrig[50000:]
tritrig_test['type']= 'tritrig'
wab_test = df_wab[6000:]
wab_test['type']= 'wab'
phiKK_test = df_phiKK[5000:]
phiKK_test['type']= 'phiKK'

df_test = pd.concat([tritrig_test, phiKK_test,wab_test], ignore_index=True, sort=False)
df_test = df_test.sample(frac=1, random_state=42).reset_index(drop=True) # Now shuffle the combined dataframe

X_test = df_test.drop(columns=['PhiKK','type'])
y_test = df_test['PhiKK']
y_adv_test = mytools.get_adv_labels( mytools.get_InvM(df_test), one_hot_edges)

df_test["InvM"] = mytools.get_InvM(df_test)
# Out:
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_33938/584016212.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tritrig_test['type']= 'tritrig'
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_33938/584016212.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wab_test['type']= 'wab'
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_33938/584016212.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phiKK_test['type']= 'phiKK'

# %% [markdown]
# ## Setup dataloaders

# %%
bsize = 2000

# Convert to tensor dataset and dataloader
train_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy().astype(np.float32))  , torch.from_numpy(y_train.to_numpy().astype(np.float32)).unsqueeze(1)  )
train_loader = DataLoader(train_dataset, batch_size=bsize, shuffle=True)

val_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy().astype(np.float32))  , torch.from_numpy(y_val.to_numpy().astype(np.float32)).unsqueeze(1)  )
val_loader = DataLoader(val_dataset, batch_size=bsize, shuffle=True)

test_dataset = TensorDataset(torch.from_numpy(X_test.to_numpy().astype(np.float32)))
test_loader = DataLoader(test_dataset, batch_size=bsize, shuffle=False)

# %% [markdown]
# ## Initialize model, objective function, and optimizer

# %%
clas = mytools.Classifier(in_features=X_train.shape[1]).to(device)
criterion_clas = nn.BCEWithLogitsLoss()
optimizer_clas = optim.Adam(clas.parameters(), lr=1e-5)
scheduler_clas = torch.optim.lr_scheduler.ExponentialLR(optimizer_clas, gamma=0.9999)

# %% [markdown]
# ## Pre-train the classifier

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 10

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 2500
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train_clas(train_loader, clas, criterion_clas, optimizer_clas, scheduler_clas, device))
    Validation_losses = np.append(Validation_losses, mytools.validate_clas(val_loader, clas, criterion_clas, device))
    
    # Keep a running copy of the model with the lowest loss
    if Validation_losses[-1] == np.min(Validation_losses):
        final_classifier = copy.deepcopy(clas)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Training loss: 0.744808
# Validation loss: 0.798494
#
# Epoch 2
# -------------------------------
# Training loss: 0.705389
# Validation loss: 0.733071
#
# Epoch 3
# -------------------------------
# Training loss: 0.679355
# Validation loss: 0.672492
#
# Epoch 4
# -------------------------------
# Training loss: 0.658507
# Validation loss: 0.650459
#
# Epoch 5
# -------------------------------
# Training loss: 0.641924
# Validation loss: 0.632984
#
# Epoch 6
# -------------------------------
# Training loss: 0.626902
# Validation loss: 0.613730
#
# Epoch 7
# -------------------------------
# Training loss: 0.613254
# Validation loss: 0.599536
#
# Epoch 8
# -------------------------------
# Training loss: 0.603843
# Validation loss: 0.584895
#
# Epoch 9
# -------------------------------
# Training loss: 0.588392
# Validation loss: 0.578465
#
# Epoch 10
# -------------------------------
# Training loss: 0.578144
# Validation loss: 0.570941
#
# Epoch 11
# -------------------------------
# Training loss: 0.573148
# Validation loss: 0.564661
#
# Epoch 12
# -------------------------------
# Training loss: 0.565256
# Validation loss: 0.566418
#
# Epoch 13
# -------------------------------
# Training loss: 0.556138
# Validation loss: 0.556143
#
# Epoch 14
# -------------------------------
# Training loss: 0.548450
# Validation loss: 0.547463
#
# Epoch 15
# -------------------------------
# Training loss: 0.542613
# Validation loss: 0.542235
#
# Epoch 16
# -------------------------------
# Training loss: 0.535798
# Validation loss: 0.534708
#
# Epoch 17
# -------------------------------
# Training loss: 0.530810
# Validation loss: 0.530778
#
# Epoch 18
# -------------------------------
# Training loss: 0.526516
# Validation loss: 0.527377
#
# Epoch 19
# -------------------------------
# Training loss: 0.523633
# Validation loss: 0.523417
#
# Epoch 20
# -------------------------------
# Training loss: 0.515821
# Validation loss: 0.513062
#
# Epoch 21
# -------------------------------
# Training loss: 0.511009
# Validation loss: 0.508917
#
# Epoch 22
# -------------------------------
# Training loss: 0.508210
# Validation loss: 0.502975
#
# Epoch 23
# -------------------------------
# Training loss: 0.503407
# Validation loss: 0.505535
#
# Epoch 24
# -------------------------------
# Training loss: 0.500515
# Validation loss: 0.492054
#
# Epoch 25
# -------------------------------
# Training loss: 0.496033
# Validation loss: 0.491787
#
# Epoch 26
# -------------------------------
# Training loss: 0.492708
# Validation loss: 0.487971
#
# Epoch 27
# -------------------------------
# Training loss: 0.490463
# Validation loss: 0.490120
#
# Epoch 28
# -------------------------------
# Training loss: 0.484790
# Validation loss: 0.482753
#
# Epoch 29
# -------------------------------
# Training loss: 0.482334
# Validation loss: 0.483686
#
# Epoch 30
# -------------------------------
# Training loss: 0.478913
# Validation loss: 0.476717
#
# Epoch 31
# -------------------------------
# Training loss: 0.476509
# Validation loss: 0.474132
#
# Epoch 32
# -------------------------------
# Training loss: 0.470652
# Validation loss: 0.466880
#
# Epoch 33
# -------------------------------
# Training loss: 0.468398
# Validation loss: 0.468091
#
# Epoch 34
# -------------------------------
# Training loss: 0.466526
# Validation loss: 0.475509
#
# Epoch 35
# -------------------------------
# Training loss: 0.464414
# Validation loss: 0.469387
#
# Epoch 36
# -------------------------------
# Training loss: 0.460685
# Validation loss: 0.461275
#
# Epoch 37
# -------------------------------
# Training loss: 0.460921
# Validation loss: 0.458563
#
# Epoch 38
# -------------------------------
# Training loss: 0.456767
# Validation loss: 0.459006
#
# Epoch 39
# -------------------------------
# Training loss: 0.451107
# Validation loss: 0.450265
#
# Epoch 40
# -------------------------------
# Training loss: 0.448404
# Validation loss: 0.452174
#
# Epoch 41
# -------------------------------
# Training loss: 0.449420
# Validation loss: 0.452072
#
# Epoch 42
# -------------------------------
# Training loss: 0.446130
# Validation loss: 0.442029
#
# Epoch 43
# -------------------------------
# Training loss: 0.443322
# Validation loss: 0.444290
#
# Epoch 44
# -------------------------------
# Training loss: 0.439747
# Validation loss: 0.439376
#
# Epoch 45
# -------------------------------
# Training loss: 0.439446
# Validation loss: 0.444159
#
# Epoch 46
# -------------------------------
# Training loss: 0.437855
# Validation loss: 0.434332
#
# Epoch 47
# -------------------------------
# Training loss: 0.433419
# Validation loss: 0.437759
#
# Epoch 48
# -------------------------------
# Training loss: 0.431398
# Validation loss: 0.434566
#
# Epoch 49
# -------------------------------
# Training loss: 0.431455
# Validation loss: 0.441312
#
# Epoch 50
# -------------------------------
# Training loss: 0.427180
# Validation loss: 0.425726
#
# Epoch 51
# -------------------------------
# Training loss: 0.425753
# Validation loss: 0.429267
#
# Epoch 52
# -------------------------------
# Training loss: 0.423410
# Validation loss: 0.423643
#
# Epoch 53
# -------------------------------
# Training loss: 0.425020
# Validation loss: 0.430346
#
# Epoch 54
# -------------------------------
# Training loss: 0.420717
# Validation loss: 0.426428
#
# Epoch 55
# -------------------------------
# Training loss: 0.417929
# Validation loss: 0.418720
#
# Epoch 56
# -------------------------------
# Training loss: 0.415200
# Validation loss: 0.418903
#
# Epoch 57
# -------------------------------
# Training loss: 0.414739
# Validation loss: 0.418396
#
# Epoch 58
# -------------------------------
# Training loss: 0.411670
# Validation loss: 0.417023
#
# Epoch 59
# -------------------------------
# Training loss: 0.410490
# Validation loss: 0.417710
#
# Epoch 60
# -------------------------------
# Training loss: 0.409410
# Validation loss: 0.410687
#
# Epoch 61
# -------------------------------
# Training loss: 0.407714
# Validation loss: 0.411051
#
# Epoch 62
# -------------------------------
# Training loss: 0.405803
# Validation loss: 0.412244
#
# Epoch 63
# -------------------------------
# Training loss: 0.404282
# Validation loss: 0.395774
#
# Epoch 64
# -------------------------------
# Training loss: 0.402321
# Validation loss: 0.403162
#
# Epoch 65
# -------------------------------
# Training loss: 0.401989
# Validation loss: 0.406597
#
# Epoch 66
# -------------------------------
# Training loss: 0.399809
# Validation loss: 0.409638
#
# Epoch 67
# -------------------------------
# Training loss: 0.399341
# Validation loss: 0.390824
#
# Epoch 68
# -------------------------------
# Training loss: 0.396170
# Validation loss: 0.392874
#
# Epoch 69
# -------------------------------
# Training loss: 0.395722
# Validation loss: 0.404768
#
# Epoch 70
# -------------------------------
# Training loss: 0.395314
# Validation loss: 0.407372
#
# Epoch 71
# -------------------------------
# Training loss: 0.391468
# Validation loss: 0.398772
#
# Epoch 72
# -------------------------------
# Training loss: 0.389810
# Validation loss: 0.403484
#
# Epoch 73
# -------------------------------
# Training loss: 0.389761
# Validation loss: 0.384397
#
# Epoch 74
# -------------------------------
# Training loss: 0.387624
# Validation loss: 0.399254
#
# Epoch 75
# -------------------------------
# Training loss: 0.386293
# Validation loss: 0.386936
#
# Epoch 76
# -------------------------------
# Training loss: 0.386107
# Validation loss: 0.395766
#
# Epoch 77
# -------------------------------
# Training loss: 0.385999
# Validation loss: 0.402760
#
# Epoch 78
# -------------------------------
# Training loss: 0.381818
# Validation loss: 0.375037
#
# Epoch 79
# -------------------------------
# Training loss: 0.381954
# Validation loss: 0.387048
#
# Epoch 80
# -------------------------------
# Training loss: 0.380933
# Validation loss: 0.398732
#
# Epoch 81
# -------------------------------
# Training loss: 0.379135
# Validation loss: 0.388541
#
# Epoch 82
# -------------------------------
# Training loss: 0.375826
# Validation loss: 0.389797
#
# Epoch 83
# -------------------------------
# Training loss: 0.377603
# Validation loss: 0.377427
#
# Epoch 84
# -------------------------------
# Training loss: 0.376733
# Validation loss: 0.384525
#
# Epoch 85
# -------------------------------
# Training loss: 0.373882
# Validation loss: 0.391081
#
# Epoch 86
# -------------------------------
# Training loss: 0.372957
# Validation loss: 0.371204
#
# Epoch 87
# -------------------------------
# Training loss: 0.372503
# Validation loss: 0.377432
#
# Epoch 88
# -------------------------------
# Training loss: 0.371660
# Validation loss: 0.383875
#
# Epoch 89
# -------------------------------
# Training loss: 0.369460
# Validation loss: 0.375760
#
# Epoch 90
# -------------------------------
# Training loss: 0.369706
# Validation loss: 0.374129
#
# Epoch 91
# -------------------------------
# Training loss: 0.365551
# Validation loss: 0.369639
#
# Epoch 92
# -------------------------------
# Training loss: 0.367040
# Validation loss: 0.371311
#
# Epoch 93
# -------------------------------
# Training loss: 0.364840
# Validation loss: 0.367818
#
# Epoch 94
# -------------------------------
# Training loss: 0.363401
# Validation loss: 0.366039
#
# Epoch 95
# -------------------------------
# Training loss: 0.362029
# Validation loss: 0.366173
#
# Epoch 96
# -------------------------------
# Training loss: 0.360732
# Validation loss: 0.369196
#
# Epoch 97
# -------------------------------
# Training loss: 0.361923
# Validation loss: 0.371914
#
# Epoch 98
# -------------------------------
# Training loss: 0.360672
# Validation loss: 0.362754
#
# Epoch 99
# -------------------------------
# Training loss: 0.358554
# Validation loss: 0.365554
#
# Epoch 100
# -------------------------------
# Training loss: 0.356986
# Validation loss: 0.363171
#
# Epoch 101
# -------------------------------
# Training loss: 0.356198
# Validation loss: 0.367463
#
# Epoch 102
# -------------------------------
# Training loss: 0.355902
# Validation loss: 0.373143
#
# Epoch 103
# -------------------------------
# Training loss: 0.354090
# Validation loss: 0.359743
#
# Epoch 104
# -------------------------------
# Training loss: 0.353379
# Validation loss: 0.348590
#
# Epoch 105
# -------------------------------
# Training loss: 0.352308
# Validation loss: 0.353150
#
# Epoch 106
# -------------------------------
# Training loss: 0.352945
# Validation loss: 0.368670
#
# Epoch 107
# -------------------------------
# Training loss: 0.350806
# Validation loss: 0.353911
#
# Epoch 108
# -------------------------------
# Training loss: 0.349776
# Validation loss: 0.353250
#
# Epoch 109
# -------------------------------
# Training loss: 0.348299
# Validation loss: 0.355777
#
# Epoch 110
# -------------------------------
# Training loss: 0.347823
# Validation loss: 0.351966
#
# Epoch 111
# -------------------------------
# Training loss: 0.346809
# Validation loss: 0.361708
#
# Epoch 112
# -------------------------------
# Training loss: 0.345243
# Validation loss: 0.347806
#
# Epoch 113
# -------------------------------
# Training loss: 0.343990
# Validation loss: 0.352577
#
# Epoch 114
# -------------------------------
# Training loss: 0.343995
# Validation loss: 0.350156
#
# Epoch 115
# -------------------------------
# Training loss: 0.344476
# Validation loss: 0.352052
#
# Epoch 116
# -------------------------------
# Training loss: 0.343693
# Validation loss: 0.345923
#
# Epoch 117
# -------------------------------
# Training loss: 0.341621
# Validation loss: 0.344312
#
# Epoch 118
# -------------------------------
# Training loss: 0.341654
# Validation loss: 0.344896
#
# Epoch 119
# -------------------------------
# Training loss: 0.341081
# Validation loss: 0.348899
#
# Epoch 120
# -------------------------------
# Training loss: 0.340577
# Validation loss: 0.343891
#
# Epoch 121
# -------------------------------
# Training loss: 0.339432
# Validation loss: 0.348437
#
# Epoch 122
# -------------------------------
# Training loss: 0.337272
# Validation loss: 0.345367
#
# Epoch 123
# -------------------------------
# Training loss: 0.335448
# Validation loss: 0.336417
#
# Epoch 124
# -------------------------------
# Training loss: 0.335217
# Validation loss: 0.340311
#
# Epoch 125
# -------------------------------
# Training loss: 0.335932
# Validation loss: 0.336181
#
# Epoch 126
# -------------------------------
# Training loss: 0.334387
# Validation loss: 0.337068
#
# Epoch 127
# -------------------------------
# Training loss: 0.333601
# Validation loss: 0.347477
#
# Epoch 128
# -------------------------------
# Training loss: 0.334244
# Validation loss: 0.343009
#
# Epoch 129
# -------------------------------
# Training loss: 0.332937
# Validation loss: 0.329158
#
# Epoch 130
# -------------------------------
# Training loss: 0.332073
# Validation loss: 0.334109
#
# Epoch 131
# -------------------------------
# Training loss: 0.331034
# Validation loss: 0.336838
#
# Epoch 132
# -------------------------------
# Training loss: 0.331673
# Validation loss: 0.336406
#
# Epoch 133
# -------------------------------
# Training loss: 0.330571
# Validation loss: 0.337575
#
# Epoch 134
# -------------------------------
# Training loss: 0.328875
# Validation loss: 0.326416
#
# Epoch 135
# -------------------------------
# Training loss: 0.327233
# Validation loss: 0.326732
#
# Epoch 136
# -------------------------------
# Training loss: 0.327550
# Validation loss: 0.329957
#
# Epoch 137
# -------------------------------
# Training loss: 0.326861
# Validation loss: 0.342908
#
# Epoch 138
# -------------------------------
# Training loss: 0.327056
# Validation loss: 0.345027
#
# Epoch 139
# -------------------------------
# Training loss: 0.325170
# Validation loss: 0.326502
#
# Epoch 140
# -------------------------------
# Training loss: 0.324821
# Validation loss: 0.332936
#
# Epoch 141
# -------------------------------
# Training loss: 0.323981
# Validation loss: 0.345595
#
# Epoch 142
# -------------------------------
# Training loss: 0.323937
# Validation loss: 0.329530
#
# Epoch 143
# -------------------------------
# Training loss: 0.322285
# Validation loss: 0.330332
#
# Epoch 144
# -------------------------------
# Training loss: 0.322150
# Validation loss: 0.322019
#
# Epoch 145
# -------------------------------
# Training loss: 0.320899
# Validation loss: 0.325281
#
# Epoch 146
# -------------------------------
# Training loss: 0.321338
# Validation loss: 0.323370
#
# Epoch 147
# -------------------------------
# Training loss: 0.320721
# Validation loss: 0.321732
#
# Epoch 148
# -------------------------------
# Training loss: 0.319325
# Validation loss: 0.324140
#
# Epoch 149
# -------------------------------
# Training loss: 0.317459
# Validation loss: 0.318246
#
# Epoch 150
# -------------------------------
# Training loss: 0.319674
# Validation loss: 0.314906
#
# Epoch 151
# -------------------------------
# Training loss: 0.315926
# Validation loss: 0.318020
#
# Epoch 152
# -------------------------------
# Training loss: 0.316453
# Validation loss: 0.321806
#
# Epoch 153
# -------------------------------
# Training loss: 0.315385
# Validation loss: 0.323458
#
# Epoch 154
# -------------------------------
# Training loss: 0.314789
# Validation loss: 0.321518
#
# Epoch 155
# -------------------------------
# Training loss: 0.314152
# Validation loss: 0.315721
#
# Epoch 156
# -------------------------------
# Training loss: 0.312987
# Validation loss: 0.322969
#
# Epoch 157
# -------------------------------
# Training loss: 0.312618
# Validation loss: 0.316330
#
# Epoch 158
# -------------------------------
# Training loss: 0.312202
# Validation loss: 0.308019
#
# Epoch 159
# -------------------------------
# Training loss: 0.311938
# Validation loss: 0.311740
#
# Epoch 160
# -------------------------------
# Training loss: 0.310628
# Validation loss: 0.318295
#
# Epoch 161
# -------------------------------
# Training loss: 0.312283
# Validation loss: 0.323206
#
# Epoch 162
# -------------------------------
# Training loss: 0.311699
# Validation loss: 0.326962
#
# Epoch 163
# -------------------------------
# Training loss: 0.309814
# Validation loss: 0.315656
#
# Epoch 164
# -------------------------------
# Training loss: 0.308097
# Validation loss: 0.312282
#
# Epoch 165
# -------------------------------
# Training loss: 0.308734
# Validation loss: 0.325926
#
# Epoch 166
# -------------------------------
# Training loss: 0.306990
# Validation loss: 0.304351
#
# Epoch 167
# -------------------------------
# Training loss: 0.307572
# Validation loss: 0.310881
#
# Epoch 168
# -------------------------------
# Training loss: 0.307360
# Validation loss: 0.322608
#
# Epoch 169
# -------------------------------
# Training loss: 0.305052
# Validation loss: 0.318372
#
# Epoch 170
# -------------------------------
# Training loss: 0.304947
# Validation loss: 0.317487
#
# Epoch 171
# -------------------------------
# Training loss: 0.304567
# Validation loss: 0.314430
#
# Epoch 172
# -------------------------------
# Training loss: 0.303812
# Validation loss: 0.319674
#
# Epoch 173
# -------------------------------
# Training loss: 0.303100
# Validation loss: 0.321648
#
# Epoch 174
# -------------------------------
# Training loss: 0.303347
# Validation loss: 0.302473
#
# Epoch 175
# -------------------------------
# Training loss: 0.303182
# Validation loss: 0.312608
#
# Epoch 176
# -------------------------------
# Training loss: 0.300710
# Validation loss: 0.303409
#
# Epoch 177
# -------------------------------
# Training loss: 0.300706
# Validation loss: 0.311588
#
# Epoch 178
# -------------------------------
# Training loss: 0.301607
# Validation loss: 0.313969
#
# Epoch 179
# -------------------------------
# Training loss: 0.299806
# Validation loss: 0.314050
#
# Epoch 180
# -------------------------------
# Training loss: 0.299080
# Validation loss: 0.302965
#
# Epoch 181
# -------------------------------
# Training loss: 0.298467
# Validation loss: 0.299406
#
# Epoch 182
# -------------------------------
# Training loss: 0.300271
# Validation loss: 0.334491
#
# Epoch 183
# -------------------------------
# Training loss: 0.298400
# Validation loss: 0.304618
#
# Epoch 184
# -------------------------------
# Training loss: 0.296322
# Validation loss: 0.301003
#
# Epoch 185
# -------------------------------
# Training loss: 0.296820
# Validation loss: 0.298313
#
# Epoch 186
# -------------------------------
# Training loss: 0.295646
# Validation loss: 0.299354
#
# Epoch 187
# -------------------------------
# Training loss: 0.295396
# Validation loss: 0.315245
#
# Epoch 188
# -------------------------------
# Training loss: 0.294279
# Validation loss: 0.295218
#
# Epoch 189
# -------------------------------
# Training loss: 0.295217
# Validation loss: 0.293536
#
# Epoch 190
# -------------------------------
# Training loss: 0.294128
# Validation loss: 0.288316
#
# Epoch 191
# -------------------------------
# Training loss: 0.292682
# Validation loss: 0.305938
#
# Epoch 192
# -------------------------------
# Training loss: 0.291177
# Validation loss: 0.321496
#
# Epoch 193
# -------------------------------
# Training loss: 0.292030
# Validation loss: 0.293432
#
# Epoch 194
# -------------------------------
# Training loss: 0.293043
# Validation loss: 0.306352
#
# Epoch 195
# -------------------------------
# Training loss: 0.290286
# Validation loss: 0.310330
#
# Epoch 196
# -------------------------------
# Training loss: 0.290276
# Validation loss: 0.298315
#
# Epoch 197
# -------------------------------
# Training loss: 0.289874
# Validation loss: 0.293013
#
# Epoch 198
# -------------------------------
# Training loss: 0.290072
# Validation loss: 0.313998
#
# Epoch 199
# -------------------------------
# Training loss: 0.289188
# Validation loss: 0.300767
#
# Epoch 200
# -------------------------------
# Training loss: 0.289660
# Validation loss: 0.296440
#
# Epoch 201
# -------------------------------
# Training loss: 0.287606
# Validation loss: 0.289684
#
# Epoch 202
# -------------------------------
# Training loss: 0.288859
# Validation loss: 0.300155
#
# Epoch 203
# -------------------------------
# Training loss: 0.287644
# Validation loss: 0.294823
#
# Epoch 204
# -------------------------------
# Training loss: 0.287280
# Validation loss: 0.296631
#
# Epoch 205
# -------------------------------
# Training loss: 0.284723
# Validation loss: 0.302443
#
# Epoch 206
# -------------------------------
# Training loss: 0.286176
# Validation loss: 0.297961
#
# Epoch 207
# -------------------------------
# Training loss: 0.285007
# Validation loss: 0.301918
#
# Epoch 208
# -------------------------------
# Training loss: 0.284434
# Validation loss: 0.285077
#
# Epoch 209
# -------------------------------
# Training loss: 0.283722
# Validation loss: 0.290566
#
# Epoch 210
# -------------------------------
# Training loss: 0.283785
# Validation loss: 0.286697
#
# Epoch 211
# -------------------------------
# Training loss: 0.282772
# Validation loss: 0.278169
#
# Epoch 212
# -------------------------------
# Training loss: 0.283515
# Validation loss: 0.290228
#
# Epoch 213
# -------------------------------
# Training loss: 0.281667
# Validation loss: 0.292727
#
# Epoch 214
# -------------------------------
# Training loss: 0.280666
# Validation loss: 0.277155
#
# Epoch 215
# -------------------------------
# Training loss: 0.280276
# Validation loss: 0.289969
#
# Epoch 216
# -------------------------------
# Training loss: 0.279357
# Validation loss: 0.299057
#
# Epoch 217
# -------------------------------
# Training loss: 0.281133
# Validation loss: 0.319117
#
# Epoch 218
# -------------------------------
# Training loss: 0.278662
# Validation loss: 0.295686
#
# Epoch 219
# -------------------------------
# Training loss: 0.278085
# Validation loss: 0.280779
#
# Epoch 220
# -------------------------------
# Training loss: 0.277636
# Validation loss: 0.289916
#
# Epoch 221
# -------------------------------
# Training loss: 0.279546
# Validation loss: 0.301901
#
# Epoch 222
# -------------------------------
# Training loss: 0.277082
# Validation loss: 0.288258
#
# Epoch 223
# -------------------------------
# Training loss: 0.277116
# Validation loss: 0.280723
#
# Epoch 224
# -------------------------------
# Training loss: 0.276295
# Validation loss: 0.285254
#
# Epoch 225
# -------------------------------
# Training loss: 0.274955
# Validation loss: 0.275399
#
# Epoch 226
# -------------------------------
# Training loss: 0.273749
# Validation loss: 0.267793
#
# Epoch 227
# -------------------------------
# Training loss: 0.274399
# Validation loss: 0.277519
#
# Epoch 228
# -------------------------------
# Training loss: 0.274381
# Validation loss: 0.294031
#
# Epoch 229
# -------------------------------
# Training loss: 0.272801
# Validation loss: 0.289680
#
# Epoch 230
# -------------------------------
# Training loss: 0.272509
# Validation loss: 0.273835
#
# Epoch 231
# -------------------------------
# Training loss: 0.272918
# Validation loss: 0.290699
#
# Epoch 232
# -------------------------------
# Training loss: 0.271574
# Validation loss: 0.294420
#
# Epoch 233
# -------------------------------
# Training loss: 0.270622
# Validation loss: 0.281347
#
# Epoch 234
# -------------------------------
# Training loss: 0.270991
# Validation loss: 0.286141
#
# Epoch 235
# -------------------------------
# Training loss: 0.269819
# Validation loss: 0.283127
#
# Epoch 236
# -------------------------------
# Training loss: 0.269087
# Validation loss: 0.270833
#
# Epoch 237
# -------------------------------
# Training loss: 0.268487
# Validation loss: 0.285644
#
# Epoch 238
# -------------------------------
# Training loss: 0.268328
# Validation loss: 0.275150
#
# Epoch 239
# -------------------------------
# Training loss: 0.266431
# Validation loss: 0.284166
#
# Epoch 240
# -------------------------------
# Training loss: 0.267035
# Validation loss: 0.277610
#
# Epoch 241
# -------------------------------
# Training loss: 0.266048
# Validation loss: 0.290347
#
# Epoch 242
# -------------------------------
# Training loss: 0.265890
# Validation loss: 0.281956
#
# Epoch 243
# -------------------------------
# Training loss: 0.266844
# Validation loss: 0.282526
#
# Epoch 244
# -------------------------------
# Training loss: 0.265573
# Validation loss: 0.293737
#
# Epoch 245
# -------------------------------
# Training loss: 0.265393
# Validation loss: 0.298653
#
# Epoch 246
# -------------------------------
# Training loss: 0.263661
# Validation loss: 0.270590
#
# Epoch 247
# -------------------------------
# Training loss: 0.262600
# Validation loss: 0.275258
#
# Epoch 248
# -------------------------------
# Training loss: 0.260791
# Validation loss: 0.266815
#
# Epoch 249
# -------------------------------
# Training loss: 0.265327
# Validation loss: 0.268486
#
# Epoch 250
# -------------------------------
# Training loss: 0.262248
# Validation loss: 0.262187
#
# Epoch 251
# -------------------------------
# Training loss: 0.260777
# Validation loss: 0.247902
#
# Epoch 252
# -------------------------------
# Training loss: 0.260748
# Validation loss: 0.313043
#
# Epoch 253
# -------------------------------
# Training loss: 0.258134
# Validation loss: 0.287439
#
# Epoch 254
# -------------------------------
# Training loss: 0.258102
# Validation loss: 0.253210
#
# Epoch 255
# -------------------------------
# Training loss: 0.259151
# Validation loss: 0.260652
#
# Epoch 256
# -------------------------------
# Training loss: 0.257296
# Validation loss: 0.271659
#
# Epoch 257
# -------------------------------
# Training loss: 0.258344
# Validation loss: 0.254852
#
# Epoch 258
# -------------------------------
# Training loss: 0.255255
# Validation loss: 0.248121
#
# Epoch 259
# -------------------------------
# Training loss: 0.254788
# Validation loss: 0.251411
#
# Epoch 260
# -------------------------------
# Training loss: 0.254822
# Validation loss: 0.259990
#
# Epoch 261
# -------------------------------
# Training loss: 0.255164
# Validation loss: 0.263502
#
# Epoch 262
# -------------------------------
# Training loss: 0.254122
# Validation loss: 0.276250
#
# Epoch 263
# -------------------------------
# Training loss: 0.252684
# Validation loss: 0.261553
#
# Epoch 264
# -------------------------------
# Training loss: 0.252883
# Validation loss: 0.259669
#
# Epoch 265
# -------------------------------
# Training loss: 0.251941
# Validation loss: 0.257327
#
# Epoch 266
# -------------------------------
# Training loss: 0.251703
# Validation loss: 0.253355
#
# Epoch 267
# -------------------------------
# Training loss: 0.251603
# Validation loss: 0.249394
#
# Epoch 268
# -------------------------------
# Training loss: 0.250012
# Validation loss: 0.242995
#
# Epoch 269
# -------------------------------
# Training loss: 0.248382
# Validation loss: 0.252657
#
# Epoch 270
# -------------------------------
# Training loss: 0.250138
# Validation loss: 0.258320
#
# Epoch 271
# -------------------------------
# Training loss: 0.247213
# Validation loss: 0.252894
#
# Epoch 272
# -------------------------------
# Training loss: 0.248132
# Validation loss: 0.248623
#
# Epoch 273
# -------------------------------
# Training loss: 0.245026
# Validation loss: 0.285218
#
# Epoch 274
# -------------------------------
# Training loss: 0.247809
# Validation loss: 0.247215
#
# Epoch 275
# -------------------------------
# Training loss: 0.245604
# Validation loss: 0.265189
#
# Epoch 276
# -------------------------------
# Training loss: 0.244747
# Validation loss: 0.250619
#
# Epoch 277
# -------------------------------
# Training loss: 0.245834
# Validation loss: 0.237703
#
# Epoch 278
# -------------------------------
# Training loss: 0.241258
# Validation loss: 0.256944
#
# Epoch 279
# -------------------------------
# Training loss: 0.242593
# Validation loss: 0.259216
#
# Epoch 280
# -------------------------------
# Training loss: 0.242370
# Validation loss: 0.267386
#
# Epoch 281
# -------------------------------
# Training loss: 0.241221
# Validation loss: 0.262131
#
# Epoch 282
# -------------------------------
# Training loss: 0.240610
# Validation loss: 0.265508
#
# Epoch 283
# -------------------------------
# Training loss: 0.240278
# Validation loss: 0.247198
#
# Epoch 284
# -------------------------------
# Training loss: 0.237045
# Validation loss: 0.281066
#
# Epoch 285
# -------------------------------
# Training loss: 0.237915
# Validation loss: 0.264224
#
# Epoch 286
# -------------------------------
# Training loss: 0.237061
# Validation loss: 0.247964
#
# Epoch 287
# -------------------------------
# Training loss: 0.236783
# Validation loss: 0.252873
#
# Epoch 288
# -------------------------------
# Training loss: 0.234476
# Validation loss: 0.241446
#
# Epoch 289
# -------------------------------
# Training loss: 0.235285
# Validation loss: 0.230889
#
# Epoch 290
# -------------------------------
# Training loss: 0.236070
# Validation loss: 0.248324
#
# Epoch 291
# -------------------------------
# Training loss: 0.234479
# Validation loss: 0.244492
#
# Epoch 292
# -------------------------------
# Training loss: 0.234484
# Validation loss: 0.227701
#
# Epoch 293
# -------------------------------
# Training loss: 0.231264
# Validation loss: 0.237983
#
# Epoch 294
# -------------------------------
# Training loss: 0.229934
# Validation loss: 0.243188
#
# Epoch 295
# -------------------------------
# Training loss: 0.233100
# Validation loss: 0.264065
#
# Epoch 296
# -------------------------------
# Training loss: 0.229510
# Validation loss: 0.223420
#
# Epoch 297
# -------------------------------
# Training loss: 0.229152
# Validation loss: 0.278927
#
# Epoch 298
# -------------------------------
# Training loss: 0.228073
# Validation loss: 0.294074
#
# Epoch 299
# -------------------------------
# Training loss: 0.226882
# Validation loss: 0.274023
#
# Epoch 300
# -------------------------------
# Training loss: 0.226729
# Validation loss: 0.236393
#
# Epoch 301
# -------------------------------
# Training loss: 0.222100
# Validation loss: 0.233513
#
# Epoch 302
# -------------------------------
# Training loss: 0.223024
# Validation loss: 0.220558
#
# Epoch 303
# -------------------------------
# Training loss: 0.221468
# Validation loss: 0.209585
#
# Epoch 304
# -------------------------------
# Training loss: 0.223589
# Validation loss: 0.219695
#
# Epoch 305
# -------------------------------
# Training loss: 0.222230
# Validation loss: 0.233023
#
# Epoch 306
# -------------------------------
# Training loss: 0.223339
# Validation loss: 0.233236
#
# Epoch 307
# -------------------------------
# Training loss: 0.222807
# Validation loss: 0.204952
#
# Epoch 308
# -------------------------------
# Training loss: 0.219317
# Validation loss: 0.228032
#
# Epoch 309
# -------------------------------
# Training loss: 0.219134
# Validation loss: 0.301235
#
# Epoch 310
# -------------------------------
# Training loss: 0.220679
# Validation loss: 0.218652
#
# Epoch 311
# -------------------------------
# Training loss: 0.218125
# Validation loss: 0.228597
#
# Epoch 312
# -------------------------------
# Training loss: 0.217206
# Validation loss: 0.244089
#
# Epoch 313
# -------------------------------
# Training loss: 0.218018
# Validation loss: 0.249135
#
# Epoch 314
# -------------------------------
# Training loss: 0.217593
# Validation loss: 0.208699
#
# Epoch 315
# -------------------------------
# Training loss: 0.216532
# Validation loss: 0.223746
#
# Epoch 316
# -------------------------------
# Training loss: 0.218070
# Validation loss: 0.231489
#
# Epoch 317
# -------------------------------
# Training loss: 0.214804
# Validation loss: 0.213090
#
# Epoch 318
# -------------------------------
# Training loss: 0.212948
# Validation loss: 0.220813
#
# Epoch 319
# -------------------------------
# Training loss: 0.209849
# Validation loss: 0.208405
#
# Epoch 320
# -------------------------------
# Training loss: 0.211077
# Validation loss: 0.223898
#
# Epoch 321
# -------------------------------
# Training loss: 0.208669
# Validation loss: 0.195547
#
# Epoch 322
# -------------------------------
# Training loss: 0.208765
# Validation loss: 0.259737
#
# Epoch 323
# -------------------------------
# Training loss: 0.208646
# Validation loss: 0.199766
#
# Epoch 324
# -------------------------------
# Training loss: 0.208579
# Validation loss: 0.208402
#
# Epoch 325
# -------------------------------
# Training loss: 0.210757
# Validation loss: 0.230198
#
# Epoch 326
# -------------------------------
# Training loss: 0.206305
# Validation loss: 0.224978
#
# Epoch 327
# -------------------------------
# Training loss: 0.205849
# Validation loss: 0.210366
#
# Epoch 328
# -------------------------------
# Training loss: 0.205289
# Validation loss: 0.206960
#
# Epoch 329
# -------------------------------
# Training loss: 0.204574
# Validation loss: 0.189425
#
# Epoch 330
# -------------------------------
# Training loss: 0.204255
# Validation loss: 0.235921
#
# Epoch 331
# -------------------------------
# Training loss: 0.203659
# Validation loss: 0.210949
#
# Epoch 332
# -------------------------------
# Training loss: 0.202056
# Validation loss: 0.219548
#
# Epoch 333
# -------------------------------
# Training loss: 0.202666
# Validation loss: 0.270123
#
# Epoch 334
# -------------------------------
# Training loss: 0.207099
# Validation loss: 0.207000
#
# Epoch 335
# -------------------------------
# Training loss: 0.204251
# Validation loss: 0.252188
#
# Epoch 336
# -------------------------------
# Training loss: 0.202554
# Validation loss: 0.230028
#
# Epoch 337
# -------------------------------
# Training loss: 0.200725
# Validation loss: 0.210822
#
# Epoch 338
# -------------------------------
# Training loss: 0.203015
# Validation loss: 0.209624
#
# Epoch 339
# -------------------------------
# Training loss: 0.198961
# Validation loss: 0.184474
#
# Epoch 340
# -------------------------------
# Training loss: 0.195451
# Validation loss: 0.195273
#
# Epoch 341
# -------------------------------
# Training loss: 0.196296
# Validation loss: 0.195929
#
# Epoch 342
# -------------------------------
# Training loss: 0.199445
# Validation loss: 0.187757
#
# Epoch 343
# -------------------------------
# Training loss: 0.201032
# Validation loss: 0.241521
#
# Epoch 344
# -------------------------------
# Training loss: 0.199920
# Validation loss: 0.198230
#
# Epoch 345
# -------------------------------
# Training loss: 0.195054
# Validation loss: 0.190218
#
# Epoch 346
# -------------------------------
# Training loss: 0.193045
# Validation loss: 0.188534
#
# Epoch 347
# -------------------------------
# Training loss: 0.192749
# Validation loss: 0.186490
#
# Epoch 348
# -------------------------------
# Training loss: 0.192491
# Validation loss: 0.187206
#
# Epoch 349
# -------------------------------
# Training loss: 0.193977
# Validation loss: 0.189774
#
# Epoch 350
# -------------------------------
# Training loss: 0.193564
# Validation loss: 0.202764
#
# Epoch 351
# -------------------------------
# Training loss: 0.191291
# Validation loss: 0.197485
#
# Epoch 352
# -------------------------------
# Training loss: 0.191409
# Validation loss: 0.196003
#
# Epoch 353
# -------------------------------
# Training loss: 0.190509
# Validation loss: 0.193218
#
# Epoch 354
# -------------------------------
# Training loss: 0.191606
# Validation loss: 0.182210
#
# Epoch 355
# -------------------------------
# Training loss: 0.188627
# Validation loss: 0.195746
#
# Epoch 356
# -------------------------------
# Training loss: 0.188108
# Validation loss: 0.179690
#
# Epoch 357
# -------------------------------
# Training loss: 0.188951
# Validation loss: 0.205926
#
# Epoch 358
# -------------------------------
# Training loss: 0.189811
# Validation loss: 0.180121
#
# Epoch 359
# -------------------------------
# Training loss: 0.186226
# Validation loss: 0.192452
#
# Epoch 360
# -------------------------------
# Training loss: 0.187838
# Validation loss: 0.207916
#
# Epoch 361
# -------------------------------
# Training loss: 0.186295
# Validation loss: 0.204773
#
# Epoch 362
# -------------------------------
# Training loss: 0.183573
# Validation loss: 0.278167
#
# Epoch 363
# -------------------------------
# Training loss: 0.188640
# Validation loss: 0.200364
#
# Epoch 364
# -------------------------------
# Training loss: 0.188052
# Validation loss: 0.210706
#
# Epoch 365
# -------------------------------
# Training loss: 0.184212
# Validation loss: 0.181208
#
# Epoch 366
# -------------------------------
# Training loss: 0.184240
# Validation loss: 0.171983
#
# Epoch 367
# -------------------------------
# Training loss: 0.183353
# Validation loss: 0.207660
#
# Epoch 368
# -------------------------------
# Training loss: 0.183267
# Validation loss: 0.181615
#
# Epoch 369
# -------------------------------
# Training loss: 0.182558
# Validation loss: 0.171316
#
# Epoch 370
# -------------------------------
# Training loss: 0.181354
# Validation loss: 0.171324
#
# Epoch 371
# -------------------------------
# Training loss: 0.180334
# Validation loss: 0.182605
#
# Epoch 372
# -------------------------------
# Training loss: 0.179537
# Validation loss: 0.202929
#
# Epoch 373
# -------------------------------
# Training loss: 0.182003
# Validation loss: 0.177526
#
# Epoch 374
# -------------------------------
# Training loss: 0.178113
# Validation loss: 0.183704
#
# Epoch 375
# -------------------------------
# Training loss: 0.178405
# Validation loss: 0.184421
#
# Epoch 376
# -------------------------------
# Training loss: 0.179759
# Validation loss: 0.192699
#
# Epoch 377
# -------------------------------
# Training loss: 0.179095
# Validation loss: 0.182662
#
# Epoch 378
# -------------------------------
# Training loss: 0.179735
# Validation loss: 0.178270
#
# Epoch 379
# -------------------------------
# Training loss: 0.177009
# Validation loss: 0.185702
#
# Epoch 380
# -------------------------------
# Training loss: 0.178877
# Validation loss: 0.189653
#
# Epoch 381
# -------------------------------
# Training loss: 0.173847
# Validation loss: 0.178581
#
# Epoch 382
# -------------------------------
# Training loss: 0.175454
# Validation loss: 0.174191
#
# Epoch 383
# -------------------------------
# Training loss: 0.176829
# Validation loss: 0.174252
#
# Epoch 384
# -------------------------------
# Training loss: 0.179338
# Validation loss: 0.173129
#
# Epoch 385
# -------------------------------
# Training loss: 0.175555
# Validation loss: 0.193149
#
# Epoch 386
# -------------------------------
# Training loss: 0.173705
# Validation loss: 0.167538
#
# Epoch 387
# -------------------------------
# Training loss: 0.171387
# Validation loss: 0.181435
#
# Epoch 388
# -------------------------------
# Training loss: 0.172904
# Validation loss: 0.180674
#
# Epoch 389
# -------------------------------
# Training loss: 0.171556
# Validation loss: 0.198929
#
# Epoch 390
# -------------------------------
# Training loss: 0.172555
# Validation loss: 0.163558
#
# Epoch 391
# -------------------------------
# Training loss: 0.170389
# Validation loss: 0.201887
#
# Epoch 392
# -------------------------------
# Training loss: 0.171135
# Validation loss: 0.163809
#
# Epoch 393
# -------------------------------
# Training loss: 0.172402
# Validation loss: 0.204379
#
# Epoch 394
# -------------------------------
# Training loss: 0.169964
# Validation loss: 0.163344
#
# Epoch 395
# -------------------------------
# Training loss: 0.172970
# Validation loss: 0.182723
#
# Epoch 396
# -------------------------------
# Training loss: 0.168831
# Validation loss: 0.184262
#
# Epoch 397
# -------------------------------
# Training loss: 0.170592
# Validation loss: 0.178038
#
# Epoch 398
# -------------------------------
# Training loss: 0.169909
# Validation loss: 0.168136
#
# Epoch 399
# -------------------------------
# Training loss: 0.169311
# Validation loss: 0.159974
#
# Epoch 400
# -------------------------------
# Training loss: 0.167393
# Validation loss: 0.181941
#
# Epoch 401
# -------------------------------
# Training loss: 0.167204
# Validation loss: 0.173217
#
# Epoch 402
# -------------------------------
# Training loss: 0.167508
# Validation loss: 0.172897
#
# Epoch 403
# -------------------------------
# Training loss: 0.165616
# Validation loss: 0.191589
#
# Epoch 404
# -------------------------------
# Training loss: 0.166954
# Validation loss: 0.237821
#
# Epoch 405
# -------------------------------
# Training loss: 0.167798
# Validation loss: 0.177777
#
# Epoch 406
# -------------------------------
# Training loss: 0.165427
# Validation loss: 0.160798
#
# Epoch 407
# -------------------------------
# Training loss: 0.164223
# Validation loss: 0.159360
#
# Epoch 408
# -------------------------------
# Training loss: 0.164101
# Validation loss: 0.155749
#
# Epoch 409
# -------------------------------
# Training loss: 0.164944
# Validation loss: 0.166452
#
# Epoch 410
# -------------------------------
# Training loss: 0.163411
# Validation loss: 0.180013
#
# Epoch 411
# -------------------------------
# Training loss: 0.163915
# Validation loss: 0.180428
#
# Epoch 412
# -------------------------------
# Training loss: 0.164491
# Validation loss: 0.182365
#
# Epoch 413
# -------------------------------
# Training loss: 0.160681
# Validation loss: 0.151096
#
# Epoch 414
# -------------------------------
# Training loss: 0.161642
# Validation loss: 0.157211
#
# Epoch 415
# -------------------------------
# Training loss: 0.161259
# Validation loss: 0.151558
#
# Epoch 416
# -------------------------------
# Training loss: 0.161535
# Validation loss: 0.165338
#
# Epoch 417
# -------------------------------
# Training loss: 0.163371
# Validation loss: 0.148596
#
# Epoch 418
# -------------------------------
# Training loss: 0.161586
# Validation loss: 0.173861
#
# Epoch 419
# -------------------------------
# Training loss: 0.161442
# Validation loss: 0.169407
#
# Epoch 420
# -------------------------------
# Training loss: 0.161025
# Validation loss: 0.160554
#
# Epoch 421
# -------------------------------
# Training loss: 0.161066
# Validation loss: 0.157297
#
# Epoch 422
# -------------------------------
# Training loss: 0.157180
# Validation loss: 0.157356
#
# Epoch 423
# -------------------------------
# Training loss: 0.157192
# Validation loss: 0.155866
#
# Epoch 424
# -------------------------------
# Training loss: 0.158627
# Validation loss: 0.166863
#
# Epoch 425
# -------------------------------
# Training loss: 0.158163
# Validation loss: 0.155268
#
# Epoch 426
# -------------------------------
# Training loss: 0.157937
# Validation loss: 0.148086
#
# Epoch 427
# -------------------------------
# Training loss: 0.157174
# Validation loss: 0.161965
#
# Epoch 428
# -------------------------------
# Training loss: 0.157865
# Validation loss: 0.154610
#
# Epoch 429
# -------------------------------
# Training loss: 0.156165
# Validation loss: 0.150962
#
# Epoch 430
# -------------------------------
# Training loss: 0.156885
# Validation loss: 0.181877
#
# Epoch 431
# -------------------------------
# Training loss: 0.160060
# Validation loss: 0.172590
#
# Epoch 432
# -------------------------------
# Training loss: 0.158052
# Validation loss: 0.146472
#
# Epoch 433
# -------------------------------
# Training loss: 0.155970
# Validation loss: 0.165468
#
# Epoch 434
# -------------------------------
# Training loss: 0.153396
# Validation loss: 0.156871
#
# Epoch 435
# -------------------------------
# Training loss: 0.153491
# Validation loss: 0.160217
#
# Epoch 436
# -------------------------------
# Training loss: 0.153732
# Validation loss: 0.160451
#
# Epoch 437
# -------------------------------
# Training loss: 0.153638
# Validation loss: 0.167493
#
# Epoch 438
# -------------------------------
# Training loss: 0.153501
# Validation loss: 0.161076
#
# Epoch 439
# -------------------------------
# Training loss: 0.152360
# Validation loss: 0.145061
#
# Epoch 440
# -------------------------------
# Training loss: 0.154535
# Validation loss: 0.160779
#
# Epoch 441
# -------------------------------
# Training loss: 0.152047
# Validation loss: 0.230398
#
# Epoch 442
# -------------------------------
# Training loss: 0.153666
# Validation loss: 0.159569
#
# Epoch 443
# -------------------------------
# Training loss: 0.152587
# Validation loss: 0.184711
#
# Epoch 444
# -------------------------------
# Training loss: 0.152637
# Validation loss: 0.157098
#
# Epoch 445
# -------------------------------
# Training loss: 0.151902
# Validation loss: 0.147188
#
# Epoch 446
# -------------------------------
# Training loss: 0.149622
# Validation loss: 0.186467
#
# Epoch 447
# -------------------------------
# Training loss: 0.150299
# Validation loss: 0.144035
#
# Epoch 448
# -------------------------------
# Training loss: 0.149612
# Validation loss: 0.147626
#
# Epoch 449
# -------------------------------
# Training loss: 0.151925
# Validation loss: 0.158290
#
# Epoch 450
# -------------------------------
# Training loss: 0.148577
# Validation loss: 0.144955
#
# Epoch 451
# -------------------------------
# Training loss: 0.149319
# Validation loss: 0.157089
#
# Epoch 452
# -------------------------------
# Training loss: 0.149264
# Validation loss: 0.220117
#
# Epoch 453
# -------------------------------
# Training loss: 0.149418
# Validation loss: 0.166782
#
# Epoch 454
# -------------------------------
# Training loss: 0.149003
# Validation loss: 0.159040
#
# Epoch 455
# -------------------------------
# Training loss: 0.148589
# Validation loss: 0.148195
#
# Epoch 456
# -------------------------------
# Training loss: 0.149365
# Validation loss: 0.152520
#
# Epoch 457
# -------------------------------
# Training loss: 0.147805
# Validation loss: 0.152169
#
# Epoch 458
# -------------------------------
# Training loss: 0.147590
# Validation loss: 0.166768
#
# Epoch 459
# -------------------------------
# Training loss: 0.147374
# Validation loss: 0.144248
#
# Epoch 460
# -------------------------------
# Training loss: 0.145643
# Validation loss: 0.146964
#
# Epoch 461
# -------------------------------
# Training loss: 0.145069
# Validation loss: 0.148907
#
# Epoch 462
# -------------------------------
# Training loss: 0.146432
# Validation loss: 0.150663
#
# Epoch 463
# -------------------------------
# Training loss: 0.145070
# Validation loss: 0.148420
#
# Epoch 464
# -------------------------------
# Training loss: 0.145457
# Validation loss: 0.147557
#
# Epoch 465
# -------------------------------
# Training loss: 0.145684
# Validation loss: 0.149602
#
# Epoch 466
# -------------------------------
# Training loss: 0.147105
# Validation loss: 0.153458
#
# Epoch 467
# -------------------------------
# Training loss: 0.144819
# Validation loss: 0.143339
#
# Epoch 468
# -------------------------------
# Training loss: 0.144599
# Validation loss: 0.175961
#
# Epoch 469
# -------------------------------
# Training loss: 0.143915
# Validation loss: 0.148693
#
# Epoch 470
# -------------------------------
# Training loss: 0.145768
# Validation loss: 0.147871
#
# Epoch 471
# -------------------------------
# Training loss: 0.144591
# Validation loss: 0.138931
#
# Epoch 472
# -------------------------------
# Training loss: 0.143791
# Validation loss: 0.142024
#
# Epoch 473
# -------------------------------
# Training loss: 0.143210
# Validation loss: 0.135885
#
# Epoch 474
# -------------------------------
# Training loss: 0.140649
# Validation loss: 0.146623
#
# Epoch 475
# -------------------------------
# Training loss: 0.141436
# Validation loss: 0.138042
#
# Epoch 476
# -------------------------------
# Training loss: 0.142792
# Validation loss: 0.129398
#
# Epoch 477
# -------------------------------
# Training loss: 0.141722
# Validation loss: 0.145709
#
# Epoch 478
# -------------------------------
# Training loss: 0.141032
# Validation loss: 0.147101
#
# Epoch 479
# -------------------------------
# Training loss: 0.142110
# Validation loss: 0.156939
#
# Epoch 480
# -------------------------------
# Training loss: 0.143233
# Validation loss: 0.145796
#
# Epoch 481
# -------------------------------
# Training loss: 0.141489
# Validation loss: 0.164543
#
# Epoch 482
# -------------------------------
# Training loss: 0.144051
# Validation loss: 0.164339
#
# Epoch 483
# -------------------------------
# Training loss: 0.141795
# Validation loss: 0.183476
#
# Epoch 484
# -------------------------------
# Training loss: 0.140134
# Validation loss: 0.145989
#
# Epoch 485
# -------------------------------
# Training loss: 0.142494
# Validation loss: 0.147385
#
# Epoch 486
# -------------------------------
# Training loss: 0.140890
# Validation loss: 0.143405
#
# Epoch 487
# -------------------------------
# Training loss: 0.138496
# Validation loss: 0.140636
#
# Epoch 488
# -------------------------------
# Training loss: 0.140077
# Validation loss: 0.131805
#
# Epoch 489
# -------------------------------
# Training loss: 0.139544
# Validation loss: 0.129017
#
# Epoch 490
# -------------------------------
# Training loss: 0.138497
# Validation loss: 0.126894
#
# Epoch 491
# -------------------------------
# Training loss: 0.138713
# Validation loss: 0.136466
#
# Epoch 492
# -------------------------------
# Training loss: 0.137718
# Validation loss: 0.150896
#
# Epoch 493
# -------------------------------
# Training loss: 0.138094
# Validation loss: 0.132126
#
# Epoch 494
# -------------------------------
# Training loss: 0.137088
# Validation loss: 0.141045
#
# Epoch 495
# -------------------------------
# Training loss: 0.137681
# Validation loss: 0.122298
#
# Epoch 496
# -------------------------------
# Training loss: 0.136971
# Validation loss: 0.132878
#
# Epoch 497
# -------------------------------
# Training loss: 0.138263
# Validation loss: 0.136514
#
# Epoch 498
# -------------------------------
# Training loss: 0.139705
# Validation loss: 0.141565
#
# Epoch 499
# -------------------------------
# Training loss: 0.137449
# Validation loss: 0.149636
#
# Epoch 500
# -------------------------------
# Training loss: 0.134557
# Validation loss: 0.135860
#
# Epoch 501
# -------------------------------
# Training loss: 0.135110
# Validation loss: 0.122209
#
# Epoch 502
# -------------------------------
# Training loss: 0.134697
# Validation loss: 0.138021
#
# Epoch 503
# -------------------------------
# Training loss: 0.134847
# Validation loss: 0.135403
#
# Epoch 504
# -------------------------------
# Training loss: 0.134939
# Validation loss: 0.128369
#
# Epoch 505
# -------------------------------
# Training loss: 0.133569
# Validation loss: 0.133777
#
# Epoch 506
# -------------------------------
# Training loss: 0.136472
# Validation loss: 0.140071
#
# Epoch 507
# -------------------------------
# Training loss: 0.133323
# Validation loss: 0.133108
#
# Epoch 508
# -------------------------------
# Training loss: 0.133147
# Validation loss: 0.129257
#
# Epoch 509
# -------------------------------
# Training loss: 0.134466
# Validation loss: 0.150447
#
# Epoch 510
# -------------------------------
# Training loss: 0.134890
# Validation loss: 0.140989
#
# Epoch 511
# -------------------------------
# Training loss: 0.132298
# Validation loss: 0.128160
#
# Epoch 512
# -------------------------------
# Training loss: 0.133489
# ...
# Validation loss: 0.059441
#
# Epoch 2333
# -------------------------------
# Training loss: 0.060550
# Validation loss: 0.059168
#
# Epoch 2334
# -------------------------------
# Training loss: 0.060610
# Validation loss: 0.060423
#
# Epoch 2335
# -------------------------------
# Training loss: 0.060923
# Validation loss: 0.064794
#
# Epoch 2336
# -------------------------------
# Training loss: 0.059574
# Validation loss: 0.060146
#
# Epoch 2337
# -------------------------------
# Training loss: 0.060018
# Validation loss: 0.059714
#
# Epoch 2338
# -------------------------------
# Training loss: 0.061302
# Validation loss: 0.063910
#
# Epoch 2339
# -------------------------------
# Training loss: 0.059997
# Validation loss: 0.061690
#
# Epoch 2340
# -------------------------------
# Training loss: 0.059868
# Validation loss: 0.061565
#
# Epoch 2341
# -------------------------------
# Training loss: 0.059538
# Validation loss: 0.058876
#
# Epoch 2342
# -------------------------------
# Training loss: 0.060160
# Validation loss: 0.060052
#
# Epoch 2343
# -------------------------------
# Training loss: 0.060132
# Validation loss: 0.059598
#
# Epoch 2344
# -------------------------------
# Training loss: 0.061028
# Validation loss: 0.062206
#
# Epoch 2345
# -------------------------------
# Training loss: 0.060536
# Validation loss: 0.063377
#
# Epoch 2346
# -------------------------------
# Training loss: 0.060152
# Validation loss: 0.058004
#
# Epoch 2347
# -------------------------------
# Training loss: 0.060038
# Validation loss: 0.058559
#
# Epoch 2348
# -------------------------------
# Training loss: 0.060681
# Validation loss: 0.062947
#
# Epoch 2349
# -------------------------------
# Training loss: 0.064640
# Validation loss: 0.072482
#
# Epoch 2350
# -------------------------------
# Training loss: 0.059871
# Validation loss: 0.059136
#
# Epoch 2351
# -------------------------------
# Training loss: 0.059361
# Validation loss: 0.060113
#
# Epoch 2352
# -------------------------------
# Training loss: 0.059613
# Validation loss: 0.061771
#
# Epoch 2353
# -------------------------------
# Training loss: 0.061208
# Validation loss: 0.060330
#
# Epoch 2354
# -------------------------------
# Training loss: 0.059750
# Validation loss: 0.057840
#
# Epoch 2355
# -------------------------------
# Training loss: 0.060808
# Validation loss: 0.058397
#
# Epoch 2356
# -------------------------------
# Training loss: 0.059695
# Validation loss: 0.063216
#
# Epoch 2357
# -------------------------------
# Training loss: 0.059953
# Validation loss: 0.059404
#
# Epoch 2358
# -------------------------------
# Training loss: 0.059884
# Validation loss: 0.062543
#
# Epoch 2359
# -------------------------------
# Training loss: 0.059929
# Validation loss: 0.059483
#
# Epoch 2360
# -------------------------------
# Training loss: 0.059999
# Validation loss: 0.057941
#
# Epoch 2361
# -------------------------------
# Training loss: 0.060306
# Validation loss: 0.063031
#
# Epoch 2362
# -------------------------------
# Training loss: 0.061762
# Validation loss: 0.063255
#
# Epoch 2363
# -------------------------------
# Training loss: 0.060330
# Validation loss: 0.060304
#
# Epoch 2364
# -------------------------------
# Training loss: 0.059477
# Validation loss: 0.057789
#
# Epoch 2365
# -------------------------------
# Training loss: 0.059760
# Validation loss: 0.063732
#
# Epoch 2366
# -------------------------------
# Training loss: 0.060278
# Validation loss: 0.063626
#
# Epoch 2367
# -------------------------------
# Training loss: 0.060738
# Validation loss: 0.060158
#
# Epoch 2368
# -------------------------------
# Training loss: 0.059685
# Validation loss: 0.061788
#
# Epoch 2369
# -------------------------------
# Training loss: 0.064709
# Validation loss: 0.073751
#
# Epoch 2370
# -------------------------------
# Training loss: 0.061026
# Validation loss: 0.066079
#
# Epoch 2371
# -------------------------------
# Training loss: 0.061310
# Validation loss: 0.069061
#
# Epoch 2372
# -------------------------------
# Training loss: 0.060467
# Validation loss: 0.061928
#
# Epoch 2373
# -------------------------------
# Training loss: 0.060245
# Validation loss: 0.058703
#
# Epoch 2374
# -------------------------------
# Training loss: 0.059810
# Validation loss: 0.062527
#
# Epoch 2375
# -------------------------------
# Training loss: 0.060343
# Validation loss: 0.063470
#
# Epoch 2376
# -------------------------------
# Training loss: 0.059605
# Validation loss: 0.058675
#
# Epoch 2377
# -------------------------------
# Training loss: 0.060897
# Validation loss: 0.061696
#
# Epoch 2378
# -------------------------------
# Training loss: 0.060510
# Validation loss: 0.061161
#
# Epoch 2379
# -------------------------------
# Training loss: 0.059866
# Validation loss: 0.061252
#
# Epoch 2380
# -------------------------------
# Training loss: 0.061334
# Validation loss: 0.067784
#
# Epoch 2381
# -------------------------------
# Training loss: 0.059662
# Validation loss: 0.060454
#
# Epoch 2382
# -------------------------------
# Training loss: 0.059676
# Validation loss: 0.061238
#
# Epoch 2383
# -------------------------------
# Training loss: 0.060081
# Validation loss: 0.059679
#
# Epoch 2384
# -------------------------------
# Training loss: 0.060163
# Validation loss: 0.057435
#
# Epoch 2385
# -------------------------------
# Training loss: 0.059796
# Validation loss: 0.059104
#
# Epoch 2386
# -------------------------------
# Training loss: 0.059771
# Validation loss: 0.058947
#
# Epoch 2387
# -------------------------------
# Training loss: 0.059572
# Validation loss: 0.061213
#
# Epoch 2388
# -------------------------------
# Training loss: 0.060087
# Validation loss: 0.062134
#
# Epoch 2389
# -------------------------------
# Training loss: 0.058910
# Validation loss: 0.058394
#
# Epoch 2390
# -------------------------------
# Training loss: 0.060472
# Validation loss: 0.060323
#
# Epoch 2391
# -------------------------------
# Training loss: 0.060738
# Validation loss: 0.063788
#
# Epoch 2392
# -------------------------------
# Training loss: 0.059781
# Validation loss: 0.059174
#
# Epoch 2393
# -------------------------------
# Training loss: 0.059997
# Validation loss: 0.057755
#
# Epoch 2394
# -------------------------------
# Training loss: 0.059953
# Validation loss: 0.062646
#
# Epoch 2395
# -------------------------------
# Training loss: 0.059650
# Validation loss: 0.058545
#
# Epoch 2396
# -------------------------------
# Training loss: 0.059593
# Validation loss: 0.059783
#
# Epoch 2397
# -------------------------------
# Training loss: 0.059574
# Validation loss: 0.058554
#
# Epoch 2398
# -------------------------------
# Training loss: 0.060917
# Validation loss: 0.061282
#
# Epoch 2399
# -------------------------------
# Training loss: 0.061255
# Validation loss: 0.060851
#
# Epoch 2400
# -------------------------------
# Training loss: 0.060729
# Validation loss: 0.064146
#
# Epoch 2401
# -------------------------------
# Training loss: 0.060339
# Validation loss: 0.061162
#
# Epoch 2402
# -------------------------------
# Training loss: 0.060862
# Validation loss: 0.061370
#
# Epoch 2403
# -------------------------------
# Training loss: 0.060494
# Validation loss: 0.062962
#
# Epoch 2404
# -------------------------------
# Training loss: 0.060424
# Validation loss: 0.067664
#
# Epoch 2405
# -------------------------------
# Training loss: 0.059883
# Validation loss: 0.061451
#
# Epoch 2406
# -------------------------------
# Training loss: 0.060178
# Validation loss: 0.059187
#
# Epoch 2407
# -------------------------------
# Training loss: 0.060135
# Validation loss: 0.062103
#
# Epoch 2408
# -------------------------------
# Training loss: 0.059401
# Validation loss: 0.061008
#
# Epoch 2409
# -------------------------------
# Training loss: 0.060169
# Validation loss: 0.059455
#
# Epoch 2410
# -------------------------------
# Training loss: 0.062552
# Validation loss: 0.068466
#
# Epoch 2411
# -------------------------------
# Training loss: 0.060514
# Validation loss: 0.063280
#
# Epoch 2412
# -------------------------------
# Training loss: 0.061043
# Validation loss: 0.066386
#
# Epoch 2413
# -------------------------------
# Training loss: 0.061393
# Validation loss: 0.061679
#
# Epoch 2414
# -------------------------------
# Training loss: 0.061111
# Validation loss: 0.067981
#
# Epoch 2415
# -------------------------------
# Training loss: 0.059490
# Validation loss: 0.060623
#
# Epoch 2416
# -------------------------------
# Training loss: 0.059699
# Validation loss: 0.060874
#
# Epoch 2417
# -------------------------------
# Training loss: 0.060257
# Validation loss: 0.061717
#
# Epoch 2418
# -------------------------------
# Training loss: 0.060260
# Validation loss: 0.061645
#
# Epoch 2419
# -------------------------------
# Training loss: 0.060606
# Validation loss: 0.060044
#
# Epoch 2420
# -------------------------------
# Training loss: 0.060320
# Validation loss: 0.059952
#
# Epoch 2421
# -------------------------------
# Training loss: 0.060558
# Validation loss: 0.059561
#
# Epoch 2422
# -------------------------------
# Training loss: 0.060383
# Validation loss: 0.060552
#
# Epoch 2423
# -------------------------------
# Training loss: 0.060271
# Validation loss: 0.062968
#
# Epoch 2424
# -------------------------------
# Training loss: 0.059809
# Validation loss: 0.058579
#
# Epoch 2425
# -------------------------------
# Training loss: 0.059122
# Validation loss: 0.059300
#
# Epoch 2426
# -------------------------------
# Training loss: 0.060729
# Validation loss: 0.062399
#
# Epoch 2427
# -------------------------------
# Training loss: 0.059412
# Validation loss: 0.058373
#
# Epoch 2428
# -------------------------------
# Training loss: 0.060673
# Validation loss: 0.061367
#
# Epoch 2429
# -------------------------------
# Training loss: 0.059316
# Validation loss: 0.063565
#
# Epoch 2430
# -------------------------------
# Training loss: 0.060669
# Validation loss: 0.062243
#
# Epoch 2431
# -------------------------------
# Training loss: 0.060432
# Validation loss: 0.060803
#
# Epoch 2432
# -------------------------------
# Training loss: 0.059683
# Validation loss: 0.061995
#
# Epoch 2433
# -------------------------------
# Training loss: 0.059985
# Validation loss: 0.058502
#
# Epoch 2434
# -------------------------------
# Training loss: 0.060401
# Validation loss: 0.060694
#
# Epoch 2435
# -------------------------------
# Training loss: 0.060056
# Validation loss: 0.060507
#
# Epoch 2436
# -------------------------------
# Training loss: 0.058773
# Validation loss: 0.060842
#
# Epoch 2437
# -------------------------------
# Training loss: 0.059564
# Validation loss: 0.058123
#
# Epoch 2438
# -------------------------------
# Training loss: 0.059512
# Validation loss: 0.057385
#
# Epoch 2439
# -------------------------------
# Training loss: 0.059991
# Validation loss: 0.058624
#
# Epoch 2440
# -------------------------------
# Training loss: 0.060639
# Validation loss: 0.058360
#
# Epoch 2441
# -------------------------------
# Training loss: 0.059353
# Validation loss: 0.059068
#
# Epoch 2442
# -------------------------------
# Training loss: 0.061274
# Validation loss: 0.061615
#
# Epoch 2443
# -------------------------------
# Training loss: 0.060036
# Validation loss: 0.064724
#
# Epoch 2444
# -------------------------------
# Training loss: 0.060396
# Validation loss: 0.061410
#
# Epoch 2445
# -------------------------------
# Training loss: 0.059944
# Validation loss: 0.060256
#
# Epoch 2446
# -------------------------------
# Training loss: 0.059552
# Validation loss: 0.060069
#
# Epoch 2447
# -------------------------------
# Training loss: 0.059893
# Validation loss: 0.060713
#
# Epoch 2448
# -------------------------------
# Training loss: 0.059309
# Validation loss: 0.058245
#
# Epoch 2449
# -------------------------------
# Training loss: 0.059662
# Validation loss: 0.061682
#
# Epoch 2450
# -------------------------------
# Training loss: 0.060080
# Validation loss: 0.059123
#
# Epoch 2451
# -------------------------------
# Training loss: 0.059522
# Validation loss: 0.059248
#
# Epoch 2452
# -------------------------------
# Training loss: 0.059403
# Validation loss: 0.061277
#
# Epoch 2453
# -------------------------------
# Training loss: 0.060389
# Validation loss: 0.061234
#
# Epoch 2454
# -------------------------------
# Training loss: 0.060148
# Validation loss: 0.060896
#
# Epoch 2455
# -------------------------------
# Training loss: 0.060351
# Validation loss: 0.066631
#
# Epoch 2456
# -------------------------------
# Training loss: 0.059754
# Validation loss: 0.063401
#
# Epoch 2457
# -------------------------------
# Training loss: 0.059709
# Validation loss: 0.058785
#
# Epoch 2458
# -------------------------------
# Training loss: 0.059540
# Validation loss: 0.061613
#
# Epoch 2459
# -------------------------------
# Training loss: 0.060222
# Validation loss: 0.062089
#
# Epoch 2460
# -------------------------------
# Training loss: 0.060445
# Validation loss: 0.061113
#
# Epoch 2461
# -------------------------------
# Training loss: 0.060332
# Validation loss: 0.063082
#
# Epoch 2462
# -------------------------------
# Training loss: 0.059684
# Validation loss: 0.058458
#
# Epoch 2463
# -------------------------------
# Training loss: 0.060591
# Validation loss: 0.058386
#
# Epoch 2464
# -------------------------------
# Training loss: 0.059592
# Validation loss: 0.061915
#
# Epoch 2465
# -------------------------------
# Training loss: 0.060134
# Validation loss: 0.063868
#
# Epoch 2466
# -------------------------------
# Training loss: 0.060246
# Validation loss: 0.061259
#
# Epoch 2467
# -------------------------------
# Training loss: 0.059865
# Validation loss: 0.059788
#
# Epoch 2468
# -------------------------------
# Training loss: 0.060593
# Validation loss: 0.060601
#
# Epoch 2469
# -------------------------------
# Training loss: 0.059921
# Validation loss: 0.062914
#
# Epoch 2470
# -------------------------------
# Training loss: 0.059279
# Validation loss: 0.059866
#
# Epoch 2471
# -------------------------------
# Training loss: 0.059539
# Validation loss: 0.060405
#
# Epoch 2472
# -------------------------------
# Training loss: 0.060228
# Validation loss: 0.059745
#
# Epoch 2473
# -------------------------------
# Training loss: 0.060165
# Validation loss: 0.058376
#
# Epoch 2474
# -------------------------------
# Training loss: 0.060203
# Validation loss: 0.058383
#
# Epoch 2475
# -------------------------------
# Training loss: 0.060028
# Validation loss: 0.059377
#
# Epoch 2476
# -------------------------------
# Training loss: 0.059999
# Validation loss: 0.058931
#
# Epoch 2477
# -------------------------------
# Training loss: 0.060237
# Validation loss: 0.062747
#
# Epoch 2478
# -------------------------------
# Training loss: 0.059946
# Validation loss: 0.062825
#
# Epoch 2479
# -------------------------------
# Training loss: 0.059946
# Validation loss: 0.058589
#
# Epoch 2480
# -------------------------------
# Training loss: 0.060555
# Validation loss: 0.058841
#
# Epoch 2481
# -------------------------------
# Training loss: 0.060105
# Validation loss: 0.061078
#
# Epoch 2482
# -------------------------------
# Training loss: 0.059734
# Validation loss: 0.059481
#
# Epoch 2483
# -------------------------------
# Training loss: 0.059521
# Validation loss: 0.060801
#
# Epoch 2484
# -------------------------------
# Training loss: 0.059683
# Validation loss: 0.059133
#
# Epoch 2485
# -------------------------------
# Training loss: 0.059445
# Validation loss: 0.060175
#
# Epoch 2486
# -------------------------------
# Training loss: 0.061358
# Validation loss: 0.063263
#
# Epoch 2487
# -------------------------------
# Training loss: 0.060114
# Validation loss: 0.059537
#
# Epoch 2488
# -------------------------------
# Training loss: 0.059918
# Validation loss: 0.061062
#
# Epoch 2489
# -------------------------------
# Training loss: 0.059248
# Validation loss: 0.058839
#
# Epoch 2490
# -------------------------------
# Training loss: 0.060188
# Validation loss: 0.059404
#
# Epoch 2491
# -------------------------------
# Training loss: 0.059807
# Validation loss: 0.063999
#
# Epoch 2492
# -------------------------------
# Training loss: 0.059873
# Validation loss: 0.058179
#
# Epoch 2493
# -------------------------------
# Training loss: 0.060227
# Validation loss: 0.060177
#
# Epoch 2494
# -------------------------------
# Training loss: 0.060145
# Validation loss: 0.061725
#
# Epoch 2495
# -------------------------------
# Training loss: 0.059662
# Validation loss: 0.058867
#
# Epoch 2496
# -------------------------------
# Training loss: 0.059072
# Validation loss: 0.060813
#
# Epoch 2497
# -------------------------------
# Training loss: 0.060799
# Validation loss: 0.059553
#
# Epoch 2498
# -------------------------------
# Training loss: 0.059262
# Validation loss: 0.057972
#
# Epoch 2499
# -------------------------------
# Training loss: 0.059269
# Validation loss: 0.062463
#
# Epoch 2500
# -------------------------------
# Training loss: 0.059065
# Validation loss: 0.060748
#
# Done!

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses)+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('BCE Loss')
#plt.yscale('log')
plt.legend()

# %%
# Now test the pretrained model
test_pred = mytools.test_clas(test_loader, final_classifier, device)
test_pred=torch.sigmoid(torch.tensor(test_pred)).numpy()


fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test, test_pred, pos_label=1)
auc_test = sklearn.metrics.auc(fpr, tpr)
print(f'Test AUROC: {auc_test:0.4f}')

plt.plot(fpr, tpr, label=f'Test AUROC: {auc_test:0.4f}')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
# Out:
# Test AUROC: 0.9960

# %%
# Store the pretrained classifier labels
df_test["Class_pre"] = test_pred

# Save the pretrained classifier model
torch.save(final_classifier.state_dict(), "/Users/mghrear/data/ML_data/2019_pass2/models/pretrained_classifier_2019_pass2_run"+str(run)+"_unscaled.pt")

# %% [markdown]
# # Setup the adversary model

# %% [markdown]
# ## Initialize model, objective function, and optimizer

# %%
adv = mytools.Adversary(n_classes=Num_classes).to(device)
criterion_adv = nn.CrossEntropyLoss(reduction='none')  # returns loss per sample so we can weight it
opt_adv = torch.optim.Adam(adv.parameters(), lr=1e-5)
scheduler_adv = torch.optim.lr_scheduler.ExponentialLR(opt_adv, gamma=0.999)

# %% [markdown]
# ## Setup dataloaders

# %%
# Convert to tensor dataset and dataloader

# the structure is: feature, adversary label, weight
# The wight is 1 for tritrig and wab, and 0 for phiKK, to prevent the adversary from learning on phiKK events

train_adv_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_train), (torch.from_numpy(y_train.to_numpy().astype(np.float32))==0).float())
train_adv_loader = DataLoader(train_adv_dataset, batch_size=bsize, shuffle=True)

val_adv_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_val), (torch.from_numpy(y_val.to_numpy().astype(np.float32))==0).float() )
val_adv_loader = DataLoader(val_adv_dataset, batch_size=bsize, shuffle=True)

# Weights are not relavent for testing
test_adv_dataset = TensorDataset(torch.from_numpy(X_test.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_test))
test_adv_loader = DataLoader(test_adv_dataset, batch_size=bsize, shuffle=True)

# %% [markdown]
# ## Pre-train the adversary leaving classifier weights fixed

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 6

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 100
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train_adv(train_adv_loader, final_classifier, adv, criterion_adv, opt_adv, scheduler_adv, device))
    Validation_losses = np.append(Validation_losses, mytools.validate_adv(val_adv_loader, final_classifier, adv, criterion_adv, device))
    
    # Keep a running copy of the model with the lowest loss
    if Validation_losses[-1] == np.min(Validation_losses):
        final_adv = copy.deepcopy(adv)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Training loss: 1.632678
# Validation loss: 1.610459
#
# Epoch 2
# -------------------------------
# Training loss: 1.622605
# Validation loss: 1.616407
#
# Epoch 3
# -------------------------------
# Training loss: 1.615806
# Validation loss: 1.616528
#
# Epoch 4
# -------------------------------
# Training loss: 1.611928
# Validation loss: 1.608406
#
# Epoch 5
# -------------------------------
# Training loss: 1.609442
# Validation loss: 1.608316
#
# Epoch 6
# -------------------------------
# Training loss: 1.608022
# Validation loss: 1.605809
#
# Epoch 7
# -------------------------------
# Training loss: 1.606988
# Validation loss: 1.605172
#
# Epoch 8
# -------------------------------
# Training loss: 1.606323
# Validation loss: 1.605375
#
# Epoch 9
# -------------------------------
# Training loss: 1.605966
# Validation loss: 1.604774
#
# Epoch 10
# -------------------------------
# Training loss: 1.605325
# Validation loss: 1.604389
#
# Epoch 11
# -------------------------------
# Training loss: 1.604904
# Validation loss: 1.603851
#
# Epoch 12
# -------------------------------
# Training loss: 1.604636
# Validation loss: 1.601703
#
# Epoch 13
# -------------------------------
# Training loss: 1.604462
# Validation loss: 1.602693
#
# Epoch 14
# -------------------------------
# Training loss: 1.604298
# Validation loss: 1.601149
#
# Epoch 15
# -------------------------------
# Training loss: 1.604174
# Validation loss: 1.602951
#
# Epoch 16
# -------------------------------
# Training loss: 1.603909
# Validation loss: 1.603680
#
# Epoch 17
# -------------------------------
# Training loss: 1.603750
# Validation loss: 1.602857
#
# Epoch 18
# -------------------------------
# Training loss: 1.603737
# Validation loss: 1.603875
#
# Epoch 19
# -------------------------------
# Training loss: 1.603429
# Validation loss: 1.600078
#
# Epoch 20
# -------------------------------
# Training loss: 1.603145
# Validation loss: 1.602934
#
# Epoch 21
# -------------------------------
# Training loss: 1.603269
# Validation loss: 1.604009
#
# Epoch 22
# -------------------------------
# Training loss: 1.603058
# Validation loss: 1.601696
#
# Epoch 23
# -------------------------------
# Training loss: 1.602989
# Validation loss: 1.602012
#
# Epoch 24
# -------------------------------
# Training loss: 1.602836
# Validation loss: 1.602004
#
# Epoch 25
# -------------------------------
# Training loss: 1.602867
# Validation loss: 1.603358
#
# Epoch 26
# -------------------------------
# Training loss: 1.602640
# Validation loss: 1.601965
#
# Epoch 27
# -------------------------------
# Training loss: 1.602833
# Validation loss: 1.602765
#
# Epoch 28
# -------------------------------
# Training loss: 1.602363
# Validation loss: 1.601698
#
# Epoch 29
# -------------------------------
# Training loss: 1.602483
# Validation loss: 1.602406
#
# Epoch 30
# -------------------------------
# Training loss: 1.602523
# Validation loss: 1.604613
#
# Epoch 31
# -------------------------------
# Training loss: 1.602323
# Validation loss: 1.600902
#
# Epoch 32
# -------------------------------
# Training loss: 1.602199
# Validation loss: 1.601231
#
# Epoch 33
# -------------------------------
# Training loss: 1.602271
# Validation loss: 1.602710
#
# Epoch 34
# -------------------------------
# Training loss: 1.602432
# Validation loss: 1.603557
#
# Epoch 35
# -------------------------------
# Training loss: 1.602257
# Validation loss: 1.600087
#
# Epoch 36
# -------------------------------
# Training loss: 1.602270
# Validation loss: 1.600062
#
# Epoch 37
# -------------------------------
# Training loss: 1.602050
# Validation loss: 1.601865
#
# Epoch 38
# -------------------------------
# Training loss: 1.602081
# Validation loss: 1.601721
#
# Epoch 39
# -------------------------------
# Training loss: 1.602074
# Validation loss: 1.601899
#
# Epoch 40
# -------------------------------
# Training loss: 1.601757
# Validation loss: 1.602085
#
# Epoch 41
# -------------------------------
# Training loss: 1.601868
# Validation loss: 1.602477
#
# Epoch 42
# -------------------------------
# Training loss: 1.601877
# Validation loss: 1.601296
#
# Epoch 43
# -------------------------------
# Training loss: 1.601809
# Validation loss: 1.599147
#
# Epoch 44
# -------------------------------
# Training loss: 1.601858
# Validation loss: 1.602030
#
# Epoch 45
# -------------------------------
# Training loss: 1.601897
# Validation loss: 1.601035
#
# Epoch 46
# -------------------------------
# Training loss: 1.601673
# Validation loss: 1.601358
#
# Epoch 47
# -------------------------------
# Training loss: 1.601672
# Validation loss: 1.602379
#
# Epoch 48
# -------------------------------
# Training loss: 1.601870
# Validation loss: 1.601029
#
# Epoch 49
# -------------------------------
# Training loss: 1.601869
# Validation loss: 1.599480
#
# Epoch 50
# -------------------------------
# Training loss: 1.601723
# Validation loss: 1.602877
#
# Epoch 51
# -------------------------------
# Training loss: 1.601503
# Validation loss: 1.603283
#
# Epoch 52
# -------------------------------
# Training loss: 1.601676
# Validation loss: 1.600918
#
# Epoch 53
# -------------------------------
# Training loss: 1.601307
# Validation loss: 1.602647
#
# Epoch 54
# -------------------------------
# Training loss: 1.601558
# Validation loss: 1.601738
#
# Epoch 55
# -------------------------------
# Training loss: 1.601662
# Validation loss: 1.601709
#
# Epoch 56
# -------------------------------
# Training loss: 1.601824
# Validation loss: 1.599885
#
# Epoch 57
# -------------------------------
# Training loss: 1.601563
# Validation loss: 1.600933
#
# Epoch 58
# -------------------------------
# Training loss: 1.601505
# Validation loss: 1.602078
#
# Epoch 59
# -------------------------------
# Training loss: 1.601262
# Validation loss: 1.602387
#
# Epoch 60
# -------------------------------
# Training loss: 1.601602
# Validation loss: 1.600207
#
# Epoch 61
# -------------------------------
# Training loss: 1.601516
# Validation loss: 1.601054
#
# Epoch 62
# -------------------------------
# Training loss: 1.601639
# Validation loss: 1.601498
#
# Epoch 63
# -------------------------------
# Training loss: 1.601547
# Validation loss: 1.601911
#
# Epoch 64
# -------------------------------
# Training loss: 1.601233
# Validation loss: 1.599950
#
# Epoch 65
# -------------------------------
# Training loss: 1.601502
# Validation loss: 1.601780
#
# Epoch 66
# -------------------------------
# Training loss: 1.601537
# Validation loss: 1.601514
#
# Epoch 67
# -------------------------------
# Training loss: 1.601590
# Validation loss: 1.602704
#
# Epoch 68
# -------------------------------
# Training loss: 1.601518
# Validation loss: 1.602625
#
# Epoch 69
# -------------------------------
# Training loss: 1.601353
# Validation loss: 1.601293
#
# Epoch 70
# -------------------------------
# Training loss: 1.601505
# Validation loss: 1.601265
#
# Epoch 71
# -------------------------------
# Training loss: 1.601353
# Validation loss: 1.599050
#
# Epoch 72
# -------------------------------
# Training loss: 1.601407
# Validation loss: 1.601153
#
# Epoch 73
# -------------------------------
# Training loss: 1.601400
# Validation loss: 1.601490
#
# Epoch 74
# -------------------------------
# Training loss: 1.601138
# Validation loss: 1.600405
#
# Epoch 75
# -------------------------------
# Training loss: 1.601311
# Validation loss: 1.598966
#
# Epoch 76
# -------------------------------
# Training loss: 1.601516
# Validation loss: 1.602500
#
# Epoch 77
# -------------------------------
# Training loss: 1.601197
# Validation loss: 1.602130
#
# Epoch 78
# -------------------------------
# Training loss: 1.601284
# Validation loss: 1.602484
#
# Epoch 79
# -------------------------------
# Training loss: 1.601207
# Validation loss: 1.601573
#
# Epoch 80
# -------------------------------
# Training loss: 1.601298
# Validation loss: 1.601570
#
# Epoch 81
# -------------------------------
# Training loss: 1.601028
# Validation loss: 1.600502
#
# Epoch 82
# -------------------------------
# Training loss: 1.601206
# Validation loss: 1.599194
#
# Epoch 83
# -------------------------------
# Training loss: 1.601441
# Validation loss: 1.602117
#
# Epoch 84
# -------------------------------
# Training loss: 1.601553
# Validation loss: 1.598446
#
# Epoch 85
# -------------------------------
# Training loss: 1.601231
# Validation loss: 1.602479
#
# Epoch 86
# -------------------------------
# Training loss: 1.601397
# Validation loss: 1.599942
#
# Epoch 87
# -------------------------------
# Training loss: 1.601567
# Validation loss: 1.601111
#
# Epoch 88
# -------------------------------
# Training loss: 1.601274
# Validation loss: 1.599331
#
# Epoch 89
# -------------------------------
# Training loss: 1.601280
# Validation loss: 1.602504
#
# Epoch 90
# -------------------------------
# Training loss: 1.601213
# Validation loss: 1.602867
#
# Epoch 91
# -------------------------------
# Training loss: 1.601299
# Validation loss: 1.599741
#
# Epoch 92
# -------------------------------
# Training loss: 1.601550
# Validation loss: 1.600771
#
# Epoch 93
# -------------------------------
# Training loss: 1.601395
# Validation loss: 1.600302
#
# Epoch 94
# -------------------------------
# Training loss: 1.601237
# Validation loss: 1.601829
#
# Epoch 95
# -------------------------------
# Training loss: 1.601456
# Validation loss: 1.601316
#
# Epoch 96
# -------------------------------
# Training loss: 1.601323
# Validation loss: 1.600153
#
# Epoch 97
# -------------------------------
# Training loss: 1.601346
# Validation loss: 1.601529
#
# Epoch 98
# -------------------------------
# Training loss: 1.601297
# Validation loss: 1.602032
#
# Epoch 99
# -------------------------------
# Training loss: 1.601162
# Validation loss: 1.602310
#
# Epoch 100
# -------------------------------
# Training loss: 1.601181
# Validation loss: 1.601332
#
# Done!

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses)+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('BCE Loss')
plt.legend()

# %% [markdown]
# # Train full adverserial neural network

# %% [markdown]
# # Setup dataloaders

# %%
# the structure is: feature, classifier label, adversary label, weight
# The wight is 1 for tritrig and wab, and 0 for phiKK, to prevent the adversary from learning on phiKK events

train_full_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy().astype(np.float32))  , torch.from_numpy(y_train.to_numpy().astype(np.float32)).unsqueeze(1), torch.from_numpy(y_adv_train),  (torch.from_numpy(y_train.to_numpy().astype(np.float32))==0).float())
train_full_loader = DataLoader(train_full_dataset, batch_size=bsize, shuffle=True)

val_full_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy().astype(np.float32))  , torch.from_numpy(y_val.to_numpy().astype(np.float32)).unsqueeze(1),  torch.from_numpy(y_adv_val),  (torch.from_numpy(y_val.to_numpy().astype(np.float32))==0).float())
val_full_loader = DataLoader(val_full_dataset, batch_size=bsize, shuffle=True)

# %% [markdown]
# ## Define loss functions

# %%
BCE_loss = nn.BCEWithLogitsLoss()
CE_loss = nn.CrossEntropyLoss(reduction='none') # returns loss per sample so we can weight it

def full_loss(output_clas, output_adv, target_clas, target_adv, w, lambda_):

    loss1 = BCE_loss(output_clas, target_clas )  # classification loss
    sample_losses2 = CE_loss(output_adv, target_adv)  # adversarial losses, since we set reduction='none', this is now a vector of losses, one per sample in the batch

    # Weighted mean loss over non-zero weights
    nonzero = w > 0
    loss2 = (sample_losses2[nonzero] * w[nonzero]).sum() / w[nonzero].sum()

    loss = loss1 - lambda_*loss2

    return loss

# %% [markdown]
# ## Setup optimizers

# %%
optimizer_clas = optim.Adam(final_classifier.parameters(), lr=1e-7,betas=(0.5, 0.999))
optimizer_adv = optim.Adam(final_adv.parameters(), lr=1e-5,betas=(0.5, 0.999))

scheduler_clas = torch.optim.lr_scheduler.ExponentialLR(optimizer_clas, gamma=0.999)
scheduler_adv = torch.optim.lr_scheduler.ExponentialLR(optimizer_adv, gamma=0.999)

# %% [markdown]
# ## Adversarial training

# %%
Training_losses_clas = np.array([])
Training_losses_adv = np.array([])
Validation_losses_clas = np.array([])
Validation_losses_adv = np.array([])
diff_scores = np.array([])


epochs = 50
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")

    # Get validation losses
    E_clas_val_loss, E_adv_val_loss = mytools.validate_full(val_full_loader, final_classifier, final_adv, full_loss, lambda_, criterion_adv, device)
    Validation_losses_clas = np.append(Validation_losses_clas, E_clas_val_loss)
    Validation_losses_adv = np.append(Validation_losses_adv, E_adv_val_loss)

    # Train adversary and classifier
    E_clas_training_loss , E_adv_training_loss = mytools.train_full(train_full_loader, final_classifier, final_adv, full_loss, lambda_, criterion_adv, optimizer_clas, optimizer_adv, scheduler_clas, scheduler_adv, device)
    Training_losses_clas = np.append(Training_losses_clas, E_clas_training_loss)
    Training_losses_adv = np.append(Training_losses_adv, E_adv_training_loss)

    # Get the diff_score
    df_test["Class_adv"] = mytools.test_clas(test_loader, final_classifier, device)
    df_bkg = df_test.loc[ (df_test.type == 'tritrig') | (df_test.type == 'wab')]
    per = np.percentile(df_bkg['Class_adv'],99)
    df_cut = df_bkg[df_bkg['Class_adv']>per].reset_index(drop=True)
    x1 = 1000* df_bkg.InvM.values
    x2 = 1000*df_cut.InvM.values
    diff_scores = np.append(diff_scores, mytools.get_diff_score(x1,x2) )

    # Keep a running copy of the model with the lowest loss
    if diff_scores[-1] == np.min(diff_scores):
        final_clas_adv = copy.deepcopy(final_classifier)
        final_adv_adv = copy.deepcopy(final_adv)

            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Classifier validation loss: -160.006031
# Adversary validation loss: 1.600669
# Classifier training loss: -160.479505
# Adversary training loss: 1.605788
# Epoch 2
# -------------------------------
# Classifier validation loss: -160.321397
# Adversary validation loss: 1.603854
# Classifier training loss: -160.824570
# Adversary training loss: 1.609613
# Epoch 3
# -------------------------------
# Classifier validation loss: -161.612076
# Adversary validation loss: 1.616833
# Classifier training loss: -161.765328
# Adversary training loss: 1.618937
# Epoch 4
# -------------------------------
# Classifier validation loss: -162.035423
# Adversary validation loss: 1.621140
# Classifier training loss: -161.425605
# Adversary training loss: 1.615170
# Epoch 5
# -------------------------------
# Classifier validation loss: -160.847282
# Adversary validation loss: 1.609330
# Classifier training loss: -160.754242
# Adversary training loss: 1.608436
# Epoch 6
# -------------------------------
# Classifier validation loss: -160.387942
# Adversary validation loss: 1.604729
# Classifier training loss: -160.660051
# Adversary training loss: 1.607552
# Epoch 7
# -------------------------------
# Classifier validation loss: -160.482837
# Adversary validation loss: 1.605566
# Classifier training loss: -160.890384
# Adversary training loss: 1.609865
# Epoch 8
# -------------------------------
# Classifier validation loss: -160.848228
# Adversary validation loss: 1.609234
# Classifier training loss: -161.005164
# Adversary training loss: 1.610840
# Epoch 9
# -------------------------------
# Classifier validation loss: -160.972400
# Adversary validation loss: 1.610417
# Classifier training loss: -160.959138
# Adversary training loss: 1.610351
# Epoch 10
# -------------------------------
# Classifier validation loss: -161.000055
# Adversary validation loss: 1.610731
# Classifier training loss: -160.970222
# Adversary training loss: 1.610469
# Epoch 11
# -------------------------------
# Classifier validation loss: -160.978442
# Adversary validation loss: 1.610547
# Classifier training loss: -160.900797
# Adversary training loss: 1.609777
# Epoch 12
# -------------------------------
# Classifier validation loss: -160.882231
# Adversary validation loss: 1.609558
# Classifier training loss: -160.886010
# Adversary training loss: 1.609668
# Epoch 13
# -------------------------------
# Classifier validation loss: -160.894800
# Adversary validation loss: 1.609785
# Classifier training loss: -160.872179
# Adversary training loss: 1.609494
# Epoch 14
# -------------------------------
# Classifier validation loss: -160.937590
# Adversary validation loss: 1.610227
# Classifier training loss: -160.853816
# Adversary training loss: 1.609296
# Epoch 15
# -------------------------------
# Classifier validation loss: -160.771957
# Adversary validation loss: 1.608508
# Classifier training loss: -160.899486
# Adversary training loss: 1.609759
# Epoch 16
# -------------------------------
# Classifier validation loss: -160.890736
# Adversary validation loss: 1.609665
# Classifier training loss: -160.823334
# Adversary training loss: 1.608984
# Epoch 17
# -------------------------------
# Classifier validation loss: -160.903399
# Adversary validation loss: 1.609808
# Classifier training loss: -160.854263
# Adversary training loss: 1.609308
# Epoch 18
# -------------------------------
# Classifier validation loss: -160.879854
# Adversary validation loss: 1.609517
# Classifier training loss: -160.853962
# Adversary training loss: 1.609296
# Epoch 19
# -------------------------------
# Classifier validation loss: -160.758488
# Adversary validation loss: 1.608286
# Classifier training loss: -160.848169
# Adversary training loss: 1.609220
# Epoch 20
# -------------------------------
# Classifier validation loss: -160.715647
# Adversary validation loss: 1.607879
# Classifier training loss: -160.860236
# Adversary training loss: 1.609351
# Epoch 21
# -------------------------------
# Classifier validation loss: -160.748713
# Adversary validation loss: 1.608186
# Classifier training loss: -160.858249
# Adversary training loss: 1.609341
# Epoch 22
# -------------------------------
# Classifier validation loss: -160.693659
# Adversary validation loss: 1.607665
# Classifier training loss: -160.860121
# Adversary training loss: 1.609373
# Epoch 23
# -------------------------------
# Classifier validation loss: -160.811181
# Adversary validation loss: 1.608812
# Classifier training loss: -160.855826
# Adversary training loss: 1.609299
# Epoch 24
# -------------------------------
# Classifier validation loss: -160.794521
# Adversary validation loss: 1.608627
# Classifier training loss: -160.834014
# Adversary training loss: 1.609089
# Epoch 25
# -------------------------------
# Classifier validation loss: -160.800665
# Adversary validation loss: 1.608733
# Classifier training loss: -160.874111
# Adversary training loss: 1.609502
# Epoch 26
# -------------------------------
# Classifier validation loss: -160.863478
# Adversary validation loss: 1.609318
# Classifier training loss: -160.832746
# Adversary training loss: 1.609068
# Epoch 27
# -------------------------------
# Classifier validation loss: -160.804940
# Adversary validation loss: 1.608762
# Classifier training loss: -160.846742
# Adversary training loss: 1.609234
# Epoch 28
# -------------------------------
# Classifier validation loss: -160.839951
# Adversary validation loss: 1.609228
# Classifier training loss: -160.872833
# Adversary training loss: 1.609475
# Epoch 29
# -------------------------------
# Classifier validation loss: -160.768406
# Adversary validation loss: 1.608387
# Classifier training loss: -160.856497
# Adversary training loss: 1.609305
# Epoch 30
# -------------------------------
# Classifier validation loss: -160.895484
# Adversary validation loss: 1.609701
# Classifier training loss: -160.855459
# Adversary training loss: 1.609303
# Epoch 31
# -------------------------------
# Classifier validation loss: -160.761515
# Adversary validation loss: 1.608291
# Classifier training loss: -160.842810
# Adversary training loss: 1.609169
# Epoch 32
# -------------------------------
# Classifier validation loss: -160.865136
# Adversary validation loss: 1.609367
# Classifier training loss: -160.788479
# Adversary training loss: 1.608615
# Epoch 33
# -------------------------------
# Classifier validation loss: -160.784404
# Adversary validation loss: 1.608557
# Classifier training loss: -160.858488
# Adversary training loss: 1.609328
# Epoch 34
# -------------------------------
# Classifier validation loss: -160.831322
# Adversary validation loss: 1.609024
# Classifier training loss: -160.849686
# Adversary training loss: 1.609258
# Epoch 35
# -------------------------------
# Classifier validation loss: -160.967120
# Adversary validation loss: 1.610495
# Classifier training loss: -160.849098
# Adversary training loss: 1.609250
# Epoch 36
# -------------------------------
# Classifier validation loss: -160.820131
# Adversary validation loss: 1.608921
# Classifier training loss: -160.839163
# Adversary training loss: 1.609139
# Epoch 37
# -------------------------------
# Classifier validation loss: -160.852961
# Adversary validation loss: 1.609287
# Classifier training loss: -160.843145
# Adversary training loss: 1.609193
# Epoch 38
# -------------------------------
# Classifier validation loss: -160.963869
# Adversary validation loss: 1.610341
# Classifier training loss: -160.822138
# Adversary training loss: 1.609014
# Epoch 39
# -------------------------------
# Classifier validation loss: -160.937035
# Adversary validation loss: 1.610173
# Classifier training loss: -160.877061
# Adversary training loss: 1.609535
# Epoch 40
# -------------------------------
# Classifier validation loss: -160.847574
# Adversary validation loss: 1.609206
# Classifier training loss: -160.865204
# Adversary training loss: 1.609416
# Epoch 41
# -------------------------------
# Classifier validation loss: -160.834860
# Adversary validation loss: 1.609057
# Classifier training loss: -160.835989
# Adversary training loss: 1.609115
# Epoch 42
# -------------------------------
# Classifier validation loss: -160.699389
# Adversary validation loss: 1.607708
# Classifier training loss: -160.837119
# Adversary training loss: 1.609101
# Epoch 43
# -------------------------------
# Classifier validation loss: -160.785183
# Adversary validation loss: 1.608548
# Classifier training loss: -160.856362
# Adversary training loss: 1.609306
# Epoch 44
# -------------------------------
# Classifier validation loss: -160.850118
# Adversary validation loss: 1.609205
# Classifier training loss: -160.857560
# Adversary training loss: 1.609320
# Epoch 45
# -------------------------------
# Classifier validation loss: -160.831016
# Adversary validation loss: 1.608997
# Classifier training loss: -160.855514
# Adversary training loss: 1.609305
# Epoch 46
# -------------------------------
# Classifier validation loss: -160.994124
# Adversary validation loss: 1.610659
# Classifier training loss: -160.883389
# Adversary training loss: 1.609575
# Epoch 47
# -------------------------------
# Classifier validation loss: -160.889866
# Adversary validation loss: 1.609573
# Classifier training loss: -160.876374
# Adversary training loss: 1.609505
# Epoch 48
# -------------------------------
# Classifier validation loss: -160.958418
# Adversary validation loss: 1.610345
# Classifier training loss: -160.866138
# Adversary training loss: 1.609415
# Epoch 49
# -------------------------------
# Classifier validation loss: -160.974457
# Adversary validation loss: 1.610467
# Classifier training loss: -160.850332
# Adversary training loss: 1.609257
# Epoch 50
# -------------------------------
# Classifier validation loss: -160.949258
# Adversary validation loss: 1.610196
# Classifier training loss: -160.868487
# Adversary training loss: 1.609454
# Done!

# %%
fig, ax1 = plt.subplots()

best_epoch = np.argmin(diff_scores)+1



#ax1.plot(np.arange(len(Training_losses_adv))+1, Training_losses_adv, 'k-', label='Training Adversary')
ax1.plot(np.arange(len(Validation_losses_adv))+1, Validation_losses_adv, 'k-', label='Validation Adversary')

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Adversary Loss', color='k')
ax1.tick_params(axis='y', labelcolor='k')

ax2 = ax1.twinx()

#ax2.plot(np.arange(len(Training_losses_clas))+1, Training_losses_clas, 'r-', label='Training Classifier')
ax2.plot(np.arange(len(Validation_losses_clas))+1, Validation_losses_clas, 'r-', label='Validation Classifier')
ax2.axvline(best_epoch,label="Final model stopped here",color='k')

ax2.set_ylabel('Classifier Loss', color='r')
ax2.tick_params(axis='y', labelcolor='r')

# %% [markdown]
# ## Test adversarially trained models

# %%
# Now test the pretrained model
test_pred = mytools.test_clas(test_loader, final_clas_adv, device)
test_pred=torch.sigmoid(torch.tensor(test_pred)).numpy()


fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test, test_pred, pos_label=1)
auc_test = sklearn.metrics.auc(fpr, tpr)
print(f'Test AUROC: {auc_test:0.4f}')

plt.plot(fpr, tpr, label=f'Test AUROC: {auc_test:0.4f}')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
# Out:
# Test AUROC: 0.9933

# %%
df_test["Class_adv"] = test_pred
df_bkg = df_test.loc[ (df_test.type == 'tritrig') | (df_test.type == 'wab')]
per = np.percentile(df_bkg['Class_adv'],99)
df_cut = df_bkg[df_bkg['Class_adv']>per].reset_index(drop=True)
x_vals = 1000*df_cut.InvM

plt.figure()
plt.hist(1000*df_bkg.InvM, bins=np.arange(980,1250,1), histtype='step', label='No selection', density=True)
plt.hist(x_vals, bins=np.arange(980,1250,1), histtype='step', label= '99 percent selection', density=True)
plt.axvline(1019.461, color='k', linestyle='dashed', linewidth=1, label='PDG phi mass')
plt.xlabel('Invariant Mass [MeV]')
plt.ylabel('Normalized Counts')
plt.legend()

# %%
x1 = 1000* df_bkg.InvM.values
x2 = 1000*df_cut.InvM.values

N, edges = np.histogram(x1, bins=np.arange(980,1250,1), density=False)
M, edges = np.histogram(x2, bins=np.arange(980,1250,1), density=False)

N2 = N[(N > 0) & (M > 0)]
M2 = M[(N > 0) & (M > 0)]

diff_score = np.mean(np.abs(N2/np.sum(N)-M2/np.sum(M)) / (np.sqrt(N2)/np.sum(N) + np.sqrt(M2)/np.sum(M) ))

print(diff_score)

N = len(df_test.loc[ ((df_test.type == 'tritrig') | (df_test.type == 'wab')) & (df_test.InvM < (1.019 + 0.01) )  & (df_test.InvM > (1.019 - 0.01) ) & ( df_test['Class_adv']>per ) ] )
S = len(df_test.loc[ (df_test.type == 'phiKK') & (df_test.InvM < (1.019 + 0.01) )  & (df_test.InvM > (1.019 - 0.01) ) & ( df_test['Class_adv']>per )  ] )

print(S/N)
# Out:
# 0.7530705557853901
# 4.471544715447155

# %%
df_test["Class_adv"] = test_pred

# %%
# Save the adversarially trained models
torch.save(final_clas_adv.state_dict(), "/Users/mghrear/data/ML_data/2019_pass2/models/classifier_adv_2019_pass2_run"+str(run)+"_unscaled.pt")
torch.save(final_adv_adv.state_dict(), "/Users/mghrear/data/ML_data/2019_pass2/models/adversary_adv_2019_pass2_run"+str(run)+"_unscaled.pt")

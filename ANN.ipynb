# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import torch 
from torch import nn, optim
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import sklearn
from sklearn.model_selection import train_test_split
import copy
import mytools


# Print and store device being used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cpu

# %% [markdown]
# # Define important parameters

# %%
# Number of class in invariant mass used by the adversary
Num_classes = 5
# Hyper-parameter for adversarial training of the classifier
lambda_ = 100.0

run = 1

# %% [markdown]
# # Load and setup the data

# %%
# Read tritrig, wab, phiKK, and data files
df_tritrig = pd.read_pickle('/Users/mghrear/data/ML_data/patch/2021_v9_pass5_TC_tritrig_limited.pk')
df_tritrig['PhiKK'] = 0.0
df_phiKK = pd.read_pickle('/Users/mghrear/data/ML_data/patch/2021_v9_pass5_TC_phiKK_limited.pk')
df_phiKK['PhiKK'] = 1.0
df_wab = pd.read_pickle('/Users/mghrear/data/ML_data/patch/2021_v9_pass5_TC_wab_limited.pk')
df_wab['PhiKK'] = 0.0 # Add label


print("tritrig: ", len(df_tritrig))
print("phiKK: ", len(df_phiKK))
print("wab: ", len(df_wab))
# Out:
# tritrig:  434371
# phiKK:  5291
# wab:  47413

# %%
# Make Training set with 20000 tritrig, 4000 phiKK, 4000 wab
tritrig_train = df_tritrig[0:20000]
wab_train = df_wab[0:3000]
phiKK_train = df_phiKK[0:3000]

# Combine and shuffle all training data
df_train = pd.concat([tritrig_train, phiKK_train, wab_train], ignore_index=True, sort=False)
df_train = df_train.sample(frac=1, random_state=42).reset_index(drop=True)

# Get edges in invariant mass classes for one-hot encoding
# To be used for adverserial labels
# The edges are chosen such that each bin has equal number of background events
one_hot_edges = mytools.get_one_hot_edges(mytools.get_InvM( pd.concat([df_tritrig, df_wab], ignore_index=True, sort=False) ), n_bins=Num_classes)

# Split the training data into training and validation sets
df_train, df_val = train_test_split(df_train, test_size=0.33, random_state=42)

# Make X and y for training and validation sets
# the adverserial network has its own labels
X_train = df_train.drop(columns=['PhiKK'])
y_train = df_train['PhiKK']
y_adv_train = mytools.get_adv_labels( mytools.get_InvM(df_train), one_hot_edges)
X_val = df_val.drop(columns=['PhiKK'])
y_val = df_val['PhiKK']
y_adv_val = mytools.get_adv_labels( mytools.get_InvM(df_val), one_hot_edges)

# Make testing set with remaining events
tritrig_test = df_tritrig[20000:]
tritrig_test['type']= 'tritrig'
wab_test = df_wab[3000:]
wab_test['type']= 'wab'
phiKK_test = df_phiKK[3000:]
phiKK_test['type']= 'phiKK'

df_test = pd.concat([tritrig_test, phiKK_test,wab_test], ignore_index=True, sort=False)
df_test = df_test.sample(frac=1, random_state=42).reset_index(drop=True) # Now shuffle the combined dataframe

X_test = df_test.drop(columns=['PhiKK','type'])
y_test = df_test['PhiKK']
y_adv_test = mytools.get_adv_labels( mytools.get_InvM(df_test), one_hot_edges)

df_test["InvM"] = mytools.get_InvM(df_test)
# Out:
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_13549/1157922432.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tritrig_test['type']= 'tritrig'
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_13549/1157922432.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wab_test['type']= 'wab'
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_13549/1157922432.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phiKK_test['type']= 'phiKK'

# %% [markdown]
# ## Setup dataloaders

# %%
bsize = 2000

# Convert to tensor dataset and dataloader
train_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy().astype(np.float32))  , torch.from_numpy(y_train.to_numpy().astype(np.float32)).unsqueeze(1)  )
train_loader = DataLoader(train_dataset, batch_size=bsize, shuffle=True)

val_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy().astype(np.float32))  , torch.from_numpy(y_val.to_numpy().astype(np.float32)).unsqueeze(1)  )
val_loader = DataLoader(val_dataset, batch_size=bsize, shuffle=True)

test_dataset = TensorDataset(torch.from_numpy(X_test.to_numpy().astype(np.float32)))
test_loader = DataLoader(test_dataset, batch_size=bsize, shuffle=False)

# %% [markdown]
# ## Initialize model, objective function, and optimizer

# %%
clas = mytools.Classifier(in_features=X_train.shape[1]).to(device)
criterion_clas = nn.BCEWithLogitsLoss()
optimizer_clas = optim.Adam(clas.parameters(), lr=1e-5)
scheduler_clas = torch.optim.lr_scheduler.ExponentialLR(optimizer_clas, gamma=0.9999)

# %% [markdown]
# ## Pre-train the classifier

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 10

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 2500
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train_clas(train_loader, clas, criterion_clas, optimizer_clas, scheduler_clas, device))
    Validation_losses = np.append(Validation_losses, mytools.validate_clas(val_loader, clas, criterion_clas, device))
    
    # Keep a running copy of the model with the lowest loss
    if Validation_losses[-1] == np.min(Validation_losses):
        final_classifier = copy.deepcopy(clas)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Training loss: 0.720202
# Validation loss: 0.657877
#
# Epoch 2
# -------------------------------
# Training loss: 0.693759
# Validation loss: 0.658623
#
# Epoch 3
# -------------------------------
# Training loss: 0.674907
# Validation loss: 0.671006
#
# Epoch 4
# -------------------------------
# Training loss: 0.663385
# Validation loss: 0.652560
#
# Epoch 5
# -------------------------------
# Training loss: 0.650453
# Validation loss: 0.626107
#
# Epoch 6
# -------------------------------
# Training loss: 0.638689
# Validation loss: 0.614672
#
# Epoch 7
# -------------------------------
# Training loss: 0.631944
# Validation loss: 0.616167
#
# Epoch 8
# -------------------------------
# Training loss: 0.629517
# Validation loss: 0.622850
#
# Epoch 9
# -------------------------------
# Training loss: 0.623020
# Validation loss: 0.626189
#
# Epoch 10
# -------------------------------
# Training loss: 0.616372
# Validation loss: 0.623218
#
# Epoch 11
# -------------------------------
# Training loss: 0.608981
# Validation loss: 0.611618
#
# Epoch 12
# -------------------------------
# Training loss: 0.605261
# Validation loss: 0.612053
#
# Epoch 13
# -------------------------------
# Training loss: 0.601300
# Validation loss: 0.610381
#
# Epoch 14
# -------------------------------
# Training loss: 0.596459
# Validation loss: 0.598880
#
# Epoch 15
# -------------------------------
# Training loss: 0.590466
# Validation loss: 0.599687
#
# Epoch 16
# -------------------------------
# Training loss: 0.585431
# Validation loss: 0.588635
#
# Epoch 17
# -------------------------------
# Training loss: 0.582397
# Validation loss: 0.591644
#
# Epoch 18
# -------------------------------
# Training loss: 0.577005
# Validation loss: 0.582052
#
# Epoch 19
# -------------------------------
# Training loss: 0.573204
# Validation loss: 0.577057
#
# Epoch 20
# -------------------------------
# Training loss: 0.573265
# Validation loss: 0.567043
#
# Epoch 21
# -------------------------------
# Training loss: 0.569147
# Validation loss: 0.561734
#
# Epoch 22
# -------------------------------
# Training loss: 0.562719
# Validation loss: 0.564788
#
# Epoch 23
# -------------------------------
# Training loss: 0.561400
# Validation loss: 0.561251
#
# Epoch 24
# -------------------------------
# Training loss: 0.558647
# Validation loss: 0.553567
#
# Epoch 25
# -------------------------------
# Training loss: 0.556507
# Validation loss: 0.545546
#
# Epoch 26
# -------------------------------
# Training loss: 0.550638
# Validation loss: 0.553265
#
# Epoch 27
# -------------------------------
# Training loss: 0.550644
# Validation loss: 0.548581
#
# Epoch 28
# -------------------------------
# Training loss: 0.546569
# Validation loss: 0.542463
#
# Epoch 29
# -------------------------------
# Training loss: 0.544672
# Validation loss: 0.545523
#
# Epoch 30
# -------------------------------
# Training loss: 0.541413
# Validation loss: 0.533526
#
# Epoch 31
# -------------------------------
# Training loss: 0.538336
# Validation loss: 0.540413
#
# Epoch 32
# -------------------------------
# Training loss: 0.542647
# Validation loss: 0.540035
#
# Epoch 33
# -------------------------------
# Training loss: 0.536733
# Validation loss: 0.532090
#
# Epoch 34
# -------------------------------
# Training loss: 0.531549
# Validation loss: 0.532699
#
# Epoch 35
# -------------------------------
# Training loss: 0.531153
# Validation loss: 0.533963
#
# Epoch 36
# -------------------------------
# Training loss: 0.529586
# Validation loss: 0.532290
#
# Epoch 37
# -------------------------------
# Training loss: 0.525206
# Validation loss: 0.523110
#
# Epoch 38
# -------------------------------
# Training loss: 0.527298
# Validation loss: 0.530238
#
# Epoch 39
# -------------------------------
# Training loss: 0.523467
# Validation loss: 0.520759
#
# Epoch 40
# -------------------------------
# Training loss: 0.521064
# Validation loss: 0.523398
#
# Epoch 41
# -------------------------------
# Training loss: 0.519610
# Validation loss: 0.524589
#
# Epoch 42
# -------------------------------
# Training loss: 0.517868
# Validation loss: 0.515538
#
# Epoch 43
# -------------------------------
# Training loss: 0.514348
# Validation loss: 0.516174
#
# Epoch 44
# -------------------------------
# Training loss: 0.513128
# Validation loss: 0.515225
#
# Epoch 45
# -------------------------------
# Training loss: 0.512551
# Validation loss: 0.516164
#
# Epoch 46
# -------------------------------
# Training loss: 0.511582
# Validation loss: 0.522094
#
# Epoch 47
# -------------------------------
# Training loss: 0.512443
# Validation loss: 0.506217
#
# Epoch 48
# -------------------------------
# Training loss: 0.511779
# Validation loss: 0.510911
#
# Epoch 49
# -------------------------------
# Training loss: 0.507476
# Validation loss: 0.515502
#
# Epoch 50
# -------------------------------
# Training loss: 0.504801
# Validation loss: 0.506817
#
# Epoch 51
# -------------------------------
# Training loss: 0.505835
# Validation loss: 0.517320
#
# Epoch 52
# -------------------------------
# Training loss: 0.500777
# Validation loss: 0.497952
#
# Epoch 53
# -------------------------------
# Training loss: 0.499797
# Validation loss: 0.500563
#
# Epoch 54
# -------------------------------
# Training loss: 0.499948
# Validation loss: 0.498789
#
# Epoch 55
# -------------------------------
# Training loss: 0.497219
# Validation loss: 0.503108
#
# Epoch 56
# -------------------------------
# Training loss: 0.496022
# Validation loss: 0.497082
#
# Epoch 57
# -------------------------------
# Training loss: 0.496535
# Validation loss: 0.499620
#
# Epoch 58
# -------------------------------
# Training loss: 0.493010
# Validation loss: 0.508218
#
# Epoch 59
# -------------------------------
# Training loss: 0.489451
# Validation loss: 0.492374
#
# Epoch 60
# -------------------------------
# Training loss: 0.492324
# Validation loss: 0.496115
#
# Epoch 61
# -------------------------------
# Training loss: 0.489779
# Validation loss: 0.488918
#
# Epoch 62
# -------------------------------
# Training loss: 0.490230
# Validation loss: 0.492705
#
# Epoch 63
# -------------------------------
# Training loss: 0.490155
# Validation loss: 0.487370
#
# Epoch 64
# -------------------------------
# Training loss: 0.489450
# Validation loss: 0.492819
#
# Epoch 65
# -------------------------------
# Training loss: 0.484885
# Validation loss: 0.487748
#
# Epoch 66
# -------------------------------
# Training loss: 0.482019
# Validation loss: 0.482043
#
# Epoch 67
# -------------------------------
# Training loss: 0.483829
# Validation loss: 0.490182
#
# Epoch 68
# -------------------------------
# Training loss: 0.482651
# Validation loss: 0.480405
#
# Epoch 69
# -------------------------------
# Training loss: 0.478938
# Validation loss: 0.492818
#
# Epoch 70
# -------------------------------
# Training loss: 0.477632
# Validation loss: 0.485710
#
# Epoch 71
# -------------------------------
# Training loss: 0.476408
# Validation loss: 0.483206
#
# Epoch 72
# -------------------------------
# Training loss: 0.474020
# Validation loss: 0.477124
#
# Epoch 73
# -------------------------------
# Training loss: 0.473765
# Validation loss: 0.477680
#
# Epoch 74
# -------------------------------
# Training loss: 0.473531
# Validation loss: 0.477217
#
# Epoch 75
# -------------------------------
# Training loss: 0.470435
# Validation loss: 0.476754
#
# Epoch 76
# -------------------------------
# Training loss: 0.474623
# Validation loss: 0.469789
#
# Epoch 77
# -------------------------------
# Training loss: 0.476068
# Validation loss: 0.472706
#
# Epoch 78
# -------------------------------
# Training loss: 0.470678
# Validation loss: 0.466144
#
# Epoch 79
# -------------------------------
# Training loss: 0.466723
# Validation loss: 0.470533
#
# Epoch 80
# -------------------------------
# Training loss: 0.465968
# Validation loss: 0.467191
#
# Epoch 81
# -------------------------------
# Training loss: 0.468026
# Validation loss: 0.469974
#
# Epoch 82
# -------------------------------
# Training loss: 0.467308
# Validation loss: 0.470930
#
# Epoch 83
# -------------------------------
# Training loss: 0.461488
# Validation loss: 0.467648
#
# Epoch 84
# -------------------------------
# Training loss: 0.464746
# Validation loss: 0.466267
#
# Epoch 85
# -------------------------------
# Training loss: 0.463941
# Validation loss: 0.459523
#
# Epoch 86
# -------------------------------
# Training loss: 0.460287
# Validation loss: 0.470944
#
# Epoch 87
# -------------------------------
# Training loss: 0.460656
# Validation loss: 0.466170
#
# Epoch 88
# -------------------------------
# Training loss: 0.457701
# Validation loss: 0.462996
#
# Epoch 89
# -------------------------------
# Training loss: 0.455891
# Validation loss: 0.458972
#
# Epoch 90
# -------------------------------
# Training loss: 0.453938
# Validation loss: 0.465312
#
# Epoch 91
# -------------------------------
# Training loss: 0.454209
# Validation loss: 0.454246
#
# Epoch 92
# -------------------------------
# Training loss: 0.453646
# Validation loss: 0.452119
#
# Epoch 93
# -------------------------------
# Training loss: 0.454392
# Validation loss: 0.455042
#
# Epoch 94
# -------------------------------
# Training loss: 0.454439
# Validation loss: 0.447797
#
# Epoch 95
# -------------------------------
# Training loss: 0.451224
# Validation loss: 0.458980
#
# Epoch 96
# -------------------------------
# Training loss: 0.449007
# Validation loss: 0.454794
#
# Epoch 97
# -------------------------------
# Training loss: 0.449998
# Validation loss: 0.451785
#
# Epoch 98
# -------------------------------
# Training loss: 0.445412
# Validation loss: 0.449599
#
# Epoch 99
# -------------------------------
# Training loss: 0.444254
# Validation loss: 0.456195
#
# Epoch 100
# -------------------------------
# Training loss: 0.446782
# Validation loss: 0.443784
#
# Epoch 101
# -------------------------------
# Training loss: 0.443843
# Validation loss: 0.453121
#
# Epoch 102
# -------------------------------
# Training loss: 0.450965
# Validation loss: 0.444362
#
# Epoch 103
# -------------------------------
# Training loss: 0.441903
# Validation loss: 0.448027
#
# Epoch 104
# -------------------------------
# Training loss: 0.445118
# Validation loss: 0.443627
#
# Epoch 105
# -------------------------------
# Training loss: 0.441001
# Validation loss: 0.442596
#
# Epoch 106
# -------------------------------
# Training loss: 0.443579
# Validation loss: 0.446683
#
# Epoch 107
# -------------------------------
# Training loss: 0.446603
# Validation loss: 0.441310
#
# Epoch 108
# -------------------------------
# Training loss: 0.441692
# Validation loss: 0.442812
#
# Epoch 109
# -------------------------------
# Training loss: 0.437892
# Validation loss: 0.443749
#
# Epoch 110
# -------------------------------
# Training loss: 0.438696
# Validation loss: 0.442102
#
# Epoch 111
# -------------------------------
# Training loss: 0.439426
# Validation loss: 0.434218
#
# Epoch 112
# -------------------------------
# Training loss: 0.434973
# Validation loss: 0.443393
#
# Epoch 113
# -------------------------------
# Training loss: 0.433017
# Validation loss: 0.444227
#
# Epoch 114
# -------------------------------
# Training loss: 0.432625
# Validation loss: 0.430929
#
# Epoch 115
# -------------------------------
# Training loss: 0.430759
# Validation loss: 0.436262
#
# Epoch 116
# -------------------------------
# Training loss: 0.432301
# Validation loss: 0.440968
#
# Epoch 117
# -------------------------------
# Training loss: 0.433164
# Validation loss: 0.435504
#
# Epoch 118
# -------------------------------
# Training loss: 0.432177
# Validation loss: 0.438466
#
# Epoch 119
# -------------------------------
# Training loss: 0.428759
# Validation loss: 0.436111
#
# Epoch 120
# -------------------------------
# Training loss: 0.427923
# Validation loss: 0.432366
#
# Epoch 121
# -------------------------------
# Training loss: 0.424549
# Validation loss: 0.437632
#
# Epoch 122
# -------------------------------
# Training loss: 0.427979
# Validation loss: 0.431891
#
# Epoch 123
# -------------------------------
# Training loss: 0.424939
# Validation loss: 0.428984
#
# Epoch 124
# -------------------------------
# Training loss: 0.426042
# Validation loss: 0.428445
#
# Epoch 125
# -------------------------------
# Training loss: 0.427082
# Validation loss: 0.428179
#
# Epoch 126
# -------------------------------
# Training loss: 0.423907
# Validation loss: 0.443675
#
# Epoch 127
# -------------------------------
# Training loss: 0.422934
# Validation loss: 0.426424
#
# Epoch 128
# -------------------------------
# Training loss: 0.427551
# Validation loss: 0.427211
#
# Epoch 129
# -------------------------------
# Training loss: 0.424965
# Validation loss: 0.424859
#
# Epoch 130
# -------------------------------
# Training loss: 0.423444
# Validation loss: 0.426997
#
# Epoch 131
# -------------------------------
# Training loss: 0.423676
# Validation loss: 0.428203
#
# Epoch 132
# -------------------------------
# Training loss: 0.422062
# Validation loss: 0.427071
#
# Epoch 133
# -------------------------------
# Training loss: 0.420006
# Validation loss: 0.424502
#
# Epoch 134
# -------------------------------
# Training loss: 0.421603
# Validation loss: 0.430542
#
# Epoch 135
# -------------------------------
# Training loss: 0.417726
# Validation loss: 0.420862
#
# Epoch 136
# -------------------------------
# Training loss: 0.418418
# Validation loss: 0.422500
#
# Epoch 137
# -------------------------------
# Training loss: 0.419514
# Validation loss: 0.424209
#
# Epoch 138
# -------------------------------
# Training loss: 0.417203
# Validation loss: 0.420957
#
# Epoch 139
# -------------------------------
# Training loss: 0.422595
# Validation loss: 0.426120
#
# Epoch 140
# -------------------------------
# Training loss: 0.415389
# Validation loss: 0.419016
#
# Epoch 141
# -------------------------------
# Training loss: 0.418082
# Validation loss: 0.419709
#
# Epoch 142
# -------------------------------
# Training loss: 0.414772
# Validation loss: 0.427725
#
# Epoch 143
# -------------------------------
# Training loss: 0.416666
# Validation loss: 0.422688
#
# Epoch 144
# -------------------------------
# Training loss: 0.411969
# Validation loss: 0.414840
#
# Epoch 145
# -------------------------------
# Training loss: 0.409686
# Validation loss: 0.415823
#
# Epoch 146
# -------------------------------
# Training loss: 0.411152
# Validation loss: 0.423087
#
# Epoch 147
# -------------------------------
# Training loss: 0.411126
# Validation loss: 0.416840
#
# Epoch 148
# -------------------------------
# Training loss: 0.411506
# Validation loss: 0.419306
#
# Epoch 149
# -------------------------------
# Training loss: 0.409452
# Validation loss: 0.414609
#
# Epoch 150
# -------------------------------
# Training loss: 0.408800
# Validation loss: 0.415692
#
# Epoch 151
# -------------------------------
# Training loss: 0.409335
# Validation loss: 0.416074
#
# Epoch 152
# -------------------------------
# Training loss: 0.405197
# Validation loss: 0.420062
#
# Epoch 153
# -------------------------------
# Training loss: 0.408300
# Validation loss: 0.416692
#
# Epoch 154
# -------------------------------
# Training loss: 0.407143
# Validation loss: 0.413868
#
# Epoch 155
# -------------------------------
# Training loss: 0.409068
# Validation loss: 0.408312
#
# Epoch 156
# -------------------------------
# Training loss: 0.407511
# Validation loss: 0.407051
#
# Epoch 157
# -------------------------------
# Training loss: 0.405465
# Validation loss: 0.422628
#
# Epoch 158
# -------------------------------
# Training loss: 0.404631
# Validation loss: 0.414010
#
# Epoch 159
# -------------------------------
# Training loss: 0.402228
# Validation loss: 0.413793
#
# Epoch 160
# -------------------------------
# Training loss: 0.405279
# Validation loss: 0.417293
#
# Epoch 161
# -------------------------------
# Training loss: 0.406226
# Validation loss: 0.409474
#
# Epoch 162
# -------------------------------
# Training loss: 0.404298
# Validation loss: 0.407437
#
# Epoch 163
# -------------------------------
# Training loss: 0.400907
# Validation loss: 0.406277
#
# Epoch 164
# -------------------------------
# Training loss: 0.402111
# Validation loss: 0.409303
#
# Epoch 165
# -------------------------------
# Training loss: 0.400067
# Validation loss: 0.413360
#
# Epoch 166
# -------------------------------
# Training loss: 0.400954
# Validation loss: 0.416865
#
# Epoch 167
# -------------------------------
# Training loss: 0.403252
# Validation loss: 0.404800
#
# Epoch 168
# -------------------------------
# Training loss: 0.402855
# Validation loss: 0.399685
#
# Epoch 169
# -------------------------------
# Training loss: 0.400075
# Validation loss: 0.406212
#
# Epoch 170
# -------------------------------
# Training loss: 0.402542
# Validation loss: 0.408824
#
# Epoch 171
# -------------------------------
# Training loss: 0.401019
# Validation loss: 0.400037
#
# Epoch 172
# -------------------------------
# Training loss: 0.396452
# Validation loss: 0.406996
#
# Epoch 173
# -------------------------------
# Training loss: 0.393581
# Validation loss: 0.407729
#
# Epoch 174
# -------------------------------
# Training loss: 0.401888
# Validation loss: 0.401417
#
# Epoch 175
# -------------------------------
# Training loss: 0.396636
# Validation loss: 0.399672
#
# Epoch 176
# -------------------------------
# Training loss: 0.396109
# Validation loss: 0.395549
#
# Epoch 177
# -------------------------------
# Training loss: 0.395350
# Validation loss: 0.404856
#
# Epoch 178
# -------------------------------
# Training loss: 0.396770
# Validation loss: 0.403135
#
# Epoch 179
# -------------------------------
# Training loss: 0.393583
# Validation loss: 0.409690
#
# Epoch 180
# -------------------------------
# Training loss: 0.393246
# Validation loss: 0.399427
#
# Epoch 181
# -------------------------------
# Training loss: 0.393273
# Validation loss: 0.397009
#
# Epoch 182
# -------------------------------
# Training loss: 0.391052
# Validation loss: 0.400348
#
# Epoch 183
# -------------------------------
# Training loss: 0.392140
# Validation loss: 0.402872
#
# Epoch 184
# -------------------------------
# Training loss: 0.393973
# Validation loss: 0.395721
#
# Epoch 185
# -------------------------------
# Training loss: 0.390442
# Validation loss: 0.399893
#
# Epoch 186
# -------------------------------
# Training loss: 0.390218
# Validation loss: 0.404019
#
# Epoch 187
# -------------------------------
# Training loss: 0.392289
# Validation loss: 0.398774
#
# Epoch 188
# -------------------------------
# Training loss: 0.389143
# Validation loss: 0.390827
#
# Epoch 189
# -------------------------------
# Training loss: 0.394664
# Validation loss: 0.395993
#
# Epoch 190
# -------------------------------
# Training loss: 0.390737
# Validation loss: 0.396198
#
# Epoch 191
# -------------------------------
# Training loss: 0.386739
# Validation loss: 0.400673
#
# Epoch 192
# -------------------------------
# Training loss: 0.389214
# Validation loss: 0.394044
#
# Epoch 193
# -------------------------------
# Training loss: 0.389056
# Validation loss: 0.402054
#
# Epoch 194
# -------------------------------
# Training loss: 0.391391
# Validation loss: 0.392894
#
# Epoch 195
# -------------------------------
# Training loss: 0.389107
# Validation loss: 0.392573
#
# Epoch 196
# -------------------------------
# Training loss: 0.389955
# Validation loss: 0.390456
#
# Epoch 197
# -------------------------------
# Training loss: 0.389136
# Validation loss: 0.391989
#
# Epoch 198
# -------------------------------
# Training loss: 0.385570
# Validation loss: 0.395140
#
# Epoch 199
# -------------------------------
# Training loss: 0.386663
# Validation loss: 0.396038
#
# Epoch 200
# -------------------------------
# Training loss: 0.387276
# Validation loss: 0.398467
#
# Epoch 201
# -------------------------------
# Training loss: 0.387789
# Validation loss: 0.394614
#
# Epoch 202
# -------------------------------
# Training loss: 0.381971
# Validation loss: 0.387855
#
# Epoch 203
# -------------------------------
# Training loss: 0.384987
# Validation loss: 0.390601
#
# Epoch 204
# -------------------------------
# Training loss: 0.383961
# Validation loss: 0.392698
#
# Epoch 205
# -------------------------------
# Training loss: 0.379590
# Validation loss: 0.393008
#
# Epoch 206
# -------------------------------
# Training loss: 0.380458
# Validation loss: 0.388826
#
# Epoch 207
# -------------------------------
# Training loss: 0.383753
# Validation loss: 0.387242
#
# Epoch 208
# -------------------------------
# Training loss: 0.379775
# Validation loss: 0.389719
#
# Epoch 209
# -------------------------------
# Training loss: 0.378937
# Validation loss: 0.386689
#
# Epoch 210
# -------------------------------
# Training loss: 0.377228
# Validation loss: 0.391171
#
# Epoch 211
# -------------------------------
# Training loss: 0.383333
# Validation loss: 0.384760
#
# Epoch 212
# -------------------------------
# Training loss: 0.379854
# Validation loss: 0.378715
#
# Epoch 213
# -------------------------------
# Training loss: 0.377719
# Validation loss: 0.394062
#
# Epoch 214
# -------------------------------
# Training loss: 0.380524
# Validation loss: 0.383845
#
# Epoch 215
# -------------------------------
# Training loss: 0.378196
# Validation loss: 0.391019
#
# Epoch 216
# -------------------------------
# Training loss: 0.378610
# Validation loss: 0.378863
#
# Epoch 217
# -------------------------------
# Training loss: 0.376487
# Validation loss: 0.388066
#
# Epoch 218
# -------------------------------
# Training loss: 0.376042
# Validation loss: 0.384350
#
# Epoch 219
# -------------------------------
# Training loss: 0.376126
# Validation loss: 0.387846
#
# Epoch 220
# -------------------------------
# Training loss: 0.374642
# Validation loss: 0.378858
#
# Epoch 221
# -------------------------------
# Training loss: 0.373448
# Validation loss: 0.381018
#
# Epoch 222
# -------------------------------
# Training loss: 0.376071
# Validation loss: 0.385182
#
# Epoch 223
# -------------------------------
# Training loss: 0.379744
# Validation loss: 0.383242
#
# Epoch 224
# -------------------------------
# Training loss: 0.372038
# Validation loss: 0.377438
#
# Epoch 225
# -------------------------------
# Training loss: 0.371377
# Validation loss: 0.381583
#
# Epoch 226
# -------------------------------
# Training loss: 0.378159
# Validation loss: 0.383201
#
# Epoch 227
# -------------------------------
# Training loss: 0.372643
# Validation loss: 0.375155
#
# Epoch 228
# -------------------------------
# Training loss: 0.371707
# Validation loss: 0.387670
#
# Epoch 229
# -------------------------------
# Training loss: 0.374630
# Validation loss: 0.378795
#
# Epoch 230
# -------------------------------
# Training loss: 0.375693
# Validation loss: 0.372442
#
# Epoch 231
# -------------------------------
# Training loss: 0.373324
# Validation loss: 0.377505
#
# Epoch 232
# -------------------------------
# Training loss: 0.370831
# Validation loss: 0.385298
#
# Epoch 233
# -------------------------------
# Training loss: 0.373309
# Validation loss: 0.374897
#
# Epoch 234
# -------------------------------
# Training loss: 0.368508
# Validation loss: 0.374442
#
# Epoch 235
# -------------------------------
# Training loss: 0.370834
# Validation loss: 0.374366
#
# Epoch 236
# -------------------------------
# Training loss: 0.371037
# Validation loss: 0.378063
#
# Epoch 237
# -------------------------------
# Training loss: 0.369505
# Validation loss: 0.379329
#
# Epoch 238
# -------------------------------
# Training loss: 0.370377
# Validation loss: 0.373103
#
# Epoch 239
# -------------------------------
# Training loss: 0.369881
# Validation loss: 0.376509
#
# Epoch 240
# -------------------------------
# Training loss: 0.366401
# Validation loss: 0.372559
#
# Epoch 241
# -------------------------------
# Training loss: 0.366498
# Validation loss: 0.377749
#
# Epoch 242
# -------------------------------
# Training loss: 0.368752
# Validation loss: 0.375093
#
# Epoch 243
# -------------------------------
# Training loss: 0.370674
# Validation loss: 0.369563
#
# Epoch 244
# -------------------------------
# Training loss: 0.367299
# Validation loss: 0.369520
#
# Epoch 245
# -------------------------------
# Training loss: 0.369902
# Validation loss: 0.372005
#
# Epoch 246
# -------------------------------
# Training loss: 0.365888
# Validation loss: 0.377544
#
# Epoch 247
# -------------------------------
# Training loss: 0.365638
# Validation loss: 0.382718
#
# Epoch 248
# -------------------------------
# Training loss: 0.364763
# Validation loss: 0.370846
#
# Epoch 249
# -------------------------------
# Training loss: 0.367715
# Validation loss: 0.376292
#
# Epoch 250
# -------------------------------
# Training loss: 0.370244
# Validation loss: 0.364313
#
# Epoch 251
# -------------------------------
# Training loss: 0.365963
# Validation loss: 0.368290
#
# Epoch 252
# -------------------------------
# Training loss: 0.365502
# Validation loss: 0.380575
#
# Epoch 253
# -------------------------------
# Training loss: 0.364023
# Validation loss: 0.370152
#
# Epoch 254
# -------------------------------
# Training loss: 0.366707
# Validation loss: 0.367644
#
# Epoch 255
# -------------------------------
# Training loss: 0.363527
# Validation loss: 0.366979
#
# Epoch 256
# -------------------------------
# Training loss: 0.363629
# Validation loss: 0.371978
#
# Epoch 257
# -------------------------------
# Training loss: 0.364098
# Validation loss: 0.366694
#
# Epoch 258
# -------------------------------
# Training loss: 0.360547
# Validation loss: 0.358749
#
# Epoch 259
# -------------------------------
# Training loss: 0.366436
# Validation loss: 0.368928
#
# Epoch 260
# -------------------------------
# Training loss: 0.360856
# Validation loss: 0.364992
#
# Epoch 261
# -------------------------------
# Training loss: 0.364212
# Validation loss: 0.367097
#
# Epoch 262
# -------------------------------
# Training loss: 0.365124
# Validation loss: 0.361460
#
# Epoch 263
# -------------------------------
# Training loss: 0.363385
# Validation loss: 0.371996
#
# Epoch 264
# -------------------------------
# Training loss: 0.365434
# Validation loss: 0.369630
#
# Epoch 265
# -------------------------------
# Training loss: 0.365955
# Validation loss: 0.365422
#
# Epoch 266
# -------------------------------
# Training loss: 0.361134
# Validation loss: 0.373710
#
# Epoch 267
# -------------------------------
# Training loss: 0.361904
# Validation loss: 0.365561
#
# Epoch 268
# -------------------------------
# Training loss: 0.358554
# Validation loss: 0.366608
#
# Epoch 269
# -------------------------------
# Training loss: 0.360989
# Validation loss: 0.367540
#
# Epoch 270
# -------------------------------
# Training loss: 0.358554
# Validation loss: 0.363961
#
# Epoch 271
# -------------------------------
# Training loss: 0.361216
# Validation loss: 0.372868
#
# Epoch 272
# -------------------------------
# Training loss: 0.359579
# Validation loss: 0.363187
#
# Epoch 273
# -------------------------------
# Training loss: 0.356828
# Validation loss: 0.364141
#
# Epoch 274
# -------------------------------
# Training loss: 0.361747
# Validation loss: 0.365736
#
# Epoch 275
# -------------------------------
# Training loss: 0.357940
# Validation loss: 0.357849
#
# Epoch 276
# -------------------------------
# Training loss: 0.357471
# Validation loss: 0.365200
#
# Epoch 277
# -------------------------------
# Training loss: 0.359731
# Validation loss: 0.364699
#
# Epoch 278
# -------------------------------
# Training loss: 0.356299
# Validation loss: 0.366621
#
# Epoch 279
# -------------------------------
# Training loss: 0.358452
# Validation loss: 0.358262
#
# Epoch 280
# -------------------------------
# Training loss: 0.358592
# Validation loss: 0.360810
#
# Epoch 281
# -------------------------------
# Training loss: 0.355810
# Validation loss: 0.359896
#
# Epoch 282
# -------------------------------
# Training loss: 0.354007
# Validation loss: 0.367960
#
# Epoch 283
# -------------------------------
# Training loss: 0.357731
# Validation loss: 0.356918
#
# Epoch 284
# -------------------------------
# Training loss: 0.359273
# Validation loss: 0.365463
#
# Epoch 285
# -------------------------------
# Training loss: 0.351814
# Validation loss: 0.364631
#
# Epoch 286
# -------------------------------
# Training loss: 0.353827
# Validation loss: 0.363587
#
# Epoch 287
# -------------------------------
# Training loss: 0.353675
# Validation loss: 0.362961
#
# Epoch 288
# -------------------------------
# Training loss: 0.352679
# Validation loss: 0.357342
#
# Epoch 289
# -------------------------------
# Training loss: 0.350778
# Validation loss: 0.358954
#
# Epoch 290
# -------------------------------
# Training loss: 0.350714
# Validation loss: 0.355945
#
# Epoch 291
# -------------------------------
# Training loss: 0.353037
# Validation loss: 0.361424
#
# Epoch 292
# -------------------------------
# Training loss: 0.353235
# Validation loss: 0.350263
#
# Epoch 293
# -------------------------------
# Training loss: 0.350398
# Validation loss: 0.360342
#
# Epoch 294
# -------------------------------
# Training loss: 0.350756
# Validation loss: 0.359346
#
# Epoch 295
# -------------------------------
# Training loss: 0.352608
# Validation loss: 0.353918
#
# Epoch 296
# -------------------------------
# Training loss: 0.351506
# Validation loss: 0.362624
#
# Epoch 297
# -------------------------------
# Training loss: 0.347912
# Validation loss: 0.367005
#
# Epoch 298
# -------------------------------
# Training loss: 0.349203
# Validation loss: 0.354053
#
# Epoch 299
# -------------------------------
# Training loss: 0.348378
# Validation loss: 0.356581
#
# Epoch 300
# -------------------------------
# Training loss: 0.349875
# Validation loss: 0.360396
#
# Epoch 301
# -------------------------------
# Training loss: 0.350355
# Validation loss: 0.348041
#
# Epoch 302
# -------------------------------
# Training loss: 0.353323
# Validation loss: 0.351350
#
# Epoch 303
# -------------------------------
# Training loss: 0.349917
# Validation loss: 0.349847
#
# Epoch 304
# -------------------------------
# Training loss: 0.350596
# Validation loss: 0.363395
#
# Epoch 305
# -------------------------------
# Training loss: 0.350424
# Validation loss: 0.362435
#
# Epoch 306
# -------------------------------
# Training loss: 0.347235
# Validation loss: 0.355658
#
# Epoch 307
# -------------------------------
# Training loss: 0.347529
# Validation loss: 0.352225
#
# Epoch 308
# -------------------------------
# Training loss: 0.345563
# Validation loss: 0.361133
#
# Epoch 309
# -------------------------------
# Training loss: 0.349970
# Validation loss: 0.361539
#
# Epoch 310
# -------------------------------
# Training loss: 0.347499
# Validation loss: 0.359719
#
# Epoch 311
# -------------------------------
# Training loss: 0.344151
# Validation loss: 0.348646
#
# Epoch 312
# -------------------------------
# Training loss: 0.346414
# Validation loss: 0.350926
#
# Epoch 313
# -------------------------------
# Training loss: 0.345878
# Validation loss: 0.351320
#
# Epoch 314
# -------------------------------
# Training loss: 0.343605
# Validation loss: 0.351618
#
# Epoch 315
# -------------------------------
# Training loss: 0.347607
# Validation loss: 0.358253
#
# Epoch 316
# -------------------------------
# Training loss: 0.345899
# Validation loss: 0.353122
#
# Epoch 317
# -------------------------------
# Training loss: 0.346309
# Validation loss: 0.348423
#
# Epoch 318
# -------------------------------
# Training loss: 0.345256
# Validation loss: 0.346536
#
# Epoch 319
# -------------------------------
# Training loss: 0.343492
# Validation loss: 0.355049
#
# Epoch 320
# -------------------------------
# Training loss: 0.343515
# Validation loss: 0.347748
#
# Epoch 321
# -------------------------------
# Training loss: 0.346626
# Validation loss: 0.352607
#
# Epoch 322
# -------------------------------
# Training loss: 0.341686
# Validation loss: 0.349929
#
# Epoch 323
# -------------------------------
# Training loss: 0.344563
# Validation loss: 0.359660
#
# Epoch 324
# -------------------------------
# Training loss: 0.342397
# Validation loss: 0.351162
#
# Epoch 325
# -------------------------------
# Training loss: 0.342732
# Validation loss: 0.361112
#
# Epoch 326
# -------------------------------
# Training loss: 0.345100
# Validation loss: 0.338785
#
# Epoch 327
# -------------------------------
# Training loss: 0.340257
# Validation loss: 0.349511
#
# Epoch 328
# -------------------------------
# Training loss: 0.340092
# Validation loss: 0.360588
#
# Epoch 329
# -------------------------------
# Training loss: 0.341048
# Validation loss: 0.355502
#
# Epoch 330
# -------------------------------
# Training loss: 0.342514
# Validation loss: 0.347874
#
# Epoch 331
# -------------------------------
# Training loss: 0.344697
# Validation loss: 0.351230
#
# Epoch 332
# -------------------------------
# Training loss: 0.341826
# Validation loss: 0.347630
#
# Epoch 333
# -------------------------------
# Training loss: 0.342759
# Validation loss: 0.353647
#
# Epoch 334
# -------------------------------
# Training loss: 0.339307
# Validation loss: 0.355051
#
# Epoch 335
# -------------------------------
# Training loss: 0.338740
# Validation loss: 0.346828
#
# Epoch 336
# -------------------------------
# Training loss: 0.339086
# Validation loss: 0.345428
#
# Epoch 337
# -------------------------------
# Training loss: 0.339384
# Validation loss: 0.348583
#
# Epoch 338
# -------------------------------
# Training loss: 0.341881
# Validation loss: 0.338089
#
# Epoch 339
# -------------------------------
# Training loss: 0.341280
# Validation loss: 0.344544
#
# Epoch 340
# -------------------------------
# Training loss: 0.337037
# Validation loss: 0.342316
#
# Epoch 341
# -------------------------------
# Training loss: 0.336300
# Validation loss: 0.345435
#
# Epoch 342
# -------------------------------
# Training loss: 0.335701
# Validation loss: 0.344682
#
# Epoch 343
# -------------------------------
# Training loss: 0.338436
# Validation loss: 0.346656
#
# Epoch 344
# -------------------------------
# Training loss: 0.336307
# Validation loss: 0.340461
#
# Epoch 345
# -------------------------------
# Training loss: 0.338782
# Validation loss: 0.340015
#
# Epoch 346
# -------------------------------
# Training loss: 0.335550
# Validation loss: 0.346773
#
# Epoch 347
# -------------------------------
# Training loss: 0.336747
# Validation loss: 0.351407
#
# Epoch 348
# -------------------------------
# Training loss: 0.337563
# Validation loss: 0.343452
#
# Epoch 349
# -------------------------------
# Training loss: 0.333870
# Validation loss: 0.341968
#
# Epoch 350
# -------------------------------
# Training loss: 0.336774
# Validation loss: 0.351407
#
# Epoch 351
# -------------------------------
# Training loss: 0.332338
# Validation loss: 0.349989
#
# Epoch 352
# -------------------------------
# Training loss: 0.335885
# Validation loss: 0.331938
#
# Epoch 353
# -------------------------------
# Training loss: 0.334082
# Validation loss: 0.337937
#
# Epoch 354
# -------------------------------
# Training loss: 0.334609
# Validation loss: 0.348102
#
# Epoch 355
# -------------------------------
# Training loss: 0.334240
# Validation loss: 0.348422
#
# Epoch 356
# -------------------------------
# Training loss: 0.335612
# Validation loss: 0.327878
#
# Epoch 357
# -------------------------------
# Training loss: 0.333915
# Validation loss: 0.344907
#
# Epoch 358
# -------------------------------
# Training loss: 0.333093
# Validation loss: 0.334462
#
# Epoch 359
# -------------------------------
# Training loss: 0.332965
# Validation loss: 0.343568
#
# Epoch 360
# -------------------------------
# Training loss: 0.332365
# Validation loss: 0.340703
#
# Epoch 361
# -------------------------------
# Training loss: 0.331658
# Validation loss: 0.339066
#
# Epoch 362
# -------------------------------
# Training loss: 0.336607
# Validation loss: 0.331877
#
# Epoch 363
# -------------------------------
# Training loss: 0.329941
# Validation loss: 0.333648
#
# Epoch 364
# -------------------------------
# Training loss: 0.331017
# Validation loss: 0.341138
#
# Epoch 365
# -------------------------------
# Training loss: 0.334804
# Validation loss: 0.334181
#
# Epoch 366
# -------------------------------
# Training loss: 0.328830
# Validation loss: 0.355932
#
# Epoch 367
# -------------------------------
# Training loss: 0.330405
# Validation loss: 0.339463
#
# Epoch 368
# -------------------------------
# Training loss: 0.334901
# Validation loss: 0.344457
#
# Epoch 369
# -------------------------------
# Training loss: 0.328437
# Validation loss: 0.340080
#
# Epoch 370
# -------------------------------
# Training loss: 0.327369
# Validation loss: 0.359106
#
# Epoch 371
# -------------------------------
# Training loss: 0.329567
# Validation loss: 0.338009
#
# Epoch 372
# -------------------------------
# Training loss: 0.330950
# Validation loss: 0.337496
#
# Epoch 373
# -------------------------------
# Training loss: 0.326337
# Validation loss: 0.337587
#
# Epoch 374
# -------------------------------
# Training loss: 0.333027
# Validation loss: 0.331176
#
# Epoch 375
# -------------------------------
# Training loss: 0.327824
# Validation loss: 0.332295
#
# Epoch 376
# -------------------------------
# Training loss: 0.328005
# Validation loss: 0.331410
#
# Epoch 377
# -------------------------------
# Training loss: 0.327900
# Validation loss: 0.324837
#
# Epoch 378
# -------------------------------
# Training loss: 0.325551
# Validation loss: 0.330160
#
# Epoch 379
# -------------------------------
# Training loss: 0.328170
# Validation loss: 0.344555
#
# Epoch 380
# -------------------------------
# Training loss: 0.328333
# Validation loss: 0.323231
#
# Epoch 381
# -------------------------------
# Training loss: 0.327647
# Validation loss: 0.335619
#
# Epoch 382
# -------------------------------
# Training loss: 0.325691
# Validation loss: 0.332143
#
# Epoch 383
# -------------------------------
# Training loss: 0.325280
# Validation loss: 0.333167
#
# Epoch 384
# -------------------------------
# Training loss: 0.331024
# Validation loss: 0.328866
#
# Epoch 385
# -------------------------------
# Training loss: 0.331838
# Validation loss: 0.321445
#
# Epoch 386
# -------------------------------
# Training loss: 0.328674
# Validation loss: 0.328458
#
# Epoch 387
# -------------------------------
# Training loss: 0.325458
# Validation loss: 0.350150
#
# Epoch 388
# -------------------------------
# Training loss: 0.325813
# Validation loss: 0.347603
#
# Epoch 389
# -------------------------------
# Training loss: 0.326554
# Validation loss: 0.336126
#
# Epoch 390
# -------------------------------
# Training loss: 0.325063
# Validation loss: 0.345771
#
# Epoch 391
# -------------------------------
# Training loss: 0.323264
# Validation loss: 0.325108
#
# Epoch 392
# -------------------------------
# Training loss: 0.323175
# Validation loss: 0.330031
#
# Epoch 393
# -------------------------------
# Training loss: 0.322915
# Validation loss: 0.338208
#
# Epoch 394
# -------------------------------
# Training loss: 0.322345
# Validation loss: 0.334105
#
# Epoch 395
# -------------------------------
# Training loss: 0.321815
# Validation loss: 0.319586
#
# Epoch 396
# -------------------------------
# Training loss: 0.325123
# Validation loss: 0.327801
#
# Epoch 397
# -------------------------------
# Training loss: 0.324027
# Validation loss: 0.323432
#
# Epoch 398
# -------------------------------
# Training loss: 0.329244
# Validation loss: 0.326142
#
# Epoch 399
# -------------------------------
# Training loss: 0.322963
# Validation loss: 0.338294
#
# Epoch 400
# -------------------------------
# Training loss: 0.321802
# Validation loss: 0.333192
#
# Epoch 401
# -------------------------------
# Training loss: 0.324227
# Validation loss: 0.335832
#
# Epoch 402
# -------------------------------
# Training loss: 0.322861
# Validation loss: 0.332052
#
# Epoch 403
# -------------------------------
# Training loss: 0.321550
# Validation loss: 0.329306
#
# Epoch 404
# -------------------------------
# Training loss: 0.321584
# Validation loss: 0.326029
#
# Epoch 405
# -------------------------------
# Training loss: 0.320183
# Validation loss: 0.331571
#
# Epoch 406
# -------------------------------
# Training loss: 0.318833
# Validation loss: 0.331449
#
# Epoch 407
# -------------------------------
# Training loss: 0.319521
# Validation loss: 0.318133
#
# Epoch 408
# -------------------------------
# Training loss: 0.321308
# Validation loss: 0.334892
#
# Epoch 409
# -------------------------------
# Training loss: 0.320120
# Validation loss: 0.326509
#
# Epoch 410
# -------------------------------
# Training loss: 0.320462
# Validation loss: 0.320328
#
# Epoch 411
# -------------------------------
# Training loss: 0.320502
# Validation loss: 0.331588
#
# Epoch 412
# -------------------------------
# Training loss: 0.318670
# Validation loss: 0.326809
#
# Epoch 413
# -------------------------------
# Training loss: 0.324058
# Validation loss: 0.324905
#
# Epoch 414
# -------------------------------
# Training loss: 0.319044
# Validation loss: 0.317533
#
# Epoch 415
# -------------------------------
# Training loss: 0.321704
# Validation loss: 0.331979
#
# Epoch 416
# -------------------------------
# Training loss: 0.318881
# Validation loss: 0.332133
#
# Epoch 417
# -------------------------------
# Training loss: 0.320978
# Validation loss: 0.324004
#
# Epoch 418
# -------------------------------
# Training loss: 0.324379
# Validation loss: 0.313791
#
# Epoch 419
# -------------------------------
# Training loss: 0.320237
# Validation loss: 0.339544
#
# Epoch 420
# -------------------------------
# Training loss: 0.319802
# Validation loss: 0.329830
#
# Epoch 421
# -------------------------------
# Training loss: 0.319216
# Validation loss: 0.324678
#
# Epoch 422
# -------------------------------
# Training loss: 0.315132
# Validation loss: 0.324829
#
# Epoch 423
# -------------------------------
# Training loss: 0.318794
# Validation loss: 0.337763
#
# Epoch 424
# -------------------------------
# Training loss: 0.316577
# Validation loss: 0.328608
#
# Epoch 425
# -------------------------------
# Training loss: 0.318711
# Validation loss: 0.322826
#
# Epoch 426
# -------------------------------
# Training loss: 0.317575
# Validation loss: 0.316535
#
# Epoch 427
# -------------------------------
# Training loss: 0.315998
# Validation loss: 0.327125
#
# Epoch 428
# -------------------------------
# Training loss: 0.315917
# Validation loss: 0.326429
#
# Epoch 429
# -------------------------------
# Training loss: 0.315387
# Validation loss: 0.318585
#
# Epoch 430
# -------------------------------
# Training loss: 0.316688
# Validation loss: 0.327244
#
# Epoch 431
# -------------------------------
# Training loss: 0.315007
# Validation loss: 0.325497
#
# Epoch 432
# -------------------------------
# Training loss: 0.315952
# Validation loss: 0.320439
#
# Epoch 433
# -------------------------------
# Training loss: 0.313445
# Validation loss: 0.321914
#
# Epoch 434
# -------------------------------
# Training loss: 0.313203
# Validation loss: 0.325333
#
# Epoch 435
# -------------------------------
# Training loss: 0.314418
# Validation loss: 0.311902
#
# Epoch 436
# -------------------------------
# Training loss: 0.315384
# Validation loss: 0.321892
#
# Epoch 437
# -------------------------------
# Training loss: 0.311897
# Validation loss: 0.349593
#
# Epoch 438
# -------------------------------
# Training loss: 0.311231
# Validation loss: 0.318845
#
# Epoch 439
# -------------------------------
# Training loss: 0.311875
# Validation loss: 0.316522
#
# Epoch 440
# -------------------------------
# Training loss: 0.312667
# Validation loss: 0.315603
#
# Epoch 441
# -------------------------------
# Training loss: 0.316488
# Validation loss: 0.334038
#
# Epoch 442
# -------------------------------
# Training loss: 0.315935
# Validation loss: 0.335125
#
# Epoch 443
# -------------------------------
# Training loss: 0.315755
# Validation loss: 0.320414
#
# Epoch 444
# -------------------------------
# Training loss: 0.310763
# Validation loss: 0.317077
#
# Epoch 445
# -------------------------------
# Training loss: 0.309715
# Validation loss: 0.333568
#
# Epoch 446
# -------------------------------
# Training loss: 0.309908
# Validation loss: 0.336557
#
# Epoch 447
# -------------------------------
# Training loss: 0.312683
# Validation loss: 0.316974
#
# Epoch 448
# -------------------------------
# Training loss: 0.310563
# Validation loss: 0.316714
#
# Epoch 449
# -------------------------------
# Training loss: 0.308425
# Validation loss: 0.324160
#
# Epoch 450
# -------------------------------
# Training loss: 0.309560
# Validation loss: 0.318901
#
# Epoch 451
# -------------------------------
# Training loss: 0.309747
# Validation loss: 0.309609
#
# Epoch 452
# -------------------------------
# Training loss: 0.310393
# Validation loss: 0.320449
#
# Epoch 453
# -------------------------------
# Training loss: 0.308170
# Validation loss: 0.329275
#
# Epoch 454
# -------------------------------
# Training loss: 0.310436
# Validation loss: 0.322587
#
# Epoch 455
# -------------------------------
# Training loss: 0.312920
# Validation loss: 0.321888
#
# Epoch 456
# -------------------------------
# Training loss: 0.310561
# Validation loss: 0.315452
#
# Epoch 457
# -------------------------------
# Training loss: 0.307450
# Validation loss: 0.310986
#
# Epoch 458
# -------------------------------
# Training loss: 0.312353
# Validation loss: 0.330201
#
# Epoch 459
# -------------------------------
# Training loss: 0.307460
# Validation loss: 0.317765
#
# Epoch 460
# -------------------------------
# Training loss: 0.306892
# Validation loss: 0.308271
#
# Epoch 461
# -------------------------------
# Training loss: 0.311143
# Validation loss: 0.302088
#
# Epoch 462
# -------------------------------
# Training loss: 0.307026
# Validation loss: 0.315279
#
# Epoch 463
# -------------------------------
# Training loss: 0.305133
# Validation loss: 0.317255
#
# Epoch 464
# -------------------------------
# Training loss: 0.311891
# Validation loss: 0.307002
#
# Epoch 465
# -------------------------------
# Training loss: 0.307348
# Validation loss: 0.326671
#
# Epoch 466
# -------------------------------
# Training loss: 0.304878
# Validation loss: 0.310851
#
# Epoch 467
# -------------------------------
# Training loss: 0.305468
# Validation loss: 0.307285
#
# Epoch 468
# -------------------------------
# Training loss: 0.305578
# Validation loss: 0.307262
#
# Epoch 469
# -------------------------------
# Training loss: 0.304826
# Validation loss: 0.341357
#
# Epoch 470
# -------------------------------
# Training loss: 0.307422
# Validation loss: 0.321239
#
# Epoch 471
# -------------------------------
# Training loss: 0.308820
# Validation loss: 0.322816
#
# Epoch 472
# -------------------------------
# Training loss: 0.307346
# Validation loss: 0.308816
#
# Epoch 473
# -------------------------------
# Training loss: 0.304772
# Validation loss: 0.311488
#
# Epoch 474
# -------------------------------
# Training loss: 0.307683
# Validation loss: 0.312606
#
# Epoch 475
# -------------------------------
# Training loss: 0.306882
# Validation loss: 0.309470
#
# Epoch 476
# -------------------------------
# Training loss: 0.306466
# Validation loss: 0.318710
#
# Epoch 477
# -------------------------------
# Training loss: 0.305985
# Validation loss: 0.327973
#
# Epoch 478
# -------------------------------
# Training loss: 0.302431
# Validation loss: 0.308938
#
# Epoch 479
# -------------------------------
# Training loss: 0.306151
# Validation loss: 0.309027
#
# Epoch 480
# -------------------------------
# Training loss: 0.302246
# Validation loss: 0.305621
#
# Epoch 481
# -------------------------------
# Training loss: 0.300880
# Validation loss: 0.329083
#
# Epoch 482
# -------------------------------
# Training loss: 0.307222
# Validation loss: 0.294567
#
# Epoch 483
# -------------------------------
# Training loss: 0.303137
# Validation loss: 0.312772
#
# Epoch 484
# -------------------------------
# Training loss: 0.301704
# Validation loss: 0.321916
#
# Epoch 485
# -------------------------------
# Training loss: 0.303892
# Validation loss: 0.324412
#
# Epoch 486
# -------------------------------
# Training loss: 0.302753
# Validation loss: 0.303565
#
# Epoch 487
# -------------------------------
# Training loss: 0.300445
# Validation loss: 0.306939
#
# Epoch 488
# -------------------------------
# Training loss: 0.302289
# Validation loss: 0.316320
#
# Epoch 489
# -------------------------------
# Training loss: 0.304448
# Validation loss: 0.296668
#
# Epoch 490
# -------------------------------
# Training loss: 0.302785
# Validation loss: 0.304616
#
# Epoch 491
# -------------------------------
# Training loss: 0.299066
# Validation loss: 0.312740
#
# Epoch 492
# -------------------------------
# Training loss: 0.298810
# Validation loss: 0.313291
#
# Epoch 493
# -------------------------------
# Training loss: 0.298821
# Validation loss: 0.331833
#
# Epoch 494
# -------------------------------
# Training loss: 0.301198
# Validation loss: 0.305857
#
# Epoch 495
# -------------------------------
# Training loss: 0.299769
# Validation loss: 0.303465
#
# Epoch 496
# -------------------------------
# Training loss: 0.297706
# Validation loss: 0.296035
#
# Epoch 497
# -------------------------------
# Training loss: 0.300824
# Validation loss: 0.303828
#
# Epoch 498
# -------------------------------
# Training loss: 0.300972
# Validation loss: 0.315696
#
# Epoch 499
# -------------------------------
# Training loss: 0.298360
# Validation loss: 0.301773
#
# Epoch 500
# -------------------------------
# Training loss: 0.299344
# Validation loss: 0.306109
#
# Epoch 501
# -------------------------------
# Training loss: 0.298893
# Validation loss: 0.348983
#
# Epoch 502
# -------------------------------
# Training loss: 0.296599
# Validation loss: 0.326847
#
# Epoch 503
# -------------------------------
# Training loss: 0.299077
# Validation loss: 0.294220
#
# Epoch 504
# -------------------------------
# Training loss: 0.298527
# Validation loss: 0.294436
#
# Epoch 505
# -------------------------------
# Training loss: 0.299717
# Validation loss: 0.302861
#
# Epoch 506
# -------------------------------
# Training loss: 0.297451
# Validation loss: 0.297549
#
# Epoch 507
# -------------------------------
# Training loss: 0.300096
# Validation loss: 0.337751
#
# Epoch 508
# -------------------------------
# Training loss: 0.297327
# Validation loss: 0.333199
#
# Epoch 509
# -------------------------------
# Training loss: 0.296175
# Validation loss: 0.327999
#
# Epoch 510
# -------------------------------
# Training loss: 0.300045
# Validation loss: 0.302092
#
# Epoch 511
# -------------------------------
# Training loss: 0.297685
# Validation loss: 0.294497
#
# Epoch 512
# -------------------------------
# Training loss: 0.294994
# ...
# Validation loss: 0.090274
#
# Epoch 2333
# -------------------------------
# Training loss: 0.081922
# Validation loss: 0.087061
#
# Epoch 2334
# -------------------------------
# Training loss: 0.082793
# Validation loss: 0.088731
#
# Epoch 2335
# -------------------------------
# Training loss: 0.079852
# Validation loss: 0.087298
#
# Epoch 2336
# -------------------------------
# Training loss: 0.084375
# Validation loss: 0.087893
#
# Epoch 2337
# -------------------------------
# Training loss: 0.082968
# Validation loss: 0.087867
#
# Epoch 2338
# -------------------------------
# Training loss: 0.083892
# Validation loss: 0.090339
#
# Epoch 2339
# -------------------------------
# Training loss: 0.080289
# Validation loss: 0.085775
#
# Epoch 2340
# -------------------------------
# Training loss: 0.080365
# Validation loss: 0.087364
#
# Epoch 2341
# -------------------------------
# Training loss: 0.084628
# Validation loss: 0.086782
#
# Epoch 2342
# -------------------------------
# Training loss: 0.084611
# Validation loss: 0.092948
#
# Epoch 2343
# -------------------------------
# Training loss: 0.081630
# Validation loss: 0.088241
#
# Epoch 2344
# -------------------------------
# Training loss: 0.080814
# Validation loss: 0.092807
#
# Epoch 2345
# -------------------------------
# Training loss: 0.083822
# Validation loss: 0.085385
#
# Epoch 2346
# -------------------------------
# Training loss: 0.082519
# Validation loss: 0.086966
#
# Epoch 2347
# -------------------------------
# Training loss: 0.082396
# Validation loss: 0.086284
#
# Epoch 2348
# -------------------------------
# Training loss: 0.084612
# Validation loss: 0.089618
#
# Epoch 2349
# -------------------------------
# Training loss: 0.080849
# Validation loss: 0.088280
#
# Epoch 2350
# -------------------------------
# Training loss: 0.083897
# Validation loss: 0.085631
#
# Epoch 2351
# -------------------------------
# Training loss: 0.082726
# Validation loss: 0.089695
#
# Epoch 2352
# -------------------------------
# Training loss: 0.079713
# Validation loss: 0.089371
#
# Epoch 2353
# -------------------------------
# Training loss: 0.079362
# Validation loss: 0.086364
#
# Epoch 2354
# -------------------------------
# Training loss: 0.084561
# Validation loss: 0.088391
#
# Epoch 2355
# -------------------------------
# Training loss: 0.081943
# Validation loss: 0.090646
#
# Epoch 2356
# -------------------------------
# Training loss: 0.081659
# Validation loss: 0.087565
#
# Epoch 2357
# -------------------------------
# Training loss: 0.082808
# Validation loss: 0.088350
#
# Epoch 2358
# -------------------------------
# Training loss: 0.080533
# Validation loss: 0.085276
#
# Epoch 2359
# -------------------------------
# Training loss: 0.082529
# Validation loss: 0.087744
#
# Epoch 2360
# -------------------------------
# Training loss: 0.081562
# Validation loss: 0.086670
#
# Epoch 2361
# -------------------------------
# Training loss: 0.080304
# Validation loss: 0.086619
#
# Epoch 2362
# -------------------------------
# Training loss: 0.080104
# Validation loss: 0.089167
#
# Epoch 2363
# -------------------------------
# Training loss: 0.085424
# Validation loss: 0.085683
#
# Epoch 2364
# -------------------------------
# Training loss: 0.080361
# Validation loss: 0.085267
#
# Epoch 2365
# -------------------------------
# Training loss: 0.083427
# Validation loss: 0.090834
#
# Epoch 2366
# -------------------------------
# Training loss: 0.083045
# Validation loss: 0.091317
#
# Epoch 2367
# -------------------------------
# Training loss: 0.078652
# Validation loss: 0.086940
#
# Epoch 2368
# -------------------------------
# Training loss: 0.087232
# Validation loss: 0.089829
#
# Epoch 2369
# -------------------------------
# Training loss: 0.080759
# Validation loss: 0.086297
#
# Epoch 2370
# -------------------------------
# Training loss: 0.080385
# Validation loss: 0.088683
#
# Epoch 2371
# -------------------------------
# Training loss: 0.079490
# Validation loss: 0.085821
#
# Epoch 2372
# -------------------------------
# Training loss: 0.083990
# Validation loss: 0.088455
#
# Epoch 2373
# -------------------------------
# Training loss: 0.079958
# Validation loss: 0.086741
#
# Epoch 2374
# -------------------------------
# Training loss: 0.079585
# Validation loss: 0.087307
#
# Epoch 2375
# -------------------------------
# Training loss: 0.079940
# Validation loss: 0.085439
#
# Epoch 2376
# -------------------------------
# Training loss: 0.080158
# Validation loss: 0.083551
#
# Epoch 2377
# -------------------------------
# Training loss: 0.076633
# Validation loss: 0.088169
#
# Epoch 2378
# -------------------------------
# Training loss: 0.081366
# Validation loss: 0.090059
#
# Epoch 2379
# -------------------------------
# Training loss: 0.084838
# Validation loss: 0.090853
#
# Epoch 2380
# -------------------------------
# Training loss: 0.081181
# Validation loss: 0.085859
#
# Epoch 2381
# -------------------------------
# Training loss: 0.081307
# Validation loss: 0.085966
#
# Epoch 2382
# -------------------------------
# Training loss: 0.085304
# Validation loss: 0.084737
#
# Epoch 2383
# -------------------------------
# Training loss: 0.080458
# Validation loss: 0.084848
#
# Epoch 2384
# -------------------------------
# Training loss: 0.076840
# Validation loss: 0.087511
#
# Epoch 2385
# -------------------------------
# Training loss: 0.079271
# Validation loss: 0.083975
#
# Epoch 2386
# -------------------------------
# Training loss: 0.084361
# Validation loss: 0.086430
#
# Epoch 2387
# -------------------------------
# Training loss: 0.085030
# Validation loss: 0.089705
#
# Epoch 2388
# -------------------------------
# Training loss: 0.079622
# Validation loss: 0.087267
#
# Epoch 2389
# -------------------------------
# Training loss: 0.079960
# Validation loss: 0.085950
#
# Epoch 2390
# -------------------------------
# Training loss: 0.079558
# Validation loss: 0.084953
#
# Epoch 2391
# -------------------------------
# Training loss: 0.079088
# Validation loss: 0.083903
#
# Epoch 2392
# -------------------------------
# Training loss: 0.085051
# Validation loss: 0.090909
#
# Epoch 2393
# -------------------------------
# Training loss: 0.082474
# Validation loss: 0.090893
#
# Epoch 2394
# -------------------------------
# Training loss: 0.080517
# Validation loss: 0.096740
#
# Epoch 2395
# -------------------------------
# Training loss: 0.083331
# Validation loss: 0.092078
#
# Epoch 2396
# -------------------------------
# Training loss: 0.081558
# Validation loss: 0.084805
#
# Epoch 2397
# -------------------------------
# Training loss: 0.080901
# Validation loss: 0.088836
#
# Epoch 2398
# -------------------------------
# Training loss: 0.084112
# Validation loss: 0.090571
#
# Epoch 2399
# -------------------------------
# Training loss: 0.081335
# Validation loss: 0.085257
#
# Epoch 2400
# -------------------------------
# Training loss: 0.080689
# Validation loss: 0.088073
#
# Epoch 2401
# -------------------------------
# Training loss: 0.081800
# Validation loss: 0.090687
#
# Epoch 2402
# -------------------------------
# Training loss: 0.079840
# Validation loss: 0.087074
#
# Epoch 2403
# -------------------------------
# Training loss: 0.078002
# Validation loss: 0.090781
#
# Epoch 2404
# -------------------------------
# Training loss: 0.086969
# Validation loss: 0.084226
#
# Epoch 2405
# -------------------------------
# Training loss: 0.080591
# Validation loss: 0.087079
#
# Epoch 2406
# -------------------------------
# Training loss: 0.081245
# Validation loss: 0.087548
#
# Epoch 2407
# -------------------------------
# Training loss: 0.077092
# Validation loss: 0.083229
#
# Epoch 2408
# -------------------------------
# Training loss: 0.080052
# Validation loss: 0.087500
#
# Epoch 2409
# -------------------------------
# Training loss: 0.080958
# Validation loss: 0.083157
#
# Epoch 2410
# -------------------------------
# Training loss: 0.078719
# Validation loss: 0.084922
#
# Epoch 2411
# -------------------------------
# Training loss: 0.087689
# Validation loss: 0.092151
#
# Epoch 2412
# -------------------------------
# Training loss: 0.081273
# Validation loss: 0.090059
#
# Epoch 2413
# -------------------------------
# Training loss: 0.084080
# Validation loss: 0.085247
#
# Epoch 2414
# -------------------------------
# Training loss: 0.083932
# Validation loss: 0.090580
#
# Epoch 2415
# -------------------------------
# Training loss: 0.079332
# Validation loss: 0.084030
#
# Epoch 2416
# -------------------------------
# Training loss: 0.078777
# Validation loss: 0.084297
#
# Epoch 2417
# -------------------------------
# Training loss: 0.080541
# Validation loss: 0.088534
#
# Epoch 2418
# -------------------------------
# Training loss: 0.082609
# Validation loss: 0.088448
#
# Epoch 2419
# -------------------------------
# Training loss: 0.080915
# Validation loss: 0.089901
#
# Epoch 2420
# -------------------------------
# Training loss: 0.084998
# Validation loss: 0.093476
#
# Epoch 2421
# -------------------------------
# Training loss: 0.080061
# Validation loss: 0.088629
#
# Epoch 2422
# -------------------------------
# Training loss: 0.079312
# Validation loss: 0.082829
#
# Epoch 2423
# -------------------------------
# Training loss: 0.080569
# Validation loss: 0.085556
#
# Epoch 2424
# -------------------------------
# Training loss: 0.078271
# Validation loss: 0.084559
#
# Epoch 2425
# -------------------------------
# Training loss: 0.081832
# Validation loss: 0.084299
#
# Epoch 2426
# -------------------------------
# Training loss: 0.076409
# Validation loss: 0.084544
#
# Epoch 2427
# -------------------------------
# Training loss: 0.080697
# Validation loss: 0.089875
#
# Epoch 2428
# -------------------------------
# Training loss: 0.081504
# Validation loss: 0.087187
#
# Epoch 2429
# -------------------------------
# Training loss: 0.082245
# Validation loss: 0.090481
#
# Epoch 2430
# -------------------------------
# Training loss: 0.078923
# Validation loss: 0.089609
#
# Epoch 2431
# -------------------------------
# Training loss: 0.079735
# Validation loss: 0.089340
#
# Epoch 2432
# -------------------------------
# Training loss: 0.077877
# Validation loss: 0.085077
#
# Epoch 2433
# -------------------------------
# Training loss: 0.079722
# Validation loss: 0.087826
#
# Epoch 2434
# -------------------------------
# Training loss: 0.080428
# Validation loss: 0.089816
#
# Epoch 2435
# -------------------------------
# Training loss: 0.082362
# Validation loss: 0.086519
#
# Epoch 2436
# -------------------------------
# Training loss: 0.079127
# Validation loss: 0.083304
#
# Epoch 2437
# -------------------------------
# Training loss: 0.078441
# Validation loss: 0.085598
#
# Epoch 2438
# -------------------------------
# Training loss: 0.084559
# Validation loss: 0.085968
#
# Epoch 2439
# -------------------------------
# Training loss: 0.080409
# Validation loss: 0.090241
#
# Epoch 2440
# -------------------------------
# Training loss: 0.081764
# Validation loss: 0.087592
#
# Epoch 2441
# -------------------------------
# Training loss: 0.083512
# Validation loss: 0.089385
#
# Epoch 2442
# -------------------------------
# Training loss: 0.078443
# Validation loss: 0.089143
#
# Epoch 2443
# -------------------------------
# Training loss: 0.080507
# Validation loss: 0.089477
#
# Epoch 2444
# -------------------------------
# Training loss: 0.080447
# Validation loss: 0.084906
#
# Epoch 2445
# -------------------------------
# Training loss: 0.079754
# Validation loss: 0.085319
#
# Epoch 2446
# -------------------------------
# Training loss: 0.079260
# Validation loss: 0.085465
#
# Epoch 2447
# -------------------------------
# Training loss: 0.080039
# Validation loss: 0.085265
#
# Epoch 2448
# -------------------------------
# Training loss: 0.080432
# Validation loss: 0.086044
#
# Epoch 2449
# -------------------------------
# Training loss: 0.079460
# Validation loss: 0.083797
#
# Epoch 2450
# -------------------------------
# Training loss: 0.080127
# Validation loss: 0.086780
#
# Epoch 2451
# -------------------------------
# Training loss: 0.077848
# Validation loss: 0.082938
#
# Epoch 2452
# -------------------------------
# Training loss: 0.078109
# Validation loss: 0.084247
#
# Epoch 2453
# -------------------------------
# Training loss: 0.081930
# Validation loss: 0.092330
#
# Epoch 2454
# -------------------------------
# Training loss: 0.081417
# Validation loss: 0.085779
#
# Epoch 2455
# -------------------------------
# Training loss: 0.081584
# Validation loss: 0.084146
#
# Epoch 2456
# -------------------------------
# Training loss: 0.078108
# Validation loss: 0.085943
#
# Epoch 2457
# -------------------------------
# Training loss: 0.085879
# Validation loss: 0.093175
#
# Epoch 2458
# -------------------------------
# Training loss: 0.079356
# Validation loss: 0.082797
#
# Epoch 2459
# -------------------------------
# Training loss: 0.079090
# Validation loss: 0.085957
#
# Epoch 2460
# -------------------------------
# Training loss: 0.078012
# Validation loss: 0.090023
#
# Epoch 2461
# -------------------------------
# Training loss: 0.082444
# Validation loss: 0.084900
#
# Epoch 2462
# -------------------------------
# Training loss: 0.081202
# Validation loss: 0.083608
#
# Epoch 2463
# -------------------------------
# Training loss: 0.081553
# Validation loss: 0.091902
#
# Epoch 2464
# -------------------------------
# Training loss: 0.083131
# Validation loss: 0.089537
#
# Epoch 2465
# -------------------------------
# Training loss: 0.077969
# Validation loss: 0.086761
#
# Epoch 2466
# -------------------------------
# Training loss: 0.078684
# Validation loss: 0.086657
#
# Epoch 2467
# -------------------------------
# Training loss: 0.077990
# Validation loss: 0.085152
#
# Epoch 2468
# -------------------------------
# Training loss: 0.078125
# Validation loss: 0.085611
#
# Epoch 2469
# -------------------------------
# Training loss: 0.080405
# Validation loss: 0.084942
#
# Epoch 2470
# -------------------------------
# Training loss: 0.081606
# Validation loss: 0.086787
#
# Epoch 2471
# -------------------------------
# Training loss: 0.077279
# Validation loss: 0.083897
#
# Epoch 2472
# -------------------------------
# Training loss: 0.078196
# Validation loss: 0.089239
#
# Epoch 2473
# -------------------------------
# Training loss: 0.080231
# Validation loss: 0.084766
#
# Epoch 2474
# -------------------------------
# Training loss: 0.082752
# Validation loss: 0.085055
#
# Epoch 2475
# -------------------------------
# Training loss: 0.078415
# Validation loss: 0.086033
#
# Epoch 2476
# -------------------------------
# Training loss: 0.077170
# Validation loss: 0.085169
#
# Epoch 2477
# -------------------------------
# Training loss: 0.081403
# Validation loss: 0.089174
#
# Epoch 2478
# -------------------------------
# Training loss: 0.077950
# Validation loss: 0.084766
#
# Epoch 2479
# -------------------------------
# Training loss: 0.079588
# Validation loss: 0.086588
#
# Epoch 2480
# -------------------------------
# Training loss: 0.081005
# Validation loss: 0.090435
#
# Epoch 2481
# -------------------------------
# Training loss: 0.078863
# Validation loss: 0.087706
#
# Epoch 2482
# -------------------------------
# Training loss: 0.079999
# Validation loss: 0.087773
#
# Epoch 2483
# -------------------------------
# Training loss: 0.080128
# Validation loss: 0.088158
#
# Epoch 2484
# -------------------------------
# Training loss: 0.078563
# Validation loss: 0.089119
#
# Epoch 2485
# -------------------------------
# Training loss: 0.077071
# Validation loss: 0.084822
#
# Epoch 2486
# -------------------------------
# Training loss: 0.078191
# Validation loss: 0.083637
#
# Epoch 2487
# -------------------------------
# Training loss: 0.078924
# Validation loss: 0.082738
#
# Epoch 2488
# -------------------------------
# Training loss: 0.078244
# Validation loss: 0.085511
#
# Epoch 2489
# -------------------------------
# Training loss: 0.076103
# Validation loss: 0.082522
#
# Epoch 2490
# -------------------------------
# Training loss: 0.077645
# Validation loss: 0.083075
#
# Epoch 2491
# -------------------------------
# Training loss: 0.079166
# Validation loss: 0.082999
#
# Epoch 2492
# -------------------------------
# Training loss: 0.078996
# Validation loss: 0.085104
#
# Epoch 2493
# -------------------------------
# Training loss: 0.082548
# Validation loss: 0.089133
#
# Epoch 2494
# -------------------------------
# Training loss: 0.080419
# Validation loss: 0.088598
#
# Epoch 2495
# -------------------------------
# Training loss: 0.077931
# Validation loss: 0.090712
#
# Epoch 2496
# -------------------------------
# Training loss: 0.076992
# Validation loss: 0.089163
#
# Epoch 2497
# -------------------------------
# Training loss: 0.077979
# Validation loss: 0.085925
#
# Epoch 2498
# -------------------------------
# Training loss: 0.077771
# Validation loss: 0.082743
#
# Epoch 2499
# -------------------------------
# Training loss: 0.078379
# Validation loss: 0.087278
#
# Epoch 2500
# -------------------------------
# Training loss: 0.077268
# Validation loss: 0.084086
#
# Done!

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses)+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('BCE Loss')
#plt.yscale('log')
plt.legend()

# %%
# Now test the pretrained model
test_pred = mytools.test_clas(test_loader, final_classifier, device)
test_pred=torch.sigmoid(torch.tensor(test_pred)).numpy()


fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test, test_pred, pos_label=1)
auc_test = sklearn.metrics.auc(fpr, tpr)
print(f'Test AUROC: {auc_test:0.4f}')

plt.plot(fpr, tpr, label=f'Test AUROC: {auc_test:0.4f}')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
# Out:
# Test AUROC: 0.9948

# %%
# Store the pretrained classifier labels
df_test["Class_pre"] = test_pred

# Save the pretrained classifier model
torch.save(final_classifier.state_dict(), "/Users/mghrear/data/ML_data/patch/pretrained_classifier_2021_v9_pass5_TC_run"+str(run)+".pt")

# %% [markdown]
# # Setup the adversary model

# %% [markdown]
# ## Initialize model, objective function, and optimizer

# %%
adv = mytools.Adversary(n_classes=Num_classes).to(device)
criterion_adv = nn.CrossEntropyLoss(reduction='none')  # returns loss per sample so we can weight it
opt_adv = torch.optim.Adam(adv.parameters(), lr=1e-5)
scheduler_adv = torch.optim.lr_scheduler.ExponentialLR(opt_adv, gamma=0.999)

# %% [markdown]
# ## Setup dataloaders

# %%
# Convert to tensor dataset and dataloader

# the structure is: feature, adversary label, weight
# The wight is 1 for tritrig and wab, and 0 for phiKK, to prevent the adversary from learning on phiKK events

train_adv_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_train), (torch.from_numpy(y_train.to_numpy().astype(np.float32))==0).float())
train_adv_loader = DataLoader(train_adv_dataset, batch_size=bsize, shuffle=True)

val_adv_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_val), (torch.from_numpy(y_val.to_numpy().astype(np.float32))==0).float() )
val_adv_loader = DataLoader(val_adv_dataset, batch_size=bsize, shuffle=True)

# Weights are not relavent for testing
test_adv_dataset = TensorDataset(torch.from_numpy(X_test.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_test))
test_adv_loader = DataLoader(test_adv_dataset, batch_size=bsize, shuffle=True)

# %% [markdown]
# ## Pre-train the adversary leaving classifier weights fixed

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 6

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 100
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train_adv(train_adv_loader, final_classifier, adv, criterion_adv, opt_adv, scheduler_adv, device))
    Validation_losses = np.append(Validation_losses, mytools.validate_adv(val_adv_loader, final_classifier, adv, criterion_adv, device))
    
    # Keep a running copy of the model with the lowest loss
    if Validation_losses[-1] == np.min(Validation_losses):
        final_adv = copy.deepcopy(adv)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Training loss: 1.632581
# Validation loss: 1.613317
#
# Epoch 2
# -------------------------------
# Training loss: 1.628013
# Validation loss: 1.617212
#
# Epoch 3
# -------------------------------
# Training loss: 1.624223
# Validation loss: 1.619631
#
# Epoch 4
# -------------------------------
# Training loss: 1.620731
# Validation loss: 1.615097
#
# Epoch 5
# -------------------------------
# Training loss: 1.617653
# Validation loss: 1.614202
#
# Epoch 6
# -------------------------------
# Training loss: 1.615241
# Validation loss: 1.612968
#
# Epoch 7
# -------------------------------
# Training loss: 1.613113
# Validation loss: 1.612304
#
# Epoch 8
# -------------------------------
# Training loss: 1.611124
# Validation loss: 1.610918
#
# Epoch 9
# -------------------------------
# Training loss: 1.609468
# Validation loss: 1.609390
#
# Epoch 10
# -------------------------------
# Training loss: 1.607591
# Validation loss: 1.608090
#
# Epoch 11
# -------------------------------
# Training loss: 1.606410
# Validation loss: 1.606965
#
# Epoch 12
# -------------------------------
# Training loss: 1.605045
# Validation loss: 1.604950
#
# Epoch 13
# -------------------------------
# Training loss: 1.603858
# Validation loss: 1.604816
#
# Epoch 14
# -------------------------------
# Training loss: 1.602929
# Validation loss: 1.602447
#
# Epoch 15
# -------------------------------
# Training loss: 1.601991
# Validation loss: 1.601894
#
# Epoch 16
# -------------------------------
# Training loss: 1.601250
# Validation loss: 1.601759
#
# Epoch 17
# -------------------------------
# Training loss: 1.600460
# Validation loss: 1.601176
#
# Epoch 18
# -------------------------------
# Training loss: 1.600020
# Validation loss: 1.600628
#
# Epoch 19
# -------------------------------
# Training loss: 1.599663
# Validation loss: 1.598731
#
# Epoch 20
# -------------------------------
# Training loss: 1.599443
# Validation loss: 1.599895
#
# Epoch 21
# -------------------------------
# Training loss: 1.598915
# Validation loss: 1.598687
#
# Epoch 22
# -------------------------------
# Training loss: 1.598617
# Validation loss: 1.598174
#
# Epoch 23
# -------------------------------
# Training loss: 1.598234
# Validation loss: 1.597928
#
# Epoch 24
# -------------------------------
# Training loss: 1.598131
# Validation loss: 1.597718
#
# Epoch 25
# -------------------------------
# Training loss: 1.597645
# Validation loss: 1.598248
#
# Epoch 26
# -------------------------------
# Training loss: 1.597586
# Validation loss: 1.598651
#
# Epoch 27
# -------------------------------
# Training loss: 1.597682
# Validation loss: 1.598148
#
# Epoch 28
# -------------------------------
# Training loss: 1.597156
# Validation loss: 1.596194
#
# Epoch 29
# -------------------------------
# Training loss: 1.597279
# Validation loss: 1.597771
#
# Epoch 30
# -------------------------------
# Training loss: 1.597146
# Validation loss: 1.597757
#
# Epoch 31
# -------------------------------
# Training loss: 1.596636
# Validation loss: 1.598203
#
# Epoch 32
# -------------------------------
# Training loss: 1.596580
# Validation loss: 1.597493
#
# Epoch 33
# -------------------------------
# Training loss: 1.596515
# Validation loss: 1.597360
#
# Epoch 34
# -------------------------------
# Training loss: 1.596127
# Validation loss: 1.597683
#
# Epoch 35
# -------------------------------
# Training loss: 1.596426
# Validation loss: 1.597300
#
# Epoch 36
# -------------------------------
# Training loss: 1.596288
# Validation loss: 1.597554
#
# Epoch 37
# -------------------------------
# Training loss: 1.596293
# Validation loss: 1.596031
#
# Epoch 38
# -------------------------------
# Training loss: 1.595954
# Validation loss: 1.596771
#
# Epoch 39
# -------------------------------
# Training loss: 1.595745
# Validation loss: 1.597646
#
# Epoch 40
# -------------------------------
# Training loss: 1.595918
# Validation loss: 1.595754
#
# Epoch 41
# -------------------------------
# Training loss: 1.595348
# Validation loss: 1.597669
#
# Epoch 42
# -------------------------------
# Training loss: 1.595557
# Validation loss: 1.596345
#
# Epoch 43
# -------------------------------
# Training loss: 1.595490
# Validation loss: 1.595753
#
# Epoch 44
# -------------------------------
# Training loss: 1.595882
# Validation loss: 1.596528
#
# Epoch 45
# -------------------------------
# Training loss: 1.595749
# Validation loss: 1.595958
#
# Epoch 46
# -------------------------------
# Training loss: 1.595481
# Validation loss: 1.595958
#
# Epoch 47
# -------------------------------
# Training loss: 1.595387
# Validation loss: 1.596213
#
# Epoch 48
# -------------------------------
# Training loss: 1.595249
# Validation loss: 1.599014
#
# Epoch 49
# -------------------------------
# Training loss: 1.595216
# Validation loss: 1.596763
#
# Epoch 50
# -------------------------------
# Training loss: 1.595340
# Validation loss: 1.595304
#
# Epoch 51
# -------------------------------
# Training loss: 1.595175
# Validation loss: 1.595744
#
# Epoch 52
# -------------------------------
# Training loss: 1.595046
# Validation loss: 1.597079
#
# Epoch 53
# -------------------------------
# Training loss: 1.595241
# Validation loss: 1.595012
#
# Epoch 54
# -------------------------------
# Training loss: 1.595185
# Validation loss: 1.596547
#
# Epoch 55
# -------------------------------
# Training loss: 1.595104
# Validation loss: 1.596950
#
# Epoch 56
# -------------------------------
# Training loss: 1.594836
# Validation loss: 1.596903
#
# Epoch 57
# -------------------------------
# Training loss: 1.594889
# Validation loss: 1.596140
#
# Epoch 58
# -------------------------------
# Training loss: 1.594854
# Validation loss: 1.596444
#
# Epoch 59
# -------------------------------
# Training loss: 1.595099
# Validation loss: 1.597049
#
# Epoch 60
# -------------------------------
# Training loss: 1.594593
# Validation loss: 1.595929
#
# Epoch 61
# -------------------------------
# Training loss: 1.594447
# Validation loss: 1.595181
#
# Epoch 62
# -------------------------------
# Training loss: 1.594698
# Validation loss: 1.597356
#
# Epoch 63
# -------------------------------
# Training loss: 1.594715
# Validation loss: 1.595656
#
# Epoch 64
# -------------------------------
# Training loss: 1.594605
# Validation loss: 1.595244
#
# Epoch 65
# -------------------------------
# Training loss: 1.594259
# Validation loss: 1.595044
#
# Epoch 66
# -------------------------------
# Training loss: 1.594621
# Validation loss: 1.596541
#
# Epoch 67
# -------------------------------
# Training loss: 1.594457
# Validation loss: 1.595811
#
# Epoch 68
# -------------------------------
# Training loss: 1.594435
# Validation loss: 1.594689
#
# Epoch 69
# -------------------------------
# Training loss: 1.594169
# Validation loss: 1.594235
#
# Epoch 70
# -------------------------------
# Training loss: 1.594419
# Validation loss: 1.595454
#
# Epoch 71
# -------------------------------
# Training loss: 1.594342
# Validation loss: 1.594864
#
# Epoch 72
# -------------------------------
# Training loss: 1.594439
# Validation loss: 1.595753
#
# Epoch 73
# -------------------------------
# Training loss: 1.593710
# Validation loss: 1.596379
#
# Epoch 74
# -------------------------------
# Training loss: 1.594109
# Validation loss: 1.595503
#
# Epoch 75
# -------------------------------
# Training loss: 1.594497
# Validation loss: 1.596351
#
# Epoch 76
# -------------------------------
# Training loss: 1.594001
# Validation loss: 1.597692
#
# Epoch 77
# -------------------------------
# Training loss: 1.593944
# Validation loss: 1.595614
#
# Epoch 78
# -------------------------------
# Training loss: 1.594062
# Validation loss: 1.595576
#
# Epoch 79
# -------------------------------
# Training loss: 1.594266
# Validation loss: 1.595112
#
# Epoch 80
# -------------------------------
# Training loss: 1.594064
# Validation loss: 1.596006
#
# Epoch 81
# -------------------------------
# Training loss: 1.593963
# Validation loss: 1.596293
#
# Epoch 82
# -------------------------------
# Training loss: 1.594227
# Validation loss: 1.593880
#
# Epoch 83
# -------------------------------
# Training loss: 1.593875
# Validation loss: 1.596045
#
# Epoch 84
# -------------------------------
# Training loss: 1.593865
# Validation loss: 1.594868
#
# Epoch 85
# -------------------------------
# Training loss: 1.594167
# Validation loss: 1.595731
#
# Epoch 86
# -------------------------------
# Training loss: 1.593794
# Validation loss: 1.595520
#
# Epoch 87
# -------------------------------
# Training loss: 1.593659
# Validation loss: 1.595334
#
# Epoch 88
# -------------------------------
# Training loss: 1.593875
# Validation loss: 1.594375
#
# Epoch 89
# -------------------------------
# Training loss: 1.593855
# Validation loss: 1.594513
#
# Epoch 90
# -------------------------------
# Training loss: 1.593488
# Validation loss: 1.594319
#
# Epoch 91
# -------------------------------
# Training loss: 1.594656
# Validation loss: 1.595541
#
# Epoch 92
# -------------------------------
# Training loss: 1.593512
# Validation loss: 1.595253
#
# Epoch 93
# -------------------------------
# Training loss: 1.593893
# Validation loss: 1.595471
#
# Epoch 94
# -------------------------------
# Training loss: 1.593411
# Validation loss: 1.595881
#
# Epoch 95
# -------------------------------
# Training loss: 1.594022
# Validation loss: 1.594417
#
# Epoch 96
# -------------------------------
# Training loss: 1.593680
# Validation loss: 1.594812
#
# Epoch 97
# -------------------------------
# Training loss: 1.593448
# Validation loss: 1.594979
#
# Epoch 98
# -------------------------------
# Training loss: 1.593632
# Validation loss: 1.594629
#
# Epoch 99
# -------------------------------
# Training loss: 1.593434
# Validation loss: 1.595572
#
# Epoch 100
# -------------------------------
# Training loss: 1.593662
# Validation loss: 1.594436
#
# Done!

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses)+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('BCE Loss')
plt.legend()

# %% [markdown]
# # Train full adverserial neural network

# %% [markdown]
# # Setup dataloaders

# %%
# the structure is: feature, classifier label, adversary label, weight
# The wight is 1 for tritrig and wab, and 0 for phiKK, to prevent the adversary from learning on phiKK events

train_full_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy().astype(np.float32))  , torch.from_numpy(y_train.to_numpy().astype(np.float32)).unsqueeze(1), torch.from_numpy(y_adv_train),  (torch.from_numpy(y_train.to_numpy().astype(np.float32))==0).float())
train_full_loader = DataLoader(train_full_dataset, batch_size=bsize, shuffle=True)

val_full_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy().astype(np.float32))  , torch.from_numpy(y_val.to_numpy().astype(np.float32)).unsqueeze(1),  torch.from_numpy(y_adv_val),  (torch.from_numpy(y_val.to_numpy().astype(np.float32))==0).float())
val_full_loader = DataLoader(val_full_dataset, batch_size=bsize, shuffle=True)

# %% [markdown]
# ## Define loss functions

# %%
BCE_loss = nn.BCEWithLogitsLoss()
CE_loss = nn.CrossEntropyLoss(reduction='none') # returns loss per sample so we can weight it

def full_loss(output_clas, output_adv, target_clas, target_adv, w, lambda_):

    loss1 = BCE_loss(output_clas, target_clas )  # classification loss
    sample_losses2 = CE_loss(output_adv, target_adv)  # adversarial losses, since we set reduction='none', this is now a vector of losses, one per sample in the batch

    # Weighted mean loss over non-zero weights
    nonzero = w > 0
    loss2 = (sample_losses2[nonzero] * w[nonzero]).sum() / w[nonzero].sum()

    loss = loss1 - lambda_*loss2

    return loss

# %% [markdown]
# ## Setup optimizers

# %%
optimizer_clas = optim.Adam(final_classifier.parameters(), lr=1e-7,betas=(0.5, 0.999))
optimizer_adv = optim.Adam(final_adv.parameters(), lr=1e-5,betas=(0.5, 0.999))

scheduler_clas = torch.optim.lr_scheduler.ExponentialLR(optimizer_clas, gamma=0.999)
scheduler_adv = torch.optim.lr_scheduler.ExponentialLR(optimizer_adv, gamma=0.999)

# %% [markdown]
# ## Adversarial training

# %%
Training_losses_clas = np.array([])
Training_losses_adv = np.array([])
Validation_losses_clas = np.array([])
Validation_losses_adv = np.array([])
diff_scores = np.array([])


epochs = 50
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")

    # Get validation losses
    E_clas_val_loss, E_adv_val_loss = mytools.validate_full(val_full_loader, final_classifier, final_adv, full_loss, lambda_, criterion_adv, device)
    Validation_losses_clas = np.append(Validation_losses_clas, E_clas_val_loss)
    Validation_losses_adv = np.append(Validation_losses_adv, E_adv_val_loss)

    # Train adversary and classifier
    E_clas_training_loss , E_adv_training_loss = mytools.train_full(train_full_loader, final_classifier, final_adv, full_loss, lambda_, criterion_adv, optimizer_clas, optimizer_adv, scheduler_clas, scheduler_adv, device)
    Training_losses_clas = np.append(Training_losses_clas, E_clas_training_loss)
    Training_losses_adv = np.append(Training_losses_adv, E_adv_training_loss)

    # Get the diff_score
    df_test["Class_adv"] = mytools.test_clas(test_loader, final_classifier, device)
    df_bkg = df_test.loc[ (df_test.type == 'tritrig') | (df_test.type == 'wab')]
    per = np.percentile(df_bkg['Class_adv'],99)
    df_cut = df_bkg[df_bkg['Class_adv']>per].reset_index(drop=True)
    x1 = 1000* df_bkg.InvM.values
    x2 = 1000*df_cut.InvM.values
    diff_scores = np.append(diff_scores, mytools.get_diff_score(x1,x2) )

    # Keep a running copy of the model with the lowest loss
    if diff_scores[-1] == np.min(diff_scores):
        final_clas_adv = copy.deepcopy(final_classifier)
        final_adv_adv = copy.deepcopy(final_adv)

            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Classifier validation loss: -159.283496
# Adversary validation loss: 1.593680
# Classifier training loss: -160.641251
# Adversary training loss: 1.608185
# Epoch 2
# -------------------------------
# Classifier validation loss: -159.521082
# Adversary validation loss: 1.596039
# Classifier training loss: -160.820828
# Adversary training loss: 1.609699
# Epoch 3
# -------------------------------
# Classifier validation loss: -160.017017
# Adversary validation loss: 1.601010
# Classifier training loss: -161.181429
# Adversary training loss: 1.613351
# Epoch 4
# -------------------------------
# Classifier validation loss: -160.166745
# Adversary validation loss: 1.602534
# Classifier training loss: -161.649390
# Adversary training loss: 1.617988
# Epoch 5
# -------------------------------
# Classifier validation loss: -160.722223
# Adversary validation loss: 1.608109
# Classifier training loss: -161.603968
# Adversary training loss: 1.617409
# Epoch 6
# -------------------------------
# Classifier validation loss: -160.510510
# Adversary validation loss: 1.606044
# Classifier training loss: -161.606640
# Adversary training loss: 1.617442
# Epoch 7
# -------------------------------
# Classifier validation loss: -160.728583
# Adversary validation loss: 1.608207
# Classifier training loss: -161.520089
# Adversary training loss: 1.616538
# Epoch 8
# -------------------------------
# Classifier validation loss: -161.010135
# Adversary validation loss: 1.611114
# Classifier training loss: -161.380293
# Adversary training loss: 1.615076
# Epoch 9
# -------------------------------
# Classifier validation loss: -160.916464
# Adversary validation loss: 1.610167
# Classifier training loss: -161.219357
# Adversary training loss: 1.613455
# Epoch 10
# -------------------------------
# Classifier validation loss: -161.017062
# Adversary validation loss: 1.611205
# Classifier training loss: -160.984568
# Adversary training loss: 1.611103
# Epoch 11
# -------------------------------
# Classifier validation loss: -160.935440
# Adversary validation loss: 1.610434
# Classifier training loss: -160.734160
# Adversary training loss: 1.608690
# Epoch 12
# -------------------------------
# Classifier validation loss: -160.804620
# Adversary validation loss: 1.609120
# Classifier training loss: -160.653844
# Adversary training loss: 1.607895
# Epoch 13
# -------------------------------
# Classifier validation loss: -160.807697
# Adversary validation loss: 1.609154
# Classifier training loss: -160.290027
# Adversary training loss: 1.604199
# Epoch 14
# -------------------------------
# Classifier validation loss: -160.350571
# Adversary validation loss: 1.604645
# Classifier training loss: -160.329703
# Adversary training loss: 1.604547
# Epoch 15
# -------------------------------
# Classifier validation loss: -160.381131
# Adversary validation loss: 1.604860
# Classifier training loss: -160.528361
# Adversary training loss: 1.606637
# Epoch 16
# -------------------------------
# Classifier validation loss: -160.883057
# Adversary validation loss: 1.609849
# Classifier training loss: -160.164044
# Adversary training loss: 1.602860
# Epoch 17
# -------------------------------
# Classifier validation loss: -160.512253
# Adversary validation loss: 1.606105
# Classifier training loss: -160.301429
# Adversary training loss: 1.604288
# Epoch 18
# -------------------------------
# Classifier validation loss: -160.727109
# Adversary validation loss: 1.608287
# Classifier training loss: -160.192110
# Adversary training loss: 1.603157
# Epoch 19
# -------------------------------
# Classifier validation loss: -160.838620
# Adversary validation loss: 1.609365
# Classifier training loss: -160.209025
# Adversary training loss: 1.603328
# Epoch 20
# -------------------------------
# Classifier validation loss: -160.524582
# Adversary validation loss: 1.606177
# Classifier training loss: -160.224965
# Adversary training loss: 1.603448
# Epoch 21
# -------------------------------
# Classifier validation loss: -160.667285
# Adversary validation loss: 1.607596
# Classifier training loss: -160.438755
# Adversary training loss: 1.605517
# Epoch 22
# -------------------------------
# Classifier validation loss: -160.694196
# Adversary validation loss: 1.607857
# Classifier training loss: -160.653768
# Adversary training loss: 1.607722
# Epoch 23
# -------------------------------
# Classifier validation loss: -160.906448
# Adversary validation loss: 1.609945
# Classifier training loss: -160.734287
# Adversary training loss: 1.608532
# Epoch 24
# -------------------------------
# Classifier validation loss: -160.869913
# Adversary validation loss: 1.609565
# Classifier training loss: -160.933801
# Adversary training loss: 1.610435
# Epoch 25
# -------------------------------
# Classifier validation loss: -161.075723
# Adversary validation loss: 1.611610
# Classifier training loss: -161.013531
# Adversary training loss: 1.611201
# Epoch 26
# -------------------------------
# Classifier validation loss: -161.201169
# Adversary validation loss: 1.612913
# Classifier training loss: -161.081482
# Adversary training loss: 1.611812
# Epoch 27
# -------------------------------
# Classifier validation loss: -161.144550
# Adversary validation loss: 1.612280
# Classifier training loss: -161.004956
# Adversary training loss: 1.611021
# Epoch 28
# -------------------------------
# Classifier validation loss: -161.135812
# Adversary validation loss: 1.612246
# Classifier training loss: -161.147115
# Adversary training loss: 1.612450
# Epoch 29
# -------------------------------
# Classifier validation loss: -161.029160
# Adversary validation loss: 1.611210
# Classifier training loss: -161.057748
# Adversary training loss: 1.611546
# Epoch 30
# -------------------------------
# Classifier validation loss: -160.999445
# Adversary validation loss: 1.610859
# Classifier training loss: -161.027291
# Adversary training loss: 1.611224
# Epoch 31
# -------------------------------
# Classifier validation loss: -160.982950
# Adversary validation loss: 1.610687
# Classifier training loss: -160.988049
# Adversary training loss: 1.610902
# Epoch 32
# -------------------------------
# Classifier validation loss: -160.930865
# Adversary validation loss: 1.610158
# Classifier training loss: -160.926342
# Adversary training loss: 1.610240
# Epoch 33
# -------------------------------
# Classifier validation loss: -160.862003
# Adversary validation loss: 1.609561
# Classifier training loss: -160.901735
# Adversary training loss: 1.610016
# Epoch 34
# -------------------------------
# Classifier validation loss: -160.905338
# Adversary validation loss: 1.610029
# Classifier training loss: -160.962760
# Adversary training loss: 1.610685
# Epoch 35
# -------------------------------
# Classifier validation loss: -160.781299
# Adversary validation loss: 1.608694
# Classifier training loss: -160.871646
# Adversary training loss: 1.609831
# Epoch 36
# -------------------------------
# Classifier validation loss: -160.777179
# Adversary validation loss: 1.608729
# Classifier training loss: -160.860955
# Adversary training loss: 1.609627
# Epoch 37
# -------------------------------
# Classifier validation loss: -160.697504
# Adversary validation loss: 1.607872
# Classifier training loss: -160.766898
# Adversary training loss: 1.608635
# Epoch 38
# -------------------------------
# Classifier validation loss: -160.668427
# Adversary validation loss: 1.607640
# Classifier training loss: -160.772968
# Adversary training loss: 1.608731
# Epoch 39
# -------------------------------
# Classifier validation loss: -160.523587
# Adversary validation loss: 1.606222
# Classifier training loss: -160.702896
# Adversary training loss: 1.608050
# Epoch 40
# -------------------------------
# Classifier validation loss: -160.600693
# Adversary validation loss: 1.606951
# Classifier training loss: -160.723758
# Adversary training loss: 1.608281
# Epoch 41
# -------------------------------
# Classifier validation loss: -160.426065
# Adversary validation loss: 1.605218
# Classifier training loss: -160.706280
# Adversary training loss: 1.608104
# Epoch 42
# -------------------------------
# Classifier validation loss: -160.542276
# Adversary validation loss: 1.606344
# Classifier training loss: -160.756371
# Adversary training loss: 1.608590
# Epoch 43
# -------------------------------
# Classifier validation loss: -160.468417
# Adversary validation loss: 1.605575
# Classifier training loss: -160.771962
# Adversary training loss: 1.608727
# Epoch 44
# -------------------------------
# Classifier validation loss: -160.440198
# Adversary validation loss: 1.605318
# Classifier training loss: -160.810203
# Adversary training loss: 1.609099
# Epoch 45
# -------------------------------
# Classifier validation loss: -160.632339
# Adversary validation loss: 1.607206
# Classifier training loss: -160.854785
# Adversary training loss: 1.609539
# Epoch 46
# -------------------------------
# Classifier validation loss: -160.679056
# Adversary validation loss: 1.607694
# Classifier training loss: -160.877762
# Adversary training loss: 1.609781
# Epoch 47
# -------------------------------
# Classifier validation loss: -160.709311
# Adversary validation loss: 1.607950
# Classifier training loss: -160.938605
# Adversary training loss: 1.610374
# Epoch 48
# -------------------------------
# Classifier validation loss: -160.581372
# Adversary validation loss: 1.606701
# Classifier training loss: -160.865985
# Adversary training loss: 1.609634
# Epoch 49
# -------------------------------
# Classifier validation loss: -160.781989
# Adversary validation loss: 1.608701
# Classifier training loss: -160.934918
# Adversary training loss: 1.610289
# Epoch 50
# -------------------------------
# Classifier validation loss: -160.849829
# Adversary validation loss: 1.609377
# Classifier training loss: -161.010166
# Adversary training loss: 1.611059
# Done!

# %%
fig, ax1 = plt.subplots()

best_epoch = np.argmin(diff_scores)+1



#ax1.plot(np.arange(len(Training_losses_adv))+1, Training_losses_adv, 'k-', label='Training Adversary')
ax1.plot(np.arange(len(Validation_losses_adv))+1, Validation_losses_adv, 'k-', label='Validation Adversary')

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Adversary Loss', color='k')
ax1.tick_params(axis='y', labelcolor='k')

ax2 = ax1.twinx()

#ax2.plot(np.arange(len(Training_losses_clas))+1, Training_losses_clas, 'r-', label='Training Classifier')
ax2.plot(np.arange(len(Validation_losses_clas))+1, Validation_losses_clas, 'r-', label='Validation Classifier')
ax2.axvline(best_epoch,label="Final model stopped here",color='k')

ax2.set_ylabel('Classifier Loss', color='r')
ax2.tick_params(axis='y', labelcolor='r')

# %% [markdown]
# ## Test adversarially trained models

# %%
# Now test the pretrained model
test_pred = mytools.test_clas(test_loader, final_clas_adv, device)
test_pred=torch.sigmoid(torch.tensor(test_pred)).numpy()


fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test, test_pred, pos_label=1)
auc_test = sklearn.metrics.auc(fpr, tpr)
print(f'Test AUROC: {auc_test:0.4f}')

plt.plot(fpr, tpr, label=f'Test AUROC: {auc_test:0.4f}')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
# Out:
# Test AUROC: 0.9907

# %%
df_test["Class_adv"] = test_pred
df_bkg = df_test.loc[ (df_test.type == 'tritrig') | (df_test.type == 'wab')]
per = np.percentile(df_bkg['Class_adv'],99)
df_cut = df_bkg[df_bkg['Class_adv']>per].reset_index(drop=True)
x_vals = 1000*df_cut.InvM

plt.figure()
plt.hist(1000*df_bkg.InvM, bins=np.arange(980,1250,1), histtype='step', label='No selection', density=True)
plt.hist(x_vals, bins=np.arange(980,1250,1), histtype='step', label= '99 percent selection', density=True)
plt.axvline(1019.461, color='k', linestyle='dashed', linewidth=1, label='PDG phi mass')
plt.xlabel('Invariant Mass [MeV]')
plt.ylabel('Normalized Counts')
plt.legend()

# %%
x1 = 1000* df_bkg.InvM.values
x2 = 1000*df_cut.InvM.values

N, edges = np.histogram(x1, bins=np.arange(980,1250,1), density=False)
M, edges = np.histogram(x2, bins=np.arange(980,1250,1), density=False)

N2 = N[(N > 0) & (M > 0)]
M2 = M[(N > 0) & (M > 0)]

diff_score = np.mean(np.abs(N2/np.sum(N)-M2/np.sum(M)) / (np.sqrt(N2)/np.sum(N) + np.sqrt(M2)/np.sum(M) ))

print(diff_score)

N = len(df_test.loc[ ((df_test.type == 'tritrig') | (df_test.type == 'wab')) & (df_test.InvM < (1.019 + 0.01) )  & (df_test.InvM > (1.019 - 0.01) ) & ( df_test['Class_adv']>per ) ] )
S = len(df_test.loc[ (df_test.type == 'phiKK') & (df_test.InvM < (1.019 + 0.01) )  & (df_test.InvM > (1.019 - 0.01) ) & ( df_test['Class_adv']>per )  ] )

print(S/N)
# Out:
# 0.7409458976017373
# 2.663538873994638

# %%
# Save the adversarially trained models
torch.save(final_clas_adv.state_dict(), "/Users/mghrear/data/ML_data/patch/classifier_adv_2021_v9_pass5_TC_run"+str(run)+".pt")
torch.save(final_adv_adv.state_dict(), "/Users/mghrear/data/ML_data/patch/adversary_adv_2021_v9_pass5_TC_run"+str(run)+".pt")

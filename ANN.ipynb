# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import torch 
from torch import nn, optim
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import sklearn
from sklearn.model_selection import train_test_split
import copy
import mytools


# Print and store device being used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cpu

# %% [markdown]
# # Define important parameters

# %%
# Number of class in invariant mass used by the adversary
Num_classes = 5
# Hyper-parameter for adversarial training of the classifier
lambda_ = 100.0

run = 1

# %% [markdown]
# # Load and setup the data

# %%
# Read tritrig, wab, phiKK, and data files
df_tritrig = pd.read_pickle('/Users/mghrear/data/ML_data/patch/2021_v9_pass5_tritrig_QualCuts.pk')
df_tritrig['PhiKK'] = 0.0
df_phiKK = pd.read_pickle('/Users/mghrear/data/ML_data/patch/2021_v9_pass5_phiKK_QualCuts.pk')
df_phiKK['PhiKK'] = 1.0
df_wab = pd.read_pickle('/Users/mghrear/data/ML_data/patch/2021_v9_pass5_wab_QualCuts.pk')
df_wab['PhiKK'] = 0.0 # Add label


print("tritrig: ", len(df_tritrig))
print("phiKK: ", len(df_phiKK))
print("wab: ", len(df_wab))
# Out:
# tritrig:  120352
# phiKK:  3845
# wab:  6580

# %%
# Make Training set with 20000 tritrig, 4000 phiKK, 4000 wab
tritrig_train = df_tritrig[0:20000]
wab_train = df_wab[0:3000]
phiKK_train = df_phiKK[0:3000]

# Combine and shuffle all training data
df_train = pd.concat([tritrig_train, phiKK_train, wab_train], ignore_index=True, sort=False)
df_train = df_train.sample(frac=1, random_state=42).reset_index(drop=True)

# Get edges in invariant mass classes for one-hot encoding
# To be used for adverserial labels
# The edges are chosen such that each bin has equal number of background events
one_hot_edges = mytools.get_one_hot_edges(mytools.get_InvM( pd.concat([df_tritrig, df_wab], ignore_index=True, sort=False) ), n_bins=Num_classes)

# Split the training data into training and validation sets
df_train, df_val = train_test_split(df_train, test_size=0.33, random_state=42)

# Make X and y for training and validation sets
# the adverserial network has its own labels
X_train = df_train.drop(columns=['PhiKK'])
y_train = df_train['PhiKK']
y_adv_train = mytools.get_adv_labels( mytools.get_InvM(df_train), one_hot_edges)
X_val = df_val.drop(columns=['PhiKK'])
y_val = df_val['PhiKK']
y_adv_val = mytools.get_adv_labels( mytools.get_InvM(df_val), one_hot_edges)

# Make testing set with remaining events
tritrig_test = df_tritrig[20000:]
tritrig_test['type']= 'tritrig'
wab_test = df_wab[3000:]
wab_test['type']= 'wab'
phiKK_test = df_phiKK[3000:]
phiKK_test['type']= 'phiKK'

df_test = pd.concat([tritrig_test, phiKK_test,wab_test], ignore_index=True, sort=False)
df_test = df_test.sample(frac=1, random_state=42).reset_index(drop=True) # Now shuffle the combined dataframe

X_test = df_test.drop(columns=['PhiKK','type'])
y_test = df_test['PhiKK']
y_adv_test = mytools.get_adv_labels( mytools.get_InvM(df_test), one_hot_edges)

df_test["InvM"] = mytools.get_InvM(df_test)
# Out:
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_54366/1157922432.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tritrig_test['type']= 'tritrig'
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_54366/1157922432.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wab_test['type']= 'wab'
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_54366/1157922432.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phiKK_test['type']= 'phiKK'

# %% [markdown]
# ## Setup dataloaders

# %%
bsize = 2000

# Convert to tensor dataset and dataloader
train_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy().astype(np.float32))  , torch.from_numpy(y_train.to_numpy().astype(np.float32)).unsqueeze(1)  )
train_loader = DataLoader(train_dataset, batch_size=bsize, shuffle=True)

val_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy().astype(np.float32))  , torch.from_numpy(y_val.to_numpy().astype(np.float32)).unsqueeze(1)  )
val_loader = DataLoader(val_dataset, batch_size=bsize, shuffle=True)

test_dataset = TensorDataset(torch.from_numpy(X_test.to_numpy().astype(np.float32)))
test_loader = DataLoader(test_dataset, batch_size=bsize, shuffle=False)

# %% [markdown]
# ## Initialize model, objective function, and optimizer

# %%
clas = mytools.Classifier(in_features=X_train.shape[1]).to(device)
criterion_clas = nn.BCEWithLogitsLoss()
optimizer_clas = optim.Adam(clas.parameters(), lr=1e-5)
scheduler_clas = torch.optim.lr_scheduler.ExponentialLR(optimizer_clas, gamma=0.9999)

# %% [markdown]
# ## Pre-train the classifier

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 10

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 2500
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train_clas(train_loader, clas, criterion_clas, optimizer_clas, scheduler_clas, device))
    Validation_losses = np.append(Validation_losses, mytools.validate_clas(val_loader, clas, criterion_clas, device))
    
    # Keep a running copy of the model with the lowest loss
    if Validation_losses[-1] == np.min(Validation_losses):
        final_classifier = copy.deepcopy(clas)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Training loss: 0.661091
# Validation loss: 0.750883
#
# Epoch 2
# -------------------------------
# Training loss: 0.637491
# Validation loss: 0.761106
#
# Epoch 3
# -------------------------------
# Training loss: 0.623397
# Validation loss: 0.724865
#
# Epoch 4
# -------------------------------
# Training loss: 0.612946
# Validation loss: 0.692926
#
# Epoch 5
# -------------------------------
# Training loss: 0.603992
# Validation loss: 0.679803
#
# Epoch 6
# -------------------------------
# Training loss: 0.597067
# Validation loss: 0.658755
#
# Epoch 7
# -------------------------------
# Training loss: 0.590523
# Validation loss: 0.627092
#
# Epoch 8
# -------------------------------
# Training loss: 0.584446
# Validation loss: 0.603696
#
# Epoch 9
# -------------------------------
# Training loss: 0.581684
# Validation loss: 0.583102
#
# Epoch 10
# -------------------------------
# Training loss: 0.575285
# Validation loss: 0.578438
#
# Epoch 11
# -------------------------------
# Training loss: 0.571251
# Validation loss: 0.579912
#
# Epoch 12
# -------------------------------
# Training loss: 0.567181
# Validation loss: 0.564509
#
# Epoch 13
# -------------------------------
# Training loss: 0.565564
# Validation loss: 0.561988
#
# Epoch 14
# -------------------------------
# Training loss: 0.562925
# Validation loss: 0.559045
#
# Epoch 15
# -------------------------------
# Training loss: 0.557375
# Validation loss: 0.564111
#
# Epoch 16
# -------------------------------
# Training loss: 0.554711
# Validation loss: 0.558354
#
# Epoch 17
# -------------------------------
# Training loss: 0.550503
# Validation loss: 0.552784
#
# Epoch 18
# -------------------------------
# Training loss: 0.548761
# Validation loss: 0.545293
#
# Epoch 19
# -------------------------------
# Training loss: 0.544863
# Validation loss: 0.545862
#
# Epoch 20
# -------------------------------
# Training loss: 0.542455
# Validation loss: 0.541873
#
# Epoch 21
# -------------------------------
# Training loss: 0.537943
# Validation loss: 0.542064
#
# Epoch 22
# -------------------------------
# Training loss: 0.535368
# Validation loss: 0.536944
#
# Epoch 23
# -------------------------------
# Training loss: 0.534846
# Validation loss: 0.528277
#
# Epoch 24
# -------------------------------
# Training loss: 0.531092
# Validation loss: 0.533557
#
# Epoch 25
# -------------------------------
# Training loss: 0.527088
# Validation loss: 0.522492
#
# Epoch 26
# -------------------------------
# Training loss: 0.524353
# Validation loss: 0.526544
#
# Epoch 27
# -------------------------------
# Training loss: 0.522939
# Validation loss: 0.522061
#
# Epoch 28
# -------------------------------
# Training loss: 0.520781
# Validation loss: 0.520850
#
# Epoch 29
# -------------------------------
# Training loss: 0.518880
# Validation loss: 0.516278
#
# Epoch 30
# -------------------------------
# Training loss: 0.518832
# Validation loss: 0.518358
#
# Epoch 31
# -------------------------------
# Training loss: 0.514405
# Validation loss: 0.517790
#
# Epoch 32
# -------------------------------
# Training loss: 0.512028
# Validation loss: 0.511094
#
# Epoch 33
# -------------------------------
# Training loss: 0.510636
# Validation loss: 0.508035
#
# Epoch 34
# -------------------------------
# Training loss: 0.509411
# Validation loss: 0.512531
#
# Epoch 35
# -------------------------------
# Training loss: 0.506972
# Validation loss: 0.506992
#
# Epoch 36
# -------------------------------
# Training loss: 0.505186
# Validation loss: 0.507242
#
# Epoch 37
# -------------------------------
# Training loss: 0.504366
# Validation loss: 0.503012
#
# Epoch 38
# -------------------------------
# Training loss: 0.501995
# Validation loss: 0.505888
#
# Epoch 39
# -------------------------------
# Training loss: 0.500542
# Validation loss: 0.496120
#
# Epoch 40
# -------------------------------
# Training loss: 0.499447
# Validation loss: 0.503354
#
# Epoch 41
# -------------------------------
# Training loss: 0.497346
# Validation loss: 0.499781
#
# Epoch 42
# -------------------------------
# Training loss: 0.496779
# Validation loss: 0.495566
#
# Epoch 43
# -------------------------------
# Training loss: 0.493998
# Validation loss: 0.492847
#
# Epoch 44
# -------------------------------
# Training loss: 0.492277
# Validation loss: 0.498052
#
# Epoch 45
# -------------------------------
# Training loss: 0.493848
# Validation loss: 0.491503
#
# Epoch 46
# -------------------------------
# Training loss: 0.493217
# Validation loss: 0.493816
#
# Epoch 47
# -------------------------------
# Training loss: 0.489168
# Validation loss: 0.490347
#
# Epoch 48
# -------------------------------
# Training loss: 0.488635
# Validation loss: 0.496052
#
# Epoch 49
# -------------------------------
# Training loss: 0.486258
# Validation loss: 0.487413
#
# Epoch 50
# -------------------------------
# Training loss: 0.486025
# Validation loss: 0.487084
#
# Epoch 51
# -------------------------------
# Training loss: 0.485509
# Validation loss: 0.482207
#
# Epoch 52
# -------------------------------
# Training loss: 0.483263
# Validation loss: 0.487830
#
# Epoch 53
# -------------------------------
# Training loss: 0.480451
# Validation loss: 0.484736
#
# Epoch 54
# -------------------------------
# Training loss: 0.480592
# Validation loss: 0.478157
#
# Epoch 55
# -------------------------------
# Training loss: 0.479255
# Validation loss: 0.481110
#
# Epoch 56
# -------------------------------
# Training loss: 0.477764
# Validation loss: 0.477742
#
# Epoch 57
# -------------------------------
# Training loss: 0.475823
# Validation loss: 0.479312
#
# Epoch 58
# -------------------------------
# Training loss: 0.475011
# Validation loss: 0.475958
#
# Epoch 59
# -------------------------------
# Training loss: 0.475458
# Validation loss: 0.477161
#
# Epoch 60
# -------------------------------
# Training loss: 0.471924
# Validation loss: 0.476101
#
# Epoch 61
# -------------------------------
# Training loss: 0.473013
# Validation loss: 0.480224
#
# Epoch 62
# -------------------------------
# Training loss: 0.471666
# Validation loss: 0.472349
#
# Epoch 63
# -------------------------------
# Training loss: 0.469527
# Validation loss: 0.481056
#
# Epoch 64
# -------------------------------
# Training loss: 0.468613
# Validation loss: 0.469066
#
# Epoch 65
# -------------------------------
# Training loss: 0.468342
# Validation loss: 0.469712
#
# Epoch 66
# -------------------------------
# Training loss: 0.465847
# Validation loss: 0.473394
#
# Epoch 67
# -------------------------------
# Training loss: 0.464403
# Validation loss: 0.468667
#
# Epoch 68
# -------------------------------
# Training loss: 0.462919
# Validation loss: 0.470632
#
# Epoch 69
# -------------------------------
# Training loss: 0.462885
# Validation loss: 0.464961
#
# Epoch 70
# -------------------------------
# Training loss: 0.462401
# Validation loss: 0.464905
#
# Epoch 71
# -------------------------------
# Training loss: 0.460106
# Validation loss: 0.464689
#
# Epoch 72
# -------------------------------
# Training loss: 0.458530
# Validation loss: 0.465374
#
# Epoch 73
# -------------------------------
# Training loss: 0.458294
# Validation loss: 0.466397
#
# Epoch 74
# -------------------------------
# Training loss: 0.457135
# Validation loss: 0.461583
#
# Epoch 75
# -------------------------------
# Training loss: 0.455434
# Validation loss: 0.467559
#
# Epoch 76
# -------------------------------
# Training loss: 0.456524
# Validation loss: 0.458789
#
# Epoch 77
# -------------------------------
# Training loss: 0.455407
# Validation loss: 0.462542
#
# Epoch 78
# -------------------------------
# Training loss: 0.453742
# Validation loss: 0.455740
#
# Epoch 79
# -------------------------------
# Training loss: 0.454337
# Validation loss: 0.455978
#
# Epoch 80
# -------------------------------
# Training loss: 0.452447
# Validation loss: 0.456885
#
# Epoch 81
# -------------------------------
# Training loss: 0.451116
# Validation loss: 0.457772
#
# Epoch 82
# -------------------------------
# Training loss: 0.450090
# Validation loss: 0.455834
#
# Epoch 83
# -------------------------------
# Training loss: 0.448025
# Validation loss: 0.459333
#
# Epoch 84
# -------------------------------
# Training loss: 0.449178
# Validation loss: 0.450733
#
# Epoch 85
# -------------------------------
# Training loss: 0.446617
# Validation loss: 0.453365
#
# Epoch 86
# -------------------------------
# Training loss: 0.446609
# Validation loss: 0.450633
#
# Epoch 87
# -------------------------------
# Training loss: 0.445457
# Validation loss: 0.452234
#
# Epoch 88
# -------------------------------
# Training loss: 0.447666
# Validation loss: 0.445243
#
# Epoch 89
# -------------------------------
# Training loss: 0.443937
# Validation loss: 0.452003
#
# Epoch 90
# -------------------------------
# Training loss: 0.442317
# Validation loss: 0.450916
#
# Epoch 91
# -------------------------------
# Training loss: 0.442527
# Validation loss: 0.448624
#
# Epoch 92
# -------------------------------
# Training loss: 0.441323
# Validation loss: 0.444064
#
# Epoch 93
# -------------------------------
# Training loss: 0.441164
# Validation loss: 0.448092
#
# Epoch 94
# -------------------------------
# Training loss: 0.439886
# Validation loss: 0.442125
#
# Epoch 95
# -------------------------------
# Training loss: 0.438305
# Validation loss: 0.448036
#
# Epoch 96
# -------------------------------
# Training loss: 0.437926
# Validation loss: 0.443294
#
# Epoch 97
# -------------------------------
# Training loss: 0.436655
# Validation loss: 0.441687
#
# Epoch 98
# -------------------------------
# Training loss: 0.438184
# Validation loss: 0.437255
#
# Epoch 99
# -------------------------------
# Training loss: 0.436041
# Validation loss: 0.442321
#
# Epoch 100
# -------------------------------
# Training loss: 0.435862
# Validation loss: 0.436882
#
# Epoch 101
# -------------------------------
# Training loss: 0.434642
# Validation loss: 0.439596
#
# Epoch 102
# -------------------------------
# Training loss: 0.433503
# Validation loss: 0.439511
#
# Epoch 103
# -------------------------------
# Training loss: 0.434985
# Validation loss: 0.434765
#
# Epoch 104
# -------------------------------
# Training loss: 0.432710
# Validation loss: 0.435337
#
# Epoch 105
# -------------------------------
# Training loss: 0.432653
# Validation loss: 0.433698
#
# Epoch 106
# -------------------------------
# Training loss: 0.431762
# Validation loss: 0.440728
#
# Epoch 107
# -------------------------------
# Training loss: 0.430750
# Validation loss: 0.433656
#
# Epoch 108
# -------------------------------
# Training loss: 0.429556
# Validation loss: 0.437413
#
# Epoch 109
# -------------------------------
# Training loss: 0.431025
# Validation loss: 0.432419
#
# Epoch 110
# -------------------------------
# Training loss: 0.428286
# Validation loss: 0.435628
#
# Epoch 111
# -------------------------------
# Training loss: 0.426410
# Validation loss: 0.433882
#
# Epoch 112
# -------------------------------
# Training loss: 0.426745
# Validation loss: 0.428125
#
# Epoch 113
# -------------------------------
# Training loss: 0.427151
# Validation loss: 0.428277
#
# Epoch 114
# -------------------------------
# Training loss: 0.424605
# Validation loss: 0.433917
#
# Epoch 115
# -------------------------------
# Training loss: 0.425247
# Validation loss: 0.432096
#
# Epoch 116
# -------------------------------
# Training loss: 0.424210
# Validation loss: 0.426686
#
# Epoch 117
# -------------------------------
# Training loss: 0.424021
# Validation loss: 0.429577
#
# Epoch 118
# -------------------------------
# Training loss: 0.422459
# Validation loss: 0.429164
#
# Epoch 119
# -------------------------------
# Training loss: 0.422375
# Validation loss: 0.428958
#
# Epoch 120
# -------------------------------
# Training loss: 0.422730
# Validation loss: 0.424251
#
# Epoch 121
# -------------------------------
# Training loss: 0.420232
# Validation loss: 0.427006
#
# Epoch 122
# -------------------------------
# Training loss: 0.420921
# Validation loss: 0.422820
#
# Epoch 123
# -------------------------------
# Training loss: 0.419830
# Validation loss: 0.426419
#
# Epoch 124
# -------------------------------
# Training loss: 0.420566
# Validation loss: 0.421871
#
# Epoch 125
# -------------------------------
# Training loss: 0.418577
# Validation loss: 0.426560
#
# Epoch 126
# -------------------------------
# Training loss: 0.418912
# Validation loss: 0.418195
#
# Epoch 127
# -------------------------------
# Training loss: 0.416397
# Validation loss: 0.426199
#
# Epoch 128
# -------------------------------
# Training loss: 0.418317
# Validation loss: 0.417994
#
# Epoch 129
# -------------------------------
# Training loss: 0.416430
# Validation loss: 0.420505
#
# Epoch 130
# -------------------------------
# Training loss: 0.415145
# Validation loss: 0.421401
#
# Epoch 131
# -------------------------------
# Training loss: 0.416292
# Validation loss: 0.422126
#
# Epoch 132
# -------------------------------
# Training loss: 0.414164
# Validation loss: 0.417679
#
# Epoch 133
# -------------------------------
# Training loss: 0.412305
# Validation loss: 0.422652
#
# Epoch 134
# -------------------------------
# Training loss: 0.413729
# Validation loss: 0.415794
#
# Epoch 135
# -------------------------------
# Training loss: 0.411972
# Validation loss: 0.419767
#
# Epoch 136
# -------------------------------
# Training loss: 0.412259
# Validation loss: 0.417082
#
# Epoch 137
# -------------------------------
# Training loss: 0.412456
# Validation loss: 0.416853
#
# Epoch 138
# -------------------------------
# Training loss: 0.410447
# Validation loss: 0.419092
#
# Epoch 139
# -------------------------------
# Training loss: 0.410201
# Validation loss: 0.415048
#
# Epoch 140
# -------------------------------
# Training loss: 0.408846
# Validation loss: 0.411735
#
# Epoch 141
# -------------------------------
# Training loss: 0.408014
# Validation loss: 0.416526
#
# Epoch 142
# -------------------------------
# Training loss: 0.408651
# Validation loss: 0.414600
#
# Epoch 143
# -------------------------------
# Training loss: 0.407169
# Validation loss: 0.413833
#
# Epoch 144
# -------------------------------
# Training loss: 0.406934
# Validation loss: 0.409846
#
# Epoch 145
# -------------------------------
# Training loss: 0.408477
# Validation loss: 0.409960
#
# Epoch 146
# -------------------------------
# Training loss: 0.407481
# Validation loss: 0.408603
#
# Epoch 147
# -------------------------------
# Training loss: 0.406110
# Validation loss: 0.413105
#
# Epoch 148
# -------------------------------
# Training loss: 0.404300
# Validation loss: 0.412164
#
# Epoch 149
# -------------------------------
# Training loss: 0.404171
# Validation loss: 0.408684
#
# Epoch 150
# -------------------------------
# Training loss: 0.404315
# Validation loss: 0.405448
#
# Epoch 151
# -------------------------------
# Training loss: 0.401754
# Validation loss: 0.411252
#
# Epoch 152
# -------------------------------
# Training loss: 0.401163
# Validation loss: 0.404764
#
# Epoch 153
# -------------------------------
# Training loss: 0.401393
# Validation loss: 0.401225
#
# Epoch 154
# -------------------------------
# Training loss: 0.400496
# Validation loss: 0.408129
#
# Epoch 155
# -------------------------------
# Training loss: 0.399532
# Validation loss: 0.404434
#
# Epoch 156
# -------------------------------
# Training loss: 0.399546
# Validation loss: 0.406553
#
# Epoch 157
# -------------------------------
# Training loss: 0.399106
# Validation loss: 0.404686
#
# Epoch 158
# -------------------------------
# Training loss: 0.399141
# Validation loss: 0.407657
#
# Epoch 159
# -------------------------------
# Training loss: 0.398275
# Validation loss: 0.407162
#
# Epoch 160
# -------------------------------
# Training loss: 0.397888
# Validation loss: 0.401185
#
# Epoch 161
# -------------------------------
# Training loss: 0.397365
# Validation loss: 0.405814
#
# Epoch 162
# -------------------------------
# Training loss: 0.396694
# Validation loss: 0.400171
#
# Epoch 163
# -------------------------------
# Training loss: 0.396086
# Validation loss: 0.404285
#
# Epoch 164
# -------------------------------
# Training loss: 0.396200
# Validation loss: 0.401793
#
# Epoch 165
# -------------------------------
# Training loss: 0.395474
# Validation loss: 0.399238
#
# Epoch 166
# -------------------------------
# Training loss: 0.394306
# Validation loss: 0.397436
#
# Epoch 167
# -------------------------------
# Training loss: 0.394759
# Validation loss: 0.401107
#
# Epoch 168
# -------------------------------
# Training loss: 0.393558
# Validation loss: 0.396916
#
# Epoch 169
# -------------------------------
# Training loss: 0.393369
# Validation loss: 0.395914
#
# Epoch 170
# -------------------------------
# Training loss: 0.392449
# Validation loss: 0.398274
#
# Epoch 171
# -------------------------------
# Training loss: 0.391195
# Validation loss: 0.401888
#
# Epoch 172
# -------------------------------
# Training loss: 0.392469
# Validation loss: 0.401222
#
# Epoch 173
# -------------------------------
# Training loss: 0.391964
# Validation loss: 0.394697
#
# Epoch 174
# -------------------------------
# Training loss: 0.390400
# Validation loss: 0.392798
#
# Epoch 175
# -------------------------------
# Training loss: 0.389748
# Validation loss: 0.394469
#
# Epoch 176
# -------------------------------
# Training loss: 0.389378
# Validation loss: 0.401979
#
# Epoch 177
# -------------------------------
# Training loss: 0.388619
# Validation loss: 0.393187
#
# Epoch 178
# -------------------------------
# Training loss: 0.388113
# Validation loss: 0.395155
#
# Epoch 179
# -------------------------------
# Training loss: 0.388265
# Validation loss: 0.391755
#
# Epoch 180
# -------------------------------
# Training loss: 0.387211
# Validation loss: 0.392827
#
# Epoch 181
# -------------------------------
# Training loss: 0.387212
# Validation loss: 0.393722
#
# Epoch 182
# -------------------------------
# Training loss: 0.385589
# Validation loss: 0.393876
#
# Epoch 183
# -------------------------------
# Training loss: 0.386994
# Validation loss: 0.394966
#
# Epoch 184
# -------------------------------
# Training loss: 0.385371
# Validation loss: 0.393299
#
# Epoch 185
# -------------------------------
# Training loss: 0.386502
# Validation loss: 0.388098
#
# Epoch 186
# -------------------------------
# Training loss: 0.384888
# Validation loss: 0.393860
#
# Epoch 187
# -------------------------------
# Training loss: 0.384846
# Validation loss: 0.388424
#
# Epoch 188
# -------------------------------
# Training loss: 0.383504
# Validation loss: 0.394825
#
# Epoch 189
# -------------------------------
# Training loss: 0.383881
# Validation loss: 0.390667
#
# Epoch 190
# -------------------------------
# Training loss: 0.382247
# Validation loss: 0.390807
#
# Epoch 191
# -------------------------------
# Training loss: 0.382687
# Validation loss: 0.389518
#
# Epoch 192
# -------------------------------
# Training loss: 0.383642
# Validation loss: 0.385220
#
# Epoch 193
# -------------------------------
# Training loss: 0.381266
# Validation loss: 0.390832
#
# Epoch 194
# -------------------------------
# Training loss: 0.380124
# Validation loss: 0.391368
#
# Epoch 195
# -------------------------------
# Training loss: 0.381682
# Validation loss: 0.383406
#
# Epoch 196
# -------------------------------
# Training loss: 0.379154
# Validation loss: 0.382084
#
# Epoch 197
# -------------------------------
# Training loss: 0.379912
# Validation loss: 0.387926
#
# Epoch 198
# -------------------------------
# Training loss: 0.378834
# Validation loss: 0.390177
#
# Epoch 199
# -------------------------------
# Training loss: 0.379494
# Validation loss: 0.388613
#
# Epoch 200
# -------------------------------
# Training loss: 0.378796
# Validation loss: 0.385965
#
# Epoch 201
# -------------------------------
# Training loss: 0.377482
# Validation loss: 0.384337
#
# Epoch 202
# -------------------------------
# Training loss: 0.376093
# Validation loss: 0.385282
#
# Epoch 203
# -------------------------------
# Training loss: 0.377168
# Validation loss: 0.383096
#
# Epoch 204
# -------------------------------
# Training loss: 0.376118
# Validation loss: 0.383005
#
# Epoch 205
# -------------------------------
# Training loss: 0.375620
# Validation loss: 0.386592
#
# Epoch 206
# -------------------------------
# Training loss: 0.375290
# Validation loss: 0.378876
#
# Epoch 207
# -------------------------------
# Training loss: 0.375121
# Validation loss: 0.382078
#
# Epoch 208
# -------------------------------
# Training loss: 0.374386
# Validation loss: 0.387156
#
# Epoch 209
# -------------------------------
# Training loss: 0.375441
# Validation loss: 0.381658
#
# Epoch 210
# -------------------------------
# Training loss: 0.373818
# Validation loss: 0.382498
#
# Epoch 211
# -------------------------------
# Training loss: 0.373508
# Validation loss: 0.378472
#
# Epoch 212
# -------------------------------
# Training loss: 0.374359
# Validation loss: 0.381217
#
# Epoch 213
# -------------------------------
# Training loss: 0.372593
# Validation loss: 0.384324
#
# Epoch 214
# -------------------------------
# Training loss: 0.371650
# Validation loss: 0.380939
#
# Epoch 215
# -------------------------------
# Training loss: 0.373598
# Validation loss: 0.377826
#
# Epoch 216
# -------------------------------
# Training loss: 0.371570
# Validation loss: 0.380190
#
# Epoch 217
# -------------------------------
# Training loss: 0.370829
# Validation loss: 0.385132
#
# Epoch 218
# -------------------------------
# Training loss: 0.370273
# Validation loss: 0.378598
#
# Epoch 219
# -------------------------------
# Training loss: 0.369475
# Validation loss: 0.380997
#
# Epoch 220
# -------------------------------
# Training loss: 0.371427
# Validation loss: 0.374052
#
# Epoch 221
# -------------------------------
# Training loss: 0.369811
# Validation loss: 0.375287
#
# Epoch 222
# -------------------------------
# Training loss: 0.368854
# Validation loss: 0.379109
#
# Epoch 223
# -------------------------------
# Training loss: 0.369790
# Validation loss: 0.369626
#
# Epoch 224
# -------------------------------
# Training loss: 0.368299
# Validation loss: 0.378137
#
# Epoch 225
# -------------------------------
# Training loss: 0.369651
# Validation loss: 0.370248
#
# Epoch 226
# -------------------------------
# Training loss: 0.367571
# Validation loss: 0.381764
#
# Epoch 227
# -------------------------------
# Training loss: 0.367968
# Validation loss: 0.373324
#
# Epoch 228
# -------------------------------
# Training loss: 0.367167
# Validation loss: 0.379512
#
# Epoch 229
# -------------------------------
# Training loss: 0.366978
# Validation loss: 0.371825
#
# Epoch 230
# -------------------------------
# Training loss: 0.365153
# Validation loss: 0.377700
#
# Epoch 231
# -------------------------------
# Training loss: 0.364939
# Validation loss: 0.376767
#
# Epoch 232
# -------------------------------
# Training loss: 0.364510
# Validation loss: 0.370758
#
# Epoch 233
# -------------------------------
# Training loss: 0.364937
# Validation loss: 0.365991
#
# Epoch 234
# -------------------------------
# Training loss: 0.365913
# Validation loss: 0.374461
#
# Epoch 235
# -------------------------------
# Training loss: 0.365110
# Validation loss: 0.367351
#
# Epoch 236
# -------------------------------
# Training loss: 0.363762
# Validation loss: 0.372329
#
# Epoch 237
# -------------------------------
# Training loss: 0.364002
# Validation loss: 0.375040
#
# Epoch 238
# -------------------------------
# Training loss: 0.363323
# Validation loss: 0.373436
#
# Epoch 239
# -------------------------------
# Training loss: 0.362472
# Validation loss: 0.374219
#
# Epoch 240
# -------------------------------
# Training loss: 0.361226
# Validation loss: 0.371173
#
# Epoch 241
# -------------------------------
# Training loss: 0.362308
# Validation loss: 0.365491
#
# Epoch 242
# -------------------------------
# Training loss: 0.361841
# Validation loss: 0.366549
#
# Epoch 243
# -------------------------------
# Training loss: 0.361058
# Validation loss: 0.371057
#
# Epoch 244
# -------------------------------
# Training loss: 0.360654
# Validation loss: 0.367473
#
# Epoch 245
# -------------------------------
# Training loss: 0.362389
# Validation loss: 0.368609
#
# Epoch 246
# -------------------------------
# Training loss: 0.359593
# Validation loss: 0.374196
#
# Epoch 247
# -------------------------------
# Training loss: 0.359862
# Validation loss: 0.371224
#
# Epoch 248
# -------------------------------
# Training loss: 0.360680
# Validation loss: 0.363017
#
# Epoch 249
# -------------------------------
# Training loss: 0.359264
# Validation loss: 0.364488
#
# Epoch 250
# -------------------------------
# Training loss: 0.358358
# Validation loss: 0.368131
#
# Epoch 251
# -------------------------------
# Training loss: 0.358850
# Validation loss: 0.369066
#
# Epoch 252
# -------------------------------
# Training loss: 0.358466
# Validation loss: 0.366884
#
# Epoch 253
# -------------------------------
# Training loss: 0.358340
# Validation loss: 0.362805
#
# Epoch 254
# -------------------------------
# Training loss: 0.358034
# Validation loss: 0.365583
#
# Epoch 255
# -------------------------------
# Training loss: 0.360056
# Validation loss: 0.360928
#
# Epoch 256
# -------------------------------
# Training loss: 0.358397
# Validation loss: 0.363176
#
# Epoch 257
# -------------------------------
# Training loss: 0.355657
# Validation loss: 0.370419
#
# Epoch 258
# -------------------------------
# Training loss: 0.355892
# Validation loss: 0.370078
#
# Epoch 259
# -------------------------------
# Training loss: 0.355091
# Validation loss: 0.373902
#
# Epoch 260
# -------------------------------
# Training loss: 0.354731
# Validation loss: 0.368247
#
# Epoch 261
# -------------------------------
# Training loss: 0.355966
# Validation loss: 0.366509
#
# Epoch 262
# -------------------------------
# Training loss: 0.356175
# Validation loss: 0.360667
#
# Epoch 263
# -------------------------------
# Training loss: 0.353576
# Validation loss: 0.368114
#
# Epoch 264
# -------------------------------
# Training loss: 0.354008
# Validation loss: 0.360019
#
# Epoch 265
# -------------------------------
# Training loss: 0.354108
# Validation loss: 0.367866
#
# Epoch 266
# -------------------------------
# Training loss: 0.353190
# Validation loss: 0.361824
#
# Epoch 267
# -------------------------------
# Training loss: 0.352859
# Validation loss: 0.366973
#
# Epoch 268
# -------------------------------
# Training loss: 0.352276
# Validation loss: 0.366030
#
# Epoch 269
# -------------------------------
# Training loss: 0.351628
# Validation loss: 0.363873
#
# Epoch 270
# -------------------------------
# Training loss: 0.352970
# Validation loss: 0.356677
#
# Epoch 271
# -------------------------------
# Training loss: 0.352020
# Validation loss: 0.361706
#
# Epoch 272
# -------------------------------
# Training loss: 0.351225
# Validation loss: 0.360134
#
# Epoch 273
# -------------------------------
# Training loss: 0.352490
# Validation loss: 0.359807
#
# Epoch 274
# -------------------------------
# Training loss: 0.350893
# Validation loss: 0.360719
#
# Epoch 275
# -------------------------------
# Training loss: 0.349693
# Validation loss: 0.367377
#
# Epoch 276
# -------------------------------
# Training loss: 0.350142
# Validation loss: 0.356459
#
# Epoch 277
# -------------------------------
# Training loss: 0.349845
# Validation loss: 0.363815
#
# Epoch 278
# -------------------------------
# Training loss: 0.348865
# Validation loss: 0.363825
#
# Epoch 279
# -------------------------------
# Training loss: 0.349039
# Validation loss: 0.354199
#
# Epoch 280
# -------------------------------
# Training loss: 0.349175
# Validation loss: 0.359858
#
# Epoch 281
# -------------------------------
# Training loss: 0.348517
# Validation loss: 0.357951
#
# Epoch 282
# -------------------------------
# Training loss: 0.347819
# Validation loss: 0.358910
#
# Epoch 283
# -------------------------------
# Training loss: 0.348461
# Validation loss: 0.357688
#
# Epoch 284
# -------------------------------
# Training loss: 0.348022
# Validation loss: 0.357060
#
# Epoch 285
# -------------------------------
# Training loss: 0.346909
# Validation loss: 0.356504
#
# Epoch 286
# -------------------------------
# Training loss: 0.346933
# Validation loss: 0.360744
#
# Epoch 287
# -------------------------------
# Training loss: 0.345565
# Validation loss: 0.357454
#
# Epoch 288
# -------------------------------
# Training loss: 0.347044
# Validation loss: 0.357403
#
# Epoch 289
# -------------------------------
# Training loss: 0.345330
# Validation loss: 0.354502
#
# Epoch 290
# -------------------------------
# Training loss: 0.346416
# Validation loss: 0.350858
#
# Epoch 291
# -------------------------------
# Training loss: 0.345582
# Validation loss: 0.352904
#
# Epoch 292
# -------------------------------
# Training loss: 0.345032
# Validation loss: 0.354091
#
# Epoch 293
# -------------------------------
# Training loss: 0.344553
# Validation loss: 0.357136
#
# Epoch 294
# -------------------------------
# Training loss: 0.345200
# Validation loss: 0.355309
#
# Epoch 295
# -------------------------------
# Training loss: 0.343538
# Validation loss: 0.358030
#
# Epoch 296
# -------------------------------
# Training loss: 0.344147
# Validation loss: 0.348209
#
# Epoch 297
# -------------------------------
# Training loss: 0.343503
# Validation loss: 0.355517
#
# Epoch 298
# -------------------------------
# Training loss: 0.342734
# Validation loss: 0.354249
#
# Epoch 299
# -------------------------------
# Training loss: 0.342397
# Validation loss: 0.360713
#
# Epoch 300
# -------------------------------
# Training loss: 0.342653
# Validation loss: 0.350232
#
# Epoch 301
# -------------------------------
# Training loss: 0.342553
# Validation loss: 0.352144
#
# Epoch 302
# -------------------------------
# Training loss: 0.342690
# Validation loss: 0.350476
#
# Epoch 303
# -------------------------------
# Training loss: 0.340359
# Validation loss: 0.354208
#
# Epoch 304
# -------------------------------
# Training loss: 0.340979
# Validation loss: 0.352931
#
# Epoch 305
# -------------------------------
# Training loss: 0.342678
# Validation loss: 0.351922
#
# Epoch 306
# -------------------------------
# Training loss: 0.340146
# Validation loss: 0.356489
#
# Epoch 307
# -------------------------------
# Training loss: 0.340545
# Validation loss: 0.349921
#
# Epoch 308
# -------------------------------
# Training loss: 0.339232
# Validation loss: 0.353766
#
# Epoch 309
# -------------------------------
# Training loss: 0.340211
# Validation loss: 0.348407
#
# Epoch 310
# -------------------------------
# Training loss: 0.338894
# Validation loss: 0.348962
#
# Epoch 311
# -------------------------------
# Training loss: 0.339769
# Validation loss: 0.348414
#
# Epoch 312
# -------------------------------
# Training loss: 0.338341
# Validation loss: 0.353617
#
# Epoch 313
# -------------------------------
# Training loss: 0.338152
# Validation loss: 0.351204
#
# Epoch 314
# -------------------------------
# Training loss: 0.338961
# Validation loss: 0.348799
#
# Epoch 315
# -------------------------------
# Training loss: 0.338411
# Validation loss: 0.349237
#
# Epoch 316
# -------------------------------
# Training loss: 0.337136
# Validation loss: 0.350958
#
# Epoch 317
# -------------------------------
# Training loss: 0.337603
# Validation loss: 0.354364
#
# Epoch 318
# -------------------------------
# Training loss: 0.336609
# Validation loss: 0.348580
#
# Epoch 319
# -------------------------------
# Training loss: 0.336649
# Validation loss: 0.347847
#
# Epoch 320
# -------------------------------
# Training loss: 0.336708
# Validation loss: 0.346529
#
# Epoch 321
# -------------------------------
# Training loss: 0.336931
# Validation loss: 0.344659
#
# Epoch 322
# -------------------------------
# Training loss: 0.335557
# Validation loss: 0.347569
#
# Epoch 323
# -------------------------------
# Training loss: 0.335754
# Validation loss: 0.345109
#
# Epoch 324
# -------------------------------
# Training loss: 0.336069
# Validation loss: 0.345045
#
# Epoch 325
# -------------------------------
# Training loss: 0.336244
# Validation loss: 0.342066
#
# Epoch 326
# -------------------------------
# Training loss: 0.335352
# Validation loss: 0.353632
#
# Epoch 327
# -------------------------------
# Training loss: 0.334948
# Validation loss: 0.342804
#
# Epoch 328
# -------------------------------
# Training loss: 0.334532
# Validation loss: 0.349670
#
# Epoch 329
# -------------------------------
# Training loss: 0.334036
# Validation loss: 0.342924
#
# Epoch 330
# -------------------------------
# Training loss: 0.332988
# Validation loss: 0.341421
#
# Epoch 331
# -------------------------------
# Training loss: 0.333416
# Validation loss: 0.347231
#
# Epoch 332
# -------------------------------
# Training loss: 0.332574
# Validation loss: 0.341720
#
# Epoch 333
# -------------------------------
# Training loss: 0.333284
# Validation loss: 0.343678
#
# Epoch 334
# -------------------------------
# Training loss: 0.333482
# Validation loss: 0.342873
#
# Epoch 335
# -------------------------------
# Training loss: 0.332154
# Validation loss: 0.342613
#
# Epoch 336
# -------------------------------
# Training loss: 0.332137
# Validation loss: 0.345650
#
# Epoch 337
# -------------------------------
# Training loss: 0.332413
# Validation loss: 0.342601
#
# Epoch 338
# -------------------------------
# Training loss: 0.331019
# Validation loss: 0.338811
#
# Epoch 339
# -------------------------------
# Training loss: 0.331492
# Validation loss: 0.344912
#
# Epoch 340
# -------------------------------
# Training loss: 0.332480
# Validation loss: 0.345554
#
# Epoch 341
# -------------------------------
# Training loss: 0.332157
# Validation loss: 0.337357
#
# Epoch 342
# -------------------------------
# Training loss: 0.329976
# Validation loss: 0.346521
#
# Epoch 343
# -------------------------------
# Training loss: 0.330263
# Validation loss: 0.345751
#
# Epoch 344
# -------------------------------
# Training loss: 0.331584
# Validation loss: 0.342629
#
# Epoch 345
# -------------------------------
# Training loss: 0.329611
# Validation loss: 0.338002
#
# Epoch 346
# -------------------------------
# Training loss: 0.329918
# Validation loss: 0.342562
#
# Epoch 347
# -------------------------------
# Training loss: 0.330478
# Validation loss: 0.340308
#
# Epoch 348
# -------------------------------
# Training loss: 0.329933
# Validation loss: 0.344304
#
# Epoch 349
# -------------------------------
# Training loss: 0.328599
# Validation loss: 0.340176
#
# Epoch 350
# -------------------------------
# Training loss: 0.328450
# Validation loss: 0.343519
#
# Epoch 351
# -------------------------------
# Training loss: 0.328133
# Validation loss: 0.343909
#
# Epoch 352
# -------------------------------
# Training loss: 0.328247
# Validation loss: 0.341634
#
# Epoch 353
# -------------------------------
# Training loss: 0.329098
# Validation loss: 0.334467
#
# Epoch 354
# -------------------------------
# Training loss: 0.327027
# Validation loss: 0.338028
#
# Epoch 355
# -------------------------------
# Training loss: 0.327084
# Validation loss: 0.340799
#
# Epoch 356
# -------------------------------
# Training loss: 0.326599
# Validation loss: 0.338809
#
# Epoch 357
# -------------------------------
# Training loss: 0.326126
# Validation loss: 0.342509
#
# Epoch 358
# -------------------------------
# Training loss: 0.324779
# Validation loss: 0.338667
#
# Epoch 359
# -------------------------------
# Training loss: 0.326574
# Validation loss: 0.332070
#
# Epoch 360
# -------------------------------
# Training loss: 0.326061
# Validation loss: 0.341932
#
# Epoch 361
# -------------------------------
# Training loss: 0.325233
# Validation loss: 0.337817
#
# Epoch 362
# -------------------------------
# Training loss: 0.325661
# Validation loss: 0.334167
#
# Epoch 363
# -------------------------------
# Training loss: 0.325585
# Validation loss: 0.339484
#
# Epoch 364
# -------------------------------
# Training loss: 0.325879
# Validation loss: 0.332593
#
# Epoch 365
# -------------------------------
# Training loss: 0.325429
# Validation loss: 0.347254
#
# Epoch 366
# -------------------------------
# Training loss: 0.323871
# Validation loss: 0.346129
#
# Epoch 367
# -------------------------------
# Training loss: 0.324083
# Validation loss: 0.336179
#
# Epoch 368
# -------------------------------
# Training loss: 0.322909
# Validation loss: 0.330723
#
# Epoch 369
# -------------------------------
# Training loss: 0.324071
# Validation loss: 0.332570
#
# Epoch 370
# -------------------------------
# Training loss: 0.322941
# Validation loss: 0.334254
#
# Epoch 371
# -------------------------------
# Training loss: 0.322639
# Validation loss: 0.339061
#
# Epoch 372
# -------------------------------
# Training loss: 0.322311
# Validation loss: 0.333092
#
# Epoch 373
# -------------------------------
# Training loss: 0.322612
# Validation loss: 0.338739
#
# Epoch 374
# -------------------------------
# Training loss: 0.321350
# Validation loss: 0.342580
#
# Epoch 375
# -------------------------------
# Training loss: 0.321524
# Validation loss: 0.344919
#
# Epoch 376
# -------------------------------
# Training loss: 0.320325
# Validation loss: 0.328985
#
# Epoch 377
# -------------------------------
# Training loss: 0.321274
# Validation loss: 0.334969
#
# Epoch 378
# -------------------------------
# Training loss: 0.321042
# Validation loss: 0.339994
#
# Epoch 379
# -------------------------------
# Training loss: 0.321217
# Validation loss: 0.332204
#
# Epoch 380
# -------------------------------
# Training loss: 0.320899
# Validation loss: 0.342125
#
# Epoch 381
# -------------------------------
# Training loss: 0.320935
# Validation loss: 0.332708
#
# Epoch 382
# -------------------------------
# Training loss: 0.320956
# Validation loss: 0.342435
#
# Epoch 383
# -------------------------------
# Training loss: 0.320315
# Validation loss: 0.332489
#
# Epoch 384
# -------------------------------
# Training loss: 0.318930
# Validation loss: 0.342400
#
# Epoch 385
# -------------------------------
# Training loss: 0.318751
# Validation loss: 0.332105
#
# Epoch 386
# -------------------------------
# Training loss: 0.319515
# Validation loss: 0.336489
#
# Epoch 387
# -------------------------------
# Training loss: 0.320254
# Validation loss: 0.329766
#
# Epoch 388
# -------------------------------
# Training loss: 0.319429
# Validation loss: 0.334601
#
# Epoch 389
# -------------------------------
# Training loss: 0.318885
# Validation loss: 0.331801
#
# Epoch 390
# -------------------------------
# Training loss: 0.317927
# Validation loss: 0.334489
#
# Epoch 391
# -------------------------------
# Training loss: 0.317998
# Validation loss: 0.335829
#
# Epoch 392
# -------------------------------
# Training loss: 0.318868
# Validation loss: 0.332200
#
# Epoch 393
# -------------------------------
# Training loss: 0.318428
# Validation loss: 0.329792
#
# Epoch 394
# -------------------------------
# Training loss: 0.317885
# Validation loss: 0.331156
#
# Epoch 395
# -------------------------------
# Training loss: 0.317612
# Validation loss: 0.333041
#
# Epoch 396
# -------------------------------
# Training loss: 0.316688
# Validation loss: 0.334056
#
# Epoch 397
# -------------------------------
# Training loss: 0.318142
# Validation loss: 0.329514
#
# Epoch 398
# -------------------------------
# Training loss: 0.315087
# Validation loss: 0.334941
#
# Epoch 399
# -------------------------------
# Training loss: 0.315687
# Validation loss: 0.331574
#
# Epoch 400
# -------------------------------
# Training loss: 0.318436
# Validation loss: 0.328515
#
# Epoch 401
# -------------------------------
# Training loss: 0.316042
# Validation loss: 0.332837
#
# Epoch 402
# -------------------------------
# Training loss: 0.314472
# Validation loss: 0.334431
#
# Epoch 403
# -------------------------------
# Training loss: 0.315041
# Validation loss: 0.333640
#
# Epoch 404
# -------------------------------
# Training loss: 0.315673
# Validation loss: 0.332484
#
# Epoch 405
# -------------------------------
# Training loss: 0.314256
# Validation loss: 0.335446
#
# Epoch 406
# -------------------------------
# Training loss: 0.315070
# Validation loss: 0.331493
#
# Epoch 407
# -------------------------------
# Training loss: 0.313816
# Validation loss: 0.329780
#
# Epoch 408
# -------------------------------
# Training loss: 0.314099
# Validation loss: 0.336599
#
# Epoch 409
# -------------------------------
# Training loss: 0.315572
# Validation loss: 0.326080
#
# Epoch 410
# -------------------------------
# Training loss: 0.313008
# Validation loss: 0.330215
#
# Epoch 411
# -------------------------------
# Training loss: 0.314108
# Validation loss: 0.325341
#
# Epoch 412
# -------------------------------
# Training loss: 0.312294
# Validation loss: 0.346189
#
# Epoch 413
# -------------------------------
# Training loss: 0.313106
# Validation loss: 0.324567
#
# Epoch 414
# -------------------------------
# Training loss: 0.312422
# Validation loss: 0.335104
#
# Epoch 415
# -------------------------------
# Training loss: 0.312814
# Validation loss: 0.334792
#
# Epoch 416
# -------------------------------
# Training loss: 0.312555
# Validation loss: 0.327100
#
# Epoch 417
# -------------------------------
# Training loss: 0.312294
# Validation loss: 0.334609
#
# Epoch 418
# -------------------------------
# Training loss: 0.312322
# Validation loss: 0.326641
#
# Epoch 419
# -------------------------------
# Training loss: 0.311747
# Validation loss: 0.332502
#
# Epoch 420
# -------------------------------
# Training loss: 0.311857
# Validation loss: 0.338698
#
# Epoch 421
# -------------------------------
# Training loss: 0.310968
# Validation loss: 0.331788
#
# Epoch 422
# -------------------------------
# Training loss: 0.313067
# Validation loss: 0.327924
#
# Epoch 423
# -------------------------------
# Training loss: 0.310923
# Validation loss: 0.331878
#
# Epoch 424
# -------------------------------
# Training loss: 0.309892
# Validation loss: 0.332430
#
# Epoch 425
# -------------------------------
# Training loss: 0.309714
# Validation loss: 0.334511
#
# Epoch 426
# -------------------------------
# Training loss: 0.310925
# Validation loss: 0.319984
#
# Epoch 427
# -------------------------------
# Training loss: 0.308972
# Validation loss: 0.335258
#
# Epoch 428
# -------------------------------
# Training loss: 0.309647
# Validation loss: 0.323926
#
# Epoch 429
# -------------------------------
# Training loss: 0.309287
# Validation loss: 0.322598
#
# Epoch 430
# -------------------------------
# Training loss: 0.308880
# Validation loss: 0.331260
#
# Epoch 431
# -------------------------------
# Training loss: 0.308025
# Validation loss: 0.326234
#
# Epoch 432
# -------------------------------
# Training loss: 0.308537
# Validation loss: 0.319607
#
# Epoch 433
# -------------------------------
# Training loss: 0.307518
# Validation loss: 0.329475
#
# Epoch 434
# -------------------------------
# Training loss: 0.307856
# Validation loss: 0.318699
#
# Epoch 435
# -------------------------------
# Training loss: 0.307589
# Validation loss: 0.323824
#
# Epoch 436
# -------------------------------
# Training loss: 0.307540
# Validation loss: 0.322663
#
# Epoch 437
# -------------------------------
# Training loss: 0.306674
# Validation loss: 0.315041
#
# Epoch 438
# -------------------------------
# Training loss: 0.306471
# Validation loss: 0.317227
#
# Epoch 439
# -------------------------------
# Training loss: 0.306065
# Validation loss: 0.326050
#
# Epoch 440
# -------------------------------
# Training loss: 0.305098
# Validation loss: 0.317051
#
# Epoch 441
# -------------------------------
# Training loss: 0.307035
# Validation loss: 0.321480
#
# Epoch 442
# -------------------------------
# Training loss: 0.305194
# Validation loss: 0.315407
#
# Epoch 443
# -------------------------------
# Training loss: 0.305607
# Validation loss: 0.312917
#
# Epoch 444
# -------------------------------
# Training loss: 0.305177
# Validation loss: 0.320834
#
# Epoch 445
# -------------------------------
# Training loss: 0.304903
# Validation loss: 0.315719
#
# Epoch 446
# -------------------------------
# Training loss: 0.304043
# Validation loss: 0.316614
#
# Epoch 447
# -------------------------------
# Training loss: 0.304656
# Validation loss: 0.320739
#
# Epoch 448
# -------------------------------
# Training loss: 0.304061
# Validation loss: 0.315380
#
# Epoch 449
# -------------------------------
# Training loss: 0.303732
# Validation loss: 0.320129
#
# Epoch 450
# -------------------------------
# Training loss: 0.303785
# Validation loss: 0.316255
#
# Epoch 451
# -------------------------------
# Training loss: 0.302791
# Validation loss: 0.315493
#
# Epoch 452
# -------------------------------
# Training loss: 0.302607
# Validation loss: 0.318708
#
# Epoch 453
# -------------------------------
# Training loss: 0.303491
# Validation loss: 0.312055
#
# Epoch 454
# -------------------------------
# Training loss: 0.302385
# Validation loss: 0.313231
#
# Epoch 455
# -------------------------------
# Training loss: 0.302272
# Validation loss: 0.321158
#
# Epoch 456
# -------------------------------
# Training loss: 0.302787
# Validation loss: 0.319367
#
# Epoch 457
# -------------------------------
# Training loss: 0.303075
# Validation loss: 0.306500
#
# Epoch 458
# -------------------------------
# Training loss: 0.302622
# Validation loss: 0.324857
#
# Epoch 459
# -------------------------------
# Training loss: 0.301662
# Validation loss: 0.311174
#
# Epoch 460
# -------------------------------
# Training loss: 0.301296
# Validation loss: 0.322731
#
# Epoch 461
# -------------------------------
# Training loss: 0.301149
# Validation loss: 0.324171
#
# Epoch 462
# -------------------------------
# Training loss: 0.301272
# Validation loss: 0.313725
#
# Epoch 463
# -------------------------------
# Training loss: 0.300579
# Validation loss: 0.318316
#
# Epoch 464
# -------------------------------
# Training loss: 0.299159
# Validation loss: 0.326979
#
# Epoch 465
# -------------------------------
# Training loss: 0.299952
# Validation loss: 0.313298
#
# Epoch 466
# -------------------------------
# Training loss: 0.300247
# Validation loss: 0.317449
#
# Epoch 467
# -------------------------------
# Training loss: 0.300221
# Validation loss: 0.316204
#
# Epoch 468
# -------------------------------
# Training loss: 0.299047
# Validation loss: 0.315899
#
# Epoch 469
# -------------------------------
# Training loss: 0.299096
# Validation loss: 0.319953
#
# Epoch 470
# -------------------------------
# Training loss: 0.301249
# Validation loss: 0.308043
#
# Epoch 471
# -------------------------------
# Training loss: 0.297488
# Validation loss: 0.312893
#
# Epoch 472
# -------------------------------
# Training loss: 0.298575
# Validation loss: 0.309499
#
# Epoch 473
# -------------------------------
# Training loss: 0.299188
# Validation loss: 0.315520
#
# Epoch 474
# -------------------------------
# Training loss: 0.297124
# Validation loss: 0.306163
#
# Epoch 475
# -------------------------------
# Training loss: 0.298410
# Validation loss: 0.337337
#
# Epoch 476
# -------------------------------
# Training loss: 0.299995
# Validation loss: 0.310925
#
# Epoch 477
# -------------------------------
# Training loss: 0.299430
# Validation loss: 0.312143
#
# Epoch 478
# -------------------------------
# Training loss: 0.297890
# Validation loss: 0.320612
#
# Epoch 479
# -------------------------------
# Training loss: 0.297735
# Validation loss: 0.314580
#
# Epoch 480
# -------------------------------
# Training loss: 0.296189
# Validation loss: 0.315587
#
# Epoch 481
# -------------------------------
# Training loss: 0.295997
# Validation loss: 0.314805
#
# Epoch 482
# -------------------------------
# Training loss: 0.295489
# Validation loss: 0.319148
#
# Epoch 483
# -------------------------------
# Training loss: 0.296747
# Validation loss: 0.297467
#
# Epoch 484
# -------------------------------
# Training loss: 0.296067
# Validation loss: 0.298454
#
# Epoch 485
# -------------------------------
# Training loss: 0.294779
# Validation loss: 0.308843
#
# Epoch 486
# -------------------------------
# Training loss: 0.296094
# Validation loss: 0.318808
#
# Epoch 487
# -------------------------------
# Training loss: 0.296806
# Validation loss: 0.303351
#
# Epoch 488
# -------------------------------
# Training loss: 0.295899
# Validation loss: 0.307158
#
# Epoch 489
# -------------------------------
# Training loss: 0.294938
# Validation loss: 0.299368
#
# Epoch 490
# -------------------------------
# Training loss: 0.294340
# Validation loss: 0.330202
#
# Epoch 491
# -------------------------------
# Training loss: 0.295738
# Validation loss: 0.304369
#
# Epoch 492
# -------------------------------
# Training loss: 0.294148
# Validation loss: 0.320268
#
# Epoch 493
# -------------------------------
# Training loss: 0.293456
# Validation loss: 0.307247
#
# Epoch 494
# -------------------------------
# Training loss: 0.293451
# Validation loss: 0.314033
#
# Epoch 495
# -------------------------------
# Training loss: 0.292776
# Validation loss: 0.312100
#
# Epoch 496
# -------------------------------
# Training loss: 0.291974
# Validation loss: 0.319382
#
# Epoch 497
# -------------------------------
# Training loss: 0.291884
# Validation loss: 0.305458
#
# Epoch 498
# -------------------------------
# Training loss: 0.292630
# Validation loss: 0.305534
#
# Epoch 499
# -------------------------------
# Training loss: 0.291120
# Validation loss: 0.296701
#
# Epoch 500
# -------------------------------
# Training loss: 0.291061
# Validation loss: 0.314296
#
# Epoch 501
# -------------------------------
# Training loss: 0.289569
# Validation loss: 0.312403
#
# Epoch 502
# -------------------------------
# Training loss: 0.293413
# Validation loss: 0.298304
#
# Epoch 503
# -------------------------------
# Training loss: 0.290506
# Validation loss: 0.298831
#
# Epoch 504
# -------------------------------
# Training loss: 0.289386
# Validation loss: 0.300365
#
# Epoch 505
# -------------------------------
# Training loss: 0.291762
# Validation loss: 0.302185
#
# Epoch 506
# -------------------------------
# Training loss: 0.289515
# Validation loss: 0.311909
#
# Epoch 507
# -------------------------------
# Training loss: 0.289721
# Validation loss: 0.294902
#
# Epoch 508
# -------------------------------
# Training loss: 0.289212
# Validation loss: 0.334721
#
# Epoch 509
# -------------------------------
# Training loss: 0.290264
# Validation loss: 0.304851
#
# Epoch 510
# -------------------------------
# Training loss: 0.290604
# Validation loss: 0.302583
#
# Epoch 511
# -------------------------------
# Training loss: 0.291196
# Validation loss: 0.310100
#
# Epoch 512
# -------------------------------
# Training loss: 0.287198
# ...
# Validation loss: 0.085562
#
# Epoch 2333
# -------------------------------
# Training loss: 0.078011
# Validation loss: 0.081624
#
# Epoch 2334
# -------------------------------
# Training loss: 0.078689
# Validation loss: 0.092519
#
# Epoch 2335
# -------------------------------
# Training loss: 0.076449
# Validation loss: 0.082069
#
# Epoch 2336
# -------------------------------
# Training loss: 0.075585
# Validation loss: 0.081271
#
# Epoch 2337
# -------------------------------
# Training loss: 0.074478
# Validation loss: 0.088429
#
# Epoch 2338
# -------------------------------
# Training loss: 0.076141
# Validation loss: 0.083693
#
# Epoch 2339
# -------------------------------
# Training loss: 0.078108
# Validation loss: 0.083604
#
# Epoch 2340
# -------------------------------
# Training loss: 0.079485
# Validation loss: 0.083350
#
# Epoch 2341
# -------------------------------
# Training loss: 0.076554
# Validation loss: 0.083848
#
# Epoch 2342
# -------------------------------
# Training loss: 0.076064
# Validation loss: 0.096823
#
# Epoch 2343
# -------------------------------
# Training loss: 0.079078
# Validation loss: 0.086195
#
# Epoch 2344
# -------------------------------
# Training loss: 0.074287
# Validation loss: 0.081673
#
# Epoch 2345
# -------------------------------
# Training loss: 0.074937
# Validation loss: 0.085594
#
# Epoch 2346
# -------------------------------
# Training loss: 0.078495
# Validation loss: 0.082191
#
# Epoch 2347
# -------------------------------
# Training loss: 0.076689
# Validation loss: 0.080366
#
# Epoch 2348
# -------------------------------
# Training loss: 0.074952
# Validation loss: 0.080945
#
# Epoch 2349
# -------------------------------
# Training loss: 0.078529
# Validation loss: 0.084700
#
# Epoch 2350
# -------------------------------
# Training loss: 0.079782
# Validation loss: 0.082813
#
# Epoch 2351
# -------------------------------
# Training loss: 0.077119
# Validation loss: 0.082101
#
# Epoch 2352
# -------------------------------
# Training loss: 0.078664
# Validation loss: 0.084421
#
# Epoch 2353
# -------------------------------
# Training loss: 0.077973
# Validation loss: 0.088770
#
# Epoch 2354
# -------------------------------
# Training loss: 0.075884
# Validation loss: 0.077958
#
# Epoch 2355
# -------------------------------
# Training loss: 0.083091
# Validation loss: 0.082543
#
# Epoch 2356
# -------------------------------
# Training loss: 0.076317
# Validation loss: 0.089173
#
# Epoch 2357
# -------------------------------
# Training loss: 0.082738
# Validation loss: 0.094294
#
# Epoch 2358
# -------------------------------
# Training loss: 0.075389
# Validation loss: 0.083979
#
# Epoch 2359
# -------------------------------
# Training loss: 0.083053
# Validation loss: 0.085958
#
# Epoch 2360
# -------------------------------
# Training loss: 0.075735
# Validation loss: 0.086949
#
# Epoch 2361
# -------------------------------
# Training loss: 0.076428
# Validation loss: 0.082197
#
# Epoch 2362
# -------------------------------
# Training loss: 0.076962
# Validation loss: 0.082070
#
# Epoch 2363
# -------------------------------
# Training loss: 0.075149
# Validation loss: 0.088818
#
# Epoch 2364
# -------------------------------
# Training loss: 0.075810
# Validation loss: 0.081965
#
# Epoch 2365
# -------------------------------
# Training loss: 0.079145
# Validation loss: 0.082583
#
# Epoch 2366
# -------------------------------
# Training loss: 0.079394
# Validation loss: 0.082256
#
# Epoch 2367
# -------------------------------
# Training loss: 0.078868
# Validation loss: 0.082156
#
# Epoch 2368
# -------------------------------
# Training loss: 0.074828
# Validation loss: 0.080071
#
# Epoch 2369
# -------------------------------
# Training loss: 0.079645
# Validation loss: 0.094488
#
# Epoch 2370
# -------------------------------
# Training loss: 0.076606
# Validation loss: 0.090006
#
# Epoch 2371
# -------------------------------
# Training loss: 0.074893
# Validation loss: 0.082606
#
# Epoch 2372
# -------------------------------
# Training loss: 0.076124
# Validation loss: 0.081988
#
# Epoch 2373
# -------------------------------
# Training loss: 0.074477
# Validation loss: 0.082149
#
# Epoch 2374
# -------------------------------
# Training loss: 0.076502
# Validation loss: 0.077335
#
# Epoch 2375
# -------------------------------
# Training loss: 0.074596
# Validation loss: 0.090184
#
# Epoch 2376
# -------------------------------
# Training loss: 0.076676
# Validation loss: 0.081356
#
# Epoch 2377
# -------------------------------
# Training loss: 0.077676
# Validation loss: 0.078703
#
# Epoch 2378
# -------------------------------
# Training loss: 0.073288
# Validation loss: 0.086953
#
# Epoch 2379
# -------------------------------
# Training loss: 0.074150
# Validation loss: 0.084956
#
# Epoch 2380
# -------------------------------
# Training loss: 0.078457
# Validation loss: 0.084543
#
# Epoch 2381
# -------------------------------
# Training loss: 0.075302
# Validation loss: 0.083687
#
# Epoch 2382
# -------------------------------
# Training loss: 0.078739
# Validation loss: 0.088147
#
# Epoch 2383
# -------------------------------
# Training loss: 0.077917
# Validation loss: 0.085045
#
# Epoch 2384
# -------------------------------
# Training loss: 0.076699
# Validation loss: 0.089207
#
# Epoch 2385
# -------------------------------
# Training loss: 0.076826
# Validation loss: 0.078947
#
# Epoch 2386
# -------------------------------
# Training loss: 0.078337
# Validation loss: 0.087104
#
# Epoch 2387
# -------------------------------
# Training loss: 0.073550
# Validation loss: 0.081911
#
# Epoch 2388
# -------------------------------
# Training loss: 0.078066
# Validation loss: 0.083832
#
# Epoch 2389
# -------------------------------
# Training loss: 0.077955
# Validation loss: 0.081760
#
# Epoch 2390
# -------------------------------
# Training loss: 0.076168
# Validation loss: 0.085892
#
# Epoch 2391
# -------------------------------
# Training loss: 0.075288
# Validation loss: 0.087980
#
# Epoch 2392
# -------------------------------
# Training loss: 0.073458
# Validation loss: 0.086233
#
# Epoch 2393
# -------------------------------
# Training loss: 0.074294
# Validation loss: 0.080966
#
# Epoch 2394
# -------------------------------
# Training loss: 0.076162
# Validation loss: 0.081304
#
# Epoch 2395
# -------------------------------
# Training loss: 0.079698
# Validation loss: 0.082335
#
# Epoch 2396
# -------------------------------
# Training loss: 0.077459
# Validation loss: 0.081498
#
# Epoch 2397
# -------------------------------
# Training loss: 0.075014
# Validation loss: 0.080835
#
# Epoch 2398
# -------------------------------
# Training loss: 0.074132
# Validation loss: 0.085078
#
# Epoch 2399
# -------------------------------
# Training loss: 0.077561
# Validation loss: 0.082404
#
# Epoch 2400
# -------------------------------
# Training loss: 0.074843
# Validation loss: 0.077737
#
# Epoch 2401
# -------------------------------
# Training loss: 0.078454
# Validation loss: 0.082673
#
# Epoch 2402
# -------------------------------
# Training loss: 0.077366
# Validation loss: 0.078561
#
# Epoch 2403
# -------------------------------
# Training loss: 0.077246
# Validation loss: 0.085549
#
# Epoch 2404
# -------------------------------
# Training loss: 0.078913
# Validation loss: 0.086360
#
# Epoch 2405
# -------------------------------
# Training loss: 0.077170
# Validation loss: 0.080275
#
# Epoch 2406
# -------------------------------
# Training loss: 0.073881
# Validation loss: 0.082926
#
# Epoch 2407
# -------------------------------
# Training loss: 0.078335
# Validation loss: 0.092668
#
# Epoch 2408
# -------------------------------
# Training loss: 0.079272
# Validation loss: 0.080844
#
# Epoch 2409
# -------------------------------
# Training loss: 0.077349
# Validation loss: 0.079278
#
# Epoch 2410
# -------------------------------
# Training loss: 0.072652
# Validation loss: 0.083410
#
# Epoch 2411
# -------------------------------
# Training loss: 0.075644
# Validation loss: 0.082243
#
# Epoch 2412
# -------------------------------
# Training loss: 0.073469
# Validation loss: 0.080261
#
# Epoch 2413
# -------------------------------
# Training loss: 0.075248
# Validation loss: 0.084125
#
# Epoch 2414
# -------------------------------
# Training loss: 0.073638
# Validation loss: 0.079368
#
# Epoch 2415
# -------------------------------
# Training loss: 0.075398
# Validation loss: 0.079305
#
# Epoch 2416
# -------------------------------
# Training loss: 0.073053
# Validation loss: 0.083307
#
# Epoch 2417
# -------------------------------
# Training loss: 0.080597
# Validation loss: 0.080851
#
# Epoch 2418
# -------------------------------
# Training loss: 0.074796
# Validation loss: 0.078739
#
# Epoch 2419
# -------------------------------
# Training loss: 0.074265
# Validation loss: 0.081099
#
# Epoch 2420
# -------------------------------
# Training loss: 0.078644
# Validation loss: 0.087225
#
# Epoch 2421
# -------------------------------
# Training loss: 0.078578
# Validation loss: 0.085691
#
# Epoch 2422
# -------------------------------
# Training loss: 0.075943
# Validation loss: 0.084127
#
# Epoch 2423
# -------------------------------
# Training loss: 0.073245
# Validation loss: 0.082166
#
# Epoch 2424
# -------------------------------
# Training loss: 0.078620
# Validation loss: 0.089221
#
# Epoch 2425
# -------------------------------
# Training loss: 0.073287
# Validation loss: 0.083609
#
# Epoch 2426
# -------------------------------
# Training loss: 0.078176
# Validation loss: 0.082694
#
# Epoch 2427
# -------------------------------
# Training loss: 0.075978
# Validation loss: 0.080449
#
# Epoch 2428
# -------------------------------
# Training loss: 0.077386
# Validation loss: 0.081507
#
# Epoch 2429
# -------------------------------
# Training loss: 0.075168
# Validation loss: 0.088227
#
# Epoch 2430
# -------------------------------
# Training loss: 0.073643
# Validation loss: 0.087646
#
# Epoch 2431
# -------------------------------
# Training loss: 0.072923
# Validation loss: 0.079995
#
# Epoch 2432
# -------------------------------
# Training loss: 0.075224
# Validation loss: 0.084994
#
# Epoch 2433
# -------------------------------
# Training loss: 0.077615
# Validation loss: 0.084012
#
# Epoch 2434
# -------------------------------
# Training loss: 0.076317
# Validation loss: 0.089161
#
# Epoch 2435
# -------------------------------
# Training loss: 0.077116
# Validation loss: 0.079989
#
# Epoch 2436
# -------------------------------
# Training loss: 0.073154
# Validation loss: 0.080768
#
# Epoch 2437
# -------------------------------
# Training loss: 0.073652
# Validation loss: 0.081021
#
# Epoch 2438
# -------------------------------
# Training loss: 0.077158
# Validation loss: 0.079295
#
# Epoch 2439
# -------------------------------
# Training loss: 0.082908
# Validation loss: 0.089933
#
# Epoch 2440
# -------------------------------
# Training loss: 0.079284
# Validation loss: 0.084388
#
# Epoch 2441
# -------------------------------
# Training loss: 0.076017
# Validation loss: 0.081340
#
# Epoch 2442
# -------------------------------
# Training loss: 0.075749
# Validation loss: 0.085608
#
# Epoch 2443
# -------------------------------
# Training loss: 0.077667
# Validation loss: 0.086468
#
# Epoch 2444
# -------------------------------
# Training loss: 0.072857
# Validation loss: 0.082198
#
# Epoch 2445
# -------------------------------
# Training loss: 0.080246
# Validation loss: 0.099028
#
# Epoch 2446
# -------------------------------
# Training loss: 0.075831
# Validation loss: 0.082525
#
# Epoch 2447
# -------------------------------
# Training loss: 0.072758
# Validation loss: 0.079922
#
# Epoch 2448
# -------------------------------
# Training loss: 0.076859
# Validation loss: 0.094308
#
# Epoch 2449
# -------------------------------
# Training loss: 0.076223
# Validation loss: 0.088467
#
# Epoch 2450
# -------------------------------
# Training loss: 0.075784
# Validation loss: 0.084726
#
# Epoch 2451
# -------------------------------
# Training loss: 0.075673
# Validation loss: 0.079742
#
# Epoch 2452
# -------------------------------
# Training loss: 0.076241
# Validation loss: 0.082376
#
# Epoch 2453
# -------------------------------
# Training loss: 0.073868
# Validation loss: 0.077257
#
# Epoch 2454
# -------------------------------
# Training loss: 0.073300
# Validation loss: 0.079310
#
# Epoch 2455
# -------------------------------
# Training loss: 0.073499
# Validation loss: 0.088171
#
# Epoch 2456
# -------------------------------
# Training loss: 0.077969
# Validation loss: 0.082202
#
# Epoch 2457
# -------------------------------
# Training loss: 0.077447
# Validation loss: 0.086734
#
# Epoch 2458
# -------------------------------
# Training loss: 0.079694
# Validation loss: 0.081135
#
# Epoch 2459
# -------------------------------
# Training loss: 0.074318
# Validation loss: 0.080731
#
# Epoch 2460
# -------------------------------
# Training loss: 0.074787
# Validation loss: 0.088010
#
# Epoch 2461
# -------------------------------
# Training loss: 0.077386
# Validation loss: 0.081723
#
# Epoch 2462
# -------------------------------
# Training loss: 0.075513
# Validation loss: 0.078586
#
# Epoch 2463
# -------------------------------
# Training loss: 0.077403
# Validation loss: 0.084279
#
# Epoch 2464
# -------------------------------
# Training loss: 0.071564
# Validation loss: 0.083293
#
# Epoch 2465
# -------------------------------
# Training loss: 0.077675
# Validation loss: 0.080509
#
# Epoch 2466
# -------------------------------
# Training loss: 0.077008
# Validation loss: 0.082871
#
# Epoch 2467
# -------------------------------
# Training loss: 0.074554
# Validation loss: 0.088641
#
# Epoch 2468
# -------------------------------
# Training loss: 0.071733
# Validation loss: 0.084551
#
# Epoch 2469
# -------------------------------
# Training loss: 0.072190
# Validation loss: 0.078935
#
# Epoch 2470
# -------------------------------
# Training loss: 0.074967
# Validation loss: 0.083882
#
# Epoch 2471
# -------------------------------
# Training loss: 0.074495
# Validation loss: 0.077411
#
# Epoch 2472
# -------------------------------
# Training loss: 0.076560
# Validation loss: 0.079444
#
# Epoch 2473
# -------------------------------
# Training loss: 0.078251
# Validation loss: 0.091181
#
# Epoch 2474
# -------------------------------
# Training loss: 0.076261
# Validation loss: 0.080575
#
# Epoch 2475
# -------------------------------
# Training loss: 0.080196
# Validation loss: 0.080125
#
# Epoch 2476
# -------------------------------
# Training loss: 0.074653
# Validation loss: 0.079235
#
# Epoch 2477
# -------------------------------
# Training loss: 0.074055
# Validation loss: 0.083551
#
# Epoch 2478
# -------------------------------
# Training loss: 0.076676
# Validation loss: 0.078636
#
# Epoch 2479
# -------------------------------
# Training loss: 0.072994
# Validation loss: 0.075659
#
# Epoch 2480
# -------------------------------
# Training loss: 0.080557
# Validation loss: 0.088567
#
# Epoch 2481
# -------------------------------
# Training loss: 0.075914
# Validation loss: 0.086366
#
# Epoch 2482
# -------------------------------
# Training loss: 0.072754
# Validation loss: 0.081390
#
# Epoch 2483
# -------------------------------
# Training loss: 0.077718
# Validation loss: 0.078382
#
# Epoch 2484
# -------------------------------
# Training loss: 0.074544
# Validation loss: 0.087503
#
# Epoch 2485
# -------------------------------
# Training loss: 0.074521
# Validation loss: 0.082180
#
# Epoch 2486
# -------------------------------
# Training loss: 0.075006
# Validation loss: 0.078953
#
# Epoch 2487
# -------------------------------
# Training loss: 0.077634
# Validation loss: 0.081098
#
# Epoch 2488
# -------------------------------
# Training loss: 0.075428
# Validation loss: 0.081149
#
# Epoch 2489
# -------------------------------
# Training loss: 0.075557
# Validation loss: 0.095120
#
# Epoch 2490
# -------------------------------
# Training loss: 0.074595
# Validation loss: 0.090979
#
# Epoch 2491
# -------------------------------
# Training loss: 0.077183
# Validation loss: 0.078800
#
# Epoch 2492
# -------------------------------
# Training loss: 0.078071
# Validation loss: 0.083012
#
# Epoch 2493
# -------------------------------
# Training loss: 0.073597
# Validation loss: 0.082097
#
# Epoch 2494
# -------------------------------
# Training loss: 0.074366
# Validation loss: 0.078283
#
# Epoch 2495
# -------------------------------
# Training loss: 0.074550
# Validation loss: 0.078980
#
# Epoch 2496
# -------------------------------
# Training loss: 0.073913
# Validation loss: 0.082773
#
# Epoch 2497
# -------------------------------
# Training loss: 0.073678
# Validation loss: 0.077965
#
# Epoch 2498
# -------------------------------
# Training loss: 0.074716
# Validation loss: 0.077956
#
# Epoch 2499
# -------------------------------
# Training loss: 0.072655
# Validation loss: 0.083229
#
# Epoch 2500
# -------------------------------
# Training loss: 0.075196
# Validation loss: 0.080462
#
# Done!

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses)+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('BCE Loss')
#plt.yscale('log')
plt.legend()

# %%
# Now test the pretrained model
test_pred = mytools.test_clas(test_loader, final_classifier, device)
test_pred=torch.sigmoid(torch.tensor(test_pred)).numpy()


fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test, test_pred, pos_label=1)
auc_test = sklearn.metrics.auc(fpr, tpr)
print(f'Test AUROC: {auc_test:0.4f}')

plt.plot(fpr, tpr, label=f'Test AUROC: {auc_test:0.4f}')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
# Out:
# Test AUROC: 0.9908

# %%
# Store the pretrained classifier labels
df_test["Class_pre"] = test_pred

# Save the pretrained classifier model
torch.save(final_classifier.state_dict(), "/Users/mghrear/data/ML_data/patch/pretrained_classifier_2021_v9_pass5_run"+str(run)+"_QualCuts.pt")

# %% [markdown]
# # Setup the adversary model

# %% [markdown]
# ## Initialize model, objective function, and optimizer

# %%
adv = mytools.Adversary(n_classes=Num_classes).to(device)
criterion_adv = nn.CrossEntropyLoss(reduction='none')  # returns loss per sample so we can weight it
opt_adv = torch.optim.Adam(adv.parameters(), lr=1e-5)
scheduler_adv = torch.optim.lr_scheduler.ExponentialLR(opt_adv, gamma=0.999)

# %% [markdown]
# ## Setup dataloaders

# %%
# Convert to tensor dataset and dataloader

# the structure is: feature, adversary label, weight
# The wight is 1 for tritrig and wab, and 0 for phiKK, to prevent the adversary from learning on phiKK events

train_adv_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_train), (torch.from_numpy(y_train.to_numpy().astype(np.float32))==0).float())
train_adv_loader = DataLoader(train_adv_dataset, batch_size=bsize, shuffle=True)

val_adv_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_val), (torch.from_numpy(y_val.to_numpy().astype(np.float32))==0).float() )
val_adv_loader = DataLoader(val_adv_dataset, batch_size=bsize, shuffle=True)

# Weights are not relavent for testing
test_adv_dataset = TensorDataset(torch.from_numpy(X_test.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_test))
test_adv_loader = DataLoader(test_adv_dataset, batch_size=bsize, shuffle=True)

# %% [markdown]
# ## Pre-train the adversary leaving classifier weights fixed

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 6

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 100
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train_adv(train_adv_loader, final_classifier, adv, criterion_adv, opt_adv, scheduler_adv, device))
    Validation_losses = np.append(Validation_losses, mytools.validate_adv(val_adv_loader, final_classifier, adv, criterion_adv, device))
    
    # Keep a running copy of the model with the lowest loss
    if Validation_losses[-1] == np.min(Validation_losses):
        final_adv = copy.deepcopy(adv)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Training loss: 1.639518
# Validation loss: 1.612824
#
# Epoch 2
# -------------------------------
# Training loss: 1.631565
# Validation loss: 1.616343
#
# Epoch 3
# -------------------------------
# Training loss: 1.625836
# Validation loss: 1.620330
#
# Epoch 4
# -------------------------------
# Training loss: 1.621642
# Validation loss: 1.626028
#
# Epoch 5
# -------------------------------
# Training loss: 1.617934
# Validation loss: 1.628300
#
# Epoch 6
# -------------------------------
# Training loss: 1.615015
# Validation loss: 1.629294
#
# Epoch 7
# -------------------------------
# Training loss: 1.612810
# Validation loss: 1.627333
#
# Epoch 8
# -------------------------------
# Training loss: 1.610579
# Validation loss: 1.622932
#
# Epoch 9
# -------------------------------
# Training loss: 1.608847
# Validation loss: 1.615025
#
# Epoch 10
# -------------------------------
# Training loss: 1.607037
# Validation loss: 1.612080
#
# Epoch 11
# -------------------------------
# Training loss: 1.605195
# Validation loss: 1.609953
#
# Epoch 12
# -------------------------------
# Training loss: 1.603648
# Validation loss: 1.606503
#
# Epoch 13
# -------------------------------
# Training loss: 1.602486
# Validation loss: 1.606662
#
# Epoch 14
# -------------------------------
# Training loss: 1.601217
# Validation loss: 1.606195
#
# Epoch 15
# -------------------------------
# Training loss: 1.600068
# Validation loss: 1.604179
#
# Epoch 16
# -------------------------------
# Training loss: 1.598689
# Validation loss: 1.603891
#
# Epoch 17
# -------------------------------
# Training loss: 1.597920
# Validation loss: 1.601768
#
# Epoch 18
# -------------------------------
# Training loss: 1.597224
# Validation loss: 1.602467
#
# Epoch 19
# -------------------------------
# Training loss: 1.596521
# Validation loss: 1.602631
#
# Epoch 20
# -------------------------------
# Training loss: 1.596158
# Validation loss: 1.602668
#
# Epoch 21
# -------------------------------
# Training loss: 1.595352
# Validation loss: 1.602925
#
# Epoch 22
# -------------------------------
# Training loss: 1.594951
# Validation loss: 1.600116
#
# Epoch 23
# -------------------------------
# Training loss: 1.594651
# Validation loss: 1.600128
#
# Epoch 24
# -------------------------------
# Training loss: 1.594444
# Validation loss: 1.598739
#
# Epoch 25
# -------------------------------
# Training loss: 1.594334
# Validation loss: 1.598925
#
# Epoch 26
# -------------------------------
# Training loss: 1.593657
# Validation loss: 1.598707
#
# Epoch 27
# -------------------------------
# Training loss: 1.593247
# Validation loss: 1.599298
#
# Epoch 28
# -------------------------------
# Training loss: 1.593216
# Validation loss: 1.599921
#
# Epoch 29
# -------------------------------
# Training loss: 1.592680
# Validation loss: 1.599390
#
# Epoch 30
# -------------------------------
# Training loss: 1.592587
# Validation loss: 1.598069
#
# Epoch 31
# -------------------------------
# Training loss: 1.592674
# Validation loss: 1.597528
#
# Epoch 32
# -------------------------------
# Training loss: 1.592427
# Validation loss: 1.597032
#
# Epoch 33
# -------------------------------
# Training loss: 1.592205
# Validation loss: 1.600945
#
# Epoch 34
# -------------------------------
# Training loss: 1.591937
# Validation loss: 1.599513
#
# Epoch 35
# -------------------------------
# Training loss: 1.591912
# Validation loss: 1.600033
#
# Epoch 36
# -------------------------------
# Training loss: 1.591286
# Validation loss: 1.599199
#
# Epoch 37
# -------------------------------
# Training loss: 1.591397
# Validation loss: 1.598008
#
# Epoch 38
# -------------------------------
# Training loss: 1.591594
# Validation loss: 1.599183
#
# Epoch 39
# -------------------------------
# Training loss: 1.591320
# Validation loss: 1.597886
#
# Epoch 40
# -------------------------------
# Training loss: 1.591160
# Validation loss: 1.598988
#
# Epoch 41
# -------------------------------
# Training loss: 1.590853
# Validation loss: 1.598237
#
# Epoch 42
# -------------------------------
# Training loss: 1.591207
# Validation loss: 1.598362
#
# Epoch 43
# -------------------------------
# Training loss: 1.590939
# Validation loss: 1.598233
#
# Epoch 44
# -------------------------------
# Training loss: 1.591017
# Validation loss: 1.597495
#
# Epoch 45
# -------------------------------
# Training loss: 1.590505
# Validation loss: 1.598718
#
# Epoch 46
# -------------------------------
# Training loss: 1.590745
# Validation loss: 1.597783
#
# Epoch 47
# -------------------------------
# Training loss: 1.590558
# Validation loss: 1.598621
#
# Epoch 48
# -------------------------------
# Training loss: 1.590407
# Validation loss: 1.597391
#
# Epoch 49
# -------------------------------
# Training loss: 1.590419
# Validation loss: 1.597866
#
# Epoch 50
# -------------------------------
# Training loss: 1.590525
# Validation loss: 1.599483
#
# Epoch 51
# -------------------------------
# Training loss: 1.590410
# Validation loss: 1.597794
#
# Epoch 52
# -------------------------------
# Training loss: 1.589904
# Validation loss: 1.598843
#
# Epoch 53
# -------------------------------
# Training loss: 1.590326
# Validation loss: 1.598477
#
# Epoch 54
# -------------------------------
# Training loss: 1.590124
# Validation loss: 1.598379
#
# Epoch 55
# -------------------------------
# Training loss: 1.590033
# Validation loss: 1.598615
#
# Epoch 56
# -------------------------------
# Training loss: 1.589789
# Validation loss: 1.597442
#
# Epoch 57
# -------------------------------
# Training loss: 1.589744
# Validation loss: 1.597063
#
# Epoch 58
# -------------------------------
# Training loss: 1.590134
# Validation loss: 1.596829
#
# Epoch 59
# -------------------------------
# Training loss: 1.589841
# Validation loss: 1.597263
#
# Epoch 60
# -------------------------------
# Training loss: 1.590155
# Validation loss: 1.598137
#
# Epoch 61
# -------------------------------
# Training loss: 1.589353
# Validation loss: 1.598409
#
# Epoch 62
# -------------------------------
# Training loss: 1.589444
# Validation loss: 1.599259
#
# Epoch 63
# -------------------------------
# Training loss: 1.590082
# Validation loss: 1.596540
#
# Epoch 64
# -------------------------------
# Training loss: 1.589834
# Validation loss: 1.594840
#
# Epoch 65
# -------------------------------
# Training loss: 1.589832
# Validation loss: 1.597470
#
# Epoch 66
# -------------------------------
# Training loss: 1.589606
# Validation loss: 1.598113
#
# Epoch 67
# -------------------------------
# Training loss: 1.589827
# Validation loss: 1.597876
#
# Epoch 68
# -------------------------------
# Training loss: 1.589656
# Validation loss: 1.599206
#
# Epoch 69
# -------------------------------
# Training loss: 1.589251
# Validation loss: 1.595694
#
# Epoch 70
# -------------------------------
# Training loss: 1.589228
# Validation loss: 1.597905
#
# Epoch 71
# -------------------------------
# Training loss: 1.589689
# Validation loss: 1.598183
#
# Epoch 72
# -------------------------------
# Training loss: 1.589122
# Validation loss: 1.597944
#
# Epoch 73
# -------------------------------
# Training loss: 1.589386
# Validation loss: 1.598394
#
# Epoch 74
# -------------------------------
# Training loss: 1.589563
# Validation loss: 1.598923
#
# Epoch 75
# -------------------------------
# Training loss: 1.589192
# Validation loss: 1.596406
#
# Epoch 76
# -------------------------------
# Training loss: 1.589337
# Validation loss: 1.597254
#
# Epoch 77
# -------------------------------
# Training loss: 1.589192
# Validation loss: 1.597837
#
# Epoch 78
# -------------------------------
# Training loss: 1.589046
# Validation loss: 1.596380
#
# Epoch 79
# -------------------------------
# Training loss: 1.589265
# Validation loss: 1.597277
#
# Epoch 80
# -------------------------------
# Training loss: 1.589142
# Validation loss: 1.597741
#
# Epoch 81
# -------------------------------
# Training loss: 1.589273
# Validation loss: 1.597420
#
# Epoch 82
# -------------------------------
# Training loss: 1.588841
# Validation loss: 1.599082
#
# Epoch 83
# -------------------------------
# Training loss: 1.588818
# Validation loss: 1.597382
#
# Epoch 84
# -------------------------------
# Training loss: 1.589324
# Validation loss: 1.596962
#
# Epoch 85
# -------------------------------
# Training loss: 1.588938
# Validation loss: 1.597154
#
# Epoch 86
# -------------------------------
# Training loss: 1.588962
# Validation loss: 1.598155
#
# Epoch 87
# -------------------------------
# Training loss: 1.588835
# Validation loss: 1.598234
#
# Epoch 88
# -------------------------------
# Training loss: 1.588973
# Validation loss: 1.600471
#
# Epoch 89
# -------------------------------
# Training loss: 1.588817
# Validation loss: 1.597518
#
# Epoch 90
# -------------------------------
# Training loss: 1.588839
# Validation loss: 1.596961
#
# Epoch 91
# -------------------------------
# Training loss: 1.589131
# Validation loss: 1.597411
#
# Epoch 92
# -------------------------------
# Training loss: 1.588484
# Validation loss: 1.597610
#
# Epoch 93
# -------------------------------
# Training loss: 1.589023
# Validation loss: 1.596968
#
# Epoch 94
# -------------------------------
# Training loss: 1.588705
# Validation loss: 1.598942
#
# Epoch 95
# -------------------------------
# Training loss: 1.588829
# Validation loss: 1.596364
#
# Epoch 96
# -------------------------------
# Training loss: 1.588754
# Validation loss: 1.596918
#
# Epoch 97
# -------------------------------
# Training loss: 1.588722
# Validation loss: 1.597734
#
# Epoch 98
# -------------------------------
# Training loss: 1.588672
# Validation loss: 1.598699
#
# Epoch 99
# -------------------------------
# Training loss: 1.588297
# Validation loss: 1.597797
#
# Epoch 100
# -------------------------------
# Training loss: 1.588770
# Validation loss: 1.594910
#
# Done!

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses)+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('BCE Loss')
plt.legend()

# %% [markdown]
# ## Test the pre-trained adversary

# %%
adv_test_pred = mytools.test_adv(test_adv_loader, final_classifier, final_adv, Num_classes, device)
adv_test_pred = torch.softmax(torch.tensor(adv_test_pred),dim=1).numpy()
score=0

for i in range(adv_test_pred.shape[1]):
    fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_adv_test[:,i], adv_test_pred[:,i], pos_label=1)
    auc_test = sklearn.metrics.auc(fpr, tpr)
    print("class " + str(i)+ " test auc score: " + str(auc_test))

    plt.plot(fpr, tpr, label='Class '+str(i)+' Test AUROC: '+str(auc_test))
    plt.xlabel('FPR')
    plt.ylabel('TPR')
    plt.legend()

    score += auc_test

print("average score: ", score/adv_test_pred.shape[1])
# Out:
# class 0 test auc score: 0.5010116107563829
# class 1 test auc score: 0.4951845995688155
# class 2 test auc score: 0.5045363700687439
# class 3 test auc score: 0.49929824248965005
# class 4 test auc score: 0.5002603434682609
# average score:  0.5000582332703707

# %% [markdown]
# # Train full adverserial neural network

# %% [markdown]
# # Setup dataloaders

# %%
# the structure is: feature, classifier label, adversary label, weight
# The wight is 1 for tritrig and wab, and 0 for phiKK, to prevent the adversary from learning on phiKK events

train_full_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy().astype(np.float32))  , torch.from_numpy(y_train.to_numpy().astype(np.float32)).unsqueeze(1), torch.from_numpy(y_adv_train),  (torch.from_numpy(y_train.to_numpy().astype(np.float32))==0).float())
train_full_loader = DataLoader(train_full_dataset, batch_size=bsize, shuffle=True)

val_full_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy().astype(np.float32))  , torch.from_numpy(y_val.to_numpy().astype(np.float32)).unsqueeze(1),  torch.from_numpy(y_adv_val),  (torch.from_numpy(y_val.to_numpy().astype(np.float32))==0).float())
val_full_loader = DataLoader(val_full_dataset, batch_size=bsize, shuffle=True)

# %% [markdown]
# ## Define loss functions

# %%
BCE_loss = nn.BCEWithLogitsLoss()
CE_loss = nn.CrossEntropyLoss(reduction='none') # returns loss per sample so we can weight it

def full_loss(output_clas, output_adv, target_clas, target_adv, w, lambda_):

    loss1 = BCE_loss(output_clas, target_clas )  # classification loss
    sample_losses2 = CE_loss(output_adv, target_adv)  # adversarial losses, since we set reduction='none', this is now a vector of losses, one per sample in the batch

    # Weighted mean loss over non-zero weights
    nonzero = w > 0
    loss2 = (sample_losses2[nonzero] * w[nonzero]).sum() / w[nonzero].sum()

    loss = loss1 - lambda_*loss2

    return loss

# %% [markdown]
# ## Setup optimizers

# %%
optimizer_clas = optim.Adam(final_classifier.parameters(), lr=1e-7,betas=(0.5, 0.999))
optimizer_adv = optim.Adam(final_adv.parameters(), lr=1e-5,betas=(0.5, 0.999))

scheduler_clas = torch.optim.lr_scheduler.ExponentialLR(optimizer_clas, gamma=0.999)
scheduler_adv = torch.optim.lr_scheduler.ExponentialLR(optimizer_adv, gamma=0.999)

# %% [markdown]
# ## Adversarial training

# %%
Training_losses_clas = np.array([])
Training_losses_adv = np.array([])
Validation_losses_clas = np.array([])
Validation_losses_adv = np.array([])
diff_scores = np.array([])


epochs = 50
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")

    # Get validation losses
    E_clas_val_loss, E_adv_val_loss = mytools.validate_full(val_full_loader, final_classifier, final_adv, full_loss, lambda_, criterion_adv, device)
    Validation_losses_clas = np.append(Validation_losses_clas, E_clas_val_loss)
    Validation_losses_adv = np.append(Validation_losses_adv, E_adv_val_loss)

    # Train adversary and classifier
    E_clas_training_loss , E_adv_training_loss = mytools.train_full(train_full_loader, final_classifier, final_adv, full_loss, lambda_, criterion_adv, optimizer_clas, optimizer_adv, scheduler_clas, scheduler_adv, device)
    Training_losses_clas = np.append(Training_losses_clas, E_clas_training_loss)
    Training_losses_adv = np.append(Training_losses_adv, E_adv_training_loss)

    # Get the diff_score
    df_test["Class_adv"] = mytools.test_clas(test_loader, final_classifier, device)
    df_bkg = df_test.loc[ (df_test.type == 'tritrig') | (df_test.type == 'wab')]
    per = np.percentile(df_bkg['Class_adv'],99)
    df_cut = df_bkg[df_bkg['Class_adv']>per].reset_index(drop=True)
    x1 = 1000* df_bkg.InvM.values
    x2 = 1000*df_cut.InvM.values
    diff_scores = np.append(diff_scores, mytools.get_diff_score(x1,x2) )

    # Keep a running copy of the model with the lowest loss
    if diff_scores[-1] == np.min(diff_scores):
        final_clas_adv = copy.deepcopy(final_classifier)
        final_adv_adv = copy.deepcopy(final_adv)

            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Classifier validation loss: -159.870776
# Adversary validation loss: 1.599484
# Classifier training loss: -159.867676
# Adversary training loss: 1.600424
# Epoch 2
# -------------------------------
# Classifier validation loss: -160.294730
# Adversary validation loss: 1.603731
# Classifier training loss: -160.314560
# Adversary training loss: 1.604746
# Epoch 3
# -------------------------------
# Classifier validation loss: -161.013586
# Adversary validation loss: 1.610958
# Classifier training loss: -160.915190
# Adversary training loss: 1.610724
# Epoch 4
# -------------------------------
# Classifier validation loss: -161.819012
# Adversary validation loss: 1.619048
# Classifier training loss: -161.184458
# Adversary training loss: 1.613230
# Epoch 5
# -------------------------------
# Classifier validation loss: -161.595178
# Adversary validation loss: 1.616805
# Classifier training loss: -161.233992
# Adversary training loss: 1.613555
# Epoch 6
# -------------------------------
# Classifier validation loss: -161.518417
# Adversary validation loss: 1.616055
# Classifier training loss: -161.136510
# Adversary training loss: 1.612397
# Epoch 7
# -------------------------------
# Classifier validation loss: -161.415680
# Adversary validation loss: 1.615048
# Classifier training loss: -161.100045
# Adversary training loss: 1.612067
# Epoch 8
# -------------------------------
# Classifier validation loss: -161.214554
# Adversary validation loss: 1.613116
# Classifier training loss: -160.992771
# Adversary training loss: 1.610935
# Epoch 9
# -------------------------------
# Classifier validation loss: -161.254233
# Adversary validation loss: 1.613543
# Classifier training loss: -160.853448
# Adversary training loss: 1.609586
# Epoch 10
# -------------------------------
# Classifier validation loss: -160.896289
# Adversary validation loss: 1.609979
# Classifier training loss: -160.801885
# Adversary training loss: 1.609066
# Epoch 11
# -------------------------------
# Classifier validation loss: -160.811829
# Adversary validation loss: 1.609148
# Classifier training loss: -160.730903
# Adversary training loss: 1.608350
# Epoch 12
# -------------------------------
# Classifier validation loss: -160.667239
# Adversary validation loss: 1.607711
# Classifier training loss: -160.764803
# Adversary training loss: 1.608732
# Epoch 13
# -------------------------------
# Classifier validation loss: -160.729294
# Adversary validation loss: 1.608292
# Classifier training loss: -160.807383
# Adversary training loss: 1.609153
# Epoch 14
# -------------------------------
# Classifier validation loss: -160.766522
# Adversary validation loss: 1.608702
# Classifier training loss: -160.730969
# Adversary training loss: 1.608401
# Epoch 15
# -------------------------------
# Classifier validation loss: -160.681653
# Adversary validation loss: 1.607867
# Classifier training loss: -160.726571
# Adversary training loss: 1.608338
# Epoch 16
# -------------------------------
# Classifier validation loss: -160.748026
# Adversary validation loss: 1.608460
# Classifier training loss: -160.812802
# Adversary training loss: 1.609237
# Epoch 17
# -------------------------------
# Classifier validation loss: -160.606677
# Adversary validation loss: 1.607128
# Classifier training loss: -160.760847
# Adversary training loss: 1.608736
# Epoch 18
# -------------------------------
# Classifier validation loss: -160.720218
# Adversary validation loss: 1.608272
# Classifier training loss: -160.783415
# Adversary training loss: 1.608893
# Epoch 19
# -------------------------------
# Classifier validation loss: -160.719012
# Adversary validation loss: 1.608266
# Classifier training loss: -160.973984
# Adversary training loss: 1.610870
# Epoch 20
# -------------------------------
# Classifier validation loss: -160.772818
# Adversary validation loss: 1.608794
# Classifier training loss: -160.785528
# Adversary training loss: 1.609014
# Epoch 21
# -------------------------------
# Classifier validation loss: -160.763544
# Adversary validation loss: 1.608714
# Classifier training loss: -160.784071
# Adversary training loss: 1.608963
# Epoch 22
# -------------------------------
# Classifier validation loss: -160.729440
# Adversary validation loss: 1.608341
# Classifier training loss: -160.855565
# Adversary training loss: 1.609672
# Epoch 23
# -------------------------------
# Classifier validation loss: -160.665775
# Adversary validation loss: 1.607776
# Classifier training loss: -160.870200
# Adversary training loss: 1.609826
# Epoch 24
# -------------------------------
# Classifier validation loss: -160.724869
# Adversary validation loss: 1.608305
# Classifier training loss: -160.802366
# Adversary training loss: 1.609115
# Epoch 25
# -------------------------------
# Classifier validation loss: -160.723151
# Adversary validation loss: 1.608304
# Classifier training loss: -160.846907
# Adversary training loss: 1.609566
# Epoch 26
# -------------------------------
# Classifier validation loss: -160.771509
# Adversary validation loss: 1.608799
# Classifier training loss: -160.830682
# Adversary training loss: 1.609372
# Epoch 27
# -------------------------------
# Classifier validation loss: -160.795825
# Adversary validation loss: 1.609053
# Classifier training loss: -160.850123
# Adversary training loss: 1.609681
# Epoch 28
# -------------------------------
# Classifier validation loss: -160.869785
# Adversary validation loss: 1.609879
# Classifier training loss: -160.813760
# Adversary training loss: 1.609204
# Epoch 29
# -------------------------------
# Classifier validation loss: -160.838358
# Adversary validation loss: 1.609442
# Classifier training loss: -160.856613
# Adversary training loss: 1.609679
# Epoch 30
# -------------------------------
# Classifier validation loss: -160.818890
# Adversary validation loss: 1.609329
# Classifier training loss: -160.861866
# Adversary training loss: 1.609688
# Epoch 31
# -------------------------------
# Classifier validation loss: -160.847482
# Adversary validation loss: 1.609521
# Classifier training loss: -160.849989
# Adversary training loss: 1.609563
# Epoch 32
# -------------------------------
# Classifier validation loss: -160.877774
# Adversary validation loss: 1.609853
# Classifier training loss: -160.780618
# Adversary training loss: 1.608826
# Epoch 33
# -------------------------------
# Classifier validation loss: -160.905392
# Adversary validation loss: 1.610059
# Classifier training loss: -160.811047
# Adversary training loss: 1.609119
# Epoch 34
# -------------------------------
# Classifier validation loss: -160.865384
# Adversary validation loss: 1.609630
# Classifier training loss: -160.817156
# Adversary training loss: 1.609217
# Epoch 35
# -------------------------------
# Classifier validation loss: -160.996179
# Adversary validation loss: 1.611012
# Classifier training loss: -160.803877
# Adversary training loss: 1.609056
# Epoch 36
# -------------------------------
# Classifier validation loss: -160.948254
# Adversary validation loss: 1.610481
# Classifier training loss: -160.805525
# Adversary training loss: 1.609154
# Epoch 37
# -------------------------------
# Classifier validation loss: -160.937314
# Adversary validation loss: 1.610433
# Classifier training loss: -160.848684
# Adversary training loss: 1.609549
# Epoch 38
# -------------------------------
# Classifier validation loss: -160.896234
# Adversary validation loss: 1.609998
# Classifier training loss: -160.793623
# Adversary training loss: 1.608940
# Epoch 39
# -------------------------------
# Classifier validation loss: -160.823938
# Adversary validation loss: 1.609231
# Classifier training loss: -160.826138
# Adversary training loss: 1.609324
# Epoch 40
# -------------------------------
# Classifier validation loss: -160.850815
# Adversary validation loss: 1.609539
# Classifier training loss: -160.832804
# Adversary training loss: 1.609376
# Epoch 41
# -------------------------------
# Classifier validation loss: -160.872574
# Adversary validation loss: 1.609782
# Classifier training loss: -160.810886
# Adversary training loss: 1.609128
# Epoch 42
# -------------------------------
# Classifier validation loss: -160.881064
# Adversary validation loss: 1.609835
# Classifier training loss: -160.793364
# Adversary training loss: 1.608989
# Epoch 43
# -------------------------------
# Classifier validation loss: -160.813516
# Adversary validation loss: 1.609189
# Classifier training loss: -160.861293
# Adversary training loss: 1.609656
# Epoch 44
# -------------------------------
# Classifier validation loss: -160.878271
# Adversary validation loss: 1.609860
# Classifier training loss: -160.800617
# Adversary training loss: 1.609082
# Epoch 45
# -------------------------------
# Classifier validation loss: -160.872003
# Adversary validation loss: 1.609872
# Classifier training loss: -160.812502
# Adversary training loss: 1.609160
# Epoch 46
# -------------------------------
# Classifier validation loss: -160.881744
# Adversary validation loss: 1.609948
# Classifier training loss: -160.797358
# Adversary training loss: 1.609020
# Epoch 47
# -------------------------------
# Classifier validation loss: -160.834409
# Adversary validation loss: 1.609437
# Classifier training loss: -160.825192
# Adversary training loss: 1.609325
# Epoch 48
# -------------------------------
# Classifier validation loss: -160.895901
# Adversary validation loss: 1.610039
# Classifier training loss: -160.854679
# Adversary training loss: 1.609602
# Epoch 49
# -------------------------------
# Classifier validation loss: -160.793307
# Adversary validation loss: 1.608980
# Classifier training loss: -160.864212
# Adversary training loss: 1.609684
# Epoch 50
# -------------------------------
# Classifier validation loss: -160.838510
# Adversary validation loss: 1.609510
# Classifier training loss: -160.817125
# Adversary training loss: 1.609211
# Done!

# %%
fig, ax1 = plt.subplots()

best_epoch = np.argmin(diff_scores)+1



#ax1.plot(np.arange(len(Training_losses_adv))+1, Training_losses_adv, 'k-', label='Training Adversary')
ax1.plot(np.arange(len(Validation_losses_adv))+1, Validation_losses_adv, 'k-', label='Validation Adversary')

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Adversary Loss', color='k')
ax1.tick_params(axis='y', labelcolor='k')

ax2 = ax1.twinx()

#ax2.plot(np.arange(len(Training_losses_clas))+1, Training_losses_clas, 'r-', label='Training Classifier')
ax2.plot(np.arange(len(Validation_losses_clas))+1, Validation_losses_clas, 'r-', label='Validation Classifier')
ax2.axvline(best_epoch,label="Final model stopped here",color='k')

ax2.set_ylabel('Classifier Loss', color='r')
ax2.tick_params(axis='y', labelcolor='r')

# %% [markdown]
# ## Test adversarially trained models

# %%
# Now test the pretrained model
test_pred = mytools.test_clas(test_loader, final_clas_adv, device)
test_pred=torch.sigmoid(torch.tensor(test_pred)).numpy()


fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test, test_pred, pos_label=1)
auc_test = sklearn.metrics.auc(fpr, tpr)
print(f'Test AUROC: {auc_test:0.4f}')

plt.plot(fpr, tpr, label=f'Test AUROC: {auc_test:0.4f}')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
# Out:
# Test AUROC: 0.9878

# %%
df_test["Class_adv"] = test_pred
df_bkg = df_test.loc[ (df_test.type == 'tritrig') | (df_test.type == 'wab')]
per = np.percentile(df_bkg['Class_adv'],99)
df_cut = df_bkg[df_bkg['Class_adv']>per].reset_index(drop=True)
x_vals = 1000*df_cut.InvM

plt.figure()
plt.hist(1000*df_bkg.InvM, bins=np.arange(980,1250,1), histtype='step', label='No selection', density=True)
plt.hist(x_vals, bins=np.arange(980,1250,1), histtype='step', label= '99 percent selection', density=True)
plt.axvline(1019.461, color='k', linestyle='dashed', linewidth=1, label='PDG phi mass')
plt.xlabel('Invariant Mass [MeV]')
plt.ylabel('Normalized Counts')
plt.legend()

# %%
x1 = 1000* df_bkg.InvM.values
x2 = 1000*df_cut.InvM.values

N, edges = np.histogram(x1, bins=np.arange(980,1250,1), density=False)
M, edges = np.histogram(x2, bins=np.arange(980,1250,1), density=False)

N2 = N[(N > 0) & (M > 0)]
M2 = M[(N > 0) & (M > 0)]

diff_score = np.mean(np.abs(N2/np.sum(N)-M2/np.sum(M)) / (np.sqrt(N2)/np.sum(N) + np.sqrt(M2)/np.sum(M) ))

print(diff_score)

N = len(df_test.loc[ ((df_test.type == 'tritrig') | (df_test.type == 'wab')) & (df_test.InvM < (1.019 + 0.01) )  & (df_test.InvM > (1.019 - 0.01) ) & ( df_test['Class_adv']>per ) ] )
S = len(df_test.loc[ (df_test.type == 'phiKK') & (df_test.InvM < (1.019 + 0.01) )  & (df_test.InvM > (1.019 - 0.01) ) & ( df_test['Class_adv']>per )  ] )

print(S/N)
# Out:
# 0.7106429587041817
# 4.021505376344086

# %%
df_test["Class_adv"] = test_pred

# %%
adv_test_pred = mytools.test_adv(test_adv_loader, final_classifier, final_adv_adv, Num_classes, device)
adv_test_pred = torch.softmax(torch.tensor(adv_test_pred),dim=1).numpy()
score=0

for i in range(adv_test_pred.shape[1]):
    fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_adv_test[:,i], adv_test_pred[:,i], pos_label=1)
    auc_test = sklearn.metrics.auc(fpr, tpr)
    print("class " + str(i)+ " test auc score: " + str(auc_test))

    plt.plot(fpr, tpr, label='Class '+str(i)+' Test AUROC: '+str(auc_test))
    plt.xlabel('FPR')
    plt.ylabel('TPR')
    plt.legend()

    score += auc_test

print("average score: ", score/adv_test_pred.shape[1])
# Out:
# class 0 test auc score: 0.49997721989816424
# class 1 test auc score: 0.4961984116116429
# class 2 test auc score: 0.49781400105264206
# class 3 test auc score: 0.5006568515894253
# class 4 test auc score: 0.49751881826587646
# average score:  0.4984330604835502

# %%
# Save the adversarially trained models
torch.save(final_clas_adv.state_dict(), "/Users/mghrear/data/ML_data/patch/classifier_adv_2021_v9_pass5_run"+str(run)+"QualCuts.pt")
torch.save(final_adv_adv.state_dict(), "/Users/mghrear/data/ML_data/patch/adversary_adv_2021_v9_pass5_run"+str(run)+"QualCuts.pt")

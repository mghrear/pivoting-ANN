# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import torch 
from torch import nn, optim
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import sklearn
from sklearn.model_selection import train_test_split
import copy
import mytools


# Print and store device being used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cpu

# %% [markdown]
# # Define important parameters

# %%
# Number of class in invariant mass used by the adversary
Num_classes = 5
# Hyper-parameter for adversarial training of the classifier
lambda_ = 100.0

run = 1

# %% [markdown]
# # Load and setup the data

# %%
# Read tritrig, wab, phiKK, and data files
df_tritrig = pd.read_pickle('/Users/mghrear/data/ML_data/patch/2021_v9_pass5_tritrig_QualCuts.pk')
df_tritrig['PhiKK'] = 0.0
df_phiKK = pd.read_pickle('/Users/mghrear/data/ML_data/patch/2021_v9_pass5_phiKK_QualCuts.pk')
df_phiKK['PhiKK'] = 1.0
df_wab = pd.read_pickle('/Users/mghrear/data/ML_data/patch/2021_v9_pass5_wab_QualCuts.pk')
df_wab['PhiKK'] = 0.0 # Add label


print("tritrig: ", len(df_tritrig))
print("phiKK: ", len(df_phiKK))
print("wab: ", len(df_wab))
# Out:
# tritrig:  120352
# phiKK:  3845
# wab:  6580

# %%
# Make Training set with 20000 tritrig, 4000 phiKK, 4000 wab
tritrig_train = df_tritrig[0:20000]
wab_train = df_wab[0:3000]
phiKK_train = df_phiKK[0:3000]

# Combine and shuffle all training data
df_train = pd.concat([tritrig_train, phiKK_train, wab_train], ignore_index=True, sort=False)
df_train = df_train.sample(frac=1, random_state=42).reset_index(drop=True)

# Get edges in invariant mass classes for one-hot encoding
# To be used for adverserial labels
# The edges are chosen such that each bin has equal number of background events
one_hot_edges = mytools.get_one_hot_edges(mytools.get_InvM( pd.concat([df_tritrig, df_wab], ignore_index=True, sort=False) ), n_bins=Num_classes)

# Split the training data into training and validation sets
df_train, df_val = train_test_split(df_train, test_size=0.33, random_state=42)

# Make X and y for training and validation sets
# the adverserial network has its own labels
X_train = df_train.drop(columns=['PhiKK'])
y_train = df_train['PhiKK']
y_adv_train = mytools.get_adv_labels( mytools.get_InvM(df_train), one_hot_edges)
X_val = df_val.drop(columns=['PhiKK'])
y_val = df_val['PhiKK']
y_adv_val = mytools.get_adv_labels( mytools.get_InvM(df_val), one_hot_edges)

# Make testing set with remaining events
tritrig_test = df_tritrig[20000:]
tritrig_test['type']= 'tritrig'
wab_test = df_wab[3000:]
wab_test['type']= 'wab'
phiKK_test = df_phiKK[3000:]
phiKK_test['type']= 'phiKK'

df_test = pd.concat([tritrig_test, phiKK_test,wab_test], ignore_index=True, sort=False)
df_test = df_test.sample(frac=1, random_state=42).reset_index(drop=True) # Now shuffle the combined dataframe

X_test = df_test.drop(columns=['PhiKK','type'])
y_test = df_test['PhiKK']
y_adv_test = mytools.get_adv_labels( mytools.get_InvM(df_test), one_hot_edges)

df_test["InvM"] = mytools.get_InvM(df_test)
# Out:
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_46492/1157922432.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tritrig_test['type']= 'tritrig'
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_46492/1157922432.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wab_test['type']= 'wab'
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_46492/1157922432.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phiKK_test['type']= 'phiKK'

# %%
from sklearn.preprocessing import StandardScaler
import joblib

scaler = StandardScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns, index=X_train.index)
X_val   = pd.DataFrame(scaler.transform(X_val),       columns=X_val.columns,   index=X_val.index)
X_test  = pd.DataFrame(scaler.transform(X_test),      columns=X_test.columns,  index=X_test.index)

# Save the scaler so it can be applied consistently during inference
joblib.dump(scaler, "/Users/mghrear/data/ML_data/patch/scaler_2021_v9_pass5_run"+str(run)+"_QualCuts.pkl")
print(f"Standardized {X_train.shape[1]} features using training-set statistics.")
# Out:
# Standardized 14 features using training-set statistics.

# %% [markdown]
# ## Setup dataloaders

# %%
bsize = 2000

# Convert to tensor dataset and dataloader
train_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy().astype(np.float32))  , torch.from_numpy(y_train.to_numpy().astype(np.float32)).unsqueeze(1)  )
train_loader = DataLoader(train_dataset, batch_size=bsize, shuffle=True)

val_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy().astype(np.float32))  , torch.from_numpy(y_val.to_numpy().astype(np.float32)).unsqueeze(1)  )
val_loader = DataLoader(val_dataset, batch_size=bsize, shuffle=True)

test_dataset = TensorDataset(torch.from_numpy(X_test.to_numpy().astype(np.float32)))
test_loader = DataLoader(test_dataset, batch_size=bsize, shuffle=False)

# %% [markdown]
# ## Initialize model, objective function, and optimizer

# %%
clas = mytools.Classifier(in_features=X_train.shape[1]).to(device)
criterion_clas = nn.BCEWithLogitsLoss()
optimizer_clas = optim.Adam(clas.parameters(), lr=1e-5)
scheduler_clas = torch.optim.lr_scheduler.ExponentialLR(optimizer_clas, gamma=0.9999)

# %% [markdown]
# ## Pre-train the classifier

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 10

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 2500
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train_clas(train_loader, clas, criterion_clas, optimizer_clas, scheduler_clas, device))
    Validation_losses = np.append(Validation_losses, mytools.validate_clas(val_loader, clas, criterion_clas, device))
    
    # Keep a running copy of the model with the lowest loss
    if Validation_losses[-1] == np.min(Validation_losses):
        final_classifier = copy.deepcopy(clas)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Training loss: 0.669311
# Validation loss: 0.635945
#
# Epoch 2
# -------------------------------
# Training loss: 0.638449
# Validation loss: 0.606581
#
# Epoch 3
# -------------------------------
# Training loss: 0.611294
# Validation loss: 0.596610
#
# Epoch 4
# -------------------------------
# Training loss: 0.587574
# Validation loss: 0.581498
#
# Epoch 5
# -------------------------------
# Training loss: 0.567103
# Validation loss: 0.562422
#
# Epoch 6
# -------------------------------
# Training loss: 0.549175
# Validation loss: 0.542224
#
# Epoch 7
# -------------------------------
# Training loss: 0.532591
# Validation loss: 0.524838
#
# Epoch 8
# -------------------------------
# Training loss: 0.517804
# Validation loss: 0.509901
#
# Epoch 9
# -------------------------------
# Training loss: 0.503485
# Validation loss: 0.495772
#
# Epoch 10
# -------------------------------
# Training loss: 0.490452
# Validation loss: 0.482967
#
# Epoch 11
# -------------------------------
# Training loss: 0.478813
# Validation loss: 0.471482
#
# Epoch 12
# -------------------------------
# Training loss: 0.467103
# Validation loss: 0.459052
#
# Epoch 13
# -------------------------------
# Training loss: 0.456226
# Validation loss: 0.448584
#
# Epoch 14
# -------------------------------
# Training loss: 0.446504
# Validation loss: 0.440387
#
# Epoch 15
# -------------------------------
# Training loss: 0.436948
# Validation loss: 0.430563
#
# Epoch 16
# -------------------------------
# Training loss: 0.428165
# Validation loss: 0.420893
#
# Epoch 17
# -------------------------------
# Training loss: 0.420240
# Validation loss: 0.414851
#
# Epoch 18
# -------------------------------
# Training loss: 0.412241
# Validation loss: 0.406058
#
# Epoch 19
# -------------------------------
# Training loss: 0.404619
# Validation loss: 0.399671
#
# Epoch 20
# -------------------------------
# Training loss: 0.398410
# Validation loss: 0.392559
#
# Epoch 21
# -------------------------------
# Training loss: 0.390786
# Validation loss: 0.384870
#
# Epoch 22
# -------------------------------
# Training loss: 0.384308
# Validation loss: 0.381130
#
# Epoch 23
# -------------------------------
# Training loss: 0.378380
# Validation loss: 0.372585
#
# Epoch 24
# -------------------------------
# Training loss: 0.372191
# Validation loss: 0.368182
#
# Epoch 25
# -------------------------------
# Training loss: 0.367144
# Validation loss: 0.362740
#
# Epoch 26
# -------------------------------
# Training loss: 0.361468
# Validation loss: 0.359496
#
# Epoch 27
# -------------------------------
# Training loss: 0.356386
# Validation loss: 0.350800
#
# Epoch 28
# -------------------------------
# Training loss: 0.351865
# Validation loss: 0.348123
#
# Epoch 29
# -------------------------------
# Training loss: 0.347214
# Validation loss: 0.344302
#
# Epoch 30
# -------------------------------
# Training loss: 0.342399
# Validation loss: 0.341105
#
# Epoch 31
# -------------------------------
# Training loss: 0.339257
# Validation loss: 0.335847
#
# Epoch 32
# -------------------------------
# Training loss: 0.334702
# Validation loss: 0.332301
#
# Epoch 33
# -------------------------------
# Training loss: 0.330898
# Validation loss: 0.326296
#
# Epoch 34
# -------------------------------
# Training loss: 0.327257
# Validation loss: 0.323576
#
# Epoch 35
# -------------------------------
# Training loss: 0.324119
# Validation loss: 0.320943
#
# Epoch 36
# -------------------------------
# Training loss: 0.320708
# Validation loss: 0.318247
#
# Epoch 37
# -------------------------------
# Training loss: 0.317572
# Validation loss: 0.314424
#
# Epoch 38
# -------------------------------
# Training loss: 0.315019
# Validation loss: 0.311072
#
# Epoch 39
# -------------------------------
# Training loss: 0.312014
# Validation loss: 0.308646
#
# Epoch 40
# -------------------------------
# Training loss: 0.309761
# Validation loss: 0.306758
#
# Epoch 41
# -------------------------------
# Training loss: 0.306836
# Validation loss: 0.304298
#
# Epoch 42
# -------------------------------
# Training loss: 0.304074
# Validation loss: 0.302146
#
# Epoch 43
# -------------------------------
# Training loss: 0.301970
# Validation loss: 0.299376
#
# Epoch 44
# -------------------------------
# Training loss: 0.299609
# Validation loss: 0.297843
#
# Epoch 45
# -------------------------------
# Training loss: 0.297095
# Validation loss: 0.294272
#
# Epoch 46
# -------------------------------
# Training loss: 0.295488
# Validation loss: 0.292203
#
# Epoch 47
# -------------------------------
# Training loss: 0.293186
# Validation loss: 0.289217
#
# Epoch 48
# -------------------------------
# Training loss: 0.290679
# Validation loss: 0.288072
#
# Epoch 49
# -------------------------------
# Training loss: 0.289361
# Validation loss: 0.286819
#
# Epoch 50
# -------------------------------
# Training loss: 0.287024
# Validation loss: 0.283769
#
# Epoch 51
# -------------------------------
# Training loss: 0.285170
# Validation loss: 0.282504
#
# Epoch 52
# -------------------------------
# Training loss: 0.283805
# Validation loss: 0.281959
#
# Epoch 53
# -------------------------------
# Training loss: 0.281809
# Validation loss: 0.278571
#
# Epoch 54
# -------------------------------
# Training loss: 0.280692
# Validation loss: 0.279197
#
# Epoch 55
# -------------------------------
# Training loss: 0.278791
# Validation loss: 0.277689
#
# Epoch 56
# -------------------------------
# Training loss: 0.276776
# Validation loss: 0.274193
#
# Epoch 57
# -------------------------------
# Training loss: 0.275308
# Validation loss: 0.272676
#
# Epoch 58
# -------------------------------
# Training loss: 0.273621
# Validation loss: 0.270388
#
# Epoch 59
# -------------------------------
# Training loss: 0.272255
# Validation loss: 0.269618
#
# Epoch 60
# -------------------------------
# Training loss: 0.270861
# Validation loss: 0.268211
#
# Epoch 61
# -------------------------------
# Training loss: 0.269470
# Validation loss: 0.267033
#
# Epoch 62
# -------------------------------
# Training loss: 0.268316
# Validation loss: 0.264570
#
# Epoch 63
# -------------------------------
# Training loss: 0.266919
# Validation loss: 0.263192
#
# Epoch 64
# -------------------------------
# Training loss: 0.265524
# Validation loss: 0.263109
#
# Epoch 65
# -------------------------------
# Training loss: 0.263762
# Validation loss: 0.261439
#
# Epoch 66
# -------------------------------
# Training loss: 0.262579
# Validation loss: 0.259896
#
# Epoch 67
# -------------------------------
# Training loss: 0.261417
# Validation loss: 0.257918
#
# Epoch 68
# -------------------------------
# Training loss: 0.260210
# Validation loss: 0.257502
#
# Epoch 69
# -------------------------------
# Training loss: 0.259560
# Validation loss: 0.256528
#
# Epoch 70
# -------------------------------
# Training loss: 0.258584
# Validation loss: 0.256420
#
# Epoch 71
# -------------------------------
# Training loss: 0.257438
# Validation loss: 0.255616
#
# Epoch 72
# -------------------------------
# Training loss: 0.256205
# Validation loss: 0.254233
#
# Epoch 73
# -------------------------------
# Training loss: 0.255024
# Validation loss: 0.253512
#
# Epoch 74
# -------------------------------
# Training loss: 0.253894
# Validation loss: 0.252358
#
# Epoch 75
# -------------------------------
# Training loss: 0.253195
# Validation loss: 0.251034
#
# Epoch 76
# -------------------------------
# Training loss: 0.251826
# Validation loss: 0.249511
#
# Epoch 77
# -------------------------------
# Training loss: 0.250590
# Validation loss: 0.249500
#
# Epoch 78
# -------------------------------
# Training loss: 0.249726
# Validation loss: 0.247510
#
# Epoch 79
# -------------------------------
# Training loss: 0.248850
# Validation loss: 0.248252
#
# Epoch 80
# -------------------------------
# Training loss: 0.247674
# Validation loss: 0.245940
#
# Epoch 81
# -------------------------------
# Training loss: 0.246807
# Validation loss: 0.244984
#
# Epoch 82
# -------------------------------
# Training loss: 0.246163
# Validation loss: 0.243444
#
# Epoch 83
# -------------------------------
# Training loss: 0.245465
# Validation loss: 0.242993
#
# Epoch 84
# -------------------------------
# Training loss: 0.244579
# Validation loss: 0.242920
#
# Epoch 85
# -------------------------------
# Training loss: 0.243681
# Validation loss: 0.241892
#
# Epoch 86
# -------------------------------
# Training loss: 0.242311
# Validation loss: 0.239952
#
# Epoch 87
# -------------------------------
# Training loss: 0.241566
# Validation loss: 0.239514
#
# Epoch 88
# -------------------------------
# Training loss: 0.240711
# Validation loss: 0.238641
#
# Epoch 89
# -------------------------------
# Training loss: 0.240450
# Validation loss: 0.239485
#
# Epoch 90
# -------------------------------
# Training loss: 0.239132
# Validation loss: 0.238229
#
# Epoch 91
# -------------------------------
# Training loss: 0.238997
# Validation loss: 0.238263
#
# Epoch 92
# -------------------------------
# Training loss: 0.237740
# Validation loss: 0.236003
#
# Epoch 93
# -------------------------------
# Training loss: 0.236559
# Validation loss: 0.234139
#
# Epoch 94
# -------------------------------
# Training loss: 0.236245
# Validation loss: 0.234443
#
# Epoch 95
# -------------------------------
# Training loss: 0.234869
# Validation loss: 0.234717
#
# Epoch 96
# -------------------------------
# Training loss: 0.234612
# Validation loss: 0.232130
#
# Epoch 97
# -------------------------------
# Training loss: 0.234190
# Validation loss: 0.232787
#
# Epoch 98
# -------------------------------
# Training loss: 0.233217
# Validation loss: 0.229471
#
# Epoch 99
# -------------------------------
# Training loss: 0.232226
# Validation loss: 0.231753
#
# Epoch 100
# -------------------------------
# Training loss: 0.231255
# Validation loss: 0.230394
#
# Epoch 101
# -------------------------------
# Training loss: 0.230959
# Validation loss: 0.228814
#
# Epoch 102
# -------------------------------
# Training loss: 0.230302
# Validation loss: 0.228414
#
# Epoch 103
# -------------------------------
# Training loss: 0.229449
# Validation loss: 0.228177
#
# Epoch 104
# -------------------------------
# Training loss: 0.228854
# Validation loss: 0.227072
#
# Epoch 105
# -------------------------------
# Training loss: 0.228032
# Validation loss: 0.227075
#
# Epoch 106
# -------------------------------
# Training loss: 0.227208
# Validation loss: 0.225239
#
# Epoch 107
# -------------------------------
# Training loss: 0.227051
# Validation loss: 0.225102
#
# Epoch 108
# -------------------------------
# Training loss: 0.226194
# Validation loss: 0.224605
#
# Epoch 109
# -------------------------------
# Training loss: 0.225153
# Validation loss: 0.223601
#
# Epoch 110
# -------------------------------
# Training loss: 0.224424
# Validation loss: 0.224919
#
# Epoch 111
# -------------------------------
# Training loss: 0.224095
# Validation loss: 0.222230
#
# Epoch 112
# -------------------------------
# Training loss: 0.223153
# Validation loss: 0.221913
#
# Epoch 113
# -------------------------------
# Training loss: 0.222971
# Validation loss: 0.222115
#
# Epoch 114
# -------------------------------
# Training loss: 0.222332
# Validation loss: 0.221436
#
# Epoch 115
# -------------------------------
# Training loss: 0.221628
# Validation loss: 0.220284
#
# Epoch 116
# -------------------------------
# Training loss: 0.220982
# Validation loss: 0.220262
#
# Epoch 117
# -------------------------------
# Training loss: 0.220550
# Validation loss: 0.220194
#
# Epoch 118
# -------------------------------
# Training loss: 0.219904
# Validation loss: 0.218288
#
# Epoch 119
# -------------------------------
# Training loss: 0.219251
# Validation loss: 0.218862
#
# Epoch 120
# -------------------------------
# Training loss: 0.218678
# Validation loss: 0.218359
#
# Epoch 121
# -------------------------------
# Training loss: 0.218237
# Validation loss: 0.217347
#
# Epoch 122
# -------------------------------
# Training loss: 0.217480
# Validation loss: 0.217517
#
# Epoch 123
# -------------------------------
# Training loss: 0.217206
# Validation loss: 0.215690
#
# Epoch 124
# -------------------------------
# Training loss: 0.216548
# Validation loss: 0.216292
#
# Epoch 125
# -------------------------------
# Training loss: 0.215668
# Validation loss: 0.215202
#
# Epoch 126
# -------------------------------
# Training loss: 0.215225
# Validation loss: 0.213770
#
# Epoch 127
# -------------------------------
# Training loss: 0.214767
# Validation loss: 0.214681
#
# Epoch 128
# -------------------------------
# Training loss: 0.214293
# Validation loss: 0.212473
#
# Epoch 129
# -------------------------------
# Training loss: 0.213582
# Validation loss: 0.213729
#
# Epoch 130
# -------------------------------
# Training loss: 0.213634
# Validation loss: 0.211909
#
# Epoch 131
# -------------------------------
# Training loss: 0.212757
# Validation loss: 0.212738
#
# Epoch 132
# -------------------------------
# Training loss: 0.212043
# Validation loss: 0.212878
#
# Epoch 133
# -------------------------------
# Training loss: 0.211620
# Validation loss: 0.211803
#
# Epoch 134
# -------------------------------
# Training loss: 0.211274
# Validation loss: 0.210452
#
# Epoch 135
# -------------------------------
# Training loss: 0.210914
# Validation loss: 0.210509
#
# Epoch 136
# -------------------------------
# Training loss: 0.210617
# Validation loss: 0.209286
#
# Epoch 137
# -------------------------------
# Training loss: 0.209586
# Validation loss: 0.207756
#
# Epoch 138
# -------------------------------
# Training loss: 0.208996
# Validation loss: 0.207322
#
# Epoch 139
# -------------------------------
# Training loss: 0.208681
# Validation loss: 0.208456
#
# Epoch 140
# -------------------------------
# Training loss: 0.208125
# Validation loss: 0.208192
#
# Epoch 141
# -------------------------------
# Training loss: 0.207629
# Validation loss: 0.206254
#
# Epoch 142
# -------------------------------
# Training loss: 0.207115
# Validation loss: 0.208247
#
# Epoch 143
# -------------------------------
# Training loss: 0.206604
# Validation loss: 0.207353
#
# Epoch 144
# -------------------------------
# Training loss: 0.206456
# Validation loss: 0.205355
#
# Epoch 145
# -------------------------------
# Training loss: 0.205792
# Validation loss: 0.204436
#
# Epoch 146
# -------------------------------
# Training loss: 0.205728
# Validation loss: 0.205653
#
# Epoch 147
# -------------------------------
# Training loss: 0.205008
# Validation loss: 0.203581
#
# Epoch 148
# -------------------------------
# Training loss: 0.204549
# Validation loss: 0.202399
#
# Epoch 149
# -------------------------------
# Training loss: 0.204325
# Validation loss: 0.203945
#
# Epoch 150
# -------------------------------
# Training loss: 0.203523
# Validation loss: 0.203365
#
# Epoch 151
# -------------------------------
# Training loss: 0.203267
# Validation loss: 0.202949
#
# Epoch 152
# -------------------------------
# Training loss: 0.202782
# Validation loss: 0.202589
#
# Epoch 153
# -------------------------------
# Training loss: 0.202045
# Validation loss: 0.201053
#
# Epoch 154
# -------------------------------
# Training loss: 0.201695
# Validation loss: 0.200979
#
# Epoch 155
# -------------------------------
# Training loss: 0.201400
# Validation loss: 0.199015
#
# Epoch 156
# -------------------------------
# Training loss: 0.200971
# Validation loss: 0.200257
#
# Epoch 157
# -------------------------------
# Training loss: 0.200536
# Validation loss: 0.200728
#
# Epoch 158
# -------------------------------
# Training loss: 0.200344
# Validation loss: 0.200474
#
# Epoch 159
# -------------------------------
# Training loss: 0.200074
# Validation loss: 0.199200
#
# Epoch 160
# -------------------------------
# Training loss: 0.199048
# Validation loss: 0.198707
#
# Epoch 161
# -------------------------------
# Training loss: 0.198887
# Validation loss: 0.199734
#
# Epoch 162
# -------------------------------
# Training loss: 0.198396
# Validation loss: 0.197672
#
# Epoch 163
# -------------------------------
# Training loss: 0.198175
# Validation loss: 0.197858
#
# Epoch 164
# -------------------------------
# Training loss: 0.198169
# Validation loss: 0.198140
#
# Epoch 165
# -------------------------------
# Training loss: 0.197293
# Validation loss: 0.197005
#
# Epoch 166
# -------------------------------
# Training loss: 0.196974
# Validation loss: 0.196005
#
# Epoch 167
# -------------------------------
# Training loss: 0.196811
# Validation loss: 0.196910
#
# Epoch 168
# -------------------------------
# Training loss: 0.196259
# Validation loss: 0.195981
#
# Epoch 169
# -------------------------------
# Training loss: 0.195944
# Validation loss: 0.194717
#
# Epoch 170
# -------------------------------
# Training loss: 0.195205
# Validation loss: 0.195327
#
# Epoch 171
# -------------------------------
# Training loss: 0.194844
# Validation loss: 0.195245
#
# Epoch 172
# -------------------------------
# Training loss: 0.194378
# Validation loss: 0.194968
#
# Epoch 173
# -------------------------------
# Training loss: 0.194837
# Validation loss: 0.194366
#
# Epoch 174
# -------------------------------
# Training loss: 0.193728
# Validation loss: 0.193152
#
# Epoch 175
# -------------------------------
# Training loss: 0.193217
# Validation loss: 0.193215
#
# Epoch 176
# -------------------------------
# Training loss: 0.193417
# Validation loss: 0.193064
#
# Epoch 177
# -------------------------------
# Training loss: 0.192992
# Validation loss: 0.192500
#
# Epoch 178
# -------------------------------
# Training loss: 0.192445
# Validation loss: 0.193919
#
# Epoch 179
# -------------------------------
# Training loss: 0.192100
# Validation loss: 0.191666
#
# Epoch 180
# -------------------------------
# Training loss: 0.191641
# Validation loss: 0.193084
#
# Epoch 181
# -------------------------------
# Training loss: 0.191070
# Validation loss: 0.190212
#
# Epoch 182
# -------------------------------
# Training loss: 0.190652
# Validation loss: 0.191971
#
# Epoch 183
# -------------------------------
# Training loss: 0.190659
# Validation loss: 0.190715
#
# Epoch 184
# -------------------------------
# Training loss: 0.190152
# Validation loss: 0.190359
#
# Epoch 185
# -------------------------------
# Training loss: 0.189538
# Validation loss: 0.189788
#
# Epoch 186
# -------------------------------
# Training loss: 0.189326
# Validation loss: 0.190002
#
# Epoch 187
# -------------------------------
# Training loss: 0.188738
# Validation loss: 0.188306
#
# Epoch 188
# -------------------------------
# Training loss: 0.188374
# Validation loss: 0.188270
#
# Epoch 189
# -------------------------------
# Training loss: 0.188010
# Validation loss: 0.188325
#
# Epoch 190
# -------------------------------
# Training loss: 0.188022
# Validation loss: 0.188915
#
# Epoch 191
# -------------------------------
# Training loss: 0.187457
# Validation loss: 0.188123
#
# Epoch 192
# -------------------------------
# Training loss: 0.187154
# Validation loss: 0.186505
#
# Epoch 193
# -------------------------------
# Training loss: 0.186690
# Validation loss: 0.188215
#
# Epoch 194
# -------------------------------
# Training loss: 0.186667
# Validation loss: 0.185935
#
# Epoch 195
# -------------------------------
# Training loss: 0.186198
# Validation loss: 0.185620
#
# Epoch 196
# -------------------------------
# Training loss: 0.185720
# Validation loss: 0.185922
#
# Epoch 197
# -------------------------------
# Training loss: 0.185453
# Validation loss: 0.186155
#
# Epoch 198
# -------------------------------
# Training loss: 0.185035
# Validation loss: 0.185340
#
# Epoch 199
# -------------------------------
# Training loss: 0.184743
# Validation loss: 0.185204
#
# Epoch 200
# -------------------------------
# Training loss: 0.184739
# Validation loss: 0.184542
#
# Epoch 201
# -------------------------------
# Training loss: 0.184239
# Validation loss: 0.185493
#
# Epoch 202
# -------------------------------
# Training loss: 0.183681
# Validation loss: 0.183854
#
# Epoch 203
# -------------------------------
# Training loss: 0.183514
# Validation loss: 0.183360
#
# Epoch 204
# -------------------------------
# Training loss: 0.183099
# Validation loss: 0.183500
#
# Epoch 205
# -------------------------------
# Training loss: 0.183147
# Validation loss: 0.185147
#
# Epoch 206
# -------------------------------
# Training loss: 0.182363
# Validation loss: 0.182977
#
# Epoch 207
# -------------------------------
# Training loss: 0.182041
# Validation loss: 0.181830
#
# Epoch 208
# -------------------------------
# Training loss: 0.182047
# Validation loss: 0.182825
#
# Epoch 209
# -------------------------------
# Training loss: 0.181694
# Validation loss: 0.182762
#
# Epoch 210
# -------------------------------
# Training loss: 0.180829
# Validation loss: 0.181509
#
# Epoch 211
# -------------------------------
# Training loss: 0.180774
# Validation loss: 0.180705
#
# Epoch 212
# -------------------------------
# Training loss: 0.180437
# Validation loss: 0.181881
#
# Epoch 213
# -------------------------------
# Training loss: 0.180278
# Validation loss: 0.180914
#
# Epoch 214
# -------------------------------
# Training loss: 0.179691
# Validation loss: 0.180618
#
# Epoch 215
# -------------------------------
# Training loss: 0.179616
# Validation loss: 0.180867
#
# Epoch 216
# -------------------------------
# Training loss: 0.179193
# Validation loss: 0.180603
#
# Epoch 217
# -------------------------------
# Training loss: 0.179134
# Validation loss: 0.180103
#
# Epoch 218
# -------------------------------
# Training loss: 0.178484
# Validation loss: 0.181139
#
# Epoch 219
# -------------------------------
# Training loss: 0.178578
# Validation loss: 0.178650
#
# Epoch 220
# -------------------------------
# Training loss: 0.177861
# Validation loss: 0.180115
#
# Epoch 221
# -------------------------------
# Training loss: 0.177651
# Validation loss: 0.178665
#
# Epoch 222
# -------------------------------
# Training loss: 0.177387
# Validation loss: 0.178055
#
# Epoch 223
# -------------------------------
# Training loss: 0.176684
# Validation loss: 0.178232
#
# Epoch 224
# -------------------------------
# Training loss: 0.176796
# Validation loss: 0.178204
#
# Epoch 225
# -------------------------------
# Training loss: 0.176536
# Validation loss: 0.178221
#
# Epoch 226
# -------------------------------
# Training loss: 0.175973
# Validation loss: 0.177282
#
# Epoch 227
# -------------------------------
# Training loss: 0.176027
# Validation loss: 0.176465
#
# Epoch 228
# -------------------------------
# Training loss: 0.175982
# Validation loss: 0.177994
#
# Epoch 229
# -------------------------------
# Training loss: 0.175033
# Validation loss: 0.177397
#
# Epoch 230
# -------------------------------
# Training loss: 0.174931
# Validation loss: 0.176066
#
# Epoch 231
# -------------------------------
# Training loss: 0.174277
# Validation loss: 0.175588
#
# Epoch 232
# -------------------------------
# Training loss: 0.174188
# Validation loss: 0.176827
#
# Epoch 233
# -------------------------------
# Training loss: 0.174380
# Validation loss: 0.175830
#
# Epoch 234
# -------------------------------
# Training loss: 0.173686
# Validation loss: 0.176206
#
# Epoch 235
# -------------------------------
# Training loss: 0.173481
# Validation loss: 0.175020
#
# Epoch 236
# -------------------------------
# Training loss: 0.173243
# Validation loss: 0.175673
#
# Epoch 237
# -------------------------------
# Training loss: 0.172539
# Validation loss: 0.174959
#
# Epoch 238
# -------------------------------
# Training loss: 0.172516
# Validation loss: 0.172785
#
# Epoch 239
# -------------------------------
# Training loss: 0.172105
# Validation loss: 0.173729
#
# Epoch 240
# -------------------------------
# Training loss: 0.172003
# Validation loss: 0.174182
#
# Epoch 241
# -------------------------------
# Training loss: 0.171699
# Validation loss: 0.174452
#
# Epoch 242
# -------------------------------
# Training loss: 0.171186
# Validation loss: 0.173317
#
# Epoch 243
# -------------------------------
# Training loss: 0.171225
# Validation loss: 0.173042
#
# Epoch 244
# -------------------------------
# Training loss: 0.170906
# Validation loss: 0.171476
#
# Epoch 245
# -------------------------------
# Training loss: 0.170435
# Validation loss: 0.170902
#
# Epoch 246
# -------------------------------
# Training loss: 0.170179
# Validation loss: 0.170725
#
# Epoch 247
# -------------------------------
# Training loss: 0.170105
# Validation loss: 0.170692
#
# Epoch 248
# -------------------------------
# Training loss: 0.169497
# Validation loss: 0.171985
#
# Epoch 249
# -------------------------------
# Training loss: 0.169334
# Validation loss: 0.171330
#
# Epoch 250
# -------------------------------
# Training loss: 0.169252
# Validation loss: 0.171322
#
# Epoch 251
# -------------------------------
# Training loss: 0.169087
# Validation loss: 0.171417
#
# Epoch 252
# -------------------------------
# Training loss: 0.168794
# Validation loss: 0.171375
#
# Epoch 253
# -------------------------------
# Training loss: 0.168156
# Validation loss: 0.169903
#
# Epoch 254
# -------------------------------
# Training loss: 0.167888
# Validation loss: 0.169694
#
# Epoch 255
# -------------------------------
# Training loss: 0.167663
# Validation loss: 0.169677
#
# Epoch 256
# -------------------------------
# Training loss: 0.167238
# Validation loss: 0.169877
#
# Epoch 257
# -------------------------------
# Training loss: 0.166905
# Validation loss: 0.168952
#
# Epoch 258
# -------------------------------
# Training loss: 0.166895
# Validation loss: 0.169524
#
# Epoch 259
# -------------------------------
# Training loss: 0.166414
# Validation loss: 0.168016
#
# Epoch 260
# -------------------------------
# Training loss: 0.166157
# Validation loss: 0.168310
#
# Epoch 261
# -------------------------------
# Training loss: 0.166046
# Validation loss: 0.167865
#
# Epoch 262
# -------------------------------
# Training loss: 0.166005
# Validation loss: 0.168462
#
# Epoch 263
# -------------------------------
# Training loss: 0.165636
# Validation loss: 0.167912
#
# Epoch 264
# -------------------------------
# Training loss: 0.165094
# Validation loss: 0.168360
#
# Epoch 265
# -------------------------------
# Training loss: 0.164936
# Validation loss: 0.166389
#
# Epoch 266
# -------------------------------
# Training loss: 0.164415
# Validation loss: 0.167223
#
# Epoch 267
# -------------------------------
# Training loss: 0.164515
# Validation loss: 0.167522
#
# Epoch 268
# -------------------------------
# Training loss: 0.164272
# Validation loss: 0.166040
#
# Epoch 269
# -------------------------------
# Training loss: 0.164385
# Validation loss: 0.165418
#
# Epoch 270
# -------------------------------
# Training loss: 0.163878
# Validation loss: 0.167126
#
# Epoch 271
# -------------------------------
# Training loss: 0.163476
# Validation loss: 0.165518
#
# Epoch 272
# -------------------------------
# Training loss: 0.163088
# Validation loss: 0.164655
#
# Epoch 273
# -------------------------------
# Training loss: 0.162909
# Validation loss: 0.165040
#
# Epoch 274
# -------------------------------
# Training loss: 0.162490
# Validation loss: 0.165068
#
# Epoch 275
# -------------------------------
# Training loss: 0.162271
# Validation loss: 0.164421
#
# Epoch 276
# -------------------------------
# Training loss: 0.162080
# Validation loss: 0.164917
#
# Epoch 277
# -------------------------------
# Training loss: 0.161834
# Validation loss: 0.163707
#
# Epoch 278
# -------------------------------
# Training loss: 0.161445
# Validation loss: 0.164590
#
# Epoch 279
# -------------------------------
# Training loss: 0.161164
# Validation loss: 0.163234
#
# Epoch 280
# -------------------------------
# Training loss: 0.161212
# Validation loss: 0.164433
#
# Epoch 281
# -------------------------------
# Training loss: 0.160985
# Validation loss: 0.162845
#
# Epoch 282
# -------------------------------
# Training loss: 0.160653
# Validation loss: 0.162571
#
# Epoch 283
# -------------------------------
# Training loss: 0.160373
# Validation loss: 0.161932
#
# Epoch 284
# -------------------------------
# Training loss: 0.160100
# Validation loss: 0.162839
#
# Epoch 285
# -------------------------------
# Training loss: 0.160082
# Validation loss: 0.161642
#
# Epoch 286
# -------------------------------
# Training loss: 0.159452
# Validation loss: 0.162029
#
# Epoch 287
# -------------------------------
# Training loss: 0.159618
# Validation loss: 0.162445
#
# Epoch 288
# -------------------------------
# Training loss: 0.159090
# Validation loss: 0.161486
#
# Epoch 289
# -------------------------------
# Training loss: 0.158718
# Validation loss: 0.161844
#
# Epoch 290
# -------------------------------
# Training loss: 0.158476
# Validation loss: 0.159983
#
# Epoch 291
# -------------------------------
# Training loss: 0.158224
# Validation loss: 0.160744
#
# Epoch 292
# -------------------------------
# Training loss: 0.158064
# Validation loss: 0.161058
#
# Epoch 293
# -------------------------------
# Training loss: 0.157815
# Validation loss: 0.161650
#
# Epoch 294
# -------------------------------
# Training loss: 0.157194
# Validation loss: 0.159500
#
# Epoch 295
# -------------------------------
# Training loss: 0.157352
# Validation loss: 0.159664
#
# Epoch 296
# -------------------------------
# Training loss: 0.157303
# Validation loss: 0.160293
#
# Epoch 297
# -------------------------------
# Training loss: 0.156661
# Validation loss: 0.159067
#
# Epoch 298
# -------------------------------
# Training loss: 0.156457
# Validation loss: 0.159792
#
# Epoch 299
# -------------------------------
# Training loss: 0.156430
# Validation loss: 0.159181
#
# Epoch 300
# -------------------------------
# Training loss: 0.155927
# Validation loss: 0.158803
#
# Epoch 301
# -------------------------------
# Training loss: 0.155632
# Validation loss: 0.158492
#
# Epoch 302
# -------------------------------
# Training loss: 0.155562
# Validation loss: 0.156732
#
# Epoch 303
# -------------------------------
# Training loss: 0.155130
# Validation loss: 0.157902
#
# Epoch 304
# -------------------------------
# Training loss: 0.154645
# Validation loss: 0.157471
#
# Epoch 305
# -------------------------------
# Training loss: 0.154552
# Validation loss: 0.157723
#
# Epoch 306
# -------------------------------
# Training loss: 0.154704
# Validation loss: 0.158224
#
# Epoch 307
# -------------------------------
# Training loss: 0.154300
# Validation loss: 0.157833
#
# Epoch 308
# -------------------------------
# Training loss: 0.153949
# Validation loss: 0.158831
#
# Epoch 309
# -------------------------------
# Training loss: 0.153803
# Validation loss: 0.156336
#
# Epoch 310
# -------------------------------
# Training loss: 0.153420
# Validation loss: 0.156155
#
# Epoch 311
# -------------------------------
# Training loss: 0.153305
# Validation loss: 0.156467
#
# Epoch 312
# -------------------------------
# Training loss: 0.153026
# Validation loss: 0.155151
#
# Epoch 313
# -------------------------------
# Training loss: 0.152746
# Validation loss: 0.155248
#
# Epoch 314
# -------------------------------
# Training loss: 0.152570
# Validation loss: 0.155344
#
# Epoch 315
# -------------------------------
# Training loss: 0.152501
# Validation loss: 0.155662
#
# Epoch 316
# -------------------------------
# Training loss: 0.152100
# Validation loss: 0.154715
#
# Epoch 317
# -------------------------------
# Training loss: 0.151743
# Validation loss: 0.153902
#
# Epoch 318
# -------------------------------
# Training loss: 0.151694
# Validation loss: 0.154051
#
# Epoch 319
# -------------------------------
# Training loss: 0.151489
# Validation loss: 0.155331
#
# Epoch 320
# -------------------------------
# Training loss: 0.151168
# Validation loss: 0.154503
#
# Epoch 321
# -------------------------------
# Training loss: 0.150783
# Validation loss: 0.153979
#
# Epoch 322
# -------------------------------
# Training loss: 0.150430
# Validation loss: 0.153276
#
# Epoch 323
# -------------------------------
# Training loss: 0.150506
# Validation loss: 0.153629
#
# Epoch 324
# -------------------------------
# Training loss: 0.150071
# Validation loss: 0.153661
#
# Epoch 325
# -------------------------------
# Training loss: 0.149886
# Validation loss: 0.153434
#
# Epoch 326
# -------------------------------
# Training loss: 0.149978
# Validation loss: 0.152888
#
# Epoch 327
# -------------------------------
# Training loss: 0.149644
# Validation loss: 0.151766
#
# Epoch 328
# -------------------------------
# Training loss: 0.149204
# Validation loss: 0.151719
#
# Epoch 329
# -------------------------------
# Training loss: 0.149123
# Validation loss: 0.151678
#
# Epoch 330
# -------------------------------
# Training loss: 0.148762
# Validation loss: 0.152288
#
# Epoch 331
# -------------------------------
# Training loss: 0.148610
# Validation loss: 0.152104
#
# Epoch 332
# -------------------------------
# Training loss: 0.148208
# Validation loss: 0.150672
#
# Epoch 333
# -------------------------------
# Training loss: 0.147956
# Validation loss: 0.151255
#
# Epoch 334
# -------------------------------
# Training loss: 0.147961
# Validation loss: 0.150095
#
# Epoch 335
# -------------------------------
# Training loss: 0.147819
# Validation loss: 0.149733
#
# Epoch 336
# -------------------------------
# Training loss: 0.147512
# Validation loss: 0.152155
#
# Epoch 337
# -------------------------------
# Training loss: 0.146900
# Validation loss: 0.149684
#
# Epoch 338
# -------------------------------
# Training loss: 0.147169
# Validation loss: 0.150325
#
# Epoch 339
# -------------------------------
# Training loss: 0.147085
# Validation loss: 0.150786
#
# Epoch 340
# -------------------------------
# Training loss: 0.146515
# Validation loss: 0.150327
#
# Epoch 341
# -------------------------------
# Training loss: 0.146269
# Validation loss: 0.150076
#
# Epoch 342
# -------------------------------
# Training loss: 0.146238
# Validation loss: 0.151111
#
# Epoch 343
# -------------------------------
# Training loss: 0.146019
# Validation loss: 0.150065
#
# Epoch 344
# -------------------------------
# Training loss: 0.145680
# Validation loss: 0.149276
#
# Epoch 345
# -------------------------------
# Training loss: 0.145443
# Validation loss: 0.149317
#
# Epoch 346
# -------------------------------
# Training loss: 0.145264
# Validation loss: 0.148515
#
# Epoch 347
# -------------------------------
# Training loss: 0.144798
# Validation loss: 0.148691
#
# Epoch 348
# -------------------------------
# Training loss: 0.144816
# Validation loss: 0.148174
#
# Epoch 349
# -------------------------------
# Training loss: 0.144628
# Validation loss: 0.148027
#
# Epoch 350
# -------------------------------
# Training loss: 0.144520
# Validation loss: 0.147525
#
# Epoch 351
# -------------------------------
# Training loss: 0.144098
# Validation loss: 0.147589
#
# Epoch 352
# -------------------------------
# Training loss: 0.143940
# Validation loss: 0.147292
#
# Epoch 353
# -------------------------------
# Training loss: 0.143808
# Validation loss: 0.149183
#
# Epoch 354
# -------------------------------
# Training loss: 0.144091
# Validation loss: 0.147966
#
# Epoch 355
# -------------------------------
# Training loss: 0.143394
# Validation loss: 0.146390
#
# Epoch 356
# -------------------------------
# Training loss: 0.143496
# Validation loss: 0.147911
#
# Epoch 357
# -------------------------------
# Training loss: 0.143133
# Validation loss: 0.148543
#
# Epoch 358
# -------------------------------
# Training loss: 0.142725
# Validation loss: 0.145967
#
# Epoch 359
# -------------------------------
# Training loss: 0.142317
# Validation loss: 0.147962
#
# Epoch 360
# -------------------------------
# Training loss: 0.142407
# Validation loss: 0.146604
#
# Epoch 361
# -------------------------------
# Training loss: 0.142122
# Validation loss: 0.146346
#
# Epoch 362
# -------------------------------
# Training loss: 0.141810
# Validation loss: 0.145499
#
# Epoch 363
# -------------------------------
# Training loss: 0.141716
# Validation loss: 0.146228
#
# Epoch 364
# -------------------------------
# Training loss: 0.141487
# Validation loss: 0.144789
#
# Epoch 365
# -------------------------------
# Training loss: 0.141138
# Validation loss: 0.144082
#
# Epoch 366
# -------------------------------
# Training loss: 0.140903
# Validation loss: 0.145302
#
# Epoch 367
# -------------------------------
# Training loss: 0.140825
# Validation loss: 0.145182
#
# Epoch 368
# -------------------------------
# Training loss: 0.140858
# Validation loss: 0.144675
#
# Epoch 369
# -------------------------------
# Training loss: 0.140635
# Validation loss: 0.144757
#
# Epoch 370
# -------------------------------
# Training loss: 0.140011
# Validation loss: 0.143959
#
# Epoch 371
# -------------------------------
# Training loss: 0.139893
# Validation loss: 0.144455
#
# Epoch 372
# -------------------------------
# Training loss: 0.139604
# Validation loss: 0.143172
#
# Epoch 373
# -------------------------------
# Training loss: 0.139396
# Validation loss: 0.143151
#
# Epoch 374
# -------------------------------
# Training loss: 0.139105
# Validation loss: 0.143370
#
# Epoch 375
# -------------------------------
# Training loss: 0.139141
# Validation loss: 0.142289
#
# Epoch 376
# -------------------------------
# Training loss: 0.138866
# Validation loss: 0.142572
#
# Epoch 377
# -------------------------------
# Training loss: 0.138821
# Validation loss: 0.141962
#
# Epoch 378
# -------------------------------
# Training loss: 0.138445
# Validation loss: 0.142254
#
# Epoch 379
# -------------------------------
# Training loss: 0.138637
# Validation loss: 0.143831
#
# Epoch 380
# -------------------------------
# Training loss: 0.138284
# Validation loss: 0.142898
#
# Epoch 381
# -------------------------------
# Training loss: 0.137658
# Validation loss: 0.142584
#
# Epoch 382
# -------------------------------
# Training loss: 0.137526
# Validation loss: 0.141285
#
# Epoch 383
# -------------------------------
# Training loss: 0.137390
# Validation loss: 0.140600
#
# Epoch 384
# -------------------------------
# Training loss: 0.137165
# Validation loss: 0.141119
#
# Epoch 385
# -------------------------------
# Training loss: 0.137082
# Validation loss: 0.142434
#
# Epoch 386
# -------------------------------
# Training loss: 0.137027
# Validation loss: 0.141579
#
# Epoch 387
# -------------------------------
# Training loss: 0.136722
# Validation loss: 0.140929
#
# Epoch 388
# -------------------------------
# Training loss: 0.136660
# Validation loss: 0.139999
#
# Epoch 389
# -------------------------------
# Training loss: 0.136199
# Validation loss: 0.140358
#
# Epoch 390
# -------------------------------
# Training loss: 0.136139
# Validation loss: 0.140410
#
# Epoch 391
# -------------------------------
# Training loss: 0.135858
# Validation loss: 0.140750
#
# Epoch 392
# -------------------------------
# Training loss: 0.135907
# Validation loss: 0.139389
#
# Epoch 393
# -------------------------------
# Training loss: 0.135527
# Validation loss: 0.140070
#
# Epoch 394
# -------------------------------
# Training loss: 0.135366
# Validation loss: 0.138666
#
# Epoch 395
# -------------------------------
# Training loss: 0.134998
# Validation loss: 0.140418
#
# Epoch 396
# -------------------------------
# Training loss: 0.135183
# Validation loss: 0.138843
#
# Epoch 397
# -------------------------------
# Training loss: 0.134832
# Validation loss: 0.138982
#
# Epoch 398
# -------------------------------
# Training loss: 0.134685
# Validation loss: 0.139037
#
# Epoch 399
# -------------------------------
# Training loss: 0.134225
# Validation loss: 0.139052
#
# Epoch 400
# -------------------------------
# Training loss: 0.134353
# Validation loss: 0.139955
#
# Epoch 401
# -------------------------------
# Training loss: 0.133887
# Validation loss: 0.137000
#
# Epoch 402
# -------------------------------
# Training loss: 0.133599
# Validation loss: 0.138518
#
# Epoch 403
# -------------------------------
# Training loss: 0.133741
# Validation loss: 0.137180
#
# Epoch 404
# -------------------------------
# Training loss: 0.133237
# Validation loss: 0.137337
#
# Epoch 405
# -------------------------------
# Training loss: 0.133177
# Validation loss: 0.138275
#
# Epoch 406
# -------------------------------
# Training loss: 0.133004
# Validation loss: 0.136730
#
# Epoch 407
# -------------------------------
# Training loss: 0.132609
# Validation loss: 0.137548
#
# Epoch 408
# -------------------------------
# Training loss: 0.132523
# Validation loss: 0.136306
#
# Epoch 409
# -------------------------------
# Training loss: 0.132426
# Validation loss: 0.136642
#
# Epoch 410
# -------------------------------
# Training loss: 0.132058
# Validation loss: 0.135369
#
# Epoch 411
# -------------------------------
# Training loss: 0.132038
# Validation loss: 0.135896
#
# Epoch 412
# -------------------------------
# Training loss: 0.131806
# Validation loss: 0.136365
#
# Epoch 413
# -------------------------------
# Training loss: 0.131673
# Validation loss: 0.135816
#
# Epoch 414
# -------------------------------
# Training loss: 0.131321
# Validation loss: 0.134879
#
# Epoch 415
# -------------------------------
# Training loss: 0.131147
# Validation loss: 0.134316
#
# Epoch 416
# -------------------------------
# Training loss: 0.130962
# Validation loss: 0.134678
#
# Epoch 417
# -------------------------------
# Training loss: 0.130855
# Validation loss: 0.135399
#
# Epoch 418
# -------------------------------
# Training loss: 0.130931
# Validation loss: 0.134170
#
# Epoch 419
# -------------------------------
# Training loss: 0.130583
# Validation loss: 0.135575
#
# Epoch 420
# -------------------------------
# Training loss: 0.130378
# Validation loss: 0.134698
#
# Epoch 421
# -------------------------------
# Training loss: 0.130134
# Validation loss: 0.135666
#
# Epoch 422
# -------------------------------
# Training loss: 0.129782
# Validation loss: 0.135207
#
# Epoch 423
# -------------------------------
# Training loss: 0.129613
# Validation loss: 0.135168
#
# Epoch 424
# -------------------------------
# Training loss: 0.129614
# Validation loss: 0.133850
#
# Epoch 425
# -------------------------------
# Training loss: 0.129587
# Validation loss: 0.133843
#
# Epoch 426
# -------------------------------
# Training loss: 0.129393
# Validation loss: 0.133945
#
# Epoch 427
# -------------------------------
# Training loss: 0.129211
# Validation loss: 0.134273
#
# Epoch 428
# -------------------------------
# Training loss: 0.128737
# Validation loss: 0.133182
#
# Epoch 429
# -------------------------------
# Training loss: 0.129226
# Validation loss: 0.135249
#
# Epoch 430
# -------------------------------
# Training loss: 0.128355
# Validation loss: 0.133874
#
# Epoch 431
# -------------------------------
# Training loss: 0.128363
# Validation loss: 0.132751
#
# Epoch 432
# -------------------------------
# Training loss: 0.128134
# Validation loss: 0.132163
#
# Epoch 433
# -------------------------------
# Training loss: 0.127614
# Validation loss: 0.132184
#
# Epoch 434
# -------------------------------
# Training loss: 0.127957
# Validation loss: 0.133325
#
# Epoch 435
# -------------------------------
# Training loss: 0.127594
# Validation loss: 0.131663
#
# Epoch 436
# -------------------------------
# Training loss: 0.127408
# Validation loss: 0.131750
#
# Epoch 437
# -------------------------------
# Training loss: 0.127242
# Validation loss: 0.131851
#
# Epoch 438
# -------------------------------
# Training loss: 0.127218
# Validation loss: 0.131696
#
# Epoch 439
# -------------------------------
# Training loss: 0.126891
# Validation loss: 0.131553
#
# Epoch 440
# -------------------------------
# Training loss: 0.126432
# Validation loss: 0.132342
#
# Epoch 441
# -------------------------------
# Training loss: 0.126401
# Validation loss: 0.131401
#
# Epoch 442
# -------------------------------
# Training loss: 0.126180
# Validation loss: 0.131669
#
# Epoch 443
# -------------------------------
# Training loss: 0.126120
# Validation loss: 0.132995
#
# Epoch 444
# -------------------------------
# Training loss: 0.126035
# Validation loss: 0.129796
#
# Epoch 445
# -------------------------------
# Training loss: 0.125900
# Validation loss: 0.131644
#
# Epoch 446
# -------------------------------
# Training loss: 0.125893
# Validation loss: 0.132341
#
# Epoch 447
# -------------------------------
# Training loss: 0.125437
# Validation loss: 0.131079
#
# Epoch 448
# -------------------------------
# Training loss: 0.125239
# Validation loss: 0.130700
#
# Epoch 449
# -------------------------------
# Training loss: 0.124860
# Validation loss: 0.128715
#
# Epoch 450
# -------------------------------
# Training loss: 0.124975
# Validation loss: 0.128784
#
# Epoch 451
# -------------------------------
# Training loss: 0.124666
# Validation loss: 0.131470
#
# Epoch 452
# -------------------------------
# Training loss: 0.124549
# Validation loss: 0.128255
#
# Epoch 453
# -------------------------------
# Training loss: 0.124366
# Validation loss: 0.128655
#
# Epoch 454
# -------------------------------
# Training loss: 0.124287
# Validation loss: 0.129172
#
# Epoch 455
# -------------------------------
# Training loss: 0.124188
# Validation loss: 0.128812
#
# Epoch 456
# -------------------------------
# Training loss: 0.124046
# Validation loss: 0.128934
#
# Epoch 457
# -------------------------------
# Training loss: 0.123667
# Validation loss: 0.129329
#
# Epoch 458
# -------------------------------
# Training loss: 0.123537
# Validation loss: 0.129166
#
# Epoch 459
# -------------------------------
# Training loss: 0.123350
# Validation loss: 0.127959
#
# Epoch 460
# -------------------------------
# Training loss: 0.123262
# Validation loss: 0.128293
#
# Epoch 461
# -------------------------------
# Training loss: 0.122849
# Validation loss: 0.128452
#
# Epoch 462
# -------------------------------
# Training loss: 0.122607
# Validation loss: 0.128646
#
# Epoch 463
# -------------------------------
# Training loss: 0.122566
# Validation loss: 0.127977
#
# Epoch 464
# -------------------------------
# Training loss: 0.122572
# Validation loss: 0.127186
#
# Epoch 465
# -------------------------------
# Training loss: 0.122706
# Validation loss: 0.128913
#
# Epoch 466
# -------------------------------
# Training loss: 0.122254
# Validation loss: 0.126736
#
# Epoch 467
# -------------------------------
# Training loss: 0.121943
# Validation loss: 0.127208
#
# Epoch 468
# -------------------------------
# Training loss: 0.121908
# Validation loss: 0.128433
#
# Epoch 469
# -------------------------------
# Training loss: 0.121452
# Validation loss: 0.127354
#
# Epoch 470
# -------------------------------
# Training loss: 0.121503
# Validation loss: 0.127482
#
# Epoch 471
# -------------------------------
# Training loss: 0.121451
# Validation loss: 0.127022
#
# Epoch 472
# -------------------------------
# Training loss: 0.121009
# Validation loss: 0.126259
#
# Epoch 473
# -------------------------------
# Training loss: 0.120990
# Validation loss: 0.127016
#
# Epoch 474
# -------------------------------
# Training loss: 0.120874
# Validation loss: 0.126693
#
# Epoch 475
# -------------------------------
# Training loss: 0.120593
# Validation loss: 0.127504
#
# Epoch 476
# -------------------------------
# Training loss: 0.120352
# Validation loss: 0.124921
#
# Epoch 477
# -------------------------------
# Training loss: 0.120439
# Validation loss: 0.126155
#
# Epoch 478
# -------------------------------
# Training loss: 0.120840
# Validation loss: 0.126025
#
# Epoch 479
# -------------------------------
# Training loss: 0.120007
# Validation loss: 0.125149
#
# Epoch 480
# -------------------------------
# Training loss: 0.119908
# Validation loss: 0.124429
#
# Epoch 481
# -------------------------------
# Training loss: 0.119712
# Validation loss: 0.126837
#
# Epoch 482
# -------------------------------
# Training loss: 0.119605
# Validation loss: 0.125203
#
# Epoch 483
# -------------------------------
# Training loss: 0.119336
# Validation loss: 0.124973
#
# Epoch 484
# -------------------------------
# Training loss: 0.119002
# Validation loss: 0.126634
#
# Epoch 485
# -------------------------------
# Training loss: 0.118900
# Validation loss: 0.125143
#
# Epoch 486
# -------------------------------
# Training loss: 0.118946
# Validation loss: 0.124305
#
# Epoch 487
# -------------------------------
# Training loss: 0.119004
# Validation loss: 0.125415
#
# Epoch 488
# -------------------------------
# Training loss: 0.118712
# Validation loss: 0.126873
#
# Epoch 489
# -------------------------------
# Training loss: 0.118212
# Validation loss: 0.124846
#
# Epoch 490
# -------------------------------
# Training loss: 0.118074
# Validation loss: 0.125839
#
# Epoch 491
# -------------------------------
# Training loss: 0.117935
# Validation loss: 0.124566
#
# Epoch 492
# -------------------------------
# Training loss: 0.117958
# Validation loss: 0.123654
#
# Epoch 493
# -------------------------------
# Training loss: 0.117799
# Validation loss: 0.124027
#
# Epoch 494
# -------------------------------
# Training loss: 0.117556
# Validation loss: 0.122780
#
# Epoch 495
# -------------------------------
# Training loss: 0.117332
# Validation loss: 0.121970
#
# Epoch 496
# -------------------------------
# Training loss: 0.117030
# Validation loss: 0.121742
#
# Epoch 497
# -------------------------------
# Training loss: 0.117051
# Validation loss: 0.123359
#
# Epoch 498
# -------------------------------
# Training loss: 0.116883
# Validation loss: 0.121954
#
# Epoch 499
# -------------------------------
# Training loss: 0.116712
# Validation loss: 0.122897
#
# Epoch 500
# -------------------------------
# Training loss: 0.116595
# Validation loss: 0.124066
#
# Epoch 501
# -------------------------------
# Training loss: 0.116318
# Validation loss: 0.123927
#
# Epoch 502
# -------------------------------
# Training loss: 0.116848
# Validation loss: 0.122288
#
# Epoch 503
# -------------------------------
# Training loss: 0.116231
# Validation loss: 0.123201
#
# Epoch 504
# -------------------------------
# Training loss: 0.116134
# Validation loss: 0.121196
#
# Epoch 505
# -------------------------------
# Training loss: 0.115909
# Validation loss: 0.122112
#
# Epoch 506
# -------------------------------
# Training loss: 0.115909
# Validation loss: 0.122790
#
# Epoch 507
# -------------------------------
# Training loss: 0.115712
# Validation loss: 0.122852
#
# Epoch 508
# -------------------------------
# Training loss: 0.115057
# Validation loss: 0.121148
#
# Epoch 509
# -------------------------------
# Training loss: 0.115326
# Validation loss: 0.121262
#
# Epoch 510
# -------------------------------
# Training loss: 0.114983
# Validation loss: 0.120519
#
# Epoch 511
# -------------------------------
# Training loss: 0.114910
# Validation loss: 0.121357
#
# Epoch 512
# -------------------------------
# Training loss: 0.114814
# ...
# Validation loss: 0.047770
#
# Epoch 2333
# -------------------------------
# Training loss: 0.031296
# Validation loss: 0.051132
#
# Epoch 2334
# -------------------------------
# Training loss: 0.031301
# Validation loss: 0.048437
#
# Epoch 2335
# -------------------------------
# Training loss: 0.031386
# Validation loss: 0.050770
#
# Epoch 2336
# -------------------------------
# Training loss: 0.031164
# Validation loss: 0.050102
#
# Epoch 2337
# -------------------------------
# Training loss: 0.031100
# Validation loss: 0.053787
#
# Epoch 2338
# -------------------------------
# Training loss: 0.031286
# Validation loss: 0.047937
#
# Epoch 2339
# -------------------------------
# Training loss: 0.031216
# Validation loss: 0.049271
#
# Epoch 2340
# -------------------------------
# Training loss: 0.031195
# Validation loss: 0.049945
#
# Epoch 2341
# -------------------------------
# Training loss: 0.031150
# Validation loss: 0.051401
#
# Epoch 2342
# -------------------------------
# Training loss: 0.031142
# Validation loss: 0.048900
#
# Epoch 2343
# -------------------------------
# Training loss: 0.031095
# Validation loss: 0.051605
#
# Epoch 2344
# -------------------------------
# Training loss: 0.031177
# Validation loss: 0.050735
#
# Epoch 2345
# -------------------------------
# Training loss: 0.031105
# Validation loss: 0.051484
#
# Epoch 2346
# -------------------------------
# Training loss: 0.031035
# Validation loss: 0.048420
#
# Epoch 2347
# -------------------------------
# Training loss: 0.031091
# Validation loss: 0.049421
#
# Epoch 2348
# -------------------------------
# Training loss: 0.031085
# Validation loss: 0.049088
#
# Epoch 2349
# -------------------------------
# Training loss: 0.031051
# Validation loss: 0.049366
#
# Epoch 2350
# -------------------------------
# Training loss: 0.031065
# Validation loss: 0.048297
#
# Epoch 2351
# -------------------------------
# Training loss: 0.031025
# Validation loss: 0.048187
#
# Epoch 2352
# -------------------------------
# Training loss: 0.031077
# Validation loss: 0.048847
#
# Epoch 2353
# -------------------------------
# Training loss: 0.031080
# Validation loss: 0.050713
#
# Epoch 2354
# -------------------------------
# Training loss: 0.031052
# Validation loss: 0.049676
#
# Epoch 2355
# -------------------------------
# Training loss: 0.031056
# Validation loss: 0.047640
#
# Epoch 2356
# -------------------------------
# Training loss: 0.031074
# Validation loss: 0.049930
#
# Epoch 2357
# -------------------------------
# Training loss: 0.030996
# Validation loss: 0.048744
#
# Epoch 2358
# -------------------------------
# Training loss: 0.031117
# Validation loss: 0.049497
#
# Epoch 2359
# -------------------------------
# Training loss: 0.030944
# Validation loss: 0.051657
#
# Epoch 2360
# -------------------------------
# Training loss: 0.030940
# Validation loss: 0.048894
#
# Epoch 2361
# -------------------------------
# Training loss: 0.031102
# Validation loss: 0.050988
#
# Epoch 2362
# -------------------------------
# Training loss: 0.030946
# Validation loss: 0.048691
#
# Epoch 2363
# -------------------------------
# Training loss: 0.030939
# Validation loss: 0.050148
#
# Epoch 2364
# -------------------------------
# Training loss: 0.030952
# Validation loss: 0.048933
#
# Epoch 2365
# -------------------------------
# Training loss: 0.031135
# Validation loss: 0.050300
#
# Epoch 2366
# -------------------------------
# Training loss: 0.031074
# Validation loss: 0.049509
#
# Epoch 2367
# -------------------------------
# Training loss: 0.030912
# Validation loss: 0.048003
#
# Epoch 2368
# -------------------------------
# Training loss: 0.030896
# Validation loss: 0.049765
#
# Epoch 2369
# -------------------------------
# Training loss: 0.030936
# Validation loss: 0.051115
#
# Epoch 2370
# -------------------------------
# Training loss: 0.030871
# Validation loss: 0.052561
#
# Epoch 2371
# -------------------------------
# Training loss: 0.030998
# Validation loss: 0.050620
#
# Epoch 2372
# -------------------------------
# Training loss: 0.030913
# Validation loss: 0.050357
#
# Epoch 2373
# -------------------------------
# Training loss: 0.030866
# Validation loss: 0.049137
#
# Epoch 2374
# -------------------------------
# Training loss: 0.030795
# Validation loss: 0.047398
#
# Epoch 2375
# -------------------------------
# Training loss: 0.030845
# Validation loss: 0.048516
#
# Epoch 2376
# -------------------------------
# Training loss: 0.030907
# Validation loss: 0.047338
#
# Epoch 2377
# -------------------------------
# Training loss: 0.030827
# Validation loss: 0.051877
#
# Epoch 2378
# -------------------------------
# Training loss: 0.030921
# Validation loss: 0.051705
#
# Epoch 2379
# -------------------------------
# Training loss: 0.030822
# Validation loss: 0.048661
#
# Epoch 2380
# -------------------------------
# Training loss: 0.030747
# Validation loss: 0.047334
#
# Epoch 2381
# -------------------------------
# Training loss: 0.030837
# Validation loss: 0.052853
#
# Epoch 2382
# -------------------------------
# Training loss: 0.030805
# Validation loss: 0.047657
#
# Epoch 2383
# -------------------------------
# Training loss: 0.030778
# Validation loss: 0.049263
#
# Epoch 2384
# -------------------------------
# Training loss: 0.030738
# Validation loss: 0.048790
#
# Epoch 2385
# -------------------------------
# Training loss: 0.030706
# Validation loss: 0.048490
#
# Epoch 2386
# -------------------------------
# Training loss: 0.030850
# Validation loss: 0.050837
#
# Epoch 2387
# -------------------------------
# Training loss: 0.030761
# Validation loss: 0.050276
#
# Epoch 2388
# -------------------------------
# Training loss: 0.030657
# Validation loss: 0.050310
#
# Epoch 2389
# -------------------------------
# Training loss: 0.030670
# Validation loss: 0.047388
#
# Epoch 2390
# -------------------------------
# Training loss: 0.030854
# Validation loss: 0.049034
#
# Epoch 2391
# -------------------------------
# Training loss: 0.030721
# Validation loss: 0.048347
#
# Epoch 2392
# -------------------------------
# Training loss: 0.030712
# Validation loss: 0.048751
#
# Epoch 2393
# -------------------------------
# Training loss: 0.030612
# Validation loss: 0.048811
#
# Epoch 2394
# -------------------------------
# Training loss: 0.030624
# Validation loss: 0.051667
#
# Epoch 2395
# -------------------------------
# Training loss: 0.030724
# Validation loss: 0.048536
#
# Epoch 2396
# -------------------------------
# Training loss: 0.030690
# Validation loss: 0.050765
#
# Epoch 2397
# -------------------------------
# Training loss: 0.030709
# Validation loss: 0.051686
#
# Epoch 2398
# -------------------------------
# Training loss: 0.030601
# Validation loss: 0.050414
#
# Epoch 2399
# -------------------------------
# Training loss: 0.030691
# Validation loss: 0.048929
#
# Epoch 2400
# -------------------------------
# Training loss: 0.030678
# Validation loss: 0.048431
#
# Epoch 2401
# -------------------------------
# Training loss: 0.030597
# Validation loss: 0.049365
#
# Epoch 2402
# -------------------------------
# Training loss: 0.030551
# Validation loss: 0.049391
#
# Epoch 2403
# -------------------------------
# Training loss: 0.030573
# Validation loss: 0.046554
#
# Epoch 2404
# -------------------------------
# Training loss: 0.030610
# Validation loss: 0.050452
#
# Epoch 2405
# -------------------------------
# Training loss: 0.030564
# Validation loss: 0.050250
#
# Epoch 2406
# -------------------------------
# Training loss: 0.030591
# Validation loss: 0.050218
#
# Epoch 2407
# -------------------------------
# Training loss: 0.030558
# Validation loss: 0.049260
#
# Epoch 2408
# -------------------------------
# Training loss: 0.030565
# Validation loss: 0.048306
#
# Epoch 2409
# -------------------------------
# Training loss: 0.030688
# Validation loss: 0.048791
#
# Epoch 2410
# -------------------------------
# Training loss: 0.030484
# Validation loss: 0.048964
#
# Epoch 2411
# -------------------------------
# Training loss: 0.030664
# Validation loss: 0.048091
#
# Epoch 2412
# -------------------------------
# Training loss: 0.030476
# Validation loss: 0.048964
#
# Epoch 2413
# -------------------------------
# Training loss: 0.030489
# Validation loss: 0.053099
#
# Epoch 2414
# -------------------------------
# Training loss: 0.030459
# Validation loss: 0.050142
#
# Epoch 2415
# -------------------------------
# Training loss: 0.030517
# Validation loss: 0.048818
#
# Epoch 2416
# -------------------------------
# Training loss: 0.030569
# Validation loss: 0.050522
#
# Epoch 2417
# -------------------------------
# Training loss: 0.030471
# Validation loss: 0.047831
#
# Epoch 2418
# -------------------------------
# Training loss: 0.030417
# Validation loss: 0.048207
#
# Epoch 2419
# -------------------------------
# Training loss: 0.030461
# Validation loss: 0.046903
#
# Epoch 2420
# -------------------------------
# Training loss: 0.030441
# Validation loss: 0.048058
#
# Epoch 2421
# -------------------------------
# Training loss: 0.030553
# Validation loss: 0.049561
#
# Epoch 2422
# -------------------------------
# Training loss: 0.030527
# Validation loss: 0.051706
#
# Epoch 2423
# -------------------------------
# Training loss: 0.030442
# Validation loss: 0.049614
#
# Epoch 2424
# -------------------------------
# Training loss: 0.030399
# Validation loss: 0.047863
#
# Epoch 2425
# -------------------------------
# Training loss: 0.030580
# Validation loss: 0.048089
#
# Epoch 2426
# -------------------------------
# Training loss: 0.030394
# Validation loss: 0.051673
#
# Epoch 2427
# -------------------------------
# Training loss: 0.030333
# Validation loss: 0.049148
#
# Epoch 2428
# -------------------------------
# Training loss: 0.030391
# Validation loss: 0.047985
#
# Epoch 2429
# -------------------------------
# Training loss: 0.030462
# Validation loss: 0.047687
#
# Epoch 2430
# -------------------------------
# Training loss: 0.030360
# Validation loss: 0.047019
#
# Epoch 2431
# -------------------------------
# Training loss: 0.030388
# Validation loss: 0.052712
#
# Epoch 2432
# -------------------------------
# Training loss: 0.030268
# Validation loss: 0.046979
#
# Epoch 2433
# -------------------------------
# Training loss: 0.030409
# Validation loss: 0.046972
#
# Epoch 2434
# -------------------------------
# Training loss: 0.030322
# Validation loss: 0.047753
#
# Epoch 2435
# -------------------------------
# Training loss: 0.030396
# Validation loss: 0.049798
#
# Epoch 2436
# -------------------------------
# Training loss: 0.030401
# Validation loss: 0.049753
#
# Epoch 2437
# -------------------------------
# Training loss: 0.030247
# Validation loss: 0.048285
#
# Epoch 2438
# -------------------------------
# Training loss: 0.030275
# Validation loss: 0.049609
#
# Epoch 2439
# -------------------------------
# Training loss: 0.030270
# Validation loss: 0.047532
#
# Epoch 2440
# -------------------------------
# Training loss: 0.030546
# Validation loss: 0.047787
#
# Epoch 2441
# -------------------------------
# Training loss: 0.030321
# Validation loss: 0.047364
#
# Epoch 2442
# -------------------------------
# Training loss: 0.030215
# Validation loss: 0.048450
#
# Epoch 2443
# -------------------------------
# Training loss: 0.030207
# Validation loss: 0.049698
#
# Epoch 2444
# -------------------------------
# Training loss: 0.030277
# Validation loss: 0.048967
#
# Epoch 2445
# -------------------------------
# Training loss: 0.030284
# Validation loss: 0.050253
#
# Epoch 2446
# -------------------------------
# Training loss: 0.030249
# Validation loss: 0.047673
#
# Epoch 2447
# -------------------------------
# Training loss: 0.030140
# Validation loss: 0.048100
#
# Epoch 2448
# -------------------------------
# Training loss: 0.030084
# Validation loss: 0.050166
#
# Epoch 2449
# -------------------------------
# Training loss: 0.030152
# Validation loss: 0.048200
#
# Epoch 2450
# -------------------------------
# Training loss: 0.030197
# Validation loss: 0.048153
#
# Epoch 2451
# -------------------------------
# Training loss: 0.030129
# Validation loss: 0.051913
#
# Epoch 2452
# -------------------------------
# Training loss: 0.030153
# Validation loss: 0.049040
#
# Epoch 2453
# -------------------------------
# Training loss: 0.030145
# Validation loss: 0.048961
#
# Epoch 2454
# -------------------------------
# Training loss: 0.030225
# Validation loss: 0.047774
#
# Epoch 2455
# -------------------------------
# Training loss: 0.030141
# Validation loss: 0.048917
#
# Epoch 2456
# -------------------------------
# Training loss: 0.030090
# Validation loss: 0.048668
#
# Epoch 2457
# -------------------------------
# Training loss: 0.030163
# Validation loss: 0.046981
#
# Epoch 2458
# -------------------------------
# Training loss: 0.030179
# Validation loss: 0.053371
#
# Epoch 2459
# -------------------------------
# Training loss: 0.030072
# Validation loss: 0.048947
#
# Epoch 2460
# -------------------------------
# Training loss: 0.030187
# Validation loss: 0.048701
#
# Epoch 2461
# -------------------------------
# Training loss: 0.030154
# Validation loss: 0.048324
#
# Epoch 2462
# -------------------------------
# Training loss: 0.030087
# Validation loss: 0.050469
#
# Epoch 2463
# -------------------------------
# Training loss: 0.030172
# Validation loss: 0.051139
#
# Epoch 2464
# -------------------------------
# Training loss: 0.030066
# Validation loss: 0.048328
#
# Epoch 2465
# -------------------------------
# Training loss: 0.030117
# Validation loss: 0.051215
#
# Epoch 2466
# -------------------------------
# Training loss: 0.030017
# Validation loss: 0.049275
#
# Epoch 2467
# -------------------------------
# Training loss: 0.029992
# Validation loss: 0.048005
#
# Epoch 2468
# -------------------------------
# Training loss: 0.029997
# Validation loss: 0.047904
#
# Epoch 2469
# -------------------------------
# Training loss: 0.029987
# Validation loss: 0.048885
#
# Epoch 2470
# -------------------------------
# Training loss: 0.030039
# Validation loss: 0.049097
#
# Epoch 2471
# -------------------------------
# Training loss: 0.030006
# Validation loss: 0.047642
#
# Epoch 2472
# -------------------------------
# Training loss: 0.029957
# Validation loss: 0.048813
#
# Epoch 2473
# -------------------------------
# Training loss: 0.030061
# Validation loss: 0.049677
#
# Epoch 2474
# -------------------------------
# Training loss: 0.030027
# Validation loss: 0.051041
#
# Epoch 2475
# -------------------------------
# Training loss: 0.029964
# Validation loss: 0.050871
#
# Epoch 2476
# -------------------------------
# Training loss: 0.029853
# Validation loss: 0.051329
#
# Epoch 2477
# -------------------------------
# Training loss: 0.029874
# Validation loss: 0.047483
#
# Epoch 2478
# -------------------------------
# Training loss: 0.029937
# Validation loss: 0.049119
#
# Epoch 2479
# -------------------------------
# Training loss: 0.029933
# Validation loss: 0.049460
#
# Epoch 2480
# -------------------------------
# Training loss: 0.029885
# Validation loss: 0.049885
#
# Epoch 2481
# -------------------------------
# Training loss: 0.029914
# Validation loss: 0.048640
#
# Epoch 2482
# -------------------------------
# Training loss: 0.029903
# Validation loss: 0.047002
#
# Epoch 2483
# -------------------------------
# Training loss: 0.029873
# Validation loss: 0.047049
#
# Epoch 2484
# -------------------------------
# Training loss: 0.029933
# Validation loss: 0.046560
#
# Epoch 2485
# -------------------------------
# Training loss: 0.029843
# Validation loss: 0.049531
#
# Epoch 2486
# -------------------------------
# Training loss: 0.029894
# Validation loss: 0.050860
#
# Epoch 2487
# -------------------------------
# Training loss: 0.029944
# Validation loss: 0.049128
#
# Epoch 2488
# -------------------------------
# Training loss: 0.029866
# Validation loss: 0.049560
#
# Epoch 2489
# -------------------------------
# Training loss: 0.030012
# Validation loss: 0.050524
#
# Epoch 2490
# -------------------------------
# Training loss: 0.029905
# Validation loss: 0.048301
#
# Epoch 2491
# -------------------------------
# Training loss: 0.029831
# Validation loss: 0.049676
#
# Epoch 2492
# -------------------------------
# Training loss: 0.029813
# Validation loss: 0.051516
#
# Epoch 2493
# -------------------------------
# Training loss: 0.029714
# Validation loss: 0.050476
#
# Epoch 2494
# -------------------------------
# Training loss: 0.029881
# Validation loss: 0.049546
#
# Epoch 2495
# -------------------------------
# Training loss: 0.029822
# Validation loss: 0.049334
#
# Epoch 2496
# -------------------------------
# Training loss: 0.029806
# Validation loss: 0.048233
#
# Epoch 2497
# -------------------------------
# Training loss: 0.029718
# Validation loss: 0.051037
#
# Epoch 2498
# -------------------------------
# Training loss: 0.029887
# Validation loss: 0.050481
#
# Epoch 2499
# -------------------------------
# Training loss: 0.029869
# Validation loss: 0.046670
#
# Epoch 2500
# -------------------------------
# Training loss: 0.029884
# Validation loss: 0.048445
#
# Done!

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses)+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('BCE Loss')
#plt.yscale('log')
plt.legend()

# %%
# Now test the pretrained model
test_pred = mytools.test_clas(test_loader, final_classifier, device)
test_pred=torch.sigmoid(torch.tensor(test_pred)).numpy()


fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test, test_pred, pos_label=1)
auc_test = sklearn.metrics.auc(fpr, tpr)
print(f'Test AUROC: {auc_test:0.4f}')

plt.plot(fpr, tpr, label=f'Test AUROC: {auc_test:0.4f}')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
# Out:
# Test AUROC: 0.9954

# %%
pretrained_clas = copy.deepcopy(final_classifier)

# %%
# Store the pretrained classifier labels
df_test["Class_pre"] = test_pred

# Save the pretrained classifier model
#torch.save(final_classifier.state_dict(), "/Users/mghrear/data/ML_data/patch/pretrained_classifier_2021_v9_pass5_run"+str(run)+"_QualCuts.pt")

# %% [markdown]
# # Setup the adversary model

# %% [markdown]
# ## Initialize model, objective function, and optimizer

# %%
adv = mytools.Adversary(n_classes=Num_classes).to(device)
criterion_adv = nn.CrossEntropyLoss(reduction='none')  # returns loss per sample so we can weight it
opt_adv = torch.optim.Adam(adv.parameters(), lr=1e-5)
scheduler_adv = torch.optim.lr_scheduler.ExponentialLR(opt_adv, gamma=0.999)

# %% [markdown]
# ## Setup dataloaders

# %%
# Convert to tensor dataset and dataloader

# the structure is: feature, adversary label, weight
# The wight is 1 for tritrig and wab, and 0 for phiKK, to prevent the adversary from learning on phiKK events

train_adv_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_train), (torch.from_numpy(y_train.to_numpy().astype(np.float32))==0).float())
train_adv_loader = DataLoader(train_adv_dataset, batch_size=bsize, shuffle=True)

val_adv_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_val), (torch.from_numpy(y_val.to_numpy().astype(np.float32))==0).float() )
val_adv_loader = DataLoader(val_adv_dataset, batch_size=bsize, shuffle=True)

# Weights are not relavent for testing
test_adv_dataset = TensorDataset(torch.from_numpy(X_test.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_test))
test_adv_loader = DataLoader(test_adv_dataset, batch_size=bsize, shuffle=True)

# %% [markdown]
# ## Pre-train the adversary leaving classifier weights fixed

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 6

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 100
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train_adv(train_adv_loader, final_classifier, adv, criterion_adv, opt_adv, scheduler_adv, device))
    Validation_losses = np.append(Validation_losses, mytools.validate_adv(val_adv_loader, final_classifier, adv, criterion_adv, device))
    
    # Keep a running copy of the model with the lowest loss
    if Validation_losses[-1] == np.min(Validation_losses):
        final_adv = copy.deepcopy(adv)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Training loss: 1.622296
# Validation loss: 1.611943
#
# Epoch 2
# -------------------------------
# Training loss: 1.619764
# Validation loss: 1.612327
#
# Epoch 3
# -------------------------------
# Training loss: 1.617294
# Validation loss: 1.612349
#
# Epoch 4
# -------------------------------
# Training loss: 1.615768
# Validation loss: 1.613962
#
# Epoch 5
# -------------------------------
# Training loss: 1.614077
# Validation loss: 1.615153
#
# Epoch 6
# -------------------------------
# Training loss: 1.613528
# Validation loss: 1.613432
#
# Epoch 7
# -------------------------------
# Training loss: 1.612186
# Validation loss: 1.614178
#
# Epoch 8
# -------------------------------
# Training loss: 1.611495
# Validation loss: 1.613162
#
# Epoch 9
# -------------------------------
# Training loss: 1.610123
# Validation loss: 1.615741
#
# Epoch 10
# -------------------------------
# Training loss: 1.609335
# Validation loss: 1.615070
#
# Epoch 11
# -------------------------------
# Training loss: 1.608947
# Validation loss: 1.612246
#
# Epoch 12
# -------------------------------
# Training loss: 1.609088
# Validation loss: 1.611578
#
# Epoch 13
# -------------------------------
# Training loss: 1.608455
# Validation loss: 1.610926
#
# Epoch 14
# -------------------------------
# Training loss: 1.607951
# Validation loss: 1.611014
#
# Epoch 15
# -------------------------------
# Training loss: 1.607883
# Validation loss: 1.611846
#
# Epoch 16
# -------------------------------
# Training loss: 1.607590
# Validation loss: 1.612736
#
# Epoch 17
# -------------------------------
# Training loss: 1.607506
# Validation loss: 1.610671
#
# Epoch 18
# -------------------------------
# Training loss: 1.607307
# Validation loss: 1.611225
#
# Epoch 19
# -------------------------------
# Training loss: 1.607479
# Validation loss: 1.611358
#
# Epoch 20
# -------------------------------
# Training loss: 1.607403
# Validation loss: 1.609931
#
# Epoch 21
# -------------------------------
# Training loss: 1.607002
# Validation loss: 1.610971
#
# Epoch 22
# -------------------------------
# Training loss: 1.607639
# Validation loss: 1.608902
#
# Epoch 23
# -------------------------------
# Training loss: 1.607343
# Validation loss: 1.609630
#
# Epoch 24
# -------------------------------
# Training loss: 1.607127
# Validation loss: 1.612151
#
# Epoch 25
# -------------------------------
# Training loss: 1.606981
# Validation loss: 1.610237
#
# Epoch 26
# -------------------------------
# Training loss: 1.606795
# Validation loss: 1.610856
#
# Epoch 27
# -------------------------------
# Training loss: 1.606734
# Validation loss: 1.609824
#
# Epoch 28
# -------------------------------
# Training loss: 1.606611
# Validation loss: 1.609641
#
# Epoch 29
# -------------------------------
# Training loss: 1.606257
# Validation loss: 1.611826
#
# Epoch 30
# -------------------------------
# Training loss: 1.606255
# Validation loss: 1.610378
#
# Epoch 31
# -------------------------------
# Training loss: 1.606283
# Validation loss: 1.610372
#
# Epoch 32
# -------------------------------
# Training loss: 1.606334
# Validation loss: 1.610624
#
# Epoch 33
# -------------------------------
# Training loss: 1.606147
# Validation loss: 1.610317
#
# Epoch 34
# -------------------------------
# Training loss: 1.606392
# Validation loss: 1.610455
#
# Epoch 35
# -------------------------------
# Training loss: 1.606808
# Validation loss: 1.612307
#
# Epoch 36
# -------------------------------
# Training loss: 1.606390
# Validation loss: 1.613295
#
# Epoch 37
# -------------------------------
# Training loss: 1.605886
# Validation loss: 1.612011
#
# Epoch 38
# -------------------------------
# Training loss: 1.605927
# Validation loss: 1.611634
#
# Epoch 39
# -------------------------------
# Training loss: 1.605793
# Validation loss: 1.611882
#
# Epoch 40
# -------------------------------
# Training loss: 1.606114
# Validation loss: 1.608226
#
# Epoch 41
# -------------------------------
# Training loss: 1.605880
# Validation loss: 1.609252
#
# Epoch 42
# -------------------------------
# Training loss: 1.605836
# Validation loss: 1.611346
#
# Epoch 43
# -------------------------------
# Training loss: 1.605547
# Validation loss: 1.610481
#
# Epoch 44
# -------------------------------
# Training loss: 1.605491
# Validation loss: 1.610855
#
# Epoch 45
# -------------------------------
# Training loss: 1.605792
# Validation loss: 1.612143
#
# Epoch 46
# -------------------------------
# Training loss: 1.605514
# Validation loss: 1.610860
#
# Epoch 47
# -------------------------------
# Training loss: 1.605551
# Validation loss: 1.612736
#
# Epoch 48
# -------------------------------
# Training loss: 1.605350
# Validation loss: 1.611389
#
# Epoch 49
# -------------------------------
# Training loss: 1.605360
# Validation loss: 1.611789
#
# Epoch 50
# -------------------------------
# Training loss: 1.605734
# Validation loss: 1.611328
#
# Epoch 51
# -------------------------------
# Training loss: 1.605639
# Validation loss: 1.610433
#
# Epoch 52
# -------------------------------
# Training loss: 1.605595
# Validation loss: 1.612916
#
# Epoch 53
# -------------------------------
# Training loss: 1.605455
# Validation loss: 1.609189
#
# Epoch 54
# -------------------------------
# Training loss: 1.605579
# Validation loss: 1.610840
#
# Epoch 55
# -------------------------------
# Training loss: 1.605606
# Validation loss: 1.610326
#
# Epoch 56
# -------------------------------
# Training loss: 1.605601
# Validation loss: 1.610612
#
# Epoch 57
# -------------------------------
# Training loss: 1.605237
# Validation loss: 1.610727
#
# Epoch 58
# -------------------------------
# Training loss: 1.605342
# Validation loss: 1.611963
#
# Epoch 59
# -------------------------------
# Training loss: 1.605503
# Validation loss: 1.610620
#
# Epoch 60
# -------------------------------
# Training loss: 1.605128
# Validation loss: 1.610883
#
# Epoch 61
# -------------------------------
# Training loss: 1.605458
# Validation loss: 1.610577
#
# Epoch 62
# -------------------------------
# Training loss: 1.605890
# Validation loss: 1.612706
#
# Epoch 63
# -------------------------------
# Training loss: 1.605113
# Validation loss: 1.609840
#
# Epoch 64
# -------------------------------
# Training loss: 1.605275
# Validation loss: 1.610699
#
# Epoch 65
# -------------------------------
# Training loss: 1.605274
# Validation loss: 1.611886
#
# Epoch 66
# -------------------------------
# Training loss: 1.604919
# Validation loss: 1.613390
#
# Epoch 67
# -------------------------------
# Training loss: 1.605160
# Validation loss: 1.610246
#
# Epoch 68
# -------------------------------
# Training loss: 1.605167
# Validation loss: 1.611531
#
# Epoch 69
# -------------------------------
# Training loss: 1.604845
# Validation loss: 1.609756
#
# Epoch 70
# -------------------------------
# Training loss: 1.604915
# Validation loss: 1.610144
#
# Epoch 71
# -------------------------------
# Training loss: 1.605184
# Validation loss: 1.611467
#
# Epoch 72
# -------------------------------
# Training loss: 1.604925
# Validation loss: 1.609613
#
# Epoch 73
# -------------------------------
# Training loss: 1.605085
# Validation loss: 1.613230
#
# Epoch 74
# -------------------------------
# Training loss: 1.604719
# Validation loss: 1.610688
#
# Epoch 75
# -------------------------------
# Training loss: 1.604947
# Validation loss: 1.611160
#
# Epoch 76
# -------------------------------
# Training loss: 1.605103
# Validation loss: 1.610318
#
# Epoch 77
# -------------------------------
# Training loss: 1.604944
# Validation loss: 1.611162
#
# Epoch 78
# -------------------------------
# Training loss: 1.604864
# Validation loss: 1.609417
#
# Epoch 79
# -------------------------------
# Training loss: 1.604828
# Validation loss: 1.612895
#
# Epoch 80
# -------------------------------
# Training loss: 1.604758
# Validation loss: 1.611639
#
# Epoch 81
# -------------------------------
# Training loss: 1.604725
# Validation loss: 1.609518
#
# Epoch 82
# -------------------------------
# Training loss: 1.605058
# Validation loss: 1.610631
#
# Epoch 83
# -------------------------------
# Training loss: 1.604782
# Validation loss: 1.609528
#
# Epoch 84
# -------------------------------
# Training loss: 1.604883
# Validation loss: 1.610328
#
# Epoch 85
# -------------------------------
# Training loss: 1.604604
# Validation loss: 1.611859
#
# Epoch 86
# -------------------------------
# Training loss: 1.605233
# Validation loss: 1.609671
#
# Epoch 87
# -------------------------------
# Training loss: 1.605053
# Validation loss: 1.611431
#
# Epoch 88
# -------------------------------
# Training loss: 1.604573
# Validation loss: 1.612278
#
# Epoch 89
# -------------------------------
# Training loss: 1.604918
# Validation loss: 1.611700
#
# Epoch 90
# -------------------------------
# Training loss: 1.604324
# Validation loss: 1.610666
#
# Epoch 91
# -------------------------------
# Training loss: 1.604533
# Validation loss: 1.612927
#
# Epoch 92
# -------------------------------
# Training loss: 1.604579
# Validation loss: 1.613218
#
# Epoch 93
# -------------------------------
# Training loss: 1.604851
# Validation loss: 1.611569
#
# Epoch 94
# -------------------------------
# Training loss: 1.604879
# Validation loss: 1.610095
#
# Epoch 95
# -------------------------------
# Training loss: 1.604728
# Validation loss: 1.610272
#
# Epoch 96
# -------------------------------
# Training loss: 1.604783
# Validation loss: 1.613207
#
# Epoch 97
# -------------------------------
# Training loss: 1.604658
# Validation loss: 1.611184
#
# Epoch 98
# -------------------------------
# Training loss: 1.604504
# Validation loss: 1.611682
#
# Epoch 99
# -------------------------------
# Training loss: 1.604557
# Validation loss: 1.611557
#
# Epoch 100
# -------------------------------
# Training loss: 1.604693
# Validation loss: 1.611843
#
# Done!

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses)+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('BCE Loss')
plt.legend()

# %% [markdown]
# ## Test the pre-trained adversary

# %%
adv_test_pred = mytools.test_adv(test_adv_loader, final_classifier, final_adv, Num_classes, device)
adv_test_pred = torch.softmax(torch.tensor(adv_test_pred),dim=1).numpy()
score=0

for i in range(adv_test_pred.shape[1]):
    fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_adv_test[:,i], adv_test_pred[:,i], pos_label=1)
    auc_test = sklearn.metrics.auc(fpr, tpr)
    print("class " + str(i)+ " test auc score: " + str(auc_test))

    plt.plot(fpr, tpr, label='Class '+str(i)+' Test AUROC: '+str(auc_test))
    plt.xlabel('FPR')
    plt.ylabel('TPR')
    plt.legend()

    score += auc_test

print("average score: ", score/adv_test_pred.shape[1])
# Out:
# class 0 test auc score: 0.5010501720144322
# class 1 test auc score: 0.5014247517188694
# class 2 test auc score: 0.502597571987984
# class 3 test auc score: 0.5037099972776082
# class 4 test auc score: 0.4985724241054888
# average score:  0.5014709834208766

# %% [markdown]
# # Train full adverserial neural network

# %% [markdown]
# # Setup dataloaders

# %%
# the structure is: feature, classifier label, adversary label, weight
# The wight is 1 for tritrig and wab, and 0 for phiKK, to prevent the adversary from learning on phiKK events

train_full_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy().astype(np.float32))  , torch.from_numpy(y_train.to_numpy().astype(np.float32)).unsqueeze(1), torch.from_numpy(y_adv_train),  (torch.from_numpy(y_train.to_numpy().astype(np.float32))==0).float())
train_full_loader = DataLoader(train_full_dataset, batch_size=bsize, shuffle=True)

val_full_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy().astype(np.float32))  , torch.from_numpy(y_val.to_numpy().astype(np.float32)).unsqueeze(1),  torch.from_numpy(y_adv_val),  (torch.from_numpy(y_val.to_numpy().astype(np.float32))==0).float())
val_full_loader = DataLoader(val_full_dataset, batch_size=bsize, shuffle=True)

# %% [markdown]
# ## Define loss functions

# %%
BCE_loss = nn.BCEWithLogitsLoss()
CE_loss = nn.CrossEntropyLoss(reduction='none') # returns loss per sample so we can weight it

def full_loss(output_clas, output_adv, target_clas, target_adv, w, lambda_):

    loss1 = BCE_loss(output_clas, target_clas )  # classification loss
    sample_losses2 = CE_loss(output_adv, target_adv)  # adversarial losses, since we set reduction='none', this is now a vector of losses, one per sample in the batch

    # Weighted mean loss over non-zero weights
    nonzero = w > 0
    loss2 = (sample_losses2[nonzero] * w[nonzero]).sum() / w[nonzero].sum()

    loss = loss1 - lambda_*loss2

    return loss

# %% [markdown]
# ## Setup optimizers

# %%
optimizer_clas = optim.Adam(final_classifier.parameters(), lr=1e-7,betas=(0.5, 0.999))
optimizer_adv = optim.Adam(final_adv.parameters(), lr=1e-5,betas=(0.5, 0.999))

scheduler_clas = torch.optim.lr_scheduler.ExponentialLR(optimizer_clas, gamma=0.999)
scheduler_adv = torch.optim.lr_scheduler.ExponentialLR(optimizer_adv, gamma=0.999)

# %% [markdown]
# ## Adversarial training

# %%
Training_losses_clas = np.array([])
Training_losses_adv = np.array([])
Validation_losses_clas = np.array([])
Validation_losses_adv = np.array([])
diff_scores = np.array([])


epochs = 50
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")

    # Get validation losses
    E_clas_val_loss, E_adv_val_loss = mytools.validate_full(val_full_loader, final_classifier, final_adv, full_loss, lambda_, criterion_adv, device)
    Validation_losses_clas = np.append(Validation_losses_clas, E_clas_val_loss)
    Validation_losses_adv = np.append(Validation_losses_adv, E_adv_val_loss)

    # Train adversary and classifier
    E_clas_training_loss , E_adv_training_loss = mytools.train_full(train_full_loader, final_classifier, final_adv, full_loss, lambda_, criterion_adv, optimizer_clas, optimizer_adv, scheduler_clas, scheduler_adv, device)
    Training_losses_clas = np.append(Training_losses_clas, E_clas_training_loss)
    Training_losses_adv = np.append(Training_losses_adv, E_adv_training_loss)

    # Get the diff_score
    df_test["Class_adv"] = mytools.test_clas(test_loader, final_classifier, device)
    df_bkg = df_test.loc[ (df_test.type == 'tritrig') | (df_test.type == 'wab')]
    per = np.percentile(df_bkg['Class_adv'],90)
    df_cut = df_bkg[df_bkg['Class_adv']>per].reset_index(drop=True)
    x1 = 1000* df_bkg.InvM.values
    x2 = 1000*df_cut.InvM.values
    diff_scores = np.append(diff_scores, mytools.get_diff_score(x1,x2) )

    # Keep a running copy of the model with the lowest loss
    if diff_scores[-1] == np.min(diff_scores):
        final_clas_adv = copy.deepcopy(final_classifier)
        final_adv_adv = copy.deepcopy(final_adv)

            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Classifier validation loss: -161.057611
# Adversary validation loss: 1.611089
# Classifier training loss: -160.563604
# Adversary training loss: 1.605969
# Epoch 2
# -------------------------------
# Classifier validation loss: -160.893765
# Adversary validation loss: 1.609417
# Classifier training loss: -160.618349
# Adversary training loss: 1.606519
# Epoch 3
# -------------------------------
# Classifier validation loss: -161.185699
# Adversary validation loss: 1.612343
# Classifier training loss: -160.569775
# Adversary training loss: 1.606031
# Epoch 4
# -------------------------------
# Classifier validation loss: -160.995493
# Adversary validation loss: 1.610436
# Classifier training loss: -160.634077
# Adversary training loss: 1.606674
# Epoch 5
# -------------------------------
# Classifier validation loss: -160.958102
# Adversary validation loss: 1.610073
# Classifier training loss: -160.605993
# Adversary training loss: 1.606392
# Epoch 6
# -------------------------------
# Classifier validation loss: -160.944199
# Adversary validation loss: 1.609934
# Classifier training loss: -160.688573
# Adversary training loss: 1.607217
# Epoch 7
# -------------------------------
# Classifier validation loss: -160.965024
# Adversary validation loss: 1.610121
# Classifier training loss: -160.620265
# Adversary training loss: 1.606532
# Epoch 8
# -------------------------------
# Classifier validation loss: -160.932117
# Adversary validation loss: 1.609822
# Classifier training loss: -160.657600
# Adversary training loss: 1.606912
# Epoch 9
# -------------------------------
# Classifier validation loss: -161.029199
# Adversary validation loss: 1.610767
# Classifier training loss: -160.706133
# Adversary training loss: 1.607394
# Epoch 10
# -------------------------------
# Classifier validation loss: -161.133298
# Adversary validation loss: 1.611859
# Classifier training loss: -160.650915
# Adversary training loss: 1.606834
# Epoch 11
# -------------------------------
# Classifier validation loss: -160.722363
# Adversary validation loss: 1.607708
# Classifier training loss: -160.703271
# Adversary training loss: 1.607358
# Epoch 12
# -------------------------------
# Classifier validation loss: -160.782935
# Adversary validation loss: 1.608350
# Classifier training loss: -160.626280
# Adversary training loss: 1.606594
# Epoch 13
# -------------------------------
# Classifier validation loss: -160.986197
# Adversary validation loss: 1.610351
# Classifier training loss: -160.732642
# Adversary training loss: 1.607654
# Epoch 14
# -------------------------------
# Classifier validation loss: -160.940286
# Adversary validation loss: 1.609891
# Classifier training loss: -160.640435
# Adversary training loss: 1.606731
# Epoch 15
# -------------------------------
# Classifier validation loss: -160.930609
# Adversary validation loss: 1.609775
# Classifier training loss: -160.628170
# Adversary training loss: 1.606605
# Epoch 16
# -------------------------------
# Classifier validation loss: -160.940961
# Adversary validation loss: 1.609896
# Classifier training loss: -160.690828
# Adversary training loss: 1.607233
# Epoch 17
# -------------------------------
# Classifier validation loss: -161.083957
# Adversary validation loss: 1.611324
# Classifier training loss: -160.657496
# Adversary training loss: 1.606900
# Epoch 18
# -------------------------------
# Classifier validation loss: -160.876904
# Adversary validation loss: 1.609233
# Classifier training loss: -160.680835
# Adversary training loss: 1.607133
# Epoch 19
# -------------------------------
# Classifier validation loss: -160.841898
# Adversary validation loss: 1.608913
# Classifier training loss: -160.680601
# Adversary training loss: 1.607132
# Epoch 20
# -------------------------------
# Classifier validation loss: -160.933722
# Adversary validation loss: 1.609849
# Classifier training loss: -160.697008
# Adversary training loss: 1.607293
# Epoch 21
# -------------------------------
# Classifier validation loss: -161.035199
# Adversary validation loss: 1.610835
# Classifier training loss: -160.674086
# Adversary training loss: 1.607065
# Epoch 22
# -------------------------------
# Classifier validation loss: -161.144485
# Adversary validation loss: 1.611961
# Classifier training loss: -160.692724
# Adversary training loss: 1.607251
# Epoch 23
# -------------------------------
# Classifier validation loss: -161.091837
# Adversary validation loss: 1.611390
# Classifier training loss: -160.702313
# Adversary training loss: 1.607347
# Epoch 24
# -------------------------------
# Classifier validation loss: -160.820508
# Adversary validation loss: 1.608698
# Classifier training loss: -160.692586
# Adversary training loss: 1.607247
# Epoch 25
# -------------------------------
# Classifier validation loss: -161.072507
# Adversary validation loss: 1.611215
# Classifier training loss: -160.726245
# Adversary training loss: 1.607587
# Epoch 26
# -------------------------------
# Classifier validation loss: -161.038068
# Adversary validation loss: 1.610873
# Classifier training loss: -160.758870
# Adversary training loss: 1.607910
# Epoch 27
# -------------------------------
# Classifier validation loss: -161.044437
# Adversary validation loss: 1.610913
# Classifier training loss: -160.664997
# Adversary training loss: 1.606971
# Epoch 28
# -------------------------------
# Classifier validation loss: -160.950375
# Adversary validation loss: 1.609983
# Classifier training loss: -160.725898
# Adversary training loss: 1.607580
# Epoch 29
# -------------------------------
# Classifier validation loss: -160.982947
# Adversary validation loss: 1.610310
# Classifier training loss: -160.741799
# Adversary training loss: 1.607737
# Epoch 30
# -------------------------------
# Classifier validation loss: -160.979953
# Adversary validation loss: 1.610290
# Classifier training loss: -160.741731
# Adversary training loss: 1.607738
# Epoch 31
# -------------------------------
# Classifier validation loss: -161.068335
# Adversary validation loss: 1.611156
# Classifier training loss: -160.762744
# Adversary training loss: 1.607948
# Epoch 32
# -------------------------------
# Classifier validation loss: -160.996454
# Adversary validation loss: 1.610471
# Classifier training loss: -160.742667
# Adversary training loss: 1.607747
# Epoch 33
# -------------------------------
# Classifier validation loss: -161.204852
# Adversary validation loss: 1.612527
# Classifier training loss: -160.753994
# Adversary training loss: 1.607858
# Epoch 34
# -------------------------------
# Classifier validation loss: -161.008456
# Adversary validation loss: 1.610556
# Classifier training loss: -160.772374
# Adversary training loss: 1.608043
# Epoch 35
# -------------------------------
# Classifier validation loss: -161.123138
# Adversary validation loss: 1.611732
# Classifier training loss: -160.698625
# Adversary training loss: 1.607305
# Epoch 36
# -------------------------------
# Classifier validation loss: -161.127872
# Adversary validation loss: 1.611759
# Classifier training loss: -160.760193
# Adversary training loss: 1.607922
# Epoch 37
# -------------------------------
# Classifier validation loss: -161.065628
# Adversary validation loss: 1.611148
# Classifier training loss: -160.751899
# Adversary training loss: 1.607837
# Epoch 38
# -------------------------------
# Classifier validation loss: -160.932935
# Adversary validation loss: 1.609809
# Classifier training loss: -160.738134
# Adversary training loss: 1.607699
# Epoch 39
# -------------------------------
# Classifier validation loss: -161.007983
# Adversary validation loss: 1.610560
# Classifier training loss: -160.709527
# Adversary training loss: 1.607413
# Epoch 40
# -------------------------------
# Classifier validation loss: -161.011557
# Adversary validation loss: 1.610629
# Classifier training loss: -160.862908
# Adversary training loss: 1.608947
# Epoch 41
# -------------------------------
# Classifier validation loss: -160.995694
# Adversary validation loss: 1.610454
# Classifier training loss: -160.739851
# Adversary training loss: 1.607717
# Epoch 42
# -------------------------------
# Classifier validation loss: -161.040518
# Adversary validation loss: 1.610904
# Classifier training loss: -160.732586
# Adversary training loss: 1.607641
# Epoch 43
# -------------------------------
# Classifier validation loss: -161.138705
# Adversary validation loss: 1.611883
# Classifier training loss: -160.715581
# Adversary training loss: 1.607474
# Epoch 44
# -------------------------------
# Classifier validation loss: -161.103287
# Adversary validation loss: 1.611517
# Classifier training loss: -160.739254
# Adversary training loss: 1.607712
# Epoch 45
# -------------------------------
# Classifier validation loss: -161.103961
# Adversary validation loss: 1.611544
# Classifier training loss: -160.745148
# Adversary training loss: 1.607770
# Epoch 46
# -------------------------------
# Classifier validation loss: -160.945001
# Adversary validation loss: 1.609935
# Classifier training loss: -160.848502
# Adversary training loss: 1.608801
# Epoch 47
# -------------------------------
# Classifier validation loss: -161.108932
# Adversary validation loss: 1.611594
# Classifier training loss: -160.781369
# Adversary training loss: 1.608130
# Epoch 48
# -------------------------------
# Classifier validation loss: -161.125189
# Adversary validation loss: 1.611727
# Classifier training loss: -160.781716
# Adversary training loss: 1.608134
# Epoch 49
# -------------------------------
# Classifier validation loss: -161.048273
# Adversary validation loss: 1.610967
# Classifier training loss: -160.755213
# Adversary training loss: 1.607868
# Epoch 50
# -------------------------------
# Classifier validation loss: -160.965137
# Adversary validation loss: 1.610131
# Classifier training loss: -160.773061
# Adversary training loss: 1.608046
# Done!

# %%
fig, ax1 = plt.subplots()

best_epoch = np.argmin(diff_scores)+1



#ax1.plot(np.arange(len(Training_losses_adv))+1, Training_losses_adv, 'k-', label='Training Adversary')
ax1.plot(np.arange(len(Validation_losses_adv))+1, Validation_losses_adv, 'k-', label='Validation Adversary')

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Adversary Loss', color='k')
ax1.tick_params(axis='y', labelcolor='k')

ax2 = ax1.twinx()

#ax2.plot(np.arange(len(Training_losses_clas))+1, Training_losses_clas, 'r-', label='Training Classifier')
ax2.plot(np.arange(len(Validation_losses_clas))+1, Validation_losses_clas, 'r-', label='Validation Classifier')
ax2.axvline(best_epoch,label="Final model stopped here",color='k')

ax2.set_ylabel('Classifier Loss', color='r')
ax2.tick_params(axis='y', labelcolor='r')

# %% [markdown]
# ## Test adversarially trained models

# %%
# Now test the pretrained model
test_pred = mytools.test_clas(test_loader, final_clas_adv, device)
test_pred=torch.sigmoid(torch.tensor(test_pred)).numpy()


fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test, test_pred, pos_label=1)
auc_test = sklearn.metrics.auc(fpr, tpr)
print(f'Test AUROC: {auc_test:0.4f}')

plt.plot(fpr, tpr, label=f'Test AUROC: {auc_test:0.4f}')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
# Out:
# Test AUROC: 0.9958

# %%
df_test["Class_adv"] = test_pred
df_bkg = df_test.loc[ (df_test.type == 'tritrig') | (df_test.type == 'wab')]
per = np.percentile(df_bkg['Class_adv'],99)
df_cut = df_bkg[df_bkg['Class_adv']>per].reset_index(drop=True)
x_vals = 1000*df_cut.InvM

plt.figure()
plt.hist(1000*df_bkg.InvM, bins=np.arange(980,1250,1), histtype='step', label='No selection', density=True)
plt.hist(x_vals, bins=np.arange(980,1250,1), histtype='step', label= '99 percent selection', density=True)
plt.axvline(1019.461, color='k', linestyle='dashed', linewidth=1, label='PDG phi mass')
plt.xlabel('Invariant Mass [MeV]')
plt.ylabel('Normalized Counts')
plt.legend()

# %%
x1 = 1000* df_bkg.InvM.values
x2 = 1000*df_cut.InvM.values

N, edges = np.histogram(x1, bins=np.arange(980,1250,1), density=False)
M, edges = np.histogram(x2, bins=np.arange(980,1250,1), density=False)

N2 = N[(N > 0) & (M > 0)]
M2 = M[(N > 0) & (M > 0)]

diff_score = np.mean( np.abs( N2/np.sum(N) - M2/np.sum(M) ) / np.sqrt( ( np.sqrt(N2)/np.sum(N) )**2 + ( np.sqrt(M2)/np.sum(M) )**2 ) )

print(diff_score)

N = len(df_test.loc[ ((df_test.type == 'tritrig') | (df_test.type == 'wab')) & (df_test.InvM < (1.019 + 0.01) )  & (df_test.InvM > (1.019 - 0.01) ) & ( df_test['Class_adv']>per ) ] )
S = len(df_test.loc[ (df_test.type == 'phiKK') & (df_test.InvM < (1.019 + 0.01) )  & (df_test.InvM > (1.019 - 0.01) ) & ( df_test['Class_adv']>per )  ] )

print(S/N)
# Out:
# 0.778662640104394
# 0.3939835031538088

# %%
df_test["Class_adv"] = test_pred

# %%
adv_test_pred = mytools.test_adv(test_adv_loader, final_classifier, final_adv_adv, Num_classes, device)
adv_test_pred = torch.softmax(torch.tensor(adv_test_pred),dim=1).numpy()
score=0

for i in range(adv_test_pred.shape[1]):
    fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_adv_test[:,i], adv_test_pred[:,i], pos_label=1)
    auc_test = sklearn.metrics.auc(fpr, tpr)
    print("class " + str(i)+ " test auc score: " + str(auc_test))

    plt.plot(fpr, tpr, label='Class '+str(i)+' Test AUROC: '+str(auc_test))
    plt.xlabel('FPR')
    plt.ylabel('TPR')
    plt.legend()

    score += auc_test

print("average score: ", score/adv_test_pred.shape[1])
# Out:
# class 0 test auc score: 0.49698043658197577
# class 1 test auc score: 0.5004761601610341
# class 2 test auc score: 0.4994230524409251
# class 3 test auc score: 0.5025535796844771
# class 4 test auc score: 0.498428461896671
# average score:  0.49957233815301655

# %%
# Save the adversarially trained models
#torch.save(final_clas_adv.state_dict(), "/Users/mghrear/data/ML_data/patch/classifier_adv_2021_v9_pass5_run"+str(run)+"QualCuts.pt")
#torch.save(final_adv_adv.state_dict(), "/Users/mghrear/data/ML_data/patch/adversary_adv_2021_v9_pass5_run"+str(run)+"QualCuts.pt")

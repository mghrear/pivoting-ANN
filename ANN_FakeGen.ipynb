# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import torch 
from torch import nn, optim
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import sklearn
from sklearn.model_selection import train_test_split
import copy
import mytools


# Print and store device being used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cpu

# %% [markdown]
# # Define important parameters

# %%
# Number of class in invariant mass used by the adversary
Num_classes = 5
# Hyper-parameter for adversarial training of the classifier
lambda_ = 100.0

run = 1

# %% [markdown]
# # Load and setup the data

# %%
df_tritrig = pd.read_pickle('/Users/mghrear/data/ML_data/2019_pass2/unscaled/2019_pass2_tritrig.pk')
df_tritrig['PhiKK'] = 0.0
df_phiKK = pd.read_pickle('/Users/mghrear/data/ML_data/2019_pass2/unscaled/2019_pass2_FakeGen_1pt05_kaon.pk')
df_phiKK['PhiKK'] = 1.0
df_wab = pd.read_pickle('/Users/mghrear/data/ML_data/2019_pass2/unscaled/2019_pass2_wab.pk')
df_wab['PhiKK'] = 0.0 # Add label


print("tritrig: ", len(df_tritrig))
print("phiKK: ", len(df_phiKK))
print("wab: ", len(df_wab))
# Out:
# tritrig:  149433
# phiKK:  83372
# wab:  16422

# %%
# Make Training set
tritrig_train = df_tritrig[0:50000]
wab_train = df_wab[0:6000]
phiKK_train = df_phiKK[0:5000]

# Combine and shuffle all training data
df_train = pd.concat([tritrig_train, phiKK_train, wab_train], ignore_index=True, sort=False)
df_train = df_train.sample(frac=1, random_state=42).reset_index(drop=True)

one_hot_edges = np.load("one_hot_edges.npy")

# Split the training data into training and validation sets
df_train, df_val = train_test_split(df_train, test_size=0.33, random_state=42)

# Make X and y for training and validation sets
# the adverserial network has its own labels
X_train = df_train.drop(columns=['PhiKK'])
y_train = df_train['PhiKK']
y_adv_train = mytools.get_adv_labels( mytools.get_InvM(df_train), one_hot_edges)
X_val = df_val.drop(columns=['PhiKK'])
y_val = df_val['PhiKK']
y_adv_val = mytools.get_adv_labels( mytools.get_InvM(df_val), one_hot_edges)

# Make testing set with remaining events
tritrig_test = df_tritrig[50000:]
tritrig_test['type']= 'tritrig'
wab_test = df_wab[6000:]
wab_test['type']= 'wab'
phiKK_test = df_phiKK[5000:]
phiKK_test['type']= 'phiKK'

df_test = pd.concat([tritrig_test, phiKK_test,wab_test], ignore_index=True, sort=False)
df_test = df_test.sample(frac=1, random_state=42).reset_index(drop=True) # Now shuffle the combined dataframe

X_test = df_test.drop(columns=['PhiKK','type'])
y_test = df_test['PhiKK']
y_adv_test = mytools.get_adv_labels( mytools.get_InvM(df_test), one_hot_edges)

df_test["InvM"] = mytools.get_InvM(df_test)
# Out:
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_54732/2924921926.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tritrig_test['type']= 'tritrig'
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_54732/2924921926.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wab_test['type']= 'wab'
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_54732/2924921926.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phiKK_test['type']= 'phiKK'

# %% [markdown]
# ## Setup dataloaders

# %%
bsize = 2000

# Convert to tensor dataset and dataloader
train_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy().astype(np.float32))  , torch.from_numpy(y_train.to_numpy().astype(np.float32)).unsqueeze(1)  )
train_loader = DataLoader(train_dataset, batch_size=bsize, shuffle=True)

val_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy().astype(np.float32))  , torch.from_numpy(y_val.to_numpy().astype(np.float32)).unsqueeze(1)  )
val_loader = DataLoader(val_dataset, batch_size=bsize, shuffle=True)

test_dataset = TensorDataset(torch.from_numpy(X_test.to_numpy().astype(np.float32)))
test_loader = DataLoader(test_dataset, batch_size=bsize, shuffle=False)

# %% [markdown]
# ## Initialize model, objective function, and optimizer

# %%
clas = mytools.Classifier(in_features=X_train.shape[1]).to(device)
criterion_clas = nn.BCEWithLogitsLoss()
optimizer_clas = optim.Adam(clas.parameters(), lr=1e-5)
scheduler_clas = torch.optim.lr_scheduler.ExponentialLR(optimizer_clas, gamma=0.9999)

# %% [markdown]
# ## Pre-train the classifier

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 10

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 2500
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train_clas(train_loader, clas, criterion_clas, optimizer_clas, scheduler_clas, device))
    Validation_losses = np.append(Validation_losses, mytools.validate_clas(val_loader, clas, criterion_clas, device))
    
    # Keep a running copy of the model with the lowest loss
    if Validation_losses[-1] == np.min(Validation_losses):
        final_classifier = copy.deepcopy(clas)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Training loss: 0.615384
# Validation loss: 0.670564
#
# Epoch 2
# -------------------------------
# Training loss: 0.585911
# Validation loss: 0.606410
#
# Epoch 3
# -------------------------------
# Training loss: 0.567634
# Validation loss: 0.549137
#
# Epoch 4
# -------------------------------
# Training loss: 0.553444
# Validation loss: 0.543768
#
# Epoch 5
# -------------------------------
# Training loss: 0.541489
# Validation loss: 0.545351
#
# Epoch 6
# -------------------------------
# Training loss: 0.530914
# Validation loss: 0.522200
#
# Epoch 7
# -------------------------------
# Training loss: 0.522081
# Validation loss: 0.516839
#
# Epoch 8
# -------------------------------
# Training loss: 0.513896
# Validation loss: 0.509569
#
# Epoch 9
# -------------------------------
# Training loss: 0.506908
# Validation loss: 0.505334
#
# Epoch 10
# -------------------------------
# Training loss: 0.500567
# Validation loss: 0.497423
#
# Epoch 11
# -------------------------------
# Training loss: 0.494189
# Validation loss: 0.492968
#
# Epoch 12
# -------------------------------
# Training loss: 0.488968
# Validation loss: 0.496877
#
# Epoch 13
# -------------------------------
# Training loss: 0.483462
# Validation loss: 0.485365
#
# Epoch 14
# -------------------------------
# Training loss: 0.480364
# Validation loss: 0.487656
#
# Epoch 15
# -------------------------------
# Training loss: 0.475447
# Validation loss: 0.470300
#
# Epoch 16
# -------------------------------
# Training loss: 0.468324
# Validation loss: 0.469696
#
# Epoch 17
# -------------------------------
# Training loss: 0.463324
# Validation loss: 0.459932
#
# Epoch 18
# -------------------------------
# Training loss: 0.460378
# Validation loss: 0.450280
#
# Epoch 19
# -------------------------------
# Training loss: 0.455453
# Validation loss: 0.457385
#
# Epoch 20
# -------------------------------
# Training loss: 0.452817
# Validation loss: 0.450497
#
# Epoch 21
# -------------------------------
# Training loss: 0.449199
# Validation loss: 0.450061
#
# Epoch 22
# -------------------------------
# Training loss: 0.444682
# Validation loss: 0.442767
#
# Epoch 23
# -------------------------------
# Training loss: 0.441518
# Validation loss: 0.435082
#
# Epoch 24
# -------------------------------
# Training loss: 0.437071
# Validation loss: 0.445569
#
# Epoch 25
# -------------------------------
# Training loss: 0.433602
# Validation loss: 0.430864
#
# Epoch 26
# -------------------------------
# Training loss: 0.430623
# Validation loss: 0.432625
#
# Epoch 27
# -------------------------------
# Training loss: 0.427064
# Validation loss: 0.424597
#
# Epoch 28
# -------------------------------
# Training loss: 0.424049
# Validation loss: 0.438286
#
# Epoch 29
# -------------------------------
# Training loss: 0.422230
# Validation loss: 0.429454
#
# Epoch 30
# -------------------------------
# Training loss: 0.418370
# Validation loss: 0.419550
#
# Epoch 31
# -------------------------------
# Training loss: 0.415074
# Validation loss: 0.423159
#
# Epoch 32
# -------------------------------
# Training loss: 0.411939
# Validation loss: 0.411729
#
# Epoch 33
# -------------------------------
# Training loss: 0.409677
# Validation loss: 0.417516
#
# Epoch 34
# -------------------------------
# Training loss: 0.406668
# Validation loss: 0.404245
#
# Epoch 35
# -------------------------------
# Training loss: 0.405054
# Validation loss: 0.406484
#
# Epoch 36
# -------------------------------
# Training loss: 0.403083
# Validation loss: 0.408333
#
# Epoch 37
# -------------------------------
# Training loss: 0.401141
# Validation loss: 0.408124
#
# Epoch 38
# -------------------------------
# Training loss: 0.398534
# Validation loss: 0.402620
#
# Epoch 39
# -------------------------------
# Training loss: 0.395298
# Validation loss: 0.392216
#
# Epoch 40
# -------------------------------
# Training loss: 0.394607
# Validation loss: 0.393224
#
# Epoch 41
# -------------------------------
# Training loss: 0.391716
# Validation loss: 0.394146
#
# Epoch 42
# -------------------------------
# Training loss: 0.389726
# Validation loss: 0.385978
#
# Epoch 43
# -------------------------------
# Training loss: 0.387413
# Validation loss: 0.384567
#
# Epoch 44
# -------------------------------
# Training loss: 0.385696
# Validation loss: 0.389351
#
# Epoch 45
# -------------------------------
# Training loss: 0.382146
# Validation loss: 0.395103
#
# Epoch 46
# -------------------------------
# Training loss: 0.382020
# Validation loss: 0.382285
#
# Epoch 47
# -------------------------------
# Training loss: 0.378568
# Validation loss: 0.379249
#
# Epoch 48
# -------------------------------
# Training loss: 0.376682
# Validation loss: 0.379216
#
# Epoch 49
# -------------------------------
# Training loss: 0.375078
# Validation loss: 0.370197
#
# Epoch 50
# -------------------------------
# Training loss: 0.373768
# Validation loss: 0.374493
#
# Epoch 51
# -------------------------------
# Training loss: 0.371492
# Validation loss: 0.381644
#
# Epoch 52
# -------------------------------
# Training loss: 0.369565
# Validation loss: 0.372426
#
# Epoch 53
# -------------------------------
# Training loss: 0.367827
# Validation loss: 0.368565
#
# Epoch 54
# -------------------------------
# Training loss: 0.365433
# Validation loss: 0.372962
#
# Epoch 55
# -------------------------------
# Training loss: 0.366289
# Validation loss: 0.360850
#
# Epoch 56
# -------------------------------
# Training loss: 0.361659
# Validation loss: 0.376048
#
# Epoch 57
# -------------------------------
# Training loss: 0.359267
# Validation loss: 0.366365
#
# Epoch 58
# -------------------------------
# Training loss: 0.357849
# Validation loss: 0.363921
#
# Epoch 59
# -------------------------------
# Training loss: 0.358351
# Validation loss: 0.362064
#
# Epoch 60
# -------------------------------
# Training loss: 0.355755
# Validation loss: 0.358050
#
# Epoch 61
# -------------------------------
# Training loss: 0.355538
# Validation loss: 0.354372
#
# Epoch 62
# -------------------------------
# Training loss: 0.352178
# Validation loss: 0.356213
#
# Epoch 63
# -------------------------------
# Training loss: 0.350583
# Validation loss: 0.349380
#
# Epoch 64
# -------------------------------
# Training loss: 0.348063
# Validation loss: 0.351608
#
# Epoch 65
# -------------------------------
# Training loss: 0.346311
# Validation loss: 0.352496
#
# Epoch 66
# -------------------------------
# Training loss: 0.345125
# Validation loss: 0.341178
#
# Epoch 67
# -------------------------------
# Training loss: 0.344091
# Validation loss: 0.340429
#
# Epoch 68
# -------------------------------
# Training loss: 0.340899
# Validation loss: 0.341007
#
# Epoch 69
# -------------------------------
# Training loss: 0.340107
# Validation loss: 0.348056
#
# Epoch 70
# -------------------------------
# Training loss: 0.338468
# Validation loss: 0.345068
#
# Epoch 71
# -------------------------------
# Training loss: 0.335910
# Validation loss: 0.356268
#
# Epoch 72
# -------------------------------
# Training loss: 0.335304
# Validation loss: 0.339249
#
# Epoch 73
# -------------------------------
# Training loss: 0.334014
# Validation loss: 0.336290
#
# Epoch 74
# -------------------------------
# Training loss: 0.330644
# Validation loss: 0.325509
#
# Epoch 75
# -------------------------------
# Training loss: 0.330872
# Validation loss: 0.339279
#
# Epoch 76
# -------------------------------
# Training loss: 0.328397
# Validation loss: 0.326531
#
# Epoch 77
# -------------------------------
# Training loss: 0.326679
# Validation loss: 0.322357
#
# Epoch 78
# -------------------------------
# Training loss: 0.326515
# Validation loss: 0.333915
#
# Epoch 79
# -------------------------------
# Training loss: 0.322901
# Validation loss: 0.323660
#
# Epoch 80
# -------------------------------
# Training loss: 0.320391
# Validation loss: 0.315685
#
# Epoch 81
# -------------------------------
# Training loss: 0.318995
# Validation loss: 0.315073
#
# Epoch 82
# -------------------------------
# Training loss: 0.318943
# Validation loss: 0.316883
#
# Epoch 83
# -------------------------------
# Training loss: 0.316065
# Validation loss: 0.314668
#
# Epoch 84
# -------------------------------
# Training loss: 0.313994
# Validation loss: 0.308393
#
# Epoch 85
# -------------------------------
# Training loss: 0.315570
# Validation loss: 0.312700
#
# Epoch 86
# -------------------------------
# Training loss: 0.312991
# Validation loss: 0.328390
#
# Epoch 87
# -------------------------------
# Training loss: 0.310414
# Validation loss: 0.314515
#
# Epoch 88
# -------------------------------
# Training loss: 0.308809
# Validation loss: 0.317906
#
# Epoch 89
# -------------------------------
# Training loss: 0.308468
# Validation loss: 0.310213
#
# Epoch 90
# -------------------------------
# Training loss: 0.307266
# Validation loss: 0.318122
#
# Epoch 91
# -------------------------------
# Training loss: 0.305262
# Validation loss: 0.313700
#
# Epoch 92
# -------------------------------
# Training loss: 0.302973
# Validation loss: 0.353267
#
# Epoch 93
# -------------------------------
# Training loss: 0.302216
# Validation loss: 0.307089
#
# Epoch 94
# -------------------------------
# Training loss: 0.298832
# Validation loss: 0.305692
#
# Epoch 95
# -------------------------------
# Training loss: 0.298999
# Validation loss: 0.327129
#
# Epoch 96
# -------------------------------
# Training loss: 0.294879
# Validation loss: 0.312752
#
# Epoch 97
# -------------------------------
# Training loss: 0.294946
# Validation loss: 0.318611
#
# Epoch 98
# -------------------------------
# Training loss: 0.293986
# Validation loss: 0.293980
#
# Epoch 99
# -------------------------------
# Training loss: 0.291759
# Validation loss: 0.289680
#
# Epoch 100
# -------------------------------
# Training loss: 0.291528
# Validation loss: 0.285427
#
# Epoch 101
# -------------------------------
# Training loss: 0.289840
# Validation loss: 0.309666
#
# Epoch 102
# -------------------------------
# Training loss: 0.288442
# Validation loss: 0.314193
#
# Epoch 103
# -------------------------------
# Training loss: 0.288641
# Validation loss: 0.280251
#
# Epoch 104
# -------------------------------
# Training loss: 0.286614
# Validation loss: 0.293145
#
# Epoch 105
# -------------------------------
# Training loss: 0.285636
# Validation loss: 0.318685
#
# Epoch 106
# -------------------------------
# Training loss: 0.284883
# Validation loss: 0.286875
#
# Epoch 107
# -------------------------------
# Training loss: 0.281691
# Validation loss: 0.281088
#
# Epoch 108
# -------------------------------
# Training loss: 0.282789
# Validation loss: 0.278403
#
# Epoch 109
# -------------------------------
# Training loss: 0.279618
# Validation loss: 0.280939
#
# Epoch 110
# -------------------------------
# Training loss: 0.275598
# Validation loss: 0.276622
#
# Epoch 111
# -------------------------------
# Training loss: 0.277699
# Validation loss: 0.284463
#
# Epoch 112
# -------------------------------
# Training loss: 0.277936
# Validation loss: 0.274531
#
# Epoch 113
# -------------------------------
# Training loss: 0.274234
# Validation loss: 0.283721
#
# Epoch 114
# -------------------------------
# Training loss: 0.273284
# Validation loss: 0.263947
#
# Epoch 115
# -------------------------------
# Training loss: 0.271610
# Validation loss: 0.269662
#
# Epoch 116
# -------------------------------
# Training loss: 0.268616
# Validation loss: 0.266498
#
# Epoch 117
# -------------------------------
# Training loss: 0.270048
# Validation loss: 0.272315
#
# Epoch 118
# -------------------------------
# Training loss: 0.268490
# Validation loss: 0.263226
#
# Epoch 119
# -------------------------------
# Training loss: 0.266568
# Validation loss: 0.261648
#
# Epoch 120
# -------------------------------
# Training loss: 0.264980
# Validation loss: 0.260671
#
# Epoch 121
# -------------------------------
# Training loss: 0.263369
# Validation loss: 0.258884
#
# Epoch 122
# -------------------------------
# Training loss: 0.263493
# Validation loss: 0.270713
#
# Epoch 123
# -------------------------------
# Training loss: 0.263704
# Validation loss: 0.256319
#
# Epoch 124
# -------------------------------
# Training loss: 0.262923
# Validation loss: 0.256725
#
# Epoch 125
# -------------------------------
# Training loss: 0.260590
# Validation loss: 0.268878
#
# Epoch 126
# -------------------------------
# Training loss: 0.259364
# Validation loss: 0.252839
#
# Epoch 127
# -------------------------------
# Training loss: 0.257362
# Validation loss: 0.251410
#
# Epoch 128
# -------------------------------
# Training loss: 0.255554
# Validation loss: 0.258071
#
# Epoch 129
# -------------------------------
# Training loss: 0.254949
# Validation loss: 0.245009
#
# Epoch 130
# -------------------------------
# Training loss: 0.254411
# Validation loss: 0.258971
#
# Epoch 131
# -------------------------------
# Training loss: 0.253904
# Validation loss: 0.260324
#
# Epoch 132
# -------------------------------
# Training loss: 0.252426
# Validation loss: 0.247544
#
# Epoch 133
# -------------------------------
# Training loss: 0.250803
# Validation loss: 0.245225
#
# Epoch 134
# -------------------------------
# Training loss: 0.249038
# Validation loss: 0.277936
#
# Epoch 135
# -------------------------------
# Training loss: 0.248125
# Validation loss: 0.299402
#
# Epoch 136
# -------------------------------
# Training loss: 0.248249
# Validation loss: 0.252632
#
# Epoch 137
# -------------------------------
# Training loss: 0.249706
# Validation loss: 0.257360
#
# Epoch 138
# -------------------------------
# Training loss: 0.244535
# Validation loss: 0.250976
#
# Epoch 139
# -------------------------------
# Training loss: 0.245832
# Validation loss: 0.244587
#
# Epoch 140
# -------------------------------
# Training loss: 0.245358
# Validation loss: 0.257251
#
# Epoch 141
# -------------------------------
# Training loss: 0.242379
# Validation loss: 0.238271
#
# Epoch 142
# -------------------------------
# Training loss: 0.240641
# Validation loss: 0.236486
#
# Epoch 143
# -------------------------------
# Training loss: 0.240902
# Validation loss: 0.247464
#
# Epoch 144
# -------------------------------
# Training loss: 0.239931
# Validation loss: 0.238791
#
# Epoch 145
# -------------------------------
# Training loss: 0.239000
# Validation loss: 0.235287
#
# Epoch 146
# -------------------------------
# Training loss: 0.239156
# Validation loss: 0.231252
#
# Epoch 147
# -------------------------------
# Training loss: 0.237368
# Validation loss: 0.261012
#
# Epoch 148
# -------------------------------
# Training loss: 0.234700
# Validation loss: 0.234174
#
# Epoch 149
# -------------------------------
# Training loss: 0.235850
# Validation loss: 0.243122
#
# Epoch 150
# -------------------------------
# Training loss: 0.235897
# Validation loss: 0.249734
#
# Epoch 151
# -------------------------------
# Training loss: 0.234764
# Validation loss: 0.239950
#
# Epoch 152
# -------------------------------
# Training loss: 0.235555
# Validation loss: 0.236418
#
# Epoch 153
# -------------------------------
# Training loss: 0.234820
# Validation loss: 0.241346
#
# Epoch 154
# -------------------------------
# Training loss: 0.232890
# Validation loss: 0.234697
#
# Epoch 155
# -------------------------------
# Training loss: 0.229728
# Validation loss: 0.223239
#
# Epoch 156
# -------------------------------
# Training loss: 0.227860
# Validation loss: 0.232787
#
# Epoch 157
# -------------------------------
# Training loss: 0.228883
# Validation loss: 0.231506
#
# Epoch 158
# -------------------------------
# Training loss: 0.228280
# Validation loss: 0.266787
#
# Epoch 159
# -------------------------------
# Training loss: 0.226585
# Validation loss: 0.217097
#
# Epoch 160
# -------------------------------
# Training loss: 0.227930
# Validation loss: 0.231103
#
# Epoch 161
# -------------------------------
# Training loss: 0.226765
# Validation loss: 0.220043
#
# Epoch 162
# -------------------------------
# Training loss: 0.223325
# Validation loss: 0.216285
#
# Epoch 163
# -------------------------------
# Training loss: 0.226547
# Validation loss: 0.242475
#
# Epoch 164
# -------------------------------
# Training loss: 0.223884
# Validation loss: 0.226205
#
# Epoch 165
# -------------------------------
# Training loss: 0.224856
# Validation loss: 0.218285
#
# Epoch 166
# -------------------------------
# Training loss: 0.223825
# Validation loss: 0.230490
#
# Epoch 167
# -------------------------------
# Training loss: 0.221706
# Validation loss: 0.221039
#
# Epoch 168
# -------------------------------
# Training loss: 0.221311
# Validation loss: 0.230104
#
# Epoch 169
# -------------------------------
# Training loss: 0.220903
# Validation loss: 0.219270
#
# Epoch 170
# -------------------------------
# Training loss: 0.218315
# Validation loss: 0.216607
#
# Epoch 171
# -------------------------------
# Training loss: 0.218997
# Validation loss: 0.215708
#
# Epoch 172
# -------------------------------
# Training loss: 0.216588
# Validation loss: 0.244332
#
# Epoch 173
# -------------------------------
# Training loss: 0.214559
# Validation loss: 0.221376
#
# Epoch 174
# -------------------------------
# Training loss: 0.214691
# Validation loss: 0.220137
#
# Epoch 175
# -------------------------------
# Training loss: 0.215786
# Validation loss: 0.210631
#
# Epoch 176
# -------------------------------
# Training loss: 0.215524
# Validation loss: 0.212471
#
# Epoch 177
# -------------------------------
# Training loss: 0.215102
# Validation loss: 0.228748
#
# Epoch 178
# -------------------------------
# Training loss: 0.214147
# Validation loss: 0.206250
#
# Epoch 179
# -------------------------------
# Training loss: 0.213846
# Validation loss: 0.206115
#
# Epoch 180
# -------------------------------
# Training loss: 0.211805
# Validation loss: 0.203802
#
# Epoch 181
# -------------------------------
# Training loss: 0.215240
# Validation loss: 0.219160
#
# Epoch 182
# -------------------------------
# Training loss: 0.210869
# Validation loss: 0.214405
#
# Epoch 183
# -------------------------------
# Training loss: 0.210457
# Validation loss: 0.215089
#
# Epoch 184
# -------------------------------
# Training loss: 0.210436
# Validation loss: 0.208650
#
# Epoch 185
# -------------------------------
# Training loss: 0.207754
# Validation loss: 0.209249
#
# Epoch 186
# -------------------------------
# Training loss: 0.206337
# Validation loss: 0.208520
#
# Epoch 187
# -------------------------------
# Training loss: 0.206045
# Validation loss: 0.217259
#
# Epoch 188
# -------------------------------
# Training loss: 0.204926
# Validation loss: 0.209173
#
# Epoch 189
# -------------------------------
# Training loss: 0.204700
# Validation loss: 0.216788
#
# Epoch 190
# -------------------------------
# Training loss: 0.204718
# Validation loss: 0.219831
#
# Epoch 191
# -------------------------------
# Training loss: 0.207748
# Validation loss: 0.242178
#
# Epoch 192
# -------------------------------
# Training loss: 0.203365
# Validation loss: 0.201447
#
# Epoch 193
# -------------------------------
# Training loss: 0.203904
# Validation loss: 0.204122
#
# Epoch 194
# -------------------------------
# Training loss: 0.202958
# Validation loss: 0.248787
#
# Epoch 195
# -------------------------------
# Training loss: 0.202170
# Validation loss: 0.193310
#
# Epoch 196
# -------------------------------
# Training loss: 0.201066
# Validation loss: 0.203221
#
# Epoch 197
# -------------------------------
# Training loss: 0.199497
# Validation loss: 0.200926
#
# Epoch 198
# -------------------------------
# Training loss: 0.197624
# Validation loss: 0.190861
#
# Epoch 199
# -------------------------------
# Training loss: 0.200059
# Validation loss: 0.214169
#
# Epoch 200
# -------------------------------
# Training loss: 0.197736
# Validation loss: 0.196770
#
# Epoch 201
# -------------------------------
# Training loss: 0.197707
# Validation loss: 0.191588
#
# Epoch 202
# -------------------------------
# Training loss: 0.197515
# Validation loss: 0.215159
#
# Epoch 203
# -------------------------------
# Training loss: 0.198156
# Validation loss: 0.192138
#
# Epoch 204
# -------------------------------
# Training loss: 0.195908
# Validation loss: 0.190886
#
# Epoch 205
# -------------------------------
# Training loss: 0.196863
# Validation loss: 0.188205
#
# Epoch 206
# -------------------------------
# Training loss: 0.195440
# Validation loss: 0.186642
#
# Epoch 207
# -------------------------------
# Training loss: 0.194444
# Validation loss: 0.188763
#
# Epoch 208
# -------------------------------
# Training loss: 0.191568
# Validation loss: 0.187912
#
# Epoch 209
# -------------------------------
# Training loss: 0.192164
# Validation loss: 0.183754
#
# Epoch 210
# -------------------------------
# Training loss: 0.191495
# Validation loss: 0.201457
#
# Epoch 211
# -------------------------------
# Training loss: 0.193264
# Validation loss: 0.199441
#
# Epoch 212
# -------------------------------
# Training loss: 0.191505
# Validation loss: 0.190025
#
# Epoch 213
# -------------------------------
# Training loss: 0.191038
# Validation loss: 0.182889
#
# Epoch 214
# -------------------------------
# Training loss: 0.189522
# Validation loss: 0.188599
#
# Epoch 215
# -------------------------------
# Training loss: 0.189439
# Validation loss: 0.186113
#
# Epoch 216
# -------------------------------
# Training loss: 0.188240
# Validation loss: 0.186567
#
# Epoch 217
# -------------------------------
# Training loss: 0.189185
# Validation loss: 0.201166
#
# Epoch 218
# -------------------------------
# Training loss: 0.188567
# Validation loss: 0.189174
#
# Epoch 219
# -------------------------------
# Training loss: 0.186843
# Validation loss: 0.183575
#
# Epoch 220
# -------------------------------
# Training loss: 0.185922
# Validation loss: 0.185031
#
# Epoch 221
# -------------------------------
# Training loss: 0.184869
# Validation loss: 0.234767
#
# Epoch 222
# -------------------------------
# Training loss: 0.185945
# Validation loss: 0.195301
#
# Epoch 223
# -------------------------------
# Training loss: 0.186341
# Validation loss: 0.301762
#
# Epoch 224
# -------------------------------
# Training loss: 0.184297
# Validation loss: 0.183972
#
# Epoch 225
# -------------------------------
# Training loss: 0.184312
# Validation loss: 0.190354
#
# Epoch 226
# -------------------------------
# Training loss: 0.187156
# Validation loss: 0.232785
#
# Epoch 227
# -------------------------------
# Training loss: 0.183325
# Validation loss: 0.192606
#
# Epoch 228
# -------------------------------
# Training loss: 0.183138
# Validation loss: 0.193276
#
# Epoch 229
# -------------------------------
# Training loss: 0.179176
# Validation loss: 0.183719
#
# Epoch 230
# -------------------------------
# Training loss: 0.179951
# Validation loss: 0.184781
#
# Epoch 231
# -------------------------------
# Training loss: 0.179684
# Validation loss: 0.183122
#
# Epoch 232
# -------------------------------
# Training loss: 0.178725
# Validation loss: 0.242050
#
# Epoch 233
# -------------------------------
# Training loss: 0.179721
# Validation loss: 0.215234
#
# Epoch 234
# -------------------------------
# Training loss: 0.177255
# Validation loss: 0.374063
#
# Epoch 235
# -------------------------------
# Training loss: 0.177879
# Validation loss: 0.316354
#
# Epoch 236
# -------------------------------
# Training loss: 0.178994
# Validation loss: 0.253672
#
# Epoch 237
# -------------------------------
# Training loss: 0.179543
# Validation loss: 0.727504
#
# Epoch 238
# -------------------------------
# Training loss: 0.177444
# Validation loss: 0.694410
#
# Epoch 239
# -------------------------------
# Training loss: 0.174910
# Validation loss: 0.174107
#
# Epoch 240
# -------------------------------
# Training loss: 0.174553
# Validation loss: 0.169997
#
# Epoch 241
# -------------------------------
# Training loss: 0.172437
# Validation loss: 0.176250
#
# Epoch 242
# -------------------------------
# Training loss: 0.172057
# Validation loss: 0.193627
#
# Epoch 243
# -------------------------------
# Training loss: 0.171888
# Validation loss: 0.168123
#
# Epoch 244
# -------------------------------
# Training loss: 0.171490
# Validation loss: 0.252623
#
# Epoch 245
# -------------------------------
# Training loss: 0.171253
# Validation loss: 0.173086
#
# Epoch 246
# -------------------------------
# Training loss: 0.170270
# Validation loss: 0.168884
#
# Epoch 247
# -------------------------------
# Training loss: 0.169154
# Validation loss: 0.166547
#
# Epoch 248
# -------------------------------
# Training loss: 0.167359
# Validation loss: 0.188528
#
# Epoch 249
# -------------------------------
# Training loss: 0.167701
# Validation loss: 0.172647
#
# Epoch 250
# -------------------------------
# Training loss: 0.168702
# Validation loss: 0.183483
#
# Epoch 251
# -------------------------------
# Training loss: 0.169003
# Validation loss: 0.177002
#
# Epoch 252
# -------------------------------
# Training loss: 0.167956
# Validation loss: 0.167270
#
# Epoch 253
# -------------------------------
# Training loss: 0.165326
# Validation loss: 0.160376
#
# Epoch 254
# -------------------------------
# Training loss: 0.165852
# Validation loss: 0.162787
#
# Epoch 255
# -------------------------------
# Training loss: 0.163757
# Validation loss: 0.161122
#
# Epoch 256
# -------------------------------
# Training loss: 0.165479
# Validation loss: 0.275509
#
# Epoch 257
# -------------------------------
# Training loss: 0.165788
# Validation loss: 0.162739
#
# Epoch 258
# -------------------------------
# Training loss: 0.165609
# Validation loss: 0.216969
#
# Epoch 259
# -------------------------------
# Training loss: 0.165502
# Validation loss: 0.164671
#
# Epoch 260
# -------------------------------
# Training loss: 0.162490
# Validation loss: 0.160786
#
# Epoch 261
# -------------------------------
# Training loss: 0.163630
# Validation loss: 0.182915
#
# Epoch 262
# -------------------------------
# Training loss: 0.165039
# Validation loss: 0.162189
#
# Epoch 263
# -------------------------------
# Training loss: 0.164139
# Validation loss: 0.161107
#
# Epoch 264
# -------------------------------
# Training loss: 0.161021
# Validation loss: 0.162979
#
# Epoch 265
# -------------------------------
# Training loss: 0.160629
# Validation loss: 0.154156
#
# Epoch 266
# -------------------------------
# Training loss: 0.161969
# Validation loss: 0.160064
#
# Epoch 267
# -------------------------------
# Training loss: 0.160450
# Validation loss: 0.157005
#
# Epoch 268
# -------------------------------
# Training loss: 0.156922
# Validation loss: 0.159198
#
# Epoch 269
# -------------------------------
# Training loss: 0.157676
# Validation loss: 0.163371
#
# Epoch 270
# -------------------------------
# Training loss: 0.159591
# Validation loss: 0.199194
#
# Epoch 271
# -------------------------------
# Training loss: 0.157626
# Validation loss: 0.194676
#
# Epoch 272
# -------------------------------
# Training loss: 0.158488
# Validation loss: 0.158068
#
# Epoch 273
# -------------------------------
# Training loss: 0.157054
# Validation loss: 0.154230
#
# Epoch 274
# -------------------------------
# Training loss: 0.156874
# Validation loss: 0.161651
#
# Epoch 275
# -------------------------------
# Training loss: 0.154696
# Validation loss: 0.153586
#
# Epoch 276
# -------------------------------
# Training loss: 0.156889
# Validation loss: 0.153118
#
# Epoch 277
# -------------------------------
# Training loss: 0.154151
# Validation loss: 0.149074
#
# Epoch 278
# -------------------------------
# Training loss: 0.153702
# Validation loss: 0.148953
#
# Epoch 279
# -------------------------------
# Training loss: 0.153928
# Validation loss: 0.149704
#
# Epoch 280
# -------------------------------
# Training loss: 0.153818
# Validation loss: 0.154467
#
# Epoch 281
# -------------------------------
# Training loss: 0.153266
# Validation loss: 0.150112
#
# Epoch 282
# -------------------------------
# Training loss: 0.151748
# Validation loss: 0.170940
#
# Epoch 283
# -------------------------------
# Training loss: 0.150390
# Validation loss: 0.159272
#
# Epoch 284
# -------------------------------
# Training loss: 0.151614
# Validation loss: 0.145921
#
# Epoch 285
# -------------------------------
# Training loss: 0.150093
# Validation loss: 0.146398
#
# Epoch 286
# -------------------------------
# Training loss: 0.149899
# Validation loss: 0.175455
#
# Epoch 287
# -------------------------------
# Training loss: 0.151204
# Validation loss: 0.145903
#
# Epoch 288
# -------------------------------
# Training loss: 0.149554
# Validation loss: 0.157660
#
# Epoch 289
# -------------------------------
# Training loss: 0.149715
# Validation loss: 0.147504
#
# Epoch 290
# -------------------------------
# Training loss: 0.148466
# Validation loss: 0.157841
#
# Epoch 291
# -------------------------------
# Training loss: 0.146706
# Validation loss: 0.137848
#
# Epoch 292
# -------------------------------
# Training loss: 0.145977
# Validation loss: 0.142804
#
# Epoch 293
# -------------------------------
# Training loss: 0.149263
# Validation loss: 0.139042
#
# Epoch 294
# -------------------------------
# Training loss: 0.149521
# Validation loss: 0.142840
#
# Epoch 295
# -------------------------------
# Training loss: 0.146837
# Validation loss: 0.144596
#
# Epoch 296
# -------------------------------
# Training loss: 0.144086
# Validation loss: 0.145028
#
# Epoch 297
# -------------------------------
# Training loss: 0.144515
# Validation loss: 0.143506
#
# Epoch 298
# -------------------------------
# Training loss: 0.143609
# Validation loss: 0.154132
#
# Epoch 299
# -------------------------------
# Training loss: 0.144280
# Validation loss: 0.137363
#
# Epoch 300
# -------------------------------
# Training loss: 0.144154
# Validation loss: 0.156554
#
# Epoch 301
# -------------------------------
# Training loss: 0.144083
# Validation loss: 0.138206
#
# Epoch 302
# -------------------------------
# Training loss: 0.140818
# Validation loss: 0.147568
#
# Epoch 303
# -------------------------------
# Training loss: 0.146062
# Validation loss: 0.246264
#
# Epoch 304
# -------------------------------
# Training loss: 0.144362
# Validation loss: 0.171545
#
# Epoch 305
# -------------------------------
# Training loss: 0.141926
# Validation loss: 0.155539
#
# Epoch 306
# -------------------------------
# Training loss: 0.141703
# Validation loss: 0.141948
#
# Epoch 307
# -------------------------------
# Training loss: 0.141677
# Validation loss: 0.161296
#
# Epoch 308
# -------------------------------
# Training loss: 0.140475
# Validation loss: 0.178221
#
# Epoch 309
# -------------------------------
# Training loss: 0.139942
# Validation loss: 0.140742
#
# Epoch 310
# -------------------------------
# Training loss: 0.142557
# Validation loss: 0.146334
#
# Epoch 311
# -------------------------------
# Training loss: 0.140068
# Validation loss: 0.138922
#
# Epoch 312
# -------------------------------
# Training loss: 0.140828
# Validation loss: 0.136987
#
# Epoch 313
# -------------------------------
# Training loss: 0.140326
# Validation loss: 0.137667
#
# Epoch 314
# -------------------------------
# Training loss: 0.138786
# Validation loss: 0.130269
#
# Epoch 315
# -------------------------------
# Training loss: 0.137642
# Validation loss: 0.141655
#
# Epoch 316
# -------------------------------
# Training loss: 0.138126
# Validation loss: 0.148670
#
# Epoch 317
# -------------------------------
# Training loss: 0.137783
# Validation loss: 0.132655
#
# Epoch 318
# -------------------------------
# Training loss: 0.136509
# Validation loss: 0.136202
#
# Epoch 319
# -------------------------------
# Training loss: 0.137338
# Validation loss: 0.133389
#
# Epoch 320
# -------------------------------
# Training loss: 0.136175
# Validation loss: 0.138014
#
# Epoch 321
# -------------------------------
# Training loss: 0.134779
# Validation loss: 0.226643
#
# Epoch 322
# -------------------------------
# Training loss: 0.134891
# Validation loss: 0.128945
#
# Epoch 323
# -------------------------------
# Training loss: 0.132763
# Validation loss: 0.144534
#
# Epoch 324
# -------------------------------
# Training loss: 0.134078
# Validation loss: 0.130376
#
# Epoch 325
# -------------------------------
# Training loss: 0.134049
# Validation loss: 0.129154
#
# Epoch 326
# -------------------------------
# Training loss: 0.132541
# Validation loss: 0.133337
#
# Epoch 327
# -------------------------------
# Training loss: 0.134220
# Validation loss: 0.130006
#
# Epoch 328
# -------------------------------
# Training loss: 0.131975
# Validation loss: 0.136821
#
# Epoch 329
# -------------------------------
# Training loss: 0.131762
# Validation loss: 0.132513
#
# Epoch 330
# -------------------------------
# Training loss: 0.130991
# Validation loss: 0.127992
#
# Epoch 331
# -------------------------------
# Training loss: 0.131994
# Validation loss: 0.203654
#
# Epoch 332
# -------------------------------
# Training loss: 0.132643
# Validation loss: 0.145113
#
# Epoch 333
# -------------------------------
# Training loss: 0.130930
# Validation loss: 0.127721
#
# Epoch 334
# -------------------------------
# Training loss: 0.131892
# Validation loss: 0.137267
#
# Epoch 335
# -------------------------------
# Training loss: 0.133748
# Validation loss: 0.145536
#
# Epoch 336
# -------------------------------
# Training loss: 0.131231
# Validation loss: 0.142505
#
# Epoch 337
# -------------------------------
# Training loss: 0.131383
# Validation loss: 0.133092
#
# Epoch 338
# -------------------------------
# Training loss: 0.129808
# Validation loss: 0.124899
#
# Epoch 339
# -------------------------------
# Training loss: 0.129971
# Validation loss: 0.127936
#
# Epoch 340
# -------------------------------
# Training loss: 0.128469
# Validation loss: 0.147350
#
# Epoch 341
# -------------------------------
# Training loss: 0.128633
# Validation loss: 0.175364
#
# Epoch 342
# -------------------------------
# Training loss: 0.126276
# Validation loss: 0.130021
#
# Epoch 343
# -------------------------------
# Training loss: 0.129189
# Validation loss: 0.131426
#
# Epoch 344
# -------------------------------
# Training loss: 0.125765
# Validation loss: 0.125621
#
# Epoch 345
# -------------------------------
# Training loss: 0.126644
# Validation loss: 0.122513
#
# Epoch 346
# -------------------------------
# Training loss: 0.125257
# Validation loss: 0.131362
#
# Epoch 347
# -------------------------------
# Training loss: 0.130154
# Validation loss: 0.131736
#
# Epoch 348
# -------------------------------
# Training loss: 0.126500
# Validation loss: 0.125228
#
# Epoch 349
# -------------------------------
# Training loss: 0.123793
# Validation loss: 0.123036
#
# Epoch 350
# -------------------------------
# Training loss: 0.125390
# Validation loss: 0.129474
#
# Epoch 351
# -------------------------------
# Training loss: 0.124750
# Validation loss: 0.145807
#
# Epoch 352
# -------------------------------
# Training loss: 0.124914
# Validation loss: 0.164512
#
# Epoch 353
# -------------------------------
# Training loss: 0.122195
# Validation loss: 0.122056
#
# Epoch 354
# -------------------------------
# Training loss: 0.122641
# Validation loss: 0.122929
#
# Epoch 355
# -------------------------------
# Training loss: 0.123686
# Validation loss: 0.147871
#
# Epoch 356
# -------------------------------
# Training loss: 0.124920
# Validation loss: 0.123391
#
# Epoch 357
# -------------------------------
# Training loss: 0.122819
# Validation loss: 0.130838
#
# Epoch 358
# -------------------------------
# Training loss: 0.121529
# Validation loss: 0.175548
#
# Epoch 359
# -------------------------------
# Training loss: 0.124888
# Validation loss: 0.131669
#
# Epoch 360
# -------------------------------
# Training loss: 0.120266
# Validation loss: 0.118734
#
# Epoch 361
# -------------------------------
# Training loss: 0.120778
# Validation loss: 0.117388
#
# Epoch 362
# -------------------------------
# Training loss: 0.120481
# Validation loss: 0.122785
#
# Epoch 363
# -------------------------------
# Training loss: 0.121494
# Validation loss: 0.144066
#
# Epoch 364
# -------------------------------
# Training loss: 0.119271
# Validation loss: 0.119024
#
# Epoch 365
# -------------------------------
# Training loss: 0.119972
# Validation loss: 0.120363
#
# Epoch 366
# -------------------------------
# Training loss: 0.120407
# Validation loss: 0.114287
#
# Epoch 367
# -------------------------------
# Training loss: 0.119805
# Validation loss: 0.113985
#
# Epoch 368
# -------------------------------
# Training loss: 0.119090
# Validation loss: 0.140380
#
# Epoch 369
# -------------------------------
# Training loss: 0.118319
# Validation loss: 0.114286
#
# Epoch 370
# -------------------------------
# Training loss: 0.117677
# Validation loss: 0.136086
#
# Epoch 371
# -------------------------------
# Training loss: 0.117856
# Validation loss: 0.143205
#
# Epoch 372
# -------------------------------
# Training loss: 0.117488
# Validation loss: 0.123954
#
# Epoch 373
# -------------------------------
# Training loss: 0.119093
# Validation loss: 0.243088
#
# Epoch 374
# -------------------------------
# Training loss: 0.118187
# Validation loss: 0.112009
#
# Epoch 375
# -------------------------------
# Training loss: 0.116985
# Validation loss: 0.128423
#
# Epoch 376
# -------------------------------
# Training loss: 0.115424
# Validation loss: 0.122612
#
# Epoch 377
# -------------------------------
# Training loss: 0.117084
# Validation loss: 0.111627
#
# Epoch 378
# -------------------------------
# Training loss: 0.116679
# Validation loss: 0.123593
#
# Epoch 379
# -------------------------------
# Training loss: 0.117418
# Validation loss: 0.128997
#
# Epoch 380
# -------------------------------
# Training loss: 0.117084
# Validation loss: 0.111043
#
# Epoch 381
# -------------------------------
# Training loss: 0.116121
# Validation loss: 0.114586
#
# Epoch 382
# -------------------------------
# Training loss: 0.115757
# Validation loss: 0.110169
#
# Epoch 383
# -------------------------------
# Training loss: 0.114402
# Validation loss: 0.111463
#
# Epoch 384
# -------------------------------
# Training loss: 0.112938
# Validation loss: 0.114374
#
# Epoch 385
# -------------------------------
# Training loss: 0.114110
# Validation loss: 0.113460
#
# Epoch 386
# -------------------------------
# Training loss: 0.115918
# Validation loss: 0.235299
#
# Epoch 387
# -------------------------------
# Training loss: 0.115310
# Validation loss: 0.107344
#
# Epoch 388
# -------------------------------
# Training loss: 0.113725
# Validation loss: 0.129884
#
# Epoch 389
# -------------------------------
# Training loss: 0.111620
# Validation loss: 0.118494
#
# Epoch 390
# -------------------------------
# Training loss: 0.114147
# Validation loss: 0.126966
#
# Epoch 391
# -------------------------------
# Training loss: 0.115376
# Validation loss: 0.113157
#
# Epoch 392
# -------------------------------
# Training loss: 0.112251
# Validation loss: 0.112555
#
# Epoch 393
# -------------------------------
# Training loss: 0.111834
# Validation loss: 0.111572
#
# Epoch 394
# -------------------------------
# Training loss: 0.111770
# Validation loss: 0.166604
#
# Epoch 395
# -------------------------------
# Training loss: 0.111934
# Validation loss: 0.106167
#
# Epoch 396
# -------------------------------
# Training loss: 0.111149
# Validation loss: 0.106748
#
# Epoch 397
# -------------------------------
# Training loss: 0.111344
# Validation loss: 0.114927
#
# Epoch 398
# -------------------------------
# Training loss: 0.108715
# Validation loss: 0.108853
#
# Epoch 399
# -------------------------------
# Training loss: 0.111462
# Validation loss: 0.111386
#
# Epoch 400
# -------------------------------
# Training loss: 0.109009
# Validation loss: 0.116374
#
# Epoch 401
# -------------------------------
# Training loss: 0.110165
# Validation loss: 0.115887
#
# Epoch 402
# -------------------------------
# Training loss: 0.109167
# Validation loss: 0.105343
#
# Epoch 403
# -------------------------------
# Training loss: 0.109017
# Validation loss: 0.107954
#
# Epoch 404
# -------------------------------
# Training loss: 0.110077
# Validation loss: 0.106357
#
# Epoch 405
# -------------------------------
# Training loss: 0.112574
# Validation loss: 0.106194
#
# Epoch 406
# -------------------------------
# Training loss: 0.110425
# Validation loss: 0.103072
#
# Epoch 407
# -------------------------------
# Training loss: 0.109666
# Validation loss: 0.103223
#
# Epoch 408
# -------------------------------
# Training loss: 0.107807
# Validation loss: 0.106399
#
# Epoch 409
# -------------------------------
# Training loss: 0.107195
# Validation loss: 0.102447
#
# Epoch 410
# -------------------------------
# Training loss: 0.107759
# Validation loss: 0.104908
#
# Epoch 411
# -------------------------------
# Training loss: 0.108025
# Validation loss: 0.101848
#
# Epoch 412
# -------------------------------
# Training loss: 0.106844
# Validation loss: 0.121422
#
# Epoch 413
# -------------------------------
# Training loss: 0.107543
# Validation loss: 0.114026
#
# Epoch 414
# -------------------------------
# Training loss: 0.108180
# Validation loss: 0.107046
#
# Epoch 415
# -------------------------------
# Training loss: 0.106445
# Validation loss: 0.111266
#
# Epoch 416
# -------------------------------
# Training loss: 0.106088
# Validation loss: 0.104339
#
# Epoch 417
# -------------------------------
# Training loss: 0.106084
# Validation loss: 0.099036
#
# Epoch 418
# -------------------------------
# Training loss: 0.105776
# Validation loss: 0.103821
#
# Epoch 419
# -------------------------------
# Training loss: 0.104699
# Validation loss: 0.106192
#
# Epoch 420
# -------------------------------
# Training loss: 0.104019
# Validation loss: 0.100919
#
# Epoch 421
# -------------------------------
# Training loss: 0.104438
# Validation loss: 0.116401
#
# Epoch 422
# -------------------------------
# Training loss: 0.107006
# Validation loss: 0.100097
#
# Epoch 423
# -------------------------------
# Training loss: 0.105852
# Validation loss: 0.101667
#
# Epoch 424
# -------------------------------
# Training loss: 0.103523
# Validation loss: 0.100380
#
# Epoch 425
# -------------------------------
# Training loss: 0.104378
# Validation loss: 0.109034
#
# Epoch 426
# -------------------------------
# Training loss: 0.104633
# Validation loss: 0.120414
#
# Epoch 427
# -------------------------------
# Training loss: 0.104755
# Validation loss: 0.099207
#
# Epoch 428
# -------------------------------
# Training loss: 0.104589
# Validation loss: 0.103531
#
# Epoch 429
# -------------------------------
# Training loss: 0.105199
# Validation loss: 0.103984
#
# Epoch 430
# -------------------------------
# Training loss: 0.103608
# Validation loss: 0.139769
#
# Epoch 431
# -------------------------------
# Training loss: 0.102775
# Validation loss: 0.108462
#
# Epoch 432
# -------------------------------
# Training loss: 0.101976
# Validation loss: 0.116816
#
# Epoch 433
# -------------------------------
# Training loss: 0.103107
# Validation loss: 0.101599
#
# Epoch 434
# -------------------------------
# Training loss: 0.102515
# Validation loss: 0.099482
#
# Epoch 435
# -------------------------------
# Training loss: 0.101280
# Validation loss: 0.105143
#
# Epoch 436
# -------------------------------
# Training loss: 0.102133
# Validation loss: 0.159658
#
# Epoch 437
# -------------------------------
# Training loss: 0.099873
# Validation loss: 0.098461
#
# Epoch 438
# -------------------------------
# Training loss: 0.099477
# Validation loss: 0.102427
#
# Epoch 439
# -------------------------------
# Training loss: 0.100268
# Validation loss: 0.105249
#
# Epoch 440
# -------------------------------
# Training loss: 0.101523
# Validation loss: 0.107669
#
# Epoch 441
# -------------------------------
# Training loss: 0.099771
# Validation loss: 0.097158
#
# Epoch 442
# -------------------------------
# Training loss: 0.099509
# Validation loss: 0.102997
#
# Epoch 443
# -------------------------------
# Training loss: 0.099935
# Validation loss: 0.101257
#
# Epoch 444
# -------------------------------
# Training loss: 0.100386
# Validation loss: 0.097481
#
# Epoch 445
# -------------------------------
# Training loss: 0.101976
# Validation loss: 0.196490
#
# Epoch 446
# -------------------------------
# Training loss: 0.098952
# Validation loss: 0.103344
#
# Epoch 447
# -------------------------------
# Training loss: 0.097212
# Validation loss: 0.104396
#
# Epoch 448
# -------------------------------
# Training loss: 0.098092
# Validation loss: 0.093825
#
# Epoch 449
# -------------------------------
# Training loss: 0.098826
# Validation loss: 0.094776
#
# Epoch 450
# -------------------------------
# Training loss: 0.098630
# Validation loss: 0.095441
#
# Epoch 451
# -------------------------------
# Training loss: 0.096599
# Validation loss: 0.094568
#
# Epoch 452
# -------------------------------
# Training loss: 0.098256
# Validation loss: 0.094762
#
# Epoch 453
# -------------------------------
# Training loss: 0.097891
# Validation loss: 0.093830
#
# Epoch 454
# -------------------------------
# Training loss: 0.096261
# Validation loss: 0.133025
#
# Epoch 455
# -------------------------------
# Training loss: 0.100396
# Validation loss: 0.105348
#
# Epoch 456
# -------------------------------
# Training loss: 0.096212
# Validation loss: 0.125139
#
# Epoch 457
# -------------------------------
# Training loss: 0.096923
# Validation loss: 0.092947
#
# Epoch 458
# -------------------------------
# Training loss: 0.095027
# Validation loss: 0.092119
#
# Epoch 459
# -------------------------------
# Training loss: 0.099721
# Validation loss: 0.133280
#
# Epoch 460
# -------------------------------
# Training loss: 0.095672
# Validation loss: 0.094636
#
# Epoch 461
# -------------------------------
# Training loss: 0.094993
# Validation loss: 0.097638
#
# Epoch 462
# -------------------------------
# Training loss: 0.095714
# Validation loss: 0.092456
#
# Epoch 463
# -------------------------------
# Training loss: 0.094254
# Validation loss: 0.093301
#
# Epoch 464
# -------------------------------
# Training loss: 0.094088
# Validation loss: 0.089565
#
# Epoch 465
# -------------------------------
# Training loss: 0.095119
# Validation loss: 0.091959
#
# Epoch 466
# -------------------------------
# Training loss: 0.094194
# Validation loss: 0.094375
#
# Epoch 467
# -------------------------------
# Training loss: 0.096979
# Validation loss: 0.091791
#
# Epoch 468
# -------------------------------
# Training loss: 0.096016
# Validation loss: 0.101600
#
# Epoch 469
# -------------------------------
# Training loss: 0.096352
# Validation loss: 0.094276
#
# Epoch 470
# -------------------------------
# Training loss: 0.094637
# Validation loss: 0.103509
#
# Epoch 471
# -------------------------------
# Training loss: 0.097637
# Validation loss: 0.458132
#
# Epoch 472
# -------------------------------
# Training loss: 0.097041
# Validation loss: 0.165126
#
# Epoch 473
# -------------------------------
# Training loss: 0.094045
# Validation loss: 0.099323
#
# Epoch 474
# -------------------------------
# Training loss: 0.093606
# Validation loss: 0.091656
#
# Epoch 475
# -------------------------------
# Training loss: 0.093471
# Validation loss: 0.090171
#
# Epoch 476
# -------------------------------
# Training loss: 0.093580
# Validation loss: 0.088422
#
# Epoch 477
# -------------------------------
# Training loss: 0.092117
# Validation loss: 0.090627
#
# Epoch 478
# -------------------------------
# Training loss: 0.092031
# Validation loss: 0.088953
#
# Epoch 479
# -------------------------------
# Training loss: 0.092725
# Validation loss: 0.095631
#
# Epoch 480
# -------------------------------
# Training loss: 0.091247
# Validation loss: 0.087958
#
# Epoch 481
# -------------------------------
# Training loss: 0.092561
# Validation loss: 0.097092
#
# Epoch 482
# -------------------------------
# Training loss: 0.090583
# Validation loss: 0.089319
#
# Epoch 483
# -------------------------------
# Training loss: 0.090819
# Validation loss: 0.109615
#
# Epoch 484
# -------------------------------
# Training loss: 0.093943
# Validation loss: 0.090117
#
# Epoch 485
# -------------------------------
# Training loss: 0.093297
# Validation loss: 0.087815
#
# Epoch 486
# -------------------------------
# Training loss: 0.091595
# Validation loss: 0.087398
#
# Epoch 487
# -------------------------------
# Training loss: 0.091379
# Validation loss: 0.090469
#
# Epoch 488
# -------------------------------
# Training loss: 0.090524
# Validation loss: 0.089319
#
# Epoch 489
# -------------------------------
# Training loss: 0.091108
# Validation loss: 0.088281
#
# Epoch 490
# -------------------------------
# Training loss: 0.089909
# Validation loss: 0.095958
#
# Epoch 491
# -------------------------------
# Training loss: 0.090515
# Validation loss: 0.096238
#
# Epoch 492
# -------------------------------
# Training loss: 0.091342
# Validation loss: 0.087648
#
# Epoch 493
# -------------------------------
# Training loss: 0.088478
# Validation loss: 0.086033
#
# Epoch 494
# -------------------------------
# Training loss: 0.089219
# Validation loss: 0.086966
#
# Epoch 495
# -------------------------------
# Training loss: 0.088471
# Validation loss: 0.091694
#
# Epoch 496
# -------------------------------
# Training loss: 0.091067
# Validation loss: 0.091090
#
# Epoch 497
# -------------------------------
# Training loss: 0.092683
# Validation loss: 0.095249
#
# Epoch 498
# -------------------------------
# Training loss: 0.092763
# Validation loss: 0.096160
#
# Epoch 499
# -------------------------------
# Training loss: 0.088708
# Validation loss: 0.087077
#
# Epoch 500
# -------------------------------
# Training loss: 0.088836
# Validation loss: 0.101581
#
# Epoch 501
# -------------------------------
# Training loss: 0.088499
# Validation loss: 0.084296
#
# Epoch 502
# -------------------------------
# Training loss: 0.088236
# Validation loss: 0.087467
#
# Epoch 503
# -------------------------------
# Training loss: 0.086538
# Validation loss: 0.106800
#
# Epoch 504
# -------------------------------
# Training loss: 0.089814
# Validation loss: 0.104187
#
# Epoch 505
# -------------------------------
# Training loss: 0.089807
# Validation loss: 0.093927
#
# Epoch 506
# -------------------------------
# Training loss: 0.088879
# Validation loss: 0.085276
#
# Epoch 507
# -------------------------------
# Training loss: 0.087010
# Validation loss: 0.084244
#
# Epoch 508
# -------------------------------
# Training loss: 0.086757
# Validation loss: 0.084499
#
# Epoch 509
# -------------------------------
# Training loss: 0.089216
# Validation loss: 0.097492
#
# Epoch 510
# -------------------------------
# Training loss: 0.086980
# Validation loss: 0.112156
#
# Epoch 511
# -------------------------------
# Training loss: 0.088637
# Validation loss: 0.091102
#
# Epoch 512
# -------------------------------
# Training loss: 0.086812
# ...
# Validation loss: 0.035945
#
# Epoch 2333
# -------------------------------
# Training loss: 0.035345
# Validation loss: 0.034703
#
# Epoch 2334
# -------------------------------
# Training loss: 0.036075
# Validation loss: 0.034494
#
# Epoch 2335
# -------------------------------
# Training loss: 0.035141
# Validation loss: 0.034662
#
# Epoch 2336
# -------------------------------
# Training loss: 0.035187
# Validation loss: 0.035646
#
# Epoch 2337
# -------------------------------
# Training loss: 0.036061
# Validation loss: 0.034775
#
# Epoch 2338
# -------------------------------
# Training loss: 0.035287
# Validation loss: 0.038304
#
# Epoch 2339
# -------------------------------
# Training loss: 0.035074
# Validation loss: 0.035207
#
# Epoch 2340
# -------------------------------
# Training loss: 0.036868
# Validation loss: 0.036545
#
# Epoch 2341
# -------------------------------
# Training loss: 0.035961
# Validation loss: 0.034803
#
# Epoch 2342
# -------------------------------
# Training loss: 0.036113
# Validation loss: 0.035356
#
# Epoch 2343
# -------------------------------
# Training loss: 0.035227
# Validation loss: 0.034689
#
# Epoch 2344
# -------------------------------
# Training loss: 0.035188
# Validation loss: 0.034688
#
# Epoch 2345
# -------------------------------
# Training loss: 0.035208
# Validation loss: 0.036874
#
# Epoch 2346
# -------------------------------
# Training loss: 0.035737
# Validation loss: 0.034699
#
# Epoch 2347
# -------------------------------
# Training loss: 0.036021
# Validation loss: 0.037142
#
# Epoch 2348
# -------------------------------
# Training loss: 0.035413
# Validation loss: 0.035874
#
# Epoch 2349
# -------------------------------
# Training loss: 0.036081
# Validation loss: 0.034798
#
# Epoch 2350
# -------------------------------
# Training loss: 0.035923
# Validation loss: 0.035693
#
# Epoch 2351
# -------------------------------
# Training loss: 0.035032
# Validation loss: 0.034659
#
# Epoch 2352
# -------------------------------
# Training loss: 0.034476
# Validation loss: 0.034770
#
# Epoch 2353
# -------------------------------
# Training loss: 0.035560
# Validation loss: 0.034666
#
# Epoch 2354
# -------------------------------
# Training loss: 0.035058
# Validation loss: 0.034715
#
# Epoch 2355
# -------------------------------
# Training loss: 0.034546
# Validation loss: 0.036732
#
# Epoch 2356
# -------------------------------
# Training loss: 0.036039
# Validation loss: 0.036325
#
# Epoch 2357
# -------------------------------
# Training loss: 0.035290
# Validation loss: 0.036676
#
# Epoch 2358
# -------------------------------
# Training loss: 0.035547
# Validation loss: 0.035368
#
# Epoch 2359
# -------------------------------
# Training loss: 0.034629
# Validation loss: 0.034570
#
# Epoch 2360
# -------------------------------
# Training loss: 0.035237
# Validation loss: 0.034764
#
# Epoch 2361
# -------------------------------
# Training loss: 0.036114
# Validation loss: 0.035239
#
# Epoch 2362
# -------------------------------
# Training loss: 0.035687
# Validation loss: 0.034846
#
# Epoch 2363
# -------------------------------
# Training loss: 0.036151
# Validation loss: 0.037951
#
# Epoch 2364
# -------------------------------
# Training loss: 0.035320
# Validation loss: 0.034881
#
# Epoch 2365
# -------------------------------
# Training loss: 0.035497
# Validation loss: 0.038339
#
# Epoch 2366
# -------------------------------
# Training loss: 0.035578
# Validation loss: 0.034300
#
# Epoch 2367
# -------------------------------
# Training loss: 0.034588
# Validation loss: 0.034514
#
# Epoch 2368
# -------------------------------
# Training loss: 0.036134
# Validation loss: 0.035171
#
# Epoch 2369
# -------------------------------
# Training loss: 0.035799
# Validation loss: 0.034694
#
# Epoch 2370
# -------------------------------
# Training loss: 0.035806
# Validation loss: 0.036912
#
# Epoch 2371
# -------------------------------
# Training loss: 0.036159
# Validation loss: 0.034985
#
# Epoch 2372
# -------------------------------
# Training loss: 0.034797
# Validation loss: 0.036589
#
# Epoch 2373
# -------------------------------
# Training loss: 0.035527
# Validation loss: 0.035131
#
# Epoch 2374
# -------------------------------
# Training loss: 0.035408
# Validation loss: 0.036723
#
# Epoch 2375
# -------------------------------
# Training loss: 0.035277
# Validation loss: 0.034870
#
# Epoch 2376
# -------------------------------
# Training loss: 0.035099
# Validation loss: 0.034980
#
# Epoch 2377
# -------------------------------
# Training loss: 0.035636
# Validation loss: 0.034621
#
# Epoch 2378
# -------------------------------
# Training loss: 0.035475
# Validation loss: 0.034797
#
# Epoch 2379
# -------------------------------
# Training loss: 0.035950
# Validation loss: 0.035833
#
# Epoch 2380
# -------------------------------
# Training loss: 0.034989
# Validation loss: 0.034572
#
# Epoch 2381
# -------------------------------
# Training loss: 0.035154
# Validation loss: 0.036837
#
# Epoch 2382
# -------------------------------
# Training loss: 0.035143
# Validation loss: 0.035373
#
# Epoch 2383
# -------------------------------
# Training loss: 0.035114
# Validation loss: 0.035036
#
# Epoch 2384
# -------------------------------
# Training loss: 0.035627
# Validation loss: 0.035626
#
# Epoch 2385
# -------------------------------
# Training loss: 0.035518
# Validation loss: 0.034428
#
# Epoch 2386
# -------------------------------
# Training loss: 0.034792
# Validation loss: 0.034636
#
# Epoch 2387
# -------------------------------
# Training loss: 0.035076
# Validation loss: 0.037531
#
# Epoch 2388
# -------------------------------
# Training loss: 0.035105
# Validation loss: 0.034797
#
# Epoch 2389
# -------------------------------
# Training loss: 0.034655
# Validation loss: 0.034881
#
# Epoch 2390
# -------------------------------
# Training loss: 0.035784
# Validation loss: 0.035280
#
# Epoch 2391
# -------------------------------
# Training loss: 0.035511
# Validation loss: 0.036974
#
# Epoch 2392
# -------------------------------
# Training loss: 0.036400
# Validation loss: 0.035068
#
# Epoch 2393
# -------------------------------
# Training loss: 0.036167
# Validation loss: 0.034916
#
# Epoch 2394
# -------------------------------
# Training loss: 0.035195
# Validation loss: 0.035307
#
# Epoch 2395
# -------------------------------
# Training loss: 0.034696
# Validation loss: 0.034675
#
# Epoch 2396
# -------------------------------
# Training loss: 0.035143
# Validation loss: 0.034291
#
# Epoch 2397
# -------------------------------
# Training loss: 0.035689
# Validation loss: 0.034544
#
# Epoch 2398
# -------------------------------
# Training loss: 0.035095
# Validation loss: 0.034600
#
# Epoch 2399
# -------------------------------
# Training loss: 0.035500
# Validation loss: 0.034781
#
# Epoch 2400
# -------------------------------
# Training loss: 0.034716
# Validation loss: 0.036273
#
# Epoch 2401
# -------------------------------
# Training loss: 0.036519
# Validation loss: 0.034467
#
# Epoch 2402
# -------------------------------
# Training loss: 0.034833
# Validation loss: 0.034682
#
# Epoch 2403
# -------------------------------
# Training loss: 0.034711
# Validation loss: 0.035970
#
# Epoch 2404
# -------------------------------
# Training loss: 0.034528
# Validation loss: 0.034704
#
# Epoch 2405
# -------------------------------
# Training loss: 0.034929
# Validation loss: 0.034265
#
# Epoch 2406
# -------------------------------
# Training loss: 0.034619
# Validation loss: 0.035229
#
# Epoch 2407
# -------------------------------
# Training loss: 0.035645
# Validation loss: 0.035546
#
# Epoch 2408
# -------------------------------
# Training loss: 0.034931
# Validation loss: 0.034560
#
# Epoch 2409
# -------------------------------
# Training loss: 0.035478
# Validation loss: 0.034798
#
# Epoch 2410
# -------------------------------
# Training loss: 0.034964
# Validation loss: 0.036650
#
# Epoch 2411
# -------------------------------
# Training loss: 0.035550
# Validation loss: 0.036561
#
# Epoch 2412
# -------------------------------
# Training loss: 0.035232
# Validation loss: 0.035478
#
# Epoch 2413
# -------------------------------
# Training loss: 0.035564
# Validation loss: 0.034649
#
# Epoch 2414
# -------------------------------
# Training loss: 0.035542
# Validation loss: 0.036519
#
# Epoch 2415
# -------------------------------
# Training loss: 0.035626
# Validation loss: 0.037102
#
# Epoch 2416
# -------------------------------
# Training loss: 0.034425
# Validation loss: 0.034898
#
# Epoch 2417
# -------------------------------
# Training loss: 0.035716
# Validation loss: 0.034619
#
# Epoch 2418
# -------------------------------
# Training loss: 0.036235
# Validation loss: 0.035184
#
# Epoch 2419
# -------------------------------
# Training loss: 0.034879
# Validation loss: 0.036424
#
# Epoch 2420
# -------------------------------
# Training loss: 0.035854
# Validation loss: 0.034781
#
# Epoch 2421
# -------------------------------
# Training loss: 0.034810
# Validation loss: 0.034588
#
# Epoch 2422
# -------------------------------
# Training loss: 0.035353
# Validation loss: 0.035914
#
# Epoch 2423
# -------------------------------
# Training loss: 0.035050
# Validation loss: 0.036762
#
# Epoch 2424
# -------------------------------
# Training loss: 0.035071
# Validation loss: 0.034576
#
# Epoch 2425
# -------------------------------
# Training loss: 0.035518
# Validation loss: 0.035380
#
# Epoch 2426
# -------------------------------
# Training loss: 0.035095
# Validation loss: 0.036574
#
# Epoch 2427
# -------------------------------
# Training loss: 0.035267
# Validation loss: 0.036087
#
# Epoch 2428
# -------------------------------
# Training loss: 0.034841
# Validation loss: 0.036267
#
# Epoch 2429
# -------------------------------
# Training loss: 0.036056
# Validation loss: 0.036908
#
# Epoch 2430
# -------------------------------
# Training loss: 0.034918
# Validation loss: 0.035257
#
# Epoch 2431
# -------------------------------
# Training loss: 0.035284
# Validation loss: 0.036077
#
# Epoch 2432
# -------------------------------
# Training loss: 0.035533
# Validation loss: 0.035061
#
# Epoch 2433
# -------------------------------
# Training loss: 0.034748
# Validation loss: 0.035481
#
# Epoch 2434
# -------------------------------
# Training loss: 0.035218
# Validation loss: 0.034415
#
# Epoch 2435
# -------------------------------
# Training loss: 0.036122
# Validation loss: 0.037645
#
# Epoch 2436
# -------------------------------
# Training loss: 0.036062
# Validation loss: 0.034598
#
# Epoch 2437
# -------------------------------
# Training loss: 0.035432
# Validation loss: 0.034428
#
# Epoch 2438
# -------------------------------
# Training loss: 0.035418
# Validation loss: 0.039657
#
# Epoch 2439
# -------------------------------
# Training loss: 0.035204
# Validation loss: 0.035069
#
# Epoch 2440
# -------------------------------
# Training loss: 0.034760
# Validation loss: 0.034582
#
# Epoch 2441
# -------------------------------
# Training loss: 0.035822
# Validation loss: 0.036156
#
# Epoch 2442
# -------------------------------
# Training loss: 0.034671
# Validation loss: 0.036728
#
# Epoch 2443
# -------------------------------
# Training loss: 0.035120
# Validation loss: 0.036837
#
# Epoch 2444
# -------------------------------
# Training loss: 0.035224
# Validation loss: 0.034251
#
# Epoch 2445
# -------------------------------
# Training loss: 0.034777
# Validation loss: 0.036661
#
# Epoch 2446
# -------------------------------
# Training loss: 0.034704
# Validation loss: 0.035044
#
# Epoch 2447
# -------------------------------
# Training loss: 0.034604
# Validation loss: 0.034894
#
# Epoch 2448
# -------------------------------
# Training loss: 0.034945
# Validation loss: 0.035106
#
# Epoch 2449
# -------------------------------
# Training loss: 0.034816
# Validation loss: 0.036396
#
# Epoch 2450
# -------------------------------
# Training loss: 0.036173
# Validation loss: 0.035580
#
# Epoch 2451
# -------------------------------
# Training loss: 0.034353
# Validation loss: 0.037133
#
# Epoch 2452
# -------------------------------
# Training loss: 0.034792
# Validation loss: 0.034503
#
# Epoch 2453
# -------------------------------
# Training loss: 0.035779
# Validation loss: 0.035302
#
# Epoch 2454
# -------------------------------
# Training loss: 0.034992
# Validation loss: 0.034722
#
# Epoch 2455
# -------------------------------
# Training loss: 0.035440
# Validation loss: 0.034881
#
# Epoch 2456
# -------------------------------
# Training loss: 0.034699
# Validation loss: 0.034825
#
# Epoch 2457
# -------------------------------
# Training loss: 0.035891
# Validation loss: 0.034747
#
# Epoch 2458
# -------------------------------
# Training loss: 0.034826
# Validation loss: 0.034313
#
# Epoch 2459
# -------------------------------
# Training loss: 0.035217
# Validation loss: 0.035231
#
# Epoch 2460
# -------------------------------
# Training loss: 0.035081
# Validation loss: 0.036215
#
# Epoch 2461
# -------------------------------
# Training loss: 0.034711
# Validation loss: 0.034931
#
# Epoch 2462
# -------------------------------
# Training loss: 0.035068
# Validation loss: 0.035128
#
# Epoch 2463
# -------------------------------
# Training loss: 0.035050
# Validation loss: 0.034468
#
# Epoch 2464
# -------------------------------
# Training loss: 0.035355
# Validation loss: 0.034616
#
# Epoch 2465
# -------------------------------
# Training loss: 0.035924
# Validation loss: 0.035662
#
# Epoch 2466
# -------------------------------
# Training loss: 0.035410
# Validation loss: 0.035314
#
# Epoch 2467
# -------------------------------
# Training loss: 0.034878
# Validation loss: 0.035630
#
# Epoch 2468
# -------------------------------
# Training loss: 0.035444
# Validation loss: 0.034545
#
# Epoch 2469
# -------------------------------
# Training loss: 0.034860
# Validation loss: 0.034799
#
# Epoch 2470
# -------------------------------
# Training loss: 0.035298
# Validation loss: 0.036719
#
# Epoch 2471
# -------------------------------
# Training loss: 0.035065
# Validation loss: 0.034668
#
# Epoch 2472
# -------------------------------
# Training loss: 0.036061
# Validation loss: 0.035143
#
# Epoch 2473
# -------------------------------
# Training loss: 0.035550
# Validation loss: 0.034647
#
# Epoch 2474
# -------------------------------
# Training loss: 0.034923
# Validation loss: 0.034353
#
# Epoch 2475
# -------------------------------
# Training loss: 0.035560
# Validation loss: 0.037718
#
# Epoch 2476
# -------------------------------
# Training loss: 0.035668
# Validation loss: 0.036564
#
# Epoch 2477
# -------------------------------
# Training loss: 0.034615
# Validation loss: 0.036011
#
# Epoch 2478
# -------------------------------
# Training loss: 0.035181
# Validation loss: 0.035113
#
# Epoch 2479
# -------------------------------
# Training loss: 0.034729
# Validation loss: 0.035045
#
# Epoch 2480
# -------------------------------
# Training loss: 0.036156
# Validation loss: 0.035267
#
# Epoch 2481
# -------------------------------
# Training loss: 0.034526
# Validation loss: 0.034637
#
# Epoch 2482
# -------------------------------
# Training loss: 0.035278
# Validation loss: 0.035496
#
# Epoch 2483
# -------------------------------
# Training loss: 0.034822
# Validation loss: 0.034222
#
# Epoch 2484
# -------------------------------
# Training loss: 0.035350
# Validation loss: 0.034657
#
# Epoch 2485
# -------------------------------
# Training loss: 0.034989
# Validation loss: 0.034573
#
# Epoch 2486
# -------------------------------
# Training loss: 0.034657
# Validation loss: 0.034717
#
# Epoch 2487
# -------------------------------
# Training loss: 0.035178
# Validation loss: 0.036159
#
# Epoch 2488
# -------------------------------
# Training loss: 0.034518
# Validation loss: 0.035764
#
# Epoch 2489
# -------------------------------
# Training loss: 0.034604
# Validation loss: 0.034321
#
# Epoch 2490
# -------------------------------
# Training loss: 0.035516
# Validation loss: 0.036141
#
# Epoch 2491
# -------------------------------
# Training loss: 0.035647
# Validation loss: 0.034200
#
# Epoch 2492
# -------------------------------
# Training loss: 0.035858
# Validation loss: 0.034389
#
# Epoch 2493
# -------------------------------
# Training loss: 0.036101
# Validation loss: 0.036670
#
# Epoch 2494
# -------------------------------
# Training loss: 0.035531
# Validation loss: 0.034617
#
# Epoch 2495
# -------------------------------
# Training loss: 0.035536
# Validation loss: 0.035515
#
# Epoch 2496
# -------------------------------
# Training loss: 0.035749
# Validation loss: 0.036758
#
# Epoch 2497
# -------------------------------
# Training loss: 0.035487
# Validation loss: 0.035519
#
# Epoch 2498
# -------------------------------
# Training loss: 0.035073
# Validation loss: 0.038481
#
# Epoch 2499
# -------------------------------
# Training loss: 0.035363
# Validation loss: 0.036659
#
# Epoch 2500
# -------------------------------
# Training loss: 0.035334
# Validation loss: 0.035187
#
# Done!

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses)+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('BCE Loss')
#plt.yscale('log')
plt.legend()

# %%
# Now test the pretrained model
test_pred = mytools.test_clas(test_loader, final_classifier, device)
test_pred=torch.sigmoid(torch.tensor(test_pred)).numpy()


fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test, test_pred, pos_label=1)
auc_test = sklearn.metrics.auc(fpr, tpr)
print(f'Test AUROC: {auc_test:0.4f}')

plt.plot(fpr, tpr, label=f'Test AUROC: {auc_test:0.4f}')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
# Out:
# Test AUROC: 0.9980

# %%
# Store the pretrained classifier labels
df_test["Class_pre"] = test_pred

# Save the pretrained classifier model
torch.save(final_classifier.state_dict(), "/Users/mghrear/data/ML_data/2019_pass2/models/pretrained_FakeGen_classifier_2019_pass2_run"+str(run)+"_unscaled.pt")

# %% [markdown]
# # Setup the adversary model

# %% [markdown]
# ## Initialize model, objective function, and optimizer

# %%
adv = mytools.Adversary(n_classes=Num_classes).to(device)
criterion_adv = nn.CrossEntropyLoss(reduction='none')  # returns loss per sample so we can weight it
opt_adv = torch.optim.Adam(adv.parameters(), lr=1e-5)
scheduler_adv = torch.optim.lr_scheduler.ExponentialLR(opt_adv, gamma=0.999)

# %% [markdown]
# ## Setup dataloaders

# %%
# Convert to tensor dataset and dataloader

# the structure is: feature, adversary label, weight
# The wight is 1 for tritrig and wab, and 0 for phiKK, to prevent the adversary from learning on phiKK events

train_adv_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_train), (torch.from_numpy(y_train.to_numpy().astype(np.float32))==0).float())
train_adv_loader = DataLoader(train_adv_dataset, batch_size=bsize, shuffle=True)

val_adv_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_val), (torch.from_numpy(y_val.to_numpy().astype(np.float32))==0).float() )
val_adv_loader = DataLoader(val_adv_dataset, batch_size=bsize, shuffle=True)

# Weights are not relavent for testing
test_adv_dataset = TensorDataset(torch.from_numpy(X_test.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_test))
test_adv_loader = DataLoader(test_adv_dataset, batch_size=bsize, shuffle=True)

# %% [markdown]
# ## Pre-train the adversary leaving classifier weights fixed

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 6

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 100
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train_adv(train_adv_loader, final_classifier, adv, criterion_adv, opt_adv, scheduler_adv, device))
    Validation_losses = np.append(Validation_losses, mytools.validate_adv(val_adv_loader, final_classifier, adv, criterion_adv, device))
    
    # Keep a running copy of the model with the lowest loss
    if Validation_losses[-1] == np.min(Validation_losses):
        final_adv = copy.deepcopy(adv)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Training loss: 1.629421
# Validation loss: 1.617126
#
# Epoch 2
# -------------------------------
# Training loss: 1.620092
# Validation loss: 1.615888
#
# Epoch 3
# -------------------------------
# Training loss: 1.613049
# Validation loss: 1.611088
#
# Epoch 4
# -------------------------------
# Training loss: 1.606497
# Validation loss: 1.603849
#
# Epoch 5
# -------------------------------
# Training loss: 1.601553
# Validation loss: 1.605265
#
# Epoch 6
# -------------------------------
# Training loss: 1.596231
# Validation loss: 1.599739
#
# Epoch 7
# -------------------------------
# Training loss: 1.592228
# Validation loss: 1.596463
#
# Epoch 8
# -------------------------------
# Training loss: 1.589842
# Validation loss: 1.593536
#
# Epoch 9
# -------------------------------
# Training loss: 1.587715
# Validation loss: 1.595887
#
# Epoch 10
# -------------------------------
# Training loss: 1.586702
# Validation loss: 1.591066
#
# Epoch 11
# -------------------------------
# Training loss: 1.585398
# Validation loss: 1.591264
#
# Epoch 12
# -------------------------------
# Training loss: 1.584654
# Validation loss: 1.588934
#
# Epoch 13
# -------------------------------
# Training loss: 1.584460
# Validation loss: 1.587601
#
# Epoch 14
# -------------------------------
# Training loss: 1.583474
# Validation loss: 1.587079
#
# Epoch 15
# -------------------------------
# Training loss: 1.582626
# Validation loss: 1.592875
#
# Epoch 16
# -------------------------------
# Training loss: 1.583163
# Validation loss: 1.588636
#
# Epoch 17
# -------------------------------
# Training loss: 1.582549
# Validation loss: 1.589371
#
# Epoch 18
# -------------------------------
# Training loss: 1.582280
# Validation loss: 1.590364
#
# Epoch 19
# -------------------------------
# Training loss: 1.581671
# Validation loss: 1.588642
#
# Epoch 20
# -------------------------------
# Training loss: 1.581543
# Validation loss: 1.585442
#
# Epoch 21
# -------------------------------
# Training loss: 1.580646
# Validation loss: 1.587184
#
# Epoch 22
# -------------------------------
# Training loss: 1.580424
# Validation loss: 1.587153
#
# Epoch 23
# -------------------------------
# Training loss: 1.580739
# Validation loss: 1.586142
#
# Epoch 24
# -------------------------------
# Training loss: 1.580476
# Validation loss: 1.583923
#
# Epoch 25
# -------------------------------
# Training loss: 1.579799
# Validation loss: 1.585761
#
# Epoch 26
# -------------------------------
# Training loss: 1.579670
# Validation loss: 1.587119
#
# Epoch 27
# -------------------------------
# Training loss: 1.579563
# Validation loss: 1.584572
#
# Epoch 28
# -------------------------------
# Training loss: 1.579408
# Validation loss: 1.583796
#
# Epoch 29
# -------------------------------
# Training loss: 1.579066
# Validation loss: 1.588318
#
# Epoch 30
# -------------------------------
# Training loss: 1.579118
# Validation loss: 1.585044
#
# Epoch 31
# -------------------------------
# Training loss: 1.578956
# Validation loss: 1.586669
#
# Epoch 32
# -------------------------------
# Training loss: 1.578966
# Validation loss: 1.583292
#
# Epoch 33
# -------------------------------
# Training loss: 1.578615
# Validation loss: 1.585554
#
# Epoch 34
# -------------------------------
# Training loss: 1.578185
# Validation loss: 1.585880
#
# Epoch 35
# -------------------------------
# Training loss: 1.578532
# Validation loss: 1.586885
#
# Epoch 36
# -------------------------------
# Training loss: 1.578489
# Validation loss: 1.585615
#
# Epoch 37
# -------------------------------
# Training loss: 1.578461
# Validation loss: 1.584172
#
# Epoch 38
# -------------------------------
# Training loss: 1.578060
# Validation loss: 1.585174
#
# Epoch 39
# -------------------------------
# Training loss: 1.577851
# Validation loss: 1.582998
#
# Epoch 40
# -------------------------------
# Training loss: 1.577446
# Validation loss: 1.582403
#
# Epoch 41
# -------------------------------
# Training loss: 1.577516
# Validation loss: 1.584253
#
# Epoch 42
# -------------------------------
# Training loss: 1.577823
# Validation loss: 1.582982
#
# Epoch 43
# -------------------------------
# Training loss: 1.577272
# Validation loss: 1.582915
#
# Epoch 44
# -------------------------------
# Training loss: 1.577276
# Validation loss: 1.584819
#
# Epoch 45
# -------------------------------
# Training loss: 1.577426
# Validation loss: 1.580769
#
# Epoch 46
# -------------------------------
# Training loss: 1.577083
# Validation loss: 1.581728
#
# Epoch 47
# -------------------------------
# Training loss: 1.577030
# Validation loss: 1.584065
#
# Epoch 48
# -------------------------------
# Training loss: 1.577234
# Validation loss: 1.583115
#
# Epoch 49
# -------------------------------
# Training loss: 1.577010
# Validation loss: 1.580853
#
# Epoch 50
# -------------------------------
# Training loss: 1.577042
# Validation loss: 1.580970
#
# Epoch 51
# -------------------------------
# Training loss: 1.576916
# Validation loss: 1.582698
#
# Epoch 52
# -------------------------------
# Training loss: 1.576743
# Validation loss: 1.585295
#
# Epoch 53
# -------------------------------
# Training loss: 1.576800
# Validation loss: 1.581554
#
# Epoch 54
# -------------------------------
# Training loss: 1.576972
# Validation loss: 1.584607
#
# Epoch 55
# -------------------------------
# Training loss: 1.575963
# Validation loss: 1.584131
#
# Epoch 56
# -------------------------------
# Training loss: 1.576240
# Validation loss: 1.582150
#
# Epoch 57
# -------------------------------
# Training loss: 1.576277
# Validation loss: 1.585504
#
# Epoch 58
# -------------------------------
# Training loss: 1.576559
# Validation loss: 1.582560
#
# Epoch 59
# -------------------------------
# Training loss: 1.576260
# Validation loss: 1.581574
#
# Epoch 60
# -------------------------------
# Training loss: 1.576330
# Validation loss: 1.583673
#
# Epoch 61
# -------------------------------
# Training loss: 1.576483
# Validation loss: 1.581744
#
# Epoch 62
# -------------------------------
# Training loss: 1.575909
# Validation loss: 1.582761
#
# Epoch 63
# -------------------------------
# Training loss: 1.575834
# Validation loss: 1.581378
#
# Epoch 64
# -------------------------------
# Training loss: 1.576521
# Validation loss: 1.580455
#
# Epoch 65
# -------------------------------
# Training loss: 1.575896
# Validation loss: 1.582867
#
# Epoch 66
# -------------------------------
# Training loss: 1.575846
# Validation loss: 1.581348
#
# Epoch 67
# -------------------------------
# Training loss: 1.575902
# Validation loss: 1.584476
#
# Epoch 68
# -------------------------------
# Training loss: 1.575689
# Validation loss: 1.582501
#
# Epoch 69
# -------------------------------
# Training loss: 1.576185
# Validation loss: 1.585156
#
# Epoch 70
# -------------------------------
# Training loss: 1.575096
# Validation loss: 1.582389
#
# Epoch 71
# -------------------------------
# Training loss: 1.575528
# Validation loss: 1.583333
#
# Epoch 72
# -------------------------------
# Training loss: 1.576074
# Validation loss: 1.583499
#
# Epoch 73
# -------------------------------
# Training loss: 1.575991
# Validation loss: 1.580124
#
# Epoch 74
# -------------------------------
# Training loss: 1.575888
# Validation loss: 1.580346
#
# Epoch 75
# -------------------------------
# Training loss: 1.575819
# Validation loss: 1.579312
#
# Epoch 76
# -------------------------------
# Training loss: 1.575654
# Validation loss: 1.582195
#
# Epoch 77
# -------------------------------
# Training loss: 1.575968
# Validation loss: 1.582894
#
# Epoch 78
# -------------------------------
# Training loss: 1.575466
# Validation loss: 1.582004
#
# Epoch 79
# -------------------------------
# Training loss: 1.575856
# Validation loss: 1.578973
#
# Epoch 80
# -------------------------------
# Training loss: 1.575523
# Validation loss: 1.582025
#
# Epoch 81
# -------------------------------
# Training loss: 1.576036
# Validation loss: 1.580620
#
# Epoch 82
# -------------------------------
# Training loss: 1.575639
# Validation loss: 1.582043
#
# Epoch 83
# -------------------------------
# Training loss: 1.575833
# Validation loss: 1.582942
#
# Epoch 84
# -------------------------------
# Training loss: 1.575680
# Validation loss: 1.582162
#
# Epoch 85
# -------------------------------
# Training loss: 1.575469
# Validation loss: 1.579130
#
# Epoch 86
# -------------------------------
# Training loss: 1.575375
# Validation loss: 1.578677
#
# Epoch 87
# -------------------------------
# Training loss: 1.575023
# Validation loss: 1.584542
#
# Epoch 88
# -------------------------------
# Training loss: 1.575651
# Validation loss: 1.581288
#
# Epoch 89
# -------------------------------
# Training loss: 1.575538
# Validation loss: 1.581116
#
# Epoch 90
# -------------------------------
# Training loss: 1.574953
# Validation loss: 1.579023
#
# Epoch 91
# -------------------------------
# Training loss: 1.575399
# Validation loss: 1.578767
#
# Epoch 92
# -------------------------------
# Training loss: 1.575147
# Validation loss: 1.582367
#
# Epoch 93
# -------------------------------
# Training loss: 1.574857
# Validation loss: 1.583385
#
# Epoch 94
# -------------------------------
# Training loss: 1.574983
# Validation loss: 1.581919
#
# Epoch 95
# -------------------------------
# Training loss: 1.574879
# Validation loss: 1.582167
#
# Epoch 96
# -------------------------------
# Training loss: 1.575023
# Validation loss: 1.581010
#
# Epoch 97
# -------------------------------
# Training loss: 1.575192
# Validation loss: 1.579711
#
# Epoch 98
# -------------------------------
# Training loss: 1.575304
# Validation loss: 1.580965
#
# Epoch 99
# -------------------------------
# Training loss: 1.574683
# Validation loss: 1.583493
#
# Epoch 100
# -------------------------------
# Training loss: 1.575324
# Validation loss: 1.581184
#
# Done!

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses)+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('BCE Loss')
plt.legend()

# %% [markdown]
# # Train full adverserial neural network

# %% [markdown]
# # Setup dataloaders

# %%
# the structure is: feature, classifier label, adversary label, weight
# The wight is 1 for tritrig and wab, and 0 for phiKK, to prevent the adversary from learning on phiKK events

train_full_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy().astype(np.float32))  , torch.from_numpy(y_train.to_numpy().astype(np.float32)).unsqueeze(1), torch.from_numpy(y_adv_train),  (torch.from_numpy(y_train.to_numpy().astype(np.float32))==0).float())
train_full_loader = DataLoader(train_full_dataset, batch_size=bsize, shuffle=True)

val_full_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy().astype(np.float32))  , torch.from_numpy(y_val.to_numpy().astype(np.float32)).unsqueeze(1),  torch.from_numpy(y_adv_val),  (torch.from_numpy(y_val.to_numpy().astype(np.float32))==0).float())
val_full_loader = DataLoader(val_full_dataset, batch_size=bsize, shuffle=True)

# %% [markdown]
# ## Define loss functions

# %%
BCE_loss = nn.BCEWithLogitsLoss()
CE_loss = nn.CrossEntropyLoss(reduction='none') # returns loss per sample so we can weight it

def full_loss(output_clas, output_adv, target_clas, target_adv, w, lambda_):

    loss1 = BCE_loss(output_clas, target_clas )  # classification loss
    sample_losses2 = CE_loss(output_adv, target_adv)  # adversarial losses, since we set reduction='none', this is now a vector of losses, one per sample in the batch

    # Weighted mean loss over non-zero weights
    nonzero = w > 0
    loss2 = (sample_losses2[nonzero] * w[nonzero]).sum() / w[nonzero].sum()

    loss = loss1 - lambda_*loss2

    return loss

# %% [markdown]
# ## Setup optimizers

# %%
optimizer_clas = optim.Adam(final_classifier.parameters(), lr=1e-7,betas=(0.5, 0.999))
optimizer_adv = optim.Adam(final_adv.parameters(), lr=1e-5,betas=(0.5, 0.999))

scheduler_clas = torch.optim.lr_scheduler.ExponentialLR(optimizer_clas, gamma=0.999)
scheduler_adv = torch.optim.lr_scheduler.ExponentialLR(optimizer_adv, gamma=0.999)

# %% [markdown]
# ## Adversarial training

# %%
Training_losses_clas = np.array([])
Training_losses_adv = np.array([])
Validation_losses_clas = np.array([])
Validation_losses_adv = np.array([])
diff_scores = np.array([])


epochs = 50
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")

    # Get validation losses
    E_clas_val_loss, E_adv_val_loss = mytools.validate_full(val_full_loader, final_classifier, final_adv, full_loss, lambda_, criterion_adv, device)
    Validation_losses_clas = np.append(Validation_losses_clas, E_clas_val_loss)
    Validation_losses_adv = np.append(Validation_losses_adv, E_adv_val_loss)

    # Train adversary and classifier
    E_clas_training_loss , E_adv_training_loss = mytools.train_full(train_full_loader, final_classifier, final_adv, full_loss, lambda_, criterion_adv, optimizer_clas, optimizer_adv, scheduler_clas, scheduler_adv, device)
    Training_losses_clas = np.append(Training_losses_clas, E_clas_training_loss)
    Training_losses_adv = np.append(Training_losses_adv, E_adv_training_loss)

    # Get the diff_score
    df_test["Class_adv"] = mytools.test_clas(test_loader, final_classifier, device)
    df_bkg = df_test.loc[ (df_test.type == 'tritrig') | (df_test.type == 'wab')]
    per = np.percentile(df_bkg['Class_adv'],99)
    df_cut = df_bkg[df_bkg['Class_adv']>per].reset_index(drop=True)
    x1 = 1000* df_bkg.InvM.values
    x2 = 1000*df_cut.InvM.values
    diff_scores = np.append(diff_scores, mytools.get_diff_score(x1,x2) )

    # Keep a running copy of the model with the lowest loss
    if diff_scores[-1] == np.min(diff_scores):
        final_clas_adv = copy.deepcopy(final_classifier)
        final_adv_adv = copy.deepcopy(final_adv)

            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Classifier validation loss: -158.223819
# Adversary validation loss: 1.582604
# Classifier training loss: -158.318268
# Adversary training loss: 1.584418
# Epoch 2
# -------------------------------
# Classifier validation loss: -159.157279
# Adversary validation loss: 1.591930
# Classifier training loss: -159.735979
# Adversary training loss: 1.598665
# Epoch 3
# -------------------------------
# Classifier validation loss: -160.506826
# Adversary validation loss: 1.605453
# Classifier training loss: -160.788108
# Adversary training loss: 1.608929
# Epoch 4
# -------------------------------
# Classifier validation loss: -161.212554
# Adversary validation loss: 1.612589
# Classifier training loss: -160.594405
# Adversary training loss: 1.606612
# Epoch 5
# -------------------------------
# Classifier validation loss: -160.784551
# Adversary validation loss: 1.608306
# Classifier training loss: -160.331180
# Adversary training loss: 1.603881
# Epoch 6
# -------------------------------
# Classifier validation loss: -160.377618
# Adversary validation loss: 1.604245
# Classifier training loss: -160.221857
# Adversary training loss: 1.602785
# Epoch 7
# -------------------------------
# Classifier validation loss: -160.419610
# Adversary validation loss: 1.604671
# Classifier training loss: -160.361638
# Adversary training loss: 1.604241
# Epoch 8
# -------------------------------
# Classifier validation loss: -160.491828
# Adversary validation loss: 1.605342
# Classifier training loss: -160.443986
# Adversary training loss: 1.605064
# Epoch 9
# -------------------------------
# Classifier validation loss: -160.668587
# Adversary validation loss: 1.607100
# Classifier training loss: -160.546442
# Adversary training loss: 1.606031
# Epoch 10
# -------------------------------
# Classifier validation loss: -160.894867
# Adversary validation loss: 1.609371
# Classifier training loss: -160.707719
# Adversary training loss: 1.607628
# Epoch 11
# -------------------------------
# Classifier validation loss: -160.776195
# Adversary validation loss: 1.608206
# Classifier training loss: -160.703607
# Adversary training loss: 1.607578
# Epoch 12
# -------------------------------
# Classifier validation loss: -160.925495
# Adversary validation loss: 1.609684
# Classifier training loss: -160.666537
# Adversary training loss: 1.607196
# Epoch 13
# -------------------------------
# Classifier validation loss: -160.795645
# Adversary validation loss: 1.608396
# Classifier training loss: -160.766681
# Adversary training loss: 1.608203
# Epoch 14
# -------------------------------
# Classifier validation loss: -160.768026
# Adversary validation loss: 1.608155
# Classifier training loss: -160.829675
# Adversary training loss: 1.608847
# Epoch 15
# -------------------------------
# Classifier validation loss: -160.884976
# Adversary validation loss: 1.609307
# Classifier training loss: -160.762496
# Adversary training loss: 1.608178
# Epoch 16
# -------------------------------
# Classifier validation loss: -161.192333
# Adversary validation loss: 1.612417
# Classifier training loss: -160.890968
# Adversary training loss: 1.609498
# Epoch 17
# -------------------------------
# Classifier validation loss: -160.955371
# Adversary validation loss: 1.610042
# Classifier training loss: -160.853165
# Adversary training loss: 1.609088
# Epoch 18
# -------------------------------
# Classifier validation loss: -160.991228
# Adversary validation loss: 1.610378
# Classifier training loss: -160.932553
# Adversary training loss: 1.609894
# Epoch 19
# -------------------------------
# Classifier validation loss: -161.128041
# Adversary validation loss: 1.611773
# Classifier training loss: -160.875424
# Adversary training loss: 1.609320
# Epoch 20
# -------------------------------
# Classifier validation loss: -160.973773
# Adversary validation loss: 1.610238
# Classifier training loss: -160.901095
# Adversary training loss: 1.609614
# Epoch 21
# -------------------------------
# Classifier validation loss: -161.048929
# Adversary validation loss: 1.610967
# Classifier training loss: -160.836461
# Adversary training loss: 1.608937
# Epoch 22
# -------------------------------
# Classifier validation loss: -161.020154
# Adversary validation loss: 1.610730
# Classifier training loss: -160.968398
# Adversary training loss: 1.610261
# Epoch 23
# -------------------------------
# Classifier validation loss: -161.016133
# Adversary validation loss: 1.610680
# Classifier training loss: -160.920147
# Adversary training loss: 1.609779
# Epoch 24
# -------------------------------
# Classifier validation loss: -161.022156
# Adversary validation loss: 1.610723
# Classifier training loss: -160.899355
# Adversary training loss: 1.609564
# Epoch 25
# -------------------------------
# Classifier validation loss: -161.167628
# Adversary validation loss: 1.612192
# Classifier training loss: -160.982774
# Adversary training loss: 1.610436
# Epoch 26
# -------------------------------
# Classifier validation loss: -161.204845
# Adversary validation loss: 1.612591
# Classifier training loss: -161.018558
# Adversary training loss: 1.610799
# Epoch 27
# -------------------------------
# Classifier validation loss: -161.100471
# Adversary validation loss: 1.611585
# Classifier training loss: -161.058028
# Adversary training loss: 1.611236
# Epoch 28
# -------------------------------
# Classifier validation loss: -161.300329
# Adversary validation loss: 1.613585
# Classifier training loss: -161.078126
# Adversary training loss: 1.611465
# Epoch 29
# -------------------------------
# Classifier validation loss: -161.123446
# Adversary validation loss: 1.611831
# Classifier training loss: -161.029292
# Adversary training loss: 1.610965
# Epoch 30
# -------------------------------
# Classifier validation loss: -161.090055
# Adversary validation loss: 1.611544
# Classifier training loss: -161.116764
# Adversary training loss: 1.611872
# Epoch 31
# -------------------------------
# Classifier validation loss: -161.295326
# Adversary validation loss: 1.613541
# Classifier training loss: -161.129692
# Adversary training loss: 1.612010
# Epoch 32
# -------------------------------
# Classifier validation loss: -161.240974
# Adversary validation loss: 1.613047
# Classifier training loss: -161.158295
# Adversary training loss: 1.612324
# Epoch 33
# -------------------------------
# Classifier validation loss: -161.213265
# Adversary validation loss: 1.612822
# Classifier training loss: -161.117098
# Adversary training loss: 1.611938
# Epoch 34
# -------------------------------
# Classifier validation loss: -161.355254
# Adversary validation loss: 1.614268
# Classifier training loss: -161.230702
# Adversary training loss: 1.613136
# Epoch 35
# -------------------------------
# Classifier validation loss: -161.361212
# Adversary validation loss: 1.614327
# Classifier training loss: -161.221183
# Adversary training loss: 1.613093
# Epoch 36
# -------------------------------
# Classifier validation loss: -161.375141
# Adversary validation loss: 1.614546
# Classifier training loss: -161.283994
# Adversary training loss: 1.613786
# Epoch 37
# -------------------------------
# Classifier validation loss: -161.408895
# Adversary validation loss: 1.614934
# Classifier training loss: -161.400452
# Adversary training loss: 1.615074
# Epoch 38
# -------------------------------
# Classifier validation loss: -161.328984
# Adversary validation loss: 1.614238
# Classifier training loss: -161.424682
# Adversary training loss: 1.615415
# Epoch 39
# -------------------------------
# Classifier validation loss: -161.418267
# Adversary validation loss: 1.615216
# Classifier training loss: -161.522645
# Adversary training loss: 1.616492
# Epoch 40
# -------------------------------
# Classifier validation loss: -162.070405
# Adversary validation loss: 1.621992
# Classifier training loss: -161.557020
# Adversary training loss: 1.616912
# Epoch 41
# -------------------------------
# Classifier validation loss: -161.557140
# Adversary validation loss: 1.616858
# Classifier training loss: -161.668989
# Adversary training loss: 1.618127
# Epoch 42
# -------------------------------
# Classifier validation loss: -161.605503
# Adversary validation loss: 1.617288
# Classifier training loss: -161.720133
# Adversary training loss: 1.618705
# Epoch 43
# -------------------------------
# Classifier validation loss: -161.784557
# Adversary validation loss: 1.619274
# Classifier training loss: -161.767891
# Adversary training loss: 1.619283
# Epoch 44
# -------------------------------
# Classifier validation loss: -162.019616
# Adversary validation loss: 1.621646
# Classifier training loss: -161.840408
# Adversary training loss: 1.620073
# Epoch 45
# -------------------------------
# Classifier validation loss: -162.017704
# Adversary validation loss: 1.621694
# Classifier training loss: -161.869508
# Adversary training loss: 1.620447
# Epoch 46
# -------------------------------
# Classifier validation loss: -162.273288
# Adversary validation loss: 1.624499
# Classifier training loss: -161.997369
# Adversary training loss: 1.621828
# Epoch 47
# -------------------------------
# Classifier validation loss: -162.185290
# Adversary validation loss: 1.623616
# Classifier training loss: -161.959124
# Adversary training loss: 1.621493
# Epoch 48
# -------------------------------
# Classifier validation loss: -162.543951
# Adversary validation loss: 1.627304
# Classifier training loss: -162.002246
# Adversary training loss: 1.621978
# Epoch 49
# -------------------------------
# Classifier validation loss: -162.092262
# Adversary validation loss: 1.622969
# Classifier training loss: -161.992931
# Adversary training loss: 1.621946
# Epoch 50
# -------------------------------
# Classifier validation loss: -162.097497
# Adversary validation loss: 1.622915
# Classifier training loss: -161.880665
# Adversary training loss: 1.620852
# Done!

# %%
fig, ax1 = plt.subplots()

best_epoch = np.argmin(diff_scores)+1



#ax1.plot(np.arange(len(Training_losses_adv))+1, Training_losses_adv, 'k-', label='Training Adversary')
ax1.plot(np.arange(len(Validation_losses_adv))+1, Validation_losses_adv, 'k-', label='Validation Adversary')

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Adversary Loss', color='k')
ax1.tick_params(axis='y', labelcolor='k')

ax2 = ax1.twinx()

#ax2.plot(np.arange(len(Training_losses_clas))+1, Training_losses_clas, 'r-', label='Training Classifier')
ax2.plot(np.arange(len(Validation_losses_clas))+1, Validation_losses_clas, 'r-', label='Validation Classifier')
ax2.axvline(best_epoch,label="Final model stopped here",color='k')

ax2.set_ylabel('Classifier Loss', color='r')
ax2.tick_params(axis='y', labelcolor='r')

# %% [markdown]
# ## Test adversarially trained models

# %%
# Now test the pretrained model
test_pred = mytools.test_clas(test_loader, final_clas_adv, device)
test_pred=torch.sigmoid(torch.tensor(test_pred)).numpy()


fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test, test_pred, pos_label=1)
auc_test = sklearn.metrics.auc(fpr, tpr)
print(f'Test AUROC: {auc_test:0.4f}')

plt.plot(fpr, tpr, label=f'Test AUROC: {auc_test:0.4f}')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
# Out:
# Test AUROC: 0.9928

# %%
df_test["Class_adv"] = test_pred
df_bkg = df_test.loc[ (df_test.type == 'tritrig') | (df_test.type == 'wab')]
per = np.percentile(df_bkg['Class_adv'],99)
df_cut = df_bkg[df_bkg['Class_adv']>per].reset_index(drop=True)
x_vals = 1000*df_cut.InvM

plt.figure()
plt.hist(1000*df_bkg.InvM, bins=np.arange(980,1250,1), histtype='step', label='No selection', density=True)
plt.hist(x_vals, bins=np.arange(980,1250,1), histtype='step', label= '99 percent selection', density=True)
plt.axvline(1019.461, color='k', linestyle='dashed', linewidth=1, label='PDG phi mass')
plt.xlabel('Invariant Mass [MeV]')
plt.ylabel('Normalized Counts')
plt.legend()

# %%
x1 = 1000* df_bkg.InvM.values
x2 = 1000*df_cut.InvM.values

N, edges = np.histogram(x1, bins=np.arange(980,1250,1), density=False)
M, edges = np.histogram(x2, bins=np.arange(980,1250,1), density=False)

N2 = N[(N > 0) & (M > 0)]
M2 = M[(N > 0) & (M > 0)]

diff_score = np.mean(np.abs(N2/np.sum(N)-M2/np.sum(M)) / (np.sqrt(N2)/np.sum(N) + np.sqrt(M2)/np.sum(M) ))

print(diff_score)

N = len(df_test.loc[ ((df_test.type == 'tritrig') | (df_test.type == 'wab')) & (df_test.InvM < (1.019 + 0.01) )  & (df_test.InvM > (1.019 - 0.01) ) & ( df_test['Class_adv']>per ) ] )
S = len(df_test.loc[ (df_test.type == 'phiKK') & (df_test.InvM < (1.019 + 0.01) )  & (df_test.InvM > (1.019 - 0.01) ) & ( df_test['Class_adv']>per )  ] )

print(S/N)
# Out:
# 0.724505264597927
# 0.7653846153846153

# %%
df_test["Class_adv"] = test_pred

# %%
# Save the adversarially trained models
torch.save(final_clas_adv.state_dict(), "/Users/mghrear/data/ML_data/2019_pass2/models/FakeGen_classifier_adv_2019_pass2_run"+str(run)+"_unscaled.pt")
torch.save(final_adv_adv.state_dict(), "/Users/mghrear/data/ML_data/2019_pass2/models/FakeGen_adversary_adv_2019_pass2_run"+str(run)+"_unscaled.pt")

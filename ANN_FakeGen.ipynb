# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import torch 
from torch import nn, optim
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import sklearn
from sklearn.model_selection import train_test_split
import copy
import mytools


# Print and store device being used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cpu

# %% [markdown]
# # Define important parameters

# %%
# Number of class in invariant mass used by the adversary
Num_classes = 5
# Hyper-parameter for adversarial training of the classifier
lambda_ = 100.0

run = 1

# %% [markdown]
# # Load and setup the data

# %%
df_tritrig = pd.read_pickle('/Users/mghrear/data/ML_data/2019_pass2/unscaled/2019_pass2_tritrig.pk')
df_tritrig['PhiKK'] = 0.0
df_phiKK = pd.read_pickle('/Users/mghrear/data/ML_data/2019_pass2/unscaled/2019_pass2_FakeGen_1pt05_kaon.pk')
df_phiKK['PhiKK'] = 1.0
df_wab = pd.read_pickle('/Users/mghrear/data/ML_data/2019_pass2/unscaled/2019_pass2_wab.pk')
df_wab['PhiKK'] = 0.0 # Add label


print("tritrig: ", len(df_tritrig))
print("phiKK: ", len(df_phiKK))
print("wab: ", len(df_wab))
# Out:
# tritrig:  149433
# phiKK:  83372
# wab:  16422

# %%
# Make Training set
tritrig_train = df_tritrig[0:50000]
wab_train = df_wab[0:6000]
phiKK_train = df_phiKK[0:5000]

# Combine and shuffle all training data
df_train = pd.concat([tritrig_train, phiKK_train, wab_train], ignore_index=True, sort=False)
df_train = df_train.sample(frac=1, random_state=42).reset_index(drop=True)

one_hot_edges = np.load("one_hot_edges.npy")

# Split the training data into training and validation sets
df_train, df_val = train_test_split(df_train, test_size=0.33, random_state=42)

# Make X and y for training and validation sets
# the adverserial network has its own labels
X_train = df_train.drop(columns=['PhiKK'])
y_train = df_train['PhiKK']
y_adv_train = mytools.get_adv_labels( mytools.get_InvM(df_train), one_hot_edges)
X_val = df_val.drop(columns=['PhiKK'])
y_val = df_val['PhiKK']
y_adv_val = mytools.get_adv_labels( mytools.get_InvM(df_val), one_hot_edges)

# Make testing set with remaining events
tritrig_test = df_tritrig[50000:]
tritrig_test['type']= 'tritrig'
wab_test = df_wab[6000:]
wab_test['type']= 'wab'
phiKK_test = df_phiKK[5000:]
phiKK_test['type']= 'phiKK'

df_test = pd.concat([tritrig_test, phiKK_test,wab_test], ignore_index=True, sort=False)
df_test = df_test.sample(frac=1, random_state=42).reset_index(drop=True) # Now shuffle the combined dataframe

X_test = df_test.drop(columns=['PhiKK','type'])
y_test = df_test['PhiKK']
y_adv_test = mytools.get_adv_labels( mytools.get_InvM(df_test), one_hot_edges)

df_test["InvM"] = mytools.get_InvM(df_test)
# Out:
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_33616/2924921926.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tritrig_test['type']= 'tritrig'
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_33616/2924921926.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wab_test['type']= 'wab'
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_33616/2924921926.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phiKK_test['type']= 'phiKK'

# %% [markdown]
# ## Setup dataloaders

# %%
bsize = 2000

# Convert to tensor dataset and dataloader
train_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy().astype(np.float32))  , torch.from_numpy(y_train.to_numpy().astype(np.float32)).unsqueeze(1)  )
train_loader = DataLoader(train_dataset, batch_size=bsize, shuffle=True)

val_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy().astype(np.float32))  , torch.from_numpy(y_val.to_numpy().astype(np.float32)).unsqueeze(1)  )
val_loader = DataLoader(val_dataset, batch_size=bsize, shuffle=True)

test_dataset = TensorDataset(torch.from_numpy(X_test.to_numpy().astype(np.float32)))
test_loader = DataLoader(test_dataset, batch_size=bsize, shuffle=False)

# %% [markdown]
# ## Initialize model, objective function, and optimizer

# %%
clas = mytools.Classifier(in_features=X_train.shape[1]).to(device)
criterion_clas = nn.BCEWithLogitsLoss()
optimizer_clas = optim.Adam(clas.parameters(), lr=1e-5)
scheduler_clas = torch.optim.lr_scheduler.ExponentialLR(optimizer_clas, gamma=0.9999)

# %% [markdown]
# ## Pre-train the classifier

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 10

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 2500
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train_clas(train_loader, clas, criterion_clas, optimizer_clas, scheduler_clas, device))
    Validation_losses = np.append(Validation_losses, mytools.validate_clas(val_loader, clas, criterion_clas, device))
    
    # Keep a running copy of the model with the lowest loss
    if Validation_losses[-1] == np.min(Validation_losses):
        final_classifier = copy.deepcopy(clas)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Training loss: 0.767362
# Validation loss: 0.839344
#
# Epoch 2
# -------------------------------
# Training loss: 0.726891
# Validation loss: 0.749037
#
# Epoch 3
# -------------------------------
# Training loss: 0.703151
# Validation loss: 0.679043
#
# Epoch 4
# -------------------------------
# Training loss: 0.683104
# Validation loss: 0.673885
#
# Epoch 5
# -------------------------------
# Training loss: 0.666469
# Validation loss: 0.665406
#
# Epoch 6
# -------------------------------
# Training loss: 0.650447
# Validation loss: 0.652949
#
# Epoch 7
# -------------------------------
# Training loss: 0.637952
# Validation loss: 0.628258
#
# Epoch 8
# -------------------------------
# Training loss: 0.624550
# Validation loss: 0.628720
#
# Epoch 9
# -------------------------------
# Training loss: 0.615260
# Validation loss: 0.619499
#
# Epoch 10
# -------------------------------
# Training loss: 0.604441
# Validation loss: 0.601107
#
# Epoch 11
# -------------------------------
# Training loss: 0.596226
# Validation loss: 0.593555
#
# Epoch 12
# -------------------------------
# Training loss: 0.589578
# Validation loss: 0.587597
#
# Epoch 13
# -------------------------------
# Training loss: 0.581294
# Validation loss: 0.585522
#
# Epoch 14
# -------------------------------
# Training loss: 0.576619
# Validation loss: 0.580759
#
# Epoch 15
# -------------------------------
# Training loss: 0.568929
# Validation loss: 0.574576
#
# Epoch 16
# -------------------------------
# Training loss: 0.563703
# Validation loss: 0.566985
#
# Epoch 17
# -------------------------------
# Training loss: 0.557924
# Validation loss: 0.563404
#
# Epoch 18
# -------------------------------
# Training loss: 0.550629
# Validation loss: 0.557234
#
# Epoch 19
# -------------------------------
# Training loss: 0.546857
# Validation loss: 0.556890
#
# Epoch 20
# -------------------------------
# Training loss: 0.541145
# Validation loss: 0.543313
#
# Epoch 21
# -------------------------------
# Training loss: 0.536433
# Validation loss: 0.537196
#
# Epoch 22
# -------------------------------
# Training loss: 0.531853
# Validation loss: 0.538646
#
# Epoch 23
# -------------------------------
# Training loss: 0.527584
# Validation loss: 0.528503
#
# Epoch 24
# -------------------------------
# Training loss: 0.522886
# Validation loss: 0.528963
#
# Epoch 25
# -------------------------------
# Training loss: 0.519101
# Validation loss: 0.521356
#
# Epoch 26
# -------------------------------
# Training loss: 0.515782
# Validation loss: 0.515614
#
# Epoch 27
# -------------------------------
# Training loss: 0.511781
# Validation loss: 0.510311
#
# Epoch 28
# -------------------------------
# Training loss: 0.510366
# Validation loss: 0.509486
#
# Epoch 29
# -------------------------------
# Training loss: 0.504509
# Validation loss: 0.514980
#
# Epoch 30
# -------------------------------
# Training loss: 0.502142
# Validation loss: 0.500941
#
# Epoch 31
# -------------------------------
# Training loss: 0.498352
# Validation loss: 0.500706
#
# Epoch 32
# -------------------------------
# Training loss: 0.494550
# Validation loss: 0.499478
#
# Epoch 33
# -------------------------------
# Training loss: 0.491732
# Validation loss: 0.496106
#
# Epoch 34
# -------------------------------
# Training loss: 0.489295
# Validation loss: 0.494722
#
# Epoch 35
# -------------------------------
# Training loss: 0.485206
# Validation loss: 0.489500
#
# Epoch 36
# -------------------------------
# Training loss: 0.483762
# Validation loss: 0.485000
#
# Epoch 37
# -------------------------------
# Training loss: 0.479506
# Validation loss: 0.481742
#
# Epoch 38
# -------------------------------
# Training loss: 0.477638
# Validation loss: 0.481791
#
# Epoch 39
# -------------------------------
# Training loss: 0.476456
# Validation loss: 0.478205
#
# Epoch 40
# -------------------------------
# Training loss: 0.471752
# Validation loss: 0.475853
#
# Epoch 41
# -------------------------------
# Training loss: 0.470251
# Validation loss: 0.475401
#
# Epoch 42
# -------------------------------
# Training loss: 0.469004
# Validation loss: 0.468086
#
# Epoch 43
# -------------------------------
# Training loss: 0.464893
# Validation loss: 0.468799
#
# Epoch 44
# -------------------------------
# Training loss: 0.462410
# Validation loss: 0.470608
#
# Epoch 45
# -------------------------------
# Training loss: 0.460766
# Validation loss: 0.466160
#
# Epoch 46
# -------------------------------
# Training loss: 0.461301
# Validation loss: 0.466012
#
# Epoch 47
# -------------------------------
# Training loss: 0.457044
# Validation loss: 0.455918
#
# Epoch 48
# -------------------------------
# Training loss: 0.455072
# Validation loss: 0.459987
#
# Epoch 49
# -------------------------------
# Training loss: 0.454188
# Validation loss: 0.459044
#
# Epoch 50
# -------------------------------
# Training loss: 0.450744
# Validation loss: 0.456011
#
# Epoch 51
# -------------------------------
# Training loss: 0.451148
# Validation loss: 0.452192
#
# Epoch 52
# -------------------------------
# Training loss: 0.445331
# Validation loss: 0.448469
#
# Epoch 53
# -------------------------------
# Training loss: 0.444724
# Validation loss: 0.453518
#
# Epoch 54
# -------------------------------
# Training loss: 0.444025
# Validation loss: 0.441759
#
# Epoch 55
# -------------------------------
# Training loss: 0.443873
# Validation loss: 0.446415
#
# Epoch 56
# -------------------------------
# Training loss: 0.438645
# Validation loss: 0.442213
#
# Epoch 57
# -------------------------------
# Training loss: 0.436774
# Validation loss: 0.442816
#
# Epoch 58
# -------------------------------
# Training loss: 0.437868
# Validation loss: 0.437081
#
# Epoch 59
# -------------------------------
# Training loss: 0.434955
# Validation loss: 0.431807
#
# Epoch 60
# -------------------------------
# Training loss: 0.431065
# Validation loss: 0.433710
#
# Epoch 61
# -------------------------------
# Training loss: 0.431985
# Validation loss: 0.426530
#
# Epoch 62
# -------------------------------
# Training loss: 0.429322
# Validation loss: 0.437792
#
# Epoch 63
# -------------------------------
# Training loss: 0.428480
# Validation loss: 0.430529
#
# Epoch 64
# -------------------------------
# Training loss: 0.424979
# Validation loss: 0.428608
#
# Epoch 65
# -------------------------------
# Training loss: 0.424357
# Validation loss: 0.425118
#
# Epoch 66
# -------------------------------
# Training loss: 0.423041
# Validation loss: 0.427157
#
# Epoch 67
# -------------------------------
# Training loss: 0.420448
# Validation loss: 0.424556
#
# Epoch 68
# -------------------------------
# Training loss: 0.419336
# Validation loss: 0.418077
#
# Epoch 69
# -------------------------------
# Training loss: 0.418224
# Validation loss: 0.417141
#
# Epoch 70
# -------------------------------
# Training loss: 0.414579
# Validation loss: 0.414149
#
# Epoch 71
# -------------------------------
# Training loss: 0.415251
# Validation loss: 0.416571
#
# Epoch 72
# -------------------------------
# Training loss: 0.412634
# Validation loss: 0.419276
#
# Epoch 73
# -------------------------------
# Training loss: 0.411295
# Validation loss: 0.413891
#
# Epoch 74
# -------------------------------
# Training loss: 0.409573
# Validation loss: 0.415217
#
# Epoch 75
# -------------------------------
# Training loss: 0.408105
# Validation loss: 0.412922
#
# Epoch 76
# -------------------------------
# Training loss: 0.408234
# Validation loss: 0.415399
#
# Epoch 77
# -------------------------------
# Training loss: 0.405643
# Validation loss: 0.406819
#
# Epoch 78
# -------------------------------
# Training loss: 0.405235
# Validation loss: 0.407648
#
# Epoch 79
# -------------------------------
# Training loss: 0.403259
# Validation loss: 0.406250
#
# Epoch 80
# -------------------------------
# Training loss: 0.402315
# Validation loss: 0.408537
#
# Epoch 81
# -------------------------------
# Training loss: 0.401631
# Validation loss: 0.401006
#
# Epoch 82
# -------------------------------
# Training loss: 0.398612
# Validation loss: 0.408828
#
# Epoch 83
# -------------------------------
# Training loss: 0.397976
# Validation loss: 0.402327
#
# Epoch 84
# -------------------------------
# Training loss: 0.396607
# Validation loss: 0.397667
#
# Epoch 85
# -------------------------------
# Training loss: 0.396815
# Validation loss: 0.407565
#
# Epoch 86
# -------------------------------
# Training loss: 0.393827
# Validation loss: 0.393070
#
# Epoch 87
# -------------------------------
# Training loss: 0.391275
# Validation loss: 0.398015
#
# Epoch 88
# -------------------------------
# Training loss: 0.392625
# Validation loss: 0.393815
#
# Epoch 89
# -------------------------------
# Training loss: 0.391498
# Validation loss: 0.393716
#
# Epoch 90
# -------------------------------
# Training loss: 0.389363
# Validation loss: 0.389283
#
# Epoch 91
# -------------------------------
# Training loss: 0.389119
# Validation loss: 0.387700
#
# Epoch 92
# -------------------------------
# Training loss: 0.387283
# Validation loss: 0.389261
#
# Epoch 93
# -------------------------------
# Training loss: 0.384753
# Validation loss: 0.385313
#
# Epoch 94
# -------------------------------
# Training loss: 0.384686
# Validation loss: 0.390167
#
# Epoch 95
# -------------------------------
# Training loss: 0.383815
# Validation loss: 0.382834
#
# Epoch 96
# -------------------------------
# Training loss: 0.381090
# Validation loss: 0.376629
#
# Epoch 97
# -------------------------------
# Training loss: 0.381097
# Validation loss: 0.382340
#
# Epoch 98
# -------------------------------
# Training loss: 0.379976
# Validation loss: 0.392928
#
# Epoch 99
# -------------------------------
# Training loss: 0.378683
# Validation loss: 0.384846
#
# Epoch 100
# -------------------------------
# Training loss: 0.377169
# Validation loss: 0.375958
#
# Epoch 101
# -------------------------------
# Training loss: 0.376003
# Validation loss: 0.379257
#
# Epoch 102
# -------------------------------
# Training loss: 0.374968
# Validation loss: 0.381232
#
# Epoch 103
# -------------------------------
# Training loss: 0.374376
# Validation loss: 0.374562
#
# Epoch 104
# -------------------------------
# Training loss: 0.374382
# Validation loss: 0.370817
#
# Epoch 105
# -------------------------------
# Training loss: 0.371308
# Validation loss: 0.372905
#
# Epoch 106
# -------------------------------
# Training loss: 0.370679
# Validation loss: 0.368980
#
# Epoch 107
# -------------------------------
# Training loss: 0.371377
# Validation loss: 0.374176
#
# Epoch 108
# -------------------------------
# Training loss: 0.367866
# Validation loss: 0.375685
#
# Epoch 109
# -------------------------------
# Training loss: 0.367417
# Validation loss: 0.368785
#
# Epoch 110
# -------------------------------
# Training loss: 0.367241
# Validation loss: 0.369003
#
# Epoch 111
# -------------------------------
# Training loss: 0.365885
# Validation loss: 0.375534
#
# Epoch 112
# -------------------------------
# Training loss: 0.364568
# Validation loss: 0.369858
#
# Epoch 113
# -------------------------------
# Training loss: 0.365147
# Validation loss: 0.361738
#
# Epoch 114
# -------------------------------
# Training loss: 0.362539
# Validation loss: 0.359512
#
# Epoch 115
# -------------------------------
# Training loss: 0.361517
# Validation loss: 0.362063
#
# Epoch 116
# -------------------------------
# Training loss: 0.359372
# Validation loss: 0.364871
#
# Epoch 117
# -------------------------------
# Training loss: 0.359516
# Validation loss: 0.357721
#
# Epoch 118
# -------------------------------
# Training loss: 0.357407
# Validation loss: 0.361760
#
# Epoch 119
# -------------------------------
# Training loss: 0.357899
# Validation loss: 0.365183
#
# Epoch 120
# -------------------------------
# Training loss: 0.356814
# Validation loss: 0.373898
#
# Epoch 121
# -------------------------------
# Training loss: 0.355720
# Validation loss: 0.363779
#
# Epoch 122
# -------------------------------
# Training loss: 0.354802
# Validation loss: 0.364248
#
# Epoch 123
# -------------------------------
# Training loss: 0.354536
# Validation loss: 0.355001
#
# Epoch 124
# -------------------------------
# Training loss: 0.351857
# Validation loss: 0.361861
#
# Epoch 125
# -------------------------------
# Training loss: 0.351645
# Validation loss: 0.361512
#
# Epoch 126
# -------------------------------
# Training loss: 0.349629
# Validation loss: 0.349136
#
# Epoch 127
# -------------------------------
# Training loss: 0.347137
# Validation loss: 0.348726
#
# Epoch 128
# -------------------------------
# Training loss: 0.347943
# Validation loss: 0.352847
#
# Epoch 129
# -------------------------------
# Training loss: 0.346045
# Validation loss: 0.349698
#
# Epoch 130
# -------------------------------
# Training loss: 0.345710
# Validation loss: 0.352897
#
# Epoch 131
# -------------------------------
# Training loss: 0.344310
# Validation loss: 0.344396
#
# Epoch 132
# -------------------------------
# Training loss: 0.344500
# Validation loss: 0.348085
#
# Epoch 133
# -------------------------------
# Training loss: 0.343526
# Validation loss: 0.357022
#
# Epoch 134
# -------------------------------
# Training loss: 0.342446
# Validation loss: 0.346713
#
# Epoch 135
# -------------------------------
# Training loss: 0.341291
# Validation loss: 0.348704
#
# Epoch 136
# -------------------------------
# Training loss: 0.340051
# Validation loss: 0.346204
#
# Epoch 137
# -------------------------------
# Training loss: 0.339164
# Validation loss: 0.340554
#
# Epoch 138
# -------------------------------
# Training loss: 0.338056
# Validation loss: 0.346006
#
# Epoch 139
# -------------------------------
# Training loss: 0.337573
# Validation loss: 0.345138
#
# Epoch 140
# -------------------------------
# Training loss: 0.335943
# Validation loss: 0.337993
#
# Epoch 141
# -------------------------------
# Training loss: 0.336606
# Validation loss: 0.333006
#
# Epoch 142
# -------------------------------
# Training loss: 0.335163
# Validation loss: 0.341849
#
# Epoch 143
# -------------------------------
# Training loss: 0.334147
# Validation loss: 0.338848
#
# Epoch 144
# -------------------------------
# Training loss: 0.332145
# Validation loss: 0.332485
#
# Epoch 145
# -------------------------------
# Training loss: 0.331471
# Validation loss: 0.337245
#
# Epoch 146
# -------------------------------
# Training loss: 0.330641
# Validation loss: 0.335840
#
# Epoch 147
# -------------------------------
# Training loss: 0.329297
# Validation loss: 0.333447
#
# Epoch 148
# -------------------------------
# Training loss: 0.329884
# Validation loss: 0.332913
#
# Epoch 149
# -------------------------------
# Training loss: 0.327530
# Validation loss: 0.333232
#
# Epoch 150
# -------------------------------
# Training loss: 0.325918
# Validation loss: 0.332474
#
# Epoch 151
# -------------------------------
# Training loss: 0.326138
# Validation loss: 0.338267
#
# Epoch 152
# -------------------------------
# Training loss: 0.325481
# Validation loss: 0.326397
#
# Epoch 153
# -------------------------------
# Training loss: 0.324044
# Validation loss: 0.334305
#
# Epoch 154
# -------------------------------
# Training loss: 0.323676
# Validation loss: 0.339683
#
# Epoch 155
# -------------------------------
# Training loss: 0.323331
# Validation loss: 0.326178
#
# Epoch 156
# -------------------------------
# Training loss: 0.321256
# Validation loss: 0.329586
#
# Epoch 157
# -------------------------------
# Training loss: 0.320342
# Validation loss: 0.320829
#
# Epoch 158
# -------------------------------
# Training loss: 0.318665
# Validation loss: 0.323513
#
# Epoch 159
# -------------------------------
# Training loss: 0.318599
# Validation loss: 0.321303
#
# Epoch 160
# -------------------------------
# Training loss: 0.318370
# Validation loss: 0.337073
#
# Epoch 161
# -------------------------------
# Training loss: 0.319859
# Validation loss: 0.330332
#
# Epoch 162
# -------------------------------
# Training loss: 0.317714
# Validation loss: 0.330497
#
# Epoch 163
# -------------------------------
# Training loss: 0.316371
# Validation loss: 0.323452
#
# Epoch 164
# -------------------------------
# Training loss: 0.315147
# Validation loss: 0.322388
#
# Epoch 165
# -------------------------------
# Training loss: 0.313729
# Validation loss: 0.320927
#
# Epoch 166
# -------------------------------
# Training loss: 0.313813
# Validation loss: 0.317051
#
# Epoch 167
# -------------------------------
# Training loss: 0.311913
# Validation loss: 0.319877
#
# Epoch 168
# -------------------------------
# Training loss: 0.311206
# Validation loss: 0.313447
#
# Epoch 169
# -------------------------------
# Training loss: 0.311421
# Validation loss: 0.315442
#
# Epoch 170
# -------------------------------
# Training loss: 0.309627
# Validation loss: 0.311776
#
# Epoch 171
# -------------------------------
# Training loss: 0.308980
# Validation loss: 0.320262
#
# Epoch 172
# -------------------------------
# Training loss: 0.307570
# Validation loss: 0.309284
#
# Epoch 173
# -------------------------------
# Training loss: 0.306815
# Validation loss: 0.316145
#
# Epoch 174
# -------------------------------
# Training loss: 0.306674
# Validation loss: 0.318057
#
# Epoch 175
# -------------------------------
# Training loss: 0.305168
# Validation loss: 0.305517
#
# Epoch 176
# -------------------------------
# Training loss: 0.304963
# Validation loss: 0.310614
#
# Epoch 177
# -------------------------------
# Training loss: 0.305466
# Validation loss: 0.317798
#
# Epoch 178
# -------------------------------
# Training loss: 0.302736
# Validation loss: 0.306553
#
# Epoch 179
# -------------------------------
# Training loss: 0.301323
# Validation loss: 0.308072
#
# Epoch 180
# -------------------------------
# Training loss: 0.301573
# Validation loss: 0.308496
#
# Epoch 181
# -------------------------------
# Training loss: 0.300319
# Validation loss: 0.310821
#
# Epoch 182
# -------------------------------
# Training loss: 0.299208
# Validation loss: 0.299881
#
# Epoch 183
# -------------------------------
# Training loss: 0.297284
# Validation loss: 0.312599
#
# Epoch 184
# -------------------------------
# Training loss: 0.297443
# Validation loss: 0.300372
#
# Epoch 185
# -------------------------------
# Training loss: 0.300292
# Validation loss: 0.295818
#
# Epoch 186
# -------------------------------
# Training loss: 0.297101
# Validation loss: 0.303626
#
# Epoch 187
# -------------------------------
# Training loss: 0.295389
# Validation loss: 0.299862
#
# Epoch 188
# -------------------------------
# Training loss: 0.294417
# Validation loss: 0.297730
#
# Epoch 189
# -------------------------------
# Training loss: 0.294591
# Validation loss: 0.302634
#
# Epoch 190
# -------------------------------
# Training loss: 0.291094
# Validation loss: 0.296884
#
# Epoch 191
# -------------------------------
# Training loss: 0.291275
# Validation loss: 0.296792
#
# Epoch 192
# -------------------------------
# Training loss: 0.290441
# Validation loss: 0.297159
#
# Epoch 193
# -------------------------------
# Training loss: 0.289141
# Validation loss: 0.283367
#
# Epoch 194
# -------------------------------
# Training loss: 0.288542
# Validation loss: 0.294326
#
# Epoch 195
# -------------------------------
# Training loss: 0.286932
# Validation loss: 0.291234
#
# Epoch 196
# -------------------------------
# Training loss: 0.288894
# Validation loss: 0.283492
#
# Epoch 197
# -------------------------------
# Training loss: 0.287766
# Validation loss: 0.297097
#
# Epoch 198
# -------------------------------
# Training loss: 0.286364
# Validation loss: 0.298310
#
# Epoch 199
# -------------------------------
# Training loss: 0.284194
# Validation loss: 0.300593
#
# Epoch 200
# -------------------------------
# Training loss: 0.285682
# Validation loss: 0.284672
#
# Epoch 201
# -------------------------------
# Training loss: 0.282108
# Validation loss: 0.283026
#
# Epoch 202
# -------------------------------
# Training loss: 0.283333
# Validation loss: 0.286124
#
# Epoch 203
# -------------------------------
# Training loss: 0.282458
# Validation loss: 0.285662
#
# Epoch 204
# -------------------------------
# Training loss: 0.280083
# Validation loss: 0.290584
#
# Epoch 205
# -------------------------------
# Training loss: 0.278842
# Validation loss: 0.287269
#
# Epoch 206
# -------------------------------
# Training loss: 0.278252
# Validation loss: 0.282859
#
# Epoch 207
# -------------------------------
# Training loss: 0.276783
# Validation loss: 0.290330
#
# Epoch 208
# -------------------------------
# Training loss: 0.276060
# Validation loss: 0.286951
#
# Epoch 209
# -------------------------------
# Training loss: 0.277438
# Validation loss: 0.273429
#
# Epoch 210
# -------------------------------
# Training loss: 0.275947
# Validation loss: 0.299761
#
# Epoch 211
# -------------------------------
# Training loss: 0.277117
# Validation loss: 0.284085
#
# Epoch 212
# -------------------------------
# Training loss: 0.273379
# Validation loss: 0.286317
#
# Epoch 213
# -------------------------------
# Training loss: 0.274240
# Validation loss: 0.269168
#
# Epoch 214
# -------------------------------
# Training loss: 0.273605
# Validation loss: 0.276169
#
# Epoch 215
# -------------------------------
# Training loss: 0.275111
# Validation loss: 0.270828
#
# Epoch 216
# -------------------------------
# Training loss: 0.271967
# Validation loss: 0.296253
#
# Epoch 217
# -------------------------------
# Training loss: 0.270734
# Validation loss: 0.278547
#
# Epoch 218
# -------------------------------
# Training loss: 0.269109
# Validation loss: 0.271702
#
# Epoch 219
# -------------------------------
# Training loss: 0.269051
# Validation loss: 0.276403
#
# Epoch 220
# -------------------------------
# Training loss: 0.266678
# Validation loss: 0.269411
#
# Epoch 221
# -------------------------------
# Training loss: 0.267632
# Validation loss: 0.263802
#
# Epoch 222
# -------------------------------
# Training loss: 0.266613
# Validation loss: 0.270777
#
# Epoch 223
# -------------------------------
# Training loss: 0.263210
# Validation loss: 0.274490
#
# Epoch 224
# -------------------------------
# Training loss: 0.262936
# Validation loss: 0.267736
#
# Epoch 225
# -------------------------------
# Training loss: 0.262225
# Validation loss: 0.274664
#
# Epoch 226
# -------------------------------
# Training loss: 0.260336
# Validation loss: 0.265525
#
# Epoch 227
# -------------------------------
# Training loss: 0.262043
# Validation loss: 0.258632
#
# Epoch 228
# -------------------------------
# Training loss: 0.259462
# Validation loss: 0.278413
#
# Epoch 229
# -------------------------------
# Training loss: 0.260314
# Validation loss: 0.271052
#
# Epoch 230
# -------------------------------
# Training loss: 0.261953
# Validation loss: 0.263080
#
# Epoch 231
# -------------------------------
# Training loss: 0.258193
# Validation loss: 0.258805
#
# Epoch 232
# -------------------------------
# Training loss: 0.256301
# Validation loss: 0.262291
#
# Epoch 233
# -------------------------------
# Training loss: 0.257214
# Validation loss: 0.265609
#
# Epoch 234
# -------------------------------
# Training loss: 0.255465
# Validation loss: 0.253659
#
# Epoch 235
# -------------------------------
# Training loss: 0.254034
# Validation loss: 0.259853
#
# Epoch 236
# -------------------------------
# Training loss: 0.253656
# Validation loss: 0.253941
#
# Epoch 237
# -------------------------------
# Training loss: 0.252619
# Validation loss: 0.245781
#
# Epoch 238
# -------------------------------
# Training loss: 0.252904
# Validation loss: 0.250588
#
# Epoch 239
# -------------------------------
# Training loss: 0.251810
# Validation loss: 0.276798
#
# Epoch 240
# -------------------------------
# Training loss: 0.250421
# Validation loss: 0.278758
#
# Epoch 241
# -------------------------------
# Training loss: 0.252425
# Validation loss: 0.241311
#
# Epoch 242
# -------------------------------
# Training loss: 0.249771
# Validation loss: 0.240707
#
# Epoch 243
# -------------------------------
# Training loss: 0.250162
# Validation loss: 0.245221
#
# Epoch 244
# -------------------------------
# Training loss: 0.249200
# Validation loss: 0.251041
#
# Epoch 245
# -------------------------------
# Training loss: 0.245459
# Validation loss: 0.249991
#
# Epoch 246
# -------------------------------
# Training loss: 0.245815
# Validation loss: 0.245390
#
# Epoch 247
# -------------------------------
# Training loss: 0.244503
# Validation loss: 0.237156
#
# Epoch 248
# -------------------------------
# Training loss: 0.245722
# Validation loss: 0.265633
#
# Epoch 249
# -------------------------------
# Training loss: 0.243055
# Validation loss: 0.276816
#
# Epoch 250
# -------------------------------
# Training loss: 0.244781
# Validation loss: 0.251672
#
# Epoch 251
# -------------------------------
# Training loss: 0.243280
# Validation loss: 0.253764
#
# Epoch 252
# -------------------------------
# Training loss: 0.241223
# Validation loss: 0.256367
#
# Epoch 253
# -------------------------------
# Training loss: 0.243824
# Validation loss: 0.237968
#
# Epoch 254
# -------------------------------
# Training loss: 0.240363
# Validation loss: 0.243388
#
# Epoch 255
# -------------------------------
# Training loss: 0.238732
# Validation loss: 0.236981
#
# Epoch 256
# -------------------------------
# Training loss: 0.237368
# Validation loss: 0.240193
#
# Epoch 257
# -------------------------------
# Training loss: 0.237050
# Validation loss: 0.243145
#
# Epoch 258
# -------------------------------
# Training loss: 0.239328
# Validation loss: 0.247119
#
# Epoch 259
# -------------------------------
# Training loss: 0.239308
# Validation loss: 0.236325
#
# Epoch 260
# -------------------------------
# Training loss: 0.237566
# Validation loss: 0.238820
#
# Epoch 261
# -------------------------------
# Training loss: 0.234017
# Validation loss: 0.231599
#
# Epoch 262
# -------------------------------
# Training loss: 0.233710
# Validation loss: 0.243122
#
# Epoch 263
# -------------------------------
# Training loss: 0.232297
# Validation loss: 0.238563
#
# Epoch 264
# -------------------------------
# Training loss: 0.231267
# Validation loss: 0.229011
#
# Epoch 265
# -------------------------------
# Training loss: 0.231199
# Validation loss: 0.233130
#
# Epoch 266
# -------------------------------
# Training loss: 0.232522
# Validation loss: 0.223406
#
# Epoch 267
# -------------------------------
# Training loss: 0.232519
# Validation loss: 0.238257
#
# Epoch 268
# -------------------------------
# Training loss: 0.228590
# Validation loss: 0.230822
#
# Epoch 269
# -------------------------------
# Training loss: 0.227607
# Validation loss: 0.229310
#
# Epoch 270
# -------------------------------
# Training loss: 0.227555
# Validation loss: 0.229417
#
# Epoch 271
# -------------------------------
# Training loss: 0.226636
# Validation loss: 0.222938
#
# Epoch 272
# -------------------------------
# Training loss: 0.227368
# Validation loss: 0.234872
#
# Epoch 273
# -------------------------------
# Training loss: 0.226208
# Validation loss: 0.223621
#
# Epoch 274
# -------------------------------
# Training loss: 0.226043
# Validation loss: 0.215164
#
# Epoch 275
# -------------------------------
# Training loss: 0.224180
# Validation loss: 0.216886
#
# Epoch 276
# -------------------------------
# Training loss: 0.223476
# Validation loss: 0.237409
#
# Epoch 277
# -------------------------------
# Training loss: 0.222833
# Validation loss: 0.216316
#
# Epoch 278
# -------------------------------
# Training loss: 0.223134
# Validation loss: 0.223671
#
# Epoch 279
# -------------------------------
# Training loss: 0.225219
# Validation loss: 0.217044
#
# Epoch 280
# -------------------------------
# Training loss: 0.224405
# Validation loss: 0.229299
#
# Epoch 281
# -------------------------------
# Training loss: 0.223596
# Validation loss: 0.234864
#
# Epoch 282
# -------------------------------
# Training loss: 0.220843
# Validation loss: 0.227692
#
# Epoch 283
# -------------------------------
# Training loss: 0.218965
# Validation loss: 0.225922
#
# Epoch 284
# -------------------------------
# Training loss: 0.218125
# Validation loss: 0.227622
#
# Epoch 285
# -------------------------------
# Training loss: 0.220071
# Validation loss: 0.226405
#
# Epoch 286
# -------------------------------
# Training loss: 0.219066
# Validation loss: 0.227097
#
# Epoch 287
# -------------------------------
# Training loss: 0.218338
# Validation loss: 0.227362
#
# Epoch 288
# -------------------------------
# Training loss: 0.217045
# Validation loss: 0.219799
#
# Epoch 289
# -------------------------------
# Training loss: 0.215662
# Validation loss: 0.225475
#
# Epoch 290
# -------------------------------
# Training loss: 0.213071
# Validation loss: 0.207585
#
# Epoch 291
# -------------------------------
# Training loss: 0.217147
# Validation loss: 0.217406
#
# Epoch 292
# -------------------------------
# Training loss: 0.214369
# Validation loss: 0.223755
#
# Epoch 293
# -------------------------------
# Training loss: 0.213766
# Validation loss: 0.255641
#
# Epoch 294
# -------------------------------
# Training loss: 0.213876
# Validation loss: 0.209703
#
# Epoch 295
# -------------------------------
# Training loss: 0.213223
# Validation loss: 0.213757
#
# Epoch 296
# -------------------------------
# Training loss: 0.210584
# Validation loss: 0.226661
#
# Epoch 297
# -------------------------------
# Training loss: 0.212523
# Validation loss: 0.249485
#
# Epoch 298
# -------------------------------
# Training loss: 0.213484
# Validation loss: 0.224668
#
# Epoch 299
# -------------------------------
# Training loss: 0.209890
# Validation loss: 0.211895
#
# Epoch 300
# -------------------------------
# Training loss: 0.210427
# Validation loss: 0.210824
#
# Epoch 301
# -------------------------------
# Training loss: 0.208489
# Validation loss: 0.211858
#
# Epoch 302
# -------------------------------
# Training loss: 0.208129
# Validation loss: 0.210661
#
# Epoch 303
# -------------------------------
# Training loss: 0.207629
# Validation loss: 0.203080
#
# Epoch 304
# -------------------------------
# Training loss: 0.206841
# Validation loss: 0.226622
#
# Epoch 305
# -------------------------------
# Training loss: 0.207172
# Validation loss: 0.211564
#
# Epoch 306
# -------------------------------
# Training loss: 0.209132
# Validation loss: 0.207857
#
# Epoch 307
# -------------------------------
# Training loss: 0.206086
# Validation loss: 0.214216
#
# Epoch 308
# -------------------------------
# Training loss: 0.208241
# Validation loss: 0.200473
#
# Epoch 309
# -------------------------------
# Training loss: 0.205572
# Validation loss: 0.209812
#
# Epoch 310
# -------------------------------
# Training loss: 0.204088
# Validation loss: 0.198158
#
# Epoch 311
# -------------------------------
# Training loss: 0.203137
# Validation loss: 0.224838
#
# Epoch 312
# -------------------------------
# Training loss: 0.204234
# Validation loss: 0.200769
#
# Epoch 313
# -------------------------------
# Training loss: 0.200584
# Validation loss: 0.200558
#
# Epoch 314
# -------------------------------
# Training loss: 0.199719
# Validation loss: 0.203792
#
# Epoch 315
# -------------------------------
# Training loss: 0.201410
# Validation loss: 0.200189
#
# Epoch 316
# -------------------------------
# Training loss: 0.201665
# Validation loss: 0.213105
#
# Epoch 317
# -------------------------------
# Training loss: 0.200316
# Validation loss: 0.200523
#
# Epoch 318
# -------------------------------
# Training loss: 0.198564
# Validation loss: 0.208382
#
# Epoch 319
# -------------------------------
# Training loss: 0.200567
# Validation loss: 0.203770
#
# Epoch 320
# -------------------------------
# Training loss: 0.202151
# Validation loss: 0.203828
#
# Epoch 321
# -------------------------------
# Training loss: 0.198773
# Validation loss: 0.202904
#
# Epoch 322
# -------------------------------
# Training loss: 0.197918
# Validation loss: 0.198371
#
# Epoch 323
# -------------------------------
# Training loss: 0.199560
# Validation loss: 0.195347
#
# Epoch 324
# -------------------------------
# Training loss: 0.198962
# Validation loss: 0.219860
#
# Epoch 325
# -------------------------------
# Training loss: 0.195552
# Validation loss: 0.200205
#
# Epoch 326
# -------------------------------
# Training loss: 0.196410
# Validation loss: 0.193724
#
# Epoch 327
# -------------------------------
# Training loss: 0.195294
# Validation loss: 0.194342
#
# Epoch 328
# -------------------------------
# Training loss: 0.194036
# Validation loss: 0.192099
#
# Epoch 329
# -------------------------------
# Training loss: 0.199550
# Validation loss: 0.239843
#
# Epoch 330
# -------------------------------
# Training loss: 0.195137
# Validation loss: 0.220776
#
# Epoch 331
# -------------------------------
# Training loss: 0.192359
# Validation loss: 0.192095
#
# Epoch 332
# -------------------------------
# Training loss: 0.193162
# Validation loss: 0.189263
#
# Epoch 333
# -------------------------------
# Training loss: 0.194169
# Validation loss: 0.191904
#
# Epoch 334
# -------------------------------
# Training loss: 0.191196
# Validation loss: 0.197174
#
# Epoch 335
# -------------------------------
# Training loss: 0.191684
# Validation loss: 0.188505
#
# Epoch 336
# -------------------------------
# Training loss: 0.190780
# Validation loss: 0.187765
#
# Epoch 337
# -------------------------------
# Training loss: 0.193616
# Validation loss: 0.209680
#
# Epoch 338
# -------------------------------
# Training loss: 0.192241
# Validation loss: 0.190669
#
# Epoch 339
# -------------------------------
# Training loss: 0.190637
# Validation loss: 0.187097
#
# Epoch 340
# -------------------------------
# Training loss: 0.189081
# Validation loss: 0.186304
#
# Epoch 341
# -------------------------------
# Training loss: 0.189684
# Validation loss: 0.202073
#
# Epoch 342
# -------------------------------
# Training loss: 0.191668
# Validation loss: 0.191405
#
# Epoch 343
# -------------------------------
# Training loss: 0.187377
# Validation loss: 0.190923
#
# Epoch 344
# -------------------------------
# Training loss: 0.189287
# Validation loss: 0.188135
#
# Epoch 345
# -------------------------------
# Training loss: 0.186223
# Validation loss: 0.185526
#
# Epoch 346
# -------------------------------
# Training loss: 0.185293
# Validation loss: 0.187416
#
# Epoch 347
# -------------------------------
# Training loss: 0.183967
# Validation loss: 0.198352
#
# Epoch 348
# -------------------------------
# Training loss: 0.187440
# Validation loss: 0.186321
#
# Epoch 349
# -------------------------------
# Training loss: 0.186437
# Validation loss: 0.184451
#
# Epoch 350
# -------------------------------
# Training loss: 0.185271
# Validation loss: 0.202192
#
# Epoch 351
# -------------------------------
# Training loss: 0.186124
# Validation loss: 0.179416
#
# Epoch 352
# -------------------------------
# Training loss: 0.184398
# Validation loss: 0.245900
#
# Epoch 353
# -------------------------------
# Training loss: 0.185115
# Validation loss: 0.186178
#
# Epoch 354
# -------------------------------
# Training loss: 0.182268
# Validation loss: 0.180877
#
# Epoch 355
# -------------------------------
# Training loss: 0.180452
# Validation loss: 0.180891
#
# Epoch 356
# -------------------------------
# Training loss: 0.182062
# Validation loss: 0.174620
#
# Epoch 357
# -------------------------------
# Training loss: 0.183135
# Validation loss: 0.180057
#
# Epoch 358
# -------------------------------
# Training loss: 0.181087
# Validation loss: 0.217844
#
# Epoch 359
# -------------------------------
# Training loss: 0.183640
# Validation loss: 0.175681
#
# Epoch 360
# -------------------------------
# Training loss: 0.184276
# Validation loss: 0.197728
#
# Epoch 361
# -------------------------------
# Training loss: 0.183110
# Validation loss: 0.186952
#
# Epoch 362
# -------------------------------
# Training loss: 0.179617
# Validation loss: 0.205193
#
# Epoch 363
# -------------------------------
# Training loss: 0.177229
# Validation loss: 0.180255
#
# Epoch 364
# -------------------------------
# Training loss: 0.178207
# Validation loss: 0.175993
#
# Epoch 365
# -------------------------------
# Training loss: 0.180041
# Validation loss: 0.178523
#
# Epoch 366
# -------------------------------
# Training loss: 0.179084
# Validation loss: 0.188094
#
# Epoch 367
# -------------------------------
# Training loss: 0.179968
# Validation loss: 0.172298
#
# Epoch 368
# -------------------------------
# Training loss: 0.176893
# Validation loss: 0.177707
#
# Epoch 369
# -------------------------------
# Training loss: 0.176238
# Validation loss: 0.177622
#
# Epoch 370
# -------------------------------
# Training loss: 0.174953
# Validation loss: 0.367705
#
# Epoch 371
# -------------------------------
# Training loss: 0.175875
# Validation loss: 0.187111
#
# Epoch 372
# -------------------------------
# Training loss: 0.176598
# Validation loss: 0.295565
#
# Epoch 373
# -------------------------------
# Training loss: 0.175320
# Validation loss: 0.173109
#
# Epoch 374
# -------------------------------
# Training loss: 0.173911
# Validation loss: 0.174096
#
# Epoch 375
# -------------------------------
# Training loss: 0.172292
# Validation loss: 0.179524
#
# Epoch 376
# -------------------------------
# Training loss: 0.176500
# Validation loss: 0.170810
#
# Epoch 377
# -------------------------------
# Training loss: 0.175297
# Validation loss: 0.238487
#
# Epoch 378
# -------------------------------
# Training loss: 0.174296
# Validation loss: 0.186893
#
# Epoch 379
# -------------------------------
# Training loss: 0.171990
# Validation loss: 0.203276
#
# Epoch 380
# -------------------------------
# Training loss: 0.170818
# Validation loss: 0.168446
#
# Epoch 381
# -------------------------------
# Training loss: 0.170925
# Validation loss: 0.170140
#
# Epoch 382
# -------------------------------
# Training loss: 0.171801
# Validation loss: 0.178308
#
# Epoch 383
# -------------------------------
# Training loss: 0.174138
# Validation loss: 0.177697
#
# Epoch 384
# -------------------------------
# Training loss: 0.169995
# Validation loss: 0.184035
#
# Epoch 385
# -------------------------------
# Training loss: 0.170903
# Validation loss: 0.179755
#
# Epoch 386
# -------------------------------
# Training loss: 0.168433
# Validation loss: 0.172739
#
# Epoch 387
# -------------------------------
# Training loss: 0.168335
# Validation loss: 0.171803
#
# Epoch 388
# -------------------------------
# Training loss: 0.169470
# Validation loss: 0.164028
#
# Epoch 389
# -------------------------------
# Training loss: 0.169001
# Validation loss: 0.160801
#
# Epoch 390
# -------------------------------
# Training loss: 0.166694
# Validation loss: 0.209486
#
# Epoch 391
# -------------------------------
# Training loss: 0.169863
# Validation loss: 0.169058
#
# Epoch 392
# -------------------------------
# Training loss: 0.165615
# Validation loss: 0.169107
#
# Epoch 393
# -------------------------------
# Training loss: 0.167001
# Validation loss: 0.210954
#
# Epoch 394
# -------------------------------
# Training loss: 0.168757
# Validation loss: 0.164561
#
# Epoch 395
# -------------------------------
# Training loss: 0.167623
# Validation loss: 0.221075
#
# Epoch 396
# -------------------------------
# Training loss: 0.168329
# Validation loss: 0.235818
#
# Epoch 397
# -------------------------------
# Training loss: 0.170759
# Validation loss: 0.170685
#
# Epoch 398
# -------------------------------
# Training loss: 0.167666
# Validation loss: 0.159254
#
# Epoch 399
# -------------------------------
# Training loss: 0.165921
# Validation loss: 0.188881
#
# Epoch 400
# -------------------------------
# Training loss: 0.164063
# Validation loss: 0.166690
#
# Epoch 401
# -------------------------------
# Training loss: 0.163589
# Validation loss: 0.164602
#
# Epoch 402
# -------------------------------
# Training loss: 0.162992
# Validation loss: 0.164090
#
# Epoch 403
# -------------------------------
# Training loss: 0.162549
# Validation loss: 0.158391
#
# Epoch 404
# -------------------------------
# Training loss: 0.163265
# Validation loss: 0.162209
#
# Epoch 405
# -------------------------------
# Training loss: 0.166375
# Validation loss: 0.164550
#
# Epoch 406
# -------------------------------
# Training loss: 0.161936
# Validation loss: 0.160174
#
# Epoch 407
# -------------------------------
# Training loss: 0.161781
# Validation loss: 0.254922
#
# Epoch 408
# -------------------------------
# Training loss: 0.162001
# Validation loss: 0.153690
#
# Epoch 409
# -------------------------------
# Training loss: 0.160616
# Validation loss: 0.200689
#
# Epoch 410
# -------------------------------
# Training loss: 0.162083
# Validation loss: 0.184984
#
# Epoch 411
# -------------------------------
# Training loss: 0.162573
# Validation loss: 0.167062
#
# Epoch 412
# -------------------------------
# Training loss: 0.167349
# Validation loss: 0.163717
#
# Epoch 413
# -------------------------------
# Training loss: 0.161416
# Validation loss: 0.158593
#
# Epoch 414
# -------------------------------
# Training loss: 0.159550
# Validation loss: 0.169609
#
# Epoch 415
# -------------------------------
# Training loss: 0.163613
# Validation loss: 0.182606
#
# Epoch 416
# -------------------------------
# Training loss: 0.160444
# Validation loss: 0.192555
#
# Epoch 417
# -------------------------------
# Training loss: 0.160885
# Validation loss: 0.154040
#
# Epoch 418
# -------------------------------
# Training loss: 0.159749
# Validation loss: 0.155430
#
# Epoch 419
# -------------------------------
# Training loss: 0.157218
# Validation loss: 0.166198
#
# Epoch 420
# -------------------------------
# Training loss: 0.161421
# Validation loss: 0.153186
#
# Epoch 421
# -------------------------------
# Training loss: 0.158083
# Validation loss: 0.154375
#
# Epoch 422
# -------------------------------
# Training loss: 0.156377
# Validation loss: 0.157324
#
# Epoch 423
# -------------------------------
# Training loss: 0.159377
# Validation loss: 0.157355
#
# Epoch 424
# -------------------------------
# Training loss: 0.156053
# Validation loss: 0.172658
#
# Epoch 425
# -------------------------------
# Training loss: 0.158545
# Validation loss: 0.170370
#
# Epoch 426
# -------------------------------
# Training loss: 0.156391
# Validation loss: 0.202977
#
# Epoch 427
# -------------------------------
# Training loss: 0.156303
# Validation loss: 0.154019
#
# Epoch 428
# -------------------------------
# Training loss: 0.156302
# Validation loss: 0.165863
#
# Epoch 429
# -------------------------------
# Training loss: 0.155028
# Validation loss: 0.150571
#
# Epoch 430
# -------------------------------
# Training loss: 0.154336
# Validation loss: 0.151942
#
# Epoch 431
# -------------------------------
# Training loss: 0.157001
# Validation loss: 0.145243
#
# Epoch 432
# -------------------------------
# Training loss: 0.154415
# Validation loss: 0.150065
#
# Epoch 433
# -------------------------------
# Training loss: 0.152333
# Validation loss: 0.173557
#
# Epoch 434
# -------------------------------
# Training loss: 0.151446
# Validation loss: 0.153013
#
# Epoch 435
# -------------------------------
# Training loss: 0.153195
# Validation loss: 0.156778
#
# Epoch 436
# -------------------------------
# Training loss: 0.152823
# Validation loss: 0.149719
#
# Epoch 437
# -------------------------------
# Training loss: 0.151024
# Validation loss: 0.150918
#
# Epoch 438
# -------------------------------
# Training loss: 0.151246
# Validation loss: 0.150337
#
# Epoch 439
# -------------------------------
# Training loss: 0.151399
# Validation loss: 0.150999
#
# Epoch 440
# -------------------------------
# Training loss: 0.150897
# Validation loss: 0.164737
#
# Epoch 441
# -------------------------------
# Training loss: 0.151832
# Validation loss: 0.148288
#
# Epoch 442
# -------------------------------
# Training loss: 0.151564
# Validation loss: 0.221054
#
# Epoch 443
# -------------------------------
# Training loss: 0.157841
# Validation loss: 0.148328
#
# Epoch 444
# -------------------------------
# Training loss: 0.149243
# Validation loss: 0.151103
#
# Epoch 445
# -------------------------------
# Training loss: 0.150730
# Validation loss: 0.148671
#
# Epoch 446
# -------------------------------
# Training loss: 0.147260
# Validation loss: 0.157909
#
# Epoch 447
# -------------------------------
# Training loss: 0.149457
# Validation loss: 0.156471
#
# Epoch 448
# -------------------------------
# Training loss: 0.150181
# Validation loss: 0.153503
#
# Epoch 449
# -------------------------------
# Training loss: 0.151397
# Validation loss: 0.285125
#
# Epoch 450
# -------------------------------
# Training loss: 0.147487
# Validation loss: 0.143209
#
# Epoch 451
# -------------------------------
# Training loss: 0.150038
# Validation loss: 0.195583
#
# Epoch 452
# -------------------------------
# Training loss: 0.149134
# Validation loss: 0.156056
#
# Epoch 453
# -------------------------------
# Training loss: 0.150106
# Validation loss: 0.291666
#
# Epoch 454
# -------------------------------
# Training loss: 0.147651
# Validation loss: 0.139694
#
# Epoch 455
# -------------------------------
# Training loss: 0.148292
# Validation loss: 0.149913
#
# Epoch 456
# -------------------------------
# Training loss: 0.146052
# Validation loss: 0.149075
#
# Epoch 457
# -------------------------------
# Training loss: 0.144707
# Validation loss: 0.171984
#
# Epoch 458
# -------------------------------
# Training loss: 0.148085
# Validation loss: 0.139495
#
# Epoch 459
# -------------------------------
# Training loss: 0.145867
# Validation loss: 0.147697
#
# Epoch 460
# -------------------------------
# Training loss: 0.147277
# Validation loss: 0.244924
#
# Epoch 461
# -------------------------------
# Training loss: 0.145510
# Validation loss: 0.170752
#
# Epoch 462
# -------------------------------
# Training loss: 0.149808
# Validation loss: 0.139516
#
# Epoch 463
# -------------------------------
# Training loss: 0.145002
# Validation loss: 0.147050
#
# Epoch 464
# -------------------------------
# Training loss: 0.143766
# Validation loss: 0.145456
#
# Epoch 465
# -------------------------------
# Training loss: 0.144006
# Validation loss: 0.140984
#
# Epoch 466
# -------------------------------
# Training loss: 0.144631
# Validation loss: 0.168061
#
# Epoch 467
# -------------------------------
# Training loss: 0.144786
# Validation loss: 0.146353
#
# Epoch 468
# -------------------------------
# Training loss: 0.144854
# Validation loss: 0.138903
#
# Epoch 469
# -------------------------------
# Training loss: 0.143089
# Validation loss: 0.192599
#
# Epoch 470
# -------------------------------
# Training loss: 0.141312
# Validation loss: 0.139405
#
# Epoch 471
# -------------------------------
# Training loss: 0.144824
# Validation loss: 0.208506
#
# Epoch 472
# -------------------------------
# Training loss: 0.144361
# Validation loss: 0.137747
#
# Epoch 473
# -------------------------------
# Training loss: 0.141783
# Validation loss: 0.144475
#
# Epoch 474
# -------------------------------
# Training loss: 0.141384
# Validation loss: 0.191046
#
# Epoch 475
# -------------------------------
# Training loss: 0.140700
# Validation loss: 0.141496
#
# Epoch 476
# -------------------------------
# Training loss: 0.141385
# Validation loss: 0.138044
#
# Epoch 477
# -------------------------------
# Training loss: 0.140977
# Validation loss: 0.133398
#
# Epoch 478
# -------------------------------
# Training loss: 0.139870
# Validation loss: 0.135743
#
# Epoch 479
# -------------------------------
# Training loss: 0.140834
# Validation loss: 0.152167
#
# Epoch 480
# -------------------------------
# Training loss: 0.139803
# Validation loss: 0.145008
#
# Epoch 481
# -------------------------------
# Training loss: 0.136929
# Validation loss: 0.133821
#
# Epoch 482
# -------------------------------
# Training loss: 0.139731
# Validation loss: 0.164568
#
# Epoch 483
# -------------------------------
# Training loss: 0.139005
# Validation loss: 0.137123
#
# Epoch 484
# -------------------------------
# Training loss: 0.139087
# Validation loss: 0.152775
#
# Epoch 485
# -------------------------------
# Training loss: 0.136831
# Validation loss: 0.158682
#
# Epoch 486
# -------------------------------
# Training loss: 0.136998
# Validation loss: 0.136430
#
# Epoch 487
# -------------------------------
# Training loss: 0.138339
# Validation loss: 0.146744
#
# Epoch 488
# -------------------------------
# Training loss: 0.142992
# Validation loss: 0.134037
#
# Epoch 489
# -------------------------------
# Training loss: 0.137914
# Validation loss: 0.134134
#
# Epoch 490
# -------------------------------
# Training loss: 0.136368
# Validation loss: 0.149515
#
# Epoch 491
# -------------------------------
# Training loss: 0.146639
# Validation loss: 0.152353
#
# Epoch 492
# -------------------------------
# Training loss: 0.140203
# Validation loss: 0.132425
#
# Epoch 493
# -------------------------------
# Training loss: 0.136456
# Validation loss: 0.228948
#
# Epoch 494
# -------------------------------
# Training loss: 0.135093
# Validation loss: 0.287417
#
# Epoch 495
# -------------------------------
# Training loss: 0.135340
# Validation loss: 0.159730
#
# Epoch 496
# -------------------------------
# Training loss: 0.134985
# Validation loss: 0.165144
#
# Epoch 497
# -------------------------------
# Training loss: 0.134363
# Validation loss: 0.150146
#
# Epoch 498
# -------------------------------
# Training loss: 0.135423
# Validation loss: 0.134750
#
# Epoch 499
# -------------------------------
# Training loss: 0.135238
# Validation loss: 0.151807
#
# Epoch 500
# -------------------------------
# Training loss: 0.135928
# Validation loss: 0.158094
#
# Epoch 501
# -------------------------------
# Training loss: 0.134122
# Validation loss: 0.127451
#
# Epoch 502
# -------------------------------
# Training loss: 0.135053
# Validation loss: 0.126803
#
# Epoch 503
# -------------------------------
# Training loss: 0.132609
# Validation loss: 0.139044
#
# Epoch 504
# -------------------------------
# Training loss: 0.134202
# Validation loss: 0.127864
#
# Epoch 505
# -------------------------------
# Training loss: 0.136031
# Validation loss: 0.289770
#
# Epoch 506
# -------------------------------
# Training loss: 0.132633
# Validation loss: 0.179373
#
# Epoch 507
# -------------------------------
# Training loss: 0.132237
# Validation loss: 0.135370
#
# Epoch 508
# -------------------------------
# Training loss: 0.132780
# Validation loss: 0.129302
#
# Epoch 509
# -------------------------------
# Training loss: 0.134281
# Validation loss: 0.129372
#
# Epoch 510
# -------------------------------
# Training loss: 0.131455
# Validation loss: 0.147918
#
# Epoch 511
# -------------------------------
# Training loss: 0.130451
# Validation loss: 0.134253
#
# Epoch 512
# -------------------------------
# Training loss: 0.131919
# ...
# Validation loss: 0.057086
#
# Epoch 2333
# -------------------------------
# Training loss: 0.055379
# Validation loss: 0.070814
#
# Epoch 2334
# -------------------------------
# Training loss: 0.053576
# Validation loss: 0.058211
#
# Epoch 2335
# -------------------------------
# Training loss: 0.053816
# Validation loss: 0.056964
#
# Epoch 2336
# -------------------------------
# Training loss: 0.052705
# Validation loss: 0.056524
#
# Epoch 2337
# -------------------------------
# Training loss: 0.053250
# Validation loss: 0.056663
#
# Epoch 2338
# -------------------------------
# Training loss: 0.053292
# Validation loss: 0.055380
#
# Epoch 2339
# -------------------------------
# Training loss: 0.052581
# Validation loss: 0.053262
#
# Epoch 2340
# -------------------------------
# Training loss: 0.053552
# Validation loss: 0.055583
#
# Epoch 2341
# -------------------------------
# Training loss: 0.053226
# Validation loss: 0.056133
#
# Epoch 2342
# -------------------------------
# Training loss: 0.052789
# Validation loss: 0.055198
#
# Epoch 2343
# -------------------------------
# Training loss: 0.054187
# Validation loss: 0.054108
#
# Epoch 2344
# -------------------------------
# Training loss: 0.054985
# Validation loss: 0.063934
#
# Epoch 2345
# -------------------------------
# Training loss: 0.052815
# Validation loss: 0.056765
#
# Epoch 2346
# -------------------------------
# Training loss: 0.054528
# Validation loss: 0.060389
#
# Epoch 2347
# -------------------------------
# Training loss: 0.055853
# Validation loss: 0.073480
#
# Epoch 2348
# -------------------------------
# Training loss: 0.053761
# Validation loss: 0.066695
#
# Epoch 2349
# -------------------------------
# Training loss: 0.053815
# Validation loss: 0.068100
#
# Epoch 2350
# -------------------------------
# Training loss: 0.053763
# Validation loss: 0.055886
#
# Epoch 2351
# -------------------------------
# Training loss: 0.053990
# Validation loss: 0.056472
#
# Epoch 2352
# -------------------------------
# Training loss: 0.052732
# Validation loss: 0.056004
#
# Epoch 2353
# -------------------------------
# Training loss: 0.053658
# Validation loss: 0.057860
#
# Epoch 2354
# -------------------------------
# Training loss: 0.052563
# Validation loss: 0.052440
#
# Epoch 2355
# -------------------------------
# Training loss: 0.053117
# Validation loss: 0.055540
#
# Epoch 2356
# -------------------------------
# Training loss: 0.053539
# Validation loss: 0.056798
#
# Epoch 2357
# -------------------------------
# Training loss: 0.053054
# Validation loss: 0.055189
#
# Epoch 2358
# -------------------------------
# Training loss: 0.052438
# Validation loss: 0.054483
#
# Epoch 2359
# -------------------------------
# Training loss: 0.052848
# Validation loss: 0.053273
#
# Epoch 2360
# -------------------------------
# Training loss: 0.053831
# Validation loss: 0.055763
#
# Epoch 2361
# -------------------------------
# Training loss: 0.054541
# Validation loss: 0.060066
#
# Epoch 2362
# -------------------------------
# Training loss: 0.054164
# Validation loss: 0.057319
#
# Epoch 2363
# -------------------------------
# Training loss: 0.052832
# Validation loss: 0.053945
#
# Epoch 2364
# -------------------------------
# Training loss: 0.053647
# Validation loss: 0.055483
#
# Epoch 2365
# -------------------------------
# Training loss: 0.053144
# Validation loss: 0.057588
#
# Epoch 2366
# -------------------------------
# Training loss: 0.053014
# Validation loss: 0.054455
#
# Epoch 2367
# -------------------------------
# Training loss: 0.053776
# Validation loss: 0.056066
#
# Epoch 2368
# -------------------------------
# Training loss: 0.052883
# Validation loss: 0.054224
#
# Epoch 2369
# -------------------------------
# Training loss: 0.053206
# Validation loss: 0.053514
#
# Epoch 2370
# -------------------------------
# Training loss: 0.052700
# Validation loss: 0.056401
#
# Epoch 2371
# -------------------------------
# Training loss: 0.053656
# Validation loss: 0.055728
#
# Epoch 2372
# -------------------------------
# Training loss: 0.054414
# Validation loss: 0.055172
#
# Epoch 2373
# -------------------------------
# Training loss: 0.052744
# Validation loss: 0.056278
#
# Epoch 2374
# -------------------------------
# Training loss: 0.052955
# Validation loss: 0.055812
#
# Epoch 2375
# -------------------------------
# Training loss: 0.053091
# Validation loss: 0.057458
#
# Epoch 2376
# -------------------------------
# Training loss: 0.054817
# Validation loss: 0.055544
#
# Epoch 2377
# -------------------------------
# Training loss: 0.053714
# Validation loss: 0.055440
#
# Epoch 2378
# -------------------------------
# Training loss: 0.052902
# Validation loss: 0.055620
#
# Epoch 2379
# -------------------------------
# Training loss: 0.052842
# Validation loss: 0.060962
#
# Epoch 2380
# -------------------------------
# Training loss: 0.054391
# Validation loss: 0.060856
#
# Epoch 2381
# -------------------------------
# Training loss: 0.052526
# Validation loss: 0.053319
#
# Epoch 2382
# -------------------------------
# Training loss: 0.059742
# Validation loss: 0.072266
#
# Epoch 2383
# -------------------------------
# Training loss: 0.052522
# Validation loss: 0.054928
#
# Epoch 2384
# -------------------------------
# Training loss: 0.052788
# Validation loss: 0.057909
#
# Epoch 2385
# -------------------------------
# Training loss: 0.054135
# Validation loss: 0.058662
#
# Epoch 2386
# -------------------------------
# Training loss: 0.052862
# Validation loss: 0.053414
#
# Epoch 2387
# -------------------------------
# Training loss: 0.053336
# Validation loss: 0.055666
#
# Epoch 2388
# -------------------------------
# Training loss: 0.054128
# Validation loss: 0.056131
#
# Epoch 2389
# -------------------------------
# Training loss: 0.053876
# Validation loss: 0.058382
#
# Epoch 2390
# -------------------------------
# Training loss: 0.053082
# Validation loss: 0.059280
#
# Epoch 2391
# -------------------------------
# Training loss: 0.055121
# Validation loss: 0.074377
#
# Epoch 2392
# -------------------------------
# Training loss: 0.052690
# Validation loss: 0.059715
#
# Epoch 2393
# -------------------------------
# Training loss: 0.053075
# Validation loss: 0.056448
#
# Epoch 2394
# -------------------------------
# Training loss: 0.052665
# Validation loss: 0.053008
#
# Epoch 2395
# -------------------------------
# Training loss: 0.054450
# Validation loss: 0.056920
#
# Epoch 2396
# -------------------------------
# Training loss: 0.053541
# Validation loss: 0.062656
#
# Epoch 2397
# -------------------------------
# Training loss: 0.052609
# Validation loss: 0.054164
#
# Epoch 2398
# -------------------------------
# Training loss: 0.052482
# Validation loss: 0.054502
#
# Epoch 2399
# -------------------------------
# Training loss: 0.052822
# Validation loss: 0.054721
#
# Epoch 2400
# -------------------------------
# Training loss: 0.053806
# Validation loss: 0.059501
#
# Epoch 2401
# -------------------------------
# Training loss: 0.053655
# Validation loss: 0.055951
#
# Epoch 2402
# -------------------------------
# Training loss: 0.052589
# Validation loss: 0.052867
#
# Epoch 2403
# -------------------------------
# Training loss: 0.053451
# Validation loss: 0.057414
#
# Epoch 2404
# -------------------------------
# Training loss: 0.052771
# Validation loss: 0.053251
#
# Epoch 2405
# -------------------------------
# Training loss: 0.052784
# Validation loss: 0.063531
#
# Epoch 2406
# -------------------------------
# Training loss: 0.052988
# Validation loss: 0.054145
#
# Epoch 2407
# -------------------------------
# Training loss: 0.052052
# Validation loss: 0.053553
#
# Epoch 2408
# -------------------------------
# Training loss: 0.054050
# Validation loss: 0.058714
#
# Epoch 2409
# -------------------------------
# Training loss: 0.053922
# Validation loss: 0.055926
#
# Epoch 2410
# -------------------------------
# Training loss: 0.053995
# Validation loss: 0.073591
#
# Epoch 2411
# -------------------------------
# Training loss: 0.053800
# Validation loss: 0.059940
#
# Epoch 2412
# -------------------------------
# Training loss: 0.053359
# Validation loss: 0.057943
#
# Epoch 2413
# -------------------------------
# Training loss: 0.053376
# Validation loss: 0.057509
#
# Epoch 2414
# -------------------------------
# Training loss: 0.052965
# Validation loss: 0.055033
#
# Epoch 2415
# -------------------------------
# Training loss: 0.053058
# Validation loss: 0.054429
#
# Epoch 2416
# -------------------------------
# Training loss: 0.054103
# Validation loss: 0.060825
#
# Epoch 2417
# -------------------------------
# Training loss: 0.053815
# Validation loss: 0.060463
#
# Epoch 2418
# -------------------------------
# Training loss: 0.052773
# Validation loss: 0.055291
#
# Epoch 2419
# -------------------------------
# Training loss: 0.052930
# Validation loss: 0.052527
#
# Epoch 2420
# -------------------------------
# Training loss: 0.051781
# Validation loss: 0.055178
#
# Epoch 2421
# -------------------------------
# Training loss: 0.052536
# Validation loss: 0.055277
#
# Epoch 2422
# -------------------------------
# Training loss: 0.053368
# Validation loss: 0.054618
#
# Epoch 2423
# -------------------------------
# Training loss: 0.053191
# Validation loss: 0.054542
#
# Epoch 2424
# -------------------------------
# Training loss: 0.052358
# Validation loss: 0.052663
#
# Epoch 2425
# -------------------------------
# Training loss: 0.052803
# Validation loss: 0.056136
#
# Epoch 2426
# -------------------------------
# Training loss: 0.053665
# Validation loss: 0.061127
#
# Epoch 2427
# -------------------------------
# Training loss: 0.052650
# Validation loss: 0.056067
#
# Epoch 2428
# -------------------------------
# Training loss: 0.053973
# Validation loss: 0.062138
#
# Epoch 2429
# -------------------------------
# Training loss: 0.056230
# Validation loss: 0.073009
#
# Epoch 2430
# -------------------------------
# Training loss: 0.052489
# Validation loss: 0.052793
#
# Epoch 2431
# -------------------------------
# Training loss: 0.052793
# Validation loss: 0.053119
#
# Epoch 2432
# -------------------------------
# Training loss: 0.053598
# Validation loss: 0.059983
#
# Epoch 2433
# -------------------------------
# Training loss: 0.053098
# Validation loss: 0.055774
#
# Epoch 2434
# -------------------------------
# Training loss: 0.052940
# Validation loss: 0.054867
#
# Epoch 2435
# -------------------------------
# Training loss: 0.052676
# Validation loss: 0.055577
#
# Epoch 2436
# -------------------------------
# Training loss: 0.053446
# Validation loss: 0.053805
#
# Epoch 2437
# -------------------------------
# Training loss: 0.053437
# Validation loss: 0.061338
#
# Epoch 2438
# -------------------------------
# Training loss: 0.053005
# Validation loss: 0.053767
#
# Epoch 2439
# -------------------------------
# Training loss: 0.053207
# Validation loss: 0.055692
#
# Epoch 2440
# -------------------------------
# Training loss: 0.054678
# Validation loss: 0.065604
#
# Epoch 2441
# -------------------------------
# Training loss: 0.052970
# Validation loss: 0.058158
#
# Epoch 2442
# -------------------------------
# Training loss: 0.053828
# Validation loss: 0.060455
#
# Epoch 2443
# -------------------------------
# Training loss: 0.052446
# Validation loss: 0.056767
#
# Epoch 2444
# -------------------------------
# Training loss: 0.053595
# Validation loss: 0.056552
#
# Epoch 2445
# -------------------------------
# Training loss: 0.054842
# Validation loss: 0.070351
#
# Epoch 2446
# -------------------------------
# Training loss: 0.053062
# Validation loss: 0.053571
#
# Epoch 2447
# -------------------------------
# Training loss: 0.053879
# Validation loss: 0.058050
#
# Epoch 2448
# -------------------------------
# Training loss: 0.053134
# Validation loss: 0.057847
#
# Epoch 2449
# -------------------------------
# Training loss: 0.052601
# Validation loss: 0.056576
#
# Epoch 2450
# -------------------------------
# Training loss: 0.053220
# Validation loss: 0.054036
#
# Epoch 2451
# -------------------------------
# Training loss: 0.053082
# Validation loss: 0.058072
#
# Epoch 2452
# -------------------------------
# Training loss: 0.053169
# Validation loss: 0.057207
#
# Epoch 2453
# -------------------------------
# Training loss: 0.054701
# Validation loss: 0.055695
#
# Epoch 2454
# -------------------------------
# Training loss: 0.053906
# Validation loss: 0.059428
#
# Epoch 2455
# -------------------------------
# Training loss: 0.060909
# Validation loss: 0.075525
#
# Epoch 2456
# -------------------------------
# Training loss: 0.053553
# Validation loss: 0.058768
#
# Epoch 2457
# -------------------------------
# Training loss: 0.053065
# Validation loss: 0.055895
#
# Epoch 2458
# -------------------------------
# Training loss: 0.052942
# Validation loss: 0.054329
#
# Epoch 2459
# -------------------------------
# Training loss: 0.053758
# Validation loss: 0.055498
#
# Epoch 2460
# -------------------------------
# Training loss: 0.053537
# Validation loss: 0.055498
#
# Epoch 2461
# -------------------------------
# Training loss: 0.052701
# Validation loss: 0.052249
#
# Epoch 2462
# -------------------------------
# Training loss: 0.052984
# Validation loss: 0.060446
#
# Epoch 2463
# -------------------------------
# Training loss: 0.053848
# Validation loss: 0.056929
#
# Epoch 2464
# -------------------------------
# Training loss: 0.053877
# Validation loss: 0.064653
#
# Epoch 2465
# -------------------------------
# Training loss: 0.052895
# Validation loss: 0.055901
#
# Epoch 2466
# -------------------------------
# Training loss: 0.052511
# Validation loss: 0.058433
#
# Epoch 2467
# -------------------------------
# Training loss: 0.053513
# Validation loss: 0.056573
#
# Epoch 2468
# -------------------------------
# Training loss: 0.053592
# Validation loss: 0.059920
#
# Epoch 2469
# -------------------------------
# Training loss: 0.052553
# Validation loss: 0.053637
#
# Epoch 2470
# -------------------------------
# Training loss: 0.053733
# Validation loss: 0.056237
#
# Epoch 2471
# -------------------------------
# Training loss: 0.053148
# Validation loss: 0.057058
#
# Epoch 2472
# -------------------------------
# Training loss: 0.053163
# Validation loss: 0.056953
#
# Epoch 2473
# -------------------------------
# Training loss: 0.052640
# Validation loss: 0.053683
#
# Epoch 2474
# -------------------------------
# Training loss: 0.052650
# Validation loss: 0.053529
#
# Epoch 2475
# -------------------------------
# Training loss: 0.053137
# Validation loss: 0.056016
#
# Epoch 2476
# -------------------------------
# Training loss: 0.053215
# Validation loss: 0.054841
#
# Epoch 2477
# -------------------------------
# Training loss: 0.053290
# Validation loss: 0.055146
#
# Epoch 2478
# -------------------------------
# Training loss: 0.052452
# Validation loss: 0.056713
#
# Epoch 2479
# -------------------------------
# Training loss: 0.053328
# Validation loss: 0.055600
#
# Epoch 2480
# -------------------------------
# Training loss: 0.053201
# Validation loss: 0.057960
#
# Epoch 2481
# -------------------------------
# Training loss: 0.052606
# Validation loss: 0.054945
#
# Epoch 2482
# -------------------------------
# Training loss: 0.053399
# Validation loss: 0.056150
#
# Epoch 2483
# -------------------------------
# Training loss: 0.053147
# Validation loss: 0.057166
#
# Epoch 2484
# -------------------------------
# Training loss: 0.052930
# Validation loss: 0.054647
#
# Epoch 2485
# -------------------------------
# Training loss: 0.052157
# Validation loss: 0.051820
#
# Epoch 2486
# -------------------------------
# Training loss: 0.052765
# Validation loss: 0.054061
#
# Epoch 2487
# -------------------------------
# Training loss: 0.052293
# Validation loss: 0.056622
#
# Epoch 2488
# -------------------------------
# Training loss: 0.052861
# Validation loss: 0.056626
#
# Epoch 2489
# -------------------------------
# Training loss: 0.052831
# Validation loss: 0.053905
#
# Epoch 2490
# -------------------------------
# Training loss: 0.052652
# Validation loss: 0.054542
#
# Epoch 2491
# -------------------------------
# Training loss: 0.053314
# Validation loss: 0.054583
#
# Epoch 2492
# -------------------------------
# Training loss: 0.053764
# Validation loss: 0.059679
#
# Epoch 2493
# -------------------------------
# Training loss: 0.052148
# Validation loss: 0.052927
#
# Epoch 2494
# -------------------------------
# Training loss: 0.052876
# Validation loss: 0.053451
#
# Epoch 2495
# -------------------------------
# Training loss: 0.054305
# Validation loss: 0.060845
#
# Epoch 2496
# -------------------------------
# Training loss: 0.052954
# Validation loss: 0.054243
#
# Epoch 2497
# -------------------------------
# Training loss: 0.052684
# Validation loss: 0.052641
#
# Epoch 2498
# -------------------------------
# Training loss: 0.054104
# Validation loss: 0.060161
#
# Epoch 2499
# -------------------------------
# Training loss: 0.052413
# Validation loss: 0.055422
#
# Epoch 2500
# -------------------------------
# Training loss: 0.054155
# Validation loss: 0.062484
#
# Done!

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses)+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('BCE Loss')
#plt.yscale('log')
plt.legend()

# %%
# Now test the pretrained model
test_pred = mytools.test_clas(test_loader, final_classifier, device)
test_pred=torch.sigmoid(torch.tensor(test_pred)).numpy()


fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test, test_pred, pos_label=1)
auc_test = sklearn.metrics.auc(fpr, tpr)
print(f'Test AUROC: {auc_test:0.4f}')

plt.plot(fpr, tpr, label=f'Test AUROC: {auc_test:0.4f}')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
# Out:
# Test AUROC: 0.9981

# %%
# Store the pretrained classifier labels
df_test["Class_pre"] = test_pred

# Save the pretrained classifier model
torch.save(final_classifier.state_dict(), "/Users/mghrear/data/ML_data/2019_pass2/models/pretrained_FakeGen_classifier_2019_pass2_run"+str(run)+"_unscaled.pt")

# %% [markdown]
# # Setup the adversary model

# %% [markdown]
# ## Initialize model, objective function, and optimizer

# %%
adv = mytools.Adversary(n_classes=Num_classes).to(device)
criterion_adv = nn.CrossEntropyLoss(reduction='none')  # returns loss per sample so we can weight it
opt_adv = torch.optim.Adam(adv.parameters(), lr=1e-5)
scheduler_adv = torch.optim.lr_scheduler.ExponentialLR(opt_adv, gamma=0.999)

# %% [markdown]
# ## Setup dataloaders

# %%
# Convert to tensor dataset and dataloader

# the structure is: feature, adversary label, weight
# The wight is 1 for tritrig and wab, and 0 for phiKK, to prevent the adversary from learning on phiKK events

train_adv_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_train), (torch.from_numpy(y_train.to_numpy().astype(np.float32))==0).float())
train_adv_loader = DataLoader(train_adv_dataset, batch_size=bsize, shuffle=True)

val_adv_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_val), (torch.from_numpy(y_val.to_numpy().astype(np.float32))==0).float() )
val_adv_loader = DataLoader(val_adv_dataset, batch_size=bsize, shuffle=True)

# Weights are not relavent for testing
test_adv_dataset = TensorDataset(torch.from_numpy(X_test.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_test))
test_adv_loader = DataLoader(test_adv_dataset, batch_size=bsize, shuffle=True)

# %% [markdown]
# ## Pre-train the adversary leaving classifier weights fixed

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 6

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 100
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train_adv(train_adv_loader, final_classifier, adv, criterion_adv, opt_adv, scheduler_adv, device))
    Validation_losses = np.append(Validation_losses, mytools.validate_adv(val_adv_loader, final_classifier, adv, criterion_adv, device))
    
    # Keep a running copy of the model with the lowest loss
    if Validation_losses[-1] == np.min(Validation_losses):
        final_adv = copy.deepcopy(adv)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Training loss: 1.610940
# Validation loss: 1.612033
#
# Epoch 2
# -------------------------------
# Training loss: 1.599831
# Validation loss: 1.610875
#
# Epoch 3
# -------------------------------
# Training loss: 1.592424
# Validation loss: 1.592722
#
# Epoch 4
# -------------------------------
# Training loss: 1.587876
# Validation loss: 1.589993
#
# Epoch 5
# -------------------------------
# Training loss: 1.583779
# Validation loss: 1.584307
#
# Epoch 6
# -------------------------------
# Training loss: 1.580561
# Validation loss: 1.581247
#
# Epoch 7
# -------------------------------
# Training loss: 1.578177
# Validation loss: 1.579342
#
# Epoch 8
# -------------------------------
# Training loss: 1.575175
# Validation loss: 1.577563
#
# Epoch 9
# -------------------------------
# Training loss: 1.572625
# Validation loss: 1.571848
#
# Epoch 10
# -------------------------------
# Training loss: 1.570749
# Validation loss: 1.574116
#
# Epoch 11
# -------------------------------
# Training loss: 1.568578
# Validation loss: 1.572476
#
# Epoch 12
# -------------------------------
# Training loss: 1.567484
# Validation loss: 1.571130
#
# Epoch 13
# -------------------------------
# Training loss: 1.567010
# Validation loss: 1.572200
#
# Epoch 14
# -------------------------------
# Training loss: 1.565823
# Validation loss: 1.566616
#
# Epoch 15
# -------------------------------
# Training loss: 1.564846
# Validation loss: 1.567623
#
# Epoch 16
# -------------------------------
# Training loss: 1.564400
# Validation loss: 1.567011
#
# Epoch 17
# -------------------------------
# Training loss: 1.563353
# Validation loss: 1.567253
#
# Epoch 18
# -------------------------------
# Training loss: 1.563074
# Validation loss: 1.563615
#
# Epoch 19
# -------------------------------
# Training loss: 1.562170
# Validation loss: 1.569987
#
# Epoch 20
# -------------------------------
# Training loss: 1.562195
# Validation loss: 1.564597
#
# Epoch 21
# -------------------------------
# Training loss: 1.561688
# Validation loss: 1.564973
#
# Epoch 22
# -------------------------------
# Training loss: 1.561326
# Validation loss: 1.567394
#
# Epoch 23
# -------------------------------
# Training loss: 1.561547
# Validation loss: 1.564601
#
# Epoch 24
# -------------------------------
# Training loss: 1.561065
# Validation loss: 1.565196
#
# Epoch 25
# -------------------------------
# Training loss: 1.560768
# Validation loss: 1.565354
#
# Epoch 26
# -------------------------------
# Training loss: 1.560193
# Validation loss: 1.564599
#
# Epoch 27
# -------------------------------
# Training loss: 1.560296
# Validation loss: 1.562616
#
# Epoch 28
# -------------------------------
# Training loss: 1.559358
# Validation loss: 1.562476
#
# Epoch 29
# -------------------------------
# Training loss: 1.559475
# Validation loss: 1.563694
#
# Epoch 30
# -------------------------------
# Training loss: 1.559027
# Validation loss: 1.564907
#
# Epoch 31
# -------------------------------
# Training loss: 1.558443
# Validation loss: 1.559756
#
# Epoch 32
# -------------------------------
# Training loss: 1.558761
# Validation loss: 1.562700
#
# Epoch 33
# -------------------------------
# Training loss: 1.558578
# Validation loss: 1.561992
#
# Epoch 34
# -------------------------------
# Training loss: 1.558233
# Validation loss: 1.561871
#
# Epoch 35
# -------------------------------
# Training loss: 1.558678
# Validation loss: 1.562342
#
# Epoch 36
# -------------------------------
# Training loss: 1.557643
# Validation loss: 1.562332
#
# Epoch 37
# -------------------------------
# Training loss: 1.558198
# Validation loss: 1.560347
#
# Epoch 38
# -------------------------------
# Training loss: 1.557851
# Validation loss: 1.559869
#
# Epoch 39
# -------------------------------
# Training loss: 1.557837
# Validation loss: 1.561091
#
# Epoch 40
# -------------------------------
# Training loss: 1.557420
# Validation loss: 1.563217
#
# Epoch 41
# -------------------------------
# Training loss: 1.557383
# Validation loss: 1.560592
#
# Epoch 42
# -------------------------------
# Training loss: 1.557263
# Validation loss: 1.560235
#
# Epoch 43
# -------------------------------
# Training loss: 1.557066
# Validation loss: 1.558238
#
# Epoch 44
# -------------------------------
# Training loss: 1.557279
# Validation loss: 1.561546
#
# Epoch 45
# -------------------------------
# Training loss: 1.556586
# Validation loss: 1.555763
#
# Epoch 46
# -------------------------------
# Training loss: 1.557037
# Validation loss: 1.561386
#
# Epoch 47
# -------------------------------
# Training loss: 1.557284
# Validation loss: 1.562767
#
# Epoch 48
# -------------------------------
# Training loss: 1.556961
# Validation loss: 1.560560
#
# Epoch 49
# -------------------------------
# Training loss: 1.556591
# Validation loss: 1.559330
#
# Epoch 50
# -------------------------------
# Training loss: 1.556406
# Validation loss: 1.561802
#
# Epoch 51
# -------------------------------
# Training loss: 1.556555
# Validation loss: 1.563007
#
# Epoch 52
# -------------------------------
# Training loss: 1.556692
# Validation loss: 1.561273
#
# Epoch 53
# -------------------------------
# Training loss: 1.556414
# Validation loss: 1.560773
#
# Epoch 54
# -------------------------------
# Training loss: 1.556801
# Validation loss: 1.560456
#
# Epoch 55
# -------------------------------
# Training loss: 1.556046
# Validation loss: 1.562686
#
# Epoch 56
# -------------------------------
# Training loss: 1.556068
# Validation loss: 1.557623
#
# Epoch 57
# -------------------------------
# Training loss: 1.555946
# Validation loss: 1.560413
#
# Epoch 58
# -------------------------------
# Training loss: 1.556382
# Validation loss: 1.556343
#
# Epoch 59
# -------------------------------
# Training loss: 1.555491
# Validation loss: 1.559636
#
# Epoch 60
# -------------------------------
# Training loss: 1.556825
# Validation loss: 1.559823
#
# Epoch 61
# -------------------------------
# Training loss: 1.555961
# Validation loss: 1.558464
#
# Epoch 62
# -------------------------------
# Training loss: 1.556092
# Validation loss: 1.562016
#
# Epoch 63
# -------------------------------
# Training loss: 1.555965
# Validation loss: 1.564639
#
# Epoch 64
# -------------------------------
# Training loss: 1.555502
# Validation loss: 1.557343
#
# Epoch 65
# -------------------------------
# Training loss: 1.556303
# Validation loss: 1.558766
#
# Epoch 66
# -------------------------------
# Training loss: 1.555332
# Validation loss: 1.559882
#
# Epoch 67
# -------------------------------
# Training loss: 1.555680
# Validation loss: 1.561703
#
# Epoch 68
# -------------------------------
# Training loss: 1.555691
# Validation loss: 1.564526
#
# Epoch 69
# -------------------------------
# Training loss: 1.555306
# Validation loss: 1.558260
#
# Epoch 70
# -------------------------------
# Training loss: 1.555854
# Validation loss: 1.556958
#
# Epoch 71
# -------------------------------
# Training loss: 1.555653
# Validation loss: 1.560896
#
# Epoch 72
# -------------------------------
# Training loss: 1.555506
# Validation loss: 1.562686
#
# Epoch 73
# -------------------------------
# Training loss: 1.555594
# Validation loss: 1.557572
#
# Epoch 74
# -------------------------------
# Training loss: 1.554799
# Validation loss: 1.559937
#
# Epoch 75
# -------------------------------
# Training loss: 1.555579
# Validation loss: 1.553891
#
# Epoch 76
# -------------------------------
# Training loss: 1.555670
# Validation loss: 1.559114
#
# Epoch 77
# -------------------------------
# Training loss: 1.555667
# Validation loss: 1.562041
#
# Epoch 78
# -------------------------------
# Training loss: 1.555322
# Validation loss: 1.561145
#
# Epoch 79
# -------------------------------
# Training loss: 1.555744
# Validation loss: 1.559690
#
# Epoch 80
# -------------------------------
# Training loss: 1.555795
# Validation loss: 1.561007
#
# Epoch 81
# -------------------------------
# Training loss: 1.555285
# Validation loss: 1.557759
#
# Epoch 82
# -------------------------------
# Training loss: 1.555131
# Validation loss: 1.557269
#
# Epoch 83
# -------------------------------
# Training loss: 1.555033
# Validation loss: 1.561869
#
# Epoch 84
# -------------------------------
# Training loss: 1.555441
# Validation loss: 1.563532
#
# Epoch 85
# -------------------------------
# Training loss: 1.555100
# Validation loss: 1.560054
#
# Epoch 86
# -------------------------------
# Training loss: 1.555573
# Validation loss: 1.559745
#
# Epoch 87
# -------------------------------
# Training loss: 1.555347
# Validation loss: 1.557636
#
# Epoch 88
# -------------------------------
# Training loss: 1.554881
# Validation loss: 1.557245
#
# Epoch 89
# -------------------------------
# Training loss: 1.554466
# Validation loss: 1.559908
#
# Epoch 90
# -------------------------------
# Training loss: 1.555128
# Validation loss: 1.558759
#
# Epoch 91
# -------------------------------
# Training loss: 1.555197
# Validation loss: 1.559573
#
# Epoch 92
# -------------------------------
# Training loss: 1.554760
# Validation loss: 1.557799
#
# Epoch 93
# -------------------------------
# Training loss: 1.555523
# Validation loss: 1.560762
#
# Epoch 94
# -------------------------------
# Training loss: 1.555087
# Validation loss: 1.556621
#
# Epoch 95
# -------------------------------
# Training loss: 1.554734
# Validation loss: 1.556089
#
# Epoch 96
# -------------------------------
# Training loss: 1.555010
# Validation loss: 1.557440
#
# Epoch 97
# -------------------------------
# Training loss: 1.554375
# Validation loss: 1.559896
#
# Epoch 98
# -------------------------------
# Training loss: 1.554635
# Validation loss: 1.558097
#
# Epoch 99
# -------------------------------
# Training loss: 1.555143
# Validation loss: 1.561526
#
# Epoch 100
# -------------------------------
# Training loss: 1.554887
# Validation loss: 1.559936
#
# Done!

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses)+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('BCE Loss')
plt.legend()

# %% [markdown]
# # Train full adverserial neural network

# %% [markdown]
# # Setup dataloaders

# %%
# the structure is: feature, classifier label, adversary label, weight
# The wight is 1 for tritrig and wab, and 0 for phiKK, to prevent the adversary from learning on phiKK events

train_full_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy().astype(np.float32))  , torch.from_numpy(y_train.to_numpy().astype(np.float32)).unsqueeze(1), torch.from_numpy(y_adv_train),  (torch.from_numpy(y_train.to_numpy().astype(np.float32))==0).float())
train_full_loader = DataLoader(train_full_dataset, batch_size=bsize, shuffle=True)

val_full_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy().astype(np.float32))  , torch.from_numpy(y_val.to_numpy().astype(np.float32)).unsqueeze(1),  torch.from_numpy(y_adv_val),  (torch.from_numpy(y_val.to_numpy().astype(np.float32))==0).float())
val_full_loader = DataLoader(val_full_dataset, batch_size=bsize, shuffle=True)

# %% [markdown]
# ## Define loss functions

# %%
BCE_loss = nn.BCEWithLogitsLoss()
CE_loss = nn.CrossEntropyLoss(reduction='none') # returns loss per sample so we can weight it

def full_loss(output_clas, output_adv, target_clas, target_adv, w, lambda_):

    loss1 = BCE_loss(output_clas, target_clas )  # classification loss
    sample_losses2 = CE_loss(output_adv, target_adv)  # adversarial losses, since we set reduction='none', this is now a vector of losses, one per sample in the batch

    # Weighted mean loss over non-zero weights
    nonzero = w > 0
    loss2 = (sample_losses2[nonzero] * w[nonzero]).sum() / w[nonzero].sum()

    loss = loss1 - lambda_*loss2

    return loss

# %% [markdown]
# ## Setup optimizers

# %%
optimizer_clas = optim.Adam(final_classifier.parameters(), lr=1e-7,betas=(0.5, 0.999))
optimizer_adv = optim.Adam(final_adv.parameters(), lr=1e-5,betas=(0.5, 0.999))

scheduler_clas = torch.optim.lr_scheduler.ExponentialLR(optimizer_clas, gamma=0.999)
scheduler_adv = torch.optim.lr_scheduler.ExponentialLR(optimizer_adv, gamma=0.999)

# %% [markdown]
# ## Adversarial training

# %%
Training_losses_clas = np.array([])
Training_losses_adv = np.array([])
Validation_losses_clas = np.array([])
Validation_losses_adv = np.array([])
diff_scores = np.array([])


epochs = 50
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")

    # Get validation losses
    E_clas_val_loss, E_adv_val_loss = mytools.validate_full(val_full_loader, final_classifier, final_adv, full_loss, lambda_, criterion_adv, device)
    Validation_losses_clas = np.append(Validation_losses_clas, E_clas_val_loss)
    Validation_losses_adv = np.append(Validation_losses_adv, E_adv_val_loss)

    # Train adversary and classifier
    E_clas_training_loss , E_adv_training_loss = mytools.train_full(train_full_loader, final_classifier, final_adv, full_loss, lambda_, criterion_adv, optimizer_clas, optimizer_adv, scheduler_clas, scheduler_adv, device)
    Training_losses_clas = np.append(Training_losses_clas, E_clas_training_loss)
    Training_losses_adv = np.append(Training_losses_adv, E_adv_training_loss)

    # Get the diff_score
    df_test["Class_adv"] = mytools.test_clas(test_loader, final_classifier, device)
    df_bkg = df_test.loc[ (df_test.type == 'tritrig') | (df_test.type == 'wab')]
    per = np.percentile(df_bkg['Class_adv'],99)
    df_cut = df_bkg[df_bkg['Class_adv']>per].reset_index(drop=True)
    x1 = 1000* df_bkg.InvM.values
    x2 = 1000*df_cut.InvM.values
    diff_scores = np.append(diff_scores, mytools.get_diff_score(x1,x2) )

    # Keep a running copy of the model with the lowest loss
    if diff_scores[-1] == np.min(diff_scores):
        final_clas_adv = copy.deepcopy(final_classifier)
        final_adv_adv = copy.deepcopy(final_adv)

            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Classifier validation loss: -155.944634
# Adversary validation loss: 1.559970
# Classifier training loss: -157.348442
# Adversary training loss: 1.575505
# Epoch 2
# -------------------------------
# Classifier validation loss: -158.088798
# Adversary validation loss: 1.581463
# Classifier training loss: -159.408459
# Adversary training loss: 1.595939
# Epoch 3
# -------------------------------
# Classifier validation loss: -159.769096
# Adversary validation loss: 1.598429
# Classifier training loss: -160.142496
# Adversary training loss: 1.602738
# Epoch 4
# -------------------------------
# Classifier validation loss: -160.458728
# Adversary validation loss: 1.605382
# Classifier training loss: -160.205985
# Adversary training loss: 1.603114
# Epoch 5
# -------------------------------
# Classifier validation loss: -159.995354
# Adversary validation loss: 1.600870
# Classifier training loss: -159.960556
# Adversary training loss: 1.600625
# Epoch 6
# -------------------------------
# Classifier validation loss: -160.174748
# Adversary validation loss: 1.602583
# Classifier training loss: -160.116336
# Adversary training loss: 1.602149
# Epoch 7
# -------------------------------
# Classifier validation loss: -160.480096
# Adversary validation loss: 1.605759
# Classifier training loss: -160.289107
# Adversary training loss: 1.603874
# Epoch 8
# -------------------------------
# Classifier validation loss: -160.495576
# Adversary validation loss: 1.605777
# Classifier training loss: -160.483479
# Adversary training loss: 1.605820
# Epoch 9
# -------------------------------
# Classifier validation loss: -160.546045
# Adversary validation loss: 1.606379
# Classifier training loss: -160.523088
# Adversary training loss: 1.606123
# Epoch 10
# -------------------------------
# Classifier validation loss: -160.772749
# Adversary validation loss: 1.608539
# Classifier training loss: -160.465003
# Adversary training loss: 1.605502
# Epoch 11
# -------------------------------
# Classifier validation loss: -160.418049
# Adversary validation loss: 1.604995
# Classifier training loss: -160.468573
# Adversary training loss: 1.605526
# Epoch 12
# -------------------------------
# Classifier validation loss: -160.535565
# Adversary validation loss: 1.606166
# Classifier training loss: -160.355135
# Adversary training loss: 1.604399
# Epoch 13
# -------------------------------
# Classifier validation loss: -160.539789
# Adversary validation loss: 1.606427
# Classifier training loss: -160.420375
# Adversary training loss: 1.605095
# Epoch 14
# -------------------------------
# Classifier validation loss: -160.572131
# Adversary validation loss: 1.606590
# Classifier training loss: -160.381020
# Adversary training loss: 1.604660
# Epoch 15
# -------------------------------
# Classifier validation loss: -160.626391
# Adversary validation loss: 1.607133
# Classifier training loss: -160.367457
# Adversary training loss: 1.604534
# Epoch 16
# -------------------------------
# Classifier validation loss: -160.557430
# Adversary validation loss: 1.606501
# Classifier training loss: -160.461584
# Adversary training loss: 1.605478
# Epoch 17
# -------------------------------
# Classifier validation loss: -160.597878
# Adversary validation loss: 1.606780
# Classifier training loss: -160.448019
# Adversary training loss: 1.605322
# Epoch 18
# -------------------------------
# Classifier validation loss: -160.898930
# Adversary validation loss: 1.609778
# Classifier training loss: -160.443247
# Adversary training loss: 1.605264
# Epoch 19
# -------------------------------
# Classifier validation loss: -160.560361
# Adversary validation loss: 1.606385
# Classifier training loss: -160.470772
# Adversary training loss: 1.605530
# Epoch 20
# -------------------------------
# Classifier validation loss: -160.326483
# Adversary validation loss: 1.604012
# Classifier training loss: -160.537843
# Adversary training loss: 1.606184
# Epoch 21
# -------------------------------
# Classifier validation loss: -160.527746
# Adversary validation loss: 1.606015
# Classifier training loss: -160.517892
# Adversary training loss: 1.606003
# Epoch 22
# -------------------------------
# Classifier validation loss: -160.849397
# Adversary validation loss: 1.609481
# Classifier training loss: -160.494545
# Adversary training loss: 1.605782
# Epoch 23
# -------------------------------
# Classifier validation loss: -160.679688
# Adversary validation loss: 1.607635
# Classifier training loss: -160.539877
# Adversary training loss: 1.606222
# Epoch 24
# -------------------------------
# Classifier validation loss: -160.754449
# Adversary validation loss: 1.608395
# Classifier training loss: -160.605358
# Adversary training loss: 1.606872
# Epoch 25
# -------------------------------
# Classifier validation loss: -160.587904
# Adversary validation loss: 1.606744
# Classifier training loss: -160.504146
# Adversary training loss: 1.605834
# Epoch 26
# -------------------------------
# Classifier validation loss: -160.752161
# Adversary validation loss: 1.608332
# Classifier training loss: -160.558166
# Adversary training loss: 1.606420
# Epoch 27
# -------------------------------
# Classifier validation loss: -160.526412
# Adversary validation loss: 1.606080
# Classifier training loss: -160.636316
# Adversary training loss: 1.607166
# Epoch 28
# -------------------------------
# Classifier validation loss: -160.862117
# Adversary validation loss: 1.609463
# Classifier training loss: -160.596365
# Adversary training loss: 1.606769
# Epoch 29
# -------------------------------
# Classifier validation loss: -160.702716
# Adversary validation loss: 1.607870
# Classifier training loss: -160.561347
# Adversary training loss: 1.606423
# Epoch 30
# -------------------------------
# Classifier validation loss: -160.869607
# Adversary validation loss: 1.609648
# Classifier training loss: -160.585766
# Adversary training loss: 1.606653
# Epoch 31
# -------------------------------
# Classifier validation loss: -160.459788
# Adversary validation loss: 1.605329
# Classifier training loss: -160.591258
# Adversary training loss: 1.606706
# Epoch 32
# -------------------------------
# Classifier validation loss: -160.671302
# Adversary validation loss: 1.607565
# Classifier training loss: -160.555410
# Adversary training loss: 1.606360
# Epoch 33
# -------------------------------
# Classifier validation loss: -160.680020
# Adversary validation loss: 1.607652
# Classifier training loss: -160.612744
# Adversary training loss: 1.606910
# Epoch 34
# -------------------------------
# Classifier validation loss: -160.626975
# Adversary validation loss: 1.607020
# Classifier training loss: -160.594185
# Adversary training loss: 1.606733
# Epoch 35
# -------------------------------
# Classifier validation loss: -160.608673
# Adversary validation loss: 1.606852
# Classifier training loss: -160.607303
# Adversary training loss: 1.606861
# Epoch 36
# -------------------------------
# Classifier validation loss: -160.555686
# Adversary validation loss: 1.606316
# Classifier training loss: -160.570166
# Adversary training loss: 1.606491
# Epoch 37
# -------------------------------
# Classifier validation loss: -160.692136
# Adversary validation loss: 1.607676
# Classifier training loss: -160.606364
# Adversary training loss: 1.606845
# Epoch 38
# -------------------------------
# Classifier validation loss: -160.530749
# Adversary validation loss: 1.606112
# Classifier training loss: -160.607322
# Adversary training loss: 1.606859
# Epoch 39
# -------------------------------
# Classifier validation loss: -160.637623
# Adversary validation loss: 1.607116
# Classifier training loss: -160.653652
# Adversary training loss: 1.607321
# Epoch 40
# -------------------------------
# Classifier validation loss: -160.661718
# Adversary validation loss: 1.607398
# Classifier training loss: -160.613686
# Adversary training loss: 1.606913
# Epoch 41
# -------------------------------
# Classifier validation loss: -160.564910
# Adversary validation loss: 1.606453
# Classifier training loss: -160.636502
# Adversary training loss: 1.607129
# Epoch 42
# -------------------------------
# Classifier validation loss: -160.621689
# Adversary validation loss: 1.606962
# Classifier training loss: -160.638816
# Adversary training loss: 1.607164
# Epoch 43
# -------------------------------
# Classifier validation loss: -160.584797
# Adversary validation loss: 1.606581
# Classifier training loss: -160.595263
# Adversary training loss: 1.606718
# Epoch 44
# -------------------------------
# Classifier validation loss: -160.590401
# Adversary validation loss: 1.606695
# Classifier training loss: -160.612277
# Adversary training loss: 1.606889
# Epoch 45
# -------------------------------
# Classifier validation loss: -160.496199
# Adversary validation loss: 1.605709
# Classifier training loss: -160.669725
# Adversary training loss: 1.607460
# Epoch 46
# -------------------------------
# Classifier validation loss: -160.709388
# Adversary validation loss: 1.607861
# Classifier training loss: -160.689169
# Adversary training loss: 1.607650
# Epoch 47
# -------------------------------
# Classifier validation loss: -160.598944
# Adversary validation loss: 1.606749
# Classifier training loss: -160.648967
# Adversary training loss: 1.607233
# Epoch 48
# -------------------------------
# Classifier validation loss: -160.624275
# Adversary validation loss: 1.606996
# Classifier training loss: -160.613472
# Adversary training loss: 1.606878
# Epoch 49
# -------------------------------
# Classifier validation loss: -160.668023
# Adversary validation loss: 1.607415
# Classifier training loss: -160.661308
# Adversary training loss: 1.607379
# Epoch 50
# -------------------------------
# Classifier validation loss: -160.497700
# Adversary validation loss: 1.605787
# Classifier training loss: -160.589666
# Adversary training loss: 1.606660
# Done!

# %%
fig, ax1 = plt.subplots()

best_epoch = np.argmin(diff_scores)+1



#ax1.plot(np.arange(len(Training_losses_adv))+1, Training_losses_adv, 'k-', label='Training Adversary')
ax1.plot(np.arange(len(Validation_losses_adv))+1, Validation_losses_adv, 'k-', label='Validation Adversary')

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Adversary Loss', color='k')
ax1.tick_params(axis='y', labelcolor='k')

ax2 = ax1.twinx()

#ax2.plot(np.arange(len(Training_losses_clas))+1, Training_losses_clas, 'r-', label='Training Classifier')
ax2.plot(np.arange(len(Validation_losses_clas))+1, Validation_losses_clas, 'r-', label='Validation Classifier')
ax2.axvline(best_epoch,label="Final model stopped here",color='k')

ax2.set_ylabel('Classifier Loss', color='r')
ax2.tick_params(axis='y', labelcolor='r')

# %% [markdown]
# ## Test adversarially trained models

# %%
# Now test the pretrained model
test_pred = mytools.test_clas(test_loader, final_clas_adv, device)
test_pred=torch.sigmoid(torch.tensor(test_pred)).numpy()


fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test, test_pred, pos_label=1)
auc_test = sklearn.metrics.auc(fpr, tpr)
print(f'Test AUROC: {auc_test:0.4f}')

plt.plot(fpr, tpr, label=f'Test AUROC: {auc_test:0.4f}')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
# Out:
# Test AUROC: 0.9898

# %%
df_test["Class_adv"] = test_pred
df_bkg = df_test.loc[ (df_test.type == 'tritrig') | (df_test.type == 'wab')]
per = np.percentile(df_bkg['Class_adv'],99)
df_cut = df_bkg[df_bkg['Class_adv']>per].reset_index(drop=True)
x_vals = 1000*df_cut.InvM

plt.figure()
plt.hist(1000*df_bkg.InvM, bins=np.arange(980,1250,1), histtype='step', label='No selection', density=True)
plt.hist(x_vals, bins=np.arange(980,1250,1), histtype='step', label= '99 percent selection', density=True)
plt.axvline(1019.461, color='k', linestyle='dashed', linewidth=1, label='PDG phi mass')
plt.xlabel('Invariant Mass [MeV]')
plt.ylabel('Normalized Counts')
plt.legend()

# %%
x1 = 1000* df_bkg.InvM.values
x2 = 1000*df_cut.InvM.values

N, edges = np.histogram(x1, bins=np.arange(980,1250,1), density=False)
M, edges = np.histogram(x2, bins=np.arange(980,1250,1), density=False)

N2 = N[(N > 0) & (M > 0)]
M2 = M[(N > 0) & (M > 0)]

diff_score = np.mean(np.abs(N2/np.sum(N)-M2/np.sum(M)) / (np.sqrt(N2)/np.sum(N) + np.sqrt(M2)/np.sum(M) ))

print(diff_score)

N = len(df_test.loc[ ((df_test.type == 'tritrig') | (df_test.type == 'wab')) & (df_test.InvM < (1.019 + 0.01) )  & (df_test.InvM > (1.019 - 0.01) ) & ( df_test['Class_adv']>per ) ] )
S = len(df_test.loc[ (df_test.type == 'phiKK') & (df_test.InvM < (1.019 + 0.01) )  & (df_test.InvM > (1.019 - 0.01) ) & ( df_test['Class_adv']>per )  ] )

print(S/N)
# Out:
# 0.7651353400903944
# 1.7457627118644068

# %%
df_test["Class_adv"] = test_pred

# %%
# Save the adversarially trained models
torch.save(final_clas_adv.state_dict(), "/Users/mghrear/data/ML_data/2019_pass2/models/FakeGen_classifier_adv_2019_pass2_run"+str(run)+"_unscaled.pt")
torch.save(final_adv_adv.state_dict(), "/Users/mghrear/data/ML_data/2019_pass2/models/FakeGen_adversary_adv_2019_pass2_run"+str(run)+"_unscaled.pt")

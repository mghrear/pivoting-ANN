# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import torch 
from torch import nn, optim
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import sklearn
from sklearn.model_selection import train_test_split
import copy
import mytools


# Print and store device being used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cpu

# %% [markdown]
# # Define important parameters

# %%
# Number of class in invariant mass used by the adversary
Num_classes = 5
# Hyper-parameter for adversarial training of the classifier
lambda_ = 100.0

run = 2

# %% [markdown]
# # Load and setup the data

# %%
# Read tritrig, wab, phiKK, and data files
df_tritrig = pd.read_pickle('/Users/mghrear/data/ML_data/patch/2021_v9_pass5_tritrig_limited.pk')
df_tritrig['PhiKK'] = 0.0
df_phiKK = pd.read_pickle('/Users/mghrear/data/ML_data/patch/2021_v9_pass5_phiKK_limited.pk')
df_phiKK['PhiKK'] = 1.0
df_wab = pd.read_pickle('/Users/mghrear/data/ML_data/patch/2021_v9_pass5_wab_limited.pk')
df_wab['PhiKK'] = 0.0 # Add label


print("tritrig: ", len(df_tritrig))
print("phiKK: ", len(df_phiKK))
print("wab: ", len(df_wab))
# Out:
# tritrig:  120739
# phiKK:  4086
# wab:  6596

# %%
# Combine and shuffle all training data
df_train = pd.concat([df_tritrig, df_phiKK, df_wab], ignore_index=True, sort=False)
df_train = df_train.sample(frac=1, random_state=42).reset_index(drop=True)

# Get edges in invariant mass classes for one-hot encoding
# To be used for adverserial labels
# The edges are chosen such that each bin has equal number of background events
one_hot_edges = mytools.get_one_hot_edges(mytools.get_InvM( pd.concat([df_tritrig, df_wab], ignore_index=True, sort=False) ), n_bins=Num_classes)

# Split the training data into training and validation sets
df_train, df_val = train_test_split(df_train, test_size=0.33, random_state=42)

# Make X and y for training and validation sets
# the adverserial network has its own labels
X_train = df_train.drop(columns=['PhiKK'])
y_train = df_train['PhiKK']
y_adv_train = mytools.get_adv_labels( mytools.get_InvM(df_train), one_hot_edges)
X_val = df_val.drop(columns=['PhiKK'])
y_val = df_val['PhiKK']
y_adv_val = mytools.get_adv_labels( mytools.get_InvM(df_val), one_hot_edges)

# %% [markdown]
# ## Setup dataloaders

# %%
bsize = 2500

# Convert to tensor dataset and dataloader
train_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy().astype(np.float32))  , torch.from_numpy(y_train.to_numpy().astype(np.float32)).unsqueeze(1)  )
train_loader = DataLoader(train_dataset, batch_size=bsize, shuffle=True)

val_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy().astype(np.float32))  , torch.from_numpy(y_val.to_numpy().astype(np.float32)).unsqueeze(1)  )
val_loader = DataLoader(val_dataset, batch_size=bsize, shuffle=True)

# %% [markdown]
# ## Initialize model, objective function, and optimizer

# %%
clas = mytools.Classifier(in_features=X_train.shape[1]).to(device)
criterion_clas = nn.BCEWithLogitsLoss()
optimizer_clas = optim.Adam(clas.parameters(), lr=1e-5)
scheduler_clas = torch.optim.lr_scheduler.ExponentialLR(optimizer_clas, gamma=0.9999)

# %% [markdown]
# ## Pre-train the classifier

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 10

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 2500
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train_clas(train_loader, clas, criterion_clas, optimizer_clas, scheduler_clas, device))
    Validation_losses = np.append(Validation_losses, mytools.validate_clas(val_loader, clas, criterion_clas, device))
    
    # Keep a running copy of the model with the lowest loss
    if Validation_losses[-1] == np.min(Validation_losses):
        final_classifier = copy.deepcopy(clas)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Training loss: 0.601106
# Validation loss: 0.561386
#
# Epoch 2
# -------------------------------
# Training loss: 0.556771
# Validation loss: 0.554977
#
# Epoch 3
# -------------------------------
# Training loss: 0.532247
# Validation loss: 0.531695
#
# Epoch 4
# -------------------------------
# Training loss: 0.512904
# Validation loss: 0.503572
#
# Epoch 5
# -------------------------------
# Training loss: 0.497777
# Validation loss: 0.491527
#
# Epoch 6
# -------------------------------
# Training loss: 0.484776
# Validation loss: 0.476908
#
# Epoch 7
# -------------------------------
# Training loss: 0.475490
# Validation loss: 0.467117
#
# Epoch 8
# -------------------------------
# Training loss: 0.465257
# Validation loss: 0.460144
#
# Epoch 9
# -------------------------------
# Training loss: 0.456451
# Validation loss: 0.451131
#
# Epoch 10
# -------------------------------
# Training loss: 0.446344
# Validation loss: 0.441648
#
# Epoch 11
# -------------------------------
# Training loss: 0.439788
# Validation loss: 0.438112
#
# Epoch 12
# -------------------------------
# Training loss: 0.432874
# Validation loss: 0.430477
#
# Epoch 13
# -------------------------------
# Training loss: 0.426015
# Validation loss: 0.420366
#
# Epoch 14
# -------------------------------
# Training loss: 0.421634
# Validation loss: 0.418999
#
# Epoch 15
# -------------------------------
# Training loss: 0.413494
# Validation loss: 0.409724
#
# Epoch 16
# -------------------------------
# Training loss: 0.407608
# Validation loss: 0.402956
#
# Epoch 17
# -------------------------------
# Training loss: 0.401706
# Validation loss: 0.397870
#
# Epoch 18
# -------------------------------
# Training loss: 0.396905
# Validation loss: 0.395725
#
# Epoch 19
# -------------------------------
# Training loss: 0.392441
# Validation loss: 0.389243
#
# Epoch 20
# -------------------------------
# Training loss: 0.387513
# Validation loss: 0.384066
#
# Epoch 21
# -------------------------------
# Training loss: 0.382453
# Validation loss: 0.383238
#
# Epoch 22
# -------------------------------
# Training loss: 0.378788
# Validation loss: 0.372647
#
# Epoch 23
# -------------------------------
# Training loss: 0.375101
# Validation loss: 0.370626
#
# Epoch 24
# -------------------------------
# Training loss: 0.370399
# Validation loss: 0.366427
#
# Epoch 25
# -------------------------------
# Training loss: 0.367597
# Validation loss: 0.370243
#
# Epoch 26
# -------------------------------
# Training loss: 0.364515
# Validation loss: 0.362357
#
# Epoch 27
# -------------------------------
# Training loss: 0.361310
# Validation loss: 0.356923
#
# Epoch 28
# -------------------------------
# Training loss: 0.357693
# Validation loss: 0.355447
#
# Epoch 29
# -------------------------------
# Training loss: 0.354231
# Validation loss: 0.352601
#
# Epoch 30
# -------------------------------
# Training loss: 0.350836
# Validation loss: 0.350387
#
# Epoch 31
# -------------------------------
# Training loss: 0.348663
# Validation loss: 0.347292
#
# Epoch 32
# -------------------------------
# Training loss: 0.344386
# Validation loss: 0.343801
#
# Epoch 33
# -------------------------------
# Training loss: 0.342101
# Validation loss: 0.342180
#
# Epoch 34
# -------------------------------
# Training loss: 0.338502
# Validation loss: 0.337669
#
# Epoch 35
# -------------------------------
# Training loss: 0.336063
# Validation loss: 0.336687
#
# Epoch 36
# -------------------------------
# Training loss: 0.333542
# Validation loss: 0.330658
#
# Epoch 37
# -------------------------------
# Training loss: 0.330899
# Validation loss: 0.328344
#
# Epoch 38
# -------------------------------
# Training loss: 0.328365
# Validation loss: 0.329664
#
# Epoch 39
# -------------------------------
# Training loss: 0.325718
# Validation loss: 0.323331
#
# Epoch 40
# -------------------------------
# Training loss: 0.322855
# Validation loss: 0.319613
#
# Epoch 41
# -------------------------------
# Training loss: 0.320811
# Validation loss: 0.317866
#
# Epoch 42
# -------------------------------
# Training loss: 0.318297
# Validation loss: 0.317124
#
# Epoch 43
# -------------------------------
# Training loss: 0.316262
# Validation loss: 0.315881
#
# Epoch 44
# -------------------------------
# Training loss: 0.314579
# Validation loss: 0.314481
#
# Epoch 45
# -------------------------------
# Training loss: 0.311961
# Validation loss: 0.311455
#
# Epoch 46
# -------------------------------
# Training loss: 0.309369
# Validation loss: 0.309512
#
# Epoch 47
# -------------------------------
# Training loss: 0.307247
# Validation loss: 0.308118
#
# Epoch 48
# -------------------------------
# Training loss: 0.305555
# Validation loss: 0.302608
#
# Epoch 49
# -------------------------------
# Training loss: 0.303234
# Validation loss: 0.301660
#
# Epoch 50
# -------------------------------
# Training loss: 0.300622
# Validation loss: 0.302478
#
# Epoch 51
# -------------------------------
# Training loss: 0.299081
# Validation loss: 0.295648
#
# Epoch 52
# -------------------------------
# Training loss: 0.298436
# Validation loss: 0.293751
#
# Epoch 53
# -------------------------------
# Training loss: 0.294614
# Validation loss: 0.296739
#
# Epoch 54
# -------------------------------
# Training loss: 0.292796
# Validation loss: 0.297432
#
# Epoch 55
# -------------------------------
# Training loss: 0.292130
# Validation loss: 0.289589
#
# Epoch 56
# -------------------------------
# Training loss: 0.289865
# Validation loss: 0.293598
#
# Epoch 57
# -------------------------------
# Training loss: 0.287873
# Validation loss: 0.288257
#
# Epoch 58
# -------------------------------
# Training loss: 0.287324
# Validation loss: 0.285397
#
# Epoch 59
# -------------------------------
# Training loss: 0.285809
# Validation loss: 0.286237
#
# Epoch 60
# -------------------------------
# Training loss: 0.283961
# Validation loss: 0.281945
#
# Epoch 61
# -------------------------------
# Training loss: 0.281442
# Validation loss: 0.282396
#
# Epoch 62
# -------------------------------
# Training loss: 0.279753
# Validation loss: 0.281082
#
# Epoch 63
# -------------------------------
# Training loss: 0.278141
# Validation loss: 0.275246
#
# Epoch 64
# -------------------------------
# Training loss: 0.276658
# Validation loss: 0.280196
#
# Epoch 65
# -------------------------------
# Training loss: 0.276154
# Validation loss: 0.276876
#
# Epoch 66
# -------------------------------
# Training loss: 0.274282
# Validation loss: 0.274958
#
# Epoch 67
# -------------------------------
# Training loss: 0.272734
# Validation loss: 0.275100
#
# Epoch 68
# -------------------------------
# Training loss: 0.271941
# Validation loss: 0.269663
#
# Epoch 69
# -------------------------------
# Training loss: 0.269073
# Validation loss: 0.268874
#
# Epoch 70
# -------------------------------
# Training loss: 0.268367
# Validation loss: 0.269484
#
# Epoch 71
# -------------------------------
# Training loss: 0.266398
# Validation loss: 0.264456
#
# Epoch 72
# -------------------------------
# Training loss: 0.265292
# Validation loss: 0.263878
#
# Epoch 73
# -------------------------------
# Training loss: 0.264003
# Validation loss: 0.263483
#
# Epoch 74
# -------------------------------
# Training loss: 0.262434
# Validation loss: 0.267533
#
# Epoch 75
# -------------------------------
# Training loss: 0.261408
# Validation loss: 0.262556
#
# Epoch 76
# -------------------------------
# Training loss: 0.260468
# Validation loss: 0.265713
#
# Epoch 77
# -------------------------------
# Training loss: 0.258922
# Validation loss: 0.260459
#
# Epoch 78
# -------------------------------
# Training loss: 0.257838
# Validation loss: 0.258022
#
# Epoch 79
# -------------------------------
# Training loss: 0.255921
# Validation loss: 0.256859
#
# Epoch 80
# -------------------------------
# Training loss: 0.255194
# Validation loss: 0.255829
#
# Epoch 81
# -------------------------------
# Training loss: 0.253742
# Validation loss: 0.253437
#
# Epoch 82
# -------------------------------
# Training loss: 0.253923
# Validation loss: 0.254581
#
# Epoch 83
# -------------------------------
# Training loss: 0.252390
# Validation loss: 0.253415
#
# Epoch 84
# -------------------------------
# Training loss: 0.250454
# Validation loss: 0.252782
#
# Epoch 85
# -------------------------------
# Training loss: 0.248462
# Validation loss: 0.250278
#
# Epoch 86
# -------------------------------
# Training loss: 0.247734
# Validation loss: 0.247893
#
# Epoch 87
# -------------------------------
# Training loss: 0.246403
# Validation loss: 0.244848
#
# Epoch 88
# -------------------------------
# Training loss: 0.245405
# Validation loss: 0.248741
#
# Epoch 89
# -------------------------------
# Training loss: 0.244942
# Validation loss: 0.248553
#
# Epoch 90
# -------------------------------
# Training loss: 0.243427
# Validation loss: 0.245150
#
# Epoch 91
# -------------------------------
# Training loss: 0.242525
# Validation loss: 0.246364
#
# Epoch 92
# -------------------------------
# Training loss: 0.241608
# Validation loss: 0.241477
#
# Epoch 93
# -------------------------------
# Training loss: 0.239531
# Validation loss: 0.241124
#
# Epoch 94
# -------------------------------
# Training loss: 0.239151
# Validation loss: 0.240973
#
# Epoch 95
# -------------------------------
# Training loss: 0.238183
# Validation loss: 0.238598
#
# Epoch 96
# -------------------------------
# Training loss: 0.236345
# Validation loss: 0.241232
#
# Epoch 97
# -------------------------------
# Training loss: 0.236472
# Validation loss: 0.234274
#
# Epoch 98
# -------------------------------
# Training loss: 0.235310
# Validation loss: 0.235111
#
# Epoch 99
# -------------------------------
# Training loss: 0.234260
# Validation loss: 0.232641
#
# Epoch 100
# -------------------------------
# Training loss: 0.233075
# Validation loss: 0.235290
#
# Epoch 101
# -------------------------------
# Training loss: 0.231755
# Validation loss: 0.233838
#
# Epoch 102
# -------------------------------
# Training loss: 0.230501
# Validation loss: 0.234933
#
# Epoch 103
# -------------------------------
# Training loss: 0.230062
# Validation loss: 0.231494
#
# Epoch 104
# -------------------------------
# Training loss: 0.229217
# Validation loss: 0.229752
#
# Epoch 105
# -------------------------------
# Training loss: 0.227941
# Validation loss: 0.231447
#
# Epoch 106
# -------------------------------
# Training loss: 0.227288
# Validation loss: 0.231646
#
# Epoch 107
# -------------------------------
# Training loss: 0.226802
# Validation loss: 0.227668
#
# Epoch 108
# -------------------------------
# Training loss: 0.225430
# Validation loss: 0.228892
#
# Epoch 109
# -------------------------------
# Training loss: 0.224188
# Validation loss: 0.227648
#
# Epoch 110
# -------------------------------
# Training loss: 0.223513
# Validation loss: 0.223123
#
# Epoch 111
# -------------------------------
# Training loss: 0.222893
# Validation loss: 0.222548
#
# Epoch 112
# -------------------------------
# Training loss: 0.222027
# Validation loss: 0.224171
#
# Epoch 113
# -------------------------------
# Training loss: 0.220618
# Validation loss: 0.221605
#
# Epoch 114
# -------------------------------
# Training loss: 0.220191
# Validation loss: 0.220667
#
# Epoch 115
# -------------------------------
# Training loss: 0.219601
# Validation loss: 0.219096
#
# Epoch 116
# -------------------------------
# Training loss: 0.218425
# Validation loss: 0.217564
#
# Epoch 117
# -------------------------------
# Training loss: 0.217703
# Validation loss: 0.219544
#
# Epoch 118
# -------------------------------
# Training loss: 0.216496
# Validation loss: 0.216115
#
# Epoch 119
# -------------------------------
# Training loss: 0.215412
# Validation loss: 0.216513
#
# Epoch 120
# -------------------------------
# Training loss: 0.214935
# Validation loss: 0.218506
#
# Epoch 121
# -------------------------------
# Training loss: 0.214943
# Validation loss: 0.213749
#
# Epoch 122
# -------------------------------
# Training loss: 0.213567
# Validation loss: 0.217875
#
# Epoch 123
# -------------------------------
# Training loss: 0.212273
# Validation loss: 0.214898
#
# Epoch 124
# -------------------------------
# Training loss: 0.211715
# Validation loss: 0.218078
#
# Epoch 125
# -------------------------------
# Training loss: 0.211371
# Validation loss: 0.211720
#
# Epoch 126
# -------------------------------
# Training loss: 0.210264
# Validation loss: 0.212356
#
# Epoch 127
# -------------------------------
# Training loss: 0.209143
# Validation loss: 0.212175
#
# Epoch 128
# -------------------------------
# Training loss: 0.209290
# Validation loss: 0.211231
#
# Epoch 129
# -------------------------------
# Training loss: 0.207674
# Validation loss: 0.210886
#
# Epoch 130
# -------------------------------
# Training loss: 0.207459
# Validation loss: 0.213147
#
# Epoch 131
# -------------------------------
# Training loss: 0.206261
# Validation loss: 0.206433
#
# Epoch 132
# -------------------------------
# Training loss: 0.205395
# Validation loss: 0.204936
#
# Epoch 133
# -------------------------------
# Training loss: 0.205148
# Validation loss: 0.208212
#
# Epoch 134
# -------------------------------
# Training loss: 0.204652
# Validation loss: 0.204289
#
# Epoch 135
# -------------------------------
# Training loss: 0.203388
# Validation loss: 0.205433
#
# Epoch 136
# -------------------------------
# Training loss: 0.202625
# Validation loss: 0.203167
#
# Epoch 137
# -------------------------------
# Training loss: 0.202444
# Validation loss: 0.204112
#
# Epoch 138
# -------------------------------
# Training loss: 0.201758
# Validation loss: 0.203824
#
# Epoch 139
# -------------------------------
# Training loss: 0.200777
# Validation loss: 0.201028
#
# Epoch 140
# -------------------------------
# Training loss: 0.199715
# Validation loss: 0.200951
#
# Epoch 141
# -------------------------------
# Training loss: 0.199415
# Validation loss: 0.206462
#
# Epoch 142
# -------------------------------
# Training loss: 0.198414
# Validation loss: 0.197841
#
# Epoch 143
# -------------------------------
# Training loss: 0.198632
# Validation loss: 0.200043
#
# Epoch 144
# -------------------------------
# Training loss: 0.197873
# Validation loss: 0.201791
#
# Epoch 145
# -------------------------------
# Training loss: 0.196578
# Validation loss: 0.201414
#
# Epoch 146
# -------------------------------
# Training loss: 0.196240
# Validation loss: 0.196885
#
# Epoch 147
# -------------------------------
# Training loss: 0.194939
# Validation loss: 0.196730
#
# Epoch 148
# -------------------------------
# Training loss: 0.194784
# Validation loss: 0.196127
#
# Epoch 149
# -------------------------------
# Training loss: 0.193899
# Validation loss: 0.197242
#
# Epoch 150
# -------------------------------
# Training loss: 0.194398
# Validation loss: 0.197472
#
# Epoch 151
# -------------------------------
# Training loss: 0.193370
# Validation loss: 0.198575
#
# Epoch 152
# -------------------------------
# Training loss: 0.192289
# Validation loss: 0.195545
#
# Epoch 153
# -------------------------------
# Training loss: 0.191237
# Validation loss: 0.195165
#
# Epoch 154
# -------------------------------
# Training loss: 0.191196
# Validation loss: 0.191966
#
# Epoch 155
# -------------------------------
# Training loss: 0.189857
# Validation loss: 0.194682
#
# Epoch 156
# -------------------------------
# Training loss: 0.190211
# Validation loss: 0.191207
#
# Epoch 157
# -------------------------------
# Training loss: 0.188467
# Validation loss: 0.193135
#
# Epoch 158
# -------------------------------
# Training loss: 0.188371
# Validation loss: 0.189196
#
# Epoch 159
# -------------------------------
# Training loss: 0.187959
# Validation loss: 0.191288
#
# Epoch 160
# -------------------------------
# Training loss: 0.187091
# Validation loss: 0.191566
#
# Epoch 161
# -------------------------------
# Training loss: 0.186445
# Validation loss: 0.193674
#
# Epoch 162
# -------------------------------
# Training loss: 0.186484
# Validation loss: 0.188545
#
# Epoch 163
# -------------------------------
# Training loss: 0.185129
# Validation loss: 0.185368
#
# Epoch 164
# -------------------------------
# Training loss: 0.184950
# Validation loss: 0.187389
#
# Epoch 165
# -------------------------------
# Training loss: 0.184894
# Validation loss: 0.187146
#
# Epoch 166
# -------------------------------
# Training loss: 0.184283
# Validation loss: 0.182842
#
# Epoch 167
# -------------------------------
# Training loss: 0.183493
# Validation loss: 0.184927
#
# Epoch 168
# -------------------------------
# Training loss: 0.182685
# Validation loss: 0.182484
#
# Epoch 169
# -------------------------------
# Training loss: 0.181672
# Validation loss: 0.190277
#
# Epoch 170
# -------------------------------
# Training loss: 0.181652
# Validation loss: 0.186014
#
# Epoch 171
# -------------------------------
# Training loss: 0.181424
# Validation loss: 0.184598
#
# Epoch 172
# -------------------------------
# Training loss: 0.180855
# Validation loss: 0.186416
#
# Epoch 173
# -------------------------------
# Training loss: 0.179676
# Validation loss: 0.181835
#
# Epoch 174
# -------------------------------
# Training loss: 0.179110
# Validation loss: 0.181017
#
# Epoch 175
# -------------------------------
# Training loss: 0.178342
# Validation loss: 0.182790
#
# Epoch 176
# -------------------------------
# Training loss: 0.178317
# Validation loss: 0.187864
#
# Epoch 177
# -------------------------------
# Training loss: 0.177827
# Validation loss: 0.183039
#
# Epoch 178
# -------------------------------
# Training loss: 0.177594
# Validation loss: 0.184918
#
# Epoch 179
# -------------------------------
# Training loss: 0.176800
# Validation loss: 0.187041
#
# Epoch 180
# -------------------------------
# Training loss: 0.176495
# Validation loss: 0.180014
#
# Epoch 181
# -------------------------------
# Training loss: 0.175449
# Validation loss: 0.173884
#
# Epoch 182
# -------------------------------
# Training loss: 0.174816
# Validation loss: 0.179926
#
# Epoch 183
# -------------------------------
# Training loss: 0.174222
# Validation loss: 0.175380
#
# Epoch 184
# -------------------------------
# Training loss: 0.174176
# Validation loss: 0.179888
#
# Epoch 185
# -------------------------------
# Training loss: 0.172931
# Validation loss: 0.171663
#
# Epoch 186
# -------------------------------
# Training loss: 0.173489
# Validation loss: 0.179033
#
# Epoch 187
# -------------------------------
# Training loss: 0.173026
# Validation loss: 0.176665
#
# Epoch 188
# -------------------------------
# Training loss: 0.171880
# Validation loss: 0.174807
#
# Epoch 189
# -------------------------------
# Training loss: 0.171603
# Validation loss: 0.172991
#
# Epoch 190
# -------------------------------
# Training loss: 0.170426
# Validation loss: 0.185538
#
# Epoch 191
# -------------------------------
# Training loss: 0.170579
# Validation loss: 0.172765
#
# Epoch 192
# -------------------------------
# Training loss: 0.169940
# Validation loss: 0.178512
#
# Epoch 193
# -------------------------------
# Training loss: 0.169990
# Validation loss: 0.191723
#
# Epoch 194
# -------------------------------
# Training loss: 0.168887
# Validation loss: 0.169726
#
# Epoch 195
# -------------------------------
# Training loss: 0.167973
# Validation loss: 0.179767
#
# Epoch 196
# -------------------------------
# Training loss: 0.167850
# Validation loss: 0.178634
#
# Epoch 197
# -------------------------------
# Training loss: 0.167422
# Validation loss: 0.177011
#
# Epoch 198
# -------------------------------
# Training loss: 0.167234
# Validation loss: 0.176152
#
# Epoch 199
# -------------------------------
# Training loss: 0.166263
# Validation loss: 0.180342
#
# Epoch 200
# -------------------------------
# Training loss: 0.166305
# Validation loss: 0.167784
#
# Epoch 201
# -------------------------------
# Training loss: 0.165101
# Validation loss: 0.171386
#
# Epoch 202
# -------------------------------
# Training loss: 0.165092
# Validation loss: 0.168356
#
# Epoch 203
# -------------------------------
# Training loss: 0.164030
# Validation loss: 0.170019
#
# Epoch 204
# -------------------------------
# Training loss: 0.163678
# Validation loss: 0.168662
#
# Epoch 205
# -------------------------------
# Training loss: 0.162811
# Validation loss: 0.162442
#
# Epoch 206
# -------------------------------
# Training loss: 0.162677
# Validation loss: 0.191527
#
# Epoch 207
# -------------------------------
# Training loss: 0.162114
# Validation loss: 0.163345
#
# Epoch 208
# -------------------------------
# Training loss: 0.161571
# Validation loss: 0.160868
#
# Epoch 209
# -------------------------------
# Training loss: 0.160767
# Validation loss: 0.165619
#
# Epoch 210
# -------------------------------
# Training loss: 0.159849
# Validation loss: 0.164214
#
# Epoch 211
# -------------------------------
# Training loss: 0.159568
# Validation loss: 0.165041
#
# Epoch 212
# -------------------------------
# Training loss: 0.158229
# Validation loss: 0.186059
#
# Epoch 213
# -------------------------------
# Training loss: 0.158623
# Validation loss: 0.151783
#
# Epoch 214
# -------------------------------
# Training loss: 0.156945
# Validation loss: 0.168184
#
# Epoch 215
# -------------------------------
# Training loss: 0.156842
# Validation loss: 0.167705
#
# Epoch 216
# -------------------------------
# Training loss: 0.156410
# Validation loss: 0.165153
#
# Epoch 217
# -------------------------------
# Training loss: 0.156175
# Validation loss: 0.169381
#
# Epoch 218
# -------------------------------
# Training loss: 0.155432
# Validation loss: 0.163082
#
# Epoch 219
# -------------------------------
# Training loss: 0.154411
# Validation loss: 0.161470
#
# Epoch 220
# -------------------------------
# Training loss: 0.153608
# Validation loss: 0.167514
#
# Epoch 221
# -------------------------------
# Training loss: 0.152643
# Validation loss: 0.191772
#
# Epoch 222
# -------------------------------
# Training loss: 0.152813
# Validation loss: 0.159004
#
# Epoch 223
# -------------------------------
# Training loss: 0.152195
# Validation loss: 0.181978
#
# Epoch 224
# -------------------------------
# Training loss: 0.150459
# Validation loss: 0.142593
#
# Epoch 225
# -------------------------------
# Training loss: 0.150632
# Validation loss: 0.166642
#
# Epoch 226
# -------------------------------
# Training loss: 0.150121
# Validation loss: 0.156007
#
# Epoch 227
# -------------------------------
# Training loss: 0.150044
# Validation loss: 0.190586
#
# Epoch 228
# -------------------------------
# Training loss: 0.147904
# Validation loss: 0.148682
#
# Epoch 229
# -------------------------------
# Training loss: 0.147827
# Validation loss: 0.181739
#
# Epoch 230
# -------------------------------
# Training loss: 0.147317
# Validation loss: 0.179729
#
# Epoch 231
# -------------------------------
# Training loss: 0.146953
# Validation loss: 0.188503
#
# Epoch 232
# -------------------------------
# Training loss: 0.144367
# Validation loss: 0.142308
#
# Epoch 233
# -------------------------------
# Training loss: 0.145445
# Validation loss: 0.202216
#
# Epoch 234
# -------------------------------
# Training loss: 0.144252
# Validation loss: 0.190356
#
# Epoch 235
# -------------------------------
# Training loss: 0.142513
# Validation loss: 0.141207
#
# Epoch 236
# -------------------------------
# Training loss: 0.141073
# Validation loss: 0.286165
#
# Epoch 237
# -------------------------------
# Training loss: 0.140027
# Validation loss: 0.137057
#
# Epoch 238
# -------------------------------
# Training loss: 0.139134
# Validation loss: 0.168142
#
# Epoch 239
# -------------------------------
# Training loss: 0.137725
# Validation loss: 0.139419
#
# Epoch 240
# -------------------------------
# Training loss: 0.137425
# Validation loss: 0.182383
#
# Epoch 241
# -------------------------------
# Training loss: 0.137897
# Validation loss: 0.140918
#
# Epoch 242
# -------------------------------
# Training loss: 0.135171
# Validation loss: 0.132658
#
# Epoch 243
# -------------------------------
# Training loss: 0.136598
# Validation loss: 0.242050
#
# Epoch 244
# -------------------------------
# Training loss: 0.135487
# Validation loss: 0.134256
#
# Epoch 245
# -------------------------------
# Training loss: 0.133587
# Validation loss: 0.157637
#
# Epoch 246
# -------------------------------
# Training loss: 0.134020
# Validation loss: 0.178829
#
# Epoch 247
# -------------------------------
# Training loss: 0.132982
# Validation loss: 0.174334
#
# Epoch 248
# -------------------------------
# Training loss: 0.133447
# Validation loss: 0.140514
#
# Epoch 249
# -------------------------------
# Training loss: 0.132190
# Validation loss: 0.125550
#
# Epoch 250
# -------------------------------
# Training loss: 0.131134
# Validation loss: 0.135843
#
# Epoch 251
# -------------------------------
# Training loss: 0.129388
# Validation loss: 0.146409
#
# Epoch 252
# -------------------------------
# Training loss: 0.131138
# Validation loss: 0.132278
#
# Epoch 253
# -------------------------------
# Training loss: 0.126948
# Validation loss: 0.249949
#
# Epoch 254
# -------------------------------
# Training loss: 0.127308
# Validation loss: 0.176802
#
# Epoch 255
# -------------------------------
# Training loss: 0.125916
# Validation loss: 0.125321
#
# Epoch 256
# -------------------------------
# Training loss: 0.127969
# Validation loss: 0.223608
#
# Epoch 257
# -------------------------------
# Training loss: 0.125215
# Validation loss: 0.123697
#
# Epoch 258
# -------------------------------
# Training loss: 0.124015
# Validation loss: 0.122008
#
# Epoch 259
# -------------------------------
# Training loss: 0.122935
# Validation loss: 0.137552
#
# Epoch 260
# -------------------------------
# Training loss: 0.123572
# Validation loss: 0.161751
#
# Epoch 261
# -------------------------------
# Training loss: 0.122383
# Validation loss: 0.119468
#
# Epoch 262
# -------------------------------
# Training loss: 0.123200
# Validation loss: 0.125615
#
# Epoch 263
# -------------------------------
# Training loss: 0.120721
# Validation loss: 0.135927
#
# Epoch 264
# -------------------------------
# Training loss: 0.121027
# Validation loss: 0.126078
#
# Epoch 265
# -------------------------------
# Training loss: 0.120597
# Validation loss: 0.186299
#
# Epoch 266
# -------------------------------
# Training loss: 0.120986
# Validation loss: 0.134748
#
# Epoch 267
# -------------------------------
# Training loss: 0.121005
# Validation loss: 0.266836
#
# Epoch 268
# -------------------------------
# Training loss: 0.118670
# Validation loss: 0.157217
#
# Epoch 269
# -------------------------------
# Training loss: 0.118646
# Validation loss: 0.122665
#
# Epoch 270
# -------------------------------
# Training loss: 0.118209
# Validation loss: 0.205289
#
# Epoch 271
# -------------------------------
# Training loss: 0.119389
# Validation loss: 0.118850
#
# Epoch 272
# -------------------------------
# Training loss: 0.116619
# Validation loss: 0.123815
#
# Epoch 273
# -------------------------------
# Training loss: 0.116143
# Validation loss: 0.117174
#
# Epoch 274
# -------------------------------
# Training loss: 0.116180
# Validation loss: 0.253866
#
# Epoch 275
# -------------------------------
# Training loss: 0.113077
# Validation loss: 0.239888
#
# Epoch 276
# -------------------------------
# Training loss: 0.117636
# Validation loss: 0.162978
#
# Epoch 277
# -------------------------------
# Training loss: 0.114709
# Validation loss: 0.278207
#
# Epoch 278
# -------------------------------
# Training loss: 0.113419
# Validation loss: 0.112688
#
# Epoch 279
# -------------------------------
# Training loss: 0.112805
# Validation loss: 0.124244
#
# Epoch 280
# -------------------------------
# Training loss: 0.112261
# Validation loss: 0.113171
#
# Epoch 281
# -------------------------------
# Training loss: 0.112299
# Validation loss: 0.116010
#
# Epoch 282
# -------------------------------
# Training loss: 0.112611
# Validation loss: 0.112054
#
# Epoch 283
# -------------------------------
# Training loss: 0.111621
# Validation loss: 0.176939
#
# Epoch 284
# -------------------------------
# Training loss: 0.112323
# Validation loss: 0.139195
#
# Epoch 285
# -------------------------------
# Training loss: 0.108942
# Validation loss: 0.140461
#
# Epoch 286
# -------------------------------
# Training loss: 0.109229
# Validation loss: 0.106433
#
# Epoch 287
# -------------------------------
# Training loss: 0.109375
# Validation loss: 0.106443
#
# Epoch 288
# -------------------------------
# Training loss: 0.108907
# Validation loss: 0.135029
#
# Epoch 289
# -------------------------------
# Training loss: 0.109797
# Validation loss: 0.147632
#
# Epoch 290
# -------------------------------
# Training loss: 0.107298
# Validation loss: 0.102325
#
# Epoch 291
# -------------------------------
# Training loss: 0.106375
# Validation loss: 0.119670
#
# Epoch 292
# -------------------------------
# Training loss: 0.107128
# Validation loss: 0.106237
#
# Epoch 293
# -------------------------------
# Training loss: 0.106438
# Validation loss: 0.106285
#
# Epoch 294
# -------------------------------
# Training loss: 0.104780
# Validation loss: 0.103601
#
# Epoch 295
# -------------------------------
# Training loss: 0.105756
# Validation loss: 0.124163
#
# Epoch 296
# -------------------------------
# Training loss: 0.105398
# Validation loss: 0.109922
#
# Epoch 297
# -------------------------------
# Training loss: 0.106113
# Validation loss: 0.131938
#
# Epoch 298
# -------------------------------
# Training loss: 0.105488
# Validation loss: 0.103458
#
# Epoch 299
# -------------------------------
# Training loss: 0.105931
# Validation loss: 0.138178
#
# Epoch 300
# -------------------------------
# Training loss: 0.104333
# Validation loss: 0.161274
#
# Epoch 301
# -------------------------------
# Training loss: 0.105067
# Validation loss: 0.104826
#
# Epoch 302
# -------------------------------
# Training loss: 0.104308
# Validation loss: 0.101868
#
# Epoch 303
# -------------------------------
# Training loss: 0.102339
# Validation loss: 0.099840
#
# Epoch 304
# -------------------------------
# Training loss: 0.103182
# Validation loss: 0.121484
#
# Epoch 305
# -------------------------------
# Training loss: 0.101970
# Validation loss: 0.101623
#
# Epoch 306
# -------------------------------
# Training loss: 0.101693
# Validation loss: 0.116141
#
# Epoch 307
# -------------------------------
# Training loss: 0.101941
# Validation loss: 0.099737
#
# Epoch 308
# -------------------------------
# Training loss: 0.101231
# Validation loss: 0.111027
#
# Epoch 309
# -------------------------------
# Training loss: 0.101365
# Validation loss: 0.096386
#
# Epoch 310
# -------------------------------
# Training loss: 0.101065
# Validation loss: 0.096504
#
# Epoch 311
# -------------------------------
# Training loss: 0.100493
# Validation loss: 0.094975
#
# Epoch 312
# -------------------------------
# Training loss: 0.099705
# Validation loss: 0.116669
#
# Epoch 313
# -------------------------------
# Training loss: 0.097674
# Validation loss: 0.096245
#
# Epoch 314
# -------------------------------
# Training loss: 0.097982
# Validation loss: 0.095807
#
# Epoch 315
# -------------------------------
# Training loss: 0.100202
# Validation loss: 0.109123
#
# Epoch 316
# -------------------------------
# Training loss: 0.097376
# Validation loss: 0.119123
#
# Epoch 317
# -------------------------------
# Training loss: 0.098008
# Validation loss: 0.097852
#
# Epoch 318
# -------------------------------
# Training loss: 0.098062
# Validation loss: 0.198650
#
# Epoch 319
# -------------------------------
# Training loss: 0.098132
# Validation loss: 0.112292
#
# Epoch 320
# -------------------------------
# Training loss: 0.095614
# Validation loss: 0.099449
#
# Epoch 321
# -------------------------------
# Training loss: 0.094102
# Validation loss: 0.101128
#
# Epoch 322
# -------------------------------
# Training loss: 0.094120
# Validation loss: 0.099162
#
# Epoch 323
# -------------------------------
# Training loss: 0.097546
# Validation loss: 0.097400
#
# Epoch 324
# -------------------------------
# Training loss: 0.096101
# Validation loss: 0.128105
#
# Epoch 325
# -------------------------------
# Training loss: 0.096383
# Validation loss: 0.112535
#
# Epoch 326
# -------------------------------
# Training loss: 0.094027
# Validation loss: 0.107987
#
# Epoch 327
# -------------------------------
# Training loss: 0.094224
# Validation loss: 0.120419
#
# Epoch 328
# -------------------------------
# Training loss: 0.095076
# Validation loss: 0.114639
#
# Epoch 329
# -------------------------------
# Training loss: 0.094192
# Validation loss: 0.111042
#
# Epoch 330
# -------------------------------
# Training loss: 0.094157
# Validation loss: 0.268289
#
# Epoch 331
# -------------------------------
# Training loss: 0.092448
# Validation loss: 0.095368
#
# Epoch 332
# -------------------------------
# Training loss: 0.092315
# Validation loss: 0.103367
#
# Epoch 333
# -------------------------------
# Training loss: 0.091798
# Validation loss: 0.087150
#
# Epoch 334
# -------------------------------
# Training loss: 0.091448
# Validation loss: 0.094046
#
# Epoch 335
# -------------------------------
# Training loss: 0.092205
# Validation loss: 0.165039
#
# Epoch 336
# -------------------------------
# Training loss: 0.091332
# Validation loss: 0.086445
#
# Epoch 337
# -------------------------------
# Training loss: 0.092823
# Validation loss: 0.092786
#
# Epoch 338
# -------------------------------
# Training loss: 0.093045
# Validation loss: 0.097485
#
# Epoch 339
# -------------------------------
# Training loss: 0.091286
# Validation loss: 0.124547
#
# Epoch 340
# -------------------------------
# Training loss: 0.090260
# Validation loss: 0.105122
#
# Epoch 341
# -------------------------------
# Training loss: 0.091252
# Validation loss: 0.121190
#
# Epoch 342
# -------------------------------
# Training loss: 0.090630
# Validation loss: 0.096027
#
# Epoch 343
# -------------------------------
# Training loss: 0.091781
# Validation loss: 0.124052
#
# Epoch 344
# -------------------------------
# Training loss: 0.090649
# Validation loss: 0.094539
#
# Epoch 345
# -------------------------------
# Training loss: 0.089879
# Validation loss: 0.113060
#
# Epoch 346
# -------------------------------
# Training loss: 0.090947
# Validation loss: 0.153808
#
# Epoch 347
# -------------------------------
# Training loss: 0.087944
# Validation loss: 0.127094
#
# Epoch 348
# -------------------------------
# Training loss: 0.089168
# Validation loss: 0.127902
#
# Epoch 349
# -------------------------------
# Training loss: 0.089293
# Validation loss: 0.211703
#
# Epoch 350
# -------------------------------
# Training loss: 0.088251
# Validation loss: 0.085140
#
# Epoch 351
# -------------------------------
# Training loss: 0.087933
# Validation loss: 0.163320
#
# Epoch 352
# -------------------------------
# Training loss: 0.087284
# Validation loss: 0.096255
#
# Epoch 353
# -------------------------------
# Training loss: 0.086452
# Validation loss: 0.100166
#
# Epoch 354
# -------------------------------
# Training loss: 0.089038
# Validation loss: 0.207345
#
# Epoch 355
# -------------------------------
# Training loss: 0.088392
# Validation loss: 0.124768
#
# Epoch 356
# -------------------------------
# Training loss: 0.090380
# Validation loss: 0.109248
#
# Epoch 357
# -------------------------------
# Training loss: 0.086159
# Validation loss: 0.188926
#
# Epoch 358
# -------------------------------
# Training loss: 0.085855
# Validation loss: 0.094466
#
# Epoch 359
# -------------------------------
# Training loss: 0.085320
# Validation loss: 0.081629
#
# Epoch 360
# -------------------------------
# Training loss: 0.086464
# Validation loss: 0.079855
#
# Epoch 361
# -------------------------------
# Training loss: 0.085912
# Validation loss: 0.351481
#
# Epoch 362
# -------------------------------
# Training loss: 0.085181
# Validation loss: 0.172358
#
# Epoch 363
# -------------------------------
# Training loss: 0.086135
# Validation loss: 0.084163
#
# Epoch 364
# -------------------------------
# Training loss: 0.085255
# Validation loss: 0.352655
#
# Epoch 365
# -------------------------------
# Training loss: 0.085206
# Validation loss: 0.111629
#
# Epoch 366
# -------------------------------
# Training loss: 0.086861
# Validation loss: 0.124797
#
# Epoch 367
# -------------------------------
# Training loss: 0.084676
# Validation loss: 0.085979
#
# Epoch 368
# -------------------------------
# Training loss: 0.084449
# Validation loss: 0.099562
#
# Epoch 369
# -------------------------------
# Training loss: 0.083657
# Validation loss: 0.083229
#
# Epoch 370
# -------------------------------
# Training loss: 0.083626
# Validation loss: 0.110733
#
# Epoch 371
# -------------------------------
# Training loss: 0.085237
# Validation loss: 0.091865
#
# Epoch 372
# -------------------------------
# Training loss: 0.083196
# Validation loss: 0.088021
#
# Epoch 373
# -------------------------------
# Training loss: 0.085744
# Validation loss: 0.172738
#
# Epoch 374
# -------------------------------
# Training loss: 0.083011
# Validation loss: 0.166112
#
# Epoch 375
# -------------------------------
# Training loss: 0.084451
# Validation loss: 0.083438
#
# Epoch 376
# -------------------------------
# Training loss: 0.083846
# Validation loss: 0.107631
#
# Epoch 377
# -------------------------------
# Training loss: 0.085659
# Validation loss: 0.144563
#
# Epoch 378
# -------------------------------
# Training loss: 0.081544
# Validation loss: 0.079716
#
# Epoch 379
# -------------------------------
# Training loss: 0.081985
# Validation loss: 0.079210
#
# Epoch 380
# -------------------------------
# Training loss: 0.082011
# Validation loss: 0.086927
#
# Epoch 381
# -------------------------------
# Training loss: 0.081454
# Validation loss: 0.079227
#
# Epoch 382
# -------------------------------
# Training loss: 0.080550
# Validation loss: 0.108441
#
# Epoch 383
# -------------------------------
# Training loss: 0.082324
# Validation loss: 0.084887
#
# Epoch 384
# -------------------------------
# Training loss: 0.080698
# Validation loss: 0.084389
#
# Epoch 385
# -------------------------------
# Training loss: 0.080896
# Validation loss: 0.080989
#
# Epoch 386
# -------------------------------
# Training loss: 0.082753
# Validation loss: 0.079134
#
# Epoch 387
# -------------------------------
# Training loss: 0.082104
# Validation loss: 0.088948
#
# Epoch 388
# -------------------------------
# Training loss: 0.079279
# Validation loss: 0.078057
#
# Epoch 389
# -------------------------------
# Training loss: 0.079330
# Validation loss: 0.089130
#
# Epoch 390
# -------------------------------
# Training loss: 0.080329
# Validation loss: 0.209628
#
# Epoch 391
# -------------------------------
# Training loss: 0.078541
# Validation loss: 0.079386
#
# Epoch 392
# -------------------------------
# Training loss: 0.079458
# Validation loss: 0.113666
#
# Epoch 393
# -------------------------------
# Training loss: 0.080849
# Validation loss: 0.107743
#
# Epoch 394
# -------------------------------
# Training loss: 0.078185
# Validation loss: 0.104446
#
# Epoch 395
# -------------------------------
# Training loss: 0.079941
# Validation loss: 0.119020
#
# Epoch 396
# -------------------------------
# Training loss: 0.076836
# Validation loss: 0.078454
#
# Epoch 397
# -------------------------------
# Training loss: 0.079317
# Validation loss: 0.078778
#
# Epoch 398
# -------------------------------
# Training loss: 0.080367
# Validation loss: 0.167148
#
# Epoch 399
# -------------------------------
# Training loss: 0.077944
# Validation loss: 0.116461
#
# Epoch 400
# -------------------------------
# Training loss: 0.077202
# Validation loss: 0.090865
#
# Epoch 401
# -------------------------------
# Training loss: 0.078009
# Validation loss: 0.078740
#
# Epoch 402
# -------------------------------
# Training loss: 0.079258
# Validation loss: 0.112132
#
# Epoch 403
# -------------------------------
# Training loss: 0.078192
# Validation loss: 0.214204
#
# Epoch 404
# -------------------------------
# Training loss: 0.076964
# Validation loss: 0.074847
#
# Epoch 405
# -------------------------------
# Training loss: 0.078385
# Validation loss: 0.087540
#
# Epoch 406
# -------------------------------
# Training loss: 0.079116
# Validation loss: 0.089289
#
# Epoch 407
# -------------------------------
# Training loss: 0.076920
# Validation loss: 0.091572
#
# Epoch 408
# -------------------------------
# Training loss: 0.077545
# Validation loss: 0.076343
#
# Epoch 409
# -------------------------------
# Training loss: 0.076687
# Validation loss: 0.086456
#
# Epoch 410
# -------------------------------
# Training loss: 0.075405
# Validation loss: 0.093063
#
# Epoch 411
# -------------------------------
# Training loss: 0.077292
# Validation loss: 0.087219
#
# Epoch 412
# -------------------------------
# Training loss: 0.074854
# Validation loss: 0.090384
#
# Epoch 413
# -------------------------------
# Training loss: 0.075481
# Validation loss: 0.094167
#
# Epoch 414
# -------------------------------
# Training loss: 0.075312
# Validation loss: 0.154380
#
# Epoch 415
# -------------------------------
# Training loss: 0.075261
# Validation loss: 0.076256
#
# Epoch 416
# -------------------------------
# Training loss: 0.075499
# Validation loss: 0.072163
#
# Epoch 417
# -------------------------------
# Training loss: 0.074960
# Validation loss: 0.097030
#
# Epoch 418
# -------------------------------
# Training loss: 0.076033
# Validation loss: 0.074599
#
# Epoch 419
# -------------------------------
# Training loss: 0.074715
# Validation loss: 0.105369
#
# Epoch 420
# -------------------------------
# Training loss: 0.075984
# Validation loss: 0.084091
#
# Epoch 421
# -------------------------------
# Training loss: 0.074581
# Validation loss: 0.074777
#
# Epoch 422
# -------------------------------
# Training loss: 0.074069
# Validation loss: 0.077903
#
# Epoch 423
# -------------------------------
# Training loss: 0.074993
# Validation loss: 0.098752
#
# Epoch 424
# -------------------------------
# Training loss: 0.073467
# Validation loss: 0.069673
#
# Epoch 425
# -------------------------------
# Training loss: 0.073668
# Validation loss: 0.098972
#
# Epoch 426
# -------------------------------
# Training loss: 0.072866
# Validation loss: 0.073175
#
# Epoch 427
# -------------------------------
# Training loss: 0.073600
# Validation loss: 0.096382
#
# Epoch 428
# -------------------------------
# Training loss: 0.073161
# Validation loss: 0.070216
#
# Epoch 429
# -------------------------------
# Training loss: 0.072639
# Validation loss: 0.085998
#
# Epoch 430
# -------------------------------
# Training loss: 0.073047
# Validation loss: 0.081768
#
# Epoch 431
# -------------------------------
# Training loss: 0.072974
# Validation loss: 0.074261
#
# Epoch 432
# -------------------------------
# Training loss: 0.072886
# Validation loss: 0.080844
#
# Epoch 433
# -------------------------------
# Training loss: 0.073813
# Validation loss: 0.076469
#
# Epoch 434
# -------------------------------
# Training loss: 0.073399
# Validation loss: 0.085569
#
# Epoch 435
# -------------------------------
# Training loss: 0.073174
# Validation loss: 0.119199
#
# Epoch 436
# -------------------------------
# Training loss: 0.072579
# Validation loss: 0.070294
#
# Epoch 437
# -------------------------------
# Training loss: 0.072920
# Validation loss: 0.112198
#
# Epoch 438
# -------------------------------
# Training loss: 0.072318
# Validation loss: 0.073868
#
# Epoch 439
# -------------------------------
# Training loss: 0.071037
# Validation loss: 0.122126
#
# Epoch 440
# -------------------------------
# Training loss: 0.070374
# Validation loss: 0.073220
#
# Epoch 441
# -------------------------------
# Training loss: 0.072058
# Validation loss: 0.072431
#
# Epoch 442
# -------------------------------
# Training loss: 0.070956
# Validation loss: 0.070779
#
# Epoch 443
# -------------------------------
# Training loss: 0.070036
# Validation loss: 0.067926
#
# Epoch 444
# -------------------------------
# Training loss: 0.071770
# Validation loss: 0.069090
#
# Epoch 445
# -------------------------------
# Training loss: 0.070668
# Validation loss: 0.091281
#
# Epoch 446
# -------------------------------
# Training loss: 0.071741
# Validation loss: 0.102992
#
# Epoch 447
# -------------------------------
# Training loss: 0.069738
# Validation loss: 0.069672
#
# Epoch 448
# -------------------------------
# Training loss: 0.070554
# Validation loss: 0.074308
#
# Epoch 449
# -------------------------------
# Training loss: 0.070818
# Validation loss: 0.067326
#
# Epoch 450
# -------------------------------
# Training loss: 0.071380
# Validation loss: 0.090413
#
# Epoch 451
# -------------------------------
# Training loss: 0.071785
# Validation loss: 0.099124
#
# Epoch 452
# -------------------------------
# Training loss: 0.070542
# Validation loss: 0.101586
#
# Epoch 453
# -------------------------------
# Training loss: 0.069111
# Validation loss: 0.073721
#
# Epoch 454
# -------------------------------
# Training loss: 0.069379
# Validation loss: 0.087862
#
# Epoch 455
# -------------------------------
# Training loss: 0.069084
# Validation loss: 0.069808
#
# Epoch 456
# -------------------------------
# Training loss: 0.069753
# Validation loss: 0.076317
#
# Epoch 457
# -------------------------------
# Training loss: 0.069595
# Validation loss: 0.072994
#
# Epoch 458
# -------------------------------
# Training loss: 0.068269
# Validation loss: 0.146319
#
# Epoch 459
# -------------------------------
# Training loss: 0.070574
# Validation loss: 0.071209
#
# Epoch 460
# -------------------------------
# Training loss: 0.069302
# Validation loss: 0.089648
#
# Epoch 461
# -------------------------------
# Training loss: 0.069033
# Validation loss: 0.077994
#
# Epoch 462
# -------------------------------
# Training loss: 0.068655
# Validation loss: 0.115200
#
# Epoch 463
# -------------------------------
# Training loss: 0.069945
# Validation loss: 0.069202
#
# Epoch 464
# -------------------------------
# Training loss: 0.068971
# Validation loss: 0.084375
#
# Epoch 465
# -------------------------------
# Training loss: 0.068432
# Validation loss: 0.073974
#
# Epoch 466
# -------------------------------
# Training loss: 0.068534
# Validation loss: 0.069012
#
# Epoch 467
# -------------------------------
# Training loss: 0.068532
# Validation loss: 0.100282
#
# Epoch 468
# -------------------------------
# Training loss: 0.066986
# Validation loss: 0.072042
#
# Epoch 469
# -------------------------------
# Training loss: 0.067949
# Validation loss: 0.068685
#
# Epoch 470
# -------------------------------
# Training loss: 0.068352
# Validation loss: 0.169509
#
# Epoch 471
# -------------------------------
# Training loss: 0.067151
# Validation loss: 0.075645
#
# Epoch 472
# -------------------------------
# Training loss: 0.067180
# Validation loss: 0.064495
#
# Epoch 473
# -------------------------------
# Training loss: 0.068268
# Validation loss: 0.072675
#
# Epoch 474
# -------------------------------
# Training loss: 0.067391
# Validation loss: 0.068909
#
# Epoch 475
# -------------------------------
# Training loss: 0.066845
# Validation loss: 0.066565
#
# Epoch 476
# -------------------------------
# Training loss: 0.067288
# Validation loss: 0.068073
#
# Epoch 477
# -------------------------------
# Training loss: 0.065801
# Validation loss: 0.071408
#
# Epoch 478
# -------------------------------
# Training loss: 0.066966
# Validation loss: 0.098534
#
# Epoch 479
# -------------------------------
# Training loss: 0.068220
# Validation loss: 0.063013
#
# Epoch 480
# -------------------------------
# Training loss: 0.069944
# Validation loss: 0.091962
#
# Epoch 481
# -------------------------------
# Training loss: 0.067017
# Validation loss: 0.072796
#
# Epoch 482
# -------------------------------
# Training loss: 0.067085
# Validation loss: 0.069371
#
# Epoch 483
# -------------------------------
# Training loss: 0.066153
# Validation loss: 0.070245
#
# Epoch 484
# -------------------------------
# Training loss: 0.067020
# Validation loss: 0.077740
#
# Epoch 485
# -------------------------------
# Training loss: 0.066711
# Validation loss: 0.088270
#
# Epoch 486
# -------------------------------
# Training loss: 0.065909
# Validation loss: 0.061731
#
# Epoch 487
# -------------------------------
# Training loss: 0.066339
# Validation loss: 0.063346
#
# Epoch 488
# -------------------------------
# Training loss: 0.065862
# Validation loss: 0.071192
#
# Epoch 489
# -------------------------------
# Training loss: 0.064934
# Validation loss: 0.095007
#
# Epoch 490
# -------------------------------
# Training loss: 0.065547
# Validation loss: 0.076723
#
# Epoch 491
# -------------------------------
# Training loss: 0.064779
# Validation loss: 0.067218
#
# Epoch 492
# -------------------------------
# Training loss: 0.065714
# Validation loss: 0.064214
#
# Epoch 493
# -------------------------------
# Training loss: 0.064562
# Validation loss: 0.065653
#
# Epoch 494
# -------------------------------
# Training loss: 0.064879
# Validation loss: 0.065205
#
# Epoch 495
# -------------------------------
# Training loss: 0.065037
# Validation loss: 0.065595
#
# Epoch 496
# -------------------------------
# Training loss: 0.064673
# Validation loss: 0.110103
#
# Epoch 497
# -------------------------------
# Training loss: 0.065901
# Validation loss: 0.067936
#
# Epoch 498
# -------------------------------
# Training loss: 0.065770
# Validation loss: 0.107380
#
# Epoch 499
# -------------------------------
# Training loss: 0.064411
# Validation loss: 0.069790
#
# Epoch 500
# -------------------------------
# Training loss: 0.063867
# Validation loss: 0.070597
#
# Epoch 501
# -------------------------------
# Training loss: 0.064761
# Validation loss: 0.084140
#
# Epoch 502
# -------------------------------
# Training loss: 0.066799
# Validation loss: 0.075714
#
# Epoch 503
# -------------------------------
# Training loss: 0.064301
# Validation loss: 0.081619
#
# Epoch 504
# -------------------------------
# Training loss: 0.065059
# Validation loss: 0.067063
#
# Epoch 505
# -------------------------------
# Training loss: 0.064315
# Validation loss: 0.146692
#
# Epoch 506
# -------------------------------
# Training loss: 0.065086
# Validation loss: 0.063653
#
# Epoch 507
# -------------------------------
# Training loss: 0.064786
# Validation loss: 0.083444
#
# Epoch 508
# -------------------------------
# Training loss: 0.064505
# Validation loss: 0.074968
#
# Epoch 509
# -------------------------------
# Training loss: 0.063570
# Validation loss: 0.092424
#
# Epoch 510
# -------------------------------
# Training loss: 0.063812
# Validation loss: 0.065040
#
# Epoch 511
# -------------------------------
# Training loss: 0.063550
# Validation loss: 0.064770
#
# Epoch 512
# -------------------------------
# Training loss: 0.064953
# ...
# Validation loss: 0.044872
#
# Epoch 2333
# -------------------------------
# Training loss: 0.042474
# Validation loss: 0.043832
#
# Epoch 2334
# -------------------------------
# Training loss: 0.043077
# Validation loss: 0.049709
#
# Epoch 2335
# -------------------------------
# Training loss: 0.042775
# Validation loss: 0.041730
#
# Epoch 2336
# -------------------------------
# Training loss: 0.043065
# Validation loss: 0.044664
#
# Epoch 2337
# -------------------------------
# Training loss: 0.042483
# Validation loss: 0.043715
#
# Epoch 2338
# -------------------------------
# Training loss: 0.043033
# Validation loss: 0.042238
#
# Epoch 2339
# -------------------------------
# Training loss: 0.042743
# Validation loss: 0.043260
#
# Epoch 2340
# -------------------------------
# Training loss: 0.043654
# Validation loss: 0.042959
#
# Epoch 2341
# -------------------------------
# Training loss: 0.042946
# Validation loss: 0.041695
#
# Epoch 2342
# -------------------------------
# Training loss: 0.042912
# Validation loss: 0.041004
#
# Epoch 2343
# -------------------------------
# Training loss: 0.042805
# Validation loss: 0.043675
#
# Epoch 2344
# -------------------------------
# Training loss: 0.043238
# Validation loss: 0.045011
#
# Epoch 2345
# -------------------------------
# Training loss: 0.043230
# Validation loss: 0.044140
#
# Epoch 2346
# -------------------------------
# Training loss: 0.042828
# Validation loss: 0.042924
#
# Epoch 2347
# -------------------------------
# Training loss: 0.042269
# Validation loss: 0.041167
#
# Epoch 2348
# -------------------------------
# Training loss: 0.043131
# Validation loss: 0.041816
#
# Epoch 2349
# -------------------------------
# Training loss: 0.042770
# Validation loss: 0.043919
#
# Epoch 2350
# -------------------------------
# Training loss: 0.043023
# Validation loss: 0.042041
#
# Epoch 2351
# -------------------------------
# Training loss: 0.042200
# Validation loss: 0.041956
#
# Epoch 2352
# -------------------------------
# Training loss: 0.042648
# Validation loss: 0.042312
#
# Epoch 2353
# -------------------------------
# Training loss: 0.042803
# Validation loss: 0.043155
#
# Epoch 2354
# -------------------------------
# Training loss: 0.042736
# Validation loss: 0.042125
#
# Epoch 2355
# -------------------------------
# Training loss: 0.043188
# Validation loss: 0.042204
#
# Epoch 2356
# -------------------------------
# Training loss: 0.043262
# Validation loss: 0.044451
#
# Epoch 2357
# -------------------------------
# Training loss: 0.043148
# Validation loss: 0.042385
#
# Epoch 2358
# -------------------------------
# Training loss: 0.044162
# Validation loss: 0.052377
#
# Epoch 2359
# -------------------------------
# Training loss: 0.042361
# Validation loss: 0.041500
#
# Epoch 2360
# -------------------------------
# Training loss: 0.042451
# Validation loss: 0.041608
#
# Epoch 2361
# -------------------------------
# Training loss: 0.042784
# Validation loss: 0.043947
#
# Epoch 2362
# -------------------------------
# Training loss: 0.042507
# Validation loss: 0.042382
#
# Epoch 2363
# -------------------------------
# Training loss: 0.043409
# Validation loss: 0.042973
#
# Epoch 2364
# -------------------------------
# Training loss: 0.043081
# Validation loss: 0.041619
#
# Epoch 2365
# -------------------------------
# Training loss: 0.042578
# Validation loss: 0.043354
#
# Epoch 2366
# -------------------------------
# Training loss: 0.043505
# Validation loss: 0.050657
#
# Epoch 2367
# -------------------------------
# Training loss: 0.042737
# Validation loss: 0.041955
#
# Epoch 2368
# -------------------------------
# Training loss: 0.042505
# Validation loss: 0.043277
#
# Epoch 2369
# -------------------------------
# Training loss: 0.043241
# Validation loss: 0.042222
#
# Epoch 2370
# -------------------------------
# Training loss: 0.043154
# Validation loss: 0.041307
#
# Epoch 2371
# -------------------------------
# Training loss: 0.042528
# Validation loss: 0.041616
#
# Epoch 2372
# -------------------------------
# Training loss: 0.042609
# Validation loss: 0.042491
#
# Epoch 2373
# -------------------------------
# Training loss: 0.042692
# Validation loss: 0.041444
#
# Epoch 2374
# -------------------------------
# Training loss: 0.043502
# Validation loss: 0.041840
#
# Epoch 2375
# -------------------------------
# Training loss: 0.042599
# Validation loss: 0.041819
#
# Epoch 2376
# -------------------------------
# Training loss: 0.042819
# Validation loss: 0.042439
#
# Epoch 2377
# -------------------------------
# Training loss: 0.043351
# Validation loss: 0.042994
#
# Epoch 2378
# -------------------------------
# Training loss: 0.043096
# Validation loss: 0.041299
#
# Epoch 2379
# -------------------------------
# Training loss: 0.042829
# Validation loss: 0.041871
#
# Epoch 2380
# -------------------------------
# Training loss: 0.042837
# Validation loss: 0.043089
#
# Epoch 2381
# -------------------------------
# Training loss: 0.042602
# Validation loss: 0.042670
#
# Epoch 2382
# -------------------------------
# Training loss: 0.043003
# Validation loss: 0.043623
#
# Epoch 2383
# -------------------------------
# Training loss: 0.043192
# Validation loss: 0.046772
#
# Epoch 2384
# -------------------------------
# Training loss: 0.042901
# Validation loss: 0.042141
#
# Epoch 2385
# -------------------------------
# Training loss: 0.042451
# Validation loss: 0.051095
#
# Epoch 2386
# -------------------------------
# Training loss: 0.042300
# Validation loss: 0.044004
#
# Epoch 2387
# -------------------------------
# Training loss: 0.042478
# Validation loss: 0.044468
#
# Epoch 2388
# -------------------------------
# Training loss: 0.042055
# Validation loss: 0.041582
#
# Epoch 2389
# -------------------------------
# Training loss: 0.042650
# Validation loss: 0.043775
#
# Epoch 2390
# -------------------------------
# Training loss: 0.042853
# Validation loss: 0.043169
#
# Epoch 2391
# -------------------------------
# Training loss: 0.042084
# Validation loss: 0.042718
#
# Epoch 2392
# -------------------------------
# Training loss: 0.043167
# Validation loss: 0.049040
#
# Epoch 2393
# -------------------------------
# Training loss: 0.043061
# Validation loss: 0.041437
#
# Epoch 2394
# -------------------------------
# Training loss: 0.042565
# Validation loss: 0.043195
#
# Epoch 2395
# -------------------------------
# Training loss: 0.043022
# Validation loss: 0.041888
#
# Epoch 2396
# -------------------------------
# Training loss: 0.043414
# Validation loss: 0.046075
#
# Epoch 2397
# -------------------------------
# Training loss: 0.042524
# Validation loss: 0.042986
#
# Epoch 2398
# -------------------------------
# Training loss: 0.042877
# Validation loss: 0.043511
#
# Epoch 2399
# -------------------------------
# Training loss: 0.042673
# Validation loss: 0.042756
#
# Epoch 2400
# -------------------------------
# Training loss: 0.042481
# Validation loss: 0.042256
#
# Epoch 2401
# -------------------------------
# Training loss: 0.042655
# Validation loss: 0.043654
#
# Epoch 2402
# -------------------------------
# Training loss: 0.043102
# Validation loss: 0.064490
#
# Epoch 2403
# -------------------------------
# Training loss: 0.042422
# Validation loss: 0.041447
#
# Epoch 2404
# -------------------------------
# Training loss: 0.042240
# Validation loss: 0.041720
#
# Epoch 2405
# -------------------------------
# Training loss: 0.042493
# Validation loss: 0.041813
#
# Epoch 2406
# -------------------------------
# Training loss: 0.042356
# Validation loss: 0.042504
#
# Epoch 2407
# -------------------------------
# Training loss: 0.042740
# Validation loss: 0.043464
#
# Epoch 2408
# -------------------------------
# Training loss: 0.043148
# Validation loss: 0.047281
#
# Epoch 2409
# -------------------------------
# Training loss: 0.042242
# Validation loss: 0.042307
#
# Epoch 2410
# -------------------------------
# Training loss: 0.043288
# Validation loss: 0.047882
#
# Epoch 2411
# -------------------------------
# Training loss: 0.042535
# Validation loss: 0.042085
#
# Epoch 2412
# -------------------------------
# Training loss: 0.042963
# Validation loss: 0.042801
#
# Epoch 2413
# -------------------------------
# Training loss: 0.042402
# Validation loss: 0.041304
#
# Epoch 2414
# -------------------------------
# Training loss: 0.042842
# Validation loss: 0.042952
#
# Epoch 2415
# -------------------------------
# Training loss: 0.043053
# Validation loss: 0.042254
#
# Epoch 2416
# -------------------------------
# Training loss: 0.042818
# Validation loss: 0.041482
#
# Epoch 2417
# -------------------------------
# Training loss: 0.042766
# Validation loss: 0.041399
#
# Epoch 2418
# -------------------------------
# Training loss: 0.042506
# Validation loss: 0.041546
#
# Epoch 2419
# -------------------------------
# Training loss: 0.042235
# Validation loss: 0.042606
#
# Epoch 2420
# -------------------------------
# Training loss: 0.043168
# Validation loss: 0.041904
#
# Epoch 2421
# -------------------------------
# Training loss: 0.042721
# Validation loss: 0.044400
#
# Epoch 2422
# -------------------------------
# Training loss: 0.042908
# Validation loss: 0.042391
#
# Epoch 2423
# -------------------------------
# Training loss: 0.043019
# Validation loss: 0.045705
#
# Epoch 2424
# -------------------------------
# Training loss: 0.043045
# Validation loss: 0.041321
#
# Epoch 2425
# -------------------------------
# Training loss: 0.042888
# Validation loss: 0.052747
#
# Epoch 2426
# -------------------------------
# Training loss: 0.042612
# Validation loss: 0.044816
#
# Epoch 2427
# -------------------------------
# Training loss: 0.042010
# Validation loss: 0.041812
#
# Epoch 2428
# -------------------------------
# Training loss: 0.043237
# Validation loss: 0.042151
#
# Epoch 2429
# -------------------------------
# Training loss: 0.042822
# Validation loss: 0.043781
#
# Epoch 2430
# -------------------------------
# Training loss: 0.043131
# Validation loss: 0.045966
#
# Epoch 2431
# -------------------------------
# Training loss: 0.042887
# Validation loss: 0.043903
#
# Epoch 2432
# -------------------------------
# Training loss: 0.042618
# Validation loss: 0.042928
#
# Epoch 2433
# -------------------------------
# Training loss: 0.042884
# Validation loss: 0.046958
#
# Epoch 2434
# -------------------------------
# Training loss: 0.042659
# Validation loss: 0.042911
#
# Epoch 2435
# -------------------------------
# Training loss: 0.042812
# Validation loss: 0.046914
#
# Epoch 2436
# -------------------------------
# Training loss: 0.042835
# Validation loss: 0.042278
#
# Epoch 2437
# -------------------------------
# Training loss: 0.043059
# Validation loss: 0.041522
#
# Epoch 2438
# -------------------------------
# Training loss: 0.043148
# Validation loss: 0.043469
#
# Epoch 2439
# -------------------------------
# Training loss: 0.042987
# Validation loss: 0.043490
#
# Epoch 2440
# -------------------------------
# Training loss: 0.042575
# Validation loss: 0.045445
#
# Epoch 2441
# -------------------------------
# Training loss: 0.043970
# Validation loss: 0.044005
#
# Epoch 2442
# -------------------------------
# Training loss: 0.043270
# Validation loss: 0.043161
#
# Epoch 2443
# -------------------------------
# Training loss: 0.042629
# Validation loss: 0.045744
#
# Epoch 2444
# -------------------------------
# Training loss: 0.043013
# Validation loss: 0.041524
#
# Epoch 2445
# -------------------------------
# Training loss: 0.042455
# Validation loss: 0.043504
#
# Epoch 2446
# -------------------------------
# Training loss: 0.043196
# Validation loss: 0.041559
#
# Epoch 2447
# -------------------------------
# Training loss: 0.042796
# Validation loss: 0.044671
#
# Epoch 2448
# -------------------------------
# Training loss: 0.043642
# Validation loss: 0.052718
#
# Epoch 2449
# -------------------------------
# Training loss: 0.043982
# Validation loss: 0.041292
#
# Epoch 2450
# -------------------------------
# Training loss: 0.042952
# Validation loss: 0.042085
#
# Epoch 2451
# -------------------------------
# Training loss: 0.042213
# Validation loss: 0.043007
#
# Epoch 2452
# -------------------------------
# Training loss: 0.042634
# Validation loss: 0.041385
#
# Epoch 2453
# -------------------------------
# Training loss: 0.043065
# Validation loss: 0.041704
#
# Epoch 2454
# -------------------------------
# Training loss: 0.042885
# Validation loss: 0.042546
#
# Epoch 2455
# -------------------------------
# Training loss: 0.043288
# Validation loss: 0.043382
#
# Epoch 2456
# -------------------------------
# Training loss: 0.042744
# Validation loss: 0.041711
#
# Epoch 2457
# -------------------------------
# Training loss: 0.042699
# Validation loss: 0.041269
#
# Epoch 2458
# -------------------------------
# Training loss: 0.042623
# Validation loss: 0.042964
#
# Epoch 2459
# -------------------------------
# Training loss: 0.042909
# Validation loss: 0.042333
#
# Epoch 2460
# -------------------------------
# Training loss: 0.043459
# Validation loss: 0.044798
#
# Epoch 2461
# -------------------------------
# Training loss: 0.042420
# Validation loss: 0.042114
#
# Epoch 2462
# -------------------------------
# Training loss: 0.042525
# Validation loss: 0.048926
#
# Epoch 2463
# -------------------------------
# Training loss: 0.043580
# Validation loss: 0.043183
#
# Epoch 2464
# -------------------------------
# Training loss: 0.042820
# Validation loss: 0.042057
#
# Epoch 2465
# -------------------------------
# Training loss: 0.043651
# Validation loss: 0.043846
#
# Epoch 2466
# -------------------------------
# Training loss: 0.043184
# Validation loss: 0.041756
#
# Epoch 2467
# -------------------------------
# Training loss: 0.042634
# Validation loss: 0.042352
#
# Epoch 2468
# -------------------------------
# Training loss: 0.042927
# Validation loss: 0.041545
#
# Epoch 2469
# -------------------------------
# Training loss: 0.042392
# Validation loss: 0.044286
#
# Epoch 2470
# -------------------------------
# Training loss: 0.043187
# Validation loss: 0.042857
#
# Epoch 2471
# -------------------------------
# Training loss: 0.042543
# Validation loss: 0.042374
#
# Epoch 2472
# -------------------------------
# Training loss: 0.042481
# Validation loss: 0.042236
#
# Epoch 2473
# -------------------------------
# Training loss: 0.042265
# Validation loss: 0.041035
#
# Epoch 2474
# -------------------------------
# Training loss: 0.042357
# Validation loss: 0.042650
#
# Epoch 2475
# -------------------------------
# Training loss: 0.042439
# Validation loss: 0.043354
#
# Epoch 2476
# -------------------------------
# Training loss: 0.043136
# Validation loss: 0.043479
#
# Epoch 2477
# -------------------------------
# Training loss: 0.042275
# Validation loss: 0.041375
#
# Epoch 2478
# -------------------------------
# Training loss: 0.042724
# Validation loss: 0.042374
#
# Epoch 2479
# -------------------------------
# Training loss: 0.042380
# Validation loss: 0.044047
#
# Epoch 2480
# -------------------------------
# Training loss: 0.042940
# Validation loss: 0.041565
#
# Epoch 2481
# -------------------------------
# Training loss: 0.044069
# Validation loss: 0.056871
#
# Epoch 2482
# -------------------------------
# Training loss: 0.042837
# Validation loss: 0.043384
#
# Epoch 2483
# -------------------------------
# Training loss: 0.042878
# Validation loss: 0.044822
#
# Epoch 2484
# -------------------------------
# Training loss: 0.043352
# Validation loss: 0.042610
#
# Epoch 2485
# -------------------------------
# Training loss: 0.043849
# Validation loss: 0.041820
#
# Epoch 2486
# -------------------------------
# Training loss: 0.043018
# Validation loss: 0.042584
#
# Epoch 2487
# -------------------------------
# Training loss: 0.042511
# Validation loss: 0.042859
#
# Epoch 2488
# -------------------------------
# Training loss: 0.042893
# Validation loss: 0.044151
#
# Epoch 2489
# -------------------------------
# Training loss: 0.042655
# Validation loss: 0.041402
#
# Epoch 2490
# -------------------------------
# Training loss: 0.042233
# Validation loss: 0.044459
#
# Epoch 2491
# -------------------------------
# Training loss: 0.042955
# Validation loss: 0.042287
#
# Epoch 2492
# -------------------------------
# Training loss: 0.042150
# Validation loss: 0.041706
#
# Epoch 2493
# -------------------------------
# Training loss: 0.043517
# Validation loss: 0.047664
#
# Epoch 2494
# -------------------------------
# Training loss: 0.042715
# Validation loss: 0.044152
#
# Epoch 2495
# -------------------------------
# Training loss: 0.042945
# Validation loss: 0.041495
#
# Epoch 2496
# -------------------------------
# Training loss: 0.042748
# Validation loss: 0.041308
#
# Epoch 2497
# -------------------------------
# Training loss: 0.042257
# Validation loss: 0.041715
#
# Epoch 2498
# -------------------------------
# Training loss: 0.042469
# Validation loss: 0.041584
#
# Epoch 2499
# -------------------------------
# Training loss: 0.042498
# Validation loss: 0.041594
#
# Epoch 2500
# -------------------------------
# Training loss: 0.042641
# Validation loss: 0.042013
#
# Done!

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses)+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('BCE Loss')
#plt.yscale('log')
plt.legend()

# %%
# Save the pretrained classifier model
torch.save(final_classifier.state_dict(), "/Users/mghrear/data/ML_data/patch/pretrained_classifier_2021_v9_pass5_run"+str(run)+".pt")

# %% [markdown]
# # Setup the adversary model

# %% [markdown]
# ## Initialize model, objective function, and optimizer

# %%
adv = mytools.Adversary(n_classes=Num_classes).to(device)
criterion_adv = nn.CrossEntropyLoss(reduction='none')  # returns loss per sample so we can weight it
opt_adv = torch.optim.Adam(adv.parameters(), lr=1e-5)
scheduler_adv = torch.optim.lr_scheduler.ExponentialLR(opt_adv, gamma=0.999)

# %% [markdown]
# ## Setup dataloaders

# %%
# Convert to tensor dataset and dataloader

# the structure is: feature, adversary label, weight
# The wight is 1 for tritrig and wab, and 0 for phiKK, to prevent the adversary from learning on phiKK events

train_adv_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_train), (torch.from_numpy(y_train.to_numpy().astype(np.float32))==0).float())
train_adv_loader = DataLoader(train_adv_dataset, batch_size=bsize, shuffle=True)

val_adv_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_val), (torch.from_numpy(y_val.to_numpy().astype(np.float32))==0).float() )
val_adv_loader = DataLoader(val_adv_dataset, batch_size=bsize, shuffle=True)

# %% [markdown]
# ## Pre-train the adversary leaving classifier weights fixed

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 6

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 100
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train_adv(train_adv_loader, final_classifier, adv, criterion_adv, opt_adv, scheduler_adv, device))
    Validation_losses = np.append(Validation_losses, mytools.validate_adv(val_adv_loader, final_classifier, adv, criterion_adv, device))
    
    # Keep a running copy of the model with the lowest loss
    if Validation_losses[-1] == np.min(Validation_losses):
        final_adv = copy.deepcopy(adv)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Training loss: 1.623688
# Validation loss: 1.622039
#
# Epoch 2
# -------------------------------
# Training loss: 1.612610
# Validation loss: 1.617346
#
# Epoch 3
# -------------------------------
# Training loss: 1.606584
# Validation loss: 1.605952
#
# Epoch 4
# -------------------------------
# Training loss: 1.602647
# Validation loss: 1.602503
#
# Epoch 5
# -------------------------------
# Training loss: 1.599820
# Validation loss: 1.599979
#
# Epoch 6
# -------------------------------
# Training loss: 1.597052
# Validation loss: 1.597459
#
# Epoch 7
# -------------------------------
# Training loss: 1.595275
# Validation loss: 1.595293
#
# Epoch 8
# -------------------------------
# Training loss: 1.592988
# Validation loss: 1.593408
#
# Epoch 9
# -------------------------------
# Training loss: 1.591221
# Validation loss: 1.591952
#
# Epoch 10
# -------------------------------
# Training loss: 1.590141
# Validation loss: 1.591235
#
# Epoch 11
# -------------------------------
# Training loss: 1.588955
# Validation loss: 1.590024
#
# Epoch 12
# -------------------------------
# Training loss: 1.588283
# Validation loss: 1.589069
#
# Epoch 13
# -------------------------------
# Training loss: 1.587947
# Validation loss: 1.588369
#
# Epoch 14
# -------------------------------
# Training loss: 1.586909
# Validation loss: 1.587462
#
# Epoch 15
# -------------------------------
# Training loss: 1.586336
# Validation loss: 1.587304
#
# Epoch 16
# -------------------------------
# Training loss: 1.586336
# Validation loss: 1.586437
#
# Epoch 17
# -------------------------------
# Training loss: 1.585516
# Validation loss: 1.585673
#
# Epoch 18
# -------------------------------
# Training loss: 1.585406
# Validation loss: 1.585305
#
# Epoch 19
# -------------------------------
# Training loss: 1.584541
# Validation loss: 1.584959
#
# Epoch 20
# -------------------------------
# Training loss: 1.584464
# Validation loss: 1.584981
#
# Epoch 21
# -------------------------------
# Training loss: 1.583967
# Validation loss: 1.584575
#
# Epoch 22
# -------------------------------
# Training loss: 1.583495
# Validation loss: 1.584294
#
# Epoch 23
# -------------------------------
# Training loss: 1.583646
# Validation loss: 1.583898
#
# Epoch 24
# -------------------------------
# Training loss: 1.583490
# Validation loss: 1.583703
#
# Epoch 25
# -------------------------------
# Training loss: 1.582641
# Validation loss: 1.583190
#
# Epoch 26
# -------------------------------
# Training loss: 1.582905
# Validation loss: 1.583266
#
# Epoch 27
# -------------------------------
# Training loss: 1.582554
# Validation loss: 1.582721
#
# Epoch 28
# -------------------------------
# Training loss: 1.582047
# Validation loss: 1.582275
#
# Epoch 29
# -------------------------------
# Training loss: 1.582130
# Validation loss: 1.582384
#
# Epoch 30
# -------------------------------
# Training loss: 1.582207
# Validation loss: 1.582638
#
# Epoch 31
# -------------------------------
# Training loss: 1.581716
# Validation loss: 1.582533
#
# Epoch 32
# -------------------------------
# Training loss: 1.582468
# Validation loss: 1.582044
#
# Epoch 33
# -------------------------------
# Training loss: 1.581526
# Validation loss: 1.581286
#
# Epoch 34
# -------------------------------
# Training loss: 1.581113
# Validation loss: 1.581586
#
# Epoch 35
# -------------------------------
# Training loss: 1.581458
# Validation loss: 1.581298
#
# Epoch 36
# -------------------------------
# Training loss: 1.581197
# Validation loss: 1.581306
#
# Epoch 37
# -------------------------------
# Training loss: 1.580944
# Validation loss: 1.581706
#
# Epoch 38
# -------------------------------
# Training loss: 1.581212
# Validation loss: 1.580856
#
# Epoch 39
# -------------------------------
# Training loss: 1.581065
# Validation loss: 1.581317
#
# Epoch 40
# -------------------------------
# Training loss: 1.580540
# Validation loss: 1.581494
#
# Epoch 41
# -------------------------------
# Training loss: 1.580245
# Validation loss: 1.581011
#
# Epoch 42
# -------------------------------
# Training loss: 1.580529
# Validation loss: 1.581239
#
# Epoch 43
# -------------------------------
# Training loss: 1.580593
# Validation loss: 1.581063
#
# Epoch 44
# -------------------------------
# Training loss: 1.580374
# Validation loss: 1.580975
#
# Epoch 45
# -------------------------------
# Training loss: 1.580494
# Validation loss: 1.580476
#
# Epoch 46
# -------------------------------
# Training loss: 1.580706
# Validation loss: 1.580750
#
# Epoch 47
# -------------------------------
# Training loss: 1.580626
# Validation loss: 1.579973
#
# Epoch 48
# -------------------------------
# Training loss: 1.580688
# Validation loss: 1.580371
#
# Epoch 49
# -------------------------------
# Training loss: 1.580250
# Validation loss: 1.580873
#
# Epoch 50
# -------------------------------
# Training loss: 1.579897
# Validation loss: 1.579859
#
# Epoch 51
# -------------------------------
# Training loss: 1.580086
# Validation loss: 1.580060
#
# Epoch 52
# -------------------------------
# Training loss: 1.580439
# Validation loss: 1.580184
#
# Epoch 53
# -------------------------------
# Training loss: 1.579956
# Validation loss: 1.579610
#
# Epoch 54
# -------------------------------
# Training loss: 1.579817
# Validation loss: 1.580260
#
# Epoch 55
# -------------------------------
# Training loss: 1.580082
# Validation loss: 1.580008
#
# Epoch 56
# -------------------------------
# Training loss: 1.580024
# Validation loss: 1.579796
#
# Epoch 57
# -------------------------------
# Training loss: 1.580005
# Validation loss: 1.579985
#
# Epoch 58
# -------------------------------
# Training loss: 1.579860
# Validation loss: 1.579923
#
# Epoch 59
# -------------------------------
# Training loss: 1.579856
# Validation loss: 1.579926
#
# Epoch 60
# -------------------------------
# Training loss: 1.579706
# Validation loss: 1.580016
#
# Epoch 61
# -------------------------------
# Training loss: 1.579840
# Validation loss: 1.579469
#
# Epoch 62
# -------------------------------
# Training loss: 1.579616
# Validation loss: 1.579923
#
# Epoch 63
# -------------------------------
# Training loss: 1.579778
# Validation loss: 1.579641
#
# Epoch 64
# -------------------------------
# Training loss: 1.579311
# Validation loss: 1.580527
#
# Epoch 65
# -------------------------------
# Training loss: 1.579508
# Validation loss: 1.580004
#
# Epoch 66
# -------------------------------
# Training loss: 1.579884
# Validation loss: 1.579846
#
# Epoch 67
# -------------------------------
# Training loss: 1.579491
# Validation loss: 1.579203
#
# Epoch 68
# -------------------------------
# Training loss: 1.579615
# Validation loss: 1.580031
#
# Epoch 69
# -------------------------------
# Training loss: 1.579685
# Validation loss: 1.579724
#
# Epoch 70
# -------------------------------
# Training loss: 1.579652
# Validation loss: 1.579815
#
# Epoch 71
# -------------------------------
# Training loss: 1.580107
# Validation loss: 1.579662
#
# Epoch 72
# -------------------------------
# Training loss: 1.579497
# Validation loss: 1.579737
#
# Epoch 73
# -------------------------------
# Training loss: 1.579189
# Validation loss: 1.579939
#
# Epoch 74
# -------------------------------
# Training loss: 1.579650
# Validation loss: 1.579414
#
# Epoch 75
# -------------------------------
# Training loss: 1.579444
# Validation loss: 1.579940
#
# Epoch 76
# -------------------------------
# Training loss: 1.579734
# Validation loss: 1.579938
#
# Epoch 77
# -------------------------------
# Training loss: 1.579248
# Validation loss: 1.579952
#
# Epoch 78
# -------------------------------
# Training loss: 1.579267
# Validation loss: 1.579347
#
# Epoch 79
# -------------------------------
# Training loss: 1.579852
# Validation loss: 1.579402
#
# Epoch 80
# -------------------------------
# Training loss: 1.579565
# Validation loss: 1.579662
#
# Epoch 81
# -------------------------------
# Training loss: 1.579991
# Validation loss: 1.579652
#
# Epoch 82
# -------------------------------
# Training loss: 1.579292
# Validation loss: 1.579574
#
# Epoch 83
# -------------------------------
# Training loss: 1.579340
# Validation loss: 1.579254
#
# Epoch 84
# -------------------------------
# Training loss: 1.579110
# Validation loss: 1.579909
#
# Epoch 85
# -------------------------------
# Training loss: 1.579318
# Validation loss: 1.579654
#
# Epoch 86
# -------------------------------
# Training loss: 1.579126
# Validation loss: 1.578863
#
# Epoch 87
# -------------------------------
# Training loss: 1.579472
# Validation loss: 1.579402
#
# Epoch 88
# -------------------------------
# Training loss: 1.579470
# Validation loss: 1.579934
#
# Epoch 89
# -------------------------------
# Training loss: 1.579309
# Validation loss: 1.579453
#
# Epoch 90
# -------------------------------
# Training loss: 1.579289
# Validation loss: 1.579632
#
# Epoch 91
# -------------------------------
# Training loss: 1.579239
# Validation loss: 1.579487
#
# Epoch 92
# -------------------------------
# Training loss: 1.579125
# Validation loss: 1.579490
#
# Epoch 93
# -------------------------------
# Training loss: 1.579740
# Validation loss: 1.579767
#
# Epoch 94
# -------------------------------
# Training loss: 1.579495
# Validation loss: 1.579626
#
# Epoch 95
# -------------------------------
# Training loss: 1.579064
# Validation loss: 1.579417
#
# Epoch 96
# -------------------------------
# Training loss: 1.579637
# Validation loss: 1.579266
#
# Epoch 97
# -------------------------------
# Training loss: 1.579453
# Validation loss: 1.579271
#
# Epoch 98
# -------------------------------
# Training loss: 1.579380
# Validation loss: 1.579162
#
# Epoch 99
# -------------------------------
# Training loss: 1.578713
# Validation loss: 1.579550
#
# Epoch 100
# -------------------------------
# Training loss: 1.579149
# Validation loss: 1.579360
#
# Done!

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses)+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('BCE Loss')
plt.legend()

# %% [markdown]
# # Train full adverserial neural network

# %% [markdown]
# # Setup dataloaders

# %%
# the structure is: feature, classifier label, adversary label, weight
# The wight is 1 for tritrig and wab, and 0 for phiKK, to prevent the adversary from learning on phiKK events

train_full_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy().astype(np.float32))  , torch.from_numpy(y_train.to_numpy().astype(np.float32)).unsqueeze(1), torch.from_numpy(y_adv_train),  (torch.from_numpy(y_train.to_numpy().astype(np.float32))==0).float())
train_full_loader = DataLoader(train_full_dataset, batch_size=bsize, shuffle=True)

val_full_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy().astype(np.float32))  , torch.from_numpy(y_val.to_numpy().astype(np.float32)).unsqueeze(1),  torch.from_numpy(y_adv_val),  (torch.from_numpy(y_val.to_numpy().astype(np.float32))==0).float())
val_full_loader = DataLoader(val_full_dataset, batch_size=bsize, shuffle=True)

# %% [markdown]
# ## Define loss functions

# %%
BCE_loss = nn.BCEWithLogitsLoss()
CE_loss = nn.CrossEntropyLoss(reduction='none') # returns loss per sample so we can weight it

def full_loss(output_clas, output_adv, target_clas, target_adv, w, lambda_):

    loss1 = BCE_loss(output_clas, target_clas )  # classification loss
    sample_losses2 = CE_loss(output_adv, target_adv)  # adversarial losses, since we set reduction='none', this is now a vector of losses, one per sample in the batch

    # Weighted mean loss over non-zero weights
    nonzero = w > 0
    loss2 = (sample_losses2[nonzero] * w[nonzero]).sum() / w[nonzero].sum()

    loss = loss1 - lambda_*loss2

    return loss

# %% [markdown]
# ## Setup optimizers

# %%
optimizer_clas = optim.Adam(final_classifier.parameters(), lr=1e-7,betas=(0.5, 0.999))
optimizer_adv = optim.Adam(final_adv.parameters(), lr=1e-5,betas=(0.5, 0.999))

scheduler_clas = torch.optim.lr_scheduler.ExponentialLR(optimizer_clas, gamma=0.999)
scheduler_adv = torch.optim.lr_scheduler.ExponentialLR(optimizer_adv, gamma=0.999)

# %% [markdown]
# ## Adversarial training

# %%
Training_losses_clas = np.array([])
Training_losses_adv = np.array([])
Validation_losses_clas = np.array([])
Validation_losses_adv = np.array([])
diff_scores = np.array([])


epochs = 15
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")

    # Get validation losses
    E_clas_val_loss, E_adv_val_loss = mytools.validate_full(val_full_loader, final_classifier, final_adv, full_loss, lambda_, criterion_adv, device)
    Validation_losses_clas = np.append(Validation_losses_clas, E_clas_val_loss)
    Validation_losses_adv = np.append(Validation_losses_adv, E_adv_val_loss)

    # Train adversary and classifier
    E_clas_training_loss , E_adv_training_loss = mytools.train_full(train_full_loader, final_classifier, final_adv, full_loss, lambda_, criterion_adv, optimizer_clas, optimizer_adv, scheduler_clas, scheduler_adv, device)
    Training_losses_clas = np.append(Training_losses_clas, E_clas_training_loss)
    Training_losses_adv = np.append(Training_losses_adv, E_adv_training_loss)

final_clas_adv = copy.deepcopy(final_classifier)
final_adv_adv = copy.deepcopy(final_adv)

            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Classifier validation loss: -157.910490
# Adversary validation loss: 1.579516
# Classifier training loss: -160.664028
# Adversary training loss: 1.609164
# Epoch 2
# -------------------------------
# Classifier validation loss: -164.555158
# Adversary validation loss: 1.646136
# Classifier training loss: -164.471426
# Adversary training loss: 1.646428
# Epoch 3
# -------------------------------
# Classifier validation loss: -164.736617
# Adversary validation loss: 1.648266
# Classifier training loss: -163.583149
# Adversary training loss: 1.637018
# Epoch 4
# -------------------------------
# Classifier validation loss: -163.089116
# Adversary validation loss: 1.631859
# Classifier training loss: -162.330021
# Adversary training loss: 1.624381
# Epoch 5
# -------------------------------
# Classifier validation loss: -162.210982
# Adversary validation loss: 1.623050
# Classifier training loss: -161.498143
# Adversary training loss: 1.616054
# Epoch 6
# -------------------------------
# Classifier validation loss: -161.093618
# Adversary validation loss: 1.612000
# Classifier training loss: -160.921271
# Adversary training loss: 1.610310
# Epoch 7
# -------------------------------
# Classifier validation loss: -160.902490
# Adversary validation loss: 1.609961
# Classifier training loss: -160.609177
# Adversary training loss: 1.607133
# Epoch 8
# -------------------------------
# Classifier validation loss: -160.734876
# Adversary validation loss: 1.608278
# Classifier training loss: -160.665540
# Adversary training loss: 1.607664
# Epoch 9
# -------------------------------
# Classifier validation loss: -160.660405
# Adversary validation loss: 1.607365
# Classifier training loss: -161.045050
# Adversary training loss: 1.611351
# Epoch 10
# -------------------------------
# Classifier validation loss: -160.171770
# Adversary validation loss: 1.602809
# Classifier training loss: -161.130310
# Adversary training loss: 1.612028
# Epoch 11
# -------------------------------
# Classifier validation loss: -160.721436
# Adversary validation loss: 1.607800
# Classifier training loss: -160.824939
# Adversary training loss: 1.608960
# Epoch 12
# -------------------------------
# Classifier validation loss: -160.673464
# Adversary validation loss: 1.607343
# Classifier training loss: -160.854838
# Adversary training loss: 1.609325
# Epoch 13
# -------------------------------
# Classifier validation loss: -160.602549
# Adversary validation loss: 1.607200
# Classifier training loss: -160.880861
# Adversary training loss: 1.609592
# Epoch 14
# -------------------------------
# Classifier validation loss: -160.873863
# Adversary validation loss: 1.609443
# Classifier training loss: -160.876122
# Adversary training loss: 1.609537
# Epoch 15
# -------------------------------
# Classifier validation loss: -160.581911
# Adversary validation loss: 1.606668
# Classifier training loss: -160.898321
# Adversary training loss: 1.609726
# Done!

# %%
fig, ax1 = plt.subplots()


#ax1.plot(np.arange(len(Training_losses_adv))+1, Training_losses_adv, 'k-', label='Training Adversary')
ax1.plot(np.arange(len(Validation_losses_adv))+1, Validation_losses_adv, 'k-', label='Validation Adversary')

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Adversary Loss', color='k')
ax1.tick_params(axis='y', labelcolor='k')

ax2 = ax1.twinx()

#ax2.plot(np.arange(len(Training_losses_clas))+1, Training_losses_clas, 'r-', label='Training Classifier')
ax2.plot(np.arange(len(Validation_losses_clas))+1, Validation_losses_clas, 'r-', label='Validation Classifier')

ax2.set_ylabel('Classifier Loss', color='r')
ax2.tick_params(axis='y', labelcolor='r')

# %%
# Save the adversarially trained models
torch.save(final_clas_adv.state_dict(), "/Users/mghrear/data/ML_data/patch/classifier_adv_2021_v9_pass5_run"+str(run)+".pt")
torch.save(final_adv_adv.state_dict(), "/Users/mghrear/data/ML_data/patch/adversary_adv_2021_v9_pass5_run"+str(run)+".pt")

# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import torch 
from torch import nn, optim
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import sklearn
from sklearn.model_selection import train_test_split
import copy
import mytools
from scipy.stats import ks_2samp, wasserstein_distance


# Print and store device being used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cpu

# %% [markdown]
# # Define important parameters

# %%
# Number of class in invariant mass used by the adversary
Num_classes = 5
# Hyper-parameter for adversarial training of the classifier
lambda_ = 100.0

run = 1

# %% [markdown]
# # Load and setup the data

# %%
df_tritrig = pd.read_pickle('/Users/mghrear/data/ML_data/patch/2021_v9_pass5_tritrig_limited.pk')
df_tritrig['PhiKK'] = 0.0 # Add label
df_phiKK = pd.read_pickle('/Users/mghrear/data/ML_data/patch/2021_v9_pass5_phiKK_limited.pk')
df_phiKK['PhiKK'] = 1.0 # Add label
df_wab = pd.read_pickle('/Users/mghrear/data/ML_data/patch/2021_v9_pass5_wab_limited.pk')
df_wab['PhiKK'] = 0.0 # Add label

df_data_train_bkg = pd.read_pickle('/Users/mghrear/data/ML_data/patch/2021_v9_pass5_data_limited_sideband_a_train_bkg.pk')
df_data_train_bkg['PhiKK'] = 0.0 # Add label

df_data = pd.read_pickle('/Users/mghrear/data/ML_data/patch/2021_v9_pass5_data_limited_sideband_a_test.pk')

print("phiKK: ", len(df_phiKK))
print("data bkg: ", len(df_data_train_bkg))
print("data: ", len(df_data))
# Out:
# phiKK:  4086
# data bkg:  23995
# data:  163958

# %%
phiKK_train = df_phiKK[0:3000]


# Combine and shuffle all training data
df_train = pd.concat([phiKK_train, df_data_train_bkg], ignore_index=True, sort=False)
df_train = df_train.sample(frac=1, random_state=42).reset_index(drop=True)

# Get edges in invariant mass classes for one-hot encoding
# To be used for adverserial labels
# The edges are chosen such that each bin has equal number of background events
one_hot_edges = mytools.get_one_hot_edges(mytools.get_InvM( df_data ), n_bins=Num_classes)

# Split the training data into training and validation sets
df_train, df_val = train_test_split(df_train, test_size=0.33, random_state=41)

# Make X and y for training and validation sets
# the adverserial network has its own labels
X_train = df_train.drop(columns=['PhiKK'])
y_train = df_train['PhiKK']
y_adv_train = mytools.get_adv_labels( mytools.get_InvM(df_train), one_hot_edges)
X_val = df_val.drop(columns=['PhiKK'])
y_val = df_val['PhiKK']
y_adv_val = mytools.get_adv_labels( mytools.get_InvM(df_val), one_hot_edges)

# Make testing set with remaining events
tritrig_test = df_tritrig[20000:]
tritrig_test['type']= 'tritrig'
wab_test = df_wab[3000:]
wab_test['type']= 'wab'
phiKK_test = df_phiKK[3000:]
phiKK_test['type']= 'phiKK'

# This is just used for an invariance test
df_test = pd.concat([tritrig_test, phiKK_test,wab_test], ignore_index=True, sort=False)
df_test = df_test.sample(frac=1, random_state=42).reset_index(drop=True) # Now shuffle the combined dataframe

X_test = df_test.drop(columns=['PhiKK','type'])
y_test = df_test['PhiKK']
y_adv_test = mytools.get_adv_labels( mytools.get_InvM(df_test), one_hot_edges)

df_test["InvM"] = mytools.get_InvM(df_test) 



# Make final data set
X_final = df_data
# Out:
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_66366/3652916753.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tritrig_test['type']= 'tritrig'
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_66366/3652916753.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wab_test['type']= 'wab'
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_66366/3652916753.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phiKK_test['type']= 'phiKK'

# %% [markdown]
# # Setup the classifier model

# %% [markdown]
# ## Setup dataloaders

# %%
bsize = 512

# Convert to tensor dataset and dataloader
train_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy().astype(np.float32))  , torch.from_numpy(y_train.to_numpy().astype(np.float32)).unsqueeze(1)  )
train_loader = DataLoader(train_dataset, batch_size=bsize, shuffle=True)

val_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy().astype(np.float32))  , torch.from_numpy(y_val.to_numpy().astype(np.float32)).unsqueeze(1)  )
val_loader = DataLoader(val_dataset, batch_size=bsize, shuffle=True)

test_dataset = TensorDataset(torch.from_numpy(X_test.to_numpy().astype(np.float32))  )
test_loader = DataLoader(test_dataset, batch_size=bsize, shuffle=False)

# %% [markdown]
# ## Initialize model, objective function, and optimizer

# %%
clas = mytools.Classifier(in_features=X_train.shape[1]).to(device)
criterion_clas = nn.BCEWithLogitsLoss()
optimizer_clas = optim.Adam(clas.parameters(), lr=1e-5)
scheduler_clas = torch.optim.lr_scheduler.ExponentialLR(optimizer_clas, gamma=0.99995)

# %% [markdown]
# ## Pre-train the classifier

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 10

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 500
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train_clas(train_loader, clas, criterion_clas, optimizer_clas, scheduler_clas, device))
    Validation_losses = np.append(Validation_losses, mytools.validate_clas(val_loader, clas, criterion_clas, device))
    
    # Keep a running copy of the model with the lowest loss
    if Validation_losses[-1] == np.min(Validation_losses):
        final_classifier = copy.deepcopy(clas)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Training loss: 0.896045
# Validation loss: 0.908534
#
# Epoch 2
# -------------------------------
# Training loss: 0.848128
# Validation loss: 0.810205
#
# Epoch 3
# -------------------------------
# Training loss: 0.817430
# Validation loss: 0.789837
#
# Epoch 4
# -------------------------------
# Training loss: 0.794704
# Validation loss: 0.766563
#
# Epoch 5
# -------------------------------
# Training loss: 0.773376
# Validation loss: 0.763088
#
# Epoch 6
# -------------------------------
# Training loss: 0.758785
# Validation loss: 0.746788
#
# Epoch 7
# -------------------------------
# Training loss: 0.746748
# Validation loss: 0.728617
#
# Epoch 8
# -------------------------------
# Training loss: 0.735414
# Validation loss: 0.727239
#
# Epoch 9
# -------------------------------
# Training loss: 0.722057
# Validation loss: 0.712731
#
# Epoch 10
# -------------------------------
# Training loss: 0.712753
# Validation loss: 0.697634
#
# Epoch 11
# -------------------------------
# Training loss: 0.703771
# Validation loss: 0.695312
#
# Epoch 12
# -------------------------------
# Training loss: 0.690688
# Validation loss: 0.677493
#
# Epoch 13
# -------------------------------
# Training loss: 0.683499
# Validation loss: 0.672053
#
# Epoch 14
# -------------------------------
# Training loss: 0.681448
# Validation loss: 0.675034
#
# Epoch 15
# -------------------------------
# Training loss: 0.671632
# Validation loss: 0.663816
#
# Epoch 16
# -------------------------------
# Training loss: 0.662080
# Validation loss: 0.649231
#
# Epoch 17
# -------------------------------
# Training loss: 0.657596
# Validation loss: 0.656757
#
# Epoch 18
# -------------------------------
# Training loss: 0.650017
# Validation loss: 0.639372
#
# Epoch 19
# -------------------------------
# Training loss: 0.642283
# Validation loss: 0.620016
#
# Epoch 20
# -------------------------------
# Training loss: 0.637497
# Validation loss: 0.626432
#
# Epoch 21
# -------------------------------
# Training loss: 0.633155
# Validation loss: 0.621381
#
# Epoch 22
# -------------------------------
# Training loss: 0.624880
# Validation loss: 0.621481
#
# Epoch 23
# -------------------------------
# Training loss: 0.616469
# Validation loss: 0.617494
#
# Epoch 24
# -------------------------------
# Training loss: 0.613296
# Validation loss: 0.603199
#
# Epoch 25
# -------------------------------
# Training loss: 0.606130
# Validation loss: 0.596426
#
# Epoch 26
# -------------------------------
# Training loss: 0.601532
# Validation loss: 0.589320
#
# Epoch 27
# -------------------------------
# Training loss: 0.596117
# Validation loss: 0.579823
#
# Epoch 28
# -------------------------------
# Training loss: 0.589869
# Validation loss: 0.570579
#
# Epoch 29
# -------------------------------
# Training loss: 0.585420
# Validation loss: 0.580304
#
# Epoch 30
# -------------------------------
# Training loss: 0.582741
# Validation loss: 0.558609
#
# Epoch 31
# -------------------------------
# Training loss: 0.574628
# Validation loss: 0.565262
#
# Epoch 32
# -------------------------------
# Training loss: 0.570732
# Validation loss: 0.559126
#
# Epoch 33
# -------------------------------
# Training loss: 0.567155
# Validation loss: 0.564079
#
# Epoch 34
# -------------------------------
# Training loss: 0.567290
# Validation loss: 0.555934
#
# Epoch 35
# -------------------------------
# Training loss: 0.562579
# Validation loss: 0.539804
#
# Epoch 36
# -------------------------------
# Training loss: 0.556987
# Validation loss: 0.543932
#
# Epoch 37
# -------------------------------
# Training loss: 0.550865
# Validation loss: 0.543530
#
# Epoch 38
# -------------------------------
# Training loss: 0.548135
# Validation loss: 0.546164
#
# Epoch 39
# -------------------------------
# Training loss: 0.545705
# Validation loss: 0.539241
#
# Epoch 40
# -------------------------------
# Training loss: 0.541768
# Validation loss: 0.524330
#
# Epoch 41
# -------------------------------
# Training loss: 0.539468
# Validation loss: 0.535915
#
# Epoch 42
# -------------------------------
# Training loss: 0.539725
# Validation loss: 0.529976
#
# Epoch 43
# -------------------------------
# Training loss: 0.531990
# Validation loss: 0.529620
#
# Epoch 44
# -------------------------------
# Training loss: 0.530085
# Validation loss: 0.521207
#
# Epoch 45
# -------------------------------
# Training loss: 0.524399
# Validation loss: 0.514858
#
# Epoch 46
# -------------------------------
# Training loss: 0.523626
# Validation loss: 0.517738
#
# Epoch 47
# -------------------------------
# Training loss: 0.520042
# Validation loss: 0.511091
#
# Epoch 48
# -------------------------------
# Training loss: 0.514382
# Validation loss: 0.500625
#
# Epoch 49
# -------------------------------
# Training loss: 0.513474
# Validation loss: 0.496447
#
# Epoch 50
# -------------------------------
# Training loss: 0.510001
# Validation loss: 0.504963
#
# Epoch 51
# -------------------------------
# Training loss: 0.508895
# Validation loss: 0.499407
#
# Epoch 52
# -------------------------------
# Training loss: 0.504854
# Validation loss: 0.489140
#
# Epoch 53
# -------------------------------
# Training loss: 0.500666
# Validation loss: 0.507960
#
# Epoch 54
# -------------------------------
# Training loss: 0.498472
# Validation loss: 0.496656
#
# Epoch 55
# -------------------------------
# Training loss: 0.496757
# Validation loss: 0.493489
#
# Epoch 56
# -------------------------------
# Training loss: 0.493546
# Validation loss: 0.489602
#
# Epoch 57
# -------------------------------
# Training loss: 0.491414
# Validation loss: 0.484860
#
# Epoch 58
# -------------------------------
# Training loss: 0.488222
# Validation loss: 0.477953
#
# Epoch 59
# -------------------------------
# Training loss: 0.484722
# Validation loss: 0.482128
#
# Epoch 60
# -------------------------------
# Training loss: 0.484132
# Validation loss: 0.487083
#
# Epoch 61
# -------------------------------
# Training loss: 0.480218
# Validation loss: 0.471694
#
# Epoch 62
# -------------------------------
# Training loss: 0.479696
# Validation loss: 0.482980
#
# Epoch 63
# -------------------------------
# Training loss: 0.474003
# Validation loss: 0.466559
#
# Epoch 64
# -------------------------------
# Training loss: 0.471398
# Validation loss: 0.470624
#
# Epoch 65
# -------------------------------
# Training loss: 0.470221
# Validation loss: 0.454609
#
# Epoch 66
# -------------------------------
# Training loss: 0.467481
# Validation loss: 0.464742
#
# Epoch 67
# -------------------------------
# Training loss: 0.467698
# Validation loss: 0.451498
#
# Epoch 68
# -------------------------------
# Training loss: 0.464963
# Validation loss: 0.454785
#
# Epoch 69
# -------------------------------
# Training loss: 0.462071
# Validation loss: 0.451004
#
# Epoch 70
# -------------------------------
# Training loss: 0.460740
# Validation loss: 0.437837
#
# Epoch 71
# -------------------------------
# Training loss: 0.457391
# Validation loss: 0.448126
#
# Epoch 72
# -------------------------------
# Training loss: 0.454467
# Validation loss: 0.450292
#
# Epoch 73
# -------------------------------
# Training loss: 0.452057
# Validation loss: 0.455255
#
# Epoch 74
# -------------------------------
# Training loss: 0.449382
# Validation loss: 0.439826
#
# Epoch 75
# -------------------------------
# Training loss: 0.448411
# Validation loss: 0.437244
#
# Epoch 76
# -------------------------------
# Training loss: 0.444672
# Validation loss: 0.434712
#
# Epoch 77
# -------------------------------
# Training loss: 0.443595
# Validation loss: 0.439682
#
# Epoch 78
# -------------------------------
# Training loss: 0.442219
# Validation loss: 0.436878
#
# Epoch 79
# -------------------------------
# Training loss: 0.437374
# Validation loss: 0.419225
#
# Epoch 80
# -------------------------------
# Training loss: 0.434499
# Validation loss: 0.444544
#
# Epoch 81
# -------------------------------
# Training loss: 0.433981
# Validation loss: 0.427512
#
# Epoch 82
# -------------------------------
# Training loss: 0.430786
# Validation loss: 0.415538
#
# Epoch 83
# -------------------------------
# Training loss: 0.428663
# Validation loss: 0.411630
#
# Epoch 84
# -------------------------------
# Training loss: 0.430183
# Validation loss: 0.454262
#
# Epoch 85
# -------------------------------
# Training loss: 0.425012
# Validation loss: 0.407492
#
# Epoch 86
# -------------------------------
# Training loss: 0.421951
# Validation loss: 0.410728
#
# Epoch 87
# -------------------------------
# Training loss: 0.416907
# Validation loss: 0.400139
#
# Epoch 88
# -------------------------------
# Training loss: 0.417094
# Validation loss: 0.398368
#
# Epoch 89
# -------------------------------
# Training loss: 0.412293
# Validation loss: 0.415432
#
# Epoch 90
# -------------------------------
# Training loss: 0.406941
# Validation loss: 0.427790
#
# Epoch 91
# -------------------------------
# Training loss: 0.403299
# Validation loss: 0.396108
#
# Epoch 92
# -------------------------------
# Training loss: 0.403480
# Validation loss: 0.393024
#
# Epoch 93
# -------------------------------
# Training loss: 0.401670
# Validation loss: 0.390899
#
# Epoch 94
# -------------------------------
# Training loss: 0.393558
# Validation loss: 0.460476
#
# Epoch 95
# -------------------------------
# Training loss: 0.393125
# Validation loss: 0.383940
#
# Epoch 96
# -------------------------------
# Training loss: 0.389815
# Validation loss: 0.403240
#
# Epoch 97
# -------------------------------
# Training loss: 0.388162
# Validation loss: 0.378667
#
# Epoch 98
# -------------------------------
# Training loss: 0.384009
# Validation loss: 0.378262
#
# Epoch 99
# -------------------------------
# Training loss: 0.379203
# Validation loss: 0.603975
#
# Epoch 100
# -------------------------------
# Training loss: 0.376600
# Validation loss: 0.373097
#
# Epoch 101
# -------------------------------
# Training loss: 0.374894
# Validation loss: 0.377817
#
# Epoch 102
# -------------------------------
# Training loss: 0.372969
# Validation loss: 0.351613
#
# Epoch 103
# -------------------------------
# Training loss: 0.368353
# Validation loss: 0.488258
#
# Epoch 104
# -------------------------------
# Training loss: 0.361549
# Validation loss: 0.352268
#
# Epoch 105
# -------------------------------
# Training loss: 0.362998
# Validation loss: 0.361141
#
# Epoch 106
# -------------------------------
# Training loss: 0.357755
# Validation loss: 0.347978
#
# Epoch 107
# -------------------------------
# Training loss: 0.357635
# Validation loss: 0.392888
#
# Epoch 108
# -------------------------------
# Training loss: 0.354467
# Validation loss: 0.344263
#
# Epoch 109
# -------------------------------
# Training loss: 0.350664
# Validation loss: 0.341010
#
# Epoch 110
# -------------------------------
# Training loss: 0.347968
# Validation loss: 0.332312
#
# Epoch 111
# -------------------------------
# Training loss: 0.345534
# Validation loss: 0.338795
#
# Epoch 112
# -------------------------------
# Training loss: 0.342496
# Validation loss: 0.321365
#
# Epoch 113
# -------------------------------
# Training loss: 0.340631
# Validation loss: 0.379414
#
# Epoch 114
# -------------------------------
# Training loss: 0.336688
# Validation loss: 0.327278
#
# Epoch 115
# -------------------------------
# Training loss: 0.333480
# Validation loss: 0.319940
#
# Epoch 116
# -------------------------------
# Training loss: 0.332456
# Validation loss: 0.345581
#
# Epoch 117
# -------------------------------
# Training loss: 0.330789
# Validation loss: 0.317747
#
# Epoch 118
# -------------------------------
# Training loss: 0.330223
# Validation loss: 0.310677
#
# Epoch 119
# -------------------------------
# Training loss: 0.326858
# Validation loss: 0.400842
#
# Epoch 120
# -------------------------------
# Training loss: 0.325237
# Validation loss: 0.311378
#
# Epoch 121
# -------------------------------
# Training loss: 0.328283
# Validation loss: 0.312741
#
# Epoch 122
# -------------------------------
# Training loss: 0.322515
# Validation loss: 0.323068
#
# Epoch 123
# -------------------------------
# Training loss: 0.319238
# Validation loss: 0.398694
#
# Epoch 124
# -------------------------------
# Training loss: 0.319678
# Validation loss: 0.310844
#
# Epoch 125
# -------------------------------
# Training loss: 0.314814
# Validation loss: 0.323996
#
# Epoch 126
# -------------------------------
# Training loss: 0.311298
# Validation loss: 0.316846
#
# Epoch 127
# -------------------------------
# Training loss: 0.311226
# Validation loss: 0.351101
#
# Epoch 128
# -------------------------------
# Training loss: 0.308708
# Validation loss: 0.303276
#
# Epoch 129
# -------------------------------
# Training loss: 0.310910
# Validation loss: 0.304372
#
# Epoch 130
# -------------------------------
# Training loss: 0.306900
# Validation loss: 0.298202
#
# Epoch 131
# -------------------------------
# Training loss: 0.305058
# Validation loss: 0.309822
#
# Epoch 132
# -------------------------------
# Training loss: 0.305691
# Validation loss: 0.349990
#
# Epoch 133
# -------------------------------
# Training loss: 0.301311
# Validation loss: 0.292984
#
# Epoch 134
# -------------------------------
# Training loss: 0.300518
# Validation loss: 0.304767
#
# Epoch 135
# -------------------------------
# Training loss: 0.298817
# Validation loss: 0.298372
#
# Epoch 136
# -------------------------------
# Training loss: 0.296735
# Validation loss: 0.407840
#
# Epoch 137
# -------------------------------
# Training loss: 0.297082
# Validation loss: 0.312040
#
# Epoch 138
# -------------------------------
# Training loss: 0.294379
# Validation loss: 0.284478
#
# Epoch 139
# -------------------------------
# Training loss: 0.290891
# Validation loss: 0.315028
#
# Epoch 140
# -------------------------------
# Training loss: 0.291115
# Validation loss: 0.337973
#
# Epoch 141
# -------------------------------
# Training loss: 0.288547
# Validation loss: 0.282406
#
# Epoch 142
# -------------------------------
# Training loss: 0.287780
# Validation loss: 0.280703
#
# Epoch 143
# -------------------------------
# Training loss: 0.288934
# Validation loss: 0.277988
#
# Epoch 144
# -------------------------------
# Training loss: 0.287136
# Validation loss: 0.275748
#
# Epoch 145
# -------------------------------
# Training loss: 0.284478
# Validation loss: 0.293740
#
# Epoch 146
# -------------------------------
# Training loss: 0.282555
# Validation loss: 0.319075
#
# Epoch 147
# -------------------------------
# Training loss: 0.280656
# Validation loss: 0.269714
#
# Epoch 148
# -------------------------------
# Training loss: 0.280402
# Validation loss: 0.270146
#
# Epoch 149
# -------------------------------
# Training loss: 0.281117
# Validation loss: 0.275737
#
# Epoch 150
# -------------------------------
# Training loss: 0.277628
# Validation loss: 0.270121
#
# Epoch 151
# -------------------------------
# Training loss: 0.279063
# Validation loss: 0.275166
#
# Epoch 152
# -------------------------------
# Training loss: 0.276119
# Validation loss: 0.281418
#
# Epoch 153
# -------------------------------
# Training loss: 0.272033
# Validation loss: 0.353050
#
# Epoch 154
# -------------------------------
# Training loss: 0.271599
# Validation loss: 0.284335
#
# Epoch 155
# -------------------------------
# Training loss: 0.272285
# Validation loss: 0.312462
#
# Epoch 156
# -------------------------------
# Training loss: 0.272112
# Validation loss: 0.270284
#
# Epoch 157
# -------------------------------
# Training loss: 0.272351
# Validation loss: 0.269121
#
# Epoch 158
# -------------------------------
# Training loss: 0.268770
# Validation loss: 0.299329
#
# Epoch 159
# -------------------------------
# Training loss: 0.266867
# Validation loss: 0.264613
#
# Epoch 160
# -------------------------------
# Training loss: 0.268450
# Validation loss: 0.265085
#
# Epoch 161
# -------------------------------
# Training loss: 0.270587
# Validation loss: 0.280062
#
# Epoch 162
# -------------------------------
# Training loss: 0.262660
# Validation loss: 0.278936
#
# Epoch 163
# -------------------------------
# Training loss: 0.263307
# Validation loss: 0.255681
#
# Epoch 164
# -------------------------------
# Training loss: 0.259543
# Validation loss: 0.250175
#
# Epoch 165
# -------------------------------
# Training loss: 0.260246
# Validation loss: 0.254026
#
# Epoch 166
# -------------------------------
# Training loss: 0.259211
# Validation loss: 0.290856
#
# Epoch 167
# -------------------------------
# Training loss: 0.256862
# Validation loss: 0.281999
#
# Epoch 168
# -------------------------------
# Training loss: 0.260470
# Validation loss: 0.339099
#
# Epoch 169
# -------------------------------
# Training loss: 0.255296
# Validation loss: 0.252839
#
# Epoch 170
# -------------------------------
# Training loss: 0.261372
# Validation loss: 0.262523
#
# Epoch 171
# -------------------------------
# Training loss: 0.258063
# Validation loss: 0.249740
#
# Epoch 172
# -------------------------------
# Training loss: 0.251278
# Validation loss: 0.344064
#
# Epoch 173
# -------------------------------
# Training loss: 0.252805
# Validation loss: 0.253550
#
# Epoch 174
# -------------------------------
# Training loss: 0.255452
# Validation loss: 0.253155
#
# Epoch 175
# -------------------------------
# Training loss: 0.249995
# Validation loss: 0.453811
#
# Epoch 176
# -------------------------------
# Training loss: 0.249369
# Validation loss: 0.244415
#
# Epoch 177
# -------------------------------
# Training loss: 0.245965
# Validation loss: 0.243584
#
# Epoch 178
# -------------------------------
# Training loss: 0.244927
# Validation loss: 0.252013
#
# Epoch 179
# -------------------------------
# Training loss: 0.242668
# Validation loss: 0.240770
#
# Epoch 180
# -------------------------------
# Training loss: 0.242053
# Validation loss: 0.252093
#
# Epoch 181
# -------------------------------
# Training loss: 0.240287
# Validation loss: 0.338446
#
# Epoch 182
# -------------------------------
# Training loss: 0.242348
# Validation loss: 0.248529
#
# Epoch 183
# -------------------------------
# Training loss: 0.239162
# Validation loss: 0.240537
#
# Epoch 184
# -------------------------------
# Training loss: 0.239348
# Validation loss: 0.231858
#
# Epoch 185
# -------------------------------
# Training loss: 0.239504
# Validation loss: 0.311908
#
# Epoch 186
# -------------------------------
# Training loss: 0.239709
# Validation loss: 0.361622
#
# Epoch 187
# -------------------------------
# Training loss: 0.237369
# Validation loss: 0.234691
#
# Epoch 188
# -------------------------------
# Training loss: 0.237503
# Validation loss: 0.226303
#
# Epoch 189
# -------------------------------
# Training loss: 0.235384
# Validation loss: 0.246479
#
# Epoch 190
# -------------------------------
# Training loss: 0.236158
# Validation loss: 0.225836
#
# Epoch 191
# -------------------------------
# Training loss: 0.228889
# Validation loss: 0.234411
#
# Epoch 192
# -------------------------------
# Training loss: 0.229055
# Validation loss: 0.237008
#
# Epoch 193
# -------------------------------
# Training loss: 0.229357
# Validation loss: 0.238640
#
# Epoch 194
# -------------------------------
# Training loss: 0.229283
# Validation loss: 0.374907
#
# Epoch 195
# -------------------------------
# Training loss: 0.228638
# Validation loss: 0.231501
#
# Epoch 196
# -------------------------------
# Training loss: 0.226100
# Validation loss: 0.233147
#
# Epoch 197
# -------------------------------
# Training loss: 0.227073
# Validation loss: 0.218290
#
# Epoch 198
# -------------------------------
# Training loss: 0.224422
# Validation loss: 0.269530
#
# Epoch 199
# -------------------------------
# Training loss: 0.223290
# Validation loss: 0.254570
#
# Epoch 200
# -------------------------------
# Training loss: 0.221552
# Validation loss: 0.222205
#
# Epoch 201
# -------------------------------
# Training loss: 0.223295
# Validation loss: 0.344725
#
# Epoch 202
# -------------------------------
# Training loss: 0.219717
# Validation loss: 0.219943
#
# Epoch 203
# -------------------------------
# Training loss: 0.216863
# Validation loss: 0.333015
#
# Epoch 204
# -------------------------------
# Training loss: 0.213884
# Validation loss: 0.221341
#
# Epoch 205
# -------------------------------
# Training loss: 0.214857
# Validation loss: 0.332714
#
# Epoch 206
# -------------------------------
# Training loss: 0.215949
# Validation loss: 0.225378
#
# Epoch 207
# -------------------------------
# Training loss: 0.211947
# Validation loss: 0.211663
#
# Epoch 208
# -------------------------------
# Training loss: 0.212824
# Validation loss: 0.256121
#
# Epoch 209
# -------------------------------
# Training loss: 0.209336
# Validation loss: 0.347470
#
# Epoch 210
# -------------------------------
# Training loss: 0.212811
# Validation loss: 0.206086
#
# Epoch 211
# -------------------------------
# Training loss: 0.209865
# Validation loss: 0.221902
#
# Epoch 212
# -------------------------------
# Training loss: 0.208318
# Validation loss: 0.266177
#
# Epoch 213
# -------------------------------
# Training loss: 0.206519
# Validation loss: 0.280349
#
# Epoch 214
# -------------------------------
# Training loss: 0.209564
# Validation loss: 0.300862
#
# Epoch 215
# -------------------------------
# Training loss: 0.204215
# Validation loss: 0.209124
#
# Epoch 216
# -------------------------------
# Training loss: 0.203575
# Validation loss: 0.275409
#
# Epoch 217
# -------------------------------
# Training loss: 0.200647
# Validation loss: 0.195225
#
# Epoch 218
# -------------------------------
# Training loss: 0.197667
# Validation loss: 0.213928
#
# Epoch 219
# -------------------------------
# Training loss: 0.200233
# Validation loss: 0.217129
#
# Epoch 220
# -------------------------------
# Training loss: 0.195890
# Validation loss: 0.324164
#
# Epoch 221
# -------------------------------
# Training loss: 0.198370
# Validation loss: 0.509139
#
# Epoch 222
# -------------------------------
# Training loss: 0.197639
# Validation loss: 0.218223
#
# Epoch 223
# -------------------------------
# Training loss: 0.191527
# Validation loss: 0.218090
#
# Epoch 224
# -------------------------------
# Training loss: 0.191924
# Validation loss: 0.200172
#
# Epoch 225
# -------------------------------
# Training loss: 0.189928
# Validation loss: 0.230655
#
# Epoch 226
# -------------------------------
# Training loss: 0.194541
# Validation loss: 0.193859
#
# Epoch 227
# -------------------------------
# Training loss: 0.190711
# Validation loss: 0.181654
#
# Epoch 228
# -------------------------------
# Training loss: 0.189949
# Validation loss: 0.178658
#
# Epoch 229
# -------------------------------
# Training loss: 0.187832
# Validation loss: 0.179059
#
# Epoch 230
# -------------------------------
# Training loss: 0.184781
# Validation loss: 0.342142
#
# Epoch 231
# -------------------------------
# Training loss: 0.182123
# Validation loss: 0.528896
#
# Epoch 232
# -------------------------------
# Training loss: 0.183588
# Validation loss: 0.207105
#
# Epoch 233
# -------------------------------
# Training loss: 0.187110
# Validation loss: 0.177099
#
# Epoch 234
# -------------------------------
# Training loss: 0.181001
# Validation loss: 0.361070
#
# Epoch 235
# -------------------------------
# Training loss: 0.186303
# Validation loss: 0.187883
#
# Epoch 236
# -------------------------------
# Training loss: 0.177916
# Validation loss: 0.187466
#
# Epoch 237
# -------------------------------
# Training loss: 0.178985
# Validation loss: 0.196191
#
# Epoch 238
# -------------------------------
# Training loss: 0.178491
# Validation loss: 0.176450
#
# Epoch 239
# -------------------------------
# Training loss: 0.181939
# Validation loss: 0.177031
#
# Epoch 240
# -------------------------------
# Training loss: 0.175795
# Validation loss: 0.173667
#
# Epoch 241
# -------------------------------
# Training loss: 0.175200
# Validation loss: 0.721909
#
# Epoch 242
# -------------------------------
# Training loss: 0.175098
# Validation loss: 0.234555
#
# Epoch 243
# -------------------------------
# Training loss: 0.172940
# Validation loss: 0.166856
#
# Epoch 244
# -------------------------------
# Training loss: 0.172013
# Validation loss: 0.215584
#
# Epoch 245
# -------------------------------
# Training loss: 0.171406
# Validation loss: 0.218792
#
# Epoch 246
# -------------------------------
# Training loss: 0.170938
# Validation loss: 0.166328
#
# Epoch 247
# -------------------------------
# Training loss: 0.168081
# Validation loss: 0.184423
#
# Epoch 248
# -------------------------------
# Training loss: 0.172059
# Validation loss: 0.177203
#
# Epoch 249
# -------------------------------
# Training loss: 0.168772
# Validation loss: 0.174535
#
# Epoch 250
# -------------------------------
# Training loss: 0.169466
# Validation loss: 0.190014
#
# Epoch 251
# -------------------------------
# Training loss: 0.166912
# Validation loss: 0.252474
#
# Epoch 252
# -------------------------------
# Training loss: 0.167562
# Validation loss: 0.173885
#
# Epoch 253
# -------------------------------
# Training loss: 0.164070
# Validation loss: 0.194649
#
# Epoch 254
# -------------------------------
# Training loss: 0.163138
# Validation loss: 0.327621
#
# Epoch 255
# -------------------------------
# Training loss: 0.162139
# Validation loss: 0.534797
#
# Epoch 256
# -------------------------------
# Training loss: 0.161843
# Validation loss: 0.173177
#
# Epoch 257
# -------------------------------
# Training loss: 0.157775
# Validation loss: 0.289679
#
# Epoch 258
# -------------------------------
# Training loss: 0.156416
# Validation loss: 0.197067
#
# Epoch 259
# -------------------------------
# Training loss: 0.160942
# Validation loss: 0.146784
#
# Epoch 260
# -------------------------------
# Training loss: 0.159567
# Validation loss: 0.164620
#
# Epoch 261
# -------------------------------
# Training loss: 0.157940
# Validation loss: 0.153413
#
# Epoch 262
# -------------------------------
# Training loss: 0.156109
# Validation loss: 0.368737
#
# Epoch 263
# -------------------------------
# Training loss: 0.155121
# Validation loss: 0.160122
#
# Epoch 264
# -------------------------------
# Training loss: 0.152846
# Validation loss: 0.236414
#
# Epoch 265
# -------------------------------
# Training loss: 0.155735
# Validation loss: 0.163734
#
# Epoch 266
# -------------------------------
# Training loss: 0.157935
# Validation loss: 0.150397
#
# Epoch 267
# -------------------------------
# Training loss: 0.155722
# Validation loss: 0.211743
#
# Epoch 268
# -------------------------------
# Training loss: 0.155327
# Validation loss: 0.178325
#
# Epoch 269
# -------------------------------
# Training loss: 0.153362
# Validation loss: 0.154494
#
# Epoch 270
# -------------------------------
# Training loss: 0.150467
# Validation loss: 0.142194
#
# Epoch 271
# -------------------------------
# Training loss: 0.151913
# Validation loss: 0.191494
#
# Epoch 272
# -------------------------------
# Training loss: 0.150098
# Validation loss: 0.154101
#
# Epoch 273
# -------------------------------
# Training loss: 0.155383
# Validation loss: 0.200910
#
# Epoch 274
# -------------------------------
# Training loss: 0.150197
# Validation loss: 0.167918
#
# Epoch 275
# -------------------------------
# Training loss: 0.147174
# Validation loss: 0.173280
#
# Epoch 276
# -------------------------------
# Training loss: 0.147781
# Validation loss: 0.337493
#
# Epoch 277
# -------------------------------
# Training loss: 0.150459
# Validation loss: 0.140356
#
# Epoch 278
# -------------------------------
# Training loss: 0.147037
# Validation loss: 0.168255
#
# Epoch 279
# -------------------------------
# Training loss: 0.144721
# Validation loss: 0.175611
#
# Epoch 280
# -------------------------------
# Training loss: 0.144333
# Validation loss: 0.134324
#
# Epoch 281
# -------------------------------
# Training loss: 0.150086
# Validation loss: 0.159664
#
# Epoch 282
# -------------------------------
# Training loss: 0.142377
# Validation loss: 0.143521
#
# Epoch 283
# -------------------------------
# Training loss: 0.141046
# Validation loss: 0.145907
#
# Epoch 284
# -------------------------------
# Training loss: 0.141938
# Validation loss: 0.150145
#
# Epoch 285
# -------------------------------
# Training loss: 0.144594
# Validation loss: 0.326047
#
# Epoch 286
# -------------------------------
# Training loss: 0.139959
# Validation loss: 0.148385
#
# Epoch 287
# -------------------------------
# Training loss: 0.141204
# Validation loss: 0.161287
#
# Epoch 288
# -------------------------------
# Training loss: 0.141982
# Validation loss: 0.150697
#
# Epoch 289
# -------------------------------
# Training loss: 0.141225
# Validation loss: 0.172841
#
# Epoch 290
# -------------------------------
# Training loss: 0.143141
# Validation loss: 0.159225
#
# Epoch 291
# -------------------------------
# Training loss: 0.139849
# Validation loss: 0.160212
#
# Epoch 292
# -------------------------------
# Training loss: 0.140507
# Validation loss: 0.210179
#
# Epoch 293
# -------------------------------
# Training loss: 0.140230
# Validation loss: 0.160453
#
# Epoch 294
# -------------------------------
# Training loss: 0.139232
# Validation loss: 0.194810
#
# Epoch 295
# -------------------------------
# Training loss: 0.134762
# Validation loss: 0.144107
#
# Epoch 296
# -------------------------------
# Training loss: 0.137727
# Validation loss: 0.156515
#
# Epoch 297
# -------------------------------
# Training loss: 0.136856
# Validation loss: 0.139312
#
# Epoch 298
# -------------------------------
# Training loss: 0.137747
# Validation loss: 0.144817
#
# Epoch 299
# -------------------------------
# Training loss: 0.133948
# Validation loss: 0.724196
#
# Epoch 300
# -------------------------------
# Training loss: 0.132834
# Validation loss: 0.138441
#
# Epoch 301
# -------------------------------
# Training loss: 0.133509
# Validation loss: 0.255434
#
# Epoch 302
# -------------------------------
# Training loss: 0.137353
# Validation loss: 0.127523
#
# Epoch 303
# -------------------------------
# Training loss: 0.131871
# Validation loss: 0.359158
#
# Epoch 304
# -------------------------------
# Training loss: 0.135005
# Validation loss: 0.137820
#
# Epoch 305
# -------------------------------
# Training loss: 0.133473
# Validation loss: 0.196008
#
# Epoch 306
# -------------------------------
# Training loss: 0.134825
# Validation loss: 0.274547
#
# Epoch 307
# -------------------------------
# Training loss: 0.134601
# Validation loss: 0.153792
#
# Epoch 308
# -------------------------------
# Training loss: 0.135800
# Validation loss: 0.131615
#
# Epoch 309
# -------------------------------
# Training loss: 0.131766
# Validation loss: 0.167067
#
# Epoch 310
# -------------------------------
# Training loss: 0.133005
# Validation loss: 0.178306
#
# Epoch 311
# -------------------------------
# Training loss: 0.129314
# Validation loss: 0.134384
#
# Epoch 312
# -------------------------------
# Training loss: 0.133336
# Validation loss: 0.126456
#
# Epoch 313
# -------------------------------
# Training loss: 0.127524
# Validation loss: 0.123156
#
# Epoch 314
# -------------------------------
# Training loss: 0.127471
# Validation loss: 0.270568
#
# Epoch 315
# -------------------------------
# Training loss: 0.128641
# Validation loss: 0.134678
#
# Epoch 316
# -------------------------------
# Training loss: 0.126603
# Validation loss: 0.137495
#
# Epoch 317
# -------------------------------
# Training loss: 0.128002
# Validation loss: 0.168378
#
# Epoch 318
# -------------------------------
# Training loss: 0.125283
# Validation loss: 0.167313
#
# Epoch 319
# -------------------------------
# Training loss: 0.126813
# Validation loss: 0.229404
#
# Epoch 320
# -------------------------------
# Training loss: 0.127585
# Validation loss: 0.129256
#
# Epoch 321
# -------------------------------
# Training loss: 0.123587
# Validation loss: 0.146810
#
# Epoch 322
# -------------------------------
# Training loss: 0.125998
# Validation loss: 0.123286
#
# Epoch 323
# -------------------------------
# Training loss: 0.125141
# Validation loss: 0.130893
#
# Epoch 324
# -------------------------------
# Training loss: 0.123947
# Validation loss: 0.153731
#
# Epoch 325
# -------------------------------
# Training loss: 0.122810
# Validation loss: 0.609517
#
# Epoch 326
# -------------------------------
# Training loss: 0.126912
# Validation loss: 0.135382
#
# Epoch 327
# -------------------------------
# Training loss: 0.120902
# Validation loss: 0.117371
#
# Epoch 328
# -------------------------------
# Training loss: 0.121328
# Validation loss: 0.161101
#
# Epoch 329
# -------------------------------
# Training loss: 0.122063
# Validation loss: 0.120173
#
# Epoch 330
# -------------------------------
# Training loss: 0.119524
# Validation loss: 0.175342
#
# Epoch 331
# -------------------------------
# Training loss: 0.123367
# Validation loss: 0.216951
#
# Epoch 332
# -------------------------------
# Training loss: 0.123127
# Validation loss: 0.127331
#
# Epoch 333
# -------------------------------
# Training loss: 0.120177
# Validation loss: 0.148678
#
# Epoch 334
# -------------------------------
# Training loss: 0.118336
# Validation loss: 0.116219
#
# Epoch 335
# -------------------------------
# Training loss: 0.118749
# Validation loss: 0.389743
#
# Epoch 336
# -------------------------------
# Training loss: 0.121779
# Validation loss: 0.241193
#
# Epoch 337
# -------------------------------
# Training loss: 0.120305
# Validation loss: 0.145273
#
# Epoch 338
# -------------------------------
# Training loss: 0.116421
# Validation loss: 0.133853
#
# Epoch 339
# -------------------------------
# Training loss: 0.118147
# Validation loss: 0.119820
#
# Epoch 340
# -------------------------------
# Training loss: 0.116600
# Validation loss: 0.210606
#
# Epoch 341
# -------------------------------
# Training loss: 0.118087
# Validation loss: 0.327802
#
# Epoch 342
# -------------------------------
# Training loss: 0.120095
# Validation loss: 0.139861
#
# Epoch 343
# -------------------------------
# Training loss: 0.117784
# Validation loss: 0.116429
#
# Epoch 344
# -------------------------------
# Training loss: 0.115511
# Validation loss: 0.136118
#
# Epoch 345
# -------------------------------
# Training loss: 0.112938
# Validation loss: 0.121474
#
# Epoch 346
# -------------------------------
# Training loss: 0.113485
# Validation loss: 0.169555
#
# Epoch 347
# -------------------------------
# Training loss: 0.112613
# Validation loss: 0.121697
#
# Epoch 348
# -------------------------------
# Training loss: 0.115668
# Validation loss: 0.284361
#
# Epoch 349
# -------------------------------
# Training loss: 0.113864
# Validation loss: 0.112478
#
# Epoch 350
# -------------------------------
# Training loss: 0.115079
# Validation loss: 0.148532
#
# Epoch 351
# -------------------------------
# Training loss: 0.118664
# Validation loss: 0.155028
#
# Epoch 352
# -------------------------------
# Training loss: 0.112628
# Validation loss: 0.707912
#
# Epoch 353
# -------------------------------
# Training loss: 0.112550
# Validation loss: 0.153293
#
# Epoch 354
# -------------------------------
# Training loss: 0.112440
# Validation loss: 0.146925
#
# Epoch 355
# -------------------------------
# Training loss: 0.112888
# Validation loss: 0.143258
#
# Epoch 356
# -------------------------------
# Training loss: 0.111096
# Validation loss: 0.148572
#
# Epoch 357
# -------------------------------
# Training loss: 0.110441
# Validation loss: 0.161161
#
# Epoch 358
# -------------------------------
# Training loss: 0.111333
# Validation loss: 0.114020
#
# Epoch 359
# -------------------------------
# Training loss: 0.114802
# Validation loss: 0.116009
#
# Epoch 360
# -------------------------------
# Training loss: 0.115672
# Validation loss: 0.128278
#
# Epoch 361
# -------------------------------
# Training loss: 0.112107
# Validation loss: 0.163440
#
# Epoch 362
# -------------------------------
# Training loss: 0.110963
# Validation loss: 0.171885
#
# Epoch 363
# -------------------------------
# Training loss: 0.109799
# Validation loss: 0.109750
#
# Epoch 364
# -------------------------------
# Training loss: 0.110366
# Validation loss: 0.172461
#
# Epoch 365
# -------------------------------
# Training loss: 0.108534
# Validation loss: 0.116366
#
# Epoch 366
# -------------------------------
# Training loss: 0.110791
# Validation loss: 0.175937
#
# Epoch 367
# -------------------------------
# Training loss: 0.111054
# Validation loss: 0.462701
#
# Epoch 368
# -------------------------------
# Training loss: 0.109390
# Validation loss: 0.243123
#
# Epoch 369
# -------------------------------
# Training loss: 0.108723
# Validation loss: 0.123952
#
# Epoch 370
# -------------------------------
# Training loss: 0.108587
# Validation loss: 0.136608
#
# Epoch 371
# -------------------------------
# Training loss: 0.106476
# Validation loss: 0.114581
#
# Epoch 372
# -------------------------------
# Training loss: 0.109921
# Validation loss: 0.146931
#
# Epoch 373
# -------------------------------
# Training loss: 0.109672
# Validation loss: 0.107468
#
# Epoch 374
# -------------------------------
# Training loss: 0.110223
# Validation loss: 0.118355
#
# Epoch 375
# -------------------------------
# Training loss: 0.104539
# Validation loss: 0.177823
#
# Epoch 376
# -------------------------------
# Training loss: 0.105378
# Validation loss: 0.144914
#
# Epoch 377
# -------------------------------
# Training loss: 0.105131
# Validation loss: 0.111379
#
# Epoch 378
# -------------------------------
# Training loss: 0.105000
# Validation loss: 0.283488
#
# Epoch 379
# -------------------------------
# Training loss: 0.104131
# Validation loss: 0.143590
#
# Epoch 380
# -------------------------------
# Training loss: 0.105707
# Validation loss: 0.250107
#
# Epoch 381
# -------------------------------
# Training loss: 0.104610
# Validation loss: 0.108901
#
# Epoch 382
# -------------------------------
# Training loss: 0.104532
# Validation loss: 0.120238
#
# Epoch 383
# -------------------------------
# Training loss: 0.103820
# Validation loss: 0.193865
#
# Epoch 384
# -------------------------------
# Training loss: 0.101472
# Validation loss: 0.122801
#
# Epoch 385
# -------------------------------
# Training loss: 0.103315
# Validation loss: 0.156755
#
# Epoch 386
# -------------------------------
# Training loss: 0.102279
# Validation loss: 0.153678
#
# Epoch 387
# -------------------------------
# Training loss: 0.103958
# Validation loss: 0.138309
#
# Epoch 388
# -------------------------------
# Training loss: 0.101715
# Validation loss: 0.157113
#
# Epoch 389
# -------------------------------
# Training loss: 0.100784
# Validation loss: 0.109213
#
# Epoch 390
# -------------------------------
# Training loss: 0.099476
# Validation loss: 0.157563
#
# Epoch 391
# -------------------------------
# Training loss: 0.100597
# Validation loss: 0.721304
#
# Epoch 392
# -------------------------------
# Training loss: 0.101405
# Validation loss: 0.113425
#
# Epoch 393
# -------------------------------
# Training loss: 0.100895
# Validation loss: 0.141972
#
# Epoch 394
# -------------------------------
# Training loss: 0.098719
# Validation loss: 0.127123
#
# Epoch 395
# -------------------------------
# Training loss: 0.103356
# Validation loss: 0.237621
#
# Epoch 396
# -------------------------------
# Training loss: 0.101767
# Validation loss: 0.132951
#
# Epoch 397
# -------------------------------
# Training loss: 0.100210
# Validation loss: 0.116914
#
# Epoch 398
# -------------------------------
# Training loss: 0.101974
# Validation loss: 0.104690
#
# Epoch 399
# -------------------------------
# Training loss: 0.099509
# Validation loss: 0.153596
#
# Epoch 400
# -------------------------------
# Training loss: 0.102551
# Validation loss: 0.118047
#
# Epoch 401
# -------------------------------
# Training loss: 0.099177
# Validation loss: 0.178754
#
# Epoch 402
# -------------------------------
# Training loss: 0.101071
# Validation loss: 0.378086
#
# Epoch 403
# -------------------------------
# Training loss: 0.098968
# Validation loss: 0.099197
#
# Epoch 404
# -------------------------------
# Training loss: 0.098008
# Validation loss: 0.229982
#
# Epoch 405
# -------------------------------
# Training loss: 0.096695
# Validation loss: 0.112098
#
# Epoch 406
# -------------------------------
# Training loss: 0.097938
# Validation loss: 0.168406
#
# Epoch 407
# -------------------------------
# Training loss: 0.097278
# Validation loss: 0.114774
#
# Epoch 408
# -------------------------------
# Training loss: 0.097174
# Validation loss: 0.097019
#
# Epoch 409
# -------------------------------
# Training loss: 0.097733
# Validation loss: 0.103060
#
# Epoch 410
# -------------------------------
# Training loss: 0.095484
# Validation loss: 0.097298
#
# Epoch 411
# -------------------------------
# Training loss: 0.096510
# Validation loss: 0.532758
#
# Epoch 412
# -------------------------------
# Training loss: 0.097550
# Validation loss: 0.096284
#
# Epoch 413
# -------------------------------
# Training loss: 0.095746
# Validation loss: 0.150319
#
# Epoch 414
# -------------------------------
# Training loss: 0.096407
# Validation loss: 0.105621
#
# Epoch 415
# -------------------------------
# Training loss: 0.096819
# Validation loss: 0.097665
#
# Epoch 416
# -------------------------------
# Training loss: 0.096271
# Validation loss: 0.125091
#
# Epoch 417
# -------------------------------
# Training loss: 0.096732
# Validation loss: 0.093910
#
# Epoch 418
# -------------------------------
# Training loss: 0.094455
# Validation loss: 0.109460
#
# Epoch 419
# -------------------------------
# Training loss: 0.094614
# Validation loss: 0.114416
#
# Epoch 420
# -------------------------------
# Training loss: 0.097191
# Validation loss: 0.103608
#
# Epoch 421
# -------------------------------
# Training loss: 0.094439
# Validation loss: 0.123743
#
# Epoch 422
# -------------------------------
# Training loss: 0.095413
# Validation loss: 0.172760
#
# Epoch 423
# -------------------------------
# Training loss: 0.094519
# Validation loss: 0.215087
#
# Epoch 424
# -------------------------------
# Training loss: 0.093746
# Validation loss: 0.100283
#
# Epoch 425
# -------------------------------
# Training loss: 0.094487
# Validation loss: 0.096028
#
# Epoch 426
# -------------------------------
# Training loss: 0.093418
# Validation loss: 0.139619
#
# Epoch 427
# -------------------------------
# Training loss: 0.091400
# Validation loss: 0.117268
#
# Epoch 428
# -------------------------------
# Training loss: 0.091719
# Validation loss: 0.152036
#
# Epoch 429
# -------------------------------
# Training loss: 0.094297
# Validation loss: 0.134366
#
# Epoch 430
# -------------------------------
# Training loss: 0.095415
# Validation loss: 0.172445
#
# Epoch 431
# -------------------------------
# Training loss: 0.096865
# Validation loss: 0.222917
#
# Epoch 432
# -------------------------------
# Training loss: 0.092581
# Validation loss: 0.225605
#
# Epoch 433
# -------------------------------
# Training loss: 0.091009
# Validation loss: 0.090671
#
# Epoch 434
# -------------------------------
# Training loss: 0.090227
# Validation loss: 0.103274
#
# Epoch 435
# -------------------------------
# Training loss: 0.093713
# Validation loss: 0.104205
#
# Epoch 436
# -------------------------------
# Training loss: 0.092089
# Validation loss: 0.102584
#
# Epoch 437
# -------------------------------
# Training loss: 0.091788
# Validation loss: 0.114378
#
# Epoch 438
# -------------------------------
# Training loss: 0.088764
# Validation loss: 0.111921
#
# Epoch 439
# -------------------------------
# Training loss: 0.089484
# Validation loss: 0.098871
#
# Epoch 440
# -------------------------------
# Training loss: 0.089433
# Validation loss: 0.146027
#
# Epoch 441
# -------------------------------
# Training loss: 0.089495
# Validation loss: 0.108629
#
# Epoch 442
# -------------------------------
# Training loss: 0.090683
# Validation loss: 0.195703
#
# Epoch 443
# -------------------------------
# Training loss: 0.090475
# Validation loss: 0.089559
#
# Epoch 444
# -------------------------------
# Training loss: 0.089465
# Validation loss: 0.116273
#
# Epoch 445
# -------------------------------
# Training loss: 0.086523
# Validation loss: 0.103276
#
# Epoch 446
# -------------------------------
# Training loss: 0.088856
# Validation loss: 0.549228
#
# Epoch 447
# -------------------------------
# Training loss: 0.088105
# Validation loss: 0.199229
#
# Epoch 448
# -------------------------------
# Training loss: 0.088672
# Validation loss: 0.093852
#
# Epoch 449
# -------------------------------
# Training loss: 0.088539
# Validation loss: 0.092320
#
# Epoch 450
# -------------------------------
# Training loss: 0.090541
# Validation loss: 0.088619
#
# Epoch 451
# -------------------------------
# Training loss: 0.089331
# Validation loss: 0.166602
#
# Epoch 452
# -------------------------------
# Training loss: 0.088397
# Validation loss: 0.090796
#
# Epoch 453
# -------------------------------
# Training loss: 0.087670
# Validation loss: 0.113439
#
# Epoch 454
# -------------------------------
# Training loss: 0.088841
# Validation loss: 0.148916
#
# Epoch 455
# -------------------------------
# Training loss: 0.087245
# Validation loss: 0.092451
#
# Epoch 456
# -------------------------------
# Training loss: 0.087957
# Validation loss: 0.127745
#
# Epoch 457
# -------------------------------
# Training loss: 0.087395
# Validation loss: 0.125362
#
# Epoch 458
# -------------------------------
# Training loss: 0.086092
# Validation loss: 0.116597
#
# Epoch 459
# -------------------------------
# Training loss: 0.088131
# Validation loss: 0.090690
#
# Epoch 460
# -------------------------------
# Training loss: 0.087649
# Validation loss: 0.235209
#
# Epoch 461
# -------------------------------
# Training loss: 0.086069
# Validation loss: 0.121498
#
# Epoch 462
# -------------------------------
# Training loss: 0.089842
# Validation loss: 0.224000
#
# Epoch 463
# -------------------------------
# Training loss: 0.089595
# Validation loss: 0.133390
#
# Epoch 464
# -------------------------------
# Training loss: 0.086361
# Validation loss: 0.169692
#
# Epoch 465
# -------------------------------
# Training loss: 0.085747
# Validation loss: 0.115822
#
# Epoch 466
# -------------------------------
# Training loss: 0.084150
# Validation loss: 0.101528
#
# Epoch 467
# -------------------------------
# Training loss: 0.086734
# Validation loss: 0.137280
#
# Epoch 468
# -------------------------------
# Training loss: 0.085418
# Validation loss: 0.125726
#
# Epoch 469
# -------------------------------
# Training loss: 0.085494
# Validation loss: 0.157034
#
# Epoch 470
# -------------------------------
# Training loss: 0.087525
# Validation loss: 0.203455
#
# Epoch 471
# -------------------------------
# Training loss: 0.085825
# Validation loss: 0.161898
#
# Epoch 472
# -------------------------------
# Training loss: 0.086153
# Validation loss: 0.414698
#
# Epoch 473
# -------------------------------
# Training loss: 0.084738
# Validation loss: 0.092466
#
# Epoch 474
# -------------------------------
# Training loss: 0.085292
# Validation loss: 0.430925
#
# Epoch 475
# -------------------------------
# Training loss: 0.085474
# Validation loss: 0.164727
#
# Epoch 476
# -------------------------------
# Training loss: 0.086500
# Validation loss: 0.094936
#
# Epoch 477
# -------------------------------
# Training loss: 0.085509
# Validation loss: 0.168047
#
# Epoch 478
# -------------------------------
# Training loss: 0.085945
# Validation loss: 0.126350
#
# Epoch 479
# -------------------------------
# Training loss: 0.085355
# Validation loss: 0.093096
#
# Epoch 480
# -------------------------------
# Training loss: 0.081294
# Validation loss: 0.125991
#
# Epoch 481
# -------------------------------
# Training loss: 0.083187
# Validation loss: 0.101540
#
# Epoch 482
# -------------------------------
# Training loss: 0.083449
# Validation loss: 0.085931
#
# Epoch 483
# -------------------------------
# Training loss: 0.082175
# Validation loss: 0.104966
#
# Epoch 484
# -------------------------------
# Training loss: 0.082135
# Validation loss: 0.112139
#
# Epoch 485
# -------------------------------
# Training loss: 0.082559
# Validation loss: 0.086675
#
# Epoch 486
# -------------------------------
# Training loss: 0.082025
# Validation loss: 0.178289
#
# Epoch 487
# -------------------------------
# Training loss: 0.083948
# Validation loss: 0.113124
#
# Epoch 488
# -------------------------------
# Training loss: 0.089086
# Validation loss: 0.132949
#
# Epoch 489
# -------------------------------
# Training loss: 0.082444
# Validation loss: 0.083331
#
# Epoch 490
# -------------------------------
# Training loss: 0.081816
# Validation loss: 0.104137
#
# Epoch 491
# -------------------------------
# Training loss: 0.081809
# Validation loss: 0.083321
#
# Epoch 492
# -------------------------------
# Training loss: 0.082342
# Validation loss: 0.083297
#
# Epoch 493
# -------------------------------
# Training loss: 0.080528
# Validation loss: 0.117005
#
# Epoch 494
# -------------------------------
# Training loss: 0.078460
# Validation loss: 0.102458
#
# Epoch 495
# -------------------------------
# Training loss: 0.081373
# Validation loss: 0.259366
#
# Epoch 496
# -------------------------------
# Training loss: 0.083912
# Validation loss: 0.144486
#
# Epoch 497
# -------------------------------
# Training loss: 0.081414
# Validation loss: 0.220320
#
# Epoch 498
# -------------------------------
# Training loss: 0.080141
# Validation loss: 0.082621
#
# Epoch 499
# -------------------------------
# Training loss: 0.079628
# Validation loss: 0.085141
#
# Epoch 500
# -------------------------------
# Training loss: 0.078843
# Validation loss: 0.093680
#
# Done!

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses)+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('BCE Loss')
#plt.yscale('log')
plt.legend()

# %%
# Now test the pretrained model
test_pred = mytools.test_clas(test_loader, final_classifier, device)
test_pred=torch.sigmoid(torch.tensor(test_pred)).numpy()


fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test, test_pred, pos_label=1)
auc_test = sklearn.metrics.auc(fpr, tpr)
print(f'Test AUROC: {auc_test:0.4f}')

plt.plot(fpr, tpr, label=f'Test AUROC: {auc_test:0.4f}')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
# Out:
# Test AUROC: 0.9941

# %%
# Store the pretrained classifier labels
df_test["Class_pre"] = test_pred

# %%
# Save the pretrained classifier model
torch.save(final_classifier.state_dict(), "/Users/mghrear/data/ML_data/patch/pretrained_classifier_2021_v9_pass5_run"+str(run)+"_limited_sideband_a.pt")

# %% [markdown]
# # Setup the adversary model

# %% [markdown]
# ## Initialize model, objective function, and optimizer

# %%
adv = mytools.Adversary(n_classes=Num_classes).to(device)
criterion_adv = nn.CrossEntropyLoss(reduction='none')  # returns loss per sample so we can weight it
opt_adv = torch.optim.Adam(adv.parameters(), lr=1e-5)
scheduler_adv = torch.optim.lr_scheduler.ExponentialLR(opt_adv, gamma=0.999)

# %% [markdown]
# ## Setup dataloaders

# %%
# Convert to tensor dataset and dataloader

# the structure is: feature, adversary label, weight
# The wight is 1 for tritrig and wab, and 0 for phiKK, to prevent the adversary from learning on phiKK events

train_adv_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_train), (torch.from_numpy(y_train.to_numpy().astype(np.float32))==0).float())
train_adv_loader = DataLoader(train_adv_dataset, batch_size=bsize, shuffle=True)

val_adv_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_val), (torch.from_numpy(y_val.to_numpy().astype(np.float32))==0).float() )
val_adv_loader = DataLoader(val_adv_dataset, batch_size=bsize, shuffle=True)

# %% [markdown]
# ## Pre-train the adversary leaving classifier weights fixed

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 6

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 100
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train_adv(train_adv_loader, final_classifier, adv, criterion_adv, opt_adv, scheduler_adv, device))
    Validation_losses = np.append(Validation_losses, mytools.validate_adv(val_adv_loader, final_classifier, adv, criterion_adv, device))
    
    # Keep a running copy of the model with the lowest loss
    if Validation_losses[-1] == np.min(Validation_losses):
        final_adv = copy.deepcopy(adv)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Training loss: 1.610695
# Validation loss: 1.593208
#
# Epoch 2
# -------------------------------
# Training loss: 1.586338
# Validation loss: 1.588140
#
# Epoch 3
# -------------------------------
# Training loss: 1.569741
# Validation loss: 1.570761
#
# Epoch 4
# -------------------------------
# Training loss: 1.559630
# Validation loss: 1.561896
#
# Epoch 5
# -------------------------------
# Training loss: 1.553168
# Validation loss: 1.558386
#
# Epoch 6
# -------------------------------
# Training loss: 1.546533
# Validation loss: 1.552150
#
# Epoch 7
# -------------------------------
# Training loss: 1.539813
# Validation loss: 1.543261
#
# Epoch 8
# -------------------------------
# Training loss: 1.531991
# Validation loss: 1.538905
#
# Epoch 9
# -------------------------------
# Training loss: 1.528388
# Validation loss: 1.535990
#
# Epoch 10
# -------------------------------
# Training loss: 1.526365
# Validation loss: 1.531924
#
# Epoch 11
# -------------------------------
# Training loss: 1.522334
# Validation loss: 1.531092
#
# Epoch 12
# -------------------------------
# Training loss: 1.519440
# Validation loss: 1.529884
#
# Epoch 13
# -------------------------------
# Training loss: 1.517695
# Validation loss: 1.528243
#
# Epoch 14
# -------------------------------
# Training loss: 1.514472
# Validation loss: 1.524716
#
# Epoch 15
# -------------------------------
# Training loss: 1.514367
# Validation loss: 1.521982
#
# Epoch 16
# -------------------------------
# Training loss: 1.513112
# Validation loss: 1.522954
#
# Epoch 17
# -------------------------------
# Training loss: 1.511751
# Validation loss: 1.523889
#
# Epoch 18
# -------------------------------
# Training loss: 1.509699
# Validation loss: 1.520209
#
# Epoch 19
# -------------------------------
# Training loss: 1.509548
# Validation loss: 1.518756
#
# Epoch 20
# -------------------------------
# Training loss: 1.507147
# Validation loss: 1.517981
#
# Epoch 21
# -------------------------------
# Training loss: 1.507709
# Validation loss: 1.517937
#
# Epoch 22
# -------------------------------
# Training loss: 1.506564
# Validation loss: 1.516800
#
# Epoch 23
# -------------------------------
# Training loss: 1.505422
# Validation loss: 1.516856
#
# Epoch 24
# -------------------------------
# Training loss: 1.505515
# Validation loss: 1.516203
#
# Epoch 25
# -------------------------------
# Training loss: 1.504183
# Validation loss: 1.516138
#
# Epoch 26
# -------------------------------
# Training loss: 1.503191
# Validation loss: 1.514480
#
# Epoch 27
# -------------------------------
# Training loss: 1.501862
# Validation loss: 1.512103
#
# Epoch 28
# -------------------------------
# Training loss: 1.500661
# Validation loss: 1.512032
#
# Epoch 29
# -------------------------------
# Training loss: 1.501632
# Validation loss: 1.510431
#
# Epoch 30
# -------------------------------
# Training loss: 1.500974
# Validation loss: 1.513245
#
# Epoch 31
# -------------------------------
# Training loss: 1.501199
# Validation loss: 1.511121
#
# Epoch 32
# -------------------------------
# Training loss: 1.498032
# Validation loss: 1.510527
#
# Epoch 33
# -------------------------------
# Training loss: 1.499163
# Validation loss: 1.511242
#
# Epoch 34
# -------------------------------
# Training loss: 1.498811
# Validation loss: 1.511816
#
# Epoch 35
# -------------------------------
# Training loss: 1.499290
# Validation loss: 1.509078
#
# Epoch 36
# -------------------------------
# Training loss: 1.497926
# Validation loss: 1.509359
#
# Epoch 37
# -------------------------------
# Training loss: 1.496479
# Validation loss: 1.509235
#
# Epoch 38
# -------------------------------
# Training loss: 1.496273
# Validation loss: 1.509311
#
# Epoch 39
# -------------------------------
# Training loss: 1.497655
# Validation loss: 1.506576
#
# Epoch 40
# -------------------------------
# Training loss: 1.497285
# Validation loss: 1.506999
#
# Epoch 41
# -------------------------------
# Training loss: 1.496810
# Validation loss: 1.507386
#
# Epoch 42
# -------------------------------
# Training loss: 1.496489
# Validation loss: 1.508744
#
# Epoch 43
# -------------------------------
# Training loss: 1.496226
# Validation loss: 1.507450
#
# Epoch 44
# -------------------------------
# Training loss: 1.495185
# Validation loss: 1.507158
#
# Epoch 45
# -------------------------------
# Training loss: 1.495555
# Validation loss: 1.505879
#
# Epoch 46
# -------------------------------
# Training loss: 1.495884
# Validation loss: 1.509086
#
# Epoch 47
# -------------------------------
# Training loss: 1.495868
# Validation loss: 1.507972
#
# Epoch 48
# -------------------------------
# Training loss: 1.494188
# Validation loss: 1.505232
#
# Epoch 49
# -------------------------------
# Training loss: 1.494470
# Validation loss: 1.505588
#
# Epoch 50
# -------------------------------
# Training loss: 1.494388
# Validation loss: 1.505724
#
# Epoch 51
# -------------------------------
# Training loss: 1.495133
# Validation loss: 1.506340
#
# Epoch 52
# -------------------------------
# Training loss: 1.495093
# Validation loss: 1.505107
#
# Epoch 53
# -------------------------------
# Training loss: 1.494771
# Validation loss: 1.504222
#
# Epoch 54
# -------------------------------
# Training loss: 1.495772
# Validation loss: 1.503923
#
# Epoch 55
# -------------------------------
# Training loss: 1.494103
# Validation loss: 1.504613
#
# Epoch 56
# -------------------------------
# Training loss: 1.494809
# Validation loss: 1.506656
#
# Epoch 57
# -------------------------------
# Training loss: 1.494645
# Validation loss: 1.504986
#
# Epoch 58
# -------------------------------
# Training loss: 1.492820
# Validation loss: 1.504634
#
# Epoch 59
# -------------------------------
# Training loss: 1.493608
# Validation loss: 1.503815
#
# Epoch 60
# -------------------------------
# Training loss: 1.492124
# Validation loss: 1.505860
#
# Epoch 61
# -------------------------------
# Training loss: 1.494083
# Validation loss: 1.505218
#
# Epoch 62
# -------------------------------
# Training loss: 1.492874
# Validation loss: 1.504389
#
# Epoch 63
# -------------------------------
# Training loss: 1.491870
# Validation loss: 1.503653
#
# Epoch 64
# -------------------------------
# Training loss: 1.491664
# Validation loss: 1.504308
#
# Epoch 65
# -------------------------------
# Training loss: 1.493754
# Validation loss: 1.504140
#
# Epoch 66
# -------------------------------
# Training loss: 1.492801
# Validation loss: 1.505090
#
# Epoch 67
# -------------------------------
# Training loss: 1.492574
# Validation loss: 1.503712
#
# Epoch 68
# -------------------------------
# Training loss: 1.491280
# Validation loss: 1.503465
#
# Epoch 69
# -------------------------------
# Training loss: 1.493301
# Validation loss: 1.503477
#
# Epoch 70
# -------------------------------
# Training loss: 1.493254
# Validation loss: 1.503210
#
# Epoch 71
# -------------------------------
# Training loss: 1.491942
# Validation loss: 1.504884
#
# Epoch 72
# -------------------------------
# Training loss: 1.491400
# Validation loss: 1.503820
#
# Epoch 73
# -------------------------------
# Training loss: 1.492618
# Validation loss: 1.503430
#
# Epoch 74
# -------------------------------
# Training loss: 1.492148
# Validation loss: 1.504660
#
# Epoch 75
# -------------------------------
# Training loss: 1.492732
# Validation loss: 1.503370
#
# Epoch 76
# -------------------------------
# Training loss: 1.491200
# Validation loss: 1.503971
#
# Epoch 77
# -------------------------------
# Training loss: 1.492369
# Validation loss: 1.502240
#
# Epoch 78
# -------------------------------
# Training loss: 1.492082
# Validation loss: 1.504478
#
# Epoch 79
# -------------------------------
# Training loss: 1.491802
# Validation loss: 1.501958
#
# Epoch 80
# -------------------------------
# Training loss: 1.491564
# Validation loss: 1.504200
#
# Epoch 81
# -------------------------------
# Training loss: 1.491274
# Validation loss: 1.505105
#
# Epoch 82
# -------------------------------
# Training loss: 1.491526
# Validation loss: 1.503047
#
# Epoch 83
# -------------------------------
# Training loss: 1.492482
# Validation loss: 1.501381
#
# Epoch 84
# -------------------------------
# Training loss: 1.491442
# Validation loss: 1.504551
#
# Epoch 85
# -------------------------------
# Training loss: 1.491245
# Validation loss: 1.503214
#
# Epoch 86
# -------------------------------
# Training loss: 1.490813
# Validation loss: 1.502773
#
# Epoch 87
# -------------------------------
# Training loss: 1.491642
# Validation loss: 1.503616
#
# Epoch 88
# -------------------------------
# Training loss: 1.490262
# Validation loss: 1.503087
#
# Epoch 89
# -------------------------------
# Training loss: 1.490972
# Validation loss: 1.500884
#
# Epoch 90
# -------------------------------
# Training loss: 1.491005
# Validation loss: 1.502739
#
# Epoch 91
# -------------------------------
# Training loss: 1.491854
# Validation loss: 1.500456
#
# Epoch 92
# -------------------------------
# Training loss: 1.490831
# Validation loss: 1.502775
#
# Epoch 93
# -------------------------------
# Training loss: 1.490237
# Validation loss: 1.503749
#
# Epoch 94
# -------------------------------
# Training loss: 1.492178
# Validation loss: 1.501367
#
# Epoch 95
# -------------------------------
# Training loss: 1.492142
# Validation loss: 1.502433
#
# Epoch 96
# -------------------------------
# Training loss: 1.489810
# Validation loss: 1.502341
#
# Epoch 97
# -------------------------------
# Training loss: 1.491798
# Validation loss: 1.503624
#
# Epoch 98
# -------------------------------
# Training loss: 1.491165
# Validation loss: 1.504338
#
# Epoch 99
# -------------------------------
# Training loss: 1.490758
# Validation loss: 1.502452
#
# Epoch 100
# -------------------------------
# Training loss: 1.491297
# Validation loss: 1.504307
#
# Done!

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses)+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('BCE Loss')
plt.legend()

# %% [markdown]
# # Train full adverserial neural network

# %% [markdown]
# # Setup dataloaders

# %%
# the structure is: feature, classifier label, adversary label, weight
# The wight is 1 for tritrig and wab, and 0 for phiKK, to prevent the adversary from learning on phiKK events

train_full_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy().astype(np.float32))  , torch.from_numpy(y_train.to_numpy().astype(np.float32)).unsqueeze(1), torch.from_numpy(y_adv_train),  (torch.from_numpy(y_train.to_numpy().astype(np.float32))==0).float())
train_full_loader = DataLoader(train_full_dataset, batch_size=bsize, shuffle=True)

val_full_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy().astype(np.float32))  , torch.from_numpy(y_val.to_numpy().astype(np.float32)).unsqueeze(1),  torch.from_numpy(y_adv_val),  (torch.from_numpy(y_val.to_numpy().astype(np.float32))==0).float())
val_full_loader = DataLoader(val_full_dataset, batch_size=bsize, shuffle=True)

# %% [markdown]
# ## Define loss functions

# %%
BCE_loss = nn.BCEWithLogitsLoss()
CE_loss = nn.CrossEntropyLoss(reduction='none') # returns loss per sample so we can weight it

def full_loss(output_clas, output_adv, target_clas, target_adv, w, lambda_):

    loss1 = BCE_loss(output_clas, target_clas )  # classification loss
    sample_losses2 = CE_loss(output_adv, target_adv)  # adversarial losses, since we set reduction='none', this is now a vector of losses, one per sample in the batch

     # Weighted mean loss over non-zero weights
    nonzero = w > 0
    loss2 = (sample_losses2[nonzero] * w[nonzero]).sum() / w[nonzero].sum()

    loss = loss1 - lambda_*loss2

    return loss

# %% [markdown]
# ## Setup optimizers

# %%
optimizer_clas = optim.Adam(final_classifier.parameters(), lr=1e-7,betas=(0.5, 0.999))
optimizer_adv = optim.Adam(final_adv.parameters(), lr=1e-5,betas=(0.5, 0.999))

scheduler_clas = torch.optim.lr_scheduler.ExponentialLR(optimizer_clas, gamma=0.999)
scheduler_adv = torch.optim.lr_scheduler.ExponentialLR(optimizer_adv, gamma=0.999)

# %% [markdown]
# ## Adversarial training

# %%
Training_losses_clas = np.array([])
Training_losses_adv = np.array([])
Validation_losses_clas = np.array([])
Validation_losses_adv = np.array([])
diff_scores = np.array([])


epochs = 50
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")

    # Get validation losses
    E_clas_val_loss, E_adv_val_loss = mytools.validate_full(val_full_loader, final_classifier, final_adv, full_loss, lambda_, criterion_adv, device)
    Validation_losses_clas = np.append(Validation_losses_clas, E_clas_val_loss)
    Validation_losses_adv = np.append(Validation_losses_adv, E_adv_val_loss)

    # Train adversary and classifier
    E_clas_training_loss , E_adv_training_loss = mytools.train_full(train_full_loader, final_classifier, final_adv, full_loss, lambda_, criterion_adv, optimizer_clas, optimizer_adv, scheduler_clas, scheduler_adv, device)
    Training_losses_clas = np.append(Training_losses_clas, E_clas_training_loss)
    Training_losses_adv = np.append(Training_losses_adv, E_adv_training_loss)

    # Get the diff_score
    df_test["Class_adv"] = mytools.test_clas(test_loader, final_classifier, device)
    df_bkg = df_test.loc[ (df_test.type == 'tritrig') | (df_test.type == 'wab')]
    per = np.percentile(df_bkg['Class_adv'],99)
    df_cut = df_bkg[df_bkg['Class_adv']>per].reset_index(drop=True)
    x1 = 1000* df_bkg.InvM.values
    x2 = 1000*df_cut.InvM.values
    diff_scores = np.append(diff_scores, mytools.get_diff_score(x1,x2) )

    # Keep a running copy of the model with the lowest loss
    if diff_scores[-1] == np.min(diff_scores):
        final_clas_adv = copy.deepcopy(final_classifier)
        final_adv_adv = copy.deepcopy(final_adv)

            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Classifier validation loss: -150.336489
# Adversary validation loss: 1.504203
# Classifier training loss: -153.101293
# Adversary training loss: 1.532574
# Epoch 2
# -------------------------------
# Classifier validation loss: -153.422833
# Adversary validation loss: 1.535053
# Classifier training loss: -154.827206
# Adversary training loss: 1.549928
# Epoch 3
# -------------------------------
# Classifier validation loss: -155.528534
# Adversary validation loss: 1.556176
# Classifier training loss: -155.871474
# Adversary training loss: 1.560209
# Epoch 4
# -------------------------------
# Classifier validation loss: -156.713929
# Adversary validation loss: 1.568057
# Classifier training loss: -156.630530
# Adversary training loss: 1.567686
# Epoch 5
# -------------------------------
# Classifier validation loss: -158.476086
# Adversary validation loss: 1.585785
# Classifier training loss: -157.007372
# Adversary training loss: 1.571373
# Epoch 6
# -------------------------------
# Classifier validation loss: -157.472193
# Adversary validation loss: 1.575764
# Classifier training loss: -157.034359
# Adversary training loss: 1.571605
# Epoch 7
# -------------------------------
# Classifier validation loss: -157.107976
# Adversary validation loss: 1.572143
# Classifier training loss: -157.325930
# Adversary training loss: 1.574622
# Epoch 8
# -------------------------------
# Classifier validation loss: -157.862519
# Adversary validation loss: 1.579857
# Classifier training loss: -157.474902
# Adversary training loss: 1.576053
# Epoch 9
# -------------------------------
# Classifier validation loss: -158.580011
# Adversary validation loss: 1.587074
# Classifier training loss: -157.536711
# Adversary training loss: 1.576795
# Epoch 10
# -------------------------------
# Classifier validation loss: -157.866496
# Adversary validation loss: 1.580006
# Classifier training loss: -157.708956
# Adversary training loss: 1.578531
# Epoch 11
# -------------------------------
# Classifier validation loss: -157.950183
# Adversary validation loss: 1.580817
# Classifier training loss: -157.590613
# Adversary training loss: 1.577366
# Epoch 12
# -------------------------------
# Classifier validation loss: -157.891260
# Adversary validation loss: 1.580399
# Classifier training loss: -157.514796
# Adversary training loss: 1.576710
# Epoch 13
# -------------------------------
# Classifier validation loss: -158.657190
# Adversary validation loss: 1.588202
# Classifier training loss: -157.349186
# Adversary training loss: 1.575082
# Epoch 14
# -------------------------------
# Classifier validation loss: -158.029393
# Adversary validation loss: 1.581901
# Classifier training loss: -157.379008
# Adversary training loss: 1.575414
# Epoch 15
# -------------------------------
# Classifier validation loss: -157.953343
# Adversary validation loss: 1.581177
# Classifier training loss: -157.240634
# Adversary training loss: 1.574052
# Epoch 16
# -------------------------------
# Classifier validation loss: -157.543090
# Adversary validation loss: 1.577036
# Classifier training loss: -157.162067
# Adversary training loss: 1.573330
# Epoch 17
# -------------------------------
# Classifier validation loss: -157.469926
# Adversary validation loss: 1.576418
# Classifier training loss: -157.074592
# Adversary training loss: 1.572503
# Epoch 18
# -------------------------------
# Classifier validation loss: -157.500182
# Adversary validation loss: 1.576712
# Classifier training loss: -157.055609
# Adversary training loss: 1.572335
# Epoch 19
# -------------------------------
# Classifier validation loss: -157.347534
# Adversary validation loss: 1.575210
# Classifier training loss: -156.739944
# Adversary training loss: 1.569168
# Epoch 20
# -------------------------------
# Classifier validation loss: -157.448464
# Adversary validation loss: 1.576247
# Classifier training loss: -156.844197
# Adversary training loss: 1.570229
# Epoch 21
# -------------------------------
# Classifier validation loss: -157.193286
# Adversary validation loss: 1.573688
# Classifier training loss: -156.584906
# Adversary training loss: 1.567657
# Epoch 22
# -------------------------------
# Classifier validation loss: -157.585954
# Adversary validation loss: 1.577580
# Classifier training loss: -156.647581
# Adversary training loss: 1.568288
# Epoch 23
# -------------------------------
# Classifier validation loss: -156.915950
# Adversary validation loss: 1.570972
# Classifier training loss: -156.501182
# Adversary training loss: 1.566865
# Epoch 24
# -------------------------------
# Classifier validation loss: -156.802577
# Adversary validation loss: 1.569854
# Classifier training loss: -156.460136
# Adversary training loss: 1.566479
# Epoch 25
# -------------------------------
# Classifier validation loss: -157.058099
# Adversary validation loss: 1.572443
# Classifier training loss: -156.378340
# Adversary training loss: 1.565634
# Epoch 26
# -------------------------------
# Classifier validation loss: -157.106758
# Adversary validation loss: 1.572972
# Classifier training loss: -156.487417
# Adversary training loss: 1.566710
# Epoch 27
# -------------------------------
# Classifier validation loss: -157.018524
# Adversary validation loss: 1.572056
# Classifier training loss: -156.505772
# Adversary training loss: 1.566928
# Epoch 28
# -------------------------------
# Classifier validation loss: -157.224804
# Adversary validation loss: 1.573831
# Classifier training loss: -156.386635
# Adversary training loss: 1.565733
# Epoch 29
# -------------------------------
# Classifier validation loss: -156.788628
# Adversary validation loss: 1.569746
# Classifier training loss: -156.332024
# Adversary training loss: 1.565222
# Epoch 30
# -------------------------------
# Classifier validation loss: -157.143645
# Adversary validation loss: 1.573209
# Classifier training loss: -156.344286
# Adversary training loss: 1.565327
# Epoch 31
# -------------------------------
# Classifier validation loss: -156.794263
# Adversary validation loss: 1.569789
# Classifier training loss: -156.252610
# Adversary training loss: 1.564447
# Epoch 32
# -------------------------------
# Classifier validation loss: -156.849463
# Adversary validation loss: 1.570454
# Classifier training loss: -156.170842
# Adversary training loss: 1.563606
# Epoch 33
# -------------------------------
# Classifier validation loss: -156.572676
# Adversary validation loss: 1.567622
# Classifier training loss: -156.124160
# Adversary training loss: 1.563155
# Epoch 34
# -------------------------------
# Classifier validation loss: -156.631564
# Adversary validation loss: 1.568224
# Classifier training loss: -156.204929
# Adversary training loss: 1.563982
# Epoch 35
# -------------------------------
# Classifier validation loss: -157.084799
# Adversary validation loss: 1.572776
# Classifier training loss: -156.057536
# Adversary training loss: 1.562494
# Epoch 36
# -------------------------------
# Classifier validation loss: -156.800047
# Adversary validation loss: 1.570095
# Classifier training loss: -156.281688
# Adversary training loss: 1.564740
# Epoch 37
# -------------------------------
# Classifier validation loss: -156.808033
# Adversary validation loss: 1.570071
# Classifier training loss: -156.121343
# Adversary training loss: 1.563137
# Epoch 38
# -------------------------------
# Classifier validation loss: -156.807096
# Adversary validation loss: 1.569986
# Classifier training loss: -156.256123
# Adversary training loss: 1.564495
# Epoch 39
# -------------------------------
# Classifier validation loss: -156.694784
# Adversary validation loss: 1.568832
# Classifier training loss: -156.147601
# Adversary training loss: 1.563394
# Epoch 40
# -------------------------------
# Classifier validation loss: -156.919077
# Adversary validation loss: 1.570943
# Classifier training loss: -156.000499
# Adversary training loss: 1.561916
# Epoch 41
# -------------------------------
# Classifier validation loss: -156.688606
# Adversary validation loss: 1.568863
# Classifier training loss: -156.057362
# Adversary training loss: 1.562527
# Epoch 42
# -------------------------------
# Classifier validation loss: -156.476241
# Adversary validation loss: 1.566700
# Classifier training loss: -156.059224
# Adversary training loss: 1.562516
# Epoch 43
# -------------------------------
# Classifier validation loss: -156.730609
# Adversary validation loss: 1.569226
# Classifier training loss: -155.968603
# Adversary training loss: 1.561624
# Epoch 44
# -------------------------------
# Classifier validation loss: -156.548508
# Adversary validation loss: 1.567447
# Classifier training loss: -156.096165
# Adversary training loss: 1.562919
# Epoch 45
# -------------------------------
# Classifier validation loss: -156.707036
# Adversary validation loss: 1.568886
# Classifier training loss: -156.078890
# Adversary training loss: 1.562718
# Epoch 46
# -------------------------------
# Classifier validation loss: -156.672858
# Adversary validation loss: 1.568765
# Classifier training loss: -156.082603
# Adversary training loss: 1.562766
# Epoch 47
# -------------------------------
# Classifier validation loss: -156.702487
# Adversary validation loss: 1.568866
# Classifier training loss: -156.133715
# Adversary training loss: 1.563289
# Epoch 48
# -------------------------------
# Classifier validation loss: -156.868532
# Adversary validation loss: 1.570535
# Classifier training loss: -155.976432
# Adversary training loss: 1.561720
# Epoch 49
# -------------------------------
# Classifier validation loss: -156.701374
# Adversary validation loss: 1.568853
# Classifier training loss: -156.004270
# Adversary training loss: 1.562003
# Epoch 50
# -------------------------------
# Classifier validation loss: -156.619555
# Adversary validation loss: 1.568161
# Classifier training loss: -155.982949
# Adversary training loss: 1.561794
# Done!

# %%
fig, ax1 = plt.subplots()

best_epoch = np.argmin(diff_scores)+1



#ax1.plot(np.arange(len(Training_losses_adv))+1, Training_losses_adv, 'k-', label='Training Adversary')
ax1.plot(np.arange(len(Validation_losses_adv))+1, Validation_losses_adv, 'k-', label='Validation Adversary')

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Adversary Loss', color='k')
ax1.tick_params(axis='y', labelcolor='k')

ax2 = ax1.twinx()

#ax2.plot(np.arange(len(Training_losses_clas))+1, Training_losses_clas, 'r-', label='Training Classifier')
ax2.plot(np.arange(len(Validation_losses_clas))+1, Validation_losses_clas, 'r-', label='Validation Classifier')
ax2.axvline(best_epoch,label="Final model stopped here",color='k')

ax2.set_ylabel('Classifier Loss', color='r')
ax2.tick_params(axis='y', labelcolor='r')

# %% [markdown]
# ## Test adversarially trained models

# %%
# Now test the pretrained model
test_pred = mytools.test_clas(test_loader, final_clas_adv, device)
test_pred=torch.sigmoid(torch.tensor(test_pred)).numpy()


fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test, test_pred, pos_label=1)
auc_test = sklearn.metrics.auc(fpr, tpr)
print(f'Test AUROC: {auc_test:0.4f}')

plt.plot(fpr, tpr, label=f'Test AUROC: {auc_test:0.4f}')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
# Out:
# Test AUROC: 0.9877

# %%
df_test["Class_adv"] = test_pred
df_bkg = df_test.loc[ (df_test.type == 'tritrig') | (df_test.type == 'wab')]
per = np.percentile(df_bkg['Class_adv'],99)
df_cut = df_bkg[df_bkg['Class_adv']>per].reset_index(drop=True)
x_vals = 1000*df_cut.InvM

plt.figure()
plt.hist(1000*df_bkg.InvM, bins=np.arange(980,1250,1), histtype='step', label='No selection', density=True)
plt.hist(x_vals, bins=np.arange(980,1250,1), histtype='step', label= '99 percent selection', density=True)
plt.axvline(1019.461, color='k', linestyle='dashed', linewidth=1, label='PDG phi mass')
plt.xlabel('Invariant Mass [MeV]')
plt.ylabel('Normalized Counts')
plt.legend()

# %%
x1 = 1000* df_bkg.InvM.values
x2 = 1000*df_cut.InvM.values

N, edges = np.histogram(x1, bins=np.arange(980,1250,1), density=False)
M, edges = np.histogram(x2, bins=np.arange(980,1250,1), density=False)

N2 = N[(N > 0) & (M > 0)]
M2 = M[(N > 0) & (M > 0)]

diff_score = np.mean(np.abs(N2/np.sum(N)-M2/np.sum(M)) / (np.sqrt(N2)/np.sum(N) + np.sqrt(M2)/np.sum(M) ))

print(diff_score)

N = len(df_test.loc[ ((df_test.type == 'tritrig') | (df_test.type == 'wab')) & (df_test.InvM < (1.019 + 0.01) )  & (df_test.InvM > (1.019 - 0.01) ) & ( df_test['Class_adv']>per ) ] )
S = len(df_test.loc[ (df_test.type == 'phiKK') & (df_test.InvM < (1.019 + 0.01) )  & (df_test.InvM > (1.019 - 0.01) ) & ( df_test['Class_adv']>per )  ] )

print(S/N)
# Out:
# 0.747033183396806
# 5.027027027027027

# %%
# Save the adversarially trained models
torch.save(final_clas_adv.state_dict(), "/Users/mghrear/data/ML_data/patch/classifier_adv_2021_v9_pass5_run"+str(run)+"_limited_sideband_a.pt")
torch.save(final_adv_adv.state_dict(), "/Users/mghrear/data/ML_data/patch/adversary_adv_2021_v9_pass5_run"+str(run)+"_limited_sideband_a.pt")

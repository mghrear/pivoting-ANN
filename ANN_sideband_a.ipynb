# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import torch 
from torch import nn, optim
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import sklearn
from sklearn.model_selection import train_test_split
import copy
import mytools
from scipy.stats import ks_2samp, wasserstein_distance


# Print and store device being used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cpu

# %% [markdown]
# # Define important parameters

# %%
# Number of class in invariant mass used by the adversary
Num_classes = 5
# Hyper-parameter for adversarial training of the classifier
lambda_ = 100.0

run = 1

# %% [markdown]
# # Load and setup the data

# %%
df_tritrig = pd.read_pickle('/Users/mghrear/data/ML_data/patch/BDT_2021_tritrig_limited.pk')
df_tritrig['PhiKK'] = 0.0 # Add label
df_tritrig = df_tritrig.sample(frac=1, random_state=42).reset_index(drop=True) # Now shuffle the combined dataframe
df_phiKK = pd.read_pickle('/Users/mghrear/data/ML_data/patch/BDT_2021_phiKK_limited.pk')
df_phiKK['PhiKK'] = 1.0 # Add label
df_wab = pd.read_pickle('/Users/mghrear/data/ML_data/patch/BDT_2021_wab_limited.pk')
df_wab['PhiKK'] = 0.0 # Add label
df_wab = df_wab.sample(frac=1, random_state=42).reset_index(drop=True) # Now shuffle the combined dataframe

df_data_train_bkg = pd.read_pickle('/Users/mghrear/data/ML_data/patch/BDT_2021_data_limited_sideband_train_bkg.pk')
df_data_train_bkg['PhiKK'] = 0.0 # Add label

df_data = pd.read_pickle('/Users/mghrear/data/ML_data/patch/BDT_2021_data_limited_sideband_test.pk')

print("phiKK: ", len(df_phiKK))
print("data bkg: ", len(df_data_train_bkg))
print("data: ", len(df_data))
# Out:
# phiKK:  3939
# data bkg:  23932
# data:  27821

# %%
phiKK_train = df_phiKK[0:3000]


# Combine and shuffle all training data
df_train = pd.concat([phiKK_train, df_data_train_bkg], ignore_index=True, sort=False)
df_train = df_train.sample(frac=1, random_state=42).reset_index(drop=True)

# Get edges in invariant mass classes for one-hot encoding
# To be used for adverserial labels
# The edges are chosen such that each bin has equal number of background events
one_hot_edges = mytools.get_one_hot_edges(mytools.get_InvM( df_data ), n_bins=Num_classes)

# Split the training data into training and validation sets
df_train, df_val = train_test_split(df_train, test_size=0.33, random_state=41)

# Make X and y for training and validation sets
# the adverserial network has its own labels
X_train = df_train.drop(columns=['PhiKK'])
y_train = df_train['PhiKK']
y_adv_train = mytools.get_adv_labels( mytools.get_InvM(df_train), one_hot_edges)
X_val = df_val.drop(columns=['PhiKK'])
y_val = df_val['PhiKK']
y_adv_val = mytools.get_adv_labels( mytools.get_InvM(df_val), one_hot_edges)

# Make testing set with remaining events
tritrig_test = df_tritrig[20000:]
tritrig_test['type']= 'tritrig'
wab_test = df_wab[3000:]
wab_test['type']= 'wab'
phiKK_test = df_phiKK[3000:]
phiKK_test['type']= 'phiKK'

# This is just used for an invariance test
df_test = pd.concat([tritrig_test, phiKK_test,wab_test], ignore_index=True, sort=False)
df_test = df_test.sample(frac=1, random_state=42).reset_index(drop=True) # Now shuffle the combined dataframe

X_test = df_test.drop(columns=['PhiKK','type'])
y_test = df_test['PhiKK']
y_adv_test = mytools.get_adv_labels( mytools.get_InvM(df_test), one_hot_edges)

df_test["InvM"] = mytools.get_InvM(df_test) 



# Make final data set
X_final = df_data
# Out:
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_83127/3652916753.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tritrig_test['type']= 'tritrig'
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_83127/3652916753.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wab_test['type']= 'wab'
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_83127/3652916753.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phiKK_test['type']= 'phiKK'

# %% [markdown]
# # Setup the classifier model

# %% [markdown]
# ## Setup dataloaders

# %%
bsize = 512

# Convert to tensor dataset and dataloader
train_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy().astype(np.float32))  , torch.from_numpy(y_train.to_numpy().astype(np.float32)).unsqueeze(1)  )
train_loader = DataLoader(train_dataset, batch_size=bsize, shuffle=True)

val_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy().astype(np.float32))  , torch.from_numpy(y_val.to_numpy().astype(np.float32)).unsqueeze(1)  )
val_loader = DataLoader(val_dataset, batch_size=bsize, shuffle=True)

test_dataset = TensorDataset(torch.from_numpy(X_test.to_numpy().astype(np.float32))  )
test_loader = DataLoader(test_dataset, batch_size=bsize, shuffle=False)

# %% [markdown]
# ## Initialize model, objective function, and optimizer

# %%
clas = mytools.Classifier(in_features=X_train.shape[1]).to(device)
criterion_clas = nn.BCEWithLogitsLoss()
optimizer_clas = optim.Adam(clas.parameters(), lr=1e-5)
scheduler_clas = torch.optim.lr_scheduler.ExponentialLR(optimizer_clas, gamma=0.99995)

# %% [markdown]
# ## Pre-train the classifier

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 10

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 500
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train_clas(train_loader, clas, criterion_clas, optimizer_clas, scheduler_clas, device))
    Validation_losses = np.append(Validation_losses, mytools.validate_clas(val_loader, clas, criterion_clas, device))
    
    # Keep a running copy of the model with the lowest loss
    if Validation_losses[-1] == np.min(Validation_losses):
        final_classifier = copy.deepcopy(clas)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Training loss: 0.761843
# Validation loss: 0.744217
#
# Epoch 2
# -------------------------------
# Training loss: 0.724209
# Validation loss: 0.680423
#
# Epoch 3
# -------------------------------
# Training loss: 0.696563
# Validation loss: 0.671081
#
# Epoch 4
# -------------------------------
# Training loss: 0.682085
# Validation loss: 0.657283
#
# Epoch 5
# -------------------------------
# Training loss: 0.664679
# Validation loss: 0.633177
#
# Epoch 6
# -------------------------------
# Training loss: 0.652137
# Validation loss: 0.623464
#
# Epoch 7
# -------------------------------
# Training loss: 0.639262
# Validation loss: 0.618844
#
# Epoch 8
# -------------------------------
# Training loss: 0.632507
# Validation loss: 0.612095
#
# Epoch 9
# -------------------------------
# Training loss: 0.622906
# Validation loss: 0.608978
#
# Epoch 10
# -------------------------------
# Training loss: 0.614360
# Validation loss: 0.608019
#
# Epoch 11
# -------------------------------
# Training loss: 0.606023
# Validation loss: 0.586253
#
# Epoch 12
# -------------------------------
# Training loss: 0.600048
# Validation loss: 0.584915
#
# Epoch 13
# -------------------------------
# Training loss: 0.592894
# Validation loss: 0.580422
#
# Epoch 14
# -------------------------------
# Training loss: 0.586337
# Validation loss: 0.573241
#
# Epoch 15
# -------------------------------
# Training loss: 0.578373
# Validation loss: 0.564422
#
# Epoch 16
# -------------------------------
# Training loss: 0.573269
# Validation loss: 0.558490
#
# Epoch 17
# -------------------------------
# Training loss: 0.567461
# Validation loss: 0.552038
#
# Epoch 18
# -------------------------------
# Training loss: 0.561194
# Validation loss: 0.555719
#
# Epoch 19
# -------------------------------
# Training loss: 0.559109
# Validation loss: 0.542832
#
# Epoch 20
# -------------------------------
# Training loss: 0.554904
# Validation loss: 0.520612
#
# Epoch 21
# -------------------------------
# Training loss: 0.547145
# Validation loss: 0.546198
#
# Epoch 22
# -------------------------------
# Training loss: 0.539377
# Validation loss: 0.528109
#
# Epoch 23
# -------------------------------
# Training loss: 0.536611
# Validation loss: 0.522210
#
# Epoch 24
# -------------------------------
# Training loss: 0.534001
# Validation loss: 0.516738
#
# Epoch 25
# -------------------------------
# Training loss: 0.527933
# Validation loss: 0.517183
#
# Epoch 26
# -------------------------------
# Training loss: 0.525619
# Validation loss: 0.512749
#
# Epoch 27
# -------------------------------
# Training loss: 0.519534
# Validation loss: 0.506479
#
# Epoch 28
# -------------------------------
# Training loss: 0.516528
# Validation loss: 0.501861
#
# Epoch 29
# -------------------------------
# Training loss: 0.512671
# Validation loss: 0.499921
#
# Epoch 30
# -------------------------------
# Training loss: 0.506807
# Validation loss: 0.502059
#
# Epoch 31
# -------------------------------
# Training loss: 0.505151
# Validation loss: 0.492542
#
# Epoch 32
# -------------------------------
# Training loss: 0.500706
# Validation loss: 0.491108
#
# Epoch 33
# -------------------------------
# Training loss: 0.498590
# Validation loss: 0.490611
#
# Epoch 34
# -------------------------------
# Training loss: 0.495249
# Validation loss: 0.484306
#
# Epoch 35
# -------------------------------
# Training loss: 0.491666
# Validation loss: 0.487916
#
# Epoch 36
# -------------------------------
# Training loss: 0.487730
# Validation loss: 0.479411
#
# Epoch 37
# -------------------------------
# Training loss: 0.484715
# Validation loss: 0.475644
#
# Epoch 38
# -------------------------------
# Training loss: 0.481209
# Validation loss: 0.479292
#
# Epoch 39
# -------------------------------
# Training loss: 0.477506
# Validation loss: 0.472304
#
# Epoch 40
# -------------------------------
# Training loss: 0.477889
# Validation loss: 0.472650
#
# Epoch 41
# -------------------------------
# Training loss: 0.473103
# Validation loss: 0.474371
#
# Epoch 42
# -------------------------------
# Training loss: 0.470236
# Validation loss: 0.461039
#
# Epoch 43
# -------------------------------
# Training loss: 0.466904
# Validation loss: 0.460453
#
# Epoch 44
# -------------------------------
# Training loss: 0.465613
# Validation loss: 0.466926
#
# Epoch 45
# -------------------------------
# Training loss: 0.463620
# Validation loss: 0.453044
#
# Epoch 46
# -------------------------------
# Training loss: 0.459823
# Validation loss: 0.454984
#
# Epoch 47
# -------------------------------
# Training loss: 0.456203
# Validation loss: 0.456188
#
# Epoch 48
# -------------------------------
# Training loss: 0.456756
# Validation loss: 0.457728
#
# Epoch 49
# -------------------------------
# Training loss: 0.451883
# Validation loss: 0.446434
#
# Epoch 50
# -------------------------------
# Training loss: 0.448859
# Validation loss: 0.452504
#
# Epoch 51
# -------------------------------
# Training loss: 0.448031
# Validation loss: 0.443894
#
# Epoch 52
# -------------------------------
# Training loss: 0.445376
# Validation loss: 0.438791
#
# Epoch 53
# -------------------------------
# Training loss: 0.444367
# Validation loss: 0.436704
#
# Epoch 54
# -------------------------------
# Training loss: 0.440027
# Validation loss: 0.438822
#
# Epoch 55
# -------------------------------
# Training loss: 0.438554
# Validation loss: 0.431822
#
# Epoch 56
# -------------------------------
# Training loss: 0.435555
# Validation loss: 0.433537
#
# Epoch 57
# -------------------------------
# Training loss: 0.434690
# Validation loss: 0.427073
#
# Epoch 58
# -------------------------------
# Training loss: 0.432037
# Validation loss: 0.431117
#
# Epoch 59
# -------------------------------
# Training loss: 0.429012
# Validation loss: 0.421287
#
# Epoch 60
# -------------------------------
# Training loss: 0.427806
# Validation loss: 0.426790
#
# Epoch 61
# -------------------------------
# Training loss: 0.426695
# Validation loss: 0.416726
#
# Epoch 62
# -------------------------------
# Training loss: 0.423786
# Validation loss: 0.416193
#
# Epoch 63
# -------------------------------
# Training loss: 0.422833
# Validation loss: 0.422153
#
# Epoch 64
# -------------------------------
# Training loss: 0.419792
# Validation loss: 0.414180
#
# Epoch 65
# -------------------------------
# Training loss: 0.417792
# Validation loss: 0.411847
#
# Epoch 66
# -------------------------------
# Training loss: 0.416624
# Validation loss: 0.415613
#
# Epoch 67
# -------------------------------
# Training loss: 0.414676
# Validation loss: 0.412880
#
# Epoch 68
# -------------------------------
# Training loss: 0.412163
# Validation loss: 0.407227
#
# Epoch 69
# -------------------------------
# Training loss: 0.410095
# Validation loss: 0.399055
#
# Epoch 70
# -------------------------------
# Training loss: 0.410034
# Validation loss: 0.407690
#
# Epoch 71
# -------------------------------
# Training loss: 0.405565
# Validation loss: 0.402087
#
# Epoch 72
# -------------------------------
# Training loss: 0.404788
# Validation loss: 0.399888
#
# Epoch 73
# -------------------------------
# Training loss: 0.402332
# Validation loss: 0.399950
#
# Epoch 74
# -------------------------------
# Training loss: 0.401435
# Validation loss: 0.392834
#
# Epoch 75
# -------------------------------
# Training loss: 0.399076
# Validation loss: 0.398407
#
# Epoch 76
# -------------------------------
# Training loss: 0.398414
# Validation loss: 0.404907
#
# Epoch 77
# -------------------------------
# Training loss: 0.397371
# Validation loss: 0.394419
#
# Epoch 78
# -------------------------------
# Training loss: 0.395065
# Validation loss: 0.394745
#
# Epoch 79
# -------------------------------
# Training loss: 0.392762
# Validation loss: 0.388991
#
# Epoch 80
# -------------------------------
# Training loss: 0.391454
# Validation loss: 0.387652
#
# Epoch 81
# -------------------------------
# Training loss: 0.390795
# Validation loss: 0.394313
#
# Epoch 82
# -------------------------------
# Training loss: 0.387995
# Validation loss: 0.381952
#
# Epoch 83
# -------------------------------
# Training loss: 0.386485
# Validation loss: 0.383897
#
# Epoch 84
# -------------------------------
# Training loss: 0.386561
# Validation loss: 0.383089
#
# Epoch 85
# -------------------------------
# Training loss: 0.383441
# Validation loss: 0.373989
#
# Epoch 86
# -------------------------------
# Training loss: 0.382318
# Validation loss: 0.379922
#
# Epoch 87
# -------------------------------
# Training loss: 0.380272
# Validation loss: 0.377660
#
# Epoch 88
# -------------------------------
# Training loss: 0.380659
# Validation loss: 0.372661
#
# Epoch 89
# -------------------------------
# Training loss: 0.377902
# Validation loss: 0.379911
#
# Epoch 90
# -------------------------------
# Training loss: 0.375406
# Validation loss: 0.367913
#
# Epoch 91
# -------------------------------
# Training loss: 0.375284
# Validation loss: 0.379207
#
# Epoch 92
# -------------------------------
# Training loss: 0.375129
# Validation loss: 0.374107
#
# Epoch 93
# -------------------------------
# Training loss: 0.372053
# Validation loss: 0.373779
#
# Epoch 94
# -------------------------------
# Training loss: 0.371658
# Validation loss: 0.365864
#
# Epoch 95
# -------------------------------
# Training loss: 0.370718
# Validation loss: 0.364925
#
# Epoch 96
# -------------------------------
# Training loss: 0.367433
# Validation loss: 0.367710
#
# Epoch 97
# -------------------------------
# Training loss: 0.365582
# Validation loss: 0.365955
#
# Epoch 98
# -------------------------------
# Training loss: 0.364236
# Validation loss: 0.366924
#
# Epoch 99
# -------------------------------
# Training loss: 0.363046
# Validation loss: 0.364482
#
# Epoch 100
# -------------------------------
# Training loss: 0.363927
# Validation loss: 0.354776
#
# Epoch 101
# -------------------------------
# Training loss: 0.360696
# Validation loss: 0.358619
#
# Epoch 102
# -------------------------------
# Training loss: 0.359372
# Validation loss: 0.360212
#
# Epoch 103
# -------------------------------
# Training loss: 0.357812
# Validation loss: 0.363075
#
# Epoch 104
# -------------------------------
# Training loss: 0.356962
# Validation loss: 0.354745
#
# Epoch 105
# -------------------------------
# Training loss: 0.355072
# Validation loss: 0.361311
#
# Epoch 106
# -------------------------------
# Training loss: 0.353762
# Validation loss: 0.349858
#
# Epoch 107
# -------------------------------
# Training loss: 0.353511
# Validation loss: 0.343660
#
# Epoch 108
# -------------------------------
# Training loss: 0.351104
# Validation loss: 0.350082
#
# Epoch 109
# -------------------------------
# Training loss: 0.352994
# Validation loss: 0.345651
#
# Epoch 110
# -------------------------------
# Training loss: 0.349249
# Validation loss: 0.349511
#
# Epoch 111
# -------------------------------
# Training loss: 0.346333
# Validation loss: 0.344032
#
# Epoch 112
# -------------------------------
# Training loss: 0.346176
# Validation loss: 0.339718
#
# Epoch 113
# -------------------------------
# Training loss: 0.346632
# Validation loss: 0.351225
#
# Epoch 114
# -------------------------------
# Training loss: 0.344133
# Validation loss: 0.341105
#
# Epoch 115
# -------------------------------
# Training loss: 0.342871
# Validation loss: 0.333148
#
# Epoch 116
# -------------------------------
# Training loss: 0.342923
# Validation loss: 0.335940
#
# Epoch 117
# -------------------------------
# Training loss: 0.340093
# Validation loss: 0.335362
#
# Epoch 118
# -------------------------------
# Training loss: 0.339817
# Validation loss: 0.346635
#
# Epoch 119
# -------------------------------
# Training loss: 0.340897
# Validation loss: 0.333395
#
# Epoch 120
# -------------------------------
# Training loss: 0.337971
# Validation loss: 0.335915
#
# Epoch 121
# -------------------------------
# Training loss: 0.337259
# Validation loss: 0.331652
#
# Epoch 122
# -------------------------------
# Training loss: 0.335190
# Validation loss: 0.325087
#
# Epoch 123
# -------------------------------
# Training loss: 0.333854
# Validation loss: 0.330092
#
# Epoch 124
# -------------------------------
# Training loss: 0.332998
# Validation loss: 0.332916
#
# Epoch 125
# -------------------------------
# Training loss: 0.331457
# Validation loss: 0.328500
#
# Epoch 126
# -------------------------------
# Training loss: 0.330546
# Validation loss: 0.327631
#
# Epoch 127
# -------------------------------
# Training loss: 0.331963
# Validation loss: 0.337667
#
# Epoch 128
# -------------------------------
# Training loss: 0.329551
# Validation loss: 0.321268
#
# Epoch 129
# -------------------------------
# Training loss: 0.326197
# Validation loss: 0.333097
#
# Epoch 130
# -------------------------------
# Training loss: 0.324982
# Validation loss: 0.320512
#
# Epoch 131
# -------------------------------
# Training loss: 0.325945
# Validation loss: 0.317480
#
# Epoch 132
# -------------------------------
# Training loss: 0.322836
# Validation loss: 0.316375
#
# Epoch 133
# -------------------------------
# Training loss: 0.323616
# Validation loss: 0.323194
#
# Epoch 134
# -------------------------------
# Training loss: 0.321344
# Validation loss: 0.312184
#
# Epoch 135
# -------------------------------
# Training loss: 0.321635
# Validation loss: 0.335188
#
# Epoch 136
# -------------------------------
# Training loss: 0.319868
# Validation loss: 0.318086
#
# Epoch 137
# -------------------------------
# Training loss: 0.318265
# Validation loss: 0.322298
#
# Epoch 138
# -------------------------------
# Training loss: 0.317003
# Validation loss: 0.313298
#
# Epoch 139
# -------------------------------
# Training loss: 0.316196
# Validation loss: 0.309577
#
# Epoch 140
# -------------------------------
# Training loss: 0.314033
# Validation loss: 0.307073
#
# Epoch 141
# -------------------------------
# Training loss: 0.312900
# Validation loss: 0.307322
#
# Epoch 142
# -------------------------------
# Training loss: 0.311578
# Validation loss: 0.307117
#
# Epoch 143
# -------------------------------
# Training loss: 0.310937
# Validation loss: 0.315140
#
# Epoch 144
# -------------------------------
# Training loss: 0.309166
# Validation loss: 0.321937
#
# Epoch 145
# -------------------------------
# Training loss: 0.305685
# Validation loss: 0.311645
#
# Epoch 146
# -------------------------------
# Training loss: 0.305216
# Validation loss: 0.319055
#
# Epoch 147
# -------------------------------
# Training loss: 0.308151
# Validation loss: 0.301754
#
# Epoch 148
# -------------------------------
# Training loss: 0.302455
# Validation loss: 0.294453
#
# Epoch 149
# -------------------------------
# Training loss: 0.302041
# Validation loss: 0.311167
#
# Epoch 150
# -------------------------------
# Training loss: 0.296799
# Validation loss: 0.296831
#
# Epoch 151
# -------------------------------
# Training loss: 0.299233
# Validation loss: 0.296859
#
# Epoch 152
# -------------------------------
# Training loss: 0.296280
# Validation loss: 0.337305
#
# Epoch 153
# -------------------------------
# Training loss: 0.293191
# Validation loss: 0.283587
#
# Epoch 154
# -------------------------------
# Training loss: 0.294343
# Validation loss: 0.306716
#
# Epoch 155
# -------------------------------
# Training loss: 0.285909
# Validation loss: 0.302873
#
# Epoch 156
# -------------------------------
# Training loss: 0.288015
# Validation loss: 0.322750
#
# Epoch 157
# -------------------------------
# Training loss: 0.287703
# Validation loss: 0.307689
#
# Epoch 158
# -------------------------------
# Training loss: 0.281476
# Validation loss: 0.282319
#
# Epoch 159
# -------------------------------
# Training loss: 0.281097
# Validation loss: 0.270370
#
# Epoch 160
# -------------------------------
# Training loss: 0.273009
# Validation loss: 0.258706
#
# Epoch 161
# -------------------------------
# Training loss: 0.272776
# Validation loss: 0.265516
#
# Epoch 162
# -------------------------------
# Training loss: 0.274785
# Validation loss: 0.292093
#
# Epoch 163
# -------------------------------
# Training loss: 0.266621
# Validation loss: 0.380042
#
# Epoch 164
# -------------------------------
# Training loss: 0.264791
# Validation loss: 0.279007
#
# Epoch 165
# -------------------------------
# Training loss: 0.265197
# Validation loss: 0.286591
#
# Epoch 166
# -------------------------------
# Training loss: 0.259341
# Validation loss: 0.355704
#
# Epoch 167
# -------------------------------
# Training loss: 0.259292
# Validation loss: 0.244401
#
# Epoch 168
# -------------------------------
# Training loss: 0.257667
# Validation loss: 0.253299
#
# Epoch 169
# -------------------------------
# Training loss: 0.253737
# Validation loss: 0.289966
#
# Epoch 170
# -------------------------------
# Training loss: 0.252647
# Validation loss: 0.246545
#
# Epoch 171
# -------------------------------
# Training loss: 0.249876
# Validation loss: 0.240548
#
# Epoch 172
# -------------------------------
# Training loss: 0.251213
# Validation loss: 0.356217
#
# Epoch 173
# -------------------------------
# Training loss: 0.244921
# Validation loss: 0.242167
#
# Epoch 174
# -------------------------------
# Training loss: 0.246553
# Validation loss: 0.227542
#
# Epoch 175
# -------------------------------
# Training loss: 0.248367
# Validation loss: 0.330656
#
# Epoch 176
# -------------------------------
# Training loss: 0.242807
# Validation loss: 0.234831
#
# Epoch 177
# -------------------------------
# Training loss: 0.238199
# Validation loss: 0.231465
#
# Epoch 178
# -------------------------------
# Training loss: 0.236711
# Validation loss: 0.253643
#
# Epoch 179
# -------------------------------
# Training loss: 0.235248
# Validation loss: 0.224653
#
# Epoch 180
# -------------------------------
# Training loss: 0.233773
# Validation loss: 0.234273
#
# Epoch 181
# -------------------------------
# Training loss: 0.238065
# Validation loss: 0.252453
#
# Epoch 182
# -------------------------------
# Training loss: 0.231394
# Validation loss: 0.339853
#
# Epoch 183
# -------------------------------
# Training loss: 0.232009
# Validation loss: 0.225624
#
# Epoch 184
# -------------------------------
# Training loss: 0.236638
# Validation loss: 0.242264
#
# Epoch 185
# -------------------------------
# Training loss: 0.228910
# Validation loss: 0.251283
#
# Epoch 186
# -------------------------------
# Training loss: 0.222693
# Validation loss: 0.243442
#
# Epoch 187
# -------------------------------
# Training loss: 0.228512
# Validation loss: 0.218531
#
# Epoch 188
# -------------------------------
# Training loss: 0.222957
# Validation loss: 0.226889
#
# Epoch 189
# -------------------------------
# Training loss: 0.221714
# Validation loss: 0.218463
#
# Epoch 190
# -------------------------------
# Training loss: 0.220055
# Validation loss: 0.335218
#
# Epoch 191
# -------------------------------
# Training loss: 0.220047
# Validation loss: 0.277072
#
# Epoch 192
# -------------------------------
# Training loss: 0.219146
# Validation loss: 0.218423
#
# Epoch 193
# -------------------------------
# Training loss: 0.215666
# Validation loss: 0.222809
#
# Epoch 194
# -------------------------------
# Training loss: 0.214568
# Validation loss: 0.212138
#
# Epoch 195
# -------------------------------
# Training loss: 0.214246
# Validation loss: 0.232408
#
# Epoch 196
# -------------------------------
# Training loss: 0.214361
# Validation loss: 0.217979
#
# Epoch 197
# -------------------------------
# Training loss: 0.213772
# Validation loss: 0.237816
#
# Epoch 198
# -------------------------------
# Training loss: 0.213658
# Validation loss: 0.206376
#
# Epoch 199
# -------------------------------
# Training loss: 0.210607
# Validation loss: 0.232746
#
# Epoch 200
# -------------------------------
# Training loss: 0.207397
# Validation loss: 0.193983
#
# Epoch 201
# -------------------------------
# Training loss: 0.205859
# Validation loss: 0.192418
#
# Epoch 202
# -------------------------------
# Training loss: 0.209050
# Validation loss: 0.205926
#
# Epoch 203
# -------------------------------
# Training loss: 0.204543
# Validation loss: 0.213066
#
# Epoch 204
# -------------------------------
# Training loss: 0.205526
# Validation loss: 0.251091
#
# Epoch 205
# -------------------------------
# Training loss: 0.210224
# Validation loss: 0.214336
#
# Epoch 206
# -------------------------------
# Training loss: 0.207395
# Validation loss: 0.237138
#
# Epoch 207
# -------------------------------
# Training loss: 0.204119
# Validation loss: 0.231445
#
# Epoch 208
# -------------------------------
# Training loss: 0.205619
# Validation loss: 0.191276
#
# Epoch 209
# -------------------------------
# Training loss: 0.197704
# Validation loss: 0.216087
#
# Epoch 210
# -------------------------------
# Training loss: 0.201089
# Validation loss: 0.282509
#
# Epoch 211
# -------------------------------
# Training loss: 0.203450
# Validation loss: 0.193312
#
# Epoch 212
# -------------------------------
# Training loss: 0.200700
# Validation loss: 0.205101
#
# Epoch 213
# -------------------------------
# Training loss: 0.195471
# Validation loss: 0.241091
#
# Epoch 214
# -------------------------------
# Training loss: 0.196900
# Validation loss: 0.205188
#
# Epoch 215
# -------------------------------
# Training loss: 0.195319
# Validation loss: 0.199575
#
# Epoch 216
# -------------------------------
# Training loss: 0.192638
# Validation loss: 0.184687
#
# Epoch 217
# -------------------------------
# Training loss: 0.191978
# Validation loss: 0.194185
#
# Epoch 218
# -------------------------------
# Training loss: 0.188954
# Validation loss: 0.180762
#
# Epoch 219
# -------------------------------
# Training loss: 0.191010
# Validation loss: 0.199804
#
# Epoch 220
# -------------------------------
# Training loss: 0.188749
# Validation loss: 0.180718
#
# Epoch 221
# -------------------------------
# Training loss: 0.183898
# Validation loss: 0.280834
#
# Epoch 222
# -------------------------------
# Training loss: 0.192201
# Validation loss: 0.268510
#
# Epoch 223
# -------------------------------
# Training loss: 0.186245
# Validation loss: 0.195922
#
# Epoch 224
# -------------------------------
# Training loss: 0.185418
# Validation loss: 0.174320
#
# Epoch 225
# -------------------------------
# Training loss: 0.183944
# Validation loss: 0.182149
#
# Epoch 226
# -------------------------------
# Training loss: 0.183798
# Validation loss: 0.175086
#
# Epoch 227
# -------------------------------
# Training loss: 0.179792
# Validation loss: 0.167790
#
# Epoch 228
# -------------------------------
# Training loss: 0.183667
# Validation loss: 0.220413
#
# Epoch 229
# -------------------------------
# Training loss: 0.178058
# Validation loss: 0.230585
#
# Epoch 230
# -------------------------------
# Training loss: 0.180152
# Validation loss: 0.173316
#
# Epoch 231
# -------------------------------
# Training loss: 0.177882
# Validation loss: 0.400237
#
# Epoch 232
# -------------------------------
# Training loss: 0.177820
# Validation loss: 0.173855
#
# Epoch 233
# -------------------------------
# Training loss: 0.172321
# Validation loss: 0.184718
#
# Epoch 234
# -------------------------------
# Training loss: 0.174785
# Validation loss: 0.250285
#
# Epoch 235
# -------------------------------
# Training loss: 0.169847
# Validation loss: 0.261437
#
# Epoch 236
# -------------------------------
# Training loss: 0.173314
# Validation loss: 0.171610
#
# Epoch 237
# -------------------------------
# Training loss: 0.173956
# Validation loss: 0.174490
#
# Epoch 238
# -------------------------------
# Training loss: 0.169597
# Validation loss: 0.177474
#
# Epoch 239
# -------------------------------
# Training loss: 0.169531
# Validation loss: 0.162295
#
# Epoch 240
# -------------------------------
# Training loss: 0.163415
# Validation loss: 0.171952
#
# Epoch 241
# -------------------------------
# Training loss: 0.169322
# Validation loss: 0.167815
#
# Epoch 242
# -------------------------------
# Training loss: 0.163738
# Validation loss: 0.171723
#
# Epoch 243
# -------------------------------
# Training loss: 0.164048
# Validation loss: 0.152096
#
# Epoch 244
# -------------------------------
# Training loss: 0.163116
# Validation loss: 0.163025
#
# Epoch 245
# -------------------------------
# Training loss: 0.162084
# Validation loss: 0.196682
#
# Epoch 246
# -------------------------------
# Training loss: 0.162227
# Validation loss: 0.194733
#
# Epoch 247
# -------------------------------
# Training loss: 0.158174
# Validation loss: 0.288659
#
# Epoch 248
# -------------------------------
# Training loss: 0.161552
# Validation loss: 0.151134
#
# Epoch 249
# -------------------------------
# Training loss: 0.157663
# Validation loss: 0.265213
#
# Epoch 250
# -------------------------------
# Training loss: 0.169233
# Validation loss: 0.200187
#
# Epoch 251
# -------------------------------
# Training loss: 0.166340
# Validation loss: 0.167767
#
# Epoch 252
# -------------------------------
# Training loss: 0.157530
# Validation loss: 0.177798
#
# Epoch 253
# -------------------------------
# Training loss: 0.156435
# Validation loss: 0.154378
#
# Epoch 254
# -------------------------------
# Training loss: 0.157249
# Validation loss: 0.149480
#
# Epoch 255
# -------------------------------
# Training loss: 0.151164
# Validation loss: 0.146192
#
# Epoch 256
# -------------------------------
# Training loss: 0.151327
# Validation loss: 0.160074
#
# Epoch 257
# -------------------------------
# Training loss: 0.148477
# Validation loss: 0.170661
#
# Epoch 258
# -------------------------------
# Training loss: 0.153955
# Validation loss: 0.149529
#
# Epoch 259
# -------------------------------
# Training loss: 0.153207
# Validation loss: 0.152857
#
# Epoch 260
# -------------------------------
# Training loss: 0.147564
# Validation loss: 0.145298
#
# Epoch 261
# -------------------------------
# Training loss: 0.151613
# Validation loss: 0.143381
#
# Epoch 262
# -------------------------------
# Training loss: 0.153248
# Validation loss: 0.169321
#
# Epoch 263
# -------------------------------
# Training loss: 0.149745
# Validation loss: 0.181540
#
# Epoch 264
# -------------------------------
# Training loss: 0.143627
# Validation loss: 0.390242
#
# Epoch 265
# -------------------------------
# Training loss: 0.147682
# Validation loss: 0.158507
#
# Epoch 266
# -------------------------------
# Training loss: 0.147028
# Validation loss: 0.146493
#
# Epoch 267
# -------------------------------
# Training loss: 0.143153
# Validation loss: 0.150463
#
# Epoch 268
# -------------------------------
# Training loss: 0.138479
# Validation loss: 0.159446
#
# Epoch 269
# -------------------------------
# Training loss: 0.147314
# Validation loss: 0.137565
#
# Epoch 270
# -------------------------------
# Training loss: 0.140577
# Validation loss: 0.182894
#
# Epoch 271
# -------------------------------
# Training loss: 0.141119
# Validation loss: 0.141185
#
# Epoch 272
# -------------------------------
# Training loss: 0.145268
# Validation loss: 0.161658
#
# Epoch 273
# -------------------------------
# Training loss: 0.136409
# Validation loss: 0.138394
#
# Epoch 274
# -------------------------------
# Training loss: 0.139778
# Validation loss: 0.134525
#
# Epoch 275
# -------------------------------
# Training loss: 0.139555
# Validation loss: 0.150818
#
# Epoch 276
# -------------------------------
# Training loss: 0.139791
# Validation loss: 0.181918
#
# Epoch 277
# -------------------------------
# Training loss: 0.136746
# Validation loss: 0.130010
#
# Epoch 278
# -------------------------------
# Training loss: 0.140666
# Validation loss: 0.193993
#
# Epoch 279
# -------------------------------
# Training loss: 0.137470
# Validation loss: 0.186452
#
# Epoch 280
# -------------------------------
# Training loss: 0.135766
# Validation loss: 0.149578
#
# Epoch 281
# -------------------------------
# Training loss: 0.135078
# Validation loss: 0.131336
#
# Epoch 282
# -------------------------------
# Training loss: 0.137243
# Validation loss: 0.148716
#
# Epoch 283
# -------------------------------
# Training loss: 0.132512
# Validation loss: 0.132137
#
# Epoch 284
# -------------------------------
# Training loss: 0.140850
# Validation loss: 0.158294
#
# Epoch 285
# -------------------------------
# Training loss: 0.131947
# Validation loss: 0.147640
#
# Epoch 286
# -------------------------------
# Training loss: 0.131016
# Validation loss: 0.132857
#
# Epoch 287
# -------------------------------
# Training loss: 0.132959
# Validation loss: 0.131108
#
# Epoch 288
# -------------------------------
# Training loss: 0.135811
# Validation loss: 0.142579
#
# Epoch 289
# -------------------------------
# Training loss: 0.130708
# Validation loss: 0.123410
#
# Epoch 290
# -------------------------------
# Training loss: 0.128088
# Validation loss: 0.130676
#
# Epoch 291
# -------------------------------
# Training loss: 0.128260
# Validation loss: 0.124947
#
# Epoch 292
# -------------------------------
# Training loss: 0.126710
# Validation loss: 0.163570
#
# Epoch 293
# -------------------------------
# Training loss: 0.129223
# Validation loss: 0.118236
#
# Epoch 294
# -------------------------------
# Training loss: 0.125630
# Validation loss: 0.124019
#
# Epoch 295
# -------------------------------
# Training loss: 0.123136
# Validation loss: 0.117460
#
# Epoch 296
# -------------------------------
# Training loss: 0.127127
# Validation loss: 0.120830
#
# Epoch 297
# -------------------------------
# Training loss: 0.129113
# Validation loss: 0.161193
#
# Epoch 298
# -------------------------------
# Training loss: 0.130022
# Validation loss: 0.306081
#
# Epoch 299
# -------------------------------
# Training loss: 0.123162
# Validation loss: 0.114664
#
# Epoch 300
# -------------------------------
# Training loss: 0.127346
# Validation loss: 0.310734
#
# Epoch 301
# -------------------------------
# Training loss: 0.131034
# Validation loss: 0.162939
#
# Epoch 302
# -------------------------------
# Training loss: 0.120811
# Validation loss: 0.136253
#
# Epoch 303
# -------------------------------
# Training loss: 0.125032
# Validation loss: 0.141548
#
# Epoch 304
# -------------------------------
# Training loss: 0.125302
# Validation loss: 0.129807
#
# Epoch 305
# -------------------------------
# Training loss: 0.124290
# Validation loss: 0.143669
#
# Epoch 306
# -------------------------------
# Training loss: 0.120719
# Validation loss: 0.152107
#
# Epoch 307
# -------------------------------
# Training loss: 0.117072
# Validation loss: 0.114047
#
# Epoch 308
# -------------------------------
# Training loss: 0.124067
# Validation loss: 0.152435
#
# Epoch 309
# -------------------------------
# Training loss: 0.118683
# Validation loss: 0.110044
#
# Epoch 310
# -------------------------------
# Training loss: 0.116633
# Validation loss: 0.126008
#
# Epoch 311
# -------------------------------
# Training loss: 0.127363
# Validation loss: 0.127619
#
# Epoch 312
# -------------------------------
# Training loss: 0.120317
# Validation loss: 0.120766
#
# Epoch 313
# -------------------------------
# Training loss: 0.118081
# Validation loss: 0.112187
#
# Epoch 314
# -------------------------------
# Training loss: 0.117305
# Validation loss: 0.218731
#
# Epoch 315
# -------------------------------
# Training loss: 0.120119
# Validation loss: 0.137155
#
# Epoch 316
# -------------------------------
# Training loss: 0.115631
# Validation loss: 0.146961
#
# Epoch 317
# -------------------------------
# Training loss: 0.120374
# Validation loss: 0.112009
#
# Epoch 318
# -------------------------------
# Training loss: 0.114523
# Validation loss: 0.125378
#
# Epoch 319
# -------------------------------
# Training loss: 0.117794
# Validation loss: 0.129343
#
# Epoch 320
# -------------------------------
# Training loss: 0.115914
# Validation loss: 0.156714
#
# Epoch 321
# -------------------------------
# Training loss: 0.114550
# Validation loss: 0.135980
#
# Epoch 322
# -------------------------------
# Training loss: 0.114546
# Validation loss: 0.134356
#
# Epoch 323
# -------------------------------
# Training loss: 0.110562
# Validation loss: 0.132239
#
# Epoch 324
# -------------------------------
# Training loss: 0.115534
# Validation loss: 0.128723
#
# Epoch 325
# -------------------------------
# Training loss: 0.119595
# Validation loss: 0.491528
#
# Epoch 326
# -------------------------------
# Training loss: 0.113477
# Validation loss: 0.108897
#
# Epoch 327
# -------------------------------
# Training loss: 0.114309
# Validation loss: 0.121748
#
# Epoch 328
# -------------------------------
# Training loss: 0.110558
# Validation loss: 0.173873
#
# Epoch 329
# -------------------------------
# Training loss: 0.114240
# Validation loss: 0.124928
#
# Epoch 330
# -------------------------------
# Training loss: 0.114707
# Validation loss: 0.131197
#
# Epoch 331
# -------------------------------
# Training loss: 0.106222
# Validation loss: 0.133293
#
# Epoch 332
# -------------------------------
# Training loss: 0.111154
# Validation loss: 0.128607
#
# Epoch 333
# -------------------------------
# Training loss: 0.108292
# Validation loss: 0.138184
#
# Epoch 334
# -------------------------------
# Training loss: 0.106509
# Validation loss: 0.104575
#
# Epoch 335
# -------------------------------
# Training loss: 0.112618
# Validation loss: 0.125851
#
# Epoch 336
# -------------------------------
# Training loss: 0.107517
# Validation loss: 0.105214
#
# Epoch 337
# -------------------------------
# Training loss: 0.110190
# Validation loss: 0.255397
#
# Epoch 338
# -------------------------------
# Training loss: 0.110983
# Validation loss: 0.118485
#
# Epoch 339
# -------------------------------
# Training loss: 0.109882
# Validation loss: 0.121448
#
# Epoch 340
# -------------------------------
# Training loss: 0.108170
# Validation loss: 0.105708
#
# Epoch 341
# -------------------------------
# Training loss: 0.105568
# Validation loss: 0.107928
#
# Epoch 342
# -------------------------------
# Training loss: 0.104453
# Validation loss: 0.107994
#
# Epoch 343
# -------------------------------
# Training loss: 0.102819
# Validation loss: 0.112191
#
# Epoch 344
# -------------------------------
# Training loss: 0.104492
# Validation loss: 0.104553
#
# Epoch 345
# -------------------------------
# Training loss: 0.106380
# Validation loss: 0.103848
#
# Epoch 346
# -------------------------------
# Training loss: 0.105709
# Validation loss: 0.110093
#
# Epoch 347
# -------------------------------
# Training loss: 0.104014
# Validation loss: 0.120512
#
# Epoch 348
# -------------------------------
# Training loss: 0.100526
# Validation loss: 0.096163
#
# Epoch 349
# -------------------------------
# Training loss: 0.100615
# Validation loss: 0.095464
#
# Epoch 350
# -------------------------------
# Training loss: 0.104762
# Validation loss: 0.102271
#
# Epoch 351
# -------------------------------
# Training loss: 0.101651
# Validation loss: 0.137420
#
# Epoch 352
# -------------------------------
# Training loss: 0.105088
# Validation loss: 0.101060
#
# Epoch 353
# -------------------------------
# Training loss: 0.102880
# Validation loss: 0.117456
#
# Epoch 354
# -------------------------------
# Training loss: 0.098715
# Validation loss: 0.113388
#
# Epoch 355
# -------------------------------
# Training loss: 0.103466
# Validation loss: 0.150327
#
# Epoch 356
# -------------------------------
# Training loss: 0.102772
# Validation loss: 0.127709
#
# Epoch 357
# -------------------------------
# Training loss: 0.101121
# Validation loss: 0.097786
#
# Epoch 358
# -------------------------------
# Training loss: 0.099029
# Validation loss: 0.091890
#
# Epoch 359
# -------------------------------
# Training loss: 0.099937
# Validation loss: 0.117067
#
# Epoch 360
# -------------------------------
# Training loss: 0.106661
# Validation loss: 0.124397
#
# Epoch 361
# -------------------------------
# Training loss: 0.099766
# Validation loss: 0.103445
#
# Epoch 362
# -------------------------------
# Training loss: 0.095837
# Validation loss: 0.091931
#
# Epoch 363
# -------------------------------
# Training loss: 0.101642
# Validation loss: 0.099906
#
# Epoch 364
# -------------------------------
# Training loss: 0.099508
# Validation loss: 0.204331
#
# Epoch 365
# -------------------------------
# Training loss: 0.103849
# Validation loss: 0.102395
#
# Epoch 366
# -------------------------------
# Training loss: 0.094856
# Validation loss: 0.105228
#
# Epoch 367
# -------------------------------
# Training loss: 0.096063
# Validation loss: 0.091419
#
# Epoch 368
# -------------------------------
# Training loss: 0.098265
# Validation loss: 0.094378
#
# Epoch 369
# -------------------------------
# Training loss: 0.099901
# Validation loss: 0.093898
#
# Epoch 370
# -------------------------------
# Training loss: 0.098193
# Validation loss: 0.095501
#
# Epoch 371
# -------------------------------
# Training loss: 0.097443
# Validation loss: 0.136335
#
# Epoch 372
# -------------------------------
# Training loss: 0.095964
# Validation loss: 0.123300
#
# Epoch 373
# -------------------------------
# Training loss: 0.096994
# Validation loss: 0.112774
#
# Epoch 374
# -------------------------------
# Training loss: 0.097922
# Validation loss: 0.093836
#
# Epoch 375
# -------------------------------
# Training loss: 0.092892
# Validation loss: 0.115502
#
# Epoch 376
# -------------------------------
# Training loss: 0.102968
# Validation loss: 0.099281
#
# Epoch 377
# -------------------------------
# Training loss: 0.101185
# Validation loss: 0.095935
#
# Epoch 378
# -------------------------------
# Training loss: 0.098563
# Validation loss: 0.144365
#
# Epoch 379
# -------------------------------
# Training loss: 0.094655
# Validation loss: 0.088204
#
# Epoch 380
# -------------------------------
# Training loss: 0.092556
# Validation loss: 0.125668
#
# Epoch 381
# -------------------------------
# Training loss: 0.096580
# Validation loss: 0.126694
#
# Epoch 382
# -------------------------------
# Training loss: 0.093328
# Validation loss: 0.090625
#
# Epoch 383
# -------------------------------
# Training loss: 0.097046
# Validation loss: 0.092965
#
# Epoch 384
# -------------------------------
# Training loss: 0.095318
# Validation loss: 0.103404
#
# Epoch 385
# -------------------------------
# Training loss: 0.095307
# Validation loss: 0.090007
#
# Epoch 386
# -------------------------------
# Training loss: 0.091839
# Validation loss: 0.094427
#
# Epoch 387
# -------------------------------
# Training loss: 0.091876
# Validation loss: 0.090781
#
# Epoch 388
# -------------------------------
# Training loss: 0.092692
# Validation loss: 0.092697
#
# Epoch 389
# -------------------------------
# Training loss: 0.091289
# Validation loss: 0.085872
#
# Epoch 390
# -------------------------------
# Training loss: 0.092029
# Validation loss: 0.107500
#
# Epoch 391
# -------------------------------
# Training loss: 0.094887
# Validation loss: 0.094154
#
# Epoch 392
# -------------------------------
# Training loss: 0.089854
# Validation loss: 0.109876
#
# Epoch 393
# -------------------------------
# Training loss: 0.091031
# Validation loss: 0.092225
#
# Epoch 394
# -------------------------------
# Training loss: 0.089964
# Validation loss: 0.109095
#
# Epoch 395
# -------------------------------
# Training loss: 0.094707
# Validation loss: 0.100669
#
# Epoch 396
# -------------------------------
# Training loss: 0.094139
# Validation loss: 0.099246
#
# Epoch 397
# -------------------------------
# Training loss: 0.089268
# Validation loss: 0.175317
#
# Epoch 398
# -------------------------------
# Training loss: 0.091271
# Validation loss: 0.094980
#
# Epoch 399
# -------------------------------
# Training loss: 0.088309
# Validation loss: 0.105895
#
# Epoch 400
# -------------------------------
# Training loss: 0.091509
# Validation loss: 0.094999
#
# Epoch 401
# -------------------------------
# Training loss: 0.090458
# Validation loss: 0.128642
#
# Epoch 402
# -------------------------------
# Training loss: 0.091341
# Validation loss: 0.093477
#
# Epoch 403
# -------------------------------
# Training loss: 0.093040
# Validation loss: 0.086296
#
# Epoch 404
# -------------------------------
# Training loss: 0.090334
# Validation loss: 0.095371
#
# Epoch 405
# -------------------------------
# Training loss: 0.087997
# Validation loss: 0.088186
#
# Epoch 406
# -------------------------------
# Training loss: 0.086809
# Validation loss: 0.084045
#
# Epoch 407
# -------------------------------
# Training loss: 0.086832
# Validation loss: 0.117929
#
# Epoch 408
# -------------------------------
# Training loss: 0.086268
# Validation loss: 0.103709
#
# Epoch 409
# -------------------------------
# Training loss: 0.088171
# Validation loss: 0.097429
#
# Epoch 410
# -------------------------------
# Training loss: 0.085220
# Validation loss: 0.085445
#
# Epoch 411
# -------------------------------
# Training loss: 0.088046
# Validation loss: 0.087590
#
# Epoch 412
# -------------------------------
# Training loss: 0.088094
# Validation loss: 0.121430
#
# Epoch 413
# -------------------------------
# Training loss: 0.087164
# Validation loss: 0.150259
#
# Epoch 414
# -------------------------------
# Training loss: 0.089136
# Validation loss: 0.091650
#
# Epoch 415
# -------------------------------
# Training loss: 0.088953
# Validation loss: 0.095281
#
# Epoch 416
# -------------------------------
# Training loss: 0.086460
# Validation loss: 0.088788
#
# Epoch 417
# -------------------------------
# Training loss: 0.085384
# Validation loss: 0.091900
#
# Epoch 418
# -------------------------------
# Training loss: 0.085825
# Validation loss: 0.113704
#
# Epoch 419
# -------------------------------
# Training loss: 0.086697
# Validation loss: 0.083804
#
# Epoch 420
# -------------------------------
# Training loss: 0.087419
# Validation loss: 0.084267
#
# Epoch 421
# -------------------------------
# Training loss: 0.086994
# Validation loss: 0.120883
#
# Epoch 422
# -------------------------------
# Training loss: 0.083612
# Validation loss: 0.081719
#
# Epoch 423
# -------------------------------
# Training loss: 0.086368
# Validation loss: 0.133959
#
# Epoch 424
# -------------------------------
# Training loss: 0.090521
# Validation loss: 0.096867
#
# Epoch 425
# -------------------------------
# Training loss: 0.086668
# Validation loss: 0.084069
#
# Epoch 426
# -------------------------------
# Training loss: 0.084221
# Validation loss: 0.086374
#
# Epoch 427
# -------------------------------
# Training loss: 0.084384
# Validation loss: 0.081400
#
# Epoch 428
# -------------------------------
# Training loss: 0.084914
# Validation loss: 0.106818
#
# Epoch 429
# -------------------------------
# Training loss: 0.083619
# Validation loss: 0.084113
#
# Epoch 430
# -------------------------------
# Training loss: 0.088567
# Validation loss: 0.096706
#
# Epoch 431
# -------------------------------
# Training loss: 0.085772
# Validation loss: 0.093337
#
# Epoch 432
# -------------------------------
# Training loss: 0.084398
# Validation loss: 0.104333
#
# Epoch 433
# -------------------------------
# Training loss: 0.086607
# Validation loss: 0.171243
#
# Epoch 434
# -------------------------------
# Training loss: 0.084253
# Validation loss: 0.078376
#
# Epoch 435
# -------------------------------
# Training loss: 0.087261
# Validation loss: 0.111732
#
# Epoch 436
# -------------------------------
# Training loss: 0.082191
# Validation loss: 0.084585
#
# Epoch 437
# -------------------------------
# Training loss: 0.082704
# Validation loss: 0.086905
#
# Epoch 438
# -------------------------------
# Training loss: 0.081418
# Validation loss: 0.091262
#
# Epoch 439
# -------------------------------
# Training loss: 0.077997
# Validation loss: 0.083131
#
# Epoch 440
# -------------------------------
# Training loss: 0.081791
# Validation loss: 0.082780
#
# Epoch 441
# -------------------------------
# Training loss: 0.084331
# Validation loss: 0.089273
#
# Epoch 442
# -------------------------------
# Training loss: 0.083001
# Validation loss: 0.111162
#
# Epoch 443
# -------------------------------
# Training loss: 0.080683
# Validation loss: 0.103937
#
# Epoch 444
# -------------------------------
# Training loss: 0.080233
# Validation loss: 0.077898
#
# Epoch 445
# -------------------------------
# Training loss: 0.081537
# Validation loss: 0.127037
#
# Epoch 446
# -------------------------------
# Training loss: 0.079322
# Validation loss: 0.105336
#
# Epoch 447
# -------------------------------
# Training loss: 0.082378
# Validation loss: 0.085094
#
# Epoch 448
# -------------------------------
# Training loss: 0.079019
# Validation loss: 0.085802
#
# Epoch 449
# -------------------------------
# Training loss: 0.082269
# Validation loss: 0.084152
#
# Epoch 450
# -------------------------------
# Training loss: 0.081708
# Validation loss: 0.116518
#
# Epoch 451
# -------------------------------
# Training loss: 0.078858
# Validation loss: 0.084187
#
# Epoch 452
# -------------------------------
# Training loss: 0.079753
# Validation loss: 0.097273
#
# Epoch 453
# -------------------------------
# Training loss: 0.079489
# Validation loss: 0.086819
#
# Epoch 454
# -------------------------------
# Training loss: 0.079372
# Validation loss: 0.111136
#
# Epoch 455
# -------------------------------
# Training loss: 0.080240
# Validation loss: 0.109482
#
# Epoch 456
# -------------------------------
# Training loss: 0.078808
# Validation loss: 0.089381
#
# Epoch 457
# -------------------------------
# Training loss: 0.077375
# Validation loss: 0.078839
#
# Epoch 458
# -------------------------------
# Training loss: 0.078570
# Validation loss: 0.092181
#
# Epoch 459
# -------------------------------
# Training loss: 0.076551
# Validation loss: 0.086662
#
# Epoch 460
# -------------------------------
# Training loss: 0.082222
# Validation loss: 0.079518
#
# Epoch 461
# -------------------------------
# Training loss: 0.082743
# Validation loss: 0.081705
#
# Epoch 462
# -------------------------------
# Training loss: 0.079109
# Validation loss: 0.075878
#
# Epoch 463
# -------------------------------
# Training loss: 0.078248
# Validation loss: 0.139872
#
# Epoch 464
# -------------------------------
# Training loss: 0.078155
# Validation loss: 0.109064
#
# Epoch 465
# -------------------------------
# Training loss: 0.077641
# Validation loss: 0.114789
#
# Epoch 466
# -------------------------------
# Training loss: 0.076439
# Validation loss: 0.073594
#
# Epoch 467
# -------------------------------
# Training loss: 0.076411
# Validation loss: 0.091278
#
# Epoch 468
# -------------------------------
# Training loss: 0.078178
# Validation loss: 0.099558
#
# Epoch 469
# -------------------------------
# Training loss: 0.074443
# Validation loss: 0.080101
#
# Epoch 470
# -------------------------------
# Training loss: 0.075253
# Validation loss: 0.082096
#
# Epoch 471
# -------------------------------
# Training loss: 0.076673
# Validation loss: 0.088211
#
# Epoch 472
# -------------------------------
# Training loss: 0.075993
# Validation loss: 0.095703
#
# Epoch 473
# -------------------------------
# Training loss: 0.074312
# Validation loss: 0.084260
#
# Epoch 474
# -------------------------------
# Training loss: 0.074675
# Validation loss: 0.082148
#
# Epoch 475
# -------------------------------
# Training loss: 0.076666
# Validation loss: 0.079711
#
# Epoch 476
# -------------------------------
# Training loss: 0.075409
# Validation loss: 0.084713
#
# Epoch 477
# -------------------------------
# Training loss: 0.075656
# Validation loss: 0.096495
#
# Epoch 478
# -------------------------------
# Training loss: 0.078002
# Validation loss: 0.078551
#
# Epoch 479
# -------------------------------
# Training loss: 0.075747
# Validation loss: 0.096461
#
# Epoch 480
# -------------------------------
# Training loss: 0.075883
# Validation loss: 0.086060
#
# Epoch 481
# -------------------------------
# Training loss: 0.076664
# Validation loss: 0.082529
#
# Epoch 482
# -------------------------------
# Training loss: 0.074013
# Validation loss: 0.100628
#
# Epoch 483
# -------------------------------
# Training loss: 0.073946
# Validation loss: 0.093754
#
# Epoch 484
# -------------------------------
# Training loss: 0.074742
# Validation loss: 0.074691
#
# Epoch 485
# -------------------------------
# Training loss: 0.072726
# Validation loss: 0.115274
#
# Epoch 486
# -------------------------------
# Training loss: 0.072279
# Validation loss: 0.196164
#
# Epoch 487
# -------------------------------
# Training loss: 0.074901
# Validation loss: 0.073772
#
# Epoch 488
# -------------------------------
# Training loss: 0.073738
# Validation loss: 0.086531
#
# Epoch 489
# -------------------------------
# Training loss: 0.076844
# Validation loss: 0.080393
#
# Epoch 490
# -------------------------------
# Training loss: 0.075277
# Validation loss: 0.075676
#
# Epoch 491
# -------------------------------
# Training loss: 0.072369
# Validation loss: 0.078834
#
# Epoch 492
# -------------------------------
# Training loss: 0.074273
# Validation loss: 0.133135
#
# Epoch 493
# -------------------------------
# Training loss: 0.076582
# Validation loss: 0.103461
#
# Epoch 494
# -------------------------------
# Training loss: 0.076155
# Validation loss: 0.106411
#
# Epoch 495
# -------------------------------
# Training loss: 0.071171
# Validation loss: 0.076050
#
# Epoch 496
# -------------------------------
# Training loss: 0.070671
# Validation loss: 0.081701
#
# Epoch 497
# -------------------------------
# Training loss: 0.073560
# Validation loss: 0.077764
#
# Epoch 498
# -------------------------------
# Training loss: 0.075075
# Validation loss: 0.080183
#
# Epoch 499
# -------------------------------
# Training loss: 0.072168
# Validation loss: 0.088576
#
# Epoch 500
# -------------------------------
# Training loss: 0.071463
# Validation loss: 0.067693
#
# Done!

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses)+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('BCE Loss')
#plt.yscale('log')
plt.legend()

# %%
# Now test the pretrained model
test_pred = mytools.test_clas(test_loader, final_classifier, device)
test_pred=torch.sigmoid(torch.tensor(test_pred)).numpy()


fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test, test_pred, pos_label=1)
auc_test = sklearn.metrics.auc(fpr, tpr)
print(f'Test AUROC: {auc_test:0.4f}')

plt.plot(fpr, tpr, label=f'Test AUROC: {auc_test:0.4f}')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
# Out:
# Test AUROC: 0.9922

# %%
# Store the pretrained classifier labels
df_test["Class_pre"] = test_pred

# %% [markdown]
# # Setup the adversary model

# %% [markdown]
# ## Initialize model, objective function, and optimizer

# %%
adv = mytools.Adversary(n_classes=Num_classes).to(device)
criterion_adv = nn.CrossEntropyLoss(reduction='none')  # returns loss per sample so we can weight it
opt_adv = torch.optim.Adam(adv.parameters(), lr=1e-5)
scheduler_adv = torch.optim.lr_scheduler.ExponentialLR(opt_adv, gamma=0.999)

# %% [markdown]
# ## Setup dataloaders

# %%
# Convert to tensor dataset and dataloader

# the structure is: feature, adversary label, weight
# The wight is 1 for tritrig and wab, and 0 for phiKK, to prevent the adversary from learning on phiKK events

train_adv_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_train), (torch.from_numpy(y_train.to_numpy().astype(np.float32))==0).float())
train_adv_loader = DataLoader(train_adv_dataset, batch_size=bsize, shuffle=True)

val_adv_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_val), (torch.from_numpy(y_val.to_numpy().astype(np.float32))==0).float() )
val_adv_loader = DataLoader(val_adv_dataset, batch_size=bsize, shuffle=True)

# %% [markdown]
# ## Pre-train the adversary leaving classifier weights fixed

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 6

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 100
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train_adv(train_adv_loader, final_classifier, adv, criterion_adv, opt_adv, scheduler_adv, device))
    Validation_losses = np.append(Validation_losses, mytools.validate_adv(val_adv_loader, final_classifier, adv, criterion_adv, device))
    
    # Keep a running copy of the model with the lowest loss
    if Validation_losses[-1] == np.min(Validation_losses):
        final_adv = copy.deepcopy(adv)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Training loss: 1.617349
# Validation loss: 1.612558
#
# Epoch 2
# -------------------------------
# Training loss: 1.600792
# Validation loss: 1.615699
#
# Epoch 3
# -------------------------------
# Training loss: 1.590138
# Validation loss: 1.585912
#
# Epoch 4
# -------------------------------
# Training loss: 1.582110
# Validation loss: 1.575203
#
# Epoch 5
# -------------------------------
# Training loss: 1.576151
# Validation loss: 1.570890
#
# Epoch 6
# -------------------------------
# Training loss: 1.571882
# Validation loss: 1.567976
#
# Epoch 7
# -------------------------------
# Training loss: 1.568339
# Validation loss: 1.565365
#
# Epoch 8
# -------------------------------
# Training loss: 1.565402
# Validation loss: 1.564037
#
# Epoch 9
# -------------------------------
# Training loss: 1.564039
# Validation loss: 1.561008
#
# Epoch 10
# -------------------------------
# Training loss: 1.561964
# Validation loss: 1.559227
#
# Epoch 11
# -------------------------------
# Training loss: 1.560948
# Validation loss: 1.556413
#
# Epoch 12
# -------------------------------
# Training loss: 1.558245
# Validation loss: 1.555399
#
# Epoch 13
# -------------------------------
# Training loss: 1.557682
# Validation loss: 1.555375
#
# Epoch 14
# -------------------------------
# Training loss: 1.558012
# Validation loss: 1.553853
#
# Epoch 15
# -------------------------------
# Training loss: 1.556882
# Validation loss: 1.553397
#
# Epoch 16
# -------------------------------
# Training loss: 1.554273
# Validation loss: 1.552825
#
# Epoch 17
# -------------------------------
# Training loss: 1.554700
# Validation loss: 1.552725
#
# Epoch 18
# -------------------------------
# Training loss: 1.554747
# Validation loss: 1.549298
#
# Epoch 19
# -------------------------------
# Training loss: 1.552032
# Validation loss: 1.549777
#
# Epoch 20
# -------------------------------
# Training loss: 1.552776
# Validation loss: 1.549694
#
# Epoch 21
# -------------------------------
# Training loss: 1.552257
# Validation loss: 1.549872
#
# Epoch 22
# -------------------------------
# Training loss: 1.552573
# Validation loss: 1.548860
#
# Epoch 23
# -------------------------------
# Training loss: 1.551750
# Validation loss: 1.546854
#
# Epoch 24
# -------------------------------
# Training loss: 1.551390
# Validation loss: 1.547442
#
# Epoch 25
# -------------------------------
# Training loss: 1.550576
# Validation loss: 1.547791
#
# Epoch 26
# -------------------------------
# Training loss: 1.548780
# Validation loss: 1.548538
#
# Epoch 27
# -------------------------------
# Training loss: 1.549620
# Validation loss: 1.549378
#
# Epoch 28
# -------------------------------
# Training loss: 1.549158
# Validation loss: 1.546475
#
# Epoch 29
# -------------------------------
# Training loss: 1.549888
# Validation loss: 1.548386
#
# Epoch 30
# -------------------------------
# Training loss: 1.548618
# Validation loss: 1.546030
#
# Epoch 31
# -------------------------------
# Training loss: 1.549061
# Validation loss: 1.545879
#
# Epoch 32
# -------------------------------
# Training loss: 1.549408
# Validation loss: 1.544612
#
# Epoch 33
# -------------------------------
# Training loss: 1.548119
# Validation loss: 1.544892
#
# Epoch 34
# -------------------------------
# Training loss: 1.549721
# Validation loss: 1.543785
#
# Epoch 35
# -------------------------------
# Training loss: 1.547298
# Validation loss: 1.545452
#
# Epoch 36
# -------------------------------
# Training loss: 1.548126
# Validation loss: 1.545023
#
# Epoch 37
# -------------------------------
# Training loss: 1.549200
# Validation loss: 1.544572
#
# Epoch 38
# -------------------------------
# Training loss: 1.547933
# Validation loss: 1.543763
#
# Epoch 39
# -------------------------------
# Training loss: 1.548828
# Validation loss: 1.544396
#
# Epoch 40
# -------------------------------
# Training loss: 1.547607
# Validation loss: 1.542388
#
# Epoch 41
# -------------------------------
# Training loss: 1.546794
# Validation loss: 1.544520
#
# Epoch 42
# -------------------------------
# Training loss: 1.546732
# Validation loss: 1.545238
#
# Epoch 43
# -------------------------------
# Training loss: 1.546087
# Validation loss: 1.545686
#
# Epoch 44
# -------------------------------
# Training loss: 1.546232
# Validation loss: 1.543679
#
# Epoch 45
# -------------------------------
# Training loss: 1.545808
# Validation loss: 1.542977
#
# Epoch 46
# -------------------------------
# Training loss: 1.547105
# Validation loss: 1.541968
#
# Epoch 47
# -------------------------------
# Training loss: 1.546708
# Validation loss: 1.544088
#
# Epoch 48
# -------------------------------
# Training loss: 1.547426
# Validation loss: 1.543702
#
# Epoch 49
# -------------------------------
# Training loss: 1.546514
# Validation loss: 1.542522
#
# Epoch 50
# -------------------------------
# Training loss: 1.545531
# Validation loss: 1.542633
#
# Epoch 51
# -------------------------------
# Training loss: 1.545916
# Validation loss: 1.544298
#
# Epoch 52
# -------------------------------
# Training loss: 1.547483
# Validation loss: 1.544428
#
# Epoch 53
# -------------------------------
# Training loss: 1.545883
# Validation loss: 1.543017
#
# Epoch 54
# -------------------------------
# Training loss: 1.546779
# Validation loss: 1.542026
#
# Epoch 55
# -------------------------------
# Training loss: 1.546386
# Validation loss: 1.542677
#
# Epoch 56
# -------------------------------
# Training loss: 1.545393
# Validation loss: 1.543131
#
# Epoch 57
# -------------------------------
# Training loss: 1.546131
# Validation loss: 1.541817
#
# Epoch 58
# -------------------------------
# Training loss: 1.546682
# Validation loss: 1.542699
#
# Epoch 59
# -------------------------------
# Training loss: 1.545920
# Validation loss: 1.541959
#
# Epoch 60
# -------------------------------
# Training loss: 1.545902
# Validation loss: 1.542519
#
# Epoch 61
# -------------------------------
# Training loss: 1.545606
# Validation loss: 1.541509
#
# Epoch 62
# -------------------------------
# Training loss: 1.546221
# Validation loss: 1.542249
#
# Epoch 63
# -------------------------------
# Training loss: 1.545075
# Validation loss: 1.541671
#
# Epoch 64
# -------------------------------
# Training loss: 1.545516
# Validation loss: 1.541539
#
# Epoch 65
# -------------------------------
# Training loss: 1.545236
# Validation loss: 1.541391
#
# Epoch 66
# -------------------------------
# Training loss: 1.545707
# Validation loss: 1.543934
#
# Epoch 67
# -------------------------------
# Training loss: 1.545166
# Validation loss: 1.542522
#
# Epoch 68
# -------------------------------
# Training loss: 1.546056
# Validation loss: 1.540351
#
# Epoch 69
# -------------------------------
# Training loss: 1.545318
# Validation loss: 1.541202
#
# Epoch 70
# -------------------------------
# Training loss: 1.545174
# Validation loss: 1.543174
#
# Epoch 71
# -------------------------------
# Training loss: 1.545677
# Validation loss: 1.543059
#
# Epoch 72
# -------------------------------
# Training loss: 1.545581
# Validation loss: 1.540923
#
# Epoch 73
# -------------------------------
# Training loss: 1.544743
# Validation loss: 1.541706
#
# Epoch 74
# -------------------------------
# Training loss: 1.545741
# Validation loss: 1.541433
#
# Epoch 75
# -------------------------------
# Training loss: 1.545947
# Validation loss: 1.541060
#
# Epoch 76
# -------------------------------
# Training loss: 1.544209
# Validation loss: 1.540032
#
# Epoch 77
# -------------------------------
# Training loss: 1.545477
# Validation loss: 1.540478
#
# Epoch 78
# -------------------------------
# Training loss: 1.545583
# Validation loss: 1.541313
#
# Epoch 79
# -------------------------------
# Training loss: 1.544448
# Validation loss: 1.540454
#
# Epoch 80
# -------------------------------
# Training loss: 1.545210
# Validation loss: 1.541746
#
# Epoch 81
# -------------------------------
# Training loss: 1.543967
# Validation loss: 1.542122
#
# Epoch 82
# -------------------------------
# Training loss: 1.544907
# Validation loss: 1.541303
#
# Epoch 83
# -------------------------------
# Training loss: 1.545071
# Validation loss: 1.541838
#
# Epoch 84
# -------------------------------
# Training loss: 1.544743
# Validation loss: 1.541524
#
# Epoch 85
# -------------------------------
# Training loss: 1.545401
# Validation loss: 1.541867
#
# Epoch 86
# -------------------------------
# Training loss: 1.545728
# Validation loss: 1.542352
#
# Epoch 87
# -------------------------------
# Training loss: 1.544964
# Validation loss: 1.541249
#
# Epoch 88
# -------------------------------
# Training loss: 1.545105
# Validation loss: 1.543064
#
# Epoch 89
# -------------------------------
# Training loss: 1.544899
# Validation loss: 1.541170
#
# Epoch 90
# -------------------------------
# Training loss: 1.543911
# Validation loss: 1.540972
#
# Epoch 91
# -------------------------------
# Training loss: 1.546135
# Validation loss: 1.540449
#
# Epoch 92
# -------------------------------
# Training loss: 1.544791
# Validation loss: 1.541194
#
# Epoch 93
# -------------------------------
# Training loss: 1.544491
# Validation loss: 1.541316
#
# Epoch 94
# -------------------------------
# Training loss: 1.544413
# Validation loss: 1.541184
#
# Epoch 95
# -------------------------------
# Training loss: 1.544981
# Validation loss: 1.539357
#
# Epoch 96
# -------------------------------
# Training loss: 1.544423
# Validation loss: 1.541671
#
# Epoch 97
# -------------------------------
# Training loss: 1.545609
# Validation loss: 1.540768
#
# Epoch 98
# -------------------------------
# Training loss: 1.544974
# Validation loss: 1.540895
#
# Epoch 99
# -------------------------------
# Training loss: 1.545555
# Validation loss: 1.540601
#
# Epoch 100
# -------------------------------
# Training loss: 1.544641
# Validation loss: 1.539851
#
# Done!

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses)+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('BCE Loss')
plt.legend()

# %% [markdown]
# # Train full adverserial neural network

# %% [markdown]
# # Setup dataloaders

# %%
# the structure is: feature, classifier label, adversary label, weight
# The wight is 1 for tritrig and wab, and 0 for phiKK, to prevent the adversary from learning on phiKK events

train_full_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy().astype(np.float32))  , torch.from_numpy(y_train.to_numpy().astype(np.float32)).unsqueeze(1), torch.from_numpy(y_adv_train),  (torch.from_numpy(y_train.to_numpy().astype(np.float32))==0).float())
train_full_loader = DataLoader(train_full_dataset, batch_size=bsize, shuffle=True)

val_full_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy().astype(np.float32))  , torch.from_numpy(y_val.to_numpy().astype(np.float32)).unsqueeze(1),  torch.from_numpy(y_adv_val),  (torch.from_numpy(y_val.to_numpy().astype(np.float32))==0).float())
val_full_loader = DataLoader(val_full_dataset, batch_size=bsize, shuffle=True)

# %% [markdown]
# ## Define loss functions

# %%
BCE_loss = nn.BCEWithLogitsLoss()
CE_loss = nn.CrossEntropyLoss(reduction='none') # returns loss per sample so we can weight it

def full_loss(output_clas, output_adv, target_clas, target_adv, w, lambda_):

    loss1 = BCE_loss(output_clas, target_clas )  # classification loss
    sample_losses2 = CE_loss(output_adv, target_adv)  # adversarial losses, since we set reduction='none', this is now a vector of losses, one per sample in the batch

     # Weighted mean loss over non-zero weights
    nonzero = w > 0
    loss2 = (sample_losses2[nonzero] * w[nonzero]).sum() / w[nonzero].sum()

    loss = loss1 - lambda_*loss2

    return loss

# %% [markdown]
# ## Setup optimizers

# %%
optimizer_clas = optim.Adam(final_classifier.parameters(), lr=1e-7,betas=(0.5, 0.999))
optimizer_adv = optim.Adam(final_adv.parameters(), lr=1e-5,betas=(0.5, 0.999))

scheduler_clas = torch.optim.lr_scheduler.ExponentialLR(optimizer_clas, gamma=0.999)
scheduler_adv = torch.optim.lr_scheduler.ExponentialLR(optimizer_adv, gamma=0.999)

# %% [markdown]
# ## Adversarial training

# %%
Training_losses_clas = np.array([])
Training_losses_adv = np.array([])
Validation_losses_clas = np.array([])
Validation_losses_adv = np.array([])
diff_scores = np.array([])


epochs = 50
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")

    # Get validation losses
    E_clas_val_loss, E_adv_val_loss = mytools.validate_full(val_full_loader, final_classifier, final_adv, full_loss, lambda_, criterion_adv, device)
    Validation_losses_clas = np.append(Validation_losses_clas, E_clas_val_loss)
    Validation_losses_adv = np.append(Validation_losses_adv, E_adv_val_loss)

    # Train adversary and classifier
    E_clas_training_loss , E_adv_training_loss = mytools.train_full(train_full_loader, final_classifier, final_adv, full_loss, lambda_, criterion_adv, optimizer_clas, optimizer_adv, scheduler_clas, scheduler_adv, device)
    Training_losses_clas = np.append(Training_losses_clas, E_clas_training_loss)
    Training_losses_adv = np.append(Training_losses_adv, E_adv_training_loss)

    # Get the diff_score
    df_test["Class_adv"] = mytools.test_clas(test_loader, final_classifier, device)
    df_bkg = df_test.loc[ (df_test.type == 'tritrig') | (df_test.type == 'wab')]
    per = np.percentile(df_bkg['Class_adv'],99)
    df_cut = df_bkg[df_bkg['Class_adv']>per].reset_index(drop=True)
    x1 = 1000* df_bkg.InvM.values
    x2 = 1000*df_cut.InvM.values
    diff_scores = np.append(diff_scores, mytools.get_diff_score(x1,x2) )

    # Keep a running copy of the model with the lowest loss
    if diff_scores[-1] == np.min(diff_scores):
        final_clas_adv = copy.deepcopy(final_classifier)
        final_adv_adv = copy.deepcopy(final_adv)

            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Classifier validation loss: -154.087596
# Adversary validation loss: 1.541573
# Classifier training loss: -155.267037
# Adversary training loss: 1.553915
# Epoch 2
# -------------------------------
# Classifier validation loss: -155.184612
# Adversary validation loss: 1.552549
# Classifier training loss: -155.573025
# Adversary training loss: 1.557029
# Epoch 3
# -------------------------------
# Classifier validation loss: -155.104947
# Adversary validation loss: 1.551764
# Classifier training loss: -156.133806
# Adversary training loss: 1.562677
# Epoch 4
# -------------------------------
# Classifier validation loss: -155.958350
# Adversary validation loss: 1.560479
# Classifier training loss: -156.935844
# Adversary training loss: 1.570793
# Epoch 5
# -------------------------------
# Classifier validation loss: -155.106441
# Adversary validation loss: 1.551925
# Classifier training loss: -157.387795
# Adversary training loss: 1.575227
# Epoch 6
# -------------------------------
# Classifier validation loss: -157.009148
# Adversary validation loss: 1.570993
# Classifier training loss: -157.437887
# Adversary training loss: 1.575643
# Epoch 7
# -------------------------------
# Classifier validation loss: -156.727173
# Adversary validation loss: 1.568172
# Classifier training loss: -157.359280
# Adversary training loss: 1.574877
# Epoch 8
# -------------------------------
# Classifier validation loss: -155.994162
# Adversary validation loss: 1.561041
# Classifier training loss: -157.084240
# Adversary training loss: 1.572109
# Epoch 9
# -------------------------------
# Classifier validation loss: -157.232146
# Adversary validation loss: 1.573339
# Classifier training loss: -156.748659
# Adversary training loss: 1.568703
# Epoch 10
# -------------------------------
# Classifier validation loss: -156.201395
# Adversary validation loss: 1.563022
# Classifier training loss: -156.545086
# Adversary training loss: 1.566664
# Epoch 11
# -------------------------------
# Classifier validation loss: -156.266100
# Adversary validation loss: 1.563575
# Classifier training loss: -156.664630
# Adversary training loss: 1.567803
# Epoch 12
# -------------------------------
# Classifier validation loss: -156.477704
# Adversary validation loss: 1.565709
# Classifier training loss: -156.585461
# Adversary training loss: 1.566999
# Epoch 13
# -------------------------------
# Classifier validation loss: -156.141282
# Adversary validation loss: 1.562382
# Classifier training loss: -156.349224
# Adversary training loss: 1.564597
# Epoch 14
# -------------------------------
# Classifier validation loss: -156.069060
# Adversary validation loss: 1.561628
# Classifier training loss: -156.411648
# Adversary training loss: 1.565227
# Epoch 15
# -------------------------------
# Classifier validation loss: -155.966422
# Adversary validation loss: 1.560603
# Classifier training loss: -156.389523
# Adversary training loss: 1.564960
# Epoch 16
# -------------------------------
# Classifier validation loss: -155.921910
# Adversary validation loss: 1.560137
# Classifier training loss: -156.457716
# Adversary training loss: 1.565609
# Epoch 17
# -------------------------------
# Classifier validation loss: -155.590181
# Adversary validation loss: 1.556790
# Classifier training loss: -156.485306
# Adversary training loss: 1.565888
# Epoch 18
# -------------------------------
# Classifier validation loss: -155.819271
# Adversary validation loss: 1.559186
# Classifier training loss: -156.339114
# Adversary training loss: 1.564411
# Epoch 19
# -------------------------------
# Classifier validation loss: -156.054415
# Adversary validation loss: 1.561451
# Classifier training loss: -156.619154
# Adversary training loss: 1.567218
# Epoch 20
# -------------------------------
# Classifier validation loss: -155.842518
# Adversary validation loss: 1.559351
# Classifier training loss: -156.469135
# Adversary training loss: 1.565685
# Epoch 21
# -------------------------------
# Classifier validation loss: -155.961005
# Adversary validation loss: 1.560491
# Classifier training loss: -156.463223
# Adversary training loss: 1.565613
# Epoch 22
# -------------------------------
# Classifier validation loss: -155.958296
# Adversary validation loss: 1.560437
# Classifier training loss: -156.577883
# Adversary training loss: 1.566745
# Epoch 23
# -------------------------------
# Classifier validation loss: -156.082776
# Adversary validation loss: 1.561667
# Classifier training loss: -156.410013
# Adversary training loss: 1.565052
# Epoch 24
# -------------------------------
# Classifier validation loss: -155.982587
# Adversary validation loss: 1.560654
# Classifier training loss: -156.535047
# Adversary training loss: 1.566289
# Epoch 25
# -------------------------------
# Classifier validation loss: -156.059117
# Adversary validation loss: 1.561478
# Classifier training loss: -156.593354
# Adversary training loss: 1.566874
# Epoch 26
# -------------------------------
# Classifier validation loss: -156.058084
# Adversary validation loss: 1.561463
# Classifier training loss: -156.571722
# Adversary training loss: 1.566658
# Epoch 27
# -------------------------------
# Classifier validation loss: -156.206457
# Adversary validation loss: 1.562928
# Classifier training loss: -156.589804
# Adversary training loss: 1.566800
# Epoch 28
# -------------------------------
# Classifier validation loss: -156.162548
# Adversary validation loss: 1.562453
# Classifier training loss: -156.590801
# Adversary training loss: 1.566831
# Epoch 29
# -------------------------------
# Classifier validation loss: -156.102846
# Adversary validation loss: 1.561896
# Classifier training loss: -156.595468
# Adversary training loss: 1.566873
# Epoch 30
# -------------------------------
# Classifier validation loss: -156.246682
# Adversary validation loss: 1.563284
# Classifier training loss: -156.488977
# Adversary training loss: 1.565809
# Epoch 31
# -------------------------------
# Classifier validation loss: -156.216918
# Adversary validation loss: 1.563024
# Classifier training loss: -156.487509
# Adversary training loss: 1.565784
# Epoch 32
# -------------------------------
# Classifier validation loss: -156.085386
# Adversary validation loss: 1.561733
# Classifier training loss: -156.550476
# Adversary training loss: 1.566390
# Epoch 33
# -------------------------------
# Classifier validation loss: -156.190959
# Adversary validation loss: 1.562750
# Classifier training loss: -156.729733
# Adversary training loss: 1.568201
# Epoch 34
# -------------------------------
# Classifier validation loss: -156.170396
# Adversary validation loss: 1.562564
# Classifier training loss: -156.611875
# Adversary training loss: 1.567011
# Epoch 35
# -------------------------------
# Classifier validation loss: -156.159764
# Adversary validation loss: 1.562528
# Classifier training loss: -156.495825
# Adversary training loss: 1.565862
# Epoch 36
# -------------------------------
# Classifier validation loss: -155.896593
# Adversary validation loss: 1.559894
# Classifier training loss: -156.653881
# Adversary training loss: 1.567425
# Epoch 37
# -------------------------------
# Classifier validation loss: -155.871493
# Adversary validation loss: 1.559550
# Classifier training loss: -156.549974
# Adversary training loss: 1.566405
# Epoch 38
# -------------------------------
# Classifier validation loss: -156.179939
# Adversary validation loss: 1.562686
# Classifier training loss: -156.517438
# Adversary training loss: 1.566099
# Epoch 39
# -------------------------------
# Classifier validation loss: -155.960076
# Adversary validation loss: 1.560473
# Classifier training loss: -156.644421
# Adversary training loss: 1.567335
# Epoch 40
# -------------------------------
# Classifier validation loss: -155.736627
# Adversary validation loss: 1.558331
# Classifier training loss: -156.573036
# Adversary training loss: 1.566607
# Epoch 41
# -------------------------------
# Classifier validation loss: -156.287773
# Adversary validation loss: 1.563710
# Classifier training loss: -156.536894
# Adversary training loss: 1.566245
# Epoch 42
# -------------------------------
# Classifier validation loss: -156.075295
# Adversary validation loss: 1.561590
# Classifier training loss: -156.450050
# Adversary training loss: 1.565385
# Epoch 43
# -------------------------------
# Classifier validation loss: -156.263912
# Adversary validation loss: 1.563503
# Classifier training loss: -156.532985
# Adversary training loss: 1.566236
# Epoch 44
# -------------------------------
# Classifier validation loss: -156.072439
# Adversary validation loss: 1.561624
# Classifier training loss: -156.612519
# Adversary training loss: 1.567016
# Epoch 45
# -------------------------------
# Classifier validation loss: -156.152456
# Adversary validation loss: 1.562365
# Classifier training loss: -156.658827
# Adversary training loss: 1.567440
# Epoch 46
# -------------------------------
# Classifier validation loss: -156.141462
# Adversary validation loss: 1.562237
# Classifier training loss: -156.538514
# Adversary training loss: 1.566261
# Epoch 47
# -------------------------------
# Classifier validation loss: -156.261594
# Adversary validation loss: 1.563434
# Classifier training loss: -156.602190
# Adversary training loss: 1.566900
# Epoch 48
# -------------------------------
# Classifier validation loss: -156.261617
# Adversary validation loss: 1.563405
# Classifier training loss: -156.650450
# Adversary training loss: 1.567373
# Epoch 49
# -------------------------------
# Classifier validation loss: -156.104838
# Adversary validation loss: 1.561845
# Classifier training loss: -156.503601
# Adversary training loss: 1.565930
# Epoch 50
# -------------------------------
# Classifier validation loss: -156.183386
# Adversary validation loss: 1.562649
# Classifier training loss: -156.597227
# Adversary training loss: 1.566851
# Done!

# %%
fig, ax1 = plt.subplots()

best_epoch = np.argmin(diff_scores)+1



#ax1.plot(np.arange(len(Training_losses_adv))+1, Training_losses_adv, 'k-', label='Training Adversary')
ax1.plot(np.arange(len(Validation_losses_adv))+1, Validation_losses_adv, 'k-', label='Validation Adversary')

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Adversary Loss', color='k')
ax1.tick_params(axis='y', labelcolor='k')

ax2 = ax1.twinx()

#ax2.plot(np.arange(len(Training_losses_clas))+1, Training_losses_clas, 'r-', label='Training Classifier')
ax2.plot(np.arange(len(Validation_losses_clas))+1, Validation_losses_clas, 'r-', label='Validation Classifier')
ax2.axvline(best_epoch,label="Final model stopped here",color='k')

ax2.set_ylabel('Classifier Loss', color='r')
ax2.tick_params(axis='y', labelcolor='r')

# %% [markdown]
# ## Test adversarially trained models

# %%
# Now test the pretrained model
test_pred = mytools.test_clas(test_loader, final_clas_adv, device)
test_pred=torch.sigmoid(torch.tensor(test_pred)).numpy()


fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test, test_pred, pos_label=1)
auc_test = sklearn.metrics.auc(fpr, tpr)
print(f'Test AUROC: {auc_test:0.4f}')

plt.plot(fpr, tpr, label=f'Test AUROC: {auc_test:0.4f}')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
# Out:
# Test AUROC: 0.9845

# %%
df_test["Class_adv"] = test_pred
df_bkg = df_test.loc[ (df_test.type == 'tritrig') | (df_test.type == 'wab')]
per = np.percentile(df_bkg['Class_adv'],99)
df_cut = df_bkg[df_bkg['Class_adv']>per].reset_index(drop=True)
x_vals = 1000*df_cut.InvM

plt.figure()
plt.hist(1000*df_bkg.InvM, bins=np.arange(980,1250,1), histtype='step', label='No selection', density=True)
plt.hist(x_vals, bins=np.arange(980,1250,1), histtype='step', label= '99 percent selection', density=True)
plt.axvline(1019.461, color='k', linestyle='dashed', linewidth=1, label='PDG phi mass')
plt.xlabel('Invariant Mass [MeV]')
plt.ylabel('Normalized Counts')
plt.legend()

# %%
x1 = 1000* df_bkg.InvM.values
x2 = 1000*df_cut.InvM.values

N, edges = np.histogram(x1, bins=np.arange(980,1250,1), density=False)
M, edges = np.histogram(x2, bins=np.arange(980,1250,1), density=False)

N2 = N[(N > 0) & (M > 0)]
M2 = M[(N > 0) & (M > 0)]

diff_score = np.mean(np.abs(N2/np.sum(N)-M2/np.sum(M)) / (np.sqrt(N2)/np.sum(N) + np.sqrt(M2)/np.sum(M) ))

print(diff_score)

N = len(df_test.loc[ ((df_test.type == 'tritrig') | (df_test.type == 'wab')) & (df_test.InvM < (1.019 + 0.01) )  & (df_test.InvM > (1.019 - 0.01) ) & ( df_test['Class_adv']>per ) ] )
S = len(df_test.loc[ (df_test.type == 'phiKK') & (df_test.InvM < (1.019 + 0.01) )  & (df_test.InvM > (1.019 - 0.01) ) & ( df_test['Class_adv']>per )  ] )

print(S/N)
# Out:
# 0.6990631415689029
# 3.579185520361991

# %%
df_test["Class_adv"] = test_pred
df_test.to_pickle("/Users/mghrear/data/ML_data/patch/ANN_results_2021_relu_run"+str(run)+"_limited_sideband_a.pk")

# %%
# Save the adversarially trained models
torch.save(final_clas_adv.state_dict(), "/Users/mghrear/data/ML_data/patch/classifier_adv_2021_relu_run"+str(run)+"_limited_sideband_a.pt")
torch.save(final_adv_adv.state_dict(), "/Users/mghrear/data/ML_data/patch/adversary_adv_2021_relu_run"+str(run)+"_limited_sideband_a.pt")

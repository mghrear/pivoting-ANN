# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import torch 
from torch import nn, optim
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import sklearn
from sklearn.model_selection import train_test_split
import copy
import mytools
from scipy.stats import ks_2samp, wasserstein_distance


# Print and store device being used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cpu

# %% [markdown]
# # Define important parameters

# %%
# Number of class in invariant mass used by the adversary
Num_classes = 5
# Hyper-parameter for adversarial training of the classifier
lambda_ = 100.0

run = 1

# %% [markdown]
# # Load and setup the data

# %%
df_tritrig = pd.read_pickle('/Users/mghrear/data/ML_data/patch/BDT_2019_tritrig_limited.pk')
df_tritrig['PhiKK'] = 0.0 # Add label
df_tritrig = df_tritrig.sample(frac=1, random_state=42).reset_index(drop=True) # Now shuffle the combined dataframe
df_phiKK = pd.read_pickle('/Users/mghrear/data/ML_data/patch/BDT_2019_phiKK_limited.pk')
df_phiKK['PhiKK'] = 1.0 # Add label
df_wab = pd.read_pickle('/Users/mghrear/data/ML_data/patch/BDT_2019_wab_limited.pk')
df_wab['PhiKK'] = 0.0 # Add label
df_wab = df_wab.sample(frac=1, random_state=42).reset_index(drop=True) # Now shuffle the combined dataframe

df_data_train_bkg = pd.read_pickle('/Users/mghrear/data/ML_data/patch/BDT_2019_data_limited_sideband_train_bkg.pk')
df_data_train_bkg['PhiKK'] = 0.0 # Add label

df_data = pd.read_pickle('/Users/mghrear/data/ML_data/patch/BDT_2019_data_limited_sideband_test.pk')

print("phiKK: ", len(df_phiKK))
print("data bkg: ", len(df_data_train_bkg))
print("data: ", len(df_data))
# Out:
# phiKK:  8193
# data bkg:  23749
# data:  45775

# %%
phiKK_train = df_phiKK[0:4000]


# Combine and shuffle all training data
df_train = pd.concat([phiKK_train, df_data_train_bkg], ignore_index=True, sort=False)
df_train = df_train.sample(frac=1, random_state=42).reset_index(drop=True)

# Get edges in invariant mass classes for one-hot encoding
# To be used for adverserial labels
# The edges are chosen such that each bin has equal number of background events
one_hot_edges = mytools.get_one_hot_edges(mytools.get_InvM( df_data ), n_bins=Num_classes)

# Split the training data into training and validation sets
df_train, df_val = train_test_split(df_train, test_size=0.33, random_state=41)

# Make X and y for training and validation sets
# the adverserial network has its own labels
X_train = df_train.drop(columns=['PhiKK'])
y_train = df_train['PhiKK']
y_adv_train = mytools.get_adv_labels( mytools.get_InvM(df_train), one_hot_edges)
X_val = df_val.drop(columns=['PhiKK'])
y_val = df_val['PhiKK']
y_adv_val = mytools.get_adv_labels( mytools.get_InvM(df_val), one_hot_edges)

# Make testing set with remaining events
tritrig_test = df_tritrig[20000:]
tritrig_test['type']= 'tritrig'
wab_test = df_wab[4000:]
wab_test['type']= 'wab'
phiKK_test = df_phiKK[4000:]
phiKK_test['type']= 'phiKK'

# This is just used for an invariance test
df_test = pd.concat([tritrig_test, phiKK_test,wab_test], ignore_index=True, sort=False)
df_test = df_test.sample(frac=1, random_state=42).reset_index(drop=True) # Now shuffle the combined dataframe

X_test = df_test.drop(columns=['PhiKK','type'])
y_test = df_test['PhiKK']
y_adv_test = mytools.get_adv_labels( mytools.get_InvM(df_test), one_hot_edges)

df_test["InvM"] = mytools.get_InvM(df_test) 



# Make final data set
X_final = df_data
# Out:
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_92642/340893858.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tritrig_test['type']= 'tritrig'
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_92642/340893858.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wab_test['type']= 'wab'
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_92642/340893858.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phiKK_test['type']= 'phiKK'

# %% [markdown]
# # Setup the classifier model

# %% [markdown]
# ## Define model architecture

# %%
# simple MLP for binary classification (single logit output)
class Classifier(nn.Module):
    def __init__(self, in_features=X_train.shape[1], hidden1=264, hidden2=264, hidden3=128, hidden4=128, hidden5=64):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(in_features, hidden1,bias=False),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Linear(hidden1, hidden2,bias=False),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Linear(hidden2, hidden3,bias=False),
            nn.BatchNorm1d(hidden3),
            nn.ReLU(),
            nn.Linear(hidden3, hidden4,bias=False),
            nn.BatchNorm1d(hidden4),
            nn.ReLU(),
            nn.Linear(hidden4, hidden5,bias=False),
            nn.BatchNorm1d(hidden5),
            nn.ReLU(),
            nn.Linear(hidden5, 1),
        )
    def forward(self, x):
        return self.net(x)

# %% [markdown]
# ## Setup dataloaders

# %%
bsize = 124

# Convert to tensor dataset and dataloader
train_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy().astype(np.float32))  , torch.from_numpy(y_train.to_numpy().astype(np.float32)).unsqueeze(1)  )
train_loader = DataLoader(train_dataset, batch_size=bsize, shuffle=True)

val_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy().astype(np.float32))  , torch.from_numpy(y_val.to_numpy().astype(np.float32)).unsqueeze(1)  )
val_loader = DataLoader(val_dataset, batch_size=bsize, shuffle=True)

test_dataset = TensorDataset(torch.from_numpy(X_test.to_numpy().astype(np.float32))  )
test_loader = DataLoader(test_dataset, batch_size=bsize, shuffle=False)

# %% [markdown]
# ## Initialize model, objective function, and optimizer

# %%
clas = Classifier().to(device)
criterion_clas = nn.BCEWithLogitsLoss()
optimizer_clas = optim.Adam(clas.parameters(), lr=1e-5)
scheduler_clas = torch.optim.lr_scheduler.ExponentialLR(optimizer_clas, gamma=0.99995)

# %% [markdown]
# ## Pre-train the classifier

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 10

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 500
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train_clas(train_loader, clas, criterion_clas, optimizer_clas, scheduler_clas, device))
    Validation_losses = np.append(Validation_losses, mytools.validate_clas(val_loader, clas, criterion_clas, device))
    
    # Keep a running copy of the model with the lowest loss
    if Validation_losses[-1] == np.min(Validation_losses):
        final_classifier = copy.deepcopy(clas)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Training loss: 0.559386
# Validation loss: 0.526089
#
# Epoch 2
# -------------------------------
# Training loss: 0.509560
# Validation loss: 0.475220
#
# Epoch 3
# -------------------------------
# Training loss: 0.479982
# Validation loss: 0.460329
#
# Epoch 4
# -------------------------------
# Training loss: 0.461200
# Validation loss: 0.427124
#
# Epoch 5
# -------------------------------
# Training loss: 0.445004
# Validation loss: 0.424577
#
# Epoch 6
# -------------------------------
# Training loss: 0.431988
# Validation loss: 0.413891
#
# Epoch 7
# -------------------------------
# Training loss: 0.421405
# Validation loss: 0.398435
#
# Epoch 8
# -------------------------------
# Training loss: 0.413584
# Validation loss: 0.394391
#
# Epoch 9
# -------------------------------
# Training loss: 0.401871
# Validation loss: 0.382952
#
# Epoch 10
# -------------------------------
# Training loss: 0.395230
# Validation loss: 0.378348
#
# Epoch 11
# -------------------------------
# Training loss: 0.388726
# Validation loss: 0.378813
#
# Epoch 12
# -------------------------------
# Training loss: 0.382086
# Validation loss: 0.367345
#
# Epoch 13
# -------------------------------
# Training loss: 0.374043
# Validation loss: 0.361381
#
# Epoch 14
# -------------------------------
# Training loss: 0.370666
# Validation loss: 0.354475
#
# Epoch 15
# -------------------------------
# Training loss: 0.366514
# Validation loss: 0.351030
#
# Epoch 16
# -------------------------------
# Training loss: 0.362366
# Validation loss: 0.349346
#
# Epoch 17
# -------------------------------
# Training loss: 0.356237
# Validation loss: 0.341745
#
# Epoch 18
# -------------------------------
# Training loss: 0.351412
# Validation loss: 0.339213
#
# Epoch 19
# -------------------------------
# Training loss: 0.348935
# Validation loss: 0.334911
#
# Epoch 20
# -------------------------------
# Training loss: 0.344839
# Validation loss: 0.325536
#
# Epoch 21
# -------------------------------
# Training loss: 0.341108
# Validation loss: 0.323895
#
# Epoch 22
# -------------------------------
# Training loss: 0.338190
# Validation loss: 0.327637
#
# Epoch 23
# -------------------------------
# Training loss: 0.336733
# Validation loss: 0.320090
#
# Epoch 24
# -------------------------------
# Training loss: 0.330925
# Validation loss: 0.322667
#
# Epoch 25
# -------------------------------
# Training loss: 0.330152
# Validation loss: 0.316837
#
# Epoch 26
# -------------------------------
# Training loss: 0.327401
# Validation loss: 0.312216
#
# Epoch 27
# -------------------------------
# Training loss: 0.326022
# Validation loss: 0.308149
#
# Epoch 28
# -------------------------------
# Training loss: 0.323102
# Validation loss: 0.316928
#
# Epoch 29
# -------------------------------
# Training loss: 0.319065
# Validation loss: 0.309316
#
# Epoch 30
# -------------------------------
# Training loss: 0.314935
# Validation loss: 0.314266
#
# Epoch 31
# -------------------------------
# Training loss: 0.314913
# Validation loss: 0.306848
#
# Epoch 32
# -------------------------------
# Training loss: 0.314361
# Validation loss: 0.302216
#
# Epoch 33
# -------------------------------
# Training loss: 0.311767
# Validation loss: 0.300063
#
# Epoch 34
# -------------------------------
# Training loss: 0.311661
# Validation loss: 0.308392
#
# Epoch 35
# -------------------------------
# Training loss: 0.308988
# Validation loss: 0.297606
#
# Epoch 36
# -------------------------------
# Training loss: 0.308127
# Validation loss: 0.298241
#
# Epoch 37
# -------------------------------
# Training loss: 0.305731
# Validation loss: 0.294139
#
# Epoch 38
# -------------------------------
# Training loss: 0.304206
# Validation loss: 0.293969
#
# Epoch 39
# -------------------------------
# Training loss: 0.301123
# Validation loss: 0.294419
#
# Epoch 40
# -------------------------------
# Training loss: 0.299458
# Validation loss: 0.287772
#
# Epoch 41
# -------------------------------
# Training loss: 0.299580
# Validation loss: 0.290007
#
# Epoch 42
# -------------------------------
# Training loss: 0.298717
# Validation loss: 0.288769
#
# Epoch 43
# -------------------------------
# Training loss: 0.296231
# Validation loss: 0.286535
#
# Epoch 44
# -------------------------------
# Training loss: 0.294553
# Validation loss: 0.283552
#
# Epoch 45
# -------------------------------
# Training loss: 0.292082
# Validation loss: 0.297720
#
# Epoch 46
# -------------------------------
# Training loss: 0.288063
# Validation loss: 0.275374
#
# Epoch 47
# -------------------------------
# Training loss: 0.287504
# Validation loss: 0.283357
#
# Epoch 48
# -------------------------------
# Training loss: 0.285078
# Validation loss: 0.281711
#
# Epoch 49
# -------------------------------
# Training loss: 0.284566
# Validation loss: 0.272477
#
# Epoch 50
# -------------------------------
# Training loss: 0.283931
# Validation loss: 0.278745
#
# Epoch 51
# -------------------------------
# Training loss: 0.278280
# Validation loss: 0.271716
#
# Epoch 52
# -------------------------------
# Training loss: 0.277084
# Validation loss: 0.265821
#
# Epoch 53
# -------------------------------
# Training loss: 0.274211
# Validation loss: 0.276163
#
# Epoch 54
# -------------------------------
# Training loss: 0.270367
# Validation loss: 0.259671
#
# Epoch 55
# -------------------------------
# Training loss: 0.267268
# Validation loss: 0.254922
#
# Epoch 56
# -------------------------------
# Training loss: 0.264807
# Validation loss: 0.245232
#
# Epoch 57
# -------------------------------
# Training loss: 0.260629
# Validation loss: 0.253734
#
# Epoch 58
# -------------------------------
# Training loss: 0.259979
# Validation loss: 0.252891
#
# Epoch 59
# -------------------------------
# Training loss: 0.253014
# Validation loss: 0.271850
#
# Epoch 60
# -------------------------------
# Training loss: 0.251930
# Validation loss: 0.285180
#
# Epoch 61
# -------------------------------
# Training loss: 0.247149
# Validation loss: 0.233852
#
# Epoch 62
# -------------------------------
# Training loss: 0.246408
# Validation loss: 0.242654
#
# Epoch 63
# -------------------------------
# Training loss: 0.243017
# Validation loss: 0.244496
#
# Epoch 64
# -------------------------------
# Training loss: 0.238350
# Validation loss: 0.228012
#
# Epoch 65
# -------------------------------
# Training loss: 0.236714
# Validation loss: 0.240123
#
# Epoch 66
# -------------------------------
# Training loss: 0.234339
# Validation loss: 0.257136
#
# Epoch 67
# -------------------------------
# Training loss: 0.227782
# Validation loss: 0.227491
#
# Epoch 68
# -------------------------------
# Training loss: 0.224040
# Validation loss: 0.213994
#
# Epoch 69
# -------------------------------
# Training loss: 0.222563
# Validation loss: 0.202191
#
# Epoch 70
# -------------------------------
# Training loss: 0.217190
# Validation loss: 0.242601
#
# Epoch 71
# -------------------------------
# Training loss: 0.213505
# Validation loss: 0.199039
#
# Epoch 72
# -------------------------------
# Training loss: 0.212746
# Validation loss: 0.233804
#
# Epoch 73
# -------------------------------
# Training loss: 0.211215
# Validation loss: 0.201502
#
# Epoch 74
# -------------------------------
# Training loss: 0.207793
# Validation loss: 0.208389
#
# Epoch 75
# -------------------------------
# Training loss: 0.207956
# Validation loss: 0.217834
#
# Epoch 76
# -------------------------------
# Training loss: 0.203021
# Validation loss: 0.186231
#
# Epoch 77
# -------------------------------
# Training loss: 0.202145
# Validation loss: 0.230056
#
# Epoch 78
# -------------------------------
# Training loss: 0.201231
# Validation loss: 0.232352
#
# Epoch 79
# -------------------------------
# Training loss: 0.199706
# Validation loss: 0.239023
#
# Epoch 80
# -------------------------------
# Training loss: 0.196379
# Validation loss: 0.181086
#
# Epoch 81
# -------------------------------
# Training loss: 0.194794
# Validation loss: 0.196271
#
# Epoch 82
# -------------------------------
# Training loss: 0.190958
# Validation loss: 0.190622
#
# Epoch 83
# -------------------------------
# Training loss: 0.187526
# Validation loss: 0.189463
#
# Epoch 84
# -------------------------------
# Training loss: 0.191051
# Validation loss: 0.181930
#
# Epoch 85
# -------------------------------
# Training loss: 0.185753
# Validation loss: 0.216678
#
# Epoch 86
# -------------------------------
# Training loss: 0.183264
# Validation loss: 0.188848
#
# Epoch 87
# -------------------------------
# Training loss: 0.181897
# Validation loss: 0.203314
#
# Epoch 88
# -------------------------------
# Training loss: 0.181054
# Validation loss: 0.182734
#
# Epoch 89
# -------------------------------
# Training loss: 0.179759
# Validation loss: 0.169659
#
# Epoch 90
# -------------------------------
# Training loss: 0.177798
# Validation loss: 0.163098
#
# Epoch 91
# -------------------------------
# Training loss: 0.174093
# Validation loss: 0.176983
#
# Epoch 92
# -------------------------------
# Training loss: 0.176928
# Validation loss: 0.175797
#
# Epoch 93
# -------------------------------
# Training loss: 0.172953
# Validation loss: 0.187370
#
# Epoch 94
# -------------------------------
# Training loss: 0.175339
# Validation loss: 0.174988
#
# Epoch 95
# -------------------------------
# Training loss: 0.173469
# Validation loss: 0.150377
#
# Epoch 96
# -------------------------------
# Training loss: 0.169598
# Validation loss: 0.200715
#
# Epoch 97
# -------------------------------
# Training loss: 0.168922
# Validation loss: 0.153141
#
# Epoch 98
# -------------------------------
# Training loss: 0.165293
# Validation loss: 0.151183
#
# Epoch 99
# -------------------------------
# Training loss: 0.160279
# Validation loss: 0.175341
#
# Epoch 100
# -------------------------------
# Training loss: 0.161112
# Validation loss: 0.146557
#
# Epoch 101
# -------------------------------
# Training loss: 0.163689
# Validation loss: 0.204727
#
# Epoch 102
# -------------------------------
# Training loss: 0.158121
# Validation loss: 0.149386
#
# Epoch 103
# -------------------------------
# Training loss: 0.159717
# Validation loss: 0.149640
#
# Epoch 104
# -------------------------------
# Training loss: 0.159560
# Validation loss: 0.174983
#
# Epoch 105
# -------------------------------
# Training loss: 0.159559
# Validation loss: 0.165686
#
# Epoch 106
# -------------------------------
# Training loss: 0.151817
# Validation loss: 0.196959
#
# Epoch 107
# -------------------------------
# Training loss: 0.155128
# Validation loss: 0.153561
#
# Epoch 108
# -------------------------------
# Training loss: 0.156002
# Validation loss: 0.132966
#
# Epoch 109
# -------------------------------
# Training loss: 0.152627
# Validation loss: 0.188620
#
# Epoch 110
# -------------------------------
# Training loss: 0.155453
# Validation loss: 0.160127
#
# Epoch 111
# -------------------------------
# Training loss: 0.151748
# Validation loss: 0.164862
#
# Epoch 112
# -------------------------------
# Training loss: 0.150372
# Validation loss: 0.137296
#
# Epoch 113
# -------------------------------
# Training loss: 0.148897
# Validation loss: 0.153960
#
# Epoch 114
# -------------------------------
# Training loss: 0.148186
# Validation loss: 0.146152
#
# Epoch 115
# -------------------------------
# Training loss: 0.147516
# Validation loss: 0.142688
#
# Epoch 116
# -------------------------------
# Training loss: 0.145516
# Validation loss: 0.160511
#
# Epoch 117
# -------------------------------
# Training loss: 0.146431
# Validation loss: 0.161181
#
# Epoch 118
# -------------------------------
# Training loss: 0.140981
# Validation loss: 0.138313
#
# Epoch 119
# -------------------------------
# Training loss: 0.141209
# Validation loss: 0.127941
#
# Epoch 120
# -------------------------------
# Training loss: 0.139633
# Validation loss: 0.130399
#
# Epoch 121
# -------------------------------
# Training loss: 0.141880
# Validation loss: 0.168644
#
# Epoch 122
# -------------------------------
# Training loss: 0.143927
# Validation loss: 0.179010
#
# Epoch 123
# -------------------------------
# Training loss: 0.141169
# Validation loss: 0.251509
#
# Epoch 124
# -------------------------------
# Training loss: 0.137076
# Validation loss: 0.178499
#
# Epoch 125
# -------------------------------
# Training loss: 0.138190
# Validation loss: 0.122801
#
# Epoch 126
# -------------------------------
# Training loss: 0.134876
# Validation loss: 0.124438
#
# Epoch 127
# -------------------------------
# Training loss: 0.132467
# Validation loss: 0.135428
#
# Epoch 128
# -------------------------------
# Training loss: 0.133735
# Validation loss: 0.113518
#
# Epoch 129
# -------------------------------
# Training loss: 0.133538
# Validation loss: 0.116321
#
# Epoch 130
# -------------------------------
# Training loss: 0.134615
# Validation loss: 0.123863
#
# Epoch 131
# -------------------------------
# Training loss: 0.132379
# Validation loss: 0.138207
#
# Epoch 132
# -------------------------------
# Training loss: 0.132512
# Validation loss: 0.130135
#
# Epoch 133
# -------------------------------
# Training loss: 0.132477
# Validation loss: 0.115633
#
# Epoch 134
# -------------------------------
# Training loss: 0.128537
# Validation loss: 0.152765
#
# Epoch 135
# -------------------------------
# Training loss: 0.127194
# Validation loss: 0.126669
#
# Epoch 136
# -------------------------------
# Training loss: 0.129396
# Validation loss: 0.128468
#
# Epoch 137
# -------------------------------
# Training loss: 0.129380
# Validation loss: 0.115717
#
# Epoch 138
# -------------------------------
# Training loss: 0.125807
# Validation loss: 0.117369
#
# Epoch 139
# -------------------------------
# Training loss: 0.125167
# Validation loss: 0.119696
#
# Epoch 140
# -------------------------------
# Training loss: 0.126789
# Validation loss: 0.124946
#
# Epoch 141
# -------------------------------
# Training loss: 0.126176
# Validation loss: 0.177717
#
# Epoch 142
# -------------------------------
# Training loss: 0.124392
# Validation loss: 0.111907
#
# Epoch 143
# -------------------------------
# Training loss: 0.122746
# Validation loss: 0.118344
#
# Epoch 144
# -------------------------------
# Training loss: 0.125883
# Validation loss: 0.117202
#
# Epoch 145
# -------------------------------
# Training loss: 0.123315
# Validation loss: 0.124152
#
# Epoch 146
# -------------------------------
# Training loss: 0.121874
# Validation loss: 0.108102
#
# Epoch 147
# -------------------------------
# Training loss: 0.119190
# Validation loss: 0.133523
#
# Epoch 148
# -------------------------------
# Training loss: 0.121494
# Validation loss: 0.124872
#
# Epoch 149
# -------------------------------
# Training loss: 0.116028
# Validation loss: 0.110464
#
# Epoch 150
# -------------------------------
# Training loss: 0.121924
# Validation loss: 0.147232
#
# Epoch 151
# -------------------------------
# Training loss: 0.119578
# Validation loss: 0.159575
#
# Epoch 152
# -------------------------------
# Training loss: 0.118103
# Validation loss: 0.111891
#
# Epoch 153
# -------------------------------
# Training loss: 0.118306
# Validation loss: 0.158819
#
# Epoch 154
# -------------------------------
# Training loss: 0.117665
# Validation loss: 0.134994
#
# Epoch 155
# -------------------------------
# Training loss: 0.115476
# Validation loss: 0.117581
#
# Epoch 156
# -------------------------------
# Training loss: 0.113212
# Validation loss: 0.102267
#
# Epoch 157
# -------------------------------
# Training loss: 0.114568
# Validation loss: 0.110965
#
# Epoch 158
# -------------------------------
# Training loss: 0.111711
# Validation loss: 0.121646
#
# Epoch 159
# -------------------------------
# Training loss: 0.111567
# Validation loss: 0.101826
#
# Epoch 160
# -------------------------------
# Training loss: 0.113880
# Validation loss: 0.109456
#
# Epoch 161
# -------------------------------
# Training loss: 0.116611
# Validation loss: 0.100749
#
# Epoch 162
# -------------------------------
# Training loss: 0.116429
# Validation loss: 0.167576
#
# Epoch 163
# -------------------------------
# Training loss: 0.114574
# Validation loss: 0.161532
#
# Epoch 164
# -------------------------------
# Training loss: 0.115126
# Validation loss: 0.122479
#
# Epoch 165
# -------------------------------
# Training loss: 0.111984
# Validation loss: 0.104959
#
# Epoch 166
# -------------------------------
# Training loss: 0.112122
# Validation loss: 0.137788
#
# Epoch 167
# -------------------------------
# Training loss: 0.112110
# Validation loss: 0.136582
#
# Epoch 168
# -------------------------------
# Training loss: 0.109633
# Validation loss: 0.095216
#
# Epoch 169
# -------------------------------
# Training loss: 0.110414
# Validation loss: 0.136521
#
# Epoch 170
# -------------------------------
# Training loss: 0.112294
# Validation loss: 0.143497
#
# Epoch 171
# -------------------------------
# Training loss: 0.108613
# Validation loss: 0.100075
#
# Epoch 172
# -------------------------------
# Training loss: 0.108526
# Validation loss: 0.103668
#
# Epoch 173
# -------------------------------
# Training loss: 0.109006
# Validation loss: 0.104305
#
# Epoch 174
# -------------------------------
# Training loss: 0.106647
# Validation loss: 0.111422
#
# Epoch 175
# -------------------------------
# Training loss: 0.107559
# Validation loss: 0.097940
#
# Epoch 176
# -------------------------------
# Training loss: 0.106138
# Validation loss: 0.090163
#
# Epoch 177
# -------------------------------
# Training loss: 0.105615
# Validation loss: 0.097552
#
# Epoch 178
# -------------------------------
# Training loss: 0.108086
# Validation loss: 0.108617
#
# Epoch 179
# -------------------------------
# Training loss: 0.105193
# Validation loss: 0.098896
#
# Epoch 180
# -------------------------------
# Training loss: 0.102788
# Validation loss: 0.091481
#
# Epoch 181
# -------------------------------
# Training loss: 0.105085
# Validation loss: 0.098826
#
# Epoch 182
# -------------------------------
# Training loss: 0.103910
# Validation loss: 0.100621
#
# Epoch 183
# -------------------------------
# Training loss: 0.104114
# Validation loss: 0.123477
#
# Epoch 184
# -------------------------------
# Training loss: 0.103535
# Validation loss: 0.096396
#
# Epoch 185
# -------------------------------
# Training loss: 0.103356
# Validation loss: 0.100117
#
# Epoch 186
# -------------------------------
# Training loss: 0.103297
# Validation loss: 0.118537
#
# Epoch 187
# -------------------------------
# Training loss: 0.103696
# Validation loss: 0.120937
#
# Epoch 188
# -------------------------------
# Training loss: 0.101380
# Validation loss: 0.110041
#
# Epoch 189
# -------------------------------
# Training loss: 0.103054
# Validation loss: 0.097960
#
# Epoch 190
# -------------------------------
# Training loss: 0.104815
# Validation loss: 0.096096
#
# Epoch 191
# -------------------------------
# Training loss: 0.101520
# Validation loss: 0.091621
#
# Epoch 192
# -------------------------------
# Training loss: 0.104544
# Validation loss: 0.229085
#
# Epoch 193
# -------------------------------
# Training loss: 0.100823
# Validation loss: 0.096769
#
# Epoch 194
# -------------------------------
# Training loss: 0.097128
# Validation loss: 0.089061
#
# Epoch 195
# -------------------------------
# Training loss: 0.100948
# Validation loss: 0.095790
#
# Epoch 196
# -------------------------------
# Training loss: 0.099829
# Validation loss: 0.084940
#
# Epoch 197
# -------------------------------
# Training loss: 0.098689
# Validation loss: 0.099060
#
# Epoch 198
# -------------------------------
# Training loss: 0.097575
# Validation loss: 0.137967
#
# Epoch 199
# -------------------------------
# Training loss: 0.101098
# Validation loss: 0.102726
#
# Epoch 200
# -------------------------------
# Training loss: 0.100266
# Validation loss: 0.082182
#
# Epoch 201
# -------------------------------
# Training loss: 0.098161
# Validation loss: 0.084058
#
# Epoch 202
# -------------------------------
# Training loss: 0.098313
# Validation loss: 0.087592
#
# Epoch 203
# -------------------------------
# Training loss: 0.096385
# Validation loss: 0.098897
#
# Epoch 204
# -------------------------------
# Training loss: 0.096928
# Validation loss: 0.084451
#
# Epoch 205
# -------------------------------
# Training loss: 0.096724
# Validation loss: 0.114125
#
# Epoch 206
# -------------------------------
# Training loss: 0.095925
# Validation loss: 0.085916
#
# Epoch 207
# -------------------------------
# Training loss: 0.095863
# Validation loss: 0.089016
#
# Epoch 208
# -------------------------------
# Training loss: 0.096196
# Validation loss: 0.080102
#
# Epoch 209
# -------------------------------
# Training loss: 0.096172
# Validation loss: 0.084353
#
# Epoch 210
# -------------------------------
# Training loss: 0.097758
# Validation loss: 0.086612
#
# Epoch 211
# -------------------------------
# Training loss: 0.092821
# Validation loss: 0.122145
#
# Epoch 212
# -------------------------------
# Training loss: 0.096149
# Validation loss: 0.084109
#
# Epoch 213
# -------------------------------
# Training loss: 0.096237
# Validation loss: 0.099689
#
# Epoch 214
# -------------------------------
# Training loss: 0.095852
# Validation loss: 0.086131
#
# Epoch 215
# -------------------------------
# Training loss: 0.093405
# Validation loss: 0.083288
#
# Epoch 216
# -------------------------------
# Training loss: 0.094103
# Validation loss: 0.106722
#
# Epoch 217
# -------------------------------
# Training loss: 0.095094
# Validation loss: 0.115896
#
# Epoch 218
# -------------------------------
# Training loss: 0.095011
# Validation loss: 0.096494
#
# Epoch 219
# -------------------------------
# Training loss: 0.094456
# Validation loss: 0.093182
#
# Epoch 220
# -------------------------------
# Training loss: 0.093496
# Validation loss: 0.092369
#
# Epoch 221
# -------------------------------
# Training loss: 0.093920
# Validation loss: 0.097361
#
# Epoch 222
# -------------------------------
# Training loss: 0.101077
# Validation loss: 0.102095
#
# Epoch 223
# -------------------------------
# Training loss: 0.091208
# Validation loss: 0.084528
#
# Epoch 224
# -------------------------------
# Training loss: 0.092902
# Validation loss: 0.100141
#
# Epoch 225
# -------------------------------
# Training loss: 0.093917
# Validation loss: 0.096663
#
# Epoch 226
# -------------------------------
# Training loss: 0.090569
# Validation loss: 0.079802
#
# Epoch 227
# -------------------------------
# Training loss: 0.094541
# Validation loss: 0.090683
#
# Epoch 228
# -------------------------------
# Training loss: 0.094572
# Validation loss: 0.086461
#
# Epoch 229
# -------------------------------
# Training loss: 0.093834
# Validation loss: 0.093448
#
# Epoch 230
# -------------------------------
# Training loss: 0.090855
# Validation loss: 0.088295
#
# Epoch 231
# -------------------------------
# Training loss: 0.093007
# Validation loss: 0.101751
#
# Epoch 232
# -------------------------------
# Training loss: 0.095237
# Validation loss: 0.076435
#
# Epoch 233
# -------------------------------
# Training loss: 0.091769
# Validation loss: 0.111157
#
# Epoch 234
# -------------------------------
# Training loss: 0.089794
# Validation loss: 0.088286
#
# Epoch 235
# -------------------------------
# Training loss: 0.089832
# Validation loss: 0.083468
#
# Epoch 236
# -------------------------------
# Training loss: 0.093414
# Validation loss: 0.101084
#
# Epoch 237
# -------------------------------
# Training loss: 0.090827
# Validation loss: 0.087763
#
# Epoch 238
# -------------------------------
# Training loss: 0.092661
# Validation loss: 0.078913
#
# Epoch 239
# -------------------------------
# Training loss: 0.090468
# Validation loss: 0.076203
#
# Epoch 240
# -------------------------------
# Training loss: 0.088536
# Validation loss: 0.079465
#
# Epoch 241
# -------------------------------
# Training loss: 0.090186
# Validation loss: 0.117046
#
# Epoch 242
# -------------------------------
# Training loss: 0.092340
# Validation loss: 0.078901
#
# Epoch 243
# -------------------------------
# Training loss: 0.088753
# Validation loss: 0.080867
#
# Epoch 244
# -------------------------------
# Training loss: 0.088820
# Validation loss: 0.087672
#
# Epoch 245
# -------------------------------
# Training loss: 0.087797
# Validation loss: 0.086713
#
# Epoch 246
# -------------------------------
# Training loss: 0.089273
# Validation loss: 0.084945
#
# Epoch 247
# -------------------------------
# Training loss: 0.086424
# Validation loss: 0.074853
#
# Epoch 248
# -------------------------------
# Training loss: 0.089799
# Validation loss: 0.081898
#
# Epoch 249
# -------------------------------
# Training loss: 0.087718
# Validation loss: 0.084055
#
# Epoch 250
# -------------------------------
# Training loss: 0.087881
# Validation loss: 0.128460
#
# Epoch 251
# -------------------------------
# Training loss: 0.089309
# Validation loss: 0.115247
#
# Epoch 252
# -------------------------------
# Training loss: 0.087726
# Validation loss: 0.077077
#
# Epoch 253
# -------------------------------
# Training loss: 0.086709
# Validation loss: 0.081476
#
# Epoch 254
# -------------------------------
# Training loss: 0.087320
# Validation loss: 0.079127
#
# Epoch 255
# -------------------------------
# Training loss: 0.088228
# Validation loss: 0.083173
#
# Epoch 256
# -------------------------------
# Training loss: 0.089815
# Validation loss: 0.084103
#
# Epoch 257
# -------------------------------
# Training loss: 0.087937
# Validation loss: 0.085472
#
# Epoch 258
# -------------------------------
# Training loss: 0.086975
# Validation loss: 0.090062
#
# Epoch 259
# -------------------------------
# Training loss: 0.085268
# Validation loss: 0.090181
#
# Epoch 260
# -------------------------------
# Training loss: 0.085817
# Validation loss: 0.074507
#
# Epoch 261
# -------------------------------
# Training loss: 0.089611
# Validation loss: 0.109619
#
# Epoch 262
# -------------------------------
# Training loss: 0.087431
# Validation loss: 0.079624
#
# Epoch 263
# -------------------------------
# Training loss: 0.085390
# Validation loss: 0.117824
#
# Epoch 264
# -------------------------------
# Training loss: 0.085898
# Validation loss: 0.075979
#
# Epoch 265
# -------------------------------
# Training loss: 0.086459
# Validation loss: 0.086680
#
# Epoch 266
# -------------------------------
# Training loss: 0.086528
# Validation loss: 0.079650
#
# Epoch 267
# -------------------------------
# Training loss: 0.087827
# Validation loss: 0.078433
#
# Epoch 268
# -------------------------------
# Training loss: 0.085424
# Validation loss: 0.082725
#
# Epoch 269
# -------------------------------
# Training loss: 0.086365
# Validation loss: 0.092030
#
# Epoch 270
# -------------------------------
# Training loss: 0.087470
# Validation loss: 0.076520
#
# Epoch 271
# -------------------------------
# Training loss: 0.084366
# Validation loss: 0.076553
#
# Epoch 272
# -------------------------------
# Training loss: 0.085490
# Validation loss: 0.084075
#
# Epoch 273
# -------------------------------
# Training loss: 0.086916
# Validation loss: 0.074149
#
# Epoch 274
# -------------------------------
# Training loss: 0.087024
# Validation loss: 0.091537
#
# Epoch 275
# -------------------------------
# Training loss: 0.087688
# Validation loss: 0.080712
#
# Epoch 276
# -------------------------------
# Training loss: 0.085599
# Validation loss: 0.103580
#
# Epoch 277
# -------------------------------
# Training loss: 0.087690
# Validation loss: 0.077719
#
# Epoch 278
# -------------------------------
# Training loss: 0.085420
# Validation loss: 0.079996
#
# Epoch 279
# -------------------------------
# Training loss: 0.084437
# Validation loss: 0.077668
#
# Epoch 280
# -------------------------------
# Training loss: 0.084216
# Validation loss: 0.074465
#
# Epoch 281
# -------------------------------
# Training loss: 0.084275
# Validation loss: 0.074104
#
# Epoch 282
# -------------------------------
# Training loss: 0.083464
# Validation loss: 0.080714
#
# Epoch 283
# -------------------------------
# Training loss: 0.087102
# Validation loss: 0.075456
#
# Epoch 284
# -------------------------------
# Training loss: 0.084130
# Validation loss: 0.101067
#
# Epoch 285
# -------------------------------
# Training loss: 0.084613
# Validation loss: 0.074162
#
# Epoch 286
# -------------------------------
# Training loss: 0.086700
# Validation loss: 0.077554
#
# Epoch 287
# -------------------------------
# Training loss: 0.086566
# Validation loss: 0.077137
#
# Epoch 288
# -------------------------------
# Training loss: 0.084760
# Validation loss: 0.076694
#
# Epoch 289
# -------------------------------
# Training loss: 0.084849
# Validation loss: 0.076663
#
# Epoch 290
# -------------------------------
# Training loss: 0.082766
# Validation loss: 0.074200
#
# Epoch 291
# -------------------------------
# Training loss: 0.083016
# Validation loss: 0.072297
#
# Epoch 292
# -------------------------------
# Training loss: 0.085413
# Validation loss: 0.075589
#
# Epoch 293
# -------------------------------
# Training loss: 0.085152
# Validation loss: 0.076983
#
# Epoch 294
# -------------------------------
# Training loss: 0.086013
# Validation loss: 0.088424
#
# Epoch 295
# -------------------------------
# Training loss: 0.083647
# Validation loss: 0.079032
#
# Epoch 296
# -------------------------------
# Training loss: 0.083367
# Validation loss: 0.076097
#
# Epoch 297
# -------------------------------
# Training loss: 0.084506
# Validation loss: 0.077426
#
# Epoch 298
# -------------------------------
# Training loss: 0.083345
# Validation loss: 0.084841
#
# Epoch 299
# -------------------------------
# Training loss: 0.083463
# Validation loss: 0.071206
#
# Epoch 300
# -------------------------------
# Training loss: 0.082146
# Validation loss: 0.077147
#
# Epoch 301
# -------------------------------
# Training loss: 0.083801
# Validation loss: 0.073284
#
# Epoch 302
# -------------------------------
# Training loss: 0.084722
# Validation loss: 0.075528
#
# Epoch 303
# -------------------------------
# Training loss: 0.083637
# Validation loss: 0.079367
#
# Epoch 304
# -------------------------------
# Training loss: 0.083251
# Validation loss: 0.079400
#
# Epoch 305
# -------------------------------
# Training loss: 0.085512
# Validation loss: 0.078472
#
# Epoch 306
# -------------------------------
# Training loss: 0.085080
# Validation loss: 0.079432
#
# Epoch 307
# -------------------------------
# Training loss: 0.085136
# Validation loss: 0.078699
#
# Epoch 308
# -------------------------------
# Training loss: 0.082479
# Validation loss: 0.081259
#
# Epoch 309
# -------------------------------
# Training loss: 0.081600
# Validation loss: 0.074004
#
# Epoch 310
# -------------------------------
# Training loss: 0.082169
# Validation loss: 0.071927
#
# Epoch 311
# -------------------------------
# Training loss: 0.082945
# Validation loss: 0.074762
#
# Epoch 312
# -------------------------------
# Training loss: 0.083436
# Validation loss: 0.079331
#
# Epoch 313
# -------------------------------
# Training loss: 0.079486
# Validation loss: 0.081098
#
# Epoch 314
# -------------------------------
# Training loss: 0.082028
# Validation loss: 0.070490
#
# Epoch 315
# -------------------------------
# Training loss: 0.081723
# Validation loss: 0.073020
#
# Epoch 316
# -------------------------------
# Training loss: 0.084008
# Validation loss: 0.070382
#
# Epoch 317
# -------------------------------
# Training loss: 0.083079
# Validation loss: 0.083386
#
# Epoch 318
# -------------------------------
# Training loss: 0.082381
# Validation loss: 0.078652
#
# Epoch 319
# -------------------------------
# Training loss: 0.081596
# Validation loss: 0.074565
#
# Epoch 320
# -------------------------------
# Training loss: 0.082645
# Validation loss: 0.079972
#
# Epoch 321
# -------------------------------
# Training loss: 0.082397
# Validation loss: 0.084834
#
# Epoch 322
# -------------------------------
# Training loss: 0.079797
# Validation loss: 0.072254
#
# Epoch 323
# -------------------------------
# Training loss: 0.082982
# Validation loss: 0.084147
#
# Epoch 324
# -------------------------------
# Training loss: 0.081627
# Validation loss: 0.081020
#
# Epoch 325
# -------------------------------
# Training loss: 0.079665
# Validation loss: 0.070270
#
# Epoch 326
# -------------------------------
# Training loss: 0.080765
# Validation loss: 0.080591
#
# Epoch 327
# -------------------------------
# Training loss: 0.081819
# Validation loss: 0.071997
#
# Epoch 328
# -------------------------------
# Training loss: 0.081667
# Validation loss: 0.073204
#
# Epoch 329
# -------------------------------
# Training loss: 0.080066
# Validation loss: 0.094255
#
# Epoch 330
# -------------------------------
# Training loss: 0.081365
# Validation loss: 0.071315
#
# Epoch 331
# -------------------------------
# Training loss: 0.081301
# Validation loss: 0.086302
#
# Epoch 332
# -------------------------------
# Training loss: 0.082091
# Validation loss: 0.070813
#
# Epoch 333
# -------------------------------
# Training loss: 0.080516
# Validation loss: 0.076752
#
# Epoch 334
# -------------------------------
# Training loss: 0.081505
# Validation loss: 0.075141
#
# Epoch 335
# -------------------------------
# Training loss: 0.080448
# Validation loss: 0.075855
#
# Epoch 336
# -------------------------------
# Training loss: 0.080716
# Validation loss: 0.078892
#
# Epoch 337
# -------------------------------
# Training loss: 0.081165
# Validation loss: 0.073821
#
# Epoch 338
# -------------------------------
# Training loss: 0.080862
# Validation loss: 0.071190
#
# Epoch 339
# -------------------------------
# Training loss: 0.082011
# Validation loss: 0.072787
#
# Epoch 340
# -------------------------------
# Training loss: 0.079230
# Validation loss: 0.073393
#
# Epoch 341
# -------------------------------
# Training loss: 0.080804
# Validation loss: 0.076155
#
# Epoch 342
# -------------------------------
# Training loss: 0.081919
# Validation loss: 0.081869
#
# Epoch 343
# -------------------------------
# Training loss: 0.081456
# Validation loss: 0.069656
#
# Epoch 344
# -------------------------------
# Training loss: 0.080249
# Validation loss: 0.084958
#
# Epoch 345
# -------------------------------
# Training loss: 0.080012
# Validation loss: 0.071168
#
# Epoch 346
# -------------------------------
# Training loss: 0.080693
# Validation loss: 0.070828
#
# Epoch 347
# -------------------------------
# Training loss: 0.080323
# Validation loss: 0.080342
#
# Epoch 348
# -------------------------------
# Training loss: 0.080600
# Validation loss: 0.074349
#
# Epoch 349
# -------------------------------
# Training loss: 0.080293
# Validation loss: 0.074588
#
# Epoch 350
# -------------------------------
# Training loss: 0.079126
# Validation loss: 0.071222
#
# Epoch 351
# -------------------------------
# Training loss: 0.079738
# Validation loss: 0.072899
#
# Epoch 352
# -------------------------------
# Training loss: 0.080728
# Validation loss: 0.069601
#
# Epoch 353
# -------------------------------
# Training loss: 0.081428
# Validation loss: 0.070267
#
# Epoch 354
# -------------------------------
# Training loss: 0.080084
# Validation loss: 0.072744
#
# Epoch 355
# -------------------------------
# Training loss: 0.079405
# Validation loss: 0.076121
#
# Epoch 356
# -------------------------------
# Training loss: 0.080352
# Validation loss: 0.075737
#
# Epoch 357
# -------------------------------
# Training loss: 0.081140
# Validation loss: 0.074175
#
# Epoch 358
# -------------------------------
# Training loss: 0.078567
# Validation loss: 0.073071
#
# Epoch 359
# -------------------------------
# Training loss: 0.079286
# Validation loss: 0.071128
#
# Epoch 360
# -------------------------------
# Training loss: 0.082401
# Validation loss: 0.081119
#
# Epoch 361
# -------------------------------
# Training loss: 0.080708
# Validation loss: 0.069795
#
# Epoch 362
# -------------------------------
# Training loss: 0.081368
# Validation loss: 0.070498
#
# Epoch 363
# -------------------------------
# Training loss: 0.078028
# Validation loss: 0.072910
#
# Epoch 364
# -------------------------------
# Training loss: 0.081313
# Validation loss: 0.070980
#
# Epoch 365
# -------------------------------
# Training loss: 0.078001
# Validation loss: 0.072423
#
# Epoch 366
# -------------------------------
# Training loss: 0.077847
# Validation loss: 0.071157
#
# Epoch 367
# -------------------------------
# Training loss: 0.079158
# Validation loss: 0.073370
#
# Epoch 368
# -------------------------------
# Training loss: 0.078095
# Validation loss: 0.076981
#
# Epoch 369
# -------------------------------
# Training loss: 0.078866
# Validation loss: 0.083769
#
# Epoch 370
# -------------------------------
# Training loss: 0.080321
# Validation loss: 0.071003
#
# Epoch 371
# -------------------------------
# Training loss: 0.079423
# Validation loss: 0.077197
#
# Epoch 372
# -------------------------------
# Training loss: 0.078809
# Validation loss: 0.076340
#
# Epoch 373
# -------------------------------
# Training loss: 0.081117
# Validation loss: 0.085919
#
# Epoch 374
# -------------------------------
# Training loss: 0.079324
# Validation loss: 0.073558
#
# Epoch 375
# -------------------------------
# Training loss: 0.079365
# Validation loss: 0.076118
#
# Epoch 376
# -------------------------------
# Training loss: 0.078069
# Validation loss: 0.078651
#
# Epoch 377
# -------------------------------
# Training loss: 0.080405
# Validation loss: 0.070903
#
# Epoch 378
# -------------------------------
# Training loss: 0.078920
# Validation loss: 0.078352
#
# Epoch 379
# -------------------------------
# Training loss: 0.076548
# Validation loss: 0.067165
#
# Epoch 380
# -------------------------------
# Training loss: 0.078441
# Validation loss: 0.073666
#
# Epoch 381
# -------------------------------
# Training loss: 0.079232
# Validation loss: 0.066842
#
# Epoch 382
# -------------------------------
# Training loss: 0.078500
# Validation loss: 0.069402
#
# Epoch 383
# -------------------------------
# Training loss: 0.077506
# Validation loss: 0.071467
#
# Epoch 384
# -------------------------------
# Training loss: 0.077094
# Validation loss: 0.072430
#
# Epoch 385
# -------------------------------
# Training loss: 0.078565
# Validation loss: 0.068197
#
# Epoch 386
# -------------------------------
# Training loss: 0.081224
# Validation loss: 0.069859
#
# Epoch 387
# -------------------------------
# Training loss: 0.078524
# Validation loss: 0.071823
#
# Epoch 388
# -------------------------------
# Training loss: 0.079693
# Validation loss: 0.081231
#
# Epoch 389
# -------------------------------
# Training loss: 0.078549
# Validation loss: 0.068371
#
# Epoch 390
# -------------------------------
# Training loss: 0.078910
# Validation loss: 0.068367
#
# Epoch 391
# -------------------------------
# Training loss: 0.080155
# Validation loss: 0.073802
#
# Epoch 392
# -------------------------------
# Training loss: 0.080339
# Validation loss: 0.078266
#
# Epoch 393
# -------------------------------
# Training loss: 0.078078
# Validation loss: 0.069044
#
# Epoch 394
# -------------------------------
# Training loss: 0.078710
# Validation loss: 0.071756
#
# Epoch 395
# -------------------------------
# Training loss: 0.077985
# Validation loss: 0.069859
#
# Epoch 396
# -------------------------------
# Training loss: 0.079312
# Validation loss: 0.068643
#
# Epoch 397
# -------------------------------
# Training loss: 0.079184
# Validation loss: 0.077073
#
# Epoch 398
# -------------------------------
# Training loss: 0.079691
# Validation loss: 0.073947
#
# Epoch 399
# -------------------------------
# Training loss: 0.078332
# Validation loss: 0.071394
#
# Epoch 400
# -------------------------------
# Training loss: 0.078446
# Validation loss: 0.075093
#
# Epoch 401
# -------------------------------
# Training loss: 0.078706
# Validation loss: 0.071117
#
# Epoch 402
# -------------------------------
# Training loss: 0.077621
# Validation loss: 0.073718
#
# Epoch 403
# -------------------------------
# Training loss: 0.077590
# Validation loss: 0.070883
#
# Epoch 404
# -------------------------------
# Training loss: 0.080245
# Validation loss: 0.070742
#
# Epoch 405
# -------------------------------
# Training loss: 0.076739
# Validation loss: 0.070902
#
# Epoch 406
# -------------------------------
# Training loss: 0.078731
# Validation loss: 0.071086
#
# Epoch 407
# -------------------------------
# Training loss: 0.078656
# Validation loss: 0.073995
#
# Epoch 408
# -------------------------------
# Training loss: 0.076423
# Validation loss: 0.070458
#
# Epoch 409
# -------------------------------
# Training loss: 0.075764
# Validation loss: 0.076970
#
# Epoch 410
# -------------------------------
# Training loss: 0.076980
# Validation loss: 0.070093
#
# Epoch 411
# -------------------------------
# Training loss: 0.077791
# Validation loss: 0.073453
#
# Epoch 412
# -------------------------------
# Training loss: 0.078508
# Validation loss: 0.071685
#
# Epoch 413
# -------------------------------
# Training loss: 0.075563
# Validation loss: 0.073517
#
# Epoch 414
# -------------------------------
# Training loss: 0.078163
# Validation loss: 0.072357
#
# Epoch 415
# -------------------------------
# Training loss: 0.077785
# Validation loss: 0.072760
#
# Epoch 416
# -------------------------------
# Training loss: 0.079329
# Validation loss: 0.074539
#
# Epoch 417
# -------------------------------
# Training loss: 0.077799
# Validation loss: 0.069384
#
# Epoch 418
# -------------------------------
# Training loss: 0.076819
# Validation loss: 0.066680
#
# Epoch 419
# -------------------------------
# Training loss: 0.076830
# Validation loss: 0.069481
#
# Epoch 420
# -------------------------------
# Training loss: 0.078474
# Validation loss: 0.072113
#
# Epoch 421
# -------------------------------
# Training loss: 0.077440
# Validation loss: 0.069290
#
# Epoch 422
# -------------------------------
# Training loss: 0.078484
# Validation loss: 0.069237
#
# Epoch 423
# -------------------------------
# Training loss: 0.078502
# Validation loss: 0.070456
#
# Epoch 424
# -------------------------------
# Training loss: 0.076965
# Validation loss: 0.071623
#
# Epoch 425
# -------------------------------
# Training loss: 0.077978
# Validation loss: 0.072364
#
# Epoch 426
# -------------------------------
# Training loss: 0.077077
# Validation loss: 0.078207
#
# Epoch 427
# -------------------------------
# Training loss: 0.077996
# Validation loss: 0.065860
#
# Epoch 428
# -------------------------------
# Training loss: 0.078166
# Validation loss: 0.071591
#
# Epoch 429
# -------------------------------
# Training loss: 0.075515
# Validation loss: 0.068337
#
# Epoch 430
# -------------------------------
# Training loss: 0.079733
# Validation loss: 0.068882
#
# Epoch 431
# -------------------------------
# Training loss: 0.077221
# Validation loss: 0.070949
#
# Epoch 432
# -------------------------------
# Training loss: 0.078942
# Validation loss: 0.071236
#
# Epoch 433
# -------------------------------
# Training loss: 0.078160
# Validation loss: 0.069244
#
# Epoch 434
# -------------------------------
# Training loss: 0.077095
# Validation loss: 0.070273
#
# Epoch 435
# -------------------------------
# Training loss: 0.076329
# Validation loss: 0.075322
#
# Epoch 436
# -------------------------------
# Training loss: 0.075967
# Validation loss: 0.068065
#
# Epoch 437
# -------------------------------
# Training loss: 0.076247
# Validation loss: 0.069832
#
# Epoch 438
# -------------------------------
# Training loss: 0.077018
# Validation loss: 0.074493
#
# Epoch 439
# -------------------------------
# Training loss: 0.076885
# Validation loss: 0.073505
#
# Epoch 440
# -------------------------------
# Training loss: 0.078556
# Validation loss: 0.070273
#
# Epoch 441
# -------------------------------
# Training loss: 0.076349
# Validation loss: 0.067510
#
# Epoch 442
# -------------------------------
# Training loss: 0.077507
# Validation loss: 0.069628
#
# Epoch 443
# -------------------------------
# Training loss: 0.075330
# Validation loss: 0.067836
#
# Epoch 444
# -------------------------------
# Training loss: 0.077724
# Validation loss: 0.066942
#
# Epoch 445
# -------------------------------
# Training loss: 0.078668
# Validation loss: 0.066879
#
# Epoch 446
# -------------------------------
# Training loss: 0.077871
# Validation loss: 0.067778
#
# Epoch 447
# -------------------------------
# Training loss: 0.076861
# Validation loss: 0.077539
#
# Epoch 448
# -------------------------------
# Training loss: 0.077188
# Validation loss: 0.067244
#
# Epoch 449
# -------------------------------
# Training loss: 0.077729
# Validation loss: 0.083039
#
# Epoch 450
# -------------------------------
# Training loss: 0.077108
# Validation loss: 0.067430
#
# Epoch 451
# -------------------------------
# Training loss: 0.076006
# Validation loss: 0.066852
#
# Epoch 452
# -------------------------------
# Training loss: 0.077907
# Validation loss: 0.074772
#
# Epoch 453
# -------------------------------
# Training loss: 0.078702
# Validation loss: 0.068377
#
# Epoch 454
# -------------------------------
# Training loss: 0.076159
# Validation loss: 0.068782
#
# Epoch 455
# -------------------------------
# Training loss: 0.077160
# Validation loss: 0.071204
#
# Epoch 456
# -------------------------------
# Training loss: 0.075295
# Validation loss: 0.069519
#
# Epoch 457
# -------------------------------
# Training loss: 0.078076
# Validation loss: 0.068902
#
# Epoch 458
# -------------------------------
# Training loss: 0.076837
# Validation loss: 0.073076
#
# Epoch 459
# -------------------------------
# Training loss: 0.077967
# Validation loss: 0.069380
#
# Epoch 460
# -------------------------------
# Training loss: 0.078611
# Validation loss: 0.068593
#
# Epoch 461
# -------------------------------
# Training loss: 0.075226
# Validation loss: 0.066329
#
# Epoch 462
# -------------------------------
# Training loss: 0.076188
# Validation loss: 0.067648
#
# Epoch 463
# -------------------------------
# Training loss: 0.076424
# Validation loss: 0.112145
#
# Epoch 464
# -------------------------------
# Training loss: 0.075079
# Validation loss: 0.074294
#
# Epoch 465
# -------------------------------
# Training loss: 0.077516
# Validation loss: 0.072015
#
# Epoch 466
# -------------------------------
# Training loss: 0.077165
# Validation loss: 0.078046
#
# Epoch 467
# -------------------------------
# Training loss: 0.078585
# Validation loss: 0.066534
#
# Epoch 468
# -------------------------------
# Training loss: 0.076113
# Validation loss: 0.070262
#
# Epoch 469
# -------------------------------
# Training loss: 0.074862
# Validation loss: 0.071223
#
# Epoch 470
# -------------------------------
# Training loss: 0.074965
# Validation loss: 0.075982
#
# Epoch 471
# -------------------------------
# Training loss: 0.080066
# Validation loss: 0.071430
#
# Epoch 472
# -------------------------------
# Training loss: 0.075965
# Validation loss: 0.086161
#
# Epoch 473
# -------------------------------
# Training loss: 0.076414
# Validation loss: 0.084391
#
# Epoch 474
# -------------------------------
# Training loss: 0.076748
# Validation loss: 0.073844
#
# Epoch 475
# -------------------------------
# Training loss: 0.074869
# Validation loss: 0.068195
#
# Epoch 476
# -------------------------------
# Training loss: 0.076054
# Validation loss: 0.069633
#
# Epoch 477
# -------------------------------
# Training loss: 0.074943
# Validation loss: 0.080210
#
# Epoch 478
# -------------------------------
# Training loss: 0.077513
# Validation loss: 0.075273
#
# Epoch 479
# -------------------------------
# Training loss: 0.076459
# Validation loss: 0.070600
#
# Epoch 480
# -------------------------------
# Training loss: 0.075956
# Validation loss: 0.067886
#
# Epoch 481
# -------------------------------
# Training loss: 0.076436
# Validation loss: 0.071765
#
# Epoch 482
# -------------------------------
# Training loss: 0.076342
# Validation loss: 0.075972
#
# Epoch 483
# -------------------------------
# Training loss: 0.077591
# Validation loss: 0.069456
#
# Epoch 484
# -------------------------------
# Training loss: 0.076691
# Validation loss: 0.071134
#
# Epoch 485
# -------------------------------
# Training loss: 0.075964
# Validation loss: 0.068094
#
# Epoch 486
# -------------------------------
# Training loss: 0.077515
# Validation loss: 0.072207
#
# Epoch 487
# -------------------------------
# Training loss: 0.076841
# Validation loss: 0.071480
#
# Epoch 488
# -------------------------------
# Training loss: 0.077745
# Validation loss: 0.069354
#
# Epoch 489
# -------------------------------
# Training loss: 0.075102
# Validation loss: 0.069275
#
# Epoch 490
# -------------------------------
# Training loss: 0.076289
# Validation loss: 0.069473
#
# Epoch 491
# -------------------------------
# Training loss: 0.076221
# Validation loss: 0.086379
#
# Epoch 492
# -------------------------------
# Training loss: 0.075806
# Validation loss: 0.074412
#
# Epoch 493
# -------------------------------
# Training loss: 0.075977
# Validation loss: 0.068275
#
# Epoch 494
# -------------------------------
# Training loss: 0.075324
# Validation loss: 0.070040
#
# Epoch 495
# -------------------------------
# Training loss: 0.076517
# Validation loss: 0.066627
#
# Epoch 496
# -------------------------------
# Training loss: 0.077130
# Validation loss: 0.070757
#
# Epoch 497
# -------------------------------
# Training loss: 0.075288
# Validation loss: 0.077004
#
# Epoch 498
# -------------------------------
# Training loss: 0.076230
# Validation loss: 0.074963
#
# Epoch 499
# -------------------------------
# Training loss: 0.076384
# Validation loss: 0.066012
#
# Epoch 500
# -------------------------------
# Training loss: 0.079660
# Validation loss: 0.075121
#
# Done!

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses)+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('BCE Loss')
#plt.yscale('log')
plt.legend()

# %%
# Now test the pretrained model
test_pred = mytools.test_clas(test_loader, final_classifier, device)
test_pred=torch.sigmoid(torch.tensor(test_pred)).numpy()


fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test, test_pred, pos_label=1)
auc_test = sklearn.metrics.auc(fpr, tpr)
print(f'Test AUROC: {auc_test:0.4f}')

plt.plot(fpr, tpr, label=f'Test AUROC: {auc_test:0.4f}')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
# Out:
# Test AUROC: 0.9936

# %%
# Store the pretrained classifier labels
df_test["Class_pre"] = test_pred

# %% [markdown]
# # Setup the adversary model

# %% [markdown]
# ## Define model architecture

# %%
class Adversary(nn.Module):
    def __init__(self, input_dim=1, hidden1=64, hidden2=128, hidden3=64, n_classes=Num_classes):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, hidden1,bias=False),
            nn.BatchNorm1d(hidden1),
            nn.ReLU(),
            nn.Linear(hidden1, hidden2,bias=False),
            nn.BatchNorm1d(hidden2),
            nn.ReLU(),
            nn.Linear(hidden2, hidden3,bias=False),
            nn.BatchNorm1d(hidden3),
            nn.ReLU(),
            nn.Linear(hidden3, n_classes)   # outputs raw logits for CrossEntropyLoss
            )
        
    def forward(self, x):
        # make the shape (N,1) in a way that is robust for squeezed / unsqueezed classifier outputs
        x = x.view(x.size(0), -1)
        return self.net(x)  # returns shape (N, n_classes)

# %% [markdown]
# ## Initialize model, objective function, and optimizer

# %%
adv = Adversary().to(device)
criterion_adv = nn.CrossEntropyLoss(reduction='none')  # returns loss per sample so we can weight it
opt_adv = torch.optim.Adam(adv.parameters(), lr=1e-5)
scheduler_adv = torch.optim.lr_scheduler.ExponentialLR(opt_adv, gamma=0.999)

# %% [markdown]
# ## Setup dataloaders

# %%
# Convert to tensor dataset and dataloader

# the structure is: feature, adversary label, weight
# The wight is 1 for tritrig and wab, and 0 for phiKK, to prevent the adversary from learning on phiKK events

train_adv_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_train), (torch.from_numpy(y_train.to_numpy().astype(np.float32))==0).float())
train_adv_loader = DataLoader(train_adv_dataset, batch_size=bsize, shuffle=True)

val_adv_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_val), (torch.from_numpy(y_val.to_numpy().astype(np.float32))==0).float() )
val_adv_loader = DataLoader(val_adv_dataset, batch_size=bsize, shuffle=True)

# %% [markdown]
# ## Pre-train the adversary leaving classifier weights fixed

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 6

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 100
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train_adv(train_adv_loader, final_classifier, adv, criterion_adv, opt_adv, scheduler_adv, device))
    Validation_losses = np.append(Validation_losses, mytools.validate_adv(val_adv_loader, final_classifier, adv, criterion_adv, device))
    
    # Keep a running copy of the model with the lowest loss
    if Validation_losses[-1] == np.min(Validation_losses):
        final_adv = copy.deepcopy(adv)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Training loss: 1.576536
# Validation loss: 1.549764
#
# Epoch 2
# -------------------------------
# Training loss: 1.530146
# Validation loss: 1.522146
#
# Epoch 3
# -------------------------------
# Training loss: 1.510982
# Validation loss: 1.508793
#
# Epoch 4
# -------------------------------
# Training loss: 1.498655
# Validation loss: 1.500444
#
# Epoch 5
# -------------------------------
# Training loss: 1.491440
# Validation loss: 1.493397
#
# Epoch 6
# -------------------------------
# Training loss: 1.486387
# Validation loss: 1.489834
#
# Epoch 7
# -------------------------------
# Training loss: 1.482980
# Validation loss: 1.486218
#
# Epoch 8
# -------------------------------
# Training loss: 1.479156
# Validation loss: 1.483808
#
# Epoch 9
# -------------------------------
# Training loss: 1.476795
# Validation loss: 1.482470
#
# Epoch 10
# -------------------------------
# Training loss: 1.476204
# Validation loss: 1.480522
#
# Epoch 11
# -------------------------------
# Training loss: 1.473947
# Validation loss: 1.478760
#
# Epoch 12
# -------------------------------
# Training loss: 1.473621
# Validation loss: 1.478314
#
# Epoch 13
# -------------------------------
# Training loss: 1.472635
# Validation loss: 1.477450
#
# Epoch 14
# -------------------------------
# Training loss: 1.471855
# Validation loss: 1.476449
#
# Epoch 15
# -------------------------------
# Training loss: 1.470138
# Validation loss: 1.476276
#
# Epoch 16
# -------------------------------
# Training loss: 1.470922
# Validation loss: 1.476725
#
# Epoch 17
# -------------------------------
# Training loss: 1.469257
# Validation loss: 1.475948
#
# Epoch 18
# -------------------------------
# Training loss: 1.468943
# Validation loss: 1.474208
#
# Epoch 19
# -------------------------------
# Training loss: 1.469491
# Validation loss: 1.474418
#
# Epoch 20
# -------------------------------
# Training loss: 1.469127
# Validation loss: 1.473690
#
# Epoch 21
# -------------------------------
# Training loss: 1.468580
# Validation loss: 1.474012
#
# Epoch 22
# -------------------------------
# Training loss: 1.467403
# Validation loss: 1.473328
#
# Epoch 23
# -------------------------------
# Training loss: 1.467633
# Validation loss: 1.473839
#
# Epoch 24
# -------------------------------
# Training loss: 1.466915
# Validation loss: 1.473452
#
# Epoch 25
# -------------------------------
# Training loss: 1.467468
# Validation loss: 1.473648
#
# Epoch 26
# -------------------------------
# Training loss: 1.467329
# Validation loss: 1.473274
#
# Epoch 27
# -------------------------------
# Training loss: 1.466394
# Validation loss: 1.473137
#
# Epoch 28
# -------------------------------
# Training loss: 1.467561
# Validation loss: 1.472992
#
# Epoch 29
# -------------------------------
# Training loss: 1.466062
# Validation loss: 1.472918
#
# Epoch 30
# -------------------------------
# Training loss: 1.466938
# Validation loss: 1.474591
#
# Epoch 31
# -------------------------------
# Training loss: 1.466863
# Validation loss: 1.472955
#
# Epoch 32
# -------------------------------
# Training loss: 1.467650
# Validation loss: 1.472839
#
# Epoch 33
# -------------------------------
# Training loss: 1.467130
# Validation loss: 1.472977
#
# Epoch 34
# -------------------------------
# Training loss: 1.467344
# Validation loss: 1.472480
#
# Epoch 35
# -------------------------------
# Training loss: 1.466370
# Validation loss: 1.472171
#
# Epoch 36
# -------------------------------
# Training loss: 1.466678
# Validation loss: 1.473033
#
# Epoch 37
# -------------------------------
# Training loss: 1.467086
# Validation loss: 1.472189
#
# Epoch 38
# -------------------------------
# Training loss: 1.467990
# Validation loss: 1.473607
#
# Epoch 39
# -------------------------------
# Training loss: 1.467096
# Validation loss: 1.472323
#
# Epoch 40
# -------------------------------
# Training loss: 1.466350
# Validation loss: 1.472410
#
# Epoch 41
# -------------------------------
# Training loss: 1.466004
# Validation loss: 1.472771
#
# Epoch 42
# -------------------------------
# Training loss: 1.466740
# Validation loss: 1.472314
#
# Epoch 43
# -------------------------------
# Training loss: 1.466584
# Validation loss: 1.471696
#
# Epoch 44
# -------------------------------
# Training loss: 1.465822
# Validation loss: 1.472569
#
# Epoch 45
# -------------------------------
# Training loss: 1.467044
# Validation loss: 1.472800
#
# Epoch 46
# -------------------------------
# Training loss: 1.467602
# Validation loss: 1.473069
#
# Epoch 47
# -------------------------------
# Training loss: 1.467668
# Validation loss: 1.473364
#
# Epoch 48
# -------------------------------
# Training loss: 1.466809
# Validation loss: 1.472646
#
# Epoch 49
# -------------------------------
# Training loss: 1.466623
# Validation loss: 1.473220
#
# Epoch 50
# -------------------------------
# Training loss: 1.466490
# Validation loss: 1.472113
#
# Epoch 51
# -------------------------------
# Training loss: 1.466660
# Validation loss: 1.472881
#
# Epoch 52
# -------------------------------
# Training loss: 1.466117
# Validation loss: 1.472925
#
# Epoch 53
# -------------------------------
# Training loss: 1.467155
# Validation loss: 1.472558
#
# Epoch 54
# -------------------------------
# Training loss: 1.466930
# Validation loss: 1.472974
#
# Epoch 55
# -------------------------------
# Training loss: 1.466149
# Validation loss: 1.471770
#
# Epoch 56
# -------------------------------
# Training loss: 1.466297
# Validation loss: 1.472737
#
# Epoch 57
# -------------------------------
# Training loss: 1.465990
# Validation loss: 1.472359
#
# Epoch 58
# -------------------------------
# Training loss: 1.466612
# Validation loss: 1.472370
#
# Epoch 59
# -------------------------------
# Training loss: 1.466866
# Validation loss: 1.472108
#
# Epoch 60
# -------------------------------
# Training loss: 1.465834
# Validation loss: 1.472015
#
# Epoch 61
# -------------------------------
# Training loss: 1.466087
# Validation loss: 1.472621
#
# Epoch 62
# -------------------------------
# Training loss: 1.466758
# Validation loss: 1.473728
#
# Epoch 63
# -------------------------------
# Training loss: 1.465327
# Validation loss: 1.472061
#
# Epoch 64
# -------------------------------
# Training loss: 1.465932
# Validation loss: 1.472436
#
# Epoch 65
# -------------------------------
# Training loss: 1.466548
# Validation loss: 1.473183
#
# Epoch 66
# -------------------------------
# Training loss: 1.466541
# Validation loss: 1.472982
#
# Epoch 67
# -------------------------------
# Training loss: 1.467581
# Validation loss: 1.471543
#
# Epoch 68
# -------------------------------
# Training loss: 1.467049
# Validation loss: 1.472687
#
# Epoch 69
# -------------------------------
# Training loss: 1.467225
# Validation loss: 1.472733
#
# Epoch 70
# -------------------------------
# Training loss: 1.465913
# Validation loss: 1.471995
#
# Epoch 71
# -------------------------------
# Training loss: 1.466228
# Validation loss: 1.471939
#
# Epoch 72
# -------------------------------
# Training loss: 1.466711
# Validation loss: 1.472101
#
# Epoch 73
# -------------------------------
# Training loss: 1.465856
# Validation loss: 1.472206
#
# Epoch 74
# -------------------------------
# Training loss: 1.467231
# Validation loss: 1.472312
#
# Epoch 75
# -------------------------------
# Training loss: 1.465666
# Validation loss: 1.472722
#
# Epoch 76
# -------------------------------
# Training loss: 1.466913
# Validation loss: 1.472583
#
# Epoch 77
# -------------------------------
# Training loss: 1.467034
# Validation loss: 1.473283
#
# Epoch 78
# -------------------------------
# Training loss: 1.464946
# Validation loss: 1.472840
#
# Epoch 79
# -------------------------------
# Training loss: 1.465480
# Validation loss: 1.472833
#
# Epoch 80
# -------------------------------
# Training loss: 1.466269
# Validation loss: 1.472784
#
# Epoch 81
# -------------------------------
# Training loss: 1.466665
# Validation loss: 1.472778
#
# Epoch 82
# -------------------------------
# Training loss: 1.466315
# Validation loss: 1.473082
#
# Epoch 83
# -------------------------------
# Training loss: 1.467124
# Validation loss: 1.473093
#
# Epoch 84
# -------------------------------
# Training loss: 1.467168
# Validation loss: 1.472598
#
# Epoch 85
# -------------------------------
# Training loss: 1.466562
# Validation loss: 1.473057
#
# Epoch 86
# -------------------------------
# Training loss: 1.465906
# Validation loss: 1.472147
#
# Epoch 87
# -------------------------------
# Training loss: 1.466194
# Validation loss: 1.472667
#
# Epoch 88
# -------------------------------
# Training loss: 1.466716
# Validation loss: 1.472608
#
# Epoch 89
# -------------------------------
# Training loss: 1.466051
# Validation loss: 1.473470
#
# Epoch 90
# -------------------------------
# Training loss: 1.467232
# Validation loss: 1.473176
#
# Epoch 91
# -------------------------------
# Training loss: 1.466415
# Validation loss: 1.472674
#
# Epoch 92
# -------------------------------
# Training loss: 1.466130
# Validation loss: 1.472523
#
# Epoch 93
# -------------------------------
# Training loss: 1.465326
# Validation loss: 1.472583
#
# Epoch 94
# -------------------------------
# Training loss: 1.466301
# Validation loss: 1.472499
#
# Epoch 95
# -------------------------------
# Training loss: 1.466336
# Validation loss: 1.472877
#
# Epoch 96
# -------------------------------
# Training loss: 1.466208
# Validation loss: 1.472306
#
# Epoch 97
# -------------------------------
# Training loss: 1.466598
# Validation loss: 1.473139
#
# Epoch 98
# -------------------------------
# Training loss: 1.466813
# Validation loss: 1.471689
#
# Epoch 99
# -------------------------------
# Training loss: 1.466461
# Validation loss: 1.472395
#
# Epoch 100
# -------------------------------
# Training loss: 1.465601
# Validation loss: 1.472580
#
# Done!

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses)+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('BCE Loss')
plt.legend()

# %% [markdown]
# # Train full adverserial neural network

# %% [markdown]
# # Setup dataloaders

# %%
# the structure is: feature, classifier label, adversary label, weight
# The wight is 1 for tritrig and wab, and 0 for phiKK, to prevent the adversary from learning on phiKK events

train_full_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy().astype(np.float32))  , torch.from_numpy(y_train.to_numpy().astype(np.float32)).unsqueeze(1), torch.from_numpy(y_adv_train),  (torch.from_numpy(y_train.to_numpy().astype(np.float32))==0).float())
train_full_loader = DataLoader(train_full_dataset, batch_size=bsize, shuffle=True)

val_full_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy().astype(np.float32))  , torch.from_numpy(y_val.to_numpy().astype(np.float32)).unsqueeze(1),  torch.from_numpy(y_adv_val),  (torch.from_numpy(y_val.to_numpy().astype(np.float32))==0).float())
val_full_loader = DataLoader(val_full_dataset, batch_size=bsize, shuffle=True)

# %% [markdown]
# ## Define loss functions

# %%
BCE_loss = nn.BCEWithLogitsLoss()
CE_loss = nn.CrossEntropyLoss(reduction='none') # returns loss per sample so we can weight it

def full_loss(output_clas, output_adv, target_clas, target_adv, w, lambda_):

    loss1 = BCE_loss(output_clas, target_clas )  # classification loss
    sample_losses2 = CE_loss(output_adv, target_adv)  # adversarial losses, since we set reduction='none', this is now a vector of losses, one per sample in the batch

     # Weighted mean loss over non-zero weights
    nonzero = w > 0
    loss2 = (sample_losses2[nonzero] * w[nonzero]).sum() / w[nonzero].sum()

    loss = loss1 - lambda_*loss2

    return loss

# %% [markdown]
# ## Setup optimizers

# %%
optimizer_clas = optim.Adam(final_classifier.parameters(), lr=1e-7,betas=(0.5, 0.999))
optimizer_adv = optim.Adam(final_adv.parameters(), lr=1e-5,betas=(0.5, 0.999))

scheduler_clas = torch.optim.lr_scheduler.ExponentialLR(optimizer_clas, gamma=0.999)
scheduler_adv = torch.optim.lr_scheduler.ExponentialLR(optimizer_adv, gamma=0.999)

# %% [markdown]
# ## Adversarial training

# %%
Training_losses_clas = np.array([])
Training_losses_adv = np.array([])
Validation_losses_clas = np.array([])
Validation_losses_adv = np.array([])
diff_scores = np.array([])


epochs = 50
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")

    # Get validation losses
    E_clas_val_loss, E_adv_val_loss = mytools.validate_full(val_full_loader, final_classifier, final_adv, full_loss, lambda_, criterion_adv, device)
    Validation_losses_clas = np.append(Validation_losses_clas, E_clas_val_loss)
    Validation_losses_adv = np.append(Validation_losses_adv, E_adv_val_loss)

    # Train adversary and classifier
    E_clas_training_loss , E_adv_training_loss = mytools.train_full(train_full_loader, final_classifier, final_adv, full_loss, lambda_, criterion_adv, optimizer_clas, optimizer_adv, scheduler_clas, scheduler_adv, device)
    Training_losses_clas = np.append(Training_losses_clas, E_clas_training_loss)
    Training_losses_adv = np.append(Training_losses_adv, E_adv_training_loss)

    # Get the diff_score
    df_test["Class_adv"] = mytools.test_clas(test_loader, final_classifier, device)
    df_bkg = df_test.loc[ (df_test.type == 'tritrig') | (df_test.type == 'wab')]
    per = np.percentile(df_bkg['Class_adv'],99)
    df_cut = df_bkg[df_bkg['Class_adv']>per].reset_index(drop=True)
    x1 = 1000* df_bkg.InvM.values
    x2 = 1000*df_cut.InvM.values
    diff_scores = np.append(diff_scores, mytools.get_diff_score(x1,x2) )

    # Keep a running copy of the model with the lowest loss
    if diff_scores[-1] == np.min(diff_scores):
        final_clas_adv = copy.deepcopy(final_classifier)
        final_adv_adv = copy.deepcopy(final_adv)

            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Classifier validation loss: -147.088498
# Adversary validation loss: 1.471543
# Classifier training loss: -151.324896
# Adversary training loss: 1.514727
# Epoch 2
# -------------------------------
# Classifier validation loss: -153.422551
# Adversary validation loss: 1.535145
# Classifier training loss: -151.587330
# Adversary training loss: 1.517247
# Epoch 3
# -------------------------------
# Classifier validation loss: -151.192309
# Adversary validation loss: 1.513062
# Classifier training loss: -150.890267
# Adversary training loss: 1.510353
# Epoch 4
# -------------------------------
# Classifier validation loss: -150.939109
# Adversary validation loss: 1.510816
# Classifier training loss: -150.483411
# Adversary training loss: 1.506501
# Epoch 5
# -------------------------------
# Classifier validation loss: -150.512797
# Adversary validation loss: 1.506639
# Classifier training loss: -150.106116
# Adversary training loss: 1.502835
# Epoch 6
# -------------------------------
# Classifier validation loss: -149.538095
# Adversary validation loss: 1.497092
# Classifier training loss: -150.162302
# Adversary training loss: 1.503537
# Epoch 7
# -------------------------------
# Classifier validation loss: -149.278565
# Adversary validation loss: 1.494758
# Classifier training loss: -149.802531
# Adversary training loss: 1.499922
# Epoch 8
# -------------------------------
# Classifier validation loss: -149.814578
# Adversary validation loss: 1.500244
# Classifier training loss: -149.553972
# Adversary training loss: 1.497385
# Epoch 9
# -------------------------------
# Classifier validation loss: -149.640799
# Adversary validation loss: 1.498052
# Classifier training loss: -149.662338
# Adversary training loss: 1.498517
# Epoch 10
# -------------------------------
# Classifier validation loss: -149.873462
# Adversary validation loss: 1.500787
# Classifier training loss: -149.456368
# Adversary training loss: 1.496432
# Epoch 11
# -------------------------------
# Classifier validation loss: -149.152940
# Adversary validation loss: 1.493222
# Classifier training loss: -149.419203
# Adversary training loss: 1.496071
# Epoch 12
# -------------------------------
# Classifier validation loss: -149.157148
# Adversary validation loss: 1.493605
# Classifier training loss: -149.333680
# Adversary training loss: 1.495217
# Epoch 13
# -------------------------------
# Classifier validation loss: -149.175454
# Adversary validation loss: 1.493525
# Classifier training loss: -149.189401
# Adversary training loss: 1.493743
# Epoch 14
# -------------------------------
# Classifier validation loss: -149.086434
# Adversary validation loss: 1.492682
# Classifier training loss: -149.262233
# Adversary training loss: 1.494444
# Epoch 15
# -------------------------------
# Classifier validation loss: -149.113902
# Adversary validation loss: 1.492898
# Classifier training loss: -149.119341
# Adversary training loss: 1.493005
# Epoch 16
# -------------------------------
# Classifier validation loss: -148.944717
# Adversary validation loss: 1.491168
# Classifier training loss: -149.122737
# Adversary training loss: 1.493061
# Epoch 17
# -------------------------------
# Classifier validation loss: -149.581146
# Adversary validation loss: 1.498070
# Classifier training loss: -149.032353
# Adversary training loss: 1.492147
# Epoch 18
# -------------------------------
# Classifier validation loss: -149.181944
# Adversary validation loss: 1.493674
# Classifier training loss: -149.137023
# Adversary training loss: 1.493192
# Epoch 19
# -------------------------------
# Classifier validation loss: -149.188011
# Adversary validation loss: 1.493797
# Classifier training loss: -149.110217
# Adversary training loss: 1.492937
# Epoch 20
# -------------------------------
# Classifier validation loss: -148.853216
# Adversary validation loss: 1.490223
# Classifier training loss: -149.206878
# Adversary training loss: 1.493915
# Epoch 21
# -------------------------------
# Classifier validation loss: -149.109682
# Adversary validation loss: 1.493074
# Classifier training loss: -149.086258
# Adversary training loss: 1.492697
# Epoch 22
# -------------------------------
# Classifier validation loss: -148.736410
# Adversary validation loss: 1.489208
# Classifier training loss: -149.015235
# Adversary training loss: 1.491979
# Epoch 23
# -------------------------------
# Classifier validation loss: -149.312342
# Adversary validation loss: 1.494796
# Classifier training loss: -149.012377
# Adversary training loss: 1.491962
# Epoch 24
# -------------------------------
# Classifier validation loss: -149.055510
# Adversary validation loss: 1.492367
# Classifier training loss: -149.031465
# Adversary training loss: 1.492169
# Epoch 25
# -------------------------------
# Classifier validation loss: -148.773874
# Adversary validation loss: 1.489534
# Classifier training loss: -148.985067
# Adversary training loss: 1.491669
# Epoch 26
# -------------------------------
# Classifier validation loss: -148.609164
# Adversary validation loss: 1.487969
# Classifier training loss: -149.098843
# Adversary training loss: 1.492820
# Epoch 27
# -------------------------------
# Classifier validation loss: -149.251796
# Adversary validation loss: 1.494340
# Classifier training loss: -149.089065
# Adversary training loss: 1.492697
# Epoch 28
# -------------------------------
# Classifier validation loss: -148.826737
# Adversary validation loss: 1.490118
# Classifier training loss: -149.008330
# Adversary training loss: 1.491895
# Epoch 29
# -------------------------------
# Classifier validation loss: -149.131698
# Adversary validation loss: 1.493172
# Classifier training loss: -149.040627
# Adversary training loss: 1.492224
# Epoch 30
# -------------------------------
# Classifier validation loss: -149.281306
# Adversary validation loss: 1.494578
# Classifier training loss: -149.033656
# Adversary training loss: 1.492151
# Epoch 31
# -------------------------------
# Classifier validation loss: -148.830505
# Adversary validation loss: 1.490006
# Classifier training loss: -149.055210
# Adversary training loss: 1.492421
# Epoch 32
# -------------------------------
# Classifier validation loss: -148.994867
# Adversary validation loss: 1.491724
# Classifier training loss: -149.154736
# Adversary training loss: 1.493381
# Epoch 33
# -------------------------------
# Classifier validation loss: -148.644083
# Adversary validation loss: 1.488361
# Classifier training loss: -149.042187
# Adversary training loss: 1.492217
# Epoch 34
# -------------------------------
# Classifier validation loss: -148.558485
# Adversary validation loss: 1.487297
# Classifier training loss: -149.153481
# Adversary training loss: 1.493360
# Epoch 35
# -------------------------------
# Classifier validation loss: -149.051120
# Adversary validation loss: 1.492195
# Classifier training loss: -148.979086
# Adversary training loss: 1.491618
# Epoch 36
# -------------------------------
# Classifier validation loss: -148.896825
# Adversary validation loss: 1.490657
# Classifier training loss: -149.091770
# Adversary training loss: 1.492753
# Epoch 37
# -------------------------------
# Classifier validation loss: -148.925904
# Adversary validation loss: 1.491106
# Classifier training loss: -148.996824
# Adversary training loss: 1.491794
# Epoch 38
# -------------------------------
# Classifier validation loss: -148.947193
# Adversary validation loss: 1.491352
# Classifier training loss: -149.021882
# Adversary training loss: 1.492025
# Epoch 39
# -------------------------------
# Classifier validation loss: -149.374613
# Adversary validation loss: 1.495970
# Classifier training loss: -149.028802
# Adversary training loss: 1.492074
# Epoch 40
# -------------------------------
# Classifier validation loss: -148.641828
# Adversary validation loss: 1.488225
# Classifier training loss: -149.038322
# Adversary training loss: 1.492194
# Epoch 41
# -------------------------------
# Classifier validation loss: -149.344402
# Adversary validation loss: 1.495329
# Classifier training loss: -148.946600
# Adversary training loss: 1.491293
# Epoch 42
# -------------------------------
# Classifier validation loss: -148.974837
# Adversary validation loss: 1.491619
# Classifier training loss: -149.021248
# Adversary training loss: 1.492041
# Epoch 43
# -------------------------------
# Classifier validation loss: -148.764128
# Adversary validation loss: 1.489300
# Classifier training loss: -149.060818
# Adversary training loss: 1.492440
# Epoch 44
# -------------------------------
# Classifier validation loss: -148.956013
# Adversary validation loss: 1.491308
# Classifier training loss: -149.001872
# Adversary training loss: 1.491833
# Epoch 45
# -------------------------------
# Classifier validation loss: -148.890536
# Adversary validation loss: 1.490733
# Classifier training loss: -149.063444
# Adversary training loss: 1.492458
# Epoch 46
# -------------------------------
# Classifier validation loss: -148.883370
# Adversary validation loss: 1.490634
# Classifier training loss: -148.936445
# Adversary training loss: 1.491168
# Epoch 47
# -------------------------------
# Classifier validation loss: -148.863012
# Adversary validation loss: 1.490660
# Classifier training loss: -149.057176
# Adversary training loss: 1.492412
# Epoch 48
# -------------------------------
# Classifier validation loss: -149.071496
# Adversary validation loss: 1.492490
# Classifier training loss: -149.019909
# Adversary training loss: 1.492031
# Epoch 49
# -------------------------------
# Classifier validation loss: -148.937674
# Adversary validation loss: 1.491475
# Classifier training loss: -148.961676
# Adversary training loss: 1.491424
# Epoch 50
# -------------------------------
# Classifier validation loss: -149.030425
# Adversary validation loss: 1.492105
# Classifier training loss: -148.935303
# Adversary training loss: 1.491155
# Done!

# %%
fig, ax1 = plt.subplots()

best_epoch = np.argmin(diff_scores)+1



#ax1.plot(np.arange(len(Training_losses_adv))+1, Training_losses_adv, 'k-', label='Training Adversary')
ax1.plot(np.arange(len(Validation_losses_adv))+1, Validation_losses_adv, 'k-', label='Validation Adversary')

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Adversary Loss', color='k')
ax1.tick_params(axis='y', labelcolor='k')

ax2 = ax1.twinx()

#ax2.plot(np.arange(len(Training_losses_clas))+1, Training_losses_clas, 'r-', label='Training Classifier')
ax2.plot(np.arange(len(Validation_losses_clas))+1, Validation_losses_clas, 'r-', label='Validation Classifier')
ax2.axvline(best_epoch,label="Final model stopped here",color='k')

ax2.set_ylabel('Classifier Loss', color='r')
ax2.tick_params(axis='y', labelcolor='r')

# %% [markdown]
# ## Test adversarially trained models

# %%
# Now test the pretrained model
test_pred = mytools.test_clas(test_loader, final_clas_adv, device)
test_pred=torch.sigmoid(torch.tensor(test_pred)).numpy()


fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test, test_pred, pos_label=1)
auc_test = sklearn.metrics.auc(fpr, tpr)
print(f'Test AUROC: {auc_test:0.4f}')

plt.plot(fpr, tpr, label=f'Test AUROC: {auc_test:0.4f}')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
# Out:
# Test AUROC: 0.9866

# %%
df_test["Class_adv"] = test_pred
df_bkg = df_test.loc[ (df_test.type == 'tritrig') | (df_test.type == 'wab')]
per = np.percentile(df_bkg['Class_adv'],99)
df_cut = df_bkg[df_bkg['Class_adv']>per].reset_index(drop=True)
x_vals = 1000*df_cut.InvM

plt.figure()
plt.hist(1000*df_bkg.InvM, bins=np.arange(980,1250,1), histtype='step', label='No selection', density=True)
plt.hist(x_vals, bins=np.arange(980,1250,1), histtype='step', label= '99 percent selection', density=True)
plt.axvline(1019.461, color='k', linestyle='dashed', linewidth=1, label='PDG phi mass')
plt.xlabel('Invariant Mass [MeV]')
plt.ylabel('Normalized Counts')
plt.legend()

# %%
x1 = 1000* df_bkg.InvM.values
x2 = 1000*df_cut.InvM.values

N, edges = np.histogram(x1, bins=np.arange(980,1250,1), density=False)
M, edges = np.histogram(x2, bins=np.arange(980,1250,1), density=False)

N2 = N[(N > 0) & (M > 0)]
M2 = M[(N > 0) & (M > 0)]

diff_score = np.mean(np.abs(N2/np.sum(N)-M2/np.sum(M)) / (np.sqrt(N2)/np.sum(N) + np.sqrt(M2)/np.sum(M) ))

print(diff_score)

N = len(df_test.loc[ ((df_test.type == 'tritrig') | (df_test.type == 'wab')) & (df_test.InvM < (1.019 + 0.01) )  & (df_test.InvM > (1.019 - 0.01) ) & ( df_test['Class_adv']>per ) ] )
S = len(df_test.loc[ (df_test.type == 'phiKK') & (df_test.InvM < (1.019 + 0.01) )  & (df_test.InvM > (1.019 - 0.01) ) & ( df_test['Class_adv']>per )  ] )

print(S/N)
# Out:
# 0.8758488502754757
# 6.68984962406015

# %%
df_test["Class_adv"] = test_pred
df_test.to_pickle("/Users/mghrear/data/ML_data/patch/ANN_results_relu_run"+str(run)+"_limited_sideband_a.pk")

# %%
# Save the adversarially trained models
torch.save(final_clas_adv.state_dict(), "/Users/mghrear/data/ML_data/patch/classifier_adv_relu_run"+str(run)+"_limited_sideband_a.pt")
torch.save(final_adv_adv.state_dict(), "/Users/mghrear/data/ML_data/patch/adversary_adv_relu_run"+str(run)+"_limited_sideband_a.pt")

# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import torch 
from torch import nn, optim
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import sklearn
from sklearn.model_selection import train_test_split
import copy
import mytools
from scipy.stats import ks_2samp, wasserstein_distance


# Print and store device being used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cpu

# %% [markdown]
# # Define important parameters

# %%
# Number of class in invariant mass used by the adversary
Num_classes = 5
# Hyper-parameter for adversarial training of the classifier
lambda_ = 100.0

run = 1

# %% [markdown]
# # Load and setup the data

# %%
df_tritrig = pd.read_pickle('/Users/mghrear/data/ML_data/patch/BDT_2019_tritrig_limited.pk')
df_tritrig['PhiKK'] = 0.0 # Add label
df_tritrig = df_tritrig.sample(frac=1, random_state=42).reset_index(drop=True) # Now shuffle the combined dataframe
df_phiKK = pd.read_pickle('/Users/mghrear/data/ML_data/patch/BDT_2019_phiKK_limited.pk')
df_phiKK['PhiKK'] = 1.0 # Add label
df_wab = pd.read_pickle('/Users/mghrear/data/ML_data/patch/BDT_2019_wab_limited.pk')
df_wab['PhiKK'] = 0.0 # Add label
df_wab = df_wab.sample(frac=1, random_state=42).reset_index(drop=True) # Now shuffle the combined dataframe

df_data_train_bkg = pd.read_pickle('/Users/mghrear/data/ML_data/patch/BDT_2019_data_limited_sideband_train_bkg.pk')
df_data_train_bkg['PhiKK'] = 0.0 # Add label

df_data = pd.read_pickle('/Users/mghrear/data/ML_data/patch/BDT_2019_data_limited_sideband_test.pk')

print("phiKK: ", len(df_phiKK))
print("data bkg: ", len(df_data_train_bkg))
print("data: ", len(df_data))
# Out:
# phiKK:  8164
# data bkg:  23704
# data:  43926

# %%
phiKK_train = df_phiKK[0:4000]


# Combine and shuffle all training data
df_train = pd.concat([phiKK_train, df_data_train_bkg], ignore_index=True, sort=False)
df_train = df_train.sample(frac=1, random_state=42).reset_index(drop=True)

# Get edges in invariant mass classes for one-hot encoding
# To be used for adverserial labels
# The edges are chosen such that each bin has equal number of background events
one_hot_edges = mytools.get_one_hot_edges(mytools.get_InvM( df_data ), n_bins=Num_classes)

# Split the training data into training and validation sets
df_train, df_val = train_test_split(df_train, test_size=0.33, random_state=41)

# Make X and y for training and validation sets
# the adverserial network has its own labels
X_train = df_train.drop(columns=['PhiKK'])
y_train = df_train['PhiKK']
y_adv_train = mytools.get_adv_labels( mytools.get_InvM(df_train), one_hot_edges)
X_val = df_val.drop(columns=['PhiKK'])
y_val = df_val['PhiKK']
y_adv_val = mytools.get_adv_labels( mytools.get_InvM(df_val), one_hot_edges)

# Make testing set with remaining events
tritrig_test = df_tritrig[20000:]
tritrig_test['type']= 'tritrig'
wab_test = df_wab[4000:]
wab_test['type']= 'wab'
phiKK_test = df_phiKK[4000:]
phiKK_test['type']= 'phiKK'

# This is just used for an invariance test
df_test = pd.concat([tritrig_test, phiKK_test,wab_test], ignore_index=True, sort=False)
df_test = df_test.sample(frac=1, random_state=42).reset_index(drop=True) # Now shuffle the combined dataframe

X_test = df_test.drop(columns=['PhiKK','type'])
y_test = df_test['PhiKK']
y_adv_test = mytools.get_adv_labels( mytools.get_InvM(df_test), one_hot_edges)

df_test["InvM"] = mytools.get_InvM(df_test) 



# Make final data set
X_final = df_data
# Out:
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_51606/340893858.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tritrig_test['type']= 'tritrig'
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_51606/340893858.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wab_test['type']= 'wab'
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_51606/340893858.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phiKK_test['type']= 'phiKK'

# %% [markdown]
# # Setup the classifier model

# %% [markdown]
# ## Setup dataloaders

# %%
bsize = 512

# Convert to tensor dataset and dataloader
train_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy().astype(np.float32))  , torch.from_numpy(y_train.to_numpy().astype(np.float32)).unsqueeze(1)  )
train_loader = DataLoader(train_dataset, batch_size=bsize, shuffle=True)

val_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy().astype(np.float32))  , torch.from_numpy(y_val.to_numpy().astype(np.float32)).unsqueeze(1)  )
val_loader = DataLoader(val_dataset, batch_size=bsize, shuffle=True)

test_dataset = TensorDataset(torch.from_numpy(X_test.to_numpy().astype(np.float32))  )
test_loader = DataLoader(test_dataset, batch_size=bsize, shuffle=False)

# %% [markdown]
# ## Initialize model, objective function, and optimizer

# %%
clas = mytools.Classifier(in_features=X_train.shape[1]).to(device)
criterion_clas = nn.BCEWithLogitsLoss()
optimizer_clas = optim.Adam(clas.parameters(), lr=1e-5)
scheduler_clas = torch.optim.lr_scheduler.ExponentialLR(optimizer_clas, gamma=0.99995)

# %% [markdown]
# ## Pre-train the classifier

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 10

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 500
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train_clas(train_loader, clas, criterion_clas, optimizer_clas, scheduler_clas, device))
    Validation_losses = np.append(Validation_losses, mytools.validate_clas(val_loader, clas, criterion_clas, device))
    
    # Keep a running copy of the model with the lowest loss
    if Validation_losses[-1] == np.min(Validation_losses):
        final_classifier = copy.deepcopy(clas)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Training loss: 0.619000
# Validation loss: 0.638691
#
# Epoch 2
# -------------------------------
# Training loss: 0.592417
# Validation loss: 0.579371
#
# Epoch 3
# -------------------------------
# Training loss: 0.574737
# Validation loss: 0.561662
#
# Epoch 4
# -------------------------------
# Training loss: 0.561693
# Validation loss: 0.548579
#
# Epoch 5
# -------------------------------
# Training loss: 0.547525
# Validation loss: 0.530962
#
# Epoch 6
# -------------------------------
# Training loss: 0.539995
# Validation loss: 0.519290
#
# Epoch 7
# -------------------------------
# Training loss: 0.528239
# Validation loss: 0.526318
#
# Epoch 8
# -------------------------------
# Training loss: 0.523418
# Validation loss: 0.511758
#
# Epoch 9
# -------------------------------
# Training loss: 0.516739
# Validation loss: 0.502193
#
# Epoch 10
# -------------------------------
# Training loss: 0.506560
# Validation loss: 0.495380
#
# Epoch 11
# -------------------------------
# Training loss: 0.500102
# Validation loss: 0.488704
#
# Epoch 12
# -------------------------------
# Training loss: 0.494710
# Validation loss: 0.481220
#
# Epoch 13
# -------------------------------
# Training loss: 0.489490
# Validation loss: 0.478323
#
# Epoch 14
# -------------------------------
# Training loss: 0.486836
# Validation loss: 0.478770
#
# Epoch 15
# -------------------------------
# Training loss: 0.480277
# Validation loss: 0.466892
#
# Epoch 16
# -------------------------------
# Training loss: 0.475032
# Validation loss: 0.463164
#
# Epoch 17
# -------------------------------
# Training loss: 0.469394
# Validation loss: 0.462725
#
# Epoch 18
# -------------------------------
# Training loss: 0.468368
# Validation loss: 0.459118
#
# Epoch 19
# -------------------------------
# Training loss: 0.462405
# Validation loss: 0.454048
#
# Epoch 20
# -------------------------------
# Training loss: 0.458553
# Validation loss: 0.453625
#
# Epoch 21
# -------------------------------
# Training loss: 0.456323
# Validation loss: 0.446086
#
# Epoch 22
# -------------------------------
# Training loss: 0.451910
# Validation loss: 0.441775
#
# Epoch 23
# -------------------------------
# Training loss: 0.448740
# Validation loss: 0.439598
#
# Epoch 24
# -------------------------------
# Training loss: 0.445178
# Validation loss: 0.432333
#
# Epoch 25
# -------------------------------
# Training loss: 0.443303
# Validation loss: 0.443132
#
# Epoch 26
# -------------------------------
# Training loss: 0.439649
# Validation loss: 0.428505
#
# Epoch 27
# -------------------------------
# Training loss: 0.436409
# Validation loss: 0.427908
#
# Epoch 28
# -------------------------------
# Training loss: 0.433298
# Validation loss: 0.425023
#
# Epoch 29
# -------------------------------
# Training loss: 0.431407
# Validation loss: 0.423391
#
# Epoch 30
# -------------------------------
# Training loss: 0.429040
# Validation loss: 0.419139
#
# Epoch 31
# -------------------------------
# Training loss: 0.425128
# Validation loss: 0.419693
#
# Epoch 32
# -------------------------------
# Training loss: 0.424350
# Validation loss: 0.414317
#
# Epoch 33
# -------------------------------
# Training loss: 0.420989
# Validation loss: 0.426499
#
# Epoch 34
# -------------------------------
# Training loss: 0.418990
# Validation loss: 0.412937
#
# Epoch 35
# -------------------------------
# Training loss: 0.416950
# Validation loss: 0.402603
#
# Epoch 36
# -------------------------------
# Training loss: 0.414496
# Validation loss: 0.405238
#
# Epoch 37
# -------------------------------
# Training loss: 0.413466
# Validation loss: 0.406160
#
# Epoch 38
# -------------------------------
# Training loss: 0.411041
# Validation loss: 0.401249
#
# Epoch 39
# -------------------------------
# Training loss: 0.408537
# Validation loss: 0.398576
#
# Epoch 40
# -------------------------------
# Training loss: 0.406330
# Validation loss: 0.401760
#
# Epoch 41
# -------------------------------
# Training loss: 0.405274
# Validation loss: 0.398723
#
# Epoch 42
# -------------------------------
# Training loss: 0.403049
# Validation loss: 0.394423
#
# Epoch 43
# -------------------------------
# Training loss: 0.400723
# Validation loss: 0.395272
#
# Epoch 44
# -------------------------------
# Training loss: 0.397493
# Validation loss: 0.385796
#
# Epoch 45
# -------------------------------
# Training loss: 0.396648
# Validation loss: 0.402114
#
# Epoch 46
# -------------------------------
# Training loss: 0.394287
# Validation loss: 0.387520
#
# Epoch 47
# -------------------------------
# Training loss: 0.394853
# Validation loss: 0.386085
#
# Epoch 48
# -------------------------------
# Training loss: 0.391972
# Validation loss: 0.389162
#
# Epoch 49
# -------------------------------
# Training loss: 0.388033
# Validation loss: 0.381094
#
# Epoch 50
# -------------------------------
# Training loss: 0.387993
# Validation loss: 0.384544
#
# Epoch 51
# -------------------------------
# Training loss: 0.386659
# Validation loss: 0.381296
#
# Epoch 52
# -------------------------------
# Training loss: 0.386861
# Validation loss: 0.374931
#
# Epoch 53
# -------------------------------
# Training loss: 0.383638
# Validation loss: 0.372544
#
# Epoch 54
# -------------------------------
# Training loss: 0.382398
# Validation loss: 0.373745
#
# Epoch 55
# -------------------------------
# Training loss: 0.382768
# Validation loss: 0.374539
#
# Epoch 56
# -------------------------------
# Training loss: 0.378235
# Validation loss: 0.377108
#
# Epoch 57
# -------------------------------
# Training loss: 0.377460
# Validation loss: 0.370309
#
# Epoch 58
# -------------------------------
# Training loss: 0.375413
# Validation loss: 0.372240
#
# Epoch 59
# -------------------------------
# Training loss: 0.376131
# Validation loss: 0.362191
#
# Epoch 60
# -------------------------------
# Training loss: 0.374065
# Validation loss: 0.370996
#
# Epoch 61
# -------------------------------
# Training loss: 0.373801
# Validation loss: 0.363837
#
# Epoch 62
# -------------------------------
# Training loss: 0.371954
# Validation loss: 0.368820
#
# Epoch 63
# -------------------------------
# Training loss: 0.368959
# Validation loss: 0.362883
#
# Epoch 64
# -------------------------------
# Training loss: 0.367459
# Validation loss: 0.369416
#
# Epoch 65
# -------------------------------
# Training loss: 0.366893
# Validation loss: 0.357047
#
# Epoch 66
# -------------------------------
# Training loss: 0.365629
# Validation loss: 0.361078
#
# Epoch 67
# -------------------------------
# Training loss: 0.365195
# Validation loss: 0.361988
#
# Epoch 68
# -------------------------------
# Training loss: 0.362531
# Validation loss: 0.362252
#
# Epoch 69
# -------------------------------
# Training loss: 0.362682
# Validation loss: 0.350521
#
# Epoch 70
# -------------------------------
# Training loss: 0.359867
# Validation loss: 0.357769
#
# Epoch 71
# -------------------------------
# Training loss: 0.358444
# Validation loss: 0.354955
#
# Epoch 72
# -------------------------------
# Training loss: 0.358004
# Validation loss: 0.361701
#
# Epoch 73
# -------------------------------
# Training loss: 0.358657
# Validation loss: 0.352649
#
# Epoch 74
# -------------------------------
# Training loss: 0.357351
# Validation loss: 0.351187
#
# Epoch 75
# -------------------------------
# Training loss: 0.354315
# Validation loss: 0.348314
#
# Epoch 76
# -------------------------------
# Training loss: 0.353862
# Validation loss: 0.346243
#
# Epoch 77
# -------------------------------
# Training loss: 0.352910
# Validation loss: 0.353732
#
# Epoch 78
# -------------------------------
# Training loss: 0.351524
# Validation loss: 0.351094
#
# Epoch 79
# -------------------------------
# Training loss: 0.351131
# Validation loss: 0.348697
#
# Epoch 80
# -------------------------------
# Training loss: 0.349365
# Validation loss: 0.356174
#
# Epoch 81
# -------------------------------
# Training loss: 0.347151
# Validation loss: 0.339920
#
# Epoch 82
# -------------------------------
# Training loss: 0.347336
# Validation loss: 0.345789
#
# Epoch 83
# -------------------------------
# Training loss: 0.346140
# Validation loss: 0.341640
#
# Epoch 84
# -------------------------------
# Training loss: 0.343633
# Validation loss: 0.336456
#
# Epoch 85
# -------------------------------
# Training loss: 0.345276
# Validation loss: 0.342179
#
# Epoch 86
# -------------------------------
# Training loss: 0.343394
# Validation loss: 0.347637
#
# Epoch 87
# -------------------------------
# Training loss: 0.341456
# Validation loss: 0.331762
#
# Epoch 88
# -------------------------------
# Training loss: 0.341553
# Validation loss: 0.334024
#
# Epoch 89
# -------------------------------
# Training loss: 0.339026
# Validation loss: 0.329426
#
# Epoch 90
# -------------------------------
# Training loss: 0.337667
# Validation loss: 0.324413
#
# Epoch 91
# -------------------------------
# Training loss: 0.338622
# Validation loss: 0.345645
#
# Epoch 92
# -------------------------------
# Training loss: 0.338662
# Validation loss: 0.335313
#
# Epoch 93
# -------------------------------
# Training loss: 0.336302
# Validation loss: 0.337321
#
# Epoch 94
# -------------------------------
# Training loss: 0.333693
# Validation loss: 0.337219
#
# Epoch 95
# -------------------------------
# Training loss: 0.331697
# Validation loss: 0.331383
#
# Epoch 96
# -------------------------------
# Training loss: 0.331305
# Validation loss: 0.323648
#
# Epoch 97
# -------------------------------
# Training loss: 0.330071
# Validation loss: 0.341305
#
# Epoch 98
# -------------------------------
# Training loss: 0.328303
# Validation loss: 0.317292
#
# Epoch 99
# -------------------------------
# Training loss: 0.327817
# Validation loss: 0.323945
#
# Epoch 100
# -------------------------------
# Training loss: 0.327782
# Validation loss: 0.320559
#
# Epoch 101
# -------------------------------
# Training loss: 0.326066
# Validation loss: 0.437244
#
# Epoch 102
# -------------------------------
# Training loss: 0.325805
# Validation loss: 0.311490
#
# Epoch 103
# -------------------------------
# Training loss: 0.324343
# Validation loss: 0.311155
#
# Epoch 104
# -------------------------------
# Training loss: 0.320907
# Validation loss: 0.319676
#
# Epoch 105
# -------------------------------
# Training loss: 0.321587
# Validation loss: 0.327025
#
# Epoch 106
# -------------------------------
# Training loss: 0.319574
# Validation loss: 0.311925
#
# Epoch 107
# -------------------------------
# Training loss: 0.319558
# Validation loss: 0.310881
#
# Epoch 108
# -------------------------------
# Training loss: 0.318828
# Validation loss: 0.313234
#
# Epoch 109
# -------------------------------
# Training loss: 0.315036
# Validation loss: 0.313147
#
# Epoch 110
# -------------------------------
# Training loss: 0.314685
# Validation loss: 0.356713
#
# Epoch 111
# -------------------------------
# Training loss: 0.312916
# Validation loss: 0.383621
#
# Epoch 112
# -------------------------------
# Training loss: 0.312695
# Validation loss: 0.304258
#
# Epoch 113
# -------------------------------
# Training loss: 0.311594
# Validation loss: 0.330781
#
# Epoch 114
# -------------------------------
# Training loss: 0.312455
# Validation loss: 0.309060
#
# Epoch 115
# -------------------------------
# Training loss: 0.313324
# Validation loss: 0.308035
#
# Epoch 116
# -------------------------------
# Training loss: 0.307834
# Validation loss: 0.314811
#
# Epoch 117
# -------------------------------
# Training loss: 0.305791
# Validation loss: 0.311666
#
# Epoch 118
# -------------------------------
# Training loss: 0.306544
# Validation loss: 0.295259
#
# Epoch 119
# -------------------------------
# Training loss: 0.303432
# Validation loss: 0.299360
#
# Epoch 120
# -------------------------------
# Training loss: 0.300060
# Validation loss: 0.288336
#
# Epoch 121
# -------------------------------
# Training loss: 0.300423
# Validation loss: 0.300268
#
# Epoch 122
# -------------------------------
# Training loss: 0.302441
# Validation loss: 0.298724
#
# Epoch 123
# -------------------------------
# Training loss: 0.299692
# Validation loss: 0.473343
#
# Epoch 124
# -------------------------------
# Training loss: 0.301352
# Validation loss: 0.349387
#
# Epoch 125
# -------------------------------
# Training loss: 0.296407
# Validation loss: 0.298813
#
# Epoch 126
# -------------------------------
# Training loss: 0.295004
# Validation loss: 0.385726
#
# Epoch 127
# -------------------------------
# Training loss: 0.293528
# Validation loss: 0.295518
#
# Epoch 128
# -------------------------------
# Training loss: 0.291957
# Validation loss: 0.287853
#
# Epoch 129
# -------------------------------
# Training loss: 0.292139
# Validation loss: 0.292612
#
# Epoch 130
# -------------------------------
# Training loss: 0.289896
# Validation loss: 0.283673
#
# Epoch 131
# -------------------------------
# Training loss: 0.285433
# Validation loss: 0.282789
#
# Epoch 132
# -------------------------------
# Training loss: 0.287180
# Validation loss: 0.274025
#
# Epoch 133
# -------------------------------
# Training loss: 0.285010
# Validation loss: 0.302429
#
# Epoch 134
# -------------------------------
# Training loss: 0.286376
# Validation loss: 0.360042
#
# Epoch 135
# -------------------------------
# Training loss: 0.284117
# Validation loss: 0.282177
#
# Epoch 136
# -------------------------------
# Training loss: 0.278857
# Validation loss: 0.281250
#
# Epoch 137
# -------------------------------
# Training loss: 0.281581
# Validation loss: 0.271365
#
# Epoch 138
# -------------------------------
# Training loss: 0.275517
# Validation loss: 0.270845
#
# Epoch 139
# -------------------------------
# Training loss: 0.274139
# Validation loss: 0.453329
#
# Epoch 140
# -------------------------------
# Training loss: 0.276222
# Validation loss: 0.281736
#
# Epoch 141
# -------------------------------
# Training loss: 0.276544
# Validation loss: 0.280833
#
# Epoch 142
# -------------------------------
# Training loss: 0.277661
# Validation loss: 0.280611
#
# Epoch 143
# -------------------------------
# Training loss: 0.272696
# Validation loss: 0.262332
#
# Epoch 144
# -------------------------------
# Training loss: 0.277690
# Validation loss: 0.285792
#
# Epoch 145
# -------------------------------
# Training loss: 0.274957
# Validation loss: 0.264530
#
# Epoch 146
# -------------------------------
# Training loss: 0.265286
# Validation loss: 0.275138
#
# Epoch 147
# -------------------------------
# Training loss: 0.261858
# Validation loss: 0.263071
#
# Epoch 148
# -------------------------------
# Training loss: 0.261797
# Validation loss: 0.260441
#
# Epoch 149
# -------------------------------
# Training loss: 0.259871
# Validation loss: 0.268543
#
# Epoch 150
# -------------------------------
# Training loss: 0.256174
# Validation loss: 0.362073
#
# Epoch 151
# -------------------------------
# Training loss: 0.250796
# Validation loss: 0.258678
#
# Epoch 152
# -------------------------------
# Training loss: 0.258587
# Validation loss: 0.314728
#
# Epoch 153
# -------------------------------
# Training loss: 0.255919
# Validation loss: 0.267569
#
# Epoch 154
# -------------------------------
# Training loss: 0.252884
# Validation loss: 0.242244
#
# Epoch 155
# -------------------------------
# Training loss: 0.247177
# Validation loss: 0.290765
#
# Epoch 156
# -------------------------------
# Training loss: 0.245172
# Validation loss: 0.266400
#
# Epoch 157
# -------------------------------
# Training loss: 0.242344
# Validation loss: 0.241515
#
# Epoch 158
# -------------------------------
# Training loss: 0.246393
# Validation loss: 0.250330
#
# Epoch 159
# -------------------------------
# Training loss: 0.243083
# Validation loss: 0.229280
#
# Epoch 160
# -------------------------------
# Training loss: 0.238477
# Validation loss: 0.245233
#
# Epoch 161
# -------------------------------
# Training loss: 0.233003
# Validation loss: 0.448841
#
# Epoch 162
# -------------------------------
# Training loss: 0.237211
# Validation loss: 0.228937
#
# Epoch 163
# -------------------------------
# Training loss: 0.234808
# Validation loss: 0.264989
#
# Epoch 164
# -------------------------------
# Training loss: 0.229587
# Validation loss: 0.536963
#
# Epoch 165
# -------------------------------
# Training loss: 0.230672
# Validation loss: 0.379491
#
# Epoch 166
# -------------------------------
# Training loss: 0.225762
# Validation loss: 0.215824
#
# Epoch 167
# -------------------------------
# Training loss: 0.222483
# Validation loss: 0.225938
#
# Epoch 168
# -------------------------------
# Training loss: 0.225161
# Validation loss: 0.222526
#
# Epoch 169
# -------------------------------
# Training loss: 0.219184
# Validation loss: 0.393387
#
# Epoch 170
# -------------------------------
# Training loss: 0.228461
# Validation loss: 0.209752
#
# Epoch 171
# -------------------------------
# Training loss: 0.217830
# Validation loss: 0.205182
#
# Epoch 172
# -------------------------------
# Training loss: 0.217254
# Validation loss: 0.207807
#
# Epoch 173
# -------------------------------
# Training loss: 0.205828
# Validation loss: 0.251817
#
# Epoch 174
# -------------------------------
# Training loss: 0.205142
# Validation loss: 0.200807
#
# Epoch 175
# -------------------------------
# Training loss: 0.203116
# Validation loss: 0.200112
#
# Epoch 176
# -------------------------------
# Training loss: 0.198057
# Validation loss: 0.206742
#
# Epoch 177
# -------------------------------
# Training loss: 0.194877
# Validation loss: 0.191995
#
# Epoch 178
# -------------------------------
# Training loss: 0.199029
# Validation loss: 0.216759
#
# Epoch 179
# -------------------------------
# Training loss: 0.191171
# Validation loss: 0.180674
#
# Epoch 180
# -------------------------------
# Training loss: 0.189391
# Validation loss: 0.185809
#
# Epoch 181
# -------------------------------
# Training loss: 0.192160
# Validation loss: 0.301270
#
# Epoch 182
# -------------------------------
# Training loss: 0.183416
# Validation loss: 0.184012
#
# Epoch 183
# -------------------------------
# Training loss: 0.184244
# Validation loss: 0.173963
#
# Epoch 184
# -------------------------------
# Training loss: 0.185409
# Validation loss: 0.177232
#
# Epoch 185
# -------------------------------
# Training loss: 0.182422
# Validation loss: 0.181047
#
# Epoch 186
# -------------------------------
# Training loss: 0.180613
# Validation loss: 0.176408
#
# Epoch 187
# -------------------------------
# Training loss: 0.175464
# Validation loss: 0.265078
#
# Epoch 188
# -------------------------------
# Training loss: 0.180648
# Validation loss: 0.169994
#
# Epoch 189
# -------------------------------
# Training loss: 0.176722
# Validation loss: 0.204958
#
# Epoch 190
# -------------------------------
# Training loss: 0.174023
# Validation loss: 0.254228
#
# Epoch 191
# -------------------------------
# Training loss: 0.171033
# Validation loss: 0.159630
#
# Epoch 192
# -------------------------------
# Training loss: 0.174537
# Validation loss: 0.159661
#
# Epoch 193
# -------------------------------
# Training loss: 0.171763
# Validation loss: 0.176057
#
# Epoch 194
# -------------------------------
# Training loss: 0.174572
# Validation loss: 0.193896
#
# Epoch 195
# -------------------------------
# Training loss: 0.174035
# Validation loss: 0.223466
#
# Epoch 196
# -------------------------------
# Training loss: 0.169336
# Validation loss: 0.154504
#
# Epoch 197
# -------------------------------
# Training loss: 0.165775
# Validation loss: 0.164419
#
# Epoch 198
# -------------------------------
# Training loss: 0.165472
# Validation loss: 0.150328
#
# Epoch 199
# -------------------------------
# Training loss: 0.163603
# Validation loss: 0.150787
#
# Epoch 200
# -------------------------------
# Training loss: 0.161042
# Validation loss: 0.168659
#
# Epoch 201
# -------------------------------
# Training loss: 0.165064
# Validation loss: 0.607026
#
# Epoch 202
# -------------------------------
# Training loss: 0.162870
# Validation loss: 0.183988
#
# Epoch 203
# -------------------------------
# Training loss: 0.157760
# Validation loss: 0.149318
#
# Epoch 204
# -------------------------------
# Training loss: 0.161612
# Validation loss: 0.140202
#
# Epoch 205
# -------------------------------
# Training loss: 0.157154
# Validation loss: 0.157676
#
# Epoch 206
# -------------------------------
# Training loss: 0.157410
# Validation loss: 0.184128
#
# Epoch 207
# -------------------------------
# Training loss: 0.153985
# Validation loss: 0.152098
#
# Epoch 208
# -------------------------------
# Training loss: 0.157219
# Validation loss: 0.171439
#
# Epoch 209
# -------------------------------
# Training loss: 0.153922
# Validation loss: 0.146277
#
# Epoch 210
# -------------------------------
# Training loss: 0.151523
# Validation loss: 0.157691
#
# Epoch 211
# -------------------------------
# Training loss: 0.151639
# Validation loss: 0.214720
#
# Epoch 212
# -------------------------------
# Training loss: 0.148314
# Validation loss: 0.145655
#
# Epoch 213
# -------------------------------
# Training loss: 0.153922
# Validation loss: 0.160200
#
# Epoch 214
# -------------------------------
# Training loss: 0.155780
# Validation loss: 0.203257
#
# Epoch 215
# -------------------------------
# Training loss: 0.150314
# Validation loss: 0.149101
#
# Epoch 216
# -------------------------------
# Training loss: 0.147862
# Validation loss: 0.136027
#
# Epoch 217
# -------------------------------
# Training loss: 0.148734
# Validation loss: 0.139917
#
# Epoch 218
# -------------------------------
# Training loss: 0.149530
# Validation loss: 0.258484
#
# Epoch 219
# -------------------------------
# Training loss: 0.146528
# Validation loss: 0.144302
#
# Epoch 220
# -------------------------------
# Training loss: 0.147065
# Validation loss: 0.130306
#
# Epoch 221
# -------------------------------
# Training loss: 0.142640
# Validation loss: 0.134370
#
# Epoch 222
# -------------------------------
# Training loss: 0.144677
# Validation loss: 0.173422
#
# Epoch 223
# -------------------------------
# Training loss: 0.144890
# Validation loss: 0.130438
#
# Epoch 224
# -------------------------------
# Training loss: 0.144056
# Validation loss: 0.174928
#
# Epoch 225
# -------------------------------
# Training loss: 0.141713
# Validation loss: 0.156270
#
# Epoch 226
# -------------------------------
# Training loss: 0.141750
# Validation loss: 0.129208
#
# Epoch 227
# -------------------------------
# Training loss: 0.140432
# Validation loss: 0.181607
#
# Epoch 228
# -------------------------------
# Training loss: 0.140411
# Validation loss: 0.138478
#
# Epoch 229
# -------------------------------
# Training loss: 0.145181
# Validation loss: 0.143041
#
# Epoch 230
# -------------------------------
# Training loss: 0.136360
# Validation loss: 0.143585
#
# Epoch 231
# -------------------------------
# Training loss: 0.138971
# Validation loss: 0.287971
#
# Epoch 232
# -------------------------------
# Training loss: 0.138831
# Validation loss: 0.152618
#
# Epoch 233
# -------------------------------
# Training loss: 0.138487
# Validation loss: 0.131541
#
# Epoch 234
# -------------------------------
# Training loss: 0.137327
# Validation loss: 0.152827
#
# Epoch 235
# -------------------------------
# Training loss: 0.139173
# Validation loss: 0.122245
#
# Epoch 236
# -------------------------------
# Training loss: 0.135345
# Validation loss: 0.145015
#
# Epoch 237
# -------------------------------
# Training loss: 0.136073
# Validation loss: 0.126451
#
# Epoch 238
# -------------------------------
# Training loss: 0.131703
# Validation loss: 0.125287
#
# Epoch 239
# -------------------------------
# Training loss: 0.130157
# Validation loss: 0.126998
#
# Epoch 240
# -------------------------------
# Training loss: 0.130834
# Validation loss: 0.137317
#
# Epoch 241
# -------------------------------
# Training loss: 0.134058
# Validation loss: 0.134917
#
# Epoch 242
# -------------------------------
# Training loss: 0.131738
# Validation loss: 0.118730
#
# Epoch 243
# -------------------------------
# Training loss: 0.132811
# Validation loss: 0.144895
#
# Epoch 244
# -------------------------------
# Training loss: 0.132359
# Validation loss: 0.284455
#
# Epoch 245
# -------------------------------
# Training loss: 0.132615
# Validation loss: 0.157970
#
# Epoch 246
# -------------------------------
# Training loss: 0.133880
# Validation loss: 0.151001
#
# Epoch 247
# -------------------------------
# Training loss: 0.128402
# Validation loss: 0.119581
#
# Epoch 248
# -------------------------------
# Training loss: 0.127989
# Validation loss: 0.172462
#
# Epoch 249
# -------------------------------
# Training loss: 0.130387
# Validation loss: 0.127912
#
# Epoch 250
# -------------------------------
# Training loss: 0.128502
# Validation loss: 0.123515
#
# Epoch 251
# -------------------------------
# Training loss: 0.131082
# Validation loss: 0.118952
#
# Epoch 252
# -------------------------------
# Training loss: 0.125907
# Validation loss: 0.120799
#
# Epoch 253
# -------------------------------
# Training loss: 0.131266
# Validation loss: 0.354774
#
# Epoch 254
# -------------------------------
# Training loss: 0.129468
# Validation loss: 0.122118
#
# Epoch 255
# -------------------------------
# Training loss: 0.129211
# Validation loss: 0.144553
#
# Epoch 256
# -------------------------------
# Training loss: 0.126927
# Validation loss: 0.125540
#
# Epoch 257
# -------------------------------
# Training loss: 0.125073
# Validation loss: 0.155486
#
# Epoch 258
# -------------------------------
# Training loss: 0.121735
# Validation loss: 0.114766
#
# Epoch 259
# -------------------------------
# Training loss: 0.122609
# Validation loss: 0.125759
#
# Epoch 260
# -------------------------------
# Training loss: 0.128692
# Validation loss: 0.113485
#
# Epoch 261
# -------------------------------
# Training loss: 0.122583
# Validation loss: 0.123537
#
# Epoch 262
# -------------------------------
# Training loss: 0.124973
# Validation loss: 0.114251
#
# Epoch 263
# -------------------------------
# Training loss: 0.121699
# Validation loss: 0.114742
#
# Epoch 264
# -------------------------------
# Training loss: 0.121415
# Validation loss: 0.117237
#
# Epoch 265
# -------------------------------
# Training loss: 0.118371
# Validation loss: 0.238760
#
# Epoch 266
# -------------------------------
# Training loss: 0.122949
# Validation loss: 0.132270
#
# Epoch 267
# -------------------------------
# Training loss: 0.119513
# Validation loss: 0.106340
#
# Epoch 268
# -------------------------------
# Training loss: 0.119014
# Validation loss: 0.123073
#
# Epoch 269
# -------------------------------
# Training loss: 0.115914
# Validation loss: 0.148278
#
# Epoch 270
# -------------------------------
# Training loss: 0.121320
# Validation loss: 0.171751
#
# Epoch 271
# -------------------------------
# Training loss: 0.117724
# Validation loss: 0.137802
#
# Epoch 272
# -------------------------------
# Training loss: 0.120715
# Validation loss: 0.111216
#
# Epoch 273
# -------------------------------
# Training loss: 0.116356
# Validation loss: 0.146854
#
# Epoch 274
# -------------------------------
# Training loss: 0.121469
# Validation loss: 0.115613
#
# Epoch 275
# -------------------------------
# Training loss: 0.117790
# Validation loss: 0.127881
#
# Epoch 276
# -------------------------------
# Training loss: 0.119044
# Validation loss: 0.134122
#
# Epoch 277
# -------------------------------
# Training loss: 0.117562
# Validation loss: 0.103526
#
# Epoch 278
# -------------------------------
# Training loss: 0.115409
# Validation loss: 0.112221
#
# Epoch 279
# -------------------------------
# Training loss: 0.116557
# Validation loss: 0.112528
#
# Epoch 280
# -------------------------------
# Training loss: 0.117541
# Validation loss: 0.124324
#
# Epoch 281
# -------------------------------
# Training loss: 0.116191
# Validation loss: 0.244962
#
# Epoch 282
# -------------------------------
# Training loss: 0.113246
# Validation loss: 0.110421
#
# Epoch 283
# -------------------------------
# Training loss: 0.112933
# Validation loss: 0.141539
#
# Epoch 284
# -------------------------------
# Training loss: 0.117879
# Validation loss: 0.102521
#
# Epoch 285
# -------------------------------
# Training loss: 0.114169
# Validation loss: 0.103664
#
# Epoch 286
# -------------------------------
# Training loss: 0.112570
# Validation loss: 0.142516
#
# Epoch 287
# -------------------------------
# Training loss: 0.111397
# Validation loss: 0.099217
#
# Epoch 288
# -------------------------------
# Training loss: 0.113860
# Validation loss: 0.127650
#
# Epoch 289
# -------------------------------
# Training loss: 0.115091
# Validation loss: 0.101798
#
# Epoch 290
# -------------------------------
# Training loss: 0.112245
# Validation loss: 0.142185
#
# Epoch 291
# -------------------------------
# Training loss: 0.117039
# Validation loss: 0.128666
#
# Epoch 292
# -------------------------------
# Training loss: 0.111315
# Validation loss: 0.132397
#
# Epoch 293
# -------------------------------
# Training loss: 0.113125
# Validation loss: 0.109493
#
# Epoch 294
# -------------------------------
# Training loss: 0.118059
# Validation loss: 0.147453
#
# Epoch 295
# -------------------------------
# Training loss: 0.110095
# Validation loss: 0.102433
#
# Epoch 296
# -------------------------------
# Training loss: 0.110580
# Validation loss: 0.103103
#
# Epoch 297
# -------------------------------
# Training loss: 0.110667
# Validation loss: 0.120564
#
# Epoch 298
# -------------------------------
# Training loss: 0.109744
# Validation loss: 0.096185
#
# Epoch 299
# -------------------------------
# Training loss: 0.104891
# Validation loss: 0.106989
#
# Epoch 300
# -------------------------------
# Training loss: 0.108143
# Validation loss: 0.105665
#
# Epoch 301
# -------------------------------
# Training loss: 0.110961
# Validation loss: 0.095647
#
# Epoch 302
# -------------------------------
# Training loss: 0.107548
# Validation loss: 0.113366
#
# Epoch 303
# -------------------------------
# Training loss: 0.106712
# Validation loss: 0.093558
#
# Epoch 304
# -------------------------------
# Training loss: 0.107708
# Validation loss: 0.098865
#
# Epoch 305
# -------------------------------
# Training loss: 0.107761
# Validation loss: 0.124404
#
# Epoch 306
# -------------------------------
# Training loss: 0.109724
# Validation loss: 0.105319
#
# Epoch 307
# -------------------------------
# Training loss: 0.106218
# Validation loss: 0.103268
#
# Epoch 308
# -------------------------------
# Training loss: 0.104684
# Validation loss: 0.102322
#
# Epoch 309
# -------------------------------
# Training loss: 0.104774
# Validation loss: 0.094321
#
# Epoch 310
# -------------------------------
# Training loss: 0.105997
# Validation loss: 0.103454
#
# Epoch 311
# -------------------------------
# Training loss: 0.104450
# Validation loss: 0.103233
#
# Epoch 312
# -------------------------------
# Training loss: 0.107495
# Validation loss: 0.102909
#
# Epoch 313
# -------------------------------
# Training loss: 0.107440
# Validation loss: 0.162698
#
# Epoch 314
# -------------------------------
# Training loss: 0.106512
# Validation loss: 0.108223
#
# Epoch 315
# -------------------------------
# Training loss: 0.106232
# Validation loss: 0.438732
#
# Epoch 316
# -------------------------------
# Training loss: 0.109465
# Validation loss: 0.120411
#
# Epoch 317
# -------------------------------
# Training loss: 0.104595
# Validation loss: 0.101228
#
# Epoch 318
# -------------------------------
# Training loss: 0.104842
# Validation loss: 0.121301
#
# Epoch 319
# -------------------------------
# Training loss: 0.106366
# Validation loss: 0.265113
#
# Epoch 320
# -------------------------------
# Training loss: 0.101267
# Validation loss: 0.097174
#
# Epoch 321
# -------------------------------
# Training loss: 0.105061
# Validation loss: 0.091566
#
# Epoch 322
# -------------------------------
# Training loss: 0.102961
# Validation loss: 0.107535
#
# Epoch 323
# -------------------------------
# Training loss: 0.105149
# Validation loss: 0.091033
#
# Epoch 324
# -------------------------------
# Training loss: 0.101459
# Validation loss: 0.092722
#
# Epoch 325
# -------------------------------
# Training loss: 0.102574
# Validation loss: 0.100864
#
# Epoch 326
# -------------------------------
# Training loss: 0.101346
# Validation loss: 0.097004
#
# Epoch 327
# -------------------------------
# Training loss: 0.103587
# Validation loss: 0.097562
#
# Epoch 328
# -------------------------------
# Training loss: 0.103793
# Validation loss: 0.111544
#
# Epoch 329
# -------------------------------
# Training loss: 0.101232
# Validation loss: 0.102806
#
# Epoch 330
# -------------------------------
# Training loss: 0.100649
# Validation loss: 0.092589
#
# Epoch 331
# -------------------------------
# Training loss: 0.100572
# Validation loss: 0.104544
#
# Epoch 332
# -------------------------------
# Training loss: 0.099885
# Validation loss: 0.096267
#
# Epoch 333
# -------------------------------
# Training loss: 0.097592
# Validation loss: 0.101398
#
# Epoch 334
# -------------------------------
# Training loss: 0.100405
# Validation loss: 0.151559
#
# Epoch 335
# -------------------------------
# Training loss: 0.099312
# Validation loss: 0.096555
#
# Epoch 336
# -------------------------------
# Training loss: 0.097248
# Validation loss: 0.095092
#
# Epoch 337
# -------------------------------
# Training loss: 0.100085
# Validation loss: 0.103436
#
# Epoch 338
# -------------------------------
# Training loss: 0.099772
# Validation loss: 0.092344
#
# Epoch 339
# -------------------------------
# Training loss: 0.098921
# Validation loss: 0.104136
#
# Epoch 340
# -------------------------------
# Training loss: 0.096835
# Validation loss: 0.111017
#
# Epoch 341
# -------------------------------
# Training loss: 0.103170
# Validation loss: 0.262584
#
# Epoch 342
# -------------------------------
# Training loss: 0.097185
# Validation loss: 0.106402
#
# Epoch 343
# -------------------------------
# Training loss: 0.097395
# Validation loss: 0.094276
#
# Epoch 344
# -------------------------------
# Training loss: 0.099263
# Validation loss: 0.086952
#
# Epoch 345
# -------------------------------
# Training loss: 0.101350
# Validation loss: 0.094053
#
# Epoch 346
# -------------------------------
# Training loss: 0.095512
# Validation loss: 0.120026
#
# Epoch 347
# -------------------------------
# Training loss: 0.096921
# Validation loss: 0.083476
#
# Epoch 348
# -------------------------------
# Training loss: 0.096260
# Validation loss: 0.091729
#
# Epoch 349
# -------------------------------
# Training loss: 0.094975
# Validation loss: 0.090319
#
# Epoch 350
# -------------------------------
# Training loss: 0.098952
# Validation loss: 0.119053
#
# Epoch 351
# -------------------------------
# Training loss: 0.096307
# Validation loss: 0.088586
#
# Epoch 352
# -------------------------------
# Training loss: 0.097201
# Validation loss: 0.091053
#
# Epoch 353
# -------------------------------
# Training loss: 0.098496
# Validation loss: 0.097630
#
# Epoch 354
# -------------------------------
# Training loss: 0.098720
# Validation loss: 0.123680
#
# Epoch 355
# -------------------------------
# Training loss: 0.095546
# Validation loss: 0.088834
#
# Epoch 356
# -------------------------------
# Training loss: 0.096773
# Validation loss: 0.093056
#
# Epoch 357
# -------------------------------
# Training loss: 0.095017
# Validation loss: 0.085867
#
# Epoch 358
# -------------------------------
# Training loss: 0.090763
# Validation loss: 0.112018
#
# Epoch 359
# -------------------------------
# Training loss: 0.094292
# Validation loss: 0.088303
#
# Epoch 360
# -------------------------------
# Training loss: 0.095740
# Validation loss: 0.100930
#
# Epoch 361
# -------------------------------
# Training loss: 0.093345
# Validation loss: 0.085365
#
# Epoch 362
# -------------------------------
# Training loss: 0.095216
# Validation loss: 0.095181
#
# Epoch 363
# -------------------------------
# Training loss: 0.091955
# Validation loss: 0.085531
#
# Epoch 364
# -------------------------------
# Training loss: 0.096812
# Validation loss: 0.085838
#
# Epoch 365
# -------------------------------
# Training loss: 0.093014
# Validation loss: 0.097816
#
# Epoch 366
# -------------------------------
# Training loss: 0.095599
# Validation loss: 0.088537
#
# Epoch 367
# -------------------------------
# Training loss: 0.095699
# Validation loss: 0.091734
#
# Epoch 368
# -------------------------------
# Training loss: 0.092248
# Validation loss: 0.080848
#
# Epoch 369
# -------------------------------
# Training loss: 0.090729
# Validation loss: 0.089864
#
# Epoch 370
# -------------------------------
# Training loss: 0.093020
# Validation loss: 0.136241
#
# Epoch 371
# -------------------------------
# Training loss: 0.091141
# Validation loss: 0.094727
#
# Epoch 372
# -------------------------------
# Training loss: 0.091377
# Validation loss: 0.087440
#
# Epoch 373
# -------------------------------
# Training loss: 0.094523
# Validation loss: 0.099142
#
# Epoch 374
# -------------------------------
# Training loss: 0.090593
# Validation loss: 0.107892
#
# Epoch 375
# -------------------------------
# Training loss: 0.091029
# Validation loss: 0.082137
#
# Epoch 376
# -------------------------------
# Training loss: 0.089633
# Validation loss: 0.090998
#
# Epoch 377
# -------------------------------
# Training loss: 0.091282
# Validation loss: 0.080528
#
# Epoch 378
# -------------------------------
# Training loss: 0.089737
# Validation loss: 0.110381
#
# Epoch 379
# -------------------------------
# Training loss: 0.090285
# Validation loss: 0.090382
#
# Epoch 380
# -------------------------------
# Training loss: 0.090455
# Validation loss: 0.180366
#
# Epoch 381
# -------------------------------
# Training loss: 0.091568
# Validation loss: 0.083477
#
# Epoch 382
# -------------------------------
# Training loss: 0.087858
# Validation loss: 0.085785
#
# Epoch 383
# -------------------------------
# Training loss: 0.090702
# Validation loss: 0.082594
#
# Epoch 384
# -------------------------------
# Training loss: 0.089757
# Validation loss: 0.096610
#
# Epoch 385
# -------------------------------
# Training loss: 0.090418
# Validation loss: 0.097000
#
# Epoch 386
# -------------------------------
# Training loss: 0.087529
# Validation loss: 0.090660
#
# Epoch 387
# -------------------------------
# Training loss: 0.088344
# Validation loss: 0.113193
#
# Epoch 388
# -------------------------------
# Training loss: 0.090294
# Validation loss: 0.088874
#
# Epoch 389
# -------------------------------
# Training loss: 0.090548
# Validation loss: 0.085575
#
# Epoch 390
# -------------------------------
# Training loss: 0.091243
# Validation loss: 0.085457
#
# Epoch 391
# -------------------------------
# Training loss: 0.089287
# Validation loss: 0.080403
#
# Epoch 392
# -------------------------------
# Training loss: 0.091720
# Validation loss: 0.121013
#
# Epoch 393
# -------------------------------
# Training loss: 0.090095
# Validation loss: 0.089276
#
# Epoch 394
# -------------------------------
# Training loss: 0.090133
# Validation loss: 0.083971
#
# Epoch 395
# -------------------------------
# Training loss: 0.087838
# Validation loss: 0.119793
#
# Epoch 396
# -------------------------------
# Training loss: 0.085640
# Validation loss: 0.116028
#
# Epoch 397
# -------------------------------
# Training loss: 0.090000
# Validation loss: 0.102151
#
# Epoch 398
# -------------------------------
# Training loss: 0.089676
# Validation loss: 0.084910
#
# Epoch 399
# -------------------------------
# Training loss: 0.088504
# Validation loss: 0.086145
#
# Epoch 400
# -------------------------------
# Training loss: 0.086388
# Validation loss: 0.117997
#
# Epoch 401
# -------------------------------
# Training loss: 0.088313
# Validation loss: 0.087455
#
# Epoch 402
# -------------------------------
# Training loss: 0.086687
# Validation loss: 0.082303
#
# Epoch 403
# -------------------------------
# Training loss: 0.093456
# Validation loss: 0.079266
#
# Epoch 404
# -------------------------------
# Training loss: 0.085994
# Validation loss: 0.081736
#
# Epoch 405
# -------------------------------
# Training loss: 0.088746
# Validation loss: 0.121923
#
# Epoch 406
# -------------------------------
# Training loss: 0.086444
# Validation loss: 0.087023
#
# Epoch 407
# -------------------------------
# Training loss: 0.085384
# Validation loss: 0.081356
#
# Epoch 408
# -------------------------------
# Training loss: 0.085456
# Validation loss: 0.122088
#
# Epoch 409
# -------------------------------
# Training loss: 0.083895
# Validation loss: 0.077255
#
# Epoch 410
# -------------------------------
# Training loss: 0.086594
# Validation loss: 0.093269
#
# Epoch 411
# -------------------------------
# Training loss: 0.088299
# Validation loss: 0.082390
#
# Epoch 412
# -------------------------------
# Training loss: 0.085519
# Validation loss: 0.086218
#
# Epoch 413
# -------------------------------
# Training loss: 0.083109
# Validation loss: 0.091045
#
# Epoch 414
# -------------------------------
# Training loss: 0.084965
# Validation loss: 0.088309
#
# Epoch 415
# -------------------------------
# Training loss: 0.083947
# Validation loss: 0.131113
#
# Epoch 416
# -------------------------------
# Training loss: 0.086751
# Validation loss: 0.078285
#
# Epoch 417
# -------------------------------
# Training loss: 0.088902
# Validation loss: 0.089509
#
# Epoch 418
# -------------------------------
# Training loss: 0.085941
# Validation loss: 0.078305
#
# Epoch 419
# -------------------------------
# Training loss: 0.085855
# Validation loss: 0.080530
#
# Epoch 420
# -------------------------------
# Training loss: 0.084054
# Validation loss: 0.074861
#
# Epoch 421
# -------------------------------
# Training loss: 0.083499
# Validation loss: 0.077276
#
# Epoch 422
# -------------------------------
# Training loss: 0.087979
# Validation loss: 0.083799
#
# Epoch 423
# -------------------------------
# Training loss: 0.085900
# Validation loss: 0.078362
#
# Epoch 424
# -------------------------------
# Training loss: 0.084635
# Validation loss: 0.080640
#
# Epoch 425
# -------------------------------
# Training loss: 0.083229
# Validation loss: 0.100664
#
# Epoch 426
# -------------------------------
# Training loss: 0.082898
# Validation loss: 0.090058
#
# Epoch 427
# -------------------------------
# Training loss: 0.085662
# Validation loss: 0.078861
#
# Epoch 428
# -------------------------------
# Training loss: 0.082976
# Validation loss: 0.087087
#
# Epoch 429
# -------------------------------
# Training loss: 0.084153
# Validation loss: 0.075596
#
# Epoch 430
# -------------------------------
# Training loss: 0.084884
# Validation loss: 0.100112
#
# Epoch 431
# -------------------------------
# Training loss: 0.084465
# Validation loss: 0.146980
#
# Epoch 432
# -------------------------------
# Training loss: 0.086569
# Validation loss: 0.085203
#
# Epoch 433
# -------------------------------
# Training loss: 0.082116
# Validation loss: 0.096846
#
# Epoch 434
# -------------------------------
# Training loss: 0.082229
# Validation loss: 0.075358
#
# Epoch 435
# -------------------------------
# Training loss: 0.084350
# Validation loss: 0.087365
#
# Epoch 436
# -------------------------------
# Training loss: 0.083644
# Validation loss: 0.084018
#
# Epoch 437
# -------------------------------
# Training loss: 0.082604
# Validation loss: 0.076235
#
# Epoch 438
# -------------------------------
# Training loss: 0.083671
# Validation loss: 0.078343
#
# Epoch 439
# -------------------------------
# Training loss: 0.081580
# Validation loss: 0.157586
#
# Epoch 440
# -------------------------------
# Training loss: 0.082968
# Validation loss: 0.078161
#
# Epoch 441
# -------------------------------
# Training loss: 0.079754
# Validation loss: 0.076460
#
# Epoch 442
# -------------------------------
# Training loss: 0.079502
# Validation loss: 0.090972
#
# Epoch 443
# -------------------------------
# Training loss: 0.081731
# Validation loss: 0.099465
#
# Epoch 444
# -------------------------------
# Training loss: 0.080995
# Validation loss: 0.075092
#
# Epoch 445
# -------------------------------
# Training loss: 0.082329
# Validation loss: 0.102232
#
# Epoch 446
# -------------------------------
# Training loss: 0.082169
# Validation loss: 0.082002
#
# Epoch 447
# -------------------------------
# Training loss: 0.083406
# Validation loss: 0.075350
#
# Epoch 448
# -------------------------------
# Training loss: 0.082144
# Validation loss: 0.139899
#
# Epoch 449
# -------------------------------
# Training loss: 0.082340
# Validation loss: 0.075044
#
# Epoch 450
# -------------------------------
# Training loss: 0.082283
# Validation loss: 0.077412
#
# Epoch 451
# -------------------------------
# Training loss: 0.080148
# Validation loss: 0.160686
#
# Epoch 452
# -------------------------------
# Training loss: 0.081293
# Validation loss: 0.072469
#
# Epoch 453
# -------------------------------
# Training loss: 0.079807
# Validation loss: 0.093792
#
# Epoch 454
# -------------------------------
# Training loss: 0.077813
# Validation loss: 0.089559
#
# Epoch 455
# -------------------------------
# Training loss: 0.082457
# Validation loss: 0.098195
#
# Epoch 456
# -------------------------------
# Training loss: 0.082511
# Validation loss: 0.131958
#
# Epoch 457
# -------------------------------
# Training loss: 0.079926
# Validation loss: 0.078793
#
# Epoch 458
# -------------------------------
# Training loss: 0.081097
# Validation loss: 0.220140
#
# Epoch 459
# -------------------------------
# Training loss: 0.078456
# Validation loss: 0.090996
#
# Epoch 460
# -------------------------------
# Training loss: 0.081767
# Validation loss: 0.157663
#
# Epoch 461
# -------------------------------
# Training loss: 0.080946
# Validation loss: 0.078513
#
# Epoch 462
# -------------------------------
# Training loss: 0.079310
# Validation loss: 0.078199
#
# Epoch 463
# -------------------------------
# Training loss: 0.080293
# Validation loss: 0.095903
#
# Epoch 464
# -------------------------------
# Training loss: 0.084055
# Validation loss: 0.078549
#
# Epoch 465
# -------------------------------
# Training loss: 0.080863
# Validation loss: 0.080215
#
# Epoch 466
# -------------------------------
# Training loss: 0.079368
# Validation loss: 0.072318
#
# Epoch 467
# -------------------------------
# Training loss: 0.079296
# Validation loss: 0.090157
#
# Epoch 468
# -------------------------------
# Training loss: 0.081818
# Validation loss: 0.075725
#
# Epoch 469
# -------------------------------
# Training loss: 0.080021
# Validation loss: 0.077246
#
# Epoch 470
# -------------------------------
# Training loss: 0.078751
# Validation loss: 0.068965
#
# Epoch 471
# -------------------------------
# Training loss: 0.078656
# Validation loss: 0.075099
#
# Epoch 472
# -------------------------------
# Training loss: 0.077998
# Validation loss: 0.070711
#
# Epoch 473
# -------------------------------
# Training loss: 0.077410
# Validation loss: 0.133846
#
# Epoch 474
# -------------------------------
# Training loss: 0.077951
# Validation loss: 0.087380
#
# Epoch 475
# -------------------------------
# Training loss: 0.077836
# Validation loss: 0.090805
#
# Epoch 476
# -------------------------------
# Training loss: 0.078508
# Validation loss: 0.072673
#
# Epoch 477
# -------------------------------
# Training loss: 0.080598
# Validation loss: 0.071804
#
# Epoch 478
# -------------------------------
# Training loss: 0.080928
# Validation loss: 0.088357
#
# Epoch 479
# -------------------------------
# Training loss: 0.077913
# Validation loss: 0.073489
#
# Epoch 480
# -------------------------------
# Training loss: 0.076502
# Validation loss: 0.070394
#
# Epoch 481
# -------------------------------
# Training loss: 0.080133
# Validation loss: 0.109495
#
# Epoch 482
# -------------------------------
# Training loss: 0.080301
# Validation loss: 0.075516
#
# Epoch 483
# -------------------------------
# Training loss: 0.076709
# Validation loss: 0.077114
#
# Epoch 484
# -------------------------------
# Training loss: 0.078436
# Validation loss: 0.091222
#
# Epoch 485
# -------------------------------
# Training loss: 0.077909
# Validation loss: 0.075225
#
# Epoch 486
# -------------------------------
# Training loss: 0.076526
# Validation loss: 0.072929
#
# Epoch 487
# -------------------------------
# Training loss: 0.074173
# Validation loss: 0.073969
#
# Epoch 488
# -------------------------------
# Training loss: 0.081057
# Validation loss: 0.101600
#
# Epoch 489
# -------------------------------
# Training loss: 0.080306
# Validation loss: 0.083332
#
# Epoch 490
# -------------------------------
# Training loss: 0.079396
# Validation loss: 0.074986
#
# Epoch 491
# -------------------------------
# Training loss: 0.076911
# Validation loss: 0.075314
#
# Epoch 492
# -------------------------------
# Training loss: 0.077811
# Validation loss: 0.068394
#
# Epoch 493
# -------------------------------
# Training loss: 0.075265
# Validation loss: 0.071525
#
# Epoch 494
# -------------------------------
# Training loss: 0.074481
# Validation loss: 0.082455
#
# Epoch 495
# -------------------------------
# Training loss: 0.074423
# Validation loss: 0.071356
#
# Epoch 496
# -------------------------------
# Training loss: 0.073895
# Validation loss: 0.067827
#
# Epoch 497
# -------------------------------
# Training loss: 0.075289
# Validation loss: 0.071755
#
# Epoch 498
# -------------------------------
# Training loss: 0.079660
# Validation loss: 0.070799
#
# Epoch 499
# -------------------------------
# Training loss: 0.078285
# Validation loss: 0.072329
#
# Epoch 500
# -------------------------------
# Training loss: 0.073903
# Validation loss: 0.074038
#
# Done!

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses)+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('BCE Loss')
#plt.yscale('log')
plt.legend()

# %%
# Now test the pretrained model
test_pred = mytools.test_clas(test_loader, final_classifier, device)
test_pred=torch.sigmoid(torch.tensor(test_pred)).numpy()


fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test, test_pred, pos_label=1)
auc_test = sklearn.metrics.auc(fpr, tpr)
print(f'Test AUROC: {auc_test:0.4f}')

plt.plot(fpr, tpr, label=f'Test AUROC: {auc_test:0.4f}')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
# Out:
# Test AUROC: 0.9928

# %%
# Store the pretrained classifier labels
df_test["Class_pre"] = test_pred

# Save the pretrained classifier model
torch.save(final_classifier.state_dict(), "/Users/mghrear/data/ML_data/patch/pretrained_classifier_run"+str(run)+"_limited_sideband_a.pt")

# %% [markdown]
# # Setup the adversary model

# %% [markdown]
# ## Initialize model, objective function, and optimizer

# %%
adv = mytools.Adversary(n_classes=Num_classes).to(device)
criterion_adv = nn.CrossEntropyLoss(reduction='none')  # returns loss per sample so we can weight it
opt_adv = torch.optim.Adam(adv.parameters(), lr=1e-5)
scheduler_adv = torch.optim.lr_scheduler.ExponentialLR(opt_adv, gamma=0.999)

# %% [markdown]
# ## Setup dataloaders

# %%
# Convert to tensor dataset and dataloader

# the structure is: feature, adversary label, weight
# The wight is 1 for tritrig and wab, and 0 for phiKK, to prevent the adversary from learning on phiKK events

train_adv_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_train), (torch.from_numpy(y_train.to_numpy().astype(np.float32))==0).float())
train_adv_loader = DataLoader(train_adv_dataset, batch_size=bsize, shuffle=True)

val_adv_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_val), (torch.from_numpy(y_val.to_numpy().astype(np.float32))==0).float() )
val_adv_loader = DataLoader(val_adv_dataset, batch_size=bsize, shuffle=True)

# %% [markdown]
# ## Pre-train the adversary leaving classifier weights fixed

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 6

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 100
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train_adv(train_adv_loader, final_classifier, adv, criterion_adv, opt_adv, scheduler_adv, device))
    Validation_losses = np.append(Validation_losses, mytools.validate_adv(val_adv_loader, final_classifier, adv, criterion_adv, device))
    
    # Keep a running copy of the model with the lowest loss
    if Validation_losses[-1] == np.min(Validation_losses):
        final_adv = copy.deepcopy(adv)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Training loss: 1.558869
# Validation loss: 1.547377
#
# Epoch 2
# -------------------------------
# Training loss: 1.536403
# Validation loss: 1.527777
#
# Epoch 3
# -------------------------------
# Training loss: 1.520506
# Validation loss: 1.511226
#
# Epoch 4
# -------------------------------
# Training loss: 1.511660
# Validation loss: 1.503907
#
# Epoch 5
# -------------------------------
# Training loss: 1.504999
# Validation loss: 1.497997
#
# Epoch 6
# -------------------------------
# Training loss: 1.499880
# Validation loss: 1.493963
#
# Epoch 7
# -------------------------------
# Training loss: 1.496450
# Validation loss: 1.489910
#
# Epoch 8
# -------------------------------
# Training loss: 1.492601
# Validation loss: 1.487097
#
# Epoch 9
# -------------------------------
# Training loss: 1.489852
# Validation loss: 1.484713
#
# Epoch 10
# -------------------------------
# Training loss: 1.487864
# Validation loss: 1.482572
#
# Epoch 11
# -------------------------------
# Training loss: 1.485647
# Validation loss: 1.480756
#
# Epoch 12
# -------------------------------
# Training loss: 1.484847
# Validation loss: 1.479418
#
# Epoch 13
# -------------------------------
# Training loss: 1.483201
# Validation loss: 1.477568
#
# Epoch 14
# -------------------------------
# Training loss: 1.481615
# Validation loss: 1.476308
#
# Epoch 15
# -------------------------------
# Training loss: 1.479795
# Validation loss: 1.474835
#
# Epoch 16
# -------------------------------
# Training loss: 1.479775
# Validation loss: 1.473590
#
# Epoch 17
# -------------------------------
# Training loss: 1.476744
# Validation loss: 1.472539
#
# Epoch 18
# -------------------------------
# Training loss: 1.475757
# Validation loss: 1.470872
#
# Epoch 19
# -------------------------------
# Training loss: 1.475442
# Validation loss: 1.469800
#
# Epoch 20
# -------------------------------
# Training loss: 1.473559
# Validation loss: 1.468927
#
# Epoch 21
# -------------------------------
# Training loss: 1.472636
# Validation loss: 1.467689
#
# Epoch 22
# -------------------------------
# Training loss: 1.470903
# Validation loss: 1.466960
#
# Epoch 23
# -------------------------------
# Training loss: 1.469663
# Validation loss: 1.465302
#
# Epoch 24
# -------------------------------
# Training loss: 1.468769
# Validation loss: 1.464806
#
# Epoch 25
# -------------------------------
# Training loss: 1.468238
# Validation loss: 1.463924
#
# Epoch 26
# -------------------------------
# Training loss: 1.468556
# Validation loss: 1.462629
#
# Epoch 27
# -------------------------------
# Training loss: 1.466990
# Validation loss: 1.461962
#
# Epoch 28
# -------------------------------
# Training loss: 1.464469
# Validation loss: 1.461450
#
# Epoch 29
# -------------------------------
# Training loss: 1.464979
# Validation loss: 1.460586
#
# Epoch 30
# -------------------------------
# Training loss: 1.464024
# Validation loss: 1.460454
#
# Epoch 31
# -------------------------------
# Training loss: 1.465192
# Validation loss: 1.460068
#
# Epoch 32
# -------------------------------
# Training loss: 1.462376
# Validation loss: 1.458759
#
# Epoch 33
# -------------------------------
# Training loss: 1.463007
# Validation loss: 1.458784
#
# Epoch 34
# -------------------------------
# Training loss: 1.462930
# Validation loss: 1.458106
#
# Epoch 35
# -------------------------------
# Training loss: 1.459988
# Validation loss: 1.457454
#
# Epoch 36
# -------------------------------
# Training loss: 1.461288
# Validation loss: 1.457680
#
# Epoch 37
# -------------------------------
# Training loss: 1.461114
# Validation loss: 1.457815
#
# Epoch 38
# -------------------------------
# Training loss: 1.460619
# Validation loss: 1.457315
#
# Epoch 39
# -------------------------------
# Training loss: 1.460318
# Validation loss: 1.456064
#
# Epoch 40
# -------------------------------
# Training loss: 1.459181
# Validation loss: 1.455752
#
# Epoch 41
# -------------------------------
# Training loss: 1.459722
# Validation loss: 1.455399
#
# Epoch 42
# -------------------------------
# Training loss: 1.459922
# Validation loss: 1.455084
#
# Epoch 43
# -------------------------------
# Training loss: 1.459568
# Validation loss: 1.454682
#
# Epoch 44
# -------------------------------
# Training loss: 1.459033
# Validation loss: 1.455654
#
# Epoch 45
# -------------------------------
# Training loss: 1.458457
# Validation loss: 1.454761
#
# Epoch 46
# -------------------------------
# Training loss: 1.457528
# Validation loss: 1.454797
#
# Epoch 47
# -------------------------------
# Training loss: 1.457744
# Validation loss: 1.453840
#
# Epoch 48
# -------------------------------
# Training loss: 1.458820
# Validation loss: 1.453374
#
# Epoch 49
# -------------------------------
# Training loss: 1.457286
# Validation loss: 1.453375
#
# Epoch 50
# -------------------------------
# Training loss: 1.457372
# Validation loss: 1.454388
#
# Epoch 51
# -------------------------------
# Training loss: 1.457264
# Validation loss: 1.453599
#
# Epoch 52
# -------------------------------
# Training loss: 1.457788
# Validation loss: 1.452887
#
# Epoch 53
# -------------------------------
# Training loss: 1.455152
# Validation loss: 1.452903
#
# Epoch 54
# -------------------------------
# Training loss: 1.457270
# Validation loss: 1.453153
#
# Epoch 55
# -------------------------------
# Training loss: 1.457517
# Validation loss: 1.453613
#
# Epoch 56
# -------------------------------
# Training loss: 1.456072
# Validation loss: 1.452598
#
# Epoch 57
# -------------------------------
# Training loss: 1.456295
# Validation loss: 1.452636
#
# Epoch 58
# -------------------------------
# Training loss: 1.455980
# Validation loss: 1.452205
#
# Epoch 59
# -------------------------------
# Training loss: 1.456729
# Validation loss: 1.452552
#
# Epoch 60
# -------------------------------
# Training loss: 1.456038
# Validation loss: 1.452260
#
# Epoch 61
# -------------------------------
# Training loss: 1.455126
# Validation loss: 1.452019
#
# Epoch 62
# -------------------------------
# Training loss: 1.455493
# Validation loss: 1.451427
#
# Epoch 63
# -------------------------------
# Training loss: 1.455855
# Validation loss: 1.451903
#
# Epoch 64
# -------------------------------
# Training loss: 1.455954
# Validation loss: 1.451291
#
# Epoch 65
# -------------------------------
# Training loss: 1.455924
# Validation loss: 1.451211
#
# Epoch 66
# -------------------------------
# Training loss: 1.454308
# Validation loss: 1.451263
#
# Epoch 67
# -------------------------------
# Training loss: 1.455339
# Validation loss: 1.451404
#
# Epoch 68
# -------------------------------
# Training loss: 1.455056
# Validation loss: 1.451245
#
# Epoch 69
# -------------------------------
# Training loss: 1.455611
# Validation loss: 1.451479
#
# Epoch 70
# -------------------------------
# Training loss: 1.455018
# Validation loss: 1.450886
#
# Epoch 71
# -------------------------------
# Training loss: 1.453533
# Validation loss: 1.450589
#
# Epoch 72
# -------------------------------
# Training loss: 1.454879
# Validation loss: 1.450700
#
# Epoch 73
# -------------------------------
# Training loss: 1.454050
# Validation loss: 1.451147
#
# Epoch 74
# -------------------------------
# Training loss: 1.453309
# Validation loss: 1.450859
#
# Epoch 75
# -------------------------------
# Training loss: 1.454696
# Validation loss: 1.450788
#
# Epoch 76
# -------------------------------
# Training loss: 1.454161
# Validation loss: 1.450565
#
# Epoch 77
# -------------------------------
# Training loss: 1.454472
# Validation loss: 1.450422
#
# Epoch 78
# -------------------------------
# Training loss: 1.453444
# Validation loss: 1.450865
#
# Epoch 79
# -------------------------------
# Training loss: 1.453212
# Validation loss: 1.450450
#
# Epoch 80
# -------------------------------
# Training loss: 1.454123
# Validation loss: 1.450523
#
# Epoch 81
# -------------------------------
# Training loss: 1.454537
# Validation loss: 1.449968
#
# Epoch 82
# -------------------------------
# Training loss: 1.456093
# Validation loss: 1.450265
#
# Epoch 83
# -------------------------------
# Training loss: 1.453933
# Validation loss: 1.450459
#
# Epoch 84
# -------------------------------
# Training loss: 1.455385
# Validation loss: 1.450325
#
# Epoch 85
# -------------------------------
# Training loss: 1.453000
# Validation loss: 1.449999
#
# Epoch 86
# -------------------------------
# Training loss: 1.453606
# Validation loss: 1.449781
#
# Epoch 87
# -------------------------------
# Training loss: 1.453873
# Validation loss: 1.450231
#
# Epoch 88
# -------------------------------
# Training loss: 1.453647
# Validation loss: 1.449962
#
# Epoch 89
# -------------------------------
# Training loss: 1.453162
# Validation loss: 1.450110
#
# Epoch 90
# -------------------------------
# Training loss: 1.452957
# Validation loss: 1.450239
#
# Epoch 91
# -------------------------------
# Training loss: 1.452406
# Validation loss: 1.450637
#
# Epoch 92
# -------------------------------
# Training loss: 1.452728
# Validation loss: 1.449805
#
# Epoch 93
# -------------------------------
# Training loss: 1.453956
# Validation loss: 1.449386
#
# Epoch 94
# -------------------------------
# Training loss: 1.454784
# Validation loss: 1.450361
#
# Epoch 95
# -------------------------------
# Training loss: 1.452930
# Validation loss: 1.449516
#
# Epoch 96
# -------------------------------
# Training loss: 1.453805
# Validation loss: 1.450032
#
# Epoch 97
# -------------------------------
# Training loss: 1.453351
# Validation loss: 1.449442
#
# Epoch 98
# -------------------------------
# Training loss: 1.453245
# Validation loss: 1.449898
#
# Epoch 99
# -------------------------------
# Training loss: 1.454186
# Validation loss: 1.450032
#
# Epoch 100
# -------------------------------
# Training loss: 1.453731
# Validation loss: 1.449567
#
# Done!

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses)+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('BCE Loss')
plt.legend()

# %% [markdown]
# # Train full adverserial neural network

# %% [markdown]
# # Setup dataloaders

# %%
# the structure is: feature, classifier label, adversary label, weight
# The wight is 1 for tritrig and wab, and 0 for phiKK, to prevent the adversary from learning on phiKK events

train_full_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy().astype(np.float32))  , torch.from_numpy(y_train.to_numpy().astype(np.float32)).unsqueeze(1), torch.from_numpy(y_adv_train),  (torch.from_numpy(y_train.to_numpy().astype(np.float32))==0).float())
train_full_loader = DataLoader(train_full_dataset, batch_size=bsize, shuffle=True)

val_full_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy().astype(np.float32))  , torch.from_numpy(y_val.to_numpy().astype(np.float32)).unsqueeze(1),  torch.from_numpy(y_adv_val),  (torch.from_numpy(y_val.to_numpy().astype(np.float32))==0).float())
val_full_loader = DataLoader(val_full_dataset, batch_size=bsize, shuffle=True)

# %% [markdown]
# ## Define loss functions

# %%
BCE_loss = nn.BCEWithLogitsLoss()
CE_loss = nn.CrossEntropyLoss(reduction='none') # returns loss per sample so we can weight it

def full_loss(output_clas, output_adv, target_clas, target_adv, w, lambda_):

    loss1 = BCE_loss(output_clas, target_clas )  # classification loss
    sample_losses2 = CE_loss(output_adv, target_adv)  # adversarial losses, since we set reduction='none', this is now a vector of losses, one per sample in the batch

     # Weighted mean loss over non-zero weights
    nonzero = w > 0
    loss2 = (sample_losses2[nonzero] * w[nonzero]).sum() / w[nonzero].sum()

    loss = loss1 - lambda_*loss2

    return loss

# %% [markdown]
# ## Setup optimizers

# %%
optimizer_clas = optim.Adam(final_classifier.parameters(), lr=1e-7,betas=(0.5, 0.999))
optimizer_adv = optim.Adam(final_adv.parameters(), lr=1e-5,betas=(0.5, 0.999))

scheduler_clas = torch.optim.lr_scheduler.ExponentialLR(optimizer_clas, gamma=0.999)
scheduler_adv = torch.optim.lr_scheduler.ExponentialLR(optimizer_adv, gamma=0.999)

# %% [markdown]
# ## Adversarial training

# %%
Training_losses_clas = np.array([])
Training_losses_adv = np.array([])
Validation_losses_clas = np.array([])
Validation_losses_adv = np.array([])
diff_scores = np.array([])


epochs = 50
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")

    # Get validation losses
    E_clas_val_loss, E_adv_val_loss = mytools.validate_full(val_full_loader, final_classifier, final_adv, full_loss, lambda_, criterion_adv, device)
    Validation_losses_clas = np.append(Validation_losses_clas, E_clas_val_loss)
    Validation_losses_adv = np.append(Validation_losses_adv, E_adv_val_loss)

    # Train adversary and classifier
    E_clas_training_loss , E_adv_training_loss = mytools.train_full(train_full_loader, final_classifier, final_adv, full_loss, lambda_, criterion_adv, optimizer_clas, optimizer_adv, scheduler_clas, scheduler_adv, device)
    Training_losses_clas = np.append(Training_losses_clas, E_clas_training_loss)
    Training_losses_adv = np.append(Training_losses_adv, E_adv_training_loss)

    # Get the diff_score
    df_test["Class_adv"] = mytools.test_clas(test_loader, final_classifier, device)
    df_bkg = df_test.loc[ (df_test.type == 'tritrig') | (df_test.type == 'wab')]
    per = np.percentile(df_bkg['Class_adv'],99)
    df_cut = df_bkg[df_bkg['Class_adv']>per].reset_index(drop=True)
    x1 = 1000* df_bkg.InvM.values
    x2 = 1000*df_cut.InvM.values
    diff_scores = np.append(diff_scores, mytools.get_diff_score(x1,x2) )

    # Keep a running copy of the model with the lowest loss
    if diff_scores[-1] == np.min(diff_scores):
        final_clas_adv = copy.deepcopy(final_classifier)
        final_adv_adv = copy.deepcopy(final_adv)

            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Classifier validation loss: -144.870955
# Adversary validation loss: 1.449394
# Classifier training loss: -148.292033
# Adversary training loss: 1.484784
# Epoch 2
# -------------------------------
# Classifier validation loss: -149.090858
# Adversary validation loss: 1.491654
# Classifier training loss: -150.095676
# Adversary training loss: 1.502437
# Epoch 3
# -------------------------------
# Classifier validation loss: -150.181275
# Adversary validation loss: 1.502654
# Classifier training loss: -150.150950
# Adversary training loss: 1.502817
# Epoch 4
# -------------------------------
# Classifier validation loss: -149.685497
# Adversary validation loss: 1.497740
# Classifier training loss: -149.743593
# Adversary training loss: 1.498789
# Epoch 5
# -------------------------------
# Classifier validation loss: -149.431256
# Adversary validation loss: 1.495260
# Classifier training loss: -149.504746
# Adversary training loss: 1.496606
# Epoch 6
# -------------------------------
# Classifier validation loss: -149.056677
# Adversary validation loss: 1.491687
# Classifier training loss: -149.573124
# Adversary training loss: 1.497676
# Epoch 7
# -------------------------------
# Classifier validation loss: -149.723466
# Adversary validation loss: 1.498691
# Classifier training loss: -149.875779
# Adversary training loss: 1.501046
# Epoch 8
# -------------------------------
# Classifier validation loss: -149.732183
# Adversary validation loss: 1.499104
# Classifier training loss: -149.911843
# Adversary training loss: 1.501670
# Epoch 9
# -------------------------------
# Classifier validation loss: -148.964684
# Adversary validation loss: 1.491720
# Classifier training loss: -149.477318
# Adversary training loss: 1.497550
# Epoch 10
# -------------------------------
# Classifier validation loss: -148.698967
# Adversary validation loss: 1.489206
# Classifier training loss: -149.000122
# Adversary training loss: 1.492862
# Epoch 11
# -------------------------------
# Classifier validation loss: -148.615349
# Adversary validation loss: 1.488528
# Classifier training loss: -148.693649
# Adversary training loss: 1.489890
# Epoch 12
# -------------------------------
# Classifier validation loss: -148.669118
# Adversary validation loss: 1.489141
# Classifier training loss: -148.059070
# Adversary training loss: 1.483546
# Epoch 13
# -------------------------------
# Classifier validation loss: -147.624902
# Adversary validation loss: 1.478602
# Classifier training loss: -147.607860
# Adversary training loss: 1.479112
# Epoch 14
# -------------------------------
# Classifier validation loss: -147.261955
# Adversary validation loss: 1.475092
# Classifier training loss: -147.264603
# Adversary training loss: 1.475662
# Epoch 15
# -------------------------------
# Classifier validation loss: -147.413656
# Adversary validation loss: 1.476669
# Classifier training loss: -147.033559
# Adversary training loss: 1.473305
# Epoch 16
# -------------------------------
# Classifier validation loss: -146.978614
# Adversary validation loss: 1.472269
# Classifier training loss: -146.978387
# Adversary training loss: 1.472762
# Epoch 17
# -------------------------------
# Classifier validation loss: -147.233415
# Adversary validation loss: 1.474790
# Classifier training loss: -146.881856
# Adversary training loss: 1.471776
# Epoch 18
# -------------------------------
# Classifier validation loss: -147.353249
# Adversary validation loss: 1.475830
# Classifier training loss: -146.949281
# Adversary training loss: 1.472403
# Epoch 19
# -------------------------------
# Classifier validation loss: -147.552062
# Adversary validation loss: 1.477859
# Classifier training loss: -147.351939
# Adversary training loss: 1.476419
# Epoch 20
# -------------------------------
# Classifier validation loss: -147.700223
# Adversary validation loss: 1.479322
# Classifier training loss: -147.958662
# Adversary training loss: 1.482451
# Epoch 21
# -------------------------------
# Classifier validation loss: -148.385110
# Adversary validation loss: 1.486043
# Classifier training loss: -148.268583
# Adversary training loss: 1.485504
# Epoch 22
# -------------------------------
# Classifier validation loss: -148.555826
# Adversary validation loss: 1.487760
# Classifier training loss: -148.702493
# Adversary training loss: 1.489848
# Epoch 23
# -------------------------------
# Classifier validation loss: -148.774055
# Adversary validation loss: 1.490102
# Classifier training loss: -149.218600
# Adversary training loss: 1.494961
# Epoch 24
# -------------------------------
# Classifier validation loss: -150.008613
# Adversary validation loss: 1.502696
# Classifier training loss: -149.082230
# Adversary training loss: 1.493561
# Epoch 25
# -------------------------------
# Classifier validation loss: -149.114421
# Adversary validation loss: 1.493416
# Classifier training loss: -149.232887
# Adversary training loss: 1.495083
# Epoch 26
# -------------------------------
# Classifier validation loss: -149.093145
# Adversary validation loss: 1.493078
# Classifier training loss: -149.272399
# Adversary training loss: 1.495485
# Epoch 27
# -------------------------------
# Classifier validation loss: -148.855037
# Adversary validation loss: 1.490983
# Classifier training loss: -149.248844
# Adversary training loss: 1.495210
# Epoch 28
# -------------------------------
# Classifier validation loss: -149.092932
# Adversary validation loss: 1.493400
# Classifier training loss: -149.151959
# Adversary training loss: 1.494340
# Epoch 29
# -------------------------------
# Classifier validation loss: -148.939526
# Adversary validation loss: 1.491680
# Classifier training loss: -149.094985
# Adversary training loss: 1.493735
# Epoch 30
# -------------------------------
# Classifier validation loss: -148.702522
# Adversary validation loss: 1.489428
# Classifier training loss: -148.982400
# Adversary training loss: 1.492651
# Epoch 31
# -------------------------------
# Classifier validation loss: -148.564900
# Adversary validation loss: 1.488315
# Classifier training loss: -148.809419
# Adversary training loss: 1.490858
# Epoch 32
# -------------------------------
# Classifier validation loss: -148.319796
# Adversary validation loss: 1.485726
# Classifier training loss: -148.764152
# Adversary training loss: 1.490411
# Epoch 33
# -------------------------------
# Classifier validation loss: -148.265121
# Adversary validation loss: 1.485140
# Classifier training loss: -148.425992
# Adversary training loss: 1.486983
# Epoch 34
# -------------------------------
# Classifier validation loss: -148.174753
# Adversary validation loss: 1.484171
# Classifier training loss: -148.438887
# Adversary training loss: 1.487108
# Epoch 35
# -------------------------------
# Classifier validation loss: -147.891363
# Adversary validation loss: 1.481539
# Classifier training loss: -148.337199
# Adversary training loss: 1.486032
# Epoch 36
# -------------------------------
# Classifier validation loss: -147.855745
# Adversary validation loss: 1.480909
# Classifier training loss: -148.181319
# Adversary training loss: 1.484445
# Epoch 37
# -------------------------------
# Classifier validation loss: -147.797403
# Adversary validation loss: 1.480373
# Classifier training loss: -148.239829
# Adversary training loss: 1.485020
# Epoch 38
# -------------------------------
# Classifier validation loss: -147.648007
# Adversary validation loss: 1.478583
# Classifier training loss: -148.105441
# Adversary training loss: 1.483651
# Epoch 39
# -------------------------------
# Classifier validation loss: -147.599103
# Adversary validation loss: 1.478456
# Classifier training loss: -147.940635
# Adversary training loss: 1.481979
# Epoch 40
# -------------------------------
# Classifier validation loss: -147.695240
# Adversary validation loss: 1.479348
# Classifier training loss: -148.133960
# Adversary training loss: 1.483920
# Epoch 41
# -------------------------------
# Classifier validation loss: -147.588237
# Adversary validation loss: 1.478180
# Classifier training loss: -148.029353
# Adversary training loss: 1.482849
# Epoch 42
# -------------------------------
# Classifier validation loss: -147.525188
# Adversary validation loss: 1.477471
# Classifier training loss: -147.962140
# Adversary training loss: 1.482133
# Epoch 43
# -------------------------------
# Classifier validation loss: -147.676921
# Adversary validation loss: 1.478992
# Classifier training loss: -148.029007
# Adversary training loss: 1.482827
# Epoch 44
# -------------------------------
# Classifier validation loss: -147.554283
# Adversary validation loss: 1.477755
# Classifier training loss: -147.948148
# Adversary training loss: 1.482025
# Epoch 45
# -------------------------------
# Classifier validation loss: -147.745768
# Adversary validation loss: 1.479707
# Classifier training loss: -148.050112
# Adversary training loss: 1.483022
# Epoch 46
# -------------------------------
# Classifier validation loss: -147.560263
# Adversary validation loss: 1.477717
# Classifier training loss: -147.986016
# Adversary training loss: 1.482354
# Epoch 47
# -------------------------------
# Classifier validation loss: -147.666952
# Adversary validation loss: 1.478986
# Classifier training loss: -148.043902
# Adversary training loss: 1.482930
# Epoch 48
# -------------------------------
# Classifier validation loss: -147.499463
# Adversary validation loss: 1.477038
# Classifier training loss: -148.027666
# Adversary training loss: 1.482720
# Epoch 49
# -------------------------------
# Classifier validation loss: -147.427511
# Adversary validation loss: 1.476387
# Classifier training loss: -148.001271
# Adversary training loss: 1.482482
# Epoch 50
# -------------------------------
# Classifier validation loss: -147.809967
# Adversary validation loss: 1.480495
# Classifier training loss: -147.967288
# Adversary training loss: 1.482108
# Done!

# %%
fig, ax1 = plt.subplots()

best_epoch = np.argmin(diff_scores)+1



#ax1.plot(np.arange(len(Training_losses_adv))+1, Training_losses_adv, 'k-', label='Training Adversary')
ax1.plot(np.arange(len(Validation_losses_adv))+1, Validation_losses_adv, 'k-', label='Validation Adversary')

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Adversary Loss', color='k')
ax1.tick_params(axis='y', labelcolor='k')

ax2 = ax1.twinx()

#ax2.plot(np.arange(len(Training_losses_clas))+1, Training_losses_clas, 'r-', label='Training Classifier')
ax2.plot(np.arange(len(Validation_losses_clas))+1, Validation_losses_clas, 'r-', label='Validation Classifier')
ax2.axvline(best_epoch,label="Final model stopped here",color='k')

ax2.set_ylabel('Classifier Loss', color='r')
ax2.tick_params(axis='y', labelcolor='r')

# %% [markdown]
# ## Test adversarially trained models

# %%
# Now test the pretrained model
test_pred = mytools.test_clas(test_loader, final_clas_adv, device)
test_pred=torch.sigmoid(torch.tensor(test_pred)).numpy()


fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test, test_pred, pos_label=1)
auc_test = sklearn.metrics.auc(fpr, tpr)
print(f'Test AUROC: {auc_test:0.4f}')

plt.plot(fpr, tpr, label=f'Test AUROC: {auc_test:0.4f}')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
# Out:
# Test AUROC: 0.9887

# %%
df_test["Class_adv"] = test_pred
df_bkg = df_test.loc[ (df_test.type == 'tritrig') | (df_test.type == 'wab')]
per = np.percentile(df_bkg['Class_adv'],99)
df_cut = df_bkg[df_bkg['Class_adv']>per].reset_index(drop=True)
x_vals = 1000*df_cut.InvM

plt.figure()
plt.hist(1000*df_bkg.InvM, bins=np.arange(980,1250,1), histtype='step', label='No selection', density=True)
plt.hist(x_vals, bins=np.arange(980,1250,1), histtype='step', label= '99 percent selection', density=True)
plt.axvline(1019.461, color='k', linestyle='dashed', linewidth=1, label='PDG phi mass')
plt.xlabel('Invariant Mass [MeV]')
plt.ylabel('Normalized Counts')
plt.legend()

# %%
x1 = 1000* df_bkg.InvM.values
x2 = 1000*df_cut.InvM.values

N, edges = np.histogram(x1, bins=np.arange(980,1250,1), density=False)
M, edges = np.histogram(x2, bins=np.arange(980,1250,1), density=False)

N2 = N[(N > 0) & (M > 0)]
M2 = M[(N > 0) & (M > 0)]

diff_score = np.mean(np.abs(N2/np.sum(N)-M2/np.sum(M)) / (np.sqrt(N2)/np.sum(N) + np.sqrt(M2)/np.sum(M) ))

print(diff_score)

N = len(df_test.loc[ ((df_test.type == 'tritrig') | (df_test.type == 'wab')) & (df_test.InvM < (1.019 + 0.01) )  & (df_test.InvM > (1.019 - 0.01) ) & ( df_test['Class_adv']>per ) ] )
S = len(df_test.loc[ (df_test.type == 'phiKK') & (df_test.InvM < (1.019 + 0.01) )  & (df_test.InvM > (1.019 - 0.01) ) & ( df_test['Class_adv']>per )  ] )

print(S/N)
# Out:
# 0.7475304749172598
# 6.918163672654691

# %%
df_test["Class_adv"] = test_pred
df_test.to_pickle("/Users/mghrear/data/ML_data/patch/ANN_results_relu_run"+str(run)+"_limited_sideband_a.pk")

# %%
# Save the adversarially trained models
torch.save(final_clas_adv.state_dict(), "/Users/mghrear/data/ML_data/patch/classifier_adv_relu_run"+str(run)+"_limited_sideband_a.pt")
torch.save(final_adv_adv.state_dict(), "/Users/mghrear/data/ML_data/patch/adversary_adv_relu_run"+str(run)+"_limited_sideband_a.pt")

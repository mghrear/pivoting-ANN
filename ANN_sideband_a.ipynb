# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import torch 
from torch import nn, optim
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import sklearn
from sklearn.model_selection import train_test_split
import copy
import mytools
from scipy.stats import ks_2samp, wasserstein_distance


# Print and store device being used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cpu

# %% [markdown]
# # Define important parameters

# %%
# Number of class in invariant mass used by the adversary
Num_classes = 5
# Hyper-parameter for adversarial training of the classifier
lambda_ = 100.0

run = 1

# %% [markdown]
# # Load and setup the data

# %%
df_tritrig = pd.read_pickle('/Users/mghrear/data/ML_data/patch/2021_v9_pass5_tritrig_limited.pk')
df_tritrig['PhiKK'] = 0.0 # Add label
df_phiKK = pd.read_pickle('/Users/mghrear/data/ML_data/patch/2021_v9_pass5_phiKK_limited.pk')
df_phiKK['PhiKK'] = 1.0 # Add label
df_wab = pd.read_pickle('/Users/mghrear/data/ML_data/patch/2021_v9_pass5_wab_limited.pk')
df_wab['PhiKK'] = 0.0 # Add label

df_data_train_bkg = pd.read_pickle('/Users/mghrear/data/ML_data/patch/2021_v9_pass5_data_limited_sideband_a_train_bkg.pk')
df_data_train_bkg['PhiKK'] = 0.0 # Add label

df_data = pd.read_pickle('/Users/mghrear/data/ML_data/patch/2021_v9_pass5_data_limited_sideband_a_test.pk')

print("phiKK: ", len(df_phiKK))
print("data bkg: ", len(df_data_train_bkg))
print("data: ", len(df_data))
# Out:
# phiKK:  4086
# data bkg:  23995
# data:  163958

# %%
phiKK_train = df_phiKK[0:3000]


# Combine and shuffle all training data
df_train = pd.concat([phiKK_train, df_data_train_bkg], ignore_index=True, sort=False)
df_train = df_train.sample(frac=1, random_state=42).reset_index(drop=True)

# Get edges in invariant mass classes for one-hot encoding
# To be used for adverserial labels
# The edges are chosen such that each bin has equal number of background events
one_hot_edges = mytools.get_one_hot_edges(mytools.get_InvM( df_data ), n_bins=Num_classes)

# Split the training data into training and validation sets
df_train, df_val = train_test_split(df_train, test_size=0.33, random_state=41)

# Make X and y for training and validation sets
# the adverserial network has its own labels
X_train = df_train.drop(columns=['PhiKK'])
y_train = df_train['PhiKK']
y_adv_train = mytools.get_adv_labels( mytools.get_InvM(df_train), one_hot_edges)
X_val = df_val.drop(columns=['PhiKK'])
y_val = df_val['PhiKK']
y_adv_val = mytools.get_adv_labels( mytools.get_InvM(df_val), one_hot_edges)

# Make testing set with remaining events
tritrig_test = df_tritrig[20000:]
tritrig_test['type']= 'tritrig'
wab_test = df_wab[3000:]
wab_test['type']= 'wab'
phiKK_test = df_phiKK[3000:]
phiKK_test['type']= 'phiKK'

# This is just used for an invariance test
df_test = pd.concat([tritrig_test, phiKK_test,wab_test], ignore_index=True, sort=False)
df_test = df_test.sample(frac=1, random_state=42).reset_index(drop=True) # Now shuffle the combined dataframe

X_test = df_test.drop(columns=['PhiKK','type'])
y_test = df_test['PhiKK']
y_adv_test = mytools.get_adv_labels( mytools.get_InvM(df_test), one_hot_edges)

df_test["InvM"] = mytools.get_InvM(df_test) 



# Make final data set
X_final = df_data
# Out:
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_79702/3652916753.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tritrig_test['type']= 'tritrig'
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_79702/3652916753.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wab_test['type']= 'wab'
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_79702/3652916753.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phiKK_test['type']= 'phiKK'

# %% [markdown]
# # Setup the classifier model

# %% [markdown]
# ## Setup dataloaders

# %%
bsize = 512

# Convert to tensor dataset and dataloader
train_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy().astype(np.float32))  , torch.from_numpy(y_train.to_numpy().astype(np.float32)).unsqueeze(1)  )
train_loader = DataLoader(train_dataset, batch_size=bsize, shuffle=True)

val_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy().astype(np.float32))  , torch.from_numpy(y_val.to_numpy().astype(np.float32)).unsqueeze(1)  )
val_loader = DataLoader(val_dataset, batch_size=bsize, shuffle=True)

test_dataset = TensorDataset(torch.from_numpy(X_test.to_numpy().astype(np.float32))  )
test_loader = DataLoader(test_dataset, batch_size=bsize, shuffle=False)

# %% [markdown]
# ## Initialize model, objective function, and optimizer

# %%
clas = mytools.Classifier(in_features=X_train.shape[1]).to(device)
criterion_clas = nn.BCEWithLogitsLoss()
optimizer_clas = optim.Adam(clas.parameters(), lr=1e-5)
scheduler_clas = torch.optim.lr_scheduler.ExponentialLR(optimizer_clas, gamma=0.99995)

# %% [markdown]
# ## Pre-train the classifier

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 10

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 500
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train_clas(train_loader, clas, criterion_clas, optimizer_clas, scheduler_clas, device))
    Validation_losses = np.append(Validation_losses, mytools.validate_clas(val_loader, clas, criterion_clas, device))
    
    # Keep a running copy of the model with the lowest loss
    if Validation_losses[-1] == np.min(Validation_losses):
        final_classifier = copy.deepcopy(clas)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Training loss: 0.577126
# Validation loss: 0.573113
#
# Epoch 2
# -------------------------------
# Training loss: 0.540072
# Validation loss: 0.530379
#
# Epoch 3
# -------------------------------
# Training loss: 0.518770
# Validation loss: 0.514034
#
# Epoch 4
# -------------------------------
# Training loss: 0.506180
# Validation loss: 0.507176
#
# Epoch 5
# -------------------------------
# Training loss: 0.496738
# Validation loss: 0.485714
#
# Epoch 6
# -------------------------------
# Training loss: 0.483455
# Validation loss: 0.479621
#
# Epoch 7
# -------------------------------
# Training loss: 0.473834
# Validation loss: 0.469957
#
# Epoch 8
# -------------------------------
# Training loss: 0.468296
# Validation loss: 0.468569
#
# Epoch 9
# -------------------------------
# Training loss: 0.460004
# Validation loss: 0.460737
#
# Epoch 10
# -------------------------------
# Training loss: 0.454178
# Validation loss: 0.452474
#
# Epoch 11
# -------------------------------
# Training loss: 0.450034
# Validation loss: 0.450155
#
# Epoch 12
# -------------------------------
# Training loss: 0.442561
# Validation loss: 0.440688
#
# Epoch 13
# -------------------------------
# Training loss: 0.439144
# Validation loss: 0.434548
#
# Epoch 14
# -------------------------------
# Training loss: 0.436169
# Validation loss: 0.424827
#
# Epoch 15
# -------------------------------
# Training loss: 0.427804
# Validation loss: 0.419821
#
# Epoch 16
# -------------------------------
# Training loss: 0.423607
# Validation loss: 0.417715
#
# Epoch 17
# -------------------------------
# Training loss: 0.418493
# Validation loss: 0.409937
#
# Epoch 18
# -------------------------------
# Training loss: 0.416875
# Validation loss: 0.411778
#
# Epoch 19
# -------------------------------
# Training loss: 0.414713
# Validation loss: 0.404373
#
# Epoch 20
# -------------------------------
# Training loss: 0.410216
# Validation loss: 0.403898
#
# Epoch 21
# -------------------------------
# Training loss: 0.405221
# Validation loss: 0.394023
#
# Epoch 22
# -------------------------------
# Training loss: 0.403341
# Validation loss: 0.394465
#
# Epoch 23
# -------------------------------
# Training loss: 0.400452
# Validation loss: 0.393174
#
# Epoch 24
# -------------------------------
# Training loss: 0.397275
# Validation loss: 0.388126
#
# Epoch 25
# -------------------------------
# Training loss: 0.395171
# Validation loss: 0.386261
#
# Epoch 26
# -------------------------------
# Training loss: 0.393241
# Validation loss: 0.383155
#
# Epoch 27
# -------------------------------
# Training loss: 0.388707
# Validation loss: 0.384360
#
# Epoch 28
# -------------------------------
# Training loss: 0.385978
# Validation loss: 0.381754
#
# Epoch 29
# -------------------------------
# Training loss: 0.383840
# Validation loss: 0.383134
#
# Epoch 30
# -------------------------------
# Training loss: 0.382172
# Validation loss: 0.371091
#
# Epoch 31
# -------------------------------
# Training loss: 0.380224
# Validation loss: 0.379901
#
# Epoch 32
# -------------------------------
# Training loss: 0.378559
# Validation loss: 0.371526
#
# Epoch 33
# -------------------------------
# Training loss: 0.374625
# Validation loss: 0.379379
#
# Epoch 34
# -------------------------------
# Training loss: 0.373661
# Validation loss: 0.365658
#
# Epoch 35
# -------------------------------
# Training loss: 0.371718
# Validation loss: 0.363363
#
# Epoch 36
# -------------------------------
# Training loss: 0.370411
# Validation loss: 0.359464
#
# Epoch 37
# -------------------------------
# Training loss: 0.367168
# Validation loss: 0.363312
#
# Epoch 38
# -------------------------------
# Training loss: 0.366442
# Validation loss: 0.360212
#
# Epoch 39
# -------------------------------
# Training loss: 0.364791
# Validation loss: 0.362765
#
# Epoch 40
# -------------------------------
# Training loss: 0.363153
# Validation loss: 0.352566
#
# Epoch 41
# -------------------------------
# Training loss: 0.360087
# Validation loss: 0.360099
#
# Epoch 42
# -------------------------------
# Training loss: 0.357271
# Validation loss: 0.351540
#
# Epoch 43
# -------------------------------
# Training loss: 0.355009
# Validation loss: 0.353048
#
# Epoch 44
# -------------------------------
# Training loss: 0.354985
# Validation loss: 0.354459
#
# Epoch 45
# -------------------------------
# Training loss: 0.352393
# Validation loss: 0.345639
#
# Epoch 46
# -------------------------------
# Training loss: 0.352382
# Validation loss: 0.349979
#
# Epoch 47
# -------------------------------
# Training loss: 0.351348
# Validation loss: 0.344116
#
# Epoch 48
# -------------------------------
# Training loss: 0.347753
# Validation loss: 0.341779
#
# Epoch 49
# -------------------------------
# Training loss: 0.346547
# Validation loss: 0.341232
#
# Epoch 50
# -------------------------------
# Training loss: 0.344366
# Validation loss: 0.342448
#
# Epoch 51
# -------------------------------
# Training loss: 0.343411
# Validation loss: 0.335548
#
# Epoch 52
# -------------------------------
# Training loss: 0.344303
# Validation loss: 0.340693
#
# Epoch 53
# -------------------------------
# Training loss: 0.339348
# Validation loss: 0.338284
#
# Epoch 54
# -------------------------------
# Training loss: 0.338310
# Validation loss: 0.332896
#
# Epoch 55
# -------------------------------
# Training loss: 0.338321
# Validation loss: 0.330146
#
# Epoch 56
# -------------------------------
# Training loss: 0.335710
# Validation loss: 0.328567
#
# Epoch 57
# -------------------------------
# Training loss: 0.335504
# Validation loss: 0.332769
#
# Epoch 58
# -------------------------------
# Training loss: 0.335102
# Validation loss: 0.333591
#
# Epoch 59
# -------------------------------
# Training loss: 0.333019
# Validation loss: 0.332267
#
# Epoch 60
# -------------------------------
# Training loss: 0.330494
# Validation loss: 0.329192
#
# Epoch 61
# -------------------------------
# Training loss: 0.329419
# Validation loss: 0.326884
#
# Epoch 62
# -------------------------------
# Training loss: 0.329729
# Validation loss: 0.326041
#
# Epoch 63
# -------------------------------
# Training loss: 0.329571
# Validation loss: 0.331114
#
# Epoch 64
# -------------------------------
# Training loss: 0.327159
# Validation loss: 0.324252
#
# Epoch 65
# -------------------------------
# Training loss: 0.325711
# Validation loss: 0.326059
#
# Epoch 66
# -------------------------------
# Training loss: 0.324787
# Validation loss: 0.321690
#
# Epoch 67
# -------------------------------
# Training loss: 0.324683
# Validation loss: 0.327602
#
# Epoch 68
# -------------------------------
# Training loss: 0.323029
# Validation loss: 0.316536
#
# Epoch 69
# -------------------------------
# Training loss: 0.323320
# Validation loss: 0.318303
#
# Epoch 70
# -------------------------------
# Training loss: 0.319925
# Validation loss: 0.324403
#
# Epoch 71
# -------------------------------
# Training loss: 0.320952
# Validation loss: 0.315137
#
# Epoch 72
# -------------------------------
# Training loss: 0.317263
# Validation loss: 0.316458
#
# Epoch 73
# -------------------------------
# Training loss: 0.317709
# Validation loss: 0.313402
#
# Epoch 74
# -------------------------------
# Training loss: 0.315839
# Validation loss: 0.312826
#
# Epoch 75
# -------------------------------
# Training loss: 0.316249
# Validation loss: 0.319455
#
# Epoch 76
# -------------------------------
# Training loss: 0.314906
# Validation loss: 0.308652
#
# Epoch 77
# -------------------------------
# Training loss: 0.312860
# Validation loss: 0.310886
#
# Epoch 78
# -------------------------------
# Training loss: 0.312582
# Validation loss: 0.308853
#
# Epoch 79
# -------------------------------
# Training loss: 0.311565
# Validation loss: 0.311816
#
# Epoch 80
# -------------------------------
# Training loss: 0.308509
# Validation loss: 0.314206
#
# Epoch 81
# -------------------------------
# Training loss: 0.309624
# Validation loss: 0.310658
#
# Epoch 82
# -------------------------------
# Training loss: 0.308141
# Validation loss: 0.307719
#
# Epoch 83
# -------------------------------
# Training loss: 0.307535
# Validation loss: 0.313984
#
# Epoch 84
# -------------------------------
# Training loss: 0.306825
# Validation loss: 0.306661
#
# Epoch 85
# -------------------------------
# Training loss: 0.306155
# Validation loss: 0.306370
#
# Epoch 86
# -------------------------------
# Training loss: 0.304334
# Validation loss: 0.307432
#
# Epoch 87
# -------------------------------
# Training loss: 0.304900
# Validation loss: 0.300079
#
# Epoch 88
# -------------------------------
# Training loss: 0.302432
# Validation loss: 0.300757
#
# Epoch 89
# -------------------------------
# Training loss: 0.302813
# Validation loss: 0.309170
#
# Epoch 90
# -------------------------------
# Training loss: 0.302188
# Validation loss: 0.303757
#
# Epoch 91
# -------------------------------
# Training loss: 0.300830
# Validation loss: 0.299002
#
# Epoch 92
# -------------------------------
# Training loss: 0.299584
# Validation loss: 0.300800
#
# Epoch 93
# -------------------------------
# Training loss: 0.298401
# Validation loss: 0.301393
#
# Epoch 94
# -------------------------------
# Training loss: 0.297130
# Validation loss: 0.299545
#
# Epoch 95
# -------------------------------
# Training loss: 0.297013
# Validation loss: 0.296576
#
# Epoch 96
# -------------------------------
# Training loss: 0.295098
# Validation loss: 0.301677
#
# Epoch 97
# -------------------------------
# Training loss: 0.295252
# Validation loss: 0.296428
#
# Epoch 98
# -------------------------------
# Training loss: 0.295063
# Validation loss: 0.290247
#
# Epoch 99
# -------------------------------
# Training loss: 0.294697
# Validation loss: 0.289195
#
# Epoch 100
# -------------------------------
# Training loss: 0.293894
# Validation loss: 0.295182
#
# Epoch 101
# -------------------------------
# Training loss: 0.294187
# Validation loss: 0.300544
#
# Epoch 102
# -------------------------------
# Training loss: 0.293476
# Validation loss: 0.297590
#
# Epoch 103
# -------------------------------
# Training loss: 0.291085
# Validation loss: 0.286419
#
# Epoch 104
# -------------------------------
# Training loss: 0.288122
# Validation loss: 0.287637
#
# Epoch 105
# -------------------------------
# Training loss: 0.289712
# Validation loss: 0.288273
#
# Epoch 106
# -------------------------------
# Training loss: 0.288427
# Validation loss: 0.290042
#
# Epoch 107
# -------------------------------
# Training loss: 0.287561
# Validation loss: 0.293276
#
# Epoch 108
# -------------------------------
# Training loss: 0.286150
# Validation loss: 0.277854
#
# Epoch 109
# -------------------------------
# Training loss: 0.286112
# Validation loss: 0.288578
#
# Epoch 110
# -------------------------------
# Training loss: 0.285804
# Validation loss: 0.289093
#
# Epoch 111
# -------------------------------
# Training loss: 0.286184
# Validation loss: 0.283147
#
# Epoch 112
# -------------------------------
# Training loss: 0.283893
# Validation loss: 0.282837
#
# Epoch 113
# -------------------------------
# Training loss: 0.282976
# Validation loss: 0.281384
#
# Epoch 114
# -------------------------------
# Training loss: 0.281518
# Validation loss: 0.277759
#
# Epoch 115
# -------------------------------
# Training loss: 0.282382
# Validation loss: 0.280815
#
# Epoch 116
# -------------------------------
# Training loss: 0.279538
# Validation loss: 0.290612
#
# Epoch 117
# -------------------------------
# Training loss: 0.282837
# Validation loss: 0.285365
#
# Epoch 118
# -------------------------------
# Training loss: 0.280341
# Validation loss: 0.285698
#
# Epoch 119
# -------------------------------
# Training loss: 0.278779
# Validation loss: 0.277103
#
# Epoch 120
# -------------------------------
# Training loss: 0.279373
# Validation loss: 0.284375
#
# Epoch 121
# -------------------------------
# Training loss: 0.277030
# Validation loss: 0.282702
#
# Epoch 122
# -------------------------------
# Training loss: 0.276977
# Validation loss: 0.279028
#
# Epoch 123
# -------------------------------
# Training loss: 0.276277
# Validation loss: 0.281061
#
# Epoch 124
# -------------------------------
# Training loss: 0.274243
# Validation loss: 0.286852
#
# Epoch 125
# -------------------------------
# Training loss: 0.273373
# Validation loss: 0.296283
#
# Epoch 126
# -------------------------------
# Training loss: 0.273553
# Validation loss: 0.293311
#
# Epoch 127
# -------------------------------
# Training loss: 0.273309
# Validation loss: 0.291175
#
# Epoch 128
# -------------------------------
# Training loss: 0.273289
# Validation loss: 0.273405
#
# Epoch 129
# -------------------------------
# Training loss: 0.271848
# Validation loss: 0.270770
#
# Epoch 130
# -------------------------------
# Training loss: 0.271070
# Validation loss: 0.286514
#
# Epoch 131
# -------------------------------
# Training loss: 0.269248
# Validation loss: 0.266004
#
# Epoch 132
# -------------------------------
# Training loss: 0.268381
# Validation loss: 0.275249
#
# Epoch 133
# -------------------------------
# Training loss: 0.268966
# Validation loss: 0.288371
#
# Epoch 134
# -------------------------------
# Training loss: 0.265819
# Validation loss: 0.267500
#
# Epoch 135
# -------------------------------
# Training loss: 0.264851
# Validation loss: 0.268942
#
# Epoch 136
# -------------------------------
# Training loss: 0.265607
# Validation loss: 0.290522
#
# Epoch 137
# -------------------------------
# Training loss: 0.262083
# Validation loss: 0.269036
#
# Epoch 138
# -------------------------------
# Training loss: 0.261219
# Validation loss: 0.274659
#
# Epoch 139
# -------------------------------
# Training loss: 0.260258
# Validation loss: 0.261204
#
# Epoch 140
# -------------------------------
# Training loss: 0.258685
# Validation loss: 0.292188
#
# Epoch 141
# -------------------------------
# Training loss: 0.259632
# Validation loss: 0.258145
#
# Epoch 142
# -------------------------------
# Training loss: 0.256729
# Validation loss: 0.271246
#
# Epoch 143
# -------------------------------
# Training loss: 0.259745
# Validation loss: 0.253307
#
# Epoch 144
# -------------------------------
# Training loss: 0.254257
# Validation loss: 0.316515
#
# Epoch 145
# -------------------------------
# Training loss: 0.253755
# Validation loss: 0.255178
#
# Epoch 146
# -------------------------------
# Training loss: 0.249814
# Validation loss: 0.246741
#
# Epoch 147
# -------------------------------
# Training loss: 0.248646
# Validation loss: 0.248100
#
# Epoch 148
# -------------------------------
# Training loss: 0.251889
# Validation loss: 0.247721
#
# Epoch 149
# -------------------------------
# Training loss: 0.246166
# Validation loss: 0.275928
#
# Epoch 150
# -------------------------------
# Training loss: 0.244459
# Validation loss: 0.240867
#
# Epoch 151
# -------------------------------
# Training loss: 0.243273
# Validation loss: 0.240843
#
# Epoch 152
# -------------------------------
# Training loss: 0.243656
# Validation loss: 0.350433
#
# Epoch 153
# -------------------------------
# Training loss: 0.238159
# Validation loss: 0.322664
#
# Epoch 154
# -------------------------------
# Training loss: 0.234665
# Validation loss: 0.414867
#
# Epoch 155
# -------------------------------
# Training loss: 0.234620
# Validation loss: 0.227904
#
# Epoch 156
# -------------------------------
# Training loss: 0.228601
# Validation loss: 0.303893
#
# Epoch 157
# -------------------------------
# Training loss: 0.231582
# Validation loss: 0.237693
#
# Epoch 158
# -------------------------------
# Training loss: 0.225923
# Validation loss: 0.227607
#
# Epoch 159
# -------------------------------
# Training loss: 0.225403
# Validation loss: 0.235583
#
# Epoch 160
# -------------------------------
# Training loss: 0.220629
# Validation loss: 0.395482
#
# Epoch 161
# -------------------------------
# Training loss: 0.217838
# Validation loss: 0.270041
#
# Epoch 162
# -------------------------------
# Training loss: 0.219499
# Validation loss: 0.273056
#
# Epoch 163
# -------------------------------
# Training loss: 0.213128
# Validation loss: 0.242870
#
# Epoch 164
# -------------------------------
# Training loss: 0.214340
# Validation loss: 0.220402
#
# Epoch 165
# -------------------------------
# Training loss: 0.212490
# Validation loss: 0.315521
#
# Epoch 166
# -------------------------------
# Training loss: 0.206553
# Validation loss: 0.211015
#
# Epoch 167
# -------------------------------
# Training loss: 0.210990
# Validation loss: 0.250315
#
# Epoch 168
# -------------------------------
# Training loss: 0.202957
# Validation loss: 0.229231
#
# Epoch 169
# -------------------------------
# Training loss: 0.204257
# Validation loss: 0.206337
#
# Epoch 170
# -------------------------------
# Training loss: 0.195628
# Validation loss: 0.313677
#
# Epoch 171
# -------------------------------
# Training loss: 0.194306
# Validation loss: 0.186634
#
# Epoch 172
# -------------------------------
# Training loss: 0.201527
# Validation loss: 0.199708
#
# Epoch 173
# -------------------------------
# Training loss: 0.192504
# Validation loss: 0.247517
#
# Epoch 174
# -------------------------------
# Training loss: 0.191417
# Validation loss: 0.223071
#
# Epoch 175
# -------------------------------
# Training loss: 0.192614
# Validation loss: 0.655209
#
# Epoch 176
# -------------------------------
# Training loss: 0.193366
# Validation loss: 0.240251
#
# Epoch 177
# -------------------------------
# Training loss: 0.184517
# Validation loss: 0.275005
#
# Epoch 178
# -------------------------------
# Training loss: 0.187088
# Validation loss: 0.182569
#
# Epoch 179
# -------------------------------
# Training loss: 0.188876
# Validation loss: 0.189932
#
# Epoch 180
# -------------------------------
# Training loss: 0.184723
# Validation loss: 0.230265
#
# Epoch 181
# -------------------------------
# Training loss: 0.187067
# Validation loss: 0.396751
#
# Epoch 182
# -------------------------------
# Training loss: 0.181207
# Validation loss: 0.184940
#
# Epoch 183
# -------------------------------
# Training loss: 0.182566
# Validation loss: 0.267463
#
# Epoch 184
# -------------------------------
# Training loss: 0.178759
# Validation loss: 0.182311
#
# Epoch 185
# -------------------------------
# Training loss: 0.179023
# Validation loss: 0.182511
#
# Epoch 186
# -------------------------------
# Training loss: 0.176420
# Validation loss: 0.440692
#
# Epoch 187
# -------------------------------
# Training loss: 0.172647
# Validation loss: 0.205390
#
# Epoch 188
# -------------------------------
# Training loss: 0.171444
# Validation loss: 0.199514
#
# Epoch 189
# -------------------------------
# Training loss: 0.165604
# Validation loss: 0.169650
#
# Epoch 190
# -------------------------------
# Training loss: 0.172906
# Validation loss: 0.216530
#
# Epoch 191
# -------------------------------
# Training loss: 0.166754
# Validation loss: 0.164225
#
# Epoch 192
# -------------------------------
# Training loss: 0.166296
# Validation loss: 0.265374
#
# Epoch 193
# -------------------------------
# Training loss: 0.167916
# Validation loss: 0.292026
#
# Epoch 194
# -------------------------------
# Training loss: 0.167867
# Validation loss: 0.163577
#
# Epoch 195
# -------------------------------
# Training loss: 0.160985
# Validation loss: 0.173967
#
# Epoch 196
# -------------------------------
# Training loss: 0.158357
# Validation loss: 0.172278
#
# Epoch 197
# -------------------------------
# Training loss: 0.164961
# Validation loss: 0.162195
#
# Epoch 198
# -------------------------------
# Training loss: 0.163494
# Validation loss: 0.163392
#
# Epoch 199
# -------------------------------
# Training loss: 0.166151
# Validation loss: 0.221386
#
# Epoch 200
# -------------------------------
# Training loss: 0.159532
# Validation loss: 0.160508
#
# Epoch 201
# -------------------------------
# Training loss: 0.158033
# Validation loss: 0.149825
#
# Epoch 202
# -------------------------------
# Training loss: 0.154129
# Validation loss: 0.192523
#
# Epoch 203
# -------------------------------
# Training loss: 0.151451
# Validation loss: 0.150659
#
# Epoch 204
# -------------------------------
# Training loss: 0.152912
# Validation loss: 0.306558
#
# Epoch 205
# -------------------------------
# Training loss: 0.155175
# Validation loss: 0.881254
#
# Epoch 206
# -------------------------------
# Training loss: 0.148732
# Validation loss: 0.148436
#
# Epoch 207
# -------------------------------
# Training loss: 0.148438
# Validation loss: 0.169579
#
# Epoch 208
# -------------------------------
# Training loss: 0.152743
# Validation loss: 0.149241
#
# Epoch 209
# -------------------------------
# Training loss: 0.153401
# Validation loss: 0.139934
#
# Epoch 210
# -------------------------------
# Training loss: 0.150012
# Validation loss: 0.181645
#
# Epoch 211
# -------------------------------
# Training loss: 0.146198
# Validation loss: 0.207837
#
# Epoch 212
# -------------------------------
# Training loss: 0.145585
# Validation loss: 0.142652
#
# Epoch 213
# -------------------------------
# Training loss: 0.146598
# Validation loss: 0.140266
#
# Epoch 214
# -------------------------------
# Training loss: 0.144766
# Validation loss: 0.264797
#
# Epoch 215
# -------------------------------
# Training loss: 0.145999
# Validation loss: 0.144510
#
# Epoch 216
# -------------------------------
# Training loss: 0.141482
# Validation loss: 0.141956
#
# Epoch 217
# -------------------------------
# Training loss: 0.140839
# Validation loss: 0.170156
#
# Epoch 218
# -------------------------------
# Training loss: 0.139292
# Validation loss: 0.140603
#
# Epoch 219
# -------------------------------
# Training loss: 0.136674
# Validation loss: 0.133503
#
# Epoch 220
# -------------------------------
# Training loss: 0.140062
# Validation loss: 0.172402
#
# Epoch 221
# -------------------------------
# Training loss: 0.142799
# Validation loss: 0.278404
#
# Epoch 222
# -------------------------------
# Training loss: 0.146536
# Validation loss: 0.147728
#
# Epoch 223
# -------------------------------
# Training loss: 0.139850
# Validation loss: 0.142098
#
# Epoch 224
# -------------------------------
# Training loss: 0.136472
# Validation loss: 0.129845
#
# Epoch 225
# -------------------------------
# Training loss: 0.133239
# Validation loss: 0.133923
#
# Epoch 226
# -------------------------------
# Training loss: 0.135134
# Validation loss: 0.159095
#
# Epoch 227
# -------------------------------
# Training loss: 0.133733
# Validation loss: 0.214615
#
# Epoch 228
# -------------------------------
# Training loss: 0.133198
# Validation loss: 0.132659
#
# Epoch 229
# -------------------------------
# Training loss: 0.134344
# Validation loss: 0.147984
#
# Epoch 230
# -------------------------------
# Training loss: 0.138652
# Validation loss: 0.133312
#
# Epoch 231
# -------------------------------
# Training loss: 0.131220
# Validation loss: 0.121487
#
# Epoch 232
# -------------------------------
# Training loss: 0.135785
# Validation loss: 0.207129
#
# Epoch 233
# -------------------------------
# Training loss: 0.136324
# Validation loss: 0.146465
#
# Epoch 234
# -------------------------------
# Training loss: 0.129940
# Validation loss: 0.234115
#
# Epoch 235
# -------------------------------
# Training loss: 0.133443
# Validation loss: 0.148941
#
# Epoch 236
# -------------------------------
# Training loss: 0.129514
# Validation loss: 0.159314
#
# Epoch 237
# -------------------------------
# Training loss: 0.127860
# Validation loss: 0.126362
#
# Epoch 238
# -------------------------------
# Training loss: 0.127092
# Validation loss: 0.129747
#
# Epoch 239
# -------------------------------
# Training loss: 0.127447
# Validation loss: 0.121151
#
# Epoch 240
# -------------------------------
# Training loss: 0.126161
# Validation loss: 0.119636
#
# Epoch 241
# -------------------------------
# Training loss: 0.125984
# Validation loss: 0.121671
#
# Epoch 242
# -------------------------------
# Training loss: 0.125872
# Validation loss: 0.171832
#
# Epoch 243
# -------------------------------
# Training loss: 0.123836
# Validation loss: 0.131006
#
# Epoch 244
# -------------------------------
# Training loss: 0.122547
# Validation loss: 0.118663
#
# Epoch 245
# -------------------------------
# Training loss: 0.122334
# Validation loss: 0.146958
#
# Epoch 246
# -------------------------------
# Training loss: 0.123539
# Validation loss: 0.129816
#
# Epoch 247
# -------------------------------
# Training loss: 0.124090
# Validation loss: 0.122810
#
# Epoch 248
# -------------------------------
# Training loss: 0.124946
# Validation loss: 0.119855
#
# Epoch 249
# -------------------------------
# Training loss: 0.122872
# Validation loss: 0.112134
#
# Epoch 250
# -------------------------------
# Training loss: 0.119386
# Validation loss: 0.118526
#
# Epoch 251
# -------------------------------
# Training loss: 0.122086
# Validation loss: 0.165908
#
# Epoch 252
# -------------------------------
# Training loss: 0.119271
# Validation loss: 0.148230
#
# Epoch 253
# -------------------------------
# Training loss: 0.119474
# Validation loss: 0.134050
#
# Epoch 254
# -------------------------------
# Training loss: 0.116099
# Validation loss: 0.123063
#
# Epoch 255
# -------------------------------
# Training loss: 0.117446
# Validation loss: 0.108251
#
# Epoch 256
# -------------------------------
# Training loss: 0.116059
# Validation loss: 0.111479
#
# Epoch 257
# -------------------------------
# Training loss: 0.114906
# Validation loss: 0.131724
#
# Epoch 258
# -------------------------------
# Training loss: 0.116890
# Validation loss: 0.112531
#
# Epoch 259
# -------------------------------
# Training loss: 0.115913
# Validation loss: 0.298352
#
# Epoch 260
# -------------------------------
# Training loss: 0.116450
# Validation loss: 0.130564
#
# Epoch 261
# -------------------------------
# Training loss: 0.114012
# Validation loss: 0.114250
#
# Epoch 262
# -------------------------------
# Training loss: 0.114763
# Validation loss: 0.123523
#
# Epoch 263
# -------------------------------
# Training loss: 0.111395
# Validation loss: 0.106424
#
# Epoch 264
# -------------------------------
# Training loss: 0.111872
# Validation loss: 0.110969
#
# Epoch 265
# -------------------------------
# Training loss: 0.111036
# Validation loss: 0.286049
#
# Epoch 266
# -------------------------------
# Training loss: 0.109595
# Validation loss: 0.108085
#
# Epoch 267
# -------------------------------
# Training loss: 0.111502
# Validation loss: 0.117897
#
# Epoch 268
# -------------------------------
# Training loss: 0.116024
# Validation loss: 0.142686
#
# Epoch 269
# -------------------------------
# Training loss: 0.117058
# Validation loss: 0.201000
#
# Epoch 270
# -------------------------------
# Training loss: 0.112469
# Validation loss: 0.115841
#
# Epoch 271
# -------------------------------
# Training loss: 0.111656
# Validation loss: 0.107320
#
# Epoch 272
# -------------------------------
# Training loss: 0.109195
# Validation loss: 0.153410
#
# Epoch 273
# -------------------------------
# Training loss: 0.110048
# Validation loss: 0.179249
#
# Epoch 274
# -------------------------------
# Training loss: 0.108368
# Validation loss: 0.137918
#
# Epoch 275
# -------------------------------
# Training loss: 0.105357
# Validation loss: 0.110919
#
# Epoch 276
# -------------------------------
# Training loss: 0.107379
# Validation loss: 0.123687
#
# Epoch 277
# -------------------------------
# Training loss: 0.108411
# Validation loss: 0.105768
#
# Epoch 278
# -------------------------------
# Training loss: 0.106828
# Validation loss: 0.147468
#
# Epoch 279
# -------------------------------
# Training loss: 0.104358
# Validation loss: 0.103620
#
# Epoch 280
# -------------------------------
# Training loss: 0.103150
# Validation loss: 0.118142
#
# Epoch 281
# -------------------------------
# Training loss: 0.107750
# Validation loss: 0.124946
#
# Epoch 282
# -------------------------------
# Training loss: 0.104200
# Validation loss: 0.126366
#
# Epoch 283
# -------------------------------
# Training loss: 0.104456
# Validation loss: 0.113059
#
# Epoch 284
# -------------------------------
# Training loss: 0.102460
# Validation loss: 0.101253
#
# Epoch 285
# -------------------------------
# Training loss: 0.103911
# Validation loss: 0.104139
#
# Epoch 286
# -------------------------------
# Training loss: 0.102701
# Validation loss: 0.102140
#
# Epoch 287
# -------------------------------
# Training loss: 0.101149
# Validation loss: 0.460941
#
# Epoch 288
# -------------------------------
# Training loss: 0.104997
# Validation loss: 0.161604
#
# Epoch 289
# -------------------------------
# Training loss: 0.105027
# Validation loss: 0.115692
#
# Epoch 290
# -------------------------------
# Training loss: 0.101737
# Validation loss: 0.112300
#
# Epoch 291
# -------------------------------
# Training loss: 0.103878
# Validation loss: 0.103475
#
# Epoch 292
# -------------------------------
# Training loss: 0.104047
# Validation loss: 0.138159
#
# Epoch 293
# -------------------------------
# Training loss: 0.101758
# Validation loss: 0.109255
#
# Epoch 294
# -------------------------------
# Training loss: 0.102696
# Validation loss: 0.124511
#
# Epoch 295
# -------------------------------
# Training loss: 0.101201
# Validation loss: 0.113725
#
# Epoch 296
# -------------------------------
# Training loss: 0.100786
# Validation loss: 0.142446
#
# Epoch 297
# -------------------------------
# Training loss: 0.102849
# Validation loss: 0.115910
#
# Epoch 298
# -------------------------------
# Training loss: 0.103709
# Validation loss: 0.115359
#
# Epoch 299
# -------------------------------
# Training loss: 0.102927
# Validation loss: 0.110262
#
# Epoch 300
# -------------------------------
# Training loss: 0.100491
# Validation loss: 0.096668
#
# Epoch 301
# -------------------------------
# Training loss: 0.101754
# Validation loss: 0.149181
#
# Epoch 302
# -------------------------------
# Training loss: 0.097769
# Validation loss: 0.120239
#
# Epoch 303
# -------------------------------
# Training loss: 0.097402
# Validation loss: 0.131532
#
# Epoch 304
# -------------------------------
# Training loss: 0.098750
# Validation loss: 0.097377
#
# Epoch 305
# -------------------------------
# Training loss: 0.098506
# Validation loss: 0.159981
#
# Epoch 306
# -------------------------------
# Training loss: 0.097277
# Validation loss: 0.181437
#
# Epoch 307
# -------------------------------
# Training loss: 0.095697
# Validation loss: 0.351236
#
# Epoch 308
# -------------------------------
# Training loss: 0.094665
# Validation loss: 0.090411
#
# Epoch 309
# -------------------------------
# Training loss: 0.094730
# Validation loss: 0.094257
#
# Epoch 310
# -------------------------------
# Training loss: 0.093333
# Validation loss: 0.103442
#
# Epoch 311
# -------------------------------
# Training loss: 0.093595
# Validation loss: 0.115455
#
# Epoch 312
# -------------------------------
# Training loss: 0.094995
# Validation loss: 0.217948
#
# Epoch 313
# -------------------------------
# Training loss: 0.096173
# Validation loss: 0.105026
#
# Epoch 314
# -------------------------------
# Training loss: 0.101551
# Validation loss: 0.098735
#
# Epoch 315
# -------------------------------
# Training loss: 0.093666
# Validation loss: 0.124002
#
# Epoch 316
# -------------------------------
# Training loss: 0.095680
# Validation loss: 0.099771
#
# Epoch 317
# -------------------------------
# Training loss: 0.095779
# Validation loss: 0.097648
#
# Epoch 318
# -------------------------------
# Training loss: 0.101960
# Validation loss: 0.102119
#
# Epoch 319
# -------------------------------
# Training loss: 0.098338
# Validation loss: 0.108718
#
# Epoch 320
# -------------------------------
# Training loss: 0.091475
# Validation loss: 0.093300
#
# Epoch 321
# -------------------------------
# Training loss: 0.094626
# Validation loss: 0.191663
#
# Epoch 322
# -------------------------------
# Training loss: 0.091172
# Validation loss: 0.318297
#
# Epoch 323
# -------------------------------
# Training loss: 0.090889
# Validation loss: 0.093764
#
# Epoch 324
# -------------------------------
# Training loss: 0.090151
# Validation loss: 0.222228
#
# Epoch 325
# -------------------------------
# Training loss: 0.089203
# Validation loss: 0.123099
#
# Epoch 326
# -------------------------------
# Training loss: 0.091795
# Validation loss: 0.097864
#
# Epoch 327
# -------------------------------
# Training loss: 0.090804
# Validation loss: 0.091048
#
# Epoch 328
# -------------------------------
# Training loss: 0.089876
# Validation loss: 0.095908
#
# Epoch 329
# -------------------------------
# Training loss: 0.088936
# Validation loss: 0.173744
#
# Epoch 330
# -------------------------------
# Training loss: 0.092458
# Validation loss: 0.102303
#
# Epoch 331
# -------------------------------
# Training loss: 0.088188
# Validation loss: 0.096228
#
# Epoch 332
# -------------------------------
# Training loss: 0.088897
# Validation loss: 0.091204
#
# Epoch 333
# -------------------------------
# Training loss: 0.090079
# Validation loss: 0.282410
#
# Epoch 334
# -------------------------------
# Training loss: 0.088802
# Validation loss: 0.108566
#
# Epoch 335
# -------------------------------
# Training loss: 0.090277
# Validation loss: 0.110382
#
# Epoch 336
# -------------------------------
# Training loss: 0.086542
# Validation loss: 0.090181
#
# Epoch 337
# -------------------------------
# Training loss: 0.089562
# Validation loss: 0.099930
#
# Epoch 338
# -------------------------------
# Training loss: 0.089723
# Validation loss: 0.110999
#
# Epoch 339
# -------------------------------
# Training loss: 0.086298
# Validation loss: 0.093425
#
# Epoch 340
# -------------------------------
# Training loss: 0.084750
# Validation loss: 0.093528
#
# Epoch 341
# -------------------------------
# Training loss: 0.089618
# Validation loss: 0.094274
#
# Epoch 342
# -------------------------------
# Training loss: 0.088354
# Validation loss: 0.104644
#
# Epoch 343
# -------------------------------
# Training loss: 0.086491
# Validation loss: 0.093661
#
# Epoch 344
# -------------------------------
# Training loss: 0.084949
# Validation loss: 0.083187
#
# Epoch 345
# -------------------------------
# Training loss: 0.085279
# Validation loss: 0.107585
#
# Epoch 346
# -------------------------------
# Training loss: 0.091236
# Validation loss: 0.130071
#
# Epoch 347
# -------------------------------
# Training loss: 0.087362
# Validation loss: 0.098208
#
# Epoch 348
# -------------------------------
# Training loss: 0.083968
# Validation loss: 0.101911
#
# Epoch 349
# -------------------------------
# Training loss: 0.085384
# Validation loss: 0.125143
#
# Epoch 350
# -------------------------------
# Training loss: 0.085120
# Validation loss: 0.128877
#
# Epoch 351
# -------------------------------
# Training loss: 0.084610
# Validation loss: 0.083950
#
# Epoch 352
# -------------------------------
# Training loss: 0.080828
# Validation loss: 0.081842
#
# Epoch 353
# -------------------------------
# Training loss: 0.086393
# Validation loss: 0.105350
#
# Epoch 354
# -------------------------------
# Training loss: 0.084004
# Validation loss: 0.095385
#
# Epoch 355
# -------------------------------
# Training loss: 0.086129
# Validation loss: 0.308963
#
# Epoch 356
# -------------------------------
# Training loss: 0.085020
# Validation loss: 0.122645
#
# Epoch 357
# -------------------------------
# Training loss: 0.085909
# Validation loss: 0.085045
#
# Epoch 358
# -------------------------------
# Training loss: 0.083712
# Validation loss: 0.083882
#
# Epoch 359
# -------------------------------
# Training loss: 0.082452
# Validation loss: 0.092381
#
# Epoch 360
# -------------------------------
# Training loss: 0.085588
# Validation loss: 0.098089
#
# Epoch 361
# -------------------------------
# Training loss: 0.081973
# Validation loss: 0.080372
#
# Epoch 362
# -------------------------------
# Training loss: 0.082650
# Validation loss: 0.083034
#
# Epoch 363
# -------------------------------
# Training loss: 0.080910
# Validation loss: 0.080859
#
# Epoch 364
# -------------------------------
# Training loss: 0.081931
# Validation loss: 0.125330
#
# Epoch 365
# -------------------------------
# Training loss: 0.084124
# Validation loss: 0.095592
#
# Epoch 366
# -------------------------------
# Training loss: 0.083381
# Validation loss: 0.102603
#
# Epoch 367
# -------------------------------
# Training loss: 0.082204
# Validation loss: 0.082858
#
# Epoch 368
# -------------------------------
# Training loss: 0.084552
# Validation loss: 0.092192
#
# Epoch 369
# -------------------------------
# Training loss: 0.083480
# Validation loss: 0.133103
#
# Epoch 370
# -------------------------------
# Training loss: 0.082438
# Validation loss: 0.114476
#
# Epoch 371
# -------------------------------
# Training loss: 0.081152
# Validation loss: 0.083623
#
# Epoch 372
# -------------------------------
# Training loss: 0.082571
# Validation loss: 0.090855
#
# Epoch 373
# -------------------------------
# Training loss: 0.081208
# Validation loss: 0.080021
#
# Epoch 374
# -------------------------------
# Training loss: 0.078844
# Validation loss: 0.081932
#
# Epoch 375
# -------------------------------
# Training loss: 0.078684
# Validation loss: 0.137433
#
# Epoch 376
# -------------------------------
# Training loss: 0.079776
# Validation loss: 0.085761
#
# Epoch 377
# -------------------------------
# Training loss: 0.078022
# Validation loss: 0.102128
#
# Epoch 378
# -------------------------------
# Training loss: 0.078966
# Validation loss: 0.462401
#
# Epoch 379
# -------------------------------
# Training loss: 0.081186
# Validation loss: 0.112231
#
# Epoch 380
# -------------------------------
# Training loss: 0.079197
# Validation loss: 0.088340
#
# Epoch 381
# -------------------------------
# Training loss: 0.079732
# Validation loss: 0.226991
#
# Epoch 382
# -------------------------------
# Training loss: 0.081217
# Validation loss: 0.077364
#
# Epoch 383
# -------------------------------
# Training loss: 0.077428
# Validation loss: 0.078658
#
# Epoch 384
# -------------------------------
# Training loss: 0.079208
# Validation loss: 0.207664
#
# Epoch 385
# -------------------------------
# Training loss: 0.076979
# Validation loss: 0.086717
#
# Epoch 386
# -------------------------------
# Training loss: 0.074818
# Validation loss: 0.079613
#
# Epoch 387
# -------------------------------
# Training loss: 0.077720
# Validation loss: 0.080867
#
# Epoch 388
# -------------------------------
# Training loss: 0.079942
# Validation loss: 0.077968
#
# Epoch 389
# -------------------------------
# Training loss: 0.077465
# Validation loss: 0.148284
#
# Epoch 390
# -------------------------------
# Training loss: 0.077107
# Validation loss: 0.108477
#
# Epoch 391
# -------------------------------
# Training loss: 0.081065
# Validation loss: 0.148121
#
# Epoch 392
# -------------------------------
# Training loss: 0.073138
# Validation loss: 0.076793
#
# Epoch 393
# -------------------------------
# Training loss: 0.076516
# Validation loss: 0.097294
#
# Epoch 394
# -------------------------------
# Training loss: 0.076345
# Validation loss: 0.101801
#
# Epoch 395
# -------------------------------
# Training loss: 0.075256
# Validation loss: 0.089228
#
# Epoch 396
# -------------------------------
# Training loss: 0.075884
# Validation loss: 0.074827
#
# Epoch 397
# -------------------------------
# Training loss: 0.076449
# Validation loss: 0.137806
#
# Epoch 398
# -------------------------------
# Training loss: 0.076098
# Validation loss: 0.085929
#
# Epoch 399
# -------------------------------
# Training loss: 0.074867
# Validation loss: 0.110548
#
# Epoch 400
# -------------------------------
# Training loss: 0.075975
# Validation loss: 0.085715
#
# Epoch 401
# -------------------------------
# Training loss: 0.074795
# Validation loss: 0.114420
#
# Epoch 402
# -------------------------------
# Training loss: 0.077019
# Validation loss: 0.093524
#
# Epoch 403
# -------------------------------
# Training loss: 0.077961
# Validation loss: 0.080361
#
# Epoch 404
# -------------------------------
# Training loss: 0.075184
# Validation loss: 0.083099
#
# Epoch 405
# -------------------------------
# Training loss: 0.072745
# Validation loss: 0.089683
#
# Epoch 406
# -------------------------------
# Training loss: 0.078070
# Validation loss: 0.073382
#
# Epoch 407
# -------------------------------
# Training loss: 0.073195
# Validation loss: 0.082795
#
# Epoch 408
# -------------------------------
# Training loss: 0.073238
# Validation loss: 0.124276
#
# Epoch 409
# -------------------------------
# Training loss: 0.076843
# Validation loss: 0.091704
#
# Epoch 410
# -------------------------------
# Training loss: 0.075351
# Validation loss: 0.075225
#
# Epoch 411
# -------------------------------
# Training loss: 0.073439
# Validation loss: 0.076836
#
# Epoch 412
# -------------------------------
# Training loss: 0.072763
# Validation loss: 0.078109
#
# Epoch 413
# -------------------------------
# Training loss: 0.074905
# Validation loss: 0.129014
#
# Epoch 414
# -------------------------------
# Training loss: 0.075579
# Validation loss: 0.094583
#
# Epoch 415
# -------------------------------
# Training loss: 0.070990
# Validation loss: 0.076155
#
# Epoch 416
# -------------------------------
# Training loss: 0.076694
# Validation loss: 0.083980
#
# Epoch 417
# -------------------------------
# Training loss: 0.077011
# Validation loss: 0.078774
#
# Epoch 418
# -------------------------------
# Training loss: 0.077249
# Validation loss: 0.114024
#
# Epoch 419
# -------------------------------
# Training loss: 0.073981
# Validation loss: 0.085487
#
# Epoch 420
# -------------------------------
# Training loss: 0.075820
# Validation loss: 0.125511
#
# Epoch 421
# -------------------------------
# Training loss: 0.071787
# Validation loss: 0.077481
#
# Epoch 422
# -------------------------------
# Training loss: 0.073083
# Validation loss: 0.074652
#
# Epoch 423
# -------------------------------
# Training loss: 0.076258
# Validation loss: 0.074084
#
# Epoch 424
# -------------------------------
# Training loss: 0.073187
# Validation loss: 0.122358
#
# Epoch 425
# -------------------------------
# Training loss: 0.074497
# Validation loss: 0.090202
#
# Epoch 426
# -------------------------------
# Training loss: 0.071284
# Validation loss: 0.076767
#
# Epoch 427
# -------------------------------
# Training loss: 0.072125
# Validation loss: 0.100723
#
# Epoch 428
# -------------------------------
# Training loss: 0.071876
# Validation loss: 0.076459
#
# Epoch 429
# -------------------------------
# Training loss: 0.073246
# Validation loss: 0.085229
#
# Epoch 430
# -------------------------------
# Training loss: 0.076254
# Validation loss: 0.086262
#
# Epoch 431
# -------------------------------
# Training loss: 0.073303
# Validation loss: 0.074857
#
# Epoch 432
# -------------------------------
# Training loss: 0.073506
# Validation loss: 0.091120
#
# Epoch 433
# -------------------------------
# Training loss: 0.074710
# Validation loss: 0.072653
#
# Epoch 434
# -------------------------------
# Training loss: 0.071393
# Validation loss: 0.077497
#
# Epoch 435
# -------------------------------
# Training loss: 0.071492
# Validation loss: 0.107704
#
# Epoch 436
# -------------------------------
# Training loss: 0.068055
# Validation loss: 0.196133
#
# Epoch 437
# -------------------------------
# Training loss: 0.068657
# Validation loss: 0.109032
#
# Epoch 438
# -------------------------------
# Training loss: 0.071410
# Validation loss: 0.071436
#
# Epoch 439
# -------------------------------
# Training loss: 0.071332
# Validation loss: 0.075573
#
# Epoch 440
# -------------------------------
# Training loss: 0.074610
# Validation loss: 0.077436
#
# Epoch 441
# -------------------------------
# Training loss: 0.069775
# Validation loss: 0.067638
#
# Epoch 442
# -------------------------------
# Training loss: 0.070541
# Validation loss: 0.082933
#
# Epoch 443
# -------------------------------
# Training loss: 0.067686
# Validation loss: 0.084439
#
# Epoch 444
# -------------------------------
# Training loss: 0.068680
# Validation loss: 0.076758
#
# Epoch 445
# -------------------------------
# Training loss: 0.069027
# Validation loss: 0.079253
#
# Epoch 446
# -------------------------------
# Training loss: 0.069910
# Validation loss: 0.072993
#
# Epoch 447
# -------------------------------
# Training loss: 0.072233
# Validation loss: 0.107382
#
# Epoch 448
# -------------------------------
# Training loss: 0.070563
# Validation loss: 0.070406
#
# Epoch 449
# -------------------------------
# Training loss: 0.068946
# Validation loss: 0.072339
#
# Epoch 450
# -------------------------------
# Training loss: 0.069076
# Validation loss: 0.073739
#
# Epoch 451
# -------------------------------
# Training loss: 0.070949
# Validation loss: 0.108525
#
# Epoch 452
# -------------------------------
# Training loss: 0.069804
# Validation loss: 0.075286
#
# Epoch 453
# -------------------------------
# Training loss: 0.069452
# Validation loss: 0.070038
#
# Epoch 454
# -------------------------------
# Training loss: 0.068659
# Validation loss: 0.071662
#
# Epoch 455
# -------------------------------
# Training loss: 0.069747
# Validation loss: 0.073342
#
# Epoch 456
# -------------------------------
# Training loss: 0.069366
# Validation loss: 0.070559
#
# Epoch 457
# -------------------------------
# Training loss: 0.065724
# Validation loss: 0.076194
#
# Epoch 458
# -------------------------------
# Training loss: 0.067427
# Validation loss: 0.075244
#
# Epoch 459
# -------------------------------
# Training loss: 0.070129
# Validation loss: 0.067103
#
# Epoch 460
# -------------------------------
# Training loss: 0.070633
# Validation loss: 0.084516
#
# Epoch 461
# -------------------------------
# Training loss: 0.066877
# Validation loss: 0.077837
#
# Epoch 462
# -------------------------------
# Training loss: 0.066920
# Validation loss: 0.068079
#
# Epoch 463
# -------------------------------
# Training loss: 0.066872
# Validation loss: 0.070842
#
# Epoch 464
# -------------------------------
# Training loss: 0.071562
# Validation loss: 0.098406
#
# Epoch 465
# -------------------------------
# Training loss: 0.070087
# Validation loss: 0.101119
#
# Epoch 466
# -------------------------------
# Training loss: 0.068832
# Validation loss: 0.065183
#
# Epoch 467
# -------------------------------
# Training loss: 0.065091
# Validation loss: 0.101417
#
# Epoch 468
# -------------------------------
# Training loss: 0.066623
# Validation loss: 0.080186
#
# Epoch 469
# -------------------------------
# Training loss: 0.066948
# Validation loss: 0.307886
#
# Epoch 470
# -------------------------------
# Training loss: 0.067649
# Validation loss: 0.068932
#
# Epoch 471
# -------------------------------
# Training loss: 0.067424
# Validation loss: 0.069255
#
# Epoch 472
# -------------------------------
# Training loss: 0.068478
# Validation loss: 0.079434
#
# Epoch 473
# -------------------------------
# Training loss: 0.065284
# Validation loss: 0.079923
#
# Epoch 474
# -------------------------------
# Training loss: 0.065423
# Validation loss: 0.068536
#
# Epoch 475
# -------------------------------
# Training loss: 0.066266
# Validation loss: 0.069258
#
# Epoch 476
# -------------------------------
# Training loss: 0.068647
# Validation loss: 0.064328
#
# Epoch 477
# -------------------------------
# Training loss: 0.065191
# Validation loss: 0.176832
#
# Epoch 478
# -------------------------------
# Training loss: 0.067533
# Validation loss: 0.072916
#
# Epoch 479
# -------------------------------
# Training loss: 0.065945
# Validation loss: 0.067214
#
# Epoch 480
# -------------------------------
# Training loss: 0.068289
# Validation loss: 0.077032
#
# Epoch 481
# -------------------------------
# Training loss: 0.064848
# Validation loss: 0.136825
#
# Epoch 482
# -------------------------------
# Training loss: 0.065274
# Validation loss: 0.067145
#
# Epoch 483
# -------------------------------
# Training loss: 0.067039
# Validation loss: 0.106725
#
# Epoch 484
# -------------------------------
# Training loss: 0.070740
# Validation loss: 0.136002
#
# Epoch 485
# -------------------------------
# Training loss: 0.065717
# Validation loss: 0.072304
#
# Epoch 486
# -------------------------------
# Training loss: 0.065902
# Validation loss: 0.079237
#
# Epoch 487
# -------------------------------
# Training loss: 0.065990
# Validation loss: 0.079417
#
# Epoch 488
# -------------------------------
# Training loss: 0.067459
# Validation loss: 0.067722
#
# Epoch 489
# -------------------------------
# Training loss: 0.068066
# Validation loss: 0.077403
#
# Epoch 490
# -------------------------------
# Training loss: 0.066729
# Validation loss: 0.082343
#
# Epoch 491
# -------------------------------
# Training loss: 0.065615
# Validation loss: 0.072846
#
# Epoch 492
# -------------------------------
# Training loss: 0.065029
# Validation loss: 0.133898
#
# Epoch 493
# -------------------------------
# Training loss: 0.066337
# Validation loss: 0.066620
#
# Epoch 494
# -------------------------------
# Training loss: 0.063657
# Validation loss: 0.064864
#
# Epoch 495
# -------------------------------
# Training loss: 0.066746
# Validation loss: 0.078912
#
# Epoch 496
# -------------------------------
# Training loss: 0.064981
# Validation loss: 0.126700
#
# Epoch 497
# -------------------------------
# Training loss: 0.062448
# Validation loss: 0.064904
#
# Epoch 498
# -------------------------------
# Training loss: 0.063928
# Validation loss: 0.068621
#
# Epoch 499
# -------------------------------
# Training loss: 0.064376
# Validation loss: 0.079206
#
# Epoch 500
# -------------------------------
# Training loss: 0.064452
# Validation loss: 0.078510
#
# Done!

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses)+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('BCE Loss')
#plt.yscale('log')
plt.legend()

# %%
# Now test the pretrained model
test_pred = mytools.test_clas(test_loader, final_classifier, device)
test_pred=torch.sigmoid(torch.tensor(test_pred)).numpy()


fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test, test_pred, pos_label=1)
auc_test = sklearn.metrics.auc(fpr, tpr)
print(f'Test AUROC: {auc_test:0.4f}')

plt.plot(fpr, tpr, label=f'Test AUROC: {auc_test:0.4f}')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
# Out:
# Test AUROC: 0.9942

# %%
# Store the pretrained classifier labels
df_test["Class_pre"] = test_pred

# %% [markdown]
# # Setup the adversary model

# %% [markdown]
# ## Initialize model, objective function, and optimizer

# %%
adv = mytools.Adversary(n_classes=Num_classes).to(device)
criterion_adv = nn.CrossEntropyLoss(reduction='none')  # returns loss per sample so we can weight it
opt_adv = torch.optim.Adam(adv.parameters(), lr=1e-5)
scheduler_adv = torch.optim.lr_scheduler.ExponentialLR(opt_adv, gamma=0.999)

# %% [markdown]
# ## Setup dataloaders

# %%
# Convert to tensor dataset and dataloader

# the structure is: feature, adversary label, weight
# The wight is 1 for tritrig and wab, and 0 for phiKK, to prevent the adversary from learning on phiKK events

train_adv_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_train), (torch.from_numpy(y_train.to_numpy().astype(np.float32))==0).float())
train_adv_loader = DataLoader(train_adv_dataset, batch_size=bsize, shuffle=True)

val_adv_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_val), (torch.from_numpy(y_val.to_numpy().astype(np.float32))==0).float() )
val_adv_loader = DataLoader(val_adv_dataset, batch_size=bsize, shuffle=True)

# %% [markdown]
# ## Pre-train the adversary leaving classifier weights fixed

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 6

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 100
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train_adv(train_adv_loader, final_classifier, adv, criterion_adv, opt_adv, scheduler_adv, device))
    Validation_losses = np.append(Validation_losses, mytools.validate_adv(val_adv_loader, final_classifier, adv, criterion_adv, device))
    
    # Keep a running copy of the model with the lowest loss
    if Validation_losses[-1] == np.min(Validation_losses):
        final_adv = copy.deepcopy(adv)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Training loss: 1.594301
# Validation loss: 1.594696
#
# Epoch 2
# -------------------------------
# Training loss: 1.580113
# Validation loss: 1.580266
#
# Epoch 3
# -------------------------------
# Training loss: 1.571531
# Validation loss: 1.573752
#
# Epoch 4
# -------------------------------
# Training loss: 1.565966
# Validation loss: 1.568017
#
# Epoch 5
# -------------------------------
# Training loss: 1.562413
# Validation loss: 1.567882
#
# Epoch 6
# -------------------------------
# Training loss: 1.559599
# Validation loss: 1.563763
#
# Epoch 7
# -------------------------------
# Training loss: 1.556225
# Validation loss: 1.560874
#
# Epoch 8
# -------------------------------
# Training loss: 1.554067
# Validation loss: 1.560775
#
# Epoch 9
# -------------------------------
# Training loss: 1.553546
# Validation loss: 1.557825
#
# Epoch 10
# -------------------------------
# Training loss: 1.552536
# Validation loss: 1.558085
#
# Epoch 11
# -------------------------------
# Training loss: 1.550903
# Validation loss: 1.555238
#
# Epoch 12
# -------------------------------
# Training loss: 1.549316
# Validation loss: 1.555327
#
# Epoch 13
# -------------------------------
# Training loss: 1.548876
# Validation loss: 1.554196
#
# Epoch 14
# -------------------------------
# Training loss: 1.548334
# Validation loss: 1.554033
#
# Epoch 15
# -------------------------------
# Training loss: 1.546924
# Validation loss: 1.552983
#
# Epoch 16
# -------------------------------
# Training loss: 1.546234
# Validation loss: 1.552382
#
# Epoch 17
# -------------------------------
# Training loss: 1.546748
# Validation loss: 1.552548
#
# Epoch 18
# -------------------------------
# Training loss: 1.545827
# Validation loss: 1.553828
#
# Epoch 19
# -------------------------------
# Training loss: 1.544345
# Validation loss: 1.550493
#
# Epoch 20
# -------------------------------
# Training loss: 1.544427
# Validation loss: 1.551532
#
# Epoch 21
# -------------------------------
# Training loss: 1.544433
# Validation loss: 1.551995
#
# Epoch 22
# -------------------------------
# Training loss: 1.543752
# Validation loss: 1.549269
#
# Epoch 23
# -------------------------------
# Training loss: 1.544484
# Validation loss: 1.549062
#
# Epoch 24
# -------------------------------
# Training loss: 1.543324
# Validation loss: 1.549360
#
# Epoch 25
# -------------------------------
# Training loss: 1.542847
# Validation loss: 1.548976
#
# Epoch 26
# -------------------------------
# Training loss: 1.542180
# Validation loss: 1.549047
#
# Epoch 27
# -------------------------------
# Training loss: 1.542456
# Validation loss: 1.549576
#
# Epoch 28
# -------------------------------
# Training loss: 1.542295
# Validation loss: 1.549156
#
# Epoch 29
# -------------------------------
# Training loss: 1.541717
# Validation loss: 1.549425
#
# Epoch 30
# -------------------------------
# Training loss: 1.541765
# Validation loss: 1.549009
#
# Epoch 31
# -------------------------------
# Training loss: 1.541048
# Validation loss: 1.548840
#
# Epoch 32
# -------------------------------
# Training loss: 1.541533
# Validation loss: 1.548257
#
# Epoch 33
# -------------------------------
# Training loss: 1.541737
# Validation loss: 1.548538
#
# Epoch 34
# -------------------------------
# Training loss: 1.541473
# Validation loss: 1.548856
#
# Epoch 35
# -------------------------------
# Training loss: 1.540692
# Validation loss: 1.547738
#
# Epoch 36
# -------------------------------
# Training loss: 1.541988
# Validation loss: 1.548396
#
# Epoch 37
# -------------------------------
# Training loss: 1.540061
# Validation loss: 1.546927
#
# Epoch 38
# -------------------------------
# Training loss: 1.539713
# Validation loss: 1.547716
#
# Epoch 39
# -------------------------------
# Training loss: 1.539237
# Validation loss: 1.547100
#
# Epoch 40
# -------------------------------
# Training loss: 1.540694
# Validation loss: 1.547176
#
# Epoch 41
# -------------------------------
# Training loss: 1.540590
# Validation loss: 1.545762
#
# Epoch 42
# -------------------------------
# Training loss: 1.539695
# Validation loss: 1.547014
#
# Epoch 43
# -------------------------------
# Training loss: 1.540648
# Validation loss: 1.547201
#
# Epoch 44
# -------------------------------
# Training loss: 1.540158
# Validation loss: 1.545927
#
# Epoch 45
# -------------------------------
# Training loss: 1.540136
# Validation loss: 1.547390
#
# Epoch 46
# -------------------------------
# Training loss: 1.539222
# Validation loss: 1.546895
#
# Epoch 47
# -------------------------------
# Training loss: 1.540148
# Validation loss: 1.547608
#
# Epoch 48
# -------------------------------
# Training loss: 1.539244
# Validation loss: 1.546432
#
# Epoch 49
# -------------------------------
# Training loss: 1.539576
# Validation loss: 1.547174
#
# Epoch 50
# -------------------------------
# Training loss: 1.538740
# Validation loss: 1.548615
#
# Epoch 51
# -------------------------------
# Training loss: 1.539263
# Validation loss: 1.546990
#
# Epoch 52
# -------------------------------
# Training loss: 1.539328
# Validation loss: 1.545768
#
# Epoch 53
# -------------------------------
# Training loss: 1.539603
# Validation loss: 1.547394
#
# Epoch 54
# -------------------------------
# Training loss: 1.538859
# Validation loss: 1.545119
#
# Epoch 55
# -------------------------------
# Training loss: 1.538580
# Validation loss: 1.547541
#
# Epoch 56
# -------------------------------
# Training loss: 1.538989
# Validation loss: 1.547023
#
# Epoch 57
# -------------------------------
# Training loss: 1.538641
# Validation loss: 1.546501
#
# Epoch 58
# -------------------------------
# Training loss: 1.538641
# Validation loss: 1.546100
#
# Epoch 59
# -------------------------------
# Training loss: 1.538218
# Validation loss: 1.546364
#
# Epoch 60
# -------------------------------
# Training loss: 1.538894
# Validation loss: 1.545149
#
# Epoch 61
# -------------------------------
# Training loss: 1.538805
# Validation loss: 1.546179
#
# Epoch 62
# -------------------------------
# Training loss: 1.538380
# Validation loss: 1.546272
#
# Epoch 63
# -------------------------------
# Training loss: 1.538696
# Validation loss: 1.546212
#
# Epoch 64
# -------------------------------
# Training loss: 1.538645
# Validation loss: 1.547611
#
# Epoch 65
# -------------------------------
# Training loss: 1.538365
# Validation loss: 1.546644
#
# Epoch 66
# -------------------------------
# Training loss: 1.538686
# Validation loss: 1.546448
#
# Epoch 67
# -------------------------------
# Training loss: 1.537936
# Validation loss: 1.545572
#
# Epoch 68
# -------------------------------
# Training loss: 1.538423
# Validation loss: 1.545973
#
# Epoch 69
# -------------------------------
# Training loss: 1.539288
# Validation loss: 1.546227
#
# Epoch 70
# -------------------------------
# Training loss: 1.538409
# Validation loss: 1.546026
#
# Epoch 71
# -------------------------------
# Training loss: 1.539788
# Validation loss: 1.546697
#
# Epoch 72
# -------------------------------
# Training loss: 1.538237
# Validation loss: 1.545198
#
# Epoch 73
# -------------------------------
# Training loss: 1.539099
# Validation loss: 1.546512
#
# Epoch 74
# -------------------------------
# Training loss: 1.537982
# Validation loss: 1.545622
#
# Epoch 75
# -------------------------------
# Training loss: 1.537740
# Validation loss: 1.545788
#
# Epoch 76
# -------------------------------
# Training loss: 1.537747
# Validation loss: 1.546029
#
# Epoch 77
# -------------------------------
# Training loss: 1.538542
# Validation loss: 1.545931
#
# Epoch 78
# -------------------------------
# Training loss: 1.538887
# Validation loss: 1.545986
#
# Epoch 79
# -------------------------------
# Training loss: 1.537509
# Validation loss: 1.545377
#
# Epoch 80
# -------------------------------
# Training loss: 1.538256
# Validation loss: 1.545880
#
# Epoch 81
# -------------------------------
# Training loss: 1.538375
# Validation loss: 1.546077
#
# Epoch 82
# -------------------------------
# Training loss: 1.538768
# Validation loss: 1.544953
#
# Epoch 83
# -------------------------------
# Training loss: 1.537952
# Validation loss: 1.546426
#
# Epoch 84
# -------------------------------
# Training loss: 1.538636
# Validation loss: 1.545679
#
# Epoch 85
# -------------------------------
# Training loss: 1.537284
# Validation loss: 1.544866
#
# Epoch 86
# -------------------------------
# Training loss: 1.538163
# Validation loss: 1.545010
#
# Epoch 87
# -------------------------------
# Training loss: 1.539363
# Validation loss: 1.544193
#
# Epoch 88
# -------------------------------
# Training loss: 1.538238
# Validation loss: 1.544142
#
# Epoch 89
# -------------------------------
# Training loss: 1.538779
# Validation loss: 1.544395
#
# Epoch 90
# -------------------------------
# Training loss: 1.538445
# Validation loss: 1.546399
#
# Epoch 91
# -------------------------------
# Training loss: 1.538164
# Validation loss: 1.546389
#
# Epoch 92
# -------------------------------
# Training loss: 1.539007
# Validation loss: 1.545035
#
# Epoch 93
# -------------------------------
# Training loss: 1.538750
# Validation loss: 1.544905
#
# Epoch 94
# -------------------------------
# Training loss: 1.537848
# Validation loss: 1.544904
#
# Epoch 95
# -------------------------------
# Training loss: 1.537828
# Validation loss: 1.544374
#
# Epoch 96
# -------------------------------
# Training loss: 1.537970
# Validation loss: 1.545822
#
# Epoch 97
# -------------------------------
# Training loss: 1.538317
# Validation loss: 1.545815
#
# Epoch 98
# -------------------------------
# Training loss: 1.538364
# Validation loss: 1.545877
#
# Epoch 99
# -------------------------------
# Training loss: 1.538248
# Validation loss: 1.545907
#
# Epoch 100
# -------------------------------
# Training loss: 1.538616
# Validation loss: 1.545156
#
# Done!

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses)+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('BCE Loss')
plt.legend()

# %% [markdown]
# # Train full adverserial neural network

# %% [markdown]
# # Setup dataloaders

# %%
# the structure is: feature, classifier label, adversary label, weight
# The wight is 1 for tritrig and wab, and 0 for phiKK, to prevent the adversary from learning on phiKK events

train_full_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy().astype(np.float32))  , torch.from_numpy(y_train.to_numpy().astype(np.float32)).unsqueeze(1), torch.from_numpy(y_adv_train),  (torch.from_numpy(y_train.to_numpy().astype(np.float32))==0).float())
train_full_loader = DataLoader(train_full_dataset, batch_size=bsize, shuffle=True)

val_full_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy().astype(np.float32))  , torch.from_numpy(y_val.to_numpy().astype(np.float32)).unsqueeze(1),  torch.from_numpy(y_adv_val),  (torch.from_numpy(y_val.to_numpy().astype(np.float32))==0).float())
val_full_loader = DataLoader(val_full_dataset, batch_size=bsize, shuffle=True)

# %% [markdown]
# ## Define loss functions

# %%
BCE_loss = nn.BCEWithLogitsLoss()
CE_loss = nn.CrossEntropyLoss(reduction='none') # returns loss per sample so we can weight it

def full_loss(output_clas, output_adv, target_clas, target_adv, w, lambda_):

    loss1 = BCE_loss(output_clas, target_clas )  # classification loss
    sample_losses2 = CE_loss(output_adv, target_adv)  # adversarial losses, since we set reduction='none', this is now a vector of losses, one per sample in the batch

     # Weighted mean loss over non-zero weights
    nonzero = w > 0
    loss2 = (sample_losses2[nonzero] * w[nonzero]).sum() / w[nonzero].sum()

    loss = loss1 - lambda_*loss2

    return loss

# %% [markdown]
# ## Setup optimizers

# %%
optimizer_clas = optim.Adam(final_classifier.parameters(), lr=1e-7,betas=(0.5, 0.999))
optimizer_adv = optim.Adam(final_adv.parameters(), lr=1e-5,betas=(0.5, 0.999))

scheduler_clas = torch.optim.lr_scheduler.ExponentialLR(optimizer_clas, gamma=0.999)
scheduler_adv = torch.optim.lr_scheduler.ExponentialLR(optimizer_adv, gamma=0.999)

# %% [markdown]
# ## Adversarial training

# %%
Training_losses_clas = np.array([])
Training_losses_adv = np.array([])
Validation_losses_clas = np.array([])
Validation_losses_adv = np.array([])
diff_scores = np.array([])


epochs = 50
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")

    # Get validation losses
    E_clas_val_loss, E_adv_val_loss = mytools.validate_full(val_full_loader, final_classifier, final_adv, full_loss, lambda_, criterion_adv, device)
    Validation_losses_clas = np.append(Validation_losses_clas, E_clas_val_loss)
    Validation_losses_adv = np.append(Validation_losses_adv, E_adv_val_loss)

    # Train adversary and classifier
    E_clas_training_loss , E_adv_training_loss = mytools.train_full(train_full_loader, final_classifier, final_adv, full_loss, lambda_, criterion_adv, optimizer_clas, optimizer_adv, scheduler_clas, scheduler_adv, device)
    Training_losses_clas = np.append(Training_losses_clas, E_clas_training_loss)
    Training_losses_adv = np.append(Training_losses_adv, E_adv_training_loss)

    # Get the diff_score
    df_test["Class_adv"] = mytools.test_clas(test_loader, final_classifier, device)
    df_bkg = df_test.loc[ (df_test.type == 'tritrig') | (df_test.type == 'wab')]
    per = np.percentile(df_bkg['Class_adv'],99)
    df_cut = df_bkg[df_bkg['Class_adv']>per].reset_index(drop=True)
    x1 = 1000* df_bkg.InvM.values
    x2 = 1000*df_cut.InvM.values
    diff_scores = np.append(diff_scores, mytools.get_diff_score(x1,x2) )

    # Keep a running copy of the model with the lowest loss
    if diff_scores[-1] == np.min(diff_scores):
        final_clas_adv = copy.deepcopy(final_classifier)
        final_adv_adv = copy.deepcopy(final_adv)

            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Classifier validation loss: -154.469104
# Adversary validation loss: 1.545329
# Classifier training loss: -153.916717
# Adversary training loss: 1.540382
# Epoch 2
# -------------------------------
# Classifier validation loss: -154.750676
# Adversary validation loss: 1.548181
# Classifier training loss: -155.201729
# Adversary training loss: 1.553299
# Epoch 3
# -------------------------------
# Classifier validation loss: -155.893516
# Adversary validation loss: 1.559644
# Classifier training loss: -155.843769
# Adversary training loss: 1.559637
# Epoch 4
# -------------------------------
# Classifier validation loss: -156.032241
# Adversary validation loss: 1.561155
# Classifier training loss: -156.313560
# Adversary training loss: 1.564340
# Epoch 5
# -------------------------------
# Classifier validation loss: -155.803302
# Adversary validation loss: 1.559008
# Classifier training loss: -156.443979
# Adversary training loss: 1.565676
# Epoch 6
# -------------------------------
# Classifier validation loss: -156.620303
# Adversary validation loss: 1.567222
# Classifier training loss: -156.414440
# Adversary training loss: 1.565450
# Epoch 7
# -------------------------------
# Classifier validation loss: -156.965659
# Adversary validation loss: 1.570786
# Classifier training loss: -156.629813
# Adversary training loss: 1.567696
# Epoch 8
# -------------------------------
# Classifier validation loss: -157.152738
# Adversary validation loss: 1.572714
# Classifier training loss: -156.407012
# Adversary training loss: 1.565546
# Epoch 9
# -------------------------------
# Classifier validation loss: -156.626297
# Adversary validation loss: 1.567641
# Classifier training loss: -156.163302
# Adversary training loss: 1.563143
# Epoch 10
# -------------------------------
# Classifier validation loss: -156.520404
# Adversary validation loss: 1.566600
# Classifier training loss: -156.223273
# Adversary training loss: 1.563884
# Epoch 11
# -------------------------------
# Classifier validation loss: -156.575274
# Adversary validation loss: 1.567307
# Classifier training loss: -155.814059
# Adversary training loss: 1.559836
# Epoch 12
# -------------------------------
# Classifier validation loss: -156.452892
# Adversary validation loss: 1.566191
# Classifier training loss: -155.901685
# Adversary training loss: 1.560710
# Epoch 13
# -------------------------------
# Classifier validation loss: -156.227261
# Adversary validation loss: 1.563784
# Classifier training loss: -155.797066
# Adversary training loss: 1.559724
# Epoch 14
# -------------------------------
# Classifier validation loss: -156.140454
# Adversary validation loss: 1.563106
# Classifier training loss: -155.693434
# Adversary training loss: 1.558751
# Epoch 15
# -------------------------------
# Classifier validation loss: -156.064015
# Adversary validation loss: 1.562360
# Classifier training loss: -155.734949
# Adversary training loss: 1.559241
# Epoch 16
# -------------------------------
# Classifier validation loss: -156.008088
# Adversary validation loss: 1.561910
# Classifier training loss: -155.625183
# Adversary training loss: 1.558139
# Epoch 17
# -------------------------------
# Classifier validation loss: -155.780869
# Adversary validation loss: 1.559721
# Classifier training loss: -155.574419
# Adversary training loss: 1.557666
# Epoch 18
# -------------------------------
# Classifier validation loss: -155.687884
# Adversary validation loss: 1.558671
# Classifier training loss: -155.349478
# Adversary training loss: 1.555431
# Epoch 19
# -------------------------------
# Classifier validation loss: -155.765637
# Adversary validation loss: 1.559580
# Classifier training loss: -155.471486
# Adversary training loss: 1.556670
# Epoch 20
# -------------------------------
# Classifier validation loss: -155.644733
# Adversary validation loss: 1.558426
# Classifier training loss: -155.460350
# Adversary training loss: 1.556592
# Epoch 21
# -------------------------------
# Classifier validation loss: -155.653424
# Adversary validation loss: 1.558432
# Classifier training loss: -155.402357
# Adversary training loss: 1.556042
# Epoch 22
# -------------------------------
# Classifier validation loss: -155.698455
# Adversary validation loss: 1.559041
# Classifier training loss: -155.396878
# Adversary training loss: 1.555969
# Epoch 23
# -------------------------------
# Classifier validation loss: -155.597210
# Adversary validation loss: 1.557911
# Classifier training loss: -155.262617
# Adversary training loss: 1.554625
# Epoch 24
# -------------------------------
# Classifier validation loss: -155.688004
# Adversary validation loss: 1.558930
# Classifier training loss: -155.294153
# Adversary training loss: 1.554929
# Epoch 25
# -------------------------------
# Classifier validation loss: -155.581808
# Adversary validation loss: 1.557601
# Classifier training loss: -155.354536
# Adversary training loss: 1.555554
# Epoch 26
# -------------------------------
# Classifier validation loss: -155.559470
# Adversary validation loss: 1.557474
# Classifier training loss: -155.192085
# Adversary training loss: 1.553894
# Epoch 27
# -------------------------------
# Classifier validation loss: -155.600200
# Adversary validation loss: 1.557921
# Classifier training loss: -155.313379
# Adversary training loss: 1.555116
# Epoch 28
# -------------------------------
# Classifier validation loss: -155.673150
# Adversary validation loss: 1.558547
# Classifier training loss: -155.287810
# Adversary training loss: 1.554830
# Epoch 29
# -------------------------------
# Classifier validation loss: -155.860396
# Adversary validation loss: 1.560438
# Classifier training loss: -155.265890
# Adversary training loss: 1.554608
# Epoch 30
# -------------------------------
# Classifier validation loss: -155.812876
# Adversary validation loss: 1.559931
# Classifier training loss: -155.310749
# Adversary training loss: 1.555030
# Epoch 31
# -------------------------------
# Classifier validation loss: -155.813707
# Adversary validation loss: 1.559921
# Classifier training loss: -155.391264
# Adversary training loss: 1.555859
# Epoch 32
# -------------------------------
# Classifier validation loss: -155.593424
# Adversary validation loss: 1.557821
# Classifier training loss: -155.354096
# Adversary training loss: 1.555471
# Epoch 33
# -------------------------------
# Classifier validation loss: -155.783631
# Adversary validation loss: 1.559725
# Classifier training loss: -155.344125
# Adversary training loss: 1.555363
# Epoch 34
# -------------------------------
# Classifier validation loss: -155.821170
# Adversary validation loss: 1.560115
# Classifier training loss: -155.459475
# Adversary training loss: 1.556499
# Epoch 35
# -------------------------------
# Classifier validation loss: -155.735679
# Adversary validation loss: 1.559201
# Classifier training loss: -155.391003
# Adversary training loss: 1.555809
# Epoch 36
# -------------------------------
# Classifier validation loss: -155.663460
# Adversary validation loss: 1.558529
# Classifier training loss: -155.406907
# Adversary training loss: 1.555944
# Epoch 37
# -------------------------------
# Classifier validation loss: -156.024859
# Adversary validation loss: 1.561946
# Classifier training loss: -155.449492
# Adversary training loss: 1.556382
# Epoch 38
# -------------------------------
# Classifier validation loss: -155.676382
# Adversary validation loss: 1.558567
# Classifier training loss: -155.469668
# Adversary training loss: 1.556559
# Epoch 39
# -------------------------------
# Classifier validation loss: -155.888523
# Adversary validation loss: 1.560708
# Classifier training loss: -155.405290
# Adversary training loss: 1.555912
# Epoch 40
# -------------------------------
# Classifier validation loss: -155.704313
# Adversary validation loss: 1.558862
# Classifier training loss: -155.377308
# Adversary training loss: 1.555620
# Epoch 41
# -------------------------------
# Classifier validation loss: -155.829150
# Adversary validation loss: 1.560122
# Classifier training loss: -155.470659
# Adversary training loss: 1.556530
# Epoch 42
# -------------------------------
# Classifier validation loss: -155.704719
# Adversary validation loss: 1.558677
# Classifier training loss: -155.438302
# Adversary training loss: 1.556217
# Epoch 43
# -------------------------------
# Classifier validation loss: -155.901430
# Adversary validation loss: 1.560762
# Classifier training loss: -155.416273
# Adversary training loss: 1.556016
# Epoch 44
# -------------------------------
# Classifier validation loss: -155.638847
# Adversary validation loss: 1.558196
# Classifier training loss: -155.431668
# Adversary training loss: 1.556155
# Epoch 45
# -------------------------------
# Classifier validation loss: -155.613931
# Adversary validation loss: 1.557830
# Classifier training loss: -155.289166
# Adversary training loss: 1.554696
# Epoch 46
# -------------------------------
# Classifier validation loss: -155.660481
# Adversary validation loss: 1.558426
# Classifier training loss: -155.437458
# Adversary training loss: 1.556191
# Epoch 47
# -------------------------------
# Classifier validation loss: -155.838263
# Adversary validation loss: 1.560061
# Classifier training loss: -155.355540
# Adversary training loss: 1.555364
# Epoch 48
# -------------------------------
# Classifier validation loss: -155.755885
# Adversary validation loss: 1.559325
# Classifier training loss: -155.385803
# Adversary training loss: 1.555632
# Epoch 49
# -------------------------------
# Classifier validation loss: -155.889334
# Adversary validation loss: 1.560497
# Classifier training loss: -155.355058
# Adversary training loss: 1.555321
# Epoch 50
# -------------------------------
# Classifier validation loss: -155.725608
# Adversary validation loss: 1.558886
# Classifier training loss: -155.310816
# Adversary training loss: 1.554904
# Done!

# %%
fig, ax1 = plt.subplots()

best_epoch = np.argmin(diff_scores)+1



#ax1.plot(np.arange(len(Training_losses_adv))+1, Training_losses_adv, 'k-', label='Training Adversary')
ax1.plot(np.arange(len(Validation_losses_adv))+1, Validation_losses_adv, 'k-', label='Validation Adversary')

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Adversary Loss', color='k')
ax1.tick_params(axis='y', labelcolor='k')

ax2 = ax1.twinx()

#ax2.plot(np.arange(len(Training_losses_clas))+1, Training_losses_clas, 'r-', label='Training Classifier')
ax2.plot(np.arange(len(Validation_losses_clas))+1, Validation_losses_clas, 'r-', label='Validation Classifier')
ax2.axvline(best_epoch,label="Final model stopped here",color='k')

ax2.set_ylabel('Classifier Loss', color='r')
ax2.tick_params(axis='y', labelcolor='r')

# %% [markdown]
# ## Test adversarially trained models

# %%
# Now test the pretrained model
test_pred = mytools.test_clas(test_loader, final_clas_adv, device)
test_pred=torch.sigmoid(torch.tensor(test_pred)).numpy()


fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test, test_pred, pos_label=1)
auc_test = sklearn.metrics.auc(fpr, tpr)
print(f'Test AUROC: {auc_test:0.4f}')

plt.plot(fpr, tpr, label=f'Test AUROC: {auc_test:0.4f}')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
# Out:
# Test AUROC: 0.9898

# %%
df_test["Class_adv"] = test_pred
df_bkg = df_test.loc[ (df_test.type == 'tritrig') | (df_test.type == 'wab')]
per = np.percentile(df_bkg['Class_adv'],99)
df_cut = df_bkg[df_bkg['Class_adv']>per].reset_index(drop=True)
x_vals = 1000*df_cut.InvM

plt.figure()
plt.hist(1000*df_bkg.InvM, bins=np.arange(980,1250,1), histtype='step', label='No selection', density=True)
plt.hist(x_vals, bins=np.arange(980,1250,1), histtype='step', label= '99 percent selection', density=True)
plt.axvline(1019.461, color='k', linestyle='dashed', linewidth=1, label='PDG phi mass')
plt.xlabel('Invariant Mass [MeV]')
plt.ylabel('Normalized Counts')
plt.legend()

# %%
x1 = 1000* df_bkg.InvM.values
x2 = 1000*df_cut.InvM.values

N, edges = np.histogram(x1, bins=np.arange(980,1250,1), density=False)
M, edges = np.histogram(x2, bins=np.arange(980,1250,1), density=False)

N2 = N[(N > 0) & (M > 0)]
M2 = M[(N > 0) & (M > 0)]

diff_score = np.mean(np.abs(N2/np.sum(N)-M2/np.sum(M)) / (np.sqrt(N2)/np.sum(N) + np.sqrt(M2)/np.sum(M) ))

print(diff_score)

N = len(df_test.loc[ ((df_test.type == 'tritrig') | (df_test.type == 'wab')) & (df_test.InvM < (1.019 + 0.01) )  & (df_test.InvM > (1.019 - 0.01) ) & ( df_test['Class_adv']>per ) ] )
S = len(df_test.loc[ (df_test.type == 'phiKK') & (df_test.InvM < (1.019 + 0.01) )  & (df_test.InvM > (1.019 - 0.01) ) & ( df_test['Class_adv']>per )  ] )

print(S/N)
# Out:
# 0.6764801373870173
# 4.604761904761904

# %%
df_test["Class_adv"] = test_pred
df_test.to_pickle("/Users/mghrear/data/ML_data/patch/ANN_results_2021_relu_run"+str(run)+"_limited_sideband_a.pk")

# %%
# Save the adversarially trained models
torch.save(final_clas_adv.state_dict(), "/Users/mghrear/data/ML_data/patch/classifier_adv_2021_v9_pass5_run"+str(run)+"_limited_sideband_a.pt")
torch.save(final_adv_adv.state_dict(), "/Users/mghrear/data/ML_data/patch/adversary_adv_2021_v9_pass5_run"+str(run)+"_limited_sideband_a.pt")

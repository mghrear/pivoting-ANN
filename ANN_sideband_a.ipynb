# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import torch 
from torch import nn, optim
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import sklearn
from sklearn.model_selection import train_test_split
import copy
import mytools
from scipy.stats import ks_2samp, wasserstein_distance


# Print and store device being used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cpu

# %% [markdown]
# # Define important parameters

# %%
# Number of class in invariant mass used by the adversary
Num_classes = 5
# Hyper-parameter for adversarial training of the classifier
lambda_ = 100.0

run = 1

# %% [markdown]
# # Load and setup the data

# %%
df_tritrig = pd.read_pickle('/Users/mghrear/data/ML_data/patch/2021_v9_pass5_tritrig_limited.pk')
df_tritrig['PhiKK'] = 0.0 # Add label
df_phiKK = pd.read_pickle('/Users/mghrear/data/ML_data/patch/2021_v9_pass5_phiKK_limited.pk')
df_phiKK['PhiKK'] = 1.0 # Add label
df_wab = pd.read_pickle('/Users/mghrear/data/ML_data/patch/2021_v9_pass5_wab_limited.pk')
df_wab['PhiKK'] = 0.0 # Add label

df_data_train_bkg = pd.read_pickle('/Users/mghrear/data/ML_data/patch/2021_v9_pass5_data_limited_sideband_a_train_bkg.pk')
df_data_train_bkg['PhiKK'] = 0.0 # Add label

df_data = pd.read_pickle('/Users/mghrear/data/ML_data/patch/2021_v9_pass5_data_limited_sideband_a_test.pk')

print("phiKK: ", len(df_phiKK))
print("data bkg: ", len(df_data_train_bkg))
print("data: ", len(df_data))
# Out:
# phiKK:  4086
# data bkg:  22849
# data:  163958

# %%
phiKK_train = df_phiKK[0:3000]


# Combine and shuffle all training data
df_train = pd.concat([phiKK_train, df_data_train_bkg], ignore_index=True, sort=False)
df_train = df_train.sample(frac=1, random_state=42).reset_index(drop=True)

# Get edges in invariant mass classes for one-hot encoding
# To be used for adverserial labels
# The edges are chosen such that each bin has equal number of background events
one_hot_edges = mytools.get_one_hot_edges(mytools.get_InvM( df_data ), n_bins=Num_classes)

# Split the training data into training and validation sets
df_train, df_val = train_test_split(df_train, test_size=0.33, random_state=41)

# Make X and y for training and validation sets
# the adverserial network has its own labels
X_train = df_train.drop(columns=['PhiKK'])
y_train = df_train['PhiKK']
y_adv_train = mytools.get_adv_labels( mytools.get_InvM(df_train), one_hot_edges)
X_val = df_val.drop(columns=['PhiKK'])
y_val = df_val['PhiKK']
y_adv_val = mytools.get_adv_labels( mytools.get_InvM(df_val), one_hot_edges)

# Make testing set with remaining events
tritrig_test = df_tritrig[20000:]
tritrig_test['type']= 'tritrig'
wab_test = df_wab[3000:]
wab_test['type']= 'wab'
phiKK_test = df_phiKK[3000:]
phiKK_test['type']= 'phiKK'

# This is just used for an invariance test
df_test = pd.concat([tritrig_test, phiKK_test,wab_test], ignore_index=True, sort=False)
df_test = df_test.sample(frac=1, random_state=42).reset_index(drop=True) # Now shuffle the combined dataframe

X_test = df_test.drop(columns=['PhiKK','type'])
y_test = df_test['PhiKK']
y_adv_test = mytools.get_adv_labels( mytools.get_InvM(df_test), one_hot_edges)

df_test["InvM"] = mytools.get_InvM(df_test) 



# Make final data set
X_final = df_data
# Out:
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_23896/3652916753.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tritrig_test['type']= 'tritrig'
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_23896/3652916753.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wab_test['type']= 'wab'
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_23896/3652916753.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phiKK_test['type']= 'phiKK'

# %% [markdown]
# # Setup the classifier model

# %% [markdown]
# ## Setup dataloaders

# %%
bsize = 2000

# Convert to tensor dataset and dataloader
train_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy().astype(np.float32))  , torch.from_numpy(y_train.to_numpy().astype(np.float32)).unsqueeze(1)  )
train_loader = DataLoader(train_dataset, batch_size=bsize, shuffle=True)

val_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy().astype(np.float32))  , torch.from_numpy(y_val.to_numpy().astype(np.float32)).unsqueeze(1)  )
val_loader = DataLoader(val_dataset, batch_size=bsize, shuffle=True)

test_dataset = TensorDataset(torch.from_numpy(X_test.to_numpy().astype(np.float32))  )
test_loader = DataLoader(test_dataset, batch_size=bsize, shuffle=False)

# %% [markdown]
# ## Initialize model, objective function, and optimizer

# %%
clas = mytools.Classifier(in_features=X_train.shape[1]).to(device)
criterion_clas = nn.BCEWithLogitsLoss()
optimizer_clas = optim.Adam(clas.parameters(), lr=1e-5)
scheduler_clas = torch.optim.lr_scheduler.ExponentialLR(optimizer_clas, gamma=0.99995)

# %% [markdown]
# ## Pre-train the classifier

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 10

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 2500
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train_clas(train_loader, clas, criterion_clas, optimizer_clas, scheduler_clas, device))
    Validation_losses = np.append(Validation_losses, mytools.validate_clas(val_loader, clas, criterion_clas, device))
    
    # Keep a running copy of the model with the lowest loss
    if Validation_losses[-1] == np.min(Validation_losses):
        final_classifier = copy.deepcopy(clas)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Training loss: 0.651092
# Validation loss: 0.698562
#
# Epoch 2
# -------------------------------
# Training loss: 0.628663
# Validation loss: 0.686543
#
# Epoch 3
# -------------------------------
# Training loss: 0.615150
# Validation loss: 0.619721
#
# Epoch 4
# -------------------------------
# Training loss: 0.600580
# Validation loss: 0.582214
#
# Epoch 5
# -------------------------------
# Training loss: 0.591208
# Validation loss: 0.588597
#
# Epoch 6
# -------------------------------
# Training loss: 0.580794
# Validation loss: 0.578604
#
# Epoch 7
# -------------------------------
# Training loss: 0.573328
# Validation loss: 0.566211
#
# Epoch 8
# -------------------------------
# Training loss: 0.566169
# Validation loss: 0.559324
#
# Epoch 9
# -------------------------------
# Training loss: 0.559293
# Validation loss: 0.551650
#
# Epoch 10
# -------------------------------
# Training loss: 0.555128
# Validation loss: 0.543063
#
# Epoch 11
# -------------------------------
# Training loss: 0.548139
# Validation loss: 0.539628
#
# Epoch 12
# -------------------------------
# Training loss: 0.545088
# Validation loss: 0.533572
#
# Epoch 13
# -------------------------------
# Training loss: 0.539535
# Validation loss: 0.524057
#
# Epoch 14
# -------------------------------
# Training loss: 0.536842
# Validation loss: 0.520435
#
# Epoch 15
# -------------------------------
# Training loss: 0.532195
# Validation loss: 0.517395
#
# Epoch 16
# -------------------------------
# Training loss: 0.527547
# Validation loss: 0.516745
#
# Epoch 17
# -------------------------------
# Training loss: 0.524186
# Validation loss: 0.515701
#
# Epoch 18
# -------------------------------
# Training loss: 0.519812
# Validation loss: 0.510882
#
# Epoch 19
# -------------------------------
# Training loss: 0.517300
# Validation loss: 0.504365
#
# Epoch 20
# -------------------------------
# Training loss: 0.514995
# Validation loss: 0.500743
#
# Epoch 21
# -------------------------------
# Training loss: 0.510754
# Validation loss: 0.499547
#
# Epoch 22
# -------------------------------
# Training loss: 0.511525
# Validation loss: 0.495632
#
# Epoch 23
# -------------------------------
# Training loss: 0.504377
# Validation loss: 0.494957
#
# Epoch 24
# -------------------------------
# Training loss: 0.504973
# Validation loss: 0.496406
#
# Epoch 25
# -------------------------------
# Training loss: 0.499188
# Validation loss: 0.493210
#
# Epoch 26
# -------------------------------
# Training loss: 0.496057
# Validation loss: 0.490993
#
# Epoch 27
# -------------------------------
# Training loss: 0.494570
# Validation loss: 0.491662
#
# Epoch 28
# -------------------------------
# Training loss: 0.492800
# Validation loss: 0.487501
#
# Epoch 29
# -------------------------------
# Training loss: 0.490475
# Validation loss: 0.482317
#
# Epoch 30
# -------------------------------
# Training loss: 0.489498
# Validation loss: 0.480892
#
# Epoch 31
# -------------------------------
# Training loss: 0.485957
# Validation loss: 0.480834
#
# Epoch 32
# -------------------------------
# Training loss: 0.481253
# Validation loss: 0.482167
#
# Epoch 33
# -------------------------------
# Training loss: 0.481288
# Validation loss: 0.478973
#
# Epoch 34
# -------------------------------
# Training loss: 0.479562
# Validation loss: 0.471720
#
# Epoch 35
# -------------------------------
# Training loss: 0.477550
# Validation loss: 0.475147
#
# Epoch 36
# -------------------------------
# Training loss: 0.473549
# Validation loss: 0.470410
#
# Epoch 37
# -------------------------------
# Training loss: 0.472952
# Validation loss: 0.468188
#
# Epoch 38
# -------------------------------
# Training loss: 0.469612
# Validation loss: 0.463750
#
# Epoch 39
# -------------------------------
# Training loss: 0.467152
# Validation loss: 0.466289
#
# Epoch 40
# -------------------------------
# Training loss: 0.467790
# Validation loss: 0.462856
#
# Epoch 41
# -------------------------------
# Training loss: 0.467390
# Validation loss: 0.456462
#
# Epoch 42
# -------------------------------
# Training loss: 0.465679
# Validation loss: 0.458546
#
# Epoch 43
# -------------------------------
# Training loss: 0.459752
# Validation loss: 0.451005
#
# Epoch 44
# -------------------------------
# Training loss: 0.459971
# Validation loss: 0.458751
#
# Epoch 45
# -------------------------------
# Training loss: 0.463769
# Validation loss: 0.452985
#
# Epoch 46
# -------------------------------
# Training loss: 0.456070
# Validation loss: 0.447608
#
# Epoch 47
# -------------------------------
# Training loss: 0.455101
# Validation loss: 0.454428
#
# Epoch 48
# -------------------------------
# Training loss: 0.453133
# Validation loss: 0.448947
#
# Epoch 49
# -------------------------------
# Training loss: 0.451714
# Validation loss: 0.447842
#
# Epoch 50
# -------------------------------
# Training loss: 0.455461
# Validation loss: 0.449810
#
# Epoch 51
# -------------------------------
# Training loss: 0.449218
# Validation loss: 0.441250
#
# Epoch 52
# -------------------------------
# Training loss: 0.447436
# Validation loss: 0.441367
#
# Epoch 53
# -------------------------------
# Training loss: 0.448433
# Validation loss: 0.433430
#
# Epoch 54
# -------------------------------
# Training loss: 0.444393
# Validation loss: 0.442333
#
# Epoch 55
# -------------------------------
# Training loss: 0.443670
# Validation loss: 0.438793
#
# Epoch 56
# -------------------------------
# Training loss: 0.441483
# Validation loss: 0.437186
#
# Epoch 57
# -------------------------------
# Training loss: 0.439876
# Validation loss: 0.437801
#
# Epoch 58
# -------------------------------
# Training loss: 0.441278
# Validation loss: 0.434769
#
# Epoch 59
# -------------------------------
# Training loss: 0.436799
# Validation loss: 0.437949
#
# Epoch 60
# -------------------------------
# Training loss: 0.436029
# Validation loss: 0.428614
#
# Epoch 61
# -------------------------------
# Training loss: 0.433626
# Validation loss: 0.428574
#
# Epoch 62
# -------------------------------
# Training loss: 0.432856
# Validation loss: 0.425345
#
# Epoch 63
# -------------------------------
# Training loss: 0.435165
# Validation loss: 0.425674
#
# Epoch 64
# -------------------------------
# Training loss: 0.429322
# Validation loss: 0.427057
#
# Epoch 65
# -------------------------------
# Training loss: 0.430053
# Validation loss: 0.422376
#
# Epoch 66
# -------------------------------
# Training loss: 0.425808
# Validation loss: 0.419921
#
# Epoch 67
# -------------------------------
# Training loss: 0.428643
# Validation loss: 0.420552
#
# Epoch 68
# -------------------------------
# Training loss: 0.423930
# Validation loss: 0.420570
#
# Epoch 69
# -------------------------------
# Training loss: 0.425412
# Validation loss: 0.419313
#
# Epoch 70
# -------------------------------
# Training loss: 0.421387
# Validation loss: 0.416808
#
# Epoch 71
# -------------------------------
# Training loss: 0.423176
# Validation loss: 0.413940
#
# Epoch 72
# -------------------------------
# Training loss: 0.425269
# Validation loss: 0.415929
#
# Epoch 73
# -------------------------------
# Training loss: 0.421786
# Validation loss: 0.418823
#
# Epoch 74
# -------------------------------
# Training loss: 0.416289
# Validation loss: 0.413345
#
# Epoch 75
# -------------------------------
# Training loss: 0.416982
# Validation loss: 0.410348
#
# Epoch 76
# -------------------------------
# Training loss: 0.417381
# Validation loss: 0.410556
#
# Epoch 77
# -------------------------------
# Training loss: 0.416079
# Validation loss: 0.408451
#
# Epoch 78
# -------------------------------
# Training loss: 0.415864
# Validation loss: 0.405368
#
# Epoch 79
# -------------------------------
# Training loss: 0.415729
# Validation loss: 0.410921
#
# Epoch 80
# -------------------------------
# Training loss: 0.417389
# Validation loss: 0.410147
#
# Epoch 81
# -------------------------------
# Training loss: 0.413702
# Validation loss: 0.411258
#
# Epoch 82
# -------------------------------
# Training loss: 0.412468
# Validation loss: 0.406570
#
# Epoch 83
# -------------------------------
# Training loss: 0.410712
# Validation loss: 0.409582
#
# Epoch 84
# -------------------------------
# Training loss: 0.417479
# Validation loss: 0.407704
#
# Epoch 85
# -------------------------------
# Training loss: 0.410334
# Validation loss: 0.405310
#
# Epoch 86
# -------------------------------
# Training loss: 0.409044
# Validation loss: 0.401978
#
# Epoch 87
# -------------------------------
# Training loss: 0.407543
# Validation loss: 0.404129
#
# Epoch 88
# -------------------------------
# Training loss: 0.403689
# Validation loss: 0.400345
#
# Epoch 89
# -------------------------------
# Training loss: 0.406481
# Validation loss: 0.402136
#
# Epoch 90
# -------------------------------
# Training loss: 0.403059
# Validation loss: 0.402501
#
# Epoch 91
# -------------------------------
# Training loss: 0.402700
# Validation loss: 0.400868
#
# Epoch 92
# -------------------------------
# Training loss: 0.403806
# Validation loss: 0.402732
#
# Epoch 93
# -------------------------------
# Training loss: 0.401918
# Validation loss: 0.400323
#
# Epoch 94
# -------------------------------
# Training loss: 0.401366
# Validation loss: 0.401101
#
# Epoch 95
# -------------------------------
# Training loss: 0.400430
# Validation loss: 0.395208
#
# Epoch 96
# -------------------------------
# Training loss: 0.402133
# Validation loss: 0.395809
#
# Epoch 97
# -------------------------------
# Training loss: 0.398807
# Validation loss: 0.401649
#
# Epoch 98
# -------------------------------
# Training loss: 0.401113
# Validation loss: 0.392188
#
# Epoch 99
# -------------------------------
# Training loss: 0.399072
# Validation loss: 0.392556
#
# Epoch 100
# -------------------------------
# Training loss: 0.398568
# Validation loss: 0.392456
#
# Epoch 101
# -------------------------------
# Training loss: 0.397741
# Validation loss: 0.397335
#
# Epoch 102
# -------------------------------
# Training loss: 0.398968
# Validation loss: 0.391186
#
# Epoch 103
# -------------------------------
# Training loss: 0.396530
# Validation loss: 0.389928
#
# Epoch 104
# -------------------------------
# Training loss: 0.395483
# Validation loss: 0.392773
#
# Epoch 105
# -------------------------------
# Training loss: 0.394141
# Validation loss: 0.391339
#
# Epoch 106
# -------------------------------
# Training loss: 0.395012
# Validation loss: 0.390403
#
# Epoch 107
# -------------------------------
# Training loss: 0.392546
# Validation loss: 0.390691
#
# Epoch 108
# -------------------------------
# Training loss: 0.393717
# Validation loss: 0.386693
#
# Epoch 109
# -------------------------------
# Training loss: 0.396287
# Validation loss: 0.387895
#
# Epoch 110
# -------------------------------
# Training loss: 0.394202
# Validation loss: 0.387491
#
# Epoch 111
# -------------------------------
# Training loss: 0.389002
# Validation loss: 0.384531
#
# Epoch 112
# -------------------------------
# Training loss: 0.393397
# Validation loss: 0.387452
#
# Epoch 113
# -------------------------------
# Training loss: 0.388247
# Validation loss: 0.388227
#
# Epoch 114
# -------------------------------
# Training loss: 0.388176
# Validation loss: 0.386261
#
# Epoch 115
# -------------------------------
# Training loss: 0.390143
# Validation loss: 0.386583
#
# Epoch 116
# -------------------------------
# Training loss: 0.385739
# Validation loss: 0.384652
#
# Epoch 117
# -------------------------------
# Training loss: 0.384943
# Validation loss: 0.382021
#
# Epoch 118
# -------------------------------
# Training loss: 0.387527
# Validation loss: 0.383745
#
# Epoch 119
# -------------------------------
# Training loss: 0.385743
# Validation loss: 0.379788
#
# Epoch 120
# -------------------------------
# Training loss: 0.383457
# Validation loss: 0.379266
#
# Epoch 121
# -------------------------------
# Training loss: 0.382869
# Validation loss: 0.383237
#
# Epoch 122
# -------------------------------
# Training loss: 0.380995
# Validation loss: 0.383046
#
# Epoch 123
# -------------------------------
# Training loss: 0.384223
# Validation loss: 0.382136
#
# Epoch 124
# -------------------------------
# Training loss: 0.383458
# Validation loss: 0.383500
#
# Epoch 125
# -------------------------------
# Training loss: 0.383267
# Validation loss: 0.380001
#
# Epoch 126
# -------------------------------
# Training loss: 0.383460
# Validation loss: 0.377098
#
# Epoch 127
# -------------------------------
# Training loss: 0.387749
# Validation loss: 0.376693
#
# Epoch 128
# -------------------------------
# Training loss: 0.382124
# Validation loss: 0.379173
#
# Epoch 129
# -------------------------------
# Training loss: 0.382209
# Validation loss: 0.376928
#
# Epoch 130
# -------------------------------
# Training loss: 0.378612
# Validation loss: 0.382980
#
# Epoch 131
# -------------------------------
# Training loss: 0.380372
# Validation loss: 0.375276
#
# Epoch 132
# -------------------------------
# Training loss: 0.377800
# Validation loss: 0.379079
#
# Epoch 133
# -------------------------------
# Training loss: 0.377358
# Validation loss: 0.373517
#
# Epoch 134
# -------------------------------
# Training loss: 0.378681
# Validation loss: 0.376886
#
# Epoch 135
# -------------------------------
# Training loss: 0.376552
# Validation loss: 0.382520
#
# Epoch 136
# -------------------------------
# Training loss: 0.377451
# Validation loss: 0.376471
#
# Epoch 137
# -------------------------------
# Training loss: 0.375166
# Validation loss: 0.376645
#
# Epoch 138
# -------------------------------
# Training loss: 0.373713
# Validation loss: 0.370203
#
# Epoch 139
# -------------------------------
# Training loss: 0.372593
# Validation loss: 0.373353
#
# Epoch 140
# -------------------------------
# Training loss: 0.372272
# Validation loss: 0.375172
#
# Epoch 141
# -------------------------------
# Training loss: 0.373608
# Validation loss: 0.373576
#
# Epoch 142
# -------------------------------
# Training loss: 0.375941
# Validation loss: 0.370433
#
# Epoch 143
# -------------------------------
# Training loss: 0.373772
# Validation loss: 0.370419
#
# Epoch 144
# -------------------------------
# Training loss: 0.371192
# Validation loss: 0.372637
#
# Epoch 145
# -------------------------------
# Training loss: 0.374483
# Validation loss: 0.364176
#
# Epoch 146
# -------------------------------
# Training loss: 0.370458
# Validation loss: 0.367532
#
# Epoch 147
# -------------------------------
# Training loss: 0.373118
# Validation loss: 0.367762
#
# Epoch 148
# -------------------------------
# Training loss: 0.370241
# Validation loss: 0.372746
#
# Epoch 149
# -------------------------------
# Training loss: 0.369770
# Validation loss: 0.367220
#
# Epoch 150
# -------------------------------
# Training loss: 0.369042
# Validation loss: 0.369836
#
# Epoch 151
# -------------------------------
# Training loss: 0.369095
# Validation loss: 0.364294
#
# Epoch 152
# -------------------------------
# Training loss: 0.370206
# Validation loss: 0.362432
#
# Epoch 153
# -------------------------------
# Training loss: 0.367936
# Validation loss: 0.369104
#
# Epoch 154
# -------------------------------
# Training loss: 0.367696
# Validation loss: 0.367575
#
# Epoch 155
# -------------------------------
# Training loss: 0.369593
# Validation loss: 0.368633
#
# Epoch 156
# -------------------------------
# Training loss: 0.366578
# Validation loss: 0.363983
#
# Epoch 157
# -------------------------------
# Training loss: 0.366653
# Validation loss: 0.362348
#
# Epoch 158
# -------------------------------
# Training loss: 0.365353
# Validation loss: 0.364378
#
# Epoch 159
# -------------------------------
# Training loss: 0.370775
# Validation loss: 0.370847
#
# Epoch 160
# -------------------------------
# Training loss: 0.366178
# Validation loss: 0.358920
#
# Epoch 161
# -------------------------------
# Training loss: 0.366690
# Validation loss: 0.362039
#
# Epoch 162
# -------------------------------
# Training loss: 0.367202
# Validation loss: 0.355651
#
# Epoch 163
# -------------------------------
# Training loss: 0.364355
# Validation loss: 0.364896
#
# Epoch 164
# -------------------------------
# Training loss: 0.365322
# Validation loss: 0.361896
#
# Epoch 165
# -------------------------------
# Training loss: 0.366056
# Validation loss: 0.365050
#
# Epoch 166
# -------------------------------
# Training loss: 0.366555
# Validation loss: 0.357545
#
# Epoch 167
# -------------------------------
# Training loss: 0.362665
# Validation loss: 0.360750
#
# Epoch 168
# -------------------------------
# Training loss: 0.362555
# Validation loss: 0.358546
#
# Epoch 169
# -------------------------------
# Training loss: 0.362949
# Validation loss: 0.360927
#
# Epoch 170
# -------------------------------
# Training loss: 0.365082
# Validation loss: 0.360037
#
# Epoch 171
# -------------------------------
# Training loss: 0.361235
# Validation loss: 0.358171
#
# Epoch 172
# -------------------------------
# Training loss: 0.362119
# Validation loss: 0.365664
#
# Epoch 173
# -------------------------------
# Training loss: 0.358141
# Validation loss: 0.357692
#
# Epoch 174
# -------------------------------
# Training loss: 0.358462
# Validation loss: 0.358082
#
# Epoch 175
# -------------------------------
# Training loss: 0.358968
# Validation loss: 0.362007
#
# Epoch 176
# -------------------------------
# Training loss: 0.359500
# Validation loss: 0.352635
#
# Epoch 177
# -------------------------------
# Training loss: 0.356791
# Validation loss: 0.360014
#
# Epoch 178
# -------------------------------
# Training loss: 0.357274
# Validation loss: 0.365776
#
# Epoch 179
# -------------------------------
# Training loss: 0.356323
# Validation loss: 0.355835
#
# Epoch 180
# -------------------------------
# Training loss: 0.358638
# Validation loss: 0.354123
#
# Epoch 181
# -------------------------------
# Training loss: 0.356492
# Validation loss: 0.349188
#
# Epoch 182
# -------------------------------
# Training loss: 0.355690
# Validation loss: 0.353199
#
# Epoch 183
# -------------------------------
# Training loss: 0.355031
# Validation loss: 0.357708
#
# Epoch 184
# -------------------------------
# Training loss: 0.358230
# Validation loss: 0.359257
#
# Epoch 185
# -------------------------------
# Training loss: 0.354316
# Validation loss: 0.350592
#
# Epoch 186
# -------------------------------
# Training loss: 0.355298
# Validation loss: 0.347093
#
# Epoch 187
# -------------------------------
# Training loss: 0.353641
# Validation loss: 0.361515
#
# Epoch 188
# -------------------------------
# Training loss: 0.353567
# Validation loss: 0.359356
#
# Epoch 189
# -------------------------------
# Training loss: 0.351223
# Validation loss: 0.351971
#
# Epoch 190
# -------------------------------
# Training loss: 0.357760
# Validation loss: 0.354491
#
# Epoch 191
# -------------------------------
# Training loss: 0.352680
# Validation loss: 0.349709
#
# Epoch 192
# -------------------------------
# Training loss: 0.351293
# Validation loss: 0.345942
#
# Epoch 193
# -------------------------------
# Training loss: 0.352814
# Validation loss: 0.350206
#
# Epoch 194
# -------------------------------
# Training loss: 0.351170
# Validation loss: 0.353915
#
# Epoch 195
# -------------------------------
# Training loss: 0.350421
# Validation loss: 0.356769
#
# Epoch 196
# -------------------------------
# Training loss: 0.349375
# Validation loss: 0.356546
#
# Epoch 197
# -------------------------------
# Training loss: 0.348095
# Validation loss: 0.359582
#
# Epoch 198
# -------------------------------
# Training loss: 0.351417
# Validation loss: 0.347268
#
# Epoch 199
# -------------------------------
# Training loss: 0.349301
# Validation loss: 0.350502
#
# Epoch 200
# -------------------------------
# Training loss: 0.350147
# Validation loss: 0.349913
#
# Epoch 201
# -------------------------------
# Training loss: 0.347586
# Validation loss: 0.348699
#
# Epoch 202
# -------------------------------
# Training loss: 0.347882
# Validation loss: 0.346204
#
# Epoch 203
# -------------------------------
# Training loss: 0.348167
# Validation loss: 0.341397
#
# Epoch 204
# -------------------------------
# Training loss: 0.346483
# Validation loss: 0.344129
#
# Epoch 205
# -------------------------------
# Training loss: 0.345783
# Validation loss: 0.356591
#
# Epoch 206
# -------------------------------
# Training loss: 0.347089
# Validation loss: 0.343831
#
# Epoch 207
# -------------------------------
# Training loss: 0.347809
# Validation loss: 0.339783
#
# Epoch 208
# -------------------------------
# Training loss: 0.345151
# Validation loss: 0.346544
#
# Epoch 209
# -------------------------------
# Training loss: 0.344997
# Validation loss: 0.351779
#
# Epoch 210
# -------------------------------
# Training loss: 0.346274
# Validation loss: 0.340936
#
# Epoch 211
# -------------------------------
# Training loss: 0.343934
# Validation loss: 0.342434
#
# Epoch 212
# -------------------------------
# Training loss: 0.345434
# Validation loss: 0.344217
#
# Epoch 213
# -------------------------------
# Training loss: 0.344114
# Validation loss: 0.344756
#
# Epoch 214
# -------------------------------
# Training loss: 0.344385
# Validation loss: 0.348385
#
# Epoch 215
# -------------------------------
# Training loss: 0.340938
# Validation loss: 0.336839
#
# Epoch 216
# -------------------------------
# Training loss: 0.341792
# Validation loss: 0.345933
#
# Epoch 217
# -------------------------------
# Training loss: 0.344109
# Validation loss: 0.338944
#
# Epoch 218
# -------------------------------
# Training loss: 0.340707
# Validation loss: 0.337709
#
# Epoch 219
# -------------------------------
# Training loss: 0.340238
# Validation loss: 0.348676
#
# Epoch 220
# -------------------------------
# Training loss: 0.342037
# Validation loss: 0.340545
#
# Epoch 221
# -------------------------------
# Training loss: 0.342547
# Validation loss: 0.342899
#
# Epoch 222
# -------------------------------
# Training loss: 0.338863
# Validation loss: 0.345952
#
# Epoch 223
# -------------------------------
# Training loss: 0.338910
# Validation loss: 0.345209
#
# Epoch 224
# -------------------------------
# Training loss: 0.342115
# Validation loss: 0.345904
#
# Epoch 225
# -------------------------------
# Training loss: 0.340120
# Validation loss: 0.339316
#
# Epoch 226
# -------------------------------
# Training loss: 0.339042
# Validation loss: 0.341447
#
# Epoch 227
# -------------------------------
# Training loss: 0.339772
# Validation loss: 0.335911
#
# Epoch 228
# -------------------------------
# Training loss: 0.339966
# Validation loss: 0.344583
#
# Epoch 229
# -------------------------------
# Training loss: 0.337336
# Validation loss: 0.336924
#
# Epoch 230
# -------------------------------
# Training loss: 0.339490
# Validation loss: 0.341538
#
# Epoch 231
# -------------------------------
# Training loss: 0.337322
# Validation loss: 0.335937
#
# Epoch 232
# -------------------------------
# Training loss: 0.338188
# Validation loss: 0.340307
#
# Epoch 233
# -------------------------------
# Training loss: 0.337019
# Validation loss: 0.330420
#
# Epoch 234
# -------------------------------
# Training loss: 0.334765
# Validation loss: 0.337687
#
# Epoch 235
# -------------------------------
# Training loss: 0.336485
# Validation loss: 0.328576
#
# Epoch 236
# -------------------------------
# Training loss: 0.335793
# Validation loss: 0.334848
#
# Epoch 237
# -------------------------------
# Training loss: 0.333990
# Validation loss: 0.332036
#
# Epoch 238
# -------------------------------
# Training loss: 0.337494
# Validation loss: 0.337816
#
# Epoch 239
# -------------------------------
# Training loss: 0.333017
# Validation loss: 0.332177
#
# Epoch 240
# -------------------------------
# Training loss: 0.334753
# Validation loss: 0.331628
#
# Epoch 241
# -------------------------------
# Training loss: 0.332612
# Validation loss: 0.335472
#
# Epoch 242
# -------------------------------
# Training loss: 0.332926
# Validation loss: 0.335416
#
# Epoch 243
# -------------------------------
# Training loss: 0.332790
# Validation loss: 0.336095
#
# Epoch 244
# -------------------------------
# Training loss: 0.331948
# Validation loss: 0.333686
#
# Epoch 245
# -------------------------------
# Training loss: 0.332772
# Validation loss: 0.335113
#
# Epoch 246
# -------------------------------
# Training loss: 0.332424
# Validation loss: 0.325284
#
# Epoch 247
# -------------------------------
# Training loss: 0.331459
# Validation loss: 0.324684
#
# Epoch 248
# -------------------------------
# Training loss: 0.334150
# Validation loss: 0.328997
#
# Epoch 249
# -------------------------------
# Training loss: 0.334034
# Validation loss: 0.331720
#
# Epoch 250
# -------------------------------
# Training loss: 0.330777
# Validation loss: 0.332876
#
# Epoch 251
# -------------------------------
# Training loss: 0.331329
# Validation loss: 0.332941
#
# Epoch 252
# -------------------------------
# Training loss: 0.327997
# Validation loss: 0.338312
#
# Epoch 253
# -------------------------------
# Training loss: 0.332476
# Validation loss: 0.329039
#
# Epoch 254
# -------------------------------
# Training loss: 0.332858
# Validation loss: 0.324250
#
# Epoch 255
# -------------------------------
# Training loss: 0.334112
# Validation loss: 0.320041
#
# Epoch 256
# -------------------------------
# Training loss: 0.329745
# Validation loss: 0.324360
#
# Epoch 257
# -------------------------------
# Training loss: 0.328176
# Validation loss: 0.334777
#
# Epoch 258
# -------------------------------
# Training loss: 0.327306
# Validation loss: 0.337054
#
# Epoch 259
# -------------------------------
# Training loss: 0.327645
# Validation loss: 0.338269
#
# Epoch 260
# -------------------------------
# Training loss: 0.327653
# Validation loss: 0.330678
#
# Epoch 261
# -------------------------------
# Training loss: 0.328614
# Validation loss: 0.328519
#
# Epoch 262
# -------------------------------
# Training loss: 0.326829
# Validation loss: 0.321644
#
# Epoch 263
# -------------------------------
# Training loss: 0.328016
# Validation loss: 0.341366
#
# Epoch 264
# -------------------------------
# Training loss: 0.328847
# Validation loss: 0.317727
#
# Epoch 265
# -------------------------------
# Training loss: 0.324927
# Validation loss: 0.328034
#
# Epoch 266
# -------------------------------
# Training loss: 0.323575
# Validation loss: 0.322445
#
# Epoch 267
# -------------------------------
# Training loss: 0.323660
# Validation loss: 0.318915
#
# Epoch 268
# -------------------------------
# Training loss: 0.325460
# Validation loss: 0.319344
#
# Epoch 269
# -------------------------------
# Training loss: 0.324218
# Validation loss: 0.330971
#
# Epoch 270
# -------------------------------
# Training loss: 0.324354
# Validation loss: 0.314878
#
# Epoch 271
# -------------------------------
# Training loss: 0.323697
# Validation loss: 0.352479
#
# Epoch 272
# -------------------------------
# Training loss: 0.323152
# Validation loss: 0.315125
#
# Epoch 273
# -------------------------------
# Training loss: 0.323115
# Validation loss: 0.322924
#
# Epoch 274
# -------------------------------
# Training loss: 0.323807
# Validation loss: 0.317573
#
# Epoch 275
# -------------------------------
# Training loss: 0.324102
# Validation loss: 0.328141
#
# Epoch 276
# -------------------------------
# Training loss: 0.326856
# Validation loss: 0.317003
#
# Epoch 277
# -------------------------------
# Training loss: 0.321067
# Validation loss: 0.315289
#
# Epoch 278
# -------------------------------
# Training loss: 0.320500
# Validation loss: 0.320798
#
# Epoch 279
# -------------------------------
# Training loss: 0.320953
# Validation loss: 0.339400
#
# Epoch 280
# -------------------------------
# Training loss: 0.321099
# Validation loss: 0.318224
#
# Epoch 281
# -------------------------------
# Training loss: 0.320341
# Validation loss: 0.335923
#
# Epoch 282
# -------------------------------
# Training loss: 0.318034
# Validation loss: 0.310230
#
# Epoch 283
# -------------------------------
# Training loss: 0.317782
# Validation loss: 0.325550
#
# Epoch 284
# -------------------------------
# Training loss: 0.318704
# Validation loss: 0.327422
#
# Epoch 285
# -------------------------------
# Training loss: 0.317654
# Validation loss: 0.316027
#
# Epoch 286
# -------------------------------
# Training loss: 0.319100
# Validation loss: 0.317004
#
# Epoch 287
# -------------------------------
# Training loss: 0.320969
# Validation loss: 0.309777
#
# Epoch 288
# -------------------------------
# Training loss: 0.317784
# Validation loss: 0.316543
#
# Epoch 289
# -------------------------------
# Training loss: 0.316065
# Validation loss: 0.324650
#
# Epoch 290
# -------------------------------
# Training loss: 0.316381
# Validation loss: 0.326511
#
# Epoch 291
# -------------------------------
# Training loss: 0.316450
# Validation loss: 0.312842
#
# Epoch 292
# -------------------------------
# Training loss: 0.316187
# Validation loss: 0.303878
#
# Epoch 293
# -------------------------------
# Training loss: 0.316226
# Validation loss: 0.306621
#
# Epoch 294
# -------------------------------
# Training loss: 0.315138
# Validation loss: 0.301545
#
# Epoch 295
# -------------------------------
# Training loss: 0.315422
# Validation loss: 0.329661
#
# Epoch 296
# -------------------------------
# Training loss: 0.314730
# Validation loss: 0.320264
#
# Epoch 297
# -------------------------------
# Training loss: 0.312756
# Validation loss: 0.303554
#
# Epoch 298
# -------------------------------
# Training loss: 0.314009
# Validation loss: 0.307228
#
# Epoch 299
# -------------------------------
# Training loss: 0.313319
# Validation loss: 0.314206
#
# Epoch 300
# -------------------------------
# Training loss: 0.311746
# Validation loss: 0.310743
#
# Epoch 301
# -------------------------------
# Training loss: 0.314209
# Validation loss: 0.304643
#
# Epoch 302
# -------------------------------
# Training loss: 0.311581
# Validation loss: 0.303261
#
# Epoch 303
# -------------------------------
# Training loss: 0.310300
# Validation loss: 0.310764
#
# Epoch 304
# -------------------------------
# Training loss: 0.310919
# Validation loss: 0.304973
#
# Epoch 305
# -------------------------------
# Training loss: 0.309214
# Validation loss: 0.349731
#
# Epoch 306
# -------------------------------
# Training loss: 0.310237
# Validation loss: 0.301061
#
# Epoch 307
# -------------------------------
# Training loss: 0.312017
# Validation loss: 0.308808
#
# Epoch 308
# -------------------------------
# Training loss: 0.311857
# Validation loss: 0.295947
#
# Epoch 309
# -------------------------------
# Training loss: 0.307152
# Validation loss: 0.353156
#
# Epoch 310
# -------------------------------
# Training loss: 0.308177
# Validation loss: 0.295343
#
# Epoch 311
# -------------------------------
# Training loss: 0.307067
# Validation loss: 0.338978
#
# Epoch 312
# -------------------------------
# Training loss: 0.309543
# Validation loss: 0.322692
#
# Epoch 313
# -------------------------------
# Training loss: 0.307835
# Validation loss: 0.295469
#
# Epoch 314
# -------------------------------
# Training loss: 0.306783
# Validation loss: 0.382089
#
# Epoch 315
# -------------------------------
# Training loss: 0.309900
# Validation loss: 0.297374
#
# Epoch 316
# -------------------------------
# Training loss: 0.309161
# Validation loss: 0.297163
#
# Epoch 317
# -------------------------------
# Training loss: 0.305882
# Validation loss: 0.302772
#
# Epoch 318
# -------------------------------
# Training loss: 0.303743
# Validation loss: 0.375896
#
# Epoch 319
# -------------------------------
# Training loss: 0.304691
# Validation loss: 0.292503
#
# Epoch 320
# -------------------------------
# Training loss: 0.301897
# Validation loss: 0.397750
#
# Epoch 321
# -------------------------------
# Training loss: 0.302953
# Validation loss: 0.347563
#
# Epoch 322
# -------------------------------
# Training loss: 0.303407
# Validation loss: 0.288819
#
# Epoch 323
# -------------------------------
# Training loss: 0.303720
# Validation loss: 0.306561
#
# Epoch 324
# -------------------------------
# Training loss: 0.301998
# Validation loss: 0.318823
#
# Epoch 325
# -------------------------------
# Training loss: 0.300390
# Validation loss: 0.320522
#
# Epoch 326
# -------------------------------
# Training loss: 0.302716
# Validation loss: 0.293825
#
# Epoch 327
# -------------------------------
# Training loss: 0.301990
# Validation loss: 0.290351
#
# Epoch 328
# -------------------------------
# Training loss: 0.303404
# Validation loss: 0.308219
#
# Epoch 329
# -------------------------------
# Training loss: 0.299885
# Validation loss: 0.323678
#
# Epoch 330
# -------------------------------
# Training loss: 0.298893
# Validation loss: 0.383617
#
# Epoch 331
# -------------------------------
# Training loss: 0.297901
# Validation loss: 0.292415
#
# Epoch 332
# -------------------------------
# Training loss: 0.297097
# Validation loss: 0.298954
#
# Epoch 333
# -------------------------------
# Training loss: 0.299634
# Validation loss: 0.293395
#
# Epoch 334
# -------------------------------
# Training loss: 0.301020
# Validation loss: 0.289560
#
# Epoch 335
# -------------------------------
# Training loss: 0.303024
# Validation loss: 0.433333
#
# Epoch 336
# -------------------------------
# Training loss: 0.300226
# Validation loss: 0.292458
#
# Epoch 337
# -------------------------------
# Training loss: 0.300140
# Validation loss: 0.290769
#
# Epoch 338
# -------------------------------
# Training loss: 0.297920
# Validation loss: 0.441241
#
# Epoch 339
# -------------------------------
# Training loss: 0.296816
# Validation loss: 0.289285
#
# Epoch 340
# -------------------------------
# Training loss: 0.297934
# Validation loss: 0.285891
#
# Epoch 341
# -------------------------------
# Training loss: 0.293806
# Validation loss: 0.327270
#
# Epoch 342
# -------------------------------
# Training loss: 0.294576
# Validation loss: 0.285866
#
# Epoch 343
# -------------------------------
# Training loss: 0.295019
# Validation loss: 0.301823
#
# Epoch 344
# -------------------------------
# Training loss: 0.295273
# Validation loss: 0.316100
#
# Epoch 345
# -------------------------------
# Training loss: 0.294906
# Validation loss: 0.348581
#
# Epoch 346
# -------------------------------
# Training loss: 0.299113
# Validation loss: 0.283929
#
# Epoch 347
# -------------------------------
# Training loss: 0.294218
# Validation loss: 0.293045
#
# Epoch 348
# -------------------------------
# Training loss: 0.294061
# Validation loss: 0.305934
#
# Epoch 349
# -------------------------------
# Training loss: 0.293195
# Validation loss: 0.393267
#
# Epoch 350
# -------------------------------
# Training loss: 0.289952
# Validation loss: 0.348218
#
# Epoch 351
# -------------------------------
# Training loss: 0.289906
# Validation loss: 0.287807
#
# Epoch 352
# -------------------------------
# Training loss: 0.289380
# Validation loss: 0.285006
#
# Epoch 353
# -------------------------------
# Training loss: 0.291745
# Validation loss: 0.397468
#
# Epoch 354
# -------------------------------
# Training loss: 0.288094
# Validation loss: 0.288775
#
# Epoch 355
# -------------------------------
# Training loss: 0.290807
# Validation loss: 0.301928
#
# Epoch 356
# -------------------------------
# Training loss: 0.288967
# Validation loss: 0.303425
#
# Epoch 357
# -------------------------------
# Training loss: 0.291625
# Validation loss: 0.280654
#
# Epoch 358
# -------------------------------
# Training loss: 0.286653
# Validation loss: 0.282705
#
# Epoch 359
# -------------------------------
# Training loss: 0.286236
# Validation loss: 0.332106
#
# Epoch 360
# -------------------------------
# Training loss: 0.286913
# Validation loss: 0.331826
#
# Epoch 361
# -------------------------------
# Training loss: 0.294385
# Validation loss: 0.312518
#
# Epoch 362
# -------------------------------
# Training loss: 0.292471
# Validation loss: 0.412641
#
# Epoch 363
# -------------------------------
# Training loss: 0.286928
# Validation loss: 0.302834
#
# Epoch 364
# -------------------------------
# Training loss: 0.288335
# Validation loss: 0.305046
#
# Epoch 365
# -------------------------------
# Training loss: 0.289229
# Validation loss: 0.295815
#
# Epoch 366
# -------------------------------
# Training loss: 0.287404
# Validation loss: 0.412907
#
# Epoch 367
# -------------------------------
# Training loss: 0.283168
# Validation loss: 0.312093
#
# Epoch 368
# -------------------------------
# Training loss: 0.283739
# Validation loss: 0.289100
#
# Epoch 369
# -------------------------------
# Training loss: 0.280511
# Validation loss: 0.437298
#
# Epoch 370
# -------------------------------
# Training loss: 0.281871
# Validation loss: 0.277018
#
# Epoch 371
# -------------------------------
# Training loss: 0.281678
# Validation loss: 0.276083
#
# Epoch 372
# -------------------------------
# Training loss: 0.280869
# Validation loss: 0.275014
#
# Epoch 373
# -------------------------------
# Training loss: 0.283490
# Validation loss: 0.303657
#
# Epoch 374
# -------------------------------
# Training loss: 0.280256
# Validation loss: 0.325541
#
# Epoch 375
# -------------------------------
# Training loss: 0.287968
# Validation loss: 0.272820
#
# Epoch 376
# -------------------------------
# Training loss: 0.282537
# Validation loss: 0.307827
#
# Epoch 377
# -------------------------------
# Training loss: 0.281702
# Validation loss: 0.272373
#
# Epoch 378
# -------------------------------
# Training loss: 0.279220
# Validation loss: 0.285937
#
# Epoch 379
# -------------------------------
# Training loss: 0.279189
# Validation loss: 0.274664
#
# Epoch 380
# -------------------------------
# Training loss: 0.278429
# Validation loss: 0.281137
#
# Epoch 381
# -------------------------------
# Training loss: 0.277883
# Validation loss: 0.272392
#
# Epoch 382
# -------------------------------
# Training loss: 0.278414
# Validation loss: 0.290194
#
# Epoch 383
# -------------------------------
# Training loss: 0.276180
# Validation loss: 0.290425
#
# Epoch 384
# -------------------------------
# Training loss: 0.275894
# Validation loss: 0.275489
#
# Epoch 385
# -------------------------------
# Training loss: 0.279127
# Validation loss: 0.278429
#
# Epoch 386
# -------------------------------
# Training loss: 0.278097
# Validation loss: 0.282982
#
# Epoch 387
# -------------------------------
# Training loss: 0.276942
# Validation loss: 0.306784
#
# Epoch 388
# -------------------------------
# Training loss: 0.273064
# Validation loss: 0.271997
#
# Epoch 389
# -------------------------------
# Training loss: 0.284411
# Validation loss: 0.272422
#
# Epoch 390
# -------------------------------
# Training loss: 0.278180
# Validation loss: 0.401209
#
# Epoch 391
# -------------------------------
# Training loss: 0.277341
# Validation loss: 0.318752
#
# Epoch 392
# -------------------------------
# Training loss: 0.272850
# Validation loss: 0.266686
#
# Epoch 393
# -------------------------------
# Training loss: 0.277888
# Validation loss: 0.398026
#
# Epoch 394
# -------------------------------
# Training loss: 0.271868
# Validation loss: 0.276739
#
# Epoch 395
# -------------------------------
# Training loss: 0.274097
# Validation loss: 0.272989
#
# Epoch 396
# -------------------------------
# Training loss: 0.273881
# Validation loss: 0.350328
#
# Epoch 397
# -------------------------------
# Training loss: 0.271622
# Validation loss: 0.401303
#
# Epoch 398
# -------------------------------
# Training loss: 0.270046
# Validation loss: 0.271663
#
# Epoch 399
# -------------------------------
# Training loss: 0.271242
# Validation loss: 0.271459
#
# Epoch 400
# -------------------------------
# Training loss: 0.272292
# Validation loss: 0.288049
#
# Epoch 401
# -------------------------------
# Training loss: 0.274615
# Validation loss: 0.400690
#
# Epoch 402
# -------------------------------
# Training loss: 0.271498
# Validation loss: 0.282105
#
# Epoch 403
# -------------------------------
# Training loss: 0.269154
# Validation loss: 0.273873
#
# Epoch 404
# -------------------------------
# Training loss: 0.268668
# Validation loss: 0.267169
#
# Epoch 405
# -------------------------------
# Training loss: 0.270017
# Validation loss: 0.537786
#
# Epoch 406
# -------------------------------
# Training loss: 0.273702
# Validation loss: 0.264798
#
# Epoch 407
# -------------------------------
# Training loss: 0.271593
# Validation loss: 0.256162
#
# Epoch 408
# -------------------------------
# Training loss: 0.269591
# Validation loss: 0.270128
#
# Epoch 409
# -------------------------------
# Training loss: 0.267142
# Validation loss: 0.404143
#
# Epoch 410
# -------------------------------
# Training loss: 0.269494
# Validation loss: 0.282509
#
# Epoch 411
# -------------------------------
# Training loss: 0.267210
# Validation loss: 0.268144
#
# Epoch 412
# -------------------------------
# Training loss: 0.273900
# Validation loss: 0.270959
#
# Epoch 413
# -------------------------------
# Training loss: 0.268200
# Validation loss: 0.322686
#
# Epoch 414
# -------------------------------
# Training loss: 0.264117
# Validation loss: 0.267118
#
# Epoch 415
# -------------------------------
# Training loss: 0.266252
# Validation loss: 0.265372
#
# Epoch 416
# -------------------------------
# Training loss: 0.266327
# Validation loss: 0.271692
#
# Epoch 417
# -------------------------------
# Training loss: 0.265000
# Validation loss: 0.262443
#
# Epoch 418
# -------------------------------
# Training loss: 0.268435
# Validation loss: 0.257497
#
# Epoch 419
# -------------------------------
# Training loss: 0.263691
# Validation loss: 0.262792
#
# Epoch 420
# -------------------------------
# Training loss: 0.266572
# Validation loss: 0.321478
#
# Epoch 421
# -------------------------------
# Training loss: 0.265104
# Validation loss: 0.268248
#
# Epoch 422
# -------------------------------
# Training loss: 0.264533
# Validation loss: 0.253505
#
# Epoch 423
# -------------------------------
# Training loss: 0.263918
# Validation loss: 0.283153
#
# Epoch 424
# -------------------------------
# Training loss: 0.264447
# Validation loss: 0.256986
#
# Epoch 425
# -------------------------------
# Training loss: 0.260119
# Validation loss: 0.327588
#
# Epoch 426
# -------------------------------
# Training loss: 0.262279
# Validation loss: 0.259142
#
# Epoch 427
# -------------------------------
# Training loss: 0.262591
# Validation loss: 0.258048
#
# Epoch 428
# -------------------------------
# Training loss: 0.262229
# Validation loss: 0.317358
#
# Epoch 429
# -------------------------------
# Training loss: 0.259046
# Validation loss: 0.264081
#
# Epoch 430
# -------------------------------
# Training loss: 0.265747
# Validation loss: 0.265283
#
# Epoch 431
# -------------------------------
# Training loss: 0.261404
# Validation loss: 0.366375
#
# Epoch 432
# -------------------------------
# Training loss: 0.258986
# Validation loss: 0.264353
#
# Epoch 433
# -------------------------------
# Training loss: 0.259703
# Validation loss: 0.257355
#
# Epoch 434
# -------------------------------
# Training loss: 0.258731
# Validation loss: 0.256598
#
# Epoch 435
# -------------------------------
# Training loss: 0.256288
# Validation loss: 0.258508
#
# Epoch 436
# -------------------------------
# Training loss: 0.257560
# Validation loss: 0.341389
#
# Epoch 437
# -------------------------------
# Training loss: 0.259239
# Validation loss: 0.260237
#
# Epoch 438
# -------------------------------
# Training loss: 0.258380
# Validation loss: 0.256153
#
# Epoch 439
# -------------------------------
# Training loss: 0.257211
# Validation loss: 0.251199
#
# Epoch 440
# -------------------------------
# Training loss: 0.253889
# Validation loss: 0.268503
#
# Epoch 441
# -------------------------------
# Training loss: 0.255367
# Validation loss: 0.367518
#
# Epoch 442
# -------------------------------
# Training loss: 0.256536
# Validation loss: 0.278808
#
# Epoch 443
# -------------------------------
# Training loss: 0.253054
# Validation loss: 0.248282
#
# Epoch 444
# -------------------------------
# Training loss: 0.252845
# Validation loss: 0.272157
#
# Epoch 445
# -------------------------------
# Training loss: 0.257505
# Validation loss: 0.289778
#
# Epoch 446
# -------------------------------
# Training loss: 0.253515
# Validation loss: 0.356545
#
# Epoch 447
# -------------------------------
# Training loss: 0.251466
# Validation loss: 0.287568
#
# Epoch 448
# -------------------------------
# Training loss: 0.252386
# Validation loss: 0.254434
#
# Epoch 449
# -------------------------------
# Training loss: 0.256203
# Validation loss: 0.255676
#
# Epoch 450
# -------------------------------
# Training loss: 0.257408
# Validation loss: 0.287101
#
# Epoch 451
# -------------------------------
# Training loss: 0.251930
# Validation loss: 0.261118
#
# Epoch 452
# -------------------------------
# Training loss: 0.253385
# Validation loss: 0.252016
#
# Epoch 453
# -------------------------------
# Training loss: 0.256041
# Validation loss: 0.284223
#
# Epoch 454
# -------------------------------
# Training loss: 0.256736
# Validation loss: 0.314631
#
# Epoch 455
# -------------------------------
# Training loss: 0.258175
# Validation loss: 0.244426
#
# Epoch 456
# -------------------------------
# Training loss: 0.253605
# Validation loss: 0.264063
#
# Epoch 457
# -------------------------------
# Training loss: 0.250850
# Validation loss: 0.262796
#
# Epoch 458
# -------------------------------
# Training loss: 0.251274
# Validation loss: 0.255268
#
# Epoch 459
# -------------------------------
# Training loss: 0.250671
# Validation loss: 0.249832
#
# Epoch 460
# -------------------------------
# Training loss: 0.249243
# Validation loss: 0.258181
#
# Epoch 461
# -------------------------------
# Training loss: 0.249331
# Validation loss: 0.251625
#
# Epoch 462
# -------------------------------
# Training loss: 0.251054
# Validation loss: 0.256780
#
# Epoch 463
# -------------------------------
# Training loss: 0.249326
# Validation loss: 0.265827
#
# Epoch 464
# -------------------------------
# Training loss: 0.249094
# Validation loss: 0.382737
#
# Epoch 465
# -------------------------------
# Training loss: 0.246708
# Validation loss: 0.252318
#
# Epoch 466
# -------------------------------
# Training loss: 0.248037
# Validation loss: 0.341323
#
# Epoch 467
# -------------------------------
# Training loss: 0.249412
# Validation loss: 0.247439
#
# Epoch 468
# -------------------------------
# Training loss: 0.248619
# Validation loss: 0.257976
#
# Epoch 469
# -------------------------------
# Training loss: 0.250451
# Validation loss: 0.243698
#
# Epoch 470
# -------------------------------
# Training loss: 0.248381
# Validation loss: 0.250996
#
# Epoch 471
# -------------------------------
# Training loss: 0.244433
# Validation loss: 0.258306
#
# Epoch 472
# -------------------------------
# Training loss: 0.245605
# Validation loss: 0.243357
#
# Epoch 473
# -------------------------------
# Training loss: 0.244103
# Validation loss: 0.242933
#
# Epoch 474
# -------------------------------
# Training loss: 0.240475
# Validation loss: 0.331668
#
# Epoch 475
# -------------------------------
# Training loss: 0.243463
# Validation loss: 0.393981
#
# Epoch 476
# -------------------------------
# Training loss: 0.251573
# Validation loss: 0.244298
#
# Epoch 477
# -------------------------------
# Training loss: 0.247259
# Validation loss: 0.249875
#
# Epoch 478
# -------------------------------
# Training loss: 0.243816
# Validation loss: 0.288660
#
# Epoch 479
# -------------------------------
# Training loss: 0.240047
# Validation loss: 0.286805
#
# Epoch 480
# -------------------------------
# Training loss: 0.242629
# Validation loss: 0.331580
#
# Epoch 481
# -------------------------------
# Training loss: 0.244428
# Validation loss: 0.348537
#
# Epoch 482
# -------------------------------
# Training loss: 0.244026
# Validation loss: 0.262708
#
# Epoch 483
# -------------------------------
# Training loss: 0.246248
# Validation loss: 0.271592
#
# Epoch 484
# -------------------------------
# Training loss: 0.243463
# Validation loss: 0.246601
#
# Epoch 485
# -------------------------------
# Training loss: 0.246126
# Validation loss: 0.238038
#
# Epoch 486
# -------------------------------
# Training loss: 0.239573
# Validation loss: 0.259543
#
# Epoch 487
# -------------------------------
# Training loss: 0.237104
# Validation loss: 0.244112
#
# Epoch 488
# -------------------------------
# Training loss: 0.241811
# Validation loss: 0.303678
#
# Epoch 489
# -------------------------------
# Training loss: 0.241047
# Validation loss: 0.262980
#
# Epoch 490
# -------------------------------
# Training loss: 0.243128
# Validation loss: 0.252562
#
# Epoch 491
# -------------------------------
# Training loss: 0.239352
# Validation loss: 0.244334
#
# Epoch 492
# -------------------------------
# Training loss: 0.242041
# Validation loss: 0.241533
#
# Epoch 493
# -------------------------------
# Training loss: 0.241447
# Validation loss: 0.231488
#
# Epoch 494
# -------------------------------
# Training loss: 0.247906
# Validation loss: 0.571820
#
# Epoch 495
# -------------------------------
# Training loss: 0.237996
# Validation loss: 0.240977
#
# Epoch 496
# -------------------------------
# Training loss: 0.238207
# Validation loss: 0.259260
#
# Epoch 497
# -------------------------------
# Training loss: 0.239105
# Validation loss: 0.232033
#
# Epoch 498
# -------------------------------
# Training loss: 0.235269
# Validation loss: 0.274693
#
# Epoch 499
# -------------------------------
# Training loss: 0.237522
# Validation loss: 0.239308
#
# Epoch 500
# -------------------------------
# Training loss: 0.238616
# Validation loss: 0.232266
#
# Epoch 501
# -------------------------------
# Training loss: 0.239560
# Validation loss: 0.245465
#
# Epoch 502
# -------------------------------
# Training loss: 0.238481
# Validation loss: 0.238111
#
# Epoch 503
# -------------------------------
# Training loss: 0.238184
# Validation loss: 0.248473
#
# Epoch 504
# -------------------------------
# Training loss: 0.232534
# Validation loss: 0.229042
#
# Epoch 505
# -------------------------------
# Training loss: 0.234899
# Validation loss: 0.260763
#
# Epoch 506
# -------------------------------
# Training loss: 0.236418
# Validation loss: 0.239460
#
# Epoch 507
# -------------------------------
# Training loss: 0.234762
# Validation loss: 0.229920
#
# Epoch 508
# -------------------------------
# Training loss: 0.235936
# Validation loss: 0.264305
#
# Epoch 509
# -------------------------------
# Training loss: 0.234607
# Validation loss: 0.239977
#
# Epoch 510
# -------------------------------
# Training loss: 0.239697
# Validation loss: 0.238437
#
# Epoch 511
# -------------------------------
# Training loss: 0.228715
# Validation loss: 0.249010
#
# Epoch 512
# -------------------------------
# Training loss: 0.231623
# ...
# Validation loss: 0.078900
#
# Epoch 2333
# -------------------------------
# Training loss: 0.046128
# Validation loss: 0.055919
#
# Epoch 2334
# -------------------------------
# Training loss: 0.045640
# Validation loss: 0.057267
#
# Epoch 2335
# -------------------------------
# Training loss: 0.047519
# Validation loss: 0.058129
#
# Epoch 2336
# -------------------------------
# Training loss: 0.047563
# Validation loss: 0.077483
#
# Epoch 2337
# -------------------------------
# Training loss: 0.049289
# Validation loss: 0.066820
#
# Epoch 2338
# -------------------------------
# Training loss: 0.046881
# Validation loss: 0.071222
#
# Epoch 2339
# -------------------------------
# Training loss: 0.045341
# Validation loss: 0.053238
#
# Epoch 2340
# -------------------------------
# Training loss: 0.051560
# Validation loss: 0.060553
#
# Epoch 2341
# -------------------------------
# Training loss: 0.048005
# Validation loss: 0.058894
#
# Epoch 2342
# -------------------------------
# Training loss: 0.047466
# Validation loss: 0.057924
#
# Epoch 2343
# -------------------------------
# Training loss: 0.046167
# Validation loss: 0.059216
#
# Epoch 2344
# -------------------------------
# Training loss: 0.046426
# Validation loss: 0.059398
#
# Epoch 2345
# -------------------------------
# Training loss: 0.048976
# Validation loss: 0.397507
#
# Epoch 2346
# -------------------------------
# Training loss: 0.047316
# Validation loss: 0.061229
#
# Epoch 2347
# -------------------------------
# Training loss: 0.050017
# Validation loss: 0.054638
#
# Epoch 2348
# -------------------------------
# Training loss: 0.049802
# Validation loss: 0.066091
#
# Epoch 2349
# -------------------------------
# Training loss: 0.051280
# Validation loss: 0.127701
#
# Epoch 2350
# -------------------------------
# Training loss: 0.046238
# Validation loss: 0.065266
#
# Epoch 2351
# -------------------------------
# Training loss: 0.046583
# Validation loss: 0.115094
#
# Epoch 2352
# -------------------------------
# Training loss: 0.046894
# Validation loss: 0.058935
#
# Epoch 2353
# -------------------------------
# Training loss: 0.047492
# Validation loss: 0.058750
#
# Epoch 2354
# -------------------------------
# Training loss: 0.048206
# Validation loss: 0.115658
#
# Epoch 2355
# -------------------------------
# Training loss: 0.047401
# Validation loss: 0.062789
#
# Epoch 2356
# -------------------------------
# Training loss: 0.049692
# Validation loss: 0.057626
#
# Epoch 2357
# -------------------------------
# Training loss: 0.047155
# Validation loss: 0.060453
#
# Epoch 2358
# -------------------------------
# Training loss: 0.047000
# Validation loss: 0.059869
#
# Epoch 2359
# -------------------------------
# Training loss: 0.048224
# Validation loss: 0.061933
#
# Epoch 2360
# -------------------------------
# Training loss: 0.046703
# Validation loss: 0.058231
#
# Epoch 2361
# -------------------------------
# Training loss: 0.046838
# Validation loss: 0.073233
#
# Epoch 2362
# -------------------------------
# Training loss: 0.046306
# Validation loss: 0.062777
#
# Epoch 2363
# -------------------------------
# Training loss: 0.046781
# Validation loss: 0.065666
#
# Epoch 2364
# -------------------------------
# Training loss: 0.046662
# Validation loss: 0.060086
#
# Epoch 2365
# -------------------------------
# Training loss: 0.049969
# Validation loss: 0.064496
#
# Epoch 2366
# -------------------------------
# Training loss: 0.059541
# Validation loss: 0.063894
#
# Epoch 2367
# -------------------------------
# Training loss: 0.049827
# Validation loss: 0.211582
#
# Epoch 2368
# -------------------------------
# Training loss: 0.053712
# Validation loss: 0.097771
#
# Epoch 2369
# -------------------------------
# Training loss: 0.048982
# Validation loss: 0.099638
#
# Epoch 2370
# -------------------------------
# Training loss: 0.048250
# Validation loss: 0.074662
#
# Epoch 2371
# -------------------------------
# Training loss: 0.051161
# Validation loss: 0.064372
#
# Epoch 2372
# -------------------------------
# Training loss: 0.046389
# Validation loss: 0.054825
#
# Epoch 2373
# -------------------------------
# Training loss: 0.050018
# Validation loss: 0.062171
#
# Epoch 2374
# -------------------------------
# Training loss: 0.048705
# Validation loss: 0.064040
#
# Epoch 2375
# -------------------------------
# Training loss: 0.051180
# Validation loss: 0.062676
#
# Epoch 2376
# -------------------------------
# Training loss: 0.049692
# Validation loss: 0.089712
#
# Epoch 2377
# -------------------------------
# Training loss: 0.050966
# Validation loss: 0.068231
#
# Epoch 2378
# -------------------------------
# Training loss: 0.047518
# Validation loss: 0.071377
#
# Epoch 2379
# -------------------------------
# Training loss: 0.046910
# Validation loss: 0.055309
#
# Epoch 2380
# -------------------------------
# Training loss: 0.045023
# Validation loss: 0.055805
#
# Epoch 2381
# -------------------------------
# Training loss: 0.045513
# Validation loss: 0.091669
#
# Epoch 2382
# -------------------------------
# Training loss: 0.046835
# Validation loss: 0.071143
#
# Epoch 2383
# -------------------------------
# Training loss: 0.045784
# Validation loss: 0.061287
#
# Epoch 2384
# -------------------------------
# Training loss: 0.048055
# Validation loss: 0.062376
#
# Epoch 2385
# -------------------------------
# Training loss: 0.046686
# Validation loss: 0.056395
#
# Epoch 2386
# -------------------------------
# Training loss: 0.047064
# Validation loss: 0.075590
#
# Epoch 2387
# -------------------------------
# Training loss: 0.046409
# Validation loss: 0.055087
#
# Epoch 2388
# -------------------------------
# Training loss: 0.047292
# Validation loss: 0.171893
#
# Epoch 2389
# -------------------------------
# Training loss: 0.048274
# Validation loss: 0.059055
#
# Epoch 2390
# -------------------------------
# Training loss: 0.045623
# Validation loss: 0.054806
#
# Epoch 2391
# -------------------------------
# Training loss: 0.046586
# Validation loss: 0.062514
#
# Epoch 2392
# -------------------------------
# Training loss: 0.046615
# Validation loss: 0.065893
#
# Epoch 2393
# -------------------------------
# Training loss: 0.046997
# Validation loss: 0.056616
#
# Epoch 2394
# -------------------------------
# Training loss: 0.048433
# Validation loss: 0.066614
#
# Epoch 2395
# -------------------------------
# Training loss: 0.046448
# Validation loss: 0.058617
#
# Epoch 2396
# -------------------------------
# Training loss: 0.045620
# Validation loss: 0.068698
#
# Epoch 2397
# -------------------------------
# Training loss: 0.048545
# Validation loss: 0.054421
#
# Epoch 2398
# -------------------------------
# Training loss: 0.045073
# Validation loss: 0.055698
#
# Epoch 2399
# -------------------------------
# Training loss: 0.048765
# Validation loss: 0.058496
#
# Epoch 2400
# -------------------------------
# Training loss: 0.048588
# Validation loss: 0.097296
#
# Epoch 2401
# -------------------------------
# Training loss: 0.046901
# Validation loss: 0.079333
#
# Epoch 2402
# -------------------------------
# Training loss: 0.046490
# Validation loss: 0.062658
#
# Epoch 2403
# -------------------------------
# Training loss: 0.048058
# Validation loss: 0.058584
#
# Epoch 2404
# -------------------------------
# Training loss: 0.047884
# Validation loss: 0.065625
#
# Epoch 2405
# -------------------------------
# Training loss: 0.045383
# Validation loss: 0.056647
#
# Epoch 2406
# -------------------------------
# Training loss: 0.046885
# Validation loss: 0.054660
#
# Epoch 2407
# -------------------------------
# Training loss: 0.047376
# Validation loss: 0.059265
#
# Epoch 2408
# -------------------------------
# Training loss: 0.044740
# Validation loss: 0.054187
#
# Epoch 2409
# -------------------------------
# Training loss: 0.045996
# Validation loss: 0.054212
#
# Epoch 2410
# -------------------------------
# Training loss: 0.044829
# Validation loss: 0.052967
#
# Epoch 2411
# -------------------------------
# Training loss: 0.045987
# Validation loss: 0.065929
#
# Epoch 2412
# -------------------------------
# Training loss: 0.045436
# Validation loss: 0.055032
#
# Epoch 2413
# -------------------------------
# Training loss: 0.045976
# Validation loss: 0.056599
#
# Epoch 2414
# -------------------------------
# Training loss: 0.047639
# Validation loss: 0.054592
#
# Epoch 2415
# -------------------------------
# Training loss: 0.044214
# Validation loss: 0.058858
#
# Epoch 2416
# -------------------------------
# Training loss: 0.046117
# Validation loss: 0.058679
#
# Epoch 2417
# -------------------------------
# Training loss: 0.046759
# Validation loss: 0.061026
#
# Epoch 2418
# -------------------------------
# Training loss: 0.050309
# Validation loss: 0.052447
#
# Epoch 2419
# -------------------------------
# Training loss: 0.045028
# Validation loss: 0.054482
#
# Epoch 2420
# -------------------------------
# Training loss: 0.045964
# Validation loss: 0.065626
#
# Epoch 2421
# -------------------------------
# Training loss: 0.045525
# Validation loss: 0.055046
#
# Epoch 2422
# -------------------------------
# Training loss: 0.045320
# Validation loss: 0.098999
#
# Epoch 2423
# -------------------------------
# Training loss: 0.046029
# Validation loss: 0.061611
#
# Epoch 2424
# -------------------------------
# Training loss: 0.047963
# Validation loss: 0.060472
#
# Epoch 2425
# -------------------------------
# Training loss: 0.046042
# Validation loss: 0.054774
#
# Epoch 2426
# -------------------------------
# Training loss: 0.045587
# Validation loss: 0.053476
#
# Epoch 2427
# -------------------------------
# Training loss: 0.046070
# Validation loss: 0.077844
#
# Epoch 2428
# -------------------------------
# Training loss: 0.045031
# Validation loss: 0.056599
#
# Epoch 2429
# -------------------------------
# Training loss: 0.049581
# Validation loss: 0.064041
#
# Epoch 2430
# -------------------------------
# Training loss: 0.046489
# Validation loss: 0.052724
#
# Epoch 2431
# -------------------------------
# Training loss: 0.047617
# Validation loss: 0.052327
#
# Epoch 2432
# -------------------------------
# Training loss: 0.045570
# Validation loss: 0.061674
#
# Epoch 2433
# -------------------------------
# Training loss: 0.045133
# Validation loss: 0.056761
#
# Epoch 2434
# -------------------------------
# Training loss: 0.045432
# Validation loss: 0.052749
#
# Epoch 2435
# -------------------------------
# Training loss: 0.045003
# Validation loss: 0.059506
#
# Epoch 2436
# -------------------------------
# Training loss: 0.045029
# Validation loss: 0.056452
#
# Epoch 2437
# -------------------------------
# Training loss: 0.045702
# Validation loss: 0.052878
#
# Epoch 2438
# -------------------------------
# Training loss: 0.047286
# Validation loss: 0.058077
#
# Epoch 2439
# -------------------------------
# Training loss: 0.045358
# Validation loss: 0.078177
#
# Epoch 2440
# -------------------------------
# Training loss: 0.047587
# Validation loss: 0.060452
#
# Epoch 2441
# -------------------------------
# Training loss: 0.047360
# Validation loss: 0.054230
#
# Epoch 2442
# -------------------------------
# Training loss: 0.046861
# Validation loss: 0.062283
#
# Epoch 2443
# -------------------------------
# Training loss: 0.048413
# Validation loss: 0.074068
#
# Epoch 2444
# -------------------------------
# Training loss: 0.045186
# Validation loss: 0.060549
#
# Epoch 2445
# -------------------------------
# Training loss: 0.046029
# Validation loss: 0.055916
#
# Epoch 2446
# -------------------------------
# Training loss: 0.053584
# Validation loss: 0.064442
#
# Epoch 2447
# -------------------------------
# Training loss: 0.047873
# Validation loss: 0.057201
#
# Epoch 2448
# -------------------------------
# Training loss: 0.046443
# Validation loss: 0.306972
#
# Epoch 2449
# -------------------------------
# Training loss: 0.049331
# Validation loss: 0.053837
#
# Epoch 2450
# -------------------------------
# Training loss: 0.045934
# Validation loss: 0.057004
#
# Epoch 2451
# -------------------------------
# Training loss: 0.043656
# Validation loss: 0.055043
#
# Epoch 2452
# -------------------------------
# Training loss: 0.046201
# Validation loss: 0.052461
#
# Epoch 2453
# -------------------------------
# Training loss: 0.046937
# Validation loss: 0.060167
#
# Epoch 2454
# -------------------------------
# Training loss: 0.047151
# Validation loss: 0.052715
#
# Epoch 2455
# -------------------------------
# Training loss: 0.050333
# Validation loss: 0.055482
#
# Epoch 2456
# -------------------------------
# Training loss: 0.045563
# Validation loss: 0.056160
#
# Epoch 2457
# -------------------------------
# Training loss: 0.045362
# Validation loss: 0.053227
#
# Epoch 2458
# -------------------------------
# Training loss: 0.046008
# Validation loss: 0.056089
#
# Epoch 2459
# -------------------------------
# Training loss: 0.044813
# Validation loss: 0.059069
#
# Epoch 2460
# -------------------------------
# Training loss: 0.042938
# Validation loss: 0.056434
#
# Epoch 2461
# -------------------------------
# Training loss: 0.045336
# Validation loss: 0.066535
#
# Epoch 2462
# -------------------------------
# Training loss: 0.047611
# Validation loss: 0.066771
#
# Epoch 2463
# -------------------------------
# Training loss: 0.046947
# Validation loss: 0.059796
#
# Epoch 2464
# -------------------------------
# Training loss: 0.049606
# Validation loss: 0.085891
#
# Epoch 2465
# -------------------------------
# Training loss: 0.045357
# Validation loss: 0.054866
#
# Epoch 2466
# -------------------------------
# Training loss: 0.047654
# Validation loss: 0.067595
#
# Epoch 2467
# -------------------------------
# Training loss: 0.046537
# Validation loss: 0.056135
#
# Epoch 2468
# -------------------------------
# Training loss: 0.046526
# Validation loss: 0.055969
#
# Epoch 2469
# -------------------------------
# Training loss: 0.045861
# Validation loss: 0.056374
#
# Epoch 2470
# -------------------------------
# Training loss: 0.045280
# Validation loss: 0.061442
#
# Epoch 2471
# -------------------------------
# Training loss: 0.044360
# Validation loss: 0.054020
#
# Epoch 2472
# -------------------------------
# Training loss: 0.044735
# Validation loss: 0.063684
#
# Epoch 2473
# -------------------------------
# Training loss: 0.044688
# Validation loss: 0.052329
#
# Epoch 2474
# -------------------------------
# Training loss: 0.046009
# Validation loss: 0.086968
#
# Epoch 2475
# -------------------------------
# Training loss: 0.048715
# Validation loss: 0.057322
#
# Epoch 2476
# -------------------------------
# Training loss: 0.045475
# Validation loss: 0.053873
#
# Epoch 2477
# -------------------------------
# Training loss: 0.044005
# Validation loss: 0.058307
#
# Epoch 2478
# -------------------------------
# Training loss: 0.046492
# Validation loss: 0.060266
#
# Epoch 2479
# -------------------------------
# Training loss: 0.046990
# Validation loss: 0.059448
#
# Epoch 2480
# -------------------------------
# Training loss: 0.045956
# Validation loss: 0.066971
#
# Epoch 2481
# -------------------------------
# Training loss: 0.049270
# Validation loss: 0.053665
#
# Epoch 2482
# -------------------------------
# Training loss: 0.046510
# Validation loss: 0.056356
#
# Epoch 2483
# -------------------------------
# Training loss: 0.045328
# Validation loss: 0.054902
#
# Epoch 2484
# -------------------------------
# Training loss: 0.045789
# Validation loss: 0.066792
#
# Epoch 2485
# -------------------------------
# Training loss: 0.046366
# Validation loss: 0.052158
#
# Epoch 2486
# -------------------------------
# Training loss: 0.043440
# Validation loss: 0.055123
#
# Epoch 2487
# -------------------------------
# Training loss: 0.043889
# Validation loss: 0.052480
#
# Epoch 2488
# -------------------------------
# Training loss: 0.045754
# Validation loss: 0.055387
#
# Epoch 2489
# -------------------------------
# Training loss: 0.043675
# Validation loss: 0.057850
#
# Epoch 2490
# -------------------------------
# Training loss: 0.043482
# Validation loss: 0.052997
#
# Epoch 2491
# -------------------------------
# Training loss: 0.042978
# Validation loss: 0.049822
#
# Epoch 2492
# -------------------------------
# Training loss: 0.046520
# Validation loss: 0.071579
#
# Epoch 2493
# -------------------------------
# Training loss: 0.047316
# Validation loss: 0.074873
#
# Epoch 2494
# -------------------------------
# Training loss: 0.045086
# Validation loss: 0.053205
#
# Epoch 2495
# -------------------------------
# Training loss: 0.045374
# Validation loss: 0.062218
#
# Epoch 2496
# -------------------------------
# Training loss: 0.043605
# Validation loss: 0.053049
#
# Epoch 2497
# -------------------------------
# Training loss: 0.043544
# Validation loss: 0.071940
#
# Epoch 2498
# -------------------------------
# Training loss: 0.047179
# Validation loss: 0.057095
#
# Epoch 2499
# -------------------------------
# Training loss: 0.047378
# Validation loss: 0.054150
#
# Epoch 2500
# -------------------------------
# Training loss: 0.050210
# Validation loss: 0.290983
#
# Done!

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses)+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('BCE Loss')
#plt.yscale('log')
plt.legend()

# %%
# Now test the pretrained model
test_pred = mytools.test_clas(test_loader, final_classifier, device)
test_pred=torch.sigmoid(torch.tensor(test_pred)).numpy()


fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test, test_pred, pos_label=1)
auc_test = sklearn.metrics.auc(fpr, tpr)
print(f'Test AUROC: {auc_test:0.4f}')

plt.plot(fpr, tpr, label=f'Test AUROC: {auc_test:0.4f}')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
# Out:
# Test AUROC: 0.9950

# %%
# Store the pretrained classifier labels
df_test["Class_pre"] = test_pred

# %%
# Save the pretrained classifier model
torch.save(final_classifier.state_dict(), "/Users/mghrear/data/ML_data/patch/pretrained_classifier_2021_v9_pass5_run"+str(run)+"_limited_sideband_a.pt")

# %% [markdown]
# # Setup the adversary model

# %% [markdown]
# ## Initialize model, objective function, and optimizer

# %%
adv = mytools.Adversary(n_classes=Num_classes).to(device)
criterion_adv = nn.CrossEntropyLoss(reduction='none')  # returns loss per sample so we can weight it
opt_adv = torch.optim.Adam(adv.parameters(), lr=1e-5)
scheduler_adv = torch.optim.lr_scheduler.ExponentialLR(opt_adv, gamma=0.999)

# %% [markdown]
# ## Setup dataloaders

# %%
# Convert to tensor dataset and dataloader

# the structure is: feature, adversary label, weight
# The wight is 1 for tritrig and wab, and 0 for phiKK, to prevent the adversary from learning on phiKK events

train_adv_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_train), (torch.from_numpy(y_train.to_numpy().astype(np.float32))==0).float())
train_adv_loader = DataLoader(train_adv_dataset, batch_size=bsize, shuffle=True)

val_adv_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_val), (torch.from_numpy(y_val.to_numpy().astype(np.float32))==0).float() )
val_adv_loader = DataLoader(val_adv_dataset, batch_size=bsize, shuffle=True)

# %% [markdown]
# ## Pre-train the adversary leaving classifier weights fixed

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 6

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 100
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train_adv(train_adv_loader, final_classifier, adv, criterion_adv, opt_adv, scheduler_adv, device))
    Validation_losses = np.append(Validation_losses, mytools.validate_adv(val_adv_loader, final_classifier, adv, criterion_adv, device))
    
    # Keep a running copy of the model with the lowest loss
    if Validation_losses[-1] == np.min(Validation_losses):
        final_adv = copy.deepcopy(adv)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Training loss: 1.626750
# Validation loss: 1.652073
#
# Epoch 2
# -------------------------------
# Training loss: 1.620264
# Validation loss: 1.657912
#
# Epoch 3
# -------------------------------
# Training loss: 1.614472
# Validation loss: 1.655381
#
# Epoch 4
# -------------------------------
# Training loss: 1.609256
# Validation loss: 1.646847
#
# Epoch 5
# -------------------------------
# Training loss: 1.604052
# Validation loss: 1.636850
#
# Epoch 6
# -------------------------------
# Training loss: 1.600020
# Validation loss: 1.625136
#
# Epoch 7
# -------------------------------
# Training loss: 1.596271
# Validation loss: 1.615495
#
# Epoch 8
# -------------------------------
# Training loss: 1.592799
# Validation loss: 1.606651
#
# Epoch 9
# -------------------------------
# Training loss: 1.589793
# Validation loss: 1.597280
#
# Epoch 10
# -------------------------------
# Training loss: 1.586842
# Validation loss: 1.588224
#
# Epoch 11
# -------------------------------
# Training loss: 1.584830
# Validation loss: 1.584939
#
# Epoch 12
# -------------------------------
# Training loss: 1.582074
# Validation loss: 1.580274
#
# Epoch 13
# -------------------------------
# Training loss: 1.580125
# Validation loss: 1.577719
#
# Epoch 14
# -------------------------------
# Training loss: 1.577808
# Validation loss: 1.574216
#
# Epoch 15
# -------------------------------
# Training loss: 1.575921
# Validation loss: 1.572913
#
# Epoch 16
# -------------------------------
# Training loss: 1.573968
# Validation loss: 1.570027
#
# Epoch 17
# -------------------------------
# Training loss: 1.572073
# Validation loss: 1.569338
#
# Epoch 18
# -------------------------------
# Training loss: 1.571261
# Validation loss: 1.566350
#
# Epoch 19
# -------------------------------
# Training loss: 1.569524
# Validation loss: 1.568233
#
# Epoch 20
# -------------------------------
# Training loss: 1.568174
# Validation loss: 1.563715
#
# Epoch 21
# -------------------------------
# Training loss: 1.567028
# Validation loss: 1.563193
#
# Epoch 22
# -------------------------------
# Training loss: 1.565490
# Validation loss: 1.561883
#
# Epoch 23
# -------------------------------
# Training loss: 1.564502
# Validation loss: 1.561879
#
# Epoch 24
# -------------------------------
# Training loss: 1.563169
# Validation loss: 1.563100
#
# Epoch 25
# -------------------------------
# Training loss: 1.562166
# Validation loss: 1.559813
#
# Epoch 26
# -------------------------------
# Training loss: 1.561154
# Validation loss: 1.559255
#
# Epoch 27
# -------------------------------
# Training loss: 1.559663
# Validation loss: 1.558519
#
# Epoch 28
# -------------------------------
# Training loss: 1.559101
# Validation loss: 1.556852
#
# Epoch 29
# -------------------------------
# Training loss: 1.557654
# Validation loss: 1.556517
#
# Epoch 30
# -------------------------------
# Training loss: 1.556983
# Validation loss: 1.558029
#
# Epoch 31
# -------------------------------
# Training loss: 1.556037
# Validation loss: 1.556714
#
# Epoch 32
# -------------------------------
# Training loss: 1.555060
# Validation loss: 1.555505
#
# Epoch 33
# -------------------------------
# Training loss: 1.554462
# Validation loss: 1.551723
#
# Epoch 34
# -------------------------------
# Training loss: 1.553107
# Validation loss: 1.551785
#
# Epoch 35
# -------------------------------
# Training loss: 1.551934
# Validation loss: 1.552023
#
# Epoch 36
# -------------------------------
# Training loss: 1.551636
# Validation loss: 1.550498
#
# Epoch 37
# -------------------------------
# Training loss: 1.550921
# Validation loss: 1.550008
#
# Epoch 38
# -------------------------------
# Training loss: 1.549880
# Validation loss: 1.549404
#
# Epoch 39
# -------------------------------
# Training loss: 1.549239
# Validation loss: 1.547916
#
# Epoch 40
# -------------------------------
# Training loss: 1.548412
# Validation loss: 1.549000
#
# Epoch 41
# -------------------------------
# Training loss: 1.547545
# Validation loss: 1.548211
#
# Epoch 42
# -------------------------------
# Training loss: 1.547319
# Validation loss: 1.547840
#
# Epoch 43
# -------------------------------
# Training loss: 1.546121
# Validation loss: 1.545461
#
# Epoch 44
# -------------------------------
# Training loss: 1.545209
# Validation loss: 1.548342
#
# Epoch 45
# -------------------------------
# Training loss: 1.544978
# Validation loss: 1.544191
#
# Epoch 46
# -------------------------------
# Training loss: 1.544746
# Validation loss: 1.542928
#
# Epoch 47
# -------------------------------
# Training loss: 1.544472
# Validation loss: 1.544001
#
# Epoch 48
# -------------------------------
# Training loss: 1.543483
# Validation loss: 1.542985
#
# Epoch 49
# -------------------------------
# Training loss: 1.542703
# Validation loss: 1.544558
#
# Epoch 50
# -------------------------------
# Training loss: 1.542017
# Validation loss: 1.546456
#
# Epoch 51
# -------------------------------
# Training loss: 1.541616
# Validation loss: 1.545323
#
# Epoch 52
# -------------------------------
# Training loss: 1.540908
# Validation loss: 1.541293
#
# Epoch 53
# -------------------------------
# Training loss: 1.540456
# Validation loss: 1.538375
#
# Epoch 54
# -------------------------------
# Training loss: 1.540200
# Validation loss: 1.541149
#
# Epoch 55
# -------------------------------
# Training loss: 1.539601
# Validation loss: 1.544838
#
# Epoch 56
# -------------------------------
# Training loss: 1.539537
# Validation loss: 1.541237
#
# Epoch 57
# -------------------------------
# Training loss: 1.538935
# Validation loss: 1.542692
#
# Epoch 58
# -------------------------------
# Training loss: 1.538444
# Validation loss: 1.540881
#
# Epoch 59
# -------------------------------
# Training loss: 1.537630
# Validation loss: 1.539779
#
# Epoch 60
# -------------------------------
# Training loss: 1.537339
# Validation loss: 1.539951
#
# Epoch 61
# -------------------------------
# Training loss: 1.537437
# Validation loss: 1.539897
#
# Epoch 62
# -------------------------------
# Training loss: 1.536920
# Validation loss: 1.538760
#
# Epoch 63
# -------------------------------
# Training loss: 1.536558
# Validation loss: 1.538881
#
# Epoch 64
# -------------------------------
# Training loss: 1.536102
# Validation loss: 1.538610
#
# Epoch 65
# -------------------------------
# Training loss: 1.535891
# Validation loss: 1.538690
#
# Epoch 66
# -------------------------------
# Training loss: 1.535224
# Validation loss: 1.534134
#
# Epoch 67
# -------------------------------
# Training loss: 1.534923
# Validation loss: 1.534534
#
# Epoch 68
# -------------------------------
# Training loss: 1.535090
# Validation loss: 1.534979
#
# Epoch 69
# -------------------------------
# Training loss: 1.534882
# Validation loss: 1.537661
#
# Epoch 70
# -------------------------------
# Training loss: 1.534305
# Validation loss: 1.534440
#
# Epoch 71
# -------------------------------
# Training loss: 1.533807
# Validation loss: 1.536296
#
# Epoch 72
# -------------------------------
# Training loss: 1.533558
# Validation loss: 1.536427
#
# Epoch 73
# -------------------------------
# Training loss: 1.532971
# Validation loss: 1.537324
#
# Epoch 74
# -------------------------------
# Training loss: 1.532670
# Validation loss: 1.536807
#
# Epoch 75
# -------------------------------
# Training loss: 1.532859
# Validation loss: 1.534704
#
# Epoch 76
# -------------------------------
# Training loss: 1.532395
# Validation loss: 1.531059
#
# Epoch 77
# -------------------------------
# Training loss: 1.532865
# Validation loss: 1.535984
#
# Epoch 78
# -------------------------------
# Training loss: 1.531412
# Validation loss: 1.530076
#
# Epoch 79
# -------------------------------
# Training loss: 1.532677
# Validation loss: 1.530769
#
# Epoch 80
# -------------------------------
# Training loss: 1.531507
# Validation loss: 1.530627
#
# Epoch 81
# -------------------------------
# Training loss: 1.531770
# Validation loss: 1.536616
#
# Epoch 82
# -------------------------------
# Training loss: 1.531432
# Validation loss: 1.534089
#
# Epoch 83
# -------------------------------
# Training loss: 1.531384
# Validation loss: 1.534065
#
# Epoch 84
# -------------------------------
# Training loss: 1.530587
# Validation loss: 1.535187
#
# Epoch 85
# -------------------------------
# Training loss: 1.530628
# Validation loss: 1.532814
#
# Epoch 86
# -------------------------------
# Training loss: 1.530734
# Validation loss: 1.531641
#
# Epoch 87
# -------------------------------
# Training loss: 1.530166
# Validation loss: 1.531441
#
# Epoch 88
# -------------------------------
# Training loss: 1.530713
# Validation loss: 1.533408
#
# Epoch 89
# -------------------------------
# Training loss: 1.529465
# Validation loss: 1.531654
#
# Epoch 90
# -------------------------------
# Training loss: 1.528859
# Validation loss: 1.532701
#
# Epoch 91
# -------------------------------
# Training loss: 1.529063
# Validation loss: 1.532319
#
# Epoch 92
# -------------------------------
# Training loss: 1.529077
# Validation loss: 1.531251
#
# Epoch 93
# -------------------------------
# Training loss: 1.528549
# Validation loss: 1.530579
#
# Epoch 94
# -------------------------------
# Training loss: 1.528139
# Validation loss: 1.531211
#
# Epoch 95
# -------------------------------
# Training loss: 1.529541
# Validation loss: 1.532077
#
# Epoch 96
# -------------------------------
# Training loss: 1.528166
# Validation loss: 1.529612
#
# Epoch 97
# -------------------------------
# Training loss: 1.527859
# Validation loss: 1.529653
#
# Epoch 98
# -------------------------------
# Training loss: 1.527651
# Validation loss: 1.532958
#
# Epoch 99
# -------------------------------
# Training loss: 1.527518
# Validation loss: 1.528603
#
# Epoch 100
# -------------------------------
# Training loss: 1.527411
# Validation loss: 1.527985
#
# Done!

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses)+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('BCE Loss')
plt.legend()

# %% [markdown]
# # Train full adverserial neural network

# %% [markdown]
# # Setup dataloaders

# %%
# the structure is: feature, classifier label, adversary label, weight
# The wight is 1 for tritrig and wab, and 0 for phiKK, to prevent the adversary from learning on phiKK events

train_full_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy().astype(np.float32))  , torch.from_numpy(y_train.to_numpy().astype(np.float32)).unsqueeze(1), torch.from_numpy(y_adv_train),  (torch.from_numpy(y_train.to_numpy().astype(np.float32))==0).float())
train_full_loader = DataLoader(train_full_dataset, batch_size=bsize, shuffle=True)

val_full_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy().astype(np.float32))  , torch.from_numpy(y_val.to_numpy().astype(np.float32)).unsqueeze(1),  torch.from_numpy(y_adv_val),  (torch.from_numpy(y_val.to_numpy().astype(np.float32))==0).float())
val_full_loader = DataLoader(val_full_dataset, batch_size=bsize, shuffle=True)

# %% [markdown]
# ## Define loss functions

# %%
BCE_loss = nn.BCEWithLogitsLoss()
CE_loss = nn.CrossEntropyLoss(reduction='none') # returns loss per sample so we can weight it

def full_loss(output_clas, output_adv, target_clas, target_adv, w, lambda_):

    loss1 = BCE_loss(output_clas, target_clas )  # classification loss
    sample_losses2 = CE_loss(output_adv, target_adv)  # adversarial losses, since we set reduction='none', this is now a vector of losses, one per sample in the batch

     # Weighted mean loss over non-zero weights
    nonzero = w > 0
    loss2 = (sample_losses2[nonzero] * w[nonzero]).sum() / w[nonzero].sum()

    loss = loss1 - lambda_*loss2

    return loss

# %% [markdown]
# ## Setup optimizers

# %%
optimizer_clas = optim.Adam(final_classifier.parameters(), lr=1e-7,betas=(0.5, 0.999))
optimizer_adv = optim.Adam(final_adv.parameters(), lr=1e-5,betas=(0.5, 0.999))

scheduler_clas = torch.optim.lr_scheduler.ExponentialLR(optimizer_clas, gamma=0.999)
scheduler_adv = torch.optim.lr_scheduler.ExponentialLR(optimizer_adv, gamma=0.999)

# %% [markdown]
# ## Adversarial training

# %%
Training_losses_clas = np.array([])
Training_losses_adv = np.array([])
Validation_losses_clas = np.array([])
Validation_losses_adv = np.array([])
diff_scores = np.array([])


epochs = 50
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")

    # Get validation losses
    E_clas_val_loss, E_adv_val_loss = mytools.validate_full(val_full_loader, final_classifier, final_adv, full_loss, lambda_, criterion_adv, device)
    Validation_losses_clas = np.append(Validation_losses_clas, E_clas_val_loss)
    Validation_losses_adv = np.append(Validation_losses_adv, E_adv_val_loss)

    # Train adversary and classifier
    E_clas_training_loss , E_adv_training_loss = mytools.train_full(train_full_loader, final_classifier, final_adv, full_loss, lambda_, criterion_adv, optimizer_clas, optimizer_adv, scheduler_clas, scheduler_adv, device)
    Training_losses_clas = np.append(Training_losses_clas, E_clas_training_loss)
    Training_losses_adv = np.append(Training_losses_adv, E_adv_training_loss)

    # Get the diff_score
    df_test["Class_adv"] = mytools.test_clas(test_loader, final_classifier, device)
    df_bkg = df_test.loc[ (df_test.type == 'tritrig') | (df_test.type == 'wab')]
    per = np.percentile(df_bkg['Class_adv'],99)
    df_cut = df_bkg[df_bkg['Class_adv']>per].reset_index(drop=True)
    x1 = 1000* df_bkg.InvM.values
    x2 = 1000*df_cut.InvM.values
    diff_scores = np.append(diff_scores, mytools.get_diff_score(x1,x2) )

    # Keep a running copy of the model with the lowest loss
    if diff_scores[-1] == np.min(diff_scores):
        final_clas_adv = copy.deepcopy(final_classifier)
        final_adv_adv = copy.deepcopy(final_adv)

            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Classifier validation loss: -152.754080
# Adversary validation loss: 1.528056
# Classifier training loss: -152.820962
# Adversary training loss: 1.529281
# Epoch 2
# -------------------------------
# Classifier validation loss: -153.223633
# Adversary validation loss: 1.532795
# Classifier training loss: -153.056622
# Adversary training loss: 1.531664
# Epoch 3
# -------------------------------
# Classifier validation loss: -153.076981
# Adversary validation loss: 1.531348
# Classifier training loss: -153.653393
# Adversary training loss: 1.537730
# Epoch 4
# -------------------------------
# Classifier validation loss: -153.605667
# Adversary validation loss: 1.536649
# Classifier training loss: -154.134878
# Adversary training loss: 1.542372
# Epoch 5
# -------------------------------
# Classifier validation loss: -153.941229
# Adversary validation loss: 1.540034
# Classifier training loss: -154.332635
# Adversary training loss: 1.544385
# Epoch 6
# -------------------------------
# Classifier validation loss: -154.358603
# Adversary validation loss: 1.544201
# Classifier training loss: -154.512651
# Adversary training loss: 1.546107
# Epoch 7
# -------------------------------
# Classifier validation loss: -154.360703
# Adversary validation loss: 1.544202
# Classifier training loss: -154.692902
# Adversary training loss: 1.547891
# Epoch 8
# -------------------------------
# Classifier validation loss: -154.639706
# Adversary validation loss: 1.547068
# Classifier training loss: -154.825322
# Adversary training loss: 1.549151
# Epoch 9
# -------------------------------
# Classifier validation loss: -154.627832
# Adversary validation loss: 1.546988
# Classifier training loss: -154.901245
# Adversary training loss: 1.549884
# Epoch 10
# -------------------------------
# Classifier validation loss: -154.855136
# Adversary validation loss: 1.549271
# Classifier training loss: -154.832604
# Adversary training loss: 1.549195
# Epoch 11
# -------------------------------
# Classifier validation loss: -154.852249
# Adversary validation loss: 1.549303
# Classifier training loss: -154.906586
# Adversary training loss: 1.549986
# Epoch 12
# -------------------------------
# Classifier validation loss: -154.429623
# Adversary validation loss: 1.545105
# Classifier training loss: -154.813170
# Adversary training loss: 1.549046
# Epoch 13
# -------------------------------
# Classifier validation loss: -154.582318
# Adversary validation loss: 1.546647
# Classifier training loss: -154.898261
# Adversary training loss: 1.549848
# Epoch 14
# -------------------------------
# Classifier validation loss: -154.307834
# Adversary validation loss: 1.543934
# Classifier training loss: -154.738961
# Adversary training loss: 1.548253
# Epoch 15
# -------------------------------
# Classifier validation loss: -154.379761
# Adversary validation loss: 1.544674
# Classifier training loss: -154.692522
# Adversary training loss: 1.547781
# Epoch 16
# -------------------------------
# Classifier validation loss: -154.182706
# Adversary validation loss: 1.542709
# Classifier training loss: -154.629996
# Adversary training loss: 1.547148
# Epoch 17
# -------------------------------
# Classifier validation loss: -154.529773
# Adversary validation loss: 1.546184
# Classifier training loss: -154.564548
# Adversary training loss: 1.546491
# Epoch 18
# -------------------------------
# Classifier validation loss: -154.158829
# Adversary validation loss: 1.542489
# Classifier training loss: -154.570619
# Adversary training loss: 1.546558
# Epoch 19
# -------------------------------
# Classifier validation loss: -154.024167
# Adversary validation loss: 1.541159
# Classifier training loss: -154.433695
# Adversary training loss: 1.545229
# Epoch 20
# -------------------------------
# Classifier validation loss: -154.082532
# Adversary validation loss: 1.541783
# Classifier training loss: -154.396016
# Adversary training loss: 1.544841
# Epoch 21
# -------------------------------
# Classifier validation loss: -154.309631
# Adversary validation loss: 1.544057
# Classifier training loss: -154.421889
# Adversary training loss: 1.545098
# Epoch 22
# -------------------------------
# Classifier validation loss: -154.055179
# Adversary validation loss: 1.541486
# Classifier training loss: -154.319692
# Adversary training loss: 1.544125
# Epoch 23
# -------------------------------
# Classifier validation loss: -154.309381
# Adversary validation loss: 1.544068
# Classifier training loss: -154.196264
# Adversary training loss: 1.542866
# Epoch 24
# -------------------------------
# Classifier validation loss: -154.082852
# Adversary validation loss: 1.541797
# Classifier training loss: -154.322171
# Adversary training loss: 1.544165
# Epoch 25
# -------------------------------
# Classifier validation loss: -154.022577
# Adversary validation loss: 1.541245
# Classifier training loss: -154.169054
# Adversary training loss: 1.542593
# Epoch 26
# -------------------------------
# Classifier validation loss: -154.238678
# Adversary validation loss: 1.543344
# Classifier training loss: -154.131275
# Adversary training loss: 1.542269
# Epoch 27
# -------------------------------
# Classifier validation loss: -153.880164
# Adversary validation loss: 1.539800
# Classifier training loss: -153.997723
# Adversary training loss: 1.540918
# Epoch 28
# -------------------------------
# Classifier validation loss: -153.920215
# Adversary validation loss: 1.540191
# Classifier training loss: -154.067018
# Adversary training loss: 1.541622
# Epoch 29
# -------------------------------
# Classifier validation loss: -153.822556
# Adversary validation loss: 1.539236
# Classifier training loss: -153.936403
# Adversary training loss: 1.540302
# Epoch 30
# -------------------------------
# Classifier validation loss: -153.592410
# Adversary validation loss: 1.536934
# Classifier training loss: -153.964415
# Adversary training loss: 1.540618
# Epoch 31
# -------------------------------
# Classifier validation loss: -153.856354
# Adversary validation loss: 1.539547
# Classifier training loss: -153.883057
# Adversary training loss: 1.539776
# Epoch 32
# -------------------------------
# Classifier validation loss: -153.403079
# Adversary validation loss: 1.535054
# Classifier training loss: -153.886642
# Adversary training loss: 1.539813
# Epoch 33
# -------------------------------
# Classifier validation loss: -153.698511
# Adversary validation loss: 1.538033
# Classifier training loss: -153.888234
# Adversary training loss: 1.539824
# Epoch 34
# -------------------------------
# Classifier validation loss: -153.691049
# Adversary validation loss: 1.537911
# Classifier training loss: -153.772166
# Adversary training loss: 1.538684
# Epoch 35
# -------------------------------
# Classifier validation loss: -153.770441
# Adversary validation loss: 1.538716
# Classifier training loss: -153.761249
# Adversary training loss: 1.538559
# Epoch 36
# -------------------------------
# Classifier validation loss: -154.034558
# Adversary validation loss: 1.541430
# Classifier training loss: -153.753855
# Adversary training loss: 1.538500
# Epoch 37
# -------------------------------
# Classifier validation loss: -153.579129
# Adversary validation loss: 1.536852
# Classifier training loss: -153.783564
# Adversary training loss: 1.538798
# Epoch 38
# -------------------------------
# Classifier validation loss: -153.439410
# Adversary validation loss: 1.535464
# Classifier training loss: -153.776805
# Adversary training loss: 1.538766
# Epoch 39
# -------------------------------
# Classifier validation loss: -153.465076
# Adversary validation loss: 1.535651
# Classifier training loss: -153.648950
# Adversary training loss: 1.537444
# Epoch 40
# -------------------------------
# Classifier validation loss: -153.302539
# Adversary validation loss: 1.534032
# Classifier training loss: -153.653978
# Adversary training loss: 1.537515
# Epoch 41
# -------------------------------
# Classifier validation loss: -153.673148
# Adversary validation loss: 1.537750
# Classifier training loss: -153.508543
# Adversary training loss: 1.536077
# Epoch 42
# -------------------------------
# Classifier validation loss: -153.561218
# Adversary validation loss: 1.536650
# Classifier training loss: -153.590171
# Adversary training loss: 1.536929
# Epoch 43
# -------------------------------
# Classifier validation loss: -153.773404
# Adversary validation loss: 1.538812
# Classifier training loss: -153.521418
# Adversary training loss: 1.536156
# Epoch 44
# -------------------------------
# Classifier validation loss: -153.245483
# Adversary validation loss: 1.533516
# Classifier training loss: -153.482310
# Adversary training loss: 1.535778
# Epoch 45
# -------------------------------
# Classifier validation loss: -153.172363
# Adversary validation loss: 1.532773
# Classifier training loss: -153.511180
# Adversary training loss: 1.536059
# Epoch 46
# -------------------------------
# Classifier validation loss: -153.367761
# Adversary validation loss: 1.534639
# Classifier training loss: -153.531843
# Adversary training loss: 1.536292
# Epoch 47
# -------------------------------
# Classifier validation loss: -153.183557
# Adversary validation loss: 1.532885
# Classifier training loss: -153.501840
# Adversary training loss: 1.535987
# Epoch 48
# -------------------------------
# Classifier validation loss: -153.491064
# Adversary validation loss: 1.535940
# Classifier training loss: -153.439501
# Adversary training loss: 1.535346
# Epoch 49
# -------------------------------
# Classifier validation loss: -153.226749
# Adversary validation loss: 1.533304
# Classifier training loss: -153.448044
# Adversary training loss: 1.535477
# Epoch 50
# -------------------------------
# Classifier validation loss: -153.389810
# Adversary validation loss: 1.534934
# Classifier training loss: -153.411843
# Adversary training loss: 1.535072
# Done!

# %%
fig, ax1 = plt.subplots()

best_epoch = np.argmin(diff_scores)+1



#ax1.plot(np.arange(len(Training_losses_adv))+1, Training_losses_adv, 'k-', label='Training Adversary')
ax1.plot(np.arange(len(Validation_losses_adv))+1, Validation_losses_adv, 'k-', label='Validation Adversary')

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Adversary Loss', color='k')
ax1.tick_params(axis='y', labelcolor='k')

ax2 = ax1.twinx()

#ax2.plot(np.arange(len(Training_losses_clas))+1, Training_losses_clas, 'r-', label='Training Classifier')
ax2.plot(np.arange(len(Validation_losses_clas))+1, Validation_losses_clas, 'r-', label='Validation Classifier')
ax2.axvline(best_epoch,label="Final model stopped here",color='k')

ax2.set_ylabel('Classifier Loss', color='r')
ax2.tick_params(axis='y', labelcolor='r')

# %% [markdown]
# ## Test adversarially trained models

# %%
# Now test the pretrained model
test_pred = mytools.test_clas(test_loader, final_clas_adv, device)
test_pred=torch.sigmoid(torch.tensor(test_pred)).numpy()


fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test, test_pred, pos_label=1)
auc_test = sklearn.metrics.auc(fpr, tpr)
print(f'Test AUROC: {auc_test:0.4f}')

plt.plot(fpr, tpr, label=f'Test AUROC: {auc_test:0.4f}')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
# Out:
# Test AUROC: 0.9851

# %%
df_test["Class_adv"] = test_pred
df_bkg = df_test.loc[ (df_test.type == 'tritrig') | (df_test.type == 'wab')]
per = np.percentile(df_bkg['Class_adv'],99)
df_cut = df_bkg[df_bkg['Class_adv']>per].reset_index(drop=True)
x_vals = 1000*df_cut.InvM

plt.figure()
plt.hist(1000*df_bkg.InvM, bins=np.arange(980,1250,1), histtype='step', label='No selection', density=True)
plt.hist(x_vals, bins=np.arange(980,1250,1), histtype='step', label= '99 percent selection', density=True)
plt.axvline(1019.461, color='k', linestyle='dashed', linewidth=1, label='PDG phi mass')
plt.xlabel('Invariant Mass [MeV]')
plt.ylabel('Normalized Counts')
plt.legend()

# %%
x1 = 1000* df_bkg.InvM.values
x2 = 1000*df_cut.InvM.values

N, edges = np.histogram(x1, bins=np.arange(980,1250,1), density=False)
M, edges = np.histogram(x2, bins=np.arange(980,1250,1), density=False)

N2 = N[(N > 0) & (M > 0)]
M2 = M[(N > 0) & (M > 0)]

diff_score = np.mean(np.abs(N2/np.sum(N)-M2/np.sum(M)) / (np.sqrt(N2)/np.sum(N) + np.sqrt(M2)/np.sum(M) ))

print(diff_score)

N = len(df_test.loc[ ((df_test.type == 'tritrig') | (df_test.type == 'wab')) & (df_test.InvM < (1.019 + 0.01) )  & (df_test.InvM > (1.019 - 0.01) ) & ( df_test['Class_adv']>per ) ] )
S = len(df_test.loc[ (df_test.type == 'phiKK') & (df_test.InvM < (1.019 + 0.01) )  & (df_test.InvM > (1.019 - 0.01) ) & ( df_test['Class_adv']>per )  ] )

print(S/N)
# Out:
# 0.7708233776831191
# 5.701863354037267

# %%
# Save the adversarially trained models
torch.save(final_clas_adv.state_dict(), "/Users/mghrear/data/ML_data/patch/classifier_adv_2021_v9_pass5_run"+str(run)+"_limited_sideband_a.pt")
torch.save(final_adv_adv.state_dict(), "/Users/mghrear/data/ML_data/patch/adversary_adv_2021_v9_pass5_run"+str(run)+"_limited_sideband_a.pt")

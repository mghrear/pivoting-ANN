# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import torch 
from torch import nn, optim
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import sklearn
from sklearn.model_selection import train_test_split
import copy
import mytools
from scipy.stats import ks_2samp, wasserstein_distance


# Print and store device being used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cpu

# %% [markdown]
# # Define important parameters

# %%
# Number of class in invariant mass used by the adversary
Num_classes = 5
# Hyper-parameter for adversarial training of the classifier
lambda_ = 100.0

run = 1

# %% [markdown]
# # Load and setup the data

# %%
df_tritrig = pd.read_pickle('/Users/mghrear/data/ML_data/patch/BDT_2019_tritrig_limited.pk')
df_tritrig['PhiKK'] = 0.0 # Add label
df_tritrig = df_tritrig.sample(frac=1, random_state=42).reset_index(drop=True) # Now shuffle the combined dataframe
df_phiKK = pd.read_pickle('/Users/mghrear/data/ML_data/patch/BDT_2019_phiKK_limited.pk')
df_phiKK['PhiKK'] = 1.0 # Add label
df_wab = pd.read_pickle('/Users/mghrear/data/ML_data/patch/BDT_2019_wab_limited.pk')
df_wab['PhiKK'] = 0.0 # Add label
df_wab = df_wab.sample(frac=1, random_state=42).reset_index(drop=True) # Now shuffle the combined dataframe

df_data_train_bkg = pd.read_pickle('/Users/mghrear/data/ML_data/patch/BDT_2019_data_limited_sideband_train_bkg.pk')
df_data_train_bkg['PhiKK'] = 0.0 # Add label

df_data = pd.read_pickle('/Users/mghrear/data/ML_data/patch/BDT_2019_data_limited_sideband_test.pk')

print("phiKK: ", len(df_phiKK))
print("data bkg: ", len(df_data_train_bkg))
print("data: ", len(df_data))
# Out:
# phiKK:  8164
# data bkg:  23704
# data:  43926

# %%
phiKK_train = df_phiKK[0:4000]


# Combine and shuffle all training data
df_train = pd.concat([phiKK_train, df_data_train_bkg], ignore_index=True, sort=False)
df_train = df_train.sample(frac=1, random_state=42).reset_index(drop=True)

# Get edges in invariant mass classes for one-hot encoding
# To be used for adverserial labels
# The edges are chosen such that each bin has equal number of background events
one_hot_edges = mytools.get_one_hot_edges(mytools.get_InvM( df_data ), n_bins=Num_classes)

# Split the training data into training and validation sets
df_train, df_val = train_test_split(df_train, test_size=0.33, random_state=41)

# Make X and y for training and validation sets
# the adverserial network has its own labels
X_train = df_train.drop(columns=['PhiKK'])
y_train = df_train['PhiKK']
y_adv_train = mytools.get_adv_labels( mytools.get_InvM(df_train), one_hot_edges)
X_val = df_val.drop(columns=['PhiKK'])
y_val = df_val['PhiKK']
y_adv_val = mytools.get_adv_labels( mytools.get_InvM(df_val), one_hot_edges)

# Make testing set with remaining events
tritrig_test = df_tritrig[20000:]
tritrig_test['type']= 'tritrig'
wab_test = df_wab[4000:]
wab_test['type']= 'wab'
phiKK_test = df_phiKK[4000:]
phiKK_test['type']= 'phiKK'

# This is just used for an invariance test
df_test = pd.concat([tritrig_test, phiKK_test,wab_test], ignore_index=True, sort=False)
df_test = df_test.sample(frac=1, random_state=42).reset_index(drop=True) # Now shuffle the combined dataframe

X_test = df_test.drop(columns=['PhiKK','type'])
y_test = df_test['PhiKK']
y_adv_test = mytools.get_adv_labels( mytools.get_InvM(df_test), one_hot_edges)

df_test["InvM"] = mytools.get_InvM(df_test) 



# Make final data set
X_final = df_data
# Out:
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_83127/340893858.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tritrig_test['type']= 'tritrig'
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_83127/340893858.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wab_test['type']= 'wab'
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_83127/340893858.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phiKK_test['type']= 'phiKK'

# %% [markdown]
# # Setup the classifier model

# %% [markdown]
# ## Setup dataloaders

# %%
bsize = 512

# Convert to tensor dataset and dataloader
train_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy().astype(np.float32))  , torch.from_numpy(y_train.to_numpy().astype(np.float32)).unsqueeze(1)  )
train_loader = DataLoader(train_dataset, batch_size=bsize, shuffle=True)

val_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy().astype(np.float32))  , torch.from_numpy(y_val.to_numpy().astype(np.float32)).unsqueeze(1)  )
val_loader = DataLoader(val_dataset, batch_size=bsize, shuffle=True)

test_dataset = TensorDataset(torch.from_numpy(X_test.to_numpy().astype(np.float32))  )
test_loader = DataLoader(test_dataset, batch_size=bsize, shuffle=False)

# %% [markdown]
# ## Initialize model, objective function, and optimizer

# %%
clas = mytools.Classifier(in_features=X_train.shape[1]).to(device)
criterion_clas = nn.BCEWithLogitsLoss()
optimizer_clas = optim.Adam(clas.parameters(), lr=1e-5)
scheduler_clas = torch.optim.lr_scheduler.ExponentialLR(optimizer_clas, gamma=0.99995)

# %% [markdown]
# ## Pre-train the classifier

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 10

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 500
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train_clas(train_loader, clas, criterion_clas, optimizer_clas, scheduler_clas, device))
    Validation_losses = np.append(Validation_losses, mytools.validate_clas(val_loader, clas, criterion_clas, device))
    
    # Keep a running copy of the model with the lowest loss
    if Validation_losses[-1] == np.min(Validation_losses):
        final_classifier = copy.deepcopy(clas)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Training loss: 0.641002
# Validation loss: 0.642567
#
# Epoch 2
# -------------------------------
# Training loss: 0.611848
# Validation loss: 0.589845
#
# Epoch 3
# -------------------------------
# Training loss: 0.596912
# Validation loss: 0.577478
#
# Epoch 4
# -------------------------------
# Training loss: 0.580289
# Validation loss: 0.572026
#
# Epoch 5
# -------------------------------
# Training loss: 0.564634
# Validation loss: 0.564806
#
# Epoch 6
# -------------------------------
# Training loss: 0.553220
# Validation loss: 0.552136
#
# Epoch 7
# -------------------------------
# Training loss: 0.545971
# Validation loss: 0.523373
#
# Epoch 8
# -------------------------------
# Training loss: 0.533176
# Validation loss: 0.521302
#
# Epoch 9
# -------------------------------
# Training loss: 0.523764
# Validation loss: 0.522354
#
# Epoch 10
# -------------------------------
# Training loss: 0.523686
# Validation loss: 0.517366
#
# Epoch 11
# -------------------------------
# Training loss: 0.511359
# Validation loss: 0.501527
#
# Epoch 12
# -------------------------------
# Training loss: 0.507132
# Validation loss: 0.490966
#
# Epoch 13
# -------------------------------
# Training loss: 0.498928
# Validation loss: 0.485564
#
# Epoch 14
# -------------------------------
# Training loss: 0.493857
# Validation loss: 0.490534
#
# Epoch 15
# -------------------------------
# Training loss: 0.488470
# Validation loss: 0.477653
#
# Epoch 16
# -------------------------------
# Training loss: 0.483899
# Validation loss: 0.474747
#
# Epoch 17
# -------------------------------
# Training loss: 0.479930
# Validation loss: 0.474467
#
# Epoch 18
# -------------------------------
# Training loss: 0.476059
# Validation loss: 0.469058
#
# Epoch 19
# -------------------------------
# Training loss: 0.471913
# Validation loss: 0.462918
#
# Epoch 20
# -------------------------------
# Training loss: 0.466737
# Validation loss: 0.464933
#
# Epoch 21
# -------------------------------
# Training loss: 0.460586
# Validation loss: 0.460719
#
# Epoch 22
# -------------------------------
# Training loss: 0.457641
# Validation loss: 0.455021
#
# Epoch 23
# -------------------------------
# Training loss: 0.456558
# Validation loss: 0.446147
#
# Epoch 24
# -------------------------------
# Training loss: 0.452107
# Validation loss: 0.449533
#
# Epoch 25
# -------------------------------
# Training loss: 0.450117
# Validation loss: 0.438649
#
# Epoch 26
# -------------------------------
# Training loss: 0.443907
# Validation loss: 0.437919
#
# Epoch 27
# -------------------------------
# Training loss: 0.441932
# Validation loss: 0.432103
#
# Epoch 28
# -------------------------------
# Training loss: 0.439828
# Validation loss: 0.432251
#
# Epoch 29
# -------------------------------
# Training loss: 0.435470
# Validation loss: 0.428642
#
# Epoch 30
# -------------------------------
# Training loss: 0.433601
# Validation loss: 0.421632
#
# Epoch 31
# -------------------------------
# Training loss: 0.430883
# Validation loss: 0.427238
#
# Epoch 32
# -------------------------------
# Training loss: 0.428103
# Validation loss: 0.419821
#
# Epoch 33
# -------------------------------
# Training loss: 0.425912
# Validation loss: 0.415413
#
# Epoch 34
# -------------------------------
# Training loss: 0.421781
# Validation loss: 0.417807
#
# Epoch 35
# -------------------------------
# Training loss: 0.419805
# Validation loss: 0.414768
#
# Epoch 36
# -------------------------------
# Training loss: 0.418112
# Validation loss: 0.417191
#
# Epoch 37
# -------------------------------
# Training loss: 0.416094
# Validation loss: 0.405665
#
# Epoch 38
# -------------------------------
# Training loss: 0.413021
# Validation loss: 0.403463
#
# Epoch 39
# -------------------------------
# Training loss: 0.411089
# Validation loss: 0.405626
#
# Epoch 40
# -------------------------------
# Training loss: 0.407853
# Validation loss: 0.406442
#
# Epoch 41
# -------------------------------
# Training loss: 0.406424
# Validation loss: 0.398277
#
# Epoch 42
# -------------------------------
# Training loss: 0.404729
# Validation loss: 0.398639
#
# Epoch 43
# -------------------------------
# Training loss: 0.402471
# Validation loss: 0.390208
#
# Epoch 44
# -------------------------------
# Training loss: 0.400162
# Validation loss: 0.396764
#
# Epoch 45
# -------------------------------
# Training loss: 0.399673
# Validation loss: 0.386708
#
# Epoch 46
# -------------------------------
# Training loss: 0.395561
# Validation loss: 0.395290
#
# Epoch 47
# -------------------------------
# Training loss: 0.393859
# Validation loss: 0.389885
#
# Epoch 48
# -------------------------------
# Training loss: 0.391523
# Validation loss: 0.400691
#
# Epoch 49
# -------------------------------
# Training loss: 0.392331
# Validation loss: 0.382398
#
# Epoch 50
# -------------------------------
# Training loss: 0.391518
# Validation loss: 0.388234
#
# Epoch 51
# -------------------------------
# Training loss: 0.387449
# Validation loss: 0.376166
#
# Epoch 52
# -------------------------------
# Training loss: 0.384990
# Validation loss: 0.379053
#
# Epoch 53
# -------------------------------
# Training loss: 0.382924
# Validation loss: 0.378930
#
# Epoch 54
# -------------------------------
# Training loss: 0.381018
# Validation loss: 0.373025
#
# Epoch 55
# -------------------------------
# Training loss: 0.380481
# Validation loss: 0.373492
#
# Epoch 56
# -------------------------------
# Training loss: 0.379842
# Validation loss: 0.370570
#
# Epoch 57
# -------------------------------
# Training loss: 0.377714
# Validation loss: 0.377528
#
# Epoch 58
# -------------------------------
# Training loss: 0.375526
# Validation loss: 0.375313
#
# Epoch 59
# -------------------------------
# Training loss: 0.376458
# Validation loss: 0.371100
#
# Epoch 60
# -------------------------------
# Training loss: 0.372942
# Validation loss: 0.376426
#
# Epoch 61
# -------------------------------
# Training loss: 0.373133
# Validation loss: 0.369473
#
# Epoch 62
# -------------------------------
# Training loss: 0.374381
# Validation loss: 0.361526
#
# Epoch 63
# -------------------------------
# Training loss: 0.369296
# Validation loss: 0.367914
#
# Epoch 64
# -------------------------------
# Training loss: 0.368808
# Validation loss: 0.369437
#
# Epoch 65
# -------------------------------
# Training loss: 0.368077
# Validation loss: 0.360275
#
# Epoch 66
# -------------------------------
# Training loss: 0.366897
# Validation loss: 0.364042
#
# Epoch 67
# -------------------------------
# Training loss: 0.366578
# Validation loss: 0.364392
#
# Epoch 68
# -------------------------------
# Training loss: 0.367860
# Validation loss: 0.355266
#
# Epoch 69
# -------------------------------
# Training loss: 0.362846
# Validation loss: 0.361108
#
# Epoch 70
# -------------------------------
# Training loss: 0.359749
# Validation loss: 0.354956
#
# Epoch 71
# -------------------------------
# Training loss: 0.359108
# Validation loss: 0.361026
#
# Epoch 72
# -------------------------------
# Training loss: 0.357901
# Validation loss: 0.351882
#
# Epoch 73
# -------------------------------
# Training loss: 0.356580
# Validation loss: 0.348038
#
# Epoch 74
# -------------------------------
# Training loss: 0.355538
# Validation loss: 0.349902
#
# Epoch 75
# -------------------------------
# Training loss: 0.353552
# Validation loss: 0.356765
#
# Epoch 76
# -------------------------------
# Training loss: 0.353157
# Validation loss: 0.358923
#
# Epoch 77
# -------------------------------
# Training loss: 0.351731
# Validation loss: 0.349661
#
# Epoch 78
# -------------------------------
# Training loss: 0.352352
# Validation loss: 0.356822
#
# Epoch 79
# -------------------------------
# Training loss: 0.350924
# Validation loss: 0.357722
#
# Epoch 80
# -------------------------------
# Training loss: 0.349683
# Validation loss: 0.345995
#
# Epoch 81
# -------------------------------
# Training loss: 0.346968
# Validation loss: 0.343276
#
# Epoch 82
# -------------------------------
# Training loss: 0.347876
# Validation loss: 0.344034
#
# Epoch 83
# -------------------------------
# Training loss: 0.345234
# Validation loss: 0.338860
#
# Epoch 84
# -------------------------------
# Training loss: 0.345167
# Validation loss: 0.363047
#
# Epoch 85
# -------------------------------
# Training loss: 0.343779
# Validation loss: 0.342436
#
# Epoch 86
# -------------------------------
# Training loss: 0.343046
# Validation loss: 0.339308
#
# Epoch 87
# -------------------------------
# Training loss: 0.343392
# Validation loss: 0.347466
#
# Epoch 88
# -------------------------------
# Training loss: 0.340744
# Validation loss: 0.332999
#
# Epoch 89
# -------------------------------
# Training loss: 0.339599
# Validation loss: 0.347032
#
# Epoch 90
# -------------------------------
# Training loss: 0.338168
# Validation loss: 0.344360
#
# Epoch 91
# -------------------------------
# Training loss: 0.338816
# Validation loss: 0.327990
#
# Epoch 92
# -------------------------------
# Training loss: 0.338087
# Validation loss: 0.336694
#
# Epoch 93
# -------------------------------
# Training loss: 0.336074
# Validation loss: 0.334258
#
# Epoch 94
# -------------------------------
# Training loss: 0.336725
# Validation loss: 0.330290
#
# Epoch 95
# -------------------------------
# Training loss: 0.334456
# Validation loss: 0.340577
#
# Epoch 96
# -------------------------------
# Training loss: 0.333868
# Validation loss: 0.331892
#
# Epoch 97
# -------------------------------
# Training loss: 0.329573
# Validation loss: 0.331114
#
# Epoch 98
# -------------------------------
# Training loss: 0.330495
# Validation loss: 0.329756
#
# Epoch 99
# -------------------------------
# Training loss: 0.328319
# Validation loss: 0.328476
#
# Epoch 100
# -------------------------------
# Training loss: 0.327213
# Validation loss: 0.319349
#
# Epoch 101
# -------------------------------
# Training loss: 0.327835
# Validation loss: 0.318948
#
# Epoch 102
# -------------------------------
# Training loss: 0.325813
# Validation loss: 0.324385
#
# Epoch 103
# -------------------------------
# Training loss: 0.324510
# Validation loss: 0.322245
#
# Epoch 104
# -------------------------------
# Training loss: 0.325765
# Validation loss: 0.327501
#
# Epoch 105
# -------------------------------
# Training loss: 0.327138
# Validation loss: 0.327269
#
# Epoch 106
# -------------------------------
# Training loss: 0.324200
# Validation loss: 0.356807
#
# Epoch 107
# -------------------------------
# Training loss: 0.322374
# Validation loss: 0.340338
#
# Epoch 108
# -------------------------------
# Training loss: 0.321084
# Validation loss: 0.322820
#
# Epoch 109
# -------------------------------
# Training loss: 0.320761
# Validation loss: 0.315304
#
# Epoch 110
# -------------------------------
# Training loss: 0.317989
# Validation loss: 0.322086
#
# Epoch 111
# -------------------------------
# Training loss: 0.318959
# Validation loss: 0.333088
#
# Epoch 112
# -------------------------------
# Training loss: 0.315594
# Validation loss: 0.312628
#
# Epoch 113
# -------------------------------
# Training loss: 0.315390
# Validation loss: 0.323518
#
# Epoch 114
# -------------------------------
# Training loss: 0.314363
# Validation loss: 0.410125
#
# Epoch 115
# -------------------------------
# Training loss: 0.310346
# Validation loss: 0.345481
#
# Epoch 116
# -------------------------------
# Training loss: 0.311692
# Validation loss: 0.318189
#
# Epoch 117
# -------------------------------
# Training loss: 0.307926
# Validation loss: 0.367163
#
# Epoch 118
# -------------------------------
# Training loss: 0.303613
# Validation loss: 0.341756
#
# Epoch 119
# -------------------------------
# Training loss: 0.307371
# Validation loss: 0.369225
#
# Epoch 120
# -------------------------------
# Training loss: 0.299617
# Validation loss: 0.300300
#
# Epoch 121
# -------------------------------
# Training loss: 0.300744
# Validation loss: 0.297279
#
# Epoch 122
# -------------------------------
# Training loss: 0.301161
# Validation loss: 0.304796
#
# Epoch 123
# -------------------------------
# Training loss: 0.299025
# Validation loss: 0.399758
#
# Epoch 124
# -------------------------------
# Training loss: 0.298313
# Validation loss: 0.396124
#
# Epoch 125
# -------------------------------
# Training loss: 0.296910
# Validation loss: 0.289108
#
# Epoch 126
# -------------------------------
# Training loss: 0.293884
# Validation loss: 0.279213
#
# Epoch 127
# -------------------------------
# Training loss: 0.288915
# Validation loss: 0.553905
#
# Epoch 128
# -------------------------------
# Training loss: 0.293137
# Validation loss: 0.298300
#
# Epoch 129
# -------------------------------
# Training loss: 0.287521
# Validation loss: 0.325673
#
# Epoch 130
# -------------------------------
# Training loss: 0.293814
# Validation loss: 0.316911
#
# Epoch 131
# -------------------------------
# Training loss: 0.290360
# Validation loss: 0.276957
#
# Epoch 132
# -------------------------------
# Training loss: 0.276949
# Validation loss: 0.270175
#
# Epoch 133
# -------------------------------
# Training loss: 0.273763
# Validation loss: 0.281818
#
# Epoch 134
# -------------------------------
# Training loss: 0.277028
# Validation loss: 0.297650
#
# Epoch 135
# -------------------------------
# Training loss: 0.274288
# Validation loss: 0.427579
#
# Epoch 136
# -------------------------------
# Training loss: 0.278464
# Validation loss: 0.278071
#
# Epoch 137
# -------------------------------
# Training loss: 0.267049
# Validation loss: 0.477041
#
# Epoch 138
# -------------------------------
# Training loss: 0.272776
# Validation loss: 0.261348
#
# Epoch 139
# -------------------------------
# Training loss: 0.264561
# Validation loss: 0.356701
#
# Epoch 140
# -------------------------------
# Training loss: 0.265524
# Validation loss: 0.304217
#
# Epoch 141
# -------------------------------
# Training loss: 0.270295
# Validation loss: 0.279255
#
# Epoch 142
# -------------------------------
# Training loss: 0.268693
# Validation loss: 0.279565
#
# Epoch 143
# -------------------------------
# Training loss: 0.263892
# Validation loss: 0.249255
#
# Epoch 144
# -------------------------------
# Training loss: 0.264057
# Validation loss: 0.253865
#
# Epoch 145
# -------------------------------
# Training loss: 0.259394
# Validation loss: 0.245578
#
# Epoch 146
# -------------------------------
# Training loss: 0.253169
# Validation loss: 0.268017
#
# Epoch 147
# -------------------------------
# Training loss: 0.261631
# Validation loss: 0.382838
#
# Epoch 148
# -------------------------------
# Training loss: 0.248725
# Validation loss: 0.305213
#
# Epoch 149
# -------------------------------
# Training loss: 0.247356
# Validation loss: 0.247731
#
# Epoch 150
# -------------------------------
# Training loss: 0.244573
# Validation loss: 0.252990
#
# Epoch 151
# -------------------------------
# Training loss: 0.241073
# Validation loss: 0.274285
#
# Epoch 152
# -------------------------------
# Training loss: 0.243641
# Validation loss: 0.583440
#
# Epoch 153
# -------------------------------
# Training loss: 0.238446
# Validation loss: 0.263010
#
# Epoch 154
# -------------------------------
# Training loss: 0.250603
# Validation loss: 0.232122
#
# Epoch 155
# -------------------------------
# Training loss: 0.244315
# Validation loss: 0.264955
#
# Epoch 156
# -------------------------------
# Training loss: 0.235528
# Validation loss: 0.262163
#
# Epoch 157
# -------------------------------
# Training loss: 0.237934
# Validation loss: 0.278444
#
# Epoch 158
# -------------------------------
# Training loss: 0.235046
# Validation loss: 0.265309
#
# Epoch 159
# -------------------------------
# Training loss: 0.231729
# Validation loss: 0.265333
#
# Epoch 160
# -------------------------------
# Training loss: 0.232431
# Validation loss: 0.269500
#
# Epoch 161
# -------------------------------
# Training loss: 0.228299
# Validation loss: 0.391684
#
# Epoch 162
# -------------------------------
# Training loss: 0.230810
# Validation loss: 0.282616
#
# Epoch 163
# -------------------------------
# Training loss: 0.226504
# Validation loss: 0.345661
#
# Epoch 164
# -------------------------------
# Training loss: 0.222035
# Validation loss: 0.322829
#
# Epoch 165
# -------------------------------
# Training loss: 0.218490
# Validation loss: 0.507284
#
# Epoch 166
# -------------------------------
# Training loss: 0.216438
# Validation loss: 0.238962
#
# Epoch 167
# -------------------------------
# Training loss: 0.208114
# Validation loss: 0.464174
#
# Epoch 168
# -------------------------------
# Training loss: 0.217840
# Validation loss: 0.210572
#
# Epoch 169
# -------------------------------
# Training loss: 0.214385
# Validation loss: 0.274648
#
# Epoch 170
# -------------------------------
# Training loss: 0.216933
# Validation loss: 0.309131
#
# Epoch 171
# -------------------------------
# Training loss: 0.214766
# Validation loss: 0.279469
#
# Epoch 172
# -------------------------------
# Training loss: 0.208450
# Validation loss: 0.295200
#
# Epoch 173
# -------------------------------
# Training loss: 0.207095
# Validation loss: 0.222379
#
# Epoch 174
# -------------------------------
# Training loss: 0.212300
# Validation loss: 0.236408
#
# Epoch 175
# -------------------------------
# Training loss: 0.209482
# Validation loss: 0.207528
#
# Epoch 176
# -------------------------------
# Training loss: 0.204539
# Validation loss: 0.196440
#
# Epoch 177
# -------------------------------
# Training loss: 0.196659
# Validation loss: 0.267348
#
# Epoch 178
# -------------------------------
# Training loss: 0.193506
# Validation loss: 0.199764
#
# Epoch 179
# -------------------------------
# Training loss: 0.206959
# Validation loss: 0.335790
#
# Epoch 180
# -------------------------------
# Training loss: 0.197331
# Validation loss: 0.248029
#
# Epoch 181
# -------------------------------
# Training loss: 0.203864
# Validation loss: 0.303900
#
# Epoch 182
# -------------------------------
# Training loss: 0.194259
# Validation loss: 0.240257
#
# Epoch 183
# -------------------------------
# Training loss: 0.188980
# Validation loss: 0.186313
#
# Epoch 184
# -------------------------------
# Training loss: 0.188270
# Validation loss: 0.179004
#
# Epoch 185
# -------------------------------
# Training loss: 0.196712
# Validation loss: 0.392250
#
# Epoch 186
# -------------------------------
# Training loss: 0.197370
# Validation loss: 0.206543
#
# Epoch 187
# -------------------------------
# Training loss: 0.184335
# Validation loss: 0.234297
#
# Epoch 188
# -------------------------------
# Training loss: 0.182776
# Validation loss: 0.230791
#
# Epoch 189
# -------------------------------
# Training loss: 0.178208
# Validation loss: 0.173256
#
# Epoch 190
# -------------------------------
# Training loss: 0.184080
# Validation loss: 0.215306
#
# Epoch 191
# -------------------------------
# Training loss: 0.194838
# Validation loss: 0.263861
#
# Epoch 192
# -------------------------------
# Training loss: 0.173714
# Validation loss: 0.339788
#
# Epoch 193
# -------------------------------
# Training loss: 0.174212
# Validation loss: 0.157176
#
# Epoch 194
# -------------------------------
# Training loss: 0.181071
# Validation loss: 0.234914
#
# Epoch 195
# -------------------------------
# Training loss: 0.177558
# Validation loss: 0.248261
#
# Epoch 196
# -------------------------------
# Training loss: 0.170226
# Validation loss: 0.170330
#
# Epoch 197
# -------------------------------
# Training loss: 0.170524
# Validation loss: 0.234550
#
# Epoch 198
# -------------------------------
# Training loss: 0.174267
# Validation loss: 0.185195
#
# Epoch 199
# -------------------------------
# Training loss: 0.171109
# Validation loss: 0.156288
#
# Epoch 200
# -------------------------------
# Training loss: 0.168493
# Validation loss: 0.152635
#
# Epoch 201
# -------------------------------
# Training loss: 0.173369
# Validation loss: 0.273478
#
# Epoch 202
# -------------------------------
# Training loss: 0.178499
# Validation loss: 0.194005
#
# Epoch 203
# -------------------------------
# Training loss: 0.165801
# Validation loss: 0.159781
#
# Epoch 204
# -------------------------------
# Training loss: 0.167025
# Validation loss: 0.148239
#
# Epoch 205
# -------------------------------
# Training loss: 0.164388
# Validation loss: 0.165600
#
# Epoch 206
# -------------------------------
# Training loss: 0.160808
# Validation loss: 0.277980
#
# Epoch 207
# -------------------------------
# Training loss: 0.164221
# Validation loss: 0.219380
#
# Epoch 208
# -------------------------------
# Training loss: 0.165415
# Validation loss: 0.153376
#
# Epoch 209
# -------------------------------
# Training loss: 0.163587
# Validation loss: 0.183079
#
# Epoch 210
# -------------------------------
# Training loss: 0.156514
# Validation loss: 0.160425
#
# Epoch 211
# -------------------------------
# Training loss: 0.167823
# Validation loss: 0.265610
#
# Epoch 212
# -------------------------------
# Training loss: 0.157475
# Validation loss: 0.802223
#
# Epoch 213
# -------------------------------
# Training loss: 0.161573
# Validation loss: 0.252963
#
# Epoch 214
# -------------------------------
# Training loss: 0.165788
# Validation loss: 0.154234
#
# Epoch 215
# -------------------------------
# Training loss: 0.159191
# Validation loss: 0.178139
#
# Epoch 216
# -------------------------------
# Training loss: 0.158520
# Validation loss: 0.159037
#
# Epoch 217
# -------------------------------
# Training loss: 0.150853
# Validation loss: 0.214938
#
# Epoch 218
# -------------------------------
# Training loss: 0.153904
# Validation loss: 0.431414
#
# Epoch 219
# -------------------------------
# Training loss: 0.151591
# Validation loss: 0.167650
#
# Epoch 220
# -------------------------------
# Training loss: 0.151800
# Validation loss: 0.184937
#
# Epoch 221
# -------------------------------
# Training loss: 0.149813
# Validation loss: 0.257713
#
# Epoch 222
# -------------------------------
# Training loss: 0.152367
# Validation loss: 0.216291
#
# Epoch 223
# -------------------------------
# Training loss: 0.150324
# Validation loss: 0.159737
#
# Epoch 224
# -------------------------------
# Training loss: 0.160313
# Validation loss: 0.169472
#
# Epoch 225
# -------------------------------
# Training loss: 0.149140
# Validation loss: 0.191863
#
# Epoch 226
# -------------------------------
# Training loss: 0.145571
# Validation loss: 0.208037
#
# Epoch 227
# -------------------------------
# Training loss: 0.146353
# Validation loss: 0.141611
#
# Epoch 228
# -------------------------------
# Training loss: 0.151103
# Validation loss: 0.145641
#
# Epoch 229
# -------------------------------
# Training loss: 0.149057
# Validation loss: 0.178266
#
# Epoch 230
# -------------------------------
# Training loss: 0.144373
# Validation loss: 0.285243
#
# Epoch 231
# -------------------------------
# Training loss: 0.158634
# Validation loss: 0.285133
#
# Epoch 232
# -------------------------------
# Training loss: 0.143399
# Validation loss: 0.197290
#
# Epoch 233
# -------------------------------
# Training loss: 0.146737
# Validation loss: 0.218231
#
# Epoch 234
# -------------------------------
# Training loss: 0.145185
# Validation loss: 0.425935
#
# Epoch 235
# -------------------------------
# Training loss: 0.137706
# Validation loss: 0.130323
#
# Epoch 236
# -------------------------------
# Training loss: 0.142521
# Validation loss: 0.129007
#
# Epoch 237
# -------------------------------
# Training loss: 0.136689
# Validation loss: 0.125794
#
# Epoch 238
# -------------------------------
# Training loss: 0.140945
# Validation loss: 0.230908
#
# Epoch 239
# -------------------------------
# Training loss: 0.143786
# Validation loss: 0.355036
#
# Epoch 240
# -------------------------------
# Training loss: 0.140137
# Validation loss: 0.226001
#
# Epoch 241
# -------------------------------
# Training loss: 0.139470
# Validation loss: 0.268693
#
# Epoch 242
# -------------------------------
# Training loss: 0.142314
# Validation loss: 0.134134
#
# Epoch 243
# -------------------------------
# Training loss: 0.141142
# Validation loss: 0.164576
#
# Epoch 244
# -------------------------------
# Training loss: 0.135616
# Validation loss: 0.211582
#
# Epoch 245
# -------------------------------
# Training loss: 0.134886
# Validation loss: 0.140601
#
# Epoch 246
# -------------------------------
# Training loss: 0.135224
# Validation loss: 0.187102
#
# Epoch 247
# -------------------------------
# Training loss: 0.139577
# Validation loss: 0.158252
#
# Epoch 248
# -------------------------------
# Training loss: 0.129567
# Validation loss: 0.137979
#
# Epoch 249
# -------------------------------
# Training loss: 0.132201
# Validation loss: 0.143334
#
# Epoch 250
# -------------------------------
# Training loss: 0.130101
# Validation loss: 0.140916
#
# Epoch 251
# -------------------------------
# Training loss: 0.129755
# Validation loss: 0.153758
#
# Epoch 252
# -------------------------------
# Training loss: 0.129507
# Validation loss: 1.219980
#
# Epoch 253
# -------------------------------
# Training loss: 0.131809
# Validation loss: 0.138896
#
# Epoch 254
# -------------------------------
# Training loss: 0.129568
# Validation loss: 0.113818
#
# Epoch 255
# -------------------------------
# Training loss: 0.128599
# Validation loss: 0.153244
#
# Epoch 256
# -------------------------------
# Training loss: 0.126004
# Validation loss: 0.136930
#
# Epoch 257
# -------------------------------
# Training loss: 0.127681
# Validation loss: 0.162831
#
# Epoch 258
# -------------------------------
# Training loss: 0.125224
# Validation loss: 0.111135
#
# Epoch 259
# -------------------------------
# Training loss: 0.130831
# Validation loss: 0.201653
#
# Epoch 260
# -------------------------------
# Training loss: 0.125265
# Validation loss: 0.145589
#
# Epoch 261
# -------------------------------
# Training loss: 0.131389
# Validation loss: 0.273227
#
# Epoch 262
# -------------------------------
# Training loss: 0.131247
# Validation loss: 0.117271
#
# Epoch 263
# -------------------------------
# Training loss: 0.132613
# Validation loss: 0.109004
#
# Epoch 264
# -------------------------------
# Training loss: 0.127444
# Validation loss: 0.111789
#
# Epoch 265
# -------------------------------
# Training loss: 0.121798
# Validation loss: 0.656809
#
# Epoch 266
# -------------------------------
# Training loss: 0.126785
# Validation loss: 0.116350
#
# Epoch 267
# -------------------------------
# Training loss: 0.132638
# Validation loss: 0.224038
#
# Epoch 268
# -------------------------------
# Training loss: 0.124467
# Validation loss: 0.133187
#
# Epoch 269
# -------------------------------
# Training loss: 0.124116
# Validation loss: 0.200876
#
# Epoch 270
# -------------------------------
# Training loss: 0.124676
# Validation loss: 0.136351
#
# Epoch 271
# -------------------------------
# Training loss: 0.128179
# Validation loss: 0.106749
#
# Epoch 272
# -------------------------------
# Training loss: 0.124527
# Validation loss: 0.118082
#
# Epoch 273
# -------------------------------
# Training loss: 0.126470
# Validation loss: 0.140183
#
# Epoch 274
# -------------------------------
# Training loss: 0.121683
# Validation loss: 0.121193
#
# Epoch 275
# -------------------------------
# Training loss: 0.119557
# Validation loss: 0.854774
#
# Epoch 276
# -------------------------------
# Training loss: 0.124457
# Validation loss: 0.149238
#
# Epoch 277
# -------------------------------
# Training loss: 0.120902
# Validation loss: 0.137366
#
# Epoch 278
# -------------------------------
# Training loss: 0.123052
# Validation loss: 0.148992
#
# Epoch 279
# -------------------------------
# Training loss: 0.116127
# Validation loss: 0.145962
#
# Epoch 280
# -------------------------------
# Training loss: 0.121188
# Validation loss: 0.114180
#
# Epoch 281
# -------------------------------
# Training loss: 0.121819
# Validation loss: 0.160251
#
# Epoch 282
# -------------------------------
# Training loss: 0.119003
# Validation loss: 0.116656
#
# Epoch 283
# -------------------------------
# Training loss: 0.114937
# Validation loss: 0.114554
#
# Epoch 284
# -------------------------------
# Training loss: 0.114323
# Validation loss: 0.114656
#
# Epoch 285
# -------------------------------
# Training loss: 0.120204
# Validation loss: 0.517969
#
# Epoch 286
# -------------------------------
# Training loss: 0.115867
# Validation loss: 0.103486
#
# Epoch 287
# -------------------------------
# Training loss: 0.113742
# Validation loss: 0.122612
#
# Epoch 288
# -------------------------------
# Training loss: 0.115792
# Validation loss: 0.109129
#
# Epoch 289
# -------------------------------
# Training loss: 0.118885
# Validation loss: 0.281489
#
# Epoch 290
# -------------------------------
# Training loss: 0.119291
# Validation loss: 0.130160
#
# Epoch 291
# -------------------------------
# Training loss: 0.118318
# Validation loss: 0.103942
#
# Epoch 292
# -------------------------------
# Training loss: 0.115967
# Validation loss: 0.191496
#
# Epoch 293
# -------------------------------
# Training loss: 0.111330
# Validation loss: 0.144985
#
# Epoch 294
# -------------------------------
# Training loss: 0.110728
# Validation loss: 0.183280
#
# Epoch 295
# -------------------------------
# Training loss: 0.112476
# Validation loss: 0.339166
#
# Epoch 296
# -------------------------------
# Training loss: 0.113197
# Validation loss: 0.206794
#
# Epoch 297
# -------------------------------
# Training loss: 0.124656
# Validation loss: 0.131915
#
# Epoch 298
# -------------------------------
# Training loss: 0.110516
# Validation loss: 0.186834
#
# Epoch 299
# -------------------------------
# Training loss: 0.113261
# Validation loss: 0.120349
#
# Epoch 300
# -------------------------------
# Training loss: 0.107733
# Validation loss: 0.146897
#
# Epoch 301
# -------------------------------
# Training loss: 0.108828
# Validation loss: 0.169382
#
# Epoch 302
# -------------------------------
# Training loss: 0.111540
# Validation loss: 0.143058
#
# Epoch 303
# -------------------------------
# Training loss: 0.111264
# Validation loss: 0.188049
#
# Epoch 304
# -------------------------------
# Training loss: 0.108616
# Validation loss: 0.235047
#
# Epoch 305
# -------------------------------
# Training loss: 0.112088
# Validation loss: 0.142147
#
# Epoch 306
# -------------------------------
# Training loss: 0.113911
# Validation loss: 0.156813
#
# Epoch 307
# -------------------------------
# Training loss: 0.113244
# Validation loss: 0.099542
#
# Epoch 308
# -------------------------------
# Training loss: 0.108477
# Validation loss: 0.124251
#
# Epoch 309
# -------------------------------
# Training loss: 0.110219
# Validation loss: 0.208571
#
# Epoch 310
# -------------------------------
# Training loss: 0.111427
# Validation loss: 0.098743
#
# Epoch 311
# -------------------------------
# Training loss: 0.113546
# Validation loss: 0.176026
#
# Epoch 312
# -------------------------------
# Training loss: 0.108123
# Validation loss: 0.094724
#
# Epoch 313
# -------------------------------
# Training loss: 0.111170
# Validation loss: 0.282394
#
# Epoch 314
# -------------------------------
# Training loss: 0.107403
# Validation loss: 0.123615
#
# Epoch 315
# -------------------------------
# Training loss: 0.104561
# Validation loss: 0.146242
#
# Epoch 316
# -------------------------------
# Training loss: 0.108121
# Validation loss: 0.109356
#
# Epoch 317
# -------------------------------
# Training loss: 0.105010
# Validation loss: 0.607311
#
# Epoch 318
# -------------------------------
# Training loss: 0.105577
# Validation loss: 0.110895
#
# Epoch 319
# -------------------------------
# Training loss: 0.112117
# Validation loss: 0.153109
#
# Epoch 320
# -------------------------------
# Training loss: 0.106324
# Validation loss: 0.098602
#
# Epoch 321
# -------------------------------
# Training loss: 0.110867
# Validation loss: 0.104613
#
# Epoch 322
# -------------------------------
# Training loss: 0.104648
# Validation loss: 0.127022
#
# Epoch 323
# -------------------------------
# Training loss: 0.106806
# Validation loss: 0.313756
#
# Epoch 324
# -------------------------------
# Training loss: 0.104062
# Validation loss: 0.118550
#
# Epoch 325
# -------------------------------
# Training loss: 0.102967
# Validation loss: 0.618966
#
# Epoch 326
# -------------------------------
# Training loss: 0.104527
# Validation loss: 0.166583
#
# Epoch 327
# -------------------------------
# Training loss: 0.109941
# Validation loss: 0.110324
#
# Epoch 328
# -------------------------------
# Training loss: 0.106124
# Validation loss: 0.438728
#
# Epoch 329
# -------------------------------
# Training loss: 0.106614
# Validation loss: 0.117342
#
# Epoch 330
# -------------------------------
# Training loss: 0.104550
# Validation loss: 0.099125
#
# Epoch 331
# -------------------------------
# Training loss: 0.105480
# Validation loss: 0.115625
#
# Epoch 332
# -------------------------------
# Training loss: 0.103236
# Validation loss: 0.222030
#
# Epoch 333
# -------------------------------
# Training loss: 0.100946
# Validation loss: 0.204275
#
# Epoch 334
# -------------------------------
# Training loss: 0.100029
# Validation loss: 0.092739
#
# Epoch 335
# -------------------------------
# Training loss: 0.100949
# Validation loss: 0.195195
#
# Epoch 336
# -------------------------------
# Training loss: 0.102687
# Validation loss: 0.089784
#
# Epoch 337
# -------------------------------
# Training loss: 0.105607
# Validation loss: 0.213927
#
# Epoch 338
# -------------------------------
# Training loss: 0.104090
# Validation loss: 0.163683
#
# Epoch 339
# -------------------------------
# Training loss: 0.099031
# Validation loss: 0.104737
#
# Epoch 340
# -------------------------------
# Training loss: 0.101275
# Validation loss: 0.118323
#
# Epoch 341
# -------------------------------
# Training loss: 0.108895
# Validation loss: 0.137277
#
# Epoch 342
# -------------------------------
# Training loss: 0.113120
# Validation loss: 0.220892
#
# Epoch 343
# -------------------------------
# Training loss: 0.099553
# Validation loss: 0.313751
#
# Epoch 344
# -------------------------------
# Training loss: 0.109207
# Validation loss: 0.177137
#
# Epoch 345
# -------------------------------
# Training loss: 0.101055
# Validation loss: 0.143657
#
# Epoch 346
# -------------------------------
# Training loss: 0.097758
# Validation loss: 0.102338
#
# Epoch 347
# -------------------------------
# Training loss: 0.099070
# Validation loss: 0.093482
#
# Epoch 348
# -------------------------------
# Training loss: 0.098926
# Validation loss: 0.091055
#
# Epoch 349
# -------------------------------
# Training loss: 0.105560
# Validation loss: 0.086857
#
# Epoch 350
# -------------------------------
# Training loss: 0.100010
# Validation loss: 0.104718
#
# Epoch 351
# -------------------------------
# Training loss: 0.097107
# Validation loss: 0.154676
#
# Epoch 352
# -------------------------------
# Training loss: 0.095870
# Validation loss: 0.150611
#
# Epoch 353
# -------------------------------
# Training loss: 0.102121
# Validation loss: 0.207780
#
# Epoch 354
# -------------------------------
# Training loss: 0.095737
# Validation loss: 0.089518
#
# Epoch 355
# -------------------------------
# Training loss: 0.095185
# Validation loss: 0.143300
#
# Epoch 356
# -------------------------------
# Training loss: 0.094902
# Validation loss: 0.111728
#
# Epoch 357
# -------------------------------
# Training loss: 0.097381
# Validation loss: 0.111855
#
# Epoch 358
# -------------------------------
# Training loss: 0.097628
# Validation loss: 0.089583
#
# Epoch 359
# -------------------------------
# Training loss: 0.095659
# Validation loss: 0.087242
#
# Epoch 360
# -------------------------------
# Training loss: 0.095331
# Validation loss: 0.099596
#
# Epoch 361
# -------------------------------
# Training loss: 0.098748
# Validation loss: 0.230312
#
# Epoch 362
# -------------------------------
# Training loss: 0.099414
# Validation loss: 0.113715
#
# Epoch 363
# -------------------------------
# Training loss: 0.091992
# Validation loss: 0.123050
#
# Epoch 364
# -------------------------------
# Training loss: 0.102321
# Validation loss: 0.175340
#
# Epoch 365
# -------------------------------
# Training loss: 0.098658
# Validation loss: 0.108319
#
# Epoch 366
# -------------------------------
# Training loss: 0.096482
# Validation loss: 0.098802
#
# Epoch 367
# -------------------------------
# Training loss: 0.093269
# Validation loss: 0.095879
#
# Epoch 368
# -------------------------------
# Training loss: 0.099367
# Validation loss: 0.120930
#
# Epoch 369
# -------------------------------
# Training loss: 0.098416
# Validation loss: 0.085869
#
# Epoch 370
# -------------------------------
# Training loss: 0.094007
# Validation loss: 0.137648
#
# Epoch 371
# -------------------------------
# Training loss: 0.098152
# Validation loss: 0.095560
#
# Epoch 372
# -------------------------------
# Training loss: 0.092795
# Validation loss: 0.109068
#
# Epoch 373
# -------------------------------
# Training loss: 0.093954
# Validation loss: 0.087808
#
# Epoch 374
# -------------------------------
# Training loss: 0.095205
# Validation loss: 0.690860
#
# Epoch 375
# -------------------------------
# Training loss: 0.095805
# Validation loss: 0.109723
#
# Epoch 376
# -------------------------------
# Training loss: 0.090726
# Validation loss: 0.083549
#
# Epoch 377
# -------------------------------
# Training loss: 0.092328
# Validation loss: 0.155105
#
# Epoch 378
# -------------------------------
# Training loss: 0.096429
# Validation loss: 0.154916
#
# Epoch 379
# -------------------------------
# Training loss: 0.093330
# Validation loss: 0.082059
#
# Epoch 380
# -------------------------------
# Training loss: 0.094418
# Validation loss: 0.145613
#
# Epoch 381
# -------------------------------
# Training loss: 0.096372
# Validation loss: 0.086711
#
# Epoch 382
# -------------------------------
# Training loss: 0.089455
# Validation loss: 0.111899
#
# Epoch 383
# -------------------------------
# Training loss: 0.091283
# Validation loss: 0.089097
#
# Epoch 384
# -------------------------------
# Training loss: 0.090639
# Validation loss: 0.088238
#
# Epoch 385
# -------------------------------
# Training loss: 0.091944
# Validation loss: 0.090526
#
# Epoch 386
# -------------------------------
# Training loss: 0.093845
# Validation loss: 0.096244
#
# Epoch 387
# -------------------------------
# Training loss: 0.097731
# Validation loss: 0.101707
#
# Epoch 388
# -------------------------------
# Training loss: 0.091755
# Validation loss: 0.082997
#
# Epoch 389
# -------------------------------
# Training loss: 0.092030
# Validation loss: 0.107431
#
# Epoch 390
# -------------------------------
# Training loss: 0.092569
# Validation loss: 0.120513
#
# Epoch 391
# -------------------------------
# Training loss: 0.098433
# Validation loss: 0.097444
#
# Epoch 392
# -------------------------------
# Training loss: 0.096108
# Validation loss: 0.104057
#
# Epoch 393
# -------------------------------
# Training loss: 0.097406
# Validation loss: 0.088282
#
# Epoch 394
# -------------------------------
# Training loss: 0.093009
# Validation loss: 0.106679
#
# Epoch 395
# -------------------------------
# Training loss: 0.089640
# Validation loss: 0.122117
#
# Epoch 396
# -------------------------------
# Training loss: 0.089493
# Validation loss: 0.106196
#
# Epoch 397
# -------------------------------
# Training loss: 0.088772
# Validation loss: 0.101724
#
# Epoch 398
# -------------------------------
# Training loss: 0.092239
# Validation loss: 0.080465
#
# Epoch 399
# -------------------------------
# Training loss: 0.091192
# Validation loss: 0.176336
#
# Epoch 400
# -------------------------------
# Training loss: 0.092302
# Validation loss: 0.085432
#
# Epoch 401
# -------------------------------
# Training loss: 0.091136
# Validation loss: 0.113994
#
# Epoch 402
# -------------------------------
# Training loss: 0.091827
# Validation loss: 0.118426
#
# Epoch 403
# -------------------------------
# Training loss: 0.087231
# Validation loss: 0.105252
#
# Epoch 404
# -------------------------------
# Training loss: 0.088286
# Validation loss: 0.230542
#
# Epoch 405
# -------------------------------
# Training loss: 0.089166
# Validation loss: 0.080555
#
# Epoch 406
# -------------------------------
# Training loss: 0.088864
# Validation loss: 0.185121
#
# Epoch 407
# -------------------------------
# Training loss: 0.088274
# Validation loss: 0.127694
#
# Epoch 408
# -------------------------------
# Training loss: 0.086279
# Validation loss: 0.092351
#
# Epoch 409
# -------------------------------
# Training loss: 0.089384
# Validation loss: 0.077462
#
# Epoch 410
# -------------------------------
# Training loss: 0.088707
# Validation loss: 0.264889
#
# Epoch 411
# -------------------------------
# Training loss: 0.093567
# Validation loss: 0.133150
#
# Epoch 412
# -------------------------------
# Training loss: 0.087853
# Validation loss: 0.174021
#
# Epoch 413
# -------------------------------
# Training loss: 0.085115
# Validation loss: 0.113271
#
# Epoch 414
# -------------------------------
# Training loss: 0.089901
# Validation loss: 0.231123
#
# Epoch 415
# -------------------------------
# Training loss: 0.092237
# Validation loss: 0.107422
#
# Epoch 416
# -------------------------------
# Training loss: 0.084173
# Validation loss: 0.173606
#
# Epoch 417
# -------------------------------
# Training loss: 0.088948
# Validation loss: 0.085961
#
# Epoch 418
# -------------------------------
# Training loss: 0.084998
# Validation loss: 0.096310
#
# Epoch 419
# -------------------------------
# Training loss: 0.084122
# Validation loss: 0.077876
#
# Epoch 420
# -------------------------------
# Training loss: 0.084520
# Validation loss: 0.112871
#
# Epoch 421
# -------------------------------
# Training loss: 0.085359
# Validation loss: 0.171862
#
# Epoch 422
# -------------------------------
# Training loss: 0.084302
# Validation loss: 0.080583
#
# Epoch 423
# -------------------------------
# Training loss: 0.085471
# Validation loss: 0.110965
#
# Epoch 424
# -------------------------------
# Training loss: 0.089388
# Validation loss: 0.090013
#
# Epoch 425
# -------------------------------
# Training loss: 0.086619
# Validation loss: 0.081830
#
# Epoch 426
# -------------------------------
# Training loss: 0.090002
# Validation loss: 0.117760
#
# Epoch 427
# -------------------------------
# Training loss: 0.083200
# Validation loss: 0.074924
#
# Epoch 428
# -------------------------------
# Training loss: 0.092319
# Validation loss: 0.161218
#
# Epoch 429
# -------------------------------
# Training loss: 0.084762
# Validation loss: 0.075408
#
# Epoch 430
# -------------------------------
# Training loss: 0.088858
# Validation loss: 0.646127
#
# Epoch 431
# -------------------------------
# Training loss: 0.087426
# Validation loss: 0.082545
#
# Epoch 432
# -------------------------------
# Training loss: 0.083903
# Validation loss: 0.444957
#
# Epoch 433
# -------------------------------
# Training loss: 0.091346
# Validation loss: 0.087750
#
# Epoch 434
# -------------------------------
# Training loss: 0.086459
# Validation loss: 0.117660
#
# Epoch 435
# -------------------------------
# Training loss: 0.084375
# Validation loss: 0.074280
#
# Epoch 436
# -------------------------------
# Training loss: 0.085462
# Validation loss: 0.141844
#
# Epoch 437
# -------------------------------
# Training loss: 0.082632
# Validation loss: 0.102809
#
# Epoch 438
# -------------------------------
# Training loss: 0.082100
# Validation loss: 0.110224
#
# Epoch 439
# -------------------------------
# Training loss: 0.084042
# Validation loss: 0.188343
#
# Epoch 440
# -------------------------------
# Training loss: 0.083066
# Validation loss: 0.077021
#
# Epoch 441
# -------------------------------
# Training loss: 0.083086
# Validation loss: 0.187462
#
# Epoch 442
# -------------------------------
# Training loss: 0.082665
# Validation loss: 0.094611
#
# Epoch 443
# -------------------------------
# Training loss: 0.081955
# Validation loss: 0.089218
#
# Epoch 444
# -------------------------------
# Training loss: 0.082258
# Validation loss: 0.076382
#
# Epoch 445
# -------------------------------
# Training loss: 0.080605
# Validation loss: 0.084510
#
# Epoch 446
# -------------------------------
# Training loss: 0.082703
# Validation loss: 0.072638
#
# Epoch 447
# -------------------------------
# Training loss: 0.082250
# Validation loss: 0.088817
#
# Epoch 448
# -------------------------------
# Training loss: 0.082512
# Validation loss: 0.128349
#
# Epoch 449
# -------------------------------
# Training loss: 0.082274
# Validation loss: 0.077139
#
# Epoch 450
# -------------------------------
# Training loss: 0.081445
# Validation loss: 0.085976
#
# Epoch 451
# -------------------------------
# Training loss: 0.084054
# Validation loss: 0.150964
#
# Epoch 452
# -------------------------------
# Training loss: 0.079437
# Validation loss: 0.126627
#
# Epoch 453
# -------------------------------
# Training loss: 0.083195
# Validation loss: 0.145322
#
# Epoch 454
# -------------------------------
# Training loss: 0.082027
# Validation loss: 0.156490
#
# Epoch 455
# -------------------------------
# Training loss: 0.089335
# Validation loss: 0.168255
#
# Epoch 456
# -------------------------------
# Training loss: 0.082279
# Validation loss: 0.144840
#
# Epoch 457
# -------------------------------
# Training loss: 0.082087
# Validation loss: 0.284594
#
# Epoch 458
# -------------------------------
# Training loss: 0.079735
# Validation loss: 0.077938
#
# Epoch 459
# -------------------------------
# Training loss: 0.082211
# Validation loss: 0.074716
#
# Epoch 460
# -------------------------------
# Training loss: 0.082269
# Validation loss: 0.089966
#
# Epoch 461
# -------------------------------
# Training loss: 0.080828
# Validation loss: 0.078976
#
# Epoch 462
# -------------------------------
# Training loss: 0.087206
# Validation loss: 0.094116
#
# Epoch 463
# -------------------------------
# Training loss: 0.084523
# Validation loss: 0.077232
#
# Epoch 464
# -------------------------------
# Training loss: 0.086434
# Validation loss: 0.084606
#
# Epoch 465
# -------------------------------
# Training loss: 0.078574
# Validation loss: 0.072956
#
# Epoch 466
# -------------------------------
# Training loss: 0.082168
# Validation loss: 0.276114
#
# Epoch 467
# -------------------------------
# Training loss: 0.084629
# Validation loss: 0.086425
#
# Epoch 468
# -------------------------------
# Training loss: 0.084502
# Validation loss: 0.077955
#
# Epoch 469
# -------------------------------
# Training loss: 0.079651
# Validation loss: 0.143376
#
# Epoch 470
# -------------------------------
# Training loss: 0.083937
# Validation loss: 0.581543
#
# Epoch 471
# -------------------------------
# Training loss: 0.082342
# Validation loss: 0.095949
#
# Epoch 472
# -------------------------------
# Training loss: 0.077128
# Validation loss: 0.106692
#
# Epoch 473
# -------------------------------
# Training loss: 0.078875
# Validation loss: 0.076424
#
# Epoch 474
# -------------------------------
# Training loss: 0.080062
# Validation loss: 0.111549
#
# Epoch 475
# -------------------------------
# Training loss: 0.084126
# Validation loss: 0.079147
#
# Epoch 476
# -------------------------------
# Training loss: 0.081886
# Validation loss: 0.091523
#
# Epoch 477
# -------------------------------
# Training loss: 0.081140
# Validation loss: 0.073159
#
# Epoch 478
# -------------------------------
# Training loss: 0.079541
# Validation loss: 0.148669
#
# Epoch 479
# -------------------------------
# Training loss: 0.079956
# Validation loss: 0.105072
#
# Epoch 480
# -------------------------------
# Training loss: 0.079450
# Validation loss: 0.165568
#
# Epoch 481
# -------------------------------
# Training loss: 0.080886
# Validation loss: 0.078712
#
# Epoch 482
# -------------------------------
# Training loss: 0.077188
# Validation loss: 0.080849
#
# Epoch 483
# -------------------------------
# Training loss: 0.078304
# Validation loss: 0.080703
#
# Epoch 484
# -------------------------------
# Training loss: 0.080132
# Validation loss: 0.081898
#
# Epoch 485
# -------------------------------
# Training loss: 0.079529
# Validation loss: 0.068458
#
# Epoch 486
# -------------------------------
# Training loss: 0.078621
# Validation loss: 0.157068
#
# Epoch 487
# -------------------------------
# Training loss: 0.079630
# Validation loss: 0.092619
#
# Epoch 488
# -------------------------------
# Training loss: 0.079287
# Validation loss: 0.071858
#
# Epoch 489
# -------------------------------
# Training loss: 0.079266
# Validation loss: 0.069870
#
# Epoch 490
# -------------------------------
# Training loss: 0.077021
# Validation loss: 0.097813
#
# Epoch 491
# -------------------------------
# Training loss: 0.077269
# Validation loss: 0.104793
#
# Epoch 492
# -------------------------------
# Training loss: 0.079777
# Validation loss: 0.143172
#
# Epoch 493
# -------------------------------
# Training loss: 0.081439
# Validation loss: 0.071579
#
# Epoch 494
# -------------------------------
# Training loss: 0.080848
# Validation loss: 0.083985
#
# Epoch 495
# -------------------------------
# Training loss: 0.075542
# Validation loss: 0.085385
#
# Epoch 496
# -------------------------------
# Training loss: 0.078695
# Validation loss: 0.085125
#
# Epoch 497
# -------------------------------
# Training loss: 0.077185
# Validation loss: 0.071951
#
# Epoch 498
# -------------------------------
# Training loss: 0.077101
# Validation loss: 0.313401
#
# Epoch 499
# -------------------------------
# Training loss: 0.079082
# Validation loss: 0.086547
#
# Epoch 500
# -------------------------------
# Training loss: 0.078199
# Validation loss: 0.077921
#
# Done!

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses)+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('BCE Loss')
#plt.yscale('log')
plt.legend()

# %%
# Now test the pretrained model
test_pred = mytools.test_clas(test_loader, final_classifier, device)
test_pred=torch.sigmoid(torch.tensor(test_pred)).numpy()


fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test, test_pred, pos_label=1)
auc_test = sklearn.metrics.auc(fpr, tpr)
print(f'Test AUROC: {auc_test:0.4f}')

plt.plot(fpr, tpr, label=f'Test AUROC: {auc_test:0.4f}')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
# Out:
# Test AUROC: 0.9946

# %%
# Store the pretrained classifier labels
df_test["Class_pre"] = test_pred

# %% [markdown]
# # Setup the adversary model

# %% [markdown]
# ## Initialize model, objective function, and optimizer

# %%
adv = mytools.Adversary(n_classes=Num_classes).to(device)
criterion_adv = nn.CrossEntropyLoss(reduction='none')  # returns loss per sample so we can weight it
opt_adv = torch.optim.Adam(adv.parameters(), lr=1e-5)
scheduler_adv = torch.optim.lr_scheduler.ExponentialLR(opt_adv, gamma=0.999)

# %% [markdown]
# ## Setup dataloaders

# %%
# Convert to tensor dataset and dataloader

# the structure is: feature, adversary label, weight
# The wight is 1 for tritrig and wab, and 0 for phiKK, to prevent the adversary from learning on phiKK events

train_adv_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_train), (torch.from_numpy(y_train.to_numpy().astype(np.float32))==0).float())
train_adv_loader = DataLoader(train_adv_dataset, batch_size=bsize, shuffle=True)

val_adv_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_val), (torch.from_numpy(y_val.to_numpy().astype(np.float32))==0).float() )
val_adv_loader = DataLoader(val_adv_dataset, batch_size=bsize, shuffle=True)

# %% [markdown]
# ## Pre-train the adversary leaving classifier weights fixed

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 6

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 100
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train_adv(train_adv_loader, final_classifier, adv, criterion_adv, opt_adv, scheduler_adv, device))
    Validation_losses = np.append(Validation_losses, mytools.validate_adv(val_adv_loader, final_classifier, adv, criterion_adv, device))
    
    # Keep a running copy of the model with the lowest loss
    if Validation_losses[-1] == np.min(Validation_losses):
        final_adv = copy.deepcopy(adv)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Training loss: 1.558869
# Validation loss: 1.547377
#
# Epoch 2
# -------------------------------
# Training loss: 1.536403
# Validation loss: 1.527777
#
# Epoch 3
# -------------------------------
# Training loss: 1.520506
# Validation loss: 1.511226
#
# Epoch 4
# -------------------------------
# Training loss: 1.511660
# Validation loss: 1.503907
#
# Epoch 5
# -------------------------------
# Training loss: 1.504999
# Validation loss: 1.497997
#
# Epoch 6
# -------------------------------
# Training loss: 1.499880
# Validation loss: 1.493963
#
# Epoch 7
# -------------------------------
# Training loss: 1.496450
# Validation loss: 1.489910
#
# Epoch 8
# -------------------------------
# Training loss: 1.492601
# Validation loss: 1.487097
#
# Epoch 9
# -------------------------------
# Training loss: 1.489852
# Validation loss: 1.484713
#
# Epoch 10
# -------------------------------
# Training loss: 1.487864
# Validation loss: 1.482572
#
# Epoch 11
# -------------------------------
# Training loss: 1.485647
# Validation loss: 1.480756
#
# Epoch 12
# -------------------------------
# Training loss: 1.484847
# Validation loss: 1.479418
#
# Epoch 13
# -------------------------------
# Training loss: 1.483201
# Validation loss: 1.477568
#
# Epoch 14
# -------------------------------
# Training loss: 1.481615
# Validation loss: 1.476308
#
# Epoch 15
# -------------------------------
# Training loss: 1.479795
# Validation loss: 1.474835
#
# Epoch 16
# -------------------------------
# Training loss: 1.479775
# Validation loss: 1.473590
#
# Epoch 17
# -------------------------------
# Training loss: 1.476744
# Validation loss: 1.472539
#
# Epoch 18
# -------------------------------
# Training loss: 1.475757
# Validation loss: 1.470872
#
# Epoch 19
# -------------------------------
# Training loss: 1.475442
# Validation loss: 1.469800
#
# Epoch 20
# -------------------------------
# Training loss: 1.473559
# Validation loss: 1.468927
#
# Epoch 21
# -------------------------------
# Training loss: 1.472636
# Validation loss: 1.467689
#
# Epoch 22
# -------------------------------
# Training loss: 1.470903
# Validation loss: 1.466960
#
# Epoch 23
# -------------------------------
# Training loss: 1.469663
# Validation loss: 1.465302
#
# Epoch 24
# -------------------------------
# Training loss: 1.468769
# Validation loss: 1.464806
#
# Epoch 25
# -------------------------------
# Training loss: 1.468238
# Validation loss: 1.463924
#
# Epoch 26
# -------------------------------
# Training loss: 1.468556
# Validation loss: 1.462629
#
# Epoch 27
# -------------------------------
# Training loss: 1.466990
# Validation loss: 1.461962
#
# Epoch 28
# -------------------------------
# Training loss: 1.464469
# Validation loss: 1.461450
#
# Epoch 29
# -------------------------------
# Training loss: 1.464979
# Validation loss: 1.460586
#
# Epoch 30
# -------------------------------
# Training loss: 1.464024
# Validation loss: 1.460454
#
# Epoch 31
# -------------------------------
# Training loss: 1.465192
# Validation loss: 1.460068
#
# Epoch 32
# -------------------------------
# Training loss: 1.462376
# Validation loss: 1.458759
#
# Epoch 33
# -------------------------------
# Training loss: 1.463007
# Validation loss: 1.458784
#
# Epoch 34
# -------------------------------
# Training loss: 1.462930
# Validation loss: 1.458106
#
# Epoch 35
# -------------------------------
# Training loss: 1.459988
# Validation loss: 1.457454
#
# Epoch 36
# -------------------------------
# Training loss: 1.461288
# Validation loss: 1.457680
#
# Epoch 37
# -------------------------------
# Training loss: 1.461114
# Validation loss: 1.457815
#
# Epoch 38
# -------------------------------
# Training loss: 1.460619
# Validation loss: 1.457315
#
# Epoch 39
# -------------------------------
# Training loss: 1.460318
# Validation loss: 1.456064
#
# Epoch 40
# -------------------------------
# Training loss: 1.459181
# Validation loss: 1.455752
#
# Epoch 41
# -------------------------------
# Training loss: 1.459722
# Validation loss: 1.455399
#
# Epoch 42
# -------------------------------
# Training loss: 1.459922
# Validation loss: 1.455084
#
# Epoch 43
# -------------------------------
# Training loss: 1.459568
# Validation loss: 1.454682
#
# Epoch 44
# -------------------------------
# Training loss: 1.459033
# Validation loss: 1.455654
#
# Epoch 45
# -------------------------------
# Training loss: 1.458457
# Validation loss: 1.454761
#
# Epoch 46
# -------------------------------
# Training loss: 1.457528
# Validation loss: 1.454797
#
# Epoch 47
# -------------------------------
# Training loss: 1.457744
# Validation loss: 1.453840
#
# Epoch 48
# -------------------------------
# Training loss: 1.458820
# Validation loss: 1.453374
#
# Epoch 49
# -------------------------------
# Training loss: 1.457286
# Validation loss: 1.453375
#
# Epoch 50
# -------------------------------
# Training loss: 1.457372
# Validation loss: 1.454388
#
# Epoch 51
# -------------------------------
# Training loss: 1.457264
# Validation loss: 1.453599
#
# Epoch 52
# -------------------------------
# Training loss: 1.457788
# Validation loss: 1.452887
#
# Epoch 53
# -------------------------------
# Training loss: 1.455152
# Validation loss: 1.452903
#
# Epoch 54
# -------------------------------
# Training loss: 1.457270
# Validation loss: 1.453153
#
# Epoch 55
# -------------------------------
# Training loss: 1.457517
# Validation loss: 1.453613
#
# Epoch 56
# -------------------------------
# Training loss: 1.456072
# Validation loss: 1.452598
#
# Epoch 57
# -------------------------------
# Training loss: 1.456295
# Validation loss: 1.452636
#
# Epoch 58
# -------------------------------
# Training loss: 1.455980
# Validation loss: 1.452205
#
# Epoch 59
# -------------------------------
# Training loss: 1.456729
# Validation loss: 1.452552
#
# Epoch 60
# -------------------------------
# Training loss: 1.456038
# Validation loss: 1.452260
#
# Epoch 61
# -------------------------------
# Training loss: 1.455126
# Validation loss: 1.452019
#
# Epoch 62
# -------------------------------
# Training loss: 1.455493
# Validation loss: 1.451427
#
# Epoch 63
# -------------------------------
# Training loss: 1.455855
# Validation loss: 1.451903
#
# Epoch 64
# -------------------------------
# Training loss: 1.455954
# Validation loss: 1.451291
#
# Epoch 65
# -------------------------------
# Training loss: 1.455924
# Validation loss: 1.451211
#
# Epoch 66
# -------------------------------
# Training loss: 1.454308
# Validation loss: 1.451263
#
# Epoch 67
# -------------------------------
# Training loss: 1.455339
# Validation loss: 1.451404
#
# Epoch 68
# -------------------------------
# Training loss: 1.455056
# Validation loss: 1.451245
#
# Epoch 69
# -------------------------------
# Training loss: 1.455611
# Validation loss: 1.451479
#
# Epoch 70
# -------------------------------
# Training loss: 1.455018
# Validation loss: 1.450886
#
# Epoch 71
# -------------------------------
# Training loss: 1.453533
# Validation loss: 1.450589
#
# Epoch 72
# -------------------------------
# Training loss: 1.454879
# Validation loss: 1.450700
#
# Epoch 73
# -------------------------------
# Training loss: 1.454050
# Validation loss: 1.451147
#
# Epoch 74
# -------------------------------
# Training loss: 1.453309
# Validation loss: 1.450859
#
# Epoch 75
# -------------------------------
# Training loss: 1.454696
# Validation loss: 1.450788
#
# Epoch 76
# -------------------------------
# Training loss: 1.454161
# Validation loss: 1.450565
#
# Epoch 77
# -------------------------------
# Training loss: 1.454472
# Validation loss: 1.450422
#
# Epoch 78
# -------------------------------
# Training loss: 1.453444
# Validation loss: 1.450865
#
# Epoch 79
# -------------------------------
# Training loss: 1.453212
# Validation loss: 1.450450
#
# Epoch 80
# -------------------------------
# Training loss: 1.454123
# Validation loss: 1.450523
#
# Epoch 81
# -------------------------------
# Training loss: 1.454537
# Validation loss: 1.449968
#
# Epoch 82
# -------------------------------
# Training loss: 1.456093
# Validation loss: 1.450265
#
# Epoch 83
# -------------------------------
# Training loss: 1.453933
# Validation loss: 1.450459
#
# Epoch 84
# -------------------------------
# Training loss: 1.455385
# Validation loss: 1.450325
#
# Epoch 85
# -------------------------------
# Training loss: 1.453000
# Validation loss: 1.449999
#
# Epoch 86
# -------------------------------
# Training loss: 1.453606
# Validation loss: 1.449781
#
# Epoch 87
# -------------------------------
# Training loss: 1.453873
# Validation loss: 1.450231
#
# Epoch 88
# -------------------------------
# Training loss: 1.453647
# Validation loss: 1.449962
#
# Epoch 89
# -------------------------------
# Training loss: 1.453162
# Validation loss: 1.450110
#
# Epoch 90
# -------------------------------
# Training loss: 1.452957
# Validation loss: 1.450239
#
# Epoch 91
# -------------------------------
# Training loss: 1.452406
# Validation loss: 1.450637
#
# Epoch 92
# -------------------------------
# Training loss: 1.452728
# Validation loss: 1.449805
#
# Epoch 93
# -------------------------------
# Training loss: 1.453956
# Validation loss: 1.449386
#
# Epoch 94
# -------------------------------
# Training loss: 1.454784
# Validation loss: 1.450361
#
# Epoch 95
# -------------------------------
# Training loss: 1.452930
# Validation loss: 1.449516
#
# Epoch 96
# -------------------------------
# Training loss: 1.453805
# Validation loss: 1.450032
#
# Epoch 97
# -------------------------------
# Training loss: 1.453351
# Validation loss: 1.449442
#
# Epoch 98
# -------------------------------
# Training loss: 1.453245
# Validation loss: 1.449898
#
# Epoch 99
# -------------------------------
# Training loss: 1.454186
# Validation loss: 1.450032
#
# Epoch 100
# -------------------------------
# Training loss: 1.453731
# Validation loss: 1.449567
#
# Done!

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses)+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('BCE Loss')
plt.legend()

# %% [markdown]
# # Train full adverserial neural network

# %% [markdown]
# # Setup dataloaders

# %%
# the structure is: feature, classifier label, adversary label, weight
# The wight is 1 for tritrig and wab, and 0 for phiKK, to prevent the adversary from learning on phiKK events

train_full_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy().astype(np.float32))  , torch.from_numpy(y_train.to_numpy().astype(np.float32)).unsqueeze(1), torch.from_numpy(y_adv_train),  (torch.from_numpy(y_train.to_numpy().astype(np.float32))==0).float())
train_full_loader = DataLoader(train_full_dataset, batch_size=bsize, shuffle=True)

val_full_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy().astype(np.float32))  , torch.from_numpy(y_val.to_numpy().astype(np.float32)).unsqueeze(1),  torch.from_numpy(y_adv_val),  (torch.from_numpy(y_val.to_numpy().astype(np.float32))==0).float())
val_full_loader = DataLoader(val_full_dataset, batch_size=bsize, shuffle=True)

# %% [markdown]
# ## Define loss functions

# %%
BCE_loss = nn.BCEWithLogitsLoss()
CE_loss = nn.CrossEntropyLoss(reduction='none') # returns loss per sample so we can weight it

def full_loss(output_clas, output_adv, target_clas, target_adv, w, lambda_):

    loss1 = BCE_loss(output_clas, target_clas )  # classification loss
    sample_losses2 = CE_loss(output_adv, target_adv)  # adversarial losses, since we set reduction='none', this is now a vector of losses, one per sample in the batch

     # Weighted mean loss over non-zero weights
    nonzero = w > 0
    loss2 = (sample_losses2[nonzero] * w[nonzero]).sum() / w[nonzero].sum()

    loss = loss1 - lambda_*loss2

    return loss

# %% [markdown]
# ## Setup optimizers

# %%
optimizer_clas = optim.Adam(final_classifier.parameters(), lr=1e-7,betas=(0.5, 0.999))
optimizer_adv = optim.Adam(final_adv.parameters(), lr=1e-5,betas=(0.5, 0.999))

scheduler_clas = torch.optim.lr_scheduler.ExponentialLR(optimizer_clas, gamma=0.999)
scheduler_adv = torch.optim.lr_scheduler.ExponentialLR(optimizer_adv, gamma=0.999)

# %% [markdown]
# ## Adversarial training

# %%
Training_losses_clas = np.array([])
Training_losses_adv = np.array([])
Validation_losses_clas = np.array([])
Validation_losses_adv = np.array([])
diff_scores = np.array([])


epochs = 50
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")

    # Get validation losses
    E_clas_val_loss, E_adv_val_loss = mytools.validate_full(val_full_loader, final_classifier, final_adv, full_loss, lambda_, criterion_adv, device)
    Validation_losses_clas = np.append(Validation_losses_clas, E_clas_val_loss)
    Validation_losses_adv = np.append(Validation_losses_adv, E_adv_val_loss)

    # Train adversary and classifier
    E_clas_training_loss , E_adv_training_loss = mytools.train_full(train_full_loader, final_classifier, final_adv, full_loss, lambda_, criterion_adv, optimizer_clas, optimizer_adv, scheduler_clas, scheduler_adv, device)
    Training_losses_clas = np.append(Training_losses_clas, E_clas_training_loss)
    Training_losses_adv = np.append(Training_losses_adv, E_adv_training_loss)

    # Get the diff_score
    df_test["Class_adv"] = mytools.test_clas(test_loader, final_classifier, device)
    df_bkg = df_test.loc[ (df_test.type == 'tritrig') | (df_test.type == 'wab')]
    per = np.percentile(df_bkg['Class_adv'],99)
    df_cut = df_bkg[df_bkg['Class_adv']>per].reset_index(drop=True)
    x1 = 1000* df_bkg.InvM.values
    x2 = 1000*df_cut.InvM.values
    diff_scores = np.append(diff_scores, mytools.get_diff_score(x1,x2) )

    # Keep a running copy of the model with the lowest loss
    if diff_scores[-1] == np.min(diff_scores):
        final_clas_adv = copy.deepcopy(final_classifier)
        final_adv_adv = copy.deepcopy(final_adv)

            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Classifier validation loss: -144.870955
# Adversary validation loss: 1.449394
# Classifier training loss: -148.292033
# Adversary training loss: 1.484784
# Epoch 2
# -------------------------------
# Classifier validation loss: -149.090858
# Adversary validation loss: 1.491654
# Classifier training loss: -150.095676
# Adversary training loss: 1.502437
# Epoch 3
# -------------------------------
# Classifier validation loss: -150.181275
# Adversary validation loss: 1.502654
# Classifier training loss: -150.150950
# Adversary training loss: 1.502817
# Epoch 4
# -------------------------------
# Classifier validation loss: -149.685497
# Adversary validation loss: 1.497740
# Classifier training loss: -149.743593
# Adversary training loss: 1.498789
# Epoch 5
# -------------------------------
# Classifier validation loss: -149.431256
# Adversary validation loss: 1.495260
# Classifier training loss: -149.504746
# Adversary training loss: 1.496606
# Epoch 6
# -------------------------------
# Classifier validation loss: -149.056677
# Adversary validation loss: 1.491687
# Classifier training loss: -149.573124
# Adversary training loss: 1.497676
# Epoch 7
# -------------------------------
# Classifier validation loss: -149.723466
# Adversary validation loss: 1.498691
# Classifier training loss: -149.875779
# Adversary training loss: 1.501046
# Epoch 8
# -------------------------------
# Classifier validation loss: -149.732183
# Adversary validation loss: 1.499104
# Classifier training loss: -149.911843
# Adversary training loss: 1.501670
# Epoch 9
# -------------------------------
# Classifier validation loss: -148.964684
# Adversary validation loss: 1.491720
# Classifier training loss: -149.477318
# Adversary training loss: 1.497550
# Epoch 10
# -------------------------------
# Classifier validation loss: -148.698967
# Adversary validation loss: 1.489206
# Classifier training loss: -149.000122
# Adversary training loss: 1.492862
# Epoch 11
# -------------------------------
# Classifier validation loss: -148.615349
# Adversary validation loss: 1.488528
# Classifier training loss: -148.693649
# Adversary training loss: 1.489890
# Epoch 12
# -------------------------------
# Classifier validation loss: -148.669118
# Adversary validation loss: 1.489141
# Classifier training loss: -148.059070
# Adversary training loss: 1.483546
# Epoch 13
# -------------------------------
# Classifier validation loss: -147.624902
# Adversary validation loss: 1.478602
# Classifier training loss: -147.607860
# Adversary training loss: 1.479112
# Epoch 14
# -------------------------------
# Classifier validation loss: -147.261955
# Adversary validation loss: 1.475092
# Classifier training loss: -147.264603
# Adversary training loss: 1.475662
# Epoch 15
# -------------------------------
# Classifier validation loss: -147.413656
# Adversary validation loss: 1.476669
# Classifier training loss: -147.033559
# Adversary training loss: 1.473305
# Epoch 16
# -------------------------------
# Classifier validation loss: -146.978614
# Adversary validation loss: 1.472269
# Classifier training loss: -146.978387
# Adversary training loss: 1.472762
# Epoch 17
# -------------------------------
# Classifier validation loss: -147.233415
# Adversary validation loss: 1.474790
# Classifier training loss: -146.881856
# Adversary training loss: 1.471776
# Epoch 18
# -------------------------------
# Classifier validation loss: -147.353249
# Adversary validation loss: 1.475830
# Classifier training loss: -146.949281
# Adversary training loss: 1.472403
# Epoch 19
# -------------------------------
# Classifier validation loss: -147.552062
# Adversary validation loss: 1.477859
# Classifier training loss: -147.351939
# Adversary training loss: 1.476419
# Epoch 20
# -------------------------------
# Classifier validation loss: -147.700223
# Adversary validation loss: 1.479322
# Classifier training loss: -147.958662
# Adversary training loss: 1.482451
# Epoch 21
# -------------------------------
# Classifier validation loss: -148.385110
# Adversary validation loss: 1.486043
# Classifier training loss: -148.268583
# Adversary training loss: 1.485504
# Epoch 22
# -------------------------------
# Classifier validation loss: -148.555826
# Adversary validation loss: 1.487760
# Classifier training loss: -148.702493
# Adversary training loss: 1.489848
# Epoch 23
# -------------------------------
# Classifier validation loss: -148.774055
# Adversary validation loss: 1.490102
# Classifier training loss: -149.218600
# Adversary training loss: 1.494961
# Epoch 24
# -------------------------------
# Classifier validation loss: -150.008613
# Adversary validation loss: 1.502696
# Classifier training loss: -149.082230
# Adversary training loss: 1.493561
# Epoch 25
# -------------------------------
# Classifier validation loss: -149.114421
# Adversary validation loss: 1.493416
# Classifier training loss: -149.232887
# Adversary training loss: 1.495083
# Epoch 26
# -------------------------------
# Classifier validation loss: -149.093145
# Adversary validation loss: 1.493078
# Classifier training loss: -149.272399
# Adversary training loss: 1.495485
# Epoch 27
# -------------------------------
# Classifier validation loss: -148.855037
# Adversary validation loss: 1.490983
# Classifier training loss: -149.248844
# Adversary training loss: 1.495210
# Epoch 28
# -------------------------------
# Classifier validation loss: -149.092932
# Adversary validation loss: 1.493400
# Classifier training loss: -149.151959
# Adversary training loss: 1.494340
# Epoch 29
# -------------------------------
# Classifier validation loss: -148.939526
# Adversary validation loss: 1.491680
# Classifier training loss: -149.094985
# Adversary training loss: 1.493735
# Epoch 30
# -------------------------------
# Classifier validation loss: -148.702522
# Adversary validation loss: 1.489428
# Classifier training loss: -148.982400
# Adversary training loss: 1.492651
# Epoch 31
# -------------------------------
# Classifier validation loss: -148.564900
# Adversary validation loss: 1.488315
# Classifier training loss: -148.809419
# Adversary training loss: 1.490858
# Epoch 32
# -------------------------------
# Classifier validation loss: -148.319796
# Adversary validation loss: 1.485726
# Classifier training loss: -148.764152
# Adversary training loss: 1.490411
# Epoch 33
# -------------------------------
# Classifier validation loss: -148.265121
# Adversary validation loss: 1.485140
# Classifier training loss: -148.425992
# Adversary training loss: 1.486983
# Epoch 34
# -------------------------------
# Classifier validation loss: -148.174753
# Adversary validation loss: 1.484171
# Classifier training loss: -148.438887
# Adversary training loss: 1.487108
# Epoch 35
# -------------------------------
# Classifier validation loss: -147.891363
# Adversary validation loss: 1.481539
# Classifier training loss: -148.337199
# Adversary training loss: 1.486032
# Epoch 36
# -------------------------------
# Classifier validation loss: -147.855745
# Adversary validation loss: 1.480909
# Classifier training loss: -148.181319
# Adversary training loss: 1.484445
# Epoch 37
# -------------------------------
# Classifier validation loss: -147.797403
# Adversary validation loss: 1.480373
# Classifier training loss: -148.239829
# Adversary training loss: 1.485020
# Epoch 38
# -------------------------------
# Classifier validation loss: -147.648007
# Adversary validation loss: 1.478583
# Classifier training loss: -148.105441
# Adversary training loss: 1.483651
# Epoch 39
# -------------------------------
# Classifier validation loss: -147.599103
# Adversary validation loss: 1.478456
# Classifier training loss: -147.940635
# Adversary training loss: 1.481979
# Epoch 40
# -------------------------------
# Classifier validation loss: -147.695240
# Adversary validation loss: 1.479348
# Classifier training loss: -148.133960
# Adversary training loss: 1.483920
# Epoch 41
# -------------------------------
# Classifier validation loss: -147.588237
# Adversary validation loss: 1.478180
# Classifier training loss: -148.029353
# Adversary training loss: 1.482849
# Epoch 42
# -------------------------------
# Classifier validation loss: -147.525188
# Adversary validation loss: 1.477471
# Classifier training loss: -147.962140
# Adversary training loss: 1.482133
# Epoch 43
# -------------------------------
# Classifier validation loss: -147.676921
# Adversary validation loss: 1.478992
# Classifier training loss: -148.029007
# Adversary training loss: 1.482827
# Epoch 44
# -------------------------------
# Classifier validation loss: -147.554283
# Adversary validation loss: 1.477755
# Classifier training loss: -147.948148
# Adversary training loss: 1.482025
# Epoch 45
# -------------------------------
# Classifier validation loss: -147.745768
# Adversary validation loss: 1.479707
# Classifier training loss: -148.050112
# Adversary training loss: 1.483022
# Epoch 46
# -------------------------------
# Classifier validation loss: -147.560263
# Adversary validation loss: 1.477717
# Classifier training loss: -147.986016
# Adversary training loss: 1.482354
# Epoch 47
# -------------------------------
# Classifier validation loss: -147.666952
# Adversary validation loss: 1.478986
# Classifier training loss: -148.043902
# Adversary training loss: 1.482930
# Epoch 48
# -------------------------------
# Classifier validation loss: -147.499463
# Adversary validation loss: 1.477038
# Classifier training loss: -148.027666
# Adversary training loss: 1.482720
# Epoch 49
# -------------------------------
# Classifier validation loss: -147.427511
# Adversary validation loss: 1.476387
# Classifier training loss: -148.001271
# Adversary training loss: 1.482482
# Epoch 50
# -------------------------------
# Classifier validation loss: -147.809967
# Adversary validation loss: 1.480495
# Classifier training loss: -147.967288
# Adversary training loss: 1.482108
# Done!

# %%
fig, ax1 = plt.subplots()

best_epoch = np.argmin(diff_scores)+1



#ax1.plot(np.arange(len(Training_losses_adv))+1, Training_losses_adv, 'k-', label='Training Adversary')
ax1.plot(np.arange(len(Validation_losses_adv))+1, Validation_losses_adv, 'k-', label='Validation Adversary')

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Adversary Loss', color='k')
ax1.tick_params(axis='y', labelcolor='k')

ax2 = ax1.twinx()

#ax2.plot(np.arange(len(Training_losses_clas))+1, Training_losses_clas, 'r-', label='Training Classifier')
ax2.plot(np.arange(len(Validation_losses_clas))+1, Validation_losses_clas, 'r-', label='Validation Classifier')
ax2.axvline(best_epoch,label="Final model stopped here",color='k')

ax2.set_ylabel('Classifier Loss', color='r')
ax2.tick_params(axis='y', labelcolor='r')

# %% [markdown]
# ## Test adversarially trained models

# %%
# Now test the pretrained model
test_pred = mytools.test_clas(test_loader, final_clas_adv, device)
test_pred=torch.sigmoid(torch.tensor(test_pred)).numpy()


fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test, test_pred, pos_label=1)
auc_test = sklearn.metrics.auc(fpr, tpr)
print(f'Test AUROC: {auc_test:0.4f}')

plt.plot(fpr, tpr, label=f'Test AUROC: {auc_test:0.4f}')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
# Out:
# Test AUROC: 0.9887

# %%
df_test["Class_adv"] = test_pred
df_bkg = df_test.loc[ (df_test.type == 'tritrig') | (df_test.type == 'wab')]
per = np.percentile(df_bkg['Class_adv'],99)
df_cut = df_bkg[df_bkg['Class_adv']>per].reset_index(drop=True)
x_vals = 1000*df_cut.InvM

plt.figure()
plt.hist(1000*df_bkg.InvM, bins=np.arange(980,1250,1), histtype='step', label='No selection', density=True)
plt.hist(x_vals, bins=np.arange(980,1250,1), histtype='step', label= '99 percent selection', density=True)
plt.axvline(1019.461, color='k', linestyle='dashed', linewidth=1, label='PDG phi mass')
plt.xlabel('Invariant Mass [MeV]')
plt.ylabel('Normalized Counts')
plt.legend()

# %%
x1 = 1000* df_bkg.InvM.values
x2 = 1000*df_cut.InvM.values

N, edges = np.histogram(x1, bins=np.arange(980,1250,1), density=False)
M, edges = np.histogram(x2, bins=np.arange(980,1250,1), density=False)

N2 = N[(N > 0) & (M > 0)]
M2 = M[(N > 0) & (M > 0)]

diff_score = np.mean(np.abs(N2/np.sum(N)-M2/np.sum(M)) / (np.sqrt(N2)/np.sum(N) + np.sqrt(M2)/np.sum(M) ))

print(diff_score)

N = len(df_test.loc[ ((df_test.type == 'tritrig') | (df_test.type == 'wab')) & (df_test.InvM < (1.019 + 0.01) )  & (df_test.InvM > (1.019 - 0.01) ) & ( df_test['Class_adv']>per ) ] )
S = len(df_test.loc[ (df_test.type == 'phiKK') & (df_test.InvM < (1.019 + 0.01) )  & (df_test.InvM > (1.019 - 0.01) ) & ( df_test['Class_adv']>per )  ] )

print(S/N)
# Out:
# 0.7475304749172598
# 6.918163672654691

# %%
df_test["Class_adv"] = test_pred
df_test.to_pickle("/Users/mghrear/data/ML_data/patch/ANN_results_relu_run"+str(run)+"_limited_sideband_a.pk")

# %%
# Save the adversarially trained models
torch.save(final_clas_adv.state_dict(), "/Users/mghrear/data/ML_data/patch/classifier_adv_relu_run"+str(run)+"_limited_sideband_a.pt")
torch.save(final_adv_adv.state_dict(), "/Users/mghrear/data/ML_data/patch/adversary_adv_relu_run"+str(run)+"_limited_sideband_a.pt")

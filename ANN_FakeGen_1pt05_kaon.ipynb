# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import torch 
from torch import nn, optim
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import sklearn
from sklearn.model_selection import train_test_split
import copy
import mytools


# Print and store device being used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cpu

# %% [markdown]
# # Define important parameters

# %%
# Number of class in invariant mass used by the adversary
Num_classes = 5
# Hyper-parameter for adversarial training of the classifier
lambda_ = 100.0

run = 1

# %% [markdown]
# # Load and setup the data

# %%
# Read tritrig, wab, phiKK, and data files
df_tritrig = pd.read_pickle('/Users/mghrear/data/ML_data/patch/2021_v9_pass5_tritrig_limited.pk')
df_tritrig['PhiKK'] = 0.0
df_phiKK = pd.read_pickle('/Users/mghrear/data/ML_data/patch/2021_v9_pass5_FakeGen_1pt05_kaon_limited.pk')
df_phiKK['PhiKK'] = 1.0
df_wab = pd.read_pickle('/Users/mghrear/data/ML_data/patch/2021_v9_pass5_wab_limited.pk')
df_wab['PhiKK'] = 0.0 # Add label


print("tritrig: ", len(df_tritrig))
print("phiKK: ", len(df_phiKK))
print("wab: ", len(df_wab))
# Out:
# tritrig:  120739
# phiKK:  11129
# wab:  6596

# %%
# Make Training set with 20000 tritrig, 4000 phiKK, 4000 wab
tritrig_train = df_tritrig[0:20000]
wab_train = df_wab[0:3000]
phiKK_train = df_phiKK[0:3000]

# Combine and shuffle all training data
df_train = pd.concat([tritrig_train, phiKK_train, wab_train], ignore_index=True, sort=False)
df_train = df_train.sample(frac=1, random_state=42).reset_index(drop=True)

# Get edges in invariant mass classes for one-hot encoding
# To be used for adverserial labels
# The edges are chosen such that each bin has equal number of background events
one_hot_edges = mytools.get_one_hot_edges(mytools.get_InvM( pd.concat([df_tritrig, df_wab], ignore_index=True, sort=False) ), n_bins=Num_classes)

# Split the training data into training and validation sets
df_train, df_val = train_test_split(df_train, test_size=0.33, random_state=42)

# Make X and y for training and validation sets
# the adverserial network has its own labels
X_train = df_train.drop(columns=['PhiKK'])
y_train = df_train['PhiKK']
y_adv_train = mytools.get_adv_labels( mytools.get_InvM(df_train), one_hot_edges)
X_val = df_val.drop(columns=['PhiKK'])
y_val = df_val['PhiKK']
y_adv_val = mytools.get_adv_labels( mytools.get_InvM(df_val), one_hot_edges)

# Make testing set with remaining events
tritrig_test = df_tritrig[20000:]
tritrig_test['type']= 'tritrig'
wab_test = df_wab[3000:]
wab_test['type']= 'wab'
phiKK_test = df_phiKK[3000:]
phiKK_test['type']= 'phiKK'

df_test = pd.concat([tritrig_test, phiKK_test,wab_test], ignore_index=True, sort=False)
df_test = df_test.sample(frac=1, random_state=42).reset_index(drop=True) # Now shuffle the combined dataframe

X_test = df_test.drop(columns=['PhiKK','type'])
y_test = df_test['PhiKK']
y_adv_test = mytools.get_adv_labels( mytools.get_InvM(df_test), one_hot_edges)

df_test["InvM"] = mytools.get_InvM(df_test)
# Out:
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_41434/1157922432.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tritrig_test['type']= 'tritrig'
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_41434/1157922432.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wab_test['type']= 'wab'
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_41434/1157922432.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phiKK_test['type']= 'phiKK'

# %% [markdown]
# ## Setup dataloaders

# %%
bsize = 2000

# Convert to tensor dataset and dataloader
train_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy().astype(np.float32))  , torch.from_numpy(y_train.to_numpy().astype(np.float32)).unsqueeze(1)  )
train_loader = DataLoader(train_dataset, batch_size=bsize, shuffle=True)

val_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy().astype(np.float32))  , torch.from_numpy(y_val.to_numpy().astype(np.float32)).unsqueeze(1)  )
val_loader = DataLoader(val_dataset, batch_size=bsize, shuffle=True)

test_dataset = TensorDataset(torch.from_numpy(X_test.to_numpy().astype(np.float32)))
test_loader = DataLoader(test_dataset, batch_size=bsize, shuffle=False)

# %% [markdown]
# ## Initialize model, objective function, and optimizer

# %%
clas = mytools.Classifier(in_features=X_train.shape[1]).to(device)
criterion_clas = nn.BCEWithLogitsLoss()
optimizer_clas = optim.Adam(clas.parameters(), lr=1e-5)
scheduler_clas = torch.optim.lr_scheduler.ExponentialLR(optimizer_clas, gamma=0.9999)

# %% [markdown]
# ## Pre-train the classifier

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 10

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 2500
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train_clas(train_loader, clas, criterion_clas, optimizer_clas, scheduler_clas, device))
    Validation_losses = np.append(Validation_losses, mytools.validate_clas(val_loader, clas, criterion_clas, device))
    
    # Keep a running copy of the model with the lowest loss
    if Validation_losses[-1] == np.min(Validation_losses):
        final_classifier = copy.deepcopy(clas)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Training loss: 0.564387
# Validation loss: 0.640916
#
# Epoch 2
# -------------------------------
# Training loss: 0.541717
# Validation loss: 0.638003
#
# Epoch 3
# -------------------------------
# Training loss: 0.532146
# Validation loss: 0.635579
#
# Epoch 4
# -------------------------------
# Training loss: 0.524157
# Validation loss: 0.630665
#
# Epoch 5
# -------------------------------
# Training loss: 0.516219
# Validation loss: 0.624946
#
# Epoch 6
# -------------------------------
# Training loss: 0.512776
# Validation loss: 0.585959
#
# Epoch 7
# -------------------------------
# Training loss: 0.506162
# Validation loss: 0.534857
#
# Epoch 8
# -------------------------------
# Training loss: 0.499984
# Validation loss: 0.511354
#
# Epoch 9
# -------------------------------
# Training loss: 0.497577
# Validation loss: 0.499881
#
# Epoch 10
# -------------------------------
# Training loss: 0.492089
# Validation loss: 0.495459
#
# Epoch 11
# -------------------------------
# Training loss: 0.486749
# Validation loss: 0.490282
#
# Epoch 12
# -------------------------------
# Training loss: 0.484084
# Validation loss: 0.485728
#
# Epoch 13
# -------------------------------
# Training loss: 0.481201
# Validation loss: 0.486072
#
# Epoch 14
# -------------------------------
# Training loss: 0.476959
# Validation loss: 0.485397
#
# Epoch 15
# -------------------------------
# Training loss: 0.473560
# Validation loss: 0.478147
#
# Epoch 16
# -------------------------------
# Training loss: 0.468201
# Validation loss: 0.471641
#
# Epoch 17
# -------------------------------
# Training loss: 0.466035
# Validation loss: 0.461810
#
# Epoch 18
# -------------------------------
# Training loss: 0.464169
# Validation loss: 0.457373
#
# Epoch 19
# -------------------------------
# Training loss: 0.459901
# Validation loss: 0.453677
#
# Epoch 20
# -------------------------------
# Training loss: 0.456179
# Validation loss: 0.446639
#
# Epoch 21
# -------------------------------
# Training loss: 0.455625
# Validation loss: 0.448334
#
# Epoch 22
# -------------------------------
# Training loss: 0.453172
# Validation loss: 0.447981
#
# Epoch 23
# -------------------------------
# Training loss: 0.448460
# Validation loss: 0.445426
#
# Epoch 24
# -------------------------------
# Training loss: 0.446051
# Validation loss: 0.441411
#
# Epoch 25
# -------------------------------
# Training loss: 0.445768
# Validation loss: 0.438440
#
# Epoch 26
# -------------------------------
# Training loss: 0.444909
# Validation loss: 0.446348
#
# Epoch 27
# -------------------------------
# Training loss: 0.439163
# Validation loss: 0.439296
#
# Epoch 28
# -------------------------------
# Training loss: 0.441072
# Validation loss: 0.437356
#
# Epoch 29
# -------------------------------
# Training loss: 0.436600
# Validation loss: 0.439903
#
# Epoch 30
# -------------------------------
# Training loss: 0.436106
# Validation loss: 0.434006
#
# Epoch 31
# -------------------------------
# Training loss: 0.433284
# Validation loss: 0.432988
#
# Epoch 32
# -------------------------------
# Training loss: 0.432661
# Validation loss: 0.436785
#
# Epoch 33
# -------------------------------
# Training loss: 0.431200
# Validation loss: 0.430587
#
# Epoch 34
# -------------------------------
# Training loss: 0.428912
# Validation loss: 0.425746
#
# Epoch 35
# -------------------------------
# Training loss: 0.427188
# Validation loss: 0.433407
#
# Epoch 36
# -------------------------------
# Training loss: 0.426369
# Validation loss: 0.434033
#
# Epoch 37
# -------------------------------
# Training loss: 0.425846
# Validation loss: 0.428222
#
# Epoch 38
# -------------------------------
# Training loss: 0.421703
# Validation loss: 0.430823
#
# Epoch 39
# -------------------------------
# Training loss: 0.421058
# Validation loss: 0.429000
#
# Epoch 40
# -------------------------------
# Training loss: 0.420688
# Validation loss: 0.423603
#
# Epoch 41
# -------------------------------
# Training loss: 0.418329
# Validation loss: 0.423869
#
# Epoch 42
# -------------------------------
# Training loss: 0.417465
# Validation loss: 0.420842
#
# Epoch 43
# -------------------------------
# Training loss: 0.414925
# Validation loss: 0.418192
#
# Epoch 44
# -------------------------------
# Training loss: 0.415336
# Validation loss: 0.417609
#
# Epoch 45
# -------------------------------
# Training loss: 0.411890
# Validation loss: 0.414196
#
# Epoch 46
# -------------------------------
# Training loss: 0.413085
# Validation loss: 0.417435
#
# Epoch 47
# -------------------------------
# Training loss: 0.411053
# Validation loss: 0.410234
#
# Epoch 48
# -------------------------------
# Training loss: 0.409051
# Validation loss: 0.413828
#
# Epoch 49
# -------------------------------
# Training loss: 0.408942
# Validation loss: 0.408845
#
# Epoch 50
# -------------------------------
# Training loss: 0.406767
# Validation loss: 0.407934
#
# Epoch 51
# -------------------------------
# Training loss: 0.405464
# Validation loss: 0.410995
#
# Epoch 52
# -------------------------------
# Training loss: 0.403727
# Validation loss: 0.401375
#
# Epoch 53
# -------------------------------
# Training loss: 0.403640
# Validation loss: 0.407975
#
# Epoch 54
# -------------------------------
# Training loss: 0.403698
# Validation loss: 0.398899
#
# Epoch 55
# -------------------------------
# Training loss: 0.401043
# Validation loss: 0.399557
#
# Epoch 56
# -------------------------------
# Training loss: 0.399714
# Validation loss: 0.403249
#
# Epoch 57
# -------------------------------
# Training loss: 0.397393
# Validation loss: 0.399208
#
# Epoch 58
# -------------------------------
# Training loss: 0.396602
# Validation loss: 0.395992
#
# Epoch 59
# -------------------------------
# Training loss: 0.398574
# Validation loss: 0.392452
#
# Epoch 60
# -------------------------------
# Training loss: 0.392948
# Validation loss: 0.393614
#
# Epoch 61
# -------------------------------
# Training loss: 0.394310
# Validation loss: 0.393096
#
# Epoch 62
# -------------------------------
# Training loss: 0.391464
# Validation loss: 0.387923
#
# Epoch 63
# -------------------------------
# Training loss: 0.390544
# Validation loss: 0.391741
#
# Epoch 64
# -------------------------------
# Training loss: 0.389345
# Validation loss: 0.392190
#
# Epoch 65
# -------------------------------
# Training loss: 0.388059
# Validation loss: 0.390789
#
# Epoch 66
# -------------------------------
# Training loss: 0.390328
# Validation loss: 0.388866
#
# Epoch 67
# -------------------------------
# Training loss: 0.387739
# Validation loss: 0.385220
#
# Epoch 68
# -------------------------------
# Training loss: 0.385758
# Validation loss: 0.383132
#
# Epoch 69
# -------------------------------
# Training loss: 0.384337
# Validation loss: 0.385815
#
# Epoch 70
# -------------------------------
# Training loss: 0.385124
# Validation loss: 0.388442
#
# Epoch 71
# -------------------------------
# Training loss: 0.384896
# Validation loss: 0.386595
#
# Epoch 72
# -------------------------------
# Training loss: 0.382456
# Validation loss: 0.385467
#
# Epoch 73
# -------------------------------
# Training loss: 0.381640
# Validation loss: 0.383227
#
# Epoch 74
# -------------------------------
# Training loss: 0.381490
# Validation loss: 0.383253
#
# Epoch 75
# -------------------------------
# Training loss: 0.378390
# Validation loss: 0.384010
#
# Epoch 76
# -------------------------------
# Training loss: 0.378976
# Validation loss: 0.379780
#
# Epoch 77
# -------------------------------
# Training loss: 0.377319
# Validation loss: 0.376637
#
# Epoch 78
# -------------------------------
# Training loss: 0.377111
# Validation loss: 0.378518
#
# Epoch 79
# -------------------------------
# Training loss: 0.376246
# Validation loss: 0.380575
#
# Epoch 80
# -------------------------------
# Training loss: 0.376847
# Validation loss: 0.375334
#
# Epoch 81
# -------------------------------
# Training loss: 0.377213
# Validation loss: 0.375335
#
# Epoch 82
# -------------------------------
# Training loss: 0.375084
# Validation loss: 0.376108
#
# Epoch 83
# -------------------------------
# Training loss: 0.372803
# Validation loss: 0.378056
#
# Epoch 84
# -------------------------------
# Training loss: 0.372730
# Validation loss: 0.377281
#
# Epoch 85
# -------------------------------
# Training loss: 0.372716
# Validation loss: 0.374218
#
# Epoch 86
# -------------------------------
# Training loss: 0.370706
# Validation loss: 0.374321
#
# Epoch 87
# -------------------------------
# Training loss: 0.370256
# Validation loss: 0.375811
#
# Epoch 88
# -------------------------------
# Training loss: 0.371068
# Validation loss: 0.370187
#
# Epoch 89
# -------------------------------
# Training loss: 0.370723
# Validation loss: 0.369963
#
# Epoch 90
# -------------------------------
# Training loss: 0.372445
# Validation loss: 0.367078
#
# Epoch 91
# -------------------------------
# Training loss: 0.368357
# Validation loss: 0.369060
#
# Epoch 92
# -------------------------------
# Training loss: 0.367649
# Validation loss: 0.370531
#
# Epoch 93
# -------------------------------
# Training loss: 0.366147
# Validation loss: 0.368275
#
# Epoch 94
# -------------------------------
# Training loss: 0.366633
# Validation loss: 0.368142
#
# Epoch 95
# -------------------------------
# Training loss: 0.366429
# Validation loss: 0.366472
#
# Epoch 96
# -------------------------------
# Training loss: 0.366069
# Validation loss: 0.368434
#
# Epoch 97
# -------------------------------
# Training loss: 0.365468
# Validation loss: 0.365075
#
# Epoch 98
# -------------------------------
# Training loss: 0.364292
# Validation loss: 0.365861
#
# Epoch 99
# -------------------------------
# Training loss: 0.362262
# Validation loss: 0.364946
#
# Epoch 100
# -------------------------------
# Training loss: 0.361839
# Validation loss: 0.369144
#
# Epoch 101
# -------------------------------
# Training loss: 0.360763
# Validation loss: 0.364985
#
# Epoch 102
# -------------------------------
# Training loss: 0.365194
# Validation loss: 0.368114
#
# Epoch 103
# -------------------------------
# Training loss: 0.361858
# Validation loss: 0.362462
#
# Epoch 104
# -------------------------------
# Training loss: 0.360907
# Validation loss: 0.361554
#
# Epoch 105
# -------------------------------
# Training loss: 0.359680
# Validation loss: 0.366697
#
# Epoch 106
# -------------------------------
# Training loss: 0.361950
# Validation loss: 0.360653
#
# Epoch 107
# -------------------------------
# Training loss: 0.358105
# Validation loss: 0.359810
#
# Epoch 108
# -------------------------------
# Training loss: 0.358280
# Validation loss: 0.356841
#
# Epoch 109
# -------------------------------
# Training loss: 0.357364
# Validation loss: 0.356023
#
# Epoch 110
# -------------------------------
# Training loss: 0.355533
# Validation loss: 0.357719
#
# Epoch 111
# -------------------------------
# Training loss: 0.355961
# Validation loss: 0.360915
#
# Epoch 112
# -------------------------------
# Training loss: 0.355450
# Validation loss: 0.359341
#
# Epoch 113
# -------------------------------
# Training loss: 0.354991
# Validation loss: 0.356532
#
# Epoch 114
# -------------------------------
# Training loss: 0.354258
# Validation loss: 0.358949
#
# Epoch 115
# -------------------------------
# Training loss: 0.354229
# Validation loss: 0.359171
#
# Epoch 116
# -------------------------------
# Training loss: 0.352728
# Validation loss: 0.356662
#
# Epoch 117
# -------------------------------
# Training loss: 0.352765
# Validation loss: 0.357008
#
# Epoch 118
# -------------------------------
# Training loss: 0.350825
# Validation loss: 0.358944
#
# Epoch 119
# -------------------------------
# Training loss: 0.351102
# Validation loss: 0.356740
#
# Epoch 120
# -------------------------------
# Training loss: 0.352042
# Validation loss: 0.355237
#
# Epoch 121
# -------------------------------
# Training loss: 0.349452
# Validation loss: 0.355171
#
# Epoch 122
# -------------------------------
# Training loss: 0.350386
# Validation loss: 0.352639
#
# Epoch 123
# -------------------------------
# Training loss: 0.347923
# Validation loss: 0.359451
#
# Epoch 124
# -------------------------------
# Training loss: 0.348166
# Validation loss: 0.353634
#
# Epoch 125
# -------------------------------
# Training loss: 0.347612
# Validation loss: 0.350625
#
# Epoch 126
# -------------------------------
# Training loss: 0.348978
# Validation loss: 0.355268
#
# Epoch 127
# -------------------------------
# Training loss: 0.348275
# Validation loss: 0.357229
#
# Epoch 128
# -------------------------------
# Training loss: 0.345436
# Validation loss: 0.355254
#
# Epoch 129
# -------------------------------
# Training loss: 0.346495
# Validation loss: 0.353768
#
# Epoch 130
# -------------------------------
# Training loss: 0.347373
# Validation loss: 0.351047
#
# Epoch 131
# -------------------------------
# Training loss: 0.345433
# Validation loss: 0.354981
#
# Epoch 132
# -------------------------------
# Training loss: 0.347124
# Validation loss: 0.355079
#
# Epoch 133
# -------------------------------
# Training loss: 0.344627
# Validation loss: 0.354458
#
# Epoch 134
# -------------------------------
# Training loss: 0.342771
# Validation loss: 0.352509
#
# Epoch 135
# -------------------------------
# Training loss: 0.342859
# Validation loss: 0.353618
#
# Epoch 136
# -------------------------------
# Training loss: 0.341016
# Validation loss: 0.348640
#
# Epoch 137
# -------------------------------
# Training loss: 0.341366
# Validation loss: 0.349901
#
# Epoch 138
# -------------------------------
# Training loss: 0.340851
# Validation loss: 0.352591
#
# Epoch 139
# -------------------------------
# Training loss: 0.341471
# Validation loss: 0.345487
#
# Epoch 140
# -------------------------------
# Training loss: 0.342867
# Validation loss: 0.350168
#
# Epoch 141
# -------------------------------
# Training loss: 0.341246
# Validation loss: 0.348790
#
# Epoch 142
# -------------------------------
# Training loss: 0.339304
# Validation loss: 0.352581
#
# Epoch 143
# -------------------------------
# Training loss: 0.338390
# Validation loss: 0.354317
#
# Epoch 144
# -------------------------------
# Training loss: 0.340744
# Validation loss: 0.345280
#
# Epoch 145
# -------------------------------
# Training loss: 0.337610
# Validation loss: 0.358538
#
# Epoch 146
# -------------------------------
# Training loss: 0.336810
# Validation loss: 0.345664
#
# Epoch 147
# -------------------------------
# Training loss: 0.336947
# Validation loss: 0.348946
#
# Epoch 148
# -------------------------------
# Training loss: 0.339530
# Validation loss: 0.346439
#
# Epoch 149
# -------------------------------
# Training loss: 0.336753
# Validation loss: 0.337794
#
# Epoch 150
# -------------------------------
# Training loss: 0.335666
# Validation loss: 0.339914
#
# Epoch 151
# -------------------------------
# Training loss: 0.335315
# Validation loss: 0.337426
#
# Epoch 152
# -------------------------------
# Training loss: 0.334080
# Validation loss: 0.339725
#
# Epoch 153
# -------------------------------
# Training loss: 0.332899
# Validation loss: 0.337441
#
# Epoch 154
# -------------------------------
# Training loss: 0.333177
# Validation loss: 0.336449
#
# Epoch 155
# -------------------------------
# Training loss: 0.332898
# Validation loss: 0.336108
#
# Epoch 156
# -------------------------------
# Training loss: 0.332344
# Validation loss: 0.333343
#
# Epoch 157
# -------------------------------
# Training loss: 0.332820
# Validation loss: 0.335287
#
# Epoch 158
# -------------------------------
# Training loss: 0.331848
# Validation loss: 0.344179
#
# Epoch 159
# -------------------------------
# Training loss: 0.332500
# Validation loss: 0.332785
#
# Epoch 160
# -------------------------------
# Training loss: 0.331603
# Validation loss: 0.334772
#
# Epoch 161
# -------------------------------
# Training loss: 0.330847
# Validation loss: 0.335958
#
# Epoch 162
# -------------------------------
# Training loss: 0.329774
# Validation loss: 0.332879
#
# Epoch 163
# -------------------------------
# Training loss: 0.330751
# Validation loss: 0.342208
#
# Epoch 164
# -------------------------------
# Training loss: 0.329963
# Validation loss: 0.332105
#
# Epoch 165
# -------------------------------
# Training loss: 0.328867
# Validation loss: 0.333591
#
# Epoch 166
# -------------------------------
# Training loss: 0.329461
# Validation loss: 0.336532
#
# Epoch 167
# -------------------------------
# Training loss: 0.329042
# Validation loss: 0.333620
#
# Epoch 168
# -------------------------------
# Training loss: 0.327770
# Validation loss: 0.330583
#
# Epoch 169
# -------------------------------
# Training loss: 0.327194
# Validation loss: 0.332977
#
# Epoch 170
# -------------------------------
# Training loss: 0.327334
# Validation loss: 0.333254
#
# Epoch 171
# -------------------------------
# Training loss: 0.327175
# Validation loss: 0.331097
#
# Epoch 172
# -------------------------------
# Training loss: 0.326550
# Validation loss: 0.332894
#
# Epoch 173
# -------------------------------
# Training loss: 0.327077
# Validation loss: 0.327936
#
# Epoch 174
# -------------------------------
# Training loss: 0.327427
# Validation loss: 0.333066
#
# Epoch 175
# -------------------------------
# Training loss: 0.324823
# Validation loss: 0.335818
#
# Epoch 176
# -------------------------------
# Training loss: 0.323704
# Validation loss: 0.328210
#
# Epoch 177
# -------------------------------
# Training loss: 0.325282
# Validation loss: 0.325709
#
# Epoch 178
# -------------------------------
# Training loss: 0.323830
# Validation loss: 0.323944
#
# Epoch 179
# -------------------------------
# Training loss: 0.322880
# Validation loss: 0.328127
#
# Epoch 180
# -------------------------------
# Training loss: 0.323020
# Validation loss: 0.328019
#
# Epoch 181
# -------------------------------
# Training loss: 0.322299
# Validation loss: 0.325314
#
# Epoch 182
# -------------------------------
# Training loss: 0.322791
# Validation loss: 0.324126
#
# Epoch 183
# -------------------------------
# Training loss: 0.320277
# Validation loss: 0.320025
#
# Epoch 184
# -------------------------------
# Training loss: 0.323693
# Validation loss: 0.326089
#
# Epoch 185
# -------------------------------
# Training loss: 0.320038
# Validation loss: 0.325272
#
# Epoch 186
# -------------------------------
# Training loss: 0.320102
# Validation loss: 0.317796
#
# Epoch 187
# -------------------------------
# Training loss: 0.319280
# Validation loss: 0.320401
#
# Epoch 188
# -------------------------------
# Training loss: 0.320027
# Validation loss: 0.323595
#
# Epoch 189
# -------------------------------
# Training loss: 0.319880
# Validation loss: 0.320743
#
# Epoch 190
# -------------------------------
# Training loss: 0.319969
# Validation loss: 0.321552
#
# Epoch 191
# -------------------------------
# Training loss: 0.320671
# Validation loss: 0.320988
#
# Epoch 192
# -------------------------------
# Training loss: 0.318831
# Validation loss: 0.321642
#
# Epoch 193
# -------------------------------
# Training loss: 0.319167
# Validation loss: 0.323138
#
# Epoch 194
# -------------------------------
# Training loss: 0.318786
# Validation loss: 0.320832
#
# Epoch 195
# -------------------------------
# Training loss: 0.316757
# Validation loss: 0.320764
#
# Epoch 196
# -------------------------------
# Training loss: 0.317795
# Validation loss: 0.325867
#
# Epoch 197
# -------------------------------
# Training loss: 0.316375
# Validation loss: 0.329728
#
# Epoch 198
# -------------------------------
# Training loss: 0.316808
# Validation loss: 0.319775
#
# Epoch 199
# -------------------------------
# Training loss: 0.314855
# Validation loss: 0.323143
#
# Epoch 200
# -------------------------------
# Training loss: 0.316608
# Validation loss: 0.317210
#
# Epoch 201
# -------------------------------
# Training loss: 0.315993
# Validation loss: 0.325088
#
# Epoch 202
# -------------------------------
# Training loss: 0.315800
# Validation loss: 0.322676
#
# Epoch 203
# -------------------------------
# Training loss: 0.314454
# Validation loss: 0.322892
#
# Epoch 204
# -------------------------------
# Training loss: 0.314759
# Validation loss: 0.317898
#
# Epoch 205
# -------------------------------
# Training loss: 0.314057
# Validation loss: 0.318816
#
# Epoch 206
# -------------------------------
# Training loss: 0.313043
# Validation loss: 0.319012
#
# Epoch 207
# -------------------------------
# Training loss: 0.311180
# Validation loss: 0.313300
#
# Epoch 208
# -------------------------------
# Training loss: 0.312053
# Validation loss: 0.309572
#
# Epoch 209
# -------------------------------
# Training loss: 0.314604
# Validation loss: 0.310456
#
# Epoch 210
# -------------------------------
# Training loss: 0.311945
# Validation loss: 0.314940
#
# Epoch 211
# -------------------------------
# Training loss: 0.314168
# Validation loss: 0.317152
#
# Epoch 212
# -------------------------------
# Training loss: 0.310744
# Validation loss: 0.310006
#
# Epoch 213
# -------------------------------
# Training loss: 0.311333
# Validation loss: 0.334872
#
# Epoch 214
# -------------------------------
# Training loss: 0.311135
# Validation loss: 0.320350
#
# Epoch 215
# -------------------------------
# Training loss: 0.311306
# Validation loss: 0.307074
#
# Epoch 216
# -------------------------------
# Training loss: 0.308424
# Validation loss: 0.307412
#
# Epoch 217
# -------------------------------
# Training loss: 0.306973
# Validation loss: 0.314878
#
# Epoch 218
# -------------------------------
# Training loss: 0.308695
# Validation loss: 0.325693
#
# Epoch 219
# -------------------------------
# Training loss: 0.308619
# Validation loss: 0.318471
#
# Epoch 220
# -------------------------------
# Training loss: 0.307864
# Validation loss: 0.309287
#
# Epoch 221
# -------------------------------
# Training loss: 0.310208
# Validation loss: 0.314946
#
# Epoch 222
# -------------------------------
# Training loss: 0.308425
# Validation loss: 0.317772
#
# Epoch 223
# -------------------------------
# Training loss: 0.307436
# Validation loss: 0.308900
#
# Epoch 224
# -------------------------------
# Training loss: 0.306915
# Validation loss: 0.306642
#
# Epoch 225
# -------------------------------
# Training loss: 0.305138
# Validation loss: 0.317677
#
# Epoch 226
# -------------------------------
# Training loss: 0.303936
# Validation loss: 0.311600
#
# Epoch 227
# -------------------------------
# Training loss: 0.304446
# Validation loss: 0.309043
#
# Epoch 228
# -------------------------------
# Training loss: 0.303896
# Validation loss: 0.301738
#
# Epoch 229
# -------------------------------
# Training loss: 0.302049
# Validation loss: 0.304241
#
# Epoch 230
# -------------------------------
# Training loss: 0.302601
# Validation loss: 0.304751
#
# Epoch 231
# -------------------------------
# Training loss: 0.302897
# Validation loss: 0.305184
#
# Epoch 232
# -------------------------------
# Training loss: 0.302019
# Validation loss: 0.296327
#
# Epoch 233
# -------------------------------
# Training loss: 0.303883
# Validation loss: 0.317580
#
# Epoch 234
# -------------------------------
# Training loss: 0.300524
# Validation loss: 0.299827
#
# Epoch 235
# -------------------------------
# Training loss: 0.303063
# Validation loss: 0.306144
#
# Epoch 236
# -------------------------------
# Training loss: 0.304999
# Validation loss: 0.307300
#
# Epoch 237
# -------------------------------
# Training loss: 0.301221
# Validation loss: 0.297053
#
# Epoch 238
# -------------------------------
# Training loss: 0.298227
# Validation loss: 0.300583
#
# Epoch 239
# -------------------------------
# Training loss: 0.299019
# Validation loss: 0.296415
#
# Epoch 240
# -------------------------------
# Training loss: 0.298424
# Validation loss: 0.299747
#
# Epoch 241
# -------------------------------
# Training loss: 0.297015
# Validation loss: 0.297495
#
# Epoch 242
# -------------------------------
# Training loss: 0.296123
# Validation loss: 0.305132
#
# Epoch 243
# -------------------------------
# Training loss: 0.298610
# Validation loss: 0.301223
#
# Epoch 244
# -------------------------------
# Training loss: 0.295953
# Validation loss: 0.310107
#
# Epoch 245
# -------------------------------
# Training loss: 0.296100
# Validation loss: 0.313606
#
# Epoch 246
# -------------------------------
# Training loss: 0.295005
# Validation loss: 0.300909
#
# Epoch 247
# -------------------------------
# Training loss: 0.296836
# Validation loss: 0.298547
#
# Epoch 248
# -------------------------------
# Training loss: 0.299181
# Validation loss: 0.295884
#
# Epoch 249
# -------------------------------
# Training loss: 0.297169
# Validation loss: 0.294889
#
# Epoch 250
# -------------------------------
# Training loss: 0.293520
# Validation loss: 0.301728
#
# Epoch 251
# -------------------------------
# Training loss: 0.291682
# Validation loss: 0.295533
#
# Epoch 252
# -------------------------------
# Training loss: 0.291005
# Validation loss: 0.288454
#
# Epoch 253
# -------------------------------
# Training loss: 0.293559
# Validation loss: 0.301734
#
# Epoch 254
# -------------------------------
# Training loss: 0.294334
# Validation loss: 0.293405
#
# Epoch 255
# -------------------------------
# Training loss: 0.290798
# Validation loss: 0.303455
#
# Epoch 256
# -------------------------------
# Training loss: 0.289540
# Validation loss: 0.304363
#
# Epoch 257
# -------------------------------
# Training loss: 0.293876
# Validation loss: 0.295455
#
# Epoch 258
# -------------------------------
# Training loss: 0.291330
# Validation loss: 0.302225
#
# Epoch 259
# -------------------------------
# Training loss: 0.287550
# Validation loss: 0.315477
#
# Epoch 260
# -------------------------------
# Training loss: 0.288209
# Validation loss: 0.290001
#
# Epoch 261
# -------------------------------
# Training loss: 0.286151
# Validation loss: 0.281811
#
# Epoch 262
# -------------------------------
# Training loss: 0.288137
# Validation loss: 0.294883
#
# Epoch 263
# -------------------------------
# Training loss: 0.284071
# Validation loss: 0.283986
#
# Epoch 264
# -------------------------------
# Training loss: 0.288679
# Validation loss: 0.284757
#
# Epoch 265
# -------------------------------
# Training loss: 0.288017
# Validation loss: 0.286867
#
# Epoch 266
# -------------------------------
# Training loss: 0.285183
# Validation loss: 0.293732
#
# Epoch 267
# -------------------------------
# Training loss: 0.288366
# Validation loss: 0.290700
#
# Epoch 268
# -------------------------------
# Training loss: 0.282977
# Validation loss: 0.288387
#
# Epoch 269
# -------------------------------
# Training loss: 0.283711
# Validation loss: 0.298000
#
# Epoch 270
# -------------------------------
# Training loss: 0.281013
# Validation loss: 0.281339
#
# Epoch 271
# -------------------------------
# Training loss: 0.280681
# Validation loss: 0.282637
#
# Epoch 272
# -------------------------------
# Training loss: 0.282410
# Validation loss: 0.291528
#
# Epoch 273
# -------------------------------
# Training loss: 0.281590
# Validation loss: 0.290886
#
# Epoch 274
# -------------------------------
# Training loss: 0.280450
# Validation loss: 0.297019
#
# Epoch 275
# -------------------------------
# Training loss: 0.278430
# Validation loss: 0.278892
#
# Epoch 276
# -------------------------------
# Training loss: 0.277070
# Validation loss: 0.278399
#
# Epoch 277
# -------------------------------
# Training loss: 0.278785
# Validation loss: 0.283707
#
# Epoch 278
# -------------------------------
# Training loss: 0.278121
# Validation loss: 0.272507
#
# Epoch 279
# -------------------------------
# Training loss: 0.277128
# Validation loss: 0.285722
#
# Epoch 280
# -------------------------------
# Training loss: 0.274744
# Validation loss: 0.274115
#
# Epoch 281
# -------------------------------
# Training loss: 0.273573
# Validation loss: 0.271904
#
# Epoch 282
# -------------------------------
# Training loss: 0.279820
# Validation loss: 0.273216
#
# Epoch 283
# -------------------------------
# Training loss: 0.276736
# Validation loss: 0.308884
#
# Epoch 284
# -------------------------------
# Training loss: 0.277125
# Validation loss: 0.295315
#
# Epoch 285
# -------------------------------
# Training loss: 0.271641
# Validation loss: 0.281126
#
# Epoch 286
# -------------------------------
# Training loss: 0.270764
# Validation loss: 0.278799
#
# Epoch 287
# -------------------------------
# Training loss: 0.274293
# Validation loss: 0.267381
#
# Epoch 288
# -------------------------------
# Training loss: 0.276489
# Validation loss: 0.281760
#
# Epoch 289
# -------------------------------
# Training loss: 0.274187
# Validation loss: 0.272683
#
# Epoch 290
# -------------------------------
# Training loss: 0.269510
# Validation loss: 0.282799
#
# Epoch 291
# -------------------------------
# Training loss: 0.267733
# Validation loss: 0.271385
#
# Epoch 292
# -------------------------------
# Training loss: 0.266049
# Validation loss: 0.265350
#
# Epoch 293
# -------------------------------
# Training loss: 0.268070
# Validation loss: 0.264603
#
# Epoch 294
# -------------------------------
# Training loss: 0.264828
# Validation loss: 0.264290
#
# Epoch 295
# -------------------------------
# Training loss: 0.270072
# Validation loss: 0.282462
#
# Epoch 296
# -------------------------------
# Training loss: 0.270309
# Validation loss: 0.260595
#
# Epoch 297
# -------------------------------
# Training loss: 0.265163
# Validation loss: 0.269402
#
# Epoch 298
# -------------------------------
# Training loss: 0.265569
# Validation loss: 0.274668
#
# Epoch 299
# -------------------------------
# Training loss: 0.269438
# Validation loss: 0.265972
#
# Epoch 300
# -------------------------------
# Training loss: 0.263859
# Validation loss: 0.401411
#
# Epoch 301
# -------------------------------
# Training loss: 0.262326
# Validation loss: 0.337595
#
# Epoch 302
# -------------------------------
# Training loss: 0.262910
# Validation loss: 0.287828
#
# Epoch 303
# -------------------------------
# Training loss: 0.263479
# Validation loss: 0.255682
#
# Epoch 304
# -------------------------------
# Training loss: 0.262363
# Validation loss: 0.277237
#
# Epoch 305
# -------------------------------
# Training loss: 0.263845
# Validation loss: 0.258456
#
# Epoch 306
# -------------------------------
# Training loss: 0.270582
# Validation loss: 0.254649
#
# Epoch 307
# -------------------------------
# Training loss: 0.264026
# Validation loss: 0.263399
#
# Epoch 308
# -------------------------------
# Training loss: 0.262201
# Validation loss: 0.263828
#
# Epoch 309
# -------------------------------
# Training loss: 0.259381
# Validation loss: 0.253752
#
# Epoch 310
# -------------------------------
# Training loss: 0.259432
# Validation loss: 0.273657
#
# Epoch 311
# -------------------------------
# Training loss: 0.257570
# Validation loss: 0.258458
#
# Epoch 312
# -------------------------------
# Training loss: 0.262579
# Validation loss: 0.258829
#
# Epoch 313
# -------------------------------
# Training loss: 0.255798
# Validation loss: 0.258169
#
# Epoch 314
# -------------------------------
# Training loss: 0.254532
# Validation loss: 0.255067
#
# Epoch 315
# -------------------------------
# Training loss: 0.252812
# Validation loss: 0.265816
#
# Epoch 316
# -------------------------------
# Training loss: 0.251600
# Validation loss: 0.253596
#
# Epoch 317
# -------------------------------
# Training loss: 0.252342
# Validation loss: 0.259086
#
# Epoch 318
# -------------------------------
# Training loss: 0.252500
# Validation loss: 0.246637
#
# Epoch 319
# -------------------------------
# Training loss: 0.252744
# Validation loss: 0.255908
#
# Epoch 320
# -------------------------------
# Training loss: 0.250318
# Validation loss: 0.260289
#
# Epoch 321
# -------------------------------
# Training loss: 0.254655
# Validation loss: 0.298215
#
# Epoch 322
# -------------------------------
# Training loss: 0.257074
# Validation loss: 0.255792
#
# Epoch 323
# -------------------------------
# Training loss: 0.249872
# Validation loss: 0.252547
#
# Epoch 324
# -------------------------------
# Training loss: 0.252363
# Validation loss: 0.249433
#
# Epoch 325
# -------------------------------
# Training loss: 0.250364
# Validation loss: 0.249447
#
# Epoch 326
# -------------------------------
# Training loss: 0.249565
# Validation loss: 0.246837
#
# Epoch 327
# -------------------------------
# Training loss: 0.246547
# Validation loss: 0.251230
#
# Epoch 328
# -------------------------------
# Training loss: 0.249802
# Validation loss: 0.243008
#
# Epoch 329
# -------------------------------
# Training loss: 0.244902
# Validation loss: 0.247950
#
# Epoch 330
# -------------------------------
# Training loss: 0.249865
# Validation loss: 0.246174
#
# Epoch 331
# -------------------------------
# Training loss: 0.249764
# Validation loss: 0.253498
#
# Epoch 332
# -------------------------------
# Training loss: 0.247124
# Validation loss: 0.243095
#
# Epoch 333
# -------------------------------
# Training loss: 0.253239
# Validation loss: 0.238252
#
# Epoch 334
# -------------------------------
# Training loss: 0.245016
# Validation loss: 0.240909
#
# Epoch 335
# -------------------------------
# Training loss: 0.245277
# Validation loss: 0.243439
#
# Epoch 336
# -------------------------------
# Training loss: 0.244801
# Validation loss: 0.246217
#
# Epoch 337
# -------------------------------
# Training loss: 0.243001
# Validation loss: 0.244811
#
# Epoch 338
# -------------------------------
# Training loss: 0.247034
# Validation loss: 0.241449
#
# Epoch 339
# -------------------------------
# Training loss: 0.244654
# Validation loss: 0.242588
#
# Epoch 340
# -------------------------------
# Training loss: 0.243673
# Validation loss: 0.240545
#
# Epoch 341
# -------------------------------
# Training loss: 0.243753
# Validation loss: 0.237744
#
# Epoch 342
# -------------------------------
# Training loss: 0.241110
# Validation loss: 0.250112
#
# Epoch 343
# -------------------------------
# Training loss: 0.246658
# Validation loss: 0.260971
#
# Epoch 344
# -------------------------------
# Training loss: 0.248905
# Validation loss: 0.236197
#
# Epoch 345
# -------------------------------
# Training loss: 0.240374
# Validation loss: 0.245185
#
# Epoch 346
# -------------------------------
# Training loss: 0.242905
# Validation loss: 0.248268
#
# Epoch 347
# -------------------------------
# Training loss: 0.241684
# Validation loss: 0.259038
#
# Epoch 348
# -------------------------------
# Training loss: 0.241815
# Validation loss: 0.278382
#
# Epoch 349
# -------------------------------
# Training loss: 0.238761
# Validation loss: 0.249499
#
# Epoch 350
# -------------------------------
# Training loss: 0.239687
# Validation loss: 0.263211
#
# Epoch 351
# -------------------------------
# Training loss: 0.241743
# Validation loss: 0.240310
#
# Epoch 352
# -------------------------------
# Training loss: 0.242890
# Validation loss: 0.289108
#
# Epoch 353
# -------------------------------
# Training loss: 0.237951
# Validation loss: 0.250885
#
# Epoch 354
# -------------------------------
# Training loss: 0.239770
# Validation loss: 0.249081
#
# Epoch 355
# -------------------------------
# Training loss: 0.244023
# Validation loss: 0.239427
#
# Epoch 356
# -------------------------------
# Training loss: 0.234902
# Validation loss: 0.243074
#
# Epoch 357
# -------------------------------
# Training loss: 0.233635
# Validation loss: 0.235681
#
# Epoch 358
# -------------------------------
# Training loss: 0.236666
# Validation loss: 0.233252
#
# Epoch 359
# -------------------------------
# Training loss: 0.240074
# Validation loss: 0.234052
#
# Epoch 360
# -------------------------------
# Training loss: 0.237922
# Validation loss: 0.237686
#
# Epoch 361
# -------------------------------
# Training loss: 0.232805
# Validation loss: 0.232222
#
# Epoch 362
# -------------------------------
# Training loss: 0.235568
# Validation loss: 0.233762
#
# Epoch 363
# -------------------------------
# Training loss: 0.236644
# Validation loss: 0.235115
#
# Epoch 364
# -------------------------------
# Training loss: 0.241996
# Validation loss: 0.227527
#
# Epoch 365
# -------------------------------
# Training loss: 0.237193
# Validation loss: 0.231101
#
# Epoch 366
# -------------------------------
# Training loss: 0.231712
# Validation loss: 0.233258
#
# Epoch 367
# -------------------------------
# Training loss: 0.228353
# Validation loss: 0.234720
#
# Epoch 368
# -------------------------------
# Training loss: 0.232546
# Validation loss: 0.223292
#
# Epoch 369
# -------------------------------
# Training loss: 0.233731
# Validation loss: 0.225319
#
# Epoch 370
# -------------------------------
# Training loss: 0.238168
# Validation loss: 0.228111
#
# Epoch 371
# -------------------------------
# Training loss: 0.239088
# Validation loss: 0.228044
#
# Epoch 372
# -------------------------------
# Training loss: 0.236395
# Validation loss: 0.233863
#
# Epoch 373
# -------------------------------
# Training loss: 0.231156
# Validation loss: 0.229165
#
# Epoch 374
# -------------------------------
# Training loss: 0.229302
# Validation loss: 0.234394
#
# Epoch 375
# -------------------------------
# Training loss: 0.231716
# Validation loss: 0.217757
#
# Epoch 376
# -------------------------------
# Training loss: 0.228672
# Validation loss: 0.233403
#
# Epoch 377
# -------------------------------
# Training loss: 0.228965
# Validation loss: 0.227274
#
# Epoch 378
# -------------------------------
# Training loss: 0.226725
# Validation loss: 0.228513
#
# Epoch 379
# -------------------------------
# Training loss: 0.223444
# Validation loss: 0.239360
#
# Epoch 380
# -------------------------------
# Training loss: 0.225486
# Validation loss: 0.232845
#
# Epoch 381
# -------------------------------
# Training loss: 0.227289
# Validation loss: 0.220013
#
# Epoch 382
# -------------------------------
# Training loss: 0.225313
# Validation loss: 0.224678
#
# Epoch 383
# -------------------------------
# Training loss: 0.230614
# Validation loss: 0.220704
#
# Epoch 384
# -------------------------------
# Training loss: 0.226620
# Validation loss: 0.220587
#
# Epoch 385
# -------------------------------
# Training loss: 0.223410
# Validation loss: 0.220835
#
# Epoch 386
# -------------------------------
# Training loss: 0.225637
# Validation loss: 0.227543
#
# Epoch 387
# -------------------------------
# Training loss: 0.224778
# Validation loss: 0.222729
#
# Epoch 388
# -------------------------------
# Training loss: 0.222887
# Validation loss: 0.221368
#
# Epoch 389
# -------------------------------
# Training loss: 0.222547
# Validation loss: 0.220314
#
# Epoch 390
# -------------------------------
# Training loss: 0.224397
# Validation loss: 0.221215
#
# Epoch 391
# -------------------------------
# Training loss: 0.223365
# Validation loss: 0.225882
#
# Epoch 392
# -------------------------------
# Training loss: 0.221684
# Validation loss: 0.224943
#
# Epoch 393
# -------------------------------
# Training loss: 0.221272
# Validation loss: 0.217689
#
# Epoch 394
# -------------------------------
# Training loss: 0.222462
# Validation loss: 0.220041
#
# Epoch 395
# -------------------------------
# Training loss: 0.220177
# Validation loss: 0.219352
#
# Epoch 396
# -------------------------------
# Training loss: 0.217700
# Validation loss: 0.220717
#
# Epoch 397
# -------------------------------
# Training loss: 0.218545
# Validation loss: 0.230491
#
# Epoch 398
# -------------------------------
# Training loss: 0.220644
# Validation loss: 0.222198
#
# Epoch 399
# -------------------------------
# Training loss: 0.218265
# Validation loss: 0.220085
#
# Epoch 400
# -------------------------------
# Training loss: 0.216430
# Validation loss: 0.227035
#
# Epoch 401
# -------------------------------
# Training loss: 0.218075
# Validation loss: 0.220733
#
# Epoch 402
# -------------------------------
# Training loss: 0.219222
# Validation loss: 0.217810
#
# Epoch 403
# -------------------------------
# Training loss: 0.214595
# Validation loss: 0.210147
#
# Epoch 404
# -------------------------------
# Training loss: 0.218507
# Validation loss: 0.210054
#
# Epoch 405
# -------------------------------
# Training loss: 0.222898
# Validation loss: 0.223495
#
# Epoch 406
# -------------------------------
# Training loss: 0.226178
# Validation loss: 0.220276
#
# Epoch 407
# -------------------------------
# Training loss: 0.214822
# Validation loss: 0.230715
#
# Epoch 408
# -------------------------------
# Training loss: 0.213295
# Validation loss: 0.214439
#
# Epoch 409
# -------------------------------
# Training loss: 0.217440
# Validation loss: 0.206848
#
# Epoch 410
# -------------------------------
# Training loss: 0.210608
# Validation loss: 0.208564
#
# Epoch 411
# -------------------------------
# Training loss: 0.214559
# Validation loss: 0.209467
#
# Epoch 412
# -------------------------------
# Training loss: 0.212098
# Validation loss: 0.220884
#
# Epoch 413
# -------------------------------
# Training loss: 0.213431
# Validation loss: 0.212129
#
# Epoch 414
# -------------------------------
# Training loss: 0.214733
# Validation loss: 0.206627
#
# Epoch 415
# -------------------------------
# Training loss: 0.209135
# Validation loss: 0.226548
#
# Epoch 416
# -------------------------------
# Training loss: 0.213664
# Validation loss: 0.208714
#
# Epoch 417
# -------------------------------
# Training loss: 0.213178
# Validation loss: 0.208109
#
# Epoch 418
# -------------------------------
# Training loss: 0.214670
# Validation loss: 0.217609
#
# Epoch 419
# -------------------------------
# Training loss: 0.208821
# Validation loss: 0.204718
#
# Epoch 420
# -------------------------------
# Training loss: 0.214909
# Validation loss: 0.215354
#
# Epoch 421
# -------------------------------
# Training loss: 0.209237
# Validation loss: 0.219791
#
# Epoch 422
# -------------------------------
# Training loss: 0.210501
# Validation loss: 0.208743
#
# Epoch 423
# -------------------------------
# Training loss: 0.211321
# Validation loss: 0.203218
#
# Epoch 424
# -------------------------------
# Training loss: 0.208776
# Validation loss: 0.204933
#
# Epoch 425
# -------------------------------
# Training loss: 0.208514
# Validation loss: 0.203933
#
# Epoch 426
# -------------------------------
# Training loss: 0.209738
# Validation loss: 0.206034
#
# Epoch 427
# -------------------------------
# Training loss: 0.206701
# Validation loss: 0.217928
#
# Epoch 428
# -------------------------------
# Training loss: 0.206888
# Validation loss: 0.211271
#
# Epoch 429
# -------------------------------
# Training loss: 0.207773
# Validation loss: 0.213944
#
# Epoch 430
# -------------------------------
# Training loss: 0.210922
# Validation loss: 0.210737
#
# Epoch 431
# -------------------------------
# Training loss: 0.209945
# Validation loss: 0.206499
#
# Epoch 432
# -------------------------------
# Training loss: 0.210119
# Validation loss: 0.204736
#
# Epoch 433
# -------------------------------
# Training loss: 0.212323
# Validation loss: 0.202323
#
# Epoch 434
# -------------------------------
# Training loss: 0.215134
# Validation loss: 0.204407
#
# Epoch 435
# -------------------------------
# Training loss: 0.203319
# Validation loss: 0.202602
#
# Epoch 436
# -------------------------------
# Training loss: 0.204580
# Validation loss: 0.211896
#
# Epoch 437
# -------------------------------
# Training loss: 0.204089
# Validation loss: 0.207597
#
# Epoch 438
# -------------------------------
# Training loss: 0.206999
# Validation loss: 0.213677
#
# Epoch 439
# -------------------------------
# Training loss: 0.204222
# Validation loss: 0.217915
#
# Epoch 440
# -------------------------------
# Training loss: 0.209396
# Validation loss: 0.209076
#
# Epoch 441
# -------------------------------
# Training loss: 0.211696
# Validation loss: 0.197358
#
# Epoch 442
# -------------------------------
# Training loss: 0.201619
# Validation loss: 0.199739
#
# Epoch 443
# -------------------------------
# Training loss: 0.201229
# Validation loss: 0.203838
#
# Epoch 444
# -------------------------------
# Training loss: 0.200803
# Validation loss: 0.206977
#
# Epoch 445
# -------------------------------
# Training loss: 0.199612
# Validation loss: 0.195048
#
# Epoch 446
# -------------------------------
# Training loss: 0.204825
# Validation loss: 0.195546
#
# Epoch 447
# -------------------------------
# Training loss: 0.196932
# Validation loss: 0.199073
#
# Epoch 448
# -------------------------------
# Training loss: 0.202594
# Validation loss: 0.199260
#
# Epoch 449
# -------------------------------
# Training loss: 0.203733
# Validation loss: 0.200537
#
# Epoch 450
# -------------------------------
# Training loss: 0.198018
# Validation loss: 0.204906
#
# Epoch 451
# -------------------------------
# Training loss: 0.198198
# Validation loss: 0.193459
#
# Epoch 452
# -------------------------------
# Training loss: 0.193744
# Validation loss: 0.199012
#
# Epoch 453
# -------------------------------
# Training loss: 0.199442
# Validation loss: 0.202455
#
# Epoch 454
# -------------------------------
# Training loss: 0.199175
# Validation loss: 0.197780
#
# Epoch 455
# -------------------------------
# Training loss: 0.196360
# Validation loss: 0.203857
#
# Epoch 456
# -------------------------------
# Training loss: 0.201247
# Validation loss: 0.195939
#
# Epoch 457
# -------------------------------
# Training loss: 0.195789
# Validation loss: 0.189337
#
# Epoch 458
# -------------------------------
# Training loss: 0.196710
# Validation loss: 0.203612
#
# Epoch 459
# -------------------------------
# Training loss: 0.194821
# Validation loss: 0.196002
#
# Epoch 460
# -------------------------------
# Training loss: 0.195612
# Validation loss: 0.199622
#
# Epoch 461
# -------------------------------
# Training loss: 0.193632
# Validation loss: 0.191546
#
# Epoch 462
# -------------------------------
# Training loss: 0.195472
# Validation loss: 0.191306
#
# Epoch 463
# -------------------------------
# Training loss: 0.194187
# Validation loss: 0.196933
#
# Epoch 464
# -------------------------------
# Training loss: 0.191518
# Validation loss: 0.191608
#
# Epoch 465
# -------------------------------
# Training loss: 0.193581
# Validation loss: 0.185946
#
# Epoch 466
# -------------------------------
# Training loss: 0.197583
# Validation loss: 0.193937
#
# Epoch 467
# -------------------------------
# Training loss: 0.196577
# Validation loss: 0.189104
#
# Epoch 468
# -------------------------------
# Training loss: 0.195204
# Validation loss: 0.193496
#
# Epoch 469
# -------------------------------
# Training loss: 0.190517
# Validation loss: 0.186230
#
# Epoch 470
# -------------------------------
# Training loss: 0.195258
# Validation loss: 0.188245
#
# Epoch 471
# -------------------------------
# Training loss: 0.193595
# Validation loss: 0.196735
#
# Epoch 472
# -------------------------------
# Training loss: 0.191098
# Validation loss: 0.193210
#
# Epoch 473
# -------------------------------
# Training loss: 0.190987
# Validation loss: 0.194333
#
# Epoch 474
# -------------------------------
# Training loss: 0.190085
# Validation loss: 0.198867
#
# Epoch 475
# -------------------------------
# Training loss: 0.192331
# Validation loss: 0.193540
#
# Epoch 476
# -------------------------------
# Training loss: 0.191195
# Validation loss: 0.192011
#
# Epoch 477
# -------------------------------
# Training loss: 0.192628
# Validation loss: 0.198318
#
# Epoch 478
# -------------------------------
# Training loss: 0.188431
# Validation loss: 0.184677
#
# Epoch 479
# -------------------------------
# Training loss: 0.193887
# Validation loss: 0.188505
#
# Epoch 480
# -------------------------------
# Training loss: 0.190759
# Validation loss: 0.196407
#
# Epoch 481
# -------------------------------
# Training loss: 0.188354
# Validation loss: 0.183107
#
# Epoch 482
# -------------------------------
# Training loss: 0.192193
# Validation loss: 0.193126
#
# Epoch 483
# -------------------------------
# Training loss: 0.184806
# Validation loss: 0.185656
#
# Epoch 484
# -------------------------------
# Training loss: 0.184706
# Validation loss: 0.182152
#
# Epoch 485
# -------------------------------
# Training loss: 0.185688
# Validation loss: 0.187723
#
# Epoch 486
# -------------------------------
# Training loss: 0.184067
# Validation loss: 0.194594
#
# Epoch 487
# -------------------------------
# Training loss: 0.185124
# Validation loss: 0.185769
#
# Epoch 488
# -------------------------------
# Training loss: 0.189359
# Validation loss: 0.186648
#
# Epoch 489
# -------------------------------
# Training loss: 0.185321
# Validation loss: 0.185414
#
# Epoch 490
# -------------------------------
# Training loss: 0.188217
# Validation loss: 0.186008
#
# Epoch 491
# -------------------------------
# Training loss: 0.190049
# Validation loss: 0.201452
#
# Epoch 492
# -------------------------------
# Training loss: 0.185684
# Validation loss: 0.181367
#
# Epoch 493
# -------------------------------
# Training loss: 0.183501
# Validation loss: 0.194676
#
# Epoch 494
# -------------------------------
# Training loss: 0.191520
# Validation loss: 0.203369
#
# Epoch 495
# -------------------------------
# Training loss: 0.184632
# Validation loss: 0.185356
#
# Epoch 496
# -------------------------------
# Training loss: 0.184006
# Validation loss: 0.193321
#
# Epoch 497
# -------------------------------
# Training loss: 0.186723
# Validation loss: 0.194063
#
# Epoch 498
# -------------------------------
# Training loss: 0.185144
# Validation loss: 0.181134
#
# Epoch 499
# -------------------------------
# Training loss: 0.185928
# Validation loss: 0.182931
#
# Epoch 500
# -------------------------------
# Training loss: 0.183502
# Validation loss: 0.189344
#
# Epoch 501
# -------------------------------
# Training loss: 0.182500
# Validation loss: 0.182189
#
# Epoch 502
# -------------------------------
# Training loss: 0.186438
# Validation loss: 0.181214
#
# Epoch 503
# -------------------------------
# Training loss: 0.178668
# Validation loss: 0.175528
#
# Epoch 504
# -------------------------------
# Training loss: 0.178977
# Validation loss: 0.173082
#
# Epoch 505
# -------------------------------
# Training loss: 0.179536
# Validation loss: 0.177124
#
# Epoch 506
# -------------------------------
# Training loss: 0.179883
# Validation loss: 0.182228
#
# Epoch 507
# -------------------------------
# Training loss: 0.178348
# Validation loss: 0.175639
#
# Epoch 508
# -------------------------------
# Training loss: 0.179754
# Validation loss: 0.183527
#
# Epoch 509
# -------------------------------
# Training loss: 0.179985
# Validation loss: 0.194089
#
# Epoch 510
# -------------------------------
# Training loss: 0.180216
# Validation loss: 0.190318
#
# Epoch 511
# -------------------------------
# Training loss: 0.181536
# Validation loss: 0.174814
#
# Epoch 512
# -------------------------------
# Training loss: 0.175192
# ...
# Validation loss: 0.041864
#
# Epoch 2333
# -------------------------------
# Training loss: 0.041237
# Validation loss: 0.041684
#
# Epoch 2334
# -------------------------------
# Training loss: 0.042517
# Validation loss: 0.044567
#
# Epoch 2335
# -------------------------------
# Training loss: 0.041181
# Validation loss: 0.042253
#
# Epoch 2336
# -------------------------------
# Training loss: 0.042063
# Validation loss: 0.040932
#
# Epoch 2337
# -------------------------------
# Training loss: 0.041071
# Validation loss: 0.040869
#
# Epoch 2338
# -------------------------------
# Training loss: 0.040714
# Validation loss: 0.040963
#
# Epoch 2339
# -------------------------------
# Training loss: 0.041321
# Validation loss: 0.042727
#
# Epoch 2340
# -------------------------------
# Training loss: 0.041627
# Validation loss: 0.042600
#
# Epoch 2341
# -------------------------------
# Training loss: 0.042182
# Validation loss: 0.042421
#
# Epoch 2342
# -------------------------------
# Training loss: 0.041453
# Validation loss: 0.040393
#
# Epoch 2343
# -------------------------------
# Training loss: 0.042692
# Validation loss: 0.042205
#
# Epoch 2344
# -------------------------------
# Training loss: 0.042717
# Validation loss: 0.041504
#
# Epoch 2345
# -------------------------------
# Training loss: 0.041918
# Validation loss: 0.042677
#
# Epoch 2346
# -------------------------------
# Training loss: 0.042022
# Validation loss: 0.042297
#
# Epoch 2347
# -------------------------------
# Training loss: 0.041904
# Validation loss: 0.041844
#
# Epoch 2348
# -------------------------------
# Training loss: 0.050180
# Validation loss: 0.043658
#
# Epoch 2349
# -------------------------------
# Training loss: 0.043101
# Validation loss: 0.043168
#
# Epoch 2350
# -------------------------------
# Training loss: 0.042109
# Validation loss: 0.042253
#
# Epoch 2351
# -------------------------------
# Training loss: 0.041816
# Validation loss: 0.043939
#
# Epoch 2352
# -------------------------------
# Training loss: 0.044324
# Validation loss: 0.041510
#
# Epoch 2353
# -------------------------------
# Training loss: 0.040947
# Validation loss: 0.042710
#
# Epoch 2354
# -------------------------------
# Training loss: 0.040481
# Validation loss: 0.041612
#
# Epoch 2355
# -------------------------------
# Training loss: 0.041461
# Validation loss: 0.043135
#
# Epoch 2356
# -------------------------------
# Training loss: 0.041567
# Validation loss: 0.042075
#
# Epoch 2357
# -------------------------------
# Training loss: 0.040443
# Validation loss: 0.042336
#
# Epoch 2358
# -------------------------------
# Training loss: 0.043493
# Validation loss: 0.044046
#
# Epoch 2359
# -------------------------------
# Training loss: 0.043523
# Validation loss: 0.042126
#
# Epoch 2360
# -------------------------------
# Training loss: 0.042996
# Validation loss: 0.041606
#
# Epoch 2361
# -------------------------------
# Training loss: 0.043016
# Validation loss: 0.042156
#
# Epoch 2362
# -------------------------------
# Training loss: 0.042945
# Validation loss: 0.044055
#
# Epoch 2363
# -------------------------------
# Training loss: 0.040995
# Validation loss: 0.041316
#
# Epoch 2364
# -------------------------------
# Training loss: 0.041472
# Validation loss: 0.039865
#
# Epoch 2365
# -------------------------------
# Training loss: 0.041325
# Validation loss: 0.041054
#
# Epoch 2366
# -------------------------------
# Training loss: 0.041682
# Validation loss: 0.041751
#
# Epoch 2367
# -------------------------------
# Training loss: 0.042227
# Validation loss: 0.041431
#
# Epoch 2368
# -------------------------------
# Training loss: 0.042607
# Validation loss: 0.041427
#
# Epoch 2369
# -------------------------------
# Training loss: 0.041674
# Validation loss: 0.043036
#
# Epoch 2370
# -------------------------------
# Training loss: 0.042835
# Validation loss: 0.042544
#
# Epoch 2371
# -------------------------------
# Training loss: 0.040868
# Validation loss: 0.042513
#
# Epoch 2372
# -------------------------------
# Training loss: 0.042445
# Validation loss: 0.042125
#
# Epoch 2373
# -------------------------------
# Training loss: 0.041454
# Validation loss: 0.041262
#
# Epoch 2374
# -------------------------------
# Training loss: 0.041507
# Validation loss: 0.041690
#
# Epoch 2375
# -------------------------------
# Training loss: 0.041272
# Validation loss: 0.042077
#
# Epoch 2376
# -------------------------------
# Training loss: 0.041311
# Validation loss: 0.042460
#
# Epoch 2377
# -------------------------------
# Training loss: 0.041270
# Validation loss: 0.042496
#
# Epoch 2378
# -------------------------------
# Training loss: 0.041516
# Validation loss: 0.041725
#
# Epoch 2379
# -------------------------------
# Training loss: 0.041023
# Validation loss: 0.043134
#
# Epoch 2380
# -------------------------------
# Training loss: 0.041923
# Validation loss: 0.042388
#
# Epoch 2381
# -------------------------------
# Training loss: 0.042144
# Validation loss: 0.042098
#
# Epoch 2382
# -------------------------------
# Training loss: 0.039994
# Validation loss: 0.041032
#
# Epoch 2383
# -------------------------------
# Training loss: 0.040645
# Validation loss: 0.043970
#
# Epoch 2384
# -------------------------------
# Training loss: 0.043041
# Validation loss: 0.042562
#
# Epoch 2385
# -------------------------------
# Training loss: 0.041047
# Validation loss: 0.040399
#
# Epoch 2386
# -------------------------------
# Training loss: 0.041379
# Validation loss: 0.040828
#
# Epoch 2387
# -------------------------------
# Training loss: 0.041053
# Validation loss: 0.041901
#
# Epoch 2388
# -------------------------------
# Training loss: 0.041257
# Validation loss: 0.041616
#
# Epoch 2389
# -------------------------------
# Training loss: 0.040305
# Validation loss: 0.041312
#
# Epoch 2390
# -------------------------------
# Training loss: 0.041405
# Validation loss: 0.042445
#
# Epoch 2391
# -------------------------------
# Training loss: 0.041722
# Validation loss: 0.041320
#
# Epoch 2392
# -------------------------------
# Training loss: 0.042794
# Validation loss: 0.042718
#
# Epoch 2393
# -------------------------------
# Training loss: 0.041661
# Validation loss: 0.042893
#
# Epoch 2394
# -------------------------------
# Training loss: 0.041112
# Validation loss: 0.041676
#
# Epoch 2395
# -------------------------------
# Training loss: 0.043809
# Validation loss: 0.044025
#
# Epoch 2396
# -------------------------------
# Training loss: 0.042365
# Validation loss: 0.046801
#
# Epoch 2397
# -------------------------------
# Training loss: 0.041439
# Validation loss: 0.042433
#
# Epoch 2398
# -------------------------------
# Training loss: 0.040863
# Validation loss: 0.043349
#
# Epoch 2399
# -------------------------------
# Training loss: 0.041981
# Validation loss: 0.043103
#
# Epoch 2400
# -------------------------------
# Training loss: 0.041531
# Validation loss: 0.042747
#
# Epoch 2401
# -------------------------------
# Training loss: 0.041106
# Validation loss: 0.041956
#
# Epoch 2402
# -------------------------------
# Training loss: 0.042084
# Validation loss: 0.041412
#
# Epoch 2403
# -------------------------------
# Training loss: 0.040805
# Validation loss: 0.040579
#
# Epoch 2404
# -------------------------------
# Training loss: 0.040201
# Validation loss: 0.039561
#
# Epoch 2405
# -------------------------------
# Training loss: 0.040024
# Validation loss: 0.040690
#
# Epoch 2406
# -------------------------------
# Training loss: 0.042289
# Validation loss: 0.040536
#
# Epoch 2407
# -------------------------------
# Training loss: 0.042236
# Validation loss: 0.043287
#
# Epoch 2408
# -------------------------------
# Training loss: 0.041403
# Validation loss: 0.040785
#
# Epoch 2409
# -------------------------------
# Training loss: 0.041729
# Validation loss: 0.043309
#
# Epoch 2410
# -------------------------------
# Training loss: 0.040722
# Validation loss: 0.040494
#
# Epoch 2411
# -------------------------------
# Training loss: 0.040837
# Validation loss: 0.041900
#
# Epoch 2412
# -------------------------------
# Training loss: 0.042088
# Validation loss: 0.041301
#
# Epoch 2413
# -------------------------------
# Training loss: 0.041133
# Validation loss: 0.043245
#
# Epoch 2414
# -------------------------------
# Training loss: 0.041990
# Validation loss: 0.041324
#
# Epoch 2415
# -------------------------------
# Training loss: 0.039823
# Validation loss: 0.042626
#
# Epoch 2416
# -------------------------------
# Training loss: 0.041516
# Validation loss: 0.040601
#
# Epoch 2417
# -------------------------------
# Training loss: 0.041427
# Validation loss: 0.040807
#
# Epoch 2418
# -------------------------------
# Training loss: 0.040694
# Validation loss: 0.040561
#
# Epoch 2419
# -------------------------------
# Training loss: 0.041027
# Validation loss: 0.040937
#
# Epoch 2420
# -------------------------------
# Training loss: 0.043764
# Validation loss: 0.043820
#
# Epoch 2421
# -------------------------------
# Training loss: 0.040988
# Validation loss: 0.041433
#
# Epoch 2422
# -------------------------------
# Training loss: 0.040508
# Validation loss: 0.040175
#
# Epoch 2423
# -------------------------------
# Training loss: 0.042398
# Validation loss: 0.042304
#
# Epoch 2424
# -------------------------------
# Training loss: 0.040894
# Validation loss: 0.043279
#
# Epoch 2425
# -------------------------------
# Training loss: 0.042204
# Validation loss: 0.045209
#
# Epoch 2426
# -------------------------------
# Training loss: 0.041202
# Validation loss: 0.041149
#
# Epoch 2427
# -------------------------------
# Training loss: 0.042565
# Validation loss: 0.039763
#
# Epoch 2428
# -------------------------------
# Training loss: 0.041762
# Validation loss: 0.043898
#
# Epoch 2429
# -------------------------------
# Training loss: 0.040372
# Validation loss: 0.042067
#
# Epoch 2430
# -------------------------------
# Training loss: 0.041404
# Validation loss: 0.041323
#
# Epoch 2431
# -------------------------------
# Training loss: 0.042919
# Validation loss: 0.042022
#
# Epoch 2432
# -------------------------------
# Training loss: 0.040109
# Validation loss: 0.042141
#
# Epoch 2433
# -------------------------------
# Training loss: 0.039973
# Validation loss: 0.040032
#
# Epoch 2434
# -------------------------------
# Training loss: 0.041185
# Validation loss: 0.042451
#
# Epoch 2435
# -------------------------------
# Training loss: 0.043581
# Validation loss: 0.041116
#
# Epoch 2436
# -------------------------------
# Training loss: 0.041441
# Validation loss: 0.042156
#
# Epoch 2437
# -------------------------------
# Training loss: 0.041660
# Validation loss: 0.042368
#
# Epoch 2438
# -------------------------------
# Training loss: 0.040825
# Validation loss: 0.040174
#
# Epoch 2439
# -------------------------------
# Training loss: 0.040805
# Validation loss: 0.038937
#
# Epoch 2440
# -------------------------------
# Training loss: 0.042959
# Validation loss: 0.040490
#
# Epoch 2441
# -------------------------------
# Training loss: 0.041274
# Validation loss: 0.043622
#
# Epoch 2442
# -------------------------------
# Training loss: 0.040795
# Validation loss: 0.043709
#
# Epoch 2443
# -------------------------------
# Training loss: 0.041966
# Validation loss: 0.043934
#
# Epoch 2444
# -------------------------------
# Training loss: 0.040882
# Validation loss: 0.042868
#
# Epoch 2445
# -------------------------------
# Training loss: 0.041432
# Validation loss: 0.042308
#
# Epoch 2446
# -------------------------------
# Training loss: 0.041055
# Validation loss: 0.041684
#
# Epoch 2447
# -------------------------------
# Training loss: 0.039153
# Validation loss: 0.041103
#
# Epoch 2448
# -------------------------------
# Training loss: 0.040646
# Validation loss: 0.043237
#
# Epoch 2449
# -------------------------------
# Training loss: 0.042219
# Validation loss: 0.040556
#
# Epoch 2450
# -------------------------------
# Training loss: 0.041835
# Validation loss: 0.040664
#
# Epoch 2451
# -------------------------------
# Training loss: 0.041553
# Validation loss: 0.041884
#
# Epoch 2452
# -------------------------------
# Training loss: 0.040579
# Validation loss: 0.043792
#
# Epoch 2453
# -------------------------------
# Training loss: 0.042916
# Validation loss: 0.042216
#
# Epoch 2454
# -------------------------------
# Training loss: 0.040688
# Validation loss: 0.042380
#
# Epoch 2455
# -------------------------------
# Training loss: 0.041191
# Validation loss: 0.040871
#
# Epoch 2456
# -------------------------------
# Training loss: 0.039823
# Validation loss: 0.040580
#
# Epoch 2457
# -------------------------------
# Training loss: 0.040259
# Validation loss: 0.040172
#
# Epoch 2458
# -------------------------------
# Training loss: 0.041636
# Validation loss: 0.040939
#
# Epoch 2459
# -------------------------------
# Training loss: 0.041574
# Validation loss: 0.041472
#
# Epoch 2460
# -------------------------------
# Training loss: 0.040012
# Validation loss: 0.039363
#
# Epoch 2461
# -------------------------------
# Training loss: 0.040043
# Validation loss: 0.041574
#
# Epoch 2462
# -------------------------------
# Training loss: 0.039667
# Validation loss: 0.040003
#
# Epoch 2463
# -------------------------------
# Training loss: 0.040901
# Validation loss: 0.042263
#
# Epoch 2464
# -------------------------------
# Training loss: 0.040841
# Validation loss: 0.041722
#
# Epoch 2465
# -------------------------------
# Training loss: 0.040890
# Validation loss: 0.040614
#
# Epoch 2466
# -------------------------------
# Training loss: 0.040634
# Validation loss: 0.041236
#
# Epoch 2467
# -------------------------------
# Training loss: 0.041966
# Validation loss: 0.044072
#
# Epoch 2468
# -------------------------------
# Training loss: 0.040249
# Validation loss: 0.042861
#
# Epoch 2469
# -------------------------------
# Training loss: 0.039523
# Validation loss: 0.042015
#
# Epoch 2470
# -------------------------------
# Training loss: 0.038886
# Validation loss: 0.040766
#
# Epoch 2471
# -------------------------------
# Training loss: 0.041219
# Validation loss: 0.040640
#
# Epoch 2472
# -------------------------------
# Training loss: 0.041702
# Validation loss: 0.043726
#
# Epoch 2473
# -------------------------------
# Training loss: 0.040077
# Validation loss: 0.040006
#
# Epoch 2474
# -------------------------------
# Training loss: 0.039523
# Validation loss: 0.039605
#
# Epoch 2475
# -------------------------------
# Training loss: 0.040939
# Validation loss: 0.041562
#
# Epoch 2476
# -------------------------------
# Training loss: 0.041347
# Validation loss: 0.041201
#
# Epoch 2477
# -------------------------------
# Training loss: 0.040465
# Validation loss: 0.040089
#
# Epoch 2478
# -------------------------------
# Training loss: 0.040987
# Validation loss: 0.042356
#
# Epoch 2479
# -------------------------------
# Training loss: 0.038981
# Validation loss: 0.040798
#
# Epoch 2480
# -------------------------------
# Training loss: 0.041949
# Validation loss: 0.041472
#
# Epoch 2481
# -------------------------------
# Training loss: 0.039604
# Validation loss: 0.039624
#
# Epoch 2482
# -------------------------------
# Training loss: 0.040233
# Validation loss: 0.041829
#
# Epoch 2483
# -------------------------------
# Training loss: 0.040053
# Validation loss: 0.039912
#
# Epoch 2484
# -------------------------------
# Training loss: 0.040133
# Validation loss: 0.043581
#
# Epoch 2485
# -------------------------------
# Training loss: 0.039333
# Validation loss: 0.041184
#
# Epoch 2486
# -------------------------------
# Training loss: 0.040386
# Validation loss: 0.041281
#
# Epoch 2487
# -------------------------------
# Training loss: 0.041421
# Validation loss: 0.041937
#
# Epoch 2488
# -------------------------------
# Training loss: 0.039532
# Validation loss: 0.040516
#
# Epoch 2489
# -------------------------------
# Training loss: 0.039721
# Validation loss: 0.040396
#
# Epoch 2490
# -------------------------------
# Training loss: 0.039673
# Validation loss: 0.043792
#
# Epoch 2491
# -------------------------------
# Training loss: 0.039475
# Validation loss: 0.039520
#
# Epoch 2492
# -------------------------------
# Training loss: 0.040012
# Validation loss: 0.041330
#
# Epoch 2493
# -------------------------------
# Training loss: 0.038964
# Validation loss: 0.040901
#
# Epoch 2494
# -------------------------------
# Training loss: 0.039762
# Validation loss: 0.040361
#
# Epoch 2495
# -------------------------------
# Training loss: 0.039652
# Validation loss: 0.039951
#
# Epoch 2496
# -------------------------------
# Training loss: 0.040020
# Validation loss: 0.040555
#
# Epoch 2497
# -------------------------------
# Training loss: 0.040610
# Validation loss: 0.041188
#
# Epoch 2498
# -------------------------------
# Training loss: 0.041343
# Validation loss: 0.040477
#
# Epoch 2499
# -------------------------------
# Training loss: 0.040649
# Validation loss: 0.042160
#
# Epoch 2500
# -------------------------------
# Training loss: 0.040812
# Validation loss: 0.040521
#
# Done!

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses)+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('BCE Loss')
#plt.yscale('log')
plt.legend()

# %%
# Now test the pretrained model
test_pred = mytools.test_clas(test_loader, final_classifier, device)
test_pred=torch.sigmoid(torch.tensor(test_pred)).numpy()


fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test, test_pred, pos_label=1)
auc_test = sklearn.metrics.auc(fpr, tpr)
print(f'Test AUROC: {auc_test:0.4f}')

plt.plot(fpr, tpr, label=f'Test AUROC: {auc_test:0.4f}')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
# Out:
# Test AUROC: 0.9967

# %%
# Store the pretrained classifier labels
df_test["Class_pre"] = test_pred

# Save the pretrained classifier model
torch.save(final_classifier.state_dict(), "/Users/mghrear/data/ML_data/patch/pretrained_classifier_2021_v9_pass5_FakeGen_1pt05_kaon_run"+str(run)+"_limited.pt")

# %% [markdown]
# # Setup the adversary model

# %% [markdown]
# ## Initialize model, objective function, and optimizer

# %%
adv = mytools.Adversary(n_classes=Num_classes).to(device)
criterion_adv = nn.CrossEntropyLoss(reduction='none')  # returns loss per sample so we can weight it
opt_adv = torch.optim.Adam(adv.parameters(), lr=1e-5)
scheduler_adv = torch.optim.lr_scheduler.ExponentialLR(opt_adv, gamma=0.999)

# %% [markdown]
# ## Setup dataloaders

# %%
# Convert to tensor dataset and dataloader

# the structure is: feature, adversary label, weight
# The wight is 1 for tritrig and wab, and 0 for phiKK, to prevent the adversary from learning on phiKK events

train_adv_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_train), (torch.from_numpy(y_train.to_numpy().astype(np.float32))==0).float())
train_adv_loader = DataLoader(train_adv_dataset, batch_size=bsize, shuffle=True)

val_adv_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_val), (torch.from_numpy(y_val.to_numpy().astype(np.float32))==0).float() )
val_adv_loader = DataLoader(val_adv_dataset, batch_size=bsize, shuffle=True)

# Weights are not relavent for testing
test_adv_dataset = TensorDataset(torch.from_numpy(X_test.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_test))
test_adv_loader = DataLoader(test_adv_dataset, batch_size=bsize, shuffle=True)

# %% [markdown]
# ## Pre-train the adversary leaving classifier weights fixed

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 6

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 100
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train_adv(train_adv_loader, final_classifier, adv, criterion_adv, opt_adv, scheduler_adv, device))
    Validation_losses = np.append(Validation_losses, mytools.validate_adv(val_adv_loader, final_classifier, adv, criterion_adv, device))
    
    # Keep a running copy of the model with the lowest loss
    if Validation_losses[-1] == np.min(Validation_losses):
        final_adv = copy.deepcopy(adv)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Training loss: 1.627243
# Validation loss: 1.609980
#
# Epoch 2
# -------------------------------
# Training loss: 1.620773
# Validation loss: 1.608846
#
# Epoch 3
# -------------------------------
# Training loss: 1.614796
# Validation loss: 1.609377
#
# Epoch 4
# -------------------------------
# Training loss: 1.609935
# Validation loss: 1.614957
#
# Epoch 5
# -------------------------------
# Training loss: 1.605815
# Validation loss: 1.612033
#
# Epoch 6
# -------------------------------
# Training loss: 1.602409
# Validation loss: 1.615052
#
# Epoch 7
# -------------------------------
# Training loss: 1.601011
# Validation loss: 1.617047
#
# Epoch 8
# -------------------------------
# Training loss: 1.599837
# Validation loss: 1.612976
#
# Epoch 9
# -------------------------------
# Training loss: 1.599245
# Validation loss: 1.611067
#
# Epoch 10
# -------------------------------
# Training loss: 1.598773
# Validation loss: 1.609881
#
# Epoch 11
# -------------------------------
# Training loss: 1.597841
# Validation loss: 1.604952
#
# Epoch 12
# -------------------------------
# Training loss: 1.597576
# Validation loss: 1.606992
#
# Epoch 13
# -------------------------------
# Training loss: 1.597541
# Validation loss: 1.602629
#
# Epoch 14
# -------------------------------
# Training loss: 1.597019
# Validation loss: 1.602946
#
# Epoch 15
# -------------------------------
# Training loss: 1.596633
# Validation loss: 1.606903
#
# Epoch 16
# -------------------------------
# Training loss: 1.595616
# Validation loss: 1.600490
#
# Epoch 17
# -------------------------------
# Training loss: 1.595669
# Validation loss: 1.602709
#
# Epoch 18
# -------------------------------
# Training loss: 1.595716
# Validation loss: 1.601347
#
# Epoch 19
# -------------------------------
# Training loss: 1.595392
# Validation loss: 1.603429
#
# Epoch 20
# -------------------------------
# Training loss: 1.595177
# Validation loss: 1.598296
#
# Epoch 21
# -------------------------------
# Training loss: 1.594684
# Validation loss: 1.598796
#
# Epoch 22
# -------------------------------
# Training loss: 1.594390
# Validation loss: 1.598920
#
# Epoch 23
# -------------------------------
# Training loss: 1.594296
# Validation loss: 1.598611
#
# Epoch 24
# -------------------------------
# Training loss: 1.594193
# Validation loss: 1.598478
#
# Epoch 25
# -------------------------------
# Training loss: 1.593470
# Validation loss: 1.598554
#
# Epoch 26
# -------------------------------
# Training loss: 1.593327
# Validation loss: 1.599738
#
# Epoch 27
# -------------------------------
# Training loss: 1.593253
# Validation loss: 1.595861
#
# Epoch 28
# -------------------------------
# Training loss: 1.592830
# Validation loss: 1.598549
#
# Epoch 29
# -------------------------------
# Training loss: 1.592662
# Validation loss: 1.597995
#
# Epoch 30
# -------------------------------
# Training loss: 1.592239
# Validation loss: 1.598803
#
# Epoch 31
# -------------------------------
# Training loss: 1.592519
# Validation loss: 1.598806
#
# Epoch 32
# -------------------------------
# Training loss: 1.592489
# Validation loss: 1.599231
#
# Epoch 33
# -------------------------------
# Training loss: 1.591842
# Validation loss: 1.595889
#
# Epoch 34
# -------------------------------
# Training loss: 1.592064
# Validation loss: 1.597548
#
# Epoch 35
# -------------------------------
# Training loss: 1.591688
# Validation loss: 1.596688
#
# Epoch 36
# -------------------------------
# Training loss: 1.591493
# Validation loss: 1.597263
#
# Epoch 37
# -------------------------------
# Training loss: 1.591440
# Validation loss: 1.595020
#
# Epoch 38
# -------------------------------
# Training loss: 1.591432
# Validation loss: 1.595374
#
# Epoch 39
# -------------------------------
# Training loss: 1.591194
# Validation loss: 1.595221
#
# Epoch 40
# -------------------------------
# Training loss: 1.590805
# Validation loss: 1.593251
#
# Epoch 41
# -------------------------------
# Training loss: 1.590692
# Validation loss: 1.596256
#
# Epoch 42
# -------------------------------
# Training loss: 1.590592
# Validation loss: 1.594300
#
# Epoch 43
# -------------------------------
# Training loss: 1.590584
# Validation loss: 1.594967
#
# Epoch 44
# -------------------------------
# Training loss: 1.590701
# Validation loss: 1.594823
#
# Epoch 45
# -------------------------------
# Training loss: 1.590654
# Validation loss: 1.595374
#
# Epoch 46
# -------------------------------
# Training loss: 1.590290
# Validation loss: 1.593926
#
# Epoch 47
# -------------------------------
# Training loss: 1.590056
# Validation loss: 1.592508
#
# Epoch 48
# -------------------------------
# Training loss: 1.590097
# Validation loss: 1.596327
#
# Epoch 49
# -------------------------------
# Training loss: 1.589724
# Validation loss: 1.595293
#
# Epoch 50
# -------------------------------
# Training loss: 1.589453
# Validation loss: 1.593813
#
# Epoch 51
# -------------------------------
# Training loss: 1.589593
# Validation loss: 1.594248
#
# Epoch 52
# -------------------------------
# Training loss: 1.589624
# Validation loss: 1.595353
#
# Epoch 53
# -------------------------------
# Training loss: 1.589333
# Validation loss: 1.593017
#
# Epoch 54
# -------------------------------
# Training loss: 1.589765
# Validation loss: 1.595863
#
# Epoch 55
# -------------------------------
# Training loss: 1.589427
# Validation loss: 1.593920
#
# Epoch 56
# -------------------------------
# Training loss: 1.589484
# Validation loss: 1.592711
#
# Epoch 57
# -------------------------------
# Training loss: 1.589028
# Validation loss: 1.595282
#
# Epoch 58
# -------------------------------
# Training loss: 1.589635
# Validation loss: 1.595015
#
# Epoch 59
# -------------------------------
# Training loss: 1.589237
# Validation loss: 1.590615
#
# Epoch 60
# -------------------------------
# Training loss: 1.589275
# Validation loss: 1.593719
#
# Epoch 61
# -------------------------------
# Training loss: 1.588805
# Validation loss: 1.591853
#
# Epoch 62
# -------------------------------
# Training loss: 1.589143
# Validation loss: 1.592271
#
# Epoch 63
# -------------------------------
# Training loss: 1.588900
# Validation loss: 1.591281
#
# Epoch 64
# -------------------------------
# Training loss: 1.588954
# Validation loss: 1.593938
#
# Epoch 65
# -------------------------------
# Training loss: 1.589246
# Validation loss: 1.593131
#
# Epoch 66
# -------------------------------
# Training loss: 1.588988
# Validation loss: 1.592703
#
# Epoch 67
# -------------------------------
# Training loss: 1.588874
# Validation loss: 1.594004
#
# Epoch 68
# -------------------------------
# Training loss: 1.588776
# Validation loss: 1.593065
#
# Epoch 69
# -------------------------------
# Training loss: 1.588575
# Validation loss: 1.593165
#
# Epoch 70
# -------------------------------
# Training loss: 1.588130
# Validation loss: 1.593858
#
# Epoch 71
# -------------------------------
# Training loss: 1.588965
# Validation loss: 1.593704
#
# Epoch 72
# -------------------------------
# Training loss: 1.588765
# Validation loss: 1.594165
#
# Epoch 73
# -------------------------------
# Training loss: 1.588422
# Validation loss: 1.591534
#
# Epoch 74
# -------------------------------
# Training loss: 1.588371
# Validation loss: 1.592445
#
# Epoch 75
# -------------------------------
# Training loss: 1.588460
# Validation loss: 1.593629
#
# Epoch 76
# -------------------------------
# Training loss: 1.588414
# Validation loss: 1.592018
#
# Epoch 77
# -------------------------------
# Training loss: 1.588432
# Validation loss: 1.593097
#
# Epoch 78
# -------------------------------
# Training loss: 1.588449
# Validation loss: 1.593904
#
# Epoch 79
# -------------------------------
# Training loss: 1.588248
# Validation loss: 1.594470
#
# Epoch 80
# -------------------------------
# Training loss: 1.588095
# Validation loss: 1.593764
#
# Epoch 81
# -------------------------------
# Training loss: 1.588370
# Validation loss: 1.592687
#
# Epoch 82
# -------------------------------
# Training loss: 1.588499
# Validation loss: 1.592373
#
# Epoch 83
# -------------------------------
# Training loss: 1.588316
# Validation loss: 1.593293
#
# Epoch 84
# -------------------------------
# Training loss: 1.587985
# Validation loss: 1.592649
#
# Epoch 85
# -------------------------------
# Training loss: 1.588404
# Validation loss: 1.593594
#
# Epoch 86
# -------------------------------
# Training loss: 1.588349
# Validation loss: 1.591370
#
# Epoch 87
# -------------------------------
# Training loss: 1.587802
# Validation loss: 1.592406
#
# Epoch 88
# -------------------------------
# Training loss: 1.588510
# Validation loss: 1.593587
#
# Epoch 89
# -------------------------------
# Training loss: 1.587936
# Validation loss: 1.593111
#
# Epoch 90
# -------------------------------
# Training loss: 1.587741
# Validation loss: 1.591267
#
# Epoch 91
# -------------------------------
# Training loss: 1.587843
# Validation loss: 1.592143
#
# Epoch 92
# -------------------------------
# Training loss: 1.587648
# Validation loss: 1.590676
#
# Epoch 93
# -------------------------------
# Training loss: 1.587525
# Validation loss: 1.592509
#
# Epoch 94
# -------------------------------
# Training loss: 1.587964
# Validation loss: 1.593599
#
# Epoch 95
# -------------------------------
# Training loss: 1.588020
# Validation loss: 1.592933
#
# Epoch 96
# -------------------------------
# Training loss: 1.587981
# Validation loss: 1.591945
#
# Epoch 97
# -------------------------------
# Training loss: 1.587643
# Validation loss: 1.589285
#
# Epoch 98
# -------------------------------
# Training loss: 1.587765
# Validation loss: 1.591272
#
# Epoch 99
# -------------------------------
# Training loss: 1.587716
# Validation loss: 1.593947
#
# Epoch 100
# -------------------------------
# Training loss: 1.587721
# Validation loss: 1.593069
#
# Done!

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses)+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('BCE Loss')
plt.legend()

# %% [markdown]
# ## Test the pre-trained adversary

# %%
adv_test_pred = mytools.test_adv(test_adv_loader, final_classifier, final_adv, Num_classes, device)
adv_test_pred = torch.softmax(torch.tensor(adv_test_pred),dim=1).numpy()
score=0

for i in range(adv_test_pred.shape[1]):
    fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_adv_test[:,i], adv_test_pred[:,i], pos_label=1)
    auc_test = sklearn.metrics.auc(fpr, tpr)
    print("class " + str(i)+ " test auc score: " + str(auc_test))

    plt.plot(fpr, tpr, label='Class '+str(i)+' Test AUROC: '+str(auc_test))
    plt.xlabel('FPR')
    plt.ylabel('TPR')
    plt.legend()

    score += auc_test

print("average score: ", score/adv_test_pred.shape[1])
# Out:
# class 0 test auc score: 0.49934887123983507
# class 1 test auc score: 0.5003507184518385
# class 2 test auc score: 0.4985407425987133
# class 3 test auc score: 0.5047518266986617
# class 4 test auc score: 0.4966864864105948
# average score:  0.49993572907992867

# %% [markdown]
# # Train full adverserial neural network

# %% [markdown]
# # Setup dataloaders

# %%
# the structure is: feature, classifier label, adversary label, weight
# The wight is 1 for tritrig and wab, and 0 for phiKK, to prevent the adversary from learning on phiKK events

train_full_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy().astype(np.float32))  , torch.from_numpy(y_train.to_numpy().astype(np.float32)).unsqueeze(1), torch.from_numpy(y_adv_train),  (torch.from_numpy(y_train.to_numpy().astype(np.float32))==0).float())
train_full_loader = DataLoader(train_full_dataset, batch_size=bsize, shuffle=True)

val_full_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy().astype(np.float32))  , torch.from_numpy(y_val.to_numpy().astype(np.float32)).unsqueeze(1),  torch.from_numpy(y_adv_val),  (torch.from_numpy(y_val.to_numpy().astype(np.float32))==0).float())
val_full_loader = DataLoader(val_full_dataset, batch_size=bsize, shuffle=True)

# %% [markdown]
# ## Define loss functions

# %%
BCE_loss = nn.BCEWithLogitsLoss()
CE_loss = nn.CrossEntropyLoss(reduction='none') # returns loss per sample so we can weight it

def full_loss(output_clas, output_adv, target_clas, target_adv, w, lambda_):

    loss1 = BCE_loss(output_clas, target_clas )  # classification loss
    sample_losses2 = CE_loss(output_adv, target_adv)  # adversarial losses, since we set reduction='none', this is now a vector of losses, one per sample in the batch

    # Weighted mean loss over non-zero weights
    nonzero = w > 0
    loss2 = (sample_losses2[nonzero] * w[nonzero]).sum() / w[nonzero].sum()

    loss = loss1 - lambda_*loss2

    return loss

# %% [markdown]
# ## Setup optimizers

# %%
optimizer_clas = optim.Adam(final_classifier.parameters(), lr=1e-7,betas=(0.5, 0.999))
optimizer_adv = optim.Adam(final_adv.parameters(), lr=1e-5,betas=(0.5, 0.999))

scheduler_clas = torch.optim.lr_scheduler.ExponentialLR(optimizer_clas, gamma=0.999)
scheduler_adv = torch.optim.lr_scheduler.ExponentialLR(optimizer_adv, gamma=0.999)

# %% [markdown]
# ## Adversarial training

# %%
Training_losses_clas = np.array([])
Training_losses_adv = np.array([])
Validation_losses_clas = np.array([])
Validation_losses_adv = np.array([])
diff_scores = np.array([])


epochs = 50
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")

    # Get validation losses
    E_clas_val_loss, E_adv_val_loss = mytools.validate_full(val_full_loader, final_classifier, final_adv, full_loss, lambda_, criterion_adv, device)
    Validation_losses_clas = np.append(Validation_losses_clas, E_clas_val_loss)
    Validation_losses_adv = np.append(Validation_losses_adv, E_adv_val_loss)

    # Train adversary and classifier
    E_clas_training_loss , E_adv_training_loss = mytools.train_full(train_full_loader, final_classifier, final_adv, full_loss, lambda_, criterion_adv, optimizer_clas, optimizer_adv, scheduler_clas, scheduler_adv, device)
    Training_losses_clas = np.append(Training_losses_clas, E_clas_training_loss)
    Training_losses_adv = np.append(Training_losses_adv, E_adv_training_loss)

    # Get the diff_score
    df_test["Class_adv"] = mytools.test_clas(test_loader, final_classifier, device)
    df_bkg = df_test.loc[ (df_test.type == 'tritrig') | (df_test.type == 'wab')]
    per = np.percentile(df_bkg['Class_adv'],99)
    df_cut = df_bkg[df_bkg['Class_adv']>per].reset_index(drop=True)
    x1 = 1000* df_bkg.InvM.values
    x2 = 1000*df_cut.InvM.values
    diff_scores = np.append(diff_scores, mytools.get_diff_score(x1,x2) )

    # Keep a running copy of the model with the lowest loss
    if diff_scores[-1] == np.min(diff_scores):
        final_clas_adv = copy.deepcopy(final_classifier)
        final_adv_adv = copy.deepcopy(final_adv)

            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Classifier validation loss: -159.136649
# Adversary validation loss: 1.591771
# Classifier training loss: -160.015350
# Adversary training loss: 1.602043
# Epoch 2
# -------------------------------
# Classifier validation loss: -159.794678
# Adversary validation loss: 1.598392
# Classifier training loss: -160.896807
# Adversary training loss: 1.610766
# Epoch 3
# -------------------------------
# Classifier validation loss: -160.954599
# Adversary validation loss: 1.609970
# Classifier training loss: -161.431503
# Adversary training loss: 1.615794
# Epoch 4
# -------------------------------
# Classifier validation loss: -161.503983
# Adversary validation loss: 1.615497
# Classifier training loss: -161.724791
# Adversary training loss: 1.618400
# Epoch 5
# -------------------------------
# Classifier validation loss: -161.692340
# Adversary validation loss: 1.617393
# Classifier training loss: -161.922538
# Adversary training loss: 1.620183
# Epoch 6
# -------------------------------
# Classifier validation loss: -161.892163
# Adversary validation loss: 1.619415
# Classifier training loss: -161.660726
# Adversary training loss: 1.617420
# Epoch 7
# -------------------------------
# Classifier validation loss: -161.805820
# Adversary validation loss: 1.618585
# Classifier training loss: -161.526920
# Adversary training loss: 1.616135
# Epoch 8
# -------------------------------
# Classifier validation loss: -161.673853
# Adversary validation loss: 1.617290
# Classifier training loss: -161.484673
# Adversary training loss: 1.615711
# Epoch 9
# -------------------------------
# Classifier validation loss: -161.477106
# Adversary validation loss: 1.615332
# Classifier training loss: -161.315387
# Adversary training loss: 1.613955
# Epoch 10
# -------------------------------
# Classifier validation loss: -161.515771
# Adversary validation loss: 1.615776
# Classifier training loss: -161.153354
# Adversary training loss: 1.612382
# Epoch 11
# -------------------------------
# Classifier validation loss: -161.300119
# Adversary validation loss: 1.613588
# Classifier training loss: -160.970239
# Adversary training loss: 1.610467
# Epoch 12
# -------------------------------
# Classifier validation loss: -161.241446
# Adversary validation loss: 1.613034
# Classifier training loss: -160.975042
# Adversary training loss: 1.610568
# Epoch 13
# -------------------------------
# Classifier validation loss: -161.213376
# Adversary validation loss: 1.612781
# Classifier training loss: -160.739917
# Adversary training loss: 1.608186
# Epoch 14
# -------------------------------
# Classifier validation loss: -161.116779
# Adversary validation loss: 1.611839
# Classifier training loss: -160.556263
# Adversary training loss: 1.606361
# Epoch 15
# -------------------------------
# Classifier validation loss: -160.827121
# Adversary validation loss: 1.608942
# Classifier training loss: -160.438427
# Adversary training loss: 1.605208
# Epoch 16
# -------------------------------
# Classifier validation loss: -160.703900
# Adversary validation loss: 1.607702
# Classifier training loss: -160.339242
# Adversary training loss: 1.604234
# Epoch 17
# -------------------------------
# Classifier validation loss: -160.478571
# Adversary validation loss: 1.605450
# Classifier training loss: -160.242793
# Adversary training loss: 1.603291
# Epoch 18
# -------------------------------
# Classifier validation loss: -160.674979
# Adversary validation loss: 1.607382
# Classifier training loss: -160.317766
# Adversary training loss: 1.604038
# Epoch 19
# -------------------------------
# Classifier validation loss: -160.524222
# Adversary validation loss: 1.605869
# Classifier training loss: -160.403637
# Adversary training loss: 1.604927
# Epoch 20
# -------------------------------
# Classifier validation loss: -160.708139
# Adversary validation loss: 1.607732
# Classifier training loss: -160.458696
# Adversary training loss: 1.605458
# Epoch 21
# -------------------------------
# Classifier validation loss: -160.655298
# Adversary validation loss: 1.607188
# Classifier training loss: -160.552855
# Adversary training loss: 1.606504
# Epoch 22
# -------------------------------
# Classifier validation loss: -160.765887
# Adversary validation loss: 1.608243
# Classifier training loss: -160.885585
# Adversary training loss: 1.609850
# Epoch 23
# -------------------------------
# Classifier validation loss: -161.134933
# Adversary validation loss: 1.611901
# Classifier training loss: -161.017787
# Adversary training loss: 1.611078
# Epoch 24
# -------------------------------
# Classifier validation loss: -161.315475
# Adversary validation loss: 1.613716
# Classifier training loss: -161.023851
# Adversary training loss: 1.610940
# Epoch 25
# -------------------------------
# Classifier validation loss: -161.340439
# Adversary validation loss: 1.613924
# Classifier training loss: -161.038657
# Adversary training loss: 1.611011
# Epoch 26
# -------------------------------
# Classifier validation loss: -161.165424
# Adversary validation loss: 1.612181
# Classifier training loss: -160.824934
# Adversary training loss: 1.608877
# Epoch 27
# -------------------------------
# Classifier validation loss: -160.969687
# Adversary validation loss: 1.610251
# Classifier training loss: -160.733637
# Adversary training loss: 1.607966
# Epoch 28
# -------------------------------
# Classifier validation loss: -160.871451
# Adversary validation loss: 1.609240
# Classifier training loss: -160.631660
# Adversary training loss: 1.606953
# Epoch 29
# -------------------------------
# Classifier validation loss: -160.698611
# Adversary validation loss: 1.607523
# Classifier training loss: -160.653042
# Adversary training loss: 1.607214
# Epoch 30
# -------------------------------
# Classifier validation loss: -160.761157
# Adversary validation loss: 1.608195
# Classifier training loss: -160.610487
# Adversary training loss: 1.606776
# Epoch 31
# -------------------------------
# Classifier validation loss: -160.820633
# Adversary validation loss: 1.608775
# Classifier training loss: -160.622387
# Adversary training loss: 1.606953
# Epoch 32
# -------------------------------
# Classifier validation loss: -160.868216
# Adversary validation loss: 1.609240
# Classifier training loss: -160.650503
# Adversary training loss: 1.607169
# Epoch 33
# -------------------------------
# Classifier validation loss: -160.669565
# Adversary validation loss: 1.607250
# Classifier training loss: -160.710085
# Adversary training loss: 1.607776
# Epoch 34
# -------------------------------
# Classifier validation loss: -160.886078
# Adversary validation loss: 1.609429
# Classifier training loss: -160.751916
# Adversary training loss: 1.608222
# Epoch 35
# -------------------------------
# Classifier validation loss: -160.935651
# Adversary validation loss: 1.609954
# Classifier training loss: -160.806934
# Adversary training loss: 1.608749
# Epoch 36
# -------------------------------
# Classifier validation loss: -160.941852
# Adversary validation loss: 1.609983
# Classifier training loss: -160.722868
# Adversary training loss: 1.607900
# Epoch 37
# -------------------------------
# Classifier validation loss: -160.848187
# Adversary validation loss: 1.609046
# Classifier training loss: -160.685079
# Adversary training loss: 1.607492
# Epoch 38
# -------------------------------
# Classifier validation loss: -160.794162
# Adversary validation loss: 1.608520
# Classifier training loss: -160.665351
# Adversary training loss: 1.607289
# Epoch 39
# -------------------------------
# Classifier validation loss: -160.822284
# Adversary validation loss: 1.608770
# Classifier training loss: -160.676556
# Adversary training loss: 1.607409
# Epoch 40
# -------------------------------
# Classifier validation loss: -160.968097
# Adversary validation loss: 1.610238
# Classifier training loss: -160.620266
# Adversary training loss: 1.606833
# Epoch 41
# -------------------------------
# Classifier validation loss: -160.772211
# Adversary validation loss: 1.608261
# Classifier training loss: -160.598311
# Adversary training loss: 1.606709
# Epoch 42
# -------------------------------
# Classifier validation loss: -160.880380
# Adversary validation loss: 1.609339
# Classifier training loss: -160.674834
# Adversary training loss: 1.607400
# Epoch 43
# -------------------------------
# Classifier validation loss: -161.043887
# Adversary validation loss: 1.610982
# Classifier training loss: -160.618993
# Adversary training loss: 1.606850
# Epoch 44
# -------------------------------
# Classifier validation loss: -160.809018
# Adversary validation loss: 1.608616
# Classifier training loss: -160.598953
# Adversary training loss: 1.606609
# Epoch 45
# -------------------------------
# Classifier validation loss: -160.891095
# Adversary validation loss: 1.609431
# Classifier training loss: -160.722543
# Adversary training loss: 1.607886
# Epoch 46
# -------------------------------
# Classifier validation loss: -160.922772
# Adversary validation loss: 1.609807
# Classifier training loss: -160.634742
# Adversary training loss: 1.606970
# Epoch 47
# -------------------------------
# Classifier validation loss: -160.947198
# Adversary validation loss: 1.609999
# Classifier training loss: -160.698574
# Adversary training loss: 1.607593
# Epoch 48
# -------------------------------
# Classifier validation loss: -160.872308
# Adversary validation loss: 1.609251
# Classifier training loss: -160.617862
# Adversary training loss: 1.606795
# Epoch 49
# -------------------------------
# Classifier validation loss: -160.849777
# Adversary validation loss: 1.609006
# Classifier training loss: -160.697159
# Adversary training loss: 1.607572
# Epoch 50
# -------------------------------
# Classifier validation loss: -160.924329
# Adversary validation loss: 1.609748
# Classifier training loss: -160.703381
# Adversary training loss: 1.607635
# Done!

# %%
fig, ax1 = plt.subplots()

best_epoch = np.argmin(diff_scores)+1



#ax1.plot(np.arange(len(Training_losses_adv))+1, Training_losses_adv, 'k-', label='Training Adversary')
ax1.plot(np.arange(len(Validation_losses_adv))+1, Validation_losses_adv, 'k-', label='Validation Adversary')

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Adversary Loss', color='k')
ax1.tick_params(axis='y', labelcolor='k')

ax2 = ax1.twinx()

#ax2.plot(np.arange(len(Training_losses_clas))+1, Training_losses_clas, 'r-', label='Training Classifier')
ax2.plot(np.arange(len(Validation_losses_clas))+1, Validation_losses_clas, 'r-', label='Validation Classifier')
ax2.axvline(best_epoch,label="Final model stopped here",color='k')

ax2.set_ylabel('Classifier Loss', color='r')
ax2.tick_params(axis='y', labelcolor='r')

# %% [markdown]
# ## Test adversarially trained models

# %%
# Now test the pretrained model
test_pred = mytools.test_clas(test_loader, final_clas_adv, device)
test_pred=torch.sigmoid(torch.tensor(test_pred)).numpy()


fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test, test_pred, pos_label=1)
auc_test = sklearn.metrics.auc(fpr, tpr)
print(f'Test AUROC: {auc_test:0.4f}')

plt.plot(fpr, tpr, label=f'Test AUROC: {auc_test:0.4f}')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
# Out:
# Test AUROC: 0.9949

# %%
df_test["Class_adv"] = test_pred
df_bkg = df_test.loc[ (df_test.type == 'tritrig') | (df_test.type == 'wab')]
per = np.percentile(df_bkg['Class_adv'],99)
df_cut = df_bkg[df_bkg['Class_adv']>per].reset_index(drop=True)
x_vals = 1000*df_cut.InvM

plt.figure()
plt.hist(1000*df_bkg.InvM, bins=np.arange(980,1250,1), histtype='step', label='No selection', density=True)
plt.hist(x_vals, bins=np.arange(980,1250,1), histtype='step', label= '99 percent selection', density=True)
plt.axvline(1019.461, color='k', linestyle='dashed', linewidth=1, label='PDG phi mass')
plt.xlabel('Invariant Mass [MeV]')
plt.ylabel('Normalized Counts')
plt.legend()

# %%
x1 = 1000* df_bkg.InvM.values
x2 = 1000*df_cut.InvM.values

N, edges = np.histogram(x1, bins=np.arange(980,1250,1), density=False)
M, edges = np.histogram(x2, bins=np.arange(980,1250,1), density=False)

N2 = N[(N > 0) & (M > 0)]
M2 = M[(N > 0) & (M > 0)]

diff_score = np.mean(np.abs(N2/np.sum(N)-M2/np.sum(M)) / (np.sqrt(N2)/np.sum(N) + np.sqrt(M2)/np.sum(M) ))

print(diff_score)

N = len(df_test.loc[ ((df_test.type == 'tritrig') | (df_test.type == 'wab')) & (df_test.InvM < (1.019 + 0.01) )  & (df_test.InvM > (1.019 - 0.01) ) & ( df_test['Class_adv']>per ) ] )
S = len(df_test.loc[ (df_test.type == 'phiKK') & (df_test.InvM < (1.019 + 0.01) )  & (df_test.InvM > (1.019 - 0.01) ) & ( df_test['Class_adv']>per )  ] )

print(S/N)
# Out:
# 0.7435738691394292
# 2.425675675675676

# %%
df_test["Class_adv"] = test_pred

# %%
adv_test_pred = mytools.test_adv(test_adv_loader, final_classifier, final_adv_adv, Num_classes, device)
adv_test_pred = torch.softmax(torch.tensor(adv_test_pred),dim=1).numpy()
score=0

for i in range(adv_test_pred.shape[1]):
    fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_adv_test[:,i], adv_test_pred[:,i], pos_label=1)
    auc_test = sklearn.metrics.auc(fpr, tpr)
    print("class " + str(i)+ " test auc score: " + str(auc_test))

    plt.plot(fpr, tpr, label='Class '+str(i)+' Test AUROC: '+str(auc_test))
    plt.xlabel('FPR')
    plt.ylabel('TPR')
    plt.legend()

    score += auc_test

print("average score: ", score/adv_test_pred.shape[1])
# Out:
# class 0 test auc score: 0.4983887648815398
# class 1 test auc score: 0.5012973551910186
# class 2 test auc score: 0.5039662064776688
# class 3 test auc score: 0.49964794905403415
# class 4 test auc score: 0.4986950718305006
# average score:  0.5003990694869523

# %%
# Save the adversarially trained models
torch.save(final_clas_adv.state_dict(), "/Users/mghrear/data/ML_data/patch/classifier_adv_2021_v9_pass5_FakeGen_1pt05_kaon_run"+str(run)+"_limited.pt")
torch.save(final_adv_adv.state_dict(), "/Users/mghrear/data/ML_data/patch/adversary_adv_2021_v9_pass5_FakeGen_1pt05_kaon_run"+str(run)+"_limited.pt")

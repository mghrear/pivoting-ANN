# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import torch 
from torch import nn, optim
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import sklearn
from sklearn.model_selection import train_test_split
import copy
import mytools


# Print and store device being used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cpu

# %% [markdown]
# # Define important parameters

# %%
# Number of class in invariant mass used by the adversary
Num_classes = 5
# Hyper-parameter for adversarial training of the classifier
lambda_ = 100.0

run = 1

# %% [markdown]
# # Load and setup the data

# %%
# Read tritrig, wab, phiKK, and data files
df_tritrig = pd.read_pickle('/Users/mghrear/data/ML_data/patch/2021_v9_pass5_tritrig_QualCuts.pk')
df_tritrig['PhiKK'] = 0.0
df_phiKK = pd.read_pickle('/Users/mghrear/data/ML_data/patch/2021_v9_pass5_FakeGen_1pt05_kaon_QualCuts.pk')
df_phiKK['PhiKK'] = 1.0
df_wab = pd.read_pickle('/Users/mghrear/data/ML_data/patch/2021_v9_pass5_wab_QualCuts.pk')
df_wab['PhiKK'] = 0.0 # Add label


print("tritrig: ", len(df_tritrig))
print("phiKK: ", len(df_phiKK))
print("wab: ", len(df_wab))
# Out:
# tritrig:  120352
# phiKK:  9853
# wab:  6580

# %%
# Make Training set with 20000 tritrig, 4000 phiKK, 4000 wab
tritrig_train = df_tritrig[0:20000]
wab_train = df_wab[0:3000]
phiKK_train = df_phiKK[0:3000]

# Combine and shuffle all training data
df_train = pd.concat([tritrig_train, phiKK_train, wab_train], ignore_index=True, sort=False)
df_train = df_train.sample(frac=1, random_state=42).reset_index(drop=True)

# Get edges in invariant mass classes for one-hot encoding
# To be used for adverserial labels
# The edges are chosen such that each bin has equal number of background events
one_hot_edges = mytools.get_one_hot_edges(mytools.get_InvM( pd.concat([df_tritrig, df_wab], ignore_index=True, sort=False) ), n_bins=Num_classes)

# Split the training data into training and validation sets
df_train, df_val = train_test_split(df_train, test_size=0.33, random_state=42)

# Make X and y for training and validation sets
# the adverserial network has its own labels
X_train = df_train.drop(columns=['PhiKK'])
y_train = df_train['PhiKK']
y_adv_train = mytools.get_adv_labels( mytools.get_InvM(df_train), one_hot_edges)
X_val = df_val.drop(columns=['PhiKK'])
y_val = df_val['PhiKK']
y_adv_val = mytools.get_adv_labels( mytools.get_InvM(df_val), one_hot_edges)

# Make testing set with remaining events
tritrig_test = df_tritrig[20000:]
tritrig_test['type']= 'tritrig'
wab_test = df_wab[3000:]
wab_test['type']= 'wab'
phiKK_test = df_phiKK[3000:]
phiKK_test['type']= 'phiKK'

df_test = pd.concat([tritrig_test, phiKK_test,wab_test], ignore_index=True, sort=False)
df_test = df_test.sample(frac=1, random_state=42).reset_index(drop=True) # Now shuffle the combined dataframe

X_test = df_test.drop(columns=['PhiKK','type'])
y_test = df_test['PhiKK']
y_adv_test = mytools.get_adv_labels( mytools.get_InvM(df_test), one_hot_edges)

df_test["InvM"] = mytools.get_InvM(df_test)
# Out:
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_56875/1157922432.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tritrig_test['type']= 'tritrig'
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_56875/1157922432.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wab_test['type']= 'wab'
# /var/folders/fx/czrkltw953xcpcjd85tf2tmm0000gn/T/ipykernel_56875/1157922432.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phiKK_test['type']= 'phiKK'

# %% [markdown]
# ## Setup dataloaders

# %%
bsize = 2000

# Convert to tensor dataset and dataloader
train_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy().astype(np.float32))  , torch.from_numpy(y_train.to_numpy().astype(np.float32)).unsqueeze(1)  )
train_loader = DataLoader(train_dataset, batch_size=bsize, shuffle=True)

val_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy().astype(np.float32))  , torch.from_numpy(y_val.to_numpy().astype(np.float32)).unsqueeze(1)  )
val_loader = DataLoader(val_dataset, batch_size=bsize, shuffle=True)

test_dataset = TensorDataset(torch.from_numpy(X_test.to_numpy().astype(np.float32)))
test_loader = DataLoader(test_dataset, batch_size=bsize, shuffle=False)

# %% [markdown]
# ## Initialize model, objective function, and optimizer

# %%
clas = mytools.Classifier(in_features=X_train.shape[1]).to(device)
criterion_clas = nn.BCEWithLogitsLoss()
optimizer_clas = optim.Adam(clas.parameters(), lr=1e-5)
scheduler_clas = torch.optim.lr_scheduler.ExponentialLR(optimizer_clas, gamma=0.9999)

# %% [markdown]
# ## Pre-train the classifier

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 10

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 2500
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train_clas(train_loader, clas, criterion_clas, optimizer_clas, scheduler_clas, device))
    Validation_losses = np.append(Validation_losses, mytools.validate_clas(val_loader, clas, criterion_clas, device))
    
    # Keep a running copy of the model with the lowest loss
    if Validation_losses[-1] == np.min(Validation_losses):
        final_classifier = copy.deepcopy(clas)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Training loss: 0.821067
# Validation loss: 0.746851
#
# Epoch 2
# -------------------------------
# Training loss: 0.795989
# Validation loss: 0.758772
#
# Epoch 3
# -------------------------------
# Training loss: 0.781381
# Validation loss: 0.754237
#
# Epoch 4
# -------------------------------
# Training loss: 0.765399
# Validation loss: 0.756146
#
# Epoch 5
# -------------------------------
# Training loss: 0.755852
# Validation loss: 0.750215
#
# Epoch 6
# -------------------------------
# Training loss: 0.748865
# Validation loss: 0.728407
#
# Epoch 7
# -------------------------------
# Training loss: 0.739673
# Validation loss: 0.731411
#
# Epoch 8
# -------------------------------
# Training loss: 0.732393
# Validation loss: 0.717982
#
# Epoch 9
# -------------------------------
# Training loss: 0.723479
# Validation loss: 0.708110
#
# Epoch 10
# -------------------------------
# Training loss: 0.718492
# Validation loss: 0.706392
#
# Epoch 11
# -------------------------------
# Training loss: 0.714347
# Validation loss: 0.703859
#
# Epoch 12
# -------------------------------
# Training loss: 0.703999
# Validation loss: 0.698228
#
# Epoch 13
# -------------------------------
# Training loss: 0.696682
# Validation loss: 0.693735
#
# Epoch 14
# -------------------------------
# Training loss: 0.692911
# Validation loss: 0.688193
#
# Epoch 15
# -------------------------------
# Training loss: 0.691495
# Validation loss: 0.688329
#
# Epoch 16
# -------------------------------
# Training loss: 0.681281
# Validation loss: 0.687002
#
# Epoch 17
# -------------------------------
# Training loss: 0.684397
# Validation loss: 0.684672
#
# Epoch 18
# -------------------------------
# Training loss: 0.675861
# Validation loss: 0.678424
#
# Epoch 19
# -------------------------------
# Training loss: 0.671805
# Validation loss: 0.679358
#
# Epoch 20
# -------------------------------
# Training loss: 0.669769
# Validation loss: 0.672689
#
# Epoch 21
# -------------------------------
# Training loss: 0.663970
# Validation loss: 0.681633
#
# Epoch 22
# -------------------------------
# Training loss: 0.658839
# Validation loss: 0.674878
#
# Epoch 23
# -------------------------------
# Training loss: 0.653441
# Validation loss: 0.678294
#
# Epoch 24
# -------------------------------
# Training loss: 0.654525
# Validation loss: 0.679597
#
# Epoch 25
# -------------------------------
# Training loss: 0.654578
# Validation loss: 0.668875
#
# Epoch 26
# -------------------------------
# Training loss: 0.644845
# Validation loss: 0.672074
#
# Epoch 27
# -------------------------------
# Training loss: 0.646455
# Validation loss: 0.669554
#
# Epoch 28
# -------------------------------
# Training loss: 0.642058
# Validation loss: 0.655481
#
# Epoch 29
# -------------------------------
# Training loss: 0.636325
# Validation loss: 0.641965
#
# Epoch 30
# -------------------------------
# Training loss: 0.633968
# Validation loss: 0.634939
#
# Epoch 31
# -------------------------------
# Training loss: 0.637287
# Validation loss: 0.634127
#
# Epoch 32
# -------------------------------
# Training loss: 0.627029
# Validation loss: 0.640537
#
# Epoch 33
# -------------------------------
# Training loss: 0.624832
# Validation loss: 0.631840
#
# Epoch 34
# -------------------------------
# Training loss: 0.625284
# Validation loss: 0.626620
#
# Epoch 35
# -------------------------------
# Training loss: 0.620732
# Validation loss: 0.620506
#
# Epoch 36
# -------------------------------
# Training loss: 0.629017
# Validation loss: 0.625877
#
# Epoch 37
# -------------------------------
# Training loss: 0.615972
# Validation loss: 0.622616
#
# Epoch 38
# -------------------------------
# Training loss: 0.616840
# Validation loss: 0.621054
#
# Epoch 39
# -------------------------------
# Training loss: 0.612486
# Validation loss: 0.623508
#
# Epoch 40
# -------------------------------
# Training loss: 0.608513
# Validation loss: 0.617383
#
# Epoch 41
# -------------------------------
# Training loss: 0.613109
# Validation loss: 0.619545
#
# Epoch 42
# -------------------------------
# Training loss: 0.607001
# Validation loss: 0.623085
#
# Epoch 43
# -------------------------------
# Training loss: 0.603836
# Validation loss: 0.616587
#
# Epoch 44
# -------------------------------
# Training loss: 0.598859
# Validation loss: 0.615400
#
# Epoch 45
# -------------------------------
# Training loss: 0.602247
# Validation loss: 0.609354
#
# Epoch 46
# -------------------------------
# Training loss: 0.603074
# Validation loss: 0.611287
#
# Epoch 47
# -------------------------------
# Training loss: 0.593044
# Validation loss: 0.611591
#
# Epoch 48
# -------------------------------
# Training loss: 0.593028
# Validation loss: 0.610353
#
# Epoch 49
# -------------------------------
# Training loss: 0.588972
# Validation loss: 0.610153
#
# Epoch 50
# -------------------------------
# Training loss: 0.586633
# Validation loss: 0.597327
#
# Epoch 51
# -------------------------------
# Training loss: 0.584100
# Validation loss: 0.602821
#
# Epoch 52
# -------------------------------
# Training loss: 0.580425
# Validation loss: 0.594076
#
# Epoch 53
# -------------------------------
# Training loss: 0.578796
# Validation loss: 0.584932
#
# Epoch 54
# -------------------------------
# Training loss: 0.580057
# Validation loss: 0.580413
#
# Epoch 55
# -------------------------------
# Training loss: 0.580707
# Validation loss: 0.602267
#
# Epoch 56
# -------------------------------
# Training loss: 0.578141
# Validation loss: 0.569662
#
# Epoch 57
# -------------------------------
# Training loss: 0.572077
# Validation loss: 0.565500
#
# Epoch 58
# -------------------------------
# Training loss: 0.569159
# Validation loss: 0.578565
#
# Epoch 59
# -------------------------------
# Training loss: 0.567073
# Validation loss: 0.568143
#
# Epoch 60
# -------------------------------
# Training loss: 0.566990
# Validation loss: 0.567701
#
# Epoch 61
# -------------------------------
# Training loss: 0.563252
# Validation loss: 0.568107
#
# Epoch 62
# -------------------------------
# Training loss: 0.562464
# Validation loss: 0.563490
#
# Epoch 63
# -------------------------------
# Training loss: 0.562190
# Validation loss: 0.569382
#
# Epoch 64
# -------------------------------
# Training loss: 0.561841
# Validation loss: 0.567108
#
# Epoch 65
# -------------------------------
# Training loss: 0.555888
# Validation loss: 0.559162
#
# Epoch 66
# -------------------------------
# Training loss: 0.557627
# Validation loss: 0.565103
#
# Epoch 67
# -------------------------------
# Training loss: 0.557023
# Validation loss: 0.561045
#
# Epoch 68
# -------------------------------
# Training loss: 0.552787
# Validation loss: 0.570462
#
# Epoch 69
# -------------------------------
# Training loss: 0.550423
# Validation loss: 0.560718
#
# Epoch 70
# -------------------------------
# Training loss: 0.548702
# Validation loss: 0.562010
#
# Epoch 71
# -------------------------------
# Training loss: 0.546339
# Validation loss: 0.557638
#
# Epoch 72
# -------------------------------
# Training loss: 0.544559
# Validation loss: 0.550363
#
# Epoch 73
# -------------------------------
# Training loss: 0.543604
# Validation loss: 0.547199
#
# Epoch 74
# -------------------------------
# Training loss: 0.540636
# Validation loss: 0.552384
#
# Epoch 75
# -------------------------------
# Training loss: 0.538478
# Validation loss: 0.554761
#
# Epoch 76
# -------------------------------
# Training loss: 0.536617
# Validation loss: 0.536011
#
# Epoch 77
# -------------------------------
# Training loss: 0.535308
# Validation loss: 0.546755
#
# Epoch 78
# -------------------------------
# Training loss: 0.531663
# Validation loss: 0.540164
#
# Epoch 79
# -------------------------------
# Training loss: 0.533866
# Validation loss: 0.526703
#
# Epoch 80
# -------------------------------
# Training loss: 0.534199
# Validation loss: 0.527647
#
# Epoch 81
# -------------------------------
# Training loss: 0.532194
# Validation loss: 0.544750
#
# Epoch 82
# -------------------------------
# Training loss: 0.531114
# Validation loss: 0.554148
#
# Epoch 83
# -------------------------------
# Training loss: 0.525581
# Validation loss: 0.558282
#
# Epoch 84
# -------------------------------
# Training loss: 0.524432
# Validation loss: 0.536594
#
# Epoch 85
# -------------------------------
# Training loss: 0.526784
# Validation loss: 0.532062
#
# Epoch 86
# -------------------------------
# Training loss: 0.527519
# Validation loss: 0.530933
#
# Epoch 87
# -------------------------------
# Training loss: 0.522766
# Validation loss: 0.532633
#
# Epoch 88
# -------------------------------
# Training loss: 0.522539
# Validation loss: 0.531261
#
# Epoch 89
# -------------------------------
# Training loss: 0.518633
# Validation loss: 0.522691
#
# Epoch 90
# -------------------------------
# Training loss: 0.517760
# Validation loss: 0.533455
#
# Epoch 91
# -------------------------------
# Training loss: 0.517863
# Validation loss: 0.515100
#
# Epoch 92
# -------------------------------
# Training loss: 0.517269
# Validation loss: 0.515475
#
# Epoch 93
# -------------------------------
# Training loss: 0.516659
# Validation loss: 0.520871
#
# Epoch 94
# -------------------------------
# Training loss: 0.512602
# Validation loss: 0.505634
#
# Epoch 95
# -------------------------------
# Training loss: 0.509607
# Validation loss: 0.528145
#
# Epoch 96
# -------------------------------
# Training loss: 0.516629
# Validation loss: 0.501033
#
# Epoch 97
# -------------------------------
# Training loss: 0.509156
# Validation loss: 0.515555
#
# Epoch 98
# -------------------------------
# Training loss: 0.510658
# Validation loss: 0.521872
#
# Epoch 99
# -------------------------------
# Training loss: 0.506209
# Validation loss: 0.510492
#
# Epoch 100
# -------------------------------
# Training loss: 0.503357
# Validation loss: 0.517144
#
# Epoch 101
# -------------------------------
# Training loss: 0.505561
# Validation loss: 0.508172
#
# Epoch 102
# -------------------------------
# Training loss: 0.500746
# Validation loss: 0.510470
#
# Epoch 103
# -------------------------------
# Training loss: 0.506322
# Validation loss: 0.508787
#
# Epoch 104
# -------------------------------
# Training loss: 0.500988
# Validation loss: 0.515060
#
# Epoch 105
# -------------------------------
# Training loss: 0.499178
# Validation loss: 0.516320
#
# Epoch 106
# -------------------------------
# Training loss: 0.498064
# Validation loss: 0.514769
#
# Epoch 107
# -------------------------------
# Training loss: 0.497831
# Validation loss: 0.503930
#
# Epoch 108
# -------------------------------
# Training loss: 0.497515
# Validation loss: 0.519428
#
# Epoch 109
# -------------------------------
# Training loss: 0.493462
# Validation loss: 0.526440
#
# Epoch 110
# -------------------------------
# Training loss: 0.491396
# Validation loss: 0.508422
#
# Epoch 111
# -------------------------------
# Training loss: 0.490234
# Validation loss: 0.507474
#
# Epoch 112
# -------------------------------
# Training loss: 0.494911
# Validation loss: 0.492755
#
# Epoch 113
# -------------------------------
# Training loss: 0.490497
# Validation loss: 0.529298
#
# Epoch 114
# -------------------------------
# Training loss: 0.489059
# Validation loss: 0.537757
#
# Epoch 115
# -------------------------------
# Training loss: 0.487015
# Validation loss: 0.522554
#
# Epoch 116
# -------------------------------
# Training loss: 0.489654
# Validation loss: 0.505714
#
# Epoch 117
# -------------------------------
# Training loss: 0.485372
# Validation loss: 0.494864
#
# Epoch 118
# -------------------------------
# Training loss: 0.484874
# Validation loss: 0.496065
#
# Epoch 119
# -------------------------------
# Training loss: 0.483929
# Validation loss: 0.497430
#
# Epoch 120
# -------------------------------
# Training loss: 0.482997
# Validation loss: 0.489754
#
# Epoch 121
# -------------------------------
# Training loss: 0.480215
# Validation loss: 0.493494
#
# Epoch 122
# -------------------------------
# Training loss: 0.479138
# Validation loss: 0.490102
#
# Epoch 123
# -------------------------------
# Training loss: 0.480559
# Validation loss: 0.490593
#
# Epoch 124
# -------------------------------
# Training loss: 0.482270
# Validation loss: 0.505741
#
# Epoch 125
# -------------------------------
# Training loss: 0.474663
# Validation loss: 0.497015
#
# Epoch 126
# -------------------------------
# Training loss: 0.475998
# Validation loss: 0.487828
#
# Epoch 127
# -------------------------------
# Training loss: 0.478386
# Validation loss: 0.500575
#
# Epoch 128
# -------------------------------
# Training loss: 0.472561
# Validation loss: 0.474164
#
# Epoch 129
# -------------------------------
# Training loss: 0.472219
# Validation loss: 0.485538
#
# Epoch 130
# -------------------------------
# Training loss: 0.476406
# Validation loss: 0.492727
#
# Epoch 131
# -------------------------------
# Training loss: 0.471880
# Validation loss: 0.487751
#
# Epoch 132
# -------------------------------
# Training loss: 0.467782
# Validation loss: 0.483453
#
# Epoch 133
# -------------------------------
# Training loss: 0.469482
# Validation loss: 0.491969
#
# Epoch 134
# -------------------------------
# Training loss: 0.466925
# Validation loss: 0.540699
#
# Epoch 135
# -------------------------------
# Training loss: 0.464456
# Validation loss: 0.467616
#
# Epoch 136
# -------------------------------
# Training loss: 0.470433
# Validation loss: 0.455128
#
# Epoch 137
# -------------------------------
# Training loss: 0.465308
# Validation loss: 0.502539
#
# Epoch 138
# -------------------------------
# Training loss: 0.466829
# Validation loss: 0.472777
#
# Epoch 139
# -------------------------------
# Training loss: 0.460855
# Validation loss: 0.491458
#
# Epoch 140
# -------------------------------
# Training loss: 0.462252
# Validation loss: 0.470032
#
# Epoch 141
# -------------------------------
# Training loss: 0.459337
# Validation loss: 0.474485
#
# Epoch 142
# -------------------------------
# Training loss: 0.461759
# Validation loss: 0.476862
#
# Epoch 143
# -------------------------------
# Training loss: 0.463928
# Validation loss: 0.469678
#
# Epoch 144
# -------------------------------
# Training loss: 0.466423
# Validation loss: 0.506480
#
# Epoch 145
# -------------------------------
# Training loss: 0.465172
# Validation loss: 0.457551
#
# Epoch 146
# -------------------------------
# Training loss: 0.459764
# Validation loss: 0.478148
#
# Epoch 147
# -------------------------------
# Training loss: 0.456892
# Validation loss: 0.508633
#
# Epoch 148
# -------------------------------
# Training loss: 0.454718
# Validation loss: 0.479891
#
# Epoch 149
# -------------------------------
# Training loss: 0.453042
# Validation loss: 0.457502
#
# Epoch 150
# -------------------------------
# Training loss: 0.451557
# Validation loss: 0.470930
#
# Epoch 151
# -------------------------------
# Training loss: 0.451880
# Validation loss: 0.465592
#
# Epoch 152
# -------------------------------
# Training loss: 0.449231
# Validation loss: 0.478822
#
# Epoch 153
# -------------------------------
# Training loss: 0.444872
# Validation loss: 0.456675
#
# Epoch 154
# -------------------------------
# Training loss: 0.446007
# Validation loss: 0.467406
#
# Epoch 155
# -------------------------------
# Training loss: 0.448306
# Validation loss: 0.451153
#
# Epoch 156
# -------------------------------
# Training loss: 0.445233
# Validation loss: 0.456154
#
# Epoch 157
# -------------------------------
# Training loss: 0.443354
# Validation loss: 0.489591
#
# Epoch 158
# -------------------------------
# Training loss: 0.442660
# Validation loss: 0.444906
#
# Epoch 159
# -------------------------------
# Training loss: 0.440361
# Validation loss: 0.471504
#
# Epoch 160
# -------------------------------
# Training loss: 0.440317
# Validation loss: 0.473635
#
# Epoch 161
# -------------------------------
# Training loss: 0.445037
# Validation loss: 0.462398
#
# Epoch 162
# -------------------------------
# Training loss: 0.451172
# Validation loss: 0.476534
#
# Epoch 163
# -------------------------------
# Training loss: 0.438010
# Validation loss: 0.484638
#
# Epoch 164
# -------------------------------
# Training loss: 0.438335
# Validation loss: 0.445103
#
# Epoch 165
# -------------------------------
# Training loss: 0.431743
# Validation loss: 0.440738
#
# Epoch 166
# -------------------------------
# Training loss: 0.439422
# Validation loss: 0.470348
#
# Epoch 167
# -------------------------------
# Training loss: 0.436113
# Validation loss: 0.458360
#
# Epoch 168
# -------------------------------
# Training loss: 0.441409
# Validation loss: 0.468562
#
# Epoch 169
# -------------------------------
# Training loss: 0.436749
# Validation loss: 0.438229
#
# Epoch 170
# -------------------------------
# Training loss: 0.432406
# Validation loss: 0.518574
#
# Epoch 171
# -------------------------------
# Training loss: 0.439389
# Validation loss: 0.473690
#
# Epoch 172
# -------------------------------
# Training loss: 0.428783
# Validation loss: 0.421019
#
# Epoch 173
# -------------------------------
# Training loss: 0.430228
# Validation loss: 0.453156
#
# Epoch 174
# -------------------------------
# Training loss: 0.431575
# Validation loss: 0.439297
#
# Epoch 175
# -------------------------------
# Training loss: 0.425472
# Validation loss: 0.459579
#
# Epoch 176
# -------------------------------
# Training loss: 0.427358
# Validation loss: 0.465466
#
# Epoch 177
# -------------------------------
# Training loss: 0.421129
# Validation loss: 0.452584
#
# Epoch 178
# -------------------------------
# Training loss: 0.430634
# Validation loss: 0.414272
#
# Epoch 179
# -------------------------------
# Training loss: 0.420659
# Validation loss: 0.433592
#
# Epoch 180
# -------------------------------
# Training loss: 0.420072
# Validation loss: 0.431122
#
# Epoch 181
# -------------------------------
# Training loss: 0.424816
# Validation loss: 0.479709
#
# Epoch 182
# -------------------------------
# Training loss: 0.431131
# Validation loss: 0.459699
#
# Epoch 183
# -------------------------------
# Training loss: 0.424578
# Validation loss: 0.480486
#
# Epoch 184
# -------------------------------
# Training loss: 0.421297
# Validation loss: 0.424810
#
# Epoch 185
# -------------------------------
# Training loss: 0.423033
# Validation loss: 0.422881
#
# Epoch 186
# -------------------------------
# Training loss: 0.415234
# Validation loss: 0.432060
#
# Epoch 187
# -------------------------------
# Training loss: 0.412951
# Validation loss: 0.456881
#
# Epoch 188
# -------------------------------
# Training loss: 0.418612
# Validation loss: 0.436147
#
# Epoch 189
# -------------------------------
# Training loss: 0.413943
# Validation loss: 0.455147
#
# Epoch 190
# -------------------------------
# Training loss: 0.413799
# Validation loss: 0.425492
#
# Epoch 191
# -------------------------------
# Training loss: 0.413556
# Validation loss: 0.410769
#
# Epoch 192
# -------------------------------
# Training loss: 0.420269
# Validation loss: 0.409954
#
# Epoch 193
# -------------------------------
# Training loss: 0.419634
# Validation loss: 0.392711
#
# Epoch 194
# -------------------------------
# Training loss: 0.416733
# Validation loss: 0.400095
#
# Epoch 195
# -------------------------------
# Training loss: 0.416330
# Validation loss: 0.444596
#
# Epoch 196
# -------------------------------
# Training loss: 0.412324
# Validation loss: 0.458371
#
# Epoch 197
# -------------------------------
# Training loss: 0.408189
# Validation loss: 0.440920
#
# Epoch 198
# -------------------------------
# Training loss: 0.410961
# Validation loss: 0.449649
#
# Epoch 199
# -------------------------------
# Training loss: 0.409030
# Validation loss: 0.420859
#
# Epoch 200
# -------------------------------
# Training loss: 0.404122
# Validation loss: 0.438101
#
# Epoch 201
# -------------------------------
# Training loss: 0.405922
# Validation loss: 0.451234
#
# Epoch 202
# -------------------------------
# Training loss: 0.403269
# Validation loss: 0.397494
#
# Epoch 203
# -------------------------------
# Training loss: 0.404348
# Validation loss: 0.402090
#
# Epoch 204
# -------------------------------
# Training loss: 0.399192
# Validation loss: 0.420101
#
# Epoch 205
# -------------------------------
# Training loss: 0.395097
# Validation loss: 0.448124
#
# Epoch 206
# -------------------------------
# Training loss: 0.399225
# Validation loss: 0.403317
#
# Epoch 207
# -------------------------------
# Training loss: 0.406048
# Validation loss: 0.377833
#
# Epoch 208
# -------------------------------
# Training loss: 0.399263
# Validation loss: 0.435037
#
# Epoch 209
# -------------------------------
# Training loss: 0.395346
# Validation loss: 0.444293
#
# Epoch 210
# -------------------------------
# Training loss: 0.404913
# Validation loss: 0.457958
#
# Epoch 211
# -------------------------------
# Training loss: 0.402198
# Validation loss: 0.494014
#
# Epoch 212
# -------------------------------
# Training loss: 0.399841
# Validation loss: 0.542037
#
# Epoch 213
# -------------------------------
# Training loss: 0.398844
# Validation loss: 0.475870
#
# Epoch 214
# -------------------------------
# Training loss: 0.397932
# Validation loss: 0.469597
#
# Epoch 215
# -------------------------------
# Training loss: 0.388120
# Validation loss: 0.462395
#
# Epoch 216
# -------------------------------
# Training loss: 0.393780
# Validation loss: 0.495321
#
# Epoch 217
# -------------------------------
# Training loss: 0.393391
# Validation loss: 0.442318
#
# Epoch 218
# -------------------------------
# Training loss: 0.401711
# Validation loss: 0.381043
#
# Epoch 219
# -------------------------------
# Training loss: 0.382473
# Validation loss: 0.375105
#
# Epoch 220
# -------------------------------
# Training loss: 0.389473
# Validation loss: 0.380730
#
# Epoch 221
# -------------------------------
# Training loss: 0.384259
# Validation loss: 0.413589
#
# Epoch 222
# -------------------------------
# Training loss: 0.386798
# Validation loss: 0.468251
#
# Epoch 223
# -------------------------------
# Training loss: 0.388797
# Validation loss: 0.412832
#
# Epoch 224
# -------------------------------
# Training loss: 0.378854
# Validation loss: 0.403223
#
# Epoch 225
# -------------------------------
# Training loss: 0.392520
# Validation loss: 0.429059
#
# Epoch 226
# -------------------------------
# Training loss: 0.382492
# Validation loss: 0.429304
#
# Epoch 227
# -------------------------------
# Training loss: 0.378782
# Validation loss: 0.475616
#
# Epoch 228
# -------------------------------
# Training loss: 0.379218
# Validation loss: 0.431537
#
# Epoch 229
# -------------------------------
# Training loss: 0.399534
# Validation loss: 0.379740
#
# Epoch 230
# -------------------------------
# Training loss: 0.386056
# Validation loss: 0.405119
#
# Epoch 231
# -------------------------------
# Training loss: 0.380491
# Validation loss: 0.380382
#
# Epoch 232
# -------------------------------
# Training loss: 0.375241
# Validation loss: 0.393177
#
# Epoch 233
# -------------------------------
# Training loss: 0.378687
# Validation loss: 0.434637
#
# Epoch 234
# -------------------------------
# Training loss: 0.372972
# Validation loss: 0.391514
#
# Epoch 235
# -------------------------------
# Training loss: 0.385194
# Validation loss: 0.410629
#
# Epoch 236
# -------------------------------
# Training loss: 0.381415
# Validation loss: 0.406029
#
# Epoch 237
# -------------------------------
# Training loss: 0.375009
# Validation loss: 0.376341
#
# Epoch 238
# -------------------------------
# Training loss: 0.371588
# Validation loss: 0.432712
#
# Epoch 239
# -------------------------------
# Training loss: 0.374602
# Validation loss: 0.433256
#
# Epoch 240
# -------------------------------
# Training loss: 0.370547
# Validation loss: 0.375241
#
# Epoch 241
# -------------------------------
# Training loss: 0.370560
# Validation loss: 0.417481
#
# Epoch 242
# -------------------------------
# Training loss: 0.362974
# Validation loss: 0.414853
#
# Epoch 243
# -------------------------------
# Training loss: 0.360909
# Validation loss: 0.390207
#
# Epoch 244
# -------------------------------
# Training loss: 0.367587
# Validation loss: 0.488480
#
# Epoch 245
# -------------------------------
# Training loss: 0.375512
# Validation loss: 0.355973
#
# Epoch 246
# -------------------------------
# Training loss: 0.365200
# Validation loss: 0.365135
#
# Epoch 247
# -------------------------------
# Training loss: 0.365755
# Validation loss: 0.402343
#
# Epoch 248
# -------------------------------
# Training loss: 0.360916
# Validation loss: 0.367417
#
# Epoch 249
# -------------------------------
# Training loss: 0.360095
# Validation loss: 0.382890
#
# Epoch 250
# -------------------------------
# Training loss: 0.367390
# Validation loss: 0.360261
#
# Epoch 251
# -------------------------------
# Training loss: 0.355196
# Validation loss: 0.354803
#
# Epoch 252
# -------------------------------
# Training loss: 0.363648
# Validation loss: 0.392880
#
# Epoch 253
# -------------------------------
# Training loss: 0.363167
# Validation loss: 0.368310
#
# Epoch 254
# -------------------------------
# Training loss: 0.363289
# Validation loss: 0.369007
#
# Epoch 255
# -------------------------------
# Training loss: 0.353110
# Validation loss: 0.452878
#
# Epoch 256
# -------------------------------
# Training loss: 0.355237
# Validation loss: 0.424316
#
# Epoch 257
# -------------------------------
# Training loss: 0.355132
# Validation loss: 0.446590
#
# Epoch 258
# -------------------------------
# Training loss: 0.363318
# Validation loss: 0.388673
#
# Epoch 259
# -------------------------------
# Training loss: 0.358607
# Validation loss: 0.394156
#
# Epoch 260
# -------------------------------
# Training loss: 0.359453
# Validation loss: 0.455172
#
# Epoch 261
# -------------------------------
# Training loss: 0.358709
# Validation loss: 0.374625
#
# Epoch 262
# -------------------------------
# Training loss: 0.351185
# Validation loss: 0.354095
#
# Epoch 263
# -------------------------------
# Training loss: 0.350027
# Validation loss: 0.431876
#
# Epoch 264
# -------------------------------
# Training loss: 0.359337
# Validation loss: 0.384972
#
# Epoch 265
# -------------------------------
# Training loss: 0.360178
# Validation loss: 0.537182
#
# Epoch 266
# -------------------------------
# Training loss: 0.359212
# Validation loss: 0.396784
#
# Epoch 267
# -------------------------------
# Training loss: 0.349748
# Validation loss: 0.363340
#
# Epoch 268
# -------------------------------
# Training loss: 0.345645
# Validation loss: 0.338347
#
# Epoch 269
# -------------------------------
# Training loss: 0.345517
# Validation loss: 0.433785
#
# Epoch 270
# -------------------------------
# Training loss: 0.343425
# Validation loss: 0.408597
#
# Epoch 271
# -------------------------------
# Training loss: 0.339568
# Validation loss: 0.412071
#
# Epoch 272
# -------------------------------
# Training loss: 0.343190
# Validation loss: 0.462629
#
# Epoch 273
# -------------------------------
# Training loss: 0.347066
# Validation loss: 0.433185
#
# Epoch 274
# -------------------------------
# Training loss: 0.355715
# Validation loss: 0.473042
#
# Epoch 275
# -------------------------------
# Training loss: 0.358149
# Validation loss: 0.369931
#
# Epoch 276
# -------------------------------
# Training loss: 0.346030
# Validation loss: 0.385717
#
# Epoch 277
# -------------------------------
# Training loss: 0.353839
# Validation loss: 0.342648
#
# Epoch 278
# -------------------------------
# Training loss: 0.349415
# Validation loss: 0.346687
#
# Epoch 279
# -------------------------------
# Training loss: 0.342466
# Validation loss: 0.337505
#
# Epoch 280
# -------------------------------
# Training loss: 0.342132
# Validation loss: 0.415485
#
# Epoch 281
# -------------------------------
# Training loss: 0.340256
# Validation loss: 0.388668
#
# Epoch 282
# -------------------------------
# Training loss: 0.331700
# Validation loss: 0.391118
#
# Epoch 283
# -------------------------------
# Training loss: 0.331141
# Validation loss: 0.397182
#
# Epoch 284
# -------------------------------
# Training loss: 0.340388
# Validation loss: 0.433053
#
# Epoch 285
# -------------------------------
# Training loss: 0.338691
# Validation loss: 0.334436
#
# Epoch 286
# -------------------------------
# Training loss: 0.333541
# Validation loss: 0.336435
#
# Epoch 287
# -------------------------------
# Training loss: 0.335003
# Validation loss: 0.409663
#
# Epoch 288
# -------------------------------
# Training loss: 0.335093
# Validation loss: 0.355546
#
# Epoch 289
# -------------------------------
# Training loss: 0.332110
# Validation loss: 0.406878
#
# Epoch 290
# -------------------------------
# Training loss: 0.329037
# Validation loss: 0.385461
#
# Epoch 291
# -------------------------------
# Training loss: 0.332743
# Validation loss: 0.405783
#
# Epoch 292
# -------------------------------
# Training loss: 0.337796
# Validation loss: 0.355435
#
# Epoch 293
# -------------------------------
# Training loss: 0.329748
# Validation loss: 0.322019
#
# Epoch 294
# -------------------------------
# Training loss: 0.329911
# Validation loss: 0.399424
#
# Epoch 295
# -------------------------------
# Training loss: 0.342808
# Validation loss: 0.363121
#
# Epoch 296
# -------------------------------
# Training loss: 0.331228
# Validation loss: 0.340410
#
# Epoch 297
# -------------------------------
# Training loss: 0.336794
# Validation loss: 0.418714
#
# Epoch 298
# -------------------------------
# Training loss: 0.329888
# Validation loss: 0.416589
#
# Epoch 299
# -------------------------------
# Training loss: 0.325473
# Validation loss: 0.335277
#
# Epoch 300
# -------------------------------
# Training loss: 0.324451
# Validation loss: 0.349871
#
# Epoch 301
# -------------------------------
# Training loss: 0.321827
# Validation loss: 0.354074
#
# Epoch 302
# -------------------------------
# Training loss: 0.323775
# Validation loss: 0.416300
#
# Epoch 303
# -------------------------------
# Training loss: 0.320923
# Validation loss: 0.409712
#
# Epoch 304
# -------------------------------
# Training loss: 0.319460
# Validation loss: 0.393006
#
# Epoch 305
# -------------------------------
# Training loss: 0.320545
# Validation loss: 0.381603
#
# Epoch 306
# -------------------------------
# Training loss: 0.323802
# Validation loss: 0.345791
#
# Epoch 307
# -------------------------------
# Training loss: 0.318157
# Validation loss: 0.335056
#
# Epoch 308
# -------------------------------
# Training loss: 0.317072
# Validation loss: 0.403367
#
# Epoch 309
# -------------------------------
# Training loss: 0.314302
# Validation loss: 0.325739
#
# Epoch 310
# -------------------------------
# Training loss: 0.325273
# Validation loss: 0.314542
#
# Epoch 311
# -------------------------------
# Training loss: 0.312916
# Validation loss: 0.317991
#
# Epoch 312
# -------------------------------
# Training loss: 0.314667
# Validation loss: 0.429474
#
# Epoch 313
# -------------------------------
# Training loss: 0.310503
# Validation loss: 0.480411
#
# Epoch 314
# -------------------------------
# Training loss: 0.320585
# Validation loss: 0.398197
#
# Epoch 315
# -------------------------------
# Training loss: 0.313759
# Validation loss: 0.308698
#
# Epoch 316
# -------------------------------
# Training loss: 0.313499
# Validation loss: 0.349863
#
# Epoch 317
# -------------------------------
# Training loss: 0.315683
# Validation loss: 0.355463
#
# Epoch 318
# -------------------------------
# Training loss: 0.310609
# Validation loss: 0.388092
#
# Epoch 319
# -------------------------------
# Training loss: 0.312263
# Validation loss: 0.361832
#
# Epoch 320
# -------------------------------
# Training loss: 0.308108
# Validation loss: 0.382775
#
# Epoch 321
# -------------------------------
# Training loss: 0.323563
# Validation loss: 0.347640
#
# Epoch 322
# -------------------------------
# Training loss: 0.318904
# Validation loss: 0.303424
#
# Epoch 323
# -------------------------------
# Training loss: 0.304768
# Validation loss: 0.383209
#
# Epoch 324
# -------------------------------
# Training loss: 0.308746
# Validation loss: 0.422429
#
# Epoch 325
# -------------------------------
# Training loss: 0.307218
# Validation loss: 0.369772
#
# Epoch 326
# -------------------------------
# Training loss: 0.309055
# Validation loss: 0.407792
#
# Epoch 327
# -------------------------------
# Training loss: 0.301132
# Validation loss: 0.343646
#
# Epoch 328
# -------------------------------
# Training loss: 0.310125
# Validation loss: 0.395297
#
# Epoch 329
# -------------------------------
# Training loss: 0.305815
# Validation loss: 0.337701
#
# Epoch 330
# -------------------------------
# Training loss: 0.309423
# Validation loss: 0.401683
#
# Epoch 331
# -------------------------------
# Training loss: 0.308167
# Validation loss: 0.371478
#
# Epoch 332
# -------------------------------
# Training loss: 0.303789
# Validation loss: 0.394025
#
# Epoch 333
# -------------------------------
# Training loss: 0.307666
# Validation loss: 0.302026
#
# Epoch 334
# -------------------------------
# Training loss: 0.302049
# Validation loss: 0.355557
#
# Epoch 335
# -------------------------------
# Training loss: 0.301879
# Validation loss: 0.314373
#
# Epoch 336
# -------------------------------
# Training loss: 0.317804
# Validation loss: 0.315949
#
# Epoch 337
# -------------------------------
# Training loss: 0.301520
# Validation loss: 0.341121
#
# Epoch 338
# -------------------------------
# Training loss: 0.306131
# Validation loss: 0.436098
#
# Epoch 339
# -------------------------------
# Training loss: 0.309364
# Validation loss: 0.296733
#
# Epoch 340
# -------------------------------
# Training loss: 0.302212
# Validation loss: 0.301708
#
# Epoch 341
# -------------------------------
# Training loss: 0.301830
# Validation loss: 0.368794
#
# Epoch 342
# -------------------------------
# Training loss: 0.306746
# Validation loss: 0.351795
#
# Epoch 343
# -------------------------------
# Training loss: 0.304021
# Validation loss: 0.292381
#
# Epoch 344
# -------------------------------
# Training loss: 0.307039
# Validation loss: 0.313898
#
# Epoch 345
# -------------------------------
# Training loss: 0.293040
# Validation loss: 0.312896
#
# Epoch 346
# -------------------------------
# Training loss: 0.299935
# Validation loss: 0.317173
#
# Epoch 347
# -------------------------------
# Training loss: 0.303618
# Validation loss: 0.324503
#
# Epoch 348
# -------------------------------
# Training loss: 0.299524
# Validation loss: 0.372698
#
# Epoch 349
# -------------------------------
# Training loss: 0.301445
# Validation loss: 0.401363
#
# Epoch 350
# -------------------------------
# Training loss: 0.305598
# Validation loss: 0.405296
#
# Epoch 351
# -------------------------------
# Training loss: 0.293647
# Validation loss: 0.333368
#
# Epoch 352
# -------------------------------
# Training loss: 0.292258
# Validation loss: 0.377486
#
# Epoch 353
# -------------------------------
# Training loss: 0.287393
# Validation loss: 0.330293
#
# Epoch 354
# -------------------------------
# Training loss: 0.304971
# Validation loss: 0.307895
#
# Epoch 355
# -------------------------------
# Training loss: 0.293391
# Validation loss: 0.287824
#
# Epoch 356
# -------------------------------
# Training loss: 0.309120
# Validation loss: 0.310156
#
# Epoch 357
# -------------------------------
# Training loss: 0.304852
# Validation loss: 0.311055
#
# Epoch 358
# -------------------------------
# Training loss: 0.291884
# Validation loss: 0.305732
#
# Epoch 359
# -------------------------------
# Training loss: 0.291464
# Validation loss: 0.332097
#
# Epoch 360
# -------------------------------
# Training loss: 0.287396
# Validation loss: 0.298469
#
# Epoch 361
# -------------------------------
# Training loss: 0.293826
# Validation loss: 0.297727
#
# Epoch 362
# -------------------------------
# Training loss: 0.293496
# Validation loss: 0.374836
#
# Epoch 363
# -------------------------------
# Training loss: 0.288038
# Validation loss: 0.326957
#
# Epoch 364
# -------------------------------
# Training loss: 0.292623
# Validation loss: 0.381469
#
# Epoch 365
# -------------------------------
# Training loss: 0.290043
# Validation loss: 0.356603
#
# Epoch 366
# -------------------------------
# Training loss: 0.292602
# Validation loss: 0.395882
#
# Epoch 367
# -------------------------------
# Training loss: 0.287954
# Validation loss: 0.399001
#
# Epoch 368
# -------------------------------
# Training loss: 0.284285
# Validation loss: 0.345996
#
# Epoch 369
# -------------------------------
# Training loss: 0.282083
# Validation loss: 0.343799
#
# Epoch 370
# -------------------------------
# Training loss: 0.280772
# Validation loss: 0.270583
#
# Epoch 371
# -------------------------------
# Training loss: 0.292123
# Validation loss: 0.315269
#
# Epoch 372
# -------------------------------
# Training loss: 0.297551
# Validation loss: 0.296051
#
# Epoch 373
# -------------------------------
# Training loss: 0.288082
# Validation loss: 0.418827
#
# Epoch 374
# -------------------------------
# Training loss: 0.300391
# Validation loss: 0.373642
#
# Epoch 375
# -------------------------------
# Training loss: 0.290187
# Validation loss: 0.329891
#
# Epoch 376
# -------------------------------
# Training loss: 0.280263
# Validation loss: 0.305712
#
# Epoch 377
# -------------------------------
# Training loss: 0.284594
# Validation loss: 0.340459
#
# Epoch 378
# -------------------------------
# Training loss: 0.286786
# Validation loss: 0.310914
#
# Epoch 379
# -------------------------------
# Training loss: 0.281723
# Validation loss: 0.294972
#
# Epoch 380
# -------------------------------
# Training loss: 0.281700
# Validation loss: 0.303551
#
# Epoch 381
# -------------------------------
# Training loss: 0.282552
# Validation loss: 0.355235
#
# Epoch 382
# -------------------------------
# Training loss: 0.284243
# Validation loss: 0.290698
#
# Epoch 383
# -------------------------------
# Training loss: 0.284446
# Validation loss: 0.307314
#
# Epoch 384
# -------------------------------
# Training loss: 0.284231
# Validation loss: 0.288885
#
# Epoch 385
# -------------------------------
# Training loss: 0.276715
# Validation loss: 0.287644
#
# Epoch 386
# -------------------------------
# Training loss: 0.282583
# Validation loss: 0.453658
#
# Epoch 387
# -------------------------------
# Training loss: 0.276178
# Validation loss: 0.271038
#
# Epoch 388
# -------------------------------
# Training loss: 0.277167
# Validation loss: 0.298566
#
# Epoch 389
# -------------------------------
# Training loss: 0.277863
# Validation loss: 0.327514
#
# Epoch 390
# -------------------------------
# Training loss: 0.280272
# Validation loss: 0.391377
#
# Epoch 391
# -------------------------------
# Training loss: 0.281499
# Validation loss: 0.427800
#
# Epoch 392
# -------------------------------
# Training loss: 0.278761
# Validation loss: 0.317543
#
# Epoch 393
# -------------------------------
# Training loss: 0.278750
# Validation loss: 0.268896
#
# Epoch 394
# -------------------------------
# Training loss: 0.289532
# Validation loss: 0.281399
#
# Epoch 395
# -------------------------------
# Training loss: 0.271890
# Validation loss: 0.295394
#
# Epoch 396
# -------------------------------
# Training loss: 0.276429
# Validation loss: 0.314327
#
# Epoch 397
# -------------------------------
# Training loss: 0.275582
# Validation loss: 0.344362
#
# Epoch 398
# -------------------------------
# Training loss: 0.269045
# Validation loss: 0.408980
#
# Epoch 399
# -------------------------------
# Training loss: 0.266555
# Validation loss: 0.281180
#
# Epoch 400
# -------------------------------
# Training loss: 0.268877
# Validation loss: 0.292037
#
# Epoch 401
# -------------------------------
# Training loss: 0.266002
# Validation loss: 0.335672
#
# Epoch 402
# -------------------------------
# Training loss: 0.269146
# Validation loss: 0.319523
#
# Epoch 403
# -------------------------------
# Training loss: 0.266090
# Validation loss: 0.329286
#
# Epoch 404
# -------------------------------
# Training loss: 0.264538
# Validation loss: 0.315372
#
# Epoch 405
# -------------------------------
# Training loss: 0.265852
# Validation loss: 0.287814
#
# Epoch 406
# -------------------------------
# Training loss: 0.272356
# Validation loss: 0.296292
#
# Epoch 407
# -------------------------------
# Training loss: 0.268710
# Validation loss: 0.331286
#
# Epoch 408
# -------------------------------
# Training loss: 0.272421
# Validation loss: 0.333956
#
# Epoch 409
# -------------------------------
# Training loss: 0.265823
# Validation loss: 0.304829
#
# Epoch 410
# -------------------------------
# Training loss: 0.269510
# Validation loss: 0.324271
#
# Epoch 411
# -------------------------------
# Training loss: 0.269542
# Validation loss: 0.308485
#
# Epoch 412
# -------------------------------
# Training loss: 0.281612
# Validation loss: 0.265543
#
# Epoch 413
# -------------------------------
# Training loss: 0.267514
# Validation loss: 0.265486
#
# Epoch 414
# -------------------------------
# Training loss: 0.267874
# Validation loss: 0.312819
#
# Epoch 415
# -------------------------------
# Training loss: 0.269879
# Validation loss: 0.360095
#
# Epoch 416
# -------------------------------
# Training loss: 0.273064
# Validation loss: 0.311194
#
# Epoch 417
# -------------------------------
# Training loss: 0.285986
# Validation loss: 0.286822
#
# Epoch 418
# -------------------------------
# Training loss: 0.276142
# Validation loss: 0.283712
#
# Epoch 419
# -------------------------------
# Training loss: 0.269918
# Validation loss: 0.307749
#
# Epoch 420
# -------------------------------
# Training loss: 0.259149
# Validation loss: 0.343339
#
# Epoch 421
# -------------------------------
# Training loss: 0.257704
# Validation loss: 0.345093
#
# Epoch 422
# -------------------------------
# Training loss: 0.260244
# Validation loss: 0.278426
#
# Epoch 423
# -------------------------------
# Training loss: 0.260419
# Validation loss: 0.269506
#
# Epoch 424
# -------------------------------
# Training loss: 0.260669
# Validation loss: 0.337657
#
# Epoch 425
# -------------------------------
# Training loss: 0.256088
# Validation loss: 0.300602
#
# Epoch 426
# -------------------------------
# Training loss: 0.256696
# Validation loss: 0.347261
#
# Epoch 427
# -------------------------------
# Training loss: 0.266354
# Validation loss: 0.381390
#
# Epoch 428
# -------------------------------
# Training loss: 0.260011
# Validation loss: 0.281877
#
# Epoch 429
# -------------------------------
# Training loss: 0.278036
# Validation loss: 0.284854
#
# Epoch 430
# -------------------------------
# Training loss: 0.257539
# Validation loss: 0.267586
#
# Epoch 431
# -------------------------------
# Training loss: 0.259844
# Validation loss: 0.250740
#
# Epoch 432
# -------------------------------
# Training loss: 0.262081
# Validation loss: 0.311449
#
# Epoch 433
# -------------------------------
# Training loss: 0.254614
# Validation loss: 0.333392
#
# Epoch 434
# -------------------------------
# Training loss: 0.256738
# Validation loss: 0.278594
#
# Epoch 435
# -------------------------------
# Training loss: 0.256402
# Validation loss: 0.314449
#
# Epoch 436
# -------------------------------
# Training loss: 0.256058
# Validation loss: 0.266401
#
# Epoch 437
# -------------------------------
# Training loss: 0.252158
# Validation loss: 0.315810
#
# Epoch 438
# -------------------------------
# Training loss: 0.255238
# Validation loss: 0.287634
#
# Epoch 439
# -------------------------------
# Training loss: 0.256120
# Validation loss: 0.300810
#
# Epoch 440
# -------------------------------
# Training loss: 0.251194
# Validation loss: 0.313733
#
# Epoch 441
# -------------------------------
# Training loss: 0.247253
# Validation loss: 0.266236
#
# Epoch 442
# -------------------------------
# Training loss: 0.249391
# Validation loss: 0.261919
#
# Epoch 443
# -------------------------------
# Training loss: 0.251692
# Validation loss: 0.376382
#
# Epoch 444
# -------------------------------
# Training loss: 0.265404
# Validation loss: 0.253136
#
# Epoch 445
# -------------------------------
# Training loss: 0.271660
# Validation loss: 0.270973
#
# Epoch 446
# -------------------------------
# Training loss: 0.257641
# Validation loss: 0.276932
#
# Epoch 447
# -------------------------------
# Training loss: 0.249178
# Validation loss: 0.254351
#
# Epoch 448
# -------------------------------
# Training loss: 0.250924
# Validation loss: 0.273422
#
# Epoch 449
# -------------------------------
# Training loss: 0.244627
# Validation loss: 0.279725
#
# Epoch 450
# -------------------------------
# Training loss: 0.250055
# Validation loss: 0.256967
#
# Epoch 451
# -------------------------------
# Training loss: 0.248455
# Validation loss: 0.282911
#
# Epoch 452
# -------------------------------
# Training loss: 0.246077
# Validation loss: 0.271410
#
# Epoch 453
# -------------------------------
# Training loss: 0.246296
# Validation loss: 0.330541
#
# Epoch 454
# -------------------------------
# Training loss: 0.244710
# Validation loss: 0.283551
#
# Epoch 455
# -------------------------------
# Training loss: 0.249695
# Validation loss: 0.249474
#
# Epoch 456
# -------------------------------
# Training loss: 0.250553
# Validation loss: 0.319910
#
# Epoch 457
# -------------------------------
# Training loss: 0.253756
# Validation loss: 0.300222
#
# Epoch 458
# -------------------------------
# Training loss: 0.264001
# Validation loss: 0.322815
#
# Epoch 459
# -------------------------------
# Training loss: 0.256060
# Validation loss: 0.255607
#
# Epoch 460
# -------------------------------
# Training loss: 0.252940
# Validation loss: 0.265719
#
# Epoch 461
# -------------------------------
# Training loss: 0.241587
# Validation loss: 0.260663
#
# Epoch 462
# -------------------------------
# Training loss: 0.245377
# Validation loss: 0.275133
#
# Epoch 463
# -------------------------------
# Training loss: 0.240815
# Validation loss: 0.276240
#
# Epoch 464
# -------------------------------
# Training loss: 0.248826
# Validation loss: 0.292250
#
# Epoch 465
# -------------------------------
# Training loss: 0.240192
# Validation loss: 0.264785
#
# Epoch 466
# -------------------------------
# Training loss: 0.246021
# Validation loss: 0.326271
#
# Epoch 467
# -------------------------------
# Training loss: 0.244824
# Validation loss: 0.254246
#
# Epoch 468
# -------------------------------
# Training loss: 0.243445
# Validation loss: 0.256278
#
# Epoch 469
# -------------------------------
# Training loss: 0.248621
# Validation loss: 0.308606
#
# Epoch 470
# -------------------------------
# Training loss: 0.250227
# Validation loss: 0.268477
#
# Epoch 471
# -------------------------------
# Training loss: 0.254027
# Validation loss: 0.272804
#
# Epoch 472
# -------------------------------
# Training loss: 0.248101
# Validation loss: 0.284201
#
# Epoch 473
# -------------------------------
# Training loss: 0.240262
# Validation loss: 0.302823
#
# Epoch 474
# -------------------------------
# Training loss: 0.244361
# Validation loss: 0.262137
#
# Epoch 475
# -------------------------------
# Training loss: 0.236045
# Validation loss: 0.288098
#
# Epoch 476
# -------------------------------
# Training loss: 0.232259
# Validation loss: 0.258369
#
# Epoch 477
# -------------------------------
# Training loss: 0.240931
# Validation loss: 0.313883
#
# Epoch 478
# -------------------------------
# Training loss: 0.239823
# Validation loss: 0.289532
#
# Epoch 479
# -------------------------------
# Training loss: 0.240661
# Validation loss: 0.273480
#
# Epoch 480
# -------------------------------
# Training loss: 0.243779
# Validation loss: 0.293720
#
# Epoch 481
# -------------------------------
# Training loss: 0.238389
# Validation loss: 0.266184
#
# Epoch 482
# -------------------------------
# Training loss: 0.233160
# Validation loss: 0.228823
#
# Epoch 483
# -------------------------------
# Training loss: 0.236232
# Validation loss: 0.249153
#
# Epoch 484
# -------------------------------
# Training loss: 0.236704
# Validation loss: 0.258843
#
# Epoch 485
# -------------------------------
# Training loss: 0.234298
# Validation loss: 0.258197
#
# Epoch 486
# -------------------------------
# Training loss: 0.239619
# Validation loss: 0.254427
#
# Epoch 487
# -------------------------------
# Training loss: 0.236786
# Validation loss: 0.246615
#
# Epoch 488
# -------------------------------
# Training loss: 0.233028
# Validation loss: 0.306161
#
# Epoch 489
# -------------------------------
# Training loss: 0.232039
# Validation loss: 0.277334
#
# Epoch 490
# -------------------------------
# Training loss: 0.232462
# Validation loss: 0.241720
#
# Epoch 491
# -------------------------------
# Training loss: 0.235396
# Validation loss: 0.263556
#
# Epoch 492
# -------------------------------
# Training loss: 0.233674
# Validation loss: 0.229780
#
# Epoch 493
# -------------------------------
# Training loss: 0.234048
# Validation loss: 0.265372
#
# Epoch 494
# -------------------------------
# Training loss: 0.231200
# Validation loss: 0.279194
#
# Epoch 495
# -------------------------------
# Training loss: 0.233108
# Validation loss: 0.319862
#
# Epoch 496
# -------------------------------
# Training loss: 0.234056
# Validation loss: 0.254883
#
# Epoch 497
# -------------------------------
# Training loss: 0.228593
# Validation loss: 0.324114
#
# Epoch 498
# -------------------------------
# Training loss: 0.230914
# Validation loss: 0.242654
#
# Epoch 499
# -------------------------------
# Training loss: 0.228277
# Validation loss: 0.284523
#
# Epoch 500
# -------------------------------
# Training loss: 0.226153
# Validation loss: 0.236593
#
# Epoch 501
# -------------------------------
# Training loss: 0.225388
# Validation loss: 0.239425
#
# Epoch 502
# -------------------------------
# Training loss: 0.240114
# Validation loss: 0.286597
#
# Epoch 503
# -------------------------------
# Training loss: 0.231896
# Validation loss: 0.240784
#
# Epoch 504
# -------------------------------
# Training loss: 0.228719
# Validation loss: 0.240982
#
# Epoch 505
# -------------------------------
# Training loss: 0.234437
# Validation loss: 0.245996
#
# Epoch 506
# -------------------------------
# Training loss: 0.229960
# Validation loss: 0.331087
#
# Epoch 507
# -------------------------------
# Training loss: 0.230701
# Validation loss: 0.257996
#
# Epoch 508
# -------------------------------
# Training loss: 0.236981
# Validation loss: 0.287093
#
# Epoch 509
# -------------------------------
# Training loss: 0.229434
# Validation loss: 0.336751
#
# Epoch 510
# -------------------------------
# Training loss: 0.231388
# Validation loss: 0.343500
#
# Epoch 511
# -------------------------------
# Training loss: 0.227165
# Validation loss: 0.235844
#
# Epoch 512
# -------------------------------
# Training loss: 0.226507
# ...
# Validation loss: 0.068372
#
# Epoch 2333
# -------------------------------
# Training loss: 0.064383
# Validation loss: 0.082392
#
# Epoch 2334
# -------------------------------
# Training loss: 0.063258
# Validation loss: 0.081742
#
# Epoch 2335
# -------------------------------
# Training loss: 0.062992
# Validation loss: 0.067957
#
# Epoch 2336
# -------------------------------
# Training loss: 0.062236
# Validation loss: 0.070293
#
# Epoch 2337
# -------------------------------
# Training loss: 0.063427
# Validation loss: 0.069052
#
# Epoch 2338
# -------------------------------
# Training loss: 0.066705
# Validation loss: 0.075046
#
# Epoch 2339
# -------------------------------
# Training loss: 0.062455
# Validation loss: 0.070887
#
# Epoch 2340
# -------------------------------
# Training loss: 0.062722
# Validation loss: 0.070026
#
# Epoch 2341
# -------------------------------
# Training loss: 0.063369
# Validation loss: 0.073127
#
# Epoch 2342
# -------------------------------
# Training loss: 0.062976
# Validation loss: 0.070627
#
# Epoch 2343
# -------------------------------
# Training loss: 0.063272
# Validation loss: 0.073110
#
# Epoch 2344
# -------------------------------
# Training loss: 0.064081
# Validation loss: 0.068224
#
# Epoch 2345
# -------------------------------
# Training loss: 0.064190
# Validation loss: 0.072805
#
# Epoch 2346
# -------------------------------
# Training loss: 0.062345
# Validation loss: 0.070090
#
# Epoch 2347
# -------------------------------
# Training loss: 0.063622
# Validation loss: 0.074653
#
# Epoch 2348
# -------------------------------
# Training loss: 0.063055
# Validation loss: 0.076817
#
# Epoch 2349
# -------------------------------
# Training loss: 0.062980
# Validation loss: 0.068349
#
# Epoch 2350
# -------------------------------
# Training loss: 0.063500
# Validation loss: 0.074990
#
# Epoch 2351
# -------------------------------
# Training loss: 0.063033
# Validation loss: 0.070915
#
# Epoch 2352
# -------------------------------
# Training loss: 0.063037
# Validation loss: 0.067501
#
# Epoch 2353
# -------------------------------
# Training loss: 0.063432
# Validation loss: 0.069858
#
# Epoch 2354
# -------------------------------
# Training loss: 0.064948
# Validation loss: 0.075747
#
# Epoch 2355
# -------------------------------
# Training loss: 0.062509
# Validation loss: 0.074143
#
# Epoch 2356
# -------------------------------
# Training loss: 0.064376
# Validation loss: 0.092138
#
# Epoch 2357
# -------------------------------
# Training loss: 0.061980
# Validation loss: 0.074722
#
# Epoch 2358
# -------------------------------
# Training loss: 0.062105
# Validation loss: 0.067228
#
# Epoch 2359
# -------------------------------
# Training loss: 0.063654
# Validation loss: 0.074763
#
# Epoch 2360
# -------------------------------
# Training loss: 0.062334
# Validation loss: 0.069377
#
# Epoch 2361
# -------------------------------
# Training loss: 0.064195
# Validation loss: 0.073677
#
# Epoch 2362
# -------------------------------
# Training loss: 0.061313
# Validation loss: 0.069818
#
# Epoch 2363
# -------------------------------
# Training loss: 0.062912
# Validation loss: 0.073441
#
# Epoch 2364
# -------------------------------
# Training loss: 0.062365
# Validation loss: 0.067751
#
# Epoch 2365
# -------------------------------
# Training loss: 0.063684
# Validation loss: 0.071395
#
# Epoch 2366
# -------------------------------
# Training loss: 0.061590
# Validation loss: 0.071939
#
# Epoch 2367
# -------------------------------
# Training loss: 0.064700
# Validation loss: 0.083691
#
# Epoch 2368
# -------------------------------
# Training loss: 0.064077
# Validation loss: 0.082767
#
# Epoch 2369
# -------------------------------
# Training loss: 0.063245
# Validation loss: 0.077604
#
# Epoch 2370
# -------------------------------
# Training loss: 0.064819
# Validation loss: 0.082380
#
# Epoch 2371
# -------------------------------
# Training loss: 0.062645
# Validation loss: 0.071952
#
# Epoch 2372
# -------------------------------
# Training loss: 0.063117
# Validation loss: 0.074138
#
# Epoch 2373
# -------------------------------
# Training loss: 0.062495
# Validation loss: 0.077197
#
# Epoch 2374
# -------------------------------
# Training loss: 0.062876
# Validation loss: 0.070399
#
# Epoch 2375
# -------------------------------
# Training loss: 0.061176
# Validation loss: 0.065803
#
# Epoch 2376
# -------------------------------
# Training loss: 0.063000
# Validation loss: 0.067590
#
# Epoch 2377
# -------------------------------
# Training loss: 0.063918
# Validation loss: 0.079467
#
# Epoch 2378
# -------------------------------
# Training loss: 0.061517
# Validation loss: 0.069089
#
# Epoch 2379
# -------------------------------
# Training loss: 0.062731
# Validation loss: 0.073342
#
# Epoch 2380
# -------------------------------
# Training loss: 0.062358
# Validation loss: 0.070536
#
# Epoch 2381
# -------------------------------
# Training loss: 0.064013
# Validation loss: 0.071250
#
# Epoch 2382
# -------------------------------
# Training loss: 0.062847
# Validation loss: 0.066055
#
# Epoch 2383
# -------------------------------
# Training loss: 0.061697
# Validation loss: 0.066534
#
# Epoch 2384
# -------------------------------
# Training loss: 0.061702
# Validation loss: 0.070640
#
# Epoch 2385
# -------------------------------
# Training loss: 0.061360
# Validation loss: 0.069738
#
# Epoch 2386
# -------------------------------
# Training loss: 0.062730
# Validation loss: 0.071239
#
# Epoch 2387
# -------------------------------
# Training loss: 0.065054
# Validation loss: 0.080453
#
# Epoch 2388
# -------------------------------
# Training loss: 0.062267
# Validation loss: 0.071603
#
# Epoch 2389
# -------------------------------
# Training loss: 0.061475
# Validation loss: 0.065669
#
# Epoch 2390
# -------------------------------
# Training loss: 0.063224
# Validation loss: 0.069790
#
# Epoch 2391
# -------------------------------
# Training loss: 0.062897
# Validation loss: 0.067535
#
# Epoch 2392
# -------------------------------
# Training loss: 0.061542
# Validation loss: 0.070451
#
# Epoch 2393
# -------------------------------
# Training loss: 0.062421
# Validation loss: 0.079391
#
# Epoch 2394
# -------------------------------
# Training loss: 0.061851
# Validation loss: 0.080239
#
# Epoch 2395
# -------------------------------
# Training loss: 0.061877
# Validation loss: 0.067837
#
# Epoch 2396
# -------------------------------
# Training loss: 0.062771
# Validation loss: 0.070196
#
# Epoch 2397
# -------------------------------
# Training loss: 0.063123
# Validation loss: 0.075389
#
# Epoch 2398
# -------------------------------
# Training loss: 0.062638
# Validation loss: 0.074960
#
# Epoch 2399
# -------------------------------
# Training loss: 0.068168
# Validation loss: 0.079315
#
# Epoch 2400
# -------------------------------
# Training loss: 0.062217
# Validation loss: 0.066348
#
# Epoch 2401
# -------------------------------
# Training loss: 0.062369
# Validation loss: 0.067475
#
# Epoch 2402
# -------------------------------
# Training loss: 0.061502
# Validation loss: 0.066785
#
# Epoch 2403
# -------------------------------
# Training loss: 0.063078
# Validation loss: 0.072473
#
# Epoch 2404
# -------------------------------
# Training loss: 0.063303
# Validation loss: 0.067870
#
# Epoch 2405
# -------------------------------
# Training loss: 0.062294
# Validation loss: 0.068817
#
# Epoch 2406
# -------------------------------
# Training loss: 0.062228
# Validation loss: 0.070694
#
# Epoch 2407
# -------------------------------
# Training loss: 0.062365
# Validation loss: 0.071694
#
# Epoch 2408
# -------------------------------
# Training loss: 0.062311
# Validation loss: 0.076405
#
# Epoch 2409
# -------------------------------
# Training loss: 0.061990
# Validation loss: 0.067391
#
# Epoch 2410
# -------------------------------
# Training loss: 0.065476
# Validation loss: 0.073348
#
# Epoch 2411
# -------------------------------
# Training loss: 0.061112
# Validation loss: 0.070540
#
# Epoch 2412
# -------------------------------
# Training loss: 0.062141
# Validation loss: 0.074802
#
# Epoch 2413
# -------------------------------
# Training loss: 0.062224
# Validation loss: 0.074447
#
# Epoch 2414
# -------------------------------
# Training loss: 0.062805
# Validation loss: 0.069683
#
# Epoch 2415
# -------------------------------
# Training loss: 0.063735
# Validation loss: 0.078321
#
# Epoch 2416
# -------------------------------
# Training loss: 0.063807
# Validation loss: 0.077695
#
# Epoch 2417
# -------------------------------
# Training loss: 0.060720
# Validation loss: 0.066725
#
# Epoch 2418
# -------------------------------
# Training loss: 0.061406
# Validation loss: 0.070779
#
# Epoch 2419
# -------------------------------
# Training loss: 0.062283
# Validation loss: 0.074788
#
# Epoch 2420
# -------------------------------
# Training loss: 0.062426
# Validation loss: 0.069635
#
# Epoch 2421
# -------------------------------
# Training loss: 0.061978
# Validation loss: 0.070674
#
# Epoch 2422
# -------------------------------
# Training loss: 0.060417
# Validation loss: 0.073729
#
# Epoch 2423
# -------------------------------
# Training loss: 0.061516
# Validation loss: 0.071754
#
# Epoch 2424
# -------------------------------
# Training loss: 0.062558
# Validation loss: 0.074805
#
# Epoch 2425
# -------------------------------
# Training loss: 0.061726
# Validation loss: 0.081688
#
# Epoch 2426
# -------------------------------
# Training loss: 0.060914
# Validation loss: 0.075791
#
# Epoch 2427
# -------------------------------
# Training loss: 0.061958
# Validation loss: 0.069761
#
# Epoch 2428
# -------------------------------
# Training loss: 0.063673
# Validation loss: 0.066054
#
# Epoch 2429
# -------------------------------
# Training loss: 0.061893
# Validation loss: 0.071243
#
# Epoch 2430
# -------------------------------
# Training loss: 0.060169
# Validation loss: 0.065040
#
# Epoch 2431
# -------------------------------
# Training loss: 0.061379
# Validation loss: 0.066945
#
# Epoch 2432
# -------------------------------
# Training loss: 0.062031
# Validation loss: 0.066988
#
# Epoch 2433
# -------------------------------
# Training loss: 0.061258
# Validation loss: 0.067396
#
# Epoch 2434
# -------------------------------
# Training loss: 0.062231
# Validation loss: 0.066411
#
# Epoch 2435
# -------------------------------
# Training loss: 0.061056
# Validation loss: 0.065454
#
# Epoch 2436
# -------------------------------
# Training loss: 0.062160
# Validation loss: 0.071158
#
# Epoch 2437
# -------------------------------
# Training loss: 0.061174
# Validation loss: 0.068482
#
# Epoch 2438
# -------------------------------
# Training loss: 0.062903
# Validation loss: 0.075761
#
# Epoch 2439
# -------------------------------
# Training loss: 0.061624
# Validation loss: 0.075206
#
# Epoch 2440
# -------------------------------
# Training loss: 0.060648
# Validation loss: 0.069937
#
# Epoch 2441
# -------------------------------
# Training loss: 0.060922
# Validation loss: 0.070010
#
# Epoch 2442
# -------------------------------
# Training loss: 0.061466
# Validation loss: 0.068373
#
# Epoch 2443
# -------------------------------
# Training loss: 0.060635
# Validation loss: 0.064139
#
# Epoch 2444
# -------------------------------
# Training loss: 0.061123
# Validation loss: 0.065598
#
# Epoch 2445
# -------------------------------
# Training loss: 0.060416
# Validation loss: 0.064744
#
# Epoch 2446
# -------------------------------
# Training loss: 0.063341
# Validation loss: 0.068087
#
# Epoch 2447
# -------------------------------
# Training loss: 0.063371
# Validation loss: 0.073082
#
# Epoch 2448
# -------------------------------
# Training loss: 0.062166
# Validation loss: 0.069059
#
# Epoch 2449
# -------------------------------
# Training loss: 0.061313
# Validation loss: 0.067993
#
# Epoch 2450
# -------------------------------
# Training loss: 0.061502
# Validation loss: 0.067756
#
# Epoch 2451
# -------------------------------
# Training loss: 0.061368
# Validation loss: 0.069092
#
# Epoch 2452
# -------------------------------
# Training loss: 0.061079
# Validation loss: 0.071599
#
# Epoch 2453
# -------------------------------
# Training loss: 0.062460
# Validation loss: 0.074835
#
# Epoch 2454
# -------------------------------
# Training loss: 0.060801
# Validation loss: 0.070910
#
# Epoch 2455
# -------------------------------
# Training loss: 0.061968
# Validation loss: 0.072274
#
# Epoch 2456
# -------------------------------
# Training loss: 0.062662
# Validation loss: 0.071998
#
# Epoch 2457
# -------------------------------
# Training loss: 0.061053
# Validation loss: 0.069635
#
# Epoch 2458
# -------------------------------
# Training loss: 0.061159
# Validation loss: 0.070966
#
# Epoch 2459
# -------------------------------
# Training loss: 0.061549
# Validation loss: 0.072306
#
# Epoch 2460
# -------------------------------
# Training loss: 0.061291
# Validation loss: 0.067203
#
# Epoch 2461
# -------------------------------
# Training loss: 0.062289
# Validation loss: 0.089012
#
# Epoch 2462
# -------------------------------
# Training loss: 0.061735
# Validation loss: 0.087123
#
# Epoch 2463
# -------------------------------
# Training loss: 0.061961
# Validation loss: 0.086188
#
# Epoch 2464
# -------------------------------
# Training loss: 0.060058
# Validation loss: 0.069899
#
# Epoch 2465
# -------------------------------
# Training loss: 0.060276
# Validation loss: 0.065775
#
# Epoch 2466
# -------------------------------
# Training loss: 0.061739
# Validation loss: 0.066030
#
# Epoch 2467
# -------------------------------
# Training loss: 0.061084
# Validation loss: 0.066841
#
# Epoch 2468
# -------------------------------
# Training loss: 0.060948
# Validation loss: 0.068627
#
# Epoch 2469
# -------------------------------
# Training loss: 0.062570
# Validation loss: 0.077259
#
# Epoch 2470
# -------------------------------
# Training loss: 0.063110
# Validation loss: 0.073390
#
# Epoch 2471
# -------------------------------
# Training loss: 0.061813
# Validation loss: 0.082676
#
# Epoch 2472
# -------------------------------
# Training loss: 0.060751
# Validation loss: 0.074996
#
# Epoch 2473
# -------------------------------
# Training loss: 0.060662
# Validation loss: 0.069512
#
# Epoch 2474
# -------------------------------
# Training loss: 0.059844
# Validation loss: 0.078804
#
# Epoch 2475
# -------------------------------
# Training loss: 0.064389
# Validation loss: 0.084984
#
# Epoch 2476
# -------------------------------
# Training loss: 0.060778
# Validation loss: 0.068673
#
# Epoch 2477
# -------------------------------
# Training loss: 0.061042
# Validation loss: 0.070301
#
# Epoch 2478
# -------------------------------
# Training loss: 0.061355
# Validation loss: 0.074911
#
# Epoch 2479
# -------------------------------
# Training loss: 0.064651
# Validation loss: 0.093588
#
# Epoch 2480
# -------------------------------
# Training loss: 0.060404
# Validation loss: 0.079027
#
# Epoch 2481
# -------------------------------
# Training loss: 0.060470
# Validation loss: 0.071600
#
# Epoch 2482
# -------------------------------
# Training loss: 0.061288
# Validation loss: 0.070545
#
# Epoch 2483
# -------------------------------
# Training loss: 0.061484
# Validation loss: 0.065645
#
# Epoch 2484
# -------------------------------
# Training loss: 0.061115
# Validation loss: 0.067673
#
# Epoch 2485
# -------------------------------
# Training loss: 0.059390
# Validation loss: 0.064632
#
# Epoch 2486
# -------------------------------
# Training loss: 0.060148
# Validation loss: 0.064711
#
# Epoch 2487
# -------------------------------
# Training loss: 0.061565
# Validation loss: 0.070697
#
# Epoch 2488
# -------------------------------
# Training loss: 0.060815
# Validation loss: 0.065227
#
# Epoch 2489
# -------------------------------
# Training loss: 0.060751
# Validation loss: 0.065898
#
# Epoch 2490
# -------------------------------
# Training loss: 0.060280
# Validation loss: 0.065957
#
# Epoch 2491
# -------------------------------
# Training loss: 0.060042
# Validation loss: 0.066176
#
# Epoch 2492
# -------------------------------
# Training loss: 0.059894
# Validation loss: 0.067581
#
# Epoch 2493
# -------------------------------
# Training loss: 0.061947
# Validation loss: 0.065910
#
# Epoch 2494
# -------------------------------
# Training loss: 0.060684
# Validation loss: 0.070896
#
# Epoch 2495
# -------------------------------
# Training loss: 0.061369
# Validation loss: 0.071012
#
# Epoch 2496
# -------------------------------
# Training loss: 0.062584
# Validation loss: 0.067452
#
# Epoch 2497
# -------------------------------
# Training loss: 0.061457
# Validation loss: 0.077961
#
# Epoch 2498
# -------------------------------
# Training loss: 0.061144
# Validation loss: 0.077646
#
# Epoch 2499
# -------------------------------
# Training loss: 0.060987
# Validation loss: 0.067127
#
# Epoch 2500
# -------------------------------
# Training loss: 0.061773
# Validation loss: 0.080963
#
# Done!

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses)+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('BCE Loss')
#plt.yscale('log')
plt.legend()

# %%
# Now test the pretrained model
test_pred = mytools.test_clas(test_loader, final_classifier, device)
test_pred=torch.sigmoid(torch.tensor(test_pred)).numpy()


fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test, test_pred, pos_label=1)
auc_test = sklearn.metrics.auc(fpr, tpr)
print(f'Test AUROC: {auc_test:0.4f}')

plt.plot(fpr, tpr, label=f'Test AUROC: {auc_test:0.4f}')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
# Out:
# Test AUROC: 0.9963

# %%
# Store the pretrained classifier labels
df_test["Class_pre"] = test_pred

# Save the pretrained classifier model
torch.save(final_classifier.state_dict(), "/Users/mghrear/data/ML_data/patch/pretrained_classifier_2021_v9_pass5_FakeGen_1pt05_kaon_run"+str(run)+"QualCuts.pt")

# %% [markdown]
# # Setup the adversary model

# %% [markdown]
# ## Initialize model, objective function, and optimizer

# %%
adv = mytools.Adversary(n_classes=Num_classes).to(device)
criterion_adv = nn.CrossEntropyLoss(reduction='none')  # returns loss per sample so we can weight it
opt_adv = torch.optim.Adam(adv.parameters(), lr=1e-5)
scheduler_adv = torch.optim.lr_scheduler.ExponentialLR(opt_adv, gamma=0.999)

# %% [markdown]
# ## Setup dataloaders

# %%
# Convert to tensor dataset and dataloader

# the structure is: feature, adversary label, weight
# The wight is 1 for tritrig and wab, and 0 for phiKK, to prevent the adversary from learning on phiKK events

train_adv_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_train), (torch.from_numpy(y_train.to_numpy().astype(np.float32))==0).float())
train_adv_loader = DataLoader(train_adv_dataset, batch_size=bsize, shuffle=True)

val_adv_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_val), (torch.from_numpy(y_val.to_numpy().astype(np.float32))==0).float() )
val_adv_loader = DataLoader(val_adv_dataset, batch_size=bsize, shuffle=True)

# Weights are not relavent for testing
test_adv_dataset = TensorDataset(torch.from_numpy(X_test.to_numpy() .astype(np.float32))  , torch.from_numpy(y_adv_test))
test_adv_loader = DataLoader(test_adv_dataset, batch_size=bsize, shuffle=True)

# %% [markdown]
# ## Pre-train the adversary leaving classifier weights fixed

# %%
# Implement early stopping in training loop
# Stop if validation loss has not decreased for the last [patience] epochs
# The model with the lowest loss is stored
patience = 6

Training_losses = np.array([])
Validation_losses = np.array([])

epochs = 100
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    
    Training_losses = np.append(Training_losses, mytools.train_adv(train_adv_loader, final_classifier, adv, criterion_adv, opt_adv, scheduler_adv, device))
    Validation_losses = np.append(Validation_losses, mytools.validate_adv(val_adv_loader, final_classifier, adv, criterion_adv, device))
    
    # Keep a running copy of the model with the lowest loss
    if Validation_losses[-1] == np.min(Validation_losses):
        final_adv = copy.deepcopy(adv)
    
    if len(Validation_losses) > patience:
        if np.sum((Validation_losses[-1*np.arange(patience)-1] - Validation_losses[-1*np.arange(patience)-2]) < 0) == 0:
            print("Stopping early!")
            break
            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Training loss: 1.620022
# Validation loss: 1.612853
#
# Epoch 2
# -------------------------------
# Training loss: 1.616117
# Validation loss: 1.616028
#
# Epoch 3
# -------------------------------
# Training loss: 1.612472
# Validation loss: 1.616993
#
# Epoch 4
# -------------------------------
# Training loss: 1.610412
# Validation loss: 1.616870
#
# Epoch 5
# -------------------------------
# Training loss: 1.608845
# Validation loss: 1.616565
#
# Epoch 6
# -------------------------------
# Training loss: 1.607816
# Validation loss: 1.615610
#
# Epoch 7
# -------------------------------
# Training loss: 1.606446
# Validation loss: 1.613577
#
# Epoch 8
# -------------------------------
# Training loss: 1.606418
# Validation loss: 1.614123
#
# Epoch 9
# -------------------------------
# Training loss: 1.605250
# Validation loss: 1.610174
#
# Epoch 10
# -------------------------------
# Training loss: 1.604969
# Validation loss: 1.610846
#
# Epoch 11
# -------------------------------
# Training loss: 1.604363
# Validation loss: 1.608735
#
# Epoch 12
# -------------------------------
# Training loss: 1.603752
# Validation loss: 1.608240
#
# Epoch 13
# -------------------------------
# Training loss: 1.603321
# Validation loss: 1.607407
#
# Epoch 14
# -------------------------------
# Training loss: 1.602498
# Validation loss: 1.607329
#
# Epoch 15
# -------------------------------
# Training loss: 1.602157
# Validation loss: 1.606039
#
# Epoch 16
# -------------------------------
# Training loss: 1.602279
# Validation loss: 1.606856
#
# Epoch 17
# -------------------------------
# Training loss: 1.601727
# Validation loss: 1.604050
#
# Epoch 18
# -------------------------------
# Training loss: 1.601176
# Validation loss: 1.604484
#
# Epoch 19
# -------------------------------
# Training loss: 1.601114
# Validation loss: 1.605509
#
# Epoch 20
# -------------------------------
# Training loss: 1.600396
# Validation loss: 1.605306
#
# Epoch 21
# -------------------------------
# Training loss: 1.600204
# Validation loss: 1.604747
#
# Epoch 22
# -------------------------------
# Training loss: 1.599950
# Validation loss: 1.604132
#
# Epoch 23
# -------------------------------
# Training loss: 1.600014
# Validation loss: 1.602261
#
# Epoch 24
# -------------------------------
# Training loss: 1.599694
# Validation loss: 1.603356
#
# Epoch 25
# -------------------------------
# Training loss: 1.599630
# Validation loss: 1.602721
#
# Epoch 26
# -------------------------------
# Training loss: 1.599394
# Validation loss: 1.603354
#
# Epoch 27
# -------------------------------
# Training loss: 1.599036
# Validation loss: 1.601775
#
# Epoch 28
# -------------------------------
# Training loss: 1.598828
# Validation loss: 1.603932
#
# Epoch 29
# -------------------------------
# Training loss: 1.598994
# Validation loss: 1.602874
#
# Epoch 30
# -------------------------------
# Training loss: 1.598995
# Validation loss: 1.603944
#
# Epoch 31
# -------------------------------
# Training loss: 1.598337
# Validation loss: 1.600608
#
# Epoch 32
# -------------------------------
# Training loss: 1.598307
# Validation loss: 1.603425
#
# Epoch 33
# -------------------------------
# Training loss: 1.597935
# Validation loss: 1.601390
#
# Epoch 34
# -------------------------------
# Training loss: 1.598105
# Validation loss: 1.598810
#
# Epoch 35
# -------------------------------
# Training loss: 1.597824
# Validation loss: 1.602244
#
# Epoch 36
# -------------------------------
# Training loss: 1.597860
# Validation loss: 1.599847
#
# Epoch 37
# -------------------------------
# Training loss: 1.597536
# Validation loss: 1.601142
#
# Epoch 38
# -------------------------------
# Training loss: 1.597470
# Validation loss: 1.600992
#
# Epoch 39
# -------------------------------
# Training loss: 1.597297
# Validation loss: 1.599709
#
# Epoch 40
# -------------------------------
# Training loss: 1.597256
# Validation loss: 1.603329
#
# Epoch 41
# -------------------------------
# Training loss: 1.596999
# Validation loss: 1.602035
#
# Epoch 42
# -------------------------------
# Training loss: 1.597456
# Validation loss: 1.599774
#
# Epoch 43
# -------------------------------
# Training loss: 1.596928
# Validation loss: 1.600121
#
# Epoch 44
# -------------------------------
# Training loss: 1.596912
# Validation loss: 1.600109
#
# Epoch 45
# -------------------------------
# Training loss: 1.596812
# Validation loss: 1.600913
#
# Epoch 46
# -------------------------------
# Training loss: 1.596578
# Validation loss: 1.603440
#
# Epoch 47
# -------------------------------
# Training loss: 1.596549
# Validation loss: 1.598743
#
# Epoch 48
# -------------------------------
# Training loss: 1.597102
# Validation loss: 1.601061
#
# Epoch 49
# -------------------------------
# Training loss: 1.596318
# Validation loss: 1.600627
#
# Epoch 50
# -------------------------------
# Training loss: 1.596562
# Validation loss: 1.599865
#
# Epoch 51
# -------------------------------
# Training loss: 1.596638
# Validation loss: 1.600286
#
# Epoch 52
# -------------------------------
# Training loss: 1.595798
# Validation loss: 1.599368
#
# Epoch 53
# -------------------------------
# Training loss: 1.595991
# Validation loss: 1.600051
#
# Epoch 54
# -------------------------------
# Training loss: 1.596107
# Validation loss: 1.598152
#
# Epoch 55
# -------------------------------
# Training loss: 1.595918
# Validation loss: 1.599288
#
# Epoch 56
# -------------------------------
# Training loss: 1.596172
# Validation loss: 1.600357
#
# Epoch 57
# -------------------------------
# Training loss: 1.595934
# Validation loss: 1.599564
#
# Epoch 58
# -------------------------------
# Training loss: 1.595640
# Validation loss: 1.599222
#
# Epoch 59
# -------------------------------
# Training loss: 1.595637
# Validation loss: 1.602265
#
# Epoch 60
# -------------------------------
# Training loss: 1.595425
# Validation loss: 1.599573
#
# Epoch 61
# -------------------------------
# Training loss: 1.595926
# Validation loss: 1.599759
#
# Epoch 62
# -------------------------------
# Training loss: 1.595380
# Validation loss: 1.598906
#
# Epoch 63
# -------------------------------
# Training loss: 1.595605
# Validation loss: 1.598972
#
# Epoch 64
# -------------------------------
# Training loss: 1.595456
# Validation loss: 1.599393
#
# Epoch 65
# -------------------------------
# Training loss: 1.595392
# Validation loss: 1.600207
#
# Epoch 66
# -------------------------------
# Training loss: 1.595089
# Validation loss: 1.598368
#
# Epoch 67
# -------------------------------
# Training loss: 1.595342
# Validation loss: 1.600692
#
# Epoch 68
# -------------------------------
# Training loss: 1.595239
# Validation loss: 1.599683
#
# Epoch 69
# -------------------------------
# Training loss: 1.595214
# Validation loss: 1.600001
#
# Epoch 70
# -------------------------------
# Training loss: 1.594872
# Validation loss: 1.598669
#
# Epoch 71
# -------------------------------
# Training loss: 1.595320
# Validation loss: 1.600611
#
# Epoch 72
# -------------------------------
# Training loss: 1.595085
# Validation loss: 1.600744
#
# Epoch 73
# -------------------------------
# Training loss: 1.595143
# Validation loss: 1.598872
#
# Epoch 74
# -------------------------------
# Training loss: 1.595524
# Validation loss: 1.599179
#
# Epoch 75
# -------------------------------
# Training loss: 1.594967
# Validation loss: 1.601600
#
# Epoch 76
# -------------------------------
# Training loss: 1.594924
# Validation loss: 1.600087
#
# Epoch 77
# -------------------------------
# Training loss: 1.594711
# Validation loss: 1.597921
#
# Epoch 78
# -------------------------------
# Training loss: 1.594559
# Validation loss: 1.600285
#
# Epoch 79
# -------------------------------
# Training loss: 1.594721
# Validation loss: 1.599237
#
# Epoch 80
# -------------------------------
# Training loss: 1.594844
# Validation loss: 1.598941
#
# Epoch 81
# -------------------------------
# Training loss: 1.594708
# Validation loss: 1.599437
#
# Epoch 82
# -------------------------------
# Training loss: 1.594960
# Validation loss: 1.598996
#
# Epoch 83
# -------------------------------
# Training loss: 1.594658
# Validation loss: 1.597897
#
# Epoch 84
# -------------------------------
# Training loss: 1.594732
# Validation loss: 1.599220
#
# Epoch 85
# -------------------------------
# Training loss: 1.594753
# Validation loss: 1.598946
#
# Epoch 86
# -------------------------------
# Training loss: 1.594403
# Validation loss: 1.598924
#
# Epoch 87
# -------------------------------
# Training loss: 1.594762
# Validation loss: 1.598916
#
# Epoch 88
# -------------------------------
# Training loss: 1.594971
# Validation loss: 1.599689
#
# Epoch 89
# -------------------------------
# Training loss: 1.594570
# Validation loss: 1.598254
#
# Epoch 90
# -------------------------------
# Training loss: 1.594721
# Validation loss: 1.600767
#
# Epoch 91
# -------------------------------
# Training loss: 1.594566
# Validation loss: 1.600437
#
# Epoch 92
# -------------------------------
# Training loss: 1.594690
# Validation loss: 1.599434
#
# Epoch 93
# -------------------------------
# Training loss: 1.594813
# Validation loss: 1.599476
#
# Epoch 94
# -------------------------------
# Training loss: 1.594773
# Validation loss: 1.598687
#
# Epoch 95
# -------------------------------
# Training loss: 1.594553
# Validation loss: 1.599522
#
# Epoch 96
# -------------------------------
# Training loss: 1.594513
# Validation loss: 1.597663
#
# Epoch 97
# -------------------------------
# Training loss: 1.594230
# Validation loss: 1.598523
#
# Epoch 98
# -------------------------------
# Training loss: 1.594468
# Validation loss: 1.598490
#
# Epoch 99
# -------------------------------
# Training loss: 1.594859
# Validation loss: 1.600746
#
# Epoch 100
# -------------------------------
# Training loss: 1.594663
# Validation loss: 1.600621
#
# Done!

# %%
# Plot Training and Validation Loss
# Indicate where the final model stopped training

best_epoch = np.argmin(Validation_losses)+1

plt.plot(np.arange(len(Training_losses))+1,Training_losses,label="Training Loss")
plt.plot(np.arange(len(Validation_losses))+1,Validation_losses,label="Validation Loss")
plt.axvline(best_epoch,label="Final model stopped here",color='k')
plt.xlabel('Epoch')
plt.ylabel('BCE Loss')
plt.legend()

# %% [markdown]
# ## Test the pre-trained adversary

# %%
adv_test_pred = mytools.test_adv(test_adv_loader, final_classifier, final_adv, Num_classes, device)
adv_test_pred = torch.softmax(torch.tensor(adv_test_pred),dim=1).numpy()
score=0

for i in range(adv_test_pred.shape[1]):
    fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_adv_test[:,i], adv_test_pred[:,i], pos_label=1)
    auc_test = sklearn.metrics.auc(fpr, tpr)
    print("class " + str(i)+ " test auc score: " + str(auc_test))

    plt.plot(fpr, tpr, label='Class '+str(i)+' Test AUROC: '+str(auc_test))
    plt.xlabel('FPR')
    plt.ylabel('TPR')
    plt.legend()

    score += auc_test

print("average score: ", score/adv_test_pred.shape[1])
# Out:
# class 0 test auc score: 0.4960901300016078
# class 1 test auc score: 0.5007207028904246
# class 2 test auc score: 0.5021849274683015
# class 3 test auc score: 0.5027665650322675
# class 4 test auc score: 0.4996092237442159
# average score:  0.5002743098273634

# %% [markdown]
# # Train full adverserial neural network

# %% [markdown]
# # Setup dataloaders

# %%
# the structure is: feature, classifier label, adversary label, weight
# The wight is 1 for tritrig and wab, and 0 for phiKK, to prevent the adversary from learning on phiKK events

train_full_dataset = TensorDataset(torch.from_numpy(X_train.to_numpy().astype(np.float32))  , torch.from_numpy(y_train.to_numpy().astype(np.float32)).unsqueeze(1), torch.from_numpy(y_adv_train),  (torch.from_numpy(y_train.to_numpy().astype(np.float32))==0).float())
train_full_loader = DataLoader(train_full_dataset, batch_size=bsize, shuffle=True)

val_full_dataset = TensorDataset(torch.from_numpy(X_val.to_numpy().astype(np.float32))  , torch.from_numpy(y_val.to_numpy().astype(np.float32)).unsqueeze(1),  torch.from_numpy(y_adv_val),  (torch.from_numpy(y_val.to_numpy().astype(np.float32))==0).float())
val_full_loader = DataLoader(val_full_dataset, batch_size=bsize, shuffle=True)

# %% [markdown]
# ## Define loss functions

# %%
BCE_loss = nn.BCEWithLogitsLoss()
CE_loss = nn.CrossEntropyLoss(reduction='none') # returns loss per sample so we can weight it

def full_loss(output_clas, output_adv, target_clas, target_adv, w, lambda_):

    loss1 = BCE_loss(output_clas, target_clas )  # classification loss
    sample_losses2 = CE_loss(output_adv, target_adv)  # adversarial losses, since we set reduction='none', this is now a vector of losses, one per sample in the batch

    # Weighted mean loss over non-zero weights
    nonzero = w > 0
    loss2 = (sample_losses2[nonzero] * w[nonzero]).sum() / w[nonzero].sum()

    loss = loss1 - lambda_*loss2

    return loss

# %% [markdown]
# ## Setup optimizers

# %%
optimizer_clas = optim.Adam(final_classifier.parameters(), lr=1e-7,betas=(0.5, 0.999))
optimizer_adv = optim.Adam(final_adv.parameters(), lr=1e-5,betas=(0.5, 0.999))

scheduler_clas = torch.optim.lr_scheduler.ExponentialLR(optimizer_clas, gamma=0.999)
scheduler_adv = torch.optim.lr_scheduler.ExponentialLR(optimizer_adv, gamma=0.999)

# %% [markdown]
# ## Adversarial training

# %%
Training_losses_clas = np.array([])
Training_losses_adv = np.array([])
Validation_losses_clas = np.array([])
Validation_losses_adv = np.array([])
diff_scores = np.array([])


epochs = 50
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")

    # Get validation losses
    E_clas_val_loss, E_adv_val_loss = mytools.validate_full(val_full_loader, final_classifier, final_adv, full_loss, lambda_, criterion_adv, device)
    Validation_losses_clas = np.append(Validation_losses_clas, E_clas_val_loss)
    Validation_losses_adv = np.append(Validation_losses_adv, E_adv_val_loss)

    # Train adversary and classifier
    E_clas_training_loss , E_adv_training_loss = mytools.train_full(train_full_loader, final_classifier, final_adv, full_loss, lambda_, criterion_adv, optimizer_clas, optimizer_adv, scheduler_clas, scheduler_adv, device)
    Training_losses_clas = np.append(Training_losses_clas, E_clas_training_loss)
    Training_losses_adv = np.append(Training_losses_adv, E_adv_training_loss)

    # Get the diff_score
    df_test["Class_adv"] = mytools.test_clas(test_loader, final_classifier, device)
    df_bkg = df_test.loc[ (df_test.type == 'tritrig') | (df_test.type == 'wab')]
    per = np.percentile(df_bkg['Class_adv'],99)
    df_cut = df_bkg[df_bkg['Class_adv']>per].reset_index(drop=True)
    x1 = 1000* df_bkg.InvM.values
    x2 = 1000*df_cut.InvM.values
    diff_scores = np.append(diff_scores, mytools.get_diff_score(x1,x2) )

    # Keep a running copy of the model with the lowest loss
    if diff_scores[-1] == np.min(diff_scores):
        final_clas_adv = copy.deepcopy(final_classifier)
        final_adv_adv = copy.deepcopy(final_adv)

            
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Classifier validation loss: -159.966855
# Adversary validation loss: 1.600297
# Classifier training loss: -159.187883
# Adversary training loss: 1.593276
# Epoch 2
# -------------------------------
# Classifier validation loss: -163.880432
# Adversary validation loss: 1.639562
# Classifier training loss: -159.899952
# Adversary training loss: 1.600423
# Epoch 3
# -------------------------------
# Classifier validation loss: -162.101944
# Adversary validation loss: 1.621735
# Classifier training loss: -160.235901
# Adversary training loss: 1.604233
# Epoch 4
# -------------------------------
# Classifier validation loss: -164.636954
# Adversary validation loss: 1.647157
# Classifier training loss: -161.007080
# Adversary training loss: 1.612023
# Epoch 5
# -------------------------------
# Classifier validation loss: -162.449762
# Adversary validation loss: 1.625175
# Classifier training loss: -161.763865
# Adversary training loss: 1.619685
# Epoch 6
# -------------------------------
# Classifier validation loss: -163.153040
# Adversary validation loss: 1.632268
# Classifier training loss: -162.435703
# Adversary training loss: 1.626101
# Epoch 7
# -------------------------------
# Classifier validation loss: -163.771945
# Adversary validation loss: 1.638502
# Classifier training loss: -162.538983
# Adversary training loss: 1.626719
# Epoch 8
# -------------------------------
# Classifier validation loss: -163.812350
# Adversary validation loss: 1.639048
# Classifier training loss: -162.578920
# Adversary training loss: 1.627039
# Epoch 9
# -------------------------------
# Classifier validation loss: -163.705942
# Adversary validation loss: 1.638188
# Classifier training loss: -162.363614
# Adversary training loss: 1.624711
# Epoch 10
# -------------------------------
# Classifier validation loss: -162.947610
# Adversary validation loss: 1.630596
# Classifier training loss: -161.941313
# Adversary training loss: 1.620451
# Epoch 11
# -------------------------------
# Classifier validation loss: -162.622375
# Adversary validation loss: 1.627562
# Classifier training loss: -161.697620
# Adversary training loss: 1.617988
# Epoch 12
# -------------------------------
# Classifier validation loss: -162.099716
# Adversary validation loss: 1.622161
# Classifier training loss: -161.339440
# Adversary training loss: 1.614446
# Epoch 13
# -------------------------------
# Classifier validation loss: -161.551294
# Adversary validation loss: 1.616681
# Classifier training loss: -161.003313
# Adversary training loss: 1.611056
# Epoch 14
# -------------------------------
# Classifier validation loss: -161.275781
# Adversary validation loss: 1.613978
# Classifier training loss: -160.760783
# Adversary training loss: 1.608623
# Epoch 15
# -------------------------------
# Classifier validation loss: -161.058408
# Adversary validation loss: 1.611886
# Classifier training loss: -160.410700
# Adversary training loss: 1.605090
# Epoch 16
# -------------------------------
# Classifier validation loss: -160.616782
# Adversary validation loss: 1.607554
# Classifier training loss: -160.089169
# Adversary training loss: 1.601891
# Epoch 17
# -------------------------------
# Classifier validation loss: -160.196591
# Adversary validation loss: 1.603093
# Classifier training loss: -159.785099
# Adversary training loss: 1.598864
# Epoch 18
# -------------------------------
# Classifier validation loss: -159.946149
# Adversary validation loss: 1.600470
# Classifier training loss: -159.499797
# Adversary training loss: 1.595984
# Epoch 19
# -------------------------------
# Classifier validation loss: -159.676675
# Adversary validation loss: 1.597773
# Classifier training loss: -159.393129
# Adversary training loss: 1.594929
# Epoch 20
# -------------------------------
# Classifier validation loss: -159.407706
# Adversary validation loss: 1.595191
# Classifier training loss: -159.177941
# Adversary training loss: 1.592796
# Epoch 21
# -------------------------------
# Classifier validation loss: -159.164444
# Adversary validation loss: 1.592642
# Classifier training loss: -159.054598
# Adversary training loss: 1.591635
# Epoch 22
# -------------------------------
# Classifier validation loss: -159.081064
# Adversary validation loss: 1.591689
# Classifier training loss: -159.019545
# Adversary training loss: 1.591401
# Epoch 23
# -------------------------------
# Classifier validation loss: -158.854037
# Adversary validation loss: 1.589404
# Classifier training loss: -159.373730
# Adversary training loss: 1.595189
# Epoch 24
# -------------------------------
# Classifier validation loss: -159.513297
# Adversary validation loss: 1.596127
# Classifier training loss: -159.962543
# Adversary training loss: 1.601344
# Epoch 25
# -------------------------------
# Classifier validation loss: -159.780774
# Adversary validation loss: 1.598664
# Classifier training loss: -160.602642
# Adversary training loss: 1.607533
# Epoch 26
# -------------------------------
# Classifier validation loss: -160.315576
# Adversary validation loss: 1.604027
# Classifier training loss: -161.042236
# Adversary training loss: 1.611678
# Epoch 27
# -------------------------------
# Classifier validation loss: -160.507083
# Adversary validation loss: 1.605908
# Classifier training loss: -161.252143
# Adversary training loss: 1.613473
# Epoch 28
# -------------------------------
# Classifier validation loss: -161.347076
# Adversary validation loss: 1.614188
# Classifier training loss: -160.982190
# Adversary training loss: 1.610662
# Epoch 29
# -------------------------------
# Classifier validation loss: -161.101855
# Adversary validation loss: 1.611784
# Classifier training loss: -160.939409
# Adversary training loss: 1.610148
# Epoch 30
# -------------------------------
# Classifier validation loss: -160.789490
# Adversary validation loss: 1.608654
# Classifier training loss: -160.736720
# Adversary training loss: 1.608116
# Epoch 31
# -------------------------------
# Classifier validation loss: -160.801321
# Adversary validation loss: 1.608770
# Classifier training loss: -160.605052
# Adversary training loss: 1.606759
# Epoch 32
# -------------------------------
# Classifier validation loss: -160.650235
# Adversary validation loss: 1.607230
# Classifier training loss: -160.423945
# Adversary training loss: 1.605003
# Epoch 33
# -------------------------------
# Classifier validation loss: -160.815933
# Adversary validation loss: 1.609097
# Classifier training loss: -160.482035
# Adversary training loss: 1.605540
# Epoch 34
# -------------------------------
# Classifier validation loss: -160.625958
# Adversary validation loss: 1.607031
# Classifier training loss: -160.360448
# Adversary training loss: 1.604392
# Epoch 35
# -------------------------------
# Classifier validation loss: -160.785684
# Adversary validation loss: 1.608674
# Classifier training loss: -160.374100
# Adversary training loss: 1.604503
# Epoch 36
# -------------------------------
# Classifier validation loss: -160.714572
# Adversary validation loss: 1.607951
# Classifier training loss: -160.350555
# Adversary training loss: 1.604334
# Epoch 37
# -------------------------------
# Classifier validation loss: -161.097076
# Adversary validation loss: 1.611827
# Classifier training loss: -160.502696
# Adversary training loss: 1.605813
# Epoch 38
# -------------------------------
# Classifier validation loss: -160.700693
# Adversary validation loss: 1.607783
# Classifier training loss: -160.520693
# Adversary training loss: 1.606026
# Epoch 39
# -------------------------------
# Classifier validation loss: -160.745584
# Adversary validation loss: 1.608242
# Classifier training loss: -160.585429
# Adversary training loss: 1.606642
# Epoch 40
# -------------------------------
# Classifier validation loss: -160.916058
# Adversary validation loss: 1.610001
# Classifier training loss: -160.564977
# Adversary training loss: 1.606470
# Epoch 41
# -------------------------------
# Classifier validation loss: -160.938361
# Adversary validation loss: 1.610202
# Classifier training loss: -160.570055
# Adversary training loss: 1.606475
# Epoch 42
# -------------------------------
# Classifier validation loss: -160.718048
# Adversary validation loss: 1.607936
# Classifier training loss: -160.609278
# Adversary training loss: 1.606886
# Epoch 43
# -------------------------------
# Classifier validation loss: -160.964487
# Adversary validation loss: 1.610483
# Classifier training loss: -160.648032
# Adversary training loss: 1.607272
# Epoch 44
# -------------------------------
# Classifier validation loss: -160.658313
# Adversary validation loss: 1.607362
# Classifier training loss: -160.660677
# Adversary training loss: 1.607398
# Epoch 45
# -------------------------------
# Classifier validation loss: -160.807059
# Adversary validation loss: 1.609038
# Classifier training loss: -160.653783
# Adversary training loss: 1.607313
# Epoch 46
# -------------------------------
# Classifier validation loss: -160.764658
# Adversary validation loss: 1.608530
# Classifier training loss: -160.570053
# Adversary training loss: 1.606517
# Epoch 47
# -------------------------------
# Classifier validation loss: -160.705215
# Adversary validation loss: 1.608044
# Classifier training loss: -160.551821
# Adversary training loss: 1.606303
# Epoch 48
# -------------------------------
# Classifier validation loss: -160.701633
# Adversary validation loss: 1.607906
# Classifier training loss: -160.620660
# Adversary training loss: 1.607009
# Epoch 49
# -------------------------------
# Classifier validation loss: -160.639905
# Adversary validation loss: 1.607368
# Classifier training loss: -160.602551
# Adversary training loss: 1.606794
# Epoch 50
# -------------------------------
# Classifier validation loss: -160.570712
# Adversary validation loss: 1.606584
# Classifier training loss: -160.612800
# Adversary training loss: 1.606899
# Done!

# %%
fig, ax1 = plt.subplots()

best_epoch = np.argmin(diff_scores)+1



#ax1.plot(np.arange(len(Training_losses_adv))+1, Training_losses_adv, 'k-', label='Training Adversary')
ax1.plot(np.arange(len(Validation_losses_adv))+1, Validation_losses_adv, 'k-', label='Validation Adversary')

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Adversary Loss', color='k')
ax1.tick_params(axis='y', labelcolor='k')

ax2 = ax1.twinx()

#ax2.plot(np.arange(len(Training_losses_clas))+1, Training_losses_clas, 'r-', label='Training Classifier')
ax2.plot(np.arange(len(Validation_losses_clas))+1, Validation_losses_clas, 'r-', label='Validation Classifier')
ax2.axvline(best_epoch,label="Final model stopped here",color='k')

ax2.set_ylabel('Classifier Loss', color='r')
ax2.tick_params(axis='y', labelcolor='r')

# %% [markdown]
# ## Test adversarially trained models

# %%
# Now test the pretrained model
test_pred = mytools.test_clas(test_loader, final_clas_adv, device)
test_pred=torch.sigmoid(torch.tensor(test_pred)).numpy()


fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_test, test_pred, pos_label=1)
auc_test = sklearn.metrics.auc(fpr, tpr)
print(f'Test AUROC: {auc_test:0.4f}')

plt.plot(fpr, tpr, label=f'Test AUROC: {auc_test:0.4f}')
plt.xlabel('FPR')
plt.ylabel('TPR')
plt.legend()
# Out:
# Test AUROC: 0.9911

# %%
df_test["Class_adv"] = test_pred
df_bkg = df_test.loc[ (df_test.type == 'tritrig') | (df_test.type == 'wab')]
per = np.percentile(df_bkg['Class_adv'],99)
df_cut = df_bkg[df_bkg['Class_adv']>per].reset_index(drop=True)
x_vals = 1000*df_cut.InvM

plt.figure()
plt.hist(1000*df_bkg.InvM, bins=np.arange(980,1250,1), histtype='step', label='No selection', density=True)
plt.hist(x_vals, bins=np.arange(980,1250,1), histtype='step', label= '99 percent selection', density=True)
plt.axvline(1019.461, color='k', linestyle='dashed', linewidth=1, label='PDG phi mass')
plt.xlabel('Invariant Mass [MeV]')
plt.ylabel('Normalized Counts')
plt.legend()

# %%
x1 = 1000* df_bkg.InvM.values
x2 = 1000*df_cut.InvM.values

N, edges = np.histogram(x1, bins=np.arange(980,1250,1), density=False)
M, edges = np.histogram(x2, bins=np.arange(980,1250,1), density=False)

N2 = N[(N > 0) & (M > 0)]
M2 = M[(N > 0) & (M > 0)]

diff_score = np.mean(np.abs(N2/np.sum(N)-M2/np.sum(M)) / (np.sqrt(N2)/np.sum(N) + np.sqrt(M2)/np.sum(M) ))

print(diff_score)

N = len(df_test.loc[ ((df_test.type == 'tritrig') | (df_test.type == 'wab')) & (df_test.InvM < (1.019 + 0.01) )  & (df_test.InvM > (1.019 - 0.01) ) & ( df_test['Class_adv']>per ) ] )
S = len(df_test.loc[ (df_test.type == 'phiKK') & (df_test.InvM < (1.019 + 0.01) )  & (df_test.InvM > (1.019 - 0.01) ) & ( df_test['Class_adv']>per )  ] )

print(S/N)
# Out:
# 0.5873438148721202
# 1.7118644067796611

# %%
df_test["Class_adv"] = test_pred

# %%
adv_test_pred = mytools.test_adv(test_adv_loader, final_classifier, final_adv_adv, Num_classes, device)
adv_test_pred = torch.softmax(torch.tensor(adv_test_pred),dim=1).numpy()
score=0

for i in range(adv_test_pred.shape[1]):
    fpr, tpr, thresholds = sklearn.metrics.roc_curve(y_adv_test[:,i], adv_test_pred[:,i], pos_label=1)
    auc_test = sklearn.metrics.auc(fpr, tpr)
    print("class " + str(i)+ " test auc score: " + str(auc_test))

    plt.plot(fpr, tpr, label='Class '+str(i)+' Test AUROC: '+str(auc_test))
    plt.xlabel('FPR')
    plt.ylabel('TPR')
    plt.legend()

    score += auc_test

print("average score: ", score/adv_test_pred.shape[1])
# Out:
# class 0 test auc score: 0.4990540588348078
# class 1 test auc score: 0.49891342493974233
# class 2 test auc score: 0.4988423665303249
# class 3 test auc score: 0.4984891800086925
# class 4 test auc score: 0.503132764329141
# average score:  0.49968635892854174

# %%
# Save the adversarially trained models
torch.save(final_clas_adv.state_dict(), "/Users/mghrear/data/ML_data/patch/classifier_adv_2021_v9_pass5_FakeGen_1pt05_kaon_run"+str(run)+"QualCuts.pt")
torch.save(final_adv_adv.state_dict(), "/Users/mghrear/data/ML_data/patch/adversary_adv_2021_v9_pass5_FakeGen_1pt05_kaon_run"+str(run)+"QualCuts.pt")
